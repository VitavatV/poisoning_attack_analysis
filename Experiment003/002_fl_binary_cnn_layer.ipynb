# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    model = MNISTNet().to(device)
    model.load_state_dict(global_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end]
            yb = y_c_tensor[start:end]
            outputs = model(xb)
            preds = (outputs >= 0.5).float()
            loss = binary_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # Return a deepcopy to avoid issues with state_dict references
    return copy.deepcopy(model.state_dict()), X_c_tensor.size(0), yb, outputs, preds

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 1
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "./data/mnist_binary_poison/train"
TEST_PATH = "./data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Poison n list: [25, 43, 67]

# %%
NODE = 1
for LAYER in [3,4,5,6]: # LAYER - (first,last)
        
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            
            # 1. Define the stack of hidden layers (Linear + ReLU)
            # Use a list comprehension to create the (Linear, ReLU) pairs
            hidden_layers = []
            for _ in range(LAYER-2):
                hidden_layers.append(nn.Conv2d(NODE, NODE, kernel_size=3, padding=1))
                hidden_layers.append(nn.ReLU())
                
            # 2. Use nn.Sequential to wrap the entire dynamic stack
            self.dynamic_hidden = nn.Sequential(*hidden_layers)
            
            # Other layers
            self.conv1 = nn.Conv2d(1, NODE, kernel_size=3, padding=1) # 28x28
            self.pool = nn.MaxPool2d(2, 2) # 14x14
            self.fc1 = nn.Linear(NODE * 14 * 14, 1)
            self.relu = nn.ReLU()

        def forward(self, x):
            x = x.view(-1, 1, 28, 28)
            x = self.pool(self.relu(self.conv1(x)))
            x = nn.ReLU()(x) # We need to manually apply ReLU here
            
            # Dynamic Hidden Layers (Executed sequentially without a loop)
            x = self.dynamic_hidden(x)
                
            # Output Layer
            x = x.view(x.size(0), -1)
            x = self.fc1(x)
            x = torch.sigmoid(x)
            
            return x

    BATCH_SIZE_list = []
    temp_bs = BATCH_SIZE
    while temp_bs >= 1:
        BATCH_SIZE_list.append(temp_bs)
        temp_bs = temp_bs // 2

    for rev in range(3):

        global_model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"FL_ModelN{NODE}L{LAYER}_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                torch.save(global_model, os.path.join(save_path,'model_init.pt'))
                global_weights = global_model.state_dict()

                records = []

                X_train_tensor = {}
                y_train_tensor = {}
                for i in range(N_HONEST):
                    X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"honest_{i}"] = X_c_tensor
                    y_train_tensor[f"honest_{i}"] = y_c_tensor
                for i in range(i_poisoned):
                    X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"poison_{i}"] = X_c_tensor
                    y_train_tensor[f"poison_{i}"] = y_c_tensor

                # Training loop
                for round in range(ROUNDS):
                    # Prepare arguments for honest clients
                    
                    #randomize the training data
                    for i in range(N_HONEST):
                        perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                        X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                        y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                    honest_args = [
                        (
                            X_train_tensor[f"honest_{i}"],
                            y_train_tensor[f"honest_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(N_HONEST)
                    ]

                    # Prepare arguments for poisoned clients
                    
                    #randomize the training data
                    for i in range(i_poisoned):
                        perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                        X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                        y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                    poison_args = [
                        (
                            X_train_tensor[f"poison_{i}"],
                            y_train_tensor[f"poison_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(i_poisoned)
                    ]

                    # Run in parallel
                    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                        honest_results = list(executor.map(train_local_worker, honest_args))
                        poison_results = list(executor.map(train_local_worker, poison_args))

                    local_weights = []
                    local_sizes = []
                    local_y = []
                    local_outputs = []
                    local_preds = []
                    for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                        local_weights.append(l_w)
                        local_sizes.append(l_sz)
                        local_y.extend(l_y)
                        local_outputs.extend(l_out)
                        local_preds.extend(l_pred)
                    loss_train = binary_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                    acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                    # Federated averaging (weighted by client data size)
                    new_weights = {}
                    for key in global_weights.keys():
                        new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                    global_weights = new_weights
                    global_model.load_state_dict(global_weights)

                    # Evaluate
                    global_model.eval()
                    with torch.no_grad():
                        outputs = global_model(X_test_tensor)
                        preds = (outputs > 0.5).float()
                        loss_test = binary_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'round': round, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"round {round}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(global_model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['round'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['round'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 20 round 0: loss_train=0.7156, acc_train=0.4560, loss_test=0.7020, acc_test=0.5000
# poison_percent 20 round 1: loss_train=0.6649, acc_train=0.5040, loss_test=0.6717, acc_test=0.5000
# poison_percent 20 round 2: loss_train=0.6353, acc_train=0.5920, loss_test=0.6338, acc_test=0.5617
# poison_percent 20 round 3: loss_train=0.6265, acc_train=0.7680, loss_test=0.6039, acc_test=0.8306
# poison_percent 20 round 4: loss_train=0.5953, acc_train=0.7920, loss_test=0.5897, acc_test=0.9276
# poison_percent 20 round 5: loss_train=0.6012, acc_train=0.8240, loss_test=0.5807, acc_test=0.9638
# poison_percent 20 round 6: loss_train=0.5972, acc_train=0.8320, loss_test=0.5735, acc_test=0.9816
# poison_percent 20 round 7: loss_train=0.5980, acc_train=0.8320, loss_test=0.5661, acc_test=0.9867
# poison_percent 20 round 8: loss_train=0.5921, acc_train=0.8640, loss_test=0.5587, acc_test=0.9908
# poison_percent 20 round 9: loss_train=0.5830, acc_train=0.8560, loss_test=0.5510, acc_test=0.9923
# poison_percent 20 round 10: loss_train=0.5861, acc_train=0.8160, loss_test=0.5436, acc_test=0.9923
# poison_percent 20 round 11: loss_train=0.5791, acc_train=0.8000, loss_test=0.5361, acc_test=0.9929
# poison_percent 20 round 12: loss_train=0.5768, acc_train=0.8080, loss_test=0.5285, acc_test=0.9923
# poison_percent 20 round 13: loss_train=0.5764, acc_train=0.7920, loss_test=0.5210, acc_test=0.9929
# poison_percent 20 round 14: loss_train=0.5723, acc_train=0.7920, loss_test=0.5135, acc_test=0.9929
# poison_percent 20 round 15: loss_train=0.5570, acc_train=0.8160, loss_test=0.5061, acc_test=0.9929
# poison_percent 20 round 16: loss_train=0.5838, acc_train=0.7680, loss_test=0.4986, acc_test=0.9929
# poison_percent 20 round 17: loss_train=0.5749, acc_train=0.8080, loss_test=0.4911, acc_test=0.9929
# poison_percent 20 round 18: loss_train=0.5530, acc_train=0.7760, loss_test=0.4836, acc_test=0.9929
# poison_percent 20 round 19: loss_train=0.5617, acc_train=0.8000, loss_test=0.4761, acc_test=0.9929
# poison_percent 20 round 20: loss_train=0.5660, acc_train=0.8000, loss_test=0.4686, acc_test=0.9934
# poison_percent 20 round 21: loss_train=0.5750, acc_train=0.7920, loss_test=0.4611, acc_test=0.9934
# poison_percent 20 round 22: loss_train=0.5592, acc_train=0.7920, loss_test=0.4536, acc_test=0.9934
# poison_percent 20 round 23: loss_train=0.5619, acc_train=0.8000, loss_test=0.4462, acc_test=0.9944
# poison_percent 20 round 24: loss_train=0.5650, acc_train=0.7920, loss_test=0.4388, acc_test=0.9944
# poison_percent 20 round 25: loss_train=0.5751, acc_train=0.8080, loss_test=0.4314, acc_test=0.9944
# poison_percent 20 round 26: loss_train=0.5614, acc_train=0.8080, loss_test=0.4240, acc_test=0.9944
# poison_percent 20 round 27: loss_train=0.5261, acc_train=0.8000, loss_test=0.4167, acc_test=0.9944
# poison_percent 20 round 28: loss_train=0.5836, acc_train=0.8000, loss_test=0.4094, acc_test=0.9944
# poison_percent 20 round 29: loss_train=0.5359, acc_train=0.8000, loss_test=0.4021, acc_test=0.9944
# poison_percent 20 round 30: loss_train=0.5288, acc_train=0.8000, loss_test=0.3949, acc_test=0.9949
# poison_percent 20 round 31: loss_train=0.5199, acc_train=0.7920, loss_test=0.3876, acc_test=0.9949
# poison_percent 20 round 32: loss_train=0.5515, acc_train=0.7920, loss_test=0.3805, acc_test=0.9949
# poison_percent 20 round 33: loss_train=0.5405, acc_train=0.7920, loss_test=0.3734, acc_test=0.9949
# poison_percent 20 round 34: loss_train=0.5065, acc_train=0.8080, loss_test=0.3664, acc_test=0.9949
# poison_percent 20 round 35: loss_train=0.5101, acc_train=0.7920, loss_test=0.3594, acc_test=0.9949
# poison_percent 20 round 36: loss_train=0.5302, acc_train=0.8000, loss_test=0.3524, acc_test=0.9964
# poison_percent 20 round 37: loss_train=0.4874, acc_train=0.7920, loss_test=0.3455, acc_test=0.9964
# poison_percent 20 round 38: loss_train=0.5345, acc_train=0.8000, loss_test=0.3386, acc_test=0.9964
# poison_percent 20 round 39: loss_train=0.4936, acc_train=0.8000, loss_test=0.3320, acc_test=0.9964
# poison_percent 20 round 40: loss_train=0.5371, acc_train=0.8000, loss_test=0.3252, acc_test=0.9964
# poison_percent 20 round 41: loss_train=0.4899, acc_train=0.7920, loss_test=0.3186, acc_test=0.9964
# poison_percent 20 round 42: loss_train=0.4932, acc_train=0.8000, loss_test=0.3121, acc_test=0.9964
# poison_percent 20 round 43: loss_train=0.4977, acc_train=0.8000, loss_test=0.3055, acc_test=0.9964
# poison_percent 20 round 44: loss_train=0.5287, acc_train=0.8000, loss_test=0.2992, acc_test=0.9964
# poison_percent 20 round 45: loss_train=0.5113, acc_train=0.7920, loss_test=0.2929, acc_test=0.9969
# poison_percent 20 round 46: loss_train=0.5243, acc_train=0.7920, loss_test=0.2866, acc_test=0.9969
# poison_percent 20 round 47: loss_train=0.5203, acc_train=0.7920, loss_test=0.2805, acc_test=0.9969
# poison_percent 20 round 48: loss_train=0.5114, acc_train=0.8000, loss_test=0.2744, acc_test=0.9969
# poison_percent 20 round 49: loss_train=0.5290, acc_train=0.7840, loss_test=0.2685, acc_test=0.9969
# poison_percent 20 round 50: loss_train=0.5334, acc_train=0.8000, loss_test=0.2626, acc_test=0.9969
# poison_percent 20 round 51: loss_train=0.5231, acc_train=0.8080, loss_test=0.2568, acc_test=0.9969
# poison_percent 20 round 52: loss_train=0.5354, acc_train=0.8000, loss_test=0.2512, acc_test=0.9969
# poison_percent 20 round 53: loss_train=0.5181, acc_train=0.8080, loss_test=0.2456, acc_test=0.9969
# poison_percent 20 round 54: loss_train=0.4780, acc_train=0.8000, loss_test=0.2401, acc_test=0.9969
# poison_percent 20 round 55: loss_train=0.4882, acc_train=0.8000, loss_test=0.2347, acc_test=0.9969
# poison_percent 20 round 56: loss_train=0.5336, acc_train=0.8000, loss_test=0.2294, acc_test=0.9969
# poison_percent 20 round 57: loss_train=0.5039, acc_train=0.7920, loss_test=0.2241, acc_test=0.9969
# poison_percent 20 round 58: loss_train=0.5370, acc_train=0.8080, loss_test=0.2190, acc_test=0.9969
# poison_percent 20 round 59: loss_train=0.5433, acc_train=0.7840, loss_test=0.2139, acc_test=0.9969
# poison_percent 20 round 60: loss_train=0.5317, acc_train=0.8080, loss_test=0.2089, acc_test=0.9974
# poison_percent 20 round 61: loss_train=0.5496, acc_train=0.8000, loss_test=0.2042, acc_test=0.9969
# poison_percent 20 round 62: loss_train=0.5146, acc_train=0.7920, loss_test=0.1994, acc_test=0.9974
# poison_percent 20 round 63: loss_train=0.5481, acc_train=0.7920, loss_test=0.1947, acc_test=0.9974
# poison_percent 20 round 64: loss_train=0.5674, acc_train=0.8000, loss_test=0.1902, acc_test=0.9974
# poison_percent 20 round 65: loss_train=0.5022, acc_train=0.8000, loss_test=0.1856, acc_test=0.9974
# poison_percent 20 round 66: loss_train=0.5508, acc_train=0.8080, loss_test=0.1812, acc_test=0.9974
# poison_percent 20 round 67: loss_train=0.5016, acc_train=0.8080, loss_test=0.1769, acc_test=0.9974
# poison_percent 20 round 68: loss_train=0.5722, acc_train=0.7840, loss_test=0.1726, acc_test=0.9974
# poison_percent 20 round 69: loss_train=0.5641, acc_train=0.8080, loss_test=0.1685, acc_test=0.9974
# poison_percent 20 round 70: loss_train=0.5948, acc_train=0.8000, loss_test=0.1644, acc_test=0.9974
# poison_percent 20 round 71: loss_train=0.5243, acc_train=0.8000, loss_test=0.1604, acc_test=0.9974
# poison_percent 20 round 72: loss_train=0.5359, acc_train=0.8000, loss_test=0.1564, acc_test=0.9974
# poison_percent 20 round 73: loss_train=0.5408, acc_train=0.7840, loss_test=0.1526, acc_test=0.9974
# poison_percent 20 round 74: loss_train=0.5721, acc_train=0.8000, loss_test=0.1489, acc_test=0.9974
# poison_percent 20 round 75: loss_train=0.5681, acc_train=0.8000, loss_test=0.1452, acc_test=0.9974
# poison_percent 20 round 76: loss_train=0.5441, acc_train=0.8080, loss_test=0.1415, acc_test=0.9974
# poison_percent 20 round 77: loss_train=0.5753, acc_train=0.7920, loss_test=0.1380, acc_test=0.9974
# poison_percent 20 round 78: loss_train=0.6029, acc_train=0.7920, loss_test=0.1346, acc_test=0.9974
# poison_percent 20 round 79: loss_train=0.5497, acc_train=0.8000, loss_test=0.1312, acc_test=0.9974
# poison_percent 20 round 80: loss_train=0.5751, acc_train=0.7920, loss_test=0.1280, acc_test=0.9974
# poison_percent 20 round 81: loss_train=0.6201, acc_train=0.8000, loss_test=0.1248, acc_test=0.9974
# poison_percent 20 round 82: loss_train=0.6456, acc_train=0.8000, loss_test=0.1217, acc_test=0.9974
# poison_percent 20 round 83: loss_train=0.5615, acc_train=0.8000, loss_test=0.1186, acc_test=0.9974
# poison_percent 20 round 84: loss_train=0.5374, acc_train=0.8000, loss_test=0.1156, acc_test=0.9974
# poison_percent 20 round 85: loss_train=0.6440, acc_train=0.8000, loss_test=0.1127, acc_test=0.9974
# poison_percent 20 round 86: loss_train=0.5849, acc_train=0.8000, loss_test=0.1098, acc_test=0.9974
# poison_percent 20 round 87: loss_train=0.5951, acc_train=0.7920, loss_test=0.1071, acc_test=0.9974
# poison_percent 20 round 88: loss_train=0.5513, acc_train=0.7920, loss_test=0.1044, acc_test=0.9974
# poison_percent 20 round 89: loss_train=0.6563, acc_train=0.7840, loss_test=0.1017, acc_test=0.9974
# poison_percent 20 round 90: loss_train=0.6187, acc_train=0.8000, loss_test=0.0991, acc_test=0.9974
# poison_percent 20 round 91: loss_train=0.5719, acc_train=0.8080, loss_test=0.0965, acc_test=0.9974
# poison_percent 20 round 92: loss_train=0.7237, acc_train=0.8000, loss_test=0.0941, acc_test=0.9974
# poison_percent 20 round 93: loss_train=0.6470, acc_train=0.8000, loss_test=0.0917, acc_test=0.9974
# poison_percent 20 round 94: loss_train=0.5937, acc_train=0.7920, loss_test=0.0893, acc_test=0.9974
# poison_percent 20 round 95: loss_train=0.6610, acc_train=0.7920, loss_test=0.0871, acc_test=0.9974
# poison_percent 20 round 96: loss_train=0.7328, acc_train=0.8000, loss_test=0.0848, acc_test=0.9974
# poison_percent 20 round 97: loss_train=0.6453, acc_train=0.8000, loss_test=0.0826, acc_test=0.9974
# poison_percent 20 round 98: loss_train=0.6835, acc_train=0.8000, loss_test=0.0805, acc_test=0.9974
# poison_percent 20 round 99: loss_train=0.6685, acc_train=0.8000, loss_test=0.0785, acc_test=0.9974
# Training log saved to ./results\FL_ModelN1L3_Batchsize1_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=0.6829, acc_train=0.5734, loss_test=0.7025, acc_test=0.5000
# poison_percent 30 round 1: loss_train=0.6975, acc_train=0.5175, loss_test=0.7020, acc_test=0.5000
# poison_percent 30 round 2: loss_train=0.6957, acc_train=0.5245, loss_test=0.7016, acc_test=0.5000
# poison_percent 30 round 3: loss_train=0.7025, acc_train=0.4965, loss_test=0.7011, acc_test=0.5000
# poison_percent 30 round 4: loss_train=0.6899, acc_train=0.5455, loss_test=0.7007, acc_test=0.5000
# poison_percent 30 round 5: loss_train=0.6985, acc_train=0.5105, loss_test=0.7003, acc_test=0.5000
# poison_percent 30 round 6: loss_train=0.6788, acc_train=0.5944, loss_test=0.7000, acc_test=0.5000
# poison_percent 30 round 7: loss_train=0.7008, acc_train=0.4965, loss_test=0.6996, acc_test=0.5000
# poison_percent 30 round 8: loss_train=0.6837, acc_train=0.5734, loss_test=0.6993, acc_test=0.5000
# poison_percent 30 round 9: loss_train=0.7062, acc_train=0.4685, loss_test=0.6989, acc_test=0.5000
# poison_percent 30 round 10: loss_train=0.7026, acc_train=0.4825, loss_test=0.6986, acc_test=0.5000
# poison_percent 30 round 11: loss_train=0.6940, acc_train=0.5245, loss_test=0.6983, acc_test=0.5000
# poison_percent 30 round 12: loss_train=0.6979, acc_train=0.5035, loss_test=0.6980, acc_test=0.5000
# poison_percent 30 round 13: loss_train=0.7167, acc_train=0.4056, loss_test=0.6978, acc_test=0.5000
# poison_percent 30 round 14: loss_train=0.7182, acc_train=0.3916, loss_test=0.6976, acc_test=0.5000
# poison_percent 30 round 15: loss_train=0.6958, acc_train=0.5105, loss_test=0.6973, acc_test=0.5000
# poison_percent 30 round 16: loss_train=0.6933, acc_train=0.5245, loss_test=0.6971, acc_test=0.5000
# poison_percent 30 round 17: loss_train=0.7005, acc_train=0.4825, loss_test=0.6969, acc_test=0.5000
# poison_percent 30 round 18: loss_train=0.6988, acc_train=0.4895, loss_test=0.6967, acc_test=0.5000
# poison_percent 30 round 19: loss_train=0.7034, acc_train=0.4615, loss_test=0.6965, acc_test=0.5000
# poison_percent 30 round 20: loss_train=0.7028, acc_train=0.4615, loss_test=0.6963, acc_test=0.5000
# poison_percent 30 round 21: loss_train=0.6929, acc_train=0.5245, loss_test=0.6961, acc_test=0.5000
# poison_percent 30 round 22: loss_train=0.6833, acc_train=0.5874, loss_test=0.6960, acc_test=0.5000
# poison_percent 30 round 23: loss_train=0.6917, acc_train=0.5315, loss_test=0.6958, acc_test=0.5000
# poison_percent 30 round 24: loss_train=0.6946, acc_train=0.5105, loss_test=0.6957, acc_test=0.5000
# poison_percent 30 round 25: loss_train=0.6994, acc_train=0.4755, loss_test=0.6956, acc_test=0.5000
# poison_percent 30 round 26: loss_train=0.7031, acc_train=0.4476, loss_test=0.6954, acc_test=0.5000
# poison_percent 30 round 27: loss_train=0.6974, acc_train=0.4895, loss_test=0.6953, acc_test=0.5000
# poison_percent 30 round 28: loss_train=0.6971, acc_train=0.4895, loss_test=0.6952, acc_test=0.5000
# poison_percent 30 round 29: loss_train=0.6874, acc_train=0.5664, loss_test=0.6951, acc_test=0.5000
# poison_percent 30 round 30: loss_train=0.6952, acc_train=0.5035, loss_test=0.6950, acc_test=0.5000
# poison_percent 30 round 31: loss_train=0.6941, acc_train=0.5105, loss_test=0.6949, acc_test=0.5000
# poison_percent 30 round 32: loss_train=0.6990, acc_train=0.4685, loss_test=0.6948, acc_test=0.5000
# poison_percent 30 round 33: loss_train=0.6963, acc_train=0.4895, loss_test=0.6947, acc_test=0.5000
# poison_percent 30 round 34: loss_train=0.6991, acc_train=0.4615, loss_test=0.6946, acc_test=0.5000
# poison_percent 30 round 35: loss_train=0.6975, acc_train=0.4755, loss_test=0.6946, acc_test=0.5000
# poison_percent 30 round 36: loss_train=0.6940, acc_train=0.5105, loss_test=0.6945, acc_test=0.5000
# poison_percent 30 round 37: loss_train=0.7011, acc_train=0.4406, loss_test=0.6944, acc_test=0.5000
# poison_percent 30 round 38: loss_train=0.6958, acc_train=0.4895, loss_test=0.6944, acc_test=0.5000
# poison_percent 30 round 39: loss_train=0.6879, acc_train=0.5734, loss_test=0.6943, acc_test=0.5000
# poison_percent 30 round 40: loss_train=0.6944, acc_train=0.5035, loss_test=0.6942, acc_test=0.5000
# poison_percent 30 round 41: loss_train=0.6951, acc_train=0.4965, loss_test=0.6942, acc_test=0.5000
# poison_percent 30 round 42: loss_train=0.7010, acc_train=0.4266, loss_test=0.6941, acc_test=0.5000
# poison_percent 30 round 43: loss_train=0.6920, acc_train=0.5315, loss_test=0.6941, acc_test=0.5000
# poison_percent 30 round 44: loss_train=0.7001, acc_train=0.4336, loss_test=0.6940, acc_test=0.5000
# poison_percent 30 round 45: loss_train=0.6993, acc_train=0.4406, loss_test=0.6940, acc_test=0.5000
# poison_percent 30 round 46: loss_train=0.6898, acc_train=0.5594, loss_test=0.6939, acc_test=0.5000
# poison_percent 30 round 47: loss_train=0.6989, acc_train=0.4406, loss_test=0.6939, acc_test=0.5000
# poison_percent 30 round 48: loss_train=0.6982, acc_train=0.4476, loss_test=0.6939, acc_test=0.5000
# poison_percent 30 round 49: loss_train=0.6971, acc_train=0.4615, loss_test=0.6938, acc_test=0.5000
# poison_percent 30 round 50: loss_train=0.6941, acc_train=0.5035, loss_test=0.6938, acc_test=0.5000
# poison_percent 30 round 51: loss_train=0.6930, acc_train=0.5175, loss_test=0.6938, acc_test=0.5000
# poison_percent 30 round 52: loss_train=0.6972, acc_train=0.4545, loss_test=0.6937, acc_test=0.5000
# poison_percent 30 round 53: loss_train=0.6948, acc_train=0.4895, loss_test=0.6937, acc_test=0.5000
# poison_percent 30 round 54: loss_train=0.6936, acc_train=0.5105, loss_test=0.6937, acc_test=0.5000
# poison_percent 30 round 55: loss_train=0.6956, acc_train=0.4755, loss_test=0.6936, acc_test=0.5000
# poison_percent 30 round 56: loss_train=0.6963, acc_train=0.4615, loss_test=0.6936, acc_test=0.5000
# poison_percent 30 round 57: loss_train=0.6945, acc_train=0.4895, loss_test=0.6936, acc_test=0.5000
# poison_percent 30 round 58: loss_train=0.6967, acc_train=0.4545, loss_test=0.6936, acc_test=0.5000
# poison_percent 30 round 59: loss_train=0.6908, acc_train=0.5594, loss_test=0.6935, acc_test=0.5000
# poison_percent 30 round 60: loss_train=0.6958, acc_train=0.4685, loss_test=0.6935, acc_test=0.5000
# poison_percent 30 round 61: loss_train=0.6988, acc_train=0.4126, loss_test=0.6935, acc_test=0.5000
# poison_percent 30 round 62: loss_train=0.6924, acc_train=0.5315, loss_test=0.6935, acc_test=0.5000
# poison_percent 30 round 63: loss_train=0.6915, acc_train=0.5524, loss_test=0.6935, acc_test=0.5000
# poison_percent 30 round 64: loss_train=0.6953, acc_train=0.4755, loss_test=0.6934, acc_test=0.5000
# poison_percent 30 round 65: loss_train=0.6953, acc_train=0.4685, loss_test=0.6934, acc_test=0.5000
# poison_percent 30 round 66: loss_train=0.6956, acc_train=0.4615, loss_test=0.6934, acc_test=0.5000
# poison_percent 30 round 67: loss_train=0.6963, acc_train=0.4545, loss_test=0.6934, acc_test=0.5000
# poison_percent 30 round 68: loss_train=0.6946, acc_train=0.4825, loss_test=0.6934, acc_test=0.5000
# poison_percent 30 round 69: loss_train=0.6926, acc_train=0.5245, loss_test=0.6934, acc_test=0.5000
# poison_percent 30 round 70: loss_train=0.6913, acc_train=0.5594, loss_test=0.6934, acc_test=0.5000
# poison_percent 30 round 71: loss_train=0.6891, acc_train=0.6084, loss_test=0.6934, acc_test=0.5000
# poison_percent 30 round 72: loss_train=0.6945, acc_train=0.4825, loss_test=0.6934, acc_test=0.5000
# poison_percent 30 round 73: loss_train=0.6940, acc_train=0.5035, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 round 74: loss_train=0.6951, acc_train=0.4615, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 round 75: loss_train=0.6953, acc_train=0.4615, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 round 76: loss_train=0.6970, acc_train=0.4196, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 round 77: loss_train=0.6922, acc_train=0.5455, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 round 78: loss_train=0.6964, acc_train=0.4266, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 round 79: loss_train=0.6946, acc_train=0.4755, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 round 80: loss_train=0.6929, acc_train=0.5245, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 round 81: loss_train=0.6940, acc_train=0.4895, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 round 82: loss_train=0.6940, acc_train=0.4895, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 round 83: loss_train=0.6939, acc_train=0.5035, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 round 84: loss_train=0.6953, acc_train=0.4476, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 round 85: loss_train=0.6953, acc_train=0.4476, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 round 86: loss_train=0.6932, acc_train=0.5175, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 round 87: loss_train=0.6923, acc_train=0.5524, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 round 88: loss_train=0.6943, acc_train=0.4755, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 round 89: loss_train=0.6935, acc_train=0.5035, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 round 90: loss_train=0.6928, acc_train=0.5385, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 round 91: loss_train=0.6945, acc_train=0.4825, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 round 92: loss_train=0.6928, acc_train=0.5385, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 round 93: loss_train=0.6941, acc_train=0.4825, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 round 94: loss_train=0.6961, acc_train=0.4056, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 round 95: loss_train=0.6941, acc_train=0.4825, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 round 96: loss_train=0.6954, acc_train=0.4266, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 round 97: loss_train=0.6945, acc_train=0.4685, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 round 98: loss_train=0.6938, acc_train=0.4965, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 round 99: loss_train=0.6922, acc_train=0.5664, loss_test=0.6932, acc_test=0.5000
# Training log saved to ./results\FL_ModelN1L3_Batchsize1_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=0.6459, acc_train=0.5629, loss_test=0.7260, acc_test=0.5000
# poison_percent 40 round 1: loss_train=0.6491, acc_train=0.5269, loss_test=0.7371, acc_test=0.5000
# poison_percent 40 round 2: loss_train=0.6598, acc_train=0.4311, loss_test=0.7453, acc_test=0.5000
# poison_percent 40 round 3: loss_train=0.6162, acc_train=0.5509, loss_test=0.7526, acc_test=0.5000
# poison_percent 40 round 4: loss_train=0.6198, acc_train=0.5629, loss_test=0.7584, acc_test=0.5000
# poison_percent 40 round 5: loss_train=0.6328, acc_train=0.5150, loss_test=0.7640, acc_test=0.5000
# poison_percent 40 round 6: loss_train=0.6294, acc_train=0.4910, loss_test=0.7686, acc_test=0.5000
# poison_percent 40 round 7: loss_train=0.6189, acc_train=0.4790, loss_test=0.7730, acc_test=0.5000
# poison_percent 40 round 8: loss_train=0.6007, acc_train=0.5269, loss_test=0.7761, acc_test=0.5000
# poison_percent 40 round 9: loss_train=0.6174, acc_train=0.5329, loss_test=0.7798, acc_test=0.5000
# poison_percent 40 round 10: loss_train=0.6078, acc_train=0.4970, loss_test=0.7834, acc_test=0.5000
# poison_percent 40 round 11: loss_train=0.6074, acc_train=0.4970, loss_test=0.7856, acc_test=0.5000
# poison_percent 40 round 12: loss_train=0.6018, acc_train=0.5150, loss_test=0.7887, acc_test=0.5000
# poison_percent 40 round 13: loss_train=0.6060, acc_train=0.5928, loss_test=0.7922, acc_test=0.5000
# poison_percent 40 round 14: loss_train=0.5999, acc_train=0.5928, loss_test=0.7966, acc_test=0.0015
# poison_percent 40 round 15: loss_train=0.6036, acc_train=0.6407, loss_test=0.7975, acc_test=0.0020
# poison_percent 40 round 16: loss_train=0.6078, acc_train=0.7066, loss_test=0.8002, acc_test=0.0026
# poison_percent 40 round 17: loss_train=0.5878, acc_train=0.6228, loss_test=0.8023, acc_test=0.0026
# poison_percent 40 round 18: loss_train=0.5827, acc_train=0.6647, loss_test=0.8053, acc_test=0.0026
# poison_percent 40 round 19: loss_train=0.5898, acc_train=0.6467, loss_test=0.8091, acc_test=0.0026
# poison_percent 40 round 20: loss_train=0.5920, acc_train=0.6707, loss_test=0.8122, acc_test=0.0036
# poison_percent 40 round 21: loss_train=0.5965, acc_train=0.6946, loss_test=0.8141, acc_test=0.0036
# poison_percent 40 round 22: loss_train=0.5935, acc_train=0.7126, loss_test=0.8166, acc_test=0.0036
# poison_percent 40 round 23: loss_train=0.5977, acc_train=0.6707, loss_test=0.8202, acc_test=0.0041
# poison_percent 40 round 24: loss_train=0.5883, acc_train=0.6886, loss_test=0.8235, acc_test=0.0041
# poison_percent 40 round 25: loss_train=0.5909, acc_train=0.6228, loss_test=0.8275, acc_test=0.0041
# poison_percent 40 round 26: loss_train=0.5641, acc_train=0.7066, loss_test=0.8309, acc_test=0.0046
# poison_percent 40 round 27: loss_train=0.5792, acc_train=0.7784, loss_test=0.8338, acc_test=0.0051
# poison_percent 40 round 28: loss_train=0.5830, acc_train=0.6826, loss_test=0.8365, acc_test=0.0051
# poison_percent 40 round 29: loss_train=0.5967, acc_train=0.6168, loss_test=0.8387, acc_test=0.0051
# poison_percent 40 round 30: loss_train=0.5581, acc_train=0.6826, loss_test=0.8420, acc_test=0.0051
# poison_percent 40 round 31: loss_train=0.5765, acc_train=0.6826, loss_test=0.8446, acc_test=0.0051
# poison_percent 40 round 32: loss_train=0.5533, acc_train=0.6946, loss_test=0.8484, acc_test=0.0051
# poison_percent 40 round 33: loss_train=0.5599, acc_train=0.7365, loss_test=0.8512, acc_test=0.0051
# poison_percent 40 round 34: loss_train=0.5622, acc_train=0.7066, loss_test=0.8546, acc_test=0.0051
# poison_percent 40 round 35: loss_train=0.5627, acc_train=0.6886, loss_test=0.8542, acc_test=0.0051
# poison_percent 40 round 36: loss_train=0.5601, acc_train=0.6886, loss_test=0.8556, acc_test=0.0056
# poison_percent 40 round 37: loss_train=0.5598, acc_train=0.7066, loss_test=0.8596, acc_test=0.0051
# poison_percent 40 round 38: loss_train=0.5755, acc_train=0.6946, loss_test=0.8615, acc_test=0.0056
# poison_percent 40 round 39: loss_train=0.5698, acc_train=0.6886, loss_test=0.8631, acc_test=0.0056
# poison_percent 40 round 40: loss_train=0.5675, acc_train=0.6886, loss_test=0.8650, acc_test=0.0061
# poison_percent 40 round 41: loss_train=0.5655, acc_train=0.6766, loss_test=0.8690, acc_test=0.0061
# poison_percent 40 round 42: loss_train=0.5693, acc_train=0.7006, loss_test=0.8739, acc_test=0.0061
# poison_percent 40 round 43: loss_train=0.5586, acc_train=0.6766, loss_test=0.8771, acc_test=0.0061
# poison_percent 40 round 44: loss_train=0.5618, acc_train=0.6707, loss_test=0.8777, acc_test=0.0066
# poison_percent 40 round 45: loss_train=0.5804, acc_train=0.6347, loss_test=0.8840, acc_test=0.0066
# poison_percent 40 round 46: loss_train=0.5833, acc_train=0.6168, loss_test=0.8855, acc_test=0.0066
# poison_percent 40 round 47: loss_train=0.5553, acc_train=0.6946, loss_test=0.8860, acc_test=0.0066
# poison_percent 40 round 48: loss_train=0.5415, acc_train=0.7665, loss_test=0.8885, acc_test=0.0066
# poison_percent 40 round 49: loss_train=0.5558, acc_train=0.7006, loss_test=0.8910, acc_test=0.0066
# poison_percent 40 round 50: loss_train=0.5458, acc_train=0.7126, loss_test=0.8936, acc_test=0.0066
# poison_percent 40 round 51: loss_train=0.5621, acc_train=0.7126, loss_test=0.8952, acc_test=0.0066
# poison_percent 40 round 52: loss_train=0.5519, acc_train=0.6826, loss_test=0.8989, acc_test=0.0066
# poison_percent 40 round 53: loss_train=0.5590, acc_train=0.6826, loss_test=0.9003, acc_test=0.0066
# poison_percent 40 round 54: loss_train=0.5635, acc_train=0.7126, loss_test=0.9010, acc_test=0.0066
# poison_percent 40 round 55: loss_train=0.5512, acc_train=0.6826, loss_test=0.9034, acc_test=0.0066
# poison_percent 40 round 56: loss_train=0.5357, acc_train=0.7725, loss_test=0.9103, acc_test=0.0066
# poison_percent 40 round 57: loss_train=0.5534, acc_train=0.7425, loss_test=0.9129, acc_test=0.0066
# poison_percent 40 round 58: loss_train=0.5532, acc_train=0.6527, loss_test=0.9127, acc_test=0.0066
# poison_percent 40 round 59: loss_train=0.5677, acc_train=0.6527, loss_test=0.9133, acc_test=0.0066
# poison_percent 40 round 60: loss_train=0.5605, acc_train=0.6647, loss_test=0.9147, acc_test=0.0066
# poison_percent 40 round 61: loss_train=0.5722, acc_train=0.6946, loss_test=0.9191, acc_test=0.0066
# poison_percent 40 round 62: loss_train=0.5654, acc_train=0.7246, loss_test=0.9196, acc_test=0.0071
# poison_percent 40 round 63: loss_train=0.5466, acc_train=0.6946, loss_test=0.9221, acc_test=0.0071
# poison_percent 40 round 64: loss_train=0.5481, acc_train=0.7365, loss_test=0.9262, acc_test=0.0071
# poison_percent 40 round 65: loss_train=0.5486, acc_train=0.6826, loss_test=0.9271, acc_test=0.0071
# poison_percent 40 round 66: loss_train=0.5504, acc_train=0.7365, loss_test=0.9298, acc_test=0.0071
# poison_percent 40 round 67: loss_train=0.5401, acc_train=0.7006, loss_test=0.9322, acc_test=0.0071
# poison_percent 40 round 68: loss_train=0.5442, acc_train=0.7126, loss_test=0.9337, acc_test=0.0071
# poison_percent 40 round 69: loss_train=0.5257, acc_train=0.7246, loss_test=0.9302, acc_test=0.0082
# poison_percent 40 round 70: loss_train=0.5517, acc_train=0.6946, loss_test=0.9352, acc_test=0.0082
# poison_percent 40 round 71: loss_train=0.5343, acc_train=0.6886, loss_test=0.9391, acc_test=0.0082
# poison_percent 40 round 72: loss_train=0.5633, acc_train=0.6707, loss_test=0.9398, acc_test=0.0082
# poison_percent 40 round 73: loss_train=0.5540, acc_train=0.6886, loss_test=0.9450, acc_test=0.0082
# poison_percent 40 round 74: loss_train=0.5422, acc_train=0.7126, loss_test=0.9510, acc_test=0.0082
# poison_percent 40 round 75: loss_train=0.5401, acc_train=0.7006, loss_test=0.9477, acc_test=0.0082
# poison_percent 40 round 76: loss_train=0.5376, acc_train=0.6946, loss_test=0.9518, acc_test=0.0082
# poison_percent 40 round 77: loss_train=0.5543, acc_train=0.6886, loss_test=0.9536, acc_test=0.0082
# poison_percent 40 round 78: loss_train=0.5570, acc_train=0.6766, loss_test=0.9495, acc_test=0.0102
# poison_percent 40 round 79: loss_train=0.5533, acc_train=0.6707, loss_test=0.9499, acc_test=0.0102
# poison_percent 40 round 80: loss_train=0.5439, acc_train=0.6826, loss_test=0.9529, acc_test=0.0102
# poison_percent 40 round 81: loss_train=0.5256, acc_train=0.7186, loss_test=0.9547, acc_test=0.0112
# poison_percent 40 round 82: loss_train=0.5492, acc_train=0.6766, loss_test=0.9619, acc_test=0.0097
# poison_percent 40 round 83: loss_train=0.5352, acc_train=0.7246, loss_test=0.9639, acc_test=0.0102
# poison_percent 40 round 84: loss_train=0.5380, acc_train=0.7066, loss_test=0.9603, acc_test=0.0133
# poison_percent 40 round 85: loss_train=0.5296, acc_train=0.6946, loss_test=0.9596, acc_test=0.0138
# poison_percent 40 round 86: loss_train=0.5393, acc_train=0.7246, loss_test=0.9640, acc_test=0.0138
# poison_percent 40 round 87: loss_train=0.5275, acc_train=0.7186, loss_test=0.9611, acc_test=0.0148
# poison_percent 40 round 88: loss_train=0.5332, acc_train=0.7006, loss_test=0.9622, acc_test=0.0148
# poison_percent 40 round 89: loss_train=0.5302, acc_train=0.7066, loss_test=0.9656, acc_test=0.0148
# poison_percent 40 round 90: loss_train=0.5584, acc_train=0.7066, loss_test=0.9645, acc_test=0.0148
# poison_percent 40 round 91: loss_train=0.5289, acc_train=0.6826, loss_test=0.9670, acc_test=0.0148
# poison_percent 40 round 92: loss_train=0.5379, acc_train=0.7305, loss_test=0.9709, acc_test=0.0148
# poison_percent 40 round 93: loss_train=0.5256, acc_train=0.6766, loss_test=0.9686, acc_test=0.0163
# poison_percent 40 round 94: loss_train=0.5667, acc_train=0.6647, loss_test=0.9743, acc_test=0.0153
# poison_percent 40 round 95: loss_train=0.5377, acc_train=0.6826, loss_test=0.9776, acc_test=0.0153
# poison_percent 40 round 96: loss_train=0.5503, acc_train=0.6527, loss_test=0.9797, acc_test=0.0163
# poison_percent 40 round 97: loss_train=0.5516, acc_train=0.6886, loss_test=0.9832, acc_test=0.0163
# poison_percent 40 round 98: loss_train=0.5804, acc_train=0.6707, loss_test=0.9779, acc_test=0.0179
# poison_percent 40 round 99: loss_train=0.5761, acc_train=0.6527, loss_test=0.9776, acc_test=0.0184
# Training log saved to ./results\FL_ModelN1L3_Batchsize1_rev0\poisoned_40percent\poisoned_40percent.csv
# poison_percent 20 round 0: loss_train=0.7057, acc_train=0.5280, loss_test=0.7175, acc_test=0.5000
# poison_percent 20 round 1: loss_train=0.6944, acc_train=0.5520, loss_test=0.7163, acc_test=0.5000
# poison_percent 20 round 2: loss_train=0.7036, acc_train=0.5280, loss_test=0.7152, acc_test=0.5000
# poison_percent 20 round 3: loss_train=0.6965, acc_train=0.5440, loss_test=0.7140, acc_test=0.5000
# poison_percent 20 round 4: loss_train=0.7085, acc_train=0.5120, loss_test=0.7130, acc_test=0.5000
# poison_percent 20 round 5: loss_train=0.7078, acc_train=0.5120, loss_test=0.7120, acc_test=0.5000
# poison_percent 20 round 6: loss_train=0.7102, acc_train=0.5040, loss_test=0.7110, acc_test=0.5000
# poison_percent 20 round 7: loss_train=0.7296, acc_train=0.4480, loss_test=0.7101, acc_test=0.5000
# poison_percent 20 round 8: loss_train=0.7257, acc_train=0.4560, loss_test=0.7092, acc_test=0.5000
# poison_percent 20 round 9: loss_train=0.7019, acc_train=0.5200, loss_test=0.7084, acc_test=0.5000
# poison_percent 20 round 10: loss_train=0.6714, acc_train=0.6080, loss_test=0.7075, acc_test=0.5000
# poison_percent 20 round 11: loss_train=0.7002, acc_train=0.5200, loss_test=0.7068, acc_test=0.5000
# poison_percent 20 round 12: loss_train=0.7389, acc_train=0.4000, loss_test=0.7061, acc_test=0.5000
# poison_percent 20 round 13: loss_train=0.6796, acc_train=0.5840, loss_test=0.7055, acc_test=0.5000
# poison_percent 20 round 14: loss_train=0.7213, acc_train=0.4480, loss_test=0.7048, acc_test=0.5000
# poison_percent 20 round 15: loss_train=0.6985, acc_train=0.5200, loss_test=0.7042, acc_test=0.5000
# poison_percent 20 round 16: loss_train=0.6843, acc_train=0.5680, loss_test=0.7036, acc_test=0.5000
# poison_percent 20 round 17: loss_train=0.6731, acc_train=0.6080, loss_test=0.7031, acc_test=0.5000
# poison_percent 20 round 18: loss_train=0.6974, acc_train=0.5200, loss_test=0.7026, acc_test=0.5000
# poison_percent 20 round 19: loss_train=0.6952, acc_train=0.5280, loss_test=0.7021, acc_test=0.5000
# poison_percent 20 round 20: loss_train=0.6970, acc_train=0.5200, loss_test=0.7016, acc_test=0.5000
# poison_percent 20 round 21: loss_train=0.6887, acc_train=0.5520, loss_test=0.7012, acc_test=0.5000
# poison_percent 20 round 22: loss_train=0.6980, acc_train=0.5120, loss_test=0.7007, acc_test=0.5000
# poison_percent 20 round 23: loss_train=0.6842, acc_train=0.5680, loss_test=0.7004, acc_test=0.5000
# poison_percent 20 round 24: loss_train=0.7128, acc_train=0.4480, loss_test=0.7000, acc_test=0.5000
# poison_percent 20 round 25: loss_train=0.7046, acc_train=0.4800, loss_test=0.6996, acc_test=0.5000
# poison_percent 20 round 26: loss_train=0.7132, acc_train=0.4400, loss_test=0.6993, acc_test=0.5000
# poison_percent 20 round 27: loss_train=0.6952, acc_train=0.5200, loss_test=0.6989, acc_test=0.5000
# poison_percent 20 round 28: loss_train=0.7018, acc_train=0.4880, loss_test=0.6987, acc_test=0.5000
# poison_percent 20 round 29: loss_train=0.6980, acc_train=0.5040, loss_test=0.6983, acc_test=0.5000
# poison_percent 20 round 30: loss_train=0.6931, acc_train=0.5280, loss_test=0.6981, acc_test=0.5000
# poison_percent 20 round 31: loss_train=0.7069, acc_train=0.4560, loss_test=0.6978, acc_test=0.5000
# poison_percent 20 round 32: loss_train=0.6973, acc_train=0.5040, loss_test=0.6976, acc_test=0.5000
# poison_percent 20 round 33: loss_train=0.7074, acc_train=0.4480, loss_test=0.6974, acc_test=0.5000
# poison_percent 20 round 34: loss_train=0.6910, acc_train=0.5360, loss_test=0.6971, acc_test=0.5000
# poison_percent 20 round 35: loss_train=0.6882, acc_train=0.5520, loss_test=0.6969, acc_test=0.5000
# poison_percent 20 round 36: loss_train=0.6964, acc_train=0.5040, loss_test=0.6967, acc_test=0.5000
# poison_percent 20 round 37: loss_train=0.6935, acc_train=0.5200, loss_test=0.6965, acc_test=0.5000
# poison_percent 20 round 38: loss_train=0.6885, acc_train=0.5520, loss_test=0.6963, acc_test=0.5000
# poison_percent 20 round 39: loss_train=0.7033, acc_train=0.4560, loss_test=0.6961, acc_test=0.5000
# poison_percent 20 round 40: loss_train=0.6912, acc_train=0.5360, loss_test=0.6959, acc_test=0.5000
# poison_percent 20 round 41: loss_train=0.6992, acc_train=0.4800, loss_test=0.6958, acc_test=0.5000
# poison_percent 20 round 42: loss_train=0.7059, acc_train=0.4320, loss_test=0.6957, acc_test=0.5000
# poison_percent 20 round 43: loss_train=0.6890, acc_train=0.5520, loss_test=0.6955, acc_test=0.5000
# poison_percent 20 round 44: loss_train=0.6932, acc_train=0.5200, loss_test=0.6954, acc_test=0.5000
# poison_percent 20 round 45: loss_train=0.6964, acc_train=0.4960, loss_test=0.6953, acc_test=0.5000
# poison_percent 20 round 46: loss_train=0.6880, acc_train=0.5600, loss_test=0.6952, acc_test=0.5000
# poison_percent 20 round 47: loss_train=0.6911, acc_train=0.5360, loss_test=0.6950, acc_test=0.5000
# poison_percent 20 round 48: loss_train=0.6948, acc_train=0.5040, loss_test=0.6949, acc_test=0.5000
# poison_percent 20 round 49: loss_train=0.6940, acc_train=0.5120, loss_test=0.6949, acc_test=0.5000
# poison_percent 20 round 50: loss_train=0.6975, acc_train=0.4800, loss_test=0.6948, acc_test=0.5000
# poison_percent 20 round 51: loss_train=0.6902, acc_train=0.5440, loss_test=0.6947, acc_test=0.5000
# poison_percent 20 round 52: loss_train=0.6946, acc_train=0.5040, loss_test=0.6946, acc_test=0.5000
# poison_percent 20 round 53: loss_train=0.6948, acc_train=0.5040, loss_test=0.6945, acc_test=0.5000
# poison_percent 20 round 54: loss_train=0.6987, acc_train=0.4640, loss_test=0.6945, acc_test=0.5000
# poison_percent 20 round 55: loss_train=0.6944, acc_train=0.5040, loss_test=0.6944, acc_test=0.5000
# poison_percent 20 round 56: loss_train=0.6929, acc_train=0.5200, loss_test=0.6943, acc_test=0.5000
# poison_percent 20 round 57: loss_train=0.6939, acc_train=0.5120, loss_test=0.6943, acc_test=0.5000
# poison_percent 20 round 58: loss_train=0.7033, acc_train=0.4080, loss_test=0.6942, acc_test=0.5000
# poison_percent 20 round 59: loss_train=0.6942, acc_train=0.5040, loss_test=0.6941, acc_test=0.5000
# poison_percent 20 round 60: loss_train=0.6921, acc_train=0.5280, loss_test=0.6941, acc_test=0.5000
# poison_percent 20 round 61: loss_train=0.6974, acc_train=0.4640, loss_test=0.6940, acc_test=0.5000
# poison_percent 20 round 62: loss_train=0.6942, acc_train=0.5040, loss_test=0.6940, acc_test=0.5000
# poison_percent 20 round 63: loss_train=0.6968, acc_train=0.4720, loss_test=0.6940, acc_test=0.5000
# poison_percent 20 round 64: loss_train=0.6984, acc_train=0.4480, loss_test=0.6939, acc_test=0.5000
# poison_percent 20 round 65: loss_train=0.6938, acc_train=0.5040, loss_test=0.6939, acc_test=0.5000
# poison_percent 20 round 66: loss_train=0.6948, acc_train=0.4960, loss_test=0.6938, acc_test=0.5000
# poison_percent 20 round 67: loss_train=0.6947, acc_train=0.4960, loss_test=0.6938, acc_test=0.5000
# poison_percent 20 round 68: loss_train=0.6944, acc_train=0.4960, loss_test=0.6938, acc_test=0.5000
# poison_percent 20 round 69: loss_train=0.6890, acc_train=0.5760, loss_test=0.6937, acc_test=0.5000
# poison_percent 20 round 70: loss_train=0.6950, acc_train=0.4880, loss_test=0.6937, acc_test=0.5000
# poison_percent 20 round 71: loss_train=0.6911, acc_train=0.5440, loss_test=0.6937, acc_test=0.5000
# poison_percent 20 round 72: loss_train=0.6942, acc_train=0.4960, loss_test=0.6937, acc_test=0.5000
# poison_percent 20 round 73: loss_train=0.6905, acc_train=0.5600, loss_test=0.6936, acc_test=0.5000
# poison_percent 20 round 74: loss_train=0.6936, acc_train=0.5120, loss_test=0.6936, acc_test=0.5000
# poison_percent 20 round 75: loss_train=0.6974, acc_train=0.4480, loss_test=0.6936, acc_test=0.5000
# poison_percent 20 round 76: loss_train=0.6947, acc_train=0.4880, loss_test=0.6936, acc_test=0.5000
# poison_percent 20 round 77: loss_train=0.6956, acc_train=0.4720, loss_test=0.6935, acc_test=0.5000
# poison_percent 20 round 78: loss_train=0.6957, acc_train=0.4720, loss_test=0.6935, acc_test=0.5000
# poison_percent 20 round 79: loss_train=0.6938, acc_train=0.5040, loss_test=0.6935, acc_test=0.5000
# poison_percent 20 round 80: loss_train=0.6932, acc_train=0.5120, loss_test=0.6935, acc_test=0.5000
# poison_percent 20 round 81: loss_train=0.6957, acc_train=0.4640, loss_test=0.6935, acc_test=0.5000
# poison_percent 20 round 82: loss_train=0.6937, acc_train=0.5040, loss_test=0.6934, acc_test=0.5000
# poison_percent 20 round 83: loss_train=0.6922, acc_train=0.5360, loss_test=0.6934, acc_test=0.5000
# poison_percent 20 round 84: loss_train=0.6962, acc_train=0.4480, loss_test=0.6934, acc_test=0.5000
# poison_percent 20 round 85: loss_train=0.6927, acc_train=0.5280, loss_test=0.6934, acc_test=0.5000
# poison_percent 20 round 86: loss_train=0.6938, acc_train=0.5040, loss_test=0.6934, acc_test=0.5000
# poison_percent 20 round 87: loss_train=0.6935, acc_train=0.5120, loss_test=0.6934, acc_test=0.5000
# poison_percent 20 round 88: loss_train=0.6914, acc_train=0.5600, loss_test=0.6934, acc_test=0.5000
# poison_percent 20 round 89: loss_train=0.6921, acc_train=0.5520, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 round 90: loss_train=0.6949, acc_train=0.4720, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 round 91: loss_train=0.6958, acc_train=0.4480, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 round 92: loss_train=0.6937, acc_train=0.5040, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 round 93: loss_train=0.6937, acc_train=0.5120, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 round 94: loss_train=0.6947, acc_train=0.4720, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 round 95: loss_train=0.6938, acc_train=0.5040, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 round 96: loss_train=0.6917, acc_train=0.5600, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 round 97: loss_train=0.6929, acc_train=0.5200, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 round 98: loss_train=0.6916, acc_train=0.5680, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 round 99: loss_train=0.6941, acc_train=0.4880, loss_test=0.6933, acc_test=0.5000
# Training log saved to ./results\FL_ModelN1L3_Batchsize1_rev1\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=0.8048, acc_train=0.4615, loss_test=0.7731, acc_test=0.5000
# poison_percent 30 round 1: loss_train=0.8224, acc_train=0.4336, loss_test=0.7693, acc_test=0.5000
# poison_percent 30 round 2: loss_train=0.7313, acc_train=0.5455, loss_test=0.7658, acc_test=0.5000
# poison_percent 30 round 3: loss_train=0.7813, acc_train=0.4755, loss_test=0.7624, acc_test=0.5000
# poison_percent 30 round 4: loss_train=0.7620, acc_train=0.4965, loss_test=0.7590, acc_test=0.5000
# poison_percent 30 round 5: loss_train=0.7739, acc_train=0.4755, loss_test=0.7558, acc_test=0.5000
# poison_percent 30 round 6: loss_train=0.7753, acc_train=0.4685, loss_test=0.7529, acc_test=0.5000
# poison_percent 30 round 7: loss_train=0.8387, acc_train=0.3706, loss_test=0.7501, acc_test=0.5000
# poison_percent 30 round 8: loss_train=0.7502, acc_train=0.4965, loss_test=0.7473, acc_test=0.5000
# poison_percent 30 round 9: loss_train=0.7473, acc_train=0.4965, loss_test=0.7446, acc_test=0.5000
# poison_percent 30 round 10: loss_train=0.7225, acc_train=0.5315, loss_test=0.7421, acc_test=0.5000
# poison_percent 30 round 11: loss_train=0.7383, acc_train=0.5035, loss_test=0.7397, acc_test=0.5000
# poison_percent 30 round 12: loss_train=0.7359, acc_train=0.5035, loss_test=0.7374, acc_test=0.5000
# poison_percent 30 round 13: loss_train=0.7214, acc_train=0.5245, loss_test=0.7351, acc_test=0.5000
# poison_percent 30 round 14: loss_train=0.7473, acc_train=0.4755, loss_test=0.7331, acc_test=0.5000
# poison_percent 30 round 15: loss_train=0.7527, acc_train=0.4615, loss_test=0.7311, acc_test=0.5000
# poison_percent 30 round 16: loss_train=0.7431, acc_train=0.4755, loss_test=0.7292, acc_test=0.5000
# poison_percent 30 round 17: loss_train=0.7150, acc_train=0.5245, loss_test=0.7274, acc_test=0.5000
# poison_percent 30 round 18: loss_train=0.6885, acc_train=0.5734, loss_test=0.7257, acc_test=0.5000
# poison_percent 30 round 19: loss_train=0.7192, acc_train=0.5105, loss_test=0.7240, acc_test=0.5000
# poison_percent 30 round 20: loss_train=0.7145, acc_train=0.5175, loss_test=0.7225, acc_test=0.5000
# poison_percent 30 round 21: loss_train=0.7232, acc_train=0.4965, loss_test=0.7210, acc_test=0.5000
# poison_percent 30 round 22: loss_train=0.7119, acc_train=0.5175, loss_test=0.7196, acc_test=0.5000
# poison_percent 30 round 23: loss_train=0.7203, acc_train=0.4965, loss_test=0.7182, acc_test=0.5000
# poison_percent 30 round 24: loss_train=0.7375, acc_train=0.4545, loss_test=0.7169, acc_test=0.5000
# poison_percent 30 round 25: loss_train=0.7090, acc_train=0.5175, loss_test=0.7158, acc_test=0.5000
# poison_percent 30 round 26: loss_train=0.7251, acc_train=0.4755, loss_test=0.7146, acc_test=0.5000
# poison_percent 30 round 27: loss_train=0.7099, acc_train=0.5105, loss_test=0.7135, acc_test=0.5000
# poison_percent 30 round 28: loss_train=0.7142, acc_train=0.4965, loss_test=0.7125, acc_test=0.5000
# poison_percent 30 round 29: loss_train=0.7135, acc_train=0.4965, loss_test=0.7115, acc_test=0.5000
# poison_percent 30 round 30: loss_train=0.7201, acc_train=0.4755, loss_test=0.7105, acc_test=0.5000
# poison_percent 30 round 31: loss_train=0.7191, acc_train=0.4755, loss_test=0.7096, acc_test=0.5000
# poison_percent 30 round 32: loss_train=0.7056, acc_train=0.5105, loss_test=0.7088, acc_test=0.5000
# poison_percent 30 round 33: loss_train=0.7123, acc_train=0.4895, loss_test=0.7080, acc_test=0.5000
# poison_percent 30 round 34: loss_train=0.7069, acc_train=0.5035, loss_test=0.7073, acc_test=0.5000
# poison_percent 30 round 35: loss_train=0.7358, acc_train=0.4126, loss_test=0.7065, acc_test=0.5000
# poison_percent 30 round 36: loss_train=0.7164, acc_train=0.4685, loss_test=0.7059, acc_test=0.5000
# poison_percent 30 round 37: loss_train=0.7286, acc_train=0.4266, loss_test=0.7052, acc_test=0.5000
# poison_percent 30 round 38: loss_train=0.6933, acc_train=0.5385, loss_test=0.7046, acc_test=0.5000
# poison_percent 30 round 39: loss_train=0.7138, acc_train=0.4685, loss_test=0.7040, acc_test=0.5000
# poison_percent 30 round 40: loss_train=0.7129, acc_train=0.4685, loss_test=0.7034, acc_test=0.5000
# poison_percent 30 round 41: loss_train=0.7044, acc_train=0.4965, loss_test=0.7029, acc_test=0.5000
# poison_percent 30 round 42: loss_train=0.6906, acc_train=0.5455, loss_test=0.7024, acc_test=0.5000
# poison_percent 30 round 43: loss_train=0.6811, acc_train=0.5804, loss_test=0.7019, acc_test=0.5000
# poison_percent 30 round 44: loss_train=0.6939, acc_train=0.5315, loss_test=0.7015, acc_test=0.5000
# poison_percent 30 round 45: loss_train=0.7006, acc_train=0.5035, loss_test=0.7010, acc_test=0.5000
# poison_percent 30 round 46: loss_train=0.6986, acc_train=0.5105, loss_test=0.7006, acc_test=0.5000
# poison_percent 30 round 47: loss_train=0.7051, acc_train=0.4825, loss_test=0.7002, acc_test=0.5000
# poison_percent 30 round 48: loss_train=0.6961, acc_train=0.5175, loss_test=0.6998, acc_test=0.5000
# poison_percent 30 round 49: loss_train=0.6976, acc_train=0.5105, loss_test=0.6995, acc_test=0.5000
# poison_percent 30 round 50: loss_train=0.7067, acc_train=0.4685, loss_test=0.6992, acc_test=0.5000
# poison_percent 30 round 51: loss_train=0.7061, acc_train=0.4685, loss_test=0.6989, acc_test=0.5000
# poison_percent 30 round 52: loss_train=0.6924, acc_train=0.5315, loss_test=0.6986, acc_test=0.5000
# poison_percent 30 round 53: loss_train=0.6954, acc_train=0.5175, loss_test=0.6983, acc_test=0.5000
# poison_percent 30 round 54: loss_train=0.6950, acc_train=0.5175, loss_test=0.6980, acc_test=0.5000
# poison_percent 30 round 55: loss_train=0.6975, acc_train=0.5035, loss_test=0.6978, acc_test=0.5000
# poison_percent 30 round 56: loss_train=0.6857, acc_train=0.5664, loss_test=0.6975, acc_test=0.5000
# poison_percent 30 round 57: loss_train=0.7049, acc_train=0.4615, loss_test=0.6973, acc_test=0.5000
# poison_percent 30 round 58: loss_train=0.6947, acc_train=0.5175, loss_test=0.6971, acc_test=0.5000
# poison_percent 30 round 59: loss_train=0.6956, acc_train=0.5105, loss_test=0.6969, acc_test=0.5000
# poison_percent 30 round 60: loss_train=0.7003, acc_train=0.4825, loss_test=0.6967, acc_test=0.5000
# poison_percent 30 round 61: loss_train=0.6895, acc_train=0.5455, loss_test=0.6965, acc_test=0.5000
# poison_percent 30 round 62: loss_train=0.7029, acc_train=0.4615, loss_test=0.6963, acc_test=0.5000
# poison_percent 30 round 63: loss_train=0.6960, acc_train=0.5035, loss_test=0.6962, acc_test=0.5000
# poison_percent 30 round 64: loss_train=0.6995, acc_train=0.4825, loss_test=0.6960, acc_test=0.5000
# poison_percent 30 round 65: loss_train=0.7048, acc_train=0.4406, loss_test=0.6959, acc_test=0.5000
# poison_percent 30 round 66: loss_train=0.6987, acc_train=0.4825, loss_test=0.6957, acc_test=0.5000
# poison_percent 30 round 67: loss_train=0.6948, acc_train=0.5105, loss_test=0.6956, acc_test=0.5000
# poison_percent 30 round 68: loss_train=0.7012, acc_train=0.4615, loss_test=0.6955, acc_test=0.5000
# poison_percent 30 round 69: loss_train=0.6963, acc_train=0.4965, loss_test=0.6953, acc_test=0.5000
# poison_percent 30 round 70: loss_train=0.7007, acc_train=0.4615, loss_test=0.6952, acc_test=0.5000
# poison_percent 30 round 71: loss_train=0.7005, acc_train=0.4615, loss_test=0.6951, acc_test=0.5000
# poison_percent 30 round 72: loss_train=0.6943, acc_train=0.5105, loss_test=0.6950, acc_test=0.5000
# poison_percent 30 round 73: loss_train=0.6949, acc_train=0.5035, loss_test=0.6949, acc_test=0.5000
# poison_percent 30 round 74: loss_train=0.6918, acc_train=0.5315, loss_test=0.6948, acc_test=0.5000
# poison_percent 30 round 75: loss_train=0.7010, acc_train=0.4476, loss_test=0.6947, acc_test=0.5000
# poison_percent 30 round 76: loss_train=0.6908, acc_train=0.5385, loss_test=0.6946, acc_test=0.5000
# poison_percent 30 round 77: loss_train=0.6895, acc_train=0.5524, loss_test=0.6945, acc_test=0.5000
