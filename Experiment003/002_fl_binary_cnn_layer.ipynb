# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x
    
# save state_dict + metadata (safe, portable)
def save_model(model, img_size, n_classes, learning_rate, experiment_bs, file_path):

    state = {
        "model_state_dict": model.state_dict(),                     # CPU/GPU tensors okay
        "arch": "MNISTNet",
        "img_size": img_size,
        "num_classes": n_classes,
        "training_args": {"lr": learning_rate, "batch_size": experiment_bs}
    }
    # ensure weights are on CPU to avoid GPU-only pickle issues
    state["model_state_dict"] = {k: v.cpu() for k, v in state["model_state_dict"].items()}
    torch.save(state, file_path)
    
def load_model(file_path, device):

    checkpoint = torch.load(file_path, map_location=device)
    model = MNISTNet().to(device)              # must have MNISTNet class defined/importable
    model.load_state_dict(checkpoint["model_state_dict"])
    model.eval()
    return model

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    # create model on target device
    model = MNISTNet().to(device)
    # ensure weights are mapped to the worker device
    state_on_device = {k: v.to(device) for k, v in global_weights.items()}
    model.load_state_dict(state_on_device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end].to(device)
            yb = y_c_tensor[start:end].to(device)
            outputs = model(xb)
            preds = (outputs >= 0.5).float()
            loss = binary_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # return CPU copies for safe aggregation in main thread
    returned_state = {k: v.detach().cpu() for k, v in model.state_dict().items()}
    return returned_state, X_c_tensor.size(0), yb.detach().cpu(), outputs.detach().cpu(), preds.detach().cpu()

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 32
N_CLASSES = 2

# Set device
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")

DATA_PATH = "./data/mnist_binary_poison/train"
TEST_PATH = "./data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
NODE = 1
for LAYER in [3,4,5,6]: # LAYER - (first,last)
        
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            
            # 1. Define the stack of hidden layers (Linear + ReLU)
            # Use a list comprehension to create the (Linear, ReLU) pairs
            hidden_layers = []
            for _ in range(LAYER-2):
                hidden_layers.append(nn.Conv2d(NODE, NODE, kernel_size=3, padding=1))
                hidden_layers.append(nn.ReLU())
                
            # 2. Use nn.Sequential to wrap the entire dynamic stack
            self.dynamic_hidden = nn.Sequential(*hidden_layers)
            
            # Other layers
            self.conv1 = nn.Conv2d(1, NODE, kernel_size=3, padding=1) # 28x28
            self.pool = nn.MaxPool2d(2, 2) # 14x14
            self.fc1 = nn.Linear(NODE * 14 * 14, 1)
            self.relu = nn.ReLU()

        def forward(self, x):
            x = x.view(-1, 1, 28, 28)
            x = self.pool(self.relu(self.conv1(x)))
            x = nn.ReLU()(x) # We need to manually apply ReLU here
            
            # Dynamic Hidden Layers (Executed sequentially without a loop)
            x = self.dynamic_hidden(x)
                
            # Output Layer
            x = x.view(x.size(0), -1)
            x = self.fc1(x)
            x = torch.sigmoid(x)
            
            return x

    BATCH_SIZE_list = [32]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        global_model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"FL_ModelN{NODE}L{LAYER}_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                # torch.save(model, os.path.join(save_path,'model_init.pt'))
                save_path_name = os.path.join(save_path,'model_init.pt')
                save_model(global_model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)
                
                global_weights = global_model.state_dict()

                records = []

                X_train_tensor = {}
                y_train_tensor = {}
                for i in range(N_HONEST):
                    X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"honest_{i}"] = X_c_tensor
                    y_train_tensor[f"honest_{i}"] = y_c_tensor
                for i in range(i_poisoned):
                    X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"poison_{i}"] = X_c_tensor
                    y_train_tensor[f"poison_{i}"] = y_c_tensor

                # Training loop
                for round in range(ROUNDS):
                    # Prepare arguments for honest clients
                    
                    #randomize the training data
                    for i in range(N_HONEST):
                        perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                        X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                        y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                    honest_args = [
                        (
                            X_train_tensor[f"honest_{i}"],
                            y_train_tensor[f"honest_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(N_HONEST)
                    ]

                    # Prepare arguments for poisoned clients
                    
                    #randomize the training data
                    for i in range(i_poisoned):
                        perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                        X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                        y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                    poison_args = [
                        (
                            X_train_tensor[f"poison_{i}"],
                            y_train_tensor[f"poison_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(i_poisoned)
                    ]

                    # Run in parallel
                    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                        honest_results = list(executor.map(train_local_worker, honest_args))
                        poison_results = list(executor.map(train_local_worker, poison_args))

                    local_weights = []
                    local_sizes = []
                    local_y = []
                    local_outputs = []
                    local_preds = []
                    for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                        local_weights.append(l_w)
                        local_sizes.append(l_sz)
                        local_y.extend(l_y)
                        local_outputs.extend(l_out)
                        local_preds.extend(l_pred)
                    loss_train = binary_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                    acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                    # Federated averaging (weighted by client data size)
                    new_weights = {}
                    for key in global_weights.keys():
                        new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                    global_weights = new_weights
                    global_model.load_state_dict(global_weights)

                    # Evaluate
                    global_model.eval()
                    with torch.no_grad():
                        outputs = global_model(X_test_tensor)
                        preds = (outputs > 0.5).float()
                        loss_test = binary_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'round': round, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"round {round}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                # torch.save(model, os.path.join(save_path,'model_last.pt'))
                save_path_name = os.path.join(save_path,'model_last.pt')
                save_model(global_model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['round'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['round'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 round 0: loss_train=0.6963, acc_train=0.4927, loss_test=0.6942, acc_test=0.5000
# poison_percent 0 round 1: loss_train=0.6967, acc_train=0.4835, loss_test=0.6939, acc_test=0.5000
# poison_percent 0 round 2: loss_train=0.6942, acc_train=0.5092, loss_test=0.6937, acc_test=0.5000
# poison_percent 0 round 3: loss_train=0.6951, acc_train=0.4927, loss_test=0.6935, acc_test=0.5000
# poison_percent 0 round 4: loss_train=0.6941, acc_train=0.5058, loss_test=0.6934, acc_test=0.5000
# poison_percent 0 round 5: loss_train=0.6940, acc_train=0.5062, loss_test=0.6932, acc_test=0.5000
# poison_percent 0 round 6: loss_train=0.6942, acc_train=0.5023, loss_test=0.6932, acc_test=0.5000
# poison_percent 0 round 7: loss_train=0.6944, acc_train=0.4854, loss_test=0.6931, acc_test=0.5000
# poison_percent 0 round 8: loss_train=0.6940, acc_train=0.4473, loss_test=0.6931, acc_test=0.5015
# poison_percent 0 round 9: loss_train=0.6942, acc_train=0.4438, loss_test=0.6931, acc_test=0.4934
# poison_percent 0 round 10: loss_train=0.6942, acc_train=0.4438, loss_test=0.6931, acc_test=0.4923
# poison_percent 0 round 11: loss_train=0.6940, acc_train=0.4500, loss_test=0.6931, acc_test=0.4964
# poison_percent 0 round 12: loss_train=0.6942, acc_train=0.4408, loss_test=0.6931, acc_test=0.5520
# poison_percent 0 round 13: loss_train=0.6941, acc_train=0.4392, loss_test=0.6930, acc_test=0.4857
# poison_percent 0 round 14: loss_train=0.6941, acc_train=0.4408, loss_test=0.6930, acc_test=0.5148
# poison_percent 0 round 15: loss_train=0.6941, acc_train=0.4423, loss_test=0.6930, acc_test=0.5520
# poison_percent 0 round 16: loss_train=0.6941, acc_train=0.4423, loss_test=0.6930, acc_test=0.5561
# poison_percent 0 round 17: loss_train=0.6941, acc_train=0.4385, loss_test=0.6929, acc_test=0.4985
# poison_percent 0 round 18: loss_train=0.6939, acc_train=0.4435, loss_test=0.6929, acc_test=0.5867
# poison_percent 0 round 19: loss_train=0.6939, acc_train=0.4423, loss_test=0.6929, acc_test=0.5679
# poison_percent 0 round 20: loss_train=0.6937, acc_train=0.4531, loss_test=0.6928, acc_test=0.5704
# poison_percent 0 round 21: loss_train=0.6937, acc_train=0.4488, loss_test=0.6928, acc_test=0.5816
# poison_percent 0 round 22: loss_train=0.6938, acc_train=0.4392, loss_test=0.6927, acc_test=0.5964
# poison_percent 0 round 23: loss_train=0.6937, acc_train=0.4419, loss_test=0.6927, acc_test=0.5694
# poison_percent 0 round 24: loss_train=0.6937, acc_train=0.4431, loss_test=0.6926, acc_test=0.6015
# poison_percent 0 round 25: loss_train=0.6936, acc_train=0.4412, loss_test=0.6925, acc_test=0.6122
# poison_percent 0 round 26: loss_train=0.6936, acc_train=0.4419, loss_test=0.6925, acc_test=0.6219
# poison_percent 0 round 27: loss_train=0.6933, acc_train=0.4527, loss_test=0.6924, acc_test=0.6204
# poison_percent 0 round 28: loss_train=0.6934, acc_train=0.4477, loss_test=0.6923, acc_test=0.6260
# poison_percent 0 round 29: loss_train=0.6933, acc_train=0.4404, loss_test=0.6922, acc_test=0.6230
# poison_percent 0 round 30: loss_train=0.6933, acc_train=0.4465, loss_test=0.6921, acc_test=0.6520
# poison_percent 0 round 31: loss_train=0.6930, acc_train=0.4473, loss_test=0.6920, acc_test=0.6531
# poison_percent 0 round 32: loss_train=0.6928, acc_train=0.4627, loss_test=0.6918, acc_test=0.6587
# poison_percent 0 round 33: loss_train=0.6926, acc_train=0.4742, loss_test=0.6917, acc_test=0.6837
# poison_percent 0 round 34: loss_train=0.6926, acc_train=0.4581, loss_test=0.6916, acc_test=0.6821
# poison_percent 0 round 35: loss_train=0.6926, acc_train=0.4758, loss_test=0.6914, acc_test=0.6847
# poison_percent 0 round 36: loss_train=0.6922, acc_train=0.4892, loss_test=0.6912, acc_test=0.7184
# poison_percent 0 round 37: loss_train=0.6921, acc_train=0.4900, loss_test=0.6910, acc_test=0.7219
# poison_percent 0 round 38: loss_train=0.6916, acc_train=0.5219, loss_test=0.6908, acc_test=0.7204
# poison_percent 0 round 39: loss_train=0.6915, acc_train=0.5196, loss_test=0.6905, acc_test=0.7423
# poison_percent 0 round 40: loss_train=0.6914, acc_train=0.5365, loss_test=0.6903, acc_test=0.7587
# poison_percent 0 round 41: loss_train=0.6912, acc_train=0.5188, loss_test=0.6900, acc_test=0.7842
# poison_percent 0 round 42: loss_train=0.6909, acc_train=0.5350, loss_test=0.6897, acc_test=0.7949
# poison_percent 0 round 43: loss_train=0.6907, acc_train=0.5342, loss_test=0.6893, acc_test=0.7648
# poison_percent 0 round 44: loss_train=0.6901, acc_train=0.5804, loss_test=0.6889, acc_test=0.8199
# poison_percent 0 round 45: loss_train=0.6897, acc_train=0.6035, loss_test=0.6885, acc_test=0.8423
# poison_percent 0 round 46: loss_train=0.6890, acc_train=0.6358, loss_test=0.6880, acc_test=0.8546
# poison_percent 0 round 47: loss_train=0.6888, acc_train=0.6138, loss_test=0.6876, acc_test=0.8628
# poison_percent 0 round 48: loss_train=0.6883, acc_train=0.6588, loss_test=0.6870, acc_test=0.8638
# poison_percent 0 round 49: loss_train=0.6878, acc_train=0.6792, loss_test=0.6865, acc_test=0.8709
# poison_percent 0 round 50: loss_train=0.6869, acc_train=0.7300, loss_test=0.6858, acc_test=0.8806
# poison_percent 0 round 51: loss_train=0.6866, acc_train=0.7300, loss_test=0.6852, acc_test=0.8893
# poison_percent 0 round 52: loss_train=0.6862, acc_train=0.7192, loss_test=0.6845, acc_test=0.8944
# poison_percent 0 round 53: loss_train=0.6849, acc_train=0.7746, loss_test=0.6838, acc_test=0.9000
# poison_percent 0 round 54: loss_train=0.6843, acc_train=0.7912, loss_test=0.6830, acc_test=0.9036
# poison_percent 0 round 55: loss_train=0.6834, acc_train=0.8088, loss_test=0.6821, acc_test=0.9071
# poison_percent 0 round 56: loss_train=0.6824, acc_train=0.8438, loss_test=0.6811, acc_test=0.9082
# poison_percent 0 round 57: loss_train=0.6819, acc_train=0.8369, loss_test=0.6802, acc_test=0.9122
# poison_percent 0 round 58: loss_train=0.6806, acc_train=0.8538, loss_test=0.6792, acc_test=0.9168
# poison_percent 0 round 59: loss_train=0.6797, acc_train=0.8573, loss_test=0.6781, acc_test=0.9184
# poison_percent 0 round 60: loss_train=0.6787, acc_train=0.8631, loss_test=0.6770, acc_test=0.9199
# poison_percent 0 round 61: loss_train=0.6770, acc_train=0.8923, loss_test=0.6758, acc_test=0.9204
# poison_percent 0 round 62: loss_train=0.6759, acc_train=0.8919, loss_test=0.6745, acc_test=0.9199
# poison_percent 0 round 63: loss_train=0.6744, acc_train=0.8958, loss_test=0.6731, acc_test=0.9250
# poison_percent 0 round 64: loss_train=0.6734, acc_train=0.9000, loss_test=0.6717, acc_test=0.9235
# poison_percent 0 round 65: loss_train=0.6717, acc_train=0.9008, loss_test=0.6701, acc_test=0.9255
# poison_percent 0 round 66: loss_train=0.6702, acc_train=0.9019, loss_test=0.6686, acc_test=0.9224
# poison_percent 0 round 67: loss_train=0.6684, acc_train=0.8977, loss_test=0.6668, acc_test=0.9204
# poison_percent 0 round 68: loss_train=0.6667, acc_train=0.9138, loss_test=0.6650, acc_test=0.9286
# poison_percent 0 round 69: loss_train=0.6648, acc_train=0.9219, loss_test=0.6632, acc_test=0.9316
# poison_percent 0 round 70: loss_train=0.6633, acc_train=0.9181, loss_test=0.6612, acc_test=0.9316
# poison_percent 0 round 71: loss_train=0.6614, acc_train=0.9246, loss_test=0.6591, acc_test=0.9337
# poison_percent 0 round 72: loss_train=0.6582, acc_train=0.9365, loss_test=0.6569, acc_test=0.9357
# poison_percent 0 round 73: loss_train=0.6571, acc_train=0.9292, loss_test=0.6546, acc_test=0.9367
# poison_percent 0 round 74: loss_train=0.6545, acc_train=0.9265, loss_test=0.6522, acc_test=0.9367
# poison_percent 0 round 75: loss_train=0.6518, acc_train=0.9346, loss_test=0.6496, acc_test=0.9403
# poison_percent 0 round 76: loss_train=0.6487, acc_train=0.9362, loss_test=0.6470, acc_test=0.9429
# poison_percent 0 round 77: loss_train=0.6473, acc_train=0.9388, loss_test=0.6441, acc_test=0.9469
# poison_percent 0 round 78: loss_train=0.6444, acc_train=0.9392, loss_test=0.6411, acc_test=0.9490
# poison_percent 0 round 79: loss_train=0.6401, acc_train=0.9454, loss_test=0.6379, acc_test=0.9500
# poison_percent 0 round 80: loss_train=0.6372, acc_train=0.9531, loss_test=0.6346, acc_test=0.9546
# poison_percent 0 round 81: loss_train=0.6343, acc_train=0.9492, loss_test=0.6310, acc_test=0.9561
# poison_percent 0 round 82: loss_train=0.6306, acc_train=0.9585, loss_test=0.6274, acc_test=0.9592
# poison_percent 0 round 83: loss_train=0.6277, acc_train=0.9512, loss_test=0.6237, acc_test=0.9607
# poison_percent 0 round 84: loss_train=0.6248, acc_train=0.9519, loss_test=0.6198, acc_test=0.9622
# poison_percent 0 round 85: loss_train=0.6188, acc_train=0.9623, loss_test=0.6157, acc_test=0.9633
# poison_percent 0 round 86: loss_train=0.6147, acc_train=0.9646, loss_test=0.6114, acc_test=0.9633
# poison_percent 0 round 87: loss_train=0.6115, acc_train=0.9654, loss_test=0.6070, acc_test=0.9643
# poison_percent 0 round 88: loss_train=0.6060, acc_train=0.9646, loss_test=0.6024, acc_test=0.9648
# poison_percent 0 round 89: loss_train=0.6015, acc_train=0.9654, loss_test=0.5975, acc_test=0.9663
# poison_percent 0 round 90: loss_train=0.5966, acc_train=0.9658, loss_test=0.5924, acc_test=0.9673
# poison_percent 0 round 91: loss_train=0.5905, acc_train=0.9735, loss_test=0.5871, acc_test=0.9694
# poison_percent 0 round 92: loss_train=0.5855, acc_train=0.9723, loss_test=0.5818, acc_test=0.9699
# poison_percent 0 round 93: loss_train=0.5817, acc_train=0.9692, loss_test=0.5760, acc_test=0.9735
# poison_percent 0 round 94: loss_train=0.5766, acc_train=0.9723, loss_test=0.5701, acc_test=0.9750
# poison_percent 0 round 95: loss_train=0.5705, acc_train=0.9704, loss_test=0.5641, acc_test=0.9765
# poison_percent 0 round 96: loss_train=0.5637, acc_train=0.9696, loss_test=0.5580, acc_test=0.9781
# poison_percent 0 round 97: loss_train=0.5563, acc_train=0.9785, loss_test=0.5514, acc_test=0.9791
# poison_percent 0 round 98: loss_train=0.5517, acc_train=0.9765, loss_test=0.5448, acc_test=0.9801
# poison_percent 0 round 99: loss_train=0.5438, acc_train=0.9762, loss_test=0.5378, acc_test=0.9816
# Training log saved to ./results\FL_ModelN1L3_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 round 0: loss_train=0.5731, acc_train=0.8788, loss_test=0.5322, acc_test=0.9827
# poison_percent 10 round 1: loss_train=0.5692, acc_train=0.8760, loss_test=0.5265, acc_test=0.9827
# poison_percent 10 round 2: loss_train=0.5679, acc_train=0.8740, loss_test=0.5206, acc_test=0.9842
# poison_percent 10 round 3: loss_train=0.5603, acc_train=0.8767, loss_test=0.5146, acc_test=0.9842
# poison_percent 10 round 4: loss_train=0.5576, acc_train=0.8805, loss_test=0.5086, acc_test=0.9842
# poison_percent 10 round 5: loss_train=0.5511, acc_train=0.8760, loss_test=0.5024, acc_test=0.9842
# poison_percent 10 round 6: loss_train=0.5471, acc_train=0.8788, loss_test=0.4961, acc_test=0.9842
# poison_percent 10 round 7: loss_train=0.5458, acc_train=0.8767, loss_test=0.4896, acc_test=0.9842
# poison_percent 10 round 8: loss_train=0.5395, acc_train=0.8788, loss_test=0.4830, acc_test=0.9842
# poison_percent 10 round 9: loss_train=0.5339, acc_train=0.8802, loss_test=0.4762, acc_test=0.9842
# poison_percent 10 round 10: loss_train=0.5311, acc_train=0.8767, loss_test=0.4692, acc_test=0.9837
# poison_percent 10 round 11: loss_train=0.5268, acc_train=0.8764, loss_test=0.4623, acc_test=0.9842
# poison_percent 10 round 12: loss_train=0.5209, acc_train=0.8788, loss_test=0.4552, acc_test=0.9842
# poison_percent 10 round 13: loss_train=0.5140, acc_train=0.8819, loss_test=0.4481, acc_test=0.9842
# poison_percent 10 round 14: loss_train=0.5094, acc_train=0.8781, loss_test=0.4406, acc_test=0.9847
# poison_percent 10 round 15: loss_train=0.5029, acc_train=0.8798, loss_test=0.4331, acc_test=0.9847
# poison_percent 10 round 16: loss_train=0.5016, acc_train=0.8791, loss_test=0.4256, acc_test=0.9852
# poison_percent 10 round 17: loss_train=0.4977, acc_train=0.8777, loss_test=0.4178, acc_test=0.9852
# poison_percent 10 round 18: loss_train=0.4919, acc_train=0.8812, loss_test=0.4101, acc_test=0.9857
# poison_percent 10 round 19: loss_train=0.4841, acc_train=0.8805, loss_test=0.4023, acc_test=0.9857
# poison_percent 10 round 20: loss_train=0.4802, acc_train=0.8826, loss_test=0.3944, acc_test=0.9857
# poison_percent 10 round 21: loss_train=0.4716, acc_train=0.8836, loss_test=0.3863, acc_test=0.9862
# poison_percent 10 round 22: loss_train=0.4677, acc_train=0.8819, loss_test=0.3782, acc_test=0.9867
# poison_percent 10 round 23: loss_train=0.4635, acc_train=0.8819, loss_test=0.3701, acc_test=0.9867
# poison_percent 10 round 24: loss_train=0.4581, acc_train=0.8808, loss_test=0.3619, acc_test=0.9872
# poison_percent 10 round 25: loss_train=0.4509, acc_train=0.8843, loss_test=0.3537, acc_test=0.9872
# poison_percent 10 round 26: loss_train=0.4487, acc_train=0.8798, loss_test=0.3455, acc_test=0.9872
# poison_percent 10 round 27: loss_train=0.4424, acc_train=0.8829, loss_test=0.3371, acc_test=0.9872
# poison_percent 10 round 28: loss_train=0.4422, acc_train=0.8791, loss_test=0.3287, acc_test=0.9883
# poison_percent 10 round 29: loss_train=0.4362, acc_train=0.8788, loss_test=0.3204, acc_test=0.9883
# poison_percent 10 round 30: loss_train=0.4300, acc_train=0.8798, loss_test=0.3121, acc_test=0.9883
# poison_percent 10 round 31: loss_train=0.4244, acc_train=0.8815, loss_test=0.3038, acc_test=0.9893
# poison_percent 10 round 32: loss_train=0.4150, acc_train=0.8846, loss_test=0.2956, acc_test=0.9893
# poison_percent 10 round 33: loss_train=0.4170, acc_train=0.8826, loss_test=0.2873, acc_test=0.9893
# poison_percent 10 round 34: loss_train=0.4081, acc_train=0.8850, loss_test=0.2792, acc_test=0.9893
# poison_percent 10 round 35: loss_train=0.4082, acc_train=0.8819, loss_test=0.2711, acc_test=0.9893
# poison_percent 10 round 36: loss_train=0.4069, acc_train=0.8781, loss_test=0.2631, acc_test=0.9893
# poison_percent 10 round 37: loss_train=0.4025, acc_train=0.8819, loss_test=0.2551, acc_test=0.9893
# poison_percent 10 round 38: loss_train=0.3944, acc_train=0.8812, loss_test=0.2473, acc_test=0.9898
# poison_percent 10 round 39: loss_train=0.3901, acc_train=0.8808, loss_test=0.2395, acc_test=0.9903
# poison_percent 10 round 40: loss_train=0.3869, acc_train=0.8832, loss_test=0.2318, acc_test=0.9903
# poison_percent 10 round 41: loss_train=0.3901, acc_train=0.8819, loss_test=0.2242, acc_test=0.9903
# poison_percent 10 round 42: loss_train=0.3838, acc_train=0.8856, loss_test=0.2168, acc_test=0.9903
# poison_percent 10 round 43: loss_train=0.3777, acc_train=0.8788, loss_test=0.2094, acc_test=0.9903
# poison_percent 10 round 44: loss_train=0.3744, acc_train=0.8846, loss_test=0.2022, acc_test=0.9908
# poison_percent 10 round 45: loss_train=0.3713, acc_train=0.8808, loss_test=0.1952, acc_test=0.9908
# poison_percent 10 round 46: loss_train=0.3728, acc_train=0.8812, loss_test=0.1883, acc_test=0.9918
# poison_percent 10 round 47: loss_train=0.3764, acc_train=0.8788, loss_test=0.1814, acc_test=0.9918
# poison_percent 10 round 48: loss_train=0.3662, acc_train=0.8850, loss_test=0.1748, acc_test=0.9918
# poison_percent 10 round 49: loss_train=0.3658, acc_train=0.8829, loss_test=0.1685, acc_test=0.9918
# poison_percent 10 round 50: loss_train=0.3595, acc_train=0.8850, loss_test=0.1621, acc_test=0.9918
# poison_percent 10 round 51: loss_train=0.3704, acc_train=0.8819, loss_test=0.1560, acc_test=0.9918
# poison_percent 10 round 52: loss_train=0.3693, acc_train=0.8822, loss_test=0.1500, acc_test=0.9923
# poison_percent 10 round 53: loss_train=0.3692, acc_train=0.8843, loss_test=0.1442, acc_test=0.9929
# poison_percent 10 round 54: loss_train=0.3648, acc_train=0.8832, loss_test=0.1387, acc_test=0.9929
# poison_percent 10 round 55: loss_train=0.3651, acc_train=0.8829, loss_test=0.1332, acc_test=0.9929
# poison_percent 10 round 56: loss_train=0.3661, acc_train=0.8839, loss_test=0.1279, acc_test=0.9929
# poison_percent 10 round 57: loss_train=0.3611, acc_train=0.8863, loss_test=0.1228, acc_test=0.9934
# poison_percent 10 round 58: loss_train=0.3679, acc_train=0.8870, loss_test=0.1178, acc_test=0.9939
# poison_percent 10 round 59: loss_train=0.3687, acc_train=0.8843, loss_test=0.1131, acc_test=0.9939
# poison_percent 10 round 60: loss_train=0.3741, acc_train=0.8853, loss_test=0.1085, acc_test=0.9939
# poison_percent 10 round 61: loss_train=0.3704, acc_train=0.8850, loss_test=0.1041, acc_test=0.9939
# poison_percent 10 round 62: loss_train=0.3763, acc_train=0.8856, loss_test=0.0999, acc_test=0.9939
# poison_percent 10 round 63: loss_train=0.3765, acc_train=0.8856, loss_test=0.0958, acc_test=0.9939
# poison_percent 10 round 64: loss_train=0.3779, acc_train=0.8843, loss_test=0.0919, acc_test=0.9939
# poison_percent 10 round 65: loss_train=0.3793, acc_train=0.8850, loss_test=0.0881, acc_test=0.9939
# poison_percent 10 round 66: loss_train=0.3858, acc_train=0.8867, loss_test=0.0846, acc_test=0.9939
# poison_percent 10 round 67: loss_train=0.3807, acc_train=0.8877, loss_test=0.0812, acc_test=0.9939
# poison_percent 10 round 68: loss_train=0.3961, acc_train=0.8829, loss_test=0.0778, acc_test=0.9939
# poison_percent 10 round 69: loss_train=0.3917, acc_train=0.8843, loss_test=0.0747, acc_test=0.9939
# poison_percent 10 round 70: loss_train=0.3927, acc_train=0.8874, loss_test=0.0717, acc_test=0.9939
# poison_percent 10 round 71: loss_train=0.4044, acc_train=0.8839, loss_test=0.0688, acc_test=0.9939
# poison_percent 10 round 72: loss_train=0.4008, acc_train=0.8867, loss_test=0.0659, acc_test=0.9939
# poison_percent 10 round 73: loss_train=0.4071, acc_train=0.8870, loss_test=0.0633, acc_test=0.9939
# poison_percent 10 round 74: loss_train=0.4134, acc_train=0.8839, loss_test=0.0608, acc_test=0.9939
# poison_percent 10 round 75: loss_train=0.4248, acc_train=0.8856, loss_test=0.0584, acc_test=0.9939
# poison_percent 10 round 76: loss_train=0.4224, acc_train=0.8877, loss_test=0.0561, acc_test=0.9939
# poison_percent 10 round 77: loss_train=0.4248, acc_train=0.8860, loss_test=0.0540, acc_test=0.9939
# poison_percent 10 round 78: loss_train=0.4325, acc_train=0.8846, loss_test=0.0519, acc_test=0.9939
# poison_percent 10 round 79: loss_train=0.4309, acc_train=0.8867, loss_test=0.0500, acc_test=0.9939
# poison_percent 10 round 80: loss_train=0.4376, acc_train=0.8846, loss_test=0.0481, acc_test=0.9944
# poison_percent 10 round 81: loss_train=0.4530, acc_train=0.8863, loss_test=0.0463, acc_test=0.9944
# poison_percent 10 round 82: loss_train=0.4575, acc_train=0.8846, loss_test=0.0446, acc_test=0.9944
# poison_percent 10 round 83: loss_train=0.4585, acc_train=0.8863, loss_test=0.0431, acc_test=0.9944
# poison_percent 10 round 84: loss_train=0.4843, acc_train=0.8856, loss_test=0.0416, acc_test=0.9944
# poison_percent 10 round 85: loss_train=0.4754, acc_train=0.8877, loss_test=0.0402, acc_test=0.9944
# poison_percent 10 round 86: loss_train=0.4753, acc_train=0.8887, loss_test=0.0388, acc_test=0.9944
# poison_percent 10 round 87: loss_train=0.4905, acc_train=0.8860, loss_test=0.0375, acc_test=0.9944
# poison_percent 10 round 88: loss_train=0.4956, acc_train=0.8880, loss_test=0.0362, acc_test=0.9949
# poison_percent 10 round 89: loss_train=0.5100, acc_train=0.8863, loss_test=0.0351, acc_test=0.9949
# poison_percent 10 round 90: loss_train=0.4938, acc_train=0.8880, loss_test=0.0340, acc_test=0.9949
# poison_percent 10 round 91: loss_train=0.5207, acc_train=0.8877, loss_test=0.0329, acc_test=0.9949
# poison_percent 10 round 92: loss_train=0.5012, acc_train=0.8880, loss_test=0.0319, acc_test=0.9949
# poison_percent 10 round 93: loss_train=0.5210, acc_train=0.8884, loss_test=0.0310, acc_test=0.9949
# poison_percent 10 round 94: loss_train=0.5255, acc_train=0.8894, loss_test=0.0301, acc_test=0.9949
# poison_percent 10 round 95: loss_train=0.5262, acc_train=0.8880, loss_test=0.0292, acc_test=0.9949
# poison_percent 10 round 96: loss_train=0.5335, acc_train=0.8905, loss_test=0.0284, acc_test=0.9944
# poison_percent 10 round 97: loss_train=0.5478, acc_train=0.8874, loss_test=0.0276, acc_test=0.9944
# poison_percent 10 round 98: loss_train=0.5429, acc_train=0.8887, loss_test=0.0269, acc_test=0.9944
# poison_percent 10 round 99: loss_train=0.5498, acc_train=0.8863, loss_test=0.0262, acc_test=0.9944
# Training log saved to ./results\FL_ModelN1L3_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=1.0234, acc_train=0.7966, loss_test=0.0257, acc_test=0.9944
# poison_percent 20 round 1: loss_train=1.0477, acc_train=0.7960, loss_test=0.0252, acc_test=0.9944
# poison_percent 20 round 2: loss_train=1.0316, acc_train=0.7957, loss_test=0.0248, acc_test=0.9944
# poison_percent 20 round 3: loss_train=1.0541, acc_train=0.7957, loss_test=0.0244, acc_test=0.9944
# poison_percent 20 round 4: loss_train=1.0511, acc_train=0.7960, loss_test=0.0239, acc_test=0.9944
# poison_percent 20 round 5: loss_train=1.0640, acc_train=0.7972, loss_test=0.0236, acc_test=0.9944
# poison_percent 20 round 6: loss_train=1.0783, acc_train=0.7966, loss_test=0.0232, acc_test=0.9944
# poison_percent 20 round 7: loss_train=1.0872, acc_train=0.7988, loss_test=0.0228, acc_test=0.9944
# poison_percent 20 round 8: loss_train=1.0852, acc_train=0.7963, loss_test=0.0224, acc_test=0.9944
# poison_percent 20 round 9: loss_train=1.0884, acc_train=0.7978, loss_test=0.0221, acc_test=0.9944
# poison_percent 20 round 10: loss_train=1.0935, acc_train=0.7994, loss_test=0.0218, acc_test=0.9949
# poison_percent 20 round 11: loss_train=1.1120, acc_train=0.7969, loss_test=0.0214, acc_test=0.9949
# poison_percent 20 round 12: loss_train=1.0988, acc_train=0.7972, loss_test=0.0211, acc_test=0.9949
# poison_percent 20 round 13: loss_train=1.1284, acc_train=0.7963, loss_test=0.0208, acc_test=0.9949
# poison_percent 20 round 14: loss_train=1.1394, acc_train=0.7966, loss_test=0.0205, acc_test=0.9949
# poison_percent 20 round 15: loss_train=1.1456, acc_train=0.7972, loss_test=0.0202, acc_test=0.9949
# poison_percent 20 round 16: loss_train=1.1355, acc_train=0.7982, loss_test=0.0200, acc_test=0.9949
# poison_percent 20 round 17: loss_train=1.1704, acc_train=0.7985, loss_test=0.0197, acc_test=0.9949
# poison_percent 20 round 18: loss_train=1.1649, acc_train=0.7982, loss_test=0.0195, acc_test=0.9949
# poison_percent 20 round 19: loss_train=1.1660, acc_train=0.7978, loss_test=0.0192, acc_test=0.9949
# poison_percent 20 round 20: loss_train=1.1847, acc_train=0.7978, loss_test=0.0190, acc_test=0.9949
# poison_percent 20 round 21: loss_train=1.1903, acc_train=0.7969, loss_test=0.0187, acc_test=0.9949
# poison_percent 20 round 22: loss_train=1.1939, acc_train=0.7985, loss_test=0.0185, acc_test=0.9949
# poison_percent 20 round 23: loss_train=1.1837, acc_train=0.7978, loss_test=0.0183, acc_test=0.9954
# poison_percent 20 round 24: loss_train=1.2255, acc_train=0.7957, loss_test=0.0181, acc_test=0.9954
# poison_percent 20 round 25: loss_train=1.2222, acc_train=0.7991, loss_test=0.0179, acc_test=0.9954
# poison_percent 20 round 26: loss_train=1.2256, acc_train=0.7975, loss_test=0.0177, acc_test=0.9954
# poison_percent 20 round 27: loss_train=1.2583, acc_train=0.7969, loss_test=0.0175, acc_test=0.9954
# poison_percent 20 round 28: loss_train=1.2392, acc_train=0.7966, loss_test=0.0173, acc_test=0.9954
# poison_percent 20 round 29: loss_train=1.2542, acc_train=0.7963, loss_test=0.0171, acc_test=0.9954
# poison_percent 20 round 30: loss_train=1.2500, acc_train=0.7994, loss_test=0.0169, acc_test=0.9954
# poison_percent 20 round 31: loss_train=1.2664, acc_train=0.7960, loss_test=0.0168, acc_test=0.9954
# poison_percent 20 round 32: loss_train=1.2626, acc_train=0.7994, loss_test=0.0166, acc_test=0.9954
# poison_percent 20 round 33: loss_train=1.2719, acc_train=0.7991, loss_test=0.0165, acc_test=0.9954
# poison_percent 20 round 34: loss_train=1.3007, acc_train=0.7963, loss_test=0.0163, acc_test=0.9954
# poison_percent 20 round 35: loss_train=1.2872, acc_train=0.7972, loss_test=0.0161, acc_test=0.9954
# poison_percent 20 round 36: loss_train=1.3043, acc_train=0.7975, loss_test=0.0160, acc_test=0.9954
# poison_percent 20 round 37: loss_train=1.3131, acc_train=0.7978, loss_test=0.0159, acc_test=0.9954
# poison_percent 20 round 38: loss_train=1.3185, acc_train=0.7978, loss_test=0.0157, acc_test=0.9954
# poison_percent 20 round 39: loss_train=1.3250, acc_train=0.7982, loss_test=0.0156, acc_test=0.9954
# poison_percent 20 round 40: loss_train=1.3238, acc_train=0.7994, loss_test=0.0155, acc_test=0.9954
# poison_percent 20 round 41: loss_train=1.3189, acc_train=0.7978, loss_test=0.0153, acc_test=0.9954
# poison_percent 20 round 42: loss_train=1.3727, acc_train=0.7972, loss_test=0.0152, acc_test=0.9954
# poison_percent 20 round 43: loss_train=1.3346, acc_train=0.7982, loss_test=0.0151, acc_test=0.9954
# poison_percent 20 round 44: loss_train=1.3776, acc_train=0.7975, loss_test=0.0150, acc_test=0.9954
# poison_percent 20 round 45: loss_train=1.3659, acc_train=0.7966, loss_test=0.0148, acc_test=0.9954
# poison_percent 20 round 46: loss_train=1.3877, acc_train=0.7972, loss_test=0.0147, acc_test=0.9954
# poison_percent 20 round 47: loss_train=1.3767, acc_train=0.7963, loss_test=0.0146, acc_test=0.9954
# poison_percent 20 round 48: loss_train=1.3805, acc_train=0.7988, loss_test=0.0145, acc_test=0.9954
# poison_percent 20 round 49: loss_train=1.3999, acc_train=0.7985, loss_test=0.0144, acc_test=0.9954
# poison_percent 20 round 50: loss_train=1.3891, acc_train=0.7988, loss_test=0.0143, acc_test=0.9954
# poison_percent 20 round 51: loss_train=1.4014, acc_train=0.7972, loss_test=0.0142, acc_test=0.9954
# poison_percent 20 round 52: loss_train=1.3847, acc_train=0.7988, loss_test=0.0141, acc_test=0.9954
# poison_percent 20 round 53: loss_train=1.4162, acc_train=0.7985, loss_test=0.0140, acc_test=0.9954
# poison_percent 20 round 54: loss_train=1.4039, acc_train=0.7951, loss_test=0.0139, acc_test=0.9954
# poison_percent 20 round 55: loss_train=1.4398, acc_train=0.7988, loss_test=0.0138, acc_test=0.9954
# poison_percent 20 round 56: loss_train=1.4382, acc_train=0.7972, loss_test=0.0137, acc_test=0.9954
# poison_percent 20 round 57: loss_train=1.4549, acc_train=0.7978, loss_test=0.0136, acc_test=0.9959
# poison_percent 20 round 58: loss_train=1.4549, acc_train=0.7985, loss_test=0.0136, acc_test=0.9959
# poison_percent 20 round 59: loss_train=1.4533, acc_train=0.7985, loss_test=0.0135, acc_test=0.9959
# poison_percent 20 round 60: loss_train=1.4647, acc_train=0.7978, loss_test=0.0134, acc_test=0.9959
# poison_percent 20 round 61: loss_train=1.5141, acc_train=0.7966, loss_test=0.0133, acc_test=0.9959
# poison_percent 20 round 62: loss_train=1.4777, acc_train=0.7988, loss_test=0.0132, acc_test=0.9959
# poison_percent 20 round 63: loss_train=1.4732, acc_train=0.7972, loss_test=0.0132, acc_test=0.9959
# poison_percent 20 round 64: loss_train=1.4822, acc_train=0.7978, loss_test=0.0131, acc_test=0.9959
# poison_percent 20 round 65: loss_train=1.5082, acc_train=0.7972, loss_test=0.0130, acc_test=0.9959
# poison_percent 20 round 66: loss_train=1.5156, acc_train=0.7972, loss_test=0.0129, acc_test=0.9959
# poison_percent 20 round 67: loss_train=1.5279, acc_train=0.7997, loss_test=0.0129, acc_test=0.9959
# poison_percent 20 round 68: loss_train=1.5247, acc_train=0.7985, loss_test=0.0128, acc_test=0.9959
# poison_percent 20 round 69: loss_train=1.5107, acc_train=0.8000, loss_test=0.0128, acc_test=0.9959
# poison_percent 20 round 70: loss_train=1.5270, acc_train=0.7978, loss_test=0.0127, acc_test=0.9959
# poison_percent 20 round 71: loss_train=1.5373, acc_train=0.7972, loss_test=0.0126, acc_test=0.9959
# poison_percent 20 round 72: loss_train=1.5367, acc_train=0.7963, loss_test=0.0126, acc_test=0.9959
# poison_percent 20 round 73: loss_train=1.5427, acc_train=0.7966, loss_test=0.0125, acc_test=0.9959
# poison_percent 20 round 74: loss_train=1.5580, acc_train=0.7978, loss_test=0.0124, acc_test=0.9959
# poison_percent 20 round 75: loss_train=1.5592, acc_train=0.7969, loss_test=0.0124, acc_test=0.9959
# poison_percent 20 round 76: loss_train=1.5955, acc_train=0.7969, loss_test=0.0123, acc_test=0.9959
# poison_percent 20 round 77: loss_train=1.5920, acc_train=0.7978, loss_test=0.0123, acc_test=0.9959
# poison_percent 20 round 78: loss_train=1.5703, acc_train=0.7978, loss_test=0.0123, acc_test=0.9959
# poison_percent 20 round 79: loss_train=1.5919, acc_train=0.8000, loss_test=0.0122, acc_test=0.9959
# poison_percent 20 round 80: loss_train=1.5800, acc_train=0.7972, loss_test=0.0122, acc_test=0.9959
# poison_percent 20 round 81: loss_train=1.5794, acc_train=0.7982, loss_test=0.0121, acc_test=0.9959
# poison_percent 20 round 82: loss_train=1.6230, acc_train=0.7975, loss_test=0.0120, acc_test=0.9959
# poison_percent 20 round 83: loss_train=1.6066, acc_train=0.7975, loss_test=0.0120, acc_test=0.9959
# poison_percent 20 round 84: loss_train=1.6338, acc_train=0.7969, loss_test=0.0119, acc_test=0.9959
# poison_percent 20 round 85: loss_train=1.6446, acc_train=0.7972, loss_test=0.0119, acc_test=0.9959
# poison_percent 20 round 86: loss_train=1.6265, acc_train=0.7972, loss_test=0.0119, acc_test=0.9959
# poison_percent 20 round 87: loss_train=1.6229, acc_train=0.7960, loss_test=0.0118, acc_test=0.9959
# poison_percent 20 round 88: loss_train=1.6367, acc_train=0.7985, loss_test=0.0118, acc_test=0.9959
# poison_percent 20 round 89: loss_train=1.6276, acc_train=0.7988, loss_test=0.0117, acc_test=0.9964
# poison_percent 20 round 90: loss_train=1.6827, acc_train=0.7985, loss_test=0.0117, acc_test=0.9964
# poison_percent 20 round 91: loss_train=1.6486, acc_train=0.7972, loss_test=0.0116, acc_test=0.9964
# poison_percent 20 round 92: loss_train=1.6602, acc_train=0.7988, loss_test=0.0116, acc_test=0.9964
# poison_percent 20 round 93: loss_train=1.6804, acc_train=0.7994, loss_test=0.0116, acc_test=0.9964
# poison_percent 20 round 94: loss_train=1.6855, acc_train=0.7966, loss_test=0.0115, acc_test=0.9964
# poison_percent 20 round 95: loss_train=1.6528, acc_train=0.7978, loss_test=0.0115, acc_test=0.9964
# poison_percent 20 round 96: loss_train=1.6862, acc_train=0.7975, loss_test=0.0114, acc_test=0.9964
# poison_percent 20 round 97: loss_train=1.6821, acc_train=0.7988, loss_test=0.0114, acc_test=0.9964
# poison_percent 20 round 98: loss_train=1.7139, acc_train=0.7982, loss_test=0.0114, acc_test=0.9964
# poison_percent 20 round 99: loss_train=1.6966, acc_train=0.7994, loss_test=0.0113, acc_test=0.9964
# Training log saved to ./results\FL_ModelN1L3_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=2.5533, acc_train=0.6993, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 1: loss_train=2.5501, acc_train=0.6982, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 2: loss_train=2.5751, acc_train=0.6971, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 3: loss_train=2.5301, acc_train=0.6980, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 4: loss_train=2.5675, acc_train=0.6966, loss_test=0.0114, acc_test=0.9964
# poison_percent 30 round 5: loss_train=2.5595, acc_train=0.6980, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 6: loss_train=2.5849, acc_train=0.6988, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 7: loss_train=2.5489, acc_train=0.6980, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 8: loss_train=2.5653, acc_train=0.6977, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 9: loss_train=2.5509, acc_train=0.6985, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 10: loss_train=2.5356, acc_train=0.6982, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 11: loss_train=2.5778, acc_train=0.6977, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 12: loss_train=2.5653, acc_train=0.6988, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 13: loss_train=2.5950, acc_train=0.6982, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 14: loss_train=2.5403, acc_train=0.6988, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 15: loss_train=2.5565, acc_train=0.6985, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 16: loss_train=2.5570, acc_train=0.6993, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 17: loss_train=2.5800, acc_train=0.6969, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 18: loss_train=2.5707, acc_train=0.6971, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 19: loss_train=2.5608, acc_train=0.6969, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 20: loss_train=2.6048, acc_train=0.6988, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 21: loss_train=2.5852, acc_train=0.6966, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 22: loss_train=2.5412, acc_train=0.6982, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 23: loss_train=2.5830, acc_train=0.6993, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 24: loss_train=2.5508, acc_train=0.6990, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 25: loss_train=2.5396, acc_train=0.6977, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 26: loss_train=2.5534, acc_train=0.6980, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 27: loss_train=2.5504, acc_train=0.6988, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 28: loss_train=2.5783, acc_train=0.6980, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 29: loss_train=2.5647, acc_train=0.6982, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 30: loss_train=2.5467, acc_train=0.6988, loss_test=0.0113, acc_test=0.9964
# poison_percent 30 round 31: loss_train=2.5372, acc_train=0.6971, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 32: loss_train=2.5314, acc_train=0.6980, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 33: loss_train=2.5410, acc_train=0.6988, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 34: loss_train=2.5360, acc_train=0.6993, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 35: loss_train=2.5486, acc_train=0.6996, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 36: loss_train=2.5314, acc_train=0.6982, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 37: loss_train=2.5616, acc_train=0.6993, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 38: loss_train=2.5708, acc_train=0.6977, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 39: loss_train=2.5677, acc_train=0.6969, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 40: loss_train=2.5550, acc_train=0.6988, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 41: loss_train=2.5423, acc_train=0.6980, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 42: loss_train=2.5750, acc_train=0.6969, loss_test=0.0112, acc_test=0.9964
# poison_percent 30 round 43: loss_train=2.5603, acc_train=0.6980, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 44: loss_train=2.5649, acc_train=0.6966, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 45: loss_train=2.5650, acc_train=0.6971, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 46: loss_train=2.5514, acc_train=0.6974, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 47: loss_train=2.5934, acc_train=0.6980, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 48: loss_train=2.5824, acc_train=0.6980, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 49: loss_train=2.5588, acc_train=0.6974, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 50: loss_train=2.5347, acc_train=0.6980, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 51: loss_train=2.5684, acc_train=0.6963, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 52: loss_train=2.5661, acc_train=0.6985, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 53: loss_train=2.5427, acc_train=0.6982, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 54: loss_train=2.5424, acc_train=0.6977, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 55: loss_train=2.5514, acc_train=0.6977, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 56: loss_train=2.5628, acc_train=0.6974, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 57: loss_train=2.5451, acc_train=0.6974, loss_test=0.0111, acc_test=0.9969
# poison_percent 30 round 58: loss_train=2.4877, acc_train=0.6982, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 59: loss_train=2.6360, acc_train=0.6966, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 60: loss_train=2.5388, acc_train=0.6990, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 61: loss_train=2.5504, acc_train=0.6985, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 62: loss_train=2.5748, acc_train=0.6985, loss_test=0.0111, acc_test=0.9964
# poison_percent 30 round 63: loss_train=2.5589, acc_train=0.6990, loss_test=0.0110, acc_test=0.9964
# poison_percent 30 round 64: loss_train=2.5482, acc_train=0.6982, loss_test=0.0110, acc_test=0.9964
# poison_percent 30 round 65: loss_train=2.5772, acc_train=0.6971, loss_test=0.0110, acc_test=0.9964
# poison_percent 30 round 66: loss_train=2.5906, acc_train=0.6961, loss_test=0.0110, acc_test=0.9964
# poison_percent 30 round 67: loss_train=2.5623, acc_train=0.6993, loss_test=0.0110, acc_test=0.9964
# poison_percent 30 round 68: loss_train=2.5866, acc_train=0.6969, loss_test=0.0110, acc_test=0.9964
# poison_percent 30 round 69: loss_train=2.5943, acc_train=0.6974, loss_test=0.0110, acc_test=0.9964
# poison_percent 30 round 70: loss_train=2.5457, acc_train=0.6982, loss_test=0.0110, acc_test=0.9969
# poison_percent 30 round 71: loss_train=2.5697, acc_train=0.6990, loss_test=0.0110, acc_test=0.9964
# poison_percent 30 round 72: loss_train=2.5808, acc_train=0.6974, loss_test=0.0110, acc_test=0.9964
# poison_percent 30 round 73: loss_train=2.5712, acc_train=0.6985, loss_test=0.0110, acc_test=0.9964
# poison_percent 30 round 74: loss_train=2.5514, acc_train=0.6963, loss_test=0.0110, acc_test=0.9969
# poison_percent 30 round 75: loss_train=2.6005, acc_train=0.6985, loss_test=0.0110, acc_test=0.9974
# poison_percent 30 round 76: loss_train=2.5746, acc_train=0.6963, loss_test=0.0110, acc_test=0.9974
# poison_percent 30 round 77: loss_train=2.5763, acc_train=0.6974, loss_test=0.0110, acc_test=0.9974
# poison_percent 30 round 78: loss_train=2.5690, acc_train=0.6974, loss_test=0.0110, acc_test=0.9974
# poison_percent 30 round 79: loss_train=2.5758, acc_train=0.6985, loss_test=0.0109, acc_test=0.9974
# poison_percent 30 round 80: loss_train=2.5454, acc_train=0.6977, loss_test=0.0109, acc_test=0.9974
# poison_percent 30 round 81: loss_train=2.6137, acc_train=0.6969, loss_test=0.0109, acc_test=0.9974
# poison_percent 30 round 82: loss_train=2.5906, acc_train=0.6963, loss_test=0.0110, acc_test=0.9974
# poison_percent 30 round 83: loss_train=2.5368, acc_train=0.6977, loss_test=0.0110, acc_test=0.9974
# poison_percent 30 round 84: loss_train=2.5961, acc_train=0.6988, loss_test=0.0110, acc_test=0.9974
# poison_percent 30 round 85: loss_train=2.5789, acc_train=0.6974, loss_test=0.0110, acc_test=0.9974
# poison_percent 30 round 86: loss_train=2.5423, acc_train=0.6985, loss_test=0.0110, acc_test=0.9974
# poison_percent 30 round 87: loss_train=2.5688, acc_train=0.6988, loss_test=0.0110, acc_test=0.9974
# poison_percent 30 round 88: loss_train=2.5751, acc_train=0.6971, loss_test=0.0110, acc_test=0.9974
# poison_percent 30 round 89: loss_train=2.5722, acc_train=0.6988, loss_test=0.0110, acc_test=0.9974
# poison_percent 30 round 90: loss_train=2.6229, acc_train=0.6993, loss_test=0.0109, acc_test=0.9974
# poison_percent 30 round 91: loss_train=2.6011, acc_train=0.6971, loss_test=0.0109, acc_test=0.9969
# poison_percent 30 round 92: loss_train=2.5756, acc_train=0.6974, loss_test=0.0109, acc_test=0.9969
# poison_percent 30 round 93: loss_train=2.5469, acc_train=0.6969, loss_test=0.0109, acc_test=0.9969
# poison_percent 30 round 94: loss_train=2.5592, acc_train=0.6982, loss_test=0.0109, acc_test=0.9969
# poison_percent 30 round 95: loss_train=2.5640, acc_train=0.6988, loss_test=0.0109, acc_test=0.9969
# poison_percent 30 round 96: loss_train=2.5606, acc_train=0.6977, loss_test=0.0109, acc_test=0.9969
# poison_percent 30 round 97: loss_train=2.5713, acc_train=0.6988, loss_test=0.0109, acc_test=0.9969
# poison_percent 30 round 98: loss_train=2.5752, acc_train=0.6982, loss_test=0.0109, acc_test=0.9969
# poison_percent 30 round 99: loss_train=2.5817, acc_train=0.6977, loss_test=0.0109, acc_test=0.9969
# Training log saved to ./results\FL_ModelN1L3_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=3.4610, acc_train=0.5988, loss_test=0.0109, acc_test=0.9969
# poison_percent 40 round 1: loss_train=3.4597, acc_train=0.5986, loss_test=0.0109, acc_test=0.9969
# poison_percent 40 round 2: loss_train=3.4391, acc_train=0.5979, loss_test=0.0110, acc_test=0.9969
# poison_percent 40 round 3: loss_train=3.4277, acc_train=0.5983, loss_test=0.0110, acc_test=0.9969
# poison_percent 40 round 4: loss_train=3.4355, acc_train=0.5981, loss_test=0.0111, acc_test=0.9969
# poison_percent 40 round 5: loss_train=3.4437, acc_train=0.5974, loss_test=0.0112, acc_test=0.9969
# poison_percent 40 round 6: loss_train=3.3963, acc_train=0.5970, loss_test=0.0112, acc_test=0.9969
# poison_percent 40 round 7: loss_train=3.3566, acc_train=0.5972, loss_test=0.0112, acc_test=0.9969
# poison_percent 40 round 8: loss_train=3.3814, acc_train=0.5972, loss_test=0.0113, acc_test=0.9969
# poison_percent 40 round 9: loss_train=3.3536, acc_train=0.5977, loss_test=0.0113, acc_test=0.9969
# poison_percent 40 round 10: loss_train=3.3363, acc_train=0.5981, loss_test=0.0114, acc_test=0.9969
# poison_percent 40 round 11: loss_train=3.3476, acc_train=0.5986, loss_test=0.0114, acc_test=0.9969
# poison_percent 40 round 12: loss_train=3.3023, acc_train=0.5979, loss_test=0.0115, acc_test=0.9969
# poison_percent 40 round 13: loss_train=3.3254, acc_train=0.5972, loss_test=0.0115, acc_test=0.9969
# poison_percent 40 round 14: loss_train=3.3081, acc_train=0.5963, loss_test=0.0116, acc_test=0.9969
# poison_percent 40 round 15: loss_train=3.3264, acc_train=0.5981, loss_test=0.0116, acc_test=0.9969
# poison_percent 40 round 16: loss_train=3.3141, acc_train=0.5977, loss_test=0.0116, acc_test=0.9969
# poison_percent 40 round 17: loss_train=3.3087, acc_train=0.5988, loss_test=0.0117, acc_test=0.9969
# poison_percent 40 round 18: loss_train=3.2879, acc_train=0.5979, loss_test=0.0117, acc_test=0.9969
# poison_percent 40 round 19: loss_train=3.2661, acc_train=0.5970, loss_test=0.0118, acc_test=0.9969
# poison_percent 40 round 20: loss_train=3.2663, acc_train=0.5988, loss_test=0.0118, acc_test=0.9969
# poison_percent 40 round 21: loss_train=3.2668, acc_train=0.5963, loss_test=0.0119, acc_test=0.9969
# poison_percent 40 round 22: loss_train=3.2323, acc_train=0.5970, loss_test=0.0119, acc_test=0.9969
# poison_percent 40 round 23: loss_train=3.2212, acc_train=0.5990, loss_test=0.0120, acc_test=0.9969
# poison_percent 40 round 24: loss_train=3.2637, acc_train=0.5974, loss_test=0.0120, acc_test=0.9969
# poison_percent 40 round 25: loss_train=3.1805, acc_train=0.5970, loss_test=0.0121, acc_test=0.9969
# poison_percent 40 round 26: loss_train=3.2199, acc_train=0.5986, loss_test=0.0121, acc_test=0.9969
# poison_percent 40 round 27: loss_train=3.1763, acc_train=0.5967, loss_test=0.0122, acc_test=0.9969
# poison_percent 40 round 28: loss_train=3.1948, acc_train=0.5981, loss_test=0.0123, acc_test=0.9969
# poison_percent 40 round 29: loss_train=3.1276, acc_train=0.5979, loss_test=0.0123, acc_test=0.9969
# poison_percent 40 round 30: loss_train=3.1751, acc_train=0.5977, loss_test=0.0123, acc_test=0.9969
# poison_percent 40 round 31: loss_train=3.1701, acc_train=0.5983, loss_test=0.0124, acc_test=0.9969
# poison_percent 40 round 32: loss_train=3.1344, acc_train=0.5979, loss_test=0.0124, acc_test=0.9969
# poison_percent 40 round 33: loss_train=3.1684, acc_train=0.5979, loss_test=0.0125, acc_test=0.9969
# poison_percent 40 round 34: loss_train=3.1417, acc_train=0.5981, loss_test=0.0125, acc_test=0.9969
# poison_percent 40 round 35: loss_train=3.0610, acc_train=0.6002, loss_test=0.0126, acc_test=0.9969
# poison_percent 40 round 36: loss_train=3.1191, acc_train=0.5986, loss_test=0.0126, acc_test=0.9964
# poison_percent 40 round 37: loss_train=3.1353, acc_train=0.5986, loss_test=0.0127, acc_test=0.9964
# poison_percent 40 round 38: loss_train=3.0933, acc_train=0.5990, loss_test=0.0127, acc_test=0.9964
# poison_percent 40 round 39: loss_train=3.0966, acc_train=0.5979, loss_test=0.0127, acc_test=0.9959
# poison_percent 40 round 40: loss_train=3.0971, acc_train=0.5988, loss_test=0.0128, acc_test=0.9959
# poison_percent 40 round 41: loss_train=3.0709, acc_train=0.5972, loss_test=0.0128, acc_test=0.9959
# poison_percent 40 round 42: loss_train=3.0827, acc_train=0.5990, loss_test=0.0128, acc_test=0.9959
# poison_percent 40 round 43: loss_train=3.0503, acc_train=0.5993, loss_test=0.0129, acc_test=0.9959
# poison_percent 40 round 44: loss_train=3.0917, acc_train=0.5981, loss_test=0.0130, acc_test=0.9959
# poison_percent 40 round 45: loss_train=3.0749, acc_train=0.5988, loss_test=0.0130, acc_test=0.9959
# poison_percent 40 round 46: loss_train=3.0436, acc_train=0.5993, loss_test=0.0131, acc_test=0.9959
# poison_percent 40 round 47: loss_train=3.0428, acc_train=0.5997, loss_test=0.0132, acc_test=0.9959
# poison_percent 40 round 48: loss_train=3.0070, acc_train=0.5988, loss_test=0.0132, acc_test=0.9959
# poison_percent 40 round 49: loss_train=3.0474, acc_train=0.5990, loss_test=0.0132, acc_test=0.9959
# poison_percent 40 round 50: loss_train=3.0336, acc_train=0.5988, loss_test=0.0133, acc_test=0.9959
# poison_percent 40 round 51: loss_train=3.0212, acc_train=0.5993, loss_test=0.0133, acc_test=0.9959
# poison_percent 40 round 52: loss_train=2.9906, acc_train=0.5995, loss_test=0.0134, acc_test=0.9959
# poison_percent 40 round 53: loss_train=3.0334, acc_train=0.5977, loss_test=0.0134, acc_test=0.9959
# poison_percent 40 round 54: loss_train=2.9699, acc_train=0.5993, loss_test=0.0135, acc_test=0.9959
# poison_percent 40 round 55: loss_train=2.9787, acc_train=0.6006, loss_test=0.0135, acc_test=0.9959
# poison_percent 40 round 56: loss_train=2.9853, acc_train=0.5990, loss_test=0.0136, acc_test=0.9959
# poison_percent 40 round 57: loss_train=2.9953, acc_train=0.5983, loss_test=0.0137, acc_test=0.9959
# poison_percent 40 round 58: loss_train=2.9419, acc_train=0.5986, loss_test=0.0137, acc_test=0.9959
# poison_percent 40 round 59: loss_train=2.9485, acc_train=0.5986, loss_test=0.0138, acc_test=0.9959
# poison_percent 40 round 60: loss_train=2.9876, acc_train=0.5979, loss_test=0.0138, acc_test=0.9959
# poison_percent 40 round 61: loss_train=2.9436, acc_train=0.5983, loss_test=0.0138, acc_test=0.9959
# poison_percent 40 round 62: loss_train=2.9583, acc_train=0.5981, loss_test=0.0139, acc_test=0.9959
# poison_percent 40 round 63: loss_train=2.9201, acc_train=0.5983, loss_test=0.0139, acc_test=0.9959
# poison_percent 40 round 64: loss_train=2.9444, acc_train=0.5997, loss_test=0.0139, acc_test=0.9959
# poison_percent 40 round 65: loss_train=2.9321, acc_train=0.5990, loss_test=0.0140, acc_test=0.9959
# poison_percent 40 round 66: loss_train=2.9569, acc_train=0.6002, loss_test=0.0141, acc_test=0.9959
# poison_percent 40 round 67: loss_train=2.9071, acc_train=0.5986, loss_test=0.0141, acc_test=0.9959
# poison_percent 40 round 68: loss_train=2.9224, acc_train=0.5995, loss_test=0.0141, acc_test=0.9959
# poison_percent 40 round 69: loss_train=2.9114, acc_train=0.5990, loss_test=0.0142, acc_test=0.9959
# poison_percent 40 round 70: loss_train=2.8933, acc_train=0.5977, loss_test=0.0142, acc_test=0.9959
# poison_percent 40 round 71: loss_train=2.8949, acc_train=0.5972, loss_test=0.0143, acc_test=0.9959
# poison_percent 40 round 72: loss_train=2.8809, acc_train=0.5995, loss_test=0.0143, acc_test=0.9959
# poison_percent 40 round 73: loss_train=2.8774, acc_train=0.5993, loss_test=0.0144, acc_test=0.9959
# poison_percent 40 round 74: loss_train=2.8589, acc_train=0.6004, loss_test=0.0144, acc_test=0.9959
# poison_percent 40 round 75: loss_train=2.8599, acc_train=0.5977, loss_test=0.0145, acc_test=0.9959
# poison_percent 40 round 76: loss_train=2.8632, acc_train=0.5986, loss_test=0.0145, acc_test=0.9959
# poison_percent 40 round 77: loss_train=2.8424, acc_train=0.5979, loss_test=0.0146, acc_test=0.9959
# poison_percent 40 round 78: loss_train=2.8651, acc_train=0.5988, loss_test=0.0146, acc_test=0.9959
# poison_percent 40 round 79: loss_train=2.8198, acc_train=0.5986, loss_test=0.0146, acc_test=0.9959
# poison_percent 40 round 80: loss_train=2.8476, acc_train=0.5988, loss_test=0.0147, acc_test=0.9959
# poison_percent 40 round 81: loss_train=2.8389, acc_train=0.5990, loss_test=0.0147, acc_test=0.9959
# ...
# poison_percent 40 round 41: loss_train=0.6932, acc_train=0.4482, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 42: loss_train=0.6932, acc_train=0.4443, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 43: loss_train=0.6932, acc_train=0.4450, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 44: loss_train=0.6932, acc_train=0.4415, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 45: loss_train=0.6932, acc_train=0.4413, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 46: loss_train=0.6932, acc_train=0.4399, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 47: loss_train=0.6932, acc_train=0.4380, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 48: loss_train=0.6932, acc_train=0.4459, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 49: loss_train=0.6932, acc_train=0.4399, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 50: loss_train=0.6932, acc_train=0.4374, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 51: loss_train=0.6932, acc_train=0.4417, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 52: loss_train=0.6932, acc_train=0.4397, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 53: loss_train=0.6932, acc_train=0.4456, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 54: loss_train=0.6932, acc_train=0.4436, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 55: loss_train=0.6932, acc_train=0.4392, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 56: loss_train=0.6932, acc_train=0.4404, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 57: loss_train=0.6932, acc_train=0.4417, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 58: loss_train=0.6932, acc_train=0.4413, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 59: loss_train=0.6932, acc_train=0.4410, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 60: loss_train=0.6932, acc_train=0.4383, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 61: loss_train=0.6932, acc_train=0.4498, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 62: loss_train=0.6932, acc_train=0.4466, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 63: loss_train=0.6932, acc_train=0.4470, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 64: loss_train=0.6932, acc_train=0.4394, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 65: loss_train=0.6932, acc_train=0.4406, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 66: loss_train=0.6932, acc_train=0.4447, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 67: loss_train=0.6932, acc_train=0.4408, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 68: loss_train=0.6932, acc_train=0.4484, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 69: loss_train=0.6932, acc_train=0.4433, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 70: loss_train=0.6932, acc_train=0.4461, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 71: loss_train=0.6932, acc_train=0.4399, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 72: loss_train=0.6932, acc_train=0.4440, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 73: loss_train=0.6932, acc_train=0.4468, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 74: loss_train=0.6932, acc_train=0.4463, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 75: loss_train=0.6932, acc_train=0.4413, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 76: loss_train=0.6932, acc_train=0.4454, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 77: loss_train=0.6932, acc_train=0.4383, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 78: loss_train=0.6932, acc_train=0.4475, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 79: loss_train=0.6932, acc_train=0.4369, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 80: loss_train=0.6932, acc_train=0.4413, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 81: loss_train=0.6932, acc_train=0.4374, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 82: loss_train=0.6932, acc_train=0.4374, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 83: loss_train=0.6932, acc_train=0.4447, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 84: loss_train=0.6932, acc_train=0.4436, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 85: loss_train=0.6932, acc_train=0.4339, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 86: loss_train=0.6932, acc_train=0.4459, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 87: loss_train=0.6932, acc_train=0.4417, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 88: loss_train=0.6932, acc_train=0.4422, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 89: loss_train=0.6932, acc_train=0.4413, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 90: loss_train=0.6932, acc_train=0.4410, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 91: loss_train=0.6932, acc_train=0.4369, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 92: loss_train=0.6932, acc_train=0.4447, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 93: loss_train=0.6932, acc_train=0.4450, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 94: loss_train=0.6932, acc_train=0.4436, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 95: loss_train=0.6932, acc_train=0.4406, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 96: loss_train=0.6932, acc_train=0.4413, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 97: loss_train=0.6932, acc_train=0.4454, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 98: loss_train=0.6932, acc_train=0.4433, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 99: loss_train=0.6932, acc_train=0.4433, loss_test=0.6931, acc_test=0.5000
# Training log saved to ./results\FL_ModelN1L6_Batchsize32_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 round 0: loss_train=0.6932, acc_train=0.4421, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 1: loss_train=0.6932, acc_train=0.4463, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 2: loss_train=0.6932, acc_train=0.4406, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 3: loss_train=0.6932, acc_train=0.4431, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 4: loss_train=0.6932, acc_train=0.4504, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 5: loss_train=0.6932, acc_train=0.4377, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 6: loss_train=0.6932, acc_train=0.4419, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 7: loss_train=0.6932, acc_train=0.4452, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 8: loss_train=0.6932, acc_train=0.4467, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 9: loss_train=0.6932, acc_train=0.4492, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 10: loss_train=0.6932, acc_train=0.4360, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 11: loss_train=0.6932, acc_train=0.4487, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 12: loss_train=0.6932, acc_train=0.4396, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 13: loss_train=0.6932, acc_train=0.4408, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 14: loss_train=0.6932, acc_train=0.4377, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 15: loss_train=0.6932, acc_train=0.4442, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 16: loss_train=0.6932, acc_train=0.4425, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 17: loss_train=0.6932, acc_train=0.4427, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 18: loss_train=0.6932, acc_train=0.4450, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 19: loss_train=0.6932, acc_train=0.4498, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 20: loss_train=0.6932, acc_train=0.4412, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 21: loss_train=0.6932, acc_train=0.4385, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 22: loss_train=0.6932, acc_train=0.4390, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 23: loss_train=0.6932, acc_train=0.4381, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 24: loss_train=0.6932, acc_train=0.4377, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 25: loss_train=0.6932, acc_train=0.4454, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 26: loss_train=0.6932, acc_train=0.4410, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 27: loss_train=0.6932, acc_train=0.4404, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 28: loss_train=0.6932, acc_train=0.4433, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 29: loss_train=0.6932, acc_train=0.4425, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 30: loss_train=0.6932, acc_train=0.4435, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 31: loss_train=0.6932, acc_train=0.4467, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 32: loss_train=0.6932, acc_train=0.4365, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 33: loss_train=0.6932, acc_train=0.4435, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 34: loss_train=0.6932, acc_train=0.4419, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 35: loss_train=0.6932, acc_train=0.4365, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 36: loss_train=0.6932, acc_train=0.4406, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 37: loss_train=0.6932, acc_train=0.4460, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 38: loss_train=0.6932, acc_train=0.4450, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 39: loss_train=0.6932, acc_train=0.4415, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 40: loss_train=0.6932, acc_train=0.4477, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 41: loss_train=0.6932, acc_train=0.4431, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 42: loss_train=0.6932, acc_train=0.4502, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 43: loss_train=0.6932, acc_train=0.4400, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 44: loss_train=0.6932, acc_train=0.4423, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 45: loss_train=0.6932, acc_train=0.4400, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 46: loss_train=0.6932, acc_train=0.4456, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 47: loss_train=0.6932, acc_train=0.4383, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 48: loss_train=0.6932, acc_train=0.4415, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 49: loss_train=0.6932, acc_train=0.4427, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 50: loss_train=0.6932, acc_train=0.4404, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 51: loss_train=0.6932, acc_train=0.4440, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 52: loss_train=0.6932, acc_train=0.4452, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 53: loss_train=0.6932, acc_train=0.4421, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 54: loss_train=0.6932, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 55: loss_train=0.6932, acc_train=0.4413, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 56: loss_train=0.6932, acc_train=0.4433, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 57: loss_train=0.6932, acc_train=0.4402, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 58: loss_train=0.6932, acc_train=0.4419, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 59: loss_train=0.6932, acc_train=0.4415, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 60: loss_train=0.6932, acc_train=0.4452, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 61: loss_train=0.6932, acc_train=0.4460, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 62: loss_train=0.6932, acc_train=0.4492, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 63: loss_train=0.6932, acc_train=0.4427, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 64: loss_train=0.6932, acc_train=0.4471, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 65: loss_train=0.6932, acc_train=0.4423, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 66: loss_train=0.6932, acc_train=0.4390, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 67: loss_train=0.6932, acc_train=0.4481, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 68: loss_train=0.6932, acc_train=0.4431, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 69: loss_train=0.6932, acc_train=0.4415, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 70: loss_train=0.6932, acc_train=0.4388, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 71: loss_train=0.6932, acc_train=0.4440, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 72: loss_train=0.6932, acc_train=0.4473, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 73: loss_train=0.6932, acc_train=0.4404, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 74: loss_train=0.6932, acc_train=0.4450, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 75: loss_train=0.6932, acc_train=0.4410, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 76: loss_train=0.6932, acc_train=0.4435, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 77: loss_train=0.6932, acc_train=0.4398, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 78: loss_train=0.6932, acc_train=0.4444, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 79: loss_train=0.6932, acc_train=0.4415, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 80: loss_train=0.6932, acc_train=0.4406, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 81: loss_train=0.6932, acc_train=0.4488, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 82: loss_train=0.6932, acc_train=0.4429, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 83: loss_train=0.6932, acc_train=0.4452, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 84: loss_train=0.6932, acc_train=0.4458, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 85: loss_train=0.6932, acc_train=0.4417, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 86: loss_train=0.6932, acc_train=0.4398, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 87: loss_train=0.6932, acc_train=0.4417, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 88: loss_train=0.6932, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 89: loss_train=0.6932, acc_train=0.4419, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 90: loss_train=0.6932, acc_train=0.4460, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 91: loss_train=0.6932, acc_train=0.4417, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 92: loss_train=0.6932, acc_train=0.4442, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 93: loss_train=0.6932, acc_train=0.4435, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 94: loss_train=0.6932, acc_train=0.4463, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 95: loss_train=0.6932, acc_train=0.4417, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 96: loss_train=0.6932, acc_train=0.4417, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 97: loss_train=0.6932, acc_train=0.4394, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 98: loss_train=0.6932, acc_train=0.4406, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 round 99: loss_train=0.6932, acc_train=0.4440, loss_test=0.6931, acc_test=0.5000
# Training log saved to ./results\FL_ModelN1L6_Batchsize32_rev2\poisoned_50percent\poisoned_50percent.csv
