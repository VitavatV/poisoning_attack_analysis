# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    model = MNISTNet().to(device)
    model.load_state_dict(global_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end]
            yb = y_c_tensor[start:end]
            outputs = model(xb)
            preds = (outputs >= 0.5).float()
            loss = binary_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # Return a deepcopy to avoid issues with state_dict references
    return copy.deepcopy(model.state_dict()), X_c_tensor.size(0), yb, outputs, preds

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 1
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "./data/mnist_binary_poison/train"
TEST_PATH = "./data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [50] #[0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 100 for percent: 50
# Poison n list: [100]

# %%
for NODE in [2]:#[1,2,4,8,16,32]:
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, 1)
            self.relu = nn.ReLU()
        def forward(self, x):
            x = self.fc1(x)
            x = self.relu(x)
            x = self.fc2(x)
            x = torch.sigmoid(x)
            return x

    BATCH_SIZE_list = []
    temp_bs = BATCH_SIZE
    while temp_bs >= 1:
        BATCH_SIZE_list.append(temp_bs)
        temp_bs = temp_bs // 2

    for rev in range(3):

        global_model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"FL_ModelN{NODE}L2_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                torch.save(global_model, os.path.join(save_path,'model_init.pt'))
                global_weights = global_model.state_dict()

                records = []

                X_train_tensor = {}
                y_train_tensor = {}
                for i in range(N_HONEST):
                    X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"honest_{i}"] = X_c_tensor
                    y_train_tensor[f"honest_{i}"] = y_c_tensor
                for i in range(i_poisoned):
                    X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"poison_{i}"] = X_c_tensor
                    y_train_tensor[f"poison_{i}"] = y_c_tensor

                # Training loop
                for round in range(ROUNDS):
                    # Prepare arguments for honest clients
                    
                    #randomize the training data
                    for i in range(N_HONEST):
                        perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                        X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                        y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                    honest_args = [
                        (
                            X_train_tensor[f"honest_{i}"],
                            y_train_tensor[f"honest_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(N_HONEST)
                    ]

                    # Prepare arguments for poisoned clients
                    
                    #randomize the training data
                    for i in range(i_poisoned):
                        perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                        X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                        y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                    poison_args = [
                        (
                            X_train_tensor[f"poison_{i}"],
                            y_train_tensor[f"poison_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(i_poisoned)
                    ]

                    # Run in parallel
                    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                        honest_results = list(executor.map(train_local_worker, honest_args))
                        poison_results = list(executor.map(train_local_worker, poison_args))

                    local_weights = []
                    local_sizes = []
                    local_y = []
                    local_outputs = []
                    local_preds = []
                    for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                        local_weights.append(l_w)
                        local_sizes.append(l_sz)
                        local_y.extend(l_y)
                        local_outputs.extend(l_out)
                        local_preds.extend(l_pred)
                    loss_train = binary_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                    acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                    # Federated averaging (weighted by client data size)
                    new_weights = {}
                    for key in global_weights.keys():
                        new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                    global_weights = new_weights
                    global_model.load_state_dict(global_weights)

                    # Evaluate
                    global_model.eval()
                    with torch.no_grad():
                        outputs = global_model(X_test_tensor)
                        preds = (outputs > 0.5).float()
                        loss_test = binary_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'round': round, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"round {round}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(global_model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['round'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['round'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 50 round 0: loss_train=0.4317, acc_train=0.9600, loss_test=0.5842, acc_test=0.8944
# poison_percent 50 round 1: loss_train=0.3857, acc_train=0.9950, loss_test=0.5341, acc_test=0.8617
# poison_percent 50 round 2: loss_train=0.4155, acc_train=0.9700, loss_test=0.5163, acc_test=0.8760
# poison_percent 50 round 3: loss_train=0.3842, acc_train=0.9700, loss_test=0.5032, acc_test=0.9010
# poison_percent 50 round 4: loss_train=0.3975, acc_train=0.9750, loss_test=0.4885, acc_test=0.9153
# poison_percent 50 round 5: loss_train=0.4021, acc_train=0.9850, loss_test=0.4798, acc_test=0.9327
# poison_percent 50 round 6: loss_train=0.3955, acc_train=0.9850, loss_test=0.4743, acc_test=0.9357
# poison_percent 50 round 7: loss_train=0.3871, acc_train=0.9550, loss_test=0.4697, acc_test=0.9449
# poison_percent 50 round 8: loss_train=0.3771, acc_train=0.9950, loss_test=0.4670, acc_test=0.9485
# poison_percent 50 round 9: loss_train=0.3668, acc_train=0.9800, loss_test=0.4641, acc_test=0.9556
# poison_percent 50 round 10: loss_train=0.3972, acc_train=0.9550, loss_test=0.4616, acc_test=0.9531
# poison_percent 50 round 11: loss_train=0.3476, acc_train=0.9750, loss_test=0.4613, acc_test=0.9536
# poison_percent 50 round 12: loss_train=0.3630, acc_train=0.9800, loss_test=0.4613, acc_test=0.9551
# poison_percent 50 round 13: loss_train=0.3633, acc_train=0.9750, loss_test=0.4611, acc_test=0.9536
# poison_percent 50 round 14: loss_train=0.3595, acc_train=0.9700, loss_test=0.4606, acc_test=0.9551
# poison_percent 50 round 15: loss_train=0.3686, acc_train=0.9750, loss_test=0.4601, acc_test=0.9520
# poison_percent 50 round 16: loss_train=0.3543, acc_train=0.9750, loss_test=0.4592, acc_test=0.9510
# poison_percent 50 round 17: loss_train=0.3483, acc_train=0.9950, loss_test=0.4589, acc_test=0.9480
# poison_percent 50 round 18: loss_train=0.3582, acc_train=0.9750, loss_test=0.4582, acc_test=0.9454
# poison_percent 50 round 19: loss_train=0.3527, acc_train=0.9600, loss_test=0.4605, acc_test=0.9459
# poison_percent 50 round 20: loss_train=0.3414, acc_train=0.9800, loss_test=0.4591, acc_test=0.9423
# poison_percent 50 round 21: loss_train=0.3540, acc_train=0.9750, loss_test=0.4605, acc_test=0.9408
# poison_percent 50 round 22: loss_train=0.3299, acc_train=0.9700, loss_test=0.4594, acc_test=0.9423
# poison_percent 50 round 23: loss_train=0.3409, acc_train=0.9600, loss_test=0.4597, acc_test=0.9372
# poison_percent 50 round 24: loss_train=0.3173, acc_train=0.9750, loss_test=0.4609, acc_test=0.9352
# poison_percent 50 round 25: loss_train=0.3415, acc_train=0.9550, loss_test=0.4577, acc_test=0.9342
# poison_percent 50 round 26: loss_train=0.3280, acc_train=0.9700, loss_test=0.4604, acc_test=0.9352
# poison_percent 50 round 27: loss_train=0.3447, acc_train=0.9500, loss_test=0.4591, acc_test=0.9347
# poison_percent 50 round 28: loss_train=0.3333, acc_train=0.9600, loss_test=0.4584, acc_test=0.9352
# poison_percent 50 round 29: loss_train=0.3479, acc_train=0.9700, loss_test=0.4572, acc_test=0.9372
# poison_percent 50 round 30: loss_train=0.3202, acc_train=0.9750, loss_test=0.4558, acc_test=0.9367
# poison_percent 50 round 31: loss_train=0.3312, acc_train=0.9900, loss_test=0.4566, acc_test=0.9347
# poison_percent 50 round 32: loss_train=0.3602, acc_train=0.9500, loss_test=0.4571, acc_test=0.9352
# poison_percent 50 round 33: loss_train=0.3392, acc_train=0.9650, loss_test=0.4586, acc_test=0.9342
# poison_percent 50 round 34: loss_train=0.3416, acc_train=0.9700, loss_test=0.4592, acc_test=0.9332
# poison_percent 50 round 35: loss_train=0.3283, acc_train=0.9650, loss_test=0.4574, acc_test=0.9337
# poison_percent 50 round 36: loss_train=0.3364, acc_train=0.9500, loss_test=0.4576, acc_test=0.9316
# poison_percent 50 round 37: loss_train=0.3176, acc_train=0.9700, loss_test=0.4590, acc_test=0.9311
# poison_percent 50 round 38: loss_train=0.3259, acc_train=0.9550, loss_test=0.4591, acc_test=0.9316
# poison_percent 50 round 39: loss_train=0.3230, acc_train=0.9700, loss_test=0.4596, acc_test=0.9301
# poison_percent 50 round 40: loss_train=0.3163, acc_train=0.9750, loss_test=0.4594, acc_test=0.9296
# poison_percent 50 round 41: loss_train=0.3351, acc_train=0.9650, loss_test=0.4584, acc_test=0.9286
# poison_percent 50 round 42: loss_train=0.3067, acc_train=0.9650, loss_test=0.4587, acc_test=0.9281
# poison_percent 50 round 43: loss_train=0.3474, acc_train=0.9550, loss_test=0.4572, acc_test=0.9286
# poison_percent 50 round 44: loss_train=0.3139, acc_train=0.9600, loss_test=0.4586, acc_test=0.9250
# poison_percent 50 round 45: loss_train=0.3246, acc_train=0.9700, loss_test=0.4585, acc_test=0.9245
# poison_percent 50 round 46: loss_train=0.3009, acc_train=0.9650, loss_test=0.4580, acc_test=0.9235
# poison_percent 50 round 47: loss_train=0.3073, acc_train=0.9550, loss_test=0.4569, acc_test=0.9235
# poison_percent 50 round 48: loss_train=0.3067, acc_train=0.9600, loss_test=0.4595, acc_test=0.9204
# poison_percent 50 round 49: loss_train=0.3005, acc_train=0.9550, loss_test=0.4565, acc_test=0.9230
# poison_percent 50 round 50: loss_train=0.3238, acc_train=0.9700, loss_test=0.4557, acc_test=0.9230
# poison_percent 50 round 51: loss_train=0.3452, acc_train=0.9650, loss_test=0.4570, acc_test=0.9204
# poison_percent 50 round 52: loss_train=0.3259, acc_train=0.9400, loss_test=0.4587, acc_test=0.9194
# poison_percent 50 round 53: loss_train=0.3198, acc_train=0.9700, loss_test=0.4610, acc_test=0.9153
# poison_percent 50 round 54: loss_train=0.2861, acc_train=0.9700, loss_test=0.4590, acc_test=0.9189
# poison_percent 50 round 55: loss_train=0.3095, acc_train=0.9450, loss_test=0.4626, acc_test=0.9143
# poison_percent 50 round 56: loss_train=0.3017, acc_train=0.9700, loss_test=0.4624, acc_test=0.9133
# poison_percent 50 round 57: loss_train=0.3086, acc_train=0.9600, loss_test=0.4603, acc_test=0.9107
# poison_percent 50 round 58: loss_train=0.3003, acc_train=0.9300, loss_test=0.4618, acc_test=0.9051
# poison_percent 50 round 59: loss_train=0.3557, acc_train=0.9300, loss_test=0.4622, acc_test=0.9046
# poison_percent 50 round 60: loss_train=0.2946, acc_train=0.9650, loss_test=0.4603, acc_test=0.9056
# poison_percent 50 round 61: loss_train=0.3061, acc_train=0.9550, loss_test=0.4616, acc_test=0.9031
# poison_percent 50 round 62: loss_train=0.2819, acc_train=0.9700, loss_test=0.4619, acc_test=0.9000
# poison_percent 50 round 63: loss_train=0.2740, acc_train=0.9750, loss_test=0.4657, acc_test=0.8918
# poison_percent 50 round 64: loss_train=0.3092, acc_train=0.9250, loss_test=0.4664, acc_test=0.8908
# poison_percent 50 round 65: loss_train=0.2999, acc_train=0.9550, loss_test=0.4684, acc_test=0.8883
# poison_percent 50 round 66: loss_train=0.2813, acc_train=0.9500, loss_test=0.4673, acc_test=0.8893
# poison_percent 50 round 67: loss_train=0.3008, acc_train=0.9550, loss_test=0.4685, acc_test=0.8888
# poison_percent 50 round 68: loss_train=0.2870, acc_train=0.9500, loss_test=0.4709, acc_test=0.8827
# poison_percent 50 round 69: loss_train=0.2972, acc_train=0.9650, loss_test=0.4746, acc_test=0.8740
# poison_percent 50 round 70: loss_train=0.2780, acc_train=0.9700, loss_test=0.4771, acc_test=0.8673
# poison_percent 50 round 71: loss_train=0.2597, acc_train=0.9600, loss_test=0.4802, acc_test=0.8628
# poison_percent 50 round 72: loss_train=0.2758, acc_train=0.9600, loss_test=0.4821, acc_test=0.8582
# poison_percent 50 round 73: loss_train=0.2821, acc_train=0.9500, loss_test=0.4873, acc_test=0.8531
# poison_percent 50 round 74: loss_train=0.2925, acc_train=0.9550, loss_test=0.4926, acc_test=0.8418
# poison_percent 50 round 75: loss_train=0.2662, acc_train=0.9650, loss_test=0.5006, acc_test=0.8270
# poison_percent 50 round 76: loss_train=0.2516, acc_train=0.9700, loss_test=0.5056, acc_test=0.8153
# poison_percent 50 round 77: loss_train=0.2418, acc_train=0.9800, loss_test=0.5132, acc_test=0.7974
# poison_percent 50 round 78: loss_train=0.2434, acc_train=0.9550, loss_test=0.5218, acc_test=0.7796
# poison_percent 50 round 79: loss_train=0.2017, acc_train=0.9950, loss_test=0.5295, acc_test=0.7622
# poison_percent 50 round 80: loss_train=0.2344, acc_train=0.9850, loss_test=0.5340, acc_test=0.7510
# poison_percent 50 round 81: loss_train=0.2177, acc_train=0.9900, loss_test=0.5428, acc_test=0.7281
# poison_percent 50 round 82: loss_train=0.2523, acc_train=0.9600, loss_test=0.5474, acc_test=0.7163
# poison_percent 50 round 83: loss_train=0.2176, acc_train=0.9800, loss_test=0.5471, acc_test=0.7158
# poison_percent 50 round 84: loss_train=0.2064, acc_train=0.9850, loss_test=0.5521, acc_test=0.7077
# poison_percent 50 round 85: loss_train=0.2351, acc_train=0.9750, loss_test=0.5563, acc_test=0.7036
# poison_percent 50 round 86: loss_train=0.2186, acc_train=0.9900, loss_test=0.5629, acc_test=0.6898
# poison_percent 50 round 87: loss_train=0.2299, acc_train=0.9750, loss_test=0.5674, acc_test=0.6832
# poison_percent 50 round 88: loss_train=0.1953, acc_train=0.9950, loss_test=0.5712, acc_test=0.6801
# poison_percent 50 round 89: loss_train=0.2012, acc_train=0.9850, loss_test=0.5786, acc_test=0.6709
# poison_percent 50 round 90: loss_train=0.1899, acc_train=1.0000, loss_test=0.5809, acc_test=0.6673
# poison_percent 50 round 91: loss_train=0.2030, acc_train=0.9900, loss_test=0.5817, acc_test=0.6622
# poison_percent 50 round 92: loss_train=0.1928, acc_train=0.9900, loss_test=0.5809, acc_test=0.6648
# poison_percent 50 round 93: loss_train=0.1814, acc_train=0.9900, loss_test=0.5831, acc_test=0.6622
# poison_percent 50 round 94: loss_train=0.1937, acc_train=0.9950, loss_test=0.5848, acc_test=0.6587
# poison_percent 50 round 95: loss_train=0.2007, acc_train=0.9900, loss_test=0.5856, acc_test=0.6582
# poison_percent 50 round 96: loss_train=0.2069, acc_train=0.9800, loss_test=0.5870, acc_test=0.6571
# poison_percent 50 round 97: loss_train=0.1768, acc_train=0.9900, loss_test=0.5874, acc_test=0.6561
# poison_percent 50 round 98: loss_train=0.1775, acc_train=0.9950, loss_test=0.5893, acc_test=0.6551
# poison_percent 50 round 99: loss_train=0.1863, acc_train=0.9800, loss_test=0.5926, acc_test=0.6505
# Training log saved to ./results\FL_ModelN2L2_Batchsize1_rev0\poisoned_50percent\poisoned_50percent.csv
# poison_percent 50 round 0: loss_train=0.4603, acc_train=0.9750, loss_test=0.8325, acc_test=0.0408
# poison_percent 50 round 1: loss_train=0.4028, acc_train=0.9750, loss_test=0.8341, acc_test=0.0214
# poison_percent 50 round 2: loss_train=0.3709, acc_train=0.9800, loss_test=0.8162, acc_test=0.0311
# poison_percent 50 round 3: loss_train=0.3518, acc_train=0.9600, loss_test=0.8093, acc_test=0.0459
# poison_percent 50 round 4: loss_train=0.3643, acc_train=0.9750, loss_test=0.8034, acc_test=0.0541
# poison_percent 50 round 5: loss_train=0.3381, acc_train=0.9850, loss_test=0.7992, acc_test=0.0617
# poison_percent 50 round 6: loss_train=0.3488, acc_train=0.9800, loss_test=0.7905, acc_test=0.0811
# poison_percent 50 round 7: loss_train=0.3356, acc_train=0.9600, loss_test=0.7847, acc_test=0.0867
# poison_percent 50 round 8: loss_train=0.3307, acc_train=0.9600, loss_test=0.7791, acc_test=0.0964
# poison_percent 50 round 9: loss_train=0.3120, acc_train=0.9950, loss_test=0.7747, acc_test=0.1036
# poison_percent 50 round 10: loss_train=0.2955, acc_train=0.9850, loss_test=0.7718, acc_test=0.1015
# poison_percent 50 round 11: loss_train=0.3008, acc_train=0.9750, loss_test=0.7676, acc_test=0.1102
# poison_percent 50 round 12: loss_train=0.2849, acc_train=0.9900, loss_test=0.7629, acc_test=0.1184
# poison_percent 50 round 13: loss_train=0.2859, acc_train=0.9850, loss_test=0.7571, acc_test=0.1337
# poison_percent 50 round 14: loss_train=0.2922, acc_train=0.9900, loss_test=0.7534, acc_test=0.1434
# poison_percent 50 round 15: loss_train=0.2909, acc_train=0.9800, loss_test=0.7480, acc_test=0.1643
# poison_percent 50 round 16: loss_train=0.2859, acc_train=0.9800, loss_test=0.7454, acc_test=0.1765
# poison_percent 50 round 17: loss_train=0.2563, acc_train=0.9950, loss_test=0.7428, acc_test=0.1903
# poison_percent 50 round 18: loss_train=0.2799, acc_train=0.9900, loss_test=0.7399, acc_test=0.2133
# poison_percent 50 round 19: loss_train=0.2625, acc_train=0.9950, loss_test=0.7378, acc_test=0.2301
# poison_percent 50 round 20: loss_train=0.2783, acc_train=0.9950, loss_test=0.7355, acc_test=0.2469
# poison_percent 50 round 21: loss_train=0.2593, acc_train=0.9900, loss_test=0.7323, acc_test=0.2709
# poison_percent 50 round 22: loss_train=0.2681, acc_train=0.9850, loss_test=0.7306, acc_test=0.3000
# poison_percent 50 round 23: loss_train=0.2559, acc_train=0.9900, loss_test=0.7273, acc_test=0.3286
# poison_percent 50 round 24: loss_train=0.2621, acc_train=0.9800, loss_test=0.7269, acc_test=0.3311
# poison_percent 50 round 25: loss_train=0.2178, acc_train=0.9950, loss_test=0.7228, acc_test=0.3454
# poison_percent 50 round 26: loss_train=0.2423, acc_train=0.9850, loss_test=0.7245, acc_test=0.3546
# poison_percent 50 round 27: loss_train=0.2137, acc_train=1.0000, loss_test=0.7219, acc_test=0.3724
# poison_percent 50 round 28: loss_train=0.2445, acc_train=0.9900, loss_test=0.7191, acc_test=0.3770
# poison_percent 50 round 29: loss_train=0.2364, acc_train=1.0000, loss_test=0.7203, acc_test=0.3908
# poison_percent 50 round 30: loss_train=0.2570, acc_train=0.9900, loss_test=0.7186, acc_test=0.4133
# poison_percent 50 round 31: loss_train=0.2416, acc_train=0.9900, loss_test=0.7148, acc_test=0.4255
# poison_percent 50 round 32: loss_train=0.2250, acc_train=1.0000, loss_test=0.7148, acc_test=0.4342
# poison_percent 50 round 33: loss_train=0.2533, acc_train=0.9850, loss_test=0.7142, acc_test=0.4332
# poison_percent 50 round 34: loss_train=0.2179, acc_train=0.9900, loss_test=0.7145, acc_test=0.4337
# poison_percent 50 round 35: loss_train=0.2115, acc_train=0.9950, loss_test=0.7116, acc_test=0.4474
# poison_percent 50 round 36: loss_train=0.2158, acc_train=0.9950, loss_test=0.7113, acc_test=0.4520
# poison_percent 50 round 37: loss_train=0.2046, acc_train=0.9950, loss_test=0.7114, acc_test=0.4607
# poison_percent 50 round 38: loss_train=0.2350, acc_train=0.9800, loss_test=0.7118, acc_test=0.4673
# poison_percent 50 round 39: loss_train=0.2102, acc_train=0.9900, loss_test=0.7122, acc_test=0.4526
# poison_percent 50 round 40: loss_train=0.1933, acc_train=0.9900, loss_test=0.7102, acc_test=0.4587
# poison_percent 50 round 41: loss_train=0.2063, acc_train=0.9850, loss_test=0.7109, acc_test=0.4699
# poison_percent 50 round 42: loss_train=0.2138, acc_train=0.9800, loss_test=0.7095, acc_test=0.4714
# poison_percent 50 round 43: loss_train=0.2035, acc_train=1.0000, loss_test=0.7124, acc_test=0.4730
# poison_percent 50 round 44: loss_train=0.2078, acc_train=1.0000, loss_test=0.7127, acc_test=0.4643
# poison_percent 50 round 45: loss_train=0.2101, acc_train=0.9850, loss_test=0.7128, acc_test=0.4719
# poison_percent 50 round 46: loss_train=0.2005, acc_train=0.9950, loss_test=0.7147, acc_test=0.4689
# poison_percent 50 round 47: loss_train=0.1778, acc_train=0.9900, loss_test=0.7140, acc_test=0.4668
# poison_percent 50 round 48: loss_train=0.1908, acc_train=0.9900, loss_test=0.7143, acc_test=0.4673
# poison_percent 50 round 49: loss_train=0.1905, acc_train=0.9900, loss_test=0.7156, acc_test=0.4541
# poison_percent 50 round 50: loss_train=0.2055, acc_train=0.9900, loss_test=0.7121, acc_test=0.4638
# poison_percent 50 round 51: loss_train=0.1930, acc_train=0.9950, loss_test=0.7120, acc_test=0.4694
# poison_percent 50 round 52: loss_train=0.1845, acc_train=1.0000, loss_test=0.7140, acc_test=0.4607
# poison_percent 50 round 53: loss_train=0.1998, acc_train=0.9900, loss_test=0.7162, acc_test=0.4536
# poison_percent 50 round 54: loss_train=0.2072, acc_train=0.9800, loss_test=0.7182, acc_test=0.4561
# poison_percent 50 round 55: loss_train=0.1575, acc_train=0.9950, loss_test=0.7143, acc_test=0.4668
# poison_percent 50 round 56: loss_train=0.1687, acc_train=1.0000, loss_test=0.7115, acc_test=0.4735
# poison_percent 50 round 57: loss_train=0.1758, acc_train=0.9950, loss_test=0.7144, acc_test=0.4740
# poison_percent 50 round 58: loss_train=0.1584, acc_train=0.9950, loss_test=0.7186, acc_test=0.4776
# poison_percent 50 round 59: loss_train=0.1825, acc_train=0.9750, loss_test=0.7182, acc_test=0.4760
# poison_percent 50 round 60: loss_train=0.1816, acc_train=0.9950, loss_test=0.7165, acc_test=0.4796
# poison_percent 50 round 61: loss_train=0.1702, acc_train=1.0000, loss_test=0.7150, acc_test=0.4786
# poison_percent 50 round 62: loss_train=0.1798, acc_train=0.9800, loss_test=0.7171, acc_test=0.4781
# poison_percent 50 round 63: loss_train=0.1783, acc_train=0.9950, loss_test=0.7182, acc_test=0.4704
# poison_percent 50 round 64: loss_train=0.1631, acc_train=1.0000, loss_test=0.7189, acc_test=0.4663
# poison_percent 50 round 65: loss_train=0.1677, acc_train=0.9950, loss_test=0.7261, acc_test=0.4566
# poison_percent 50 round 66: loss_train=0.1860, acc_train=0.9850, loss_test=0.7187, acc_test=0.4648
# poison_percent 50 round 67: loss_train=0.1628, acc_train=0.9950, loss_test=0.7188, acc_test=0.4689
# poison_percent 50 round 68: loss_train=0.1666, acc_train=1.0000, loss_test=0.7140, acc_test=0.4796
# poison_percent 50 round 69: loss_train=0.1568, acc_train=0.9950, loss_test=0.7128, acc_test=0.4980
# poison_percent 50 round 70: loss_train=0.1597, acc_train=0.9950, loss_test=0.7144, acc_test=0.4939
# poison_percent 50 round 71: loss_train=0.1538, acc_train=1.0000, loss_test=0.7068, acc_test=0.5041
# poison_percent 50 round 72: loss_train=0.1852, acc_train=0.9750, loss_test=0.7084, acc_test=0.5000
# poison_percent 50 round 73: loss_train=0.1502, acc_train=0.9900, loss_test=0.7110, acc_test=0.4974
# poison_percent 50 round 74: loss_train=0.1523, acc_train=0.9900, loss_test=0.7122, acc_test=0.5061
# poison_percent 50 round 75: loss_train=0.1535, acc_train=0.9900, loss_test=0.7091, acc_test=0.5082
# poison_percent 50 round 76: loss_train=0.1514, acc_train=0.9900, loss_test=0.7108, acc_test=0.5026
# poison_percent 50 round 77: loss_train=0.1471, acc_train=1.0000, loss_test=0.7078, acc_test=0.5112
# poison_percent 50 round 78: loss_train=0.1703, acc_train=0.9750, loss_test=0.7052, acc_test=0.5153
# poison_percent 50 round 79: loss_train=0.1499, acc_train=1.0000, loss_test=0.7052, acc_test=0.5179
# poison_percent 50 round 80: loss_train=0.1494, acc_train=0.9950, loss_test=0.7075, acc_test=0.5189
# poison_percent 50 round 81: loss_train=0.1654, acc_train=0.9800, loss_test=0.7087, acc_test=0.5194
# poison_percent 50 round 82: loss_train=0.1519, acc_train=1.0000, loss_test=0.7079, acc_test=0.5158
# poison_percent 50 round 83: loss_train=0.1557, acc_train=0.9850, loss_test=0.7187, acc_test=0.4934
# poison_percent 50 round 84: loss_train=0.1386, acc_train=0.9950, loss_test=0.7202, acc_test=0.4847
# poison_percent 50 round 85: loss_train=0.1423, acc_train=1.0000, loss_test=0.7220, acc_test=0.4821
# poison_percent 50 round 86: loss_train=0.1476, acc_train=0.9900, loss_test=0.7202, acc_test=0.4903
# poison_percent 50 round 87: loss_train=0.1322, acc_train=1.0000, loss_test=0.7160, acc_test=0.4964
# poison_percent 50 round 88: loss_train=0.1471, acc_train=0.9900, loss_test=0.7178, acc_test=0.4918
# poison_percent 50 round 89: loss_train=0.1405, acc_train=0.9900, loss_test=0.7219, acc_test=0.4832
# poison_percent 50 round 90: loss_train=0.1559, acc_train=0.9800, loss_test=0.7253, acc_test=0.4816
# poison_percent 50 round 91: loss_train=0.1430, acc_train=0.9900, loss_test=0.7197, acc_test=0.4944
# poison_percent 50 round 92: loss_train=0.1460, acc_train=0.9950, loss_test=0.7214, acc_test=0.4918
# poison_percent 50 round 93: loss_train=0.1473, acc_train=0.9900, loss_test=0.7208, acc_test=0.4862
# poison_percent 50 round 94: loss_train=0.1470, acc_train=0.9900, loss_test=0.7218, acc_test=0.4934
# poison_percent 50 round 95: loss_train=0.1324, acc_train=1.0000, loss_test=0.7151, acc_test=0.4980
# poison_percent 50 round 96: loss_train=0.1523, acc_train=0.9800, loss_test=0.7207, acc_test=0.4974
# poison_percent 50 round 97: loss_train=0.1288, acc_train=1.0000, loss_test=0.7229, acc_test=0.4893
# poison_percent 50 round 98: loss_train=0.1255, acc_train=0.9950, loss_test=0.7286, acc_test=0.4791
# poison_percent 50 round 99: loss_train=0.1349, acc_train=0.9900, loss_test=0.7323, acc_test=0.4740
# Training log saved to ./results\FL_ModelN2L2_Batchsize1_rev1\poisoned_50percent\poisoned_50percent.csv
# poison_percent 50 round 0: loss_train=0.4366, acc_train=0.8650, loss_test=0.9252, acc_test=0.0321
# poison_percent 50 round 1: loss_train=0.3996, acc_train=0.9550, loss_test=0.9819, acc_test=0.0469
# poison_percent 50 round 2: loss_train=0.3597, acc_train=0.9900, loss_test=0.9843, acc_test=0.0602
# poison_percent 50 round 3: loss_train=0.3620, acc_train=0.9700, loss_test=0.9843, acc_test=0.0684
# poison_percent 50 round 4: loss_train=0.3489, acc_train=0.9750, loss_test=0.9819, acc_test=0.0786
# poison_percent 50 round 5: loss_train=0.3433, acc_train=0.9750, loss_test=0.9881, acc_test=0.0944
# poison_percent 50 round 6: loss_train=0.3538, acc_train=0.9850, loss_test=0.9915, acc_test=0.1031
# poison_percent 50 round 7: loss_train=0.3263, acc_train=0.9850, loss_test=0.9951, acc_test=0.1138
# poison_percent 50 round 8: loss_train=0.3474, acc_train=0.9750, loss_test=0.9981, acc_test=0.1413
# poison_percent 50 round 9: loss_train=0.3436, acc_train=0.9900, loss_test=0.9967, acc_test=0.1474
# poison_percent 50 round 10: loss_train=0.3359, acc_train=0.9750, loss_test=1.0019, acc_test=0.1449
# poison_percent 50 round 11: loss_train=0.3313, acc_train=0.9800, loss_test=1.0120, acc_test=0.1704
# poison_percent 50 round 12: loss_train=0.3352, acc_train=0.9850, loss_test=1.0110, acc_test=0.1505
# poison_percent 50 round 13: loss_train=0.3262, acc_train=0.9800, loss_test=1.0150, acc_test=0.1577
# poison_percent 50 round 14: loss_train=0.3357, acc_train=0.9700, loss_test=1.0120, acc_test=0.1658
# poison_percent 50 round 15: loss_train=0.3253, acc_train=0.9900, loss_test=1.0098, acc_test=0.1913
# poison_percent 50 round 16: loss_train=0.3192, acc_train=0.9850, loss_test=1.0148, acc_test=0.2051
# poison_percent 50 round 17: loss_train=0.3264, acc_train=0.9700, loss_test=1.0142, acc_test=0.2031
# poison_percent 50 round 18: loss_train=0.3173, acc_train=0.9550, loss_test=1.0202, acc_test=0.2041
# poison_percent 50 round 19: loss_train=0.3241, acc_train=0.9700, loss_test=1.0293, acc_test=0.2291
# poison_percent 50 round 20: loss_train=0.3086, acc_train=0.9850, loss_test=1.0236, acc_test=0.2133
# poison_percent 50 round 21: loss_train=0.3159, acc_train=0.9750, loss_test=1.0313, acc_test=0.2112
# poison_percent 50 round 22: loss_train=0.3202, acc_train=0.9600, loss_test=1.0309, acc_test=0.2163
# poison_percent 50 round 23: loss_train=0.3085, acc_train=0.9850, loss_test=1.0315, acc_test=0.2454
# poison_percent 50 round 24: loss_train=0.3077, acc_train=0.9550, loss_test=1.0262, acc_test=0.2413
# poison_percent 50 round 25: loss_train=0.3015, acc_train=0.9700, loss_test=1.0310, acc_test=0.2454
# poison_percent 50 round 26: loss_train=0.2901, acc_train=0.9750, loss_test=1.0223, acc_test=0.2490
# poison_percent 50 round 27: loss_train=0.3123, acc_train=0.9750, loss_test=1.0233, acc_test=0.2622
# poison_percent 50 round 28: loss_train=0.3008, acc_train=0.9750, loss_test=1.0249, acc_test=0.2602
# poison_percent 50 round 29: loss_train=0.3237, acc_train=0.9550, loss_test=1.0283, acc_test=0.2755
# poison_percent 50 round 30: loss_train=0.3014, acc_train=0.9700, loss_test=1.0310, acc_test=0.2699
# poison_percent 50 round 31: loss_train=0.2954, acc_train=0.9850, loss_test=1.0324, acc_test=0.2704
# poison_percent 50 round 32: loss_train=0.3279, acc_train=0.9450, loss_test=1.0316, acc_test=0.2724
# poison_percent 50 round 33: loss_train=0.3108, acc_train=0.9600, loss_test=1.0276, acc_test=0.2806
# poison_percent 50 round 34: loss_train=0.3033, acc_train=0.9650, loss_test=1.0293, acc_test=0.2796
# poison_percent 50 round 35: loss_train=0.2887, acc_train=0.9700, loss_test=1.0262, acc_test=0.2750
# poison_percent 50 round 36: loss_train=0.2950, acc_train=0.9550, loss_test=1.0316, acc_test=0.2852
# poison_percent 50 round 37: loss_train=0.2927, acc_train=0.9550, loss_test=1.0302, acc_test=0.2898
# poison_percent 50 round 38: loss_train=0.2914, acc_train=0.9550, loss_test=1.0268, acc_test=0.3026
# poison_percent 50 round 39: loss_train=0.2892, acc_train=0.9700, loss_test=1.0287, acc_test=0.3061
# poison_percent 50 round 40: loss_train=0.2847, acc_train=0.9700, loss_test=1.0296, acc_test=0.3092
# poison_percent 50 round 41: loss_train=0.2984, acc_train=0.9650, loss_test=1.0267, acc_test=0.3071
# poison_percent 50 round 42: loss_train=0.2678, acc_train=0.9950, loss_test=1.0292, acc_test=0.3122
# poison_percent 50 round 43: loss_train=0.3095, acc_train=0.9500, loss_test=1.0373, acc_test=0.3066
# poison_percent 50 round 44: loss_train=0.3080, acc_train=0.9500, loss_test=1.0333, acc_test=0.3087
# poison_percent 50 round 45: loss_train=0.2719, acc_train=0.9650, loss_test=1.0380, acc_test=0.3056
# poison_percent 50 round 46: loss_train=0.2856, acc_train=0.9900, loss_test=1.0391, acc_test=0.3061
# poison_percent 50 round 47: loss_train=0.3239, acc_train=0.9500, loss_test=1.0358, acc_test=0.3066
# poison_percent 50 round 48: loss_train=0.3003, acc_train=0.9600, loss_test=1.0413, acc_test=0.3128
# poison_percent 50 round 49: loss_train=0.2860, acc_train=0.9650, loss_test=1.0362, acc_test=0.3138
# poison_percent 50 round 50: loss_train=0.2601, acc_train=0.9750, loss_test=1.0457, acc_test=0.3199
# poison_percent 50 round 51: loss_train=0.3001, acc_train=0.9600, loss_test=1.0486, acc_test=0.3214
# poison_percent 50 round 52: loss_train=0.2772, acc_train=0.9600, loss_test=1.0449, acc_test=0.3092
# poison_percent 50 round 53: loss_train=0.3154, acc_train=0.9450, loss_test=1.0489, acc_test=0.3179
# poison_percent 50 round 54: loss_train=0.2526, acc_train=0.9900, loss_test=1.0461, acc_test=0.3194
# poison_percent 50 round 55: loss_train=0.2682, acc_train=0.9750, loss_test=1.0484, acc_test=0.3158
# poison_percent 50 round 56: loss_train=0.2857, acc_train=0.9350, loss_test=1.0571, acc_test=0.3245
# poison_percent 50 round 57: loss_train=0.2840, acc_train=0.9600, loss_test=1.0545, acc_test=0.3250
# poison_percent 50 round 58: loss_train=0.3036, acc_train=0.9500, loss_test=1.0522, acc_test=0.3321
# poison_percent 50 round 59: loss_train=0.2985, acc_train=0.9400, loss_test=1.0581, acc_test=0.3270
# poison_percent 50 round 60: loss_train=0.2760, acc_train=0.9650, loss_test=1.0562, acc_test=0.3260
# poison_percent 50 round 61: loss_train=0.2947, acc_train=0.9400, loss_test=1.0582, acc_test=0.3316
# poison_percent 50 round 62: loss_train=0.2724, acc_train=0.9600, loss_test=1.0432, acc_test=0.3342
# poison_percent 50 round 63: loss_train=0.2870, acc_train=0.9650, loss_test=1.0383, acc_test=0.3464
# poison_percent 50 round 64: loss_train=0.2944, acc_train=0.9350, loss_test=1.0410, acc_test=0.3444
# poison_percent 50 round 65: loss_train=0.2762, acc_train=0.9550, loss_test=1.0378, acc_test=0.3485
# poison_percent 50 round 66: loss_train=0.3186, acc_train=0.9500, loss_test=1.0498, acc_test=0.3439
# poison_percent 50 round 67: loss_train=0.2785, acc_train=0.9550, loss_test=1.0582, acc_test=0.3378
# poison_percent 50 round 68: loss_train=0.2964, acc_train=0.9500, loss_test=1.0506, acc_test=0.3418
# poison_percent 50 round 69: loss_train=0.2740, acc_train=0.9650, loss_test=1.0553, acc_test=0.3418
# poison_percent 50 round 70: loss_train=0.2527, acc_train=0.9550, loss_test=1.0547, acc_test=0.3429
# poison_percent 50 round 71: loss_train=0.2886, acc_train=0.9400, loss_test=1.0601, acc_test=0.3418
# poison_percent 50 round 72: loss_train=0.3187, acc_train=0.9300, loss_test=1.0594, acc_test=0.3449
# poison_percent 50 round 73: loss_train=0.2979, acc_train=0.9500, loss_test=1.0584, acc_test=0.3495
# poison_percent 50 round 74: loss_train=0.2916, acc_train=0.9450, loss_test=1.0615, acc_test=0.3551
# poison_percent 50 round 75: loss_train=0.3221, acc_train=0.9400, loss_test=1.0621, acc_test=0.3505
# poison_percent 50 round 76: loss_train=0.2839, acc_train=0.9600, loss_test=1.0689, acc_test=0.3510
# poison_percent 50 round 77: loss_train=0.3005, acc_train=0.9400, loss_test=1.0574, acc_test=0.3526
# poison_percent 50 round 78: loss_train=0.2987, acc_train=0.9400, loss_test=1.0519, acc_test=0.3571
# poison_percent 50 round 79: loss_train=0.3123, acc_train=0.9350, loss_test=1.0619, acc_test=0.3628
# poison_percent 50 round 80: loss_train=0.2564, acc_train=0.9650, loss_test=1.0666, acc_test=0.3602
# poison_percent 50 round 81: loss_train=0.2739, acc_train=0.9550, loss_test=1.0579, acc_test=0.3648
# poison_percent 50 round 82: loss_train=0.2723, acc_train=0.9650, loss_test=1.0514, acc_test=0.3704
# poison_percent 50 round 83: loss_train=0.2865, acc_train=0.9400, loss_test=1.0502, acc_test=0.3724
# poison_percent 50 round 84: loss_train=0.3014, acc_train=0.9250, loss_test=1.0490, acc_test=0.3745
# poison_percent 50 round 85: loss_train=0.3014, acc_train=0.9600, loss_test=1.0538, acc_test=0.3668
# poison_percent 50 round 86: loss_train=0.2599, acc_train=0.9600, loss_test=1.0569, acc_test=0.3724
# poison_percent 50 round 87: loss_train=0.2670, acc_train=0.9400, loss_test=1.0723, acc_test=0.3673
# poison_percent 50 round 88: loss_train=0.3082, acc_train=0.9450, loss_test=1.0665, acc_test=0.3612
# poison_percent 50 round 89: loss_train=0.2739, acc_train=0.9350, loss_test=1.0674, acc_test=0.3638
# poison_percent 50 round 90: loss_train=0.2971, acc_train=0.9450, loss_test=1.0708, acc_test=0.3673
# poison_percent 50 round 91: loss_train=0.3473, acc_train=0.9400, loss_test=1.0682, acc_test=0.3704
# poison_percent 50 round 92: loss_train=0.2701, acc_train=0.9600, loss_test=1.0811, acc_test=0.3648
# poison_percent 50 round 93: loss_train=0.2865, acc_train=0.9450, loss_test=1.0768, acc_test=0.3628
# poison_percent 50 round 94: loss_train=0.2644, acc_train=0.9550, loss_test=1.0763, acc_test=0.3699
# poison_percent 50 round 95: loss_train=0.3251, acc_train=0.9300, loss_test=1.0901, acc_test=0.3648
# poison_percent 50 round 96: loss_train=0.2786, acc_train=0.9400, loss_test=1.0732, acc_test=0.3673
# poison_percent 50 round 97: loss_train=0.2755, acc_train=0.9550, loss_test=1.0760, acc_test=0.3704
# poison_percent 50 round 98: loss_train=0.2982, acc_train=0.9300, loss_test=1.0706, acc_test=0.3724
# poison_percent 50 round 99: loss_train=0.2779, acc_train=0.9300, loss_test=1.0865, acc_test=0.3673
# Training log saved to ./results\FL_ModelN2L2_Batchsize1_rev2\poisoned_50percent\poisoned_50percent.csv
