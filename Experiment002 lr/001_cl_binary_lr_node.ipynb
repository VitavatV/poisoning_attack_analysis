# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 1
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "./data/mnist_binary_poison/train"
TEST_PATH = "./data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
for NODE in [1,2,4,8,16,32]:
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, 1)
            self.relu = nn.ReLU()
        def forward(self, x):
            x = self.fc1(x)
            x = self.relu(x)
            x = self.fc2(x)
            x = torch.sigmoid(x)
            return x

    BATCH_SIZE_list = []
    temp_bs = BATCH_SIZE
    while temp_bs >= 1:
        BATCH_SIZE_list.append(temp_bs)
        temp_bs = temp_bs // 2

    for rev in range(3):

        model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"CL_ModelN{NODE}L2_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                        poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                        select='Honest+Poisoned')
                X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
                # print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
                # print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")

                X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
                y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                torch.save(model, os.path.join(save_path,'model_init.pt'))
                optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

                records = []

                # Training loop
                for epoch in range(EPOCHS):

                    # Train
                    model.train()
                    
                    #randomize the training data
                    perm = torch.randperm(X_train_tensor.size(0))
                    X_train_tensor = X_train_tensor[perm]
                    y_train_tensor = y_train_tensor[perm]

                    for start in range(0, X_train_tensor.size(0), experiment_bs):
                        end = start + experiment_bs
                        xb = X_train_tensor[start:end]
                        yb = y_train_tensor[start:end]
                        outputs = model(xb)
                        preds = (outputs >= 0.5).float()
                        acc_train = (preds == yb).float().mean().item()
                        loss_train = binary_cross_entropy(outputs, yb)
                        optimizer.zero_grad()
                        loss_train.backward()
                        optimizer.step()

                    # Evaluate
                    model.eval()
                    with torch.no_grad():
                        outputs = model(X_test_tensor)
                        preds = (outputs >= 0.5).float()
                        loss_test = binary_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"epoch {epoch}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['epoch'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['epoch'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 epoch 0: loss_train=0.0912, acc_train=1.0000, loss_test=0.0475, acc_test=0.9995
# poison_percent 0 epoch 1: loss_train=0.0000, acc_train=1.0000, loss_test=0.0096, acc_test=0.9995
# poison_percent 0 epoch 2: loss_train=0.0000, acc_train=1.0000, loss_test=0.0040, acc_test=0.9995
# poison_percent 0 epoch 3: loss_train=0.0030, acc_train=1.0000, loss_test=0.0025, acc_test=0.9995
# poison_percent 0 epoch 4: loss_train=0.0020, acc_train=1.0000, loss_test=0.0018, acc_test=1.0000
# poison_percent 0 epoch 5: loss_train=0.0000, acc_train=1.0000, loss_test=0.0013, acc_test=1.0000
# poison_percent 0 epoch 6: loss_train=0.0000, acc_train=1.0000, loss_test=0.0011, acc_test=1.0000
# poison_percent 0 epoch 7: loss_train=0.0007, acc_train=1.0000, loss_test=0.0012, acc_test=1.0000
# poison_percent 0 epoch 8: loss_train=0.0000, acc_train=1.0000, loss_test=0.0007, acc_test=1.0000
# poison_percent 0 epoch 9: loss_train=0.0004, acc_train=1.0000, loss_test=0.0008, acc_test=1.0000
# poison_percent 0 epoch 10: loss_train=0.0000, acc_train=1.0000, loss_test=0.0005, acc_test=1.0000
# poison_percent 0 epoch 11: loss_train=0.0003, acc_train=1.0000, loss_test=0.0005, acc_test=1.0000
# poison_percent 0 epoch 12: loss_train=0.0000, acc_train=1.0000, loss_test=0.0017, acc_test=0.9990
# poison_percent 0 epoch 13: loss_train=0.0002, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 14: loss_train=0.0000, acc_train=1.0000, loss_test=0.0011, acc_test=0.9995
# poison_percent 0 epoch 15: loss_train=0.0001, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 16: loss_train=0.0000, acc_train=1.0000, loss_test=0.0012, acc_test=0.9990
# poison_percent 0 epoch 17: loss_train=0.0000, acc_train=1.0000, loss_test=0.0001, acc_test=1.0000
# poison_percent 0 epoch 18: loss_train=0.0000, acc_train=1.0000, loss_test=0.0001, acc_test=1.0000
# poison_percent 0 epoch 19: loss_train=0.0000, acc_train=1.0000, loss_test=0.0001, acc_test=1.0000
# poison_percent 0 epoch 20: loss_train=0.0000, acc_train=1.0000, loss_test=0.0002, acc_test=1.0000
# poison_percent 0 epoch 21: loss_train=0.0000, acc_train=1.0000, loss_test=0.0008, acc_test=0.9995
# poison_percent 0 epoch 22: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 23: loss_train=0.0000, acc_train=1.0000, loss_test=0.0014, acc_test=0.9995
# poison_percent 0 epoch 24: loss_train=0.0000, acc_train=1.0000, loss_test=0.0009, acc_test=0.9995
# poison_percent 0 epoch 25: loss_train=0.0000, acc_train=1.0000, loss_test=0.0018, acc_test=0.9995
# poison_percent 0 epoch 26: loss_train=0.0000, acc_train=1.0000, loss_test=0.0005, acc_test=1.0000
# poison_percent 0 epoch 27: loss_train=0.0000, acc_train=1.0000, loss_test=0.0005, acc_test=1.0000
# poison_percent 0 epoch 28: loss_train=0.0000, acc_train=1.0000, loss_test=0.0010, acc_test=0.9995
# poison_percent 0 epoch 29: loss_train=0.0000, acc_train=1.0000, loss_test=0.0011, acc_test=0.9995
# poison_percent 0 epoch 30: loss_train=0.0000, acc_train=1.0000, loss_test=0.0012, acc_test=0.9990
# poison_percent 0 epoch 31: loss_train=0.0000, acc_train=1.0000, loss_test=0.0009, acc_test=0.9995
# poison_percent 0 epoch 32: loss_train=0.0000, acc_train=1.0000, loss_test=0.0011, acc_test=0.9995
# poison_percent 0 epoch 33: loss_train=0.0000, acc_train=1.0000, loss_test=0.0013, acc_test=0.9995
# poison_percent 0 epoch 34: loss_train=0.0000, acc_train=1.0000, loss_test=0.0026, acc_test=0.9995
# poison_percent 0 epoch 35: loss_train=0.0000, acc_train=1.0000, loss_test=0.0016, acc_test=0.9990
# poison_percent 0 epoch 36: loss_train=0.0000, acc_train=1.0000, loss_test=0.0017, acc_test=0.9995
# poison_percent 0 epoch 37: loss_train=0.0000, acc_train=1.0000, loss_test=0.0027, acc_test=0.9995
# poison_percent 0 epoch 38: loss_train=0.0000, acc_train=1.0000, loss_test=0.0022, acc_test=0.9995
# poison_percent 0 epoch 39: loss_train=0.0000, acc_train=1.0000, loss_test=0.0023, acc_test=0.9990
# poison_percent 0 epoch 40: loss_train=0.0000, acc_train=1.0000, loss_test=0.0021, acc_test=0.9995
# poison_percent 0 epoch 41: loss_train=0.0000, acc_train=1.0000, loss_test=0.0024, acc_test=0.9995
# poison_percent 0 epoch 42: loss_train=0.0000, acc_train=1.0000, loss_test=0.0035, acc_test=0.9995
# poison_percent 0 epoch 43: loss_train=0.0000, acc_train=1.0000, loss_test=0.0035, acc_test=0.9995
# poison_percent 0 epoch 44: loss_train=0.0000, acc_train=1.0000, loss_test=0.0027, acc_test=0.9995
# poison_percent 0 epoch 45: loss_train=0.0000, acc_train=1.0000, loss_test=0.0042, acc_test=0.9995
# poison_percent 0 epoch 46: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 47: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 48: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 49: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 50: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 51: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 52: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 53: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 54: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 55: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 56: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 57: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 58: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 59: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 60: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 61: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 62: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 63: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 64: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 65: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 66: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 67: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 68: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 69: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 70: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 71: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 72: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 73: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 74: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 75: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 76: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 77: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 78: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 79: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 80: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 81: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 82: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 83: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 84: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 85: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 86: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 87: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 88: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 89: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 90: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 91: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 92: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 93: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 94: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 95: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 96: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 97: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 98: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# poison_percent 0 epoch 99: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9995
# Training log saved to ./results\CL_ModelN1L2_Batchsize1_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 epoch 0: loss_train=0.1204, acc_train=1.0000, loss_test=0.2100, acc_test=0.9969
# poison_percent 10 epoch 1: loss_train=0.1546, acc_train=1.0000, loss_test=0.1400, acc_test=0.9985
# poison_percent 10 epoch 2: loss_train=2.0546, acc_train=0.0000, loss_test=0.1428, acc_test=0.9985
# poison_percent 10 epoch 3: loss_train=0.1322, acc_train=1.0000, loss_test=0.1735, acc_test=0.9939
# poison_percent 10 epoch 4: loss_train=0.1305, acc_train=1.0000, loss_test=0.1341, acc_test=0.9969
# poison_percent 10 epoch 5: loss_train=0.3167, acc_train=1.0000, loss_test=0.1564, acc_test=0.9944
# poison_percent 10 epoch 6: loss_train=0.1199, acc_train=1.0000, loss_test=0.1234, acc_test=0.9985
# poison_percent 10 epoch 7: loss_train=0.1271, acc_train=1.0000, loss_test=0.1477, acc_test=0.9949
# poison_percent 10 epoch 8: loss_train=0.0588, acc_train=1.0000, loss_test=0.1357, acc_test=0.9969
# poison_percent 10 epoch 9: loss_train=0.3458, acc_train=1.0000, loss_test=0.1411, acc_test=0.9954
# poison_percent 10 epoch 10: loss_train=0.5068, acc_train=1.0000, loss_test=0.1291, acc_test=0.9964
# poison_percent 10 epoch 11: loss_train=0.0296, acc_train=1.0000, loss_test=0.1298, acc_test=0.9985
# poison_percent 10 epoch 12: loss_train=0.1234, acc_train=1.0000, loss_test=0.1394, acc_test=0.9949
# poison_percent 10 epoch 13: loss_train=0.1380, acc_train=1.0000, loss_test=0.1242, acc_test=0.9974
# poison_percent 10 epoch 14: loss_train=0.0813, acc_train=1.0000, loss_test=0.1115, acc_test=0.9990
# poison_percent 10 epoch 15: loss_train=0.1170, acc_train=1.0000, loss_test=0.2058, acc_test=0.9770
# poison_percent 10 epoch 16: loss_train=0.1208, acc_train=1.0000, loss_test=0.1020, acc_test=0.9995
# poison_percent 10 epoch 17: loss_train=0.3254, acc_train=1.0000, loss_test=0.1423, acc_test=0.9959
# poison_percent 10 epoch 18: loss_train=0.0647, acc_train=1.0000, loss_test=0.1284, acc_test=0.9974
# poison_percent 10 epoch 19: loss_train=0.1195, acc_train=1.0000, loss_test=0.1223, acc_test=0.9985
# poison_percent 10 epoch 20: loss_train=0.3357, acc_train=1.0000, loss_test=0.1152, acc_test=0.9980
# poison_percent 10 epoch 21: loss_train=0.1167, acc_train=1.0000, loss_test=0.1199, acc_test=0.9954
# poison_percent 10 epoch 22: loss_train=0.0623, acc_train=1.0000, loss_test=0.1111, acc_test=0.9974
# poison_percent 10 epoch 23: loss_train=1.0251, acc_train=0.0000, loss_test=0.1372, acc_test=0.9954
# poison_percent 10 epoch 24: loss_train=0.0861, acc_train=1.0000, loss_test=0.1203, acc_test=0.9980
# poison_percent 10 epoch 25: loss_train=0.0443, acc_train=1.0000, loss_test=0.1338, acc_test=0.9944
# poison_percent 10 epoch 26: loss_train=0.1154, acc_train=1.0000, loss_test=0.1254, acc_test=0.9974
# poison_percent 10 epoch 27: loss_train=0.1170, acc_train=1.0000, loss_test=0.1357, acc_test=0.9964
# poison_percent 10 epoch 28: loss_train=0.1155, acc_train=1.0000, loss_test=0.1152, acc_test=0.9974
# poison_percent 10 epoch 29: loss_train=0.1434, acc_train=1.0000, loss_test=0.1454, acc_test=0.9934
# poison_percent 10 epoch 30: loss_train=0.2229, acc_train=1.0000, loss_test=0.1379, acc_test=0.9923
# poison_percent 10 epoch 31: loss_train=0.1168, acc_train=1.0000, loss_test=0.1166, acc_test=0.9964
# poison_percent 10 epoch 32: loss_train=0.1863, acc_train=1.0000, loss_test=0.1163, acc_test=0.9959
# poison_percent 10 epoch 33: loss_train=0.1382, acc_train=1.0000, loss_test=0.0926, acc_test=0.9969
# poison_percent 10 epoch 34: loss_train=2.2331, acc_train=0.0000, loss_test=0.1233, acc_test=0.9969
# poison_percent 10 epoch 35: loss_train=0.1097, acc_train=1.0000, loss_test=0.1063, acc_test=0.9954
# poison_percent 10 epoch 36: loss_train=0.1102, acc_train=1.0000, loss_test=0.1105, acc_test=0.9959
# poison_percent 10 epoch 37: loss_train=0.1992, acc_train=1.0000, loss_test=0.1487, acc_test=0.9913
# poison_percent 10 epoch 38: loss_train=0.0260, acc_train=1.0000, loss_test=0.1079, acc_test=0.9954
# poison_percent 10 epoch 39: loss_train=0.1129, acc_train=1.0000, loss_test=0.1040, acc_test=0.9980
# poison_percent 10 epoch 40: loss_train=0.0681, acc_train=1.0000, loss_test=0.1212, acc_test=0.9929
# poison_percent 10 epoch 41: loss_train=0.2211, acc_train=1.0000, loss_test=0.1083, acc_test=0.9934
# poison_percent 10 epoch 42: loss_train=0.0932, acc_train=1.0000, loss_test=0.1264, acc_test=0.9929
# poison_percent 10 epoch 43: loss_train=0.1114, acc_train=1.0000, loss_test=0.1039, acc_test=0.9949
# poison_percent 10 epoch 44: loss_train=0.0000, acc_train=1.0000, loss_test=0.1294, acc_test=0.9939
# poison_percent 10 epoch 45: loss_train=0.1128, acc_train=1.0000, loss_test=0.1369, acc_test=0.9913
# poison_percent 10 epoch 46: loss_train=0.0164, acc_train=1.0000, loss_test=0.1219, acc_test=0.9939
# poison_percent 10 epoch 47: loss_train=0.1236, acc_train=1.0000, loss_test=0.1118, acc_test=0.9939
# poison_percent 10 epoch 48: loss_train=0.0739, acc_train=1.0000, loss_test=0.1050, acc_test=0.9954
# poison_percent 10 epoch 49: loss_train=0.1027, acc_train=1.0000, loss_test=0.1091, acc_test=0.9954
# poison_percent 10 epoch 50: loss_train=2.2368, acc_train=0.0000, loss_test=0.1060, acc_test=0.9949
# poison_percent 10 epoch 51: loss_train=0.1120, acc_train=1.0000, loss_test=0.1103, acc_test=0.9954
# poison_percent 10 epoch 52: loss_train=0.1110, acc_train=1.0000, loss_test=0.1056, acc_test=0.9954
# poison_percent 10 epoch 53: loss_train=0.0089, acc_train=1.0000, loss_test=0.1076, acc_test=0.9954
# poison_percent 10 epoch 54: loss_train=0.1120, acc_train=1.0000, loss_test=0.1247, acc_test=0.9918
# poison_percent 10 epoch 55: loss_train=0.0214, acc_train=1.0000, loss_test=0.1023, acc_test=0.9934
# poison_percent 10 epoch 56: loss_train=0.1119, acc_train=1.0000, loss_test=0.1091, acc_test=0.9934
# poison_percent 10 epoch 57: loss_train=0.0231, acc_train=1.0000, loss_test=0.1175, acc_test=0.9918
# poison_percent 10 epoch 58: loss_train=0.1134, acc_train=1.0000, loss_test=0.1105, acc_test=0.9944
# poison_percent 10 epoch 59: loss_train=0.0599, acc_train=1.0000, loss_test=0.1212, acc_test=0.9929
# poison_percent 10 epoch 60: loss_train=0.1115, acc_train=1.0000, loss_test=0.1129, acc_test=0.9929
# poison_percent 10 epoch 61: loss_train=0.1109, acc_train=1.0000, loss_test=0.1218, acc_test=0.9918
# poison_percent 10 epoch 62: loss_train=0.0191, acc_train=1.0000, loss_test=0.1010, acc_test=0.9929
# poison_percent 10 epoch 63: loss_train=0.1284, acc_train=1.0000, loss_test=0.1296, acc_test=0.9913
# poison_percent 10 epoch 64: loss_train=0.1088, acc_train=1.0000, loss_test=0.1102, acc_test=0.9939
# poison_percent 10 epoch 65: loss_train=0.1092, acc_train=1.0000, loss_test=0.1229, acc_test=0.9934
# poison_percent 10 epoch 66: loss_train=0.1112, acc_train=1.0000, loss_test=0.1016, acc_test=0.9949
# poison_percent 10 epoch 67: loss_train=0.1083, acc_train=1.0000, loss_test=0.1093, acc_test=0.9934
# poison_percent 10 epoch 68: loss_train=0.0976, acc_train=1.0000, loss_test=0.1398, acc_test=0.9898
# poison_percent 10 epoch 69: loss_train=0.0158, acc_train=1.0000, loss_test=0.1011, acc_test=0.9944
# poison_percent 10 epoch 70: loss_train=0.0469, acc_train=1.0000, loss_test=0.1674, acc_test=0.9796
# poison_percent 10 epoch 71: loss_train=0.1057, acc_train=1.0000, loss_test=0.1180, acc_test=0.9923
# poison_percent 10 epoch 72: loss_train=0.0199, acc_train=1.0000, loss_test=0.1245, acc_test=0.9903
# poison_percent 10 epoch 73: loss_train=0.0889, acc_train=1.0000, loss_test=0.1021, acc_test=0.9944
# poison_percent 10 epoch 74: loss_train=0.1112, acc_train=1.0000, loss_test=0.1218, acc_test=0.9903
# poison_percent 10 epoch 75: loss_train=0.2006, acc_train=1.0000, loss_test=0.1151, acc_test=0.9918
# poison_percent 10 epoch 76: loss_train=0.0697, acc_train=1.0000, loss_test=0.1230, acc_test=0.9893
# poison_percent 10 epoch 77: loss_train=0.0215, acc_train=1.0000, loss_test=0.1234, acc_test=0.9913
# poison_percent 10 epoch 78: loss_train=0.1087, acc_train=1.0000, loss_test=0.1186, acc_test=0.9908
# poison_percent 10 epoch 79: loss_train=0.1820, acc_train=1.0000, loss_test=0.1719, acc_test=0.9750
# poison_percent 10 epoch 80: loss_train=0.1077, acc_train=1.0000, loss_test=0.1177, acc_test=0.9918
# poison_percent 10 epoch 81: loss_train=0.1099, acc_train=1.0000, loss_test=0.1218, acc_test=0.9908
# poison_percent 10 epoch 82: loss_train=0.1083, acc_train=1.0000, loss_test=0.1105, acc_test=0.9913
# poison_percent 10 epoch 83: loss_train=0.1112, acc_train=1.0000, loss_test=0.1079, acc_test=0.9908
# poison_percent 10 epoch 84: loss_train=1.4068, acc_train=0.0000, loss_test=0.1344, acc_test=0.9898
# poison_percent 10 epoch 85: loss_train=3.7492, acc_train=0.0000, loss_test=0.1231, acc_test=0.9903
# poison_percent 10 epoch 86: loss_train=0.1094, acc_train=1.0000, loss_test=0.1681, acc_test=0.9776
# poison_percent 10 epoch 87: loss_train=0.1164, acc_train=1.0000, loss_test=0.1471, acc_test=0.9862
# poison_percent 10 epoch 88: loss_train=0.1966, acc_train=1.0000, loss_test=0.1037, acc_test=0.9939
# poison_percent 10 epoch 89: loss_train=0.0156, acc_train=1.0000, loss_test=0.1160, acc_test=0.9913
# poison_percent 10 epoch 90: loss_train=0.1070, acc_train=1.0000, loss_test=0.1736, acc_test=0.9760
# poison_percent 10 epoch 91: loss_train=0.1082, acc_train=1.0000, loss_test=0.1156, acc_test=0.9908
# poison_percent 10 epoch 92: loss_train=0.1055, acc_train=1.0000, loss_test=0.1234, acc_test=0.9893
# poison_percent 10 epoch 93: loss_train=0.0343, acc_train=1.0000, loss_test=0.1160, acc_test=0.9913
# poison_percent 10 epoch 94: loss_train=2.2675, acc_train=0.0000, loss_test=0.1186, acc_test=0.9923
# poison_percent 10 epoch 95: loss_train=0.0361, acc_train=1.0000, loss_test=0.1078, acc_test=0.9923
# poison_percent 10 epoch 96: loss_train=0.1099, acc_train=1.0000, loss_test=0.1310, acc_test=0.9888
# poison_percent 10 epoch 97: loss_train=0.1090, acc_train=1.0000, loss_test=0.1242, acc_test=0.9888
# poison_percent 10 epoch 98: loss_train=0.1067, acc_train=1.0000, loss_test=0.1358, acc_test=0.9878
# poison_percent 10 epoch 99: loss_train=0.1094, acc_train=1.0000, loss_test=0.1099, acc_test=0.9903
# Training log saved to ./results\CL_ModelN1L2_Batchsize1_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 epoch 0: loss_train=0.3452, acc_train=1.0000, loss_test=0.2877, acc_test=0.9985
# poison_percent 20 epoch 1: loss_train=0.3591, acc_train=1.0000, loss_test=0.2354, acc_test=0.9964
# poison_percent 20 epoch 2: loss_train=0.2781, acc_train=1.0000, loss_test=0.2646, acc_test=0.9939
# poison_percent 20 epoch 3: loss_train=0.2302, acc_train=1.0000, loss_test=0.1937, acc_test=0.9985
# poison_percent 20 epoch 4: loss_train=0.2253, acc_train=1.0000, loss_test=0.2104, acc_test=0.9969
# poison_percent 20 epoch 5: loss_train=0.2042, acc_train=1.0000, loss_test=0.2332, acc_test=0.9944
# poison_percent 20 epoch 6: loss_train=0.3580, acc_train=1.0000, loss_test=0.2765, acc_test=0.9949
# poison_percent 20 epoch 7: loss_train=0.1632, acc_train=1.0000, loss_test=0.2392, acc_test=0.9959
# poison_percent 20 epoch 8: loss_train=0.2218, acc_train=1.0000, loss_test=0.2709, acc_test=0.9878
# poison_percent 20 epoch 9: loss_train=0.0987, acc_train=1.0000, loss_test=0.1947, acc_test=0.9944
# poison_percent 20 epoch 10: loss_train=0.2196, acc_train=1.0000, loss_test=0.2156, acc_test=0.9980
# poison_percent 20 epoch 11: loss_train=1.6219, acc_train=0.0000, loss_test=0.2315, acc_test=0.9929
# poison_percent 20 epoch 12: loss_train=1.6118, acc_train=0.0000, loss_test=0.1945, acc_test=0.9939
# poison_percent 20 epoch 13: loss_train=1.6587, acc_train=0.0000, loss_test=0.2261, acc_test=0.9949
# poison_percent 20 epoch 14: loss_train=1.6235, acc_train=0.0000, loss_test=0.2436, acc_test=0.9949
# poison_percent 20 epoch 15: loss_train=1.5649, acc_train=0.0000, loss_test=0.2540, acc_test=0.9954
# poison_percent 20 epoch 16: loss_train=0.2204, acc_train=1.0000, loss_test=0.2446, acc_test=0.9903
# poison_percent 20 epoch 17: loss_train=0.1619, acc_train=1.0000, loss_test=0.2247, acc_test=0.9939
# poison_percent 20 epoch 18: loss_train=1.6280, acc_train=0.0000, loss_test=0.1902, acc_test=0.9939
# poison_percent 20 epoch 19: loss_train=1.5039, acc_train=0.0000, loss_test=0.2291, acc_test=0.9918
# poison_percent 20 epoch 20: loss_train=0.1626, acc_train=1.0000, loss_test=0.2378, acc_test=0.9944
# poison_percent 20 epoch 21: loss_train=0.2169, acc_train=1.0000, loss_test=0.2859, acc_test=0.9898
# poison_percent 20 epoch 22: loss_train=0.1372, acc_train=1.0000, loss_test=0.2130, acc_test=0.9944
# poison_percent 20 epoch 23: loss_train=0.2223, acc_train=1.0000, loss_test=0.2488, acc_test=0.9923
# poison_percent 20 epoch 24: loss_train=0.2166, acc_train=1.0000, loss_test=0.2326, acc_test=0.9903
# poison_percent 20 epoch 25: loss_train=1.6213, acc_train=0.0000, loss_test=0.2319, acc_test=0.9934
# poison_percent 20 epoch 26: loss_train=0.1142, acc_train=1.0000, loss_test=0.2242, acc_test=0.9923
# poison_percent 20 epoch 27: loss_train=0.1254, acc_train=1.0000, loss_test=0.2226, acc_test=0.9939
# poison_percent 20 epoch 28: loss_train=0.0524, acc_train=1.0000, loss_test=0.2029, acc_test=0.9923
# poison_percent 20 epoch 29: loss_train=0.2180, acc_train=1.0000, loss_test=0.2180, acc_test=0.9939
# poison_percent 20 epoch 30: loss_train=0.2223, acc_train=1.0000, loss_test=0.2274, acc_test=0.9934
# poison_percent 20 epoch 31: loss_train=0.3432, acc_train=1.0000, loss_test=0.2374, acc_test=0.9913
# poison_percent 20 epoch 32: loss_train=0.2154, acc_train=1.0000, loss_test=0.2174, acc_test=0.9934
# poison_percent 20 epoch 33: loss_train=1.7550, acc_train=0.0000, loss_test=0.2585, acc_test=0.9888
# poison_percent 20 epoch 34: loss_train=0.2204, acc_train=1.0000, loss_test=0.2314, acc_test=0.9903
# poison_percent 20 epoch 35: loss_train=1.6399, acc_train=0.0000, loss_test=0.2359, acc_test=0.9923
# poison_percent 20 epoch 36: loss_train=0.2954, acc_train=1.0000, loss_test=0.2686, acc_test=0.9867
# poison_percent 20 epoch 37: loss_train=0.2155, acc_train=1.0000, loss_test=0.2211, acc_test=0.9918
# poison_percent 20 epoch 38: loss_train=0.2174, acc_train=1.0000, loss_test=0.2285, acc_test=0.9934
# poison_percent 20 epoch 39: loss_train=0.1477, acc_train=1.0000, loss_test=0.2316, acc_test=0.9908
# poison_percent 20 epoch 40: loss_train=0.2204, acc_train=1.0000, loss_test=0.2204, acc_test=0.9903
# poison_percent 20 epoch 41: loss_train=0.2165, acc_train=1.0000, loss_test=0.2159, acc_test=0.9918
# poison_percent 20 epoch 42: loss_train=0.2169, acc_train=1.0000, loss_test=0.2781, acc_test=0.9842
# poison_percent 20 epoch 43: loss_train=0.2398, acc_train=1.0000, loss_test=0.2328, acc_test=0.9903
# poison_percent 20 epoch 44: loss_train=0.2202, acc_train=1.0000, loss_test=0.2022, acc_test=0.9929
# poison_percent 20 epoch 45: loss_train=1.6394, acc_train=0.0000, loss_test=0.2295, acc_test=0.9918
# poison_percent 20 epoch 46: loss_train=0.1376, acc_train=1.0000, loss_test=0.2334, acc_test=0.9878
# poison_percent 20 epoch 47: loss_train=0.2166, acc_train=1.0000, loss_test=0.2340, acc_test=0.9898
# poison_percent 20 epoch 48: loss_train=0.2192, acc_train=1.0000, loss_test=0.2155, acc_test=0.9903
# poison_percent 20 epoch 49: loss_train=0.1555, acc_train=1.0000, loss_test=0.2387, acc_test=0.9888
# poison_percent 20 epoch 50: loss_train=0.8290, acc_train=0.0000, loss_test=0.2618, acc_test=0.9862
# poison_percent 20 epoch 51: loss_train=1.6363, acc_train=0.0000, loss_test=0.2241, acc_test=0.9903
# poison_percent 20 epoch 52: loss_train=0.1160, acc_train=1.0000, loss_test=0.2287, acc_test=0.9893
# poison_percent 20 epoch 53: loss_train=0.2155, acc_train=1.0000, loss_test=0.2367, acc_test=0.9878
# poison_percent 20 epoch 54: loss_train=0.1734, acc_train=1.0000, loss_test=0.2194, acc_test=0.9903
# poison_percent 20 epoch 55: loss_train=0.4745, acc_train=1.0000, loss_test=0.2368, acc_test=0.9878
# poison_percent 20 epoch 56: loss_train=0.2126, acc_train=1.0000, loss_test=0.2341, acc_test=0.9918
# poison_percent 20 epoch 57: loss_train=0.2291, acc_train=1.0000, loss_test=0.2353, acc_test=0.9888
# poison_percent 20 epoch 58: loss_train=0.2190, acc_train=1.0000, loss_test=0.2321, acc_test=0.9888
# poison_percent 20 epoch 59: loss_train=0.2181, acc_train=1.0000, loss_test=0.2203, acc_test=0.9898
# poison_percent 20 epoch 60: loss_train=0.2145, acc_train=1.0000, loss_test=0.2412, acc_test=0.9878
# poison_percent 20 epoch 61: loss_train=0.2096, acc_train=1.0000, loss_test=0.2156, acc_test=0.9898
# poison_percent 20 epoch 62: loss_train=0.4380, acc_train=1.0000, loss_test=0.2249, acc_test=0.9893
# poison_percent 20 epoch 63: loss_train=0.2135, acc_train=1.0000, loss_test=0.2252, acc_test=0.9893
# poison_percent 20 epoch 64: loss_train=0.5978, acc_train=1.0000, loss_test=0.2405, acc_test=0.9898
# poison_percent 20 epoch 65: loss_train=0.2112, acc_train=1.0000, loss_test=0.2331, acc_test=0.9883
# poison_percent 20 epoch 66: loss_train=0.1661, acc_train=1.0000, loss_test=0.2364, acc_test=0.9893
# poison_percent 20 epoch 67: loss_train=0.2163, acc_train=1.0000, loss_test=0.2288, acc_test=0.9903
# poison_percent 20 epoch 68: loss_train=0.2123, acc_train=1.0000, loss_test=0.2574, acc_test=0.9888
# poison_percent 20 epoch 69: loss_train=1.6349, acc_train=0.0000, loss_test=0.2119, acc_test=0.9903
# poison_percent 20 epoch 70: loss_train=0.1390, acc_train=1.0000, loss_test=0.2061, acc_test=0.9898
# poison_percent 20 epoch 71: loss_train=0.2109, acc_train=1.0000, loss_test=0.2689, acc_test=0.9847
# poison_percent 20 epoch 72: loss_train=0.2174, acc_train=1.0000, loss_test=0.2378, acc_test=0.9862
# poison_percent 20 epoch 73: loss_train=0.1677, acc_train=1.0000, loss_test=0.2034, acc_test=0.9923
# poison_percent 20 epoch 74: loss_train=0.2139, acc_train=1.0000, loss_test=0.2189, acc_test=0.9888
# poison_percent 20 epoch 75: loss_train=0.1948, acc_train=1.0000, loss_test=0.2399, acc_test=0.9888
# poison_percent 20 epoch 76: loss_train=0.2712, acc_train=1.0000, loss_test=0.2339, acc_test=0.9893
# poison_percent 20 epoch 77: loss_train=0.0598, acc_train=1.0000, loss_test=0.2465, acc_test=0.9888
# poison_percent 20 epoch 78: loss_train=0.2195, acc_train=1.0000, loss_test=0.2036, acc_test=0.9918
# poison_percent 20 epoch 79: loss_train=0.3765, acc_train=1.0000, loss_test=0.2727, acc_test=0.9821
# poison_percent 20 epoch 80: loss_train=0.4924, acc_train=1.0000, loss_test=0.2421, acc_test=0.9837
# poison_percent 20 epoch 81: loss_train=0.2623, acc_train=1.0000, loss_test=0.2540, acc_test=0.9852
# poison_percent 20 epoch 82: loss_train=0.2104, acc_train=1.0000, loss_test=0.2393, acc_test=0.9867
# poison_percent 20 epoch 83: loss_train=0.2120, acc_train=1.0000, loss_test=0.2339, acc_test=0.9872
# poison_percent 20 epoch 84: loss_train=0.3032, acc_train=1.0000, loss_test=0.2321, acc_test=0.9867
# poison_percent 20 epoch 85: loss_train=0.1129, acc_train=1.0000, loss_test=0.2383, acc_test=0.9878
# poison_percent 20 epoch 86: loss_train=1.6413, acc_train=0.0000, loss_test=0.2469, acc_test=0.9816
# poison_percent 20 epoch 87: loss_train=1.5590, acc_train=0.0000, loss_test=0.2457, acc_test=0.9857
# poison_percent 20 epoch 88: loss_train=0.2127, acc_train=1.0000, loss_test=0.2355, acc_test=0.9872
# poison_percent 20 epoch 89: loss_train=0.2191, acc_train=1.0000, loss_test=0.2272, acc_test=0.9878
# poison_percent 20 epoch 90: loss_train=1.4218, acc_train=0.0000, loss_test=0.2631, acc_test=0.9811
# poison_percent 20 epoch 91: loss_train=0.2113, acc_train=1.0000, loss_test=0.2639, acc_test=0.9842
# poison_percent 20 epoch 92: loss_train=0.2147, acc_train=1.0000, loss_test=0.2109, acc_test=0.9893
# poison_percent 20 epoch 93: loss_train=0.2122, acc_train=1.0000, loss_test=0.2579, acc_test=0.9827
# poison_percent 20 epoch 94: loss_train=0.2118, acc_train=1.0000, loss_test=0.2456, acc_test=0.9872
# poison_percent 20 epoch 95: loss_train=0.2132, acc_train=1.0000, loss_test=0.2495, acc_test=0.9862
# poison_percent 20 epoch 96: loss_train=0.0992, acc_train=1.0000, loss_test=0.2228, acc_test=0.9893
# poison_percent 20 epoch 97: loss_train=0.3325, acc_train=1.0000, loss_test=0.2197, acc_test=0.9883
# poison_percent 20 epoch 98: loss_train=0.0800, acc_train=1.0000, loss_test=0.2359, acc_test=0.9872
# poison_percent 20 epoch 99: loss_train=1.6591, acc_train=0.0000, loss_test=0.2351, acc_test=0.9878
# Training log saved to ./results\CL_ModelN1L2_Batchsize1_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 epoch 0: loss_train=1.3942, acc_train=0.0000, loss_test=0.3527, acc_test=0.9944
# poison_percent 30 epoch 1: loss_train=0.3643, acc_train=1.0000, loss_test=0.4785, acc_test=0.8903
# poison_percent 30 epoch 2: loss_train=0.3755, acc_train=1.0000, loss_test=0.3551, acc_test=0.9862
# poison_percent 30 epoch 3: loss_train=1.2914, acc_train=0.0000, loss_test=0.3574, acc_test=0.9872
# poison_percent 30 epoch 4: loss_train=0.3867, acc_train=1.0000, loss_test=0.4362, acc_test=0.9408
# poison_percent 30 epoch 5: loss_train=1.1655, acc_train=0.0000, loss_test=0.3599, acc_test=0.9918
# poison_percent 30 epoch 6: loss_train=0.3414, acc_train=1.0000, loss_test=0.3628, acc_test=0.9878
# poison_percent 30 epoch 7: loss_train=1.5304, acc_train=0.0000, loss_test=0.3748, acc_test=0.9837
# poison_percent 30 epoch 8: loss_train=0.3880, acc_train=1.0000, loss_test=0.3683, acc_test=0.9816
# poison_percent 30 epoch 9: loss_train=0.2139, acc_train=1.0000, loss_test=0.3262, acc_test=0.9929
# poison_percent 30 epoch 10: loss_train=0.2365, acc_train=1.0000, loss_test=0.3608, acc_test=0.9816
# poison_percent 30 epoch 11: loss_train=0.3622, acc_train=1.0000, loss_test=0.4179, acc_test=0.9505
# poison_percent 30 epoch 12: loss_train=0.3546, acc_train=1.0000, loss_test=0.3912, acc_test=0.9679
# poison_percent 30 epoch 13: loss_train=0.7998, acc_train=0.0000, loss_test=0.3663, acc_test=0.9786
# poison_percent 30 epoch 14: loss_train=1.2021, acc_train=0.0000, loss_test=0.3956, acc_test=0.9673
# poison_percent 30 epoch 15: loss_train=0.2895, acc_train=1.0000, loss_test=0.3911, acc_test=0.9694
# poison_percent 30 epoch 16: loss_train=1.1423, acc_train=0.0000, loss_test=0.3610, acc_test=0.9704
# poison_percent 30 epoch 17: loss_train=1.3169, acc_train=0.0000, loss_test=0.3978, acc_test=0.9587
# poison_percent 30 epoch 18: loss_train=1.9095, acc_train=0.0000, loss_test=0.3360, acc_test=0.9745
# poison_percent 30 epoch 19: loss_train=1.2102, acc_train=0.0000, loss_test=0.3991, acc_test=0.9592
# poison_percent 30 epoch 20: loss_train=1.2120, acc_train=0.0000, loss_test=0.3588, acc_test=0.9821
# poison_percent 30 epoch 21: loss_train=0.3528, acc_train=1.0000, loss_test=0.3962, acc_test=0.9663
# poison_percent 30 epoch 22: loss_train=0.6490, acc_train=1.0000, loss_test=0.3621, acc_test=0.9796
# poison_percent 30 epoch 23: loss_train=1.5272, acc_train=0.0000, loss_test=0.3925, acc_test=0.9622
# poison_percent 30 epoch 24: loss_train=1.2029, acc_train=0.0000, loss_test=0.3487, acc_test=0.9770
# poison_percent 30 epoch 25: loss_train=1.0420, acc_train=0.0000, loss_test=0.3587, acc_test=0.9776
# poison_percent 30 epoch 26: loss_train=0.4921, acc_train=1.0000, loss_test=0.4376, acc_test=0.9199
# poison_percent 30 epoch 27: loss_train=0.3498, acc_train=1.0000, loss_test=0.3833, acc_test=0.9765
# poison_percent 30 epoch 28: loss_train=1.1251, acc_train=0.0000, loss_test=0.4511, acc_test=0.8949
# poison_percent 30 epoch 29: loss_train=0.3426, acc_train=1.0000, loss_test=0.4042, acc_test=0.9459
# poison_percent 30 epoch 30: loss_train=0.2284, acc_train=1.0000, loss_test=0.3831, acc_test=0.9633
# poison_percent 30 epoch 31: loss_train=0.9790, acc_train=0.0000, loss_test=0.4383, acc_test=0.9128
# poison_percent 30 epoch 32: loss_train=0.4138, acc_train=1.0000, loss_test=0.3474, acc_test=0.9837
# poison_percent 30 epoch 33: loss_train=0.2564, acc_train=1.0000, loss_test=0.3341, acc_test=0.9857
# poison_percent 30 epoch 34: loss_train=0.3457, acc_train=1.0000, loss_test=0.3324, acc_test=0.9872
# poison_percent 30 epoch 35: loss_train=1.2336, acc_train=0.0000, loss_test=0.3348, acc_test=0.9796
# poison_percent 30 epoch 36: loss_train=1.1490, acc_train=0.0000, loss_test=0.3509, acc_test=0.9745
# poison_percent 30 epoch 37: loss_train=1.1806, acc_train=0.0000, loss_test=0.3244, acc_test=0.9842
# poison_percent 30 epoch 38: loss_train=0.3375, acc_train=1.0000, loss_test=0.3730, acc_test=0.9663
# poison_percent 30 epoch 39: loss_train=1.1724, acc_train=0.0000, loss_test=0.3524, acc_test=0.9776
# poison_percent 30 epoch 40: loss_train=0.6419, acc_train=1.0000, loss_test=0.4186, acc_test=0.9199
# poison_percent 30 epoch 41: loss_train=0.3409, acc_train=1.0000, loss_test=0.4465, acc_test=0.8929
# poison_percent 30 epoch 42: loss_train=0.8720, acc_train=0.0000, loss_test=0.4041, acc_test=0.9423
# poison_percent 30 epoch 43: loss_train=0.3435, acc_train=1.0000, loss_test=0.4061, acc_test=0.9469
# poison_percent 30 epoch 44: loss_train=1.0988, acc_train=0.0000, loss_test=0.4049, acc_test=0.9413
# poison_percent 30 epoch 45: loss_train=1.2414, acc_train=0.0000, loss_test=0.3242, acc_test=0.9837
# poison_percent 30 epoch 46: loss_train=0.2276, acc_train=1.0000, loss_test=0.3570, acc_test=0.9704
# poison_percent 30 epoch 47: loss_train=0.3698, acc_train=1.0000, loss_test=0.4516, acc_test=0.8857
# poison_percent 30 epoch 48: loss_train=0.3237, acc_train=1.0000, loss_test=0.3537, acc_test=0.9719
# poison_percent 30 epoch 49: loss_train=0.3433, acc_train=1.0000, loss_test=0.3252, acc_test=0.9755
# poison_percent 30 epoch 50: loss_train=0.3360, acc_train=1.0000, loss_test=0.3524, acc_test=0.9776
# poison_percent 30 epoch 51: loss_train=1.2544, acc_train=0.0000, loss_test=0.3475, acc_test=0.9765
# poison_percent 30 epoch 52: loss_train=0.3146, acc_train=1.0000, loss_test=0.4157, acc_test=0.9332
# poison_percent 30 epoch 53: loss_train=0.5390, acc_train=1.0000, loss_test=0.3424, acc_test=0.9781
# poison_percent 30 epoch 54: loss_train=0.3418, acc_train=1.0000, loss_test=0.4067, acc_test=0.9362
# poison_percent 30 epoch 55: loss_train=0.4933, acc_train=1.0000, loss_test=0.4126, acc_test=0.9260
# poison_percent 30 epoch 56: loss_train=0.2855, acc_train=1.0000, loss_test=0.3644, acc_test=0.9633
# poison_percent 30 epoch 57: loss_train=0.3555, acc_train=1.0000, loss_test=0.3010, acc_test=0.9801
# poison_percent 30 epoch 58: loss_train=0.3426, acc_train=1.0000, loss_test=0.3184, acc_test=0.9821
# poison_percent 30 epoch 59: loss_train=1.3407, acc_train=0.0000, loss_test=0.3352, acc_test=0.9786
# poison_percent 30 epoch 60: loss_train=1.1643, acc_train=0.0000, loss_test=0.3477, acc_test=0.9704
# poison_percent 30 epoch 61: loss_train=0.3485, acc_train=1.0000, loss_test=0.3465, acc_test=0.9811
# poison_percent 30 epoch 62: loss_train=2.1557, acc_train=0.0000, loss_test=0.4027, acc_test=0.9393
# poison_percent 30 epoch 63: loss_train=0.3348, acc_train=1.0000, loss_test=0.3717, acc_test=0.9607
# poison_percent 30 epoch 64: loss_train=1.3189, acc_train=0.0000, loss_test=0.3366, acc_test=0.9821
# poison_percent 30 epoch 65: loss_train=1.1260, acc_train=0.0000, loss_test=0.3356, acc_test=0.9816
# poison_percent 30 epoch 66: loss_train=0.2721, acc_train=1.0000, loss_test=0.3778, acc_test=0.9592
# poison_percent 30 epoch 67: loss_train=1.7855, acc_train=0.0000, loss_test=0.3249, acc_test=0.9781
# poison_percent 30 epoch 68: loss_train=0.4332, acc_train=1.0000, loss_test=0.3649, acc_test=0.9638
# poison_percent 30 epoch 69: loss_train=0.3488, acc_train=1.0000, loss_test=0.3572, acc_test=0.9663
# poison_percent 30 epoch 70: loss_train=0.3457, acc_train=1.0000, loss_test=0.3849, acc_test=0.9531
# poison_percent 30 epoch 71: loss_train=1.2543, acc_train=0.0000, loss_test=0.3688, acc_test=0.9658
# poison_percent 30 epoch 72: loss_train=0.5241, acc_train=1.0000, loss_test=0.4284, acc_test=0.9168
# poison_percent 30 epoch 73: loss_train=1.1141, acc_train=0.0000, loss_test=0.3454, acc_test=0.9750
# poison_percent 30 epoch 74: loss_train=0.4465, acc_train=1.0000, loss_test=0.3389, acc_test=0.9724
# poison_percent 30 epoch 75: loss_train=0.8836, acc_train=0.0000, loss_test=0.3930, acc_test=0.9439
# poison_percent 30 epoch 76: loss_train=1.2378, acc_train=0.0000, loss_test=0.3865, acc_test=0.9536
# poison_percent 30 epoch 77: loss_train=0.3803, acc_train=1.0000, loss_test=0.3966, acc_test=0.9439
# poison_percent 30 epoch 78: loss_train=0.3443, acc_train=1.0000, loss_test=0.4059, acc_test=0.9357
# poison_percent 30 epoch 79: loss_train=0.3413, acc_train=1.0000, loss_test=0.4171, acc_test=0.9199
# poison_percent 30 epoch 80: loss_train=0.6695, acc_train=1.0000, loss_test=0.3659, acc_test=0.9597
# poison_percent 30 epoch 81: loss_train=0.2685, acc_train=1.0000, loss_test=0.3861, acc_test=0.9485
# poison_percent 30 epoch 82: loss_train=0.8178, acc_train=0.0000, loss_test=0.4260, acc_test=0.9122
# poison_percent 30 epoch 83: loss_train=0.8351, acc_train=0.0000, loss_test=0.4083, acc_test=0.9306
# poison_percent 30 epoch 84: loss_train=1.2137, acc_train=0.0000, loss_test=0.4651, acc_test=0.8587
# poison_percent 30 epoch 85: loss_train=0.3363, acc_train=1.0000, loss_test=0.3318, acc_test=0.9760
# poison_percent 30 epoch 86: loss_train=0.3422, acc_train=1.0000, loss_test=0.3420, acc_test=0.9735
# poison_percent 30 epoch 87: loss_train=0.2841, acc_train=1.0000, loss_test=0.3362, acc_test=0.9735
# poison_percent 30 epoch 88: loss_train=1.2149, acc_train=0.0000, loss_test=0.3546, acc_test=0.9684
# poison_percent 30 epoch 89: loss_train=0.3420, acc_train=1.0000, loss_test=0.4460, acc_test=0.8934
# poison_percent 30 epoch 90: loss_train=0.2872, acc_train=1.0000, loss_test=0.3558, acc_test=0.9658
# poison_percent 30 epoch 91: loss_train=0.2099, acc_train=1.0000, loss_test=0.3588, acc_test=0.9587
# poison_percent 30 epoch 92: loss_train=0.3388, acc_train=1.0000, loss_test=0.3308, acc_test=0.9653
# poison_percent 30 epoch 93: loss_train=0.3328, acc_train=1.0000, loss_test=0.3894, acc_test=0.9490
# poison_percent 30 epoch 94: loss_train=0.3272, acc_train=1.0000, loss_test=0.3890, acc_test=0.9393
# poison_percent 30 epoch 95: loss_train=1.3733, acc_train=0.0000, loss_test=0.3373, acc_test=0.9740
# poison_percent 30 epoch 96: loss_train=0.4897, acc_train=1.0000, loss_test=0.3731, acc_test=0.9607
# poison_percent 30 epoch 97: loss_train=0.3365, acc_train=1.0000, loss_test=0.3663, acc_test=0.9602
# poison_percent 30 epoch 98: loss_train=0.2797, acc_train=1.0000, loss_test=0.3824, acc_test=0.9490
# poison_percent 30 epoch 99: loss_train=0.3240, acc_train=1.0000, loss_test=0.3594, acc_test=0.9638
# Training log saved to ./results\CL_ModelN1L2_Batchsize1_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 epoch 0: loss_train=0.6838, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 1: loss_train=0.6882, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 2: loss_train=0.6743, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 3: loss_train=0.6913, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 4: loss_train=0.7041, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 5: loss_train=0.6984, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 6: loss_train=0.6955, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 7: loss_train=0.6853, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 8: loss_train=0.6893, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 9: loss_train=0.7010, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 10: loss_train=0.6876, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 11: loss_train=0.6826, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 12: loss_train=0.6888, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 13: loss_train=0.6890, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 14: loss_train=0.6758, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 15: loss_train=0.6899, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 16: loss_train=0.7128, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 17: loss_train=0.6816, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 18: loss_train=0.6821, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 19: loss_train=0.7065, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 20: loss_train=0.6757, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 21: loss_train=0.6837, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 22: loss_train=0.6815, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 23: loss_train=0.6909, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 24: loss_train=0.6847, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 25: loss_train=0.6953, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 26: loss_train=0.7141, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 27: loss_train=0.7017, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 28: loss_train=0.6830, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 29: loss_train=0.7090, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 30: loss_train=0.6906, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 31: loss_train=0.6720, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 32: loss_train=0.6614, acc_train=1.0000, loss_test=0.6937, acc_test=0.5000
# poison_percent 40 epoch 33: loss_train=0.6820, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 34: loss_train=0.6861, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 35: loss_train=0.7025, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 36: loss_train=0.6973, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 37: loss_train=0.7000, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 38: loss_train=0.6878, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 39: loss_train=0.6730, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 40: loss_train=0.6962, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 41: loss_train=0.6993, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 42: loss_train=0.6952, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 43: loss_train=0.6714, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 44: loss_train=0.6929, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 45: loss_train=0.6841, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 46: loss_train=0.7082, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 47: loss_train=0.7090, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 48: loss_train=0.7064, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 49: loss_train=0.6953, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 50: loss_train=0.6944, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 51: loss_train=0.6894, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 52: loss_train=0.7190, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 40 epoch 53: loss_train=0.7006, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 54: loss_train=0.6789, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 55: loss_train=0.6830, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 56: loss_train=0.7196, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 40 epoch 57: loss_train=0.7084, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 58: loss_train=0.6931, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 59: loss_train=0.7052, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 60: loss_train=0.6978, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 61: loss_train=0.6840, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 62: loss_train=0.6904, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 63: loss_train=0.7329, acc_train=0.0000, loss_test=0.6939, acc_test=0.5000
# poison_percent 40 epoch 64: loss_train=0.6823, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 65: loss_train=0.7015, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 66: loss_train=0.6993, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 67: loss_train=0.7090, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 68: loss_train=0.6901, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 69: loss_train=0.6904, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 70: loss_train=0.6996, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 71: loss_train=0.7023, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 72: loss_train=0.6864, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 73: loss_train=0.7285, acc_train=0.0000, loss_test=0.6937, acc_test=0.5000
# poison_percent 40 epoch 74: loss_train=0.6962, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 75: loss_train=0.6856, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 76: loss_train=0.7083, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 77: loss_train=0.6875, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 78: loss_train=0.6748, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 79: loss_train=0.7138, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 80: loss_train=0.6986, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 81: loss_train=0.7006, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# ...
# poison_percent 40 epoch 41: loss_train=0.9769, acc_train=0.0000, loss_test=0.5623, acc_test=0.8117
# poison_percent 40 epoch 42: loss_train=0.0844, acc_train=1.0000, loss_test=0.5325, acc_test=0.8092
# poison_percent 40 epoch 43: loss_train=0.7021, acc_train=0.0000, loss_test=0.5294, acc_test=0.7903
# poison_percent 40 epoch 44: loss_train=0.5864, acc_train=1.0000, loss_test=0.5442, acc_test=0.8260
# poison_percent 40 epoch 45: loss_train=0.4723, acc_train=1.0000, loss_test=0.5523, acc_test=0.7403
# poison_percent 40 epoch 46: loss_train=0.6893, acc_train=1.0000, loss_test=0.5772, acc_test=0.7311
# poison_percent 40 epoch 47: loss_train=0.6853, acc_train=1.0000, loss_test=0.5309, acc_test=0.7770
# poison_percent 40 epoch 48: loss_train=0.6895, acc_train=1.0000, loss_test=0.5758, acc_test=0.7694
# poison_percent 40 epoch 49: loss_train=0.7480, acc_train=0.0000, loss_test=0.5468, acc_test=0.8138
# poison_percent 40 epoch 50: loss_train=0.6739, acc_train=1.0000, loss_test=0.6199, acc_test=0.7556
# poison_percent 40 epoch 51: loss_train=0.0624, acc_train=1.0000, loss_test=0.5922, acc_test=0.6878
# poison_percent 40 epoch 52: loss_train=0.2692, acc_train=1.0000, loss_test=0.5067, acc_test=0.7980
# poison_percent 40 epoch 53: loss_train=0.8528, acc_train=0.0000, loss_test=0.6442, acc_test=0.7520
# poison_percent 40 epoch 54: loss_train=0.7720, acc_train=0.0000, loss_test=0.6260, acc_test=0.7857
# poison_percent 40 epoch 55: loss_train=0.1111, acc_train=1.0000, loss_test=0.5273, acc_test=0.8429
# poison_percent 40 epoch 56: loss_train=0.6826, acc_train=1.0000, loss_test=0.5878, acc_test=0.7265
# poison_percent 40 epoch 57: loss_train=0.7072, acc_train=0.0000, loss_test=0.6763, acc_test=0.7214
# poison_percent 40 epoch 58: loss_train=0.6773, acc_train=1.0000, loss_test=0.6202, acc_test=0.8056
# poison_percent 40 epoch 59: loss_train=0.6286, acc_train=1.0000, loss_test=0.6139, acc_test=0.7311
# poison_percent 40 epoch 60: loss_train=0.6818, acc_train=1.0000, loss_test=0.5942, acc_test=0.7066
# poison_percent 40 epoch 61: loss_train=1.3534, acc_train=0.0000, loss_test=0.5811, acc_test=0.8158
# poison_percent 40 epoch 62: loss_train=0.0374, acc_train=1.0000, loss_test=0.6459, acc_test=0.7571
# poison_percent 40 epoch 63: loss_train=0.3141, acc_train=1.0000, loss_test=0.6771, acc_test=0.7107
# poison_percent 40 epoch 64: loss_train=0.7823, acc_train=0.0000, loss_test=0.6071, acc_test=0.7031
# poison_percent 40 epoch 65: loss_train=0.6883, acc_train=1.0000, loss_test=0.6219, acc_test=0.7694
# poison_percent 40 epoch 66: loss_train=1.4211, acc_train=0.0000, loss_test=0.5825, acc_test=0.7918
# poison_percent 40 epoch 67: loss_train=0.7008, acc_train=0.0000, loss_test=0.6227, acc_test=0.7393
# poison_percent 40 epoch 68: loss_train=0.7684, acc_train=0.0000, loss_test=0.5979, acc_test=0.7388
# poison_percent 40 epoch 69: loss_train=0.7550, acc_train=0.0000, loss_test=0.6128, acc_test=0.6867
# poison_percent 40 epoch 70: loss_train=0.5187, acc_train=1.0000, loss_test=0.6031, acc_test=0.7270
# poison_percent 40 epoch 71: loss_train=0.6837, acc_train=1.0000, loss_test=0.5818, acc_test=0.7490
# poison_percent 40 epoch 72: loss_train=0.6913, acc_train=1.0000, loss_test=0.6260, acc_test=0.6969
# poison_percent 40 epoch 73: loss_train=2.4460, acc_train=0.0000, loss_test=0.5624, acc_test=0.7801
# poison_percent 40 epoch 74: loss_train=1.1620, acc_train=0.0000, loss_test=0.5251, acc_test=0.7964
# poison_percent 40 epoch 75: loss_train=0.6727, acc_train=1.0000, loss_test=0.6330, acc_test=0.7245
# poison_percent 40 epoch 76: loss_train=0.5342, acc_train=1.0000, loss_test=0.6057, acc_test=0.7286
# poison_percent 40 epoch 77: loss_train=0.2972, acc_train=1.0000, loss_test=0.6733, acc_test=0.6500
# poison_percent 40 epoch 78: loss_train=0.6953, acc_train=0.0000, loss_test=0.6582, acc_test=0.6980
# poison_percent 40 epoch 79: loss_train=0.7047, acc_train=0.0000, loss_test=0.6317, acc_test=0.7679
# poison_percent 40 epoch 80: loss_train=0.7074, acc_train=0.0000, loss_test=0.6259, acc_test=0.7240
# poison_percent 40 epoch 81: loss_train=0.8709, acc_train=0.0000, loss_test=0.7165, acc_test=0.6770
# poison_percent 40 epoch 82: loss_train=0.6970, acc_train=0.0000, loss_test=0.6413, acc_test=0.6679
# poison_percent 40 epoch 83: loss_train=0.4204, acc_train=1.0000, loss_test=0.5956, acc_test=0.8066
# poison_percent 40 epoch 84: loss_train=0.6883, acc_train=1.0000, loss_test=0.6229, acc_test=0.7250
# poison_percent 40 epoch 85: loss_train=0.7030, acc_train=0.0000, loss_test=0.6273, acc_test=0.7541
# poison_percent 40 epoch 86: loss_train=0.6961, acc_train=0.0000, loss_test=0.5969, acc_test=0.7673
# poison_percent 40 epoch 87: loss_train=0.6989, acc_train=0.0000, loss_test=0.6609, acc_test=0.6786
# poison_percent 40 epoch 88: loss_train=0.6851, acc_train=1.0000, loss_test=0.6275, acc_test=0.7388
# poison_percent 40 epoch 89: loss_train=0.6732, acc_train=1.0000, loss_test=0.6702, acc_test=0.7352
# poison_percent 40 epoch 90: loss_train=0.7056, acc_train=0.0000, loss_test=0.6108, acc_test=0.7719
# poison_percent 40 epoch 91: loss_train=0.7890, acc_train=0.0000, loss_test=0.6467, acc_test=0.7056
# poison_percent 40 epoch 92: loss_train=0.6871, acc_train=1.0000, loss_test=0.6372, acc_test=0.7689
# poison_percent 40 epoch 93: loss_train=0.6760, acc_train=1.0000, loss_test=0.6305, acc_test=0.6362
# poison_percent 40 epoch 94: loss_train=0.6986, acc_train=0.0000, loss_test=0.6923, acc_test=0.7347
# poison_percent 40 epoch 95: loss_train=0.6815, acc_train=1.0000, loss_test=0.6669, acc_test=0.6995
# poison_percent 40 epoch 96: loss_train=0.1793, acc_train=1.0000, loss_test=0.5823, acc_test=0.7694
# poison_percent 40 epoch 97: loss_train=0.7136, acc_train=0.0000, loss_test=0.6114, acc_test=0.7122
# poison_percent 40 epoch 98: loss_train=0.7053, acc_train=0.0000, loss_test=0.6770, acc_test=0.6434
# poison_percent 40 epoch 99: loss_train=0.1458, acc_train=1.0000, loss_test=0.5959, acc_test=0.7485
# Training log saved to ./results\CL_ModelN16L2_Batchsize1_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 epoch 0: loss_train=0.6829, acc_train=1.0000, loss_test=0.6964, acc_test=0.4592
# poison_percent 50 epoch 1: loss_train=0.6733, acc_train=1.0000, loss_test=0.6988, acc_test=0.4918
# poison_percent 50 epoch 2: loss_train=0.6669, acc_train=1.0000, loss_test=0.6952, acc_test=0.5857
# poison_percent 50 epoch 3: loss_train=0.8935, acc_train=0.0000, loss_test=0.6898, acc_test=0.5235
# poison_percent 50 epoch 4: loss_train=0.7328, acc_train=0.0000, loss_test=0.7065, acc_test=0.4995
# poison_percent 50 epoch 5: loss_train=0.7063, acc_train=0.0000, loss_test=0.6845, acc_test=0.6128
# poison_percent 50 epoch 6: loss_train=0.6576, acc_train=1.0000, loss_test=0.6861, acc_test=0.6036
# poison_percent 50 epoch 7: loss_train=0.7078, acc_train=0.0000, loss_test=0.7009, acc_test=0.5372
# poison_percent 50 epoch 8: loss_train=0.6960, acc_train=0.0000, loss_test=0.7082, acc_test=0.5153
# poison_percent 50 epoch 9: loss_train=0.5407, acc_train=1.0000, loss_test=0.7049, acc_test=0.5658
# poison_percent 50 epoch 10: loss_train=0.6812, acc_train=1.0000, loss_test=0.6922, acc_test=0.6102
# poison_percent 50 epoch 11: loss_train=0.9460, acc_train=0.0000, loss_test=0.6963, acc_test=0.5281
# poison_percent 50 epoch 12: loss_train=0.7033, acc_train=0.0000, loss_test=0.6842, acc_test=0.5143
# poison_percent 50 epoch 13: loss_train=0.6925, acc_train=1.0000, loss_test=0.6951, acc_test=0.5490
# poison_percent 50 epoch 14: loss_train=0.7030, acc_train=0.0000, loss_test=0.7065, acc_test=0.5393
# poison_percent 50 epoch 15: loss_train=0.7050, acc_train=0.0000, loss_test=0.7234, acc_test=0.5648
# poison_percent 50 epoch 16: loss_train=0.6727, acc_train=1.0000, loss_test=0.7081, acc_test=0.5337
# poison_percent 50 epoch 17: loss_train=0.6965, acc_train=0.0000, loss_test=0.7103, acc_test=0.5423
# poison_percent 50 epoch 18: loss_train=0.6693, acc_train=1.0000, loss_test=0.6842, acc_test=0.6041
# poison_percent 50 epoch 19: loss_train=0.7269, acc_train=0.0000, loss_test=0.6675, acc_test=0.6745
# poison_percent 50 epoch 20: loss_train=0.1826, acc_train=1.0000, loss_test=0.7061, acc_test=0.5673
# poison_percent 50 epoch 21: loss_train=0.6993, acc_train=0.0000, loss_test=0.7057, acc_test=0.5291
# poison_percent 50 epoch 22: loss_train=0.6769, acc_train=1.0000, loss_test=0.7398, acc_test=0.5005
# poison_percent 50 epoch 23: loss_train=0.6961, acc_train=0.0000, loss_test=0.7047, acc_test=0.5388
# poison_percent 50 epoch 24: loss_train=0.2714, acc_train=1.0000, loss_test=0.7230, acc_test=0.5760
# poison_percent 50 epoch 25: loss_train=0.6708, acc_train=1.0000, loss_test=0.7243, acc_test=0.5122
# poison_percent 50 epoch 26: loss_train=0.6951, acc_train=0.0000, loss_test=0.7706, acc_test=0.5587
# poison_percent 50 epoch 27: loss_train=0.7178, acc_train=0.0000, loss_test=0.7431, acc_test=0.4944
# poison_percent 50 epoch 28: loss_train=0.7096, acc_train=0.0000, loss_test=0.7513, acc_test=0.4832
# poison_percent 50 epoch 29: loss_train=0.7176, acc_train=0.0000, loss_test=0.7161, acc_test=0.4888
# poison_percent 50 epoch 30: loss_train=0.7039, acc_train=0.0000, loss_test=0.7630, acc_test=0.4760
# poison_percent 50 epoch 31: loss_train=0.6421, acc_train=1.0000, loss_test=0.8171, acc_test=0.4536
# poison_percent 50 epoch 32: loss_train=0.6808, acc_train=1.0000, loss_test=0.7336, acc_test=0.5689
# poison_percent 50 epoch 33: loss_train=0.6793, acc_train=1.0000, loss_test=0.7724, acc_test=0.5041
# poison_percent 50 epoch 34: loss_train=0.7154, acc_train=0.0000, loss_test=0.7549, acc_test=0.5306
# poison_percent 50 epoch 35: loss_train=0.6911, acc_train=1.0000, loss_test=0.7689, acc_test=0.4872
# poison_percent 50 epoch 36: loss_train=0.6799, acc_train=1.0000, loss_test=0.7432, acc_test=0.5791
# poison_percent 50 epoch 37: loss_train=0.6802, acc_train=1.0000, loss_test=0.7559, acc_test=0.5250
# poison_percent 50 epoch 38: loss_train=0.7032, acc_train=0.0000, loss_test=0.7893, acc_test=0.5071
# poison_percent 50 epoch 39: loss_train=0.6932, acc_train=0.0000, loss_test=0.7835, acc_test=0.4934
# poison_percent 50 epoch 40: loss_train=0.5723, acc_train=1.0000, loss_test=0.7818, acc_test=0.5337
# poison_percent 50 epoch 41: loss_train=0.6700, acc_train=1.0000, loss_test=0.7486, acc_test=0.5423
# poison_percent 50 epoch 42: loss_train=0.6957, acc_train=0.0000, loss_test=0.7544, acc_test=0.5526
# poison_percent 50 epoch 43: loss_train=0.6856, acc_train=1.0000, loss_test=0.7709, acc_test=0.5337
# poison_percent 50 epoch 44: loss_train=0.6836, acc_train=1.0000, loss_test=0.7810, acc_test=0.5541
# poison_percent 50 epoch 45: loss_train=0.6851, acc_train=1.0000, loss_test=0.8621, acc_test=0.4964
# poison_percent 50 epoch 46: loss_train=0.6794, acc_train=1.0000, loss_test=0.7786, acc_test=0.5179
# poison_percent 50 epoch 47: loss_train=0.0000, acc_train=1.0000, loss_test=0.9194, acc_test=0.5286
# poison_percent 50 epoch 48: loss_train=0.6830, acc_train=1.0000, loss_test=0.8010, acc_test=0.5668
# poison_percent 50 epoch 49: loss_train=0.7061, acc_train=0.0000, loss_test=0.8228, acc_test=0.5332
# poison_percent 50 epoch 50: loss_train=0.6973, acc_train=0.0000, loss_test=0.8207, acc_test=0.5434
# poison_percent 50 epoch 51: loss_train=0.6798, acc_train=1.0000, loss_test=0.8040, acc_test=0.5184
# poison_percent 50 epoch 52: loss_train=0.6807, acc_train=1.0000, loss_test=0.8209, acc_test=0.5418
# poison_percent 50 epoch 53: loss_train=0.7112, acc_train=0.0000, loss_test=0.8756, acc_test=0.4944
# poison_percent 50 epoch 54: loss_train=0.6646, acc_train=1.0000, loss_test=0.8299, acc_test=0.4908
# poison_percent 50 epoch 55: loss_train=0.6703, acc_train=1.0000, loss_test=0.8840, acc_test=0.5403
# poison_percent 50 epoch 56: loss_train=0.0000, acc_train=1.0000, loss_test=0.7915, acc_test=0.5648
# poison_percent 50 epoch 57: loss_train=0.6832, acc_train=1.0000, loss_test=0.8368, acc_test=0.4811
# poison_percent 50 epoch 58: loss_train=0.6964, acc_train=0.0000, loss_test=0.9134, acc_test=0.4796
# poison_percent 50 epoch 59: loss_train=0.0462, acc_train=1.0000, loss_test=0.8332, acc_test=0.5495
# poison_percent 50 epoch 60: loss_train=0.6981, acc_train=0.0000, loss_test=0.9621, acc_test=0.5209
# poison_percent 50 epoch 61: loss_train=0.6939, acc_train=0.0000, loss_test=0.9535, acc_test=0.4969
# poison_percent 50 epoch 62: loss_train=0.6811, acc_train=1.0000, loss_test=0.8636, acc_test=0.5571
# poison_percent 50 epoch 63: loss_train=0.7127, acc_train=0.0000, loss_test=0.8649, acc_test=0.5526
# poison_percent 50 epoch 64: loss_train=0.6593, acc_train=1.0000, loss_test=0.8830, acc_test=0.5551
# poison_percent 50 epoch 65: loss_train=0.6730, acc_train=1.0000, loss_test=0.8740, acc_test=0.5429
# poison_percent 50 epoch 66: loss_train=0.0000, acc_train=1.0000, loss_test=0.9801, acc_test=0.5444
# poison_percent 50 epoch 67: loss_train=0.7261, acc_train=0.0000, loss_test=0.9589, acc_test=0.5372
# poison_percent 50 epoch 68: loss_train=0.7220, acc_train=0.0000, loss_test=0.9692, acc_test=0.5469
# poison_percent 50 epoch 69: loss_train=0.1092, acc_train=1.0000, loss_test=0.9013, acc_test=0.5612
# poison_percent 50 epoch 70: loss_train=0.6886, acc_train=1.0000, loss_test=0.8745, acc_test=0.4867
# poison_percent 50 epoch 71: loss_train=0.0174, acc_train=1.0000, loss_test=0.9742, acc_test=0.5505
# poison_percent 50 epoch 72: loss_train=0.7429, acc_train=0.0000, loss_test=0.9213, acc_test=0.5423
# poison_percent 50 epoch 73: loss_train=0.6773, acc_train=1.0000, loss_test=0.9675, acc_test=0.5556
# poison_percent 50 epoch 74: loss_train=0.8628, acc_train=0.0000, loss_test=0.9216, acc_test=0.5832
# poison_percent 50 epoch 75: loss_train=0.6514, acc_train=1.0000, loss_test=0.9517, acc_test=0.5469
# poison_percent 50 epoch 76: loss_train=0.6795, acc_train=1.0000, loss_test=0.9770, acc_test=0.5541
# poison_percent 50 epoch 77: loss_train=0.8970, acc_train=0.0000, loss_test=0.9477, acc_test=0.5459
# poison_percent 50 epoch 78: loss_train=0.6777, acc_train=1.0000, loss_test=0.9415, acc_test=0.5490
# poison_percent 50 epoch 79: loss_train=0.6796, acc_train=1.0000, loss_test=1.0130, acc_test=0.5138
# poison_percent 50 epoch 80: loss_train=0.6846, acc_train=1.0000, loss_test=1.0206, acc_test=0.5505
# poison_percent 50 epoch 81: loss_train=0.6894, acc_train=1.0000, loss_test=1.0048, acc_test=0.4837
# poison_percent 50 epoch 82: loss_train=0.7090, acc_train=0.0000, loss_test=1.0626, acc_test=0.5403
# poison_percent 50 epoch 83: loss_train=0.3356, acc_train=1.0000, loss_test=1.0249, acc_test=0.5367
# poison_percent 50 epoch 84: loss_train=0.7220, acc_train=0.0000, loss_test=1.0754, acc_test=0.5429
# poison_percent 50 epoch 85: loss_train=0.6631, acc_train=1.0000, loss_test=1.1604, acc_test=0.5224
# poison_percent 50 epoch 86: loss_train=0.7050, acc_train=0.0000, loss_test=0.9929, acc_test=0.5311
# poison_percent 50 epoch 87: loss_train=0.6689, acc_train=1.0000, loss_test=1.0125, acc_test=0.5469
# poison_percent 50 epoch 88: loss_train=0.0106, acc_train=1.0000, loss_test=1.0525, acc_test=0.5536
# poison_percent 50 epoch 89: loss_train=0.6872, acc_train=1.0000, loss_test=1.0247, acc_test=0.5005
# poison_percent 50 epoch 90: loss_train=0.0000, acc_train=1.0000, loss_test=1.1342, acc_test=0.4689
# poison_percent 50 epoch 91: loss_train=0.7077, acc_train=0.0000, loss_test=1.0496, acc_test=0.5403
# poison_percent 50 epoch 92: loss_train=0.8231, acc_train=0.0000, loss_test=1.1180, acc_test=0.4714
# poison_percent 50 epoch 93: loss_train=0.6840, acc_train=1.0000, loss_test=1.0727, acc_test=0.5316
# poison_percent 50 epoch 94: loss_train=0.7229, acc_train=0.0000, loss_test=0.9645, acc_test=0.5699
# poison_percent 50 epoch 95: loss_train=0.6597, acc_train=1.0000, loss_test=1.1861, acc_test=0.5378
# poison_percent 50 epoch 96: loss_train=0.7067, acc_train=0.0000, loss_test=1.0275, acc_test=0.5464
# poison_percent 50 epoch 97: loss_train=0.7133, acc_train=0.0000, loss_test=1.0424, acc_test=0.5551
# poison_percent 50 epoch 98: loss_train=0.7187, acc_train=0.0000, loss_test=1.0128, acc_test=0.5638
# poison_percent 50 epoch 99: loss_train=0.6630, acc_train=1.0000, loss_test=1.0551, acc_test=0.5597
# Training log saved to ./results\CL_ModelN16L2_Batchsize1_rev2\poisoned_50percent\poisoned_50percent.csv
