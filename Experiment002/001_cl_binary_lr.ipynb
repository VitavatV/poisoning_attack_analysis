# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
class MNISTNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28*28, 1)
        self.fc2 = nn.Linear(1, 1)
        self.relu = nn.ReLU()
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = torch.sigmoid(x)
        return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 20
BATCH_SIZE = 1
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "./data/mnist_binary_poison/train"
TEST_PATH = "./data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
BATCH_SIZE_list = []
temp_bs = BATCH_SIZE
while temp_bs >= 1:
    BATCH_SIZE_list.append(temp_bs)
    temp_bs = temp_bs // 2

for experiment_bs in BATCH_SIZE_list:

    name_save_path = f"CL_MODEL_N1L2_BATCH_SIZE{experiment_bs}"
    mode = "mnist_binary_random_data"
    for i_poisoned in poison_n_list:
        percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

        # create directory
        NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
        save_path = os.path.join(RESULT_PATH,name_save_path,mode,NAME_SAVE_update_PATH)
        # Remove existing directory if it exists
        if os.path.exists(save_path):
            shutil.rmtree(save_path)
        if not os.path.exists(save_path):
            os.makedirs(save_path)
        save_all_path = os.path.join(RESULT_PATH,name_save_path,mode,'all')
        os.makedirs(save_all_path, exist_ok=True)
        
        # Load data
        X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                  poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                  select='Honest+Poisoned')
        X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
        print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
        print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

        if X_test.shape[0] == 0:
            raise ValueError("No valid test images found in the test directory!")

        X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
        X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
        y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

        model = MNISTNet().to(device)
        torch.save(model, os.path.join(save_path,'model_init.pt'))
        optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

        records = []

        # Training loop
        for epoch in range(EPOCHS):

            # Train
            model.train()
            
            #randomize the training data
            perm = torch.randperm(X_train_tensor.size(0))
            X_train_tensor = X_train_tensor[perm]
            y_train_tensor = y_train_tensor[perm]

            for start in range(0, X_train_tensor.size(0), experiment_bs):
                end = start + experiment_bs
                xb = X_train_tensor[start:end]
                yb = y_train_tensor[start:end]
                outputs = model(xb)
                preds = (outputs >= 0.5).float()
                acc_train = (preds == yb).float().mean().item()
                loss_train = binary_cross_entropy(outputs, yb)
                optimizer.zero_grad()
                loss_train.backward()
                optimizer.step()

            # Evaluate
            model.eval()
            with torch.no_grad():
                outputs = model(X_test_tensor)
                preds = (outputs >= 0.5).float()
                loss_test = binary_cross_entropy(outputs, y_test_tensor)
                acc_test = (preds == y_test_tensor).float().mean().item()
            records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                            'loss_train': loss_train.item(), 'acc_train': acc_train, 
                            'loss_test': loss_test.item(), 'acc_test': acc_test})
            report_txt = f"poison_percent {percent_poisoned} "
            report_txt += f"epoch {epoch}: "
            report_txt += f"loss_train={loss_train.item():.4f}, "
            report_txt += f"acc_train={acc_train:.4f}, "
            report_txt += f"loss_test={loss_test.item():.4f}, "
            report_txt += f"acc_test={acc_test:.4f}"
            print(report_txt)

        torch.save(model, os.path.join(save_path,'model_init.pt'))

        # Save training log
        df = pd.DataFrame(records)
        save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
        df.to_csv(save_name_path, index=False)
        print(f"Training log saved to {save_name_path}")

        # Plot loss and accuracy
        plt.figure(figsize=(10,4))

        plt.subplot(1,2,1)
        plt.plot(df['epoch'], df['loss_test'], marker='o')
        plt.title('Test Loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.grid(True)
        plt.ylim(0, 1.1)
        # plt.legend()

        plt.subplot(1,2,2)
        plt.plot(df['epoch'], df['acc_test'], marker='o')
        plt.title('Test Accuracy')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.grid(True)
        plt.ylim(0, 1.1)
        # plt.legend()

        plt.tight_layout()
        save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
        plt.savefig(save_name_path)

        save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
        plt.savefig(save_name_path)
        plt.close()
# Out:
# Loaded train: X=(5800, 784), y=(5800,)
# Loaded test: X=(1960, 784), y=(1960,)
# poison_percent 0 epoch 0: loss_train=0.0912, acc_train=1.0000, loss_test=0.0475, acc_test=0.9995
# poison_percent 0 epoch 1: loss_train=0.0000, acc_train=1.0000, loss_test=0.0096, acc_test=0.9995
# poison_percent 0 epoch 2: loss_train=0.0000, acc_train=1.0000, loss_test=0.0040, acc_test=0.9995
# poison_percent 0 epoch 3: loss_train=0.0030, acc_train=1.0000, loss_test=0.0025, acc_test=0.9995
# poison_percent 0 epoch 4: loss_train=0.0020, acc_train=1.0000, loss_test=0.0018, acc_test=1.0000
# poison_percent 0 epoch 5: loss_train=0.0000, acc_train=1.0000, loss_test=0.0013, acc_test=1.0000
# poison_percent 0 epoch 6: loss_train=0.0000, acc_train=1.0000, loss_test=0.0011, acc_test=1.0000
# poison_percent 0 epoch 7: loss_train=0.0007, acc_train=1.0000, loss_test=0.0012, acc_test=1.0000
# poison_percent 0 epoch 8: loss_train=0.0000, acc_train=1.0000, loss_test=0.0007, acc_test=1.0000
# poison_percent 0 epoch 9: loss_train=0.0004, acc_train=1.0000, loss_test=0.0008, acc_test=1.0000
# poison_percent 0 epoch 10: loss_train=0.0000, acc_train=1.0000, loss_test=0.0005, acc_test=1.0000
# poison_percent 0 epoch 11: loss_train=0.0003, acc_train=1.0000, loss_test=0.0005, acc_test=1.0000
# poison_percent 0 epoch 12: loss_train=0.0000, acc_train=1.0000, loss_test=0.0017, acc_test=0.9990
# poison_percent 0 epoch 13: loss_train=0.0002, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 14: loss_train=0.0000, acc_train=1.0000, loss_test=0.0011, acc_test=0.9995
# poison_percent 0 epoch 15: loss_train=0.0001, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 16: loss_train=0.0000, acc_train=1.0000, loss_test=0.0012, acc_test=0.9990
# poison_percent 0 epoch 17: loss_train=0.0000, acc_train=1.0000, loss_test=0.0001, acc_test=1.0000
# poison_percent 0 epoch 18: loss_train=0.0000, acc_train=1.0000, loss_test=0.0001, acc_test=1.0000
# poison_percent 0 epoch 19: loss_train=0.0000, acc_train=1.0000, loss_test=0.0001, acc_test=1.0000
# Training log saved to ./results\CL_MODEL_N1L2_BATCH_SIZE1\mnist_binary_random_data\poisoned_0percent\poisoned_0percent.csv
# Loaded train: X=(6496, 784), y=(6496,)
# Loaded test: X=(1960, 784), y=(1960,)
# poison_percent 10 epoch 0: loss_train=0.1032, acc_train=1.0000, loss_test=0.1761, acc_test=0.9985
# poison_percent 10 epoch 1: loss_train=0.0958, acc_train=1.0000, loss_test=0.1819, acc_test=0.9944
# poison_percent 10 epoch 2: loss_train=0.0724, acc_train=1.0000, loss_test=0.1718, acc_test=0.9949
# poison_percent 10 epoch 3: loss_train=0.1339, acc_train=1.0000, loss_test=0.1374, acc_test=0.9964
# poison_percent 10 epoch 4: loss_train=0.1308, acc_train=1.0000, loss_test=0.1668, acc_test=0.9944
# poison_percent 10 epoch 5: loss_train=0.0545, acc_train=1.0000, loss_test=0.1554, acc_test=0.9959
# poison_percent 10 epoch 6: loss_train=0.1279, acc_train=1.0000, loss_test=0.1418, acc_test=0.9969
# poison_percent 10 epoch 7: loss_train=0.1312, acc_train=1.0000, loss_test=0.1471, acc_test=0.9964
# poison_percent 10 epoch 8: loss_train=0.1253, acc_train=1.0000, loss_test=0.1302, acc_test=0.9974
# poison_percent 10 epoch 9: loss_train=0.1264, acc_train=1.0000, loss_test=0.1050, acc_test=0.9990
# poison_percent 10 epoch 10: loss_train=0.1269, acc_train=1.0000, loss_test=0.1412, acc_test=0.9974
# poison_percent 10 epoch 11: loss_train=0.1106, acc_train=1.0000, loss_test=0.1221, acc_test=0.9980
# poison_percent 10 epoch 12: loss_train=0.0571, acc_train=1.0000, loss_test=0.1138, acc_test=0.9995
# poison_percent 10 epoch 13: loss_train=0.2202, acc_train=1.0000, loss_test=0.1460, acc_test=0.9964
# poison_percent 10 epoch 14: loss_train=0.1693, acc_train=1.0000, loss_test=0.1153, acc_test=0.9980
# poison_percent 10 epoch 15: loss_train=0.1223, acc_train=1.0000, loss_test=0.1211, acc_test=0.9974
# poison_percent 10 epoch 16: loss_train=0.1212, acc_train=1.0000, loss_test=0.1139, acc_test=0.9980
# poison_percent 10 epoch 17: loss_train=0.1062, acc_train=1.0000, loss_test=0.1195, acc_test=0.9985
# poison_percent 10 epoch 18: loss_train=0.1222, acc_train=1.0000, loss_test=0.1411, acc_test=0.9954
# poison_percent 10 epoch 19: loss_train=0.1198, acc_train=1.0000, loss_test=0.1397, acc_test=0.9959
# Training log saved to ./results\CL_MODEL_N1L2_BATCH_SIZE1\mnist_binary_random_data\poisoned_10percent\poisoned_10percent.csv
# Loaded train: X=(7250, 784), y=(7250,)
# Loaded test: X=(1960, 784), y=(1960,)
# poison_percent 20 epoch 0: loss_train=0.0932, acc_train=1.0000, loss_test=0.3429, acc_test=0.9980
# poison_percent 20 epoch 1: loss_train=0.2729, acc_train=1.0000, loss_test=0.2913, acc_test=0.9918
# poison_percent 20 epoch 2: loss_train=0.3738, acc_train=1.0000, loss_test=0.2955, acc_test=0.9847
# poison_percent 20 epoch 3: loss_train=0.2273, acc_train=1.0000, loss_test=0.2601, acc_test=0.9888
# poison_percent 20 epoch 4: loss_train=0.2169, acc_train=1.0000, loss_test=0.2235, acc_test=0.9974
# poison_percent 20 epoch 5: loss_train=0.2396, acc_train=1.0000, loss_test=0.2441, acc_test=0.9934
# poison_percent 20 epoch 6: loss_train=0.2364, acc_train=1.0000, loss_test=0.2771, acc_test=0.9857
# poison_percent 20 epoch 7: loss_train=0.1558, acc_train=1.0000, loss_test=0.2453, acc_test=0.9878
# poison_percent 20 epoch 8: loss_train=0.2346, acc_train=1.0000, loss_test=0.2644, acc_test=0.9888
# poison_percent 20 epoch 9: loss_train=0.3378, acc_train=1.0000, loss_test=0.2080, acc_test=0.9974
# poison_percent 20 epoch 10: loss_train=0.2308, acc_train=1.0000, loss_test=0.2087, acc_test=0.9959
# poison_percent 20 epoch 11: loss_train=0.2353, acc_train=1.0000, loss_test=0.2251, acc_test=0.9949
# poison_percent 20 epoch 12: loss_train=2.7741, acc_train=0.0000, loss_test=0.2170, acc_test=0.9959
# poison_percent 20 epoch 13: loss_train=0.1097, acc_train=1.0000, loss_test=0.2194, acc_test=0.9934
# poison_percent 20 epoch 14: loss_train=0.2305, acc_train=1.0000, loss_test=0.2256, acc_test=0.9913
# poison_percent 20 epoch 15: loss_train=0.2316, acc_train=1.0000, loss_test=0.2333, acc_test=0.9908
# poison_percent 20 epoch 16: loss_train=0.2617, acc_train=1.0000, loss_test=0.1940, acc_test=0.9964
# poison_percent 20 epoch 17: loss_train=0.1937, acc_train=1.0000, loss_test=0.2241, acc_test=0.9913
# poison_percent 20 epoch 18: loss_train=0.3543, acc_train=1.0000, loss_test=0.2516, acc_test=0.9872
# poison_percent 20 epoch 19: loss_train=0.8628, acc_train=0.0000, loss_test=0.2095, acc_test=0.9939
# Training log saved to ./results\CL_MODEL_N1L2_BATCH_SIZE1\mnist_binary_random_data\poisoned_20percent\poisoned_20percent.csv
# Loaded train: X=(8294, 784), y=(8294,)
# Loaded test: X=(1960, 784), y=(1960,)
# poison_percent 30 epoch 0: loss_train=0.6843, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 1: loss_train=0.6948, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 2: loss_train=0.6882, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 3: loss_train=0.6862, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 4: loss_train=0.6793, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 5: loss_train=0.6900, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 6: loss_train=0.6781, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 epoch 7: loss_train=0.6794, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 8: loss_train=0.6976, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 9: loss_train=0.6946, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 10: loss_train=0.6901, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 11: loss_train=0.6988, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 12: loss_train=0.6834, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 13: loss_train=0.6876, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 14: loss_train=0.6820, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 15: loss_train=0.6804, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 16: loss_train=0.6989, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 17: loss_train=0.7088, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 epoch 18: loss_train=0.6980, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 19: loss_train=0.6955, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# Training log saved to ./results\CL_MODEL_N1L2_BATCH_SIZE1\mnist_binary_random_data\poisoned_30percent\poisoned_30percent.csv
# Loaded train: X=(9686, 784), y=(9686,)
# Loaded test: X=(1960, 784), y=(1960,)
# poison_percent 40 epoch 0: loss_train=0.6777, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 1: loss_train=0.6897, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 2: loss_train=0.7150, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 3: loss_train=0.7113, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 4: loss_train=0.7030, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 5: loss_train=0.6938, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 6: loss_train=0.6832, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 7: loss_train=0.6751, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 8: loss_train=0.6811, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 9: loss_train=0.6944, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 10: loss_train=0.6696, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 11: loss_train=0.6837, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 12: loss_train=0.6916, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 13: loss_train=0.6992, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 14: loss_train=0.6803, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 15: loss_train=0.7190, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 40 epoch 16: loss_train=0.6778, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 17: loss_train=0.6976, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 18: loss_train=0.7086, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 19: loss_train=0.6868, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# Training log saved to ./results\CL_MODEL_N1L2_BATCH_SIZE1\mnist_binary_random_data\poisoned_40percent\poisoned_40percent.csv
# Loaded train: X=(11600, 784), y=(11600,)
# Loaded test: X=(1960, 784), y=(1960,)
# poison_percent 50 epoch 0: loss_train=0.9135, acc_train=0.0000, loss_test=0.7560, acc_test=0.3378
# poison_percent 50 epoch 1: loss_train=0.6380, acc_train=1.0000, loss_test=0.6901, acc_test=0.5454
# poison_percent 50 epoch 2: loss_train=0.6022, acc_train=1.0000, loss_test=0.7072, acc_test=0.4117
# poison_percent 50 epoch 3: loss_train=0.6885, acc_train=1.0000, loss_test=0.6596, acc_test=0.7781
# poison_percent 50 epoch 4: loss_train=0.6033, acc_train=1.0000, loss_test=0.6895, acc_test=0.5602
# poison_percent 50 epoch 5: loss_train=0.6486, acc_train=1.0000, loss_test=0.6778, acc_test=0.6046
# poison_percent 50 epoch 6: loss_train=0.5957, acc_train=1.0000, loss_test=0.6818, acc_test=0.6393
# poison_percent 50 epoch 7: loss_train=0.8051, acc_train=0.0000, loss_test=0.6962, acc_test=0.5378
# poison_percent 50 epoch 8: loss_train=0.7445, acc_train=0.0000, loss_test=0.7079, acc_test=0.4128
# poison_percent 50 epoch 9: loss_train=0.7555, acc_train=0.0000, loss_test=0.6702, acc_test=0.6490
# poison_percent 50 epoch 10: loss_train=0.9744, acc_train=0.0000, loss_test=0.6379, acc_test=0.7291
# poison_percent 50 epoch 11: loss_train=0.5933, acc_train=1.0000, loss_test=0.6968, acc_test=0.5189
# poison_percent 50 epoch 12: loss_train=0.6871, acc_train=1.0000, loss_test=0.7090, acc_test=0.4668
# poison_percent 50 epoch 13: loss_train=1.0003, acc_train=0.0000, loss_test=0.6666, acc_test=0.5505
# poison_percent 50 epoch 14: loss_train=0.7352, acc_train=0.0000, loss_test=0.7020, acc_test=0.4837
# poison_percent 50 epoch 15: loss_train=0.6203, acc_train=1.0000, loss_test=0.7026, acc_test=0.4857
# poison_percent 50 epoch 16: loss_train=0.5955, acc_train=1.0000, loss_test=0.7201, acc_test=0.4107
# poison_percent 50 epoch 17: loss_train=1.0362, acc_train=0.0000, loss_test=0.6866, acc_test=0.5342
# poison_percent 50 epoch 18: loss_train=0.5888, acc_train=1.0000, loss_test=0.6973, acc_test=0.4934
# poison_percent 50 epoch 19: loss_train=0.6928, acc_train=1.0000, loss_test=0.7067, acc_test=0.4781
# Training log saved to ./results\CL_MODEL_N1L2_BATCH_SIZE1\mnist_binary_random_data\poisoned_50percent\poisoned_50percent.csv
