# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    model = MNISTNet().to(device)
    model.load_state_dict(global_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end]
            yb = y_c_tensor[start:end]
            outputs = model(xb)
            preds = (outputs >= 0.5).float()
            loss = binary_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # Return a deepcopy to avoid issues with state_dict references
    return copy.deepcopy(model.state_dict()), X_c_tensor.size(0), yb, outputs, preds

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 1
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "./data/mnist_binary_poison/train"
TEST_PATH = "./data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
for NODE in [1,2,4,8,16,32]:
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, 1)
            self.relu = nn.ReLU()
        def forward(self, x):
            x = self.fc1(x)
            x = self.relu(x)
            x = self.fc2(x)
            x = torch.sigmoid(x)
            return x

    BATCH_SIZE_list = []
    temp_bs = BATCH_SIZE
    while temp_bs >= 1:
        BATCH_SIZE_list.append(temp_bs)
        temp_bs = temp_bs // 2

    for rev in range(3):

        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"FL_ModelN{NODE}L2_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                global_model = MNISTNet().to(device)
                torch.save(global_model, os.path.join(save_path,'model_init.pt'))
                global_weights = global_model.state_dict()

                records = []

                X_train_tensor = {}
                y_train_tensor = {}
                for i in range(N_HONEST):
                    X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"honest_{i}"] = X_c_tensor
                    y_train_tensor[f"honest_{i}"] = y_c_tensor
                for i in range(i_poisoned):
                    X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"poison_{i}"] = X_c_tensor
                    y_train_tensor[f"poison_{i}"] = y_c_tensor

                # Training loop
                for round in range(ROUNDS):
                    # Prepare arguments for honest clients
                    
                    #randomize the training data
                    for i in range(N_HONEST):
                        perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                        X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                        y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                    honest_args = [
                        (
                            X_train_tensor[f"honest_{i}"],
                            y_train_tensor[f"honest_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(N_HONEST)
                    ]

                    # Prepare arguments for poisoned clients
                    
                    #randomize the training data
                    for i in range(i_poisoned):
                        perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                        X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                        y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                    poison_args = [
                        (
                            X_train_tensor[f"poison_{i}"],
                            y_train_tensor[f"poison_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(i_poisoned)
                    ]

                    # Run in parallel
                    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                        honest_results = list(executor.map(train_local_worker, honest_args))
                        poison_results = list(executor.map(train_local_worker, poison_args))

                    local_weights = []
                    local_sizes = []
                    local_y = []
                    local_outputs = []
                    local_preds = []
                    for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                        local_weights.append(l_w)
                        local_sizes.append(l_sz)
                        local_y.extend(l_y)
                        local_outputs.extend(l_out)
                        local_preds.extend(l_pred)
                    loss_train = binary_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                    acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                    # Federated averaging (weighted by client data size)
                    new_weights = {}
                    for key in global_weights.keys():
                        new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                    global_weights = new_weights
                    global_model.load_state_dict(global_weights)

                    # Evaluate
                    global_model.eval()
                    with torch.no_grad():
                        outputs = global_model(X_test_tensor)
                        preds = (outputs > 0.5).float()
                        loss_test = binary_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'round': round, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"round {round}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(global_model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['round'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['round'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 round 0: loss_train=0.6359, acc_train=0.4300, loss_test=0.5890, acc_test=0.5000
# poison_percent 0 round 1: loss_train=0.4673, acc_train=0.5200, loss_test=0.4863, acc_test=0.5000
# poison_percent 0 round 2: loss_train=0.4789, acc_train=0.4700, loss_test=0.4427, acc_test=0.5000
# poison_percent 0 round 3: loss_train=0.4477, acc_train=0.4700, loss_test=0.4198, acc_test=0.5000
# poison_percent 0 round 4: loss_train=0.4692, acc_train=0.4300, loss_test=0.4049, acc_test=0.5000
# poison_percent 0 round 5: loss_train=0.3492, acc_train=0.5500, loss_test=0.3932, acc_test=0.5000
# poison_percent 0 round 6: loss_train=0.3486, acc_train=0.5300, loss_test=0.3827, acc_test=0.5000
# poison_percent 0 round 7: loss_train=0.4188, acc_train=0.4300, loss_test=0.3737, acc_test=0.5000
# poison_percent 0 round 8: loss_train=0.3140, acc_train=0.8600, loss_test=0.3651, acc_test=0.9551
# poison_percent 0 round 9: loss_train=0.3072, acc_train=0.9500, loss_test=0.3567, acc_test=0.9597
# poison_percent 0 round 10: loss_train=0.3553, acc_train=0.9600, loss_test=0.3483, acc_test=0.9622
# poison_percent 0 round 11: loss_train=0.3744, acc_train=0.9300, loss_test=0.3408, acc_test=0.9628
# poison_percent 0 round 12: loss_train=0.3325, acc_train=0.9500, loss_test=0.3322, acc_test=0.9653
# poison_percent 0 round 13: loss_train=0.3272, acc_train=0.9800, loss_test=0.3243, acc_test=0.9663
# poison_percent 0 round 14: loss_train=0.3533, acc_train=0.9500, loss_test=0.3167, acc_test=0.9673
# poison_percent 0 round 15: loss_train=0.2804, acc_train=0.9400, loss_test=0.3095, acc_test=0.9679
# poison_percent 0 round 16: loss_train=0.3271, acc_train=0.9500, loss_test=0.3016, acc_test=0.9709
# poison_percent 0 round 17: loss_train=0.3354, acc_train=0.9500, loss_test=0.2938, acc_test=0.9719
# poison_percent 0 round 18: loss_train=0.3099, acc_train=0.9700, loss_test=0.2859, acc_test=0.9724
# poison_percent 0 round 19: loss_train=0.2694, acc_train=0.9700, loss_test=0.2790, acc_test=0.9740
# poison_percent 0 round 20: loss_train=0.2793, acc_train=0.9700, loss_test=0.2723, acc_test=0.9745
# poison_percent 0 round 21: loss_train=0.2690, acc_train=0.9800, loss_test=0.2650, acc_test=0.9755
# poison_percent 0 round 22: loss_train=0.2391, acc_train=0.9900, loss_test=0.2584, acc_test=0.9760
# poison_percent 0 round 23: loss_train=0.2461, acc_train=0.9900, loss_test=0.2515, acc_test=0.9770
# poison_percent 0 round 24: loss_train=0.1776, acc_train=1.0000, loss_test=0.2450, acc_test=0.9776
# poison_percent 0 round 25: loss_train=0.2428, acc_train=0.9800, loss_test=0.2384, acc_test=0.9781
# poison_percent 0 round 26: loss_train=0.2568, acc_train=0.9600, loss_test=0.2321, acc_test=0.9786
# poison_percent 0 round 27: loss_train=0.3547, acc_train=0.9500, loss_test=0.2257, acc_test=0.9791
# poison_percent 0 round 28: loss_train=0.2028, acc_train=0.9900, loss_test=0.2195, acc_test=0.9791
# poison_percent 0 round 29: loss_train=0.2017, acc_train=0.9900, loss_test=0.2133, acc_test=0.9796
# poison_percent 0 round 30: loss_train=0.2140, acc_train=0.9900, loss_test=0.2073, acc_test=0.9801
# poison_percent 0 round 31: loss_train=0.1619, acc_train=0.9900, loss_test=0.2014, acc_test=0.9801
# poison_percent 0 round 32: loss_train=0.1599, acc_train=1.0000, loss_test=0.1957, acc_test=0.9821
# poison_percent 0 round 33: loss_train=0.1671, acc_train=0.9800, loss_test=0.1903, acc_test=0.9821
# poison_percent 0 round 34: loss_train=0.1517, acc_train=1.0000, loss_test=0.1849, acc_test=0.9821
# poison_percent 0 round 35: loss_train=0.1557, acc_train=0.9900, loss_test=0.1797, acc_test=0.9837
# poison_percent 0 round 36: loss_train=0.2915, acc_train=0.9800, loss_test=0.1747, acc_test=0.9837
# poison_percent 0 round 37: loss_train=0.2147, acc_train=0.9600, loss_test=0.1696, acc_test=0.9837
# poison_percent 0 round 38: loss_train=0.1336, acc_train=0.9900, loss_test=0.1646, acc_test=0.9847
# poison_percent 0 round 39: loss_train=0.1600, acc_train=0.9900, loss_test=0.1603, acc_test=0.9847
# poison_percent 0 round 40: loss_train=0.2122, acc_train=0.9500, loss_test=0.1559, acc_test=0.9872
# poison_percent 0 round 41: loss_train=0.1658, acc_train=0.9800, loss_test=0.1515, acc_test=0.9878
# poison_percent 0 round 42: loss_train=0.1007, acc_train=0.9900, loss_test=0.1473, acc_test=0.9878
# poison_percent 0 round 43: loss_train=0.1528, acc_train=0.9700, loss_test=0.1432, acc_test=0.9878
# poison_percent 0 round 44: loss_train=0.1638, acc_train=0.9900, loss_test=0.1391, acc_test=0.9878
# poison_percent 0 round 45: loss_train=0.1933, acc_train=0.9800, loss_test=0.1351, acc_test=0.9878
# poison_percent 0 round 46: loss_train=0.1751, acc_train=0.9700, loss_test=0.1313, acc_test=0.9878
# poison_percent 0 round 47: loss_train=0.2100, acc_train=0.9700, loss_test=0.1277, acc_test=0.9888
# poison_percent 0 round 48: loss_train=0.1033, acc_train=0.9900, loss_test=0.1239, acc_test=0.9893
# poison_percent 0 round 49: loss_train=0.1139, acc_train=0.9900, loss_test=0.1205, acc_test=0.9893
# poison_percent 0 round 50: loss_train=0.2443, acc_train=0.9600, loss_test=0.1171, acc_test=0.9898
# poison_percent 0 round 51: loss_train=0.1407, acc_train=0.9900, loss_test=0.1140, acc_test=0.9898
# poison_percent 0 round 52: loss_train=0.0784, acc_train=1.0000, loss_test=0.1109, acc_test=0.9898
# poison_percent 0 round 53: loss_train=0.0916, acc_train=1.0000, loss_test=0.1078, acc_test=0.9898
# poison_percent 0 round 54: loss_train=0.0919, acc_train=1.0000, loss_test=0.1048, acc_test=0.9898
# poison_percent 0 round 55: loss_train=0.0960, acc_train=0.9900, loss_test=0.1019, acc_test=0.9903
# poison_percent 0 round 56: loss_train=0.1090, acc_train=0.9900, loss_test=0.0991, acc_test=0.9903
# poison_percent 0 round 57: loss_train=0.1233, acc_train=0.9900, loss_test=0.0963, acc_test=0.9903
# poison_percent 0 round 58: loss_train=0.1122, acc_train=0.9900, loss_test=0.0937, acc_test=0.9903
# poison_percent 0 round 59: loss_train=0.0854, acc_train=0.9900, loss_test=0.0912, acc_test=0.9908
# poison_percent 0 round 60: loss_train=0.0620, acc_train=1.0000, loss_test=0.0886, acc_test=0.9908
# poison_percent 0 round 61: loss_train=0.1020, acc_train=0.9600, loss_test=0.0863, acc_test=0.9908
# poison_percent 0 round 62: loss_train=0.0788, acc_train=0.9900, loss_test=0.0841, acc_test=0.9913
# poison_percent 0 round 63: loss_train=0.0688, acc_train=1.0000, loss_test=0.0820, acc_test=0.9913
# poison_percent 0 round 64: loss_train=0.1059, acc_train=0.9800, loss_test=0.0797, acc_test=0.9918
# poison_percent 0 round 65: loss_train=0.0822, acc_train=0.9900, loss_test=0.0776, acc_test=0.9918
# poison_percent 0 round 66: loss_train=0.0943, acc_train=0.9900, loss_test=0.0755, acc_test=0.9918
# poison_percent 0 round 67: loss_train=0.0552, acc_train=1.0000, loss_test=0.0734, acc_test=0.9923
# poison_percent 0 round 68: loss_train=0.0795, acc_train=0.9900, loss_test=0.0715, acc_test=0.9923
# poison_percent 0 round 69: loss_train=0.1041, acc_train=0.9900, loss_test=0.0698, acc_test=0.9923
# poison_percent 0 round 70: loss_train=0.0546, acc_train=1.0000, loss_test=0.0679, acc_test=0.9923
# poison_percent 0 round 71: loss_train=0.0507, acc_train=1.0000, loss_test=0.0662, acc_test=0.9923
# poison_percent 0 round 72: loss_train=0.0851, acc_train=0.9800, loss_test=0.0648, acc_test=0.9923
# poison_percent 0 round 73: loss_train=0.1218, acc_train=0.9700, loss_test=0.0631, acc_test=0.9923
# poison_percent 0 round 74: loss_train=0.0471, acc_train=0.9900, loss_test=0.0615, acc_test=0.9929
# poison_percent 0 round 75: loss_train=0.0666, acc_train=0.9800, loss_test=0.0599, acc_test=0.9929
# poison_percent 0 round 76: loss_train=0.0392, acc_train=1.0000, loss_test=0.0585, acc_test=0.9929
# poison_percent 0 round 77: loss_train=0.0387, acc_train=1.0000, loss_test=0.0571, acc_test=0.9929
# poison_percent 0 round 78: loss_train=0.1652, acc_train=0.9800, loss_test=0.0557, acc_test=0.9929
# poison_percent 0 round 79: loss_train=0.0330, acc_train=1.0000, loss_test=0.0542, acc_test=0.9929
# poison_percent 0 round 80: loss_train=0.0652, acc_train=0.9800, loss_test=0.0529, acc_test=0.9939
# poison_percent 0 round 81: loss_train=0.0356, acc_train=1.0000, loss_test=0.0517, acc_test=0.9939
# poison_percent 0 round 82: loss_train=0.0240, acc_train=1.0000, loss_test=0.0505, acc_test=0.9939
# poison_percent 0 round 83: loss_train=0.0521, acc_train=0.9900, loss_test=0.0493, acc_test=0.9939
# poison_percent 0 round 84: loss_train=0.1130, acc_train=0.9800, loss_test=0.0482, acc_test=0.9939
# poison_percent 0 round 85: loss_train=0.0687, acc_train=0.9700, loss_test=0.0471, acc_test=0.9939
# poison_percent 0 round 86: loss_train=0.0976, acc_train=0.9800, loss_test=0.0460, acc_test=0.9939
# poison_percent 0 round 87: loss_train=0.0482, acc_train=0.9900, loss_test=0.0451, acc_test=0.9939
# poison_percent 0 round 88: loss_train=0.0286, acc_train=1.0000, loss_test=0.0440, acc_test=0.9939
# poison_percent 0 round 89: loss_train=0.0358, acc_train=0.9900, loss_test=0.0431, acc_test=0.9939
# poison_percent 0 round 90: loss_train=0.0436, acc_train=0.9900, loss_test=0.0421, acc_test=0.9939
# poison_percent 0 round 91: loss_train=0.0270, acc_train=1.0000, loss_test=0.0413, acc_test=0.9939
# poison_percent 0 round 92: loss_train=0.0229, acc_train=1.0000, loss_test=0.0404, acc_test=0.9939
# poison_percent 0 round 93: loss_train=0.0604, acc_train=0.9800, loss_test=0.0395, acc_test=0.9939
# poison_percent 0 round 94: loss_train=0.0232, acc_train=1.0000, loss_test=0.0387, acc_test=0.9949
# poison_percent 0 round 95: loss_train=0.0190, acc_train=1.0000, loss_test=0.0379, acc_test=0.9949
# poison_percent 0 round 96: loss_train=0.1660, acc_train=0.9800, loss_test=0.0372, acc_test=0.9949
# poison_percent 0 round 97: loss_train=0.0530, acc_train=0.9900, loss_test=0.0365, acc_test=0.9949
# poison_percent 0 round 98: loss_train=0.0476, acc_train=0.9900, loss_test=0.0357, acc_test=0.9954
# poison_percent 0 round 99: loss_train=0.0248, acc_train=0.9900, loss_test=0.0349, acc_test=0.9959
# Training log saved to ./results\FL_ModelN1L2_Batchsize1_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 round 0: loss_train=0.6413, acc_train=0.5714, loss_test=0.6789, acc_test=0.5000
# poison_percent 10 round 1: loss_train=0.5648, acc_train=0.5536, loss_test=0.5758, acc_test=0.5000
# poison_percent 10 round 2: loss_train=0.5222, acc_train=0.4911, loss_test=0.5126, acc_test=0.5000
# poison_percent 10 round 3: loss_train=0.5165, acc_train=0.4643, loss_test=0.4675, acc_test=0.5000
# poison_percent 10 round 4: loss_train=0.4971, acc_train=0.4821, loss_test=0.4341, acc_test=0.5000
# poison_percent 10 round 5: loss_train=0.4714, acc_train=0.4911, loss_test=0.4088, acc_test=0.5000
# poison_percent 10 round 6: loss_train=0.4846, acc_train=0.4911, loss_test=0.3890, acc_test=0.5000
# poison_percent 10 round 7: loss_train=0.4701, acc_train=0.8929, loss_test=0.3726, acc_test=0.9847
# poison_percent 10 round 8: loss_train=0.5403, acc_train=0.8393, loss_test=0.3585, acc_test=0.9852
# poison_percent 10 round 9: loss_train=0.4668, acc_train=0.8750, loss_test=0.3462, acc_test=0.9883
# poison_percent 10 round 10: loss_train=0.4516, acc_train=0.8750, loss_test=0.3350, acc_test=0.9888
# poison_percent 10 round 11: loss_train=0.4479, acc_train=0.8750, loss_test=0.3247, acc_test=0.9908
# poison_percent 10 round 12: loss_train=0.4337, acc_train=0.8482, loss_test=0.3150, acc_test=0.9908
# poison_percent 10 round 13: loss_train=0.4729, acc_train=0.8571, loss_test=0.3059, acc_test=0.9913
# poison_percent 10 round 14: loss_train=0.4596, acc_train=0.8750, loss_test=0.2971, acc_test=0.9918
# poison_percent 10 round 15: loss_train=0.5012, acc_train=0.8839, loss_test=0.2887, acc_test=0.9918
# poison_percent 10 round 16: loss_train=0.5018, acc_train=0.8571, loss_test=0.2809, acc_test=0.9918
# poison_percent 10 round 17: loss_train=0.4493, acc_train=0.8571, loss_test=0.2730, acc_test=0.9923
# poison_percent 10 round 18: loss_train=0.5100, acc_train=0.8839, loss_test=0.2654, acc_test=0.9929
# poison_percent 10 round 19: loss_train=0.5457, acc_train=0.8839, loss_test=0.2583, acc_test=0.9929
# poison_percent 10 round 20: loss_train=0.5692, acc_train=0.8929, loss_test=0.2511, acc_test=0.9934
# poison_percent 10 round 21: loss_train=0.5321, acc_train=0.8661, loss_test=0.2441, acc_test=0.9934
# poison_percent 10 round 22: loss_train=0.5698, acc_train=0.8839, loss_test=0.2375, acc_test=0.9934
# poison_percent 10 round 23: loss_train=0.5193, acc_train=0.8839, loss_test=0.2309, acc_test=0.9934
# poison_percent 10 round 24: loss_train=0.4353, acc_train=0.8929, loss_test=0.2247, acc_test=0.9934
# poison_percent 10 round 25: loss_train=0.6536, acc_train=0.8839, loss_test=0.2187, acc_test=0.9939
# poison_percent 10 round 26: loss_train=0.6293, acc_train=0.8750, loss_test=0.2125, acc_test=0.9944
# poison_percent 10 round 27: loss_train=0.6377, acc_train=0.8929, loss_test=0.2069, acc_test=0.9944
# poison_percent 10 round 28: loss_train=0.5105, acc_train=0.8929, loss_test=0.2012, acc_test=0.9944
# poison_percent 10 round 29: loss_train=0.5693, acc_train=0.8661, loss_test=0.1956, acc_test=0.9944
# poison_percent 10 round 30: loss_train=0.6038, acc_train=0.8661, loss_test=0.1903, acc_test=0.9944
# poison_percent 10 round 31: loss_train=0.6153, acc_train=0.8839, loss_test=0.1853, acc_test=0.9944
# poison_percent 10 round 32: loss_train=0.4670, acc_train=0.8750, loss_test=0.1802, acc_test=0.9944
# poison_percent 10 round 33: loss_train=0.5669, acc_train=0.8839, loss_test=0.1755, acc_test=0.9944
# poison_percent 10 round 34: loss_train=0.6555, acc_train=0.8571, loss_test=0.1705, acc_test=0.9944
# poison_percent 10 round 35: loss_train=0.6029, acc_train=0.8929, loss_test=0.1658, acc_test=0.9944
# poison_percent 10 round 36: loss_train=0.7059, acc_train=0.8750, loss_test=0.1615, acc_test=0.9944
# poison_percent 10 round 37: loss_train=0.3762, acc_train=0.8929, loss_test=0.1570, acc_test=0.9944
# poison_percent 10 round 38: loss_train=0.5723, acc_train=0.8661, loss_test=0.1530, acc_test=0.9944
# poison_percent 10 round 39: loss_train=0.5939, acc_train=0.8839, loss_test=0.1489, acc_test=0.9944
# poison_percent 10 round 40: loss_train=0.5977, acc_train=0.8839, loss_test=0.1444, acc_test=0.9944
# poison_percent 10 round 41: loss_train=0.7347, acc_train=0.8750, loss_test=0.1403, acc_test=0.9949
# poison_percent 10 round 42: loss_train=0.7551, acc_train=0.8571, loss_test=0.1369, acc_test=0.9944
# poison_percent 10 round 43: loss_train=0.7460, acc_train=0.8839, loss_test=0.1331, acc_test=0.9944
# poison_percent 10 round 44: loss_train=0.5083, acc_train=0.8661, loss_test=0.1297, acc_test=0.9944
# poison_percent 10 round 45: loss_train=0.6152, acc_train=0.8750, loss_test=0.1259, acc_test=0.9949
# poison_percent 10 round 46: loss_train=0.6161, acc_train=0.8839, loss_test=0.1226, acc_test=0.9949
# poison_percent 10 round 47: loss_train=0.6912, acc_train=0.8839, loss_test=0.1194, acc_test=0.9949
# poison_percent 10 round 48: loss_train=0.6811, acc_train=0.9018, loss_test=0.1161, acc_test=0.9949
# poison_percent 10 round 49: loss_train=0.6408, acc_train=0.8839, loss_test=0.1130, acc_test=0.9949
# poison_percent 10 round 50: loss_train=0.6685, acc_train=0.8839, loss_test=0.1099, acc_test=0.9949
# poison_percent 10 round 51: loss_train=0.6957, acc_train=0.8661, loss_test=0.1071, acc_test=0.9949
# poison_percent 10 round 52: loss_train=0.6546, acc_train=0.8839, loss_test=0.1041, acc_test=0.9949
# poison_percent 10 round 53: loss_train=0.3738, acc_train=0.8839, loss_test=0.1012, acc_test=0.9949
# poison_percent 10 round 54: loss_train=0.7906, acc_train=0.8750, loss_test=0.0987, acc_test=0.9949
# poison_percent 10 round 55: loss_train=0.8274, acc_train=0.8661, loss_test=0.0963, acc_test=0.9949
# poison_percent 10 round 56: loss_train=0.6322, acc_train=0.8750, loss_test=0.0938, acc_test=0.9949
# poison_percent 10 round 57: loss_train=0.7275, acc_train=0.8750, loss_test=0.0914, acc_test=0.9949
# poison_percent 10 round 58: loss_train=0.6300, acc_train=0.8929, loss_test=0.0895, acc_test=0.9949
# poison_percent 10 round 59: loss_train=0.5854, acc_train=0.8661, loss_test=0.0874, acc_test=0.9949
# poison_percent 10 round 60: loss_train=0.7357, acc_train=0.8929, loss_test=0.0850, acc_test=0.9949
# poison_percent 10 round 61: loss_train=0.9356, acc_train=0.8929, loss_test=0.0830, acc_test=0.9949
# poison_percent 10 round 62: loss_train=0.5721, acc_train=0.8839, loss_test=0.0807, acc_test=0.9949
# poison_percent 10 round 63: loss_train=0.8397, acc_train=0.8929, loss_test=0.0786, acc_test=0.9949
# poison_percent 10 round 64: loss_train=0.5547, acc_train=0.8839, loss_test=0.0767, acc_test=0.9949
# poison_percent 10 round 65: loss_train=0.8859, acc_train=0.8661, loss_test=0.0747, acc_test=0.9949
# poison_percent 10 round 66: loss_train=0.8730, acc_train=0.8661, loss_test=0.0728, acc_test=0.9949
# poison_percent 10 round 67: loss_train=0.4853, acc_train=0.8929, loss_test=0.0712, acc_test=0.9949
# poison_percent 10 round 68: loss_train=0.6933, acc_train=0.8929, loss_test=0.0696, acc_test=0.9949
# poison_percent 10 round 69: loss_train=0.8697, acc_train=0.8750, loss_test=0.0677, acc_test=0.9949
# poison_percent 10 round 70: loss_train=0.5893, acc_train=0.8839, loss_test=0.0661, acc_test=0.9949
# poison_percent 10 round 71: loss_train=1.0487, acc_train=0.8750, loss_test=0.0644, acc_test=0.9949
# poison_percent 10 round 72: loss_train=0.9382, acc_train=0.8750, loss_test=0.0629, acc_test=0.9949
# poison_percent 10 round 73: loss_train=0.8317, acc_train=0.8750, loss_test=0.0616, acc_test=0.9949
# poison_percent 10 round 74: loss_train=0.9712, acc_train=0.8750, loss_test=0.0605, acc_test=0.9949
# poison_percent 10 round 75: loss_train=0.4771, acc_train=0.8929, loss_test=0.0589, acc_test=0.9949
# poison_percent 10 round 76: loss_train=0.7749, acc_train=0.8929, loss_test=0.0579, acc_test=0.9949
# poison_percent 10 round 77: loss_train=0.6566, acc_train=0.8929, loss_test=0.0565, acc_test=0.9949
# poison_percent 10 round 78: loss_train=0.8954, acc_train=0.8571, loss_test=0.0553, acc_test=0.9949
# poison_percent 10 round 79: loss_train=0.8744, acc_train=0.8839, loss_test=0.0539, acc_test=0.9949
# poison_percent 10 round 80: loss_train=1.0706, acc_train=0.8839, loss_test=0.0527, acc_test=0.9949
# poison_percent 10 round 81: loss_train=0.7344, acc_train=0.8929, loss_test=0.0517, acc_test=0.9949
# poison_percent 10 round 82: loss_train=0.8617, acc_train=0.9018, loss_test=0.0507, acc_test=0.9949
# poison_percent 10 round 83: loss_train=0.8501, acc_train=0.8839, loss_test=0.0496, acc_test=0.9949
# poison_percent 10 round 84: loss_train=0.7997, acc_train=0.8839, loss_test=0.0487, acc_test=0.9949
# poison_percent 10 round 85: loss_train=0.8256, acc_train=0.8839, loss_test=0.0477, acc_test=0.9949
# poison_percent 10 round 86: loss_train=0.7192, acc_train=0.8929, loss_test=0.0465, acc_test=0.9949
# poison_percent 10 round 87: loss_train=0.8236, acc_train=0.8750, loss_test=0.0455, acc_test=0.9949
# poison_percent 10 round 88: loss_train=1.1872, acc_train=0.8750, loss_test=0.0445, acc_test=0.9949
# poison_percent 10 round 89: loss_train=0.8309, acc_train=0.8929, loss_test=0.0434, acc_test=0.9954
# poison_percent 10 round 90: loss_train=0.9304, acc_train=0.8929, loss_test=0.0425, acc_test=0.9954
# poison_percent 10 round 91: loss_train=1.2363, acc_train=0.8929, loss_test=0.0418, acc_test=0.9954
# poison_percent 10 round 92: loss_train=1.0313, acc_train=0.8839, loss_test=0.0410, acc_test=0.9954
# poison_percent 10 round 93: loss_train=1.0264, acc_train=0.8929, loss_test=0.0402, acc_test=0.9959
# poison_percent 10 round 94: loss_train=0.8288, acc_train=0.8929, loss_test=0.0395, acc_test=0.9959
# poison_percent 10 round 95: loss_train=1.1520, acc_train=0.8750, loss_test=0.0388, acc_test=0.9959
# poison_percent 10 round 96: loss_train=0.7882, acc_train=0.8839, loss_test=0.0379, acc_test=0.9959
# poison_percent 10 round 97: loss_train=0.9661, acc_train=0.8839, loss_test=0.0372, acc_test=0.9959
# poison_percent 10 round 98: loss_train=0.7674, acc_train=0.8929, loss_test=0.0364, acc_test=0.9959
# poison_percent 10 round 99: loss_train=0.6850, acc_train=0.8929, loss_test=0.0358, acc_test=0.9959
# Training log saved to ./results\FL_ModelN1L2_Batchsize1_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=0.6335, acc_train=0.5280, loss_test=0.6702, acc_test=0.5000
# poison_percent 20 round 1: loss_train=0.6287, acc_train=0.5040, loss_test=0.6199, acc_test=0.5000
# poison_percent 20 round 2: loss_train=0.6502, acc_train=0.4640, loss_test=0.5885, acc_test=0.5000
# poison_percent 20 round 3: loss_train=0.5581, acc_train=0.5360, loss_test=0.5642, acc_test=0.5000
# poison_percent 20 round 4: loss_train=0.6365, acc_train=0.4800, loss_test=0.5449, acc_test=0.5000
# poison_percent 20 round 5: loss_train=0.5511, acc_train=0.5840, loss_test=0.5287, acc_test=0.5000
# poison_percent 20 round 6: loss_train=0.6294, acc_train=0.5520, loss_test=0.5144, acc_test=0.5000
# poison_percent 20 round 7: loss_train=0.6877, acc_train=0.5040, loss_test=0.5014, acc_test=0.5000
# poison_percent 20 round 8: loss_train=0.6056, acc_train=0.5840, loss_test=0.4892, acc_test=0.5000
# poison_percent 20 round 9: loss_train=0.6962, acc_train=0.5120, loss_test=0.4776, acc_test=0.5000
# poison_percent 20 round 10: loss_train=0.6008, acc_train=0.5600, loss_test=0.4665, acc_test=0.5000
# poison_percent 20 round 11: loss_train=0.7092, acc_train=0.4400, loss_test=0.4557, acc_test=0.5000
# poison_percent 20 round 12: loss_train=0.8035, acc_train=0.4880, loss_test=0.4450, acc_test=0.5000
# poison_percent 20 round 13: loss_train=0.8709, acc_train=0.4160, loss_test=0.4348, acc_test=0.5000
# poison_percent 20 round 14: loss_train=0.7541, acc_train=0.6320, loss_test=0.4248, acc_test=0.5000
# poison_percent 20 round 15: loss_train=0.7971, acc_train=0.4640, loss_test=0.4150, acc_test=0.5000
# poison_percent 20 round 16: loss_train=0.7909, acc_train=0.4880, loss_test=0.4054, acc_test=0.5000
# poison_percent 20 round 17: loss_train=0.8855, acc_train=0.4880, loss_test=0.3961, acc_test=0.5000
# poison_percent 20 round 18: loss_train=0.8019, acc_train=0.4800, loss_test=0.3868, acc_test=0.5000
# poison_percent 20 round 19: loss_train=0.7595, acc_train=0.4720, loss_test=0.3775, acc_test=0.5000
# poison_percent 20 round 20: loss_train=0.9333, acc_train=0.5600, loss_test=0.3688, acc_test=0.5000
# poison_percent 20 round 21: loss_train=1.0428, acc_train=0.4000, loss_test=0.3601, acc_test=0.5000
# poison_percent 20 round 22: loss_train=0.9370, acc_train=0.7680, loss_test=0.3514, acc_test=0.9791
# poison_percent 20 round 23: loss_train=1.0821, acc_train=0.7760, loss_test=0.3433, acc_test=0.9791
# poison_percent 20 round 24: loss_train=1.0614, acc_train=0.7920, loss_test=0.3350, acc_test=0.9801
# poison_percent 20 round 25: loss_train=0.7910, acc_train=0.7920, loss_test=0.3269, acc_test=0.9832
# poison_percent 20 round 26: loss_train=1.0490, acc_train=0.7760, loss_test=0.3190, acc_test=0.9847
# poison_percent 20 round 27: loss_train=0.9259, acc_train=0.7760, loss_test=0.3114, acc_test=0.9852
# poison_percent 20 round 28: loss_train=0.9159, acc_train=0.7920, loss_test=0.3039, acc_test=0.9857
# poison_percent 20 round 29: loss_train=1.2624, acc_train=0.7840, loss_test=0.2966, acc_test=0.9862
# poison_percent 20 round 30: loss_train=0.8441, acc_train=0.7840, loss_test=0.2893, acc_test=0.9862
# poison_percent 20 round 31: loss_train=0.9899, acc_train=0.7680, loss_test=0.2820, acc_test=0.9872
# poison_percent 20 round 32: loss_train=0.9786, acc_train=0.7840, loss_test=0.2750, acc_test=0.9878
# poison_percent 20 round 33: loss_train=0.9986, acc_train=0.7920, loss_test=0.2682, acc_test=0.9878
# poison_percent 20 round 34: loss_train=1.0460, acc_train=0.8000, loss_test=0.2617, acc_test=0.9883
# poison_percent 20 round 35: loss_train=0.8920, acc_train=0.8000, loss_test=0.2552, acc_test=0.9888
# poison_percent 20 round 36: loss_train=1.0743, acc_train=0.7840, loss_test=0.2490, acc_test=0.9888
# poison_percent 20 round 37: loss_train=0.9845, acc_train=0.7760, loss_test=0.2428, acc_test=0.9893
# poison_percent 20 round 38: loss_train=1.1736, acc_train=0.7920, loss_test=0.2369, acc_test=0.9898
# poison_percent 20 round 39: loss_train=0.9881, acc_train=0.7600, loss_test=0.2308, acc_test=0.9898
# poison_percent 20 round 40: loss_train=1.3508, acc_train=0.7920, loss_test=0.2250, acc_test=0.9908
# poison_percent 20 round 41: loss_train=1.2190, acc_train=0.8000, loss_test=0.2193, acc_test=0.9908
# poison_percent 20 round 42: loss_train=1.2290, acc_train=0.7920, loss_test=0.2138, acc_test=0.9908
# poison_percent 20 round 43: loss_train=1.1918, acc_train=0.7920, loss_test=0.2085, acc_test=0.9913
# poison_percent 20 round 44: loss_train=1.1006, acc_train=0.7920, loss_test=0.2033, acc_test=0.9913
# poison_percent 20 round 45: loss_train=1.1469, acc_train=0.7920, loss_test=0.1982, acc_test=0.9918
# poison_percent 20 round 46: loss_train=1.1807, acc_train=0.8000, loss_test=0.1933, acc_test=0.9918
# poison_percent 20 round 47: loss_train=1.4066, acc_train=0.8000, loss_test=0.1885, acc_test=0.9918
# poison_percent 20 round 48: loss_train=1.1649, acc_train=0.7920, loss_test=0.1837, acc_test=0.9918
# poison_percent 20 round 49: loss_train=1.4183, acc_train=0.7920, loss_test=0.1790, acc_test=0.9918
# poison_percent 20 round 50: loss_train=1.0433, acc_train=0.7920, loss_test=0.1745, acc_test=0.9918
# poison_percent 20 round 51: loss_train=0.8149, acc_train=0.8000, loss_test=0.1703, acc_test=0.9923
# poison_percent 20 round 52: loss_train=1.1417, acc_train=0.7840, loss_test=0.1660, acc_test=0.9923
# poison_percent 20 round 53: loss_train=1.4082, acc_train=0.7920, loss_test=0.1618, acc_test=0.9929
# poison_percent 20 round 54: loss_train=1.4756, acc_train=0.7920, loss_test=0.1577, acc_test=0.9929
# poison_percent 20 round 55: loss_train=0.9277, acc_train=0.7920, loss_test=0.1537, acc_test=0.9929
# poison_percent 20 round 56: loss_train=1.1962, acc_train=0.8000, loss_test=0.1498, acc_test=0.9934
# poison_percent 20 round 57: loss_train=1.4769, acc_train=0.8000, loss_test=0.1462, acc_test=0.9934
# poison_percent 20 round 58: loss_train=1.2941, acc_train=0.8000, loss_test=0.1426, acc_test=0.9934
# poison_percent 20 round 59: loss_train=1.5601, acc_train=0.7920, loss_test=0.1390, acc_test=0.9944
# poison_percent 20 round 60: loss_train=0.8890, acc_train=0.8080, loss_test=0.1356, acc_test=0.9944
# poison_percent 20 round 61: loss_train=1.0805, acc_train=0.8000, loss_test=0.1322, acc_test=0.9944
# poison_percent 20 round 62: loss_train=1.2256, acc_train=0.7760, loss_test=0.1289, acc_test=0.9944
# poison_percent 20 round 63: loss_train=0.9984, acc_train=0.8000, loss_test=0.1257, acc_test=0.9944
# poison_percent 20 round 64: loss_train=1.1140, acc_train=0.7920, loss_test=0.1226, acc_test=0.9944
# poison_percent 20 round 65: loss_train=1.1531, acc_train=0.8080, loss_test=0.1196, acc_test=0.9944
# poison_percent 20 round 66: loss_train=1.0078, acc_train=0.8000, loss_test=0.1167, acc_test=0.9944
# poison_percent 20 round 67: loss_train=0.9054, acc_train=0.8000, loss_test=0.1139, acc_test=0.9944
# poison_percent 20 round 68: loss_train=1.4635, acc_train=0.7920, loss_test=0.1111, acc_test=0.9944
# poison_percent 20 round 69: loss_train=1.2663, acc_train=0.7920, loss_test=0.1084, acc_test=0.9944
# poison_percent 20 round 70: loss_train=1.2724, acc_train=0.7840, loss_test=0.1058, acc_test=0.9944
# poison_percent 20 round 71: loss_train=1.3796, acc_train=0.7920, loss_test=0.1033, acc_test=0.9944
# poison_percent 20 round 72: loss_train=1.4007, acc_train=0.8000, loss_test=0.1008, acc_test=0.9944
# poison_percent 20 round 73: loss_train=1.2388, acc_train=0.8080, loss_test=0.0983, acc_test=0.9944
# poison_percent 20 round 74: loss_train=1.1701, acc_train=0.7920, loss_test=0.0960, acc_test=0.9944
# poison_percent 20 round 75: loss_train=1.2919, acc_train=0.8000, loss_test=0.0937, acc_test=0.9954
# poison_percent 20 round 76: loss_train=1.2814, acc_train=0.8000, loss_test=0.0915, acc_test=0.9954
# poison_percent 20 round 77: loss_train=1.4699, acc_train=0.8000, loss_test=0.0893, acc_test=0.9954
# poison_percent 20 round 78: loss_train=1.4326, acc_train=0.7920, loss_test=0.0873, acc_test=0.9954
# poison_percent 20 round 79: loss_train=1.4658, acc_train=0.8000, loss_test=0.0853, acc_test=0.9949
# poison_percent 20 round 80: loss_train=1.4592, acc_train=0.8000, loss_test=0.0832, acc_test=0.9949
# poison_percent 20 round 81: loss_train=0.9838, acc_train=0.8080, loss_test=0.0813, acc_test=0.9954
# poison_percent 20 round 82: loss_train=1.1055, acc_train=0.7840, loss_test=0.0794, acc_test=0.9954
# poison_percent 20 round 83: loss_train=1.3925, acc_train=0.7840, loss_test=0.0777, acc_test=0.9954
# poison_percent 20 round 84: loss_train=1.4738, acc_train=0.8000, loss_test=0.0759, acc_test=0.9954
# poison_percent 20 round 85: loss_train=1.5170, acc_train=0.7760, loss_test=0.0741, acc_test=0.9969
# poison_percent 20 round 86: loss_train=1.2367, acc_train=0.8000, loss_test=0.0724, acc_test=0.9969
# poison_percent 20 round 87: loss_train=1.4889, acc_train=0.8000, loss_test=0.0708, acc_test=0.9969
# poison_percent 20 round 88: loss_train=1.8172, acc_train=0.8000, loss_test=0.0693, acc_test=0.9969
# poison_percent 20 round 89: loss_train=1.1650, acc_train=0.8000, loss_test=0.0677, acc_test=0.9969
# poison_percent 20 round 90: loss_train=1.5040, acc_train=0.8000, loss_test=0.0662, acc_test=0.9969
# poison_percent 20 round 91: loss_train=1.5435, acc_train=0.7920, loss_test=0.0646, acc_test=0.9969
# poison_percent 20 round 92: loss_train=1.4257, acc_train=0.7920, loss_test=0.0632, acc_test=0.9969
# poison_percent 20 round 93: loss_train=1.1764, acc_train=0.7920, loss_test=0.0619, acc_test=0.9969
# poison_percent 20 round 94: loss_train=1.1431, acc_train=0.8000, loss_test=0.0605, acc_test=0.9969
# poison_percent 20 round 95: loss_train=1.3375, acc_train=0.8000, loss_test=0.0593, acc_test=0.9969
# poison_percent 20 round 96: loss_train=1.2045, acc_train=0.7840, loss_test=0.0580, acc_test=0.9969
# poison_percent 20 round 97: loss_train=1.2827, acc_train=0.7840, loss_test=0.0568, acc_test=0.9969
# poison_percent 20 round 98: loss_train=1.4422, acc_train=0.8000, loss_test=0.0556, acc_test=0.9969
# poison_percent 20 round 99: loss_train=1.5570, acc_train=0.7920, loss_test=0.0544, acc_test=0.9969
# Training log saved to ./results\FL_ModelN1L2_Batchsize1_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=0.5171, acc_train=0.5315, loss_test=0.5921, acc_test=0.5000
# poison_percent 30 round 1: loss_train=0.5064, acc_train=0.5315, loss_test=0.5115, acc_test=0.5000
# poison_percent 30 round 2: loss_train=0.5305, acc_train=0.5315, loss_test=0.4823, acc_test=0.5000
# poison_percent 30 round 3: loss_train=0.5429, acc_train=0.4406, loss_test=0.4634, acc_test=0.5000
# poison_percent 30 round 4: loss_train=0.5035, acc_train=0.5245, loss_test=0.4469, acc_test=0.5000
# poison_percent 30 round 5: loss_train=0.4795, acc_train=0.5664, loss_test=0.4328, acc_test=0.5000
# poison_percent 30 round 6: loss_train=0.5336, acc_train=0.4476, loss_test=0.4205, acc_test=0.5000
# poison_percent 30 round 7: loss_train=0.5353, acc_train=0.4965, loss_test=0.4096, acc_test=0.5000
# poison_percent 30 round 8: loss_train=0.5170, acc_train=0.4895, loss_test=0.3991, acc_test=0.5000
# poison_percent 30 round 9: loss_train=0.5140, acc_train=0.5315, loss_test=0.3892, acc_test=0.5000
# poison_percent 30 round 10: loss_train=0.5288, acc_train=0.5105, loss_test=0.3798, acc_test=0.5000
# poison_percent 30 round 11: loss_train=0.5820, acc_train=0.4406, loss_test=0.3709, acc_test=0.5000
# poison_percent 30 round 12: loss_train=0.6026, acc_train=0.4266, loss_test=0.3621, acc_test=0.5000
# poison_percent 30 round 13: loss_train=0.5846, acc_train=0.8112, loss_test=0.3539, acc_test=0.9954
# poison_percent 30 round 14: loss_train=0.5257, acc_train=0.6923, loss_test=0.3456, acc_test=0.9954
# poison_percent 30 round 15: loss_train=0.5784, acc_train=0.6993, loss_test=0.3377, acc_test=0.9964
# poison_percent 30 round 16: loss_train=0.5134, acc_train=0.7133, loss_test=0.3300, acc_test=0.9969
# poison_percent 30 round 17: loss_train=0.6013, acc_train=0.7063, loss_test=0.3222, acc_test=0.9964
# poison_percent 30 round 18: loss_train=0.5374, acc_train=0.7273, loss_test=0.3148, acc_test=0.9974
# poison_percent 30 round 19: loss_train=0.6150, acc_train=0.7063, loss_test=0.3078, acc_test=0.9974
# poison_percent 30 round 20: loss_train=0.6325, acc_train=0.6783, loss_test=0.3009, acc_test=0.9974
# poison_percent 30 round 21: loss_train=0.7502, acc_train=0.7133, loss_test=0.2940, acc_test=0.9974
# poison_percent 30 round 22: loss_train=0.5929, acc_train=0.7133, loss_test=0.2873, acc_test=0.9974
# poison_percent 30 round 23: loss_train=0.6292, acc_train=0.7063, loss_test=0.2808, acc_test=0.9974
# poison_percent 30 round 24: loss_train=0.7238, acc_train=0.6923, loss_test=0.2744, acc_test=0.9969
# poison_percent 30 round 25: loss_train=0.6609, acc_train=0.6993, loss_test=0.2681, acc_test=0.9969
# poison_percent 30 round 26: loss_train=0.7661, acc_train=0.6923, loss_test=0.2621, acc_test=0.9969
# poison_percent 30 round 27: loss_train=0.5896, acc_train=0.7063, loss_test=0.2562, acc_test=0.9969
# poison_percent 30 round 28: loss_train=0.6407, acc_train=0.7273, loss_test=0.2504, acc_test=0.9969
# poison_percent 30 round 29: loss_train=0.6880, acc_train=0.7063, loss_test=0.2447, acc_test=0.9969
# poison_percent 30 round 30: loss_train=0.6946, acc_train=0.6993, loss_test=0.2390, acc_test=0.9969
# poison_percent 30 round 31: loss_train=0.6822, acc_train=0.6783, loss_test=0.2336, acc_test=0.9974
# poison_percent 30 round 32: loss_train=0.7345, acc_train=0.6923, loss_test=0.2283, acc_test=0.9974
# poison_percent 30 round 33: loss_train=0.8684, acc_train=0.6923, loss_test=0.2231, acc_test=0.9974
# poison_percent 30 round 34: loss_train=0.6344, acc_train=0.6993, loss_test=0.2181, acc_test=0.9974
# poison_percent 30 round 35: loss_train=0.7500, acc_train=0.7133, loss_test=0.2132, acc_test=0.9974
# poison_percent 30 round 36: loss_train=0.7021, acc_train=0.7133, loss_test=0.2084, acc_test=0.9974
# poison_percent 30 round 37: loss_train=0.7657, acc_train=0.6993, loss_test=0.2036, acc_test=0.9974
# poison_percent 30 round 38: loss_train=0.7474, acc_train=0.7203, loss_test=0.1991, acc_test=0.9974
# poison_percent 30 round 39: loss_train=0.9004, acc_train=0.6993, loss_test=0.1947, acc_test=0.9974
# poison_percent 30 round 40: loss_train=0.7061, acc_train=0.7203, loss_test=0.1903, acc_test=0.9974
# poison_percent 30 round 41: loss_train=0.9307, acc_train=0.6923, loss_test=0.1862, acc_test=0.9974
# poison_percent 30 round 42: loss_train=0.7354, acc_train=0.6923, loss_test=0.1821, acc_test=0.9980
# poison_percent 30 round 43: loss_train=0.7596, acc_train=0.6993, loss_test=0.1780, acc_test=0.9980
# poison_percent 30 round 44: loss_train=0.7957, acc_train=0.7063, loss_test=0.1741, acc_test=0.9980
# poison_percent 30 round 45: loss_train=0.7492, acc_train=0.7063, loss_test=0.1703, acc_test=0.9980
# poison_percent 30 round 46: loss_train=0.8433, acc_train=0.6993, loss_test=0.1666, acc_test=0.9980
# poison_percent 30 round 47: loss_train=0.7663, acc_train=0.7063, loss_test=0.1630, acc_test=0.9980
# poison_percent 30 round 48: loss_train=0.7779, acc_train=0.7203, loss_test=0.1593, acc_test=0.9980
# poison_percent 30 round 49: loss_train=0.7056, acc_train=0.7133, loss_test=0.1558, acc_test=0.9980
# poison_percent 30 round 50: loss_train=0.9140, acc_train=0.6993, loss_test=0.1525, acc_test=0.9980
# poison_percent 30 round 51: loss_train=0.8331, acc_train=0.7063, loss_test=0.1493, acc_test=0.9980
# poison_percent 30 round 52: loss_train=0.8728, acc_train=0.6923, loss_test=0.1461, acc_test=0.9980
# poison_percent 30 round 53: loss_train=0.8344, acc_train=0.7203, loss_test=0.1431, acc_test=0.9980
# poison_percent 30 round 54: loss_train=0.7562, acc_train=0.7203, loss_test=0.1399, acc_test=0.9980
# poison_percent 30 round 55: loss_train=0.8049, acc_train=0.7133, loss_test=0.1370, acc_test=0.9980
# poison_percent 30 round 56: loss_train=0.6787, acc_train=0.7133, loss_test=0.1342, acc_test=0.9980
# poison_percent 30 round 57: loss_train=0.6862, acc_train=0.7133, loss_test=0.1315, acc_test=0.9980
# poison_percent 30 round 58: loss_train=0.9347, acc_train=0.6993, loss_test=0.1289, acc_test=0.9980
# poison_percent 30 round 59: loss_train=0.8896, acc_train=0.7273, loss_test=0.1264, acc_test=0.9980
# poison_percent 30 round 60: loss_train=0.7406, acc_train=0.7063, loss_test=0.1237, acc_test=0.9980
# poison_percent 30 round 61: loss_train=0.8928, acc_train=0.6993, loss_test=0.1209, acc_test=0.9980
# poison_percent 30 round 62: loss_train=0.8974, acc_train=0.7063, loss_test=0.1187, acc_test=0.9980
# poison_percent 30 round 63: loss_train=0.9358, acc_train=0.7063, loss_test=0.1163, acc_test=0.9980
# poison_percent 30 round 64: loss_train=1.0435, acc_train=0.7133, loss_test=0.1139, acc_test=0.9980
# poison_percent 30 round 65: loss_train=0.8452, acc_train=0.7273, loss_test=0.1115, acc_test=0.9980
# poison_percent 30 round 66: loss_train=0.8929, acc_train=0.7203, loss_test=0.1092, acc_test=0.9980
# poison_percent 30 round 67: loss_train=0.9232, acc_train=0.7063, loss_test=0.1071, acc_test=0.9980
# poison_percent 30 round 68: loss_train=0.9026, acc_train=0.7063, loss_test=0.1048, acc_test=0.9980
# poison_percent 30 round 69: loss_train=0.8684, acc_train=0.7133, loss_test=0.1029, acc_test=0.9980
# poison_percent 30 round 70: loss_train=1.0891, acc_train=0.7133, loss_test=0.1010, acc_test=0.9980
# poison_percent 30 round 71: loss_train=0.8952, acc_train=0.7203, loss_test=0.0992, acc_test=0.9980
# poison_percent 30 round 72: loss_train=0.8245, acc_train=0.7063, loss_test=0.0973, acc_test=0.9980
# poison_percent 30 round 73: loss_train=0.9050, acc_train=0.6993, loss_test=0.0955, acc_test=0.9980
# poison_percent 30 round 74: loss_train=0.8499, acc_train=0.7063, loss_test=0.0939, acc_test=0.9980
# poison_percent 30 round 75: loss_train=1.0239, acc_train=0.6993, loss_test=0.0921, acc_test=0.9980
# poison_percent 30 round 76: loss_train=1.1597, acc_train=0.7063, loss_test=0.0907, acc_test=0.9980
# poison_percent 30 round 77: loss_train=1.0312, acc_train=0.7063, loss_test=0.0891, acc_test=0.9980
# poison_percent 30 round 78: loss_train=0.9917, acc_train=0.7203, loss_test=0.0876, acc_test=0.9980
# poison_percent 30 round 79: loss_train=0.9107, acc_train=0.7343, loss_test=0.0861, acc_test=0.9980
# poison_percent 30 round 80: loss_train=0.8724, acc_train=0.7343, loss_test=0.0846, acc_test=0.9980
# poison_percent 30 round 81: loss_train=0.9408, acc_train=0.7133, loss_test=0.0834, acc_test=0.9980
# poison_percent 30 round 82: loss_train=0.9622, acc_train=0.7343, loss_test=0.0818, acc_test=0.9980
# poison_percent 30 round 83: loss_train=0.9023, acc_train=0.7343, loss_test=0.0805, acc_test=0.9980
# poison_percent 30 round 84: loss_train=0.8634, acc_train=0.7343, loss_test=0.0789, acc_test=0.9980
# poison_percent 30 round 85: loss_train=0.9251, acc_train=0.6993, loss_test=0.0776, acc_test=0.9980
# poison_percent 30 round 86: loss_train=1.0838, acc_train=0.7063, loss_test=0.0763, acc_test=0.9980
# poison_percent 30 round 87: loss_train=0.8740, acc_train=0.7343, loss_test=0.0751, acc_test=0.9980
# poison_percent 30 round 88: loss_train=1.0060, acc_train=0.7063, loss_test=0.0738, acc_test=0.9980
# poison_percent 30 round 89: loss_train=1.2535, acc_train=0.7063, loss_test=0.0729, acc_test=0.9980
# poison_percent 30 round 90: loss_train=1.1377, acc_train=0.7063, loss_test=0.0718, acc_test=0.9980
# poison_percent 30 round 91: loss_train=1.1348, acc_train=0.7203, loss_test=0.0707, acc_test=0.9980
# poison_percent 30 round 92: loss_train=1.1963, acc_train=0.7063, loss_test=0.0692, acc_test=0.9980
# poison_percent 30 round 93: loss_train=1.1507, acc_train=0.7273, loss_test=0.0683, acc_test=0.9980
# poison_percent 30 round 94: loss_train=1.1866, acc_train=0.7133, loss_test=0.0670, acc_test=0.9980
# poison_percent 30 round 95: loss_train=1.0408, acc_train=0.7133, loss_test=0.0662, acc_test=0.9980
# poison_percent 30 round 96: loss_train=0.9595, acc_train=0.7133, loss_test=0.0655, acc_test=0.9985
# poison_percent 30 round 97: loss_train=1.0543, acc_train=0.7273, loss_test=0.0645, acc_test=0.9985
# poison_percent 30 round 98: loss_train=0.9137, acc_train=0.7203, loss_test=0.0635, acc_test=0.9985
# poison_percent 30 round 99: loss_train=1.0163, acc_train=0.7133, loss_test=0.0625, acc_test=0.9985
# Training log saved to ./results\FL_ModelN1L2_Batchsize1_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=0.5291, acc_train=0.5210, loss_test=0.6079, acc_test=0.5000
# poison_percent 40 round 1: loss_train=0.5207, acc_train=0.5150, loss_test=0.5611, acc_test=0.5000
# poison_percent 40 round 2: loss_train=0.5447, acc_train=0.4671, loss_test=0.5220, acc_test=0.5000
# poison_percent 40 round 3: loss_train=0.5147, acc_train=0.4910, loss_test=0.4929, acc_test=0.5000
# poison_percent 40 round 4: loss_train=0.5450, acc_train=0.5269, loss_test=0.4806, acc_test=0.5000
# poison_percent 40 round 5: loss_train=0.5336, acc_train=0.4731, loss_test=0.4668, acc_test=0.5000
# poison_percent 40 round 6: loss_train=0.5347, acc_train=0.4491, loss_test=0.4518, acc_test=0.5000
# poison_percent 40 round 7: loss_train=0.5051, acc_train=0.4970, loss_test=0.4373, acc_test=0.5000
# poison_percent 40 round 8: loss_train=0.5081, acc_train=0.5150, loss_test=0.4261, acc_test=0.5000
# poison_percent 40 round 9: loss_train=0.5189, acc_train=0.5988, loss_test=0.4161, acc_test=0.5000
# poison_percent 40 round 10: loss_train=0.4756, acc_train=0.7066, loss_test=0.4065, acc_test=0.9985
# poison_percent 40 round 11: loss_train=0.5057, acc_train=0.7725, loss_test=0.3980, acc_test=0.9980
# poison_percent 40 round 12: loss_train=0.4759, acc_train=0.7006, loss_test=0.3906, acc_test=0.9980
# poison_percent 40 round 13: loss_train=0.4795, acc_train=0.7665, loss_test=0.3839, acc_test=0.9980
# poison_percent 40 round 14: loss_train=0.4975, acc_train=0.7605, loss_test=0.3771, acc_test=0.9980
# poison_percent 40 round 15: loss_train=0.4851, acc_train=0.7665, loss_test=0.3703, acc_test=0.9980
# poison_percent 40 round 16: loss_train=0.4637, acc_train=0.7725, loss_test=0.3639, acc_test=0.9980
# poison_percent 40 round 17: loss_train=0.5001, acc_train=0.7066, loss_test=0.3588, acc_test=0.9980
# poison_percent 40 round 18: loss_train=0.5029, acc_train=0.7365, loss_test=0.3532, acc_test=0.9974
# poison_percent 40 round 19: loss_train=0.4784, acc_train=0.7784, loss_test=0.3471, acc_test=0.9974
# poison_percent 40 round 20: loss_train=0.4948, acc_train=0.7365, loss_test=0.3415, acc_test=0.9974
# poison_percent 40 round 21: loss_train=0.4672, acc_train=0.7605, loss_test=0.3359, acc_test=0.9974
# poison_percent 40 round 22: loss_train=0.4654, acc_train=0.7365, loss_test=0.3299, acc_test=0.9974
# poison_percent 40 round 23: loss_train=0.4557, acc_train=0.7246, loss_test=0.3250, acc_test=0.9969
# poison_percent 40 round 24: loss_train=0.4651, acc_train=0.7725, loss_test=0.3204, acc_test=0.9964
# poison_percent 40 round 25: loss_train=0.4928, acc_train=0.7365, loss_test=0.3164, acc_test=0.9959
# poison_percent 40 round 26: loss_train=0.4741, acc_train=0.7784, loss_test=0.3117, acc_test=0.9959
# poison_percent 40 round 27: loss_train=0.4834, acc_train=0.7545, loss_test=0.3080, acc_test=0.9959
# poison_percent 40 round 28: loss_train=0.4775, acc_train=0.7425, loss_test=0.3034, acc_test=0.9959
# poison_percent 40 round 29: loss_train=0.4769, acc_train=0.7605, loss_test=0.2989, acc_test=0.9959
# poison_percent 40 round 30: loss_train=0.4529, acc_train=0.7725, loss_test=0.2954, acc_test=0.9959
# poison_percent 40 round 31: loss_train=0.4514, acc_train=0.7665, loss_test=0.2918, acc_test=0.9964
# poison_percent 40 round 32: loss_train=0.4871, acc_train=0.7246, loss_test=0.2870, acc_test=0.9964
# poison_percent 40 round 33: loss_train=0.4765, acc_train=0.7126, loss_test=0.2828, acc_test=0.9964
# poison_percent 40 round 34: loss_train=0.4417, acc_train=0.7904, loss_test=0.2789, acc_test=0.9964
# poison_percent 40 round 35: loss_train=0.4757, acc_train=0.7665, loss_test=0.2766, acc_test=0.9964
# poison_percent 40 round 36: loss_train=0.4658, acc_train=0.7365, loss_test=0.2735, acc_test=0.9959
# poison_percent 40 round 37: loss_train=0.4579, acc_train=0.7485, loss_test=0.2697, acc_test=0.9959
# poison_percent 40 round 38: loss_train=0.4409, acc_train=0.7665, loss_test=0.2674, acc_test=0.9959
# poison_percent 40 round 39: loss_train=0.4865, acc_train=0.7605, loss_test=0.2647, acc_test=0.9959
# poison_percent 40 round 40: loss_train=0.4482, acc_train=0.7485, loss_test=0.2603, acc_test=0.9959
# poison_percent 40 round 41: loss_train=0.4547, acc_train=0.7844, loss_test=0.2565, acc_test=0.9959
# poison_percent 40 round 42: loss_train=0.4374, acc_train=0.7725, loss_test=0.2549, acc_test=0.9959
# poison_percent 40 round 43: loss_train=0.4323, acc_train=0.7964, loss_test=0.2519, acc_test=0.9954
# poison_percent 40 round 44: loss_train=0.4309, acc_train=0.7605, loss_test=0.2485, acc_test=0.9954
# poison_percent 40 round 45: loss_train=0.4561, acc_train=0.7665, loss_test=0.2460, acc_test=0.9954
# poison_percent 40 round 46: loss_train=0.4126, acc_train=0.8024, loss_test=0.2430, acc_test=0.9954
# poison_percent 40 round 47: loss_train=0.4777, acc_train=0.7365, loss_test=0.2400, acc_test=0.9954
# poison_percent 40 round 48: loss_train=0.4381, acc_train=0.7904, loss_test=0.2376, acc_test=0.9954
# poison_percent 40 round 49: loss_train=0.4271, acc_train=0.7904, loss_test=0.2353, acc_test=0.9954
# poison_percent 40 round 50: loss_train=0.4786, acc_train=0.7545, loss_test=0.2329, acc_test=0.9954
# poison_percent 40 round 51: loss_train=0.4828, acc_train=0.7365, loss_test=0.2299, acc_test=0.9954
# poison_percent 40 round 52: loss_train=0.4537, acc_train=0.7784, loss_test=0.2272, acc_test=0.9954
# poison_percent 40 round 53: loss_train=0.4631, acc_train=0.7605, loss_test=0.2252, acc_test=0.9954
# poison_percent 40 round 54: loss_train=0.4598, acc_train=0.7545, loss_test=0.2233, acc_test=0.9954
# poison_percent 40 round 55: loss_train=0.4738, acc_train=0.7485, loss_test=0.2213, acc_test=0.9954
# poison_percent 40 round 56: loss_train=0.4553, acc_train=0.7665, loss_test=0.2190, acc_test=0.9954
# poison_percent 40 round 57: loss_train=0.4438, acc_train=0.7784, loss_test=0.2183, acc_test=0.9954
# poison_percent 40 round 58: loss_train=0.5346, acc_train=0.7305, loss_test=0.2158, acc_test=0.9954
# poison_percent 40 round 59: loss_train=0.4342, acc_train=0.7964, loss_test=0.2153, acc_test=0.9954
# poison_percent 40 round 60: loss_train=0.4608, acc_train=0.7784, loss_test=0.2126, acc_test=0.9954
# poison_percent 40 round 61: loss_train=0.4666, acc_train=0.7784, loss_test=0.2104, acc_test=0.9954
# poison_percent 40 round 62: loss_train=0.4690, acc_train=0.7485, loss_test=0.2085, acc_test=0.9954
# poison_percent 40 round 63: loss_train=0.4572, acc_train=0.7605, loss_test=0.2062, acc_test=0.9954
# poison_percent 40 round 64: loss_train=0.4901, acc_train=0.7425, loss_test=0.2045, acc_test=0.9954
# poison_percent 40 round 65: loss_train=0.4556, acc_train=0.7904, loss_test=0.2022, acc_test=0.9954
# poison_percent 40 round 66: loss_train=0.4600, acc_train=0.7784, loss_test=0.2013, acc_test=0.9954
# poison_percent 40 round 67: loss_train=0.4397, acc_train=0.8024, loss_test=0.2000, acc_test=0.9954
# poison_percent 40 round 68: loss_train=0.4599, acc_train=0.7725, loss_test=0.1994, acc_test=0.9954
# poison_percent 40 round 69: loss_train=0.4543, acc_train=0.7844, loss_test=0.1996, acc_test=0.9954
# poison_percent 40 round 70: loss_train=0.4303, acc_train=0.7964, loss_test=0.1974, acc_test=0.9954
# poison_percent 40 round 71: loss_train=0.4721, acc_train=0.7725, loss_test=0.1962, acc_test=0.9954
# poison_percent 40 round 72: loss_train=0.4289, acc_train=0.7904, loss_test=0.1936, acc_test=0.9954
# poison_percent 40 round 73: loss_train=0.4517, acc_train=0.7784, loss_test=0.1910, acc_test=0.9954
# poison_percent 40 round 74: loss_train=0.4858, acc_train=0.7725, loss_test=0.1900, acc_test=0.9954
# poison_percent 40 round 75: loss_train=0.4798, acc_train=0.7665, loss_test=0.1902, acc_test=0.9949
# poison_percent 40 round 76: loss_train=0.4544, acc_train=0.7844, loss_test=0.1894, acc_test=0.9949
# poison_percent 40 round 77: loss_train=0.4536, acc_train=0.7844, loss_test=0.1862, acc_test=0.9949
# poison_percent 40 round 78: loss_train=0.4799, acc_train=0.7425, loss_test=0.1848, acc_test=0.9949
# poison_percent 40 round 79: loss_train=0.4932, acc_train=0.7545, loss_test=0.1841, acc_test=0.9949
# poison_percent 40 round 80: loss_train=0.4199, acc_train=0.8084, loss_test=0.1829, acc_test=0.9949
# poison_percent 40 round 81: loss_train=0.4902, acc_train=0.7665, loss_test=0.1816, acc_test=0.9949
# ...
# poison_percent 40 round 41: loss_train=0.1169, acc_train=0.9461, loss_test=0.0684, acc_test=0.9964
# poison_percent 40 round 42: loss_train=0.1161, acc_train=0.9760, loss_test=0.0681, acc_test=0.9964
# poison_percent 40 round 43: loss_train=0.1378, acc_train=0.9521, loss_test=0.0668, acc_test=0.9964
# poison_percent 40 round 44: loss_train=0.1351, acc_train=0.9341, loss_test=0.0647, acc_test=0.9964
# poison_percent 40 round 45: loss_train=0.1119, acc_train=0.9820, loss_test=0.0675, acc_test=0.9964
# poison_percent 40 round 46: loss_train=0.1923, acc_train=0.9281, loss_test=0.0684, acc_test=0.9964
# poison_percent 40 round 47: loss_train=0.1072, acc_train=0.9760, loss_test=0.0697, acc_test=0.9964
# poison_percent 40 round 48: loss_train=0.1508, acc_train=0.9281, loss_test=0.0699, acc_test=0.9964
# poison_percent 40 round 49: loss_train=0.1011, acc_train=0.9701, loss_test=0.0728, acc_test=0.9954
# poison_percent 40 round 50: loss_train=0.1567, acc_train=0.9461, loss_test=0.0728, acc_test=0.9954
# poison_percent 40 round 51: loss_train=0.1354, acc_train=0.9341, loss_test=0.0725, acc_test=0.9949
# poison_percent 40 round 52: loss_train=0.1121, acc_train=0.9701, loss_test=0.0753, acc_test=0.9934
# poison_percent 40 round 53: loss_train=0.0915, acc_train=0.9820, loss_test=0.0787, acc_test=0.9929
# poison_percent 40 round 54: loss_train=0.1091, acc_train=0.9521, loss_test=0.0817, acc_test=0.9918
# poison_percent 40 round 55: loss_train=0.1093, acc_train=0.9760, loss_test=0.0831, acc_test=0.9913
# poison_percent 40 round 56: loss_train=0.1374, acc_train=0.9701, loss_test=0.0835, acc_test=0.9913
# poison_percent 40 round 57: loss_train=0.1297, acc_train=0.9461, loss_test=0.0838, acc_test=0.9913
# poison_percent 40 round 58: loss_train=0.1416, acc_train=0.9401, loss_test=0.0850, acc_test=0.9908
# poison_percent 40 round 59: loss_train=0.1003, acc_train=0.9701, loss_test=0.0846, acc_test=0.9908
# poison_percent 40 round 60: loss_train=0.1022, acc_train=0.9701, loss_test=0.0849, acc_test=0.9903
# poison_percent 40 round 61: loss_train=0.1146, acc_train=0.9701, loss_test=0.0850, acc_test=0.9898
# poison_percent 40 round 62: loss_train=0.1088, acc_train=0.9641, loss_test=0.0859, acc_test=0.9893
# poison_percent 40 round 63: loss_train=0.1150, acc_train=0.9581, loss_test=0.0898, acc_test=0.9878
# poison_percent 40 round 64: loss_train=0.1497, acc_train=0.9341, loss_test=0.0904, acc_test=0.9878
# poison_percent 40 round 65: loss_train=0.1711, acc_train=0.9341, loss_test=0.0938, acc_test=0.9872
# poison_percent 40 round 66: loss_train=0.1190, acc_train=0.9701, loss_test=0.0921, acc_test=0.9872
# poison_percent 40 round 67: loss_train=0.0691, acc_train=0.9880, loss_test=0.0909, acc_test=0.9872
# poison_percent 40 round 68: loss_train=0.1020, acc_train=0.9820, loss_test=0.0924, acc_test=0.9852
# poison_percent 40 round 69: loss_train=0.1204, acc_train=0.9701, loss_test=0.0954, acc_test=0.9852
# poison_percent 40 round 70: loss_train=0.1039, acc_train=0.9401, loss_test=0.0943, acc_test=0.9852
# poison_percent 40 round 71: loss_train=0.1018, acc_train=0.9701, loss_test=0.0978, acc_test=0.9832
# poison_percent 40 round 72: loss_train=0.1080, acc_train=0.9641, loss_test=0.0962, acc_test=0.9837
# poison_percent 40 round 73: loss_train=0.1173, acc_train=0.9581, loss_test=0.0991, acc_test=0.9816
# poison_percent 40 round 74: loss_train=0.1153, acc_train=0.9701, loss_test=0.1006, acc_test=0.9811
# poison_percent 40 round 75: loss_train=0.1024, acc_train=0.9760, loss_test=0.1019, acc_test=0.9816
# poison_percent 40 round 76: loss_train=0.1082, acc_train=0.9581, loss_test=0.0998, acc_test=0.9811
# poison_percent 40 round 77: loss_train=0.1466, acc_train=0.9461, loss_test=0.1026, acc_test=0.9806
# poison_percent 40 round 78: loss_train=0.0592, acc_train=0.9940, loss_test=0.1047, acc_test=0.9786
# poison_percent 40 round 79: loss_train=0.0928, acc_train=0.9641, loss_test=0.1007, acc_test=0.9801
# poison_percent 40 round 80: loss_train=0.1091, acc_train=0.9641, loss_test=0.1056, acc_test=0.9786
# poison_percent 40 round 81: loss_train=0.0960, acc_train=0.9701, loss_test=0.1093, acc_test=0.9781
# poison_percent 40 round 82: loss_train=0.1908, acc_train=0.9281, loss_test=0.1137, acc_test=0.9750
# poison_percent 40 round 83: loss_train=0.0998, acc_train=0.9641, loss_test=0.1114, acc_test=0.9755
# poison_percent 40 round 84: loss_train=0.1388, acc_train=0.9401, loss_test=0.1079, acc_test=0.9781
# poison_percent 40 round 85: loss_train=0.1677, acc_train=0.9461, loss_test=0.1090, acc_test=0.9770
# poison_percent 40 round 86: loss_train=0.0951, acc_train=0.9581, loss_test=0.1079, acc_test=0.9770
# poison_percent 40 round 87: loss_train=0.0944, acc_train=0.9581, loss_test=0.1074, acc_test=0.9765
# poison_percent 40 round 88: loss_train=0.1492, acc_train=0.9581, loss_test=0.1067, acc_test=0.9776
# poison_percent 40 round 89: loss_train=0.1420, acc_train=0.9461, loss_test=0.1121, acc_test=0.9730
# poison_percent 40 round 90: loss_train=0.0858, acc_train=0.9641, loss_test=0.1130, acc_test=0.9735
# poison_percent 40 round 91: loss_train=0.1366, acc_train=0.9461, loss_test=0.1153, acc_test=0.9719
# poison_percent 40 round 92: loss_train=0.0953, acc_train=0.9701, loss_test=0.1157, acc_test=0.9714
# poison_percent 40 round 93: loss_train=0.1284, acc_train=0.9461, loss_test=0.1135, acc_test=0.9730
# poison_percent 40 round 94: loss_train=0.1139, acc_train=0.9521, loss_test=0.1167, acc_test=0.9714
# poison_percent 40 round 95: loss_train=0.1485, acc_train=0.9521, loss_test=0.1175, acc_test=0.9714
# poison_percent 40 round 96: loss_train=0.0873, acc_train=0.9641, loss_test=0.1165, acc_test=0.9714
# poison_percent 40 round 97: loss_train=0.1047, acc_train=0.9581, loss_test=0.1232, acc_test=0.9699
# poison_percent 40 round 98: loss_train=0.1452, acc_train=0.9341, loss_test=0.1209, acc_test=0.9709
# poison_percent 40 round 99: loss_train=0.1174, acc_train=0.9581, loss_test=0.1213, acc_test=0.9699
# Training log saved to ./results\FL_ModelN16L2_Batchsize1_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 round 0: loss_train=0.2376, acc_train=0.9800, loss_test=0.6215, acc_test=0.9617
# poison_percent 50 round 1: loss_train=0.1721, acc_train=0.9950, loss_test=0.6091, acc_test=0.9000
# poison_percent 50 round 2: loss_train=0.1566, acc_train=0.9950, loss_test=0.6143, acc_test=0.9020
# poison_percent 50 round 3: loss_train=0.1343, acc_train=0.9900, loss_test=0.6350, acc_test=0.8872
# poison_percent 50 round 4: loss_train=0.1319, acc_train=0.9900, loss_test=0.6533, acc_test=0.8005
# poison_percent 50 round 5: loss_train=0.1188, acc_train=0.9950, loss_test=0.6592, acc_test=0.7117
# poison_percent 50 round 6: loss_train=0.1004, acc_train=0.9950, loss_test=0.6671, acc_test=0.6765
# poison_percent 50 round 7: loss_train=0.1021, acc_train=0.9950, loss_test=0.6673, acc_test=0.6872
# poison_percent 50 round 8: loss_train=0.1045, acc_train=0.9900, loss_test=0.6658, acc_test=0.6454
# poison_percent 50 round 9: loss_train=0.0926, acc_train=0.9950, loss_test=0.6739, acc_test=0.6495
# poison_percent 50 round 10: loss_train=0.0821, acc_train=1.0000, loss_test=0.6737, acc_test=0.6265
# poison_percent 50 round 11: loss_train=0.0767, acc_train=1.0000, loss_test=0.6776, acc_test=0.6224
# poison_percent 50 round 12: loss_train=0.0856, acc_train=0.9950, loss_test=0.6808, acc_test=0.5949
# poison_percent 50 round 13: loss_train=0.0966, acc_train=0.9850, loss_test=0.6774, acc_test=0.5913
# poison_percent 50 round 14: loss_train=0.0837, acc_train=0.9950, loss_test=0.6784, acc_test=0.5985
# poison_percent 50 round 15: loss_train=0.0704, acc_train=0.9900, loss_test=0.6731, acc_test=0.6255
# poison_percent 50 round 16: loss_train=0.0778, acc_train=0.9900, loss_test=0.6712, acc_test=0.6480
# poison_percent 50 round 17: loss_train=0.0661, acc_train=1.0000, loss_test=0.6722, acc_test=0.6270
# poison_percent 50 round 18: loss_train=0.0676, acc_train=0.9950, loss_test=0.6795, acc_test=0.5857
# poison_percent 50 round 19: loss_train=0.0708, acc_train=0.9950, loss_test=0.6722, acc_test=0.5954
# poison_percent 50 round 20: loss_train=0.0681, acc_train=0.9950, loss_test=0.6668, acc_test=0.6490
# poison_percent 50 round 21: loss_train=0.0616, acc_train=0.9950, loss_test=0.6752, acc_test=0.6107
# poison_percent 50 round 22: loss_train=0.0561, acc_train=1.0000, loss_test=0.6749, acc_test=0.6005
# poison_percent 50 round 23: loss_train=0.0732, acc_train=0.9900, loss_test=0.6762, acc_test=0.6077
# poison_percent 50 round 24: loss_train=0.0688, acc_train=0.9900, loss_test=0.6781, acc_test=0.6102
# poison_percent 50 round 25: loss_train=0.0623, acc_train=0.9950, loss_test=0.6763, acc_test=0.6214
# poison_percent 50 round 26: loss_train=0.0648, acc_train=0.9850, loss_test=0.6733, acc_test=0.6311
# poison_percent 50 round 27: loss_train=0.0473, acc_train=1.0000, loss_test=0.6755, acc_test=0.6209
# poison_percent 50 round 28: loss_train=0.0762, acc_train=0.9850, loss_test=0.6726, acc_test=0.6383
# poison_percent 50 round 29: loss_train=0.0541, acc_train=0.9950, loss_test=0.6637, acc_test=0.6383
# poison_percent 50 round 30: loss_train=0.0515, acc_train=0.9950, loss_test=0.6590, acc_test=0.6531
# poison_percent 50 round 31: loss_train=0.0526, acc_train=0.9950, loss_test=0.6510, acc_test=0.6934
# poison_percent 50 round 32: loss_train=0.0495, acc_train=0.9950, loss_test=0.6651, acc_test=0.6597
# poison_percent 50 round 33: loss_train=0.0600, acc_train=0.9950, loss_test=0.6625, acc_test=0.6541
# poison_percent 50 round 34: loss_train=0.0492, acc_train=0.9950, loss_test=0.6553, acc_test=0.6668
# poison_percent 50 round 35: loss_train=0.0532, acc_train=0.9900, loss_test=0.6682, acc_test=0.6393
# poison_percent 50 round 36: loss_train=0.0521, acc_train=0.9950, loss_test=0.6713, acc_test=0.5974
# poison_percent 50 round 37: loss_train=0.0611, acc_train=0.9900, loss_test=0.6706, acc_test=0.6122
# poison_percent 50 round 38: loss_train=0.0634, acc_train=0.9950, loss_test=0.6838, acc_test=0.5663
# poison_percent 50 round 39: loss_train=0.0500, acc_train=0.9900, loss_test=0.6842, acc_test=0.5464
# poison_percent 50 round 40: loss_train=0.0499, acc_train=0.9950, loss_test=0.6801, acc_test=0.5714
# poison_percent 50 round 41: loss_train=0.0457, acc_train=1.0000, loss_test=0.6798, acc_test=0.5597
# poison_percent 50 round 42: loss_train=0.0442, acc_train=0.9950, loss_test=0.6797, acc_test=0.5913
# poison_percent 50 round 43: loss_train=0.0400, acc_train=1.0000, loss_test=0.6759, acc_test=0.5934
# poison_percent 50 round 44: loss_train=0.0427, acc_train=0.9900, loss_test=0.6707, acc_test=0.5898
# poison_percent 50 round 45: loss_train=0.0534, acc_train=0.9950, loss_test=0.6834, acc_test=0.5959
# poison_percent 50 round 46: loss_train=0.0431, acc_train=0.9950, loss_test=0.6821, acc_test=0.5566
# poison_percent 50 round 47: loss_train=0.0354, acc_train=1.0000, loss_test=0.6865, acc_test=0.5505
# poison_percent 50 round 48: loss_train=0.0469, acc_train=0.9900, loss_test=0.6835, acc_test=0.5628
# poison_percent 50 round 49: loss_train=0.0602, acc_train=0.9850, loss_test=0.6936, acc_test=0.5582
# poison_percent 50 round 50: loss_train=0.0726, acc_train=0.9850, loss_test=0.6894, acc_test=0.5592
# poison_percent 50 round 51: loss_train=0.0360, acc_train=1.0000, loss_test=0.6846, acc_test=0.5566
# poison_percent 50 round 52: loss_train=0.0454, acc_train=0.9950, loss_test=0.6785, acc_test=0.5908
# poison_percent 50 round 53: loss_train=0.0347, acc_train=1.0000, loss_test=0.6911, acc_test=0.5469
# poison_percent 50 round 54: loss_train=0.0306, acc_train=1.0000, loss_test=0.6980, acc_test=0.5179
# poison_percent 50 round 55: loss_train=0.0440, acc_train=0.9900, loss_test=0.7079, acc_test=0.5056
# poison_percent 50 round 56: loss_train=0.0324, acc_train=1.0000, loss_test=0.6918, acc_test=0.5505
# poison_percent 50 round 57: loss_train=0.0542, acc_train=0.9850, loss_test=0.6992, acc_test=0.5316
# poison_percent 50 round 58: loss_train=0.0397, acc_train=0.9950, loss_test=0.7000, acc_test=0.5286
# poison_percent 50 round 59: loss_train=0.0423, acc_train=0.9900, loss_test=0.6913, acc_test=0.5454
# poison_percent 50 round 60: loss_train=0.0336, acc_train=1.0000, loss_test=0.6995, acc_test=0.5301
# poison_percent 50 round 61: loss_train=0.0353, acc_train=1.0000, loss_test=0.7034, acc_test=0.5194
# poison_percent 50 round 62: loss_train=0.0471, acc_train=0.9850, loss_test=0.6863, acc_test=0.5520
# poison_percent 50 round 63: loss_train=0.0393, acc_train=0.9900, loss_test=0.6924, acc_test=0.5526
# poison_percent 50 round 64: loss_train=0.0393, acc_train=0.9850, loss_test=0.6999, acc_test=0.5495
# poison_percent 50 round 65: loss_train=0.0362, acc_train=1.0000, loss_test=0.6885, acc_test=0.5556
# poison_percent 50 round 66: loss_train=0.0329, acc_train=0.9950, loss_test=0.7135, acc_test=0.5133
# poison_percent 50 round 67: loss_train=0.0533, acc_train=0.9950, loss_test=0.7003, acc_test=0.5316
# poison_percent 50 round 68: loss_train=0.0408, acc_train=0.9900, loss_test=0.7155, acc_test=0.4964
# poison_percent 50 round 69: loss_train=0.0550, acc_train=0.9900, loss_test=0.7086, acc_test=0.4980
# poison_percent 50 round 70: loss_train=0.0357, acc_train=0.9950, loss_test=0.7148, acc_test=0.5010
# poison_percent 50 round 71: loss_train=0.0409, acc_train=0.9900, loss_test=0.7216, acc_test=0.4607
# poison_percent 50 round 72: loss_train=0.0436, acc_train=0.9950, loss_test=0.7265, acc_test=0.4628
# poison_percent 50 round 73: loss_train=0.0334, acc_train=1.0000, loss_test=0.7218, acc_test=0.4709
# poison_percent 50 round 74: loss_train=0.0371, acc_train=0.9950, loss_test=0.7115, acc_test=0.4893
# poison_percent 50 round 75: loss_train=0.0426, acc_train=0.9900, loss_test=0.7256, acc_test=0.4622
# poison_percent 50 round 76: loss_train=0.0751, acc_train=0.9800, loss_test=0.7098, acc_test=0.5061
# poison_percent 50 round 77: loss_train=0.0477, acc_train=0.9900, loss_test=0.7158, acc_test=0.4918
# poison_percent 50 round 78: loss_train=0.0286, acc_train=1.0000, loss_test=0.7099, acc_test=0.5148
# poison_percent 50 round 79: loss_train=0.0314, acc_train=1.0000, loss_test=0.6957, acc_test=0.5474
# poison_percent 50 round 80: loss_train=0.0338, acc_train=1.0000, loss_test=0.6935, acc_test=0.5607
# poison_percent 50 round 81: loss_train=0.0255, acc_train=0.9950, loss_test=0.6808, acc_test=0.5842
# poison_percent 50 round 82: loss_train=0.0404, acc_train=0.9950, loss_test=0.6955, acc_test=0.5526
# poison_percent 50 round 83: loss_train=0.0313, acc_train=0.9950, loss_test=0.7081, acc_test=0.5342
# poison_percent 50 round 84: loss_train=0.0361, acc_train=0.9950, loss_test=0.7029, acc_test=0.5296
# poison_percent 50 round 85: loss_train=0.0376, acc_train=0.9900, loss_test=0.7102, acc_test=0.5138
# poison_percent 50 round 86: loss_train=0.0326, acc_train=1.0000, loss_test=0.7148, acc_test=0.4985
# poison_percent 50 round 87: loss_train=0.0337, acc_train=0.9950, loss_test=0.7204, acc_test=0.4954
# poison_percent 50 round 88: loss_train=0.0249, acc_train=1.0000, loss_test=0.7183, acc_test=0.4969
# poison_percent 50 round 89: loss_train=0.0286, acc_train=1.0000, loss_test=0.7157, acc_test=0.4811
# poison_percent 50 round 90: loss_train=0.0290, acc_train=1.0000, loss_test=0.7197, acc_test=0.4755
# poison_percent 50 round 91: loss_train=0.0267, acc_train=1.0000, loss_test=0.7110, acc_test=0.4929
# poison_percent 50 round 92: loss_train=0.0231, acc_train=1.0000, loss_test=0.7174, acc_test=0.5240
# poison_percent 50 round 93: loss_train=0.0298, acc_train=0.9950, loss_test=0.7108, acc_test=0.5209
# poison_percent 50 round 94: loss_train=0.0360, acc_train=0.9950, loss_test=0.7259, acc_test=0.5158
# poison_percent 50 round 95: loss_train=0.0392, acc_train=0.9950, loss_test=0.7190, acc_test=0.5153
# poison_percent 50 round 96: loss_train=0.0290, acc_train=0.9950, loss_test=0.6985, acc_test=0.5495
# poison_percent 50 round 97: loss_train=0.0460, acc_train=0.9800, loss_test=0.7128, acc_test=0.5214
# poison_percent 50 round 98: loss_train=0.0292, acc_train=1.0000, loss_test=0.7042, acc_test=0.5357
# poison_percent 50 round 99: loss_train=0.0284, acc_train=0.9950, loss_test=0.7037, acc_test=0.5306
# Training log saved to ./results\FL_ModelN16L2_Batchsize1_rev2\poisoned_50percent\poisoned_50percent.csv
