# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    model = MNISTNet().to(device)
    model.load_state_dict(global_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end]
            yb = y_c_tensor[start:end]
            outputs = model(xb)
            preds = (outputs >= 0.5).float()
            loss = binary_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # Return a deepcopy to avoid issues with state_dict references
    return copy.deepcopy(model.state_dict()), X_c_tensor.size(0), yb, outputs, preds

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 1
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "./data/mnist_binary_poison/train"
TEST_PATH = "./data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
NODE = 1
for LAYER in [3,4,5,6]: # LAYER - (first,last)

    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            
            # 1. Define the stack of hidden layers (Linear + ReLU)
            # Use a list comprehension to create the (Linear, ReLU) pairs
            hidden_layers = []
            for _ in range(LAYER-2):
                hidden_layers.append(nn.Linear(NODE, NODE))
                hidden_layers.append(nn.ReLU())
                
            # 2. Use nn.Sequential to wrap the entire dynamic stack
            self.dynamic_hidden = nn.Sequential(*hidden_layers)
            
            # Other layers
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, 1)

        def forward(self, x):
            # Flatten the input
            x = x.view(x.size(0), -1) 
            
            # Input Layer
            x = self.fc1(x)
            x = nn.ReLU()(x) # We need to manually apply ReLU here
            
            # Dynamic Hidden Layers (Executed sequentially without a loop)
            x = self.dynamic_hidden(x)
                
            # Output Layer
            x = self.fc2(x)
            x = torch.sigmoid(x)
            
            return x

    BATCH_SIZE_list = []
    temp_bs = BATCH_SIZE
    while temp_bs >= 1:
        BATCH_SIZE_list.append(temp_bs)
        temp_bs = temp_bs // 2

    for rev in range(3):

        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"FL_ModelN{NODE}L{LAYER}_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                global_model = MNISTNet().to(device)
                torch.save(global_model, os.path.join(save_path,'model_init.pt'))
                global_weights = global_model.state_dict()

                records = []

                X_train_tensor = {}
                y_train_tensor = {}
                for i in range(N_HONEST):
                    X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"honest_{i}"] = X_c_tensor
                    y_train_tensor[f"honest_{i}"] = y_c_tensor
                for i in range(i_poisoned):
                    X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"poison_{i}"] = X_c_tensor
                    y_train_tensor[f"poison_{i}"] = y_c_tensor

                # Training loop
                for round in range(ROUNDS):
                    # Prepare arguments for honest clients
                    
                    #randomize the training data
                    for i in range(N_HONEST):
                        perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                        X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                        y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                    honest_args = [
                        (
                            X_train_tensor[f"honest_{i}"],
                            y_train_tensor[f"honest_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(N_HONEST)
                    ]

                    # Prepare arguments for poisoned clients
                    
                    #randomize the training data
                    for i in range(i_poisoned):
                        perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                        X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                        y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                    poison_args = [
                        (
                            X_train_tensor[f"poison_{i}"],
                            y_train_tensor[f"poison_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(i_poisoned)
                    ]

                    # Run in parallel
                    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                        honest_results = list(executor.map(train_local_worker, honest_args))
                        poison_results = list(executor.map(train_local_worker, poison_args))

                    local_weights = []
                    local_sizes = []
                    local_y = []
                    local_outputs = []
                    local_preds = []
                    for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                        local_weights.append(l_w)
                        local_sizes.append(l_sz)
                        local_y.extend(l_y)
                        local_outputs.extend(l_out)
                        local_preds.extend(l_pred)
                    loss_train = binary_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                    acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                    # Federated averaging (weighted by client data size)
                    new_weights = {}
                    for key in global_weights.keys():
                        new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                    global_weights = new_weights
                    global_model.load_state_dict(global_weights)

                    # Evaluate
                    global_model.eval()
                    with torch.no_grad():
                        outputs = global_model(X_test_tensor)
                        preds = (outputs > 0.5).float()
                        loss_test = binary_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'round': round, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"round {round}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(global_model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['round'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['round'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 round 0: loss_train=0.7156, acc_train=0.4500, loss_test=0.6939, acc_test=0.5000
# poison_percent 0 round 1: loss_train=0.6658, acc_train=0.4400, loss_test=0.6422, acc_test=0.5010
# poison_percent 0 round 2: loss_train=0.6040, acc_train=0.7900, loss_test=0.5934, acc_test=0.8740
# poison_percent 0 round 3: loss_train=0.5841, acc_train=0.9600, loss_test=0.5783, acc_test=0.9520
# poison_percent 0 round 4: loss_train=0.5534, acc_train=0.9900, loss_test=0.5669, acc_test=0.9735
# poison_percent 0 round 5: loss_train=0.5618, acc_train=0.9800, loss_test=0.5559, acc_test=0.9806
# poison_percent 0 round 6: loss_train=0.5579, acc_train=0.9800, loss_test=0.5445, acc_test=0.9827
# poison_percent 0 round 7: loss_train=0.5394, acc_train=1.0000, loss_test=0.5330, acc_test=0.9832
# poison_percent 0 round 8: loss_train=0.5277, acc_train=0.9700, loss_test=0.5213, acc_test=0.9852
# poison_percent 0 round 9: loss_train=0.4815, acc_train=1.0000, loss_test=0.5096, acc_test=0.9862
# poison_percent 0 round 10: loss_train=0.4939, acc_train=0.9900, loss_test=0.4978, acc_test=0.9867
# poison_percent 0 round 11: loss_train=0.4886, acc_train=0.9900, loss_test=0.4860, acc_test=0.9878
# poison_percent 0 round 12: loss_train=0.4722, acc_train=1.0000, loss_test=0.4742, acc_test=0.9883
# poison_percent 0 round 13: loss_train=0.4723, acc_train=1.0000, loss_test=0.4624, acc_test=0.9888
# poison_percent 0 round 14: loss_train=0.4652, acc_train=1.0000, loss_test=0.4506, acc_test=0.9898
# poison_percent 0 round 15: loss_train=0.4522, acc_train=0.9600, loss_test=0.4389, acc_test=0.9893
# poison_percent 0 round 16: loss_train=0.4260, acc_train=1.0000, loss_test=0.4273, acc_test=0.9913
# poison_percent 0 round 17: loss_train=0.4008, acc_train=1.0000, loss_test=0.4158, acc_test=0.9913
# poison_percent 0 round 18: loss_train=0.4331, acc_train=0.9800, loss_test=0.4045, acc_test=0.9913
# poison_percent 0 round 19: loss_train=0.3836, acc_train=1.0000, loss_test=0.3933, acc_test=0.9918
# poison_percent 0 round 20: loss_train=0.4271, acc_train=0.9900, loss_test=0.3823, acc_test=0.9918
# poison_percent 0 round 21: loss_train=0.3836, acc_train=0.9900, loss_test=0.3715, acc_test=0.9918
# poison_percent 0 round 22: loss_train=0.3400, acc_train=1.0000, loss_test=0.3609, acc_test=0.9923
# poison_percent 0 round 23: loss_train=0.3186, acc_train=1.0000, loss_test=0.3504, acc_test=0.9923
# poison_percent 0 round 24: loss_train=0.3521, acc_train=0.9900, loss_test=0.3402, acc_test=0.9934
# poison_percent 0 round 25: loss_train=0.3593, acc_train=0.9900, loss_test=0.3301, acc_test=0.9934
# poison_percent 0 round 26: loss_train=0.3157, acc_train=0.9900, loss_test=0.3202, acc_test=0.9939
# poison_percent 0 round 27: loss_train=0.2790, acc_train=1.0000, loss_test=0.3106, acc_test=0.9944
# poison_percent 0 round 28: loss_train=0.2950, acc_train=0.9900, loss_test=0.3013, acc_test=0.9954
# poison_percent 0 round 29: loss_train=0.2768, acc_train=1.0000, loss_test=0.2922, acc_test=0.9954
# poison_percent 0 round 30: loss_train=0.3123, acc_train=0.9700, loss_test=0.2832, acc_test=0.9954
# poison_percent 0 round 31: loss_train=0.2516, acc_train=1.0000, loss_test=0.2745, acc_test=0.9969
# poison_percent 0 round 32: loss_train=0.2994, acc_train=1.0000, loss_test=0.2660, acc_test=0.9974
# poison_percent 0 round 33: loss_train=0.2753, acc_train=1.0000, loss_test=0.2576, acc_test=0.9974
# poison_percent 0 round 34: loss_train=0.2634, acc_train=1.0000, loss_test=0.2496, acc_test=0.9974
# poison_percent 0 round 35: loss_train=0.2653, acc_train=1.0000, loss_test=0.2416, acc_test=0.9974
# poison_percent 0 round 36: loss_train=0.2070, acc_train=0.9900, loss_test=0.2340, acc_test=0.9980
# poison_percent 0 round 37: loss_train=0.2458, acc_train=0.9700, loss_test=0.2266, acc_test=0.9980
# poison_percent 0 round 38: loss_train=0.2396, acc_train=0.9800, loss_test=0.2194, acc_test=0.9980
# poison_percent 0 round 39: loss_train=0.2155, acc_train=1.0000, loss_test=0.2123, acc_test=0.9980
# poison_percent 0 round 40: loss_train=0.2154, acc_train=0.9800, loss_test=0.2054, acc_test=0.9980
# poison_percent 0 round 41: loss_train=0.2003, acc_train=1.0000, loss_test=0.1988, acc_test=0.9980
# poison_percent 0 round 42: loss_train=0.2461, acc_train=0.9600, loss_test=0.1924, acc_test=0.9980
# poison_percent 0 round 43: loss_train=0.1912, acc_train=1.0000, loss_test=0.1861, acc_test=0.9980
# poison_percent 0 round 44: loss_train=0.2052, acc_train=0.9900, loss_test=0.1801, acc_test=0.9974
# poison_percent 0 round 45: loss_train=0.1823, acc_train=1.0000, loss_test=0.1742, acc_test=0.9974
# poison_percent 0 round 46: loss_train=0.1601, acc_train=0.9900, loss_test=0.1685, acc_test=0.9974
# poison_percent 0 round 47: loss_train=0.1816, acc_train=0.9800, loss_test=0.1629, acc_test=0.9974
# poison_percent 0 round 48: loss_train=0.1540, acc_train=1.0000, loss_test=0.1576, acc_test=0.9974
# poison_percent 0 round 49: loss_train=0.1608, acc_train=0.9900, loss_test=0.1523, acc_test=0.9974
# poison_percent 0 round 50: loss_train=0.1446, acc_train=1.0000, loss_test=0.1472, acc_test=0.9974
# poison_percent 0 round 51: loss_train=0.1468, acc_train=1.0000, loss_test=0.1422, acc_test=0.9974
# poison_percent 0 round 52: loss_train=0.1368, acc_train=0.9800, loss_test=0.1375, acc_test=0.9974
# poison_percent 0 round 53: loss_train=0.1515, acc_train=1.0000, loss_test=0.1329, acc_test=0.9974
# poison_percent 0 round 54: loss_train=0.1174, acc_train=1.0000, loss_test=0.1285, acc_test=0.9974
# poison_percent 0 round 55: loss_train=0.1337, acc_train=0.9800, loss_test=0.1242, acc_test=0.9974
# poison_percent 0 round 56: loss_train=0.1087, acc_train=1.0000, loss_test=0.1201, acc_test=0.9974
# poison_percent 0 round 57: loss_train=0.1003, acc_train=1.0000, loss_test=0.1161, acc_test=0.9980
# poison_percent 0 round 58: loss_train=0.0945, acc_train=1.0000, loss_test=0.1122, acc_test=0.9980
# poison_percent 0 round 59: loss_train=0.1249, acc_train=0.9900, loss_test=0.1084, acc_test=0.9980
# poison_percent 0 round 60: loss_train=0.1110, acc_train=0.9900, loss_test=0.1048, acc_test=0.9980
# poison_percent 0 round 61: loss_train=0.0979, acc_train=1.0000, loss_test=0.1013, acc_test=0.9980
# poison_percent 0 round 62: loss_train=0.0849, acc_train=1.0000, loss_test=0.0978, acc_test=0.9980
# poison_percent 0 round 63: loss_train=0.0848, acc_train=1.0000, loss_test=0.0946, acc_test=0.9980
# poison_percent 0 round 64: loss_train=0.0836, acc_train=1.0000, loss_test=0.0914, acc_test=0.9980
# poison_percent 0 round 65: loss_train=0.0842, acc_train=1.0000, loss_test=0.0883, acc_test=0.9980
# poison_percent 0 round 66: loss_train=0.0713, acc_train=1.0000, loss_test=0.0854, acc_test=0.9980
# poison_percent 0 round 67: loss_train=0.1047, acc_train=0.9900, loss_test=0.0825, acc_test=0.9980
# poison_percent 0 round 68: loss_train=0.0693, acc_train=1.0000, loss_test=0.0797, acc_test=0.9980
# poison_percent 0 round 69: loss_train=0.0691, acc_train=1.0000, loss_test=0.0770, acc_test=0.9980
# poison_percent 0 round 70: loss_train=0.0757, acc_train=1.0000, loss_test=0.0744, acc_test=0.9980
# poison_percent 0 round 71: loss_train=0.0635, acc_train=1.0000, loss_test=0.0719, acc_test=0.9980
# poison_percent 0 round 72: loss_train=0.0769, acc_train=1.0000, loss_test=0.0695, acc_test=0.9980
# poison_percent 0 round 73: loss_train=0.0656, acc_train=1.0000, loss_test=0.0672, acc_test=0.9980
# poison_percent 0 round 74: loss_train=0.0604, acc_train=1.0000, loss_test=0.0649, acc_test=0.9980
# poison_percent 0 round 75: loss_train=0.0628, acc_train=1.0000, loss_test=0.0627, acc_test=0.9980
# poison_percent 0 round 76: loss_train=0.0611, acc_train=1.0000, loss_test=0.0607, acc_test=0.9980
# poison_percent 0 round 77: loss_train=0.0611, acc_train=1.0000, loss_test=0.0587, acc_test=0.9980
# poison_percent 0 round 78: loss_train=0.0584, acc_train=1.0000, loss_test=0.0567, acc_test=0.9980
# poison_percent 0 round 79: loss_train=0.0569, acc_train=0.9900, loss_test=0.0549, acc_test=0.9980
# poison_percent 0 round 80: loss_train=0.0481, acc_train=1.0000, loss_test=0.0531, acc_test=0.9980
# poison_percent 0 round 81: loss_train=0.0560, acc_train=1.0000, loss_test=0.0514, acc_test=0.9980
# poison_percent 0 round 82: loss_train=0.0437, acc_train=1.0000, loss_test=0.0497, acc_test=0.9980
# poison_percent 0 round 83: loss_train=0.0496, acc_train=1.0000, loss_test=0.0480, acc_test=0.9980
# poison_percent 0 round 84: loss_train=0.0467, acc_train=0.9900, loss_test=0.0465, acc_test=0.9980
# poison_percent 0 round 85: loss_train=0.0491, acc_train=1.0000, loss_test=0.0450, acc_test=0.9980
# poison_percent 0 round 86: loss_train=0.0393, acc_train=1.0000, loss_test=0.0435, acc_test=0.9980
# poison_percent 0 round 87: loss_train=0.0470, acc_train=1.0000, loss_test=0.0421, acc_test=0.9980
# poison_percent 0 round 88: loss_train=0.0451, acc_train=1.0000, loss_test=0.0407, acc_test=0.9980
# poison_percent 0 round 89: loss_train=0.0359, acc_train=1.0000, loss_test=0.0394, acc_test=0.9980
# poison_percent 0 round 90: loss_train=0.0375, acc_train=1.0000, loss_test=0.0382, acc_test=0.9980
# poison_percent 0 round 91: loss_train=0.0405, acc_train=1.0000, loss_test=0.0370, acc_test=0.9980
# poison_percent 0 round 92: loss_train=0.0299, acc_train=1.0000, loss_test=0.0358, acc_test=0.9980
# poison_percent 0 round 93: loss_train=0.0544, acc_train=0.9900, loss_test=0.0347, acc_test=0.9980
# poison_percent 0 round 94: loss_train=0.0290, acc_train=1.0000, loss_test=0.0336, acc_test=0.9980
# poison_percent 0 round 95: loss_train=0.0384, acc_train=1.0000, loss_test=0.0326, acc_test=0.9980
# poison_percent 0 round 96: loss_train=0.0366, acc_train=0.9900, loss_test=0.0316, acc_test=0.9980
# poison_percent 0 round 97: loss_train=0.0270, acc_train=1.0000, loss_test=0.0306, acc_test=0.9980
# poison_percent 0 round 98: loss_train=0.1199, acc_train=0.9900, loss_test=0.0297, acc_test=0.9980
# poison_percent 0 round 99: loss_train=0.0356, acc_train=0.9900, loss_test=0.0288, acc_test=0.9980
# Training log saved to ./results\FL_ModelN1L3_Batchsize1_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 round 0: loss_train=0.7200, acc_train=0.5714, loss_test=0.8097, acc_test=0.5000
# poison_percent 10 round 1: loss_train=0.7364, acc_train=0.5357, loss_test=0.7616, acc_test=0.5000
# poison_percent 10 round 2: loss_train=0.8963, acc_train=0.3661, loss_test=0.7193, acc_test=0.5000
# poison_percent 10 round 3: loss_train=0.6739, acc_train=0.5268, loss_test=0.6814, acc_test=0.5000
# poison_percent 10 round 4: loss_train=0.6808, acc_train=0.5000, loss_test=0.6479, acc_test=0.5000
# poison_percent 10 round 5: loss_train=0.6803, acc_train=0.5089, loss_test=0.6177, acc_test=0.5000
# poison_percent 10 round 6: loss_train=0.6634, acc_train=0.4911, loss_test=0.5901, acc_test=0.5000
# poison_percent 10 round 7: loss_train=0.5878, acc_train=0.5714, loss_test=0.5647, acc_test=0.5000
# poison_percent 10 round 8: loss_train=0.6492, acc_train=0.5000, loss_test=0.5409, acc_test=0.5000
# poison_percent 10 round 9: loss_train=0.6560, acc_train=0.5000, loss_test=0.5191, acc_test=0.5000
# poison_percent 10 round 10: loss_train=0.6078, acc_train=0.4911, loss_test=0.4984, acc_test=0.5000
# poison_percent 10 round 11: loss_train=0.6341, acc_train=0.5000, loss_test=0.4793, acc_test=0.5000
# poison_percent 10 round 12: loss_train=0.7091, acc_train=0.4554, loss_test=0.4611, acc_test=0.5000
# poison_percent 10 round 13: loss_train=0.6025, acc_train=0.5357, loss_test=0.4442, acc_test=0.5000
# poison_percent 10 round 14: loss_train=0.6933, acc_train=0.3929, loss_test=0.4283, acc_test=0.5000
# poison_percent 10 round 15: loss_train=0.5856, acc_train=0.4732, loss_test=0.4130, acc_test=0.5000
# poison_percent 10 round 16: loss_train=0.4875, acc_train=0.5714, loss_test=0.3987, acc_test=0.5000
# poison_percent 10 round 17: loss_train=0.5342, acc_train=0.5089, loss_test=0.3851, acc_test=0.5000
# poison_percent 10 round 18: loss_train=0.5203, acc_train=0.4821, loss_test=0.3721, acc_test=0.5000
# poison_percent 10 round 19: loss_train=0.6027, acc_train=0.8750, loss_test=0.3597, acc_test=0.9571
# poison_percent 10 round 20: loss_train=0.5961, acc_train=0.8482, loss_test=0.3476, acc_test=0.9643
# poison_percent 10 round 21: loss_train=0.4967, acc_train=0.8482, loss_test=0.3356, acc_test=0.9689
# poison_percent 10 round 22: loss_train=0.5228, acc_train=0.8750, loss_test=0.3244, acc_test=0.9719
# poison_percent 10 round 23: loss_train=0.5451, acc_train=0.8750, loss_test=0.3136, acc_test=0.9735
# poison_percent 10 round 24: loss_train=0.5557, acc_train=0.8750, loss_test=0.3040, acc_test=0.9755
# poison_percent 10 round 25: loss_train=0.4852, acc_train=0.8750, loss_test=0.2962, acc_test=0.9760
# poison_percent 10 round 26: loss_train=0.5697, acc_train=0.8482, loss_test=0.2884, acc_test=0.9776
# poison_percent 10 round 27: loss_train=0.6338, acc_train=0.8393, loss_test=0.2809, acc_test=0.9796
# poison_percent 10 round 28: loss_train=0.4642, acc_train=0.8929, loss_test=0.2736, acc_test=0.9806
# poison_percent 10 round 29: loss_train=0.5666, acc_train=0.8750, loss_test=0.2666, acc_test=0.9806
# poison_percent 10 round 30: loss_train=0.6583, acc_train=0.8661, loss_test=0.2596, acc_test=0.9816
# poison_percent 10 round 31: loss_train=0.8058, acc_train=0.8393, loss_test=0.2530, acc_test=0.9821
# poison_percent 10 round 32: loss_train=0.6480, acc_train=0.8839, loss_test=0.2462, acc_test=0.9832
# poison_percent 10 round 33: loss_train=0.7041, acc_train=0.8571, loss_test=0.2398, acc_test=0.9832
# poison_percent 10 round 34: loss_train=0.5179, acc_train=0.8839, loss_test=0.2337, acc_test=0.9837
# poison_percent 10 round 35: loss_train=0.6253, acc_train=0.8929, loss_test=0.2276, acc_test=0.9857
# poison_percent 10 round 36: loss_train=0.5404, acc_train=0.8839, loss_test=0.2215, acc_test=0.9857
# poison_percent 10 round 37: loss_train=0.6062, acc_train=0.8661, loss_test=0.2157, acc_test=0.9857
# poison_percent 10 round 38: loss_train=0.6055, acc_train=0.8929, loss_test=0.2097, acc_test=0.9883
# poison_percent 10 round 39: loss_train=0.6530, acc_train=0.8839, loss_test=0.2042, acc_test=0.9888
# poison_percent 10 round 40: loss_train=0.6849, acc_train=0.8839, loss_test=0.1988, acc_test=0.9893
# poison_percent 10 round 41: loss_train=0.5530, acc_train=0.8839, loss_test=0.1934, acc_test=0.9898
# poison_percent 10 round 42: loss_train=0.5260, acc_train=0.9018, loss_test=0.1883, acc_test=0.9898
# poison_percent 10 round 43: loss_train=0.6432, acc_train=0.8839, loss_test=0.1832, acc_test=0.9898
# poison_percent 10 round 44: loss_train=0.6127, acc_train=0.8750, loss_test=0.1782, acc_test=0.9898
# poison_percent 10 round 45: loss_train=0.7439, acc_train=0.8929, loss_test=0.1733, acc_test=0.9903
# poison_percent 10 round 46: loss_train=0.6248, acc_train=0.8661, loss_test=0.1688, acc_test=0.9903
# poison_percent 10 round 47: loss_train=0.5391, acc_train=0.8839, loss_test=0.1643, acc_test=0.9903
# poison_percent 10 round 48: loss_train=0.5799, acc_train=0.8929, loss_test=0.1600, acc_test=0.9908
# poison_percent 10 round 49: loss_train=0.3892, acc_train=0.8750, loss_test=0.1557, acc_test=0.9908
# poison_percent 10 round 50: loss_train=0.6702, acc_train=0.9018, loss_test=0.1516, acc_test=0.9908
# poison_percent 10 round 51: loss_train=0.7269, acc_train=0.8839, loss_test=0.1476, acc_test=0.9908
# poison_percent 10 round 52: loss_train=0.6341, acc_train=0.8750, loss_test=0.1434, acc_test=0.9908
# poison_percent 10 round 53: loss_train=0.7153, acc_train=0.8839, loss_test=0.1395, acc_test=0.9913
# poison_percent 10 round 54: loss_train=0.5966, acc_train=0.8929, loss_test=0.1358, acc_test=0.9913
# poison_percent 10 round 55: loss_train=0.8749, acc_train=0.8839, loss_test=0.1322, acc_test=0.9913
# poison_percent 10 round 56: loss_train=0.7707, acc_train=0.8750, loss_test=0.1288, acc_test=0.9918
# poison_percent 10 round 57: loss_train=0.4945, acc_train=0.8839, loss_test=0.1254, acc_test=0.9918
# poison_percent 10 round 58: loss_train=0.5922, acc_train=0.8929, loss_test=0.1220, acc_test=0.9929
# poison_percent 10 round 59: loss_train=0.7023, acc_train=0.8750, loss_test=0.1187, acc_test=0.9939
# poison_percent 10 round 60: loss_train=0.5465, acc_train=0.8839, loss_test=0.1155, acc_test=0.9939
# poison_percent 10 round 61: loss_train=0.7847, acc_train=0.8839, loss_test=0.1124, acc_test=0.9939
# poison_percent 10 round 62: loss_train=0.5992, acc_train=0.8839, loss_test=0.1096, acc_test=0.9939
# poison_percent 10 round 63: loss_train=0.7296, acc_train=0.8750, loss_test=0.1067, acc_test=0.9939
# poison_percent 10 round 64: loss_train=0.6326, acc_train=0.8750, loss_test=0.1040, acc_test=0.9939
# poison_percent 10 round 65: loss_train=0.5871, acc_train=0.8929, loss_test=0.1012, acc_test=0.9939
# poison_percent 10 round 66: loss_train=0.3949, acc_train=0.8929, loss_test=0.0985, acc_test=0.9939
# poison_percent 10 round 67: loss_train=0.7889, acc_train=0.8839, loss_test=0.0960, acc_test=0.9939
# poison_percent 10 round 68: loss_train=0.6552, acc_train=0.8839, loss_test=0.0936, acc_test=0.9944
# poison_percent 10 round 69: loss_train=0.5148, acc_train=0.8929, loss_test=0.0912, acc_test=0.9944
# poison_percent 10 round 70: loss_train=0.4911, acc_train=0.8661, loss_test=0.0889, acc_test=0.9949
# poison_percent 10 round 71: loss_train=0.7073, acc_train=0.8750, loss_test=0.0867, acc_test=0.9954
# poison_percent 10 round 72: loss_train=0.6987, acc_train=0.8839, loss_test=0.0845, acc_test=0.9954
# poison_percent 10 round 73: loss_train=0.7851, acc_train=0.8661, loss_test=0.0823, acc_test=0.9954
# poison_percent 10 round 74: loss_train=0.7202, acc_train=0.8839, loss_test=0.0803, acc_test=0.9949
# poison_percent 10 round 75: loss_train=0.9728, acc_train=0.8839, loss_test=0.0784, acc_test=0.9949
# poison_percent 10 round 76: loss_train=0.8313, acc_train=0.8839, loss_test=0.0764, acc_test=0.9949
# poison_percent 10 round 77: loss_train=0.5842, acc_train=0.8929, loss_test=0.0745, acc_test=0.9949
# poison_percent 10 round 78: loss_train=0.8558, acc_train=0.8929, loss_test=0.0726, acc_test=0.9949
# poison_percent 10 round 79: loss_train=0.5425, acc_train=0.8929, loss_test=0.0710, acc_test=0.9949
# poison_percent 10 round 80: loss_train=0.3415, acc_train=0.8839, loss_test=0.0692, acc_test=0.9944
# poison_percent 10 round 81: loss_train=0.6376, acc_train=0.8839, loss_test=0.0675, acc_test=0.9949
# poison_percent 10 round 82: loss_train=0.4546, acc_train=0.8839, loss_test=0.0660, acc_test=0.9949
# poison_percent 10 round 83: loss_train=0.9289, acc_train=0.8750, loss_test=0.0645, acc_test=0.9949
# poison_percent 10 round 84: loss_train=0.5036, acc_train=0.9018, loss_test=0.0630, acc_test=0.9949
# poison_percent 10 round 85: loss_train=0.7423, acc_train=0.8839, loss_test=0.0615, acc_test=0.9949
# poison_percent 10 round 86: loss_train=0.6286, acc_train=0.8929, loss_test=0.0601, acc_test=0.9949
# poison_percent 10 round 87: loss_train=0.5621, acc_train=0.8929, loss_test=0.0588, acc_test=0.9949
# poison_percent 10 round 88: loss_train=0.9127, acc_train=0.9018, loss_test=0.0574, acc_test=0.9949
# poison_percent 10 round 89: loss_train=0.6905, acc_train=0.8929, loss_test=0.0561, acc_test=0.9949
# poison_percent 10 round 90: loss_train=0.5814, acc_train=0.8929, loss_test=0.0549, acc_test=0.9949
# poison_percent 10 round 91: loss_train=0.8571, acc_train=0.8929, loss_test=0.0537, acc_test=0.9949
# poison_percent 10 round 92: loss_train=0.4502, acc_train=0.8839, loss_test=0.0526, acc_test=0.9949
# poison_percent 10 round 93: loss_train=0.7036, acc_train=0.8929, loss_test=0.0514, acc_test=0.9954
# poison_percent 10 round 94: loss_train=0.6178, acc_train=0.8839, loss_test=0.0503, acc_test=0.9954
# poison_percent 10 round 95: loss_train=0.6455, acc_train=0.8750, loss_test=0.0492, acc_test=0.9954
# poison_percent 10 round 96: loss_train=0.8035, acc_train=0.8929, loss_test=0.0482, acc_test=0.9959
# poison_percent 10 round 97: loss_train=0.5522, acc_train=0.8839, loss_test=0.0471, acc_test=0.9959
# poison_percent 10 round 98: loss_train=0.8700, acc_train=0.8839, loss_test=0.0461, acc_test=0.9959
# poison_percent 10 round 99: loss_train=0.4524, acc_train=0.8839, loss_test=0.0451, acc_test=0.9959
# Training log saved to ./results\FL_ModelN1L3_Batchsize1_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=0.6755, acc_train=0.5360, loss_test=0.6882, acc_test=0.5000
# poison_percent 20 round 1: loss_train=0.6638, acc_train=0.5360, loss_test=0.6678, acc_test=0.5000
# poison_percent 20 round 2: loss_train=0.6594, acc_train=0.5440, loss_test=0.6633, acc_test=0.5000
# poison_percent 20 round 3: loss_train=0.6692, acc_train=0.4880, loss_test=0.6581, acc_test=0.5000
# poison_percent 20 round 4: loss_train=0.6610, acc_train=0.5040, loss_test=0.6527, acc_test=0.5000
# poison_percent 20 round 5: loss_train=0.6697, acc_train=0.4720, loss_test=0.6473, acc_test=0.5000
# poison_percent 20 round 6: loss_train=0.6419, acc_train=0.5440, loss_test=0.6420, acc_test=0.5000
# poison_percent 20 round 7: loss_train=0.6464, acc_train=0.5120, loss_test=0.6366, acc_test=0.5000
# poison_percent 20 round 8: loss_train=0.6445, acc_train=0.5120, loss_test=0.6310, acc_test=0.5000
# poison_percent 20 round 9: loss_train=0.6617, acc_train=0.4480, loss_test=0.6251, acc_test=0.5000
# poison_percent 20 round 10: loss_train=0.6618, acc_train=0.4480, loss_test=0.6191, acc_test=0.5000
# poison_percent 20 round 11: loss_train=0.6367, acc_train=0.4960, loss_test=0.6131, acc_test=0.5000
# poison_percent 20 round 12: loss_train=0.6316, acc_train=0.4960, loss_test=0.6070, acc_test=0.5000
# poison_percent 20 round 13: loss_train=0.6122, acc_train=0.5440, loss_test=0.6009, acc_test=0.5000
# poison_percent 20 round 14: loss_train=0.6205, acc_train=0.4960, loss_test=0.5940, acc_test=0.5000
# poison_percent 20 round 15: loss_train=0.6324, acc_train=0.4560, loss_test=0.5873, acc_test=0.5000
# poison_percent 20 round 16: loss_train=0.6335, acc_train=0.4400, loss_test=0.5805, acc_test=0.5000
# poison_percent 20 round 17: loss_train=0.6365, acc_train=0.4320, loss_test=0.5736, acc_test=0.5000
# poison_percent 20 round 18: loss_train=0.6055, acc_train=0.5120, loss_test=0.5666, acc_test=0.5000
# poison_percent 20 round 19: loss_train=0.6129, acc_train=0.4880, loss_test=0.5596, acc_test=0.5000
# poison_percent 20 round 20: loss_train=0.6130, acc_train=0.4560, loss_test=0.5524, acc_test=0.5000
# poison_percent 20 round 21: loss_train=0.5847, acc_train=0.5360, loss_test=0.5453, acc_test=0.5000
# poison_percent 20 round 22: loss_train=0.5633, acc_train=0.6960, loss_test=0.5384, acc_test=0.5000
# poison_percent 20 round 23: loss_train=0.5723, acc_train=0.8880, loss_test=0.5311, acc_test=0.9673
# poison_percent 20 round 24: loss_train=0.5641, acc_train=0.8640, loss_test=0.5236, acc_test=0.9730
# poison_percent 20 round 25: loss_train=0.5965, acc_train=0.8160, loss_test=0.5160, acc_test=0.9770
# poison_percent 20 round 26: loss_train=0.6080, acc_train=0.8400, loss_test=0.5087, acc_test=0.9770
# poison_percent 20 round 27: loss_train=0.5801, acc_train=0.8560, loss_test=0.5012, acc_test=0.9781
# poison_percent 20 round 28: loss_train=0.5634, acc_train=0.8320, loss_test=0.4934, acc_test=0.9837
# poison_percent 20 round 29: loss_train=0.5512, acc_train=0.8480, loss_test=0.4857, acc_test=0.9878
# poison_percent 20 round 30: loss_train=0.5938, acc_train=0.8320, loss_test=0.4780, acc_test=0.9878
# poison_percent 20 round 31: loss_train=0.5490, acc_train=0.8400, loss_test=0.4703, acc_test=0.9888
# poison_percent 20 round 32: loss_train=0.5403, acc_train=0.8240, loss_test=0.4625, acc_test=0.9908
# poison_percent 20 round 33: loss_train=0.5610, acc_train=0.8160, loss_test=0.4546, acc_test=0.9913
# poison_percent 20 round 34: loss_train=0.5548, acc_train=0.8000, loss_test=0.4467, acc_test=0.9929
# poison_percent 20 round 35: loss_train=0.5622, acc_train=0.8080, loss_test=0.4389, acc_test=0.9939
# poison_percent 20 round 36: loss_train=0.5614, acc_train=0.7920, loss_test=0.4311, acc_test=0.9949
# poison_percent 20 round 37: loss_train=0.5788, acc_train=0.7840, loss_test=0.4233, acc_test=0.9949
# poison_percent 20 round 38: loss_train=0.5561, acc_train=0.8000, loss_test=0.4156, acc_test=0.9949
# poison_percent 20 round 39: loss_train=0.5449, acc_train=0.8160, loss_test=0.4078, acc_test=0.9949
# poison_percent 20 round 40: loss_train=0.5282, acc_train=0.8000, loss_test=0.4000, acc_test=0.9949
# poison_percent 20 round 41: loss_train=0.5440, acc_train=0.8000, loss_test=0.3922, acc_test=0.9954
# poison_percent 20 round 42: loss_train=0.5054, acc_train=0.8080, loss_test=0.3846, acc_test=0.9954
# poison_percent 20 round 43: loss_train=0.5088, acc_train=0.7920, loss_test=0.3769, acc_test=0.9954
# poison_percent 20 round 44: loss_train=0.5147, acc_train=0.7920, loss_test=0.3694, acc_test=0.9959
# poison_percent 20 round 45: loss_train=0.5177, acc_train=0.8000, loss_test=0.3620, acc_test=0.9954
# poison_percent 20 round 46: loss_train=0.5282, acc_train=0.8000, loss_test=0.3546, acc_test=0.9954
# poison_percent 20 round 47: loss_train=0.5325, acc_train=0.8000, loss_test=0.3473, acc_test=0.9959
# poison_percent 20 round 48: loss_train=0.5125, acc_train=0.8080, loss_test=0.3401, acc_test=0.9959
# poison_percent 20 round 49: loss_train=0.5358, acc_train=0.8080, loss_test=0.3329, acc_test=0.9959
# poison_percent 20 round 50: loss_train=0.5138, acc_train=0.8080, loss_test=0.3257, acc_test=0.9959
# poison_percent 20 round 51: loss_train=0.5167, acc_train=0.8000, loss_test=0.3187, acc_test=0.9959
# poison_percent 20 round 52: loss_train=0.5175, acc_train=0.8080, loss_test=0.3117, acc_test=0.9959
# poison_percent 20 round 53: loss_train=0.5457, acc_train=0.8000, loss_test=0.3049, acc_test=0.9959
# poison_percent 20 round 54: loss_train=0.5204, acc_train=0.8080, loss_test=0.2981, acc_test=0.9959
# poison_percent 20 round 55: loss_train=0.5597, acc_train=0.7920, loss_test=0.2914, acc_test=0.9959
# poison_percent 20 round 56: loss_train=0.5093, acc_train=0.8000, loss_test=0.2848, acc_test=0.9959
# poison_percent 20 round 57: loss_train=0.5108, acc_train=0.7920, loss_test=0.2783, acc_test=0.9959
# poison_percent 20 round 58: loss_train=0.5452, acc_train=0.8000, loss_test=0.2719, acc_test=0.9959
# poison_percent 20 round 59: loss_train=0.5309, acc_train=0.7920, loss_test=0.2655, acc_test=0.9959
# poison_percent 20 round 60: loss_train=0.5637, acc_train=0.8000, loss_test=0.2593, acc_test=0.9959
# poison_percent 20 round 61: loss_train=0.4975, acc_train=0.8000, loss_test=0.2532, acc_test=0.9959
# poison_percent 20 round 62: loss_train=0.5587, acc_train=0.8000, loss_test=0.2472, acc_test=0.9959
# poison_percent 20 round 63: loss_train=0.5463, acc_train=0.7920, loss_test=0.2413, acc_test=0.9959
# poison_percent 20 round 64: loss_train=0.5371, acc_train=0.8000, loss_test=0.2355, acc_test=0.9959
# poison_percent 20 round 65: loss_train=0.5757, acc_train=0.8000, loss_test=0.2298, acc_test=0.9959
# poison_percent 20 round 66: loss_train=0.5213, acc_train=0.7920, loss_test=0.2242, acc_test=0.9959
# poison_percent 20 round 67: loss_train=0.5333, acc_train=0.7920, loss_test=0.2186, acc_test=0.9959
# poison_percent 20 round 68: loss_train=0.5251, acc_train=0.7920, loss_test=0.2132, acc_test=0.9964
# poison_percent 20 round 69: loss_train=0.4992, acc_train=0.7920, loss_test=0.2079, acc_test=0.9964
# poison_percent 20 round 70: loss_train=0.4926, acc_train=0.8000, loss_test=0.2028, acc_test=0.9959
# poison_percent 20 round 71: loss_train=0.5215, acc_train=0.7920, loss_test=0.1977, acc_test=0.9964
# poison_percent 20 round 72: loss_train=0.5936, acc_train=0.8000, loss_test=0.1926, acc_test=0.9974
# poison_percent 20 round 73: loss_train=0.5682, acc_train=0.8000, loss_test=0.1878, acc_test=0.9974
# poison_percent 20 round 74: loss_train=0.5367, acc_train=0.7920, loss_test=0.1830, acc_test=0.9974
# poison_percent 20 round 75: loss_train=0.5922, acc_train=0.8000, loss_test=0.1784, acc_test=0.9974
# poison_percent 20 round 76: loss_train=0.5883, acc_train=0.8000, loss_test=0.1739, acc_test=0.9974
# poison_percent 20 round 77: loss_train=0.5231, acc_train=0.8000, loss_test=0.1695, acc_test=0.9974
# poison_percent 20 round 78: loss_train=0.6369, acc_train=0.8000, loss_test=0.1651, acc_test=0.9974
# poison_percent 20 round 79: loss_train=0.5599, acc_train=0.8000, loss_test=0.1609, acc_test=0.9974
# poison_percent 20 round 80: loss_train=0.5935, acc_train=0.8000, loss_test=0.1567, acc_test=0.9974
# poison_percent 20 round 81: loss_train=0.6039, acc_train=0.7920, loss_test=0.1526, acc_test=0.9974
# poison_percent 20 round 82: loss_train=0.6639, acc_train=0.8000, loss_test=0.1486, acc_test=0.9974
# poison_percent 20 round 83: loss_train=0.5593, acc_train=0.8000, loss_test=0.1448, acc_test=0.9974
# poison_percent 20 round 84: loss_train=0.5601, acc_train=0.7920, loss_test=0.1410, acc_test=0.9974
# poison_percent 20 round 85: loss_train=0.6122, acc_train=0.8000, loss_test=0.1373, acc_test=0.9974
# poison_percent 20 round 86: loss_train=0.6484, acc_train=0.7920, loss_test=0.1338, acc_test=0.9974
# poison_percent 20 round 87: loss_train=0.6315, acc_train=0.8000, loss_test=0.1302, acc_test=0.9974
# poison_percent 20 round 88: loss_train=0.5409, acc_train=0.8000, loss_test=0.1268, acc_test=0.9974
# poison_percent 20 round 89: loss_train=0.6669, acc_train=0.8000, loss_test=0.1235, acc_test=0.9974
# poison_percent 20 round 90: loss_train=0.6253, acc_train=0.8080, loss_test=0.1202, acc_test=0.9974
# poison_percent 20 round 91: loss_train=0.6173, acc_train=0.8000, loss_test=0.1169, acc_test=0.9980
# poison_percent 20 round 92: loss_train=0.6231, acc_train=0.8000, loss_test=0.1138, acc_test=0.9980
# poison_percent 20 round 93: loss_train=0.6360, acc_train=0.8000, loss_test=0.1108, acc_test=0.9980
# poison_percent 20 round 94: loss_train=0.6212, acc_train=0.8080, loss_test=0.1078, acc_test=0.9980
# poison_percent 20 round 95: loss_train=0.6639, acc_train=0.8000, loss_test=0.1050, acc_test=0.9974
# poison_percent 20 round 96: loss_train=0.6863, acc_train=0.7840, loss_test=0.1021, acc_test=0.9980
# poison_percent 20 round 97: loss_train=0.6529, acc_train=0.8000, loss_test=0.0994, acc_test=0.9980
# poison_percent 20 round 98: loss_train=0.5842, acc_train=0.8000, loss_test=0.0966, acc_test=0.9980
# poison_percent 20 round 99: loss_train=0.6812, acc_train=0.8000, loss_test=0.0942, acc_test=0.9980
# Training log saved to ./results\FL_ModelN1L3_Batchsize1_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=0.9046, acc_train=0.4545, loss_test=0.8427, acc_test=0.5000
# poison_percent 30 round 1: loss_train=0.7721, acc_train=0.5175, loss_test=0.7911, acc_test=0.5000
# poison_percent 30 round 2: loss_train=0.6891, acc_train=0.5594, loss_test=0.7503, acc_test=0.5000
# poison_percent 30 round 3: loss_train=0.6483, acc_train=0.5804, loss_test=0.7140, acc_test=0.5000
# poison_percent 30 round 4: loss_train=0.7044, acc_train=0.5035, loss_test=0.6807, acc_test=0.5000
# poison_percent 30 round 5: loss_train=0.6808, acc_train=0.5315, loss_test=0.6503, acc_test=0.5000
# poison_percent 30 round 6: loss_train=0.6141, acc_train=0.5594, loss_test=0.6215, acc_test=0.5000
# poison_percent 30 round 7: loss_train=0.7252, acc_train=0.4755, loss_test=0.5951, acc_test=0.5000
# poison_percent 30 round 8: loss_train=0.6954, acc_train=0.4965, loss_test=0.5705, acc_test=0.5000
# poison_percent 30 round 9: loss_train=0.6799, acc_train=0.4965, loss_test=0.5480, acc_test=0.5000
# poison_percent 30 round 10: loss_train=0.6876, acc_train=0.4825, loss_test=0.5268, acc_test=0.5000
# poison_percent 30 round 11: loss_train=0.6951, acc_train=0.4825, loss_test=0.5070, acc_test=0.5000
# poison_percent 30 round 12: loss_train=0.7969, acc_train=0.3706, loss_test=0.4886, acc_test=0.5000
# poison_percent 30 round 13: loss_train=0.7446, acc_train=0.4615, loss_test=0.4715, acc_test=0.5000
# poison_percent 30 round 14: loss_train=0.6453, acc_train=0.5524, loss_test=0.4551, acc_test=0.5000
# poison_percent 30 round 15: loss_train=0.6473, acc_train=0.5455, loss_test=0.4399, acc_test=0.5000
# poison_percent 30 round 16: loss_train=0.7232, acc_train=0.4755, loss_test=0.4256, acc_test=0.5000
# poison_percent 30 round 17: loss_train=0.6911, acc_train=0.4895, loss_test=0.4121, acc_test=0.5000
# poison_percent 30 round 18: loss_train=0.7701, acc_train=0.4545, loss_test=0.3993, acc_test=0.5000
# poison_percent 30 round 19: loss_train=0.6278, acc_train=0.5455, loss_test=0.3869, acc_test=0.5000
# poison_percent 30 round 20: loss_train=0.6422, acc_train=0.5524, loss_test=0.3751, acc_test=0.5000
# poison_percent 30 round 21: loss_train=0.7304, acc_train=0.6643, loss_test=0.3638, acc_test=0.9862
# poison_percent 30 round 22: loss_train=0.7550, acc_train=0.6503, loss_test=0.3530, acc_test=0.9872
# poison_percent 30 round 23: loss_train=0.6694, acc_train=0.6993, loss_test=0.3425, acc_test=0.9883
# poison_percent 30 round 24: loss_train=0.6852, acc_train=0.6783, loss_test=0.3321, acc_test=0.9893
# poison_percent 30 round 25: loss_train=0.6743, acc_train=0.6993, loss_test=0.3223, acc_test=0.9908
# poison_percent 30 round 26: loss_train=0.6507, acc_train=0.6853, loss_test=0.3125, acc_test=0.9929
# poison_percent 30 round 27: loss_train=0.7499, acc_train=0.6853, loss_test=0.3030, acc_test=0.9934
# poison_percent 30 round 28: loss_train=0.7683, acc_train=0.6923, loss_test=0.2939, acc_test=0.9934
# poison_percent 30 round 29: loss_train=0.8130, acc_train=0.6923, loss_test=0.2848, acc_test=0.9939
# poison_percent 30 round 30: loss_train=0.7564, acc_train=0.6853, loss_test=0.2761, acc_test=0.9939
# poison_percent 30 round 31: loss_train=0.8279, acc_train=0.6923, loss_test=0.2692, acc_test=0.9949
# poison_percent 30 round 32: loss_train=0.7044, acc_train=0.6853, loss_test=0.2627, acc_test=0.9959
# poison_percent 30 round 33: loss_train=0.7646, acc_train=0.6853, loss_test=0.2565, acc_test=0.9969
# poison_percent 30 round 34: loss_train=0.6979, acc_train=0.6993, loss_test=0.2506, acc_test=0.9964
# poison_percent 30 round 35: loss_train=0.8445, acc_train=0.6923, loss_test=0.2447, acc_test=0.9969
# poison_percent 30 round 36: loss_train=0.7633, acc_train=0.6923, loss_test=0.2390, acc_test=0.9969
# poison_percent 30 round 37: loss_train=0.8255, acc_train=0.6993, loss_test=0.2335, acc_test=0.9969
# poison_percent 30 round 38: loss_train=0.7853, acc_train=0.6923, loss_test=0.2281, acc_test=0.9969
# poison_percent 30 round 39: loss_train=0.7687, acc_train=0.6853, loss_test=0.2229, acc_test=0.9969
# poison_percent 30 round 40: loss_train=0.7969, acc_train=0.6853, loss_test=0.2178, acc_test=0.9969
# poison_percent 30 round 41: loss_train=0.9263, acc_train=0.6853, loss_test=0.2128, acc_test=0.9969
# poison_percent 30 round 42: loss_train=0.7147, acc_train=0.7063, loss_test=0.2081, acc_test=0.9969
# poison_percent 30 round 43: loss_train=0.8516, acc_train=0.6993, loss_test=0.2033, acc_test=0.9974
# poison_percent 30 round 44: loss_train=0.7758, acc_train=0.6993, loss_test=0.1988, acc_test=0.9974
# poison_percent 30 round 45: loss_train=0.8182, acc_train=0.6923, loss_test=0.1943, acc_test=0.9974
# poison_percent 30 round 46: loss_train=0.9852, acc_train=0.6993, loss_test=0.1900, acc_test=0.9974
# poison_percent 30 round 47: loss_train=0.9060, acc_train=0.6993, loss_test=0.1858, acc_test=0.9974
# poison_percent 30 round 48: loss_train=0.8394, acc_train=0.6993, loss_test=0.1816, acc_test=0.9974
# poison_percent 30 round 49: loss_train=0.9108, acc_train=0.6923, loss_test=0.1776, acc_test=0.9974
# poison_percent 30 round 50: loss_train=0.9938, acc_train=0.6993, loss_test=0.1737, acc_test=0.9974
# poison_percent 30 round 51: loss_train=0.9511, acc_train=0.6993, loss_test=0.1697, acc_test=0.9974
# poison_percent 30 round 52: loss_train=0.9665, acc_train=0.6993, loss_test=0.1660, acc_test=0.9969
# poison_percent 30 round 53: loss_train=0.8470, acc_train=0.7063, loss_test=0.1624, acc_test=0.9969
# poison_percent 30 round 54: loss_train=0.9022, acc_train=0.6993, loss_test=0.1589, acc_test=0.9969
# poison_percent 30 round 55: loss_train=0.8462, acc_train=0.6923, loss_test=0.1555, acc_test=0.9969
# poison_percent 30 round 56: loss_train=0.7968, acc_train=0.6993, loss_test=0.1521, acc_test=0.9969
# poison_percent 30 round 57: loss_train=1.0710, acc_train=0.6923, loss_test=0.1488, acc_test=0.9969
# poison_percent 30 round 58: loss_train=0.9614, acc_train=0.6993, loss_test=0.1457, acc_test=0.9969
# poison_percent 30 round 59: loss_train=1.0091, acc_train=0.6993, loss_test=0.1425, acc_test=0.9969
# poison_percent 30 round 60: loss_train=1.0415, acc_train=0.6993, loss_test=0.1395, acc_test=0.9969
# poison_percent 30 round 61: loss_train=0.9312, acc_train=0.6993, loss_test=0.1365, acc_test=0.9969
# poison_percent 30 round 62: loss_train=0.9161, acc_train=0.6923, loss_test=0.1337, acc_test=0.9969
# poison_percent 30 round 63: loss_train=0.8863, acc_train=0.7063, loss_test=0.1309, acc_test=0.9969
# poison_percent 30 round 64: loss_train=0.9257, acc_train=0.6993, loss_test=0.1282, acc_test=0.9969
# poison_percent 30 round 65: loss_train=1.0401, acc_train=0.6853, loss_test=0.1256, acc_test=0.9969
# poison_percent 30 round 66: loss_train=0.8174, acc_train=0.6993, loss_test=0.1230, acc_test=0.9969
# poison_percent 30 round 67: loss_train=1.0751, acc_train=0.6993, loss_test=0.1205, acc_test=0.9969
# poison_percent 30 round 68: loss_train=0.9124, acc_train=0.6853, loss_test=0.1181, acc_test=0.9969
# poison_percent 30 round 69: loss_train=0.9076, acc_train=0.6993, loss_test=0.1157, acc_test=0.9969
# poison_percent 30 round 70: loss_train=1.0327, acc_train=0.6923, loss_test=0.1134, acc_test=0.9969
# poison_percent 30 round 71: loss_train=0.8163, acc_train=0.7063, loss_test=0.1112, acc_test=0.9964
# poison_percent 30 round 72: loss_train=0.9175, acc_train=0.6853, loss_test=0.1089, acc_test=0.9964
# poison_percent 30 round 73: loss_train=0.9537, acc_train=0.6783, loss_test=0.1067, acc_test=0.9964
# poison_percent 30 round 74: loss_train=1.0227, acc_train=0.6923, loss_test=0.1047, acc_test=0.9964
# poison_percent 30 round 75: loss_train=1.2027, acc_train=0.6993, loss_test=0.1027, acc_test=0.9964
# poison_percent 30 round 76: loss_train=1.0134, acc_train=0.6923, loss_test=0.1006, acc_test=0.9964
# poison_percent 30 round 77: loss_train=1.1397, acc_train=0.6993, loss_test=0.0987, acc_test=0.9969
# poison_percent 30 round 78: loss_train=1.0186, acc_train=0.6993, loss_test=0.0970, acc_test=0.9969
# poison_percent 30 round 79: loss_train=1.0151, acc_train=0.6993, loss_test=0.0951, acc_test=0.9969
# poison_percent 30 round 80: loss_train=1.0355, acc_train=0.6993, loss_test=0.0935, acc_test=0.9969
# poison_percent 30 round 81: loss_train=1.1517, acc_train=0.6993, loss_test=0.0918, acc_test=0.9969
# poison_percent 30 round 82: loss_train=1.0123, acc_train=0.7063, loss_test=0.0901, acc_test=0.9969
# poison_percent 30 round 83: loss_train=1.0941, acc_train=0.6993, loss_test=0.0886, acc_test=0.9969
# poison_percent 30 round 84: loss_train=1.0381, acc_train=0.6993, loss_test=0.0872, acc_test=0.9969
# poison_percent 30 round 85: loss_train=1.0429, acc_train=0.7063, loss_test=0.0857, acc_test=0.9969
# poison_percent 30 round 86: loss_train=1.0379, acc_train=0.6993, loss_test=0.0842, acc_test=0.9969
# poison_percent 30 round 87: loss_train=1.0152, acc_train=0.6853, loss_test=0.0828, acc_test=0.9969
# poison_percent 30 round 88: loss_train=1.0103, acc_train=0.6923, loss_test=0.0814, acc_test=0.9969
# poison_percent 30 round 89: loss_train=1.1428, acc_train=0.6993, loss_test=0.0800, acc_test=0.9969
# poison_percent 30 round 90: loss_train=1.0958, acc_train=0.7063, loss_test=0.0787, acc_test=0.9969
# poison_percent 30 round 91: loss_train=0.9858, acc_train=0.6923, loss_test=0.0774, acc_test=0.9969
# poison_percent 30 round 92: loss_train=1.0962, acc_train=0.6853, loss_test=0.0761, acc_test=0.9969
# poison_percent 30 round 93: loss_train=1.1082, acc_train=0.6993, loss_test=0.0749, acc_test=0.9969
# poison_percent 30 round 94: loss_train=1.3343, acc_train=0.6993, loss_test=0.0738, acc_test=0.9969
# poison_percent 30 round 95: loss_train=1.0957, acc_train=0.6993, loss_test=0.0726, acc_test=0.9969
# poison_percent 30 round 96: loss_train=1.0401, acc_train=0.6993, loss_test=0.0715, acc_test=0.9969
# poison_percent 30 round 97: loss_train=0.9680, acc_train=0.6923, loss_test=0.0702, acc_test=0.9969
# poison_percent 30 round 98: loss_train=1.1703, acc_train=0.6923, loss_test=0.0692, acc_test=0.9974
# poison_percent 30 round 99: loss_train=1.2489, acc_train=0.7063, loss_test=0.0682, acc_test=0.9974
# Training log saved to ./results\FL_ModelN1L3_Batchsize1_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=0.7509, acc_train=0.5090, loss_test=0.8238, acc_test=0.5000
# poison_percent 40 round 1: loss_train=0.7167, acc_train=0.5329, loss_test=0.7868, acc_test=0.5000
# poison_percent 40 round 2: loss_train=0.7580, acc_train=0.4850, loss_test=0.7648, acc_test=0.5000
# poison_percent 40 round 3: loss_train=0.7797, acc_train=0.4551, loss_test=0.7503, acc_test=0.5000
# poison_percent 40 round 4: loss_train=0.7378, acc_train=0.5030, loss_test=0.7400, acc_test=0.5000
# poison_percent 40 round 5: loss_train=0.7494, acc_train=0.4790, loss_test=0.7325, acc_test=0.5000
# poison_percent 40 round 6: loss_train=0.7247, acc_train=0.5030, loss_test=0.7246, acc_test=0.5000
# poison_percent 40 round 7: loss_train=0.7176, acc_train=0.5030, loss_test=0.7168, acc_test=0.5000
# poison_percent 40 round 8: loss_train=0.7390, acc_train=0.4731, loss_test=0.7097, acc_test=0.5000
# poison_percent 40 round 9: loss_train=0.7616, acc_train=0.4371, loss_test=0.7031, acc_test=0.5000
# poison_percent 40 round 10: loss_train=0.6880, acc_train=0.5210, loss_test=0.6969, acc_test=0.5000
# poison_percent 40 round 11: loss_train=0.6996, acc_train=0.4970, loss_test=0.6903, acc_test=0.5000
# poison_percent 40 round 12: loss_train=0.6622, acc_train=0.5389, loss_test=0.6848, acc_test=0.5000
# poison_percent 40 round 13: loss_train=0.6821, acc_train=0.5090, loss_test=0.6792, acc_test=0.5000
# poison_percent 40 round 14: loss_train=0.7296, acc_train=0.4371, loss_test=0.6731, acc_test=0.5000
# poison_percent 40 round 15: loss_train=0.6790, acc_train=0.5030, loss_test=0.6678, acc_test=0.5000
# poison_percent 40 round 16: loss_train=0.6859, acc_train=0.4910, loss_test=0.6614, acc_test=0.5000
# poison_percent 40 round 17: loss_train=0.6888, acc_train=0.4731, loss_test=0.6560, acc_test=0.5000
# poison_percent 40 round 18: loss_train=0.6807, acc_train=0.4731, loss_test=0.6505, acc_test=0.5000
# poison_percent 40 round 19: loss_train=0.6608, acc_train=0.4910, loss_test=0.6456, acc_test=0.5000
# poison_percent 40 round 20: loss_train=0.6523, acc_train=0.4970, loss_test=0.6394, acc_test=0.5000
# poison_percent 40 round 21: loss_train=0.6490, acc_train=0.4970, loss_test=0.6339, acc_test=0.5000
# poison_percent 40 round 22: loss_train=0.6291, acc_train=0.5269, loss_test=0.6280, acc_test=0.5000
# poison_percent 40 round 23: loss_train=0.6581, acc_train=0.4790, loss_test=0.6237, acc_test=0.5000
# poison_percent 40 round 24: loss_train=0.6724, acc_train=0.4311, loss_test=0.6180, acc_test=0.5000
# poison_percent 40 round 25: loss_train=0.5920, acc_train=0.5749, loss_test=0.6128, acc_test=0.5000
# poison_percent 40 round 26: loss_train=0.6243, acc_train=0.5090, loss_test=0.6078, acc_test=0.5000
# poison_percent 40 round 27: loss_train=0.5809, acc_train=0.5749, loss_test=0.6028, acc_test=0.5000
# poison_percent 40 round 28: loss_train=0.6328, acc_train=0.4731, loss_test=0.5972, acc_test=0.5000
# poison_percent 40 round 29: loss_train=0.6086, acc_train=0.5090, loss_test=0.5918, acc_test=0.5000
# poison_percent 40 round 30: loss_train=0.5954, acc_train=0.5329, loss_test=0.5874, acc_test=0.5000
# poison_percent 40 round 31: loss_train=0.5951, acc_train=0.5150, loss_test=0.5823, acc_test=0.5000
# poison_percent 40 round 32: loss_train=0.6123, acc_train=0.4850, loss_test=0.5766, acc_test=0.5000
# poison_percent 40 round 33: loss_train=0.5478, acc_train=0.5988, loss_test=0.5728, acc_test=0.5000
# poison_percent 40 round 34: loss_train=0.6099, acc_train=0.4790, loss_test=0.5672, acc_test=0.5000
# poison_percent 40 round 35: loss_train=0.5986, acc_train=0.4850, loss_test=0.5616, acc_test=0.5000
# poison_percent 40 round 36: loss_train=0.6121, acc_train=0.4311, loss_test=0.5566, acc_test=0.5000
# poison_percent 40 round 37: loss_train=0.5764, acc_train=0.5329, loss_test=0.5524, acc_test=0.5000
# poison_percent 40 round 38: loss_train=0.5575, acc_train=0.5509, loss_test=0.5469, acc_test=0.5000
# poison_percent 40 round 39: loss_train=0.5927, acc_train=0.4551, loss_test=0.5417, acc_test=0.5000
# poison_percent 40 round 40: loss_train=0.5187, acc_train=0.6467, loss_test=0.5373, acc_test=0.5000
# poison_percent 40 round 41: loss_train=0.5580, acc_train=0.5150, loss_test=0.5313, acc_test=0.5000
# poison_percent 40 round 42: loss_train=0.5858, acc_train=0.4431, loss_test=0.5242, acc_test=0.5000
# poison_percent 40 round 43: loss_train=0.5666, acc_train=0.5210, loss_test=0.5222, acc_test=0.5000
# poison_percent 40 round 44: loss_train=0.5559, acc_train=0.4970, loss_test=0.5173, acc_test=0.5000
# poison_percent 40 round 45: loss_train=0.5618, acc_train=0.4910, loss_test=0.5112, acc_test=0.5000
# poison_percent 40 round 46: loss_train=0.5711, acc_train=0.4311, loss_test=0.5085, acc_test=0.5000
# poison_percent 40 round 47: loss_train=0.5427, acc_train=0.5569, loss_test=0.5037, acc_test=0.5000
# poison_percent 40 round 48: loss_train=0.5485, acc_train=0.5150, loss_test=0.4984, acc_test=0.5000
# poison_percent 40 round 49: loss_train=0.5434, acc_train=0.8144, loss_test=0.4933, acc_test=0.9944
# poison_percent 40 round 50: loss_train=0.5385, acc_train=0.7365, loss_test=0.4892, acc_test=0.9949
# poison_percent 40 round 51: loss_train=0.5259, acc_train=0.7964, loss_test=0.4852, acc_test=0.9949
# poison_percent 40 round 52: loss_train=0.5420, acc_train=0.7844, loss_test=0.4788, acc_test=0.9949
# poison_percent 40 round 53: loss_train=0.5119, acc_train=0.7784, loss_test=0.4745, acc_test=0.9954
# poison_percent 40 round 54: loss_train=0.5250, acc_train=0.7186, loss_test=0.4697, acc_test=0.9954
# poison_percent 40 round 55: loss_train=0.5070, acc_train=0.8144, loss_test=0.4629, acc_test=0.9954
# poison_percent 40 round 56: loss_train=0.5307, acc_train=0.7904, loss_test=0.4595, acc_test=0.9954
# poison_percent 40 round 57: loss_train=0.5305, acc_train=0.8383, loss_test=0.4561, acc_test=0.9944
# poison_percent 40 round 58: loss_train=0.5163, acc_train=0.7665, loss_test=0.4495, acc_test=0.9944
# poison_percent 40 round 59: loss_train=0.5256, acc_train=0.7784, loss_test=0.4459, acc_test=0.9944
# poison_percent 40 round 60: loss_train=0.5360, acc_train=0.7844, loss_test=0.4396, acc_test=0.9944
# poison_percent 40 round 61: loss_train=0.4820, acc_train=0.7904, loss_test=0.4371, acc_test=0.9949
# poison_percent 40 round 62: loss_train=0.4839, acc_train=0.7904, loss_test=0.4305, acc_test=0.9949
# poison_percent 40 round 63: loss_train=0.5074, acc_train=0.8084, loss_test=0.4261, acc_test=0.9949
# poison_percent 40 round 64: loss_train=0.5190, acc_train=0.8024, loss_test=0.4263, acc_test=0.9949
# poison_percent 40 round 65: loss_train=0.4668, acc_train=0.8084, loss_test=0.4227, acc_test=0.9954
# poison_percent 40 round 66: loss_train=0.4981, acc_train=0.8084, loss_test=0.4132, acc_test=0.9954
# poison_percent 40 round 67: loss_train=0.4972, acc_train=0.7545, loss_test=0.4094, acc_test=0.9954
# poison_percent 40 round 68: loss_train=0.5047, acc_train=0.7485, loss_test=0.4102, acc_test=0.9954
# poison_percent 40 round 69: loss_train=0.4762, acc_train=0.7964, loss_test=0.4024, acc_test=0.9954
# poison_percent 40 round 70: loss_train=0.4792, acc_train=0.7844, loss_test=0.3996, acc_test=0.9954
# poison_percent 40 round 71: loss_train=0.4516, acc_train=0.8024, loss_test=0.3951, acc_test=0.9954
# poison_percent 40 round 72: loss_train=0.4560, acc_train=0.7964, loss_test=0.3880, acc_test=0.9954
# poison_percent 40 round 73: loss_train=0.4648, acc_train=0.8204, loss_test=0.3851, acc_test=0.9954
# poison_percent 40 round 74: loss_train=0.4862, acc_train=0.8024, loss_test=0.3836, acc_test=0.9954
# poison_percent 40 round 75: loss_train=0.5005, acc_train=0.7725, loss_test=0.3773, acc_test=0.9954
# poison_percent 40 round 76: loss_train=0.4984, acc_train=0.7305, loss_test=0.3720, acc_test=0.9954
# poison_percent 40 round 77: loss_train=0.4805, acc_train=0.7425, loss_test=0.3702, acc_test=0.9949
# poison_percent 40 round 78: loss_train=0.4577, acc_train=0.8084, loss_test=0.3692, acc_test=0.9949
# poison_percent 40 round 79: loss_train=0.4682, acc_train=0.8024, loss_test=0.3652, acc_test=0.9949
# poison_percent 40 round 80: loss_train=0.4483, acc_train=0.8204, loss_test=0.3589, acc_test=0.9949
# poison_percent 40 round 81: loss_train=0.4713, acc_train=0.7725, loss_test=0.3554, acc_test=0.9949
# ...
# poison_percent 40 round 41: loss_train=0.6937, acc_train=0.5329, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 42: loss_train=0.6949, acc_train=0.5090, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 43: loss_train=0.6947, acc_train=0.4850, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 44: loss_train=0.6943, acc_train=0.5030, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 45: loss_train=0.6934, acc_train=0.5629, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 46: loss_train=0.6965, acc_train=0.3593, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 47: loss_train=0.6957, acc_train=0.3832, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 48: loss_train=0.6943, acc_train=0.4850, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 49: loss_train=0.6939, acc_train=0.4910, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 50: loss_train=0.6940, acc_train=0.4970, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 51: loss_train=0.6941, acc_train=0.5030, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 52: loss_train=0.6932, acc_train=0.5509, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 53: loss_train=0.6946, acc_train=0.4371, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 54: loss_train=0.6939, acc_train=0.4731, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 55: loss_train=0.6943, acc_train=0.4311, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 56: loss_train=0.6952, acc_train=0.3772, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 57: loss_train=0.6943, acc_train=0.4132, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 58: loss_train=0.6944, acc_train=0.4012, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 59: loss_train=0.6939, acc_train=0.4311, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 60: loss_train=0.6937, acc_train=0.4671, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 61: loss_train=0.6942, acc_train=0.3772, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 62: loss_train=0.6944, acc_train=0.3832, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 63: loss_train=0.6944, acc_train=0.3593, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 64: loss_train=0.6943, acc_train=0.3832, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 round 65: loss_train=0.6941, acc_train=0.4491, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 66: loss_train=0.6942, acc_train=0.3892, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 67: loss_train=0.6946, acc_train=0.3533, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 68: loss_train=0.6947, acc_train=0.3892, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 69: loss_train=0.6945, acc_train=0.4012, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 70: loss_train=0.6944, acc_train=0.3952, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 71: loss_train=0.6944, acc_train=0.3473, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 72: loss_train=0.6941, acc_train=0.4431, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 73: loss_train=0.6942, acc_train=0.4431, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 74: loss_train=0.6942, acc_train=0.4311, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 75: loss_train=0.6945, acc_train=0.3713, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 76: loss_train=0.6946, acc_train=0.3413, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 77: loss_train=0.6936, acc_train=0.4611, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 78: loss_train=0.6942, acc_train=0.4072, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 79: loss_train=0.6942, acc_train=0.4012, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 80: loss_train=0.6944, acc_train=0.4012, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 81: loss_train=0.6945, acc_train=0.3892, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 82: loss_train=0.6942, acc_train=0.3653, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 83: loss_train=0.6940, acc_train=0.4072, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 84: loss_train=0.6947, acc_train=0.3293, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 85: loss_train=0.6938, acc_train=0.4371, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 86: loss_train=0.6942, acc_train=0.3653, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 87: loss_train=0.6939, acc_train=0.4132, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 88: loss_train=0.6940, acc_train=0.4431, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 89: loss_train=0.6944, acc_train=0.3653, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 90: loss_train=0.6944, acc_train=0.3593, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 91: loss_train=0.6946, acc_train=0.3353, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 92: loss_train=0.6935, acc_train=0.4431, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 93: loss_train=0.6944, acc_train=0.3832, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 94: loss_train=0.6937, acc_train=0.4251, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 95: loss_train=0.6941, acc_train=0.4012, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 96: loss_train=0.6946, acc_train=0.3713, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 97: loss_train=0.6940, acc_train=0.4012, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 98: loss_train=0.6946, acc_train=0.3533, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 round 99: loss_train=0.6947, acc_train=0.3713, loss_test=0.6931, acc_test=0.5000
# Training log saved to ./results\FL_ModelN1L6_Batchsize1_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 round 0: loss_train=0.7076, acc_train=0.4550, loss_test=0.6978, acc_test=0.5000
# poison_percent 50 round 1: loss_train=0.6922, acc_train=0.5350, loss_test=0.6972, acc_test=0.5000
# poison_percent 50 round 2: loss_train=0.6919, acc_train=0.5350, loss_test=0.6968, acc_test=0.5000
# poison_percent 50 round 3: loss_train=0.6843, acc_train=0.5800, loss_test=0.6963, acc_test=0.5000
# poison_percent 50 round 4: loss_train=0.6964, acc_train=0.5050, loss_test=0.6960, acc_test=0.5000
# poison_percent 50 round 5: loss_train=0.6954, acc_train=0.5100, loss_test=0.6957, acc_test=0.5000
# poison_percent 50 round 6: loss_train=0.7033, acc_train=0.4500, loss_test=0.6954, acc_test=0.5000
# poison_percent 50 round 7: loss_train=0.6973, acc_train=0.4950, loss_test=0.6951, acc_test=0.5000
# poison_percent 50 round 8: loss_train=0.6962, acc_train=0.4950, loss_test=0.6949, acc_test=0.5000
# poison_percent 50 round 9: loss_train=0.6938, acc_train=0.5200, loss_test=0.6947, acc_test=0.5000
# poison_percent 50 round 10: loss_train=0.6963, acc_train=0.4900, loss_test=0.6946, acc_test=0.5000
# poison_percent 50 round 11: loss_train=0.6917, acc_train=0.5350, loss_test=0.6944, acc_test=0.5000
# poison_percent 50 round 12: loss_train=0.6934, acc_train=0.5200, loss_test=0.6943, acc_test=0.5000
# poison_percent 50 round 13: loss_train=0.6939, acc_train=0.5150, loss_test=0.6942, acc_test=0.5000
# poison_percent 50 round 14: loss_train=0.6962, acc_train=0.4900, loss_test=0.6941, acc_test=0.5000
# poison_percent 50 round 15: loss_train=0.6968, acc_train=0.4750, loss_test=0.6940, acc_test=0.5000
# poison_percent 50 round 16: loss_train=0.6945, acc_train=0.5050, loss_test=0.6939, acc_test=0.5000
# poison_percent 50 round 17: loss_train=0.6957, acc_train=0.4850, loss_test=0.6938, acc_test=0.5000
# poison_percent 50 round 18: loss_train=0.6900, acc_train=0.5700, loss_test=0.6937, acc_test=0.5000
# poison_percent 50 round 19: loss_train=0.6992, acc_train=0.4300, loss_test=0.6937, acc_test=0.5000
# poison_percent 50 round 20: loss_train=0.6960, acc_train=0.4800, loss_test=0.6936, acc_test=0.5000
# poison_percent 50 round 21: loss_train=0.6939, acc_train=0.5050, loss_test=0.6936, acc_test=0.5000
# poison_percent 50 round 22: loss_train=0.6946, acc_train=0.5050, loss_test=0.6935, acc_test=0.5000
# poison_percent 50 round 23: loss_train=0.6948, acc_train=0.5000, loss_test=0.6935, acc_test=0.5000
# poison_percent 50 round 24: loss_train=0.6889, acc_train=0.6200, loss_test=0.6934, acc_test=0.5000
# poison_percent 50 round 25: loss_train=0.6922, acc_train=0.5500, loss_test=0.6934, acc_test=0.5000
# poison_percent 50 round 26: loss_train=0.6924, acc_train=0.5550, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 round 27: loss_train=0.6926, acc_train=0.5450, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 round 28: loss_train=0.6938, acc_train=0.5100, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 round 29: loss_train=0.6940, acc_train=0.4950, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 round 30: loss_train=0.6929, acc_train=0.5300, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 round 31: loss_train=0.6956, acc_train=0.4350, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 round 32: loss_train=0.6954, acc_train=0.4450, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 round 33: loss_train=0.6957, acc_train=0.4300, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 round 34: loss_train=0.6936, acc_train=0.5050, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 35: loss_train=0.6925, acc_train=0.5400, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 36: loss_train=0.6935, acc_train=0.5150, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 37: loss_train=0.6925, acc_train=0.5400, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 38: loss_train=0.6923, acc_train=0.5450, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 39: loss_train=0.6950, acc_train=0.4450, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 40: loss_train=0.6958, acc_train=0.4100, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 41: loss_train=0.6925, acc_train=0.5500, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 42: loss_train=0.6938, acc_train=0.4900, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 43: loss_train=0.6931, acc_train=0.5250, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 44: loss_train=0.6945, acc_train=0.4650, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 45: loss_train=0.6936, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 46: loss_train=0.6931, acc_train=0.5350, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 47: loss_train=0.6935, acc_train=0.5100, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 48: loss_train=0.6930, acc_train=0.5300, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 49: loss_train=0.6934, acc_train=0.5150, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 50: loss_train=0.6935, acc_train=0.5250, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 51: loss_train=0.6935, acc_train=0.5150, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 52: loss_train=0.6948, acc_train=0.4450, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 53: loss_train=0.6949, acc_train=0.4250, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 54: loss_train=0.6950, acc_train=0.4050, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 55: loss_train=0.6935, acc_train=0.5100, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 56: loss_train=0.6929, acc_train=0.5300, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 57: loss_train=0.6939, acc_train=0.4900, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 58: loss_train=0.6934, acc_train=0.5150, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 59: loss_train=0.6934, acc_train=0.5250, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 60: loss_train=0.6948, acc_train=0.4300, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 61: loss_train=0.6930, acc_train=0.5400, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 62: loss_train=0.6938, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 63: loss_train=0.6944, acc_train=0.4650, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 64: loss_train=0.6940, acc_train=0.4750, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 65: loss_train=0.6943, acc_train=0.4450, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 66: loss_train=0.6934, acc_train=0.5250, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 67: loss_train=0.6943, acc_train=0.4450, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 68: loss_train=0.6948, acc_train=0.4100, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 69: loss_train=0.6938, acc_train=0.4900, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 70: loss_train=0.6937, acc_train=0.4900, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 71: loss_train=0.6935, acc_train=0.5250, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 72: loss_train=0.6937, acc_train=0.4950, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 73: loss_train=0.6942, acc_train=0.4450, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 74: loss_train=0.6928, acc_train=0.5750, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 75: loss_train=0.6942, acc_train=0.4550, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 76: loss_train=0.6940, acc_train=0.4750, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 77: loss_train=0.6935, acc_train=0.5150, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 78: loss_train=0.6937, acc_train=0.4800, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 79: loss_train=0.6934, acc_train=0.4800, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 80: loss_train=0.6935, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 81: loss_train=0.6932, acc_train=0.5300, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 82: loss_train=0.6937, acc_train=0.5050, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 83: loss_train=0.6933, acc_train=0.5300, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 84: loss_train=0.6938, acc_train=0.4700, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 85: loss_train=0.6938, acc_train=0.4600, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 86: loss_train=0.6937, acc_train=0.4800, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 87: loss_train=0.6940, acc_train=0.4500, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 88: loss_train=0.6939, acc_train=0.4200, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 89: loss_train=0.6934, acc_train=0.5200, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 90: loss_train=0.6940, acc_train=0.4400, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 91: loss_train=0.6941, acc_train=0.4450, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 92: loss_train=0.6935, acc_train=0.5100, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 93: loss_train=0.6939, acc_train=0.4400, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 94: loss_train=0.6934, acc_train=0.5250, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 95: loss_train=0.6937, acc_train=0.4800, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 96: loss_train=0.6937, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 97: loss_train=0.6937, acc_train=0.4700, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 98: loss_train=0.6934, acc_train=0.5100, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 round 99: loss_train=0.6939, acc_train=0.4600, loss_test=0.6932, acc_test=0.5000
# Training log saved to ./results\FL_ModelN1L6_Batchsize1_rev2\poisoned_50percent\poisoned_50percent.csv
