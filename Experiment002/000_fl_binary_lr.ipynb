# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
class MNISTNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28*28, 1)
    def forward(self, x):
        x = self.fc1(x)
        x = torch.sigmoid(x)
        return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    model = MNISTNet().to(device)
    model.load_state_dict(global_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end]
            yb = y_c_tensor[start:end]
            outputs = model(xb)
            preds = (outputs >= 0.5).float()
            loss = binary_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # Return a deepcopy to avoid issues with state_dict references
    return copy.deepcopy(model.state_dict()), X_c_tensor.size(0), yb, outputs, preds

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 1
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "./data/mnist_binary_poison/train"
TEST_PATH = "./data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
BATCH_SIZE_list = []
temp_bs = BATCH_SIZE
while temp_bs >= 1:
    BATCH_SIZE_list.append(temp_bs)
    temp_bs = temp_bs // 2

for rev in range(3):

    global_model = MNISTNet().to(device)
    for experiment_bs in BATCH_SIZE_list:

        name_save_path = f"FL_ModelN1L1_Batchsize{experiment_bs}_rev{rev}"
        
        for i_poisoned in poison_n_list:
            percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

            # create directory
            NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
            save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
            # Remove existing directory if it exists
            if os.path.exists(save_path):
                shutil.rmtree(save_path)
            if not os.path.exists(save_path):
                os.makedirs(save_path)
            save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
            os.makedirs(save_all_path, exist_ok=True)
            
            # Load data
            X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
            if X_test.shape[0] == 0:
                raise ValueError("No valid test images found in the test directory!")
            X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
            y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

            torch.save(global_model, os.path.join(save_path,'model_init.pt'))
            global_weights = global_model.state_dict()

            records = []

            X_train_tensor = {}
            y_train_tensor = {}
            for i in range(N_HONEST):
                X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                if len(X_c) == 0:
                    continue
                X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                X_train_tensor[f"honest_{i}"] = X_c_tensor
                y_train_tensor[f"honest_{i}"] = y_c_tensor
            for i in range(i_poisoned):
                X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                if len(X_c) == 0:
                    continue
                X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                X_train_tensor[f"poison_{i}"] = X_c_tensor
                y_train_tensor[f"poison_{i}"] = y_c_tensor

            # Training loop
            for round in range(ROUNDS):
                # Prepare arguments for honest clients
                
                #randomize the training data
                for i in range(N_HONEST):
                    perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                    X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                    y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                honest_args = [
                    (
                        X_train_tensor[f"honest_{i}"],
                        y_train_tensor[f"honest_{i}"],
                        global_weights,
                        LEARNING_RATE,
                        LOCAL_EPOCHS,
                        experiment_bs,
                        device
                    )
                    for i in range(N_HONEST)
                ]

                # Prepare arguments for poisoned clients
                
                #randomize the training data
                for i in range(i_poisoned):
                    perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                    X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                    y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                poison_args = [
                    (
                        X_train_tensor[f"poison_{i}"],
                        y_train_tensor[f"poison_{i}"],
                        global_weights,
                        LEARNING_RATE,
                        LOCAL_EPOCHS,
                        experiment_bs,
                        device
                    )
                    for i in range(i_poisoned)
                ]

                # Run in parallel
                with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                    honest_results = list(executor.map(train_local_worker, honest_args))
                    poison_results = list(executor.map(train_local_worker, poison_args))

                local_weights = []
                local_sizes = []
                local_y = []
                local_outputs = []
                local_preds = []
                for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                    local_weights.append(l_w)
                    local_sizes.append(l_sz)
                    local_y.extend(l_y)
                    local_outputs.extend(l_out)
                    local_preds.extend(l_pred)
                loss_train = binary_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                # Federated averaging (weighted by client data size)
                new_weights = {}
                for key in global_weights.keys():
                    new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                global_weights = new_weights
                global_model.load_state_dict(global_weights)

                # Evaluate
                global_model.eval()
                with torch.no_grad():
                    outputs = global_model(X_test_tensor)
                    preds = (outputs > 0.5).float()
                    loss_test = binary_cross_entropy(outputs, y_test_tensor)
                    acc_test = (preds == y_test_tensor).float().mean().item()
                records.append({'poison_percent': percent_poisoned, 'round': round, 
                                'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                'loss_test': loss_test.item(), 'acc_test': acc_test})
                report_txt = f"poison_percent {percent_poisoned} "
                report_txt += f"round {round}: "
                report_txt += f"loss_train={loss_train.item():.4f}, "
                report_txt += f"acc_train={acc_train:.4f}, "
                report_txt += f"loss_test={loss_test.item():.4f}, "
                report_txt += f"acc_test={acc_test:.4f}"
                print(report_txt)

            torch.save(global_model, os.path.join(save_path,'model_last.pt'))

            # Save training log
            df = pd.DataFrame(records)
            save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
            df.to_csv(save_name_path, index=False)
            print(f"Training log saved to {save_name_path}")

            # Plot loss and accuracy
            plt.figure(figsize=(10,4))

            plt.subplot(1,2,1)
            plt.plot(df['round'], df['loss_test'], marker='o')
            plt.title('Test Loss')
            plt.ylabel('Loss')
            plt.xlabel('Epoch')
            plt.grid(True)
            plt.ylim(0, 1.1)
            # plt.legend()

            plt.subplot(1,2,2)
            plt.plot(df['round'], df['acc_test'], marker='o')
            plt.title('Test Accuracy')
            plt.ylabel('Accuracy')
            plt.xlabel('Epoch')
            plt.grid(True)
            plt.ylim(0, 1.1)
            # plt.legend()

            plt.tight_layout()
            save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
            plt.savefig(save_name_path)

            save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
            plt.savefig(save_name_path)
            plt.close()
# Out:
# poison_percent 0 round 0: loss_train=0.2663, acc_train=1.0000, loss_test=0.2765, acc_test=0.9974
# poison_percent 0 round 1: loss_train=0.1257, acc_train=1.0000, loss_test=0.1283, acc_test=0.9980
# poison_percent 0 round 2: loss_train=0.0728, acc_train=1.0000, loss_test=0.0666, acc_test=0.9980
# poison_percent 0 round 3: loss_train=0.0401, acc_train=1.0000, loss_test=0.0389, acc_test=0.9969
# poison_percent 0 round 4: loss_train=0.0497, acc_train=0.9800, loss_test=0.0256, acc_test=0.9964
# poison_percent 0 round 5: loss_train=0.0454, acc_train=0.9800, loss_test=0.0181, acc_test=0.9964
# poison_percent 0 round 6: loss_train=0.0135, acc_train=1.0000, loss_test=0.0137, acc_test=0.9969
# poison_percent 0 round 7: loss_train=0.0434, acc_train=0.9900, loss_test=0.0110, acc_test=0.9969
# poison_percent 0 round 8: loss_train=0.0076, acc_train=1.0000, loss_test=0.0092, acc_test=0.9985
# poison_percent 0 round 9: loss_train=0.0115, acc_train=1.0000, loss_test=0.0079, acc_test=0.9985
# poison_percent 0 round 10: loss_train=0.0212, acc_train=0.9900, loss_test=0.0071, acc_test=0.9985
# poison_percent 0 round 11: loss_train=0.0015, acc_train=1.0000, loss_test=0.0064, acc_test=0.9985
# poison_percent 0 round 12: loss_train=0.0465, acc_train=0.9900, loss_test=0.0060, acc_test=0.9980
# poison_percent 0 round 13: loss_train=0.0123, acc_train=0.9900, loss_test=0.0056, acc_test=0.9985
# poison_percent 0 round 14: loss_train=0.0254, acc_train=0.9800, loss_test=0.0054, acc_test=0.9980
# poison_percent 0 round 15: loss_train=0.0006, acc_train=1.0000, loss_test=0.0051, acc_test=0.9980
# poison_percent 0 round 16: loss_train=0.0182, acc_train=0.9900, loss_test=0.0050, acc_test=0.9980
# poison_percent 0 round 17: loss_train=0.0043, acc_train=1.0000, loss_test=0.0048, acc_test=0.9980
# poison_percent 0 round 18: loss_train=0.1078, acc_train=0.9700, loss_test=0.0047, acc_test=0.9980
# poison_percent 0 round 19: loss_train=0.0183, acc_train=1.0000, loss_test=0.0046, acc_test=0.9980
# poison_percent 0 round 20: loss_train=0.0013, acc_train=1.0000, loss_test=0.0046, acc_test=0.9980
# poison_percent 0 round 21: loss_train=0.0074, acc_train=1.0000, loss_test=0.0045, acc_test=0.9980
# poison_percent 0 round 22: loss_train=0.0003, acc_train=1.0000, loss_test=0.0045, acc_test=0.9980
# poison_percent 0 round 23: loss_train=0.0008, acc_train=1.0000, loss_test=0.0044, acc_test=0.9980
# poison_percent 0 round 24: loss_train=0.0709, acc_train=0.9900, loss_test=0.0044, acc_test=0.9980
# poison_percent 0 round 25: loss_train=0.0014, acc_train=1.0000, loss_test=0.0044, acc_test=0.9980
# poison_percent 0 round 26: loss_train=0.0002, acc_train=1.0000, loss_test=0.0043, acc_test=0.9980
# poison_percent 0 round 27: loss_train=0.0041, acc_train=1.0000, loss_test=0.0043, acc_test=0.9980
# poison_percent 0 round 28: loss_train=0.0119, acc_train=0.9900, loss_test=0.0042, acc_test=0.9980
# poison_percent 0 round 29: loss_train=0.0002, acc_train=1.0000, loss_test=0.0042, acc_test=0.9980
# poison_percent 0 round 30: loss_train=0.0019, acc_train=1.0000, loss_test=0.0042, acc_test=0.9980
# poison_percent 0 round 31: loss_train=0.0038, acc_train=1.0000, loss_test=0.0041, acc_test=0.9980
# poison_percent 0 round 32: loss_train=0.0000, acc_train=1.0000, loss_test=0.0041, acc_test=0.9980
# poison_percent 0 round 33: loss_train=0.0106, acc_train=1.0000, loss_test=0.0041, acc_test=0.9980
# poison_percent 0 round 34: loss_train=0.0002, acc_train=1.0000, loss_test=0.0040, acc_test=0.9980
# poison_percent 0 round 35: loss_train=0.0001, acc_train=1.0000, loss_test=0.0040, acc_test=0.9980
# poison_percent 0 round 36: loss_train=0.0022, acc_train=1.0000, loss_test=0.0040, acc_test=0.9980
# poison_percent 0 round 37: loss_train=0.0768, acc_train=0.9900, loss_test=0.0039, acc_test=0.9980
# poison_percent 0 round 38: loss_train=0.0013, acc_train=1.0000, loss_test=0.0039, acc_test=0.9980
# poison_percent 0 round 39: loss_train=0.0012, acc_train=1.0000, loss_test=0.0038, acc_test=0.9980
# poison_percent 0 round 40: loss_train=0.0000, acc_train=1.0000, loss_test=0.0038, acc_test=0.9980
# poison_percent 0 round 41: loss_train=0.0000, acc_train=1.0000, loss_test=0.0037, acc_test=0.9980
# poison_percent 0 round 42: loss_train=0.0011, acc_train=1.0000, loss_test=0.0037, acc_test=0.9980
# poison_percent 0 round 43: loss_train=0.0003, acc_train=1.0000, loss_test=0.0037, acc_test=0.9980
# poison_percent 0 round 44: loss_train=0.0344, acc_train=0.9900, loss_test=0.0037, acc_test=0.9980
# poison_percent 0 round 45: loss_train=0.1457, acc_train=0.9800, loss_test=0.0036, acc_test=0.9980
# poison_percent 0 round 46: loss_train=0.0000, acc_train=1.0000, loss_test=0.0036, acc_test=0.9980
# poison_percent 0 round 47: loss_train=0.0000, acc_train=1.0000, loss_test=0.0036, acc_test=0.9980
# poison_percent 0 round 48: loss_train=0.0891, acc_train=0.9900, loss_test=0.0035, acc_test=0.9980
# poison_percent 0 round 49: loss_train=0.0005, acc_train=1.0000, loss_test=0.0035, acc_test=0.9980
# poison_percent 0 round 50: loss_train=0.0678, acc_train=0.9900, loss_test=0.0035, acc_test=0.9980
# poison_percent 0 round 51: loss_train=0.0314, acc_train=0.9900, loss_test=0.0034, acc_test=0.9980
# poison_percent 0 round 52: loss_train=0.0010, acc_train=1.0000, loss_test=0.0033, acc_test=0.9985
# poison_percent 0 round 53: loss_train=0.0005, acc_train=1.0000, loss_test=0.0033, acc_test=0.9985
# poison_percent 0 round 54: loss_train=0.0118, acc_train=0.9900, loss_test=0.0033, acc_test=0.9985
# poison_percent 0 round 55: loss_train=0.0000, acc_train=1.0000, loss_test=0.0032, acc_test=0.9985
# poison_percent 0 round 56: loss_train=0.0000, acc_train=1.0000, loss_test=0.0032, acc_test=0.9985
# poison_percent 0 round 57: loss_train=0.0010, acc_train=1.0000, loss_test=0.0032, acc_test=0.9985
# poison_percent 0 round 58: loss_train=0.0001, acc_train=1.0000, loss_test=0.0031, acc_test=0.9985
# poison_percent 0 round 59: loss_train=0.0000, acc_train=1.0000, loss_test=0.0031, acc_test=0.9985
# poison_percent 0 round 60: loss_train=0.0666, acc_train=0.9900, loss_test=0.0031, acc_test=0.9985
# poison_percent 0 round 61: loss_train=0.0000, acc_train=1.0000, loss_test=0.0030, acc_test=0.9985
# poison_percent 0 round 62: loss_train=0.0000, acc_train=1.0000, loss_test=0.0030, acc_test=0.9990
# poison_percent 0 round 63: loss_train=0.0000, acc_train=1.0000, loss_test=0.0030, acc_test=0.9990
# poison_percent 0 round 64: loss_train=0.0018, acc_train=1.0000, loss_test=0.0029, acc_test=0.9990
# poison_percent 0 round 65: loss_train=0.0000, acc_train=1.0000, loss_test=0.0029, acc_test=0.9990
# poison_percent 0 round 66: loss_train=0.0179, acc_train=0.9900, loss_test=0.0029, acc_test=0.9990
# poison_percent 0 round 67: loss_train=0.0002, acc_train=1.0000, loss_test=0.0029, acc_test=0.9990
# poison_percent 0 round 68: loss_train=0.0003, acc_train=1.0000, loss_test=0.0029, acc_test=0.9990
# poison_percent 0 round 69: loss_train=0.0000, acc_train=1.0000, loss_test=0.0029, acc_test=0.9990
# poison_percent 0 round 70: loss_train=0.0000, acc_train=1.0000, loss_test=0.0028, acc_test=0.9990
# poison_percent 0 round 71: loss_train=0.0004, acc_train=1.0000, loss_test=0.0028, acc_test=0.9990
# poison_percent 0 round 72: loss_train=0.0000, acc_train=1.0000, loss_test=0.0028, acc_test=0.9990
# poison_percent 0 round 73: loss_train=0.0631, acc_train=0.9900, loss_test=0.0028, acc_test=0.9990
# poison_percent 0 round 74: loss_train=0.0000, acc_train=1.0000, loss_test=0.0028, acc_test=0.9990
# poison_percent 0 round 75: loss_train=0.0004, acc_train=1.0000, loss_test=0.0027, acc_test=0.9990
# poison_percent 0 round 76: loss_train=0.0000, acc_train=1.0000, loss_test=0.0027, acc_test=0.9990
# poison_percent 0 round 77: loss_train=0.0195, acc_train=0.9900, loss_test=0.0027, acc_test=0.9990
# poison_percent 0 round 78: loss_train=0.0004, acc_train=1.0000, loss_test=0.0027, acc_test=0.9990
# poison_percent 0 round 79: loss_train=0.0145, acc_train=0.9900, loss_test=0.0026, acc_test=0.9990
# poison_percent 0 round 80: loss_train=0.0697, acc_train=0.9900, loss_test=0.0026, acc_test=0.9990
# poison_percent 0 round 81: loss_train=0.0000, acc_train=1.0000, loss_test=0.0026, acc_test=0.9990
# poison_percent 0 round 82: loss_train=0.0123, acc_train=0.9900, loss_test=0.0026, acc_test=0.9990
# poison_percent 0 round 83: loss_train=0.0157, acc_train=0.9900, loss_test=0.0026, acc_test=0.9990
# poison_percent 0 round 84: loss_train=0.0000, acc_train=1.0000, loss_test=0.0026, acc_test=0.9990
# poison_percent 0 round 85: loss_train=0.0000, acc_train=1.0000, loss_test=0.0025, acc_test=0.9990
# poison_percent 0 round 86: loss_train=0.0648, acc_train=0.9900, loss_test=0.0025, acc_test=0.9990
# poison_percent 0 round 87: loss_train=0.0000, acc_train=1.0000, loss_test=0.0025, acc_test=0.9990
# poison_percent 0 round 88: loss_train=0.0001, acc_train=1.0000, loss_test=0.0025, acc_test=0.9990
# poison_percent 0 round 89: loss_train=0.2164, acc_train=0.9800, loss_test=0.0025, acc_test=0.9990
# poison_percent 0 round 90: loss_train=0.0001, acc_train=1.0000, loss_test=0.0025, acc_test=0.9990
# poison_percent 0 round 91: loss_train=0.0000, acc_train=1.0000, loss_test=0.0025, acc_test=0.9990
# poison_percent 0 round 92: loss_train=0.0105, acc_train=0.9900, loss_test=0.0025, acc_test=0.9990
# poison_percent 0 round 93: loss_train=0.0000, acc_train=1.0000, loss_test=0.0025, acc_test=0.9990
# poison_percent 0 round 94: loss_train=0.0000, acc_train=1.0000, loss_test=0.0025, acc_test=0.9990
# poison_percent 0 round 95: loss_train=0.0001, acc_train=1.0000, loss_test=0.0024, acc_test=0.9990
# poison_percent 0 round 96: loss_train=0.0030, acc_train=1.0000, loss_test=0.0024, acc_test=0.9990
# poison_percent 0 round 97: loss_train=0.0059, acc_train=1.0000, loss_test=0.0024, acc_test=0.9995
# poison_percent 0 round 98: loss_train=0.0001, acc_train=1.0000, loss_test=0.0024, acc_test=0.9995
# poison_percent 0 round 99: loss_train=0.0000, acc_train=1.0000, loss_test=0.0024, acc_test=0.9995
# Training log saved to ./results\FL_ModelN1L1_Batchsize1_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 round 0: loss_train=0.2907, acc_train=0.9821, loss_test=0.3286, acc_test=0.9872
# poison_percent 10 round 1: loss_train=0.2046, acc_train=0.9643, loss_test=0.1754, acc_test=0.9969
# poison_percent 10 round 2: loss_train=0.2287, acc_train=0.8929, loss_test=0.1007, acc_test=0.9985
# poison_percent 10 round 3: loss_train=0.2195, acc_train=0.8929, loss_test=0.0631, acc_test=0.9969
# poison_percent 10 round 4: loss_train=0.2314, acc_train=0.9018, loss_test=0.0425, acc_test=0.9964
# poison_percent 10 round 5: loss_train=0.3685, acc_train=0.8661, loss_test=0.0307, acc_test=0.9964
# poison_percent 10 round 6: loss_train=0.3492, acc_train=0.8750, loss_test=0.0233, acc_test=0.9964
# poison_percent 10 round 7: loss_train=0.4248, acc_train=0.8929, loss_test=0.0183, acc_test=0.9969
# poison_percent 10 round 8: loss_train=0.5403, acc_train=0.8929, loss_test=0.0150, acc_test=0.9969
# poison_percent 10 round 9: loss_train=0.4328, acc_train=0.8571, loss_test=0.0126, acc_test=0.9969
# poison_percent 10 round 10: loss_train=0.6006, acc_train=0.8661, loss_test=0.0108, acc_test=0.9969
# poison_percent 10 round 11: loss_train=0.5984, acc_train=0.8839, loss_test=0.0096, acc_test=0.9969
# poison_percent 10 round 12: loss_train=0.6542, acc_train=0.8929, loss_test=0.0086, acc_test=0.9974
# poison_percent 10 round 13: loss_train=0.7737, acc_train=0.8839, loss_test=0.0079, acc_test=0.9980
# poison_percent 10 round 14: loss_train=0.6833, acc_train=0.8929, loss_test=0.0073, acc_test=0.9980
# poison_percent 10 round 15: loss_train=0.8509, acc_train=0.8929, loss_test=0.0068, acc_test=0.9980
# poison_percent 10 round 16: loss_train=0.9796, acc_train=0.8839, loss_test=0.0064, acc_test=0.9980
# poison_percent 10 round 17: loss_train=0.8859, acc_train=0.8929, loss_test=0.0061, acc_test=0.9980
# poison_percent 10 round 18: loss_train=1.0824, acc_train=0.8929, loss_test=0.0058, acc_test=0.9980
# poison_percent 10 round 19: loss_train=0.9070, acc_train=0.8929, loss_test=0.0055, acc_test=0.9980
# poison_percent 10 round 20: loss_train=0.8161, acc_train=0.8929, loss_test=0.0053, acc_test=0.9985
# poison_percent 10 round 21: loss_train=1.2202, acc_train=0.8839, loss_test=0.0051, acc_test=0.9985
# poison_percent 10 round 22: loss_train=0.9642, acc_train=0.8929, loss_test=0.0050, acc_test=0.9985
# poison_percent 10 round 23: loss_train=1.2432, acc_train=0.8929, loss_test=0.0048, acc_test=0.9985
# poison_percent 10 round 24: loss_train=1.1491, acc_train=0.8929, loss_test=0.0047, acc_test=0.9985
# poison_percent 10 round 25: loss_train=1.0915, acc_train=0.9018, loss_test=0.0046, acc_test=0.9985
# poison_percent 10 round 26: loss_train=1.0784, acc_train=0.8929, loss_test=0.0045, acc_test=0.9985
# poison_percent 10 round 27: loss_train=1.3869, acc_train=0.8839, loss_test=0.0044, acc_test=0.9985
# poison_percent 10 round 28: loss_train=0.9627, acc_train=0.8929, loss_test=0.0043, acc_test=0.9985
# poison_percent 10 round 29: loss_train=1.0956, acc_train=0.8929, loss_test=0.0042, acc_test=0.9985
# poison_percent 10 round 30: loss_train=1.3063, acc_train=0.8929, loss_test=0.0042, acc_test=0.9985
# poison_percent 10 round 31: loss_train=1.4277, acc_train=0.8929, loss_test=0.0041, acc_test=0.9985
# poison_percent 10 round 32: loss_train=1.2257, acc_train=0.8929, loss_test=0.0040, acc_test=0.9985
# poison_percent 10 round 33: loss_train=1.5969, acc_train=0.8839, loss_test=0.0040, acc_test=0.9985
# poison_percent 10 round 34: loss_train=1.4478, acc_train=0.8750, loss_test=0.0039, acc_test=0.9985
# poison_percent 10 round 35: loss_train=1.1960, acc_train=0.9018, loss_test=0.0039, acc_test=0.9985
# poison_percent 10 round 36: loss_train=1.2776, acc_train=0.8839, loss_test=0.0038, acc_test=0.9985
# poison_percent 10 round 37: loss_train=1.4655, acc_train=0.8929, loss_test=0.0038, acc_test=0.9985
# poison_percent 10 round 38: loss_train=1.3097, acc_train=0.8929, loss_test=0.0037, acc_test=0.9985
# poison_percent 10 round 39: loss_train=1.4159, acc_train=0.8929, loss_test=0.0037, acc_test=0.9985
# poison_percent 10 round 40: loss_train=1.3637, acc_train=0.9107, loss_test=0.0037, acc_test=0.9985
# poison_percent 10 round 41: loss_train=1.5200, acc_train=0.8929, loss_test=0.0036, acc_test=0.9985
# poison_percent 10 round 42: loss_train=1.4292, acc_train=0.8929, loss_test=0.0036, acc_test=0.9985
# poison_percent 10 round 43: loss_train=1.5936, acc_train=0.8929, loss_test=0.0036, acc_test=0.9985
# poison_percent 10 round 44: loss_train=1.2102, acc_train=0.8929, loss_test=0.0035, acc_test=0.9985
# poison_percent 10 round 45: loss_train=1.6863, acc_train=0.8839, loss_test=0.0035, acc_test=0.9985
# poison_percent 10 round 46: loss_train=1.3709, acc_train=0.8929, loss_test=0.0035, acc_test=0.9985
# poison_percent 10 round 47: loss_train=1.3575, acc_train=0.8929, loss_test=0.0035, acc_test=0.9985
# poison_percent 10 round 48: loss_train=1.5174, acc_train=0.8839, loss_test=0.0035, acc_test=0.9985
# poison_percent 10 round 49: loss_train=1.5220, acc_train=0.8839, loss_test=0.0034, acc_test=0.9985
# poison_percent 10 round 50: loss_train=1.5443, acc_train=0.8929, loss_test=0.0034, acc_test=0.9985
# poison_percent 10 round 51: loss_train=1.4341, acc_train=0.8929, loss_test=0.0033, acc_test=0.9985
# poison_percent 10 round 52: loss_train=1.5318, acc_train=0.8929, loss_test=0.0033, acc_test=0.9985
# poison_percent 10 round 53: loss_train=1.6489, acc_train=0.8929, loss_test=0.0033, acc_test=0.9985
# poison_percent 10 round 54: loss_train=1.3546, acc_train=0.8929, loss_test=0.0033, acc_test=0.9985
# poison_percent 10 round 55: loss_train=1.6094, acc_train=0.8929, loss_test=0.0032, acc_test=0.9985
# poison_percent 10 round 56: loss_train=1.5591, acc_train=0.8929, loss_test=0.0032, acc_test=0.9985
# poison_percent 10 round 57: loss_train=1.6452, acc_train=0.8929, loss_test=0.0032, acc_test=0.9985
# poison_percent 10 round 58: loss_train=1.7596, acc_train=0.8750, loss_test=0.0032, acc_test=0.9985
# poison_percent 10 round 59: loss_train=1.6995, acc_train=0.8929, loss_test=0.0031, acc_test=0.9985
# poison_percent 10 round 60: loss_train=1.5418, acc_train=0.8929, loss_test=0.0031, acc_test=0.9985
# poison_percent 10 round 61: loss_train=1.5797, acc_train=0.8929, loss_test=0.0031, acc_test=0.9985
# poison_percent 10 round 62: loss_train=1.6440, acc_train=0.8929, loss_test=0.0030, acc_test=0.9985
# poison_percent 10 round 63: loss_train=1.6701, acc_train=0.8929, loss_test=0.0030, acc_test=0.9985
# poison_percent 10 round 64: loss_train=1.4089, acc_train=0.9107, loss_test=0.0030, acc_test=0.9985
# poison_percent 10 round 65: loss_train=1.6750, acc_train=0.8929, loss_test=0.0030, acc_test=0.9985
# poison_percent 10 round 66: loss_train=1.6568, acc_train=0.8929, loss_test=0.0030, acc_test=0.9985
# poison_percent 10 round 67: loss_train=1.7035, acc_train=0.8839, loss_test=0.0029, acc_test=0.9985
# poison_percent 10 round 68: loss_train=1.6408, acc_train=0.8929, loss_test=0.0029, acc_test=0.9985
# poison_percent 10 round 69: loss_train=1.9057, acc_train=0.8750, loss_test=0.0029, acc_test=0.9985
# poison_percent 10 round 70: loss_train=1.5751, acc_train=0.8929, loss_test=0.0029, acc_test=0.9985
# poison_percent 10 round 71: loss_train=1.4988, acc_train=0.9018, loss_test=0.0029, acc_test=0.9985
# poison_percent 10 round 72: loss_train=1.6522, acc_train=0.8750, loss_test=0.0029, acc_test=0.9985
# poison_percent 10 round 73: loss_train=1.7041, acc_train=0.8839, loss_test=0.0028, acc_test=0.9985
# poison_percent 10 round 74: loss_train=1.6777, acc_train=0.8929, loss_test=0.0028, acc_test=0.9985
# poison_percent 10 round 75: loss_train=1.6894, acc_train=0.8839, loss_test=0.0028, acc_test=0.9985
# poison_percent 10 round 76: loss_train=1.6079, acc_train=0.8929, loss_test=0.0028, acc_test=0.9985
# poison_percent 10 round 77: loss_train=1.6740, acc_train=0.8929, loss_test=0.0028, acc_test=0.9990
# poison_percent 10 round 78: loss_train=1.7279, acc_train=0.8839, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 79: loss_train=1.6311, acc_train=0.8929, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 80: loss_train=1.5831, acc_train=0.8929, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 81: loss_train=1.6262, acc_train=0.8929, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 82: loss_train=1.6315, acc_train=0.8839, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 83: loss_train=1.6798, acc_train=0.8929, loss_test=0.0026, acc_test=0.9990
# poison_percent 10 round 84: loss_train=1.7178, acc_train=0.8929, loss_test=0.0026, acc_test=0.9990
# poison_percent 10 round 85: loss_train=1.6317, acc_train=0.8839, loss_test=0.0026, acc_test=0.9990
# poison_percent 10 round 86: loss_train=1.7145, acc_train=0.8929, loss_test=0.0026, acc_test=0.9990
# poison_percent 10 round 87: loss_train=1.6691, acc_train=0.8929, loss_test=0.0026, acc_test=0.9990
# poison_percent 10 round 88: loss_train=1.7163, acc_train=0.8929, loss_test=0.0026, acc_test=0.9990
# poison_percent 10 round 89: loss_train=1.7270, acc_train=0.8839, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 90: loss_train=1.5758, acc_train=0.8929, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 91: loss_train=1.7078, acc_train=0.8929, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 92: loss_train=1.5059, acc_train=0.8839, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 93: loss_train=1.5556, acc_train=0.9018, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 94: loss_train=1.6858, acc_train=0.8929, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 95: loss_train=1.7580, acc_train=0.8839, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 96: loss_train=1.7063, acc_train=0.8929, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 97: loss_train=1.6837, acc_train=0.8839, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 98: loss_train=1.7222, acc_train=0.8929, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 99: loss_train=1.7175, acc_train=0.8929, loss_test=0.0023, acc_test=0.9990
# Training log saved to ./results\FL_ModelN1L1_Batchsize1_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=0.3395, acc_train=0.9760, loss_test=0.4291, acc_test=0.9643
# poison_percent 20 round 1: loss_train=0.2722, acc_train=0.9680, loss_test=0.2638, acc_test=0.9939
# poison_percent 20 round 2: loss_train=0.2545, acc_train=0.9040, loss_test=0.1688, acc_test=0.9974
# poison_percent 20 round 3: loss_train=0.2541, acc_train=0.8640, loss_test=0.1137, acc_test=0.9974
# poison_percent 20 round 4: loss_train=0.3268, acc_train=0.8160, loss_test=0.0802, acc_test=0.9964
# poison_percent 20 round 5: loss_train=0.4012, acc_train=0.8000, loss_test=0.0598, acc_test=0.9964
# poison_percent 20 round 6: loss_train=0.4283, acc_train=0.8080, loss_test=0.0464, acc_test=0.9959
# poison_percent 20 round 7: loss_train=0.5048, acc_train=0.8000, loss_test=0.0368, acc_test=0.9959
# poison_percent 20 round 8: loss_train=0.5727, acc_train=0.8000, loss_test=0.0300, acc_test=0.9964
# poison_percent 20 round 9: loss_train=0.6130, acc_train=0.8000, loss_test=0.0250, acc_test=0.9980
# poison_percent 20 round 10: loss_train=0.7939, acc_train=0.8000, loss_test=0.0213, acc_test=0.9974
# poison_percent 20 round 11: loss_train=0.7342, acc_train=0.8080, loss_test=0.0185, acc_test=0.9974
# poison_percent 20 round 12: loss_train=0.7073, acc_train=0.7920, loss_test=0.0162, acc_test=0.9980
# poison_percent 20 round 13: loss_train=0.8667, acc_train=0.7920, loss_test=0.0143, acc_test=0.9980
# poison_percent 20 round 14: loss_train=0.9324, acc_train=0.8000, loss_test=0.0129, acc_test=0.9980
# poison_percent 20 round 15: loss_train=0.9792, acc_train=0.8080, loss_test=0.0117, acc_test=0.9980
# poison_percent 20 round 16: loss_train=1.0420, acc_train=0.8000, loss_test=0.0107, acc_test=0.9980
# poison_percent 20 round 17: loss_train=1.1068, acc_train=0.8000, loss_test=0.0099, acc_test=0.9980
# poison_percent 20 round 18: loss_train=1.2300, acc_train=0.8000, loss_test=0.0092, acc_test=0.9980
# poison_percent 20 round 19: loss_train=1.2216, acc_train=0.7920, loss_test=0.0085, acc_test=0.9980
# poison_percent 20 round 20: loss_train=1.2252, acc_train=0.8000, loss_test=0.0080, acc_test=0.9980
# poison_percent 20 round 21: loss_train=1.2751, acc_train=0.8000, loss_test=0.0075, acc_test=0.9980
# poison_percent 20 round 22: loss_train=1.5006, acc_train=0.7920, loss_test=0.0072, acc_test=0.9980
# poison_percent 20 round 23: loss_train=1.2289, acc_train=0.8000, loss_test=0.0068, acc_test=0.9980
# poison_percent 20 round 24: loss_train=1.3820, acc_train=0.8160, loss_test=0.0065, acc_test=0.9980
# poison_percent 20 round 25: loss_train=1.3358, acc_train=0.8000, loss_test=0.0062, acc_test=0.9980
# poison_percent 20 round 26: loss_train=1.6248, acc_train=0.8000, loss_test=0.0060, acc_test=0.9980
# poison_percent 20 round 27: loss_train=1.5045, acc_train=0.8000, loss_test=0.0058, acc_test=0.9980
# poison_percent 20 round 28: loss_train=1.6551, acc_train=0.8080, loss_test=0.0056, acc_test=0.9980
# poison_percent 20 round 29: loss_train=1.8210, acc_train=0.8000, loss_test=0.0054, acc_test=0.9985
# poison_percent 20 round 30: loss_train=1.8205, acc_train=0.7840, loss_test=0.0053, acc_test=0.9985
# poison_percent 20 round 31: loss_train=1.7252, acc_train=0.7920, loss_test=0.0051, acc_test=0.9985
# poison_percent 20 round 32: loss_train=1.9983, acc_train=0.8000, loss_test=0.0050, acc_test=0.9985
# poison_percent 20 round 33: loss_train=2.0892, acc_train=0.8000, loss_test=0.0049, acc_test=0.9985
# poison_percent 20 round 34: loss_train=1.9552, acc_train=0.8000, loss_test=0.0047, acc_test=0.9985
# poison_percent 20 round 35: loss_train=1.8127, acc_train=0.7840, loss_test=0.0046, acc_test=0.9985
# poison_percent 20 round 36: loss_train=2.0148, acc_train=0.8000, loss_test=0.0045, acc_test=0.9985
# poison_percent 20 round 37: loss_train=1.9474, acc_train=0.7920, loss_test=0.0044, acc_test=0.9985
# poison_percent 20 round 38: loss_train=1.9674, acc_train=0.8000, loss_test=0.0043, acc_test=0.9985
# poison_percent 20 round 39: loss_train=1.8099, acc_train=0.8000, loss_test=0.0042, acc_test=0.9985
# poison_percent 20 round 40: loss_train=2.0936, acc_train=0.8000, loss_test=0.0041, acc_test=0.9985
# poison_percent 20 round 41: loss_train=1.9973, acc_train=0.8080, loss_test=0.0040, acc_test=0.9985
# poison_percent 20 round 42: loss_train=2.2668, acc_train=0.8080, loss_test=0.0040, acc_test=0.9985
# poison_percent 20 round 43: loss_train=2.0535, acc_train=0.8000, loss_test=0.0039, acc_test=0.9985
# poison_percent 20 round 44: loss_train=2.1437, acc_train=0.8000, loss_test=0.0038, acc_test=0.9985
# poison_percent 20 round 45: loss_train=2.2573, acc_train=0.8000, loss_test=0.0038, acc_test=0.9985
# poison_percent 20 round 46: loss_train=2.1230, acc_train=0.8080, loss_test=0.0037, acc_test=0.9985
# poison_percent 20 round 47: loss_train=2.2319, acc_train=0.7920, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 48: loss_train=2.4375, acc_train=0.8000, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 49: loss_train=2.6115, acc_train=0.8000, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 50: loss_train=2.3683, acc_train=0.8000, loss_test=0.0035, acc_test=0.9985
# poison_percent 20 round 51: loss_train=2.2081, acc_train=0.8000, loss_test=0.0035, acc_test=0.9985
# poison_percent 20 round 52: loss_train=2.5269, acc_train=0.8000, loss_test=0.0034, acc_test=0.9985
# poison_percent 20 round 53: loss_train=2.3895, acc_train=0.8000, loss_test=0.0034, acc_test=0.9985
# poison_percent 20 round 54: loss_train=2.4037, acc_train=0.7920, loss_test=0.0034, acc_test=0.9985
# poison_percent 20 round 55: loss_train=2.3029, acc_train=0.8000, loss_test=0.0033, acc_test=0.9985
# poison_percent 20 round 56: loss_train=2.3860, acc_train=0.8000, loss_test=0.0033, acc_test=0.9985
# poison_percent 20 round 57: loss_train=2.5168, acc_train=0.8000, loss_test=0.0033, acc_test=0.9985
# poison_percent 20 round 58: loss_train=2.5024, acc_train=0.8000, loss_test=0.0033, acc_test=0.9985
# poison_percent 20 round 59: loss_train=2.3855, acc_train=0.7920, loss_test=0.0032, acc_test=0.9985
# poison_percent 20 round 60: loss_train=2.6537, acc_train=0.8000, loss_test=0.0032, acc_test=0.9985
# poison_percent 20 round 61: loss_train=2.6461, acc_train=0.8080, loss_test=0.0032, acc_test=0.9985
# poison_percent 20 round 62: loss_train=2.5575, acc_train=0.8000, loss_test=0.0032, acc_test=0.9985
# poison_percent 20 round 63: loss_train=2.8209, acc_train=0.8000, loss_test=0.0032, acc_test=0.9985
# poison_percent 20 round 64: loss_train=2.5765, acc_train=0.8080, loss_test=0.0031, acc_test=0.9985
# poison_percent 20 round 65: loss_train=2.7577, acc_train=0.8000, loss_test=0.0031, acc_test=0.9985
# poison_percent 20 round 66: loss_train=2.9005, acc_train=0.8000, loss_test=0.0031, acc_test=0.9985
# poison_percent 20 round 67: loss_train=2.6228, acc_train=0.8000, loss_test=0.0031, acc_test=0.9985
# poison_percent 20 round 68: loss_train=2.5552, acc_train=0.7920, loss_test=0.0031, acc_test=0.9985
# poison_percent 20 round 69: loss_train=2.5191, acc_train=0.8000, loss_test=0.0031, acc_test=0.9985
# poison_percent 20 round 70: loss_train=2.7451, acc_train=0.8000, loss_test=0.0030, acc_test=0.9985
# poison_percent 20 round 71: loss_train=2.8519, acc_train=0.8000, loss_test=0.0030, acc_test=0.9985
# poison_percent 20 round 72: loss_train=2.7230, acc_train=0.8000, loss_test=0.0030, acc_test=0.9985
# poison_percent 20 round 73: loss_train=2.8155, acc_train=0.8000, loss_test=0.0030, acc_test=0.9985
# poison_percent 20 round 74: loss_train=2.7062, acc_train=0.8000, loss_test=0.0030, acc_test=0.9985
# poison_percent 20 round 75: loss_train=2.5350, acc_train=0.8000, loss_test=0.0030, acc_test=0.9985
# poison_percent 20 round 76: loss_train=2.7531, acc_train=0.7920, loss_test=0.0029, acc_test=0.9985
# poison_percent 20 round 77: loss_train=2.5821, acc_train=0.8000, loss_test=0.0029, acc_test=0.9985
# poison_percent 20 round 78: loss_train=2.7660, acc_train=0.7840, loss_test=0.0029, acc_test=0.9985
# poison_percent 20 round 79: loss_train=2.6164, acc_train=0.8080, loss_test=0.0029, acc_test=0.9985
# poison_percent 20 round 80: loss_train=2.6923, acc_train=0.8000, loss_test=0.0028, acc_test=0.9985
# poison_percent 20 round 81: loss_train=2.7697, acc_train=0.7840, loss_test=0.0028, acc_test=0.9985
# poison_percent 20 round 82: loss_train=2.9224, acc_train=0.8000, loss_test=0.0028, acc_test=0.9985
# poison_percent 20 round 83: loss_train=2.7670, acc_train=0.8000, loss_test=0.0028, acc_test=0.9985
# poison_percent 20 round 84: loss_train=2.8173, acc_train=0.7920, loss_test=0.0028, acc_test=0.9985
# poison_percent 20 round 85: loss_train=2.5474, acc_train=0.8080, loss_test=0.0027, acc_test=0.9985
# poison_percent 20 round 86: loss_train=2.6976, acc_train=0.7920, loss_test=0.0027, acc_test=0.9985
# poison_percent 20 round 87: loss_train=2.7359, acc_train=0.8080, loss_test=0.0027, acc_test=0.9985
# poison_percent 20 round 88: loss_train=2.5901, acc_train=0.8000, loss_test=0.0027, acc_test=0.9985
# poison_percent 20 round 89: loss_train=2.8011, acc_train=0.8000, loss_test=0.0027, acc_test=0.9985
# poison_percent 20 round 90: loss_train=2.7789, acc_train=0.7920, loss_test=0.0026, acc_test=0.9985
# poison_percent 20 round 91: loss_train=2.9410, acc_train=0.8000, loss_test=0.0026, acc_test=0.9985
# poison_percent 20 round 92: loss_train=2.8920, acc_train=0.8000, loss_test=0.0026, acc_test=0.9985
# poison_percent 20 round 93: loss_train=2.9559, acc_train=0.8000, loss_test=0.0026, acc_test=0.9985
# poison_percent 20 round 94: loss_train=2.7998, acc_train=0.8000, loss_test=0.0025, acc_test=0.9985
# poison_percent 20 round 95: loss_train=2.9280, acc_train=0.8000, loss_test=0.0025, acc_test=0.9985
# poison_percent 20 round 96: loss_train=2.6836, acc_train=0.8000, loss_test=0.0025, acc_test=0.9985
# poison_percent 20 round 97: loss_train=2.7700, acc_train=0.8000, loss_test=0.0025, acc_test=0.9985
# poison_percent 20 round 98: loss_train=2.7112, acc_train=0.8000, loss_test=0.0025, acc_test=0.9985
# poison_percent 20 round 99: loss_train=2.9314, acc_train=0.7920, loss_test=0.0025, acc_test=0.9985
# Training log saved to ./results\FL_ModelN1L1_Batchsize1_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=0.3206, acc_train=0.9930, loss_test=0.5015, acc_test=0.9821
# poison_percent 30 round 1: loss_train=0.2771, acc_train=0.9930, loss_test=0.3597, acc_test=0.9969
# poison_percent 30 round 2: loss_train=0.2989, acc_train=0.8811, loss_test=0.2641, acc_test=0.9959
# poison_percent 30 round 3: loss_train=0.3109, acc_train=0.8392, loss_test=0.1981, acc_test=0.9954
# poison_percent 30 round 4: loss_train=0.3242, acc_train=0.8462, loss_test=0.1540, acc_test=0.9954
# poison_percent 30 round 5: loss_train=0.4015, acc_train=0.7762, loss_test=0.1216, acc_test=0.9959
# poison_percent 30 round 6: loss_train=0.4055, acc_train=0.7552, loss_test=0.0995, acc_test=0.9959
# poison_percent 30 round 7: loss_train=0.4978, acc_train=0.7133, loss_test=0.0824, acc_test=0.9959
# poison_percent 30 round 8: loss_train=0.5319, acc_train=0.7133, loss_test=0.0703, acc_test=0.9964
# poison_percent 30 round 9: loss_train=0.5877, acc_train=0.7203, loss_test=0.0601, acc_test=0.9969
# poison_percent 30 round 10: loss_train=0.5577, acc_train=0.7133, loss_test=0.0522, acc_test=0.9969
# poison_percent 30 round 11: loss_train=0.6123, acc_train=0.6993, loss_test=0.0461, acc_test=0.9969
# poison_percent 30 round 12: loss_train=0.7317, acc_train=0.7063, loss_test=0.0411, acc_test=0.9969
# poison_percent 30 round 13: loss_train=0.7106, acc_train=0.7203, loss_test=0.0369, acc_test=0.9969
# poison_percent 30 round 14: loss_train=0.8075, acc_train=0.6993, loss_test=0.0333, acc_test=0.9969
# poison_percent 30 round 15: loss_train=0.8543, acc_train=0.6993, loss_test=0.0302, acc_test=0.9969
# poison_percent 30 round 16: loss_train=0.8931, acc_train=0.7063, loss_test=0.0275, acc_test=0.9974
# poison_percent 30 round 17: loss_train=0.9367, acc_train=0.6923, loss_test=0.0253, acc_test=0.9974
# poison_percent 30 round 18: loss_train=0.9013, acc_train=0.6993, loss_test=0.0236, acc_test=0.9974
# poison_percent 30 round 19: loss_train=1.0326, acc_train=0.6923, loss_test=0.0219, acc_test=0.9974
# poison_percent 30 round 20: loss_train=1.0949, acc_train=0.7063, loss_test=0.0203, acc_test=0.9974
# poison_percent 30 round 21: loss_train=1.0916, acc_train=0.6923, loss_test=0.0190, acc_test=0.9980
# poison_percent 30 round 22: loss_train=1.1351, acc_train=0.6993, loss_test=0.0179, acc_test=0.9980
# poison_percent 30 round 23: loss_train=1.1256, acc_train=0.6993, loss_test=0.0168, acc_test=0.9980
# poison_percent 30 round 24: loss_train=1.1601, acc_train=0.6993, loss_test=0.0159, acc_test=0.9985
# poison_percent 30 round 25: loss_train=1.2526, acc_train=0.7063, loss_test=0.0151, acc_test=0.9985
# poison_percent 30 round 26: loss_train=1.2548, acc_train=0.7063, loss_test=0.0143, acc_test=0.9990
# poison_percent 30 round 27: loss_train=1.2432, acc_train=0.7063, loss_test=0.0137, acc_test=0.9990
# poison_percent 30 round 28: loss_train=1.2488, acc_train=0.7063, loss_test=0.0130, acc_test=0.9990
# poison_percent 30 round 29: loss_train=1.3877, acc_train=0.6993, loss_test=0.0123, acc_test=0.9990
# poison_percent 30 round 30: loss_train=1.2980, acc_train=0.6993, loss_test=0.0118, acc_test=0.9990
# poison_percent 30 round 31: loss_train=1.4088, acc_train=0.6993, loss_test=0.0114, acc_test=0.9990
# poison_percent 30 round 32: loss_train=1.2862, acc_train=0.6993, loss_test=0.0110, acc_test=0.9990
# poison_percent 30 round 33: loss_train=1.5185, acc_train=0.6993, loss_test=0.0105, acc_test=0.9990
# poison_percent 30 round 34: loss_train=1.5249, acc_train=0.7063, loss_test=0.0101, acc_test=0.9990
# poison_percent 30 round 35: loss_train=1.5628, acc_train=0.6993, loss_test=0.0097, acc_test=0.9990
# poison_percent 30 round 36: loss_train=1.4779, acc_train=0.6993, loss_test=0.0094, acc_test=0.9990
# poison_percent 30 round 37: loss_train=1.5649, acc_train=0.6993, loss_test=0.0090, acc_test=0.9990
# poison_percent 30 round 38: loss_train=1.7014, acc_train=0.6923, loss_test=0.0087, acc_test=0.9990
# poison_percent 30 round 39: loss_train=1.5580, acc_train=0.6993, loss_test=0.0086, acc_test=0.9990
# poison_percent 30 round 40: loss_train=1.6715, acc_train=0.6923, loss_test=0.0082, acc_test=0.9990
# poison_percent 30 round 41: loss_train=1.6311, acc_train=0.6923, loss_test=0.0079, acc_test=0.9990
# poison_percent 30 round 42: loss_train=1.6417, acc_train=0.6993, loss_test=0.0076, acc_test=0.9990
# poison_percent 30 round 43: loss_train=1.6112, acc_train=0.6993, loss_test=0.0074, acc_test=0.9990
# poison_percent 30 round 44: loss_train=1.7291, acc_train=0.6993, loss_test=0.0072, acc_test=0.9990
# poison_percent 30 round 45: loss_train=1.7306, acc_train=0.6923, loss_test=0.0070, acc_test=0.9990
# poison_percent 30 round 46: loss_train=1.6216, acc_train=0.6993, loss_test=0.0069, acc_test=0.9990
# poison_percent 30 round 47: loss_train=1.5837, acc_train=0.6993, loss_test=0.0067, acc_test=0.9990
# poison_percent 30 round 48: loss_train=1.6100, acc_train=0.7063, loss_test=0.0065, acc_test=0.9990
# poison_percent 30 round 49: loss_train=1.7315, acc_train=0.6993, loss_test=0.0064, acc_test=0.9990
# poison_percent 30 round 50: loss_train=1.9121, acc_train=0.6993, loss_test=0.0062, acc_test=0.9990
# poison_percent 30 round 51: loss_train=1.6741, acc_train=0.6993, loss_test=0.0061, acc_test=0.9990
# poison_percent 30 round 52: loss_train=1.8897, acc_train=0.6923, loss_test=0.0060, acc_test=0.9990
# poison_percent 30 round 53: loss_train=1.7388, acc_train=0.6993, loss_test=0.0058, acc_test=0.9990
# poison_percent 30 round 54: loss_train=1.8932, acc_train=0.6923, loss_test=0.0058, acc_test=0.9990
# poison_percent 30 round 55: loss_train=1.9572, acc_train=0.6923, loss_test=0.0057, acc_test=0.9990
# poison_percent 30 round 56: loss_train=1.8865, acc_train=0.6993, loss_test=0.0055, acc_test=0.9990
# poison_percent 30 round 57: loss_train=1.9556, acc_train=0.6993, loss_test=0.0054, acc_test=0.9990
# poison_percent 30 round 58: loss_train=1.7880, acc_train=0.6993, loss_test=0.0053, acc_test=0.9990
# poison_percent 30 round 59: loss_train=1.9961, acc_train=0.6993, loss_test=0.0052, acc_test=0.9990
# poison_percent 30 round 60: loss_train=1.9301, acc_train=0.6993, loss_test=0.0051, acc_test=0.9990
# poison_percent 30 round 61: loss_train=1.9740, acc_train=0.6993, loss_test=0.0050, acc_test=0.9990
# poison_percent 30 round 62: loss_train=2.0283, acc_train=0.6993, loss_test=0.0049, acc_test=0.9990
# poison_percent 30 round 63: loss_train=1.9880, acc_train=0.6853, loss_test=0.0048, acc_test=0.9990
# poison_percent 30 round 64: loss_train=1.8875, acc_train=0.6993, loss_test=0.0047, acc_test=0.9990
# poison_percent 30 round 65: loss_train=2.1966, acc_train=0.6993, loss_test=0.0046, acc_test=0.9990
# poison_percent 30 round 66: loss_train=1.9461, acc_train=0.6993, loss_test=0.0045, acc_test=0.9990
# poison_percent 30 round 67: loss_train=1.9738, acc_train=0.7063, loss_test=0.0045, acc_test=0.9990
# poison_percent 30 round 68: loss_train=2.1313, acc_train=0.7063, loss_test=0.0044, acc_test=0.9990
# poison_percent 30 round 69: loss_train=1.9899, acc_train=0.7063, loss_test=0.0044, acc_test=0.9990
# poison_percent 30 round 70: loss_train=1.9770, acc_train=0.6993, loss_test=0.0043, acc_test=0.9990
# poison_percent 30 round 71: loss_train=2.1681, acc_train=0.6993, loss_test=0.0042, acc_test=0.9990
# poison_percent 30 round 72: loss_train=2.1581, acc_train=0.6993, loss_test=0.0042, acc_test=0.9990
# poison_percent 30 round 73: loss_train=2.0398, acc_train=0.6993, loss_test=0.0041, acc_test=0.9990
# poison_percent 30 round 74: loss_train=2.1833, acc_train=0.6993, loss_test=0.0041, acc_test=0.9990
# poison_percent 30 round 75: loss_train=1.9326, acc_train=0.6993, loss_test=0.0040, acc_test=0.9990
# poison_percent 30 round 76: loss_train=2.0606, acc_train=0.7063, loss_test=0.0040, acc_test=0.9990
# poison_percent 30 round 77: loss_train=2.1966, acc_train=0.6993, loss_test=0.0039, acc_test=0.9990
# poison_percent 30 round 78: loss_train=2.2228, acc_train=0.6993, loss_test=0.0039, acc_test=0.9990
# poison_percent 30 round 79: loss_train=2.0911, acc_train=0.6923, loss_test=0.0038, acc_test=0.9990
# poison_percent 30 round 80: loss_train=2.2770, acc_train=0.6993, loss_test=0.0038, acc_test=0.9990
# poison_percent 30 round 81: loss_train=2.2284, acc_train=0.6993, loss_test=0.0037, acc_test=0.9990
# poison_percent 30 round 82: loss_train=2.0039, acc_train=0.6993, loss_test=0.0037, acc_test=0.9990
# poison_percent 30 round 83: loss_train=2.2207, acc_train=0.6993, loss_test=0.0036, acc_test=0.9990
# poison_percent 30 round 84: loss_train=2.1000, acc_train=0.6993, loss_test=0.0036, acc_test=0.9990
# poison_percent 30 round 85: loss_train=2.4191, acc_train=0.6993, loss_test=0.0035, acc_test=0.9990
# poison_percent 30 round 86: loss_train=2.1313, acc_train=0.6993, loss_test=0.0035, acc_test=0.9990
# poison_percent 30 round 87: loss_train=2.3786, acc_train=0.6923, loss_test=0.0034, acc_test=0.9990
# poison_percent 30 round 88: loss_train=2.3141, acc_train=0.7063, loss_test=0.0034, acc_test=0.9990
# poison_percent 30 round 89: loss_train=2.3324, acc_train=0.6993, loss_test=0.0034, acc_test=0.9990
# poison_percent 30 round 90: loss_train=2.3400, acc_train=0.6993, loss_test=0.0033, acc_test=0.9990
# poison_percent 30 round 91: loss_train=2.4944, acc_train=0.6993, loss_test=0.0033, acc_test=0.9990
# poison_percent 30 round 92: loss_train=2.7871, acc_train=0.6993, loss_test=0.0033, acc_test=0.9990
# poison_percent 30 round 93: loss_train=2.4241, acc_train=0.6923, loss_test=0.0032, acc_test=0.9990
# poison_percent 30 round 94: loss_train=2.5703, acc_train=0.6993, loss_test=0.0032, acc_test=0.9990
# poison_percent 30 round 95: loss_train=2.2685, acc_train=0.6993, loss_test=0.0032, acc_test=0.9990
# poison_percent 30 round 96: loss_train=2.4457, acc_train=0.6853, loss_test=0.0032, acc_test=0.9990
# poison_percent 30 round 97: loss_train=2.3098, acc_train=0.6993, loss_test=0.0031, acc_test=0.9990
# poison_percent 30 round 98: loss_train=2.3619, acc_train=0.6993, loss_test=0.0031, acc_test=0.9990
# poison_percent 30 round 99: loss_train=2.5526, acc_train=0.6993, loss_test=0.0031, acc_test=0.9990
# Training log saved to ./results\FL_ModelN1L1_Batchsize1_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=0.3107, acc_train=0.9521, loss_test=0.5989, acc_test=0.9352
# poison_percent 40 round 1: loss_train=0.3017, acc_train=0.9760, loss_test=0.5075, acc_test=0.9903
# poison_percent 40 round 2: loss_train=0.2999, acc_train=0.9880, loss_test=0.4354, acc_test=0.9929
# poison_percent 40 round 3: loss_train=0.3095, acc_train=0.9461, loss_test=0.3782, acc_test=0.9959
# poison_percent 40 round 4: loss_train=0.3271, acc_train=0.8084, loss_test=0.3326, acc_test=0.9954
# poison_percent 40 round 5: loss_train=0.3297, acc_train=0.8024, loss_test=0.2946, acc_test=0.9949
# poison_percent 40 round 6: loss_train=0.3539, acc_train=0.7784, loss_test=0.2634, acc_test=0.9954
# poison_percent 40 round 7: loss_train=0.3733, acc_train=0.7904, loss_test=0.2372, acc_test=0.9954
# poison_percent 40 round 8: loss_train=0.3991, acc_train=0.7904, loss_test=0.2153, acc_test=0.9954
# poison_percent 40 round 9: loss_train=0.4424, acc_train=0.7425, loss_test=0.1974, acc_test=0.9964
# poison_percent 40 round 10: loss_train=0.4546, acc_train=0.7485, loss_test=0.1828, acc_test=0.9964
# poison_percent 40 round 11: loss_train=0.4489, acc_train=0.7725, loss_test=0.1696, acc_test=0.9964
# poison_percent 40 round 12: loss_train=0.4741, acc_train=0.7605, loss_test=0.1583, acc_test=0.9964
# poison_percent 40 round 13: loss_train=0.4948, acc_train=0.7485, loss_test=0.1491, acc_test=0.9969
# poison_percent 40 round 14: loss_train=0.4874, acc_train=0.7485, loss_test=0.1399, acc_test=0.9969
# poison_percent 40 round 15: loss_train=0.5158, acc_train=0.7485, loss_test=0.1326, acc_test=0.9974
# poison_percent 40 round 16: loss_train=0.4650, acc_train=0.7485, loss_test=0.1250, acc_test=0.9974
# poison_percent 40 round 17: loss_train=0.5575, acc_train=0.7186, loss_test=0.1192, acc_test=0.9974
# poison_percent 40 round 18: loss_train=0.5310, acc_train=0.7246, loss_test=0.1137, acc_test=0.9974
# poison_percent 40 round 19: loss_train=0.5725, acc_train=0.7246, loss_test=0.1088, acc_test=0.9974
# poison_percent 40 round 20: loss_train=0.5816, acc_train=0.7006, loss_test=0.1047, acc_test=0.9974
# poison_percent 40 round 21: loss_train=0.5527, acc_train=0.6647, loss_test=0.1001, acc_test=0.9980
# poison_percent 40 round 22: loss_train=0.6185, acc_train=0.6647, loss_test=0.0970, acc_test=0.9985
# poison_percent 40 round 23: loss_train=0.6166, acc_train=0.6647, loss_test=0.0938, acc_test=0.9985
# poison_percent 40 round 24: loss_train=0.5609, acc_train=0.6647, loss_test=0.0904, acc_test=0.9985
# poison_percent 40 round 25: loss_train=0.6159, acc_train=0.6647, loss_test=0.0873, acc_test=0.9985
# poison_percent 40 round 26: loss_train=0.6641, acc_train=0.6467, loss_test=0.0846, acc_test=0.9990
# poison_percent 40 round 27: loss_train=0.6918, acc_train=0.6527, loss_test=0.0828, acc_test=0.9990
# poison_percent 40 round 28: loss_train=0.6938, acc_train=0.6647, loss_test=0.0803, acc_test=0.9990
# poison_percent 40 round 29: loss_train=0.7521, acc_train=0.6287, loss_test=0.0784, acc_test=0.9990
# poison_percent 40 round 30: loss_train=0.6342, acc_train=0.6647, loss_test=0.0761, acc_test=0.9990
# poison_percent 40 round 31: loss_train=0.8080, acc_train=0.6168, loss_test=0.0749, acc_test=0.9990
# poison_percent 40 round 32: loss_train=0.7249, acc_train=0.6467, loss_test=0.0729, acc_test=0.9990
# poison_percent 40 round 33: loss_train=0.6673, acc_train=0.6287, loss_test=0.0709, acc_test=0.9990
# poison_percent 40 round 34: loss_train=0.8023, acc_train=0.6108, loss_test=0.0696, acc_test=0.9990
# poison_percent 40 round 35: loss_train=0.6723, acc_train=0.6347, loss_test=0.0686, acc_test=0.9990
# poison_percent 40 round 36: loss_train=0.7430, acc_train=0.6347, loss_test=0.0673, acc_test=0.9990
# poison_percent 40 round 37: loss_train=0.7516, acc_train=0.6347, loss_test=0.0661, acc_test=0.9990
# poison_percent 40 round 38: loss_train=0.7525, acc_train=0.6347, loss_test=0.0652, acc_test=0.9990
# poison_percent 40 round 39: loss_train=0.7496, acc_train=0.6168, loss_test=0.0639, acc_test=0.9990
# poison_percent 40 round 40: loss_train=0.7251, acc_train=0.6347, loss_test=0.0625, acc_test=0.9990
# poison_percent 40 round 41: loss_train=0.8183, acc_train=0.6287, loss_test=0.0621, acc_test=0.9990
# poison_percent 40 round 42: loss_train=0.7513, acc_train=0.6168, loss_test=0.0613, acc_test=0.9990
# poison_percent 40 round 43: loss_train=0.8192, acc_train=0.6527, loss_test=0.0600, acc_test=0.9990
# poison_percent 40 round 44: loss_train=0.8077, acc_train=0.6347, loss_test=0.0596, acc_test=0.9990
# poison_percent 40 round 45: loss_train=0.8591, acc_train=0.6168, loss_test=0.0592, acc_test=0.9990
# poison_percent 40 round 46: loss_train=0.7592, acc_train=0.6228, loss_test=0.0581, acc_test=0.9990
# poison_percent 40 round 47: loss_train=0.7686, acc_train=0.6108, loss_test=0.0577, acc_test=0.9990
# poison_percent 40 round 48: loss_train=0.7533, acc_train=0.6347, loss_test=0.0570, acc_test=0.9990
# poison_percent 40 round 49: loss_train=0.7743, acc_train=0.6347, loss_test=0.0561, acc_test=0.9990
# poison_percent 40 round 50: loss_train=0.7988, acc_train=0.6287, loss_test=0.0549, acc_test=0.9995
# poison_percent 40 round 51: loss_train=0.6980, acc_train=0.6347, loss_test=0.0542, acc_test=0.9995
# poison_percent 40 round 52: loss_train=0.8870, acc_train=0.6228, loss_test=0.0539, acc_test=0.9995
# poison_percent 40 round 53: loss_train=0.8051, acc_train=0.6168, loss_test=0.0529, acc_test=0.9995
# poison_percent 40 round 54: loss_train=0.7876, acc_train=0.6228, loss_test=0.0525, acc_test=0.9995
# poison_percent 40 round 55: loss_train=0.9052, acc_train=0.6287, loss_test=0.0516, acc_test=0.9995
# poison_percent 40 round 56: loss_train=0.8488, acc_train=0.5988, loss_test=0.0509, acc_test=0.9995
# poison_percent 40 round 57: loss_train=0.9220, acc_train=0.6108, loss_test=0.0501, acc_test=0.9995
# poison_percent 40 round 58: loss_train=0.8458, acc_train=0.6168, loss_test=0.0497, acc_test=0.9995
# poison_percent 40 round 59: loss_train=0.8658, acc_train=0.6108, loss_test=0.0494, acc_test=0.9995
# poison_percent 40 round 60: loss_train=0.8076, acc_train=0.6228, loss_test=0.0488, acc_test=0.9995
# poison_percent 40 round 61: loss_train=0.7861, acc_train=0.6048, loss_test=0.0484, acc_test=0.9995
# poison_percent 40 round 62: loss_train=0.8236, acc_train=0.6108, loss_test=0.0480, acc_test=0.9995
# poison_percent 40 round 63: loss_train=0.8741, acc_train=0.6168, loss_test=0.0475, acc_test=0.9995
# poison_percent 40 round 64: loss_train=0.8141, acc_train=0.6108, loss_test=0.0472, acc_test=0.9995
# poison_percent 40 round 65: loss_train=0.8411, acc_train=0.6108, loss_test=0.0470, acc_test=0.9995
# poison_percent 40 round 66: loss_train=0.8787, acc_train=0.6228, loss_test=0.0468, acc_test=0.9995
# poison_percent 40 round 67: loss_train=0.9523, acc_train=0.6287, loss_test=0.0461, acc_test=0.9995
# poison_percent 40 round 68: loss_train=0.9911, acc_train=0.6048, loss_test=0.0457, acc_test=0.9995
# poison_percent 40 round 69: loss_train=1.0474, acc_train=0.6048, loss_test=0.0454, acc_test=0.9995
# poison_percent 40 round 70: loss_train=0.9288, acc_train=0.6168, loss_test=0.0452, acc_test=0.9995
# poison_percent 40 round 71: loss_train=0.8347, acc_train=0.6347, loss_test=0.0449, acc_test=0.9995
# poison_percent 40 round 72: loss_train=0.8524, acc_train=0.6108, loss_test=0.0450, acc_test=0.9995
# poison_percent 40 round 73: loss_train=0.8963, acc_train=0.6347, loss_test=0.0448, acc_test=0.9995
# poison_percent 40 round 74: loss_train=0.8723, acc_train=0.6228, loss_test=0.0445, acc_test=0.9995
# poison_percent 40 round 75: loss_train=0.8594, acc_train=0.6108, loss_test=0.0441, acc_test=0.9995
# poison_percent 40 round 76: loss_train=0.9017, acc_train=0.6228, loss_test=0.0440, acc_test=0.9995
# poison_percent 40 round 77: loss_train=0.9382, acc_train=0.6168, loss_test=0.0437, acc_test=0.9995
# poison_percent 40 round 78: loss_train=1.0247, acc_train=0.6168, loss_test=0.0439, acc_test=0.9995
# poison_percent 40 round 79: loss_train=0.8672, acc_train=0.6228, loss_test=0.0432, acc_test=0.9995
# poison_percent 40 round 80: loss_train=0.9747, acc_train=0.6168, loss_test=0.0433, acc_test=0.9995
# poison_percent 40 round 81: loss_train=0.8723, acc_train=0.6168, loss_test=0.0429, acc_test=0.9995
# ...
# poison_percent 40 round 41: loss_train=0.7687, acc_train=0.6347, loss_test=0.0587, acc_test=0.9990
# poison_percent 40 round 42: loss_train=0.6948, acc_train=0.6228, loss_test=0.0581, acc_test=0.9990
# poison_percent 40 round 43: loss_train=0.8102, acc_train=0.6168, loss_test=0.0574, acc_test=0.9990
# poison_percent 40 round 44: loss_train=0.8308, acc_train=0.6347, loss_test=0.0563, acc_test=0.9990
# poison_percent 40 round 45: loss_train=0.7445, acc_train=0.6228, loss_test=0.0559, acc_test=0.9990
# poison_percent 40 round 46: loss_train=0.8690, acc_train=0.6347, loss_test=0.0559, acc_test=0.9990
# poison_percent 40 round 47: loss_train=0.7658, acc_train=0.6287, loss_test=0.0551, acc_test=0.9990
# poison_percent 40 round 48: loss_train=0.8206, acc_train=0.6168, loss_test=0.0550, acc_test=0.9990
# poison_percent 40 round 49: loss_train=0.8754, acc_train=0.6048, loss_test=0.0536, acc_test=0.9990
# poison_percent 40 round 50: loss_train=0.8069, acc_train=0.6228, loss_test=0.0531, acc_test=0.9995
# poison_percent 40 round 51: loss_train=0.7572, acc_train=0.6467, loss_test=0.0528, acc_test=0.9995
# poison_percent 40 round 52: loss_train=0.7760, acc_train=0.6287, loss_test=0.0524, acc_test=0.9995
# poison_percent 40 round 53: loss_train=0.8444, acc_train=0.6108, loss_test=0.0519, acc_test=0.9995
# poison_percent 40 round 54: loss_train=0.9172, acc_train=0.6108, loss_test=0.0513, acc_test=0.9995
# poison_percent 40 round 55: loss_train=0.9138, acc_train=0.6228, loss_test=0.0510, acc_test=0.9995
# poison_percent 40 round 56: loss_train=0.9153, acc_train=0.6108, loss_test=0.0497, acc_test=0.9995
# poison_percent 40 round 57: loss_train=0.9639, acc_train=0.5988, loss_test=0.0492, acc_test=0.9995
# poison_percent 40 round 58: loss_train=0.8518, acc_train=0.6108, loss_test=0.0491, acc_test=0.9995
# poison_percent 40 round 59: loss_train=0.8493, acc_train=0.6108, loss_test=0.0483, acc_test=0.9995
# poison_percent 40 round 60: loss_train=0.8893, acc_train=0.6228, loss_test=0.0480, acc_test=0.9995
# poison_percent 40 round 61: loss_train=0.9888, acc_train=0.6108, loss_test=0.0475, acc_test=0.9995
# poison_percent 40 round 62: loss_train=0.9049, acc_train=0.6048, loss_test=0.0473, acc_test=0.9995
# poison_percent 40 round 63: loss_train=0.8822, acc_train=0.6168, loss_test=0.0466, acc_test=0.9995
# poison_percent 40 round 64: loss_train=0.8462, acc_train=0.6108, loss_test=0.0462, acc_test=0.9995
# poison_percent 40 round 65: loss_train=0.8630, acc_train=0.6168, loss_test=0.0460, acc_test=0.9995
# poison_percent 40 round 66: loss_train=0.8330, acc_train=0.6048, loss_test=0.0456, acc_test=0.9995
# poison_percent 40 round 67: loss_train=0.9069, acc_train=0.6168, loss_test=0.0455, acc_test=0.9995
# poison_percent 40 round 68: loss_train=0.8691, acc_train=0.6287, loss_test=0.0452, acc_test=0.9995
# poison_percent 40 round 69: loss_train=0.8305, acc_train=0.6228, loss_test=0.0448, acc_test=0.9995
# poison_percent 40 round 70: loss_train=0.9648, acc_train=0.6228, loss_test=0.0446, acc_test=0.9995
# poison_percent 40 round 71: loss_train=0.8497, acc_train=0.6228, loss_test=0.0443, acc_test=0.9995
# poison_percent 40 round 72: loss_train=0.8659, acc_train=0.6287, loss_test=0.0440, acc_test=0.9995
# poison_percent 40 round 73: loss_train=0.8640, acc_train=0.6407, loss_test=0.0436, acc_test=0.9995
# poison_percent 40 round 74: loss_train=0.8270, acc_train=0.6587, loss_test=0.0432, acc_test=0.9995
# poison_percent 40 round 75: loss_train=0.9868, acc_train=0.6168, loss_test=0.0432, acc_test=0.9995
# poison_percent 40 round 76: loss_train=1.0225, acc_train=0.6228, loss_test=0.0434, acc_test=0.9995
# poison_percent 40 round 77: loss_train=0.9006, acc_train=0.6108, loss_test=0.0434, acc_test=0.9995
# poison_percent 40 round 78: loss_train=0.8727, acc_train=0.6168, loss_test=0.0431, acc_test=0.9995
# poison_percent 40 round 79: loss_train=0.9380, acc_train=0.6168, loss_test=0.0428, acc_test=0.9995
# poison_percent 40 round 80: loss_train=0.8610, acc_train=0.6228, loss_test=0.0423, acc_test=0.9995
# poison_percent 40 round 81: loss_train=0.9515, acc_train=0.6228, loss_test=0.0423, acc_test=0.9995
# poison_percent 40 round 82: loss_train=1.0057, acc_train=0.6108, loss_test=0.0425, acc_test=0.9995
# poison_percent 40 round 83: loss_train=0.8412, acc_train=0.6228, loss_test=0.0424, acc_test=0.9995
# poison_percent 40 round 84: loss_train=0.9895, acc_train=0.6108, loss_test=0.0422, acc_test=0.9995
# poison_percent 40 round 85: loss_train=0.8924, acc_train=0.6168, loss_test=0.0418, acc_test=0.9995
# poison_percent 40 round 86: loss_train=0.9152, acc_train=0.6108, loss_test=0.0414, acc_test=0.9995
# poison_percent 40 round 87: loss_train=0.9294, acc_train=0.6287, loss_test=0.0415, acc_test=0.9995
# poison_percent 40 round 88: loss_train=0.8643, acc_train=0.6467, loss_test=0.0418, acc_test=0.9995
# poison_percent 40 round 89: loss_train=0.8732, acc_train=0.6287, loss_test=0.0415, acc_test=0.9995
# poison_percent 40 round 90: loss_train=0.9893, acc_train=0.6108, loss_test=0.0415, acc_test=0.9995
# poison_percent 40 round 91: loss_train=0.8815, acc_train=0.6347, loss_test=0.0414, acc_test=0.9995
# poison_percent 40 round 92: loss_train=0.9626, acc_train=0.6467, loss_test=0.0414, acc_test=0.9995
# poison_percent 40 round 93: loss_train=0.9891, acc_train=0.6168, loss_test=0.0417, acc_test=0.9995
# poison_percent 40 round 94: loss_train=0.8881, acc_train=0.6287, loss_test=0.0416, acc_test=0.9990
# poison_percent 40 round 95: loss_train=0.9654, acc_train=0.6168, loss_test=0.0419, acc_test=0.9990
# poison_percent 40 round 96: loss_train=0.9259, acc_train=0.6467, loss_test=0.0420, acc_test=0.9990
# poison_percent 40 round 97: loss_train=1.0699, acc_train=0.6168, loss_test=0.0421, acc_test=0.9990
# poison_percent 40 round 98: loss_train=1.0020, acc_train=0.6168, loss_test=0.0420, acc_test=0.9990
# poison_percent 40 round 99: loss_train=0.9214, acc_train=0.6228, loss_test=0.0416, acc_test=0.9985
# Training log saved to ./results\FL_ModelN1L1_Batchsize1_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 round 0: loss_train=0.2986, acc_train=0.9950, loss_test=0.6876, acc_test=0.5638
# poison_percent 50 round 1: loss_train=0.2927, acc_train=0.9800, loss_test=0.6892, acc_test=0.5577
# poison_percent 50 round 2: loss_train=0.3208, acc_train=0.9650, loss_test=0.6889, acc_test=0.5571
# poison_percent 50 round 3: loss_train=0.3301, acc_train=0.9900, loss_test=0.6884, acc_test=0.5694
# poison_percent 50 round 4: loss_train=0.2959, acc_train=0.9900, loss_test=0.6881, acc_test=0.5816
# poison_percent 50 round 5: loss_train=0.2948, acc_train=0.9750, loss_test=0.6884, acc_test=0.5821
# poison_percent 50 round 6: loss_train=0.2925, acc_train=0.9850, loss_test=0.6868, acc_test=0.5878
# poison_percent 50 round 7: loss_train=0.3128, acc_train=0.9750, loss_test=0.6865, acc_test=0.5918
# poison_percent 50 round 8: loss_train=0.3135, acc_train=0.9750, loss_test=0.6858, acc_test=0.5954
# poison_percent 50 round 9: loss_train=0.3097, acc_train=0.9800, loss_test=0.6855, acc_test=0.5980
# poison_percent 50 round 10: loss_train=0.2982, acc_train=0.9900, loss_test=0.6850, acc_test=0.6020
# poison_percent 50 round 11: loss_train=0.3068, acc_train=0.9850, loss_test=0.6845, acc_test=0.6117
# poison_percent 50 round 12: loss_train=0.3175, acc_train=0.9800, loss_test=0.6826, acc_test=0.6209
# poison_percent 50 round 13: loss_train=0.3250, acc_train=0.9700, loss_test=0.6823, acc_test=0.6311
# poison_percent 50 round 14: loss_train=0.3023, acc_train=0.9900, loss_test=0.6828, acc_test=0.6286
# poison_percent 50 round 15: loss_train=0.2995, acc_train=0.9950, loss_test=0.6818, acc_test=0.6337
# poison_percent 50 round 16: loss_train=0.2976, acc_train=0.9850, loss_test=0.6813, acc_test=0.6378
# poison_percent 50 round 17: loss_train=0.2844, acc_train=0.9900, loss_test=0.6818, acc_test=0.6367
# poison_percent 50 round 18: loss_train=0.3049, acc_train=0.9950, loss_test=0.6825, acc_test=0.6327
# poison_percent 50 round 19: loss_train=0.3127, acc_train=0.9800, loss_test=0.6817, acc_test=0.6383
# poison_percent 50 round 20: loss_train=0.3040, acc_train=0.9900, loss_test=0.6811, acc_test=0.6434
# poison_percent 50 round 21: loss_train=0.3281, acc_train=0.9750, loss_test=0.6821, acc_test=0.6378
# poison_percent 50 round 22: loss_train=0.2768, acc_train=0.9850, loss_test=0.6802, acc_test=0.6515
# poison_percent 50 round 23: loss_train=0.2821, acc_train=0.9950, loss_test=0.6796, acc_test=0.6561
# poison_percent 50 round 24: loss_train=0.3100, acc_train=0.9800, loss_test=0.6785, acc_test=0.6587
# poison_percent 50 round 25: loss_train=0.3126, acc_train=0.9900, loss_test=0.6781, acc_test=0.6582
# poison_percent 50 round 26: loss_train=0.2877, acc_train=0.9900, loss_test=0.6782, acc_test=0.6622
# poison_percent 50 round 27: loss_train=0.2983, acc_train=0.9950, loss_test=0.6785, acc_test=0.6551
# poison_percent 50 round 28: loss_train=0.2958, acc_train=0.9950, loss_test=0.6763, acc_test=0.6653
# poison_percent 50 round 29: loss_train=0.3016, acc_train=0.9750, loss_test=0.6781, acc_test=0.6571
# poison_percent 50 round 30: loss_train=0.2982, acc_train=0.9900, loss_test=0.6780, acc_test=0.6566
# poison_percent 50 round 31: loss_train=0.3094, acc_train=0.9950, loss_test=0.6785, acc_test=0.6526
# poison_percent 50 round 32: loss_train=0.3087, acc_train=0.9900, loss_test=0.6799, acc_test=0.6439
# poison_percent 50 round 33: loss_train=0.2892, acc_train=1.0000, loss_test=0.6797, acc_test=0.6413
# poison_percent 50 round 34: loss_train=0.3023, acc_train=0.9900, loss_test=0.6795, acc_test=0.6378
# poison_percent 50 round 35: loss_train=0.3091, acc_train=0.9900, loss_test=0.6816, acc_test=0.6260
# poison_percent 50 round 36: loss_train=0.2972, acc_train=0.9950, loss_test=0.6815, acc_test=0.6291
# poison_percent 50 round 37: loss_train=0.2967, acc_train=0.9800, loss_test=0.6815, acc_test=0.6276
# poison_percent 50 round 38: loss_train=0.2960, acc_train=1.0000, loss_test=0.6816, acc_test=0.6276
# poison_percent 50 round 39: loss_train=0.2984, acc_train=0.9900, loss_test=0.6816, acc_test=0.6260
# poison_percent 50 round 40: loss_train=0.3165, acc_train=1.0000, loss_test=0.6852, acc_test=0.6061
# poison_percent 50 round 41: loss_train=0.2888, acc_train=1.0000, loss_test=0.6861, acc_test=0.6020
# poison_percent 50 round 42: loss_train=0.3052, acc_train=0.9900, loss_test=0.6844, acc_test=0.6112
# poison_percent 50 round 43: loss_train=0.3113, acc_train=0.9850, loss_test=0.6840, acc_test=0.6153
# poison_percent 50 round 44: loss_train=0.2983, acc_train=0.9900, loss_test=0.6846, acc_test=0.6102
# poison_percent 50 round 45: loss_train=0.3082, acc_train=0.9900, loss_test=0.6831, acc_test=0.6179
# poison_percent 50 round 46: loss_train=0.2828, acc_train=0.9950, loss_test=0.6834, acc_test=0.6097
# poison_percent 50 round 47: loss_train=0.2913, acc_train=0.9850, loss_test=0.6830, acc_test=0.6148
# poison_percent 50 round 48: loss_train=0.2927, acc_train=0.9900, loss_test=0.6835, acc_test=0.6097
# poison_percent 50 round 49: loss_train=0.3046, acc_train=0.9900, loss_test=0.6845, acc_test=0.6036
# poison_percent 50 round 50: loss_train=0.2952, acc_train=0.9950, loss_test=0.6827, acc_test=0.6122
# poison_percent 50 round 51: loss_train=0.3115, acc_train=0.9800, loss_test=0.6850, acc_test=0.6031
# poison_percent 50 round 52: loss_train=0.3170, acc_train=0.9650, loss_test=0.6844, acc_test=0.6061
# poison_percent 50 round 53: loss_train=0.2998, acc_train=0.9850, loss_test=0.6834, acc_test=0.6087
# poison_percent 50 round 54: loss_train=0.3132, acc_train=0.9950, loss_test=0.6846, acc_test=0.6015
# poison_percent 50 round 55: loss_train=0.3017, acc_train=0.9900, loss_test=0.6813, acc_test=0.6153
# poison_percent 50 round 56: loss_train=0.2932, acc_train=0.9800, loss_test=0.6809, acc_test=0.6173
# poison_percent 50 round 57: loss_train=0.3091, acc_train=0.9800, loss_test=0.6813, acc_test=0.6148
# poison_percent 50 round 58: loss_train=0.2939, acc_train=0.9900, loss_test=0.6812, acc_test=0.6102
# poison_percent 50 round 59: loss_train=0.3117, acc_train=0.9850, loss_test=0.6814, acc_test=0.6168
# poison_percent 50 round 60: loss_train=0.3111, acc_train=0.9800, loss_test=0.6826, acc_test=0.6087
# poison_percent 50 round 61: loss_train=0.3020, acc_train=0.9800, loss_test=0.6814, acc_test=0.6133
# poison_percent 50 round 62: loss_train=0.2900, acc_train=0.9900, loss_test=0.6825, acc_test=0.6112
# poison_percent 50 round 63: loss_train=0.2913, acc_train=1.0000, loss_test=0.6837, acc_test=0.6112
# poison_percent 50 round 64: loss_train=0.2907, acc_train=0.9850, loss_test=0.6808, acc_test=0.6173
# poison_percent 50 round 65: loss_train=0.2917, acc_train=0.9900, loss_test=0.6824, acc_test=0.6087
# poison_percent 50 round 66: loss_train=0.2985, acc_train=0.9900, loss_test=0.6848, acc_test=0.6031
# poison_percent 50 round 67: loss_train=0.2973, acc_train=0.9950, loss_test=0.6844, acc_test=0.6010
# poison_percent 50 round 68: loss_train=0.3049, acc_train=0.9800, loss_test=0.6861, acc_test=0.5969
# poison_percent 50 round 69: loss_train=0.2877, acc_train=1.0000, loss_test=0.6870, acc_test=0.5898
# poison_percent 50 round 70: loss_train=0.3023, acc_train=0.9800, loss_test=0.6868, acc_test=0.5883
# poison_percent 50 round 71: loss_train=0.2931, acc_train=0.9750, loss_test=0.6865, acc_test=0.5842
# poison_percent 50 round 72: loss_train=0.3304, acc_train=0.9800, loss_test=0.6871, acc_test=0.5878
# poison_percent 50 round 73: loss_train=0.2875, acc_train=0.9800, loss_test=0.6881, acc_test=0.5816
# poison_percent 50 round 74: loss_train=0.3220, acc_train=0.9850, loss_test=0.6893, acc_test=0.5770
# poison_percent 50 round 75: loss_train=0.2965, acc_train=0.9800, loss_test=0.6877, acc_test=0.5821
# poison_percent 50 round 76: loss_train=0.3101, acc_train=0.9800, loss_test=0.6894, acc_test=0.5750
# poison_percent 50 round 77: loss_train=0.2893, acc_train=0.9950, loss_test=0.6899, acc_test=0.5709
# poison_percent 50 round 78: loss_train=0.3090, acc_train=1.0000, loss_test=0.6875, acc_test=0.5821
# poison_percent 50 round 79: loss_train=0.3106, acc_train=0.9850, loss_test=0.6869, acc_test=0.5816
# poison_percent 50 round 80: loss_train=0.3233, acc_train=0.9600, loss_test=0.6884, acc_test=0.5776
# poison_percent 50 round 81: loss_train=0.3142, acc_train=0.9800, loss_test=0.6879, acc_test=0.5811
# poison_percent 50 round 82: loss_train=0.2920, acc_train=0.9800, loss_test=0.6874, acc_test=0.5821
# poison_percent 50 round 83: loss_train=0.3032, acc_train=0.9950, loss_test=0.6888, acc_test=0.5770
# poison_percent 50 round 84: loss_train=0.3022, acc_train=0.9900, loss_test=0.6898, acc_test=0.5719
# poison_percent 50 round 85: loss_train=0.3101, acc_train=0.9800, loss_test=0.6916, acc_test=0.5628
# poison_percent 50 round 86: loss_train=0.3175, acc_train=0.9800, loss_test=0.6912, acc_test=0.5617
# poison_percent 50 round 87: loss_train=0.2898, acc_train=0.9950, loss_test=0.6898, acc_test=0.5663
# poison_percent 50 round 88: loss_train=0.3227, acc_train=0.9800, loss_test=0.6920, acc_test=0.5587
# poison_percent 50 round 89: loss_train=0.3201, acc_train=1.0000, loss_test=0.6911, acc_test=0.5546
# poison_percent 50 round 90: loss_train=0.3126, acc_train=0.9950, loss_test=0.6914, acc_test=0.5592
# poison_percent 50 round 91: loss_train=0.2805, acc_train=0.9950, loss_test=0.6907, acc_test=0.5607
# poison_percent 50 round 92: loss_train=0.3004, acc_train=0.9850, loss_test=0.6934, acc_test=0.5546
# poison_percent 50 round 93: loss_train=0.3011, acc_train=0.9850, loss_test=0.6928, acc_test=0.5566
# poison_percent 50 round 94: loss_train=0.2987, acc_train=0.9850, loss_test=0.6928, acc_test=0.5536
# poison_percent 50 round 95: loss_train=0.2952, acc_train=0.9900, loss_test=0.6934, acc_test=0.5536
# poison_percent 50 round 96: loss_train=0.3069, acc_train=0.9700, loss_test=0.6946, acc_test=0.5515
# poison_percent 50 round 97: loss_train=0.3150, acc_train=0.9750, loss_test=0.6953, acc_test=0.5495
# poison_percent 50 round 98: loss_train=0.2914, acc_train=0.9900, loss_test=0.6954, acc_test=0.5485
# poison_percent 50 round 99: loss_train=0.2681, acc_train=0.9950, loss_test=0.6957, acc_test=0.5480
# Training log saved to ./results\FL_ModelN1L1_Batchsize1_rev2\poisoned_50percent\poisoned_50percent.csv
