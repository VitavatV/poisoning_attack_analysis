# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 1
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "./data/mnist_binary_poison/train"
TEST_PATH = "./data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
NODE = 1
for LAYER in [3,4,5,6]: # LAYER - (first,last)
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            
            # 1. Define the stack of hidden layers (Linear + ReLU)
            # Use a list comprehension to create the (Linear, ReLU) pairs
            hidden_layers = []
            for _ in range(LAYER-2):
                hidden_layers.append(nn.Linear(NODE, NODE))
                hidden_layers.append(nn.ReLU())
                
            # 2. Use nn.Sequential to wrap the entire dynamic stack
            self.dynamic_hidden = nn.Sequential(*hidden_layers)
            
            # Other layers
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, 1)

        def forward(self, x):
            # Flatten the input
            x = x.view(x.size(0), -1) 
            
            # Input Layer
            x = self.fc1(x)
            x = nn.ReLU()(x) # We need to manually apply ReLU here
            
            # Dynamic Hidden Layers (Executed sequentially without a loop)
            x = self.dynamic_hidden(x)
                
            # Output Layer
            x = self.fc2(x)
            x = torch.sigmoid(x)
            
            return x

    BATCH_SIZE_list = []
    temp_bs = BATCH_SIZE
    while temp_bs >= 1:
        BATCH_SIZE_list.append(temp_bs)
        temp_bs = temp_bs // 2

    for rev in range(3):

        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"CL_ModelN{NODE}L{LAYER}_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                        poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                        select='Honest+Poisoned')
                X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
                # print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
                # print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")

                X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
                y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                model = MNISTNet().to(device)
                torch.save(model, os.path.join(save_path,'model_init.pt'))
                optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

                records = []

                # Training loop
                for epoch in range(EPOCHS):

                    # Train
                    model.train()
                    
                    #randomize the training data
                    perm = torch.randperm(X_train_tensor.size(0))
                    X_train_tensor = X_train_tensor[perm]
                    y_train_tensor = y_train_tensor[perm]

                    for start in range(0, X_train_tensor.size(0), experiment_bs):
                        end = start + experiment_bs
                        xb = X_train_tensor[start:end]
                        yb = y_train_tensor[start:end]
                        outputs = model(xb)
                        preds = (outputs >= 0.5).float()
                        acc_train = (preds == yb).float().mean().item()
                        loss_train = binary_cross_entropy(outputs, yb)
                        optimizer.zero_grad()
                        loss_train.backward()
                        optimizer.step()

                    # Evaluate
                    model.eval()
                    with torch.no_grad():
                        outputs = model(X_test_tensor)
                        preds = (outputs >= 0.5).float()
                        loss_test = binary_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"epoch {epoch}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['epoch'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['epoch'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 epoch 0: loss_train=0.1133, acc_train=1.0000, loss_test=0.0630, acc_test=0.9990
# poison_percent 0 epoch 1: loss_train=0.0182, acc_train=1.0000, loss_test=0.0152, acc_test=0.9985
# poison_percent 0 epoch 2: loss_train=0.0010, acc_train=1.0000, loss_test=0.0062, acc_test=0.9995
# poison_percent 0 epoch 3: loss_train=0.0040, acc_train=1.0000, loss_test=0.0054, acc_test=0.9990
# poison_percent 0 epoch 4: loss_train=0.0026, acc_train=1.0000, loss_test=0.0037, acc_test=0.9990
# poison_percent 0 epoch 5: loss_train=0.0018, acc_train=1.0000, loss_test=0.0032, acc_test=0.9990
# poison_percent 0 epoch 6: loss_train=0.0002, acc_train=1.0000, loss_test=0.0032, acc_test=0.9985
# poison_percent 0 epoch 7: loss_train=0.0007, acc_train=1.0000, loss_test=0.0054, acc_test=0.9980
# poison_percent 0 epoch 8: loss_train=0.0006, acc_train=1.0000, loss_test=0.0048, acc_test=0.9985
# poison_percent 0 epoch 9: loss_train=0.0005, acc_train=1.0000, loss_test=0.0068, acc_test=0.9980
# poison_percent 0 epoch 10: loss_train=0.0005, acc_train=1.0000, loss_test=0.0062, acc_test=0.9974
# poison_percent 0 epoch 11: loss_train=0.0001, acc_train=1.0000, loss_test=0.0061, acc_test=0.9980
# poison_percent 0 epoch 12: loss_train=0.0001, acc_train=1.0000, loss_test=0.0060, acc_test=0.9980
# poison_percent 0 epoch 13: loss_train=0.0001, acc_train=1.0000, loss_test=0.0060, acc_test=0.9980
# poison_percent 0 epoch 14: loss_train=0.0000, acc_train=1.0000, loss_test=0.0062, acc_test=0.9974
# poison_percent 0 epoch 15: loss_train=0.0002, acc_train=1.0000, loss_test=0.0062, acc_test=0.9974
# poison_percent 0 epoch 16: loss_train=0.0002, acc_train=1.0000, loss_test=0.0063, acc_test=0.9974
# poison_percent 0 epoch 17: loss_train=0.0002, acc_train=1.0000, loss_test=0.0063, acc_test=0.9974
# poison_percent 0 epoch 18: loss_train=0.0002, acc_train=1.0000, loss_test=0.0062, acc_test=0.9974
# poison_percent 0 epoch 19: loss_train=0.0001, acc_train=1.0000, loss_test=0.0061, acc_test=0.9980
# poison_percent 0 epoch 20: loss_train=0.0001, acc_train=1.0000, loss_test=0.0061, acc_test=0.9980
# poison_percent 0 epoch 21: loss_train=0.0002, acc_train=1.0000, loss_test=0.0061, acc_test=0.9980
# poison_percent 0 epoch 22: loss_train=0.0002, acc_train=1.0000, loss_test=0.0061, acc_test=0.9974
# poison_percent 0 epoch 23: loss_train=0.0001, acc_train=1.0000, loss_test=0.0061, acc_test=0.9980
# poison_percent 0 epoch 24: loss_train=0.0001, acc_train=1.0000, loss_test=0.0061, acc_test=0.9980
# poison_percent 0 epoch 25: loss_train=0.0001, acc_train=1.0000, loss_test=0.0061, acc_test=0.9980
# poison_percent 0 epoch 26: loss_train=0.0001, acc_train=1.0000, loss_test=0.0063, acc_test=0.9974
# poison_percent 0 epoch 27: loss_train=0.0000, acc_train=1.0000, loss_test=0.0063, acc_test=0.9974
# poison_percent 0 epoch 28: loss_train=0.0001, acc_train=1.0000, loss_test=0.0062, acc_test=0.9974
# poison_percent 0 epoch 29: loss_train=0.0001, acc_train=1.0000, loss_test=0.0061, acc_test=0.9980
# poison_percent 0 epoch 30: loss_train=0.0000, acc_train=1.0000, loss_test=0.0061, acc_test=0.9980
# poison_percent 0 epoch 31: loss_train=0.0000, acc_train=1.0000, loss_test=0.0062, acc_test=0.9974
# poison_percent 0 epoch 32: loss_train=0.0001, acc_train=1.0000, loss_test=0.0061, acc_test=0.9980
# poison_percent 0 epoch 33: loss_train=0.0001, acc_train=1.0000, loss_test=0.0061, acc_test=0.9980
# poison_percent 0 epoch 34: loss_train=0.0001, acc_train=1.0000, loss_test=0.0075, acc_test=0.9980
# poison_percent 0 epoch 35: loss_train=0.0000, acc_train=1.0000, loss_test=0.0066, acc_test=0.9980
# poison_percent 0 epoch 36: loss_train=0.0001, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 37: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 38: loss_train=0.0001, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 39: loss_train=0.0000, acc_train=1.0000, loss_test=0.0072, acc_test=0.9974
# poison_percent 0 epoch 40: loss_train=0.0001, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 41: loss_train=0.0001, acc_train=1.0000, loss_test=0.0072, acc_test=0.9974
# poison_percent 0 epoch 42: loss_train=0.0000, acc_train=1.0000, loss_test=0.0076, acc_test=0.9974
# poison_percent 0 epoch 43: loss_train=0.0000, acc_train=1.0000, loss_test=0.0075, acc_test=0.9974
# poison_percent 0 epoch 44: loss_train=0.0000, acc_train=1.0000, loss_test=0.0075, acc_test=0.9974
# poison_percent 0 epoch 45: loss_train=0.0001, acc_train=1.0000, loss_test=0.0075, acc_test=0.9974
# poison_percent 0 epoch 46: loss_train=0.0000, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 47: loss_train=0.0001, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 48: loss_train=0.0001, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 49: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 50: loss_train=0.0000, acc_train=1.0000, loss_test=0.0072, acc_test=0.9974
# poison_percent 0 epoch 51: loss_train=0.0000, acc_train=1.0000, loss_test=0.0076, acc_test=0.9974
# poison_percent 0 epoch 52: loss_train=0.0001, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 53: loss_train=0.0000, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 54: loss_train=0.0001, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 55: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 56: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 57: loss_train=0.0001, acc_train=1.0000, loss_test=0.0072, acc_test=0.9974
# poison_percent 0 epoch 58: loss_train=0.0001, acc_train=1.0000, loss_test=0.0072, acc_test=0.9974
# poison_percent 0 epoch 59: loss_train=0.0000, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 60: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 61: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 62: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 63: loss_train=0.0000, acc_train=1.0000, loss_test=0.0077, acc_test=0.9974
# poison_percent 0 epoch 64: loss_train=0.0000, acc_train=1.0000, loss_test=0.0075, acc_test=0.9974
# poison_percent 0 epoch 65: loss_train=0.0000, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 66: loss_train=0.0001, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 67: loss_train=0.0001, acc_train=1.0000, loss_test=0.0075, acc_test=0.9974
# poison_percent 0 epoch 68: loss_train=0.0001, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 69: loss_train=0.0000, acc_train=1.0000, loss_test=0.0075, acc_test=0.9974
# poison_percent 0 epoch 70: loss_train=0.0001, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 71: loss_train=0.0001, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 72: loss_train=0.0001, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 73: loss_train=0.0001, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 74: loss_train=0.0001, acc_train=1.0000, loss_test=0.0076, acc_test=0.9974
# poison_percent 0 epoch 75: loss_train=0.0000, acc_train=1.0000, loss_test=0.0075, acc_test=0.9974
# poison_percent 0 epoch 76: loss_train=0.0001, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 77: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 78: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 79: loss_train=0.0001, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 80: loss_train=0.0001, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 81: loss_train=0.0001, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 82: loss_train=0.0001, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 83: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 84: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 85: loss_train=0.0000, acc_train=1.0000, loss_test=0.0072, acc_test=0.9980
# poison_percent 0 epoch 86: loss_train=0.0000, acc_train=1.0000, loss_test=0.0072, acc_test=0.9980
# poison_percent 0 epoch 87: loss_train=0.0000, acc_train=1.0000, loss_test=0.0076, acc_test=0.9974
# poison_percent 0 epoch 88: loss_train=0.0000, acc_train=1.0000, loss_test=0.0075, acc_test=0.9974
# poison_percent 0 epoch 89: loss_train=0.0000, acc_train=1.0000, loss_test=0.0075, acc_test=0.9974
# poison_percent 0 epoch 90: loss_train=0.0000, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 91: loss_train=0.0000, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 92: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 93: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 94: loss_train=0.0000, acc_train=1.0000, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 epoch 95: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 96: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 97: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 98: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 epoch 99: loss_train=0.0000, acc_train=1.0000, loss_test=0.0073, acc_test=0.9974
# Training log saved to ./results\CL_ModelN1L3_Batchsize1_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 epoch 0: loss_train=0.2607, acc_train=1.0000, loss_test=0.1885, acc_test=0.9995
# poison_percent 10 epoch 1: loss_train=0.0397, acc_train=1.0000, loss_test=0.1255, acc_test=1.0000
# poison_percent 10 epoch 2: loss_train=0.1404, acc_train=1.0000, loss_test=0.1487, acc_test=0.9959
# poison_percent 10 epoch 3: loss_train=0.0747, acc_train=1.0000, loss_test=0.1300, acc_test=0.9964
# poison_percent 10 epoch 4: loss_train=0.1335, acc_train=1.0000, loss_test=0.1189, acc_test=0.9995
# poison_percent 10 epoch 5: loss_train=0.0497, acc_train=1.0000, loss_test=0.1383, acc_test=0.9964
# poison_percent 10 epoch 6: loss_train=0.4170, acc_train=1.0000, loss_test=0.1366, acc_test=0.9964
# poison_percent 10 epoch 7: loss_train=0.0693, acc_train=1.0000, loss_test=0.1687, acc_test=0.9944
# poison_percent 10 epoch 8: loss_train=0.1246, acc_train=1.0000, loss_test=0.1331, acc_test=0.9964
# poison_percent 10 epoch 9: loss_train=0.0251, acc_train=1.0000, loss_test=0.1335, acc_test=0.9974
# poison_percent 10 epoch 10: loss_train=0.1277, acc_train=1.0000, loss_test=0.1198, acc_test=0.9985
# poison_percent 10 epoch 11: loss_train=0.8989, acc_train=0.0000, loss_test=0.1740, acc_test=0.9883
# poison_percent 10 epoch 12: loss_train=0.0670, acc_train=1.0000, loss_test=0.1705, acc_test=0.9939
# poison_percent 10 epoch 13: loss_train=0.3510, acc_train=1.0000, loss_test=0.1231, acc_test=0.9974
# poison_percent 10 epoch 14: loss_train=0.1193, acc_train=1.0000, loss_test=0.1275, acc_test=0.9969
# poison_percent 10 epoch 15: loss_train=0.2721, acc_train=1.0000, loss_test=0.1166, acc_test=0.9969
# poison_percent 10 epoch 16: loss_train=0.0562, acc_train=1.0000, loss_test=0.1154, acc_test=0.9974
# poison_percent 10 epoch 17: loss_train=0.1181, acc_train=1.0000, loss_test=0.1464, acc_test=0.9964
# poison_percent 10 epoch 18: loss_train=0.0584, acc_train=1.0000, loss_test=0.1007, acc_test=0.9985
# poison_percent 10 epoch 19: loss_train=0.1192, acc_train=1.0000, loss_test=0.1211, acc_test=0.9980
# poison_percent 10 epoch 20: loss_train=0.1948, acc_train=1.0000, loss_test=0.1744, acc_test=0.9913
# poison_percent 10 epoch 21: loss_train=0.1191, acc_train=1.0000, loss_test=0.1131, acc_test=0.9990
# poison_percent 10 epoch 22: loss_train=2.2105, acc_train=0.0000, loss_test=0.1090, acc_test=0.9990
# poison_percent 10 epoch 23: loss_train=0.1159, acc_train=1.0000, loss_test=0.2193, acc_test=0.9704
# poison_percent 10 epoch 24: loss_train=0.1165, acc_train=1.0000, loss_test=0.0992, acc_test=0.9985
# poison_percent 10 epoch 25: loss_train=0.1147, acc_train=1.0000, loss_test=0.1171, acc_test=0.9969
# poison_percent 10 epoch 26: loss_train=0.2523, acc_train=1.0000, loss_test=0.1302, acc_test=0.9954
# poison_percent 10 epoch 27: loss_train=0.0403, acc_train=1.0000, loss_test=0.1096, acc_test=0.9980
# poison_percent 10 epoch 28: loss_train=0.0460, acc_train=1.0000, loss_test=0.0931, acc_test=0.9990
# poison_percent 10 epoch 29: loss_train=0.0847, acc_train=1.0000, loss_test=0.1239, acc_test=0.9964
# poison_percent 10 epoch 30: loss_train=0.1165, acc_train=1.0000, loss_test=0.1271, acc_test=0.9969
# poison_percent 10 epoch 31: loss_train=2.2327, acc_train=0.0000, loss_test=0.1608, acc_test=0.9908
# poison_percent 10 epoch 32: loss_train=0.1178, acc_train=1.0000, loss_test=0.1065, acc_test=0.9959
# poison_percent 10 epoch 33: loss_train=0.2454, acc_train=1.0000, loss_test=0.1102, acc_test=0.9974
# poison_percent 10 epoch 34: loss_train=0.0643, acc_train=1.0000, loss_test=0.1187, acc_test=0.9949
# poison_percent 10 epoch 35: loss_train=0.1120, acc_train=1.0000, loss_test=0.1599, acc_test=0.9908
# poison_percent 10 epoch 36: loss_train=2.2316, acc_train=0.0000, loss_test=0.0928, acc_test=0.9974
# poison_percent 10 epoch 37: loss_train=0.1907, acc_train=1.0000, loss_test=0.1252, acc_test=0.9939
# poison_percent 10 epoch 38: loss_train=0.0084, acc_train=1.0000, loss_test=0.0993, acc_test=0.9974
# poison_percent 10 epoch 39: loss_train=0.1110, acc_train=1.0000, loss_test=0.1100, acc_test=0.9954
# poison_percent 10 epoch 40: loss_train=0.0662, acc_train=1.0000, loss_test=0.1441, acc_test=0.9923
# poison_percent 10 epoch 41: loss_train=0.1143, acc_train=1.0000, loss_test=0.1169, acc_test=0.9934
# poison_percent 10 epoch 42: loss_train=0.0609, acc_train=1.0000, loss_test=0.1174, acc_test=0.9913
# poison_percent 10 epoch 43: loss_train=0.1133, acc_train=1.0000, loss_test=0.1010, acc_test=0.9954
# poison_percent 10 epoch 44: loss_train=0.1136, acc_train=1.0000, loss_test=0.1114, acc_test=0.9944
# poison_percent 10 epoch 45: loss_train=0.0478, acc_train=1.0000, loss_test=0.1209, acc_test=0.9934
# poison_percent 10 epoch 46: loss_train=0.1004, acc_train=1.0000, loss_test=0.1238, acc_test=0.9939
# poison_percent 10 epoch 47: loss_train=0.1415, acc_train=1.0000, loss_test=0.0952, acc_test=0.9964
# poison_percent 10 epoch 48: loss_train=0.1136, acc_train=1.0000, loss_test=0.1092, acc_test=0.9949
# poison_percent 10 epoch 49: loss_train=2.3351, acc_train=0.0000, loss_test=0.1574, acc_test=0.9837
# poison_percent 10 epoch 50: loss_train=1.9664, acc_train=0.0000, loss_test=0.1089, acc_test=0.9944
# poison_percent 10 epoch 51: loss_train=0.1109, acc_train=1.0000, loss_test=0.1226, acc_test=0.9913
# poison_percent 10 epoch 52: loss_train=0.1110, acc_train=1.0000, loss_test=0.1183, acc_test=0.9929
# poison_percent 10 epoch 53: loss_train=2.2657, acc_train=0.0000, loss_test=0.2018, acc_test=0.9745
# poison_percent 10 epoch 54: loss_train=1.5896, acc_train=0.0000, loss_test=0.1370, acc_test=0.9923
# poison_percent 10 epoch 55: loss_train=0.1120, acc_train=1.0000, loss_test=0.0964, acc_test=0.9954
# poison_percent 10 epoch 56: loss_train=0.1110, acc_train=1.0000, loss_test=0.1298, acc_test=0.9929
# poison_percent 10 epoch 57: loss_train=0.1122, acc_train=1.0000, loss_test=0.1206, acc_test=0.9934
# poison_percent 10 epoch 58: loss_train=0.1074, acc_train=1.0000, loss_test=0.1189, acc_test=0.9903
# poison_percent 10 epoch 59: loss_train=0.1157, acc_train=1.0000, loss_test=0.1127, acc_test=0.9918
# poison_percent 10 epoch 60: loss_train=0.1105, acc_train=1.0000, loss_test=0.1279, acc_test=0.9913
# poison_percent 10 epoch 61: loss_train=0.5087, acc_train=1.0000, loss_test=0.0960, acc_test=0.9949
# poison_percent 10 epoch 62: loss_train=0.0084, acc_train=1.0000, loss_test=0.1041, acc_test=0.9934
# poison_percent 10 epoch 63: loss_train=0.2515, acc_train=1.0000, loss_test=0.1217, acc_test=0.9918
# poison_percent 10 epoch 64: loss_train=0.1076, acc_train=1.0000, loss_test=0.1290, acc_test=0.9898
# poison_percent 10 epoch 65: loss_train=0.6413, acc_train=1.0000, loss_test=0.1166, acc_test=0.9929
# poison_percent 10 epoch 66: loss_train=0.1607, acc_train=1.0000, loss_test=0.1226, acc_test=0.9923
# poison_percent 10 epoch 67: loss_train=0.1098, acc_train=1.0000, loss_test=0.1212, acc_test=0.9929
# poison_percent 10 epoch 68: loss_train=0.1280, acc_train=1.0000, loss_test=0.1245, acc_test=0.9918
# poison_percent 10 epoch 69: loss_train=2.2674, acc_train=0.0000, loss_test=0.1132, acc_test=0.9934
# poison_percent 10 epoch 70: loss_train=0.1084, acc_train=1.0000, loss_test=0.1024, acc_test=0.9939
# poison_percent 10 epoch 71: loss_train=2.2605, acc_train=0.0000, loss_test=0.1406, acc_test=0.9883
# poison_percent 10 epoch 72: loss_train=0.1362, acc_train=1.0000, loss_test=0.1224, acc_test=0.9929
# poison_percent 10 epoch 73: loss_train=0.1115, acc_train=1.0000, loss_test=0.1131, acc_test=0.9929
# poison_percent 10 epoch 74: loss_train=0.1122, acc_train=1.0000, loss_test=0.0941, acc_test=0.9949
# poison_percent 10 epoch 75: loss_train=0.1109, acc_train=1.0000, loss_test=0.1070, acc_test=0.9903
# poison_percent 10 epoch 76: loss_train=3.1333, acc_train=0.0000, loss_test=0.1229, acc_test=0.9913
# poison_percent 10 epoch 77: loss_train=0.4463, acc_train=1.0000, loss_test=0.1468, acc_test=0.9867
# poison_percent 10 epoch 78: loss_train=0.0361, acc_train=1.0000, loss_test=0.1066, acc_test=0.9923
# poison_percent 10 epoch 79: loss_train=0.1092, acc_train=1.0000, loss_test=0.1330, acc_test=0.9883
# poison_percent 10 epoch 80: loss_train=0.1099, acc_train=1.0000, loss_test=0.1104, acc_test=0.9918
# poison_percent 10 epoch 81: loss_train=0.1106, acc_train=1.0000, loss_test=0.0980, acc_test=0.9918
# poison_percent 10 epoch 82: loss_train=0.1099, acc_train=1.0000, loss_test=0.0971, acc_test=0.9939
# poison_percent 10 epoch 83: loss_train=0.1111, acc_train=1.0000, loss_test=0.1091, acc_test=0.9934
# poison_percent 10 epoch 84: loss_train=0.1097, acc_train=1.0000, loss_test=0.1399, acc_test=0.9872
# poison_percent 10 epoch 85: loss_train=0.1211, acc_train=1.0000, loss_test=0.1278, acc_test=0.9908
# poison_percent 10 epoch 86: loss_train=0.0474, acc_train=1.0000, loss_test=0.1144, acc_test=0.9918
# poison_percent 10 epoch 87: loss_train=2.7056, acc_train=0.0000, loss_test=0.1064, acc_test=0.9939
# poison_percent 10 epoch 88: loss_train=0.1129, acc_train=1.0000, loss_test=0.1139, acc_test=0.9903
# poison_percent 10 epoch 89: loss_train=0.1096, acc_train=1.0000, loss_test=0.2058, acc_test=0.9617
# poison_percent 10 epoch 90: loss_train=1.0937, acc_train=0.0000, loss_test=0.1240, acc_test=0.9908
# poison_percent 10 epoch 91: loss_train=2.4595, acc_train=0.0000, loss_test=0.1208, acc_test=0.9908
# poison_percent 10 epoch 92: loss_train=0.0573, acc_train=1.0000, loss_test=0.1367, acc_test=0.9872
# poison_percent 10 epoch 93: loss_train=0.1088, acc_train=1.0000, loss_test=0.1306, acc_test=0.9883
# poison_percent 10 epoch 94: loss_train=0.1087, acc_train=1.0000, loss_test=0.1264, acc_test=0.9893
# poison_percent 10 epoch 95: loss_train=0.1121, acc_train=1.0000, loss_test=0.1166, acc_test=0.9913
# poison_percent 10 epoch 96: loss_train=0.0551, acc_train=1.0000, loss_test=0.1387, acc_test=0.9862
# poison_percent 10 epoch 97: loss_train=0.1105, acc_train=1.0000, loss_test=0.1022, acc_test=0.9923
# poison_percent 10 epoch 98: loss_train=0.1088, acc_train=1.0000, loss_test=0.1313, acc_test=0.9878
# poison_percent 10 epoch 99: loss_train=0.0405, acc_train=1.0000, loss_test=0.1003, acc_test=0.9923
# Training log saved to ./results\CL_ModelN1L3_Batchsize1_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 epoch 0: loss_train=0.7008, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 1: loss_train=0.7024, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 2: loss_train=0.6849, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 3: loss_train=0.7072, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 4: loss_train=0.6962, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 5: loss_train=0.6968, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 6: loss_train=0.6852, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 7: loss_train=0.6883, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 8: loss_train=0.7085, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 epoch 9: loss_train=0.7012, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 10: loss_train=0.6999, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 11: loss_train=0.6875, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 12: loss_train=0.6908, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 13: loss_train=0.6935, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 14: loss_train=0.6973, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 15: loss_train=0.6856, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 16: loss_train=0.6919, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 17: loss_train=0.6815, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 18: loss_train=0.6975, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 19: loss_train=0.6919, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 20: loss_train=0.6805, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 21: loss_train=0.7152, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 20 epoch 22: loss_train=0.7000, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 23: loss_train=0.6935, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 24: loss_train=0.6911, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 25: loss_train=0.7061, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 26: loss_train=0.6850, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 27: loss_train=0.7003, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 28: loss_train=0.6953, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 29: loss_train=0.6970, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 30: loss_train=0.6891, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 31: loss_train=0.6748, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 epoch 32: loss_train=0.7182, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 20 epoch 33: loss_train=0.7029, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 34: loss_train=0.6996, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 35: loss_train=0.7025, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 36: loss_train=0.6875, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 37: loss_train=0.6873, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 38: loss_train=0.7011, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 39: loss_train=0.6859, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 40: loss_train=0.6866, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 41: loss_train=0.6830, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 42: loss_train=0.6827, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 43: loss_train=0.7096, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 epoch 44: loss_train=0.6864, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 45: loss_train=0.6907, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 46: loss_train=0.6866, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 47: loss_train=0.6802, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 48: loss_train=0.7032, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 49: loss_train=0.6875, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 50: loss_train=0.6946, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 51: loss_train=0.6952, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 52: loss_train=0.6916, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 53: loss_train=0.6879, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 54: loss_train=0.6993, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 55: loss_train=0.6965, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 56: loss_train=0.7109, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 epoch 57: loss_train=0.6933, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 58: loss_train=0.6921, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 59: loss_train=0.7037, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 60: loss_train=0.6941, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 61: loss_train=0.7144, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 20 epoch 62: loss_train=0.6919, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 63: loss_train=0.6996, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 64: loss_train=0.6852, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 65: loss_train=0.7013, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 66: loss_train=0.6944, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 67: loss_train=0.6840, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 68: loss_train=0.6967, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 69: loss_train=0.7081, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 epoch 70: loss_train=0.6799, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 71: loss_train=0.6993, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 72: loss_train=0.6986, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 73: loss_train=0.7107, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 epoch 74: loss_train=0.7006, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 75: loss_train=0.7039, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 76: loss_train=0.6779, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 epoch 77: loss_train=0.6893, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 78: loss_train=0.7021, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 79: loss_train=0.6911, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 80: loss_train=0.6952, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 81: loss_train=0.7033, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 82: loss_train=0.6992, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 83: loss_train=0.7161, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 20 epoch 84: loss_train=0.6885, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 85: loss_train=0.6854, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 86: loss_train=0.6977, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 87: loss_train=0.7113, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 20 epoch 88: loss_train=0.6950, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 89: loss_train=0.6793, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 90: loss_train=0.6878, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 91: loss_train=0.6915, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 92: loss_train=0.6966, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 93: loss_train=0.6963, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 94: loss_train=0.6855, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 95: loss_train=0.6916, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 96: loss_train=0.6938, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 97: loss_train=0.6945, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 20 epoch 98: loss_train=0.6798, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 20 epoch 99: loss_train=0.6886, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# Training log saved to ./results\CL_ModelN1L3_Batchsize1_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 epoch 0: loss_train=0.7067, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 1: loss_train=0.6936, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 2: loss_train=0.6868, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 3: loss_train=0.7015, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 4: loss_train=0.6909, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 5: loss_train=0.6871, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 6: loss_train=0.7113, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 epoch 7: loss_train=0.6936, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 8: loss_train=0.6789, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 epoch 9: loss_train=0.6862, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 10: loss_train=0.6914, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 11: loss_train=0.6939, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 12: loss_train=0.7109, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 epoch 13: loss_train=0.6839, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 14: loss_train=0.6963, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 15: loss_train=0.6910, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 16: loss_train=0.6991, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 17: loss_train=0.6837, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 18: loss_train=0.7058, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 19: loss_train=0.7017, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 20: loss_train=0.6954, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 21: loss_train=0.6813, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 22: loss_train=0.6957, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 23: loss_train=0.6971, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 24: loss_train=0.6882, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 25: loss_train=0.6851, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 26: loss_train=0.6911, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 27: loss_train=0.6862, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 28: loss_train=0.6899, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 29: loss_train=0.6984, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 30: loss_train=0.7007, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 31: loss_train=0.7040, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 32: loss_train=0.7205, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 30 epoch 33: loss_train=0.7004, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 34: loss_train=0.6751, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 epoch 35: loss_train=0.7058, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 36: loss_train=0.7020, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 37: loss_train=0.6850, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 38: loss_train=0.6902, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 39: loss_train=0.6739, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 epoch 40: loss_train=0.7080, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 epoch 41: loss_train=0.6792, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 42: loss_train=0.6969, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 43: loss_train=0.6957, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 44: loss_train=0.6950, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 45: loss_train=0.6855, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 46: loss_train=0.6888, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 47: loss_train=0.6801, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 48: loss_train=0.7005, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 49: loss_train=0.7006, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 50: loss_train=0.7070, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 51: loss_train=0.7221, acc_train=0.0000, loss_test=0.6936, acc_test=0.5000
# poison_percent 30 epoch 52: loss_train=0.7014, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 53: loss_train=0.6939, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 54: loss_train=0.6862, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 55: loss_train=0.6877, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 56: loss_train=0.6785, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 epoch 57: loss_train=0.6740, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 epoch 58: loss_train=0.7067, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 59: loss_train=0.6966, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 60: loss_train=0.6861, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 61: loss_train=0.6977, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 62: loss_train=0.6956, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 63: loss_train=0.6969, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 64: loss_train=0.6829, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 65: loss_train=0.6925, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 66: loss_train=0.6928, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 67: loss_train=0.6820, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 68: loss_train=0.6956, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 69: loss_train=0.6875, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 70: loss_train=0.7037, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 71: loss_train=0.6948, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 30 epoch 72: loss_train=0.6816, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 73: loss_train=0.7070, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 74: loss_train=0.7013, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 75: loss_train=0.7133, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 epoch 76: loss_train=0.7158, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 30 epoch 77: loss_train=0.7017, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 78: loss_train=0.6746, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 epoch 79: loss_train=0.6872, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 80: loss_train=0.7129, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 epoch 81: loss_train=0.7088, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 30 epoch 82: loss_train=0.7003, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 83: loss_train=0.6816, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 84: loss_train=0.7000, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 85: loss_train=0.6992, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 86: loss_train=0.6892, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 87: loss_train=0.6829, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 88: loss_train=0.6963, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 89: loss_train=0.6823, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 90: loss_train=0.7025, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 91: loss_train=0.6976, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 92: loss_train=0.6873, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 93: loss_train=0.7028, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 94: loss_train=0.7004, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 95: loss_train=0.7054, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 96: loss_train=0.6901, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 97: loss_train=0.6860, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 98: loss_train=0.7011, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 30 epoch 99: loss_train=0.7091, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# Training log saved to ./results\CL_ModelN1L3_Batchsize1_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 epoch 0: loss_train=0.6913, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 1: loss_train=0.6735, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 2: loss_train=0.6851, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 3: loss_train=0.6941, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 4: loss_train=0.6823, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 5: loss_train=0.6882, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 6: loss_train=0.7147, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 7: loss_train=0.6986, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 8: loss_train=0.7046, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 9: loss_train=0.6836, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 10: loss_train=0.6909, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 11: loss_train=0.6722, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 12: loss_train=0.6961, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 13: loss_train=0.6984, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 14: loss_train=0.6780, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 15: loss_train=0.6722, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 16: loss_train=0.6804, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 17: loss_train=0.6847, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 18: loss_train=0.6790, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 19: loss_train=0.6840, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 20: loss_train=0.6717, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 21: loss_train=0.7160, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 22: loss_train=0.7038, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 23: loss_train=0.6809, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 24: loss_train=0.6923, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 25: loss_train=0.7000, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 26: loss_train=0.6957, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 27: loss_train=0.6962, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 28: loss_train=0.7075, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 29: loss_train=0.6871, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 30: loss_train=0.6897, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 31: loss_train=0.7001, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 32: loss_train=0.6914, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 33: loss_train=0.7120, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 34: loss_train=0.7070, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 35: loss_train=0.6937, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 36: loss_train=0.6683, acc_train=1.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 40 epoch 37: loss_train=0.7025, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 38: loss_train=0.6737, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 39: loss_train=0.6906, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 40: loss_train=0.6835, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 41: loss_train=0.6816, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 42: loss_train=0.6920, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 43: loss_train=0.6674, acc_train=1.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 40 epoch 44: loss_train=0.6927, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 45: loss_train=0.6671, acc_train=1.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 40 epoch 46: loss_train=0.6848, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 47: loss_train=0.6944, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 48: loss_train=0.6866, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 49: loss_train=0.6921, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 50: loss_train=0.7006, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 51: loss_train=0.6844, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 52: loss_train=0.6848, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 53: loss_train=0.6832, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 54: loss_train=0.7058, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 55: loss_train=0.7013, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 56: loss_train=0.6844, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 57: loss_train=0.6826, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 58: loss_train=0.7029, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 59: loss_train=0.7005, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 60: loss_train=0.6952, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 61: loss_train=0.7068, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 62: loss_train=0.6836, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 63: loss_train=0.6819, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 64: loss_train=0.6925, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 65: loss_train=0.6917, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 66: loss_train=0.6930, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 67: loss_train=0.6963, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 68: loss_train=0.7063, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 69: loss_train=0.7035, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 70: loss_train=0.7025, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 71: loss_train=0.7131, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 72: loss_train=0.6666, acc_train=1.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 40 epoch 73: loss_train=0.6996, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 74: loss_train=0.6945, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 75: loss_train=0.6933, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 76: loss_train=0.6882, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 77: loss_train=0.7059, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 78: loss_train=0.6859, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 79: loss_train=0.6959, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 80: loss_train=0.6977, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 81: loss_train=0.7027, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# ...
# poison_percent 40 epoch 41: loss_train=0.7080, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 42: loss_train=0.7278, acc_train=0.0000, loss_test=0.6937, acc_test=0.5000
# poison_percent 40 epoch 43: loss_train=0.6554, acc_train=1.0000, loss_test=0.6939, acc_test=0.5000
# poison_percent 40 epoch 44: loss_train=0.7089, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 45: loss_train=0.6987, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 46: loss_train=0.6978, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 47: loss_train=0.7019, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 48: loss_train=0.6924, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 49: loss_train=0.6531, acc_train=1.0000, loss_test=0.6940, acc_test=0.5000
# poison_percent 40 epoch 50: loss_train=0.6780, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 51: loss_train=0.6777, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 52: loss_train=0.6658, acc_train=1.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 40 epoch 53: loss_train=0.6849, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 54: loss_train=0.7129, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 55: loss_train=0.6713, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 56: loss_train=0.7161, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 57: loss_train=0.7194, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 40 epoch 58: loss_train=0.6872, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 59: loss_train=0.6580, acc_train=1.0000, loss_test=0.6938, acc_test=0.5000
# poison_percent 40 epoch 60: loss_train=0.7237, acc_train=0.0000, loss_test=0.6936, acc_test=0.5000
# poison_percent 40 epoch 61: loss_train=0.7256, acc_train=0.0000, loss_test=0.6936, acc_test=0.5000
# poison_percent 40 epoch 62: loss_train=0.6657, acc_train=1.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 40 epoch 63: loss_train=0.6374, acc_train=1.0000, loss_test=0.6948, acc_test=0.5000
# poison_percent 40 epoch 64: loss_train=0.7283, acc_train=0.0000, loss_test=0.6937, acc_test=0.5000
# poison_percent 40 epoch 65: loss_train=0.6982, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 66: loss_train=0.6922, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 67: loss_train=0.6819, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 68: loss_train=0.7237, acc_train=0.0000, loss_test=0.6936, acc_test=0.5000
# poison_percent 40 epoch 69: loss_train=0.6968, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 70: loss_train=0.7008, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 71: loss_train=0.7309, acc_train=0.0000, loss_test=0.6938, acc_test=0.5000
# poison_percent 40 epoch 72: loss_train=0.7172, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 73: loss_train=0.7025, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 74: loss_train=0.7094, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 75: loss_train=0.7076, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 76: loss_train=0.6701, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 77: loss_train=0.6690, acc_train=1.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 40 epoch 78: loss_train=0.6868, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 79: loss_train=0.6702, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 80: loss_train=0.7151, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 81: loss_train=0.6627, acc_train=1.0000, loss_test=0.6936, acc_test=0.5000
# poison_percent 40 epoch 82: loss_train=0.6978, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 83: loss_train=0.7159, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 84: loss_train=0.6841, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 85: loss_train=0.7104, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 86: loss_train=0.6784, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 87: loss_train=0.6864, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 88: loss_train=0.7085, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 89: loss_train=0.6644, acc_train=1.0000, loss_test=0.6936, acc_test=0.5000
# poison_percent 40 epoch 90: loss_train=0.7127, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 91: loss_train=0.6696, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 40 epoch 92: loss_train=0.6688, acc_train=1.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 40 epoch 93: loss_train=0.7106, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 94: loss_train=0.7075, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 95: loss_train=0.6597, acc_train=1.0000, loss_test=0.6937, acc_test=0.5000
# poison_percent 40 epoch 96: loss_train=0.6771, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 97: loss_train=0.6641, acc_train=1.0000, loss_test=0.6936, acc_test=0.5000
# poison_percent 40 epoch 98: loss_train=0.6741, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 40 epoch 99: loss_train=0.6906, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# Training log saved to ./results\CL_ModelN1L6_Batchsize1_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 epoch 0: loss_train=0.6994, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 1: loss_train=0.6923, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 2: loss_train=0.7041, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 3: loss_train=0.6789, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 4: loss_train=0.7023, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 5: loss_train=0.6829, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 6: loss_train=0.7219, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 50 epoch 7: loss_train=0.6812, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 8: loss_train=0.7126, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 9: loss_train=0.7019, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 10: loss_train=0.7054, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 11: loss_train=0.7049, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 12: loss_train=0.6804, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 13: loss_train=0.6697, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 50 epoch 14: loss_train=0.7015, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 15: loss_train=0.6900, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 16: loss_train=0.7221, acc_train=0.0000, loss_test=0.6936, acc_test=0.5000
# poison_percent 50 epoch 17: loss_train=0.6811, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 18: loss_train=0.6782, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 19: loss_train=0.6983, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 20: loss_train=0.6846, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 21: loss_train=0.6823, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 22: loss_train=0.6988, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 23: loss_train=0.6979, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 24: loss_train=0.6930, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 25: loss_train=0.6847, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 26: loss_train=0.7125, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 27: loss_train=0.7100, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 28: loss_train=0.6884, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 29: loss_train=0.6851, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 30: loss_train=0.7122, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 31: loss_train=0.7176, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 50 epoch 32: loss_train=0.7243, acc_train=0.0000, loss_test=0.6936, acc_test=0.5000
# poison_percent 50 epoch 33: loss_train=0.6922, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 34: loss_train=0.7007, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 35: loss_train=0.7090, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 36: loss_train=0.6749, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 37: loss_train=0.7170, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 50 epoch 38: loss_train=0.7164, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 50 epoch 39: loss_train=0.6620, acc_train=1.0000, loss_test=0.6936, acc_test=0.5000
# poison_percent 50 epoch 40: loss_train=0.6853, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 41: loss_train=0.6973, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 42: loss_train=0.6760, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 43: loss_train=0.7007, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 44: loss_train=0.6774, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 45: loss_train=0.6957, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 46: loss_train=0.6985, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 47: loss_train=0.6865, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 48: loss_train=0.6768, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 49: loss_train=0.6814, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 50: loss_train=0.7006, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 51: loss_train=0.7055, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 52: loss_train=0.7169, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 50 epoch 53: loss_train=0.7218, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 50 epoch 54: loss_train=0.6949, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 55: loss_train=0.6845, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 56: loss_train=0.6906, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 57: loss_train=0.6943, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 58: loss_train=0.7055, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 59: loss_train=0.6984, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 60: loss_train=0.6744, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 61: loss_train=0.6758, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 62: loss_train=0.6824, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 63: loss_train=0.6803, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 64: loss_train=0.6819, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 65: loss_train=0.6959, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 66: loss_train=0.6921, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 67: loss_train=0.7143, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 50 epoch 68: loss_train=0.6926, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 69: loss_train=0.6987, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 70: loss_train=0.7083, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 71: loss_train=0.6693, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 50 epoch 72: loss_train=0.7181, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 50 epoch 73: loss_train=0.6743, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 74: loss_train=0.6887, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 75: loss_train=0.7091, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 76: loss_train=0.7008, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 77: loss_train=0.7040, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 78: loss_train=0.6779, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 79: loss_train=0.6672, acc_train=1.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 50 epoch 80: loss_train=0.6954, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 81: loss_train=0.7031, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 82: loss_train=0.6892, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 83: loss_train=0.7128, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 84: loss_train=0.7061, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 85: loss_train=0.6798, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 86: loss_train=0.6825, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 87: loss_train=0.6744, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 88: loss_train=0.6775, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 89: loss_train=0.6888, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 90: loss_train=0.6750, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 91: loss_train=0.6870, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 92: loss_train=0.6937, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 93: loss_train=0.6864, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 94: loss_train=0.6808, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 95: loss_train=0.7129, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 50 epoch 96: loss_train=0.7140, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 50 epoch 97: loss_train=0.6986, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 98: loss_train=0.6818, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 99: loss_train=0.7182, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# Training log saved to ./results\CL_ModelN1L6_Batchsize1_rev2\poisoned_50percent\poisoned_50percent.csv
