# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 1
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "./data/mnist_binary_poison/train"
TEST_PATH = "./data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [10]#[0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 12 for percent: 10
# Poison n list: [12]

# %%
NODE = 1
for LAYER in [6]:#[3,4,5,6]: # LAYER - (first,last)
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            
            # 1. Define the stack of hidden layers (Linear + ReLU)
            # Use a list comprehension to create the (Linear, ReLU) pairs
            hidden_layers = []
            for _ in range(LAYER-2):
                hidden_layers.append(nn.Linear(NODE, NODE))
                hidden_layers.append(nn.ReLU())
                
            # 2. Use nn.Sequential to wrap the entire dynamic stack
            self.dynamic_hidden = nn.Sequential(*hidden_layers)
            
            # Other layers
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, 1)

        def forward(self, x):
            # Flatten the input
            x = x.view(x.size(0), -1) 
            
            # Input Layer
            x = self.fc1(x)
            x = nn.ReLU()(x) # We need to manually apply ReLU here
            
            # Dynamic Hidden Layers (Executed sequentially without a loop)
            x = self.dynamic_hidden(x)
                
            # Output Layer
            x = self.fc2(x)
            x = torch.sigmoid(x)
            
            return x

    BATCH_SIZE_list = []
    temp_bs = BATCH_SIZE
    while temp_bs >= 1:
        BATCH_SIZE_list.append(temp_bs)
        temp_bs = temp_bs // 2

    for rev in range(3):

        model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"CL_ModelN{NODE}L{LAYER}_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                        poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                        select='Honest+Poisoned')
                X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
                # print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
                # print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")

                X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
                y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                torch.save(model, os.path.join(save_path,'model_init.pt'))
                optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

                records = []

                # Training loop
                for epoch in range(EPOCHS):

                    # Train
                    model.train()
                    
                    #randomize the training data
                    perm = torch.randperm(X_train_tensor.size(0))
                    X_train_tensor = X_train_tensor[perm]
                    y_train_tensor = y_train_tensor[perm]

                    for start in range(0, X_train_tensor.size(0), experiment_bs):
                        end = start + experiment_bs
                        xb = X_train_tensor[start:end]
                        yb = y_train_tensor[start:end]
                        outputs = model(xb)
                        preds = (outputs >= 0.5).float()
                        acc_train = (preds == yb).float().mean().item()
                        loss_train = binary_cross_entropy(outputs, yb)
                        optimizer.zero_grad()
                        loss_train.backward()
                        optimizer.step()

                    # Evaluate
                    model.eval()
                    with torch.no_grad():
                        outputs = model(X_test_tensor)
                        preds = (outputs >= 0.5).float()
                        loss_test = binary_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"epoch {epoch}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['epoch'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['epoch'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 10 epoch 0: loss_train=0.7083, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 1: loss_train=0.7115, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 2: loss_train=0.6636, acc_train=1.0000, loss_test=0.6936, acc_test=0.5000
# poison_percent 10 epoch 3: loss_train=0.6785, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 4: loss_train=0.6842, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 5: loss_train=0.6851, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 6: loss_train=0.7140, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 7: loss_train=0.6590, acc_train=1.0000, loss_test=0.6938, acc_test=0.5000
# poison_percent 10 epoch 8: loss_train=0.7157, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 9: loss_train=0.6729, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 10: loss_train=0.7167, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 11: loss_train=0.6825, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 12: loss_train=0.7352, acc_train=0.0000, loss_test=0.6940, acc_test=0.5000
# poison_percent 10 epoch 13: loss_train=0.6646, acc_train=1.0000, loss_test=0.6936, acc_test=0.5000
# poison_percent 10 epoch 14: loss_train=0.6952, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 15: loss_train=0.6965, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 16: loss_train=0.6666, acc_train=1.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 10 epoch 17: loss_train=0.7025, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 18: loss_train=0.6841, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 19: loss_train=0.6830, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 20: loss_train=0.7379, acc_train=0.0000, loss_test=0.6941, acc_test=0.5000
# poison_percent 10 epoch 21: loss_train=0.7023, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 22: loss_train=0.6990, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 23: loss_train=0.6838, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 24: loss_train=0.6947, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 25: loss_train=0.7012, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 26: loss_train=0.7037, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 27: loss_train=0.7053, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 28: loss_train=0.6705, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 29: loss_train=0.6769, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 30: loss_train=0.6865, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 31: loss_train=0.6772, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 32: loss_train=0.6995, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 33: loss_train=0.6949, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 34: loss_train=0.6684, acc_train=1.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 10 epoch 35: loss_train=0.6703, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 36: loss_train=0.7009, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 37: loss_train=0.6860, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 38: loss_train=0.6983, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 39: loss_train=0.6773, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 40: loss_train=0.6998, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 41: loss_train=0.7103, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 42: loss_train=0.6915, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 43: loss_train=0.6882, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 44: loss_train=0.6544, acc_train=1.0000, loss_test=0.6939, acc_test=0.5000
# poison_percent 10 epoch 45: loss_train=0.7195, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 10 epoch 46: loss_train=0.6848, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 47: loss_train=0.6908, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 48: loss_train=0.6909, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 49: loss_train=0.7179, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 50: loss_train=0.6771, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 51: loss_train=0.6992, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 52: loss_train=0.7081, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 53: loss_train=0.7105, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 54: loss_train=0.6721, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 55: loss_train=0.7188, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 10 epoch 56: loss_train=0.7000, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 57: loss_train=0.6899, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 58: loss_train=0.7035, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 59: loss_train=0.7107, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 60: loss_train=0.6987, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 61: loss_train=0.6947, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 62: loss_train=0.6971, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 63: loss_train=0.7099, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 64: loss_train=0.7027, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 65: loss_train=0.6792, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 66: loss_train=0.7199, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 10 epoch 67: loss_train=0.7170, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 68: loss_train=0.7023, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 69: loss_train=0.7106, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 70: loss_train=0.6894, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 71: loss_train=0.6915, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 72: loss_train=0.6953, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 73: loss_train=0.6897, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 74: loss_train=0.7141, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 75: loss_train=0.6821, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 76: loss_train=0.7052, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 77: loss_train=0.6873, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 78: loss_train=0.7035, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 79: loss_train=0.7183, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 10 epoch 80: loss_train=0.7021, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 81: loss_train=0.7250, acc_train=0.0000, loss_test=0.6936, acc_test=0.5000
# poison_percent 10 epoch 82: loss_train=0.6817, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 83: loss_train=0.6833, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 84: loss_train=0.6856, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 85: loss_train=0.7037, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 86: loss_train=0.7015, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 87: loss_train=0.6771, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 88: loss_train=0.6972, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 89: loss_train=0.6919, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 90: loss_train=0.6845, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 91: loss_train=0.7041, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 92: loss_train=0.6960, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 93: loss_train=0.6888, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 94: loss_train=0.6891, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 95: loss_train=0.7200, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 10 epoch 96: loss_train=0.7011, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 97: loss_train=0.7185, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 10 epoch 98: loss_train=0.6601, acc_train=1.0000, loss_test=0.6937, acc_test=0.5000
# poison_percent 10 epoch 99: loss_train=0.6775, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# Training log saved to ./results\CL_ModelN1L6_Batchsize1_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 10 epoch 0: loss_train=0.7097, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 1: loss_train=0.6936, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 2: loss_train=0.6928, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 3: loss_train=0.7085, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 4: loss_train=0.6991, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 5: loss_train=0.7006, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 6: loss_train=0.6938, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 7: loss_train=0.7009, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 8: loss_train=0.6913, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 9: loss_train=0.6864, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 10: loss_train=0.6954, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 11: loss_train=0.6975, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 12: loss_train=0.6966, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 13: loss_train=0.6843, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 14: loss_train=0.6922, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 15: loss_train=0.7039, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 16: loss_train=0.7025, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 17: loss_train=0.6899, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 18: loss_train=0.6863, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 19: loss_train=0.6668, acc_train=1.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 10 epoch 20: loss_train=0.7052, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 21: loss_train=0.6864, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 22: loss_train=0.6911, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 23: loss_train=0.6965, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 24: loss_train=0.6974, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 25: loss_train=0.6949, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 26: loss_train=0.7088, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 27: loss_train=0.7034, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 28: loss_train=0.6858, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 29: loss_train=0.6930, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 30: loss_train=0.6921, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 31: loss_train=0.6852, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 32: loss_train=0.7013, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 33: loss_train=0.7043, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 34: loss_train=0.6876, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 35: loss_train=0.6847, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 36: loss_train=0.7084, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 37: loss_train=0.6988, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 38: loss_train=0.6875, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 39: loss_train=0.6909, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 40: loss_train=0.6960, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 41: loss_train=0.7130, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 42: loss_train=0.6943, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 43: loss_train=0.7010, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 44: loss_train=0.6886, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 45: loss_train=0.7022, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 46: loss_train=0.6860, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 47: loss_train=0.6983, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 48: loss_train=0.7013, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 49: loss_train=0.6987, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 50: loss_train=0.6889, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 51: loss_train=0.6892, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 52: loss_train=0.6981, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 53: loss_train=0.7055, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 54: loss_train=0.7041, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 55: loss_train=0.7070, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 56: loss_train=0.6888, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 57: loss_train=0.6891, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 58: loss_train=0.6967, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 59: loss_train=0.7049, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 60: loss_train=0.7017, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 61: loss_train=0.6773, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 62: loss_train=0.6829, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 63: loss_train=0.6861, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 64: loss_train=0.7028, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 65: loss_train=0.7097, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 66: loss_train=0.7135, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 67: loss_train=0.7159, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 68: loss_train=0.6899, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 69: loss_train=0.6781, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 70: loss_train=0.7203, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 10 epoch 71: loss_train=0.6852, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 72: loss_train=0.7139, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 73: loss_train=0.6937, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 74: loss_train=0.6798, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 75: loss_train=0.6913, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 76: loss_train=0.6983, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 77: loss_train=0.6843, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 78: loss_train=0.6939, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 79: loss_train=0.6818, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 80: loss_train=0.6809, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 81: loss_train=0.6986, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 82: loss_train=0.6958, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 83: loss_train=0.6900, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 84: loss_train=0.6918, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 85: loss_train=0.6856, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 86: loss_train=0.6983, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 87: loss_train=0.6821, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 88: loss_train=0.6922, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 89: loss_train=0.6951, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 90: loss_train=0.6884, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 91: loss_train=0.7060, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 92: loss_train=0.6869, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 93: loss_train=0.6888, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 94: loss_train=0.6904, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 95: loss_train=0.7069, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 96: loss_train=0.7177, acc_train=0.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 97: loss_train=0.6845, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 98: loss_train=0.6925, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 99: loss_train=0.6787, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# Training log saved to ./results\CL_ModelN1L6_Batchsize1_rev1\poisoned_10percent\poisoned_10percent.csv
# poison_percent 10 epoch 0: loss_train=0.6769, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 1: loss_train=0.6810, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 2: loss_train=0.6909, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 3: loss_train=0.6948, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 4: loss_train=0.6940, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 5: loss_train=0.6867, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 6: loss_train=0.6831, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 7: loss_train=0.6988, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 8: loss_train=0.6905, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 9: loss_train=0.6923, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 10: loss_train=0.7054, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 11: loss_train=0.7025, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 12: loss_train=0.7104, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 13: loss_train=0.6861, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 14: loss_train=0.6962, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 15: loss_train=0.6777, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 16: loss_train=0.6842, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 17: loss_train=0.6904, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 18: loss_train=0.6854, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 19: loss_train=0.6984, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 20: loss_train=0.6704, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 21: loss_train=0.6975, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 22: loss_train=0.6934, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 23: loss_train=0.7052, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 24: loss_train=0.6866, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 25: loss_train=0.6720, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 26: loss_train=0.6761, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 27: loss_train=0.7130, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 28: loss_train=0.6881, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 29: loss_train=0.7127, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 30: loss_train=0.7027, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 31: loss_train=0.7051, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 32: loss_train=0.6899, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 33: loss_train=0.6857, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 34: loss_train=0.6910, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 35: loss_train=0.6830, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 36: loss_train=0.6912, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 37: loss_train=0.6968, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 38: loss_train=0.6748, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 39: loss_train=0.6713, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 40: loss_train=0.6922, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 41: loss_train=0.7022, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 42: loss_train=0.6931, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 43: loss_train=0.6968, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 44: loss_train=0.6875, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 45: loss_train=0.6861, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 46: loss_train=0.6881, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 47: loss_train=0.6978, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 48: loss_train=0.6879, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 49: loss_train=0.6946, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 50: loss_train=0.6894, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 51: loss_train=0.7016, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 52: loss_train=0.6932, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 53: loss_train=0.7075, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 54: loss_train=0.6952, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 55: loss_train=0.6943, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 56: loss_train=0.6947, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 57: loss_train=0.6680, acc_train=1.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 10 epoch 58: loss_train=0.6835, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 59: loss_train=0.6924, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 60: loss_train=0.7212, acc_train=0.0000, loss_test=0.6935, acc_test=0.5000
# poison_percent 10 epoch 61: loss_train=0.6778, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 62: loss_train=0.6899, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 63: loss_train=0.6944, acc_train=0.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 64: loss_train=0.6850, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 65: loss_train=0.7101, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 66: loss_train=0.6931, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 67: loss_train=0.6880, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 68: loss_train=0.7063, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 69: loss_train=0.7019, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 70: loss_train=0.6739, acc_train=1.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 71: loss_train=0.7075, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 72: loss_train=0.6960, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 73: loss_train=0.6853, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 74: loss_train=0.6979, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 75: loss_train=0.6919, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 76: loss_train=0.6995, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 77: loss_train=0.6983, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 78: loss_train=0.7050, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 79: loss_train=0.7080, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 80: loss_train=0.6992, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 81: loss_train=0.6885, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 82: loss_train=0.6960, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 83: loss_train=0.6988, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 84: loss_train=0.7017, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 85: loss_train=0.6993, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 86: loss_train=0.6888, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 87: loss_train=0.6692, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 88: loss_train=0.6713, acc_train=1.0000, loss_test=0.6934, acc_test=0.5000
# poison_percent 10 epoch 89: loss_train=0.6930, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 90: loss_train=0.7086, acc_train=0.0000, loss_test=0.6933, acc_test=0.5000
# poison_percent 10 epoch 91: loss_train=0.6865, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 92: loss_train=0.6891, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 93: loss_train=0.6845, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 94: loss_train=0.7004, acc_train=0.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 95: loss_train=0.6893, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 96: loss_train=0.6923, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 97: loss_train=0.6924, acc_train=1.0000, loss_test=0.6931, acc_test=0.5000
# poison_percent 10 epoch 98: loss_train=0.6810, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# poison_percent 10 epoch 99: loss_train=0.6894, acc_train=1.0000, loss_test=0.6932, acc_test=0.5000
# Training log saved to ./results\CL_ModelN1L6_Batchsize1_rev2\poisoned_10percent\poisoned_10percent.csv
