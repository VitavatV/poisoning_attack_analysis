# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
class MNISTNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28*28, 1)
    def forward(self, x):
        x = self.fc1(x)
        x = torch.sigmoid(x)
        return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 1
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "./data/mnist_binary_poison/train"
TEST_PATH = "./data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [40]#[0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 67 for percent: 40
# Poison n list: [67]

# %%
BATCH_SIZE_list = []
temp_bs = BATCH_SIZE
while temp_bs >= 1:
    BATCH_SIZE_list.append(temp_bs)
    temp_bs = temp_bs // 2

for rev in range(3):

    model = MNISTNet().to(device)
    for experiment_bs in BATCH_SIZE_list:

        name_save_path = f"CL_ModelN1L1_Batchsize{experiment_bs}_rev{rev}"
        
        for i_poisoned in poison_n_list:
            percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

            # create directory
            NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
            save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
            # Remove existing directory if it exists
            if os.path.exists(save_path):
                shutil.rmtree(save_path)
            if not os.path.exists(save_path):
                os.makedirs(save_path)
            save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
            os.makedirs(save_all_path, exist_ok=True)
            
            # Load data
            X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                    poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                    select='Honest+Poisoned')
            X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
            # print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
            # print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

            if X_test.shape[0] == 0:
                raise ValueError("No valid test images found in the test directory!")

            X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
            y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
            X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
            y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

            torch.save(model, os.path.join(save_path,'model_init.pt'))
            optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

            records = []

            # Training loop
            for epoch in range(EPOCHS):

                # Train
                model.train()
                
                #randomize the training data
                perm = torch.randperm(X_train_tensor.size(0))
                X_train_tensor = X_train_tensor[perm]
                y_train_tensor = y_train_tensor[perm]

                for start in range(0, X_train_tensor.size(0), experiment_bs):
                    end = start + experiment_bs
                    xb = X_train_tensor[start:end]
                    yb = y_train_tensor[start:end]
                    outputs = model(xb)
                    preds = (outputs >= 0.5).float()
                    acc_train = (preds == yb).float().mean().item()
                    loss_train = binary_cross_entropy(outputs, yb)
                    optimizer.zero_grad()
                    loss_train.backward()
                    optimizer.step()

                # Evaluate
                model.eval()
                with torch.no_grad():
                    outputs = model(X_test_tensor)
                    preds = (outputs >= 0.5).float()
                    loss_test = binary_cross_entropy(outputs, y_test_tensor)
                    acc_test = (preds == y_test_tensor).float().mean().item()
                records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                                'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                'loss_test': loss_test.item(), 'acc_test': acc_test})
                report_txt = f"poison_percent {percent_poisoned} "
                report_txt += f"epoch {epoch}: "
                report_txt += f"loss_train={loss_train.item():.4f}, "
                report_txt += f"acc_train={acc_train:.4f}, "
                report_txt += f"loss_test={loss_test.item():.4f}, "
                report_txt += f"acc_test={acc_test:.4f}"
                print(report_txt)

            torch.save(model, os.path.join(save_path,'model_last.pt'))

            # Save training log
            df = pd.DataFrame(records)
            save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
            df.to_csv(save_name_path, index=False)
            print(f"Training log saved to {save_name_path}")

            # Plot loss and accuracy
            plt.figure(figsize=(10,4))

            plt.subplot(1,2,1)
            plt.plot(df['epoch'], df['loss_test'], marker='o')
            plt.title('Test Loss')
            plt.ylabel('Loss')
            plt.xlabel('Epoch')
            plt.grid(True)
            plt.ylim(0, 1.1)
            # plt.legend()

            plt.subplot(1,2,2)
            plt.plot(df['epoch'], df['acc_test'], marker='o')
            plt.title('Test Accuracy')
            plt.ylabel('Accuracy')
            plt.xlabel('Epoch')
            plt.grid(True)
            plt.ylim(0, 1.1)
            # plt.legend()

            plt.tight_layout()
            save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
            plt.savefig(save_name_path)

            save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
            plt.savefig(save_name_path)
            plt.close()
# Out:
# poison_percent 40 epoch 0: loss_train=0.3217, acc_train=1.0000, loss_test=0.5188, acc_test=0.9214
# poison_percent 40 epoch 1: loss_train=1.0278, acc_train=0.0000, loss_test=0.5442, acc_test=0.8888
# poison_percent 40 epoch 2: loss_train=0.4251, acc_train=1.0000, loss_test=0.6710, acc_test=0.6112
# poison_percent 40 epoch 3: loss_train=0.1337, acc_train=1.0000, loss_test=0.5045, acc_test=0.8872
# poison_percent 40 epoch 4: loss_train=1.0032, acc_train=0.0000, loss_test=0.5243, acc_test=0.9031
# poison_percent 40 epoch 5: loss_train=0.6315, acc_train=1.0000, loss_test=0.4062, acc_test=0.9760
# poison_percent 40 epoch 6: loss_train=0.9965, acc_train=0.0000, loss_test=0.4988, acc_test=0.8888
# poison_percent 40 epoch 7: loss_train=0.4704, acc_train=1.0000, loss_test=0.5773, acc_test=0.7755
# poison_percent 40 epoch 8: loss_train=1.3202, acc_train=0.0000, loss_test=0.4641, acc_test=0.9056
# poison_percent 40 epoch 9: loss_train=0.4936, acc_train=1.0000, loss_test=0.5194, acc_test=0.8536
# poison_percent 40 epoch 10: loss_train=0.7771, acc_train=0.0000, loss_test=0.4540, acc_test=0.9189
# poison_percent 40 epoch 11: loss_train=0.4662, acc_train=1.0000, loss_test=0.6300, acc_test=0.6893
# poison_percent 40 epoch 12: loss_train=0.3815, acc_train=1.0000, loss_test=0.5443, acc_test=0.8020
# poison_percent 40 epoch 13: loss_train=1.0023, acc_train=0.0000, loss_test=0.4848, acc_test=0.8934
# poison_percent 40 epoch 14: loss_train=0.4412, acc_train=1.0000, loss_test=0.4744, acc_test=0.8888
# poison_percent 40 epoch 15: loss_train=0.9860, acc_train=0.0000, loss_test=0.4387, acc_test=0.9240
# poison_percent 40 epoch 16: loss_train=0.6948, acc_train=0.0000, loss_test=0.5487, acc_test=0.8153
# poison_percent 40 epoch 17: loss_train=0.8130, acc_train=0.0000, loss_test=0.5164, acc_test=0.8653
# poison_percent 40 epoch 18: loss_train=0.5172, acc_train=1.0000, loss_test=0.5953, acc_test=0.7158
# poison_percent 40 epoch 19: loss_train=0.8374, acc_train=0.0000, loss_test=0.4846, acc_test=0.8791
# poison_percent 40 epoch 20: loss_train=0.3247, acc_train=1.0000, loss_test=0.5761, acc_test=0.7087
# poison_percent 40 epoch 21: loss_train=0.1961, acc_train=1.0000, loss_test=0.5082, acc_test=0.8541
# poison_percent 40 epoch 22: loss_train=1.0311, acc_train=0.0000, loss_test=0.4711, acc_test=0.9010
# poison_percent 40 epoch 23: loss_train=0.6268, acc_train=1.0000, loss_test=0.4579, acc_test=0.8949
# poison_percent 40 epoch 24: loss_train=0.6884, acc_train=1.0000, loss_test=0.6505, acc_test=0.6556
# poison_percent 40 epoch 25: loss_train=1.2361, acc_train=0.0000, loss_test=0.7310, acc_test=0.5791
# poison_percent 40 epoch 26: loss_train=0.7614, acc_train=0.0000, loss_test=0.5919, acc_test=0.7429
# poison_percent 40 epoch 27: loss_train=0.6565, acc_train=1.0000, loss_test=0.5619, acc_test=0.7327
# poison_percent 40 epoch 28: loss_train=0.3901, acc_train=1.0000, loss_test=0.5920, acc_test=0.7408
# poison_percent 40 epoch 29: loss_train=0.5359, acc_train=1.0000, loss_test=0.5043, acc_test=0.8699
# poison_percent 40 epoch 30: loss_train=0.5467, acc_train=1.0000, loss_test=0.5369, acc_test=0.7464
# poison_percent 40 epoch 31: loss_train=0.4148, acc_train=1.0000, loss_test=0.5393, acc_test=0.7969
# poison_percent 40 epoch 32: loss_train=1.2097, acc_train=0.0000, loss_test=0.5527, acc_test=0.7770
# poison_percent 40 epoch 33: loss_train=0.8824, acc_train=0.0000, loss_test=0.5145, acc_test=0.8408
# poison_percent 40 epoch 34: loss_train=0.7192, acc_train=0.0000, loss_test=0.5047, acc_test=0.8689
# poison_percent 40 epoch 35: loss_train=0.5741, acc_train=1.0000, loss_test=0.6116, acc_test=0.6862
# poison_percent 40 epoch 36: loss_train=0.4135, acc_train=1.0000, loss_test=0.5877, acc_test=0.7653
# poison_percent 40 epoch 37: loss_train=0.5496, acc_train=1.0000, loss_test=0.5199, acc_test=0.8077
# poison_percent 40 epoch 38: loss_train=0.8492, acc_train=0.0000, loss_test=0.4570, acc_test=0.8964
# poison_percent 40 epoch 39: loss_train=0.4135, acc_train=1.0000, loss_test=0.5349, acc_test=0.7510
# poison_percent 40 epoch 40: loss_train=0.4989, acc_train=1.0000, loss_test=0.6042, acc_test=0.7372
# poison_percent 40 epoch 41: loss_train=0.6703, acc_train=1.0000, loss_test=0.4595, acc_test=0.9046
# poison_percent 40 epoch 42: loss_train=0.6762, acc_train=1.0000, loss_test=0.6408, acc_test=0.6903
# poison_percent 40 epoch 43: loss_train=0.7675, acc_train=0.0000, loss_test=0.4414, acc_test=0.9112
# poison_percent 40 epoch 44: loss_train=0.5965, acc_train=1.0000, loss_test=0.4220, acc_test=0.9260
# poison_percent 40 epoch 45: loss_train=0.5328, acc_train=1.0000, loss_test=0.5279, acc_test=0.7893
# poison_percent 40 epoch 46: loss_train=0.4693, acc_train=1.0000, loss_test=0.5798, acc_test=0.7908
# poison_percent 40 epoch 47: loss_train=0.5868, acc_train=1.0000, loss_test=0.5384, acc_test=0.7393
# poison_percent 40 epoch 48: loss_train=0.5470, acc_train=1.0000, loss_test=0.5523, acc_test=0.7719
# poison_percent 40 epoch 49: loss_train=0.6581, acc_train=1.0000, loss_test=0.5338, acc_test=0.7643
# poison_percent 40 epoch 50: loss_train=0.7276, acc_train=0.0000, loss_test=0.6650, acc_test=0.5781
# poison_percent 40 epoch 51: loss_train=0.3810, acc_train=1.0000, loss_test=0.5028, acc_test=0.8184
# poison_percent 40 epoch 52: loss_train=0.3726, acc_train=1.0000, loss_test=0.6733, acc_test=0.6041
# poison_percent 40 epoch 53: loss_train=1.0314, acc_train=0.0000, loss_test=0.5697, acc_test=0.7801
# poison_percent 40 epoch 54: loss_train=0.7257, acc_train=0.0000, loss_test=0.5272, acc_test=0.8311
# poison_percent 40 epoch 55: loss_train=0.4919, acc_train=1.0000, loss_test=0.6407, acc_test=0.6867
# poison_percent 40 epoch 56: loss_train=0.9504, acc_train=0.0000, loss_test=0.5209, acc_test=0.8321
# poison_percent 40 epoch 57: loss_train=0.4610, acc_train=1.0000, loss_test=0.5135, acc_test=0.8526
# poison_percent 40 epoch 58: loss_train=0.8759, acc_train=0.0000, loss_test=0.4629, acc_test=0.8959
# poison_percent 40 epoch 59: loss_train=0.4311, acc_train=1.0000, loss_test=0.5357, acc_test=0.8107
# poison_percent 40 epoch 60: loss_train=0.2581, acc_train=1.0000, loss_test=0.5384, acc_test=0.7857
# poison_percent 40 epoch 61: loss_train=0.4985, acc_train=1.0000, loss_test=0.5686, acc_test=0.7367
# poison_percent 40 epoch 62: loss_train=0.3752, acc_train=1.0000, loss_test=0.4772, acc_test=0.8765
# poison_percent 40 epoch 63: loss_train=0.4617, acc_train=1.0000, loss_test=0.4923, acc_test=0.8658
# poison_percent 40 epoch 64: loss_train=0.7656, acc_train=0.0000, loss_test=0.6058, acc_test=0.7071
# poison_percent 40 epoch 65: loss_train=0.2746, acc_train=1.0000, loss_test=0.4690, acc_test=0.8801
# poison_percent 40 epoch 66: loss_train=0.9531, acc_train=0.0000, loss_test=0.5296, acc_test=0.8321
# poison_percent 40 epoch 67: loss_train=0.9638, acc_train=0.0000, loss_test=0.5403, acc_test=0.8163
# poison_percent 40 epoch 68: loss_train=1.8017, acc_train=0.0000, loss_test=0.5157, acc_test=0.8480
# poison_percent 40 epoch 69: loss_train=0.1388, acc_train=1.0000, loss_test=0.5562, acc_test=0.7643
# poison_percent 40 epoch 70: loss_train=0.8821, acc_train=0.0000, loss_test=0.4796, acc_test=0.8883
# poison_percent 40 epoch 71: loss_train=1.0726, acc_train=0.0000, loss_test=0.5293, acc_test=0.8240
# poison_percent 40 epoch 72: loss_train=0.7955, acc_train=0.0000, loss_test=0.6270, acc_test=0.6878
# poison_percent 40 epoch 73: loss_train=0.8608, acc_train=0.0000, loss_test=0.6124, acc_test=0.6617
# poison_percent 40 epoch 74: loss_train=1.0717, acc_train=0.0000, loss_test=0.5885, acc_test=0.7219
# poison_percent 40 epoch 75: loss_train=0.6147, acc_train=1.0000, loss_test=0.6071, acc_test=0.7133
# poison_percent 40 epoch 76: loss_train=0.7345, acc_train=0.0000, loss_test=0.5972, acc_test=0.7556
# poison_percent 40 epoch 77: loss_train=0.4216, acc_train=1.0000, loss_test=0.4789, acc_test=0.8852
# poison_percent 40 epoch 78: loss_train=0.4169, acc_train=1.0000, loss_test=0.4912, acc_test=0.8638
# poison_percent 40 epoch 79: loss_train=0.9440, acc_train=0.0000, loss_test=0.5806, acc_test=0.7668
# poison_percent 40 epoch 80: loss_train=0.7502, acc_train=0.0000, loss_test=0.4615, acc_test=0.8827
# poison_percent 40 epoch 81: loss_train=1.4076, acc_train=0.0000, loss_test=0.4941, acc_test=0.8704
# poison_percent 40 epoch 82: loss_train=0.5620, acc_train=1.0000, loss_test=0.5450, acc_test=0.8051
# poison_percent 40 epoch 83: loss_train=1.1442, acc_train=0.0000, loss_test=0.5974, acc_test=0.7577
# poison_percent 40 epoch 84: loss_train=1.2804, acc_train=0.0000, loss_test=0.5507, acc_test=0.8087
# poison_percent 40 epoch 85: loss_train=0.5174, acc_train=1.0000, loss_test=0.5175, acc_test=0.7520
# poison_percent 40 epoch 86: loss_train=0.3472, acc_train=1.0000, loss_test=0.5483, acc_test=0.7806
# poison_percent 40 epoch 87: loss_train=1.1334, acc_train=0.0000, loss_test=0.6525, acc_test=0.6469
# poison_percent 40 epoch 88: loss_train=0.4911, acc_train=1.0000, loss_test=0.5160, acc_test=0.8316
# poison_percent 40 epoch 89: loss_train=0.2965, acc_train=1.0000, loss_test=0.5321, acc_test=0.7827
# poison_percent 40 epoch 90: loss_train=1.0453, acc_train=0.0000, loss_test=0.5068, acc_test=0.8622
# poison_percent 40 epoch 91: loss_train=0.2923, acc_train=1.0000, loss_test=0.5835, acc_test=0.6964
# poison_percent 40 epoch 92: loss_train=0.7132, acc_train=0.0000, loss_test=0.6414, acc_test=0.6526
# poison_percent 40 epoch 93: loss_train=1.1399, acc_train=0.0000, loss_test=0.4871, acc_test=0.8286
# poison_percent 40 epoch 94: loss_train=0.9472, acc_train=0.0000, loss_test=0.5081, acc_test=0.8459
# poison_percent 40 epoch 95: loss_train=0.5229, acc_train=1.0000, loss_test=0.4929, acc_test=0.8714
# poison_percent 40 epoch 96: loss_train=0.6969, acc_train=0.0000, loss_test=0.5133, acc_test=0.8510
# poison_percent 40 epoch 97: loss_train=0.6107, acc_train=1.0000, loss_test=0.4760, acc_test=0.8857
# poison_percent 40 epoch 98: loss_train=0.6070, acc_train=1.0000, loss_test=0.4845, acc_test=0.8577
# poison_percent 40 epoch 99: loss_train=1.3758, acc_train=0.0000, loss_test=0.6015, acc_test=0.6888
# Training log saved to ./results\CL_ModelN1L1_Batchsize1_rev0\poisoned_40percent\poisoned_40percent.csv
# poison_percent 40 epoch 0: loss_train=0.7364, acc_train=0.0000, loss_test=0.5634, acc_test=0.7240
# poison_percent 40 epoch 1: loss_train=0.5125, acc_train=1.0000, loss_test=0.6109, acc_test=0.7546
# poison_percent 40 epoch 2: loss_train=1.5877, acc_train=0.0000, loss_test=0.4887, acc_test=0.9209
# poison_percent 40 epoch 3: loss_train=0.5176, acc_train=1.0000, loss_test=0.5335, acc_test=0.8592
# poison_percent 40 epoch 4: loss_train=0.2654, acc_train=1.0000, loss_test=0.5113, acc_test=0.8770
# poison_percent 40 epoch 5: loss_train=0.3060, acc_train=1.0000, loss_test=0.4548, acc_test=0.9306
# poison_percent 40 epoch 6: loss_train=0.7784, acc_train=0.0000, loss_test=0.5772, acc_test=0.8173
# poison_percent 40 epoch 7: loss_train=0.6062, acc_train=1.0000, loss_test=0.5472, acc_test=0.7949
# poison_percent 40 epoch 8: loss_train=0.7784, acc_train=0.0000, loss_test=0.5959, acc_test=0.7133
# poison_percent 40 epoch 9: loss_train=0.8368, acc_train=0.0000, loss_test=0.5390, acc_test=0.8204
# poison_percent 40 epoch 10: loss_train=0.5005, acc_train=1.0000, loss_test=0.6115, acc_test=0.6342
# poison_percent 40 epoch 11: loss_train=1.3505, acc_train=0.0000, loss_test=0.5836, acc_test=0.7714
# poison_percent 40 epoch 12: loss_train=0.5027, acc_train=1.0000, loss_test=0.4732, acc_test=0.9082
# poison_percent 40 epoch 13: loss_train=0.5396, acc_train=1.0000, loss_test=0.5083, acc_test=0.8179
# poison_percent 40 epoch 14: loss_train=0.2629, acc_train=1.0000, loss_test=0.4572, acc_test=0.9306
# poison_percent 40 epoch 15: loss_train=0.7070, acc_train=0.0000, loss_test=0.7189, acc_test=0.5934
# poison_percent 40 epoch 16: loss_train=0.6994, acc_train=0.0000, loss_test=0.4914, acc_test=0.8582
# poison_percent 40 epoch 17: loss_train=0.4400, acc_train=1.0000, loss_test=0.5679, acc_test=0.7908
# poison_percent 40 epoch 18: loss_train=0.2873, acc_train=1.0000, loss_test=0.6115, acc_test=0.6969
# poison_percent 40 epoch 19: loss_train=1.2491, acc_train=0.0000, loss_test=0.5523, acc_test=0.7852
# poison_percent 40 epoch 20: loss_train=0.5019, acc_train=1.0000, loss_test=0.6075, acc_test=0.6704
# poison_percent 40 epoch 21: loss_train=0.5397, acc_train=1.0000, loss_test=0.4700, acc_test=0.8653
# poison_percent 40 epoch 22: loss_train=0.5829, acc_train=1.0000, loss_test=0.5751, acc_test=0.8031
# poison_percent 40 epoch 23: loss_train=0.8128, acc_train=0.0000, loss_test=0.5976, acc_test=0.7347
# poison_percent 40 epoch 24: loss_train=0.3406, acc_train=1.0000, loss_test=0.6673, acc_test=0.6327
# poison_percent 40 epoch 25: loss_train=0.6449, acc_train=1.0000, loss_test=0.5715, acc_test=0.7745
# poison_percent 40 epoch 26: loss_train=0.3445, acc_train=1.0000, loss_test=0.5681, acc_test=0.7597
# poison_percent 40 epoch 27: loss_train=0.6138, acc_train=1.0000, loss_test=0.3865, acc_test=0.9429
# poison_percent 40 epoch 28: loss_train=0.3536, acc_train=1.0000, loss_test=0.5109, acc_test=0.8760
# poison_percent 40 epoch 29: loss_train=0.5839, acc_train=1.0000, loss_test=0.5528, acc_test=0.7454
# poison_percent 40 epoch 30: loss_train=0.8486, acc_train=0.0000, loss_test=0.4663, acc_test=0.8781
# poison_percent 40 epoch 31: loss_train=0.4109, acc_train=1.0000, loss_test=0.5332, acc_test=0.8250
# poison_percent 40 epoch 32: loss_train=0.6430, acc_train=1.0000, loss_test=0.5768, acc_test=0.6934
# poison_percent 40 epoch 33: loss_train=0.7538, acc_train=0.0000, loss_test=0.5233, acc_test=0.8260
# poison_percent 40 epoch 34: loss_train=0.5945, acc_train=1.0000, loss_test=0.5897, acc_test=0.7566
# poison_percent 40 epoch 35: loss_train=1.0359, acc_train=0.0000, loss_test=0.4313, acc_test=0.9250
# poison_percent 40 epoch 36: loss_train=0.5331, acc_train=1.0000, loss_test=0.6342, acc_test=0.6903
# poison_percent 40 epoch 37: loss_train=0.3564, acc_train=1.0000, loss_test=0.5065, acc_test=0.8474
# poison_percent 40 epoch 38: loss_train=0.9630, acc_train=0.0000, loss_test=0.5852, acc_test=0.7449
# poison_percent 40 epoch 39: loss_train=0.6480, acc_train=1.0000, loss_test=0.5770, acc_test=0.6923
# poison_percent 40 epoch 40: loss_train=0.3642, acc_train=1.0000, loss_test=0.5659, acc_test=0.7281
# poison_percent 40 epoch 41: loss_train=1.4711, acc_train=0.0000, loss_test=0.5758, acc_test=0.7357
# poison_percent 40 epoch 42: loss_train=1.1724, acc_train=0.0000, loss_test=0.5615, acc_test=0.7515
# poison_percent 40 epoch 43: loss_train=1.6618, acc_train=0.0000, loss_test=0.5649, acc_test=0.7786
# poison_percent 40 epoch 44: loss_train=0.7942, acc_train=0.0000, loss_test=0.5062, acc_test=0.8602
# poison_percent 40 epoch 45: loss_train=0.4831, acc_train=1.0000, loss_test=0.5238, acc_test=0.8388
# poison_percent 40 epoch 46: loss_train=0.3256, acc_train=1.0000, loss_test=0.4774, acc_test=0.8964
# poison_percent 40 epoch 47: loss_train=0.3806, acc_train=1.0000, loss_test=0.4951, acc_test=0.8337
# poison_percent 40 epoch 48: loss_train=0.9662, acc_train=0.0000, loss_test=0.5218, acc_test=0.8311
# poison_percent 40 epoch 49: loss_train=0.3381, acc_train=1.0000, loss_test=0.5942, acc_test=0.6898
# poison_percent 40 epoch 50: loss_train=0.4094, acc_train=1.0000, loss_test=0.4053, acc_test=0.9352
# poison_percent 40 epoch 51: loss_train=0.8276, acc_train=0.0000, loss_test=0.6281, acc_test=0.6862
# poison_percent 40 epoch 52: loss_train=0.5596, acc_train=1.0000, loss_test=0.5706, acc_test=0.7821
# poison_percent 40 epoch 53: loss_train=0.9538, acc_train=0.0000, loss_test=0.4714, acc_test=0.8546
# poison_percent 40 epoch 54: loss_train=0.9994, acc_train=0.0000, loss_test=0.4470, acc_test=0.9046
# poison_percent 40 epoch 55: loss_train=1.4646, acc_train=0.0000, loss_test=0.6331, acc_test=0.6566
# poison_percent 40 epoch 56: loss_train=0.8151, acc_train=0.0000, loss_test=0.6460, acc_test=0.6908
# poison_percent 40 epoch 57: loss_train=0.7768, acc_train=0.0000, loss_test=0.6192, acc_test=0.7036
# poison_percent 40 epoch 58: loss_train=0.5161, acc_train=1.0000, loss_test=0.4950, acc_test=0.8612
# poison_percent 40 epoch 59: loss_train=0.5243, acc_train=1.0000, loss_test=0.5537, acc_test=0.8010
# poison_percent 40 epoch 60: loss_train=0.4673, acc_train=1.0000, loss_test=0.5365, acc_test=0.7878
# poison_percent 40 epoch 61: loss_train=0.2051, acc_train=1.0000, loss_test=0.4528, acc_test=0.8893
# poison_percent 40 epoch 62: loss_train=0.8786, acc_train=0.0000, loss_test=0.7064, acc_test=0.5893
# poison_percent 40 epoch 63: loss_train=0.2836, acc_train=1.0000, loss_test=0.5636, acc_test=0.7837
# poison_percent 40 epoch 64: loss_train=0.5930, acc_train=1.0000, loss_test=0.4124, acc_test=0.9301
# poison_percent 40 epoch 65: loss_train=0.9369, acc_train=0.0000, loss_test=0.6034, acc_test=0.7245
# poison_percent 40 epoch 66: loss_train=0.6277, acc_train=1.0000, loss_test=0.5944, acc_test=0.7362
# poison_percent 40 epoch 67: loss_train=0.1914, acc_train=1.0000, loss_test=0.4670, acc_test=0.8622
# poison_percent 40 epoch 68: loss_train=0.8635, acc_train=0.0000, loss_test=0.6045, acc_test=0.7066
# poison_percent 40 epoch 69: loss_train=0.2938, acc_train=1.0000, loss_test=0.4592, acc_test=0.8806
# poison_percent 40 epoch 70: loss_train=0.5048, acc_train=1.0000, loss_test=0.5208, acc_test=0.8332
# poison_percent 40 epoch 71: loss_train=0.8118, acc_train=0.0000, loss_test=0.5317, acc_test=0.8168
# poison_percent 40 epoch 72: loss_train=1.3340, acc_train=0.0000, loss_test=0.7366, acc_test=0.5913
# poison_percent 40 epoch 73: loss_train=0.5591, acc_train=1.0000, loss_test=0.5768, acc_test=0.7556
# poison_percent 40 epoch 74: loss_train=0.4499, acc_train=1.0000, loss_test=0.5262, acc_test=0.8296
# poison_percent 40 epoch 75: loss_train=0.0461, acc_train=1.0000, loss_test=0.4828, acc_test=0.8781
# poison_percent 40 epoch 76: loss_train=0.1808, acc_train=1.0000, loss_test=0.4985, acc_test=0.8638
# poison_percent 40 epoch 77: loss_train=0.4608, acc_train=1.0000, loss_test=0.6112, acc_test=0.7138
# poison_percent 40 epoch 78: loss_train=0.3322, acc_train=1.0000, loss_test=0.5120, acc_test=0.8526
# poison_percent 40 epoch 79: loss_train=0.4237, acc_train=1.0000, loss_test=0.5447, acc_test=0.8000
# poison_percent 40 epoch 80: loss_train=0.2379, acc_train=1.0000, loss_test=0.5188, acc_test=0.8107
# poison_percent 40 epoch 81: loss_train=1.3008, acc_train=0.0000, loss_test=0.6458, acc_test=0.6934
# poison_percent 40 epoch 82: loss_train=1.0238, acc_train=0.0000, loss_test=0.6407, acc_test=0.6791
# poison_percent 40 epoch 83: loss_train=0.3298, acc_train=1.0000, loss_test=0.5080, acc_test=0.8546
# poison_percent 40 epoch 84: loss_train=0.4008, acc_train=1.0000, loss_test=0.5357, acc_test=0.8015
# poison_percent 40 epoch 85: loss_train=1.2043, acc_train=0.0000, loss_test=0.5145, acc_test=0.8245
# poison_percent 40 epoch 86: loss_train=0.5874, acc_train=1.0000, loss_test=0.5316, acc_test=0.7276
# poison_percent 40 epoch 87: loss_train=2.1430, acc_train=0.0000, loss_test=0.4737, acc_test=0.8168
# poison_percent 40 epoch 88: loss_train=0.9557, acc_train=0.0000, loss_test=0.4831, acc_test=0.8500
# poison_percent 40 epoch 89: loss_train=0.4323, acc_train=1.0000, loss_test=0.3923, acc_test=0.9383
# poison_percent 40 epoch 90: loss_train=0.2065, acc_train=1.0000, loss_test=0.5242, acc_test=0.7954
# poison_percent 40 epoch 91: loss_train=0.5872, acc_train=1.0000, loss_test=0.4041, acc_test=0.9128
# poison_percent 40 epoch 92: loss_train=0.3560, acc_train=1.0000, loss_test=0.5698, acc_test=0.7827
# poison_percent 40 epoch 93: loss_train=0.4627, acc_train=1.0000, loss_test=0.6479, acc_test=0.6112
# poison_percent 40 epoch 94: loss_train=0.3025, acc_train=1.0000, loss_test=0.6907, acc_test=0.6276
# poison_percent 40 epoch 95: loss_train=0.5555, acc_train=1.0000, loss_test=0.5009, acc_test=0.8520
# poison_percent 40 epoch 96: loss_train=0.2876, acc_train=1.0000, loss_test=0.5426, acc_test=0.8031
# poison_percent 40 epoch 97: loss_train=0.4055, acc_train=1.0000, loss_test=0.5314, acc_test=0.7658
# poison_percent 40 epoch 98: loss_train=0.4763, acc_train=1.0000, loss_test=0.5262, acc_test=0.8444
# poison_percent 40 epoch 99: loss_train=0.4387, acc_train=1.0000, loss_test=0.6316, acc_test=0.7071
# Training log saved to ./results\CL_ModelN1L1_Batchsize1_rev1\poisoned_40percent\poisoned_40percent.csv
# poison_percent 40 epoch 0: loss_train=0.4465, acc_train=1.0000, loss_test=0.5818, acc_test=0.6980
# poison_percent 40 epoch 1: loss_train=0.4436, acc_train=1.0000, loss_test=0.4849, acc_test=0.9459
# poison_percent 40 epoch 2: loss_train=0.2655, acc_train=1.0000, loss_test=0.4836, acc_test=0.8663
# poison_percent 40 epoch 3: loss_train=0.5740, acc_train=1.0000, loss_test=0.5223, acc_test=0.8408
# poison_percent 40 epoch 4: loss_train=0.3784, acc_train=1.0000, loss_test=0.4046, acc_test=0.9582
# poison_percent 40 epoch 5: loss_train=0.7510, acc_train=0.0000, loss_test=0.4770, acc_test=0.7403
# poison_percent 40 epoch 6: loss_train=0.5444, acc_train=1.0000, loss_test=0.5140, acc_test=0.8893
# poison_percent 40 epoch 7: loss_train=0.5917, acc_train=1.0000, loss_test=0.4261, acc_test=0.9005
# poison_percent 40 epoch 8: loss_train=0.4057, acc_train=1.0000, loss_test=0.5935, acc_test=0.6888
# poison_percent 40 epoch 9: loss_train=0.7371, acc_train=0.0000, loss_test=0.5788, acc_test=0.7949
# poison_percent 40 epoch 10: loss_train=1.1558, acc_train=0.0000, loss_test=0.6429, acc_test=0.6847
# poison_percent 40 epoch 11: loss_train=0.4643, acc_train=1.0000, loss_test=0.5044, acc_test=0.8842
# poison_percent 40 epoch 12: loss_train=0.5629, acc_train=1.0000, loss_test=0.4314, acc_test=0.9561
# poison_percent 40 epoch 13: loss_train=0.8025, acc_train=0.0000, loss_test=0.4693, acc_test=0.9250
# poison_percent 40 epoch 14: loss_train=0.3159, acc_train=1.0000, loss_test=0.4460, acc_test=0.8995
# poison_percent 40 epoch 15: loss_train=0.7070, acc_train=0.0000, loss_test=0.5293, acc_test=0.8408
# poison_percent 40 epoch 16: loss_train=0.1801, acc_train=1.0000, loss_test=0.5084, acc_test=0.8577
# poison_percent 40 epoch 17: loss_train=0.4657, acc_train=1.0000, loss_test=0.5522, acc_test=0.8148
# poison_percent 40 epoch 18: loss_train=0.3847, acc_train=1.0000, loss_test=0.4830, acc_test=0.8893
# poison_percent 40 epoch 19: loss_train=0.6174, acc_train=1.0000, loss_test=0.5193, acc_test=0.8566
# poison_percent 40 epoch 20: loss_train=0.7289, acc_train=0.0000, loss_test=0.5877, acc_test=0.7235
# poison_percent 40 epoch 21: loss_train=0.4269, acc_train=1.0000, loss_test=0.5451, acc_test=0.8230
# poison_percent 40 epoch 22: loss_train=0.4233, acc_train=1.0000, loss_test=0.5022, acc_test=0.8765
# poison_percent 40 epoch 23: loss_train=0.3607, acc_train=1.0000, loss_test=0.6533, acc_test=0.6122
# poison_percent 40 epoch 24: loss_train=0.7845, acc_train=0.0000, loss_test=0.6495, acc_test=0.6735
# poison_percent 40 epoch 25: loss_train=2.1178, acc_train=0.0000, loss_test=0.4767, acc_test=0.8990
# poison_percent 40 epoch 26: loss_train=1.4027, acc_train=0.0000, loss_test=0.5897, acc_test=0.6827
# poison_percent 40 epoch 27: loss_train=0.2547, acc_train=1.0000, loss_test=0.6097, acc_test=0.7133
# poison_percent 40 epoch 28: loss_train=0.4432, acc_train=1.0000, loss_test=0.5161, acc_test=0.8561
# poison_percent 40 epoch 29: loss_train=0.7729, acc_train=0.0000, loss_test=0.6545, acc_test=0.6673
# poison_percent 40 epoch 30: loss_train=1.1540, acc_train=0.0000, loss_test=0.5650, acc_test=0.8066
# poison_percent 40 epoch 31: loss_train=0.8737, acc_train=0.0000, loss_test=0.5380, acc_test=0.8276
# poison_percent 40 epoch 32: loss_train=0.4313, acc_train=1.0000, loss_test=0.5586, acc_test=0.7852
# poison_percent 40 epoch 33: loss_train=0.5917, acc_train=1.0000, loss_test=0.5507, acc_test=0.8082
# poison_percent 40 epoch 34: loss_train=0.3810, acc_train=1.0000, loss_test=0.5217, acc_test=0.8556
# poison_percent 40 epoch 35: loss_train=0.5424, acc_train=1.0000, loss_test=0.5345, acc_test=0.8148
# poison_percent 40 epoch 36: loss_train=1.2443, acc_train=0.0000, loss_test=0.6248, acc_test=0.7036
# poison_percent 40 epoch 37: loss_train=1.1494, acc_train=0.0000, loss_test=0.4739, acc_test=0.8959
# poison_percent 40 epoch 38: loss_train=1.0264, acc_train=0.0000, loss_test=0.4002, acc_test=0.9449
# poison_percent 40 epoch 39: loss_train=0.4300, acc_train=1.0000, loss_test=0.4836, acc_test=0.8811
# poison_percent 40 epoch 40: loss_train=0.6665, acc_train=1.0000, loss_test=0.6092, acc_test=0.7015
# poison_percent 40 epoch 41: loss_train=0.8920, acc_train=0.0000, loss_test=0.5256, acc_test=0.7949
# poison_percent 40 epoch 42: loss_train=1.2755, acc_train=0.0000, loss_test=0.5422, acc_test=0.8327
# poison_percent 40 epoch 43: loss_train=0.8828, acc_train=0.0000, loss_test=0.5669, acc_test=0.7857
# poison_percent 40 epoch 44: loss_train=0.2744, acc_train=1.0000, loss_test=0.5390, acc_test=0.8102
# poison_percent 40 epoch 45: loss_train=0.2860, acc_train=1.0000, loss_test=0.4585, acc_test=0.9097
# poison_percent 40 epoch 46: loss_train=1.0890, acc_train=0.0000, loss_test=0.6177, acc_test=0.6811
# poison_percent 40 epoch 47: loss_train=0.0341, acc_train=1.0000, loss_test=0.4647, acc_test=0.8352
# poison_percent 40 epoch 48: loss_train=0.4263, acc_train=1.0000, loss_test=0.5638, acc_test=0.7811
# poison_percent 40 epoch 49: loss_train=0.2774, acc_train=1.0000, loss_test=0.5710, acc_test=0.7495
# poison_percent 40 epoch 50: loss_train=0.3615, acc_train=1.0000, loss_test=0.5922, acc_test=0.6857
# poison_percent 40 epoch 51: loss_train=0.8724, acc_train=0.0000, loss_test=0.5522, acc_test=0.7852
# poison_percent 40 epoch 52: loss_train=0.6554, acc_train=1.0000, loss_test=0.6829, acc_test=0.6291
# poison_percent 40 epoch 53: loss_train=0.2285, acc_train=1.0000, loss_test=0.5723, acc_test=0.7413
# poison_percent 40 epoch 54: loss_train=0.4469, acc_train=1.0000, loss_test=0.4317, acc_test=0.9245
# poison_percent 40 epoch 55: loss_train=0.6276, acc_train=1.0000, loss_test=0.6107, acc_test=0.7061
# poison_percent 40 epoch 56: loss_train=0.1635, acc_train=1.0000, loss_test=0.5405, acc_test=0.7974
# poison_percent 40 epoch 57: loss_train=0.6383, acc_train=1.0000, loss_test=0.4816, acc_test=0.8449
# poison_percent 40 epoch 58: loss_train=0.5788, acc_train=1.0000, loss_test=0.6308, acc_test=0.6857
# poison_percent 40 epoch 59: loss_train=1.3836, acc_train=0.0000, loss_test=0.4289, acc_test=0.8781
# poison_percent 40 epoch 60: loss_train=0.3253, acc_train=1.0000, loss_test=0.4472, acc_test=0.9128
# poison_percent 40 epoch 61: loss_train=0.4983, acc_train=1.0000, loss_test=0.5128, acc_test=0.8265
# poison_percent 40 epoch 62: loss_train=0.4339, acc_train=1.0000, loss_test=0.5338, acc_test=0.8061
# poison_percent 40 epoch 63: loss_train=0.4175, acc_train=1.0000, loss_test=0.5553, acc_test=0.7832
# poison_percent 40 epoch 64: loss_train=0.3771, acc_train=1.0000, loss_test=0.5482, acc_test=0.8061
# poison_percent 40 epoch 65: loss_train=0.7954, acc_train=0.0000, loss_test=0.4821, acc_test=0.8770
# poison_percent 40 epoch 66: loss_train=0.5025, acc_train=1.0000, loss_test=0.4763, acc_test=0.7816
# poison_percent 40 epoch 67: loss_train=0.6443, acc_train=1.0000, loss_test=0.5073, acc_test=0.8561
# poison_percent 40 epoch 68: loss_train=0.9404, acc_train=0.0000, loss_test=0.5202, acc_test=0.8413
# poison_percent 40 epoch 69: loss_train=0.6021, acc_train=1.0000, loss_test=0.4198, acc_test=0.9000
# poison_percent 40 epoch 70: loss_train=0.3607, acc_train=1.0000, loss_test=0.6029, acc_test=0.7296
# poison_percent 40 epoch 71: loss_train=0.4377, acc_train=1.0000, loss_test=0.4554, acc_test=0.8954
# poison_percent 40 epoch 72: loss_train=1.0315, acc_train=0.0000, loss_test=0.5792, acc_test=0.7735
# poison_percent 40 epoch 73: loss_train=0.4357, acc_train=1.0000, loss_test=0.5611, acc_test=0.8112
# poison_percent 40 epoch 74: loss_train=0.3287, acc_train=1.0000, loss_test=0.6234, acc_test=0.7036
# poison_percent 40 epoch 75: loss_train=0.4138, acc_train=1.0000, loss_test=0.4897, acc_test=0.8408
# poison_percent 40 epoch 76: loss_train=0.4160, acc_train=1.0000, loss_test=0.5177, acc_test=0.8301
# poison_percent 40 epoch 77: loss_train=0.6728, acc_train=1.0000, loss_test=0.6258, acc_test=0.7020
# poison_percent 40 epoch 78: loss_train=0.4968, acc_train=1.0000, loss_test=0.5694, acc_test=0.7699
# poison_percent 40 epoch 79: loss_train=0.6787, acc_train=1.0000, loss_test=0.6790, acc_test=0.6219
# poison_percent 40 epoch 80: loss_train=0.4894, acc_train=1.0000, loss_test=0.5486, acc_test=0.7857
# poison_percent 40 epoch 81: loss_train=0.8073, acc_train=0.0000, loss_test=0.6259, acc_test=0.6954
# poison_percent 40 epoch 82: loss_train=0.7620, acc_train=0.0000, loss_test=0.6106, acc_test=0.7071
# poison_percent 40 epoch 83: loss_train=0.6570, acc_train=1.0000, loss_test=0.5007, acc_test=0.8628
# poison_percent 40 epoch 84: loss_train=0.3633, acc_train=1.0000, loss_test=0.5922, acc_test=0.7281
# poison_percent 40 epoch 85: loss_train=0.2849, acc_train=1.0000, loss_test=0.6090, acc_test=0.6316
# poison_percent 40 epoch 86: loss_train=0.2727, acc_train=1.0000, loss_test=0.5355, acc_test=0.8077
# poison_percent 40 epoch 87: loss_train=1.1269, acc_train=0.0000, loss_test=0.6265, acc_test=0.6883
# poison_percent 40 epoch 88: loss_train=0.8569, acc_train=0.0000, loss_test=0.4555, acc_test=0.8923
# poison_percent 40 epoch 89: loss_train=0.9540, acc_train=0.0000, loss_test=0.5215, acc_test=0.8367
# poison_percent 40 epoch 90: loss_train=0.6597, acc_train=1.0000, loss_test=0.5979, acc_test=0.7087
# poison_percent 40 epoch 91: loss_train=0.4988, acc_train=1.0000, loss_test=0.4675, acc_test=0.8929
# poison_percent 40 epoch 92: loss_train=0.4902, acc_train=1.0000, loss_test=0.6853, acc_test=0.6571
# poison_percent 40 epoch 93: loss_train=0.3831, acc_train=1.0000, loss_test=0.4788, acc_test=0.8847
# poison_percent 40 epoch 94: loss_train=0.2327, acc_train=1.0000, loss_test=0.5420, acc_test=0.7888
# poison_percent 40 epoch 95: loss_train=0.1060, acc_train=1.0000, loss_test=0.5926, acc_test=0.7449
# poison_percent 40 epoch 96: loss_train=0.0877, acc_train=1.0000, loss_test=0.4408, acc_test=0.9087
# poison_percent 40 epoch 97: loss_train=0.6954, acc_train=0.0000, loss_test=0.4859, acc_test=0.8801
# poison_percent 40 epoch 98: loss_train=0.5016, acc_train=1.0000, loss_test=0.5174, acc_test=0.8260
# poison_percent 40 epoch 99: loss_train=0.4610, acc_train=1.0000, loss_test=0.5520, acc_test=0.8107
# Training log saved to ./results\CL_ModelN1L1_Batchsize1_rev2\poisoned_40percent\poisoned_40percent.csv
