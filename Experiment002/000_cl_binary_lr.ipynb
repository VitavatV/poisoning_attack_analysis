# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
class MNISTNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28*28, 1)
    def forward(self, x):
        x = self.fc1(x)
        x = torch.sigmoid(x)
        return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 1
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "./data/mnist_binary_poison/train"
TEST_PATH = "./data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
BATCH_SIZE_list = []
temp_bs = BATCH_SIZE
while temp_bs >= 1:
    BATCH_SIZE_list.append(temp_bs)
    temp_bs = temp_bs // 2

for rev in range(3):

    for experiment_bs in BATCH_SIZE_list:

        name_save_path = f"CL_ModelN1L1_Batchsize{experiment_bs}_rev{rev}"
        
        for i_poisoned in poison_n_list:
            percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

            # create directory
            NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
            save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
            # Remove existing directory if it exists
            if os.path.exists(save_path):
                shutil.rmtree(save_path)
            if not os.path.exists(save_path):
                os.makedirs(save_path)
            save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
            os.makedirs(save_all_path, exist_ok=True)
            
            # Load data
            X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                    poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                    select='Honest+Poisoned')
            X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
            # print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
            # print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

            if X_test.shape[0] == 0:
                raise ValueError("No valid test images found in the test directory!")

            X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
            y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
            X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
            y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

            model = MNISTNet().to(device)
            torch.save(model, os.path.join(save_path,'model_init.pt'))
            optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

            records = []

            # Training loop
            for epoch in range(EPOCHS):

                # Train
                model.train()
                
                #randomize the training data
                perm = torch.randperm(X_train_tensor.size(0))
                X_train_tensor = X_train_tensor[perm]
                y_train_tensor = y_train_tensor[perm]

                for start in range(0, X_train_tensor.size(0), experiment_bs):
                    end = start + experiment_bs
                    xb = X_train_tensor[start:end]
                    yb = y_train_tensor[start:end]
                    outputs = model(xb)
                    preds = (outputs >= 0.5).float()
                    acc_train = (preds == yb).float().mean().item()
                    loss_train = binary_cross_entropy(outputs, yb)
                    optimizer.zero_grad()
                    loss_train.backward()
                    optimizer.step()

                # Evaluate
                model.eval()
                with torch.no_grad():
                    outputs = model(X_test_tensor)
                    preds = (outputs >= 0.5).float()
                    loss_test = binary_cross_entropy(outputs, y_test_tensor)
                    acc_test = (preds == y_test_tensor).float().mean().item()
                records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                                'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                'loss_test': loss_test.item(), 'acc_test': acc_test})
                report_txt = f"poison_percent {percent_poisoned} "
                report_txt += f"epoch {epoch}: "
                report_txt += f"loss_train={loss_train.item():.4f}, "
                report_txt += f"acc_train={acc_train:.4f}, "
                report_txt += f"loss_test={loss_test.item():.4f}, "
                report_txt += f"acc_test={acc_test:.4f}"
                print(report_txt)

            torch.save(model, os.path.join(save_path,'model_last.pt'))

            # Save training log
            df = pd.DataFrame(records)
            save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
            df.to_csv(save_name_path, index=False)
            print(f"Training log saved to {save_name_path}")

            # Plot loss and accuracy
            plt.figure(figsize=(10,4))

            plt.subplot(1,2,1)
            plt.plot(df['epoch'], df['loss_test'], marker='o')
            plt.title('Test Loss')
            plt.ylabel('Loss')
            plt.xlabel('Epoch')
            plt.grid(True)
            plt.ylim(0, 1.1)
            # plt.legend()

            plt.subplot(1,2,2)
            plt.plot(df['epoch'], df['acc_test'], marker='o')
            plt.title('Test Accuracy')
            plt.ylabel('Accuracy')
            plt.xlabel('Epoch')
            plt.grid(True)
            plt.ylim(0, 1.1)
            # plt.legend()

            plt.tight_layout()
            save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
            plt.savefig(save_name_path)

            save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
            plt.savefig(save_name_path)
            plt.close()
# Out:
# poison_percent 0 epoch 0: loss_train=0.0285, acc_train=1.0000, loss_test=0.0030, acc_test=1.0000
# poison_percent 0 epoch 1: loss_train=0.0000, acc_train=1.0000, loss_test=0.0013, acc_test=0.9995
# poison_percent 0 epoch 2: loss_train=0.0000, acc_train=1.0000, loss_test=0.0014, acc_test=1.0000
# poison_percent 0 epoch 3: loss_train=0.0000, acc_train=1.0000, loss_test=0.0010, acc_test=0.9995
# poison_percent 0 epoch 4: loss_train=0.0000, acc_train=1.0000, loss_test=0.0011, acc_test=1.0000
# poison_percent 0 epoch 5: loss_train=0.0000, acc_train=1.0000, loss_test=0.0008, acc_test=1.0000
# poison_percent 0 epoch 6: loss_train=0.0000, acc_train=1.0000, loss_test=0.0007, acc_test=1.0000
# poison_percent 0 epoch 7: loss_train=0.0000, acc_train=1.0000, loss_test=0.0006, acc_test=1.0000
# poison_percent 0 epoch 8: loss_train=0.0000, acc_train=1.0000, loss_test=0.0005, acc_test=1.0000
# poison_percent 0 epoch 9: loss_train=0.0000, acc_train=1.0000, loss_test=0.0004, acc_test=1.0000
# poison_percent 0 epoch 10: loss_train=0.0000, acc_train=1.0000, loss_test=0.0004, acc_test=1.0000
# poison_percent 0 epoch 11: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 12: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 13: loss_train=0.0000, acc_train=1.0000, loss_test=0.0008, acc_test=1.0000
# poison_percent 0 epoch 14: loss_train=0.0000, acc_train=1.0000, loss_test=0.0006, acc_test=1.0000
# poison_percent 0 epoch 15: loss_train=0.0000, acc_train=1.0000, loss_test=0.0002, acc_test=1.0000
# poison_percent 0 epoch 16: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 17: loss_train=0.0000, acc_train=1.0000, loss_test=0.0002, acc_test=1.0000
# poison_percent 0 epoch 18: loss_train=0.0000, acc_train=1.0000, loss_test=0.0002, acc_test=1.0000
# poison_percent 0 epoch 19: loss_train=0.0000, acc_train=1.0000, loss_test=0.0004, acc_test=1.0000
# poison_percent 0 epoch 20: loss_train=0.0000, acc_train=1.0000, loss_test=0.0002, acc_test=1.0000
# poison_percent 0 epoch 21: loss_train=0.0000, acc_train=1.0000, loss_test=0.0002, acc_test=1.0000
# poison_percent 0 epoch 22: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 23: loss_train=0.0000, acc_train=1.0000, loss_test=0.0004, acc_test=1.0000
# poison_percent 0 epoch 24: loss_train=0.0000, acc_train=1.0000, loss_test=0.0002, acc_test=1.0000
# poison_percent 0 epoch 25: loss_train=0.0000, acc_train=1.0000, loss_test=0.0002, acc_test=1.0000
# poison_percent 0 epoch 26: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 27: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 28: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 29: loss_train=0.0000, acc_train=1.0000, loss_test=0.0004, acc_test=1.0000
# poison_percent 0 epoch 30: loss_train=0.0000, acc_train=1.0000, loss_test=0.0002, acc_test=1.0000
# poison_percent 0 epoch 31: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 32: loss_train=0.0000, acc_train=1.0000, loss_test=0.0004, acc_test=0.9995
# poison_percent 0 epoch 33: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 34: loss_train=0.0000, acc_train=1.0000, loss_test=0.0004, acc_test=1.0000
# poison_percent 0 epoch 35: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 36: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 37: loss_train=0.0000, acc_train=1.0000, loss_test=0.0008, acc_test=0.9995
# poison_percent 0 epoch 38: loss_train=0.0000, acc_train=1.0000, loss_test=0.0004, acc_test=1.0000
# poison_percent 0 epoch 39: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 40: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 41: loss_train=0.0000, acc_train=1.0000, loss_test=0.0004, acc_test=0.9995
# poison_percent 0 epoch 42: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 43: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 44: loss_train=0.0000, acc_train=1.0000, loss_test=0.0004, acc_test=1.0000
# poison_percent 0 epoch 45: loss_train=0.0000, acc_train=1.0000, loss_test=0.0007, acc_test=0.9995
# poison_percent 0 epoch 46: loss_train=0.0000, acc_train=1.0000, loss_test=0.0006, acc_test=0.9995
# poison_percent 0 epoch 47: loss_train=0.0000, acc_train=1.0000, loss_test=0.0004, acc_test=0.9995
# poison_percent 0 epoch 48: loss_train=0.0000, acc_train=1.0000, loss_test=0.0007, acc_test=0.9995
# poison_percent 0 epoch 49: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 50: loss_train=0.0000, acc_train=1.0000, loss_test=0.0003, acc_test=1.0000
# poison_percent 0 epoch 51: loss_train=0.0000, acc_train=1.0000, loss_test=0.0006, acc_test=0.9995
# poison_percent 0 epoch 52: loss_train=0.0000, acc_train=1.0000, loss_test=0.0004, acc_test=1.0000
# poison_percent 0 epoch 53: loss_train=0.0000, acc_train=1.0000, loss_test=0.0004, acc_test=1.0000
# poison_percent 0 epoch 54: loss_train=0.0000, acc_train=1.0000, loss_test=0.0005, acc_test=0.9995
# poison_percent 0 epoch 55: loss_train=0.0000, acc_train=1.0000, loss_test=0.0004, acc_test=1.0000
# poison_percent 0 epoch 56: loss_train=0.0000, acc_train=1.0000, loss_test=0.0008, acc_test=0.9995
# poison_percent 0 epoch 57: loss_train=0.0000, acc_train=1.0000, loss_test=0.0005, acc_test=0.9995
# poison_percent 0 epoch 58: loss_train=0.0000, acc_train=1.0000, loss_test=0.0005, acc_test=1.0000
# poison_percent 0 epoch 59: loss_train=0.0000, acc_train=1.0000, loss_test=0.0013, acc_test=0.9995
# poison_percent 0 epoch 60: loss_train=0.0000, acc_train=1.0000, loss_test=0.0008, acc_test=0.9995
# poison_percent 0 epoch 61: loss_train=0.0000, acc_train=1.0000, loss_test=0.0008, acc_test=0.9995
# poison_percent 0 epoch 62: loss_train=0.0000, acc_train=1.0000, loss_test=0.0015, acc_test=0.9995
# poison_percent 0 epoch 63: loss_train=0.0000, acc_train=1.0000, loss_test=0.0012, acc_test=0.9995
# poison_percent 0 epoch 64: loss_train=0.0000, acc_train=1.0000, loss_test=0.0006, acc_test=0.9995
# poison_percent 0 epoch 65: loss_train=0.0000, acc_train=1.0000, loss_test=0.0008, acc_test=0.9995
# poison_percent 0 epoch 66: loss_train=0.0000, acc_train=1.0000, loss_test=0.0016, acc_test=0.9995
# poison_percent 0 epoch 67: loss_train=0.0000, acc_train=1.0000, loss_test=0.0008, acc_test=0.9995
# poison_percent 0 epoch 68: loss_train=0.0000, acc_train=1.0000, loss_test=0.0012, acc_test=0.9995
# poison_percent 0 epoch 69: loss_train=0.0000, acc_train=1.0000, loss_test=0.0009, acc_test=0.9995
# poison_percent 0 epoch 70: loss_train=0.0000, acc_train=1.0000, loss_test=0.0007, acc_test=0.9995
# poison_percent 0 epoch 71: loss_train=0.0000, acc_train=1.0000, loss_test=0.0010, acc_test=0.9995
# poison_percent 0 epoch 72: loss_train=0.0000, acc_train=1.0000, loss_test=0.0014, acc_test=0.9995
# poison_percent 0 epoch 73: loss_train=0.0000, acc_train=1.0000, loss_test=0.0011, acc_test=0.9995
# poison_percent 0 epoch 74: loss_train=0.0000, acc_train=1.0000, loss_test=0.0011, acc_test=0.9995
# poison_percent 0 epoch 75: loss_train=0.0000, acc_train=1.0000, loss_test=0.0012, acc_test=0.9995
# poison_percent 0 epoch 76: loss_train=0.0000, acc_train=1.0000, loss_test=0.0013, acc_test=0.9995
# poison_percent 0 epoch 77: loss_train=0.0000, acc_train=1.0000, loss_test=0.0011, acc_test=0.9995
# poison_percent 0 epoch 78: loss_train=0.0000, acc_train=1.0000, loss_test=0.0014, acc_test=0.9995
# poison_percent 0 epoch 79: loss_train=0.0000, acc_train=1.0000, loss_test=0.0015, acc_test=0.9995
# poison_percent 0 epoch 80: loss_train=0.0000, acc_train=1.0000, loss_test=0.0010, acc_test=0.9995
# poison_percent 0 epoch 81: loss_train=0.0000, acc_train=1.0000, loss_test=0.0011, acc_test=0.9995
# poison_percent 0 epoch 82: loss_train=0.0000, acc_train=1.0000, loss_test=0.0012, acc_test=0.9995
# poison_percent 0 epoch 83: loss_train=0.0000, acc_train=1.0000, loss_test=0.0012, acc_test=0.9995
# poison_percent 0 epoch 84: loss_train=0.0000, acc_train=1.0000, loss_test=0.0012, acc_test=0.9995
# poison_percent 0 epoch 85: loss_train=0.0000, acc_train=1.0000, loss_test=0.0012, acc_test=0.9995
# poison_percent 0 epoch 86: loss_train=0.0000, acc_train=1.0000, loss_test=0.0014, acc_test=0.9995
# poison_percent 0 epoch 87: loss_train=0.0000, acc_train=1.0000, loss_test=0.0017, acc_test=0.9995
# poison_percent 0 epoch 88: loss_train=0.0000, acc_train=1.0000, loss_test=0.0013, acc_test=0.9995
# poison_percent 0 epoch 89: loss_train=0.0000, acc_train=1.0000, loss_test=0.0013, acc_test=0.9995
# poison_percent 0 epoch 90: loss_train=0.0000, acc_train=1.0000, loss_test=0.0015, acc_test=0.9995
# poison_percent 0 epoch 91: loss_train=0.0000, acc_train=1.0000, loss_test=0.0012, acc_test=0.9990
# poison_percent 0 epoch 92: loss_train=0.0000, acc_train=1.0000, loss_test=0.0013, acc_test=0.9995
# poison_percent 0 epoch 93: loss_train=0.0000, acc_train=1.0000, loss_test=0.0014, acc_test=0.9995
# poison_percent 0 epoch 94: loss_train=0.0000, acc_train=1.0000, loss_test=0.0014, acc_test=0.9995
# poison_percent 0 epoch 95: loss_train=0.0000, acc_train=1.0000, loss_test=0.0015, acc_test=0.9995
# poison_percent 0 epoch 96: loss_train=0.0000, acc_train=1.0000, loss_test=0.0013, acc_test=0.9990
# poison_percent 0 epoch 97: loss_train=0.0000, acc_train=1.0000, loss_test=0.0014, acc_test=0.9995
# poison_percent 0 epoch 98: loss_train=0.0000, acc_train=1.0000, loss_test=0.0014, acc_test=0.9995
# poison_percent 0 epoch 99: loss_train=0.0000, acc_train=1.0000, loss_test=0.0013, acc_test=0.9995
# Training log saved to ./results\CL_ModelN1L1_Batchsize1_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 epoch 0: loss_train=0.1982, acc_train=1.0000, loss_test=0.1727, acc_test=0.9969
# poison_percent 10 epoch 1: loss_train=0.0167, acc_train=1.0000, loss_test=0.1048, acc_test=0.9995
# poison_percent 10 epoch 2: loss_train=0.0704, acc_train=1.0000, loss_test=0.1120, acc_test=0.9969
# poison_percent 10 epoch 3: loss_train=0.0802, acc_train=1.0000, loss_test=0.1343, acc_test=0.9990
# poison_percent 10 epoch 4: loss_train=0.0363, acc_train=1.0000, loss_test=0.0931, acc_test=1.0000
# poison_percent 10 epoch 5: loss_train=0.0724, acc_train=1.0000, loss_test=0.1679, acc_test=0.9888
# poison_percent 10 epoch 6: loss_train=0.0877, acc_train=1.0000, loss_test=0.1127, acc_test=0.9974
# poison_percent 10 epoch 7: loss_train=0.1164, acc_train=1.0000, loss_test=0.1211, acc_test=0.9969
# poison_percent 10 epoch 8: loss_train=0.8961, acc_train=0.0000, loss_test=0.0924, acc_test=0.9969
# poison_percent 10 epoch 9: loss_train=0.0300, acc_train=1.0000, loss_test=0.2794, acc_test=0.9173
# poison_percent 10 epoch 10: loss_train=0.0661, acc_train=1.0000, loss_test=0.1106, acc_test=0.9954
# poison_percent 10 epoch 11: loss_train=0.0552, acc_train=1.0000, loss_test=0.1144, acc_test=0.9949
# poison_percent 10 epoch 12: loss_train=0.0697, acc_train=1.0000, loss_test=0.1184, acc_test=0.9964
# poison_percent 10 epoch 13: loss_train=0.5346, acc_train=1.0000, loss_test=0.1318, acc_test=0.9918
# poison_percent 10 epoch 14: loss_train=0.1795, acc_train=1.0000, loss_test=0.0873, acc_test=0.9974
# poison_percent 10 epoch 15: loss_train=0.1547, acc_train=1.0000, loss_test=0.1198, acc_test=0.9954
# poison_percent 10 epoch 16: loss_train=0.1225, acc_train=1.0000, loss_test=0.1294, acc_test=0.9949
# poison_percent 10 epoch 17: loss_train=1.3660, acc_train=0.0000, loss_test=0.1582, acc_test=0.9857
# poison_percent 10 epoch 18: loss_train=0.0768, acc_train=1.0000, loss_test=0.1375, acc_test=0.9929
# poison_percent 10 epoch 19: loss_train=0.1428, acc_train=1.0000, loss_test=0.1828, acc_test=0.9801
# poison_percent 10 epoch 20: loss_train=0.1204, acc_train=1.0000, loss_test=0.1112, acc_test=0.9949
# poison_percent 10 epoch 21: loss_train=0.0547, acc_train=1.0000, loss_test=0.1120, acc_test=0.9954
# poison_percent 10 epoch 22: loss_train=0.4952, acc_train=1.0000, loss_test=0.1451, acc_test=0.9944
# poison_percent 10 epoch 23: loss_train=0.1278, acc_train=1.0000, loss_test=0.1131, acc_test=0.9939
# poison_percent 10 epoch 24: loss_train=0.0865, acc_train=1.0000, loss_test=0.1359, acc_test=0.9923
# poison_percent 10 epoch 25: loss_train=0.0587, acc_train=1.0000, loss_test=0.1161, acc_test=0.9929
# poison_percent 10 epoch 26: loss_train=0.1469, acc_train=1.0000, loss_test=0.1291, acc_test=0.9929
# poison_percent 10 epoch 27: loss_train=2.7887, acc_train=0.0000, loss_test=0.1383, acc_test=0.9918
# poison_percent 10 epoch 28: loss_train=0.1611, acc_train=1.0000, loss_test=0.1006, acc_test=0.9949
# poison_percent 10 epoch 29: loss_train=0.0872, acc_train=1.0000, loss_test=0.1102, acc_test=0.9934
# poison_percent 10 epoch 30: loss_train=2.4543, acc_train=0.0000, loss_test=0.1398, acc_test=0.9862
# poison_percent 10 epoch 31: loss_train=0.0899, acc_train=1.0000, loss_test=0.1568, acc_test=0.9857
# poison_percent 10 epoch 32: loss_train=0.0983, acc_train=1.0000, loss_test=0.1370, acc_test=0.9903
# poison_percent 10 epoch 33: loss_train=0.0565, acc_train=1.0000, loss_test=0.0830, acc_test=0.9959
# poison_percent 10 epoch 34: loss_train=0.0864, acc_train=1.0000, loss_test=0.1102, acc_test=0.9918
# poison_percent 10 epoch 35: loss_train=3.0613, acc_train=0.0000, loss_test=0.0956, acc_test=0.9944
# poison_percent 10 epoch 36: loss_train=0.0638, acc_train=1.0000, loss_test=0.1048, acc_test=0.9934
# poison_percent 10 epoch 37: loss_train=0.1781, acc_train=1.0000, loss_test=0.1112, acc_test=0.9939
# poison_percent 10 epoch 38: loss_train=0.0585, acc_train=1.0000, loss_test=0.1209, acc_test=0.9883
# poison_percent 10 epoch 39: loss_train=0.0229, acc_train=1.0000, loss_test=0.1320, acc_test=0.9923
# poison_percent 10 epoch 40: loss_train=0.1584, acc_train=1.0000, loss_test=0.1461, acc_test=0.9832
# poison_percent 10 epoch 41: loss_train=0.3210, acc_train=1.0000, loss_test=0.1564, acc_test=0.9847
# poison_percent 10 epoch 42: loss_train=1.0019, acc_train=0.0000, loss_test=0.1204, acc_test=0.9923
# poison_percent 10 epoch 43: loss_train=0.0615, acc_train=1.0000, loss_test=0.1143, acc_test=0.9903
# poison_percent 10 epoch 44: loss_train=0.0577, acc_train=1.0000, loss_test=0.1006, acc_test=0.9939
# poison_percent 10 epoch 45: loss_train=0.0852, acc_train=1.0000, loss_test=0.1009, acc_test=0.9944
# poison_percent 10 epoch 46: loss_train=0.1308, acc_train=1.0000, loss_test=0.1487, acc_test=0.9883
# poison_percent 10 epoch 47: loss_train=0.0733, acc_train=1.0000, loss_test=0.1035, acc_test=0.9939
# poison_percent 10 epoch 48: loss_train=0.1305, acc_train=1.0000, loss_test=0.1355, acc_test=0.9862
# poison_percent 10 epoch 49: loss_train=0.0283, acc_train=1.0000, loss_test=0.1097, acc_test=0.9929
# poison_percent 10 epoch 50: loss_train=0.0460, acc_train=1.0000, loss_test=0.1264, acc_test=0.9903
# poison_percent 10 epoch 51: loss_train=0.0673, acc_train=1.0000, loss_test=0.1541, acc_test=0.9893
# poison_percent 10 epoch 52: loss_train=0.0388, acc_train=1.0000, loss_test=0.1406, acc_test=0.9816
# poison_percent 10 epoch 53: loss_train=0.0266, acc_train=1.0000, loss_test=0.0855, acc_test=0.9944
# poison_percent 10 epoch 54: loss_train=2.5143, acc_train=0.0000, loss_test=0.1253, acc_test=0.9878
# poison_percent 10 epoch 55: loss_train=0.1752, acc_train=1.0000, loss_test=0.1240, acc_test=0.9913
# poison_percent 10 epoch 56: loss_train=0.0829, acc_train=1.0000, loss_test=0.1709, acc_test=0.9847
# poison_percent 10 epoch 57: loss_train=0.1105, acc_train=1.0000, loss_test=0.1367, acc_test=0.9893
# poison_percent 10 epoch 58: loss_train=0.1436, acc_train=1.0000, loss_test=0.1684, acc_test=0.9827
# poison_percent 10 epoch 59: loss_train=0.3247, acc_train=1.0000, loss_test=0.1398, acc_test=0.9842
# poison_percent 10 epoch 60: loss_train=0.0826, acc_train=1.0000, loss_test=0.1169, acc_test=0.9913
# poison_percent 10 epoch 61: loss_train=0.0895, acc_train=1.0000, loss_test=0.1093, acc_test=0.9929
# poison_percent 10 epoch 62: loss_train=0.2960, acc_train=1.0000, loss_test=0.1159, acc_test=0.9903
# poison_percent 10 epoch 63: loss_train=0.0310, acc_train=1.0000, loss_test=0.1144, acc_test=0.9862
# poison_percent 10 epoch 64: loss_train=0.0515, acc_train=1.0000, loss_test=0.1026, acc_test=0.9918
# poison_percent 10 epoch 65: loss_train=0.0408, acc_train=1.0000, loss_test=0.1156, acc_test=0.9888
# poison_percent 10 epoch 66: loss_train=0.1731, acc_train=1.0000, loss_test=0.1285, acc_test=0.9918
# poison_percent 10 epoch 67: loss_train=0.1167, acc_train=1.0000, loss_test=0.1464, acc_test=0.9821
# poison_percent 10 epoch 68: loss_train=0.1274, acc_train=1.0000, loss_test=0.1267, acc_test=0.9847
# poison_percent 10 epoch 69: loss_train=0.0223, acc_train=1.0000, loss_test=0.0948, acc_test=0.9908
# poison_percent 10 epoch 70: loss_train=0.0864, acc_train=1.0000, loss_test=0.1302, acc_test=0.9903
# poison_percent 10 epoch 71: loss_train=2.4553, acc_train=0.0000, loss_test=0.1305, acc_test=0.9888
# poison_percent 10 epoch 72: loss_train=0.1362, acc_train=1.0000, loss_test=0.1379, acc_test=0.9878
# poison_percent 10 epoch 73: loss_train=0.0311, acc_train=1.0000, loss_test=0.1070, acc_test=0.9918
# poison_percent 10 epoch 74: loss_train=0.0573, acc_train=1.0000, loss_test=0.0932, acc_test=0.9908
# poison_percent 10 epoch 75: loss_train=0.0264, acc_train=1.0000, loss_test=0.1042, acc_test=0.9918
# poison_percent 10 epoch 76: loss_train=0.5106, acc_train=1.0000, loss_test=0.1561, acc_test=0.9811
# poison_percent 10 epoch 77: loss_train=0.5505, acc_train=1.0000, loss_test=0.1569, acc_test=0.9857
# poison_percent 10 epoch 78: loss_train=0.0547, acc_train=1.0000, loss_test=0.1170, acc_test=0.9898
# poison_percent 10 epoch 79: loss_train=0.5445, acc_train=1.0000, loss_test=0.1106, acc_test=0.9918
# poison_percent 10 epoch 80: loss_train=0.0752, acc_train=1.0000, loss_test=0.1244, acc_test=0.9883
# poison_percent 10 epoch 81: loss_train=0.0936, acc_train=1.0000, loss_test=0.1406, acc_test=0.9791
# poison_percent 10 epoch 82: loss_train=0.3504, acc_train=1.0000, loss_test=0.1085, acc_test=0.9893
# poison_percent 10 epoch 83: loss_train=0.0790, acc_train=1.0000, loss_test=0.1143, acc_test=0.9837
# poison_percent 10 epoch 84: loss_train=0.1462, acc_train=1.0000, loss_test=0.1146, acc_test=0.9883
# poison_percent 10 epoch 85: loss_train=0.2875, acc_train=1.0000, loss_test=0.1075, acc_test=0.9913
# poison_percent 10 epoch 86: loss_train=0.2755, acc_train=1.0000, loss_test=0.1476, acc_test=0.9770
# poison_percent 10 epoch 87: loss_train=0.1308, acc_train=1.0000, loss_test=0.1390, acc_test=0.9857
# poison_percent 10 epoch 88: loss_train=0.0510, acc_train=1.0000, loss_test=0.1726, acc_test=0.9694
# poison_percent 10 epoch 89: loss_train=0.0484, acc_train=1.0000, loss_test=0.1221, acc_test=0.9867
# poison_percent 10 epoch 90: loss_train=0.0792, acc_train=1.0000, loss_test=0.1185, acc_test=0.9888
# poison_percent 10 epoch 91: loss_train=0.2352, acc_train=1.0000, loss_test=0.1077, acc_test=0.9898
# poison_percent 10 epoch 92: loss_train=0.0967, acc_train=1.0000, loss_test=0.1315, acc_test=0.9893
# poison_percent 10 epoch 93: loss_train=0.0994, acc_train=1.0000, loss_test=0.1379, acc_test=0.9816
# poison_percent 10 epoch 94: loss_train=0.2917, acc_train=1.0000, loss_test=0.1666, acc_test=0.9719
# poison_percent 10 epoch 95: loss_train=0.6653, acc_train=1.0000, loss_test=0.1266, acc_test=0.9872
# poison_percent 10 epoch 96: loss_train=0.0492, acc_train=1.0000, loss_test=0.1362, acc_test=0.9837
# poison_percent 10 epoch 97: loss_train=0.0347, acc_train=1.0000, loss_test=0.1302, acc_test=0.9796
# poison_percent 10 epoch 98: loss_train=2.6374, acc_train=0.0000, loss_test=0.1119, acc_test=0.9903
# poison_percent 10 epoch 99: loss_train=0.0843, acc_train=1.0000, loss_test=0.0787, acc_test=0.9939
# Training log saved to ./results\CL_ModelN1L1_Batchsize1_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 epoch 0: loss_train=0.4175, acc_train=1.0000, loss_test=0.2572, acc_test=0.9985
# poison_percent 20 epoch 1: loss_train=1.6849, acc_train=0.0000, loss_test=0.2681, acc_test=0.9801
# poison_percent 20 epoch 2: loss_train=0.3108, acc_train=1.0000, loss_test=0.2648, acc_test=0.9862
# poison_percent 20 epoch 3: loss_train=0.1270, acc_train=1.0000, loss_test=0.2636, acc_test=0.9878
# poison_percent 20 epoch 4: loss_train=0.0878, acc_train=1.0000, loss_test=0.2463, acc_test=0.9923
# poison_percent 20 epoch 5: loss_train=0.1370, acc_train=1.0000, loss_test=0.1847, acc_test=0.9949
# poison_percent 20 epoch 6: loss_train=0.3349, acc_train=1.0000, loss_test=0.2513, acc_test=0.9908
# poison_percent 20 epoch 7: loss_train=0.1067, acc_train=1.0000, loss_test=0.2543, acc_test=0.9811
# poison_percent 20 epoch 8: loss_train=0.1115, acc_train=1.0000, loss_test=0.2614, acc_test=0.9847
# poison_percent 20 epoch 9: loss_train=0.0957, acc_train=1.0000, loss_test=0.2326, acc_test=0.9898
# poison_percent 20 epoch 10: loss_train=0.1397, acc_train=1.0000, loss_test=0.2125, acc_test=0.9893
# poison_percent 20 epoch 11: loss_train=0.2435, acc_train=1.0000, loss_test=0.2323, acc_test=0.9857
# poison_percent 20 epoch 12: loss_train=0.1287, acc_train=1.0000, loss_test=0.2291, acc_test=0.9908
# poison_percent 20 epoch 13: loss_train=0.2121, acc_train=1.0000, loss_test=0.2289, acc_test=0.9867
# poison_percent 20 epoch 14: loss_train=1.6824, acc_train=0.0000, loss_test=0.2465, acc_test=0.9760
# poison_percent 20 epoch 15: loss_train=0.0936, acc_train=1.0000, loss_test=0.1709, acc_test=0.9918
# poison_percent 20 epoch 16: loss_train=1.8148, acc_train=0.0000, loss_test=0.3361, acc_test=0.8980
# poison_percent 20 epoch 17: loss_train=0.2222, acc_train=1.0000, loss_test=0.2271, acc_test=0.9867
# poison_percent 20 epoch 18: loss_train=1.7335, acc_train=0.0000, loss_test=0.1948, acc_test=0.9898
# poison_percent 20 epoch 19: loss_train=0.1486, acc_train=1.0000, loss_test=0.2098, acc_test=0.9852
# poison_percent 20 epoch 20: loss_train=1.6117, acc_train=0.0000, loss_test=0.2276, acc_test=0.9878
# poison_percent 20 epoch 21: loss_train=0.1632, acc_train=1.0000, loss_test=0.2354, acc_test=0.9806
# poison_percent 20 epoch 22: loss_train=0.2588, acc_train=1.0000, loss_test=0.2545, acc_test=0.9827
# poison_percent 20 epoch 23: loss_train=0.1253, acc_train=1.0000, loss_test=0.2264, acc_test=0.9872
# poison_percent 20 epoch 24: loss_train=0.0802, acc_train=1.0000, loss_test=0.2259, acc_test=0.9888
# poison_percent 20 epoch 25: loss_train=0.2271, acc_train=1.0000, loss_test=0.2698, acc_test=0.9658
# poison_percent 20 epoch 26: loss_train=0.2846, acc_train=1.0000, loss_test=0.2927, acc_test=0.9827
# poison_percent 20 epoch 27: loss_train=1.4790, acc_train=0.0000, loss_test=0.2175, acc_test=0.9862
# poison_percent 20 epoch 28: loss_train=0.0277, acc_train=1.0000, loss_test=0.2232, acc_test=0.9867
# poison_percent 20 epoch 29: loss_train=2.2062, acc_train=0.0000, loss_test=0.2677, acc_test=0.9811
# poison_percent 20 epoch 30: loss_train=1.3989, acc_train=0.0000, loss_test=0.2838, acc_test=0.9776
# poison_percent 20 epoch 31: loss_train=0.2082, acc_train=1.0000, loss_test=0.2275, acc_test=0.9842
# poison_percent 20 epoch 32: loss_train=0.2196, acc_train=1.0000, loss_test=0.2543, acc_test=0.9801
# poison_percent 20 epoch 33: loss_train=0.2540, acc_train=1.0000, loss_test=0.2247, acc_test=0.9888
# poison_percent 20 epoch 34: loss_train=0.2910, acc_train=1.0000, loss_test=0.1991, acc_test=0.9867
# poison_percent 20 epoch 35: loss_train=0.4628, acc_train=1.0000, loss_test=0.2504, acc_test=0.9847
# poison_percent 20 epoch 36: loss_train=0.9026, acc_train=0.0000, loss_test=0.3798, acc_test=0.9240
# poison_percent 20 epoch 37: loss_train=0.2470, acc_train=1.0000, loss_test=0.3162, acc_test=0.9500
# poison_percent 20 epoch 38: loss_train=0.7228, acc_train=0.0000, loss_test=0.2002, acc_test=0.9898
# poison_percent 20 epoch 39: loss_train=0.1689, acc_train=1.0000, loss_test=0.2249, acc_test=0.9801
# poison_percent 20 epoch 40: loss_train=0.0907, acc_train=1.0000, loss_test=0.1857, acc_test=0.9883
# poison_percent 20 epoch 41: loss_train=1.4451, acc_train=0.0000, loss_test=0.2117, acc_test=0.9883
# poison_percent 20 epoch 42: loss_train=0.2393, acc_train=1.0000, loss_test=0.2742, acc_test=0.9633
# poison_percent 20 epoch 43: loss_train=0.2286, acc_train=1.0000, loss_test=0.2535, acc_test=0.9719
# poison_percent 20 epoch 44: loss_train=0.2245, acc_train=1.0000, loss_test=0.2477, acc_test=0.9719
# poison_percent 20 epoch 45: loss_train=0.3491, acc_train=1.0000, loss_test=0.2082, acc_test=0.9827
# poison_percent 20 epoch 46: loss_train=0.2212, acc_train=1.0000, loss_test=0.2832, acc_test=0.9770
# poison_percent 20 epoch 47: loss_train=0.2390, acc_train=1.0000, loss_test=0.2216, acc_test=0.9811
# poison_percent 20 epoch 48: loss_train=0.2377, acc_train=1.0000, loss_test=0.2939, acc_test=0.9648
# poison_percent 20 epoch 49: loss_train=0.2524, acc_train=1.0000, loss_test=0.2646, acc_test=0.9668
# poison_percent 20 epoch 50: loss_train=0.0943, acc_train=1.0000, loss_test=0.2171, acc_test=0.9872
# poison_percent 20 epoch 51: loss_train=0.3758, acc_train=1.0000, loss_test=0.2064, acc_test=0.9878
# poison_percent 20 epoch 52: loss_train=0.1700, acc_train=1.0000, loss_test=0.2497, acc_test=0.9633
# poison_percent 20 epoch 53: loss_train=1.7023, acc_train=0.0000, loss_test=0.2941, acc_test=0.9505
# poison_percent 20 epoch 54: loss_train=2.3834, acc_train=0.0000, loss_test=0.1796, acc_test=0.9898
# poison_percent 20 epoch 55: loss_train=0.0984, acc_train=1.0000, loss_test=0.1947, acc_test=0.9832
# poison_percent 20 epoch 56: loss_train=0.8904, acc_train=0.0000, loss_test=0.2289, acc_test=0.9842
# poison_percent 20 epoch 57: loss_train=0.0956, acc_train=1.0000, loss_test=0.2156, acc_test=0.9837
# poison_percent 20 epoch 58: loss_train=0.1341, acc_train=1.0000, loss_test=0.2776, acc_test=0.9745
# poison_percent 20 epoch 59: loss_train=0.0333, acc_train=1.0000, loss_test=0.1962, acc_test=0.9842
# poison_percent 20 epoch 60: loss_train=0.4142, acc_train=1.0000, loss_test=0.2549, acc_test=0.9801
# poison_percent 20 epoch 61: loss_train=0.3149, acc_train=1.0000, loss_test=0.2571, acc_test=0.9796
# poison_percent 20 epoch 62: loss_train=0.3023, acc_train=1.0000, loss_test=0.2613, acc_test=0.9745
# poison_percent 20 epoch 63: loss_train=0.0225, acc_train=1.0000, loss_test=0.1909, acc_test=0.9867
# poison_percent 20 epoch 64: loss_train=1.7788, acc_train=0.0000, loss_test=0.3013, acc_test=0.9250
# poison_percent 20 epoch 65: loss_train=1.5431, acc_train=0.0000, loss_test=0.2334, acc_test=0.9745
# poison_percent 20 epoch 66: loss_train=0.1335, acc_train=1.0000, loss_test=0.2249, acc_test=0.9827
# poison_percent 20 epoch 67: loss_train=0.2324, acc_train=1.0000, loss_test=0.3296, acc_test=0.9276
# poison_percent 20 epoch 68: loss_train=0.2254, acc_train=1.0000, loss_test=0.2028, acc_test=0.9872
# poison_percent 20 epoch 69: loss_train=1.4202, acc_train=0.0000, loss_test=0.2128, acc_test=0.9862
# poison_percent 20 epoch 70: loss_train=0.0467, acc_train=1.0000, loss_test=0.2667, acc_test=0.9740
# poison_percent 20 epoch 71: loss_train=0.5108, acc_train=1.0000, loss_test=0.2086, acc_test=0.9796
# poison_percent 20 epoch 72: loss_train=1.5203, acc_train=0.0000, loss_test=0.2580, acc_test=0.9505
# poison_percent 20 epoch 73: loss_train=0.0304, acc_train=1.0000, loss_test=0.2177, acc_test=0.9832
# poison_percent 20 epoch 74: loss_train=0.2021, acc_train=1.0000, loss_test=0.2215, acc_test=0.9719
# poison_percent 20 epoch 75: loss_train=0.0706, acc_train=1.0000, loss_test=0.2310, acc_test=0.9852
# poison_percent 20 epoch 76: loss_train=1.4694, acc_train=0.0000, loss_test=0.2373, acc_test=0.9821
# poison_percent 20 epoch 77: loss_train=0.7022, acc_train=0.0000, loss_test=0.3052, acc_test=0.9352
# poison_percent 20 epoch 78: loss_train=0.3327, acc_train=1.0000, loss_test=0.2915, acc_test=0.9541
# poison_percent 20 epoch 79: loss_train=0.2142, acc_train=1.0000, loss_test=0.2859, acc_test=0.9704
# poison_percent 20 epoch 80: loss_train=1.0016, acc_train=0.0000, loss_test=0.2637, acc_test=0.9740
# poison_percent 20 epoch 81: loss_train=0.1775, acc_train=1.0000, loss_test=0.2873, acc_test=0.9740
# poison_percent 20 epoch 82: loss_train=0.1398, acc_train=1.0000, loss_test=0.2417, acc_test=0.9847
# poison_percent 20 epoch 83: loss_train=0.1534, acc_train=1.0000, loss_test=0.1804, acc_test=0.9883
# poison_percent 20 epoch 84: loss_train=0.1506, acc_train=1.0000, loss_test=0.2735, acc_test=0.9587
# poison_percent 20 epoch 85: loss_train=0.0415, acc_train=1.0000, loss_test=0.2232, acc_test=0.9714
# poison_percent 20 epoch 86: loss_train=0.1795, acc_train=1.0000, loss_test=0.2241, acc_test=0.9847
# poison_percent 20 epoch 87: loss_train=0.3289, acc_train=1.0000, loss_test=0.2514, acc_test=0.9724
# poison_percent 20 epoch 88: loss_train=0.1778, acc_train=1.0000, loss_test=0.1954, acc_test=0.9867
# poison_percent 20 epoch 89: loss_train=1.2113, acc_train=0.0000, loss_test=0.2755, acc_test=0.9684
# poison_percent 20 epoch 90: loss_train=0.1373, acc_train=1.0000, loss_test=0.1977, acc_test=0.9816
# poison_percent 20 epoch 91: loss_train=0.0634, acc_train=1.0000, loss_test=0.2306, acc_test=0.9837
# poison_percent 20 epoch 92: loss_train=0.0822, acc_train=1.0000, loss_test=0.2634, acc_test=0.9668
# poison_percent 20 epoch 93: loss_train=0.1595, acc_train=1.0000, loss_test=0.2031, acc_test=0.9878
# poison_percent 20 epoch 94: loss_train=0.3025, acc_train=1.0000, loss_test=0.2407, acc_test=0.9745
# poison_percent 20 epoch 95: loss_train=0.1182, acc_train=1.0000, loss_test=0.2786, acc_test=0.9582
# poison_percent 20 epoch 96: loss_train=1.9710, acc_train=0.0000, loss_test=0.2536, acc_test=0.9658
# poison_percent 20 epoch 97: loss_train=0.1522, acc_train=1.0000, loss_test=0.2699, acc_test=0.9444
# poison_percent 20 epoch 98: loss_train=0.1991, acc_train=1.0000, loss_test=0.2001, acc_test=0.9821
# poison_percent 20 epoch 99: loss_train=1.1202, acc_train=0.0000, loss_test=0.1919, acc_test=0.9893
# Training log saved to ./results\CL_ModelN1L1_Batchsize1_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 epoch 0: loss_train=0.5004, acc_train=1.0000, loss_test=0.5576, acc_test=0.7056
# poison_percent 30 epoch 1: loss_train=1.2880, acc_train=0.0000, loss_test=0.4134, acc_test=0.9112
# poison_percent 30 epoch 2: loss_train=0.4710, acc_train=1.0000, loss_test=0.3130, acc_test=0.9648
# poison_percent 30 epoch 3: loss_train=0.6239, acc_train=1.0000, loss_test=0.3653, acc_test=0.9638
# poison_percent 30 epoch 4: loss_train=0.2858, acc_train=1.0000, loss_test=0.3396, acc_test=0.9816
# poison_percent 30 epoch 5: loss_train=0.2546, acc_train=1.0000, loss_test=0.3550, acc_test=0.9607
# poison_percent 30 epoch 6: loss_train=0.2411, acc_train=1.0000, loss_test=0.3449, acc_test=0.9597
# poison_percent 30 epoch 7: loss_train=0.7129, acc_train=0.0000, loss_test=0.4312, acc_test=0.9413
# poison_percent 30 epoch 8: loss_train=2.6459, acc_train=0.0000, loss_test=0.4038, acc_test=0.9520
# poison_percent 30 epoch 9: loss_train=0.7373, acc_train=0.0000, loss_test=0.4616, acc_test=0.9276
# poison_percent 30 epoch 10: loss_train=0.4191, acc_train=1.0000, loss_test=0.2875, acc_test=0.9878
# poison_percent 30 epoch 11: loss_train=1.2807, acc_train=0.0000, loss_test=0.3194, acc_test=0.9811
# poison_percent 30 epoch 12: loss_train=1.0121, acc_train=0.0000, loss_test=0.3972, acc_test=0.9546
# poison_percent 30 epoch 13: loss_train=0.5552, acc_train=1.0000, loss_test=0.3669, acc_test=0.9658
# poison_percent 30 epoch 14: loss_train=0.3476, acc_train=1.0000, loss_test=0.3770, acc_test=0.9418
# poison_percent 30 epoch 15: loss_train=1.1799, acc_train=0.0000, loss_test=0.3831, acc_test=0.9745
# poison_percent 30 epoch 16: loss_train=0.2085, acc_train=1.0000, loss_test=0.3201, acc_test=0.9694
# poison_percent 30 epoch 17: loss_train=0.2818, acc_train=1.0000, loss_test=0.3469, acc_test=0.9653
# poison_percent 30 epoch 18: loss_train=0.7516, acc_train=0.0000, loss_test=0.4163, acc_test=0.8689
# poison_percent 30 epoch 19: loss_train=0.5173, acc_train=1.0000, loss_test=0.4123, acc_test=0.9429
# poison_percent 30 epoch 20: loss_train=1.0816, acc_train=0.0000, loss_test=0.4027, acc_test=0.9464
# poison_percent 30 epoch 21: loss_train=0.2824, acc_train=1.0000, loss_test=0.3410, acc_test=0.9551
# poison_percent 30 epoch 22: loss_train=1.3826, acc_train=0.0000, loss_test=0.3126, acc_test=0.9740
# poison_percent 30 epoch 23: loss_train=0.5273, acc_train=1.0000, loss_test=0.4085, acc_test=0.9418
# poison_percent 30 epoch 24: loss_train=0.1070, acc_train=1.0000, loss_test=0.3172, acc_test=0.9663
# poison_percent 30 epoch 25: loss_train=0.3312, acc_train=1.0000, loss_test=0.3584, acc_test=0.9663
# poison_percent 30 epoch 26: loss_train=1.1986, acc_train=0.0000, loss_test=0.3225, acc_test=0.9628
# poison_percent 30 epoch 27: loss_train=1.1869, acc_train=0.0000, loss_test=0.3739, acc_test=0.9403
# poison_percent 30 epoch 28: loss_train=0.5816, acc_train=1.0000, loss_test=0.4184, acc_test=0.9291
# poison_percent 30 epoch 29: loss_train=0.5333, acc_train=1.0000, loss_test=0.4361, acc_test=0.9133
# poison_percent 30 epoch 30: loss_train=0.3243, acc_train=1.0000, loss_test=0.3725, acc_test=0.9556
# poison_percent 30 epoch 31: loss_train=0.4036, acc_train=1.0000, loss_test=0.3500, acc_test=0.9597
# poison_percent 30 epoch 32: loss_train=0.2658, acc_train=1.0000, loss_test=0.4052, acc_test=0.9107
# poison_percent 30 epoch 33: loss_train=0.5271, acc_train=1.0000, loss_test=0.3646, acc_test=0.9515
# poison_percent 30 epoch 34: loss_train=0.3455, acc_train=1.0000, loss_test=0.3946, acc_test=0.9464
# poison_percent 30 epoch 35: loss_train=0.8200, acc_train=0.0000, loss_test=0.4664, acc_test=0.7821
# poison_percent 30 epoch 36: loss_train=0.1384, acc_train=1.0000, loss_test=0.4689, acc_test=0.8413
# poison_percent 30 epoch 37: loss_train=1.2033, acc_train=0.0000, loss_test=0.4250, acc_test=0.9199
# poison_percent 30 epoch 38: loss_train=1.1307, acc_train=0.0000, loss_test=0.3980, acc_test=0.9388
# poison_percent 30 epoch 39: loss_train=0.2660, acc_train=1.0000, loss_test=0.3810, acc_test=0.9546
# poison_percent 30 epoch 40: loss_train=0.7902, acc_train=0.0000, loss_test=0.4120, acc_test=0.9357
# poison_percent 30 epoch 41: loss_train=0.6746, acc_train=1.0000, loss_test=0.5074, acc_test=0.7923
# poison_percent 30 epoch 42: loss_train=0.4828, acc_train=1.0000, loss_test=0.3022, acc_test=0.9730
# poison_percent 30 epoch 43: loss_train=1.1106, acc_train=0.0000, loss_test=0.3292, acc_test=0.9663
# poison_percent 30 epoch 44: loss_train=0.1245, acc_train=1.0000, loss_test=0.4192, acc_test=0.9153
# poison_percent 30 epoch 45: loss_train=0.1834, acc_train=1.0000, loss_test=0.4052, acc_test=0.9056
# poison_percent 30 epoch 46: loss_train=0.6676, acc_train=1.0000, loss_test=0.3041, acc_test=0.9663
# poison_percent 30 epoch 47: loss_train=1.0941, acc_train=0.0000, loss_test=0.3755, acc_test=0.9321
# poison_percent 30 epoch 48: loss_train=1.1082, acc_train=0.0000, loss_test=0.2882, acc_test=0.9801
# poison_percent 30 epoch 49: loss_train=0.2716, acc_train=1.0000, loss_test=0.4161, acc_test=0.9102
# poison_percent 30 epoch 50: loss_train=0.4674, acc_train=1.0000, loss_test=0.3254, acc_test=0.9689
# poison_percent 30 epoch 51: loss_train=1.0496, acc_train=0.0000, loss_test=0.3672, acc_test=0.9469
# poison_percent 30 epoch 52: loss_train=0.2441, acc_train=1.0000, loss_test=0.3528, acc_test=0.9413
# poison_percent 30 epoch 53: loss_train=0.9406, acc_train=0.0000, loss_test=0.3661, acc_test=0.9566
# poison_percent 30 epoch 54: loss_train=0.2139, acc_train=1.0000, loss_test=0.3352, acc_test=0.9704
# poison_percent 30 epoch 55: loss_train=0.3772, acc_train=1.0000, loss_test=0.3056, acc_test=0.9684
# poison_percent 30 epoch 56: loss_train=0.4311, acc_train=1.0000, loss_test=0.3423, acc_test=0.9673
# poison_percent 30 epoch 57: loss_train=2.0238, acc_train=0.0000, loss_test=0.2783, acc_test=0.9832
# poison_percent 30 epoch 58: loss_train=2.5592, acc_train=0.0000, loss_test=0.3710, acc_test=0.9301
# poison_percent 30 epoch 59: loss_train=0.4466, acc_train=1.0000, loss_test=0.3749, acc_test=0.9286
# poison_percent 30 epoch 60: loss_train=1.7017, acc_train=0.0000, loss_test=0.3373, acc_test=0.9673
# poison_percent 30 epoch 61: loss_train=0.4656, acc_train=1.0000, loss_test=0.4158, acc_test=0.9224
# poison_percent 30 epoch 62: loss_train=0.3668, acc_train=1.0000, loss_test=0.4773, acc_test=0.8434
# poison_percent 30 epoch 63: loss_train=0.4179, acc_train=1.0000, loss_test=0.3884, acc_test=0.9393
# poison_percent 30 epoch 64: loss_train=0.3616, acc_train=1.0000, loss_test=0.3451, acc_test=0.9607
# poison_percent 30 epoch 65: loss_train=0.7347, acc_train=0.0000, loss_test=0.4130, acc_test=0.8704
# poison_percent 30 epoch 66: loss_train=1.4639, acc_train=0.0000, loss_test=0.3745, acc_test=0.9378
# poison_percent 30 epoch 67: loss_train=0.6189, acc_train=1.0000, loss_test=0.4414, acc_test=0.8939
# poison_percent 30 epoch 68: loss_train=0.2759, acc_train=1.0000, loss_test=0.3892, acc_test=0.9245
# poison_percent 30 epoch 69: loss_train=0.0956, acc_train=1.0000, loss_test=0.3261, acc_test=0.9612
# poison_percent 30 epoch 70: loss_train=0.2794, acc_train=1.0000, loss_test=0.3829, acc_test=0.9112
# poison_percent 30 epoch 71: loss_train=0.1255, acc_train=1.0000, loss_test=0.2966, acc_test=0.9633
# poison_percent 30 epoch 72: loss_train=0.7251, acc_train=0.0000, loss_test=0.4092, acc_test=0.9214
# poison_percent 30 epoch 73: loss_train=0.4262, acc_train=1.0000, loss_test=0.4182, acc_test=0.8673
# poison_percent 30 epoch 74: loss_train=0.2468, acc_train=1.0000, loss_test=0.4528, acc_test=0.8577
# poison_percent 30 epoch 75: loss_train=0.5621, acc_train=1.0000, loss_test=0.4062, acc_test=0.8898
# poison_percent 30 epoch 76: loss_train=0.1679, acc_train=1.0000, loss_test=0.3289, acc_test=0.9612
# poison_percent 30 epoch 77: loss_train=1.0001, acc_train=0.0000, loss_test=0.3671, acc_test=0.9434
# poison_percent 30 epoch 78: loss_train=0.4991, acc_train=1.0000, loss_test=0.3901, acc_test=0.9311
# poison_percent 30 epoch 79: loss_train=0.3118, acc_train=1.0000, loss_test=0.3255, acc_test=0.9408
# poison_percent 30 epoch 80: loss_train=0.5613, acc_train=1.0000, loss_test=0.3486, acc_test=0.9352
# poison_percent 30 epoch 81: loss_train=0.0817, acc_train=1.0000, loss_test=0.3555, acc_test=0.9577
# poison_percent 30 epoch 82: loss_train=0.0405, acc_train=1.0000, loss_test=0.2514, acc_test=0.9821
# poison_percent 30 epoch 83: loss_train=1.6510, acc_train=0.0000, loss_test=0.2937, acc_test=0.9816
# poison_percent 30 epoch 84: loss_train=0.6942, acc_train=0.0000, loss_test=0.4446, acc_test=0.9041
# poison_percent 30 epoch 85: loss_train=0.3303, acc_train=1.0000, loss_test=0.3026, acc_test=0.9704
# poison_percent 30 epoch 86: loss_train=1.1475, acc_train=0.0000, loss_test=0.3525, acc_test=0.9541
# poison_percent 30 epoch 87: loss_train=0.1871, acc_train=1.0000, loss_test=0.3023, acc_test=0.9694
# poison_percent 30 epoch 88: loss_train=0.2181, acc_train=1.0000, loss_test=0.3559, acc_test=0.9551
# poison_percent 30 epoch 89: loss_train=0.6099, acc_train=1.0000, loss_test=0.4596, acc_test=0.8913
# poison_percent 30 epoch 90: loss_train=1.0228, acc_train=0.0000, loss_test=0.3898, acc_test=0.9408
# poison_percent 30 epoch 91: loss_train=0.3563, acc_train=1.0000, loss_test=0.3720, acc_test=0.9372
# poison_percent 30 epoch 92: loss_train=1.6577, acc_train=0.0000, loss_test=0.3584, acc_test=0.9515
# poison_percent 30 epoch 93: loss_train=0.3807, acc_train=1.0000, loss_test=0.3632, acc_test=0.9378
# poison_percent 30 epoch 94: loss_train=1.5355, acc_train=0.0000, loss_test=0.4468, acc_test=0.8587
# poison_percent 30 epoch 95: loss_train=0.0732, acc_train=1.0000, loss_test=0.3363, acc_test=0.9434
# poison_percent 30 epoch 96: loss_train=0.2597, acc_train=1.0000, loss_test=0.3959, acc_test=0.9026
# poison_percent 30 epoch 97: loss_train=0.1964, acc_train=1.0000, loss_test=0.3838, acc_test=0.9398
# poison_percent 30 epoch 98: loss_train=0.3797, acc_train=1.0000, loss_test=0.3621, acc_test=0.9413
# poison_percent 30 epoch 99: loss_train=0.2991, acc_train=1.0000, loss_test=0.3803, acc_test=0.9372
# Training log saved to ./results\CL_ModelN1L1_Batchsize1_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 epoch 0: loss_train=0.5037, acc_train=1.0000, loss_test=0.5853, acc_test=0.8474
# poison_percent 40 epoch 1: loss_train=0.9176, acc_train=0.0000, loss_test=0.5301, acc_test=0.9071
# poison_percent 40 epoch 2: loss_train=0.5511, acc_train=1.0000, loss_test=0.6464, acc_test=0.6765
# poison_percent 40 epoch 3: loss_train=0.6867, acc_train=1.0000, loss_test=0.4469, acc_test=0.9526
# poison_percent 40 epoch 4: loss_train=0.1821, acc_train=1.0000, loss_test=0.4628, acc_test=0.8872
# poison_percent 40 epoch 5: loss_train=0.3191, acc_train=1.0000, loss_test=0.5546, acc_test=0.8204
# poison_percent 40 epoch 6: loss_train=0.7734, acc_train=0.0000, loss_test=0.4744, acc_test=0.9393
# poison_percent 40 epoch 7: loss_train=0.5778, acc_train=1.0000, loss_test=0.6177, acc_test=0.7000
# poison_percent 40 epoch 8: loss_train=0.7981, acc_train=0.0000, loss_test=0.6602, acc_test=0.6418
# poison_percent 40 epoch 9: loss_train=0.7606, acc_train=0.0000, loss_test=0.5300, acc_test=0.8423
# poison_percent 40 epoch 10: loss_train=0.5635, acc_train=1.0000, loss_test=0.5337, acc_test=0.7255
# poison_percent 40 epoch 11: loss_train=0.8907, acc_train=0.0000, loss_test=0.5017, acc_test=0.8878
# poison_percent 40 epoch 12: loss_train=0.3574, acc_train=1.0000, loss_test=0.9083, acc_test=0.5230
# poison_percent 40 epoch 13: loss_train=0.5214, acc_train=1.0000, loss_test=0.5596, acc_test=0.6704
# poison_percent 40 epoch 14: loss_train=0.5291, acc_train=1.0000, loss_test=0.5929, acc_test=0.7694
# poison_percent 40 epoch 15: loss_train=0.7995, acc_train=0.0000, loss_test=0.5227, acc_test=0.8429
# poison_percent 40 epoch 16: loss_train=0.3258, acc_train=1.0000, loss_test=0.5419, acc_test=0.8291
# poison_percent 40 epoch 17: loss_train=0.2015, acc_train=1.0000, loss_test=0.4792, acc_test=0.9061
# poison_percent 40 epoch 18: loss_train=0.4298, acc_train=1.0000, loss_test=0.5186, acc_test=0.8673
# poison_percent 40 epoch 19: loss_train=1.1543, acc_train=0.0000, loss_test=0.6395, acc_test=0.6939
# poison_percent 40 epoch 20: loss_train=0.3092, acc_train=1.0000, loss_test=0.5311, acc_test=0.8296
# poison_percent 40 epoch 21: loss_train=0.4580, acc_train=1.0000, loss_test=0.5461, acc_test=0.8224
# poison_percent 40 epoch 22: loss_train=0.6501, acc_train=1.0000, loss_test=0.5766, acc_test=0.7776
# poison_percent 40 epoch 23: loss_train=0.2350, acc_train=1.0000, loss_test=0.6860, acc_test=0.5832
# poison_percent 40 epoch 24: loss_train=0.3581, acc_train=1.0000, loss_test=0.4885, acc_test=0.8918
# poison_percent 40 epoch 25: loss_train=0.4463, acc_train=1.0000, loss_test=0.6639, acc_test=0.6337
# poison_percent 40 epoch 26: loss_train=0.5719, acc_train=1.0000, loss_test=0.4670, acc_test=0.9209
# poison_percent 40 epoch 27: loss_train=0.4361, acc_train=1.0000, loss_test=0.4359, acc_test=0.9372
# poison_percent 40 epoch 28: loss_train=1.5195, acc_train=0.0000, loss_test=0.3647, acc_test=0.9531
# poison_percent 40 epoch 29: loss_train=0.5770, acc_train=1.0000, loss_test=0.5856, acc_test=0.7112
# poison_percent 40 epoch 30: loss_train=0.8096, acc_train=0.0000, loss_test=0.4414, acc_test=0.8898
# poison_percent 40 epoch 31: loss_train=1.0976, acc_train=0.0000, loss_test=0.6041, acc_test=0.7153
# poison_percent 40 epoch 32: loss_train=0.7417, acc_train=0.0000, loss_test=0.6802, acc_test=0.5393
# poison_percent 40 epoch 33: loss_train=0.1953, acc_train=1.0000, loss_test=0.4736, acc_test=0.8704
# poison_percent 40 epoch 34: loss_train=0.6236, acc_train=1.0000, loss_test=0.5552, acc_test=0.8000
# poison_percent 40 epoch 35: loss_train=1.3934, acc_train=0.0000, loss_test=0.5919, acc_test=0.7143
# poison_percent 40 epoch 36: loss_train=0.3344, acc_train=1.0000, loss_test=0.4439, acc_test=0.9097
# poison_percent 40 epoch 37: loss_train=0.4507, acc_train=1.0000, loss_test=0.4818, acc_test=0.8990
# poison_percent 40 epoch 38: loss_train=0.5664, acc_train=1.0000, loss_test=0.5328, acc_test=0.7893
# poison_percent 40 epoch 39: loss_train=0.9500, acc_train=0.0000, loss_test=0.6477, acc_test=0.6796
# poison_percent 40 epoch 40: loss_train=0.8548, acc_train=0.0000, loss_test=0.5943, acc_test=0.7439
# poison_percent 40 epoch 41: loss_train=0.6138, acc_train=1.0000, loss_test=0.5780, acc_test=0.7490
# poison_percent 40 epoch 42: loss_train=1.5794, acc_train=0.0000, loss_test=0.4597, acc_test=0.8827
# poison_percent 40 epoch 43: loss_train=0.1121, acc_train=1.0000, loss_test=0.7494, acc_test=0.5638
# poison_percent 40 epoch 44: loss_train=0.8929, acc_train=0.0000, loss_test=0.4443, acc_test=0.9153
# poison_percent 40 epoch 45: loss_train=0.8421, acc_train=0.0000, loss_test=0.5378, acc_test=0.8209
# poison_percent 40 epoch 46: loss_train=0.1125, acc_train=1.0000, loss_test=0.5483, acc_test=0.8010
# poison_percent 40 epoch 47: loss_train=0.2513, acc_train=1.0000, loss_test=0.4819, acc_test=0.8724
# poison_percent 40 epoch 48: loss_train=0.4844, acc_train=1.0000, loss_test=0.4828, acc_test=0.8378
# poison_percent 40 epoch 49: loss_train=0.5961, acc_train=1.0000, loss_test=0.6019, acc_test=0.6954
# poison_percent 40 epoch 50: loss_train=0.2519, acc_train=1.0000, loss_test=0.4724, acc_test=0.8714
# poison_percent 40 epoch 51: loss_train=0.6768, acc_train=1.0000, loss_test=0.5615, acc_test=0.7173
# poison_percent 40 epoch 52: loss_train=0.4277, acc_train=1.0000, loss_test=0.6422, acc_test=0.6337
# poison_percent 40 epoch 53: loss_train=0.6975, acc_train=0.0000, loss_test=0.5954, acc_test=0.7383
# poison_percent 40 epoch 54: loss_train=1.9558, acc_train=0.0000, loss_test=0.5247, acc_test=0.7612
# poison_percent 40 epoch 55: loss_train=0.5887, acc_train=1.0000, loss_test=0.4359, acc_test=0.8770
# poison_percent 40 epoch 56: loss_train=0.9179, acc_train=0.0000, loss_test=0.6236, acc_test=0.6862
# poison_percent 40 epoch 57: loss_train=0.4513, acc_train=1.0000, loss_test=0.5964, acc_test=0.7291
# poison_percent 40 epoch 58: loss_train=0.7250, acc_train=0.0000, loss_test=0.5553, acc_test=0.7699
# poison_percent 40 epoch 59: loss_train=0.3898, acc_train=1.0000, loss_test=0.5075, acc_test=0.8638
# poison_percent 40 epoch 60: loss_train=0.3559, acc_train=1.0000, loss_test=0.4577, acc_test=0.9026
# poison_percent 40 epoch 61: loss_train=1.1097, acc_train=0.0000, loss_test=0.5573, acc_test=0.8041
# poison_percent 40 epoch 62: loss_train=0.1878, acc_train=1.0000, loss_test=0.4736, acc_test=0.8781
# poison_percent 40 epoch 63: loss_train=0.4167, acc_train=1.0000, loss_test=0.6036, acc_test=0.7117
# poison_percent 40 epoch 64: loss_train=1.4076, acc_train=0.0000, loss_test=0.5804, acc_test=0.7036
# poison_percent 40 epoch 65: loss_train=1.1641, acc_train=0.0000, loss_test=0.5285, acc_test=0.8301
# poison_percent 40 epoch 66: loss_train=0.7561, acc_train=0.0000, loss_test=0.6878, acc_test=0.5791
# poison_percent 40 epoch 67: loss_train=1.4509, acc_train=0.0000, loss_test=0.6208, acc_test=0.6643
# poison_percent 40 epoch 68: loss_train=0.1220, acc_train=1.0000, loss_test=0.5657, acc_test=0.7791
# poison_percent 40 epoch 69: loss_train=0.2776, acc_train=1.0000, loss_test=0.6891, acc_test=0.6143
# poison_percent 40 epoch 70: loss_train=0.9976, acc_train=0.0000, loss_test=0.5983, acc_test=0.7270
# poison_percent 40 epoch 71: loss_train=0.3679, acc_train=1.0000, loss_test=0.5351, acc_test=0.8209
# poison_percent 40 epoch 72: loss_train=1.0470, acc_train=0.0000, loss_test=0.5644, acc_test=0.7735
# poison_percent 40 epoch 73: loss_train=0.5125, acc_train=1.0000, loss_test=0.5141, acc_test=0.8500
# poison_percent 40 epoch 74: loss_train=0.4057, acc_train=1.0000, loss_test=0.5518, acc_test=0.8036
# poison_percent 40 epoch 75: loss_train=0.3443, acc_train=1.0000, loss_test=0.5385, acc_test=0.7959
# poison_percent 40 epoch 76: loss_train=0.3005, acc_train=1.0000, loss_test=0.5819, acc_test=0.7827
# poison_percent 40 epoch 77: loss_train=0.9660, acc_train=0.0000, loss_test=0.6605, acc_test=0.6837
# poison_percent 40 epoch 78: loss_train=0.5917, acc_train=1.0000, loss_test=0.6164, acc_test=0.7148
# poison_percent 40 epoch 79: loss_train=0.6378, acc_train=1.0000, loss_test=0.5969, acc_test=0.7327
# poison_percent 40 epoch 80: loss_train=1.3101, acc_train=0.0000, loss_test=0.5514, acc_test=0.7908
# poison_percent 40 epoch 81: loss_train=0.5219, acc_train=1.0000, loss_test=0.5625, acc_test=0.7816
# ...
# poison_percent 40 epoch 41: loss_train=0.3665, acc_train=1.0000, loss_test=0.6459, acc_test=0.6679
# poison_percent 40 epoch 42: loss_train=0.5854, acc_train=1.0000, loss_test=0.5006, acc_test=0.8194
# poison_percent 40 epoch 43: loss_train=0.7106, acc_train=0.0000, loss_test=0.6075, acc_test=0.7265
# poison_percent 40 epoch 44: loss_train=1.3025, acc_train=0.0000, loss_test=0.4662, acc_test=0.8969
# poison_percent 40 epoch 45: loss_train=0.3777, acc_train=1.0000, loss_test=0.4807, acc_test=0.8745
# poison_percent 40 epoch 46: loss_train=0.8703, acc_train=0.0000, loss_test=0.4656, acc_test=0.9031
# poison_percent 40 epoch 47: loss_train=0.6767, acc_train=1.0000, loss_test=0.4787, acc_test=0.8168
# poison_percent 40 epoch 48: loss_train=1.3339, acc_train=0.0000, loss_test=0.6222, acc_test=0.6898
# poison_percent 40 epoch 49: loss_train=0.3036, acc_train=1.0000, loss_test=0.3921, acc_test=0.9418
# poison_percent 40 epoch 50: loss_train=1.2668, acc_train=0.0000, loss_test=0.5196, acc_test=0.7980
# poison_percent 40 epoch 51: loss_train=0.3734, acc_train=1.0000, loss_test=0.4916, acc_test=0.8755
# poison_percent 40 epoch 52: loss_train=1.2384, acc_train=0.0000, loss_test=0.6617, acc_test=0.6311
# poison_percent 40 epoch 53: loss_train=0.5529, acc_train=1.0000, loss_test=0.4625, acc_test=0.8270
# poison_percent 40 epoch 54: loss_train=0.3617, acc_train=1.0000, loss_test=0.4460, acc_test=0.9173
# poison_percent 40 epoch 55: loss_train=1.2211, acc_train=0.0000, loss_test=0.5168, acc_test=0.8398
# poison_percent 40 epoch 56: loss_train=0.4537, acc_train=1.0000, loss_test=0.5380, acc_test=0.8153
# poison_percent 40 epoch 57: loss_train=0.8527, acc_train=0.0000, loss_test=0.6260, acc_test=0.6969
# poison_percent 40 epoch 58: loss_train=1.0074, acc_train=0.0000, loss_test=0.7154, acc_test=0.6112
# poison_percent 40 epoch 59: loss_train=0.5421, acc_train=1.0000, loss_test=0.4693, acc_test=0.9077
# poison_percent 40 epoch 60: loss_train=0.1739, acc_train=1.0000, loss_test=0.4453, acc_test=0.9179
# poison_percent 40 epoch 61: loss_train=1.0233, acc_train=0.0000, loss_test=0.4600, acc_test=0.8944
# poison_percent 40 epoch 62: loss_train=0.3747, acc_train=1.0000, loss_test=0.5000, acc_test=0.8566
# poison_percent 40 epoch 63: loss_train=0.4871, acc_train=1.0000, loss_test=0.5923, acc_test=0.7117
# poison_percent 40 epoch 64: loss_train=0.3722, acc_train=1.0000, loss_test=0.5211, acc_test=0.8112
# poison_percent 40 epoch 65: loss_train=1.8206, acc_train=0.0000, loss_test=0.5084, acc_test=0.8005
# poison_percent 40 epoch 66: loss_train=0.7640, acc_train=0.0000, loss_test=0.5315, acc_test=0.8230
# poison_percent 40 epoch 67: loss_train=1.0767, acc_train=0.0000, loss_test=0.5328, acc_test=0.7939
# poison_percent 40 epoch 68: loss_train=0.4517, acc_train=1.0000, loss_test=0.6317, acc_test=0.6597
# poison_percent 40 epoch 69: loss_train=0.6614, acc_train=1.0000, loss_test=0.5806, acc_test=0.7270
# poison_percent 40 epoch 70: loss_train=0.7812, acc_train=0.0000, loss_test=0.6865, acc_test=0.6255
# poison_percent 40 epoch 71: loss_train=1.0262, acc_train=0.0000, loss_test=0.4698, acc_test=0.8913
# poison_percent 40 epoch 72: loss_train=1.1801, acc_train=0.0000, loss_test=0.5390, acc_test=0.8209
# poison_percent 40 epoch 73: loss_train=0.2227, acc_train=1.0000, loss_test=0.5021, acc_test=0.8520
# poison_percent 40 epoch 74: loss_train=0.8130, acc_train=0.0000, loss_test=0.4970, acc_test=0.8372
# poison_percent 40 epoch 75: loss_train=1.1476, acc_train=0.0000, loss_test=0.5878, acc_test=0.7423
# poison_percent 40 epoch 76: loss_train=0.8813, acc_train=0.0000, loss_test=0.6805, acc_test=0.6449
# poison_percent 40 epoch 77: loss_train=0.9052, acc_train=0.0000, loss_test=0.4554, acc_test=0.8770
# poison_percent 40 epoch 78: loss_train=0.4970, acc_train=1.0000, loss_test=0.5966, acc_test=0.7469
# poison_percent 40 epoch 79: loss_train=0.3939, acc_train=1.0000, loss_test=0.4074, acc_test=0.9276
# poison_percent 40 epoch 80: loss_train=0.4319, acc_train=1.0000, loss_test=0.6993, acc_test=0.6179
# poison_percent 40 epoch 81: loss_train=0.3358, acc_train=1.0000, loss_test=0.5828, acc_test=0.7566
# poison_percent 40 epoch 82: loss_train=1.4567, acc_train=0.0000, loss_test=0.6434, acc_test=0.6087
# poison_percent 40 epoch 83: loss_train=0.6471, acc_train=1.0000, loss_test=0.4896, acc_test=0.8638
# poison_percent 40 epoch 84: loss_train=1.1717, acc_train=0.0000, loss_test=0.6635, acc_test=0.6515
# poison_percent 40 epoch 85: loss_train=0.4411, acc_train=1.0000, loss_test=0.5731, acc_test=0.7209
# poison_percent 40 epoch 86: loss_train=0.6028, acc_train=1.0000, loss_test=0.5427, acc_test=0.7929
# poison_percent 40 epoch 87: loss_train=0.7010, acc_train=0.0000, loss_test=0.6897, acc_test=0.6408
# poison_percent 40 epoch 88: loss_train=0.3843, acc_train=1.0000, loss_test=0.4564, acc_test=0.8913
# poison_percent 40 epoch 89: loss_train=0.5261, acc_train=1.0000, loss_test=0.4888, acc_test=0.8500
# poison_percent 40 epoch 90: loss_train=0.7275, acc_train=0.0000, loss_test=0.4813, acc_test=0.8719
# poison_percent 40 epoch 91: loss_train=1.3547, acc_train=0.0000, loss_test=0.4404, acc_test=0.8913
# poison_percent 40 epoch 92: loss_train=0.5531, acc_train=1.0000, loss_test=0.4257, acc_test=0.9087
# poison_percent 40 epoch 93: loss_train=0.2160, acc_train=1.0000, loss_test=0.6100, acc_test=0.7138
# poison_percent 40 epoch 94: loss_train=1.1402, acc_train=0.0000, loss_test=0.4760, acc_test=0.8735
# poison_percent 40 epoch 95: loss_train=0.0263, acc_train=1.0000, loss_test=0.4630, acc_test=0.9015
# poison_percent 40 epoch 96: loss_train=0.5540, acc_train=1.0000, loss_test=0.6612, acc_test=0.6500
# poison_percent 40 epoch 97: loss_train=0.9499, acc_train=0.0000, loss_test=0.5855, acc_test=0.7204
# poison_percent 40 epoch 98: loss_train=0.2876, acc_train=1.0000, loss_test=0.5248, acc_test=0.8362
# poison_percent 40 epoch 99: loss_train=0.4928, acc_train=1.0000, loss_test=0.5795, acc_test=0.7633
# Training log saved to ./results\CL_ModelN1L1_Batchsize1_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 epoch 0: loss_train=0.7790, acc_train=0.0000, loss_test=0.8084, acc_test=0.4434
# poison_percent 50 epoch 1: loss_train=0.6881, acc_train=1.0000, loss_test=0.6736, acc_test=0.6393
# poison_percent 50 epoch 2: loss_train=0.3062, acc_train=1.0000, loss_test=0.6628, acc_test=0.6638
# poison_percent 50 epoch 3: loss_train=0.7913, acc_train=0.0000, loss_test=0.8156, acc_test=0.3684
# poison_percent 50 epoch 4: loss_train=0.5622, acc_train=1.0000, loss_test=0.6678, acc_test=0.5939
# poison_percent 50 epoch 5: loss_train=0.6131, acc_train=1.0000, loss_test=0.7317, acc_test=0.5449
# poison_percent 50 epoch 6: loss_train=1.2601, acc_train=0.0000, loss_test=0.8327, acc_test=0.3189
# poison_percent 50 epoch 7: loss_train=0.4919, acc_train=1.0000, loss_test=0.6590, acc_test=0.6204
# poison_percent 50 epoch 8: loss_train=0.5582, acc_train=1.0000, loss_test=0.7759, acc_test=0.3704
# poison_percent 50 epoch 9: loss_train=0.9076, acc_train=0.0000, loss_test=0.6917, acc_test=0.4837
# poison_percent 50 epoch 10: loss_train=0.9656, acc_train=0.0000, loss_test=0.7099, acc_test=0.4832
# poison_percent 50 epoch 11: loss_train=0.3943, acc_train=1.0000, loss_test=0.7665, acc_test=0.4199
# poison_percent 50 epoch 12: loss_train=0.6325, acc_train=1.0000, loss_test=0.7302, acc_test=0.5270
# poison_percent 50 epoch 13: loss_train=0.5706, acc_train=1.0000, loss_test=0.7151, acc_test=0.5903
# poison_percent 50 epoch 14: loss_train=0.6968, acc_train=0.0000, loss_test=0.7702, acc_test=0.4316
# poison_percent 50 epoch 15: loss_train=2.0884, acc_train=0.0000, loss_test=0.8125, acc_test=0.4929
# poison_percent 50 epoch 16: loss_train=0.5435, acc_train=1.0000, loss_test=0.8074, acc_test=0.4913
# poison_percent 50 epoch 17: loss_train=1.3423, acc_train=0.0000, loss_test=0.7839, acc_test=0.3872
# poison_percent 50 epoch 18: loss_train=0.8811, acc_train=0.0000, loss_test=0.8789, acc_test=0.2347
# poison_percent 50 epoch 19: loss_train=0.9960, acc_train=0.0000, loss_test=0.6961, acc_test=0.6005
# poison_percent 50 epoch 20: loss_train=0.7366, acc_train=0.0000, loss_test=0.5583, acc_test=0.7760
# poison_percent 50 epoch 21: loss_train=0.6649, acc_train=1.0000, loss_test=0.7858, acc_test=0.4898
# poison_percent 50 epoch 22: loss_train=0.1226, acc_train=1.0000, loss_test=0.8401, acc_test=0.4918
# poison_percent 50 epoch 23: loss_train=0.5164, acc_train=1.0000, loss_test=0.7509, acc_test=0.4250
# poison_percent 50 epoch 24: loss_train=0.7003, acc_train=0.0000, loss_test=0.8064, acc_test=0.4015
# poison_percent 50 epoch 25: loss_train=0.4875, acc_train=1.0000, loss_test=0.7114, acc_test=0.5490
# poison_percent 50 epoch 26: loss_train=0.5414, acc_train=1.0000, loss_test=0.7769, acc_test=0.5367
# poison_percent 50 epoch 27: loss_train=0.4919, acc_train=1.0000, loss_test=0.8373, acc_test=0.3265
# poison_percent 50 epoch 28: loss_train=0.6447, acc_train=1.0000, loss_test=0.7241, acc_test=0.5097
# poison_percent 50 epoch 29: loss_train=0.5061, acc_train=1.0000, loss_test=0.7422, acc_test=0.5776
# poison_percent 50 epoch 30: loss_train=0.5195, acc_train=1.0000, loss_test=0.7104, acc_test=0.4806
# poison_percent 50 epoch 31: loss_train=1.2097, acc_train=0.0000, loss_test=0.6412, acc_test=0.6801
# poison_percent 50 epoch 32: loss_train=0.1839, acc_train=1.0000, loss_test=0.6089, acc_test=0.6158
# poison_percent 50 epoch 33: loss_train=0.4759, acc_train=1.0000, loss_test=0.6325, acc_test=0.6765
# poison_percent 50 epoch 34: loss_train=0.9802, acc_train=0.0000, loss_test=0.7551, acc_test=0.5240
# poison_percent 50 epoch 35: loss_train=0.8912, acc_train=0.0000, loss_test=0.6007, acc_test=0.6893
# poison_percent 50 epoch 36: loss_train=0.8605, acc_train=0.0000, loss_test=0.7496, acc_test=0.5398
# poison_percent 50 epoch 37: loss_train=0.4871, acc_train=1.0000, loss_test=0.8112, acc_test=0.4199
# poison_percent 50 epoch 38: loss_train=0.6909, acc_train=1.0000, loss_test=0.6305, acc_test=0.6526
# poison_percent 50 epoch 39: loss_train=0.4477, acc_train=1.0000, loss_test=0.7509, acc_test=0.4827
# poison_percent 50 epoch 40: loss_train=0.5360, acc_train=1.0000, loss_test=0.8615, acc_test=0.3837
# poison_percent 50 epoch 41: loss_train=0.6509, acc_train=1.0000, loss_test=0.7631, acc_test=0.4117
# poison_percent 50 epoch 42: loss_train=0.8531, acc_train=0.0000, loss_test=0.6248, acc_test=0.6265
# poison_percent 50 epoch 43: loss_train=1.1451, acc_train=0.0000, loss_test=0.6683, acc_test=0.6398
# poison_percent 50 epoch 44: loss_train=0.9709, acc_train=0.0000, loss_test=0.8088, acc_test=0.3714
# poison_percent 50 epoch 45: loss_train=0.5949, acc_train=1.0000, loss_test=0.7258, acc_test=0.4362
# poison_percent 50 epoch 46: loss_train=0.4760, acc_train=1.0000, loss_test=0.7876, acc_test=0.3883
# poison_percent 50 epoch 47: loss_train=0.5699, acc_train=1.0000, loss_test=0.5573, acc_test=0.7878
# poison_percent 50 epoch 48: loss_train=1.2325, acc_train=0.0000, loss_test=0.7250, acc_test=0.6056
# poison_percent 50 epoch 49: loss_train=1.2840, acc_train=0.0000, loss_test=0.6007, acc_test=0.6342
# poison_percent 50 epoch 50: loss_train=0.6930, acc_train=1.0000, loss_test=0.6770, acc_test=0.6612
# poison_percent 50 epoch 51: loss_train=0.5473, acc_train=1.0000, loss_test=0.6679, acc_test=0.6276
# poison_percent 50 epoch 52: loss_train=0.6811, acc_train=1.0000, loss_test=0.6815, acc_test=0.6194
# poison_percent 50 epoch 53: loss_train=0.6834, acc_train=1.0000, loss_test=0.7024, acc_test=0.4811
# poison_percent 50 epoch 54: loss_train=0.6612, acc_train=1.0000, loss_test=0.7846, acc_test=0.3918
# poison_percent 50 epoch 55: loss_train=1.2736, acc_train=0.0000, loss_test=0.7013, acc_test=0.6301
# poison_percent 50 epoch 56: loss_train=0.6699, acc_train=1.0000, loss_test=0.7308, acc_test=0.4806
# poison_percent 50 epoch 57: loss_train=1.0064, acc_train=0.0000, loss_test=0.8110, acc_test=0.5010
# poison_percent 50 epoch 58: loss_train=0.3503, acc_train=1.0000, loss_test=0.6341, acc_test=0.6622
# poison_percent 50 epoch 59: loss_train=1.0581, acc_train=0.0000, loss_test=0.7499, acc_test=0.4276
# poison_percent 50 epoch 60: loss_train=1.0718, acc_train=0.0000, loss_test=0.8413, acc_test=0.3097
# poison_percent 50 epoch 61: loss_train=1.2692, acc_train=0.0000, loss_test=0.7323, acc_test=0.5622
# poison_percent 50 epoch 62: loss_train=0.7118, acc_train=0.0000, loss_test=0.7148, acc_test=0.4883
# poison_percent 50 epoch 63: loss_train=0.9987, acc_train=0.0000, loss_test=0.7419, acc_test=0.5684
# poison_percent 50 epoch 64: loss_train=0.6198, acc_train=1.0000, loss_test=0.7430, acc_test=0.5281
# poison_percent 50 epoch 65: loss_train=0.7037, acc_train=0.0000, loss_test=0.8377, acc_test=0.4490
# poison_percent 50 epoch 66: loss_train=0.6395, acc_train=1.0000, loss_test=0.6718, acc_test=0.5689
# poison_percent 50 epoch 67: loss_train=0.5435, acc_train=1.0000, loss_test=0.7433, acc_test=0.4270
# poison_percent 50 epoch 68: loss_train=0.7578, acc_train=0.0000, loss_test=0.6576, acc_test=0.6046
# poison_percent 50 epoch 69: loss_train=0.5731, acc_train=1.0000, loss_test=0.8002, acc_test=0.4852
# poison_percent 50 epoch 70: loss_train=0.9158, acc_train=0.0000, loss_test=0.6495, acc_test=0.7056
# poison_percent 50 epoch 71: loss_train=0.6233, acc_train=1.0000, loss_test=0.6983, acc_test=0.5934
# poison_percent 50 epoch 72: loss_train=1.1193, acc_train=0.0000, loss_test=0.7591, acc_test=0.4332
# poison_percent 50 epoch 73: loss_train=0.6117, acc_train=1.0000, loss_test=0.6973, acc_test=0.5505
# poison_percent 50 epoch 74: loss_train=0.8951, acc_train=0.0000, loss_test=0.6933, acc_test=0.6036
# poison_percent 50 epoch 75: loss_train=0.5229, acc_train=1.0000, loss_test=0.7520, acc_test=0.4505
# poison_percent 50 epoch 76: loss_train=0.7390, acc_train=0.0000, loss_test=0.6168, acc_test=0.7204
# poison_percent 50 epoch 77: loss_train=0.9896, acc_train=0.0000, loss_test=0.6222, acc_test=0.7327
# poison_percent 50 epoch 78: loss_train=0.6834, acc_train=1.0000, loss_test=0.7452, acc_test=0.4459
# poison_percent 50 epoch 79: loss_train=0.6312, acc_train=1.0000, loss_test=0.8054, acc_test=0.4015
# poison_percent 50 epoch 80: loss_train=0.1596, acc_train=1.0000, loss_test=0.7479, acc_test=0.5092
# poison_percent 50 epoch 81: loss_train=0.2699, acc_train=1.0000, loss_test=0.7240, acc_test=0.4520
# poison_percent 50 epoch 82: loss_train=0.5621, acc_train=1.0000, loss_test=0.8159, acc_test=0.4372
# poison_percent 50 epoch 83: loss_train=0.8090, acc_train=0.0000, loss_test=0.8462, acc_test=0.3230
# poison_percent 50 epoch 84: loss_train=0.7871, acc_train=0.0000, loss_test=0.7513, acc_test=0.4837
# poison_percent 50 epoch 85: loss_train=0.4318, acc_train=1.0000, loss_test=0.8270, acc_test=0.5245
# poison_percent 50 epoch 86: loss_train=0.4833, acc_train=1.0000, loss_test=0.7451, acc_test=0.5071
# poison_percent 50 epoch 87: loss_train=0.5274, acc_train=1.0000, loss_test=0.8932, acc_test=0.3332
# poison_percent 50 epoch 88: loss_train=0.8248, acc_train=0.0000, loss_test=0.6277, acc_test=0.6888
# poison_percent 50 epoch 89: loss_train=0.7112, acc_train=0.0000, loss_test=0.6570, acc_test=0.6745
# poison_percent 50 epoch 90: loss_train=0.4910, acc_train=1.0000, loss_test=0.6755, acc_test=0.6071
# poison_percent 50 epoch 91: loss_train=0.5063, acc_train=1.0000, loss_test=0.7541, acc_test=0.4622
# poison_percent 50 epoch 92: loss_train=0.4711, acc_train=1.0000, loss_test=0.7471, acc_test=0.4760
# poison_percent 50 epoch 93: loss_train=1.3961, acc_train=0.0000, loss_test=0.7117, acc_test=0.5469
# poison_percent 50 epoch 94: loss_train=0.4682, acc_train=1.0000, loss_test=0.7583, acc_test=0.4663
# poison_percent 50 epoch 95: loss_train=0.6042, acc_train=1.0000, loss_test=0.7664, acc_test=0.5352
# poison_percent 50 epoch 96: loss_train=0.5808, acc_train=1.0000, loss_test=0.8069, acc_test=0.4046
# poison_percent 50 epoch 97: loss_train=0.7317, acc_train=0.0000, loss_test=0.5615, acc_test=0.8138
# poison_percent 50 epoch 98: loss_train=0.1708, acc_train=1.0000, loss_test=0.8112, acc_test=0.5418
# poison_percent 50 epoch 99: loss_train=0.8004, acc_train=0.0000, loss_test=0.6704, acc_test=0.6423
# Training log saved to ./results\CL_ModelN1L1_Batchsize1_rev2\poisoned_50percent\poisoned_50percent.csv
