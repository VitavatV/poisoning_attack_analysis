# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
# def binary_cross_entropy(pred, target):
#     eps = 1e-7
#     pred = torch.clamp(pred, eps, 1 - eps)
#     return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

def multiclass_cross_entropy(logits, target, from_probs=False, eps=1e-7):
    """
    Cross-entropy loss for multiclass (e.g., 10 classes).
    - logits: Tensor shape (N, C) containing raw scores (preferred) or probabilities if from_probs=True
    - target: Tensor shape (N,) or (N,1) containing class indices (0..C-1)
    """
    if logits.dim() == 1:
        logits = logits.unsqueeze(0)
    target = target.squeeze()
    if target.dtype != torch.long:
        target = target.long()
    if from_probs:
        probs = torch.clamp(logits, eps, 1.0 - eps)
        log_probs = torch.log(probs)
        return -log_probs[torch.arange(target.size(0)), target].mean()
    return nn.functional.cross_entropy(logits, target)

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 32
N_CLASSES = 10

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_multiple_poison/train"
TEST_PATH = "../data/mnist_multiple_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
import re
def make_safe_filename(name: str) -> str:
    # remove control chars and characters invalid on Windows
    safe = re.sub(r'[<>:"/\\|?*\x00-\x1F]', '_', name)
    # strip trailing dots/spaces which are problematic on Windows
    safe = safe.rstrip('. ')
    return safe

# %%
for NODE in [1,2,4,8,16,32]:
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, N_CLASSES)
            self.relu = nn.ReLU()
        def forward(self, x):
            x = self.fc1(x)
            x = self.relu(x)
            x = self.fc2(x)
            # x = torch.sigmoid(x)
            return x

    BATCH_SIZE_list = [BATCH_SIZE]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"CL_ModelN{NODE}L2_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                        poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                        select='Honest+Poisoned')
                X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
                # print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
                # print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")

                X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
                y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                torch.save(model, os.path.join(save_path,'model_init.pt'))
                optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

                records = []

                # Training loop
                for epoch in range(EPOCHS):

                    # Train
                    model.train()
                    
                    #randomize the training data
                    perm = torch.randperm(X_train_tensor.size(0))
                    X_train_tensor = X_train_tensor[perm]
                    y_train_tensor = y_train_tensor[perm]

                    for start in range(0, X_train_tensor.size(0), experiment_bs):
                        end = start + experiment_bs
                        xb = X_train_tensor[start:end]
                        yb = y_train_tensor[start:end]
                        outputs = model(xb)
                        # preds = (outputs >= 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        acc_train = (preds == yb).float().mean().item()
                        loss_train = multiclass_cross_entropy(outputs, yb)
                        optimizer.zero_grad()
                        loss_train.backward()
                        optimizer.step()

                    # Evaluate
                    model.eval()
                    with torch.no_grad():
                        outputs = model(X_test_tensor)
                        # preds = (outputs >= 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        loss_test = multiclass_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"epoch {epoch}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)
                
                # save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                safe_name = make_safe_filename(NAME_SAVE_update_PATH)
                save_name_path = os.path.abspath(os.path.join(save_path, f'{safe_name}.csv'))
                os.makedirs(os.path.dirname(save_name_path), exist_ok=True)

                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['epoch'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['epoch'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 epoch 0: loss_train=2.2872, acc_train=0.1579, loss_test=2.3864, acc_test=0.0000
# poison_percent 0 epoch 1: loss_train=2.2942, acc_train=0.1053, loss_test=2.3031, acc_test=0.0000
# poison_percent 0 epoch 2: loss_train=2.3050, acc_train=0.0526, loss_test=2.2876, acc_test=0.0000
# poison_percent 0 epoch 3: loss_train=2.3073, acc_train=0.0526, loss_test=2.2795, acc_test=0.5000
# poison_percent 0 epoch 4: loss_train=2.3089, acc_train=0.0526, loss_test=2.2831, acc_test=0.0000
# poison_percent 0 epoch 5: loss_train=2.2973, acc_train=0.0526, loss_test=2.2972, acc_test=0.0000
# poison_percent 0 epoch 6: loss_train=2.2945, acc_train=0.0526, loss_test=2.2873, acc_test=0.0000
# poison_percent 0 epoch 7: loss_train=2.3143, acc_train=0.0000, loss_test=2.2890, acc_test=0.0000
# poison_percent 0 epoch 8: loss_train=2.2916, acc_train=0.0000, loss_test=2.2905, acc_test=0.0000
# poison_percent 0 epoch 9: loss_train=2.2939, acc_train=0.0000, loss_test=2.2853, acc_test=0.0000
# poison_percent 0 epoch 10: loss_train=2.3027, acc_train=0.2105, loss_test=2.2951, acc_test=0.0000
# poison_percent 0 epoch 11: loss_train=2.3139, acc_train=0.0526, loss_test=2.2871, acc_test=0.0000
# poison_percent 0 epoch 12: loss_train=2.2961, acc_train=0.1053, loss_test=2.2838, acc_test=0.0000
# poison_percent 0 epoch 13: loss_train=2.2945, acc_train=0.2632, loss_test=2.2846, acc_test=0.0000
# poison_percent 0 epoch 14: loss_train=2.3147, acc_train=0.1579, loss_test=2.2867, acc_test=0.0000
# poison_percent 0 epoch 15: loss_train=2.3158, acc_train=0.0000, loss_test=2.2823, acc_test=0.5000
# poison_percent 0 epoch 16: loss_train=2.2993, acc_train=0.2105, loss_test=2.2849, acc_test=0.0000
# poison_percent 0 epoch 17: loss_train=2.2983, acc_train=0.0526, loss_test=2.2904, acc_test=0.0000
# poison_percent 0 epoch 18: loss_train=2.3035, acc_train=0.0526, loss_test=2.2890, acc_test=0.0000
# poison_percent 0 epoch 19: loss_train=2.3022, acc_train=0.0526, loss_test=2.2868, acc_test=0.0000
# poison_percent 0 epoch 20: loss_train=2.3057, acc_train=0.1053, loss_test=2.2833, acc_test=0.5000
# poison_percent 0 epoch 21: loss_train=2.2975, acc_train=0.1053, loss_test=2.2840, acc_test=0.0000
# poison_percent 0 epoch 22: loss_train=2.3025, acc_train=0.0526, loss_test=2.2879, acc_test=0.0000
# poison_percent 0 epoch 23: loss_train=2.2988, acc_train=0.1053, loss_test=2.2844, acc_test=0.0000
# poison_percent 0 epoch 24: loss_train=2.2975, acc_train=0.2632, loss_test=2.2913, acc_test=0.0000
# poison_percent 0 epoch 25: loss_train=2.2965, acc_train=0.1053, loss_test=2.2883, acc_test=0.0000
# poison_percent 0 epoch 26: loss_train=2.3120, acc_train=0.2105, loss_test=2.2809, acc_test=0.5000
# poison_percent 0 epoch 27: loss_train=2.2961, acc_train=0.1053, loss_test=2.2844, acc_test=0.5000
# poison_percent 0 epoch 28: loss_train=2.2977, acc_train=0.1053, loss_test=2.2839, acc_test=0.0000
# poison_percent 0 epoch 29: loss_train=2.3015, acc_train=0.2105, loss_test=2.2946, acc_test=0.0000
# poison_percent 0 epoch 30: loss_train=2.3027, acc_train=0.1053, loss_test=2.2902, acc_test=0.0000
# poison_percent 0 epoch 31: loss_train=2.2957, acc_train=0.0526, loss_test=2.2863, acc_test=0.0000
# poison_percent 0 epoch 32: loss_train=2.3317, acc_train=0.0000, loss_test=2.2862, acc_test=0.0000
# poison_percent 0 epoch 33: loss_train=2.3007, acc_train=0.2632, loss_test=2.2900, acc_test=0.0000
# poison_percent 0 epoch 34: loss_train=2.3087, acc_train=0.0000, loss_test=2.2833, acc_test=0.5000
# poison_percent 0 epoch 35: loss_train=2.2942, acc_train=0.0000, loss_test=2.2842, acc_test=0.0000
# poison_percent 0 epoch 36: loss_train=2.2909, acc_train=0.2105, loss_test=2.2879, acc_test=0.5000
# poison_percent 0 epoch 37: loss_train=2.3033, acc_train=0.1579, loss_test=2.2796, acc_test=0.5000
# poison_percent 0 epoch 38: loss_train=2.3123, acc_train=0.0526, loss_test=2.2805, acc_test=0.0000
# poison_percent 0 epoch 39: loss_train=2.3072, acc_train=0.0000, loss_test=2.2809, acc_test=0.5000
# poison_percent 0 epoch 40: loss_train=2.2904, acc_train=0.1579, loss_test=2.2916, acc_test=0.0000
# poison_percent 0 epoch 41: loss_train=2.2947, acc_train=0.2105, loss_test=2.2821, acc_test=0.5000
# poison_percent 0 epoch 42: loss_train=2.2902, acc_train=0.0526, loss_test=2.2761, acc_test=0.5000
# poison_percent 0 epoch 43: loss_train=2.3056, acc_train=0.1579, loss_test=2.2914, acc_test=0.0000
# poison_percent 0 epoch 44: loss_train=2.2903, acc_train=0.1579, loss_test=2.2885, acc_test=0.0000
# poison_percent 0 epoch 45: loss_train=2.3005, acc_train=0.1053, loss_test=2.2812, acc_test=0.0000
# poison_percent 0 epoch 46: loss_train=2.2976, acc_train=0.0526, loss_test=2.2820, acc_test=0.5000
# poison_percent 0 epoch 47: loss_train=2.3084, acc_train=0.1053, loss_test=2.2827, acc_test=0.0000
# poison_percent 0 epoch 48: loss_train=2.3188, acc_train=0.0000, loss_test=2.2897, acc_test=0.0000
# poison_percent 0 epoch 49: loss_train=2.3108, acc_train=0.2105, loss_test=2.2861, acc_test=0.0000
# poison_percent 0 epoch 50: loss_train=2.2989, acc_train=0.0526, loss_test=2.2896, acc_test=0.0000
# poison_percent 0 epoch 51: loss_train=2.2930, acc_train=0.0526, loss_test=2.2836, acc_test=0.5000
# poison_percent 0 epoch 52: loss_train=2.3193, acc_train=0.0000, loss_test=2.2937, acc_test=0.0000
# poison_percent 0 epoch 53: loss_train=2.2943, acc_train=0.0526, loss_test=2.2858, acc_test=0.5000
# poison_percent 0 epoch 54: loss_train=2.2936, acc_train=0.1053, loss_test=2.2861, acc_test=0.0000
# poison_percent 0 epoch 55: loss_train=2.3216, acc_train=0.1053, loss_test=2.2895, acc_test=0.0000
# poison_percent 0 epoch 56: loss_train=2.3020, acc_train=0.1053, loss_test=2.2941, acc_test=0.0000
# poison_percent 0 epoch 57: loss_train=2.2946, acc_train=0.2632, loss_test=2.2906, acc_test=0.0000
# poison_percent 0 epoch 58: loss_train=2.2983, acc_train=0.1053, loss_test=2.2879, acc_test=0.0000
# poison_percent 0 epoch 59: loss_train=2.2936, acc_train=0.1579, loss_test=2.2879, acc_test=0.0000
# poison_percent 0 epoch 60: loss_train=2.3018, acc_train=0.1053, loss_test=2.2898, acc_test=0.0000
# poison_percent 0 epoch 61: loss_train=2.2956, acc_train=0.1053, loss_test=2.2898, acc_test=0.0000
# poison_percent 0 epoch 62: loss_train=2.2949, acc_train=0.0526, loss_test=2.2932, acc_test=0.0000
# poison_percent 0 epoch 63: loss_train=2.3090, acc_train=0.0526, loss_test=2.2889, acc_test=0.0000
# poison_percent 0 epoch 64: loss_train=2.3001, acc_train=0.1053, loss_test=2.2897, acc_test=0.0000
# poison_percent 0 epoch 65: loss_train=2.2973, acc_train=0.1053, loss_test=2.2843, acc_test=0.0000
# poison_percent 0 epoch 66: loss_train=2.3145, acc_train=0.0526, loss_test=2.2861, acc_test=0.0000
# poison_percent 0 epoch 67: loss_train=2.2918, acc_train=0.1579, loss_test=2.2809, acc_test=0.5000
# poison_percent 0 epoch 68: loss_train=2.3145, acc_train=0.0000, loss_test=2.2843, acc_test=0.0000
# poison_percent 0 epoch 69: loss_train=2.2977, acc_train=0.0526, loss_test=2.2920, acc_test=0.0000
# poison_percent 0 epoch 70: loss_train=2.3114, acc_train=0.0526, loss_test=2.2908, acc_test=0.0000
# poison_percent 0 epoch 71: loss_train=2.2952, acc_train=0.0526, loss_test=2.2901, acc_test=0.0000
# poison_percent 0 epoch 72: loss_train=2.3068, acc_train=0.1053, loss_test=2.2843, acc_test=0.5000
# poison_percent 0 epoch 73: loss_train=2.3090, acc_train=0.0526, loss_test=2.2816, acc_test=0.5000
# poison_percent 0 epoch 74: loss_train=2.3044, acc_train=0.1053, loss_test=2.2843, acc_test=0.0000
# poison_percent 0 epoch 75: loss_train=2.3158, acc_train=0.0526, loss_test=2.2836, acc_test=0.0000
# poison_percent 0 epoch 76: loss_train=2.3099, acc_train=0.0526, loss_test=2.2890, acc_test=0.0000
# poison_percent 0 epoch 77: loss_train=2.2964, acc_train=0.0526, loss_test=2.2841, acc_test=0.0000
# poison_percent 0 epoch 78: loss_train=2.2979, acc_train=0.0000, loss_test=2.2858, acc_test=0.0000
# poison_percent 0 epoch 79: loss_train=2.2971, acc_train=0.2105, loss_test=2.2914, acc_test=0.0000
# poison_percent 0 epoch 80: loss_train=2.3128, acc_train=0.0526, loss_test=2.2889, acc_test=0.0000
# poison_percent 0 epoch 81: loss_train=2.2928, acc_train=0.0526, loss_test=2.2866, acc_test=0.0000
# poison_percent 0 epoch 82: loss_train=2.3057, acc_train=0.0526, loss_test=2.2864, acc_test=0.0000
# poison_percent 0 epoch 83: loss_train=2.3058, acc_train=0.0526, loss_test=2.2899, acc_test=0.0000
# poison_percent 0 epoch 84: loss_train=2.3119, acc_train=0.0000, loss_test=2.2890, acc_test=0.0000
# poison_percent 0 epoch 85: loss_train=2.2942, acc_train=0.1053, loss_test=2.2896, acc_test=0.0000
# poison_percent 0 epoch 86: loss_train=2.2986, acc_train=0.0000, loss_test=2.2908, acc_test=0.0000
# poison_percent 0 epoch 87: loss_train=2.2952, acc_train=0.0526, loss_test=2.2859, acc_test=0.0000
# poison_percent 0 epoch 88: loss_train=2.3158, acc_train=0.0526, loss_test=2.2825, acc_test=0.0000
# poison_percent 0 epoch 89: loss_train=2.2980, acc_train=0.0526, loss_test=2.2905, acc_test=0.0000
# poison_percent 0 epoch 90: loss_train=2.3018, acc_train=0.1053, loss_test=2.2865, acc_test=0.5000
# poison_percent 0 epoch 91: loss_train=2.2935, acc_train=0.1579, loss_test=2.2816, acc_test=0.5000
# poison_percent 0 epoch 92: loss_train=2.3107, acc_train=0.1053, loss_test=2.2826, acc_test=0.0000
# poison_percent 0 epoch 93: loss_train=2.2927, acc_train=0.2632, loss_test=2.2823, acc_test=0.0000
# poison_percent 0 epoch 94: loss_train=2.2969, acc_train=0.1053, loss_test=2.2822, acc_test=0.0000
# poison_percent 0 epoch 95: loss_train=2.2936, acc_train=0.1053, loss_test=2.2901, acc_test=0.0000
# poison_percent 0 epoch 96: loss_train=2.3094, acc_train=0.0000, loss_test=2.2807, acc_test=0.0000
# poison_percent 0 epoch 97: loss_train=2.3215, acc_train=0.0526, loss_test=2.2804, acc_test=0.0000
# poison_percent 0 epoch 98: loss_train=2.3061, acc_train=0.0526, loss_test=2.2782, acc_test=0.5000
# poison_percent 0 epoch 99: loss_train=2.3029, acc_train=0.0526, loss_test=2.2854, acc_test=0.5000
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\CL_ModelN1L2_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 epoch 0: loss_train=2.1977, acc_train=0.2812, loss_test=2.0299, acc_test=0.5000
# poison_percent 10 epoch 1: loss_train=2.2703, acc_train=0.1875, loss_test=1.9903, acc_test=0.5000
# poison_percent 10 epoch 2: loss_train=2.2529, acc_train=0.2188, loss_test=1.9740, acc_test=0.5000
# poison_percent 10 epoch 3: loss_train=2.3203, acc_train=0.0938, loss_test=1.9885, acc_test=0.5000
# poison_percent 10 epoch 4: loss_train=2.2273, acc_train=0.2500, loss_test=1.9818, acc_test=0.5000
# poison_percent 10 epoch 5: loss_train=2.2602, acc_train=0.1875, loss_test=1.9786, acc_test=0.5000
# poison_percent 10 epoch 6: loss_train=2.2886, acc_train=0.1562, loss_test=1.9826, acc_test=0.5000
# poison_percent 10 epoch 7: loss_train=2.2416, acc_train=0.2188, loss_test=1.9829, acc_test=0.5000
# poison_percent 10 epoch 8: loss_train=2.3528, acc_train=0.0938, loss_test=1.9805, acc_test=0.5000
# poison_percent 10 epoch 9: loss_train=2.2661, acc_train=0.1875, loss_test=1.9677, acc_test=0.5000
# poison_percent 10 epoch 10: loss_train=2.2266, acc_train=0.2500, loss_test=1.9763, acc_test=0.5000
# poison_percent 10 epoch 11: loss_train=2.2882, acc_train=0.1562, loss_test=1.9755, acc_test=0.5000
# poison_percent 10 epoch 12: loss_train=2.1939, acc_train=0.2812, loss_test=1.9817, acc_test=0.5000
# poison_percent 10 epoch 13: loss_train=2.3282, acc_train=0.1250, loss_test=1.9785, acc_test=0.5000
# poison_percent 10 epoch 14: loss_train=2.3058, acc_train=0.1562, loss_test=1.9721, acc_test=0.5000
# poison_percent 10 epoch 15: loss_train=2.2915, acc_train=0.1562, loss_test=1.9892, acc_test=0.5000
# poison_percent 10 epoch 16: loss_train=2.3165, acc_train=0.1250, loss_test=1.9815, acc_test=0.5000
# poison_percent 10 epoch 17: loss_train=2.1677, acc_train=0.3125, loss_test=1.9763, acc_test=0.5000
# poison_percent 10 epoch 18: loss_train=2.2555, acc_train=0.1875, loss_test=1.9868, acc_test=0.5000
# poison_percent 10 epoch 19: loss_train=2.1267, acc_train=0.3750, loss_test=1.9792, acc_test=0.5000
# poison_percent 10 epoch 20: loss_train=2.2990, acc_train=0.1250, loss_test=1.9820, acc_test=0.5000
# poison_percent 10 epoch 21: loss_train=2.2696, acc_train=0.1875, loss_test=1.9778, acc_test=0.5000
# poison_percent 10 epoch 22: loss_train=2.2179, acc_train=0.2500, loss_test=1.9798, acc_test=0.5000
# poison_percent 10 epoch 23: loss_train=2.3470, acc_train=0.0938, loss_test=1.9741, acc_test=0.5000
# poison_percent 10 epoch 24: loss_train=2.3071, acc_train=0.1250, loss_test=1.9822, acc_test=0.5000
# poison_percent 10 epoch 25: loss_train=2.2193, acc_train=0.2500, loss_test=1.9844, acc_test=0.5000
# poison_percent 10 epoch 26: loss_train=2.3348, acc_train=0.0938, loss_test=1.9822, acc_test=0.5000
# poison_percent 10 epoch 27: loss_train=2.2788, acc_train=0.1875, loss_test=1.9846, acc_test=0.5000
# poison_percent 10 epoch 28: loss_train=2.3512, acc_train=0.0625, loss_test=1.9853, acc_test=0.5000
# poison_percent 10 epoch 29: loss_train=2.1446, acc_train=0.3438, loss_test=1.9805, acc_test=0.5000
# poison_percent 10 epoch 30: loss_train=2.3049, acc_train=0.1250, loss_test=1.9769, acc_test=0.5000
# poison_percent 10 epoch 31: loss_train=2.2273, acc_train=0.2500, loss_test=1.9692, acc_test=0.5000
# poison_percent 10 epoch 32: loss_train=2.2562, acc_train=0.2188, loss_test=1.9782, acc_test=0.5000
# poison_percent 10 epoch 33: loss_train=2.1865, acc_train=0.3125, loss_test=1.9730, acc_test=0.5000
# poison_percent 10 epoch 34: loss_train=2.1631, acc_train=0.3125, loss_test=1.9807, acc_test=0.5000
# poison_percent 10 epoch 35: loss_train=2.2042, acc_train=0.2500, loss_test=1.9826, acc_test=0.5000
# poison_percent 10 epoch 36: loss_train=2.1745, acc_train=0.3125, loss_test=1.9714, acc_test=0.5000
# poison_percent 10 epoch 37: loss_train=2.2158, acc_train=0.2500, loss_test=1.9831, acc_test=0.5000
# poison_percent 10 epoch 38: loss_train=2.2636, acc_train=0.1875, loss_test=1.9850, acc_test=0.5000
# poison_percent 10 epoch 39: loss_train=2.2706, acc_train=0.1875, loss_test=1.9765, acc_test=0.5000
# poison_percent 10 epoch 40: loss_train=2.2436, acc_train=0.1875, loss_test=1.9848, acc_test=0.5000
# poison_percent 10 epoch 41: loss_train=2.3090, acc_train=0.1250, loss_test=1.9847, acc_test=0.5000
# poison_percent 10 epoch 42: loss_train=2.2086, acc_train=0.2500, loss_test=1.9704, acc_test=0.5000
# poison_percent 10 epoch 43: loss_train=2.3335, acc_train=0.0938, loss_test=1.9815, acc_test=0.5000
# poison_percent 10 epoch 44: loss_train=2.2858, acc_train=0.1562, loss_test=1.9769, acc_test=0.5000
# poison_percent 10 epoch 45: loss_train=2.2477, acc_train=0.2188, loss_test=1.9781, acc_test=0.5000
# poison_percent 10 epoch 46: loss_train=2.2900, acc_train=0.1562, loss_test=1.9826, acc_test=0.5000
# poison_percent 10 epoch 47: loss_train=2.3338, acc_train=0.0938, loss_test=1.9849, acc_test=0.5000
# poison_percent 10 epoch 48: loss_train=2.2354, acc_train=0.2188, loss_test=1.9759, acc_test=0.5000
# poison_percent 10 epoch 49: loss_train=2.2966, acc_train=0.1562, loss_test=1.9774, acc_test=0.5000
# poison_percent 10 epoch 50: loss_train=2.2673, acc_train=0.1875, loss_test=1.9914, acc_test=0.5000
# poison_percent 10 epoch 51: loss_train=2.3003, acc_train=0.1250, loss_test=1.9855, acc_test=0.5000
# poison_percent 10 epoch 52: loss_train=2.1994, acc_train=0.2812, loss_test=1.9845, acc_test=0.5000
# poison_percent 10 epoch 53: loss_train=2.3785, acc_train=0.0312, loss_test=1.9908, acc_test=0.5000
# poison_percent 10 epoch 54: loss_train=2.3354, acc_train=0.0938, loss_test=1.9746, acc_test=0.5000
# poison_percent 10 epoch 55: loss_train=2.2612, acc_train=0.1875, loss_test=1.9821, acc_test=0.5000
# poison_percent 10 epoch 56: loss_train=2.2586, acc_train=0.1875, loss_test=1.9739, acc_test=0.5000
# poison_percent 10 epoch 57: loss_train=2.2658, acc_train=0.1875, loss_test=1.9700, acc_test=0.5000
# poison_percent 10 epoch 58: loss_train=2.2684, acc_train=0.1875, loss_test=1.9872, acc_test=0.5000
# poison_percent 10 epoch 59: loss_train=2.2475, acc_train=0.1875, loss_test=1.9858, acc_test=0.5000
# poison_percent 10 epoch 60: loss_train=2.2867, acc_train=0.1562, loss_test=1.9899, acc_test=0.5000
# poison_percent 10 epoch 61: loss_train=2.2457, acc_train=0.2188, loss_test=1.9789, acc_test=0.5000
# poison_percent 10 epoch 62: loss_train=2.2680, acc_train=0.1875, loss_test=1.9877, acc_test=0.5000
# poison_percent 10 epoch 63: loss_train=2.2352, acc_train=0.2188, loss_test=1.9832, acc_test=0.5000
# poison_percent 10 epoch 64: loss_train=2.2609, acc_train=0.1875, loss_test=1.9793, acc_test=0.5000
# poison_percent 10 epoch 65: loss_train=2.2271, acc_train=0.2500, loss_test=1.9802, acc_test=0.5000
# poison_percent 10 epoch 66: loss_train=2.2732, acc_train=0.1875, loss_test=1.9885, acc_test=0.5000
# poison_percent 10 epoch 67: loss_train=2.2798, acc_train=0.1562, loss_test=1.9930, acc_test=0.5000
# poison_percent 10 epoch 68: loss_train=2.2815, acc_train=0.1562, loss_test=1.9847, acc_test=0.5000
# poison_percent 10 epoch 69: loss_train=2.2498, acc_train=0.2188, loss_test=1.9770, acc_test=0.5000
# poison_percent 10 epoch 70: loss_train=2.2751, acc_train=0.1875, loss_test=1.9790, acc_test=0.5000
# poison_percent 10 epoch 71: loss_train=2.2916, acc_train=0.1562, loss_test=1.9852, acc_test=0.5000
# poison_percent 10 epoch 72: loss_train=2.2438, acc_train=0.2188, loss_test=1.9833, acc_test=0.5000
# poison_percent 10 epoch 73: loss_train=2.2675, acc_train=0.1875, loss_test=1.9826, acc_test=0.5000
# poison_percent 10 epoch 74: loss_train=2.2780, acc_train=0.1562, loss_test=1.9775, acc_test=0.5000
# poison_percent 10 epoch 75: loss_train=2.3357, acc_train=0.0938, loss_test=1.9754, acc_test=0.5000
# poison_percent 10 epoch 76: loss_train=2.2445, acc_train=0.2188, loss_test=1.9802, acc_test=0.5000
# poison_percent 10 epoch 77: loss_train=2.2421, acc_train=0.2500, loss_test=1.9830, acc_test=0.5000
# poison_percent 10 epoch 78: loss_train=2.2546, acc_train=0.1875, loss_test=1.9792, acc_test=0.5000
# poison_percent 10 epoch 79: loss_train=2.1878, acc_train=0.2812, loss_test=1.9865, acc_test=0.5000
# poison_percent 10 epoch 80: loss_train=2.2460, acc_train=0.2188, loss_test=1.9769, acc_test=0.5000
# poison_percent 10 epoch 81: loss_train=2.2046, acc_train=0.2812, loss_test=1.9796, acc_test=0.5000
# poison_percent 10 epoch 82: loss_train=2.2557, acc_train=0.2188, loss_test=1.9781, acc_test=0.5000
# poison_percent 10 epoch 83: loss_train=2.2317, acc_train=0.2188, loss_test=1.9875, acc_test=0.5000
# poison_percent 10 epoch 84: loss_train=2.2515, acc_train=0.2188, loss_test=1.9879, acc_test=0.5000
# poison_percent 10 epoch 85: loss_train=2.2699, acc_train=0.1875, loss_test=1.9821, acc_test=0.5000
# poison_percent 10 epoch 86: loss_train=2.2707, acc_train=0.1875, loss_test=1.9787, acc_test=0.5000
# poison_percent 10 epoch 87: loss_train=2.2454, acc_train=0.2188, loss_test=1.9753, acc_test=0.5000
# poison_percent 10 epoch 88: loss_train=2.2867, acc_train=0.1562, loss_test=1.9780, acc_test=0.5000
# poison_percent 10 epoch 89: loss_train=2.2669, acc_train=0.1875, loss_test=1.9823, acc_test=0.5000
# poison_percent 10 epoch 90: loss_train=2.2409, acc_train=0.2188, loss_test=1.9850, acc_test=0.5000
# poison_percent 10 epoch 91: loss_train=2.2434, acc_train=0.2188, loss_test=1.9822, acc_test=0.5000
# poison_percent 10 epoch 92: loss_train=2.2301, acc_train=0.2500, loss_test=1.9893, acc_test=0.5000
# poison_percent 10 epoch 93: loss_train=2.1771, acc_train=0.3125, loss_test=1.9838, acc_test=0.5000
# poison_percent 10 epoch 94: loss_train=2.2603, acc_train=0.1875, loss_test=1.9808, acc_test=0.5000
# poison_percent 10 epoch 95: loss_train=2.3223, acc_train=0.0938, loss_test=1.9854, acc_test=0.5000
# poison_percent 10 epoch 96: loss_train=2.2767, acc_train=0.1875, loss_test=1.9862, acc_test=0.5000
# poison_percent 10 epoch 97: loss_train=2.2718, acc_train=0.1875, loss_test=1.9826, acc_test=0.5000
# poison_percent 10 epoch 98: loss_train=2.2474, acc_train=0.2188, loss_test=1.9835, acc_test=0.5000
# poison_percent 10 epoch 99: loss_train=2.2257, acc_train=0.2500, loss_test=1.9743, acc_test=0.5000
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\CL_ModelN1L2_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 epoch 0: loss_train=2.2733, acc_train=0.1935, loss_test=1.8291, acc_test=0.5000
# poison_percent 20 epoch 1: loss_train=2.3306, acc_train=0.1613, loss_test=1.8244, acc_test=0.5000
# poison_percent 20 epoch 2: loss_train=2.0365, acc_train=0.3871, loss_test=1.8141, acc_test=0.5000
# poison_percent 20 epoch 3: loss_train=2.3829, acc_train=0.0968, loss_test=1.8117, acc_test=0.5000
# poison_percent 20 epoch 4: loss_train=2.3275, acc_train=0.1613, loss_test=1.8192, acc_test=0.5000
# poison_percent 20 epoch 5: loss_train=2.1793, acc_train=0.2581, loss_test=1.8139, acc_test=0.5000
# poison_percent 20 epoch 6: loss_train=2.1446, acc_train=0.3226, loss_test=1.8119, acc_test=0.5000
# poison_percent 20 epoch 7: loss_train=2.2261, acc_train=0.2258, loss_test=1.8149, acc_test=0.5000
# poison_percent 20 epoch 8: loss_train=2.2659, acc_train=0.1935, loss_test=1.8191, acc_test=0.5000
# poison_percent 20 epoch 9: loss_train=2.0905, acc_train=0.3548, loss_test=1.8151, acc_test=0.5000
# poison_percent 20 epoch 10: loss_train=2.1066, acc_train=0.3226, loss_test=1.8107, acc_test=0.5000
# poison_percent 20 epoch 11: loss_train=2.2497, acc_train=0.2258, loss_test=1.8207, acc_test=0.5000
# poison_percent 20 epoch 12: loss_train=2.0024, acc_train=0.4194, loss_test=1.8113, acc_test=0.5000
# poison_percent 20 epoch 13: loss_train=2.2383, acc_train=0.2258, loss_test=1.8133, acc_test=0.5000
# poison_percent 20 epoch 14: loss_train=2.3490, acc_train=0.1290, loss_test=1.8152, acc_test=0.5000
# poison_percent 20 epoch 15: loss_train=2.2083, acc_train=0.2581, loss_test=1.8162, acc_test=0.5000
# poison_percent 20 epoch 16: loss_train=2.2301, acc_train=0.2258, loss_test=1.8233, acc_test=0.5000
# poison_percent 20 epoch 17: loss_train=2.1110, acc_train=0.3226, loss_test=1.8214, acc_test=0.5000
# poison_percent 20 epoch 18: loss_train=2.0413, acc_train=0.3871, loss_test=1.8149, acc_test=0.5000
# poison_percent 20 epoch 19: loss_train=2.1326, acc_train=0.3226, loss_test=1.8114, acc_test=0.5000
# poison_percent 20 epoch 20: loss_train=2.1815, acc_train=0.2903, loss_test=1.8176, acc_test=0.5000
# poison_percent 20 epoch 21: loss_train=2.0467, acc_train=0.3871, loss_test=1.8162, acc_test=0.5000
# poison_percent 20 epoch 22: loss_train=2.2479, acc_train=0.1935, loss_test=1.8156, acc_test=0.5000
# poison_percent 20 epoch 23: loss_train=2.1615, acc_train=0.2903, loss_test=1.8181, acc_test=0.5000
# poison_percent 20 epoch 24: loss_train=2.2067, acc_train=0.2258, loss_test=1.8167, acc_test=0.5000
# poison_percent 20 epoch 25: loss_train=2.2904, acc_train=0.1613, loss_test=1.8171, acc_test=0.5000
# poison_percent 20 epoch 26: loss_train=2.0544, acc_train=0.3871, loss_test=1.8255, acc_test=0.5000
# poison_percent 20 epoch 27: loss_train=2.1985, acc_train=0.2581, loss_test=1.8200, acc_test=0.5000
# poison_percent 20 epoch 28: loss_train=2.1709, acc_train=0.2903, loss_test=1.8223, acc_test=0.5000
# poison_percent 20 epoch 29: loss_train=2.2931, acc_train=0.1613, loss_test=1.8154, acc_test=0.5000
# poison_percent 20 epoch 30: loss_train=2.1248, acc_train=0.3226, loss_test=1.8098, acc_test=0.5000
# poison_percent 20 epoch 31: loss_train=2.1510, acc_train=0.3226, loss_test=1.8185, acc_test=0.5000
# poison_percent 20 epoch 32: loss_train=2.1532, acc_train=0.2903, loss_test=1.8185, acc_test=0.5000
# poison_percent 20 epoch 33: loss_train=2.1624, acc_train=0.2903, loss_test=1.8137, acc_test=0.5000
# poison_percent 20 epoch 34: loss_train=2.2469, acc_train=0.2258, loss_test=1.8160, acc_test=0.5000
# poison_percent 20 epoch 35: loss_train=2.2330, acc_train=0.2258, loss_test=1.8093, acc_test=0.5000
# poison_percent 20 epoch 36: loss_train=2.2818, acc_train=0.1935, loss_test=1.8128, acc_test=0.5000
# poison_percent 20 epoch 37: loss_train=2.1283, acc_train=0.3226, loss_test=1.8164, acc_test=0.5000
# poison_percent 20 epoch 38: loss_train=2.2161, acc_train=0.2258, loss_test=1.8183, acc_test=0.5000
# poison_percent 20 epoch 39: loss_train=2.2891, acc_train=0.1935, loss_test=1.8049, acc_test=0.5000
# poison_percent 20 epoch 40: loss_train=2.2008, acc_train=0.2581, loss_test=1.8132, acc_test=0.5000
# poison_percent 20 epoch 41: loss_train=2.4215, acc_train=0.0645, loss_test=1.8077, acc_test=0.5000
# poison_percent 20 epoch 42: loss_train=2.3550, acc_train=0.1290, loss_test=1.8234, acc_test=0.5000
# poison_percent 20 epoch 43: loss_train=2.0994, acc_train=0.3548, loss_test=1.8211, acc_test=0.5000
# poison_percent 20 epoch 44: loss_train=2.2468, acc_train=0.2258, loss_test=1.8159, acc_test=0.5000
# poison_percent 20 epoch 45: loss_train=2.2717, acc_train=0.1935, loss_test=1.8259, acc_test=0.5000
# poison_percent 20 epoch 46: loss_train=2.2593, acc_train=0.1935, loss_test=1.8172, acc_test=0.5000
# poison_percent 20 epoch 47: loss_train=2.1326, acc_train=0.3226, loss_test=1.8149, acc_test=0.5000
# poison_percent 20 epoch 48: loss_train=2.1348, acc_train=0.3226, loss_test=1.8179, acc_test=0.5000
# poison_percent 20 epoch 49: loss_train=2.1966, acc_train=0.2581, loss_test=1.8137, acc_test=0.5000
# poison_percent 20 epoch 50: loss_train=2.2808, acc_train=0.1935, loss_test=1.8187, acc_test=0.5000
# poison_percent 20 epoch 51: loss_train=2.3428, acc_train=0.1290, loss_test=1.8212, acc_test=0.5000
# poison_percent 20 epoch 52: loss_train=1.9661, acc_train=0.4516, loss_test=1.8138, acc_test=0.5000
# poison_percent 20 epoch 53: loss_train=2.2452, acc_train=0.2258, loss_test=1.8111, acc_test=0.5000
# poison_percent 20 epoch 54: loss_train=2.0799, acc_train=0.3548, loss_test=1.8073, acc_test=0.5000
# poison_percent 20 epoch 55: loss_train=2.1049, acc_train=0.3226, loss_test=1.8138, acc_test=0.5000
# poison_percent 20 epoch 56: loss_train=2.1648, acc_train=0.2903, loss_test=1.8159, acc_test=0.5000
# poison_percent 20 epoch 57: loss_train=2.1994, acc_train=0.2581, loss_test=1.8167, acc_test=0.5000
# poison_percent 20 epoch 58: loss_train=2.2122, acc_train=0.2258, loss_test=1.8089, acc_test=0.5000
# poison_percent 20 epoch 59: loss_train=2.2029, acc_train=0.2581, loss_test=1.8162, acc_test=0.5000
# poison_percent 20 epoch 60: loss_train=2.2127, acc_train=0.2581, loss_test=1.8036, acc_test=0.5000
# poison_percent 20 epoch 61: loss_train=2.1232, acc_train=0.3226, loss_test=1.8192, acc_test=0.5000
# poison_percent 20 epoch 62: loss_train=2.2564, acc_train=0.1935, loss_test=1.8167, acc_test=0.5000
# poison_percent 20 epoch 63: loss_train=2.1681, acc_train=0.2581, loss_test=1.8177, acc_test=0.5000
# poison_percent 20 epoch 64: loss_train=2.1712, acc_train=0.2903, loss_test=1.8177, acc_test=0.5000
# poison_percent 20 epoch 65: loss_train=2.2161, acc_train=0.2258, loss_test=1.8103, acc_test=0.5000
# poison_percent 20 epoch 66: loss_train=2.1488, acc_train=0.2903, loss_test=1.8083, acc_test=0.5000
# poison_percent 20 epoch 67: loss_train=2.1367, acc_train=0.3226, loss_test=1.8118, acc_test=0.5000
# poison_percent 20 epoch 68: loss_train=2.2102, acc_train=0.2581, loss_test=1.8171, acc_test=0.5000
# poison_percent 20 epoch 69: loss_train=2.0181, acc_train=0.4194, loss_test=1.8132, acc_test=0.5000
# poison_percent 20 epoch 70: loss_train=2.3877, acc_train=0.0968, loss_test=1.8215, acc_test=0.5000
# poison_percent 20 epoch 71: loss_train=2.1722, acc_train=0.2903, loss_test=1.8171, acc_test=0.5000
# poison_percent 20 epoch 72: loss_train=2.2704, acc_train=0.1935, loss_test=1.8163, acc_test=0.5000
# poison_percent 20 epoch 73: loss_train=2.2429, acc_train=0.2258, loss_test=1.8116, acc_test=0.5000
# poison_percent 20 epoch 74: loss_train=2.2333, acc_train=0.2258, loss_test=1.8038, acc_test=0.5000
# poison_percent 20 epoch 75: loss_train=2.3533, acc_train=0.1290, loss_test=1.8127, acc_test=0.5000
# poison_percent 20 epoch 76: loss_train=2.2531, acc_train=0.1935, loss_test=1.8223, acc_test=0.5000
# poison_percent 20 epoch 77: loss_train=2.1103, acc_train=0.3226, loss_test=1.8079, acc_test=0.5000
# poison_percent 20 epoch 78: loss_train=2.3007, acc_train=0.1935, loss_test=1.8142, acc_test=0.5000
# poison_percent 20 epoch 79: loss_train=2.1103, acc_train=0.3226, loss_test=1.8082, acc_test=0.5000
# poison_percent 20 epoch 80: loss_train=2.1610, acc_train=0.2903, loss_test=1.8140, acc_test=0.5000
# poison_percent 20 epoch 81: loss_train=2.0493, acc_train=0.3871, loss_test=1.8166, acc_test=0.5000
# poison_percent 20 epoch 82: loss_train=2.1131, acc_train=0.3226, loss_test=1.8112, acc_test=0.5000
# poison_percent 20 epoch 83: loss_train=2.1839, acc_train=0.2903, loss_test=1.8209, acc_test=0.5000
# poison_percent 20 epoch 84: loss_train=2.0145, acc_train=0.4194, loss_test=1.8130, acc_test=0.5000
# poison_percent 20 epoch 85: loss_train=2.1162, acc_train=0.3226, loss_test=1.8085, acc_test=0.5000
# poison_percent 20 epoch 86: loss_train=2.1670, acc_train=0.2903, loss_test=1.8183, acc_test=0.5000
# poison_percent 20 epoch 87: loss_train=2.2226, acc_train=0.2581, loss_test=1.8181, acc_test=0.5000
# poison_percent 20 epoch 88: loss_train=2.2688, acc_train=0.1935, loss_test=1.8128, acc_test=0.5000
# poison_percent 20 epoch 89: loss_train=2.1165, acc_train=0.3226, loss_test=1.8140, acc_test=0.5000
# poison_percent 20 epoch 90: loss_train=2.2966, acc_train=0.1613, loss_test=1.8143, acc_test=0.5000
# poison_percent 20 epoch 91: loss_train=2.1758, acc_train=0.2581, loss_test=1.8133, acc_test=0.5000
# poison_percent 20 epoch 92: loss_train=2.0421, acc_train=0.3871, loss_test=1.8072, acc_test=0.5000
# poison_percent 20 epoch 93: loss_train=2.0215, acc_train=0.4194, loss_test=1.8186, acc_test=0.5000
# poison_percent 20 epoch 94: loss_train=2.1196, acc_train=0.3226, loss_test=1.8156, acc_test=0.5000
# poison_percent 20 epoch 95: loss_train=2.2978, acc_train=0.1935, loss_test=1.8157, acc_test=0.5000
# poison_percent 20 epoch 96: loss_train=2.3352, acc_train=0.1613, loss_test=1.8201, acc_test=0.5000
# poison_percent 20 epoch 97: loss_train=2.3163, acc_train=0.1613, loss_test=1.8152, acc_test=0.5000
# poison_percent 20 epoch 98: loss_train=2.1737, acc_train=0.2903, loss_test=1.8152, acc_test=0.5000
# poison_percent 20 epoch 99: loss_train=2.1359, acc_train=0.3226, loss_test=1.8124, acc_test=0.5000
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\CL_ModelN1L2_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 epoch 0: loss_train=2.0634, acc_train=0.3462, loss_test=1.6890, acc_test=0.5000
# poison_percent 30 epoch 1: loss_train=1.8734, acc_train=0.4615, loss_test=1.6838, acc_test=0.5000
# poison_percent 30 epoch 2: loss_train=2.0486, acc_train=0.3846, loss_test=1.6775, acc_test=0.5000
# poison_percent 30 epoch 3: loss_train=2.2025, acc_train=0.2692, loss_test=1.6828, acc_test=0.5000
# poison_percent 30 epoch 4: loss_train=1.8487, acc_train=0.5000, loss_test=1.6838, acc_test=0.5000
# poison_percent 30 epoch 5: loss_train=2.0375, acc_train=0.3846, loss_test=1.6801, acc_test=0.5000
# poison_percent 30 epoch 6: loss_train=2.1552, acc_train=0.3077, loss_test=1.6779, acc_test=0.5000
# poison_percent 30 epoch 7: loss_train=1.9177, acc_train=0.4615, loss_test=1.6800, acc_test=0.5000
# poison_percent 30 epoch 8: loss_train=1.8382, acc_train=0.5000, loss_test=1.6748, acc_test=0.5000
# poison_percent 30 epoch 9: loss_train=1.9744, acc_train=0.4231, loss_test=1.6815, acc_test=0.5000
# poison_percent 30 epoch 10: loss_train=1.9747, acc_train=0.4231, loss_test=1.6826, acc_test=0.5000
# poison_percent 30 epoch 11: loss_train=2.2144, acc_train=0.2692, loss_test=1.6794, acc_test=0.5000
# poison_percent 30 epoch 12: loss_train=1.8832, acc_train=0.4231, loss_test=1.6732, acc_test=0.5000
# poison_percent 30 epoch 13: loss_train=2.1417, acc_train=0.2692, loss_test=1.6773, acc_test=0.5000
# poison_percent 30 epoch 14: loss_train=2.1185, acc_train=0.3077, loss_test=1.6873, acc_test=0.5000
# poison_percent 30 epoch 15: loss_train=2.1699, acc_train=0.2692, loss_test=1.6815, acc_test=0.5000
# poison_percent 30 epoch 16: loss_train=1.9029, acc_train=0.4615, loss_test=1.6837, acc_test=0.5000
# poison_percent 30 epoch 17: loss_train=1.9464, acc_train=0.4231, loss_test=1.6821, acc_test=0.5000
# poison_percent 30 epoch 18: loss_train=1.9429, acc_train=0.4231, loss_test=1.6765, acc_test=0.5000
# poison_percent 30 epoch 19: loss_train=2.2241, acc_train=0.2692, loss_test=1.6679, acc_test=0.5000
# poison_percent 30 epoch 20: loss_train=1.9333, acc_train=0.4615, loss_test=1.6901, acc_test=0.5000
# poison_percent 30 epoch 21: loss_train=1.9003, acc_train=0.4615, loss_test=1.6873, acc_test=0.5000
# poison_percent 30 epoch 22: loss_train=2.0287, acc_train=0.3846, loss_test=1.6823, acc_test=0.5000
# poison_percent 30 epoch 23: loss_train=2.1888, acc_train=0.2692, loss_test=1.6861, acc_test=0.5000
# poison_percent 30 epoch 24: loss_train=1.9492, acc_train=0.4231, loss_test=1.6871, acc_test=0.5000
# poison_percent 30 epoch 25: loss_train=2.1070, acc_train=0.3462, loss_test=1.6844, acc_test=0.5000
# poison_percent 30 epoch 26: loss_train=2.0673, acc_train=0.3462, loss_test=1.6862, acc_test=0.5000
# poison_percent 30 epoch 27: loss_train=2.0289, acc_train=0.3846, loss_test=1.6810, acc_test=0.5000
# poison_percent 30 epoch 28: loss_train=2.0566, acc_train=0.3462, loss_test=1.6796, acc_test=0.5000
# poison_percent 30 epoch 29: loss_train=2.2441, acc_train=0.2692, loss_test=1.6889, acc_test=0.5000
# poison_percent 30 epoch 30: loss_train=1.9514, acc_train=0.4231, loss_test=1.6877, acc_test=0.5000
# poison_percent 30 epoch 31: loss_train=1.9816, acc_train=0.4231, loss_test=1.6878, acc_test=0.5000
# poison_percent 30 epoch 32: loss_train=2.0411, acc_train=0.3462, loss_test=1.6910, acc_test=0.5000
# poison_percent 30 epoch 33: loss_train=2.1890, acc_train=0.2692, loss_test=1.6830, acc_test=0.5000
# poison_percent 30 epoch 34: loss_train=2.1836, acc_train=0.2692, loss_test=1.6751, acc_test=0.5000
# poison_percent 30 epoch 35: loss_train=2.5348, acc_train=0.0385, loss_test=1.6801, acc_test=0.5000
# poison_percent 30 epoch 36: loss_train=2.3049, acc_train=0.1923, loss_test=1.6731, acc_test=0.5000
# poison_percent 30 epoch 37: loss_train=1.9328, acc_train=0.4615, loss_test=1.6779, acc_test=0.5000
# poison_percent 30 epoch 38: loss_train=1.9591, acc_train=0.4231, loss_test=1.6825, acc_test=0.5000
# poison_percent 30 epoch 39: loss_train=1.9361, acc_train=0.4231, loss_test=1.6830, acc_test=0.5000
# poison_percent 30 epoch 40: loss_train=1.8866, acc_train=0.4615, loss_test=1.6837, acc_test=0.5000
# poison_percent 30 epoch 41: loss_train=2.1765, acc_train=0.2692, loss_test=1.6767, acc_test=0.5000
# poison_percent 30 epoch 42: loss_train=1.9983, acc_train=0.3846, loss_test=1.6901, acc_test=0.5000
# poison_percent 30 epoch 43: loss_train=2.3282, acc_train=0.1923, loss_test=1.6786, acc_test=0.5000
# poison_percent 30 epoch 44: loss_train=2.0211, acc_train=0.3846, loss_test=1.6854, acc_test=0.5000
# poison_percent 30 epoch 45: loss_train=2.1748, acc_train=0.2692, loss_test=1.6751, acc_test=0.5000
# poison_percent 30 epoch 46: loss_train=2.2003, acc_train=0.2692, loss_test=1.6856, acc_test=0.5000
# poison_percent 30 epoch 47: loss_train=1.9491, acc_train=0.4231, loss_test=1.6842, acc_test=0.5000
# poison_percent 30 epoch 48: loss_train=2.2493, acc_train=0.2308, loss_test=1.6790, acc_test=0.5000
# poison_percent 30 epoch 49: loss_train=2.2111, acc_train=0.2692, loss_test=1.6830, acc_test=0.5000
# poison_percent 30 epoch 50: loss_train=2.4428, acc_train=0.1154, loss_test=1.6790, acc_test=0.5000
# poison_percent 30 epoch 51: loss_train=2.1423, acc_train=0.3077, loss_test=1.6776, acc_test=0.5000
# poison_percent 30 epoch 52: loss_train=2.1251, acc_train=0.3077, loss_test=1.6690, acc_test=0.5000
# poison_percent 30 epoch 53: loss_train=2.1279, acc_train=0.3462, loss_test=1.6851, acc_test=0.5000
# poison_percent 30 epoch 54: loss_train=1.9827, acc_train=0.4231, loss_test=1.6781, acc_test=0.5000
# poison_percent 30 epoch 55: loss_train=2.0086, acc_train=0.3846, loss_test=1.6836, acc_test=0.5000
# poison_percent 30 epoch 56: loss_train=2.0994, acc_train=0.3462, loss_test=1.6800, acc_test=0.5000
# poison_percent 30 epoch 57: loss_train=2.1037, acc_train=0.3462, loss_test=1.6674, acc_test=0.5000
# poison_percent 30 epoch 58: loss_train=1.9892, acc_train=0.4231, loss_test=1.6803, acc_test=0.5000
# poison_percent 30 epoch 59: loss_train=2.2407, acc_train=0.2308, loss_test=1.6811, acc_test=0.5000
# poison_percent 30 epoch 60: loss_train=2.2252, acc_train=0.2692, loss_test=1.6757, acc_test=0.5000
# poison_percent 30 epoch 61: loss_train=2.1358, acc_train=0.3077, loss_test=1.6798, acc_test=0.5000
# poison_percent 30 epoch 62: loss_train=2.0018, acc_train=0.3846, loss_test=1.6853, acc_test=0.5000
# poison_percent 30 epoch 63: loss_train=1.9606, acc_train=0.4231, loss_test=1.6819, acc_test=0.5000
# poison_percent 30 epoch 64: loss_train=1.9939, acc_train=0.4231, loss_test=1.6877, acc_test=0.5000
# poison_percent 30 epoch 65: loss_train=1.9332, acc_train=0.4231, loss_test=1.6818, acc_test=0.5000
# poison_percent 30 epoch 66: loss_train=1.9618, acc_train=0.4231, loss_test=1.6822, acc_test=0.5000
# poison_percent 30 epoch 67: loss_train=2.0569, acc_train=0.3462, loss_test=1.6898, acc_test=0.5000
# poison_percent 30 epoch 68: loss_train=2.1168, acc_train=0.3077, loss_test=1.6859, acc_test=0.5000
# poison_percent 30 epoch 69: loss_train=2.2076, acc_train=0.2692, loss_test=1.6896, acc_test=0.5000
# poison_percent 30 epoch 70: loss_train=2.3215, acc_train=0.1923, loss_test=1.6785, acc_test=0.5000
# poison_percent 30 epoch 71: loss_train=2.1132, acc_train=0.3462, loss_test=1.6821, acc_test=0.5000
# poison_percent 30 epoch 72: loss_train=1.8212, acc_train=0.5000, loss_test=1.6743, acc_test=0.5000
# poison_percent 30 epoch 73: loss_train=1.7320, acc_train=0.5769, loss_test=1.6804, acc_test=0.5000
# poison_percent 30 epoch 74: loss_train=2.1756, acc_train=0.3077, loss_test=1.6891, acc_test=0.5000
# poison_percent 30 epoch 75: loss_train=1.9325, acc_train=0.4615, loss_test=1.6803, acc_test=0.5000
# poison_percent 30 epoch 76: loss_train=2.1126, acc_train=0.3077, loss_test=1.6841, acc_test=0.5000
# poison_percent 30 epoch 77: loss_train=2.0956, acc_train=0.3462, loss_test=1.6832, acc_test=0.5000
# poison_percent 30 epoch 78: loss_train=2.0247, acc_train=0.3846, loss_test=1.6853, acc_test=0.5000
# poison_percent 30 epoch 79: loss_train=2.1196, acc_train=0.3077, loss_test=1.6829, acc_test=0.5000
# poison_percent 30 epoch 80: loss_train=2.0565, acc_train=0.3846, loss_test=1.6836, acc_test=0.5000
# poison_percent 30 epoch 81: loss_train=2.0736, acc_train=0.3462, loss_test=1.6826, acc_test=0.5000
# poison_percent 30 epoch 82: loss_train=2.1312, acc_train=0.3077, loss_test=1.6772, acc_test=0.5000
# poison_percent 30 epoch 83: loss_train=2.2072, acc_train=0.2692, loss_test=1.6903, acc_test=0.5000
# poison_percent 30 epoch 84: loss_train=2.0295, acc_train=0.3846, loss_test=1.6840, acc_test=0.5000
# poison_percent 30 epoch 85: loss_train=2.2099, acc_train=0.2692, loss_test=1.6701, acc_test=0.5000
# poison_percent 30 epoch 86: loss_train=2.2268, acc_train=0.2308, loss_test=1.6879, acc_test=0.5000
# poison_percent 30 epoch 87: loss_train=2.0178, acc_train=0.3846, loss_test=1.6833, acc_test=0.5000
# poison_percent 30 epoch 88: loss_train=1.9756, acc_train=0.3846, loss_test=1.6837, acc_test=0.5000
# poison_percent 30 epoch 89: loss_train=2.2029, acc_train=0.2692, loss_test=1.6804, acc_test=0.5000
# poison_percent 30 epoch 90: loss_train=1.9582, acc_train=0.4231, loss_test=1.6774, acc_test=0.5000
# poison_percent 30 epoch 91: loss_train=1.9693, acc_train=0.4231, loss_test=1.6740, acc_test=0.5000
# poison_percent 30 epoch 92: loss_train=1.9109, acc_train=0.4615, loss_test=1.6816, acc_test=0.5000
# poison_percent 30 epoch 93: loss_train=2.0284, acc_train=0.3846, loss_test=1.6840, acc_test=0.5000
# poison_percent 30 epoch 94: loss_train=2.0283, acc_train=0.3846, loss_test=1.6801, acc_test=0.5000
# poison_percent 30 epoch 95: loss_train=2.1680, acc_train=0.3077, loss_test=1.6846, acc_test=0.5000
# poison_percent 30 epoch 96: loss_train=2.0945, acc_train=0.3077, loss_test=1.6823, acc_test=0.5000
# poison_percent 30 epoch 97: loss_train=2.1028, acc_train=0.3462, loss_test=1.6893, acc_test=0.5000
# poison_percent 30 epoch 98: loss_train=2.1821, acc_train=0.2692, loss_test=1.6831, acc_test=0.5000
# poison_percent 30 epoch 99: loss_train=2.0375, acc_train=0.3846, loss_test=1.6822, acc_test=0.5000
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\CL_ModelN1L2_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 epoch 0: loss_train=1.9276, acc_train=0.4000, loss_test=1.5906, acc_test=0.5000
# poison_percent 40 epoch 1: loss_train=2.1725, acc_train=0.3000, loss_test=1.5754, acc_test=0.5000
# poison_percent 40 epoch 2: loss_train=2.1694, acc_train=0.3000, loss_test=1.5768, acc_test=0.5000
# poison_percent 40 epoch 3: loss_train=2.1179, acc_train=0.3000, loss_test=1.5689, acc_test=0.5000
# poison_percent 40 epoch 4: loss_train=1.4058, acc_train=0.7000, loss_test=1.5816, acc_test=0.5000
# poison_percent 40 epoch 5: loss_train=1.8443, acc_train=0.5000, loss_test=1.5674, acc_test=0.5000
# poison_percent 40 epoch 6: loss_train=1.5946, acc_train=0.6000, loss_test=1.5724, acc_test=0.5000
# poison_percent 40 epoch 7: loss_train=2.1781, acc_train=0.3000, loss_test=1.5721, acc_test=0.5000
# poison_percent 40 epoch 8: loss_train=2.0679, acc_train=0.3000, loss_test=1.5726, acc_test=0.5000
# poison_percent 40 epoch 9: loss_train=1.8758, acc_train=0.4000, loss_test=1.5741, acc_test=0.5000
# poison_percent 40 epoch 10: loss_train=2.3700, acc_train=0.2000, loss_test=1.5815, acc_test=0.5000
# poison_percent 40 epoch 11: loss_train=1.6454, acc_train=0.6000, loss_test=1.5720, acc_test=0.5000
# poison_percent 40 epoch 12: loss_train=2.1675, acc_train=0.3000, loss_test=1.5783, acc_test=0.5000
# poison_percent 40 epoch 13: loss_train=1.9834, acc_train=0.4000, loss_test=1.5746, acc_test=0.5000
# poison_percent 40 epoch 14: loss_train=2.1933, acc_train=0.3000, loss_test=1.5742, acc_test=0.5000
# poison_percent 40 epoch 15: loss_train=2.2000, acc_train=0.3000, loss_test=1.5748, acc_test=0.5000
# poison_percent 40 epoch 16: loss_train=1.6379, acc_train=0.6000, loss_test=1.5773, acc_test=0.5000
# poison_percent 40 epoch 17: loss_train=1.9313, acc_train=0.4000, loss_test=1.5738, acc_test=0.5000
# poison_percent 40 epoch 18: loss_train=1.6542, acc_train=0.6000, loss_test=1.5698, acc_test=0.5000
# poison_percent 40 epoch 19: loss_train=2.2365, acc_train=0.3000, loss_test=1.5743, acc_test=0.5000
# poison_percent 40 epoch 20: loss_train=1.6440, acc_train=0.6000, loss_test=1.5831, acc_test=0.5000
# poison_percent 40 epoch 21: loss_train=1.5368, acc_train=0.6000, loss_test=1.5725, acc_test=0.5000
# poison_percent 40 epoch 22: loss_train=1.7825, acc_train=0.5000, loss_test=1.5808, acc_test=0.5000
# poison_percent 40 epoch 23: loss_train=2.2315, acc_train=0.3000, loss_test=1.5728, acc_test=0.5000
# poison_percent 40 epoch 24: loss_train=1.7297, acc_train=0.5000, loss_test=1.5774, acc_test=0.5000
# poison_percent 40 epoch 25: loss_train=2.2325, acc_train=0.3000, loss_test=1.5742, acc_test=0.5000
# poison_percent 40 epoch 26: loss_train=1.8243, acc_train=0.4000, loss_test=1.5757, acc_test=0.5000
# poison_percent 40 epoch 27: loss_train=2.1238, acc_train=0.3000, loss_test=1.5795, acc_test=0.5000
# poison_percent 40 epoch 28: loss_train=1.7872, acc_train=0.5000, loss_test=1.5832, acc_test=0.5000
# poison_percent 40 epoch 29: loss_train=1.9216, acc_train=0.4000, loss_test=1.5713, acc_test=0.5000
# poison_percent 40 epoch 30: loss_train=1.6034, acc_train=0.6000, loss_test=1.5742, acc_test=0.5000
# poison_percent 40 epoch 31: loss_train=2.0269, acc_train=0.4000, loss_test=1.5847, acc_test=0.5000
# poison_percent 40 epoch 32: loss_train=2.1823, acc_train=0.3000, loss_test=1.5730, acc_test=0.5000
# poison_percent 40 epoch 33: loss_train=1.4579, acc_train=0.7000, loss_test=1.5751, acc_test=0.5000
# poison_percent 40 epoch 34: loss_train=2.3254, acc_train=0.2000, loss_test=1.5757, acc_test=0.5000
# poison_percent 40 epoch 35: loss_train=2.0292, acc_train=0.4000, loss_test=1.5784, acc_test=0.5000
# poison_percent 40 epoch 36: loss_train=1.9892, acc_train=0.4000, loss_test=1.5833, acc_test=0.5000
# poison_percent 40 epoch 37: loss_train=1.7305, acc_train=0.5000, loss_test=1.5741, acc_test=0.5000
# poison_percent 40 epoch 38: loss_train=1.6483, acc_train=0.6000, loss_test=1.5836, acc_test=0.5000
# poison_percent 40 epoch 39: loss_train=2.2218, acc_train=0.3000, loss_test=1.5765, acc_test=0.5000
# poison_percent 40 epoch 40: loss_train=2.0696, acc_train=0.3000, loss_test=1.5885, acc_test=0.5000
# poison_percent 40 epoch 41: loss_train=2.4266, acc_train=0.2000, loss_test=1.5797, acc_test=0.5000
# poison_percent 40 epoch 42: loss_train=2.1182, acc_train=0.3000, loss_test=1.5792, acc_test=0.5000
# poison_percent 40 epoch 43: loss_train=2.2289, acc_train=0.3000, loss_test=1.5735, acc_test=0.5000
# poison_percent 40 epoch 44: loss_train=2.1833, acc_train=0.3000, loss_test=1.5790, acc_test=0.5000
# poison_percent 40 epoch 45: loss_train=1.8502, acc_train=0.5000, loss_test=1.5767, acc_test=0.5000
# poison_percent 40 epoch 46: loss_train=1.6543, acc_train=0.6000, loss_test=1.5795, acc_test=0.5000
# poison_percent 40 epoch 47: loss_train=1.7853, acc_train=0.5000, loss_test=1.5798, acc_test=0.5000
# poison_percent 40 epoch 48: loss_train=2.0405, acc_train=0.4000, loss_test=1.5747, acc_test=0.5000
# poison_percent 40 epoch 49: loss_train=1.4583, acc_train=0.7000, loss_test=1.5773, acc_test=0.5000
# poison_percent 40 epoch 50: loss_train=1.5923, acc_train=0.6000, loss_test=1.5683, acc_test=0.5000
# poison_percent 40 epoch 51: loss_train=2.4424, acc_train=0.2000, loss_test=1.5831, acc_test=0.5000
# poison_percent 40 epoch 52: loss_train=1.5859, acc_train=0.6000, loss_test=1.5783, acc_test=0.5000
# poison_percent 40 epoch 53: loss_train=2.1223, acc_train=0.3000, loss_test=1.5709, acc_test=0.5000
# poison_percent 40 epoch 54: loss_train=1.5909, acc_train=0.6000, loss_test=1.5866, acc_test=0.5000
# poison_percent 40 epoch 55: loss_train=1.9889, acc_train=0.4000, loss_test=1.5697, acc_test=0.5000
# poison_percent 40 epoch 56: loss_train=1.7441, acc_train=0.5000, loss_test=1.5814, acc_test=0.5000
# poison_percent 40 epoch 57: loss_train=1.4581, acc_train=0.7000, loss_test=1.5773, acc_test=0.5000
# poison_percent 40 epoch 58: loss_train=2.6207, acc_train=0.1000, loss_test=1.5719, acc_test=0.5000
# poison_percent 40 epoch 59: loss_train=1.8691, acc_train=0.4000, loss_test=1.5686, acc_test=0.5000
# poison_percent 40 epoch 60: loss_train=1.6522, acc_train=0.6000, loss_test=1.5709, acc_test=0.5000
# poison_percent 40 epoch 61: loss_train=2.0372, acc_train=0.4000, loss_test=1.5783, acc_test=0.5000
# poison_percent 40 epoch 62: loss_train=1.9761, acc_train=0.4000, loss_test=1.5735, acc_test=0.5000
# poison_percent 40 epoch 63: loss_train=1.9734, acc_train=0.4000, loss_test=1.5734, acc_test=0.5000
# poison_percent 40 epoch 64: loss_train=1.5900, acc_train=0.6000, loss_test=1.5794, acc_test=0.5000
# poison_percent 40 epoch 65: loss_train=1.5368, acc_train=0.6000, loss_test=1.5753, acc_test=0.5000
# poison_percent 40 epoch 66: loss_train=2.0408, acc_train=0.4000, loss_test=1.5811, acc_test=0.5000
# poison_percent 40 epoch 67: loss_train=2.0420, acc_train=0.4000, loss_test=1.5778, acc_test=0.5000
# poison_percent 40 epoch 68: loss_train=1.9337, acc_train=0.4000, loss_test=1.5743, acc_test=0.5000
# poison_percent 40 epoch 69: loss_train=2.0620, acc_train=0.3000, loss_test=1.5766, acc_test=0.5000
# poison_percent 40 epoch 70: loss_train=2.0400, acc_train=0.4000, loss_test=1.5735, acc_test=0.5000
# poison_percent 40 epoch 71: loss_train=1.9280, acc_train=0.4000, loss_test=1.5748, acc_test=0.5000
# poison_percent 40 epoch 72: loss_train=2.3123, acc_train=0.2000, loss_test=1.5675, acc_test=0.5000
# poison_percent 40 epoch 73: loss_train=2.6148, acc_train=0.1000, loss_test=1.5701, acc_test=0.5000
# poison_percent 40 epoch 74: loss_train=2.3075, acc_train=0.2000, loss_test=1.5685, acc_test=0.5000
# poison_percent 40 epoch 75: loss_train=2.0346, acc_train=0.4000, loss_test=1.5785, acc_test=0.5000
# poison_percent 40 epoch 76: loss_train=1.5898, acc_train=0.6000, loss_test=1.5715, acc_test=0.5000
# poison_percent 40 epoch 77: loss_train=1.5833, acc_train=0.6000, loss_test=1.5739, acc_test=0.5000
# poison_percent 40 epoch 78: loss_train=1.9865, acc_train=0.4000, loss_test=1.5696, acc_test=0.5000
# ...
# poison_percent 40 epoch 42: loss_train=0.5376, acc_train=0.8000, loss_test=0.6904, acc_test=0.7169
# poison_percent 40 epoch 43: loss_train=0.5479, acc_train=0.7000, loss_test=0.6931, acc_test=0.7390
# poison_percent 40 epoch 44: loss_train=0.5307, acc_train=0.7000, loss_test=0.6787, acc_test=0.7469
# poison_percent 40 epoch 45: loss_train=0.5813, acc_train=0.6000, loss_test=0.7325, acc_test=0.6863
# poison_percent 40 epoch 46: loss_train=0.3971, acc_train=0.8000, loss_test=0.6656, acc_test=0.7525
# poison_percent 40 epoch 47: loss_train=0.8111, acc_train=0.6000, loss_test=0.7451, acc_test=0.6887
# poison_percent 40 epoch 48: loss_train=0.6854, acc_train=0.6000, loss_test=0.7621, acc_test=0.6685
# poison_percent 40 epoch 49: loss_train=0.5773, acc_train=0.6000, loss_test=0.7882, acc_test=0.6593
# poison_percent 40 epoch 50: loss_train=0.4020, acc_train=0.8000, loss_test=0.6873, acc_test=0.7377
# poison_percent 40 epoch 51: loss_train=0.4924, acc_train=0.7000, loss_test=0.7008, acc_test=0.7237
# poison_percent 40 epoch 52: loss_train=0.5203, acc_train=0.7000, loss_test=0.7189, acc_test=0.7200
# poison_percent 40 epoch 53: loss_train=0.3440, acc_train=0.8000, loss_test=0.6751, acc_test=0.7445
# poison_percent 40 epoch 54: loss_train=0.4534, acc_train=0.9000, loss_test=0.6873, acc_test=0.7365
# poison_percent 40 epoch 55: loss_train=0.3047, acc_train=1.0000, loss_test=0.6452, acc_test=0.7806
# poison_percent 40 epoch 56: loss_train=0.3213, acc_train=0.8000, loss_test=0.7281, acc_test=0.7157
# poison_percent 40 epoch 57: loss_train=0.7965, acc_train=0.5000, loss_test=0.7700, acc_test=0.6765
# poison_percent 40 epoch 58: loss_train=0.7684, acc_train=0.4000, loss_test=0.6187, acc_test=0.7972
# poison_percent 40 epoch 59: loss_train=0.5413, acc_train=0.7000, loss_test=0.7226, acc_test=0.7083
# poison_percent 40 epoch 60: loss_train=0.5906, acc_train=0.7000, loss_test=0.7092, acc_test=0.7237
# poison_percent 40 epoch 61: loss_train=0.9049, acc_train=0.5000, loss_test=0.6540, acc_test=0.7561
# poison_percent 40 epoch 62: loss_train=1.1811, acc_train=0.7000, loss_test=0.8261, acc_test=0.6078
# poison_percent 40 epoch 63: loss_train=0.4313, acc_train=0.7000, loss_test=0.7254, acc_test=0.6955
# poison_percent 40 epoch 64: loss_train=0.6869, acc_train=0.5000, loss_test=0.6165, acc_test=0.7990
# poison_percent 40 epoch 65: loss_train=0.8958, acc_train=0.4000, loss_test=0.6977, acc_test=0.7377
# poison_percent 40 epoch 66: loss_train=0.2873, acc_train=1.0000, loss_test=0.7679, acc_test=0.6520
# poison_percent 40 epoch 67: loss_train=0.7171, acc_train=0.5000, loss_test=0.7210, acc_test=0.7151
# poison_percent 40 epoch 68: loss_train=0.4949, acc_train=0.6000, loss_test=0.7076, acc_test=0.7163
# poison_percent 40 epoch 69: loss_train=0.4578, acc_train=0.9000, loss_test=0.6983, acc_test=0.7328
# poison_percent 40 epoch 70: loss_train=0.5722, acc_train=0.8000, loss_test=0.6964, acc_test=0.7439
# poison_percent 40 epoch 71: loss_train=0.4433, acc_train=0.9000, loss_test=0.6727, acc_test=0.7592
# poison_percent 40 epoch 72: loss_train=0.5908, acc_train=0.7000, loss_test=0.6900, acc_test=0.7733
# poison_percent 40 epoch 73: loss_train=0.7533, acc_train=0.6000, loss_test=0.6560, acc_test=0.7757
# poison_percent 40 epoch 74: loss_train=0.5209, acc_train=0.8000, loss_test=0.6980, acc_test=0.7390
# poison_percent 40 epoch 75: loss_train=0.8117, acc_train=0.7000, loss_test=0.6820, acc_test=0.7604
# poison_percent 40 epoch 76: loss_train=0.5984, acc_train=0.5000, loss_test=0.6419, acc_test=0.7917
# poison_percent 40 epoch 77: loss_train=0.4924, acc_train=0.6000, loss_test=0.7237, acc_test=0.7138
# poison_percent 40 epoch 78: loss_train=0.8076, acc_train=0.6000, loss_test=0.7427, acc_test=0.7089
# poison_percent 40 epoch 79: loss_train=0.6797, acc_train=0.5000, loss_test=0.6998, acc_test=0.7377
# poison_percent 40 epoch 80: loss_train=0.5137, acc_train=0.8000, loss_test=0.6510, acc_test=0.7745
# poison_percent 40 epoch 81: loss_train=0.2276, acc_train=1.0000, loss_test=0.6491, acc_test=0.7843
# poison_percent 40 epoch 82: loss_train=0.3397, acc_train=0.9000, loss_test=0.6101, acc_test=0.8278
# poison_percent 40 epoch 83: loss_train=0.6703, acc_train=0.6000, loss_test=0.7886, acc_test=0.6575
# poison_percent 40 epoch 84: loss_train=0.3344, acc_train=0.9000, loss_test=0.7406, acc_test=0.7157
# poison_percent 40 epoch 85: loss_train=0.5619, acc_train=0.7000, loss_test=0.7778, acc_test=0.6777
# poison_percent 40 epoch 86: loss_train=0.3712, acc_train=0.8000, loss_test=0.7381, acc_test=0.7114
# poison_percent 40 epoch 87: loss_train=0.5085, acc_train=0.8000, loss_test=0.7211, acc_test=0.7286
# poison_percent 40 epoch 88: loss_train=0.6341, acc_train=0.6000, loss_test=0.6545, acc_test=0.7812
# poison_percent 40 epoch 89: loss_train=0.2846, acc_train=0.8000, loss_test=0.7062, acc_test=0.7249
# poison_percent 40 epoch 90: loss_train=0.5608, acc_train=0.7000, loss_test=0.8216, acc_test=0.6434
# poison_percent 40 epoch 91: loss_train=0.4982, acc_train=0.8000, loss_test=0.6978, acc_test=0.7500
# poison_percent 40 epoch 92: loss_train=0.3938, acc_train=0.9000, loss_test=0.7249, acc_test=0.7108
# poison_percent 40 epoch 93: loss_train=0.5771, acc_train=0.8000, loss_test=0.7324, acc_test=0.7310
# poison_percent 40 epoch 94: loss_train=0.5214, acc_train=0.7000, loss_test=0.8037, acc_test=0.6575
# poison_percent 40 epoch 95: loss_train=0.2956, acc_train=0.9000, loss_test=0.7088, acc_test=0.7304
# poison_percent 40 epoch 96: loss_train=0.4119, acc_train=0.8000, loss_test=0.6388, acc_test=0.7917
# poison_percent 40 epoch 97: loss_train=0.3855, acc_train=0.8000, loss_test=0.6625, acc_test=0.7549
# poison_percent 40 epoch 98: loss_train=0.6244, acc_train=0.8000, loss_test=0.7604, acc_test=0.7010
# poison_percent 40 epoch 99: loss_train=0.5716, acc_train=0.7000, loss_test=0.6999, acc_test=0.7531
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\CL_ModelN32L2_Batchsize32_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 epoch 0: loss_train=0.6199, acc_train=0.7500, loss_test=0.8791, acc_test=0.5227
# poison_percent 50 epoch 1: loss_train=0.6059, acc_train=0.5714, loss_test=0.9184, acc_test=0.4951
# poison_percent 50 epoch 2: loss_train=0.6443, acc_train=0.6786, loss_test=0.8990, acc_test=0.4596
# poison_percent 50 epoch 3: loss_train=0.4748, acc_train=0.7500, loss_test=0.8644, acc_test=0.5343
# poison_percent 50 epoch 4: loss_train=0.5991, acc_train=0.7500, loss_test=0.8015, acc_test=0.5858
# poison_percent 50 epoch 5: loss_train=0.5548, acc_train=0.7143, loss_test=0.8509, acc_test=0.5656
# poison_percent 50 epoch 6: loss_train=0.6359, acc_train=0.7500, loss_test=0.9146, acc_test=0.4228
# poison_percent 50 epoch 7: loss_train=0.5932, acc_train=0.6786, loss_test=0.9131, acc_test=0.4442
# poison_percent 50 epoch 8: loss_train=0.5469, acc_train=0.6786, loss_test=1.0051, acc_test=0.3609
# poison_percent 50 epoch 9: loss_train=0.5789, acc_train=0.7143, loss_test=0.8164, acc_test=0.5784
# poison_percent 50 epoch 10: loss_train=0.7259, acc_train=0.6429, loss_test=0.8821, acc_test=0.5374
# poison_percent 50 epoch 11: loss_train=0.4787, acc_train=0.7857, loss_test=0.9048, acc_test=0.5147
# poison_percent 50 epoch 12: loss_train=0.8246, acc_train=0.4643, loss_test=0.8043, acc_test=0.6109
# poison_percent 50 epoch 13: loss_train=0.7944, acc_train=0.5000, loss_test=0.8782, acc_test=0.4933
# poison_percent 50 epoch 14: loss_train=0.6297, acc_train=0.6071, loss_test=1.0123, acc_test=0.3848
# poison_percent 50 epoch 15: loss_train=0.6822, acc_train=0.6429, loss_test=1.0164, acc_test=0.4173
# poison_percent 50 epoch 16: loss_train=0.6757, acc_train=0.6429, loss_test=0.8977, acc_test=0.4939
# poison_percent 50 epoch 17: loss_train=0.6135, acc_train=0.7500, loss_test=0.8771, acc_test=0.4975
# poison_percent 50 epoch 18: loss_train=0.6687, acc_train=0.5714, loss_test=0.9522, acc_test=0.4381
# poison_percent 50 epoch 19: loss_train=0.5419, acc_train=0.7143, loss_test=0.8765, acc_test=0.4994
# poison_percent 50 epoch 20: loss_train=0.5507, acc_train=0.6429, loss_test=0.9865, acc_test=0.3578
# poison_percent 50 epoch 21: loss_train=0.6225, acc_train=0.6786, loss_test=0.9279, acc_test=0.4841
# poison_percent 50 epoch 22: loss_train=0.6383, acc_train=0.6071, loss_test=0.8691, acc_test=0.5202
# poison_percent 50 epoch 23: loss_train=0.6853, acc_train=0.7143, loss_test=0.8700, acc_test=0.5221
# poison_percent 50 epoch 24: loss_train=0.6740, acc_train=0.6429, loss_test=0.8909, acc_test=0.4400
# poison_percent 50 epoch 25: loss_train=0.6130, acc_train=0.7500, loss_test=0.9069, acc_test=0.4749
# poison_percent 50 epoch 26: loss_train=0.5758, acc_train=0.6786, loss_test=1.0482, acc_test=0.3217
# poison_percent 50 epoch 27: loss_train=0.6577, acc_train=0.7143, loss_test=0.8750, acc_test=0.5423
# poison_percent 50 epoch 28: loss_train=0.7108, acc_train=0.6071, loss_test=0.8491, acc_test=0.5527
# poison_percent 50 epoch 29: loss_train=0.5762, acc_train=0.7857, loss_test=0.8205, acc_test=0.6066
# poison_percent 50 epoch 30: loss_train=0.4842, acc_train=0.8214, loss_test=0.8821, acc_test=0.5312
# poison_percent 50 epoch 31: loss_train=0.8973, acc_train=0.5357, loss_test=0.7589, acc_test=0.6495
# poison_percent 50 epoch 32: loss_train=0.6643, acc_train=0.6786, loss_test=0.9753, acc_test=0.4069
# poison_percent 50 epoch 33: loss_train=0.4890, acc_train=0.7857, loss_test=0.9281, acc_test=0.4859
# poison_percent 50 epoch 34: loss_train=0.5612, acc_train=0.7500, loss_test=1.0021, acc_test=0.4105
# poison_percent 50 epoch 35: loss_train=0.5322, acc_train=0.7857, loss_test=0.8021, acc_test=0.5944
# poison_percent 50 epoch 36: loss_train=0.6928, acc_train=0.7143, loss_test=0.8796, acc_test=0.5221
# poison_percent 50 epoch 37: loss_train=0.5777, acc_train=0.6071, loss_test=0.8003, acc_test=0.5987
# poison_percent 50 epoch 38: loss_train=0.5212, acc_train=0.7500, loss_test=0.8978, acc_test=0.4828
# poison_percent 50 epoch 39: loss_train=0.6238, acc_train=0.6071, loss_test=0.8819, acc_test=0.4583
# poison_percent 50 epoch 40: loss_train=0.5229, acc_train=0.7857, loss_test=0.7529, acc_test=0.6863
# poison_percent 50 epoch 41: loss_train=0.5180, acc_train=0.6786, loss_test=0.9300, acc_test=0.4620
# poison_percent 50 epoch 42: loss_train=0.6203, acc_train=0.6786, loss_test=0.9261, acc_test=0.5374
# poison_percent 50 epoch 43: loss_train=0.7422, acc_train=0.5714, loss_test=0.8995, acc_test=0.5123
# poison_percent 50 epoch 44: loss_train=0.4318, acc_train=0.7500, loss_test=0.8183, acc_test=0.5674
# poison_percent 50 epoch 45: loss_train=0.6266, acc_train=0.8214, loss_test=0.8911, acc_test=0.5423
# poison_percent 50 epoch 46: loss_train=0.5988, acc_train=0.6786, loss_test=0.8927, acc_test=0.5386
# poison_percent 50 epoch 47: loss_train=0.8385, acc_train=0.5357, loss_test=0.8710, acc_test=0.5478
# poison_percent 50 epoch 48: loss_train=0.6130, acc_train=0.6429, loss_test=0.9609, acc_test=0.5049
# poison_percent 50 epoch 49: loss_train=0.6057, acc_train=0.5714, loss_test=0.8415, acc_test=0.5607
# poison_percent 50 epoch 50: loss_train=0.5120, acc_train=0.7857, loss_test=0.9602, acc_test=0.4338
# poison_percent 50 epoch 51: loss_train=0.6951, acc_train=0.5714, loss_test=0.8908, acc_test=0.5650
# poison_percent 50 epoch 52: loss_train=0.7056, acc_train=0.5357, loss_test=0.8331, acc_test=0.6121
# poison_percent 50 epoch 53: loss_train=0.6424, acc_train=0.6786, loss_test=0.9775, acc_test=0.4259
# poison_percent 50 epoch 54: loss_train=0.5870, acc_train=0.7143, loss_test=0.8954, acc_test=0.5558
# poison_percent 50 epoch 55: loss_train=0.7009, acc_train=0.6429, loss_test=0.9188, acc_test=0.4534
# poison_percent 50 epoch 56: loss_train=0.6008, acc_train=0.7143, loss_test=0.8763, acc_test=0.5423
# poison_percent 50 epoch 57: loss_train=0.6227, acc_train=0.6429, loss_test=0.8865, acc_test=0.5270
# poison_percent 50 epoch 58: loss_train=0.6328, acc_train=0.6071, loss_test=0.8763, acc_test=0.5411
# poison_percent 50 epoch 59: loss_train=0.6783, acc_train=0.6071, loss_test=0.9720, acc_test=0.4393
# poison_percent 50 epoch 60: loss_train=0.6013, acc_train=0.6786, loss_test=0.9097, acc_test=0.4865
# poison_percent 50 epoch 61: loss_train=0.5980, acc_train=0.7500, loss_test=0.8356, acc_test=0.5913
# poison_percent 50 epoch 62: loss_train=0.4903, acc_train=0.6786, loss_test=0.8893, acc_test=0.5582
# poison_percent 50 epoch 63: loss_train=0.5549, acc_train=0.7500, loss_test=0.8496, acc_test=0.5202
# poison_percent 50 epoch 64: loss_train=0.5554, acc_train=0.6786, loss_test=0.8397, acc_test=0.6483
# poison_percent 50 epoch 65: loss_train=0.5924, acc_train=0.6786, loss_test=0.8587, acc_test=0.5374
# poison_percent 50 epoch 66: loss_train=0.5921, acc_train=0.7143, loss_test=0.8057, acc_test=0.5901
# poison_percent 50 epoch 67: loss_train=0.8638, acc_train=0.5714, loss_test=1.0240, acc_test=0.4338
# poison_percent 50 epoch 68: loss_train=0.5481, acc_train=0.6071, loss_test=0.9078, acc_test=0.5159
# poison_percent 50 epoch 69: loss_train=0.6869, acc_train=0.6071, loss_test=0.9229, acc_test=0.4877
# poison_percent 50 epoch 70: loss_train=0.5354, acc_train=0.7500, loss_test=0.9377, acc_test=0.5025
# poison_percent 50 epoch 71: loss_train=0.6142, acc_train=0.6071, loss_test=0.8895, acc_test=0.5172
# poison_percent 50 epoch 72: loss_train=0.7212, acc_train=0.5714, loss_test=0.8903, acc_test=0.5233
# poison_percent 50 epoch 73: loss_train=0.7100, acc_train=0.5000, loss_test=0.7993, acc_test=0.6385
# poison_percent 50 epoch 74: loss_train=0.4505, acc_train=0.7857, loss_test=0.9109, acc_test=0.5006
# poison_percent 50 epoch 75: loss_train=0.5641, acc_train=0.6786, loss_test=0.9445, acc_test=0.5331
# poison_percent 50 epoch 76: loss_train=0.4406, acc_train=0.6786, loss_test=0.9358, acc_test=0.5300
# poison_percent 50 epoch 77: loss_train=0.5077, acc_train=0.7143, loss_test=0.8632, acc_test=0.6066
# poison_percent 50 epoch 78: loss_train=0.6870, acc_train=0.6429, loss_test=0.8325, acc_test=0.5527
# poison_percent 50 epoch 79: loss_train=0.5083, acc_train=0.7857, loss_test=0.9449, acc_test=0.5037
# poison_percent 50 epoch 80: loss_train=0.6860, acc_train=0.6429, loss_test=0.7641, acc_test=0.6569
# poison_percent 50 epoch 81: loss_train=0.5918, acc_train=0.6786, loss_test=0.9264, acc_test=0.5190
# poison_percent 50 epoch 82: loss_train=0.6216, acc_train=0.6786, loss_test=0.9231, acc_test=0.5502
# poison_percent 50 epoch 83: loss_train=0.7993, acc_train=0.6429, loss_test=0.9044, acc_test=0.5263
# poison_percent 50 epoch 84: loss_train=0.5824, acc_train=0.6429, loss_test=0.9308, acc_test=0.5227
# poison_percent 50 epoch 85: loss_train=0.7921, acc_train=0.5714, loss_test=0.9031, acc_test=0.5392
# poison_percent 50 epoch 86: loss_train=0.6617, acc_train=0.5357, loss_test=0.9588, acc_test=0.4669
# poison_percent 50 epoch 87: loss_train=0.6891, acc_train=0.5357, loss_test=0.8370, acc_test=0.6207
# poison_percent 50 epoch 88: loss_train=0.4983, acc_train=0.6786, loss_test=0.9564, acc_test=0.4651
# poison_percent 50 epoch 89: loss_train=0.6331, acc_train=0.7143, loss_test=0.9921, acc_test=0.4375
# poison_percent 50 epoch 90: loss_train=0.5831, acc_train=0.6786, loss_test=0.9205, acc_test=0.5294
# poison_percent 50 epoch 91: loss_train=0.5638, acc_train=0.7143, loss_test=0.9471, acc_test=0.4565
# poison_percent 50 epoch 92: loss_train=0.6426, acc_train=0.5000, loss_test=0.8439, acc_test=0.6219
# poison_percent 50 epoch 93: loss_train=0.5536, acc_train=0.6786, loss_test=0.9276, acc_test=0.5270
# poison_percent 50 epoch 94: loss_train=0.5847, acc_train=0.7143, loss_test=0.9077, acc_test=0.5686
# poison_percent 50 epoch 95: loss_train=0.5302, acc_train=0.6071, loss_test=0.7901, acc_test=0.6857
# poison_percent 50 epoch 96: loss_train=0.5475, acc_train=0.7143, loss_test=0.8500, acc_test=0.5668
# poison_percent 50 epoch 97: loss_train=0.5068, acc_train=0.7143, loss_test=1.0034, acc_test=0.4528
# poison_percent 50 epoch 98: loss_train=0.6257, acc_train=0.6429, loss_test=0.9221, acc_test=0.5159
# poison_percent 50 epoch 99: loss_train=0.4717, acc_train=0.7857, loss_test=0.8367, acc_test=0.6299
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\CL_ModelN32L2_Batchsize32_rev2\poisoned_50percent\poisoned_50percent.csv
