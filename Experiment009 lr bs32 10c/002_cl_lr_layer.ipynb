# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
# def binary_cross_entropy(pred, target):
#     eps = 1e-7
#     pred = torch.clamp(pred, eps, 1 - eps)
#     return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

def multiclass_cross_entropy(logits, target, from_probs=False, eps=1e-7):
    """
    Cross-entropy loss for multiclass (e.g., 10 classes).
    - logits: Tensor shape (N, C) containing raw scores (preferred) or probabilities if from_probs=True
    - target: Tensor shape (N,) or (N,1) containing class indices (0..C-1)
    """
    if logits.dim() == 1:
        logits = logits.unsqueeze(0)
    target = target.squeeze()
    if target.dtype != torch.long:
        target = target.long()
    if from_probs:
        probs = torch.clamp(logits, eps, 1.0 - eps)
        log_probs = torch.log(probs)
        return -log_probs[torch.arange(target.size(0)), target].mean()
    return nn.functional.cross_entropy(logits, target)

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 32
N_CLASSES = 10

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_multiple_poison/train"
TEST_PATH = "../data/mnist_multiple_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0]#[0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Poison n list: [0]

# %%
import re
def make_safe_filename(name: str) -> str:
    # remove control chars and characters invalid on Windows
    safe = re.sub(r'[<>:"/\\|?*\x00-\x1F]', '_', name)
    # strip trailing dots/spaces which are problematic on Windows
    safe = safe.rstrip('. ')
    return safe

# %%
NODE = 1
for LAYER in [3]:#[3,4,5,6]: # LAYER - (first,last)
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            
            # 1. Define the stack of hidden layers (Linear + ReLU)
            # Use a list comprehension to create the (Linear, ReLU) pairs
            hidden_layers = []
            for _ in range(LAYER-2):
                hidden_layers.append(nn.Linear(NODE, NODE))
                hidden_layers.append(nn.ReLU())
                
            # 2. Use nn.Sequential to wrap the entire dynamic stack
            self.dynamic_hidden = nn.Sequential(*hidden_layers)
            
            # Other layers
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, N_CLASSES)

        def forward(self, x):
            # Flatten the input
            x = x.view(x.size(0), -1) 
            
            # Input Layer
            x = self.fc1(x)
            x = nn.ReLU()(x) # We need to manually apply ReLU here
            
            # Dynamic Hidden Layers (Executed sequentially without a loop)
            x = self.dynamic_hidden(x)
                
            # Output Layer
            x = self.fc2(x)
            # x = torch.sigmoid(x)
            
            return x

    BATCH_SIZE_list = [BATCH_SIZE]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"CL_ModelN{NODE}L{LAYER}_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                        poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                        select='Honest+Poisoned')
                X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
                # print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
                # print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")

                X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
                y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                torch.save(model, os.path.join(save_path,'model_init.pt'))
                optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

                records = []

                # Training loop
                for epoch in range(EPOCHS):

                    # Train
                    model.train()
                    
                    #randomize the training data
                    perm = torch.randperm(X_train_tensor.size(0))
                    X_train_tensor = X_train_tensor[perm]
                    y_train_tensor = y_train_tensor[perm]

                    for start in range(0, X_train_tensor.size(0), experiment_bs):
                        end = start + experiment_bs
                        xb = X_train_tensor[start:end]
                        yb = y_train_tensor[start:end]
                        outputs = model(xb)
                        # preds = (outputs >= 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        acc_train = (preds == yb).float().mean().item()
                        loss_train = multiclass_cross_entropy(outputs, yb)
                        optimizer.zero_grad()
                        loss_train.backward()
                        optimizer.step()

                    # Evaluate
                    model.eval()
                    with torch.no_grad():
                        outputs = model(X_test_tensor)
                        # preds = (outputs >= 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        loss_test = multiclass_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"epoch {epoch}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)

                # save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                safe_name = make_safe_filename(NAME_SAVE_update_PATH)
                save_name_path = os.path.abspath(os.path.join(save_path, f'{safe_name}.csv'))
                os.makedirs(os.path.dirname(save_name_path), exist_ok=True)

                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['epoch'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['epoch'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 epoch 0: loss_train=1.9543, acc_train=0.3684, loss_test=2.2302, acc_test=0.4871
# poison_percent 0 epoch 1: loss_train=1.9492, acc_train=0.2632, loss_test=1.8538, acc_test=0.0711
# poison_percent 0 epoch 2: loss_train=1.9080, acc_train=0.1579, loss_test=1.7080, acc_test=0.1048
# poison_percent 0 epoch 3: loss_train=1.6779, acc_train=0.3684, loss_test=1.6900, acc_test=0.0000
# poison_percent 0 epoch 4: loss_train=1.8340, acc_train=0.2105, loss_test=1.6527, acc_test=0.5025
# poison_percent 0 epoch 5: loss_train=1.6869, acc_train=0.2632, loss_test=1.6209, acc_test=0.4908
# poison_percent 0 epoch 6: loss_train=1.6627, acc_train=0.2105, loss_test=1.5792, acc_test=0.9406
# poison_percent 0 epoch 7: loss_train=1.6143, acc_train=0.3684, loss_test=1.5832, acc_test=0.4939
# poison_percent 0 epoch 8: loss_train=1.6620, acc_train=0.3158, loss_test=1.5761, acc_test=0.5043
# poison_percent 0 epoch 9: loss_train=1.6312, acc_train=0.1053, loss_test=1.5647, acc_test=0.4467
# poison_percent 0 epoch 10: loss_train=1.7142, acc_train=0.3684, loss_test=1.5384, acc_test=0.4908
# poison_percent 0 epoch 11: loss_train=1.9775, acc_train=0.3158, loss_test=1.5191, acc_test=0.4743
# poison_percent 0 epoch 12: loss_train=1.6865, acc_train=0.5263, loss_test=1.5111, acc_test=0.4902
# poison_percent 0 epoch 13: loss_train=1.7228, acc_train=0.2632, loss_test=1.4767, acc_test=0.5055
# poison_percent 0 epoch 14: loss_train=1.8429, acc_train=0.2632, loss_test=1.4555, acc_test=0.5876
# poison_percent 0 epoch 15: loss_train=1.6368, acc_train=0.3684, loss_test=1.4445, acc_test=0.6354
# poison_percent 0 epoch 16: loss_train=1.9246, acc_train=0.1579, loss_test=1.4158, acc_test=0.4344
# poison_percent 0 epoch 17: loss_train=1.5206, acc_train=0.4737, loss_test=1.3945, acc_test=0.4277
# poison_percent 0 epoch 18: loss_train=1.5285, acc_train=0.4737, loss_test=1.3567, acc_test=0.8860
# poison_percent 0 epoch 19: loss_train=1.5552, acc_train=0.3684, loss_test=1.3861, acc_test=0.3738
# poison_percent 0 epoch 20: loss_train=1.5301, acc_train=0.2632, loss_test=1.3391, acc_test=0.8940
# poison_percent 0 epoch 21: loss_train=1.8250, acc_train=0.1579, loss_test=1.3207, acc_test=0.8738
# poison_percent 0 epoch 22: loss_train=1.7170, acc_train=0.1579, loss_test=1.3541, acc_test=0.3824
# poison_percent 0 epoch 23: loss_train=1.8002, acc_train=0.1053, loss_test=1.3339, acc_test=0.3897
# poison_percent 0 epoch 24: loss_train=1.8267, acc_train=0.3158, loss_test=1.3291, acc_test=0.8468
# poison_percent 0 epoch 25: loss_train=1.4809, acc_train=0.4737, loss_test=1.3379, acc_test=0.8260
# poison_percent 0 epoch 26: loss_train=1.4512, acc_train=0.4737, loss_test=1.3085, acc_test=0.7911
# poison_percent 0 epoch 27: loss_train=1.6485, acc_train=0.3158, loss_test=1.3521, acc_test=0.0000
# poison_percent 0 epoch 28: loss_train=1.6570, acc_train=0.3158, loss_test=1.2766, acc_test=0.4957
# poison_percent 0 epoch 29: loss_train=1.6758, acc_train=0.3684, loss_test=1.3583, acc_test=0.4945
# poison_percent 0 epoch 30: loss_train=1.3981, acc_train=0.4737, loss_test=1.3133, acc_test=0.4589
# poison_percent 0 epoch 31: loss_train=1.7819, acc_train=0.3684, loss_test=1.3083, acc_test=0.4786
# poison_percent 0 epoch 32: loss_train=1.6361, acc_train=0.3158, loss_test=1.3429, acc_test=0.3450
# poison_percent 0 epoch 33: loss_train=1.4018, acc_train=0.4211, loss_test=1.3545, acc_test=0.5600
# poison_percent 0 epoch 34: loss_train=1.6738, acc_train=0.5263, loss_test=1.3496, acc_test=0.4743
# poison_percent 0 epoch 35: loss_train=1.6846, acc_train=0.4211, loss_test=1.3079, acc_test=0.5202
# poison_percent 0 epoch 36: loss_train=1.8381, acc_train=0.2105, loss_test=1.3450, acc_test=0.5380
# poison_percent 0 epoch 37: loss_train=1.4927, acc_train=0.3158, loss_test=1.3463, acc_test=0.5331
# poison_percent 0 epoch 38: loss_train=1.7030, acc_train=0.2632, loss_test=1.3887, acc_test=0.5325
# poison_percent 0 epoch 39: loss_train=1.5192, acc_train=0.2632, loss_test=1.3280, acc_test=0.4755
# poison_percent 0 epoch 40: loss_train=1.5489, acc_train=0.3684, loss_test=1.3444, acc_test=0.5270
# poison_percent 0 epoch 41: loss_train=1.8031, acc_train=0.3158, loss_test=1.3467, acc_test=0.5778
# poison_percent 0 epoch 42: loss_train=1.4464, acc_train=0.3158, loss_test=1.3467, acc_test=0.5533
# poison_percent 0 epoch 43: loss_train=1.7122, acc_train=0.3158, loss_test=1.3588, acc_test=0.5490
# poison_percent 0 epoch 44: loss_train=1.3937, acc_train=0.5789, loss_test=1.3750, acc_test=0.4105
# poison_percent 0 epoch 45: loss_train=1.7667, acc_train=0.2632, loss_test=1.3945, acc_test=0.5300
# poison_percent 0 epoch 46: loss_train=1.5949, acc_train=0.5263, loss_test=1.3294, acc_test=0.5460
# poison_percent 0 epoch 47: loss_train=2.0997, acc_train=0.3158, loss_test=1.4008, acc_test=0.5478
# poison_percent 0 epoch 48: loss_train=1.4178, acc_train=0.4737, loss_test=1.3876, acc_test=0.5833
# poison_percent 0 epoch 49: loss_train=1.6595, acc_train=0.3684, loss_test=1.4288, acc_test=0.1673
# poison_percent 0 epoch 50: loss_train=1.7933, acc_train=0.2632, loss_test=1.4013, acc_test=0.4994
# poison_percent 0 epoch 51: loss_train=1.5525, acc_train=0.4737, loss_test=1.4054, acc_test=0.2175
# poison_percent 0 epoch 52: loss_train=1.5009, acc_train=0.3158, loss_test=1.3657, acc_test=0.6930
# poison_percent 0 epoch 53: loss_train=1.4950, acc_train=0.3684, loss_test=1.3689, acc_test=0.6134
# poison_percent 0 epoch 54: loss_train=1.5408, acc_train=0.3158, loss_test=1.3896, acc_test=0.6912
# poison_percent 0 epoch 55: loss_train=1.4314, acc_train=0.3158, loss_test=1.3707, acc_test=0.7684
# poison_percent 0 epoch 56: loss_train=1.5635, acc_train=0.3158, loss_test=1.3823, acc_test=0.7531
# poison_percent 0 epoch 57: loss_train=1.5744, acc_train=0.2105, loss_test=1.4270, acc_test=0.7016
# poison_percent 0 epoch 58: loss_train=1.5030, acc_train=0.4211, loss_test=1.3658, acc_test=0.7475
# poison_percent 0 epoch 59: loss_train=1.7100, acc_train=0.0000, loss_test=1.4098, acc_test=0.6942
# poison_percent 0 epoch 60: loss_train=1.7183, acc_train=0.6316, loss_test=1.3841, acc_test=0.7138
# poison_percent 0 epoch 61: loss_train=1.6249, acc_train=0.2632, loss_test=1.4034, acc_test=0.6685
# poison_percent 0 epoch 62: loss_train=1.5862, acc_train=0.2632, loss_test=1.4677, acc_test=0.3094
# poison_percent 0 epoch 63: loss_train=1.5669, acc_train=0.3684, loss_test=1.3807, acc_test=0.6881
# poison_percent 0 epoch 64: loss_train=1.3599, acc_train=0.4737, loss_test=1.4001, acc_test=0.3180
# poison_percent 0 epoch 65: loss_train=1.4608, acc_train=0.5263, loss_test=1.3838, acc_test=0.7077
# poison_percent 0 epoch 66: loss_train=1.3613, acc_train=0.6316, loss_test=1.3979, acc_test=0.5043
# poison_percent 0 epoch 67: loss_train=1.5934, acc_train=0.3684, loss_test=1.3993, acc_test=0.6979
# poison_percent 0 epoch 68: loss_train=1.7974, acc_train=0.3684, loss_test=1.3728, acc_test=0.7390
# poison_percent 0 epoch 69: loss_train=1.8148, acc_train=0.4211, loss_test=1.4116, acc_test=0.4761
# poison_percent 0 epoch 70: loss_train=1.5590, acc_train=0.2632, loss_test=1.4186, acc_test=0.6385
# poison_percent 0 epoch 71: loss_train=1.6241, acc_train=0.4737, loss_test=1.3809, acc_test=0.7200
# poison_percent 0 epoch 72: loss_train=1.4703, acc_train=0.1579, loss_test=1.3879, acc_test=0.7267
# poison_percent 0 epoch 73: loss_train=1.5338, acc_train=0.3158, loss_test=1.4272, acc_test=0.6918
# poison_percent 0 epoch 74: loss_train=1.5846, acc_train=0.3158, loss_test=1.4366, acc_test=0.2678
# poison_percent 0 epoch 75: loss_train=1.2684, acc_train=0.1579, loss_test=1.4049, acc_test=0.6998
# poison_percent 0 epoch 76: loss_train=1.3752, acc_train=0.4211, loss_test=1.3827, acc_test=0.7230
# poison_percent 0 epoch 77: loss_train=1.3348, acc_train=0.4737, loss_test=1.4052, acc_test=0.6863
# poison_percent 0 epoch 78: loss_train=1.7724, acc_train=0.5263, loss_test=1.4382, acc_test=0.2463
# poison_percent 0 epoch 79: loss_train=1.5363, acc_train=0.1579, loss_test=1.4166, acc_test=0.4816
# poison_percent 0 epoch 80: loss_train=1.6922, acc_train=0.3684, loss_test=1.4252, acc_test=0.3039
# poison_percent 0 epoch 81: loss_train=1.6223, acc_train=0.6316, loss_test=1.4396, acc_test=0.2776
# poison_percent 0 epoch 82: loss_train=1.3911, acc_train=0.3684, loss_test=1.4548, acc_test=0.2665
# poison_percent 0 epoch 83: loss_train=1.5800, acc_train=0.4737, loss_test=1.4492, acc_test=0.6134
# poison_percent 0 epoch 84: loss_train=1.6988, acc_train=0.2105, loss_test=1.4776, acc_test=0.2751
# poison_percent 0 epoch 85: loss_train=1.6358, acc_train=0.2105, loss_test=1.3870, acc_test=0.7188
# poison_percent 0 epoch 86: loss_train=1.6649, acc_train=0.3158, loss_test=1.4074, acc_test=0.6918
# poison_percent 0 epoch 87: loss_train=1.3729, acc_train=0.4211, loss_test=1.4114, acc_test=0.5576
# poison_percent 0 epoch 88: loss_train=1.4113, acc_train=0.2632, loss_test=1.3936, acc_test=0.7145
# poison_percent 0 epoch 89: loss_train=1.4962, acc_train=0.3684, loss_test=1.4373, acc_test=0.2819
# poison_percent 0 epoch 90: loss_train=1.6405, acc_train=0.2632, loss_test=1.4551, acc_test=0.3094
# poison_percent 0 epoch 91: loss_train=1.6474, acc_train=0.4211, loss_test=1.3982, acc_test=0.7096
# poison_percent 0 epoch 92: loss_train=1.4753, acc_train=0.3158, loss_test=1.4519, acc_test=0.6507
# poison_percent 0 epoch 93: loss_train=1.5426, acc_train=0.2105, loss_test=1.4160, acc_test=0.6900
# poison_percent 0 epoch 94: loss_train=1.7611, acc_train=0.3684, loss_test=1.4303, acc_test=0.4393
# poison_percent 0 epoch 95: loss_train=1.7764, acc_train=0.3684, loss_test=1.3912, acc_test=0.7322
# poison_percent 0 epoch 96: loss_train=1.7483, acc_train=0.2632, loss_test=1.4401, acc_test=0.2788
# poison_percent 0 epoch 97: loss_train=1.6349, acc_train=0.1579, loss_test=1.4406, acc_test=0.2776
# poison_percent 0 epoch 98: loss_train=1.6892, acc_train=0.2632, loss_test=1.4094, acc_test=0.7040
# poison_percent 0 epoch 99: loss_train=1.5829, acc_train=0.4211, loss_test=1.4069, acc_test=0.7010
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\CL_ModelN1L3_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 0 epoch 0: loss_train=1.9880, acc_train=0.2105, loss_test=1.7067, acc_test=0.4718
# poison_percent 0 epoch 1: loss_train=1.9115, acc_train=0.3158, loss_test=1.4742, acc_test=0.4614
# poison_percent 0 epoch 2: loss_train=1.8576, acc_train=0.2105, loss_test=1.4089, acc_test=0.4412
# poison_percent 0 epoch 3: loss_train=1.9104, acc_train=0.1053, loss_test=1.3638, acc_test=0.8879
# poison_percent 0 epoch 4: loss_train=1.5731, acc_train=0.2632, loss_test=1.2692, acc_test=0.9007
# poison_percent 0 epoch 5: loss_train=1.6379, acc_train=0.4737, loss_test=1.2851, acc_test=0.8860
# poison_percent 0 epoch 6: loss_train=1.7331, acc_train=0.3684, loss_test=1.2401, acc_test=0.8854
# poison_percent 0 epoch 7: loss_train=1.4787, acc_train=0.3684, loss_test=1.2179, acc_test=0.4442
# poison_percent 0 epoch 8: loss_train=2.0056, acc_train=0.2105, loss_test=1.2299, acc_test=0.4289
# poison_percent 0 epoch 9: loss_train=1.7640, acc_train=0.2105, loss_test=1.2532, acc_test=0.4571
# poison_percent 0 epoch 10: loss_train=1.6652, acc_train=0.4211, loss_test=1.2222, acc_test=0.4295
# poison_percent 0 epoch 11: loss_train=1.4866, acc_train=0.4211, loss_test=1.1986, acc_test=0.4559
# poison_percent 0 epoch 12: loss_train=1.4608, acc_train=0.4737, loss_test=1.2117, acc_test=0.5913
# poison_percent 0 epoch 13: loss_train=1.7452, acc_train=0.2105, loss_test=1.2367, acc_test=0.6581
# poison_percent 0 epoch 14: loss_train=1.3989, acc_train=0.3684, loss_test=1.1305, acc_test=0.8254
# poison_percent 0 epoch 15: loss_train=1.6143, acc_train=0.2632, loss_test=1.1078, acc_test=0.8462
# poison_percent 0 epoch 16: loss_train=1.6542, acc_train=0.4737, loss_test=1.1214, acc_test=0.8401
# poison_percent 0 epoch 17: loss_train=1.7138, acc_train=0.3684, loss_test=1.1277, acc_test=0.8248
# poison_percent 0 epoch 18: loss_train=1.6053, acc_train=0.3158, loss_test=1.1105, acc_test=0.8548
# poison_percent 0 epoch 19: loss_train=1.4231, acc_train=0.4737, loss_test=1.1263, acc_test=0.8223
# poison_percent 0 epoch 20: loss_train=1.4133, acc_train=0.4737, loss_test=1.1070, acc_test=0.8487
# poison_percent 0 epoch 21: loss_train=1.5895, acc_train=0.4211, loss_test=1.1384, acc_test=0.8382
# poison_percent 0 epoch 22: loss_train=1.5444, acc_train=0.4211, loss_test=1.0791, acc_test=0.8536
# poison_percent 0 epoch 23: loss_train=1.7153, acc_train=0.2105, loss_test=1.0932, acc_test=0.8444
# poison_percent 0 epoch 24: loss_train=1.4965, acc_train=0.4211, loss_test=1.1501, acc_test=0.8229
# poison_percent 0 epoch 25: loss_train=1.3372, acc_train=0.4737, loss_test=1.1105, acc_test=0.8272
# poison_percent 0 epoch 26: loss_train=1.7183, acc_train=0.3158, loss_test=1.0734, acc_test=0.8462
# poison_percent 0 epoch 27: loss_train=1.5006, acc_train=0.5263, loss_test=1.0968, acc_test=0.8450
# poison_percent 0 epoch 28: loss_train=1.3442, acc_train=0.4211, loss_test=1.0654, acc_test=0.8578
# poison_percent 0 epoch 29: loss_train=1.4970, acc_train=0.4211, loss_test=1.0171, acc_test=0.8707
# poison_percent 0 epoch 30: loss_train=1.6497, acc_train=0.3684, loss_test=1.0880, acc_test=0.8419
# poison_percent 0 epoch 31: loss_train=2.4343, acc_train=0.2105, loss_test=1.0452, acc_test=0.8597
# poison_percent 0 epoch 32: loss_train=1.7246, acc_train=0.1579, loss_test=1.1008, acc_test=0.8303
# poison_percent 0 epoch 33: loss_train=1.4447, acc_train=0.5263, loss_test=1.1149, acc_test=0.8303
# poison_percent 0 epoch 34: loss_train=1.6717, acc_train=0.2105, loss_test=1.0401, acc_test=0.8621
# poison_percent 0 epoch 35: loss_train=1.4292, acc_train=0.4737, loss_test=1.0314, acc_test=0.8480
# poison_percent 0 epoch 36: loss_train=1.3412, acc_train=0.5789, loss_test=1.0531, acc_test=0.8456
# poison_percent 0 epoch 37: loss_train=1.5108, acc_train=0.3684, loss_test=1.0782, acc_test=0.8339
# poison_percent 0 epoch 38: loss_train=1.1047, acc_train=0.4737, loss_test=1.0768, acc_test=0.8425
# poison_percent 0 epoch 39: loss_train=1.4112, acc_train=0.3684, loss_test=1.0835, acc_test=0.8499
# poison_percent 0 epoch 40: loss_train=1.2459, acc_train=0.3684, loss_test=1.1376, acc_test=0.8199
# poison_percent 0 epoch 41: loss_train=1.2522, acc_train=0.5263, loss_test=1.0847, acc_test=0.8235
# poison_percent 0 epoch 42: loss_train=1.5723, acc_train=0.2632, loss_test=1.0713, acc_test=0.8474
# poison_percent 0 epoch 43: loss_train=1.3709, acc_train=0.4211, loss_test=1.1110, acc_test=0.8346
# poison_percent 0 epoch 44: loss_train=1.5053, acc_train=0.1579, loss_test=1.0316, acc_test=0.8554
# poison_percent 0 epoch 45: loss_train=1.8303, acc_train=0.2105, loss_test=1.0762, acc_test=0.8364
# poison_percent 0 epoch 46: loss_train=1.4447, acc_train=0.4211, loss_test=1.0412, acc_test=0.8566
# poison_percent 0 epoch 47: loss_train=1.6021, acc_train=0.5263, loss_test=1.0827, acc_test=0.8450
# poison_percent 0 epoch 48: loss_train=1.4375, acc_train=0.3684, loss_test=1.0864, acc_test=0.8309
# poison_percent 0 epoch 49: loss_train=1.8275, acc_train=0.3158, loss_test=1.0485, acc_test=0.8548
# poison_percent 0 epoch 50: loss_train=1.4953, acc_train=0.4211, loss_test=1.0339, acc_test=0.8517
# poison_percent 0 epoch 51: loss_train=1.6159, acc_train=0.3684, loss_test=1.0696, acc_test=0.8364
# poison_percent 0 epoch 52: loss_train=1.4257, acc_train=0.3684, loss_test=1.0450, acc_test=0.8511
# poison_percent 0 epoch 53: loss_train=1.5576, acc_train=0.3158, loss_test=1.0707, acc_test=0.8425
# poison_percent 0 epoch 54: loss_train=1.4342, acc_train=0.4737, loss_test=1.0662, acc_test=0.8382
# poison_percent 0 epoch 55: loss_train=1.5411, acc_train=0.3158, loss_test=1.0365, acc_test=0.8529
# poison_percent 0 epoch 56: loss_train=1.7585, acc_train=0.1053, loss_test=1.0761, acc_test=0.8364
# poison_percent 0 epoch 57: loss_train=1.3888, acc_train=0.3684, loss_test=1.0443, acc_test=0.8444
# poison_percent 0 epoch 58: loss_train=1.9018, acc_train=0.4211, loss_test=1.1211, acc_test=0.8241
# poison_percent 0 epoch 59: loss_train=1.4518, acc_train=0.4211, loss_test=0.9968, acc_test=0.8707
# poison_percent 0 epoch 60: loss_train=1.3050, acc_train=0.4211, loss_test=1.0632, acc_test=0.8364
# poison_percent 0 epoch 61: loss_train=1.5519, acc_train=0.4211, loss_test=0.9628, acc_test=0.8775
# poison_percent 0 epoch 62: loss_train=1.3474, acc_train=0.5789, loss_test=1.0888, acc_test=0.8278
# poison_percent 0 epoch 63: loss_train=1.4836, acc_train=0.2632, loss_test=1.0970, acc_test=0.8333
# poison_percent 0 epoch 64: loss_train=1.2269, acc_train=0.4211, loss_test=1.0598, acc_test=0.8438
# poison_percent 0 epoch 65: loss_train=1.6686, acc_train=0.1579, loss_test=1.0415, acc_test=0.8462
# poison_percent 0 epoch 66: loss_train=1.4157, acc_train=0.4211, loss_test=1.0256, acc_test=0.8480
# poison_percent 0 epoch 67: loss_train=1.5314, acc_train=0.2105, loss_test=1.0324, acc_test=0.8511
# poison_percent 0 epoch 68: loss_train=1.3997, acc_train=0.2632, loss_test=1.0118, acc_test=0.8566
# poison_percent 0 epoch 69: loss_train=1.5586, acc_train=0.4211, loss_test=0.9584, acc_test=0.8848
# poison_percent 0 epoch 70: loss_train=1.3890, acc_train=0.4211, loss_test=1.0136, acc_test=0.8609
# poison_percent 0 epoch 71: loss_train=1.6595, acc_train=0.3684, loss_test=1.0026, acc_test=0.8670
# poison_percent 0 epoch 72: loss_train=1.4438, acc_train=0.3158, loss_test=1.0566, acc_test=0.8444
# poison_percent 0 epoch 73: loss_train=1.5155, acc_train=0.3684, loss_test=1.0656, acc_test=0.8346
# poison_percent 0 epoch 74: loss_train=1.4060, acc_train=0.3684, loss_test=1.1043, acc_test=0.8082
# poison_percent 0 epoch 75: loss_train=1.5075, acc_train=0.3684, loss_test=1.0599, acc_test=0.8419
# poison_percent 0 epoch 76: loss_train=1.5243, acc_train=0.3684, loss_test=0.9944, acc_test=0.8634
# poison_percent 0 epoch 77: loss_train=1.5343, acc_train=0.4211, loss_test=1.0395, acc_test=0.8468
# poison_percent 0 epoch 78: loss_train=1.5859, acc_train=0.3158, loss_test=1.0117, acc_test=0.8566
# poison_percent 0 epoch 79: loss_train=1.9098, acc_train=0.1579, loss_test=0.9965, acc_test=0.8683
# poison_percent 0 epoch 80: loss_train=1.4520, acc_train=0.5789, loss_test=1.0471, acc_test=0.8456
# poison_percent 0 epoch 81: loss_train=1.6541, acc_train=0.3684, loss_test=1.0607, acc_test=0.8364
# poison_percent 0 epoch 82: loss_train=1.3753, acc_train=0.4737, loss_test=1.0294, acc_test=0.8487
# poison_percent 0 epoch 83: loss_train=1.6308, acc_train=0.2632, loss_test=1.0683, acc_test=0.8395
# poison_percent 0 epoch 84: loss_train=1.6662, acc_train=0.2632, loss_test=1.0366, acc_test=0.8523
# poison_percent 0 epoch 85: loss_train=1.6850, acc_train=0.3158, loss_test=1.0092, acc_test=0.8597
# poison_percent 0 epoch 86: loss_train=1.4609, acc_train=0.3684, loss_test=0.9768, acc_test=0.8707
# poison_percent 0 epoch 87: loss_train=1.5730, acc_train=0.3684, loss_test=1.0287, acc_test=0.8327
# poison_percent 0 epoch 88: loss_train=1.2087, acc_train=0.5789, loss_test=1.0706, acc_test=0.8168
# poison_percent 0 epoch 89: loss_train=1.2778, acc_train=0.4737, loss_test=1.0691, acc_test=0.8370
# poison_percent 0 epoch 90: loss_train=1.9340, acc_train=0.3158, loss_test=1.0579, acc_test=0.8382
# poison_percent 0 epoch 91: loss_train=1.3190, acc_train=0.3684, loss_test=0.9584, acc_test=0.8719
# poison_percent 0 epoch 92: loss_train=1.6794, acc_train=0.4211, loss_test=1.0388, acc_test=0.8333
# poison_percent 0 epoch 93: loss_train=1.2030, acc_train=0.4211, loss_test=1.0189, acc_test=0.8566
# poison_percent 0 epoch 94: loss_train=1.4090, acc_train=0.3684, loss_test=1.0302, acc_test=0.8444
# poison_percent 0 epoch 95: loss_train=1.4878, acc_train=0.4737, loss_test=1.0225, acc_test=0.8517
# poison_percent 0 epoch 96: loss_train=1.5229, acc_train=0.2632, loss_test=1.1022, acc_test=0.8186
# poison_percent 0 epoch 97: loss_train=1.5819, acc_train=0.2105, loss_test=1.0557, acc_test=0.8315
# poison_percent 0 epoch 98: loss_train=1.5408, acc_train=0.3158, loss_test=1.0701, acc_test=0.8235
# poison_percent 0 epoch 99: loss_train=1.5458, acc_train=0.2632, loss_test=1.0090, acc_test=0.8609
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\CL_ModelN1L3_Batchsize32_rev1\poisoned_0percent\poisoned_0percent.csv
# poison_percent 0 epoch 0: loss_train=2.3331, acc_train=0.0000, loss_test=2.3445, acc_test=0.0000
# poison_percent 0 epoch 1: loss_train=2.3118, acc_train=0.1053, loss_test=2.3022, acc_test=0.0000
# poison_percent 0 epoch 2: loss_train=2.3121, acc_train=0.1053, loss_test=2.2839, acc_test=0.0000
# poison_percent 0 epoch 3: loss_train=2.2981, acc_train=0.0000, loss_test=2.2898, acc_test=0.0000
# poison_percent 0 epoch 4: loss_train=2.3021, acc_train=0.0000, loss_test=2.2866, acc_test=0.0000
# poison_percent 0 epoch 5: loss_train=2.2986, acc_train=0.0526, loss_test=2.2824, acc_test=0.0000
# poison_percent 0 epoch 6: loss_train=2.3043, acc_train=0.0526, loss_test=2.2883, acc_test=0.0000
# poison_percent 0 epoch 7: loss_train=2.3164, acc_train=0.1053, loss_test=2.2863, acc_test=0.0000
# poison_percent 0 epoch 8: loss_train=2.2964, acc_train=0.0526, loss_test=2.2838, acc_test=0.0000
# poison_percent 0 epoch 9: loss_train=2.2984, acc_train=0.1579, loss_test=2.2919, acc_test=0.0000
# poison_percent 0 epoch 10: loss_train=2.2925, acc_train=0.0526, loss_test=2.2809, acc_test=0.5000
# poison_percent 0 epoch 11: loss_train=2.2987, acc_train=0.1053, loss_test=2.2900, acc_test=0.0000
# poison_percent 0 epoch 12: loss_train=2.2925, acc_train=0.0526, loss_test=2.2829, acc_test=0.5000
# poison_percent 0 epoch 13: loss_train=2.2961, acc_train=0.0000, loss_test=2.2826, acc_test=0.0000
# poison_percent 0 epoch 14: loss_train=2.2994, acc_train=0.0000, loss_test=2.2808, acc_test=0.5000
# poison_percent 0 epoch 15: loss_train=2.2972, acc_train=0.0526, loss_test=2.2812, acc_test=0.0000
# poison_percent 0 epoch 16: loss_train=2.3010, acc_train=0.0526, loss_test=2.2884, acc_test=0.0000
# poison_percent 0 epoch 17: loss_train=2.3022, acc_train=0.0526, loss_test=2.2872, acc_test=0.0000
# poison_percent 0 epoch 18: loss_train=2.2994, acc_train=0.1579, loss_test=2.2833, acc_test=0.0000
# poison_percent 0 epoch 19: loss_train=2.3039, acc_train=0.1053, loss_test=2.2852, acc_test=0.0000
# poison_percent 0 epoch 20: loss_train=2.3102, acc_train=0.1053, loss_test=2.2871, acc_test=0.0000
# poison_percent 0 epoch 21: loss_train=2.2988, acc_train=0.1579, loss_test=2.2909, acc_test=0.0000
# poison_percent 0 epoch 22: loss_train=2.2899, acc_train=0.0526, loss_test=2.2888, acc_test=0.0000
# poison_percent 0 epoch 23: loss_train=2.2863, acc_train=0.1053, loss_test=2.2888, acc_test=0.0000
# poison_percent 0 epoch 24: loss_train=2.3086, acc_train=0.0000, loss_test=2.2869, acc_test=0.0000
# poison_percent 0 epoch 25: loss_train=2.3022, acc_train=0.0526, loss_test=2.2829, acc_test=0.0000
# poison_percent 0 epoch 26: loss_train=2.3008, acc_train=0.0526, loss_test=2.2899, acc_test=0.0000
# poison_percent 0 epoch 27: loss_train=2.2910, acc_train=0.1053, loss_test=2.2982, acc_test=0.0000
# poison_percent 0 epoch 28: loss_train=2.3037, acc_train=0.1053, loss_test=2.2888, acc_test=0.5000
# poison_percent 0 epoch 29: loss_train=2.3100, acc_train=0.0526, loss_test=2.2791, acc_test=0.5000
# poison_percent 0 epoch 30: loss_train=2.2961, acc_train=0.1053, loss_test=2.2838, acc_test=0.5000
# poison_percent 0 epoch 31: loss_train=2.2894, acc_train=0.1053, loss_test=2.2839, acc_test=0.5000
# poison_percent 0 epoch 32: loss_train=2.3009, acc_train=0.1579, loss_test=2.2754, acc_test=0.5000
# poison_percent 0 epoch 33: loss_train=2.2888, acc_train=0.2105, loss_test=2.2801, acc_test=0.5000
# poison_percent 0 epoch 34: loss_train=2.2988, acc_train=0.1053, loss_test=2.2854, acc_test=0.0000
# poison_percent 0 epoch 35: loss_train=2.3002, acc_train=0.1053, loss_test=2.2824, acc_test=0.5000
# poison_percent 0 epoch 36: loss_train=2.3088, acc_train=0.0000, loss_test=2.2845, acc_test=0.0000
# poison_percent 0 epoch 37: loss_train=2.3063, acc_train=0.1053, loss_test=2.2888, acc_test=0.5000
# poison_percent 0 epoch 38: loss_train=2.3002, acc_train=0.1579, loss_test=2.2877, acc_test=0.0000
# poison_percent 0 epoch 39: loss_train=2.3072, acc_train=0.1053, loss_test=2.2814, acc_test=0.5000
# poison_percent 0 epoch 40: loss_train=2.3038, acc_train=0.0526, loss_test=2.2790, acc_test=0.5000
# poison_percent 0 epoch 41: loss_train=2.2938, acc_train=0.1579, loss_test=2.2840, acc_test=0.0000
# poison_percent 0 epoch 42: loss_train=2.2967, acc_train=0.1053, loss_test=2.2788, acc_test=0.5000
# poison_percent 0 epoch 43: loss_train=2.3052, acc_train=0.0526, loss_test=2.2829, acc_test=0.0000
# poison_percent 0 epoch 44: loss_train=2.2953, acc_train=0.1579, loss_test=2.2844, acc_test=0.0000
# poison_percent 0 epoch 45: loss_train=2.2974, acc_train=0.2105, loss_test=2.2846, acc_test=0.5000
# poison_percent 0 epoch 46: loss_train=2.2970, acc_train=0.1579, loss_test=2.2862, acc_test=0.0000
# poison_percent 0 epoch 47: loss_train=2.2988, acc_train=0.0526, loss_test=2.2809, acc_test=0.0000
# poison_percent 0 epoch 48: loss_train=2.3044, acc_train=0.1053, loss_test=2.2829, acc_test=0.5000
# poison_percent 0 epoch 49: loss_train=2.3029, acc_train=0.1579, loss_test=2.2798, acc_test=0.5000
# poison_percent 0 epoch 50: loss_train=2.2962, acc_train=0.0000, loss_test=2.2813, acc_test=0.5000
# poison_percent 0 epoch 51: loss_train=2.3098, acc_train=0.0000, loss_test=2.2872, acc_test=0.0000
# poison_percent 0 epoch 52: loss_train=2.2954, acc_train=0.1579, loss_test=2.2810, acc_test=0.5000
# poison_percent 0 epoch 53: loss_train=2.3046, acc_train=0.0000, loss_test=2.2807, acc_test=0.5000
# poison_percent 0 epoch 54: loss_train=2.2990, acc_train=0.1579, loss_test=2.2782, acc_test=0.0000
# poison_percent 0 epoch 55: loss_train=2.2976, acc_train=0.0526, loss_test=2.2759, acc_test=0.5000
# poison_percent 0 epoch 56: loss_train=2.2940, acc_train=0.1579, loss_test=2.2828, acc_test=0.0000
# poison_percent 0 epoch 57: loss_train=2.3105, acc_train=0.2105, loss_test=2.2815, acc_test=0.0000
# poison_percent 0 epoch 58: loss_train=2.2963, acc_train=0.2632, loss_test=2.2857, acc_test=0.0000
# poison_percent 0 epoch 59: loss_train=2.3205, acc_train=0.1579, loss_test=2.2825, acc_test=0.0000
# poison_percent 0 epoch 60: loss_train=2.2965, acc_train=0.1579, loss_test=2.2755, acc_test=0.5000
# poison_percent 0 epoch 61: loss_train=2.3047, acc_train=0.0000, loss_test=2.2853, acc_test=0.0000
# poison_percent 0 epoch 62: loss_train=2.3015, acc_train=0.1053, loss_test=2.2869, acc_test=0.0000
# poison_percent 0 epoch 63: loss_train=2.2960, acc_train=0.0526, loss_test=2.2767, acc_test=0.0000
# poison_percent 0 epoch 64: loss_train=2.2984, acc_train=0.0000, loss_test=2.2809, acc_test=0.0000
# poison_percent 0 epoch 65: loss_train=2.2998, acc_train=0.1053, loss_test=2.2820, acc_test=0.5000
# poison_percent 0 epoch 66: loss_train=2.2997, acc_train=0.1579, loss_test=2.2844, acc_test=0.0000
# poison_percent 0 epoch 67: loss_train=2.3213, acc_train=0.0526, loss_test=2.2860, acc_test=0.0000
# poison_percent 0 epoch 68: loss_train=2.3018, acc_train=0.2105, loss_test=2.2853, acc_test=0.0000
# poison_percent 0 epoch 69: loss_train=2.3045, acc_train=0.1579, loss_test=2.2842, acc_test=0.5000
# poison_percent 0 epoch 70: loss_train=2.3028, acc_train=0.1053, loss_test=2.2822, acc_test=0.5000
# poison_percent 0 epoch 71: loss_train=2.3055, acc_train=0.1053, loss_test=2.2762, acc_test=0.5000
# poison_percent 0 epoch 72: loss_train=2.3282, acc_train=0.0526, loss_test=2.2835, acc_test=0.0000
# poison_percent 0 epoch 73: loss_train=2.3066, acc_train=0.1053, loss_test=2.2842, acc_test=0.0000
# poison_percent 0 epoch 74: loss_train=2.2994, acc_train=0.1053, loss_test=2.2875, acc_test=0.0000
# poison_percent 0 epoch 75: loss_train=2.3058, acc_train=0.1053, loss_test=2.2938, acc_test=0.0000
# poison_percent 0 epoch 76: loss_train=2.3084, acc_train=0.1053, loss_test=2.2918, acc_test=0.0000
# poison_percent 0 epoch 77: loss_train=2.2962, acc_train=0.1053, loss_test=2.2883, acc_test=0.0000
# poison_percent 0 epoch 78: loss_train=2.3040, acc_train=0.1053, loss_test=2.2839, acc_test=0.0000
# poison_percent 0 epoch 79: loss_train=2.2916, acc_train=0.1579, loss_test=2.2898, acc_test=0.0000
# poison_percent 0 epoch 80: loss_train=2.2992, acc_train=0.1053, loss_test=2.2830, acc_test=0.0000
# poison_percent 0 epoch 81: loss_train=2.2996, acc_train=0.1053, loss_test=2.2850, acc_test=0.0000
# poison_percent 0 epoch 82: loss_train=2.2979, acc_train=0.0526, loss_test=2.2927, acc_test=0.0000
# poison_percent 0 epoch 83: loss_train=2.2906, acc_train=0.1579, loss_test=2.2907, acc_test=0.0000
# poison_percent 0 epoch 84: loss_train=2.2898, acc_train=0.2632, loss_test=2.2850, acc_test=0.0000
# poison_percent 0 epoch 85: loss_train=2.3008, acc_train=0.0526, loss_test=2.2799, acc_test=0.5000
# poison_percent 0 epoch 86: loss_train=2.3035, acc_train=0.0526, loss_test=2.2754, acc_test=0.5000
# poison_percent 0 epoch 87: loss_train=2.3067, acc_train=0.1579, loss_test=2.2771, acc_test=0.5000
# poison_percent 0 epoch 88: loss_train=2.3089, acc_train=0.0000, loss_test=2.2742, acc_test=0.5000
# poison_percent 0 epoch 89: loss_train=2.2903, acc_train=0.0526, loss_test=2.2852, acc_test=0.0000
# poison_percent 0 epoch 90: loss_train=2.2986, acc_train=0.2105, loss_test=2.2844, acc_test=0.0000
# poison_percent 0 epoch 91: loss_train=2.2933, acc_train=0.1579, loss_test=2.2879, acc_test=0.0000
# poison_percent 0 epoch 92: loss_train=2.2969, acc_train=0.1053, loss_test=2.2857, acc_test=0.5000
# poison_percent 0 epoch 93: loss_train=2.2992, acc_train=0.1053, loss_test=2.2949, acc_test=0.5000
# poison_percent 0 epoch 94: loss_train=2.3087, acc_train=0.1053, loss_test=2.2841, acc_test=0.5000
# poison_percent 0 epoch 95: loss_train=2.2928, acc_train=0.1053, loss_test=2.2822, acc_test=0.5000
# poison_percent 0 epoch 96: loss_train=2.2955, acc_train=0.2105, loss_test=2.2906, acc_test=0.0000
# poison_percent 0 epoch 97: loss_train=2.3012, acc_train=0.1579, loss_test=2.2770, acc_test=0.0000
# poison_percent 0 epoch 98: loss_train=2.3158, acc_train=0.0000, loss_test=2.2814, acc_test=0.0000
# poison_percent 0 epoch 99: loss_train=2.3021, acc_train=0.0526, loss_test=2.2776, acc_test=0.5000
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\CL_ModelN1L3_Batchsize32_rev2\poisoned_0percent\poisoned_0percent.csv
