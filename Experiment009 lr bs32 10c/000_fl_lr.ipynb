# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
# def binary_cross_entropy(pred, target):
#     eps = 1e-7
#     pred = torch.clamp(pred, eps, 1 - eps)
#     return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

def multiclass_cross_entropy(logits, target, from_probs=False, eps=1e-7):
    """
    Cross-entropy loss for multiclass (e.g., 10 classes).
    - logits: Tensor shape (N, C) containing raw scores (preferred) or probabilities if from_probs=True
    - target: Tensor shape (N,) or (N,1) containing class indices (0..C-1)
    """
    if logits.dim() == 1:
        logits = logits.unsqueeze(0)
    target = target.squeeze()
    if target.dtype != torch.long:
        target = target.long()
    if from_probs:
        probs = torch.clamp(logits, eps, 1.0 - eps)
        log_probs = torch.log(probs)
        return -log_probs[torch.arange(target.size(0)), target].mean()
    return nn.functional.cross_entropy(logits, target)

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    model = MNISTNet().to(device)
    model.load_state_dict(global_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end]
            yb = y_c_tensor[start:end]
            outputs = model(xb)
            # preds = (outputs >= 0.5).float()
            preds = torch.argmax(outputs, dim=1, keepdim=True)
            loss = multiclass_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # Return a deepcopy to avoid issues with state_dict references
    return copy.deepcopy(model.state_dict()), X_c_tensor.size(0), yb, outputs, preds

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 32
N_CLASSES = 10

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_multiple_poison/train"
TEST_PATH = "../data/mnist_multiple_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
# For 10-class classification
class MNISTNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28*28, N_CLASSES)
    def forward(self, x):
        x = self.fc1(x)
        return x
    
BATCH_SIZE_list = [BATCH_SIZE]
# temp_bs = BATCH_SIZE
# while temp_bs >= 1:
#     BATCH_SIZE_list.append(temp_bs)
#     temp_bs = temp_bs // 2

for rev in range(3):

    global_model = MNISTNet().to(device)
    for experiment_bs in BATCH_SIZE_list:

        name_save_path = f"FL_ModelN1L1_Batchsize{experiment_bs}_rev{rev}"
        
        for i_poisoned in poison_n_list:
            percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

            # create directory
            NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
            save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
            # Remove existing directory if it exists
            if os.path.exists(save_path):
                shutil.rmtree(save_path)
            if not os.path.exists(save_path):
                os.makedirs(save_path)
            save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
            os.makedirs(save_all_path, exist_ok=True)
            
            # Load data
            X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
            if X_test.shape[0] == 0:
                raise ValueError("No valid test images found in the test directory!")
            X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
            y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

            torch.save(global_model, os.path.join(save_path,'model_init.pt'))
            global_weights = global_model.state_dict()

            records = []

            X_train_tensor = {}
            y_train_tensor = {}
            for i in range(N_HONEST):
                X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                if len(X_c) == 0:
                    continue
                X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                X_train_tensor[f"honest_{i}"] = X_c_tensor
                y_train_tensor[f"honest_{i}"] = y_c_tensor
            for i in range(i_poisoned):
                X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                if len(X_c) == 0:
                    continue
                X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                X_train_tensor[f"poison_{i}"] = X_c_tensor
                y_train_tensor[f"poison_{i}"] = y_c_tensor

            # Training loop
            for round in range(ROUNDS):
                # Prepare arguments for honest clients
                
                #randomize the training data
                for i in range(N_HONEST):
                    perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                    X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                    y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                honest_args = [
                    (
                        X_train_tensor[f"honest_{i}"],
                        y_train_tensor[f"honest_{i}"],
                        global_weights,
                        LEARNING_RATE,
                        LOCAL_EPOCHS,
                        experiment_bs,
                        device
                    )
                    for i in range(N_HONEST)
                ]

                # Prepare arguments for poisoned clients
                
                #randomize the training data
                for i in range(i_poisoned):
                    perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                    X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                    y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                poison_args = [
                    (
                        X_train_tensor[f"poison_{i}"],
                        y_train_tensor[f"poison_{i}"],
                        global_weights,
                        LEARNING_RATE,
                        LOCAL_EPOCHS,
                        experiment_bs,
                        device
                    )
                    for i in range(i_poisoned)
                ]

                # Run in parallel
                with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                    honest_results = list(executor.map(train_local_worker, honest_args))
                    poison_results = list(executor.map(train_local_worker, poison_args))

                local_weights = []
                local_sizes = []
                local_y = []
                local_outputs = []
                local_preds = []
                for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                    local_weights.append(l_w)
                    local_sizes.append(l_sz)
                    local_y.extend(l_y)
                    local_outputs.extend(l_out)
                    local_preds.extend(l_pred)
                loss_train = multiclass_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                # Federated averaging (weighted by client data size)
                new_weights = {}
                for key in global_weights.keys():
                    new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                global_weights = new_weights
                global_model.load_state_dict(global_weights)

                # Evaluate
                global_model.eval()
                with torch.no_grad():
                    outputs = global_model(X_test_tensor)
                    # preds = (outputs > 0.5).float()
                    preds = torch.argmax(outputs, dim=1, keepdim=True)
                    loss_test = multiclass_cross_entropy(outputs, y_test_tensor)
                    acc_test = (preds == y_test_tensor).float().mean().item()
                records.append({'poison_percent': percent_poisoned, 'round': round, 
                                'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                'loss_test': loss_test.item(), 'acc_test': acc_test})
                report_txt = f"poison_percent {percent_poisoned} "
                report_txt += f"round {round}: "
                report_txt += f"loss_train={loss_train.item():.4f}, "
                report_txt += f"acc_train={acc_train:.4f}, "
                report_txt += f"loss_test={loss_test.item():.4f}, "
                report_txt += f"acc_test={acc_test:.4f}"
                print(report_txt)

            torch.save(global_model, os.path.join(save_path,'model_last.pt'))

            # Save training log
            df = pd.DataFrame(records)
            save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
            df.to_csv(save_name_path, index=False)
            print(f"Training log saved to {save_name_path}")

            # Plot loss and accuracy
            plt.figure(figsize=(10,4))

            plt.subplot(1,2,1)
            plt.plot(df['round'], df['loss_test'], marker='o')
            plt.title('Test Loss')
            plt.ylabel('Loss')
            plt.xlabel('Epoch')
            plt.grid(True)
            plt.ylim(0, 1.1)
            # plt.legend()

            plt.subplot(1,2,2)
            plt.plot(df['round'], df['acc_test'], marker='o')
            plt.title('Test Accuracy')
            plt.ylabel('Accuracy')
            plt.xlabel('Epoch')
            plt.grid(True)
            plt.ylim(0, 1.1)
            # plt.legend()

            plt.tight_layout()
            save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
            plt.savefig(save_name_path)

            save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
            plt.savefig(save_name_path)
            plt.close()
# Out:
# poison_percent 0 round 0: loss_train=2.1234, acc_train=0.3432, loss_test=2.0609, acc_test=0.4528
# poison_percent 0 round 1: loss_train=1.8794, acc_train=0.5671, loss_test=1.7629, acc_test=0.7016
# poison_percent 0 round 2: loss_train=1.6811, acc_train=0.6954, loss_test=1.5219, acc_test=0.8548
# poison_percent 0 round 3: loss_train=1.5140, acc_train=0.7358, loss_test=1.3125, acc_test=0.9093
# poison_percent 0 round 4: loss_train=1.3676, acc_train=0.7620, loss_test=1.1371, acc_test=0.9246
# poison_percent 0 round 5: loss_train=1.2384, acc_train=0.7720, loss_test=0.9940, acc_test=0.9308
# poison_percent 0 round 6: loss_train=1.1241, acc_train=0.8006, loss_test=0.8713, acc_test=0.9363
# poison_percent 0 round 7: loss_train=1.0460, acc_train=0.7979, loss_test=0.7695, acc_test=0.9400
# poison_percent 0 round 8: loss_train=0.9654, acc_train=0.8117, loss_test=0.6912, acc_test=0.9400
# poison_percent 0 round 9: loss_train=0.9268, acc_train=0.8079, loss_test=0.6241, acc_test=0.9430
# poison_percent 0 round 10: loss_train=0.8668, acc_train=0.8224, loss_test=0.5693, acc_test=0.9455
# poison_percent 0 round 11: loss_train=0.8223, acc_train=0.8241, loss_test=0.5226, acc_test=0.9455
# poison_percent 0 round 12: loss_train=0.7829, acc_train=0.8251, loss_test=0.4828, acc_test=0.9455
# poison_percent 0 round 13: loss_train=0.7459, acc_train=0.8289, loss_test=0.4529, acc_test=0.9479
# poison_percent 0 round 14: loss_train=0.7196, acc_train=0.8382, loss_test=0.4231, acc_test=0.9510
# poison_percent 0 round 15: loss_train=0.6928, acc_train=0.8299, loss_test=0.3985, acc_test=0.9534
# poison_percent 0 round 16: loss_train=0.6705, acc_train=0.8396, loss_test=0.3777, acc_test=0.9534
# poison_percent 0 round 17: loss_train=0.6528, acc_train=0.8382, loss_test=0.3591, acc_test=0.9547
# poison_percent 0 round 18: loss_train=0.6281, acc_train=0.8458, loss_test=0.3434, acc_test=0.9534
# poison_percent 0 round 19: loss_train=0.5928, acc_train=0.8510, loss_test=0.3287, acc_test=0.9547
# poison_percent 0 round 20: loss_train=0.5789, acc_train=0.8634, loss_test=0.3139, acc_test=0.9553
# poison_percent 0 round 21: loss_train=0.5880, acc_train=0.8503, loss_test=0.3018, acc_test=0.9565
# poison_percent 0 round 22: loss_train=0.5494, acc_train=0.8696, loss_test=0.2910, acc_test=0.9589
# poison_percent 0 round 23: loss_train=0.5254, acc_train=0.8662, loss_test=0.2815, acc_test=0.9589
# poison_percent 0 round 24: loss_train=0.5509, acc_train=0.8568, loss_test=0.2707, acc_test=0.9596
# poison_percent 0 round 25: loss_train=0.5218, acc_train=0.8665, loss_test=0.2658, acc_test=0.9602
# poison_percent 0 round 26: loss_train=0.5281, acc_train=0.8644, loss_test=0.2570, acc_test=0.9608
# poison_percent 0 round 27: loss_train=0.4850, acc_train=0.8744, loss_test=0.2522, acc_test=0.9608
# poison_percent 0 round 28: loss_train=0.4873, acc_train=0.8734, loss_test=0.2463, acc_test=0.9608
# poison_percent 0 round 29: loss_train=0.5130, acc_train=0.8637, loss_test=0.2391, acc_test=0.9620
# poison_percent 0 round 30: loss_train=0.4862, acc_train=0.8741, loss_test=0.2338, acc_test=0.9626
# poison_percent 0 round 31: loss_train=0.4842, acc_train=0.8744, loss_test=0.2289, acc_test=0.9632
# poison_percent 0 round 32: loss_train=0.4637, acc_train=0.8751, loss_test=0.2247, acc_test=0.9626
# poison_percent 0 round 33: loss_train=0.4772, acc_train=0.8658, loss_test=0.2215, acc_test=0.9626
# poison_percent 0 round 34: loss_train=0.4649, acc_train=0.8696, loss_test=0.2181, acc_test=0.9632
# poison_percent 0 round 35: loss_train=0.4409, acc_train=0.8800, loss_test=0.2136, acc_test=0.9638
# poison_percent 0 round 36: loss_train=0.4651, acc_train=0.8648, loss_test=0.2099, acc_test=0.9657
# poison_percent 0 round 37: loss_train=0.4425, acc_train=0.8758, loss_test=0.2065, acc_test=0.9657
# poison_percent 0 round 38: loss_train=0.4500, acc_train=0.8824, loss_test=0.2049, acc_test=0.9657
# poison_percent 0 round 39: loss_train=0.4339, acc_train=0.8779, loss_test=0.2022, acc_test=0.9657
# poison_percent 0 round 40: loss_train=0.4383, acc_train=0.8800, loss_test=0.2006, acc_test=0.9657
# poison_percent 0 round 41: loss_train=0.4261, acc_train=0.8820, loss_test=0.1979, acc_test=0.9663
# poison_percent 0 round 42: loss_train=0.4217, acc_train=0.8865, loss_test=0.1947, acc_test=0.9663
# poison_percent 0 round 43: loss_train=0.4272, acc_train=0.8834, loss_test=0.1924, acc_test=0.9663
# poison_percent 0 round 44: loss_train=0.4277, acc_train=0.8820, loss_test=0.1918, acc_test=0.9663
# poison_percent 0 round 45: loss_train=0.4185, acc_train=0.8869, loss_test=0.1887, acc_test=0.9663
# poison_percent 0 round 46: loss_train=0.4333, acc_train=0.8810, loss_test=0.1897, acc_test=0.9663
# poison_percent 0 round 47: loss_train=0.3936, acc_train=0.8972, loss_test=0.1885, acc_test=0.9657
# poison_percent 0 round 48: loss_train=0.4060, acc_train=0.8820, loss_test=0.1862, acc_test=0.9663
# poison_percent 0 round 49: loss_train=0.4135, acc_train=0.8855, loss_test=0.1832, acc_test=0.9663
# poison_percent 0 round 50: loss_train=0.4131, acc_train=0.8889, loss_test=0.1822, acc_test=0.9663
# poison_percent 0 round 51: loss_train=0.4128, acc_train=0.8907, loss_test=0.1807, acc_test=0.9657
# poison_percent 0 round 52: loss_train=0.4037, acc_train=0.8824, loss_test=0.1790, acc_test=0.9657
# poison_percent 0 round 53: loss_train=0.4148, acc_train=0.8879, loss_test=0.1784, acc_test=0.9657
# poison_percent 0 round 54: loss_train=0.3930, acc_train=0.8920, loss_test=0.1776, acc_test=0.9657
# poison_percent 0 round 55: loss_train=0.3930, acc_train=0.8886, loss_test=0.1770, acc_test=0.9657
# poison_percent 0 round 56: loss_train=0.3914, acc_train=0.8941, loss_test=0.1748, acc_test=0.9657
# poison_percent 0 round 57: loss_train=0.4055, acc_train=0.8896, loss_test=0.1743, acc_test=0.9657
# poison_percent 0 round 58: loss_train=0.3938, acc_train=0.8917, loss_test=0.1735, acc_test=0.9657
# poison_percent 0 round 59: loss_train=0.3936, acc_train=0.8927, loss_test=0.1729, acc_test=0.9657
# poison_percent 0 round 60: loss_train=0.3755, acc_train=0.8969, loss_test=0.1711, acc_test=0.9663
# poison_percent 0 round 61: loss_train=0.4185, acc_train=0.8862, loss_test=0.1701, acc_test=0.9663
# poison_percent 0 round 62: loss_train=0.3840, acc_train=0.8941, loss_test=0.1697, acc_test=0.9657
# poison_percent 0 round 63: loss_train=0.4001, acc_train=0.8824, loss_test=0.1703, acc_test=0.9657
# poison_percent 0 round 64: loss_train=0.3615, acc_train=0.8972, loss_test=0.1698, acc_test=0.9651
# poison_percent 0 round 65: loss_train=0.3797, acc_train=0.8844, loss_test=0.1686, acc_test=0.9651
# poison_percent 0 round 66: loss_train=0.3516, acc_train=0.8979, loss_test=0.1688, acc_test=0.9651
# poison_percent 0 round 67: loss_train=0.3760, acc_train=0.8944, loss_test=0.1689, acc_test=0.9651
# poison_percent 0 round 68: loss_train=0.4005, acc_train=0.8834, loss_test=0.1683, acc_test=0.9651
# poison_percent 0 round 69: loss_train=0.3809, acc_train=0.8903, loss_test=0.1667, acc_test=0.9657
# poison_percent 0 round 70: loss_train=0.4134, acc_train=0.8824, loss_test=0.1659, acc_test=0.9657
# poison_percent 0 round 71: loss_train=0.3684, acc_train=0.8955, loss_test=0.1650, acc_test=0.9663
# poison_percent 0 round 72: loss_train=0.3480, acc_train=0.8989, loss_test=0.1645, acc_test=0.9663
# poison_percent 0 round 73: loss_train=0.3685, acc_train=0.8927, loss_test=0.1644, acc_test=0.9657
# poison_percent 0 round 74: loss_train=0.4018, acc_train=0.8924, loss_test=0.1647, acc_test=0.9651
# poison_percent 0 round 75: loss_train=0.3669, acc_train=0.8917, loss_test=0.1653, acc_test=0.9651
# poison_percent 0 round 76: loss_train=0.3950, acc_train=0.8858, loss_test=0.1649, acc_test=0.9651
# poison_percent 0 round 77: loss_train=0.3527, acc_train=0.9069, loss_test=0.1657, acc_test=0.9651
# poison_percent 0 round 78: loss_train=0.3847, acc_train=0.8872, loss_test=0.1650, acc_test=0.9651
# poison_percent 0 round 79: loss_train=0.3967, acc_train=0.8800, loss_test=0.1638, acc_test=0.9651
# poison_percent 0 round 80: loss_train=0.3798, acc_train=0.8955, loss_test=0.1637, acc_test=0.9651
# poison_percent 0 round 81: loss_train=0.3817, acc_train=0.8879, loss_test=0.1633, acc_test=0.9651
# poison_percent 0 round 82: loss_train=0.3841, acc_train=0.8896, loss_test=0.1633, acc_test=0.9651
# poison_percent 0 round 83: loss_train=0.3759, acc_train=0.8879, loss_test=0.1630, acc_test=0.9657
# poison_percent 0 round 84: loss_train=0.3606, acc_train=0.9000, loss_test=0.1643, acc_test=0.9651
# poison_percent 0 round 85: loss_train=0.3991, acc_train=0.8855, loss_test=0.1639, acc_test=0.9651
# poison_percent 0 round 86: loss_train=0.3391, acc_train=0.9020, loss_test=0.1630, acc_test=0.9657
# poison_percent 0 round 87: loss_train=0.3603, acc_train=0.9007, loss_test=0.1625, acc_test=0.9657
# poison_percent 0 round 88: loss_train=0.3817, acc_train=0.8834, loss_test=0.1627, acc_test=0.9663
# poison_percent 0 round 89: loss_train=0.3833, acc_train=0.8917, loss_test=0.1626, acc_test=0.9663
# poison_percent 0 round 90: loss_train=0.3423, acc_train=0.9069, loss_test=0.1631, acc_test=0.9657
# poison_percent 0 round 91: loss_train=0.3840, acc_train=0.9007, loss_test=0.1628, acc_test=0.9663
# poison_percent 0 round 92: loss_train=0.3849, acc_train=0.8893, loss_test=0.1624, acc_test=0.9663
# poison_percent 0 round 93: loss_train=0.3806, acc_train=0.8907, loss_test=0.1623, acc_test=0.9663
# poison_percent 0 round 94: loss_train=0.3674, acc_train=0.8889, loss_test=0.1621, acc_test=0.9663
# poison_percent 0 round 95: loss_train=0.3723, acc_train=0.8924, loss_test=0.1619, acc_test=0.9663
# poison_percent 0 round 96: loss_train=0.3507, acc_train=0.8969, loss_test=0.1618, acc_test=0.9663
# poison_percent 0 round 97: loss_train=0.3829, acc_train=0.8931, loss_test=0.1612, acc_test=0.9669
# poison_percent 0 round 98: loss_train=0.3398, acc_train=0.9069, loss_test=0.1618, acc_test=0.9663
# poison_percent 0 round 99: loss_train=0.3704, acc_train=0.9058, loss_test=0.1617, acc_test=0.9663
# Training log saved to ./results\FL_ModelN1L1_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 round 0: loss_train=1.4891, acc_train=0.8116, loss_test=0.1548, acc_test=0.9700
# poison_percent 10 round 1: loss_train=1.5579, acc_train=0.8054, loss_test=0.1506, acc_test=0.9706
# poison_percent 10 round 2: loss_train=1.5419, acc_train=0.8075, loss_test=0.1472, acc_test=0.9712
# poison_percent 10 round 3: loss_train=1.4734, acc_train=0.8051, loss_test=0.1444, acc_test=0.9718
# poison_percent 10 round 4: loss_train=1.5351, acc_train=0.7980, loss_test=0.1432, acc_test=0.9718
# poison_percent 10 round 5: loss_train=1.5249, acc_train=0.8066, loss_test=0.1426, acc_test=0.9718
# poison_percent 10 round 6: loss_train=1.5363, acc_train=0.8116, loss_test=0.1416, acc_test=0.9718
# poison_percent 10 round 7: loss_train=1.4208, acc_train=0.8091, loss_test=0.1400, acc_test=0.9724
# poison_percent 10 round 8: loss_train=1.4330, acc_train=0.8091, loss_test=0.1394, acc_test=0.9724
# poison_percent 10 round 9: loss_train=1.4975, acc_train=0.8066, loss_test=0.1393, acc_test=0.9730
# poison_percent 10 round 10: loss_train=1.6274, acc_train=0.7992, loss_test=0.1385, acc_test=0.9730
# poison_percent 10 round 11: loss_train=1.6001, acc_train=0.8097, loss_test=0.1378, acc_test=0.9730
# poison_percent 10 round 12: loss_train=1.5570, acc_train=0.8066, loss_test=0.1376, acc_test=0.9730
# poison_percent 10 round 13: loss_train=1.4664, acc_train=0.8088, loss_test=0.1370, acc_test=0.9730
# poison_percent 10 round 14: loss_train=1.5844, acc_train=0.8051, loss_test=0.1368, acc_test=0.9730
# poison_percent 10 round 15: loss_train=1.6215, acc_train=0.8106, loss_test=0.1374, acc_test=0.9730
# poison_percent 10 round 16: loss_train=1.5571, acc_train=0.8091, loss_test=0.1372, acc_test=0.9730
# poison_percent 10 round 17: loss_train=1.4560, acc_train=0.8168, loss_test=0.1371, acc_test=0.9730
# poison_percent 10 round 18: loss_train=1.5799, acc_train=0.8091, loss_test=0.1364, acc_test=0.9730
# poison_percent 10 round 19: loss_train=1.5609, acc_train=0.8038, loss_test=0.1366, acc_test=0.9730
# poison_percent 10 round 20: loss_train=1.5871, acc_train=0.8144, loss_test=0.1367, acc_test=0.9730
# poison_percent 10 round 21: loss_train=1.5983, acc_train=0.8079, loss_test=0.1363, acc_test=0.9730
# poison_percent 10 round 22: loss_train=1.5339, acc_train=0.7998, loss_test=0.1365, acc_test=0.9730
# poison_percent 10 round 23: loss_train=1.5311, acc_train=0.8085, loss_test=0.1364, acc_test=0.9730
# poison_percent 10 round 24: loss_train=1.6731, acc_train=0.8094, loss_test=0.1357, acc_test=0.9730
# poison_percent 10 round 25: loss_train=1.5209, acc_train=0.8178, loss_test=0.1359, acc_test=0.9737
# poison_percent 10 round 26: loss_train=1.7050, acc_train=0.8011, loss_test=0.1358, acc_test=0.9737
# poison_percent 10 round 27: loss_train=1.5522, acc_train=0.8100, loss_test=0.1350, acc_test=0.9737
# poison_percent 10 round 28: loss_train=1.5940, acc_train=0.8079, loss_test=0.1341, acc_test=0.9737
# poison_percent 10 round 29: loss_train=1.5452, acc_train=0.8171, loss_test=0.1338, acc_test=0.9737
# poison_percent 10 round 30: loss_train=1.6141, acc_train=0.8150, loss_test=0.1342, acc_test=0.9737
# poison_percent 10 round 31: loss_train=1.6241, acc_train=0.8014, loss_test=0.1337, acc_test=0.9737
# poison_percent 10 round 32: loss_train=1.6040, acc_train=0.8075, loss_test=0.1337, acc_test=0.9737
# poison_percent 10 round 33: loss_train=1.5972, acc_train=0.8045, loss_test=0.1337, acc_test=0.9737
# poison_percent 10 round 34: loss_train=1.5042, acc_train=0.8116, loss_test=0.1340, acc_test=0.9737
# poison_percent 10 round 35: loss_train=1.6432, acc_train=0.7995, loss_test=0.1341, acc_test=0.9737
# poison_percent 10 round 36: loss_train=1.5705, acc_train=0.8032, loss_test=0.1341, acc_test=0.9737
# poison_percent 10 round 37: loss_train=1.5217, acc_train=0.8106, loss_test=0.1339, acc_test=0.9737
# poison_percent 10 round 38: loss_train=1.6004, acc_train=0.8125, loss_test=0.1333, acc_test=0.9737
# poison_percent 10 round 39: loss_train=1.5983, acc_train=0.8159, loss_test=0.1336, acc_test=0.9737
# poison_percent 10 round 40: loss_train=1.5938, acc_train=0.8131, loss_test=0.1337, acc_test=0.9737
# poison_percent 10 round 41: loss_train=1.6322, acc_train=0.8122, loss_test=0.1341, acc_test=0.9737
# poison_percent 10 round 42: loss_train=1.6619, acc_train=0.8060, loss_test=0.1340, acc_test=0.9737
# poison_percent 10 round 43: loss_train=1.6198, acc_train=0.8106, loss_test=0.1342, acc_test=0.9737
# poison_percent 10 round 44: loss_train=1.5524, acc_train=0.8116, loss_test=0.1341, acc_test=0.9737
# poison_percent 10 round 45: loss_train=1.5726, acc_train=0.8159, loss_test=0.1338, acc_test=0.9743
# poison_percent 10 round 46: loss_train=1.6222, acc_train=0.8063, loss_test=0.1338, acc_test=0.9743
# poison_percent 10 round 47: loss_train=1.6360, acc_train=0.8063, loss_test=0.1334, acc_test=0.9749
# poison_percent 10 round 48: loss_train=1.6429, acc_train=0.8082, loss_test=0.1338, acc_test=0.9743
# poison_percent 10 round 49: loss_train=1.6621, acc_train=0.8122, loss_test=0.1336, acc_test=0.9749
# poison_percent 10 round 50: loss_train=1.5030, acc_train=0.8100, loss_test=0.1337, acc_test=0.9743
# poison_percent 10 round 51: loss_train=1.6590, acc_train=0.8057, loss_test=0.1330, acc_test=0.9749
# poison_percent 10 round 52: loss_train=1.5635, acc_train=0.8193, loss_test=0.1332, acc_test=0.9749
# poison_percent 10 round 53: loss_train=1.6653, acc_train=0.8168, loss_test=0.1334, acc_test=0.9749
# poison_percent 10 round 54: loss_train=1.6045, acc_train=0.8100, loss_test=0.1329, acc_test=0.9749
# poison_percent 10 round 55: loss_train=1.6369, acc_train=0.8165, loss_test=0.1329, acc_test=0.9749
# poison_percent 10 round 56: loss_train=1.6079, acc_train=0.8038, loss_test=0.1325, acc_test=0.9749
# poison_percent 10 round 57: loss_train=1.5926, acc_train=0.8116, loss_test=0.1323, acc_test=0.9755
# poison_percent 10 round 58: loss_train=1.6734, acc_train=0.8128, loss_test=0.1324, acc_test=0.9755
# poison_percent 10 round 59: loss_train=1.7555, acc_train=0.8091, loss_test=0.1327, acc_test=0.9755
# poison_percent 10 round 60: loss_train=1.4998, acc_train=0.8100, loss_test=0.1326, acc_test=0.9755
# poison_percent 10 round 61: loss_train=1.7539, acc_train=0.8140, loss_test=0.1323, acc_test=0.9755
# poison_percent 10 round 62: loss_train=1.7198, acc_train=0.8122, loss_test=0.1325, acc_test=0.9755
# poison_percent 10 round 63: loss_train=1.6339, acc_train=0.8066, loss_test=0.1322, acc_test=0.9755
# poison_percent 10 round 64: loss_train=1.6972, acc_train=0.8113, loss_test=0.1321, acc_test=0.9755
# poison_percent 10 round 65: loss_train=1.7213, acc_train=0.8066, loss_test=0.1327, acc_test=0.9755
# poison_percent 10 round 66: loss_train=1.6803, acc_train=0.8094, loss_test=0.1329, acc_test=0.9755
# poison_percent 10 round 67: loss_train=1.6241, acc_train=0.8103, loss_test=0.1333, acc_test=0.9755
# poison_percent 10 round 68: loss_train=1.7067, acc_train=0.8060, loss_test=0.1330, acc_test=0.9755
# poison_percent 10 round 69: loss_train=1.7060, acc_train=0.8153, loss_test=0.1325, acc_test=0.9755
# poison_percent 10 round 70: loss_train=1.6056, acc_train=0.8181, loss_test=0.1328, acc_test=0.9755
# poison_percent 10 round 71: loss_train=1.7303, acc_train=0.8125, loss_test=0.1324, acc_test=0.9755
# poison_percent 10 round 72: loss_train=1.6886, acc_train=0.8175, loss_test=0.1323, acc_test=0.9755
# poison_percent 10 round 73: loss_train=1.6097, acc_train=0.8100, loss_test=0.1319, acc_test=0.9761
# poison_percent 10 round 74: loss_train=1.7616, acc_train=0.8162, loss_test=0.1319, acc_test=0.9761
# poison_percent 10 round 75: loss_train=1.6455, acc_train=0.8066, loss_test=0.1316, acc_test=0.9761
# poison_percent 10 round 76: loss_train=1.6425, acc_train=0.8168, loss_test=0.1316, acc_test=0.9761
# poison_percent 10 round 77: loss_train=1.6851, acc_train=0.8147, loss_test=0.1322, acc_test=0.9761
# poison_percent 10 round 78: loss_train=1.7950, acc_train=0.8026, loss_test=0.1320, acc_test=0.9761
# poison_percent 10 round 79: loss_train=1.7275, acc_train=0.8162, loss_test=0.1323, acc_test=0.9761
# poison_percent 10 round 80: loss_train=1.6682, acc_train=0.8103, loss_test=0.1328, acc_test=0.9761
# poison_percent 10 round 81: loss_train=1.6737, acc_train=0.8196, loss_test=0.1331, acc_test=0.9761
# poison_percent 10 round 82: loss_train=1.7400, acc_train=0.8131, loss_test=0.1327, acc_test=0.9761
# poison_percent 10 round 83: loss_train=1.7041, acc_train=0.8079, loss_test=0.1325, acc_test=0.9761
# poison_percent 10 round 84: loss_train=1.7423, acc_train=0.8131, loss_test=0.1317, acc_test=0.9761
# poison_percent 10 round 85: loss_train=1.7072, acc_train=0.8113, loss_test=0.1316, acc_test=0.9761
# poison_percent 10 round 86: loss_train=1.6902, acc_train=0.8144, loss_test=0.1318, acc_test=0.9761
# poison_percent 10 round 87: loss_train=1.8023, acc_train=0.8147, loss_test=0.1320, acc_test=0.9761
# poison_percent 10 round 88: loss_train=1.7573, acc_train=0.8156, loss_test=0.1321, acc_test=0.9761
# poison_percent 10 round 89: loss_train=1.7829, acc_train=0.8113, loss_test=0.1324, acc_test=0.9761
# poison_percent 10 round 90: loss_train=1.6371, acc_train=0.8162, loss_test=0.1330, acc_test=0.9761
# poison_percent 10 round 91: loss_train=1.7745, acc_train=0.8175, loss_test=0.1325, acc_test=0.9761
# poison_percent 10 round 92: loss_train=1.7583, acc_train=0.8147, loss_test=0.1325, acc_test=0.9761
# poison_percent 10 round 93: loss_train=1.7265, acc_train=0.8106, loss_test=0.1325, acc_test=0.9761
# poison_percent 10 round 94: loss_train=1.7008, acc_train=0.8137, loss_test=0.1326, acc_test=0.9761
# poison_percent 10 round 95: loss_train=1.7038, acc_train=0.8116, loss_test=0.1323, acc_test=0.9761
# poison_percent 10 round 96: loss_train=1.6481, acc_train=0.8209, loss_test=0.1320, acc_test=0.9761
# poison_percent 10 round 97: loss_train=1.7452, acc_train=0.8113, loss_test=0.1323, acc_test=0.9761
# poison_percent 10 round 98: loss_train=1.7051, acc_train=0.8057, loss_test=0.1326, acc_test=0.9761
# poison_percent 10 round 99: loss_train=1.7346, acc_train=0.8110, loss_test=0.1326, acc_test=0.9761
# Training log saved to ./results\FL_ModelN1L1_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=2.8664, acc_train=0.7343, loss_test=0.1287, acc_test=0.9761
# poison_percent 20 round 1: loss_train=2.9793, acc_train=0.7229, loss_test=0.1258, acc_test=0.9761
# poison_percent 20 round 2: loss_train=3.0419, acc_train=0.7312, loss_test=0.1233, acc_test=0.9761
# poison_percent 20 round 3: loss_train=2.8514, acc_train=0.7382, loss_test=0.1219, acc_test=0.9761
# poison_percent 20 round 4: loss_train=2.9180, acc_train=0.7365, loss_test=0.1200, acc_test=0.9761
# poison_percent 20 round 5: loss_train=2.8932, acc_train=0.7287, loss_test=0.1188, acc_test=0.9779
# poison_percent 20 round 6: loss_train=2.7621, acc_train=0.7354, loss_test=0.1173, acc_test=0.9779
# poison_percent 20 round 7: loss_train=2.8102, acc_train=0.7357, loss_test=0.1164, acc_test=0.9786
# poison_percent 20 round 8: loss_train=2.8311, acc_train=0.7404, loss_test=0.1156, acc_test=0.9792
# poison_percent 20 round 9: loss_train=2.7104, acc_train=0.7354, loss_test=0.1149, acc_test=0.9798
# poison_percent 20 round 10: loss_train=2.7981, acc_train=0.7310, loss_test=0.1144, acc_test=0.9798
# poison_percent 20 round 11: loss_train=2.7744, acc_train=0.7293, loss_test=0.1137, acc_test=0.9798
# poison_percent 20 round 12: loss_train=2.8749, acc_train=0.7363, loss_test=0.1135, acc_test=0.9798
# poison_percent 20 round 13: loss_train=2.8293, acc_train=0.7268, loss_test=0.1132, acc_test=0.9798
# poison_percent 20 round 14: loss_train=2.8766, acc_train=0.7351, loss_test=0.1122, acc_test=0.9798
# poison_percent 20 round 15: loss_train=2.8633, acc_train=0.7329, loss_test=0.1116, acc_test=0.9798
# poison_percent 20 round 16: loss_train=2.8167, acc_train=0.7276, loss_test=0.1113, acc_test=0.9798
# poison_percent 20 round 17: loss_train=2.7631, acc_train=0.7399, loss_test=0.1109, acc_test=0.9798
# poison_percent 20 round 18: loss_train=2.7569, acc_train=0.7340, loss_test=0.1107, acc_test=0.9798
# poison_percent 20 round 19: loss_train=2.7868, acc_train=0.7346, loss_test=0.1107, acc_test=0.9798
# poison_percent 20 round 20: loss_train=2.7992, acc_train=0.7365, loss_test=0.1109, acc_test=0.9798
# poison_percent 20 round 21: loss_train=2.7689, acc_train=0.7393, loss_test=0.1109, acc_test=0.9798
# poison_percent 20 round 22: loss_train=2.7316, acc_train=0.7321, loss_test=0.1105, acc_test=0.9798
# poison_percent 20 round 23: loss_train=2.7472, acc_train=0.7312, loss_test=0.1103, acc_test=0.9798
# poison_percent 20 round 24: loss_train=2.8444, acc_train=0.7354, loss_test=0.1100, acc_test=0.9798
# poison_percent 20 round 25: loss_train=2.6481, acc_train=0.7357, loss_test=0.1103, acc_test=0.9798
# poison_percent 20 round 26: loss_train=2.7843, acc_train=0.7340, loss_test=0.1106, acc_test=0.9798
# poison_percent 20 round 27: loss_train=2.8272, acc_train=0.7368, loss_test=0.1105, acc_test=0.9798
# poison_percent 20 round 28: loss_train=2.6785, acc_train=0.7321, loss_test=0.1104, acc_test=0.9798
# poison_percent 20 round 29: loss_train=2.7998, acc_train=0.7326, loss_test=0.1101, acc_test=0.9798
# poison_percent 20 round 30: loss_train=2.7515, acc_train=0.7407, loss_test=0.1100, acc_test=0.9798
# poison_percent 20 round 31: loss_train=2.7352, acc_train=0.7402, loss_test=0.1095, acc_test=0.9798
# poison_percent 20 round 32: loss_train=2.6903, acc_train=0.7354, loss_test=0.1096, acc_test=0.9798
# poison_percent 20 round 33: loss_train=2.8359, acc_train=0.7270, loss_test=0.1096, acc_test=0.9798
# poison_percent 20 round 34: loss_train=2.7396, acc_train=0.7301, loss_test=0.1099, acc_test=0.9798
# poison_percent 20 round 35: loss_train=2.8598, acc_train=0.7279, loss_test=0.1099, acc_test=0.9798
# poison_percent 20 round 36: loss_train=2.8009, acc_train=0.7335, loss_test=0.1098, acc_test=0.9798
# poison_percent 20 round 37: loss_train=2.7722, acc_train=0.7427, loss_test=0.1095, acc_test=0.9798
# poison_percent 20 round 38: loss_train=2.7835, acc_train=0.7349, loss_test=0.1092, acc_test=0.9798
# poison_percent 20 round 39: loss_train=2.7824, acc_train=0.7349, loss_test=0.1095, acc_test=0.9798
# poison_percent 20 round 40: loss_train=2.7271, acc_train=0.7365, loss_test=0.1092, acc_test=0.9798
# poison_percent 20 round 41: loss_train=2.6829, acc_train=0.7404, loss_test=0.1089, acc_test=0.9798
# poison_percent 20 round 42: loss_train=2.7838, acc_train=0.7357, loss_test=0.1089, acc_test=0.9798
# poison_percent 20 round 43: loss_train=2.7396, acc_train=0.7335, loss_test=0.1086, acc_test=0.9804
# poison_percent 20 round 44: loss_train=2.7094, acc_train=0.7379, loss_test=0.1084, acc_test=0.9804
# poison_percent 20 round 45: loss_train=2.7232, acc_train=0.7413, loss_test=0.1081, acc_test=0.9804
# poison_percent 20 round 46: loss_train=2.8653, acc_train=0.7396, loss_test=0.1080, acc_test=0.9804
# poison_percent 20 round 47: loss_train=2.7192, acc_train=0.7424, loss_test=0.1086, acc_test=0.9804
# poison_percent 20 round 48: loss_train=2.7273, acc_train=0.7340, loss_test=0.1085, acc_test=0.9804
# poison_percent 20 round 49: loss_train=2.7584, acc_train=0.7262, loss_test=0.1082, acc_test=0.9804
# poison_percent 20 round 50: loss_train=2.7724, acc_train=0.7349, loss_test=0.1082, acc_test=0.9804
# poison_percent 20 round 51: loss_train=2.6874, acc_train=0.7340, loss_test=0.1083, acc_test=0.9804
# poison_percent 20 round 52: loss_train=2.6484, acc_train=0.7432, loss_test=0.1082, acc_test=0.9804
# poison_percent 20 round 53: loss_train=2.8739, acc_train=0.7307, loss_test=0.1081, acc_test=0.9804
# poison_percent 20 round 54: loss_train=2.6191, acc_train=0.7393, loss_test=0.1083, acc_test=0.9804
# poison_percent 20 round 55: loss_train=2.8026, acc_train=0.7337, loss_test=0.1078, acc_test=0.9810
# poison_percent 20 round 56: loss_train=2.8277, acc_train=0.7430, loss_test=0.1080, acc_test=0.9810
# poison_percent 20 round 57: loss_train=2.7360, acc_train=0.7393, loss_test=0.1083, acc_test=0.9810
# poison_percent 20 round 58: loss_train=2.8019, acc_train=0.7357, loss_test=0.1086, acc_test=0.9810
# poison_percent 20 round 59: loss_train=2.6728, acc_train=0.7388, loss_test=0.1084, acc_test=0.9810
# poison_percent 20 round 60: loss_train=2.7301, acc_train=0.7374, loss_test=0.1086, acc_test=0.9810
# poison_percent 20 round 61: loss_train=2.8558, acc_train=0.7390, loss_test=0.1087, acc_test=0.9810
# poison_percent 20 round 62: loss_train=2.7231, acc_train=0.7332, loss_test=0.1083, acc_test=0.9810
# poison_percent 20 round 63: loss_train=2.7108, acc_train=0.7323, loss_test=0.1085, acc_test=0.9810
# poison_percent 20 round 64: loss_train=2.7408, acc_train=0.7377, loss_test=0.1082, acc_test=0.9810
# poison_percent 20 round 65: loss_train=2.7818, acc_train=0.7374, loss_test=0.1082, acc_test=0.9810
# poison_percent 20 round 66: loss_train=2.7387, acc_train=0.7357, loss_test=0.1078, acc_test=0.9810
# poison_percent 20 round 67: loss_train=2.6810, acc_train=0.7460, loss_test=0.1076, acc_test=0.9810
# poison_percent 20 round 68: loss_train=2.6492, acc_train=0.7360, loss_test=0.1074, acc_test=0.9810
# poison_percent 20 round 69: loss_train=2.7808, acc_train=0.7343, loss_test=0.1071, acc_test=0.9810
# poison_percent 20 round 70: loss_train=2.6509, acc_train=0.7424, loss_test=0.1075, acc_test=0.9810
# poison_percent 20 round 71: loss_train=2.6761, acc_train=0.7360, loss_test=0.1078, acc_test=0.9810
# poison_percent 20 round 72: loss_train=2.8397, acc_train=0.7321, loss_test=0.1079, acc_test=0.9810
# poison_percent 20 round 73: loss_train=2.8319, acc_train=0.7343, loss_test=0.1081, acc_test=0.9804
# poison_percent 20 round 74: loss_train=2.7589, acc_train=0.7346, loss_test=0.1079, acc_test=0.9810
# poison_percent 20 round 75: loss_train=2.6750, acc_train=0.7318, loss_test=0.1078, acc_test=0.9816
# poison_percent 20 round 76: loss_train=2.7725, acc_train=0.7385, loss_test=0.1077, acc_test=0.9816
# poison_percent 20 round 77: loss_train=2.6298, acc_train=0.7382, loss_test=0.1075, acc_test=0.9810
# poison_percent 20 round 78: loss_train=2.6591, acc_train=0.7396, loss_test=0.1078, acc_test=0.9804
# poison_percent 20 round 79: loss_train=2.6364, acc_train=0.7416, loss_test=0.1076, acc_test=0.9816
# poison_percent 20 round 80: loss_train=2.7115, acc_train=0.7430, loss_test=0.1078, acc_test=0.9804
# poison_percent 20 round 81: loss_train=2.7101, acc_train=0.7343, loss_test=0.1080, acc_test=0.9804
# poison_percent 20 round 82: loss_train=2.7560, acc_train=0.7321, loss_test=0.1074, acc_test=0.9810
# poison_percent 20 round 83: loss_train=2.7221, acc_train=0.7346, loss_test=0.1078, acc_test=0.9804
# poison_percent 20 round 84: loss_train=2.7032, acc_train=0.7351, loss_test=0.1081, acc_test=0.9804
# poison_percent 20 round 85: loss_train=2.6627, acc_train=0.7374, loss_test=0.1082, acc_test=0.9804
# poison_percent 20 round 86: loss_train=2.8359, acc_train=0.7371, loss_test=0.1078, acc_test=0.9804
# poison_percent 20 round 87: loss_train=2.7362, acc_train=0.7374, loss_test=0.1076, acc_test=0.9804
# poison_percent 20 round 88: loss_train=2.7142, acc_train=0.7404, loss_test=0.1079, acc_test=0.9804
# poison_percent 20 round 89: loss_train=2.6808, acc_train=0.7335, loss_test=0.1078, acc_test=0.9804
# poison_percent 20 round 90: loss_train=2.7335, acc_train=0.7374, loss_test=0.1085, acc_test=0.9804
# poison_percent 20 round 91: loss_train=2.6480, acc_train=0.7377, loss_test=0.1084, acc_test=0.9804
# poison_percent 20 round 92: loss_train=2.7574, acc_train=0.7374, loss_test=0.1082, acc_test=0.9804
# poison_percent 20 round 93: loss_train=2.6443, acc_train=0.7438, loss_test=0.1084, acc_test=0.9804
# poison_percent 20 round 94: loss_train=2.6685, acc_train=0.7407, loss_test=0.1082, acc_test=0.9804
# poison_percent 20 round 95: loss_train=2.7482, acc_train=0.7371, loss_test=0.1081, acc_test=0.9810
# poison_percent 20 round 96: loss_train=2.7645, acc_train=0.7284, loss_test=0.1081, acc_test=0.9804
# poison_percent 20 round 97: loss_train=2.7127, acc_train=0.7363, loss_test=0.1081, acc_test=0.9810
# poison_percent 20 round 98: loss_train=2.7333, acc_train=0.7315, loss_test=0.1076, acc_test=0.9816
# poison_percent 20 round 99: loss_train=2.6693, acc_train=0.7368, loss_test=0.1074, acc_test=0.9816
# Training log saved to ./results\FL_ModelN1L1_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=3.9802, acc_train=0.6550, loss_test=0.1039, acc_test=0.9816
# poison_percent 30 round 1: loss_train=3.8665, acc_train=0.6540, loss_test=0.1011, acc_test=0.9828
# poison_percent 30 round 2: loss_train=3.7632, acc_train=0.6525, loss_test=0.0988, acc_test=0.9828
# poison_percent 30 round 3: loss_train=3.6645, acc_train=0.6550, loss_test=0.0970, acc_test=0.9828
# poison_percent 30 round 4: loss_train=3.7035, acc_train=0.6617, loss_test=0.0953, acc_test=0.9835
# poison_percent 30 round 5: loss_train=3.7354, acc_train=0.6572, loss_test=0.0943, acc_test=0.9835
# poison_percent 30 round 6: loss_train=3.6717, acc_train=0.6582, loss_test=0.0933, acc_test=0.9835
# poison_percent 30 round 7: loss_train=3.5849, acc_train=0.6619, loss_test=0.0925, acc_test=0.9835
# poison_percent 30 round 8: loss_train=3.6495, acc_train=0.6508, loss_test=0.0918, acc_test=0.9835
# poison_percent 30 round 9: loss_train=3.6306, acc_train=0.6572, loss_test=0.0912, acc_test=0.9835
# poison_percent 30 round 10: loss_train=3.5082, acc_train=0.6543, loss_test=0.0908, acc_test=0.9835
# poison_percent 30 round 11: loss_train=3.7021, acc_train=0.6491, loss_test=0.0905, acc_test=0.9835
# poison_percent 30 round 12: loss_train=3.5136, acc_train=0.6631, loss_test=0.0903, acc_test=0.9835
# poison_percent 30 round 13: loss_train=3.4821, acc_train=0.6506, loss_test=0.0901, acc_test=0.9835
# poison_percent 30 round 14: loss_train=3.5780, acc_train=0.6585, loss_test=0.0895, acc_test=0.9835
# poison_percent 30 round 15: loss_train=3.5590, acc_train=0.6644, loss_test=0.0891, acc_test=0.9835
# poison_percent 30 round 16: loss_train=3.4618, acc_train=0.6525, loss_test=0.0889, acc_test=0.9835
# poison_percent 30 round 17: loss_train=3.5004, acc_train=0.6506, loss_test=0.0889, acc_test=0.9835
# poison_percent 30 round 18: loss_train=3.3316, acc_train=0.6609, loss_test=0.0885, acc_test=0.9835
# poison_percent 30 round 19: loss_train=3.4138, acc_train=0.6518, loss_test=0.0884, acc_test=0.9835
# poison_percent 30 round 20: loss_train=3.3841, acc_train=0.6575, loss_test=0.0883, acc_test=0.9841
# poison_percent 30 round 21: loss_train=3.3619, acc_train=0.6567, loss_test=0.0879, acc_test=0.9841
# poison_percent 30 round 22: loss_train=3.3948, acc_train=0.6525, loss_test=0.0880, acc_test=0.9841
# poison_percent 30 round 23: loss_train=3.3270, acc_train=0.6552, loss_test=0.0880, acc_test=0.9841
# poison_percent 30 round 24: loss_train=3.3565, acc_train=0.6617, loss_test=0.0880, acc_test=0.9841
# poison_percent 30 round 25: loss_train=3.3993, acc_train=0.6476, loss_test=0.0880, acc_test=0.9847
# poison_percent 30 round 26: loss_train=3.3146, acc_train=0.6580, loss_test=0.0885, acc_test=0.9847
# poison_percent 30 round 27: loss_train=3.1568, acc_train=0.6572, loss_test=0.0884, acc_test=0.9841
# poison_percent 30 round 28: loss_train=3.3416, acc_train=0.6594, loss_test=0.0885, acc_test=0.9841
# poison_percent 30 round 29: loss_train=3.3077, acc_train=0.6597, loss_test=0.0885, acc_test=0.9847
# poison_percent 30 round 30: loss_train=3.2307, acc_train=0.6597, loss_test=0.0884, acc_test=0.9847
# poison_percent 30 round 31: loss_train=3.2686, acc_train=0.6594, loss_test=0.0885, acc_test=0.9847
# poison_percent 30 round 32: loss_train=3.2664, acc_train=0.6550, loss_test=0.0887, acc_test=0.9847
# poison_percent 30 round 33: loss_train=3.2459, acc_train=0.6555, loss_test=0.0888, acc_test=0.9847
# poison_percent 30 round 34: loss_train=3.1647, acc_train=0.6614, loss_test=0.0890, acc_test=0.9847
# poison_percent 30 round 35: loss_train=3.2767, acc_train=0.6530, loss_test=0.0892, acc_test=0.9841
# poison_percent 30 round 36: loss_train=3.2996, acc_train=0.6555, loss_test=0.0891, acc_test=0.9841
# poison_percent 30 round 37: loss_train=3.2143, acc_train=0.6570, loss_test=0.0898, acc_test=0.9841
# poison_percent 30 round 38: loss_train=3.2679, acc_train=0.6577, loss_test=0.0897, acc_test=0.9841
# poison_percent 30 round 39: loss_train=3.2091, acc_train=0.6580, loss_test=0.0897, acc_test=0.9841
# poison_percent 30 round 40: loss_train=3.1151, acc_train=0.6597, loss_test=0.0901, acc_test=0.9841
# poison_percent 30 round 41: loss_train=3.2548, acc_train=0.6580, loss_test=0.0901, acc_test=0.9841
# poison_percent 30 round 42: loss_train=3.1294, acc_train=0.6560, loss_test=0.0902, acc_test=0.9841
# poison_percent 30 round 43: loss_train=3.1280, acc_train=0.6555, loss_test=0.0900, acc_test=0.9841
# poison_percent 30 round 44: loss_train=3.2008, acc_train=0.6498, loss_test=0.0901, acc_test=0.9841
# poison_percent 30 round 45: loss_train=3.1906, acc_train=0.6538, loss_test=0.0902, acc_test=0.9841
# poison_percent 30 round 46: loss_train=3.0944, acc_train=0.6649, loss_test=0.0906, acc_test=0.9841
# poison_percent 30 round 47: loss_train=3.1883, acc_train=0.6540, loss_test=0.0905, acc_test=0.9841
# poison_percent 30 round 48: loss_train=3.1487, acc_train=0.6594, loss_test=0.0907, acc_test=0.9841
# poison_percent 30 round 49: loss_train=3.0994, acc_train=0.6572, loss_test=0.0908, acc_test=0.9835
# poison_percent 30 round 50: loss_train=3.0835, acc_train=0.6555, loss_test=0.0902, acc_test=0.9853
# poison_percent 30 round 51: loss_train=3.1309, acc_train=0.6523, loss_test=0.0906, acc_test=0.9847
# poison_percent 30 round 52: loss_train=3.0286, acc_train=0.6580, loss_test=0.0910, acc_test=0.9847
# poison_percent 30 round 53: loss_train=3.1115, acc_train=0.6474, loss_test=0.0914, acc_test=0.9847
# poison_percent 30 round 54: loss_train=3.1041, acc_train=0.6506, loss_test=0.0914, acc_test=0.9847
# poison_percent 30 round 55: loss_train=3.1450, acc_train=0.6607, loss_test=0.0916, acc_test=0.9847
# poison_percent 30 round 56: loss_train=3.1330, acc_train=0.6577, loss_test=0.0917, acc_test=0.9847
# poison_percent 30 round 57: loss_train=3.0272, acc_train=0.6550, loss_test=0.0922, acc_test=0.9847
# poison_percent 30 round 58: loss_train=3.1164, acc_train=0.6535, loss_test=0.0923, acc_test=0.9847
# poison_percent 30 round 59: loss_train=3.0940, acc_train=0.6577, loss_test=0.0925, acc_test=0.9847
# poison_percent 30 round 60: loss_train=3.0313, acc_train=0.6562, loss_test=0.0928, acc_test=0.9847
# poison_percent 30 round 61: loss_train=3.0524, acc_train=0.6562, loss_test=0.0926, acc_test=0.9847
# poison_percent 30 round 62: loss_train=3.0193, acc_train=0.6592, loss_test=0.0925, acc_test=0.9847
# poison_percent 30 round 63: loss_train=3.1311, acc_train=0.6518, loss_test=0.0929, acc_test=0.9847
# poison_percent 30 round 64: loss_train=3.0561, acc_train=0.6557, loss_test=0.0929, acc_test=0.9847
# poison_percent 30 round 65: loss_train=3.0386, acc_train=0.6506, loss_test=0.0934, acc_test=0.9847
# poison_percent 30 round 66: loss_train=2.9888, acc_train=0.6577, loss_test=0.0937, acc_test=0.9847
# poison_percent 30 round 67: loss_train=3.0114, acc_train=0.6533, loss_test=0.0942, acc_test=0.9847
# poison_percent 30 round 68: loss_train=3.0014, acc_train=0.6535, loss_test=0.0946, acc_test=0.9847
# poison_percent 30 round 69: loss_train=3.0286, acc_train=0.6533, loss_test=0.0942, acc_test=0.9847
# poison_percent 30 round 70: loss_train=2.9117, acc_train=0.6597, loss_test=0.0945, acc_test=0.9847
# poison_percent 30 round 71: loss_train=3.1048, acc_train=0.6479, loss_test=0.0945, acc_test=0.9847
# poison_percent 30 round 72: loss_train=3.1202, acc_train=0.6560, loss_test=0.0947, acc_test=0.9847
# poison_percent 30 round 73: loss_train=2.9970, acc_train=0.6535, loss_test=0.0949, acc_test=0.9847
# poison_percent 30 round 74: loss_train=2.9186, acc_train=0.6634, loss_test=0.0955, acc_test=0.9847
# poison_percent 30 round 75: loss_train=2.9622, acc_train=0.6589, loss_test=0.0951, acc_test=0.9847
# poison_percent 30 round 76: loss_train=2.9921, acc_train=0.6493, loss_test=0.0951, acc_test=0.9847
# poison_percent 30 round 77: loss_train=2.9173, acc_train=0.6555, loss_test=0.0952, acc_test=0.9847
# poison_percent 30 round 78: loss_train=2.9123, acc_train=0.6543, loss_test=0.0952, acc_test=0.9847
# poison_percent 30 round 79: loss_train=2.9246, acc_train=0.6528, loss_test=0.0955, acc_test=0.9847
# poison_percent 30 round 80: loss_train=3.0123, acc_train=0.6520, loss_test=0.0959, acc_test=0.9847
# poison_percent 30 round 81: loss_train=2.9485, acc_train=0.6538, loss_test=0.0961, acc_test=0.9847
# poison_percent 30 round 82: loss_train=2.9597, acc_train=0.6567, loss_test=0.0957, acc_test=0.9847
# poison_percent 30 round 83: loss_train=2.9765, acc_train=0.6535, loss_test=0.0962, acc_test=0.9847
# poison_percent 30 round 84: loss_train=2.9076, acc_train=0.6592, loss_test=0.0970, acc_test=0.9847
# poison_percent 30 round 85: loss_train=2.9956, acc_train=0.6552, loss_test=0.0970, acc_test=0.9847
# poison_percent 30 round 86: loss_train=2.9178, acc_train=0.6557, loss_test=0.0970, acc_test=0.9847
# poison_percent 30 round 87: loss_train=2.8993, acc_train=0.6555, loss_test=0.0961, acc_test=0.9847
# poison_percent 30 round 88: loss_train=2.9376, acc_train=0.6597, loss_test=0.0966, acc_test=0.9847
# poison_percent 30 round 89: loss_train=2.8784, acc_train=0.6520, loss_test=0.0968, acc_test=0.9847
# poison_percent 30 round 90: loss_train=2.8865, acc_train=0.6540, loss_test=0.0970, acc_test=0.9847
# poison_percent 30 round 91: loss_train=2.9388, acc_train=0.6513, loss_test=0.0974, acc_test=0.9847
# poison_percent 30 round 92: loss_train=2.9316, acc_train=0.6498, loss_test=0.0981, acc_test=0.9847
# poison_percent 30 round 93: loss_train=2.9761, acc_train=0.6508, loss_test=0.0985, acc_test=0.9841
# poison_percent 30 round 94: loss_train=2.9003, acc_train=0.6540, loss_test=0.0988, acc_test=0.9841
# poison_percent 30 round 95: loss_train=2.9467, acc_train=0.6548, loss_test=0.0989, acc_test=0.9841
# poison_percent 30 round 96: loss_train=2.9855, acc_train=0.6525, loss_test=0.0991, acc_test=0.9841
# poison_percent 30 round 97: loss_train=2.9161, acc_train=0.6594, loss_test=0.0991, acc_test=0.9841
# poison_percent 30 round 98: loss_train=2.9179, acc_train=0.6513, loss_test=0.0996, acc_test=0.9841
# poison_percent 30 round 99: loss_train=2.9015, acc_train=0.6508, loss_test=0.1006, acc_test=0.9841
# Training log saved to ./results\FL_ModelN1L1_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=3.6747, acc_train=0.5703, loss_test=0.0972, acc_test=0.9847
# poison_percent 40 round 1: loss_train=3.6521, acc_train=0.5765, loss_test=0.0947, acc_test=0.9853
# poison_percent 40 round 2: loss_train=3.6194, acc_train=0.5750, loss_test=0.0928, acc_test=0.9859
# poison_percent 40 round 3: loss_train=3.5719, acc_train=0.5735, loss_test=0.0916, acc_test=0.9859
# poison_percent 40 round 4: loss_train=3.5069, acc_train=0.5767, loss_test=0.0906, acc_test=0.9865
# poison_percent 40 round 5: loss_train=3.3790, acc_train=0.5792, loss_test=0.0897, acc_test=0.9865
# poison_percent 40 round 6: loss_train=3.3616, acc_train=0.5780, loss_test=0.0895, acc_test=0.9859
# poison_percent 40 round 7: loss_train=3.3345, acc_train=0.5784, loss_test=0.0896, acc_test=0.9847
# poison_percent 40 round 8: loss_train=3.2780, acc_train=0.5795, loss_test=0.0902, acc_test=0.9847
# poison_percent 40 round 9: loss_train=3.1848, acc_train=0.5861, loss_test=0.0904, acc_test=0.9847
# poison_percent 40 round 10: loss_train=3.1929, acc_train=0.5809, loss_test=0.0913, acc_test=0.9847
# poison_percent 40 round 11: loss_train=3.0356, acc_train=0.5882, loss_test=0.0917, acc_test=0.9847
# poison_percent 40 round 12: loss_train=3.0555, acc_train=0.5899, loss_test=0.0928, acc_test=0.9847
# poison_percent 40 round 13: loss_train=3.1198, acc_train=0.5869, loss_test=0.0934, acc_test=0.9847
# poison_percent 40 round 14: loss_train=3.1158, acc_train=0.5805, loss_test=0.0940, acc_test=0.9841
# poison_percent 40 round 15: loss_train=2.9638, acc_train=0.5891, loss_test=0.0947, acc_test=0.9841
# poison_percent 40 round 16: loss_train=2.9184, acc_train=0.5848, loss_test=0.0955, acc_test=0.9841
# poison_percent 40 round 17: loss_train=2.9968, acc_train=0.5865, loss_test=0.0962, acc_test=0.9841
# poison_percent 40 round 18: loss_train=2.9198, acc_train=0.5891, loss_test=0.0973, acc_test=0.9841
# poison_percent 40 round 19: loss_train=2.8621, acc_train=0.5801, loss_test=0.0988, acc_test=0.9841
# poison_percent 40 round 20: loss_train=2.9308, acc_train=0.5842, loss_test=0.0997, acc_test=0.9841
# poison_percent 40 round 21: loss_train=2.8983, acc_train=0.5867, loss_test=0.1005, acc_test=0.9828
# poison_percent 40 round 22: loss_train=2.9240, acc_train=0.5831, loss_test=0.1015, acc_test=0.9822
# poison_percent 40 round 23: loss_train=2.7453, acc_train=0.5908, loss_test=0.1023, acc_test=0.9822
# poison_percent 40 round 24: loss_train=2.7140, acc_train=0.5901, loss_test=0.1036, acc_test=0.9810
# poison_percent 40 round 25: loss_train=2.8202, acc_train=0.5899, loss_test=0.1046, acc_test=0.9810
# poison_percent 40 round 26: loss_train=2.8029, acc_train=0.5897, loss_test=0.1052, acc_test=0.9810
# poison_percent 40 round 27: loss_train=2.6955, acc_train=0.5854, loss_test=0.1065, acc_test=0.9804
# poison_percent 40 round 28: loss_train=2.6922, acc_train=0.5914, loss_test=0.1079, acc_test=0.9804
# poison_percent 40 round 29: loss_train=2.6098, acc_train=0.5925, loss_test=0.1090, acc_test=0.9804
# poison_percent 40 round 30: loss_train=2.7749, acc_train=0.5839, loss_test=0.1102, acc_test=0.9804
# poison_percent 40 round 31: loss_train=2.7654, acc_train=0.5839, loss_test=0.1121, acc_test=0.9804
# poison_percent 40 round 32: loss_train=2.6233, acc_train=0.5918, loss_test=0.1135, acc_test=0.9804
# poison_percent 40 round 33: loss_train=2.5640, acc_train=0.5993, loss_test=0.1146, acc_test=0.9786
# poison_percent 40 round 34: loss_train=2.6995, acc_train=0.5886, loss_test=0.1160, acc_test=0.9786
# poison_percent 40 round 35: loss_train=2.6592, acc_train=0.5908, loss_test=0.1176, acc_test=0.9786
# poison_percent 40 round 36: loss_train=2.5481, acc_train=0.5974, loss_test=0.1194, acc_test=0.9786
# poison_percent 40 round 37: loss_train=2.5315, acc_train=0.5869, loss_test=0.1214, acc_test=0.9767
# poison_percent 40 round 38: loss_train=2.5265, acc_train=0.5948, loss_test=0.1229, acc_test=0.9761
# poison_percent 40 round 39: loss_train=2.6221, acc_train=0.5827, loss_test=0.1245, acc_test=0.9755
# poison_percent 40 round 40: loss_train=2.6023, acc_train=0.5908, loss_test=0.1269, acc_test=0.9749
# poison_percent 40 round 41: loss_train=2.5043, acc_train=0.5897, loss_test=0.1276, acc_test=0.9743
# poison_percent 40 round 42: loss_train=2.4492, acc_train=0.5961, loss_test=0.1297, acc_test=0.9737
# poison_percent 40 round 43: loss_train=2.4912, acc_train=0.5950, loss_test=0.1315, acc_test=0.9712
# poison_percent 40 round 44: loss_train=2.5911, acc_train=0.5878, loss_test=0.1338, acc_test=0.9706
# poison_percent 40 round 45: loss_train=2.4688, acc_train=0.5903, loss_test=0.1357, acc_test=0.9694
# poison_percent 40 round 46: loss_train=2.5191, acc_train=0.5882, loss_test=0.1373, acc_test=0.9694
# poison_percent 40 round 47: loss_train=2.5188, acc_train=0.5827, loss_test=0.1393, acc_test=0.9675
# poison_percent 40 round 48: loss_train=2.5167, acc_train=0.5901, loss_test=0.1415, acc_test=0.9669
# poison_percent 40 round 49: loss_train=2.4853, acc_train=0.5869, loss_test=0.1440, acc_test=0.9669
# poison_percent 40 round 50: loss_train=2.4629, acc_train=0.5968, loss_test=0.1465, acc_test=0.9657
# poison_percent 40 round 51: loss_train=2.4385, acc_train=0.5938, loss_test=0.1487, acc_test=0.9632
# poison_percent 40 round 52: loss_train=2.4592, acc_train=0.5893, loss_test=0.1507, acc_test=0.9620
# poison_percent 40 round 53: loss_train=2.3786, acc_train=0.5880, loss_test=0.1526, acc_test=0.9614
# poison_percent 40 round 54: loss_train=2.4202, acc_train=0.5886, loss_test=0.1551, acc_test=0.9614
# poison_percent 40 round 55: loss_train=2.3561, acc_train=0.5910, loss_test=0.1578, acc_test=0.9596
# poison_percent 40 round 56: loss_train=2.3964, acc_train=0.5965, loss_test=0.1601, acc_test=0.9596
# poison_percent 40 round 57: loss_train=2.4423, acc_train=0.5893, loss_test=0.1622, acc_test=0.9583
# poison_percent 40 round 58: loss_train=2.3316, acc_train=0.5931, loss_test=0.1642, acc_test=0.9571
# poison_percent 40 round 59: loss_train=2.3392, acc_train=0.6021, loss_test=0.1659, acc_test=0.9565
# poison_percent 40 round 60: loss_train=2.3920, acc_train=0.5886, loss_test=0.1684, acc_test=0.9565
# poison_percent 40 round 61: loss_train=2.3259, acc_train=0.5818, loss_test=0.1705, acc_test=0.9547
# poison_percent 40 round 62: loss_train=2.3676, acc_train=0.5923, loss_test=0.1730, acc_test=0.9540
# poison_percent 40 round 63: loss_train=2.2985, acc_train=0.5957, loss_test=0.1756, acc_test=0.9528
# poison_percent 40 round 64: loss_train=2.3593, acc_train=0.5916, loss_test=0.1774, acc_test=0.9522
# poison_percent 40 round 65: loss_train=2.3259, acc_train=0.5925, loss_test=0.1796, acc_test=0.9510
# poison_percent 40 round 66: loss_train=2.3828, acc_train=0.5871, loss_test=0.1816, acc_test=0.9504
# poison_percent 40 round 67: loss_train=2.3360, acc_train=0.5948, loss_test=0.1831, acc_test=0.9491
# poison_percent 40 round 68: loss_train=2.2701, acc_train=0.5961, loss_test=0.1842, acc_test=0.9485
# poison_percent 40 round 69: loss_train=2.3679, acc_train=0.5897, loss_test=0.1865, acc_test=0.9461
# poison_percent 40 round 70: loss_train=2.3150, acc_train=0.5916, loss_test=0.1889, acc_test=0.9455
# poison_percent 40 round 71: loss_train=2.2655, acc_train=0.5968, loss_test=0.1903, acc_test=0.9449
# poison_percent 40 round 72: loss_train=2.1816, acc_train=0.5995, loss_test=0.1918, acc_test=0.9442
# poison_percent 40 round 73: loss_train=2.2513, acc_train=0.5882, loss_test=0.1939, acc_test=0.9442
# poison_percent 40 round 74: loss_train=2.3354, acc_train=0.5867, loss_test=0.1954, acc_test=0.9442
# poison_percent 40 round 75: loss_train=2.2304, acc_train=0.5921, loss_test=0.1968, acc_test=0.9442
# poison_percent 40 round 76: loss_train=2.2902, acc_train=0.5942, loss_test=0.1986, acc_test=0.9442
# poison_percent 40 round 77: loss_train=2.2324, acc_train=0.5997, loss_test=0.2016, acc_test=0.9436
# poison_percent 40 round 78: loss_train=2.2633, acc_train=0.5925, loss_test=0.2033, acc_test=0.9430
# poison_percent 40 round 79: loss_train=2.2665, acc_train=0.5914, loss_test=0.2046, acc_test=0.9430
# poison_percent 40 round 80: loss_train=2.2331, acc_train=0.6002, loss_test=0.2057, acc_test=0.9436
# poison_percent 40 round 81: loss_train=2.2218, acc_train=0.5935, loss_test=0.2077, acc_test=0.9430
# poison_percent 40 round 82: loss_train=2.2415, acc_train=0.6004, loss_test=0.2100, acc_test=0.9424
# poison_percent 40 round 83: loss_train=2.1899, acc_train=0.6017, loss_test=0.2119, acc_test=0.9418
# poison_percent 40 round 84: loss_train=2.2663, acc_train=0.5918, loss_test=0.2128, acc_test=0.9418
# poison_percent 40 round 85: loss_train=2.2260, acc_train=0.5918, loss_test=0.2143, acc_test=0.9418
# poison_percent 40 round 86: loss_train=2.2053, acc_train=0.5948, loss_test=0.2155, acc_test=0.9418
# poison_percent 40 round 87: loss_train=2.2009, acc_train=0.5953, loss_test=0.2169, acc_test=0.9412
# poison_percent 40 round 88: loss_train=2.2388, acc_train=0.5946, loss_test=0.2175, acc_test=0.9418
# poison_percent 40 round 89: loss_train=2.2195, acc_train=0.5835, loss_test=0.2183, acc_test=0.9424
# poison_percent 40 round 90: loss_train=2.1798, acc_train=0.5989, loss_test=0.2193, acc_test=0.9418
# poison_percent 40 round 91: loss_train=2.2740, acc_train=0.5963, loss_test=0.2205, acc_test=0.9418
# poison_percent 40 round 92: loss_train=2.2316, acc_train=0.5893, loss_test=0.2212, acc_test=0.9400
# poison_percent 40 round 93: loss_train=2.1104, acc_train=0.5927, loss_test=0.2230, acc_test=0.9400
# poison_percent 40 round 94: loss_train=2.1936, acc_train=0.5946, loss_test=0.2244, acc_test=0.9375
# poison_percent 40 round 95: loss_train=2.1596, acc_train=0.5974, loss_test=0.2257, acc_test=0.9375
# poison_percent 40 round 96: loss_train=2.1810, acc_train=0.5974, loss_test=0.2263, acc_test=0.9369
# poison_percent 40 round 97: loss_train=2.2060, acc_train=0.5942, loss_test=0.2272, acc_test=0.9369
# poison_percent 40 round 98: loss_train=2.1516, acc_train=0.6017, loss_test=0.2293, acc_test=0.9363
# poison_percent 40 round 99: loss_train=2.1708, acc_train=0.5929, loss_test=0.2302, acc_test=0.9357
# Training log saved to ./results\FL_ModelN1L1_Batchsize32_rev0\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 round 0: loss_train=2.5514, acc_train=0.5262, loss_test=0.2252, acc_test=0.9375
# poison_percent 50 round 1: loss_train=2.5101, acc_train=0.5286, loss_test=0.2218, acc_test=0.9381
# poison_percent 50 round 2: loss_train=2.4398, acc_train=0.5343, loss_test=0.2209, acc_test=0.9375
# poison_percent 50 round 3: loss_train=2.3374, acc_train=0.5439, loss_test=0.2209, acc_test=0.9387
# poison_percent 50 round 4: loss_train=2.2588, acc_train=0.5490, loss_test=0.2227, acc_test=0.9381
# poison_percent 50 round 5: loss_train=2.2667, acc_train=0.5488, loss_test=0.2241, acc_test=0.9393
# poison_percent 50 round 6: loss_train=2.2230, acc_train=0.5578, loss_test=0.2265, acc_test=0.9381
# poison_percent 50 round 7: loss_train=2.1710, acc_train=0.5483, loss_test=0.2297, acc_test=0.9375
# poison_percent 50 round 8: loss_train=2.1285, acc_train=0.5553, loss_test=0.2340, acc_test=0.9363
# poison_percent 50 round 9: loss_train=2.1166, acc_train=0.5580, loss_test=0.2384, acc_test=0.9357
# poison_percent 50 round 10: loss_train=2.0248, acc_train=0.5705, loss_test=0.2434, acc_test=0.9338
# poison_percent 50 round 11: loss_train=2.0815, acc_train=0.5640, loss_test=0.2491, acc_test=0.9320
# poison_percent 50 round 12: loss_train=2.0606, acc_train=0.5642, loss_test=0.2548, acc_test=0.9314
# poison_percent 50 round 13: loss_train=2.0220, acc_train=0.5629, loss_test=0.2610, acc_test=0.9295
# poison_percent 50 round 14: loss_train=1.9472, acc_train=0.5723, loss_test=0.2679, acc_test=0.9277
# poison_percent 50 round 15: loss_train=2.0029, acc_train=0.5665, loss_test=0.2748, acc_test=0.9246
# poison_percent 50 round 16: loss_train=1.9759, acc_train=0.5721, loss_test=0.2811, acc_test=0.9228
# poison_percent 50 round 17: loss_train=1.9568, acc_train=0.5750, loss_test=0.2880, acc_test=0.9216
# poison_percent 50 round 18: loss_train=1.9450, acc_train=0.5642, loss_test=0.2946, acc_test=0.9203
# poison_percent 50 round 19: loss_train=1.9488, acc_train=0.5656, loss_test=0.3016, acc_test=0.9185
