# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
# def binary_cross_entropy(pred, target):
#     eps = 1e-7
#     pred = torch.clamp(pred, eps, 1 - eps)
#     return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

def multiclass_cross_entropy(logits, target, from_probs=False, eps=1e-7):
    """
    Cross-entropy loss for multiclass (e.g., 10 classes).
    - logits: Tensor shape (N, C) containing raw scores (preferred) or probabilities if from_probs=True
    - target: Tensor shape (N,) or (N,1) containing class indices (0..C-1)
    """
    if logits.dim() == 1:
        logits = logits.unsqueeze(0)
    target = target.squeeze()
    if target.dtype != torch.long:
        target = target.long()
    if from_probs:
        probs = torch.clamp(logits, eps, 1.0 - eps)
        log_probs = torch.log(probs)
        return -log_probs[torch.arange(target.size(0)), target].mean()
    return nn.functional.cross_entropy(logits, target)

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    model = MNISTNet().to(device)
    model.load_state_dict(global_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end]
            yb = y_c_tensor[start:end]
            outputs = model(xb)
            # preds = (outputs >= 0.5).float()
            preds = torch.argmax(outputs, dim=1, keepdim=True)
            loss = multiclass_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # Return a deepcopy to avoid issues with state_dict references
    return copy.deepcopy(model.state_dict()), X_c_tensor.size(0), yb, outputs, preds

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 32
N_CLASSES = 10

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_multiple_poison/train"
TEST_PATH = "../data/mnist_multiple_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
NODE = 1
for LAYER in [3,4,5,6]: # LAYER - (first,last)

    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            
            # 1. Define the stack of hidden layers (Linear + ReLU)
            # Use a list comprehension to create the (Linear, ReLU) pairs
            hidden_layers = []
            for _ in range(LAYER-2):
                hidden_layers.append(nn.Linear(NODE, NODE))
                hidden_layers.append(nn.ReLU())
                
            # 2. Use nn.Sequential to wrap the entire dynamic stack
            self.dynamic_hidden = nn.Sequential(*hidden_layers)
            
            # Other layers
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, N_CLASSES)

        def forward(self, x):
            # Flatten the input
            x = x.view(x.size(0), -1) 
            
            # Input Layer
            x = self.fc1(x)
            x = nn.ReLU()(x) # We need to manually apply ReLU here
            
            # Dynamic Hidden Layers (Executed sequentially without a loop)
            x = self.dynamic_hidden(x)
                
            # Output Layer
            x = self.fc2(x)
            # x = torch.sigmoid(x)
            
            return x

    BATCH_SIZE_list = [BATCH_SIZE]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        global_model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"FL_ModelN{NODE}L{LAYER}_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                torch.save(global_model, os.path.join(save_path,'model_init.pt'))
                global_weights = global_model.state_dict()

                records = []

                X_train_tensor = {}
                y_train_tensor = {}
                for i in range(N_HONEST):
                    X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"honest_{i}"] = X_c_tensor
                    y_train_tensor[f"honest_{i}"] = y_c_tensor
                for i in range(i_poisoned):
                    X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"poison_{i}"] = X_c_tensor
                    y_train_tensor[f"poison_{i}"] = y_c_tensor

                # Training loop
                for round in range(ROUNDS):
                    # Prepare arguments for honest clients
                    
                    #randomize the training data
                    for i in range(N_HONEST):
                        perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                        X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                        y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                    honest_args = [
                        (
                            X_train_tensor[f"honest_{i}"],
                            y_train_tensor[f"honest_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(N_HONEST)
                    ]

                    # Prepare arguments for poisoned clients
                    
                    #randomize the training data
                    for i in range(i_poisoned):
                        perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                        X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                        y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                    poison_args = [
                        (
                            X_train_tensor[f"poison_{i}"],
                            y_train_tensor[f"poison_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(i_poisoned)
                    ]

                    # Run in parallel
                    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                        honest_results = list(executor.map(train_local_worker, honest_args))
                        poison_results = list(executor.map(train_local_worker, poison_args))

                    local_weights = []
                    local_sizes = []
                    local_y = []
                    local_outputs = []
                    local_preds = []
                    for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                        local_weights.append(l_w)
                        local_sizes.append(l_sz)
                        local_y.extend(l_y)
                        local_outputs.extend(l_out)
                        local_preds.extend(l_pred)
                    loss_train = multiclass_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                    acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                    # Federated averaging (weighted by client data size)
                    new_weights = {}
                    for key in global_weights.keys():
                        new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                    global_weights = new_weights
                    global_model.load_state_dict(global_weights)

                    # Evaluate
                    global_model.eval()
                    with torch.no_grad():
                        outputs = global_model(X_test_tensor)
                        # preds = (outputs > 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        loss_test = multiclass_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'round': round, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"round {round}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(global_model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['round'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['round'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 round 0: loss_train=2.5358, acc_train=0.0914, loss_test=3.2450, acc_test=0.0000
# poison_percent 0 round 1: loss_train=2.5510, acc_train=0.0918, loss_test=3.2119, acc_test=0.0000
# poison_percent 0 round 2: loss_train=2.5212, acc_train=0.0907, loss_test=3.1731, acc_test=0.0000
# poison_percent 0 round 3: loss_train=2.5198, acc_train=0.0928, loss_test=3.1296, acc_test=0.0000
# poison_percent 0 round 4: loss_train=2.4831, acc_train=0.0928, loss_test=3.0827, acc_test=0.0000
# poison_percent 0 round 5: loss_train=2.4776, acc_train=0.0880, loss_test=3.0356, acc_test=0.0000
# poison_percent 0 round 6: loss_train=2.4601, acc_train=0.0935, loss_test=2.9925, acc_test=0.0000
# poison_percent 0 round 7: loss_train=2.4480, acc_train=0.0993, loss_test=2.9616, acc_test=0.0000
# poison_percent 0 round 8: loss_train=2.4467, acc_train=0.0997, loss_test=2.9427, acc_test=0.0000
# poison_percent 0 round 9: loss_train=2.4271, acc_train=0.1145, loss_test=2.9299, acc_test=0.0000
# poison_percent 0 round 10: loss_train=2.4333, acc_train=0.1100, loss_test=2.9193, acc_test=0.0000
# poison_percent 0 round 11: loss_train=2.4323, acc_train=0.1200, loss_test=2.9090, acc_test=0.0000
# poison_percent 0 round 12: loss_train=2.4273, acc_train=0.1207, loss_test=2.8994, acc_test=0.0000
# poison_percent 0 round 13: loss_train=2.4023, acc_train=0.1356, loss_test=2.8886, acc_test=0.0000
# poison_percent 0 round 14: loss_train=2.3976, acc_train=0.1325, loss_test=2.8787, acc_test=0.0000
# poison_percent 0 round 15: loss_train=2.4191, acc_train=0.1187, loss_test=2.8691, acc_test=0.0000
# poison_percent 0 round 16: loss_train=2.3791, acc_train=0.1338, loss_test=2.8592, acc_test=0.0000
# poison_percent 0 round 17: loss_train=2.3734, acc_train=0.1442, loss_test=2.8486, acc_test=0.0000
# poison_percent 0 round 18: loss_train=2.3918, acc_train=0.1418, loss_test=2.8390, acc_test=0.0000
# poison_percent 0 round 19: loss_train=2.3780, acc_train=0.1342, loss_test=2.8290, acc_test=0.0000
# poison_percent 0 round 20: loss_train=2.3718, acc_train=0.1321, loss_test=2.8184, acc_test=0.0000
# poison_percent 0 round 21: loss_train=2.3603, acc_train=0.1438, loss_test=2.8075, acc_test=0.0000
# poison_percent 0 round 22: loss_train=2.3607, acc_train=0.1463, loss_test=2.7971, acc_test=0.0000
# poison_percent 0 round 23: loss_train=2.3597, acc_train=0.1421, loss_test=2.7867, acc_test=0.0000
# poison_percent 0 round 24: loss_train=2.3597, acc_train=0.1352, loss_test=2.7766, acc_test=0.0000
# poison_percent 0 round 25: loss_train=2.3419, acc_train=0.1442, loss_test=2.7656, acc_test=0.0000
# poison_percent 0 round 26: loss_train=2.3364, acc_train=0.1459, loss_test=2.7554, acc_test=0.0000
# poison_percent 0 round 27: loss_train=2.3379, acc_train=0.1294, loss_test=2.7450, acc_test=0.0000
# poison_percent 0 round 28: loss_train=2.3207, acc_train=0.1494, loss_test=2.7353, acc_test=0.0000
# poison_percent 0 round 29: loss_train=2.3351, acc_train=0.1404, loss_test=2.7246, acc_test=0.0000
# poison_percent 0 round 30: loss_train=2.3268, acc_train=0.1435, loss_test=2.7148, acc_test=0.0000
# poison_percent 0 round 31: loss_train=2.3064, acc_train=0.1542, loss_test=2.7043, acc_test=0.0000
# poison_percent 0 round 32: loss_train=2.3106, acc_train=0.1411, loss_test=2.6947, acc_test=0.0000
# poison_percent 0 round 33: loss_train=2.2846, acc_train=0.1625, loss_test=2.6844, acc_test=0.0000
# poison_percent 0 round 34: loss_train=2.2859, acc_train=0.1518, loss_test=2.6748, acc_test=0.0000
# poison_percent 0 round 35: loss_train=2.2988, acc_train=0.1456, loss_test=2.6655, acc_test=0.0000
# poison_percent 0 round 36: loss_train=2.2860, acc_train=0.1518, loss_test=2.6551, acc_test=0.0000
# poison_percent 0 round 37: loss_train=2.2834, acc_train=0.1583, loss_test=2.6457, acc_test=0.0000
# poison_percent 0 round 38: loss_train=2.2754, acc_train=0.1556, loss_test=2.6361, acc_test=0.0000
# poison_percent 0 round 39: loss_train=2.2707, acc_train=0.1521, loss_test=2.6265, acc_test=0.0000
# poison_percent 0 round 40: loss_train=2.2655, acc_train=0.1532, loss_test=2.6171, acc_test=0.0000
# poison_percent 0 round 41: loss_train=2.2589, acc_train=0.1535, loss_test=2.6081, acc_test=0.0000
# poison_percent 0 round 42: loss_train=2.2472, acc_train=0.1583, loss_test=2.5985, acc_test=0.0000
# poison_percent 0 round 43: loss_train=2.2445, acc_train=0.1649, loss_test=2.5902, acc_test=0.0000
# poison_percent 0 round 44: loss_train=2.2494, acc_train=0.1594, loss_test=2.5812, acc_test=0.0000
# poison_percent 0 round 45: loss_train=2.2464, acc_train=0.1507, loss_test=2.5722, acc_test=0.0000
# poison_percent 0 round 46: loss_train=2.2402, acc_train=0.1614, loss_test=2.5640, acc_test=0.0000
# poison_percent 0 round 47: loss_train=2.2405, acc_train=0.1563, loss_test=2.5555, acc_test=0.0000
# poison_percent 0 round 48: loss_train=2.2273, acc_train=0.1739, loss_test=2.5469, acc_test=0.0000
# poison_percent 0 round 49: loss_train=2.2222, acc_train=0.1570, loss_test=2.5388, acc_test=0.0000
# poison_percent 0 round 50: loss_train=2.2209, acc_train=0.1628, loss_test=2.5305, acc_test=0.0000
# poison_percent 0 round 51: loss_train=2.2144, acc_train=0.1518, loss_test=2.5224, acc_test=0.0000
# poison_percent 0 round 52: loss_train=2.2205, acc_train=0.1469, loss_test=2.5143, acc_test=0.0000
# poison_percent 0 round 53: loss_train=2.2128, acc_train=0.1604, loss_test=2.5060, acc_test=0.0000
# poison_percent 0 round 54: loss_train=2.2083, acc_train=0.1628, loss_test=2.4978, acc_test=0.0000
# poison_percent 0 round 55: loss_train=2.2047, acc_train=0.1570, loss_test=2.4901, acc_test=0.0000
# poison_percent 0 round 56: loss_train=2.2044, acc_train=0.1432, loss_test=2.4824, acc_test=0.0000
# poison_percent 0 round 57: loss_train=2.2035, acc_train=0.1556, loss_test=2.4742, acc_test=0.0000
# poison_percent 0 round 58: loss_train=2.1910, acc_train=0.1625, loss_test=2.4667, acc_test=0.0000
# poison_percent 0 round 59: loss_train=2.1949, acc_train=0.1487, loss_test=2.4594, acc_test=0.0000
# poison_percent 0 round 60: loss_train=2.1936, acc_train=0.1469, loss_test=2.4522, acc_test=0.0000
# poison_percent 0 round 61: loss_train=2.1828, acc_train=0.1583, loss_test=2.4445, acc_test=0.0000
# poison_percent 0 round 62: loss_train=2.1760, acc_train=0.1501, loss_test=2.4368, acc_test=0.0000
# poison_percent 0 round 63: loss_train=2.1706, acc_train=0.1538, loss_test=2.4299, acc_test=0.0000
# poison_percent 0 round 64: loss_train=2.1762, acc_train=0.1501, loss_test=2.4225, acc_test=0.0000
# poison_percent 0 round 65: loss_train=2.1658, acc_train=0.1463, loss_test=2.4153, acc_test=0.0000
# poison_percent 0 round 66: loss_train=2.1612, acc_train=0.1511, loss_test=2.4082, acc_test=0.0000
# poison_percent 0 round 67: loss_train=2.1660, acc_train=0.1532, loss_test=2.4011, acc_test=0.0000
# poison_percent 0 round 68: loss_train=2.1516, acc_train=0.1614, loss_test=2.3938, acc_test=0.0000
# poison_percent 0 round 69: loss_train=2.1580, acc_train=0.1514, loss_test=2.3872, acc_test=0.0000
# poison_percent 0 round 70: loss_train=2.1524, acc_train=0.1545, loss_test=2.3798, acc_test=0.0000
# poison_percent 0 round 71: loss_train=2.1552, acc_train=0.1400, loss_test=2.3732, acc_test=0.0000
# poison_percent 0 round 72: loss_train=2.1546, acc_train=0.1494, loss_test=2.3668, acc_test=0.0000
# poison_percent 0 round 73: loss_train=2.1442, acc_train=0.1583, loss_test=2.3599, acc_test=0.0000
# poison_percent 0 round 74: loss_train=2.1449, acc_train=0.1559, loss_test=2.3532, acc_test=0.0000
# poison_percent 0 round 75: loss_train=2.1406, acc_train=0.1532, loss_test=2.3465, acc_test=0.0000
# poison_percent 0 round 76: loss_train=2.1391, acc_train=0.1356, loss_test=2.3402, acc_test=0.0000
# poison_percent 0 round 77: loss_train=2.1374, acc_train=0.1494, loss_test=2.3338, acc_test=0.0000
# poison_percent 0 round 78: loss_train=2.1272, acc_train=0.1445, loss_test=2.3273, acc_test=0.0000
# poison_percent 0 round 79: loss_train=2.1182, acc_train=0.1570, loss_test=2.3205, acc_test=0.0000
# poison_percent 0 round 80: loss_train=2.1244, acc_train=0.1459, loss_test=2.3138, acc_test=0.0000
# poison_percent 0 round 81: loss_train=2.1256, acc_train=0.1504, loss_test=2.3072, acc_test=0.0000
# poison_percent 0 round 82: loss_train=2.1192, acc_train=0.1473, loss_test=2.3006, acc_test=0.0000
# poison_percent 0 round 83: loss_train=2.1182, acc_train=0.1542, loss_test=2.2944, acc_test=0.0000
# poison_percent 0 round 84: loss_train=2.1085, acc_train=0.1466, loss_test=2.2874, acc_test=0.0000
# poison_percent 0 round 85: loss_train=2.1095, acc_train=0.1411, loss_test=2.2809, acc_test=0.0000
# poison_percent 0 round 86: loss_train=2.1102, acc_train=0.1939, loss_test=2.2749, acc_test=0.0061
# poison_percent 0 round 87: loss_train=2.1069, acc_train=0.2166, loss_test=2.2688, acc_test=0.0460
# poison_percent 0 round 88: loss_train=2.1030, acc_train=0.2097, loss_test=2.2628, acc_test=0.0668
# poison_percent 0 round 89: loss_train=2.0929, acc_train=0.2232, loss_test=2.2571, acc_test=0.0686
# poison_percent 0 round 90: loss_train=2.1004, acc_train=0.2156, loss_test=2.2511, acc_test=0.0754
# poison_percent 0 round 91: loss_train=2.0928, acc_train=0.2211, loss_test=2.2451, acc_test=0.0741
# poison_percent 0 round 92: loss_train=2.0954, acc_train=0.2170, loss_test=2.2384, acc_test=0.0748
# poison_percent 0 round 93: loss_train=2.0890, acc_train=0.2001, loss_test=2.2328, acc_test=0.0748
# poison_percent 0 round 94: loss_train=2.0941, acc_train=0.2156, loss_test=2.2262, acc_test=0.0741
# poison_percent 0 round 95: loss_train=2.0847, acc_train=0.2118, loss_test=2.2204, acc_test=0.0699
# poison_percent 0 round 96: loss_train=2.0812, acc_train=0.2173, loss_test=2.2146, acc_test=0.0662
# poison_percent 0 round 97: loss_train=2.0759, acc_train=0.2118, loss_test=2.2089, acc_test=0.0643
# poison_percent 0 round 98: loss_train=2.0736, acc_train=0.2063, loss_test=2.2028, acc_test=0.0643
# poison_percent 0 round 99: loss_train=2.0711, acc_train=0.2049, loss_test=2.1968, acc_test=0.0643
# Training log saved to ./results\FL_ModelN1L3_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 round 0: loss_train=2.1661, acc_train=0.1822, loss_test=2.1907, acc_test=0.0674
# poison_percent 10 round 1: loss_train=2.1613, acc_train=0.1801, loss_test=2.1852, acc_test=0.0686
# poison_percent 10 round 2: loss_train=2.1545, acc_train=0.1906, loss_test=2.1788, acc_test=0.0686
# poison_percent 10 round 3: loss_train=2.1541, acc_train=0.1795, loss_test=2.1727, acc_test=0.0668
# poison_percent 10 round 4: loss_train=2.1544, acc_train=0.1788, loss_test=2.1657, acc_test=0.0668
# poison_percent 10 round 5: loss_train=2.1495, acc_train=0.1742, loss_test=2.1593, acc_test=0.0637
# poison_percent 10 round 6: loss_train=2.1487, acc_train=0.1866, loss_test=2.1532, acc_test=0.0613
# poison_percent 10 round 7: loss_train=2.1458, acc_train=0.1785, loss_test=2.1472, acc_test=0.0607
# poison_percent 10 round 8: loss_train=2.1475, acc_train=0.1723, loss_test=2.1414, acc_test=0.0594
# poison_percent 10 round 9: loss_train=2.1393, acc_train=0.1776, loss_test=2.1358, acc_test=0.0576
# poison_percent 10 round 10: loss_train=2.1367, acc_train=0.1825, loss_test=2.1301, acc_test=0.0558
# poison_percent 10 round 11: loss_train=2.1380, acc_train=0.1850, loss_test=2.1241, acc_test=0.0545
# poison_percent 10 round 12: loss_train=2.1316, acc_train=0.1844, loss_test=2.1180, acc_test=0.0527
# poison_percent 10 round 13: loss_train=2.1274, acc_train=0.1829, loss_test=2.1124, acc_test=0.0521
# poison_percent 10 round 14: loss_train=2.1276, acc_train=0.1844, loss_test=2.1069, acc_test=0.0521
# poison_percent 10 round 15: loss_train=2.1320, acc_train=0.1835, loss_test=2.1008, acc_test=0.0527
# poison_percent 10 round 16: loss_train=2.1185, acc_train=0.1807, loss_test=2.0953, acc_test=0.0527
# poison_percent 10 round 17: loss_train=2.1344, acc_train=0.1618, loss_test=2.0899, acc_test=0.0509
# poison_percent 10 round 18: loss_train=2.1239, acc_train=0.1798, loss_test=2.0841, acc_test=0.0509
# poison_percent 10 round 19: loss_train=2.1151, acc_train=0.1890, loss_test=2.0791, acc_test=0.0502
# poison_percent 10 round 20: loss_train=2.1254, acc_train=0.1810, loss_test=2.0742, acc_test=0.0502
# poison_percent 10 round 21: loss_train=2.1259, acc_train=0.1742, loss_test=2.0694, acc_test=0.0502
# poison_percent 10 round 22: loss_train=2.1155, acc_train=0.1745, loss_test=2.0642, acc_test=0.0496
# poison_percent 10 round 23: loss_train=2.1159, acc_train=0.1856, loss_test=2.0590, acc_test=0.0490
# poison_percent 10 round 24: loss_train=2.1063, acc_train=0.1810, loss_test=2.0534, acc_test=0.0496
# poison_percent 10 round 25: loss_train=2.1107, acc_train=0.1779, loss_test=2.0487, acc_test=0.0466
# poison_percent 10 round 26: loss_train=2.1166, acc_train=0.1767, loss_test=2.0438, acc_test=0.0472
# poison_percent 10 round 27: loss_train=2.1062, acc_train=0.1791, loss_test=2.0388, acc_test=0.0441
# poison_percent 10 round 28: loss_train=2.1114, acc_train=0.1829, loss_test=2.0342, acc_test=0.0429
# poison_percent 10 round 29: loss_train=2.1003, acc_train=0.1912, loss_test=2.0293, acc_test=0.0429
# poison_percent 10 round 30: loss_train=2.1128, acc_train=0.1816, loss_test=2.0247, acc_test=0.0404
# poison_percent 10 round 31: loss_train=2.1100, acc_train=0.1705, loss_test=2.0196, acc_test=0.0417
# poison_percent 10 round 32: loss_train=2.1080, acc_train=0.1733, loss_test=2.0150, acc_test=0.0411
# poison_percent 10 round 33: loss_train=2.1021, acc_train=0.1761, loss_test=2.0100, acc_test=0.0386
# poison_percent 10 round 34: loss_train=2.1042, acc_train=0.1773, loss_test=2.0055, acc_test=0.0417
# poison_percent 10 round 35: loss_train=2.0897, acc_train=0.1931, loss_test=2.0012, acc_test=0.0417
# poison_percent 10 round 36: loss_train=2.0922, acc_train=0.1832, loss_test=1.9968, acc_test=0.0398
# poison_percent 10 round 37: loss_train=2.0976, acc_train=0.1689, loss_test=1.9926, acc_test=0.0380
# poison_percent 10 round 38: loss_train=2.0962, acc_train=0.1832, loss_test=1.9880, acc_test=0.0404
# poison_percent 10 round 39: loss_train=2.0831, acc_train=0.1767, loss_test=1.9837, acc_test=0.0411
# poison_percent 10 round 40: loss_train=2.0952, acc_train=0.1680, loss_test=1.9797, acc_test=0.0429
# poison_percent 10 round 41: loss_train=2.0943, acc_train=0.1714, loss_test=1.9753, acc_test=0.0404
# poison_percent 10 round 42: loss_train=2.0810, acc_train=0.1776, loss_test=1.9705, acc_test=0.0423
# poison_percent 10 round 43: loss_train=2.0826, acc_train=0.1748, loss_test=1.9661, acc_test=0.0417
# poison_percent 10 round 44: loss_train=2.0889, acc_train=0.1745, loss_test=1.9620, acc_test=0.0411
# poison_percent 10 round 45: loss_train=2.0881, acc_train=0.1717, loss_test=1.9576, acc_test=0.0411
# poison_percent 10 round 46: loss_train=2.0740, acc_train=0.1717, loss_test=1.9531, acc_test=0.0429
# poison_percent 10 round 47: loss_train=2.0787, acc_train=0.1699, loss_test=1.9489, acc_test=0.0435
# poison_percent 10 round 48: loss_train=2.0811, acc_train=0.1863, loss_test=1.9448, acc_test=0.0417
# poison_percent 10 round 49: loss_train=2.0844, acc_train=0.1788, loss_test=1.9407, acc_test=0.0435
# poison_percent 10 round 50: loss_train=2.0702, acc_train=0.1674, loss_test=1.9365, acc_test=0.0435
# poison_percent 10 round 51: loss_train=2.0783, acc_train=0.1745, loss_test=1.9322, acc_test=0.0429
# poison_percent 10 round 52: loss_train=2.0807, acc_train=0.1714, loss_test=1.9287, acc_test=0.0441
# poison_percent 10 round 53: loss_train=2.0692, acc_train=0.1708, loss_test=1.9248, acc_test=0.0447
# poison_percent 10 round 54: loss_train=2.0642, acc_train=0.1918, loss_test=1.9211, acc_test=0.0447
# poison_percent 10 round 55: loss_train=2.0848, acc_train=0.1733, loss_test=1.9177, acc_test=0.0447
# poison_percent 10 round 56: loss_train=2.0640, acc_train=0.1832, loss_test=1.9132, acc_test=0.0447
# poison_percent 10 round 57: loss_train=2.0716, acc_train=0.1795, loss_test=1.9097, acc_test=0.0447
# poison_percent 10 round 58: loss_train=2.0678, acc_train=0.1779, loss_test=1.9063, acc_test=0.0447
# poison_percent 10 round 59: loss_train=2.0674, acc_train=0.1739, loss_test=1.9025, acc_test=0.0441
# poison_percent 10 round 60: loss_train=2.0543, acc_train=0.1835, loss_test=1.8985, acc_test=0.0453
# poison_percent 10 round 61: loss_train=2.0645, acc_train=0.1603, loss_test=1.8947, acc_test=0.0441
# poison_percent 10 round 62: loss_train=2.0827, acc_train=0.1764, loss_test=1.8908, acc_test=0.0447
# poison_percent 10 round 63: loss_train=2.0633, acc_train=0.1649, loss_test=1.8873, acc_test=0.0441
# poison_percent 10 round 64: loss_train=2.0640, acc_train=0.1699, loss_test=1.8842, acc_test=0.0447
# poison_percent 10 round 65: loss_train=2.0542, acc_train=0.1912, loss_test=1.8810, acc_test=0.0447
# poison_percent 10 round 66: loss_train=2.0592, acc_train=0.1751, loss_test=1.8775, acc_test=0.0441
# poison_percent 10 round 67: loss_train=2.0574, acc_train=0.1807, loss_test=1.8745, acc_test=0.0447
# poison_percent 10 round 68: loss_train=2.0496, acc_train=0.1825, loss_test=1.8715, acc_test=0.0447
# poison_percent 10 round 69: loss_train=2.0529, acc_train=0.1767, loss_test=1.8682, acc_test=0.0453
# poison_percent 10 round 70: loss_train=2.0522, acc_train=0.1742, loss_test=1.8649, acc_test=0.0460
# poison_percent 10 round 71: loss_train=2.0697, acc_train=0.1658, loss_test=1.8613, acc_test=0.0460
# poison_percent 10 round 72: loss_train=2.0435, acc_train=0.1825, loss_test=1.8579, acc_test=0.0460
# poison_percent 10 round 73: loss_train=2.0437, acc_train=0.1838, loss_test=1.8551, acc_test=0.0453
# poison_percent 10 round 74: loss_train=2.0298, acc_train=0.1791, loss_test=1.8522, acc_test=0.0472
# poison_percent 10 round 75: loss_train=2.0580, acc_train=0.1723, loss_test=1.8490, acc_test=0.0453
# poison_percent 10 round 76: loss_train=2.0474, acc_train=0.1739, loss_test=1.8457, acc_test=0.0478
# poison_percent 10 round 77: loss_train=2.0574, acc_train=0.1761, loss_test=1.8429, acc_test=0.0460
# poison_percent 10 round 78: loss_train=2.0652, acc_train=0.1819, loss_test=1.8399, acc_test=0.0478
# poison_percent 10 round 79: loss_train=2.0415, acc_train=0.1683, loss_test=1.8364, acc_test=0.0484
# poison_percent 10 round 80: loss_train=2.0497, acc_train=0.1742, loss_test=1.8338, acc_test=0.0490
# poison_percent 10 round 81: loss_train=2.0348, acc_train=0.1795, loss_test=1.8307, acc_test=0.0490
# poison_percent 10 round 82: loss_train=2.0454, acc_train=0.1761, loss_test=1.8282, acc_test=0.0484
# poison_percent 10 round 83: loss_train=2.0445, acc_train=0.1692, loss_test=1.8255, acc_test=0.0490
# poison_percent 10 round 84: loss_train=2.0358, acc_train=0.1801, loss_test=1.8225, acc_test=0.0490
# poison_percent 10 round 85: loss_train=2.0679, acc_train=0.1748, loss_test=1.8203, acc_test=0.0490
# poison_percent 10 round 86: loss_train=2.0459, acc_train=0.1757, loss_test=1.8188, acc_test=0.0490
# poison_percent 10 round 87: loss_train=2.0329, acc_train=0.1754, loss_test=1.8158, acc_test=0.0490
# poison_percent 10 round 88: loss_train=2.0471, acc_train=0.1798, loss_test=1.8131, acc_test=0.0496
# poison_percent 10 round 89: loss_train=2.0493, acc_train=0.1773, loss_test=1.8100, acc_test=0.0496
# poison_percent 10 round 90: loss_train=2.0486, acc_train=0.1819, loss_test=1.8072, acc_test=0.0502
# poison_percent 10 round 91: loss_train=2.0518, acc_train=0.1742, loss_test=1.8048, acc_test=0.0502
# poison_percent 10 round 92: loss_train=2.0426, acc_train=0.1689, loss_test=1.8024, acc_test=0.0502
# poison_percent 10 round 93: loss_train=2.0197, acc_train=0.1801, loss_test=1.7998, acc_test=0.0502
# poison_percent 10 round 94: loss_train=2.0401, acc_train=0.1841, loss_test=1.7970, acc_test=0.0502
# poison_percent 10 round 95: loss_train=2.0504, acc_train=0.1745, loss_test=1.7949, acc_test=0.0515
# poison_percent 10 round 96: loss_train=2.0416, acc_train=0.1723, loss_test=1.7927, acc_test=0.0502
# poison_percent 10 round 97: loss_train=2.0425, acc_train=0.1847, loss_test=1.7906, acc_test=0.0502
# poison_percent 10 round 98: loss_train=2.0354, acc_train=0.1770, loss_test=1.7881, acc_test=0.0502
# poison_percent 10 round 99: loss_train=2.0395, acc_train=0.1807, loss_test=1.7853, acc_test=0.0509
# Training log saved to ./results\FL_ModelN1L3_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=2.1017, acc_train=0.1677, loss_test=1.7828, acc_test=0.0662
# poison_percent 20 round 1: loss_train=2.1024, acc_train=0.1719, loss_test=1.7797, acc_test=0.0662
# poison_percent 20 round 2: loss_train=2.1087, acc_train=0.1555, loss_test=1.7764, acc_test=0.0680
# poison_percent 20 round 3: loss_train=2.0958, acc_train=0.1616, loss_test=1.7734, acc_test=0.0699
# poison_percent 20 round 4: loss_train=2.1061, acc_train=0.1602, loss_test=1.7699, acc_test=0.0705
# poison_percent 20 round 5: loss_train=2.0982, acc_train=0.1641, loss_test=1.7667, acc_test=0.0729
# poison_percent 20 round 6: loss_train=2.0961, acc_train=0.1622, loss_test=1.7634, acc_test=0.0760
# poison_percent 20 round 7: loss_train=2.0954, acc_train=0.1714, loss_test=1.7603, acc_test=0.0729
# poison_percent 20 round 8: loss_train=2.0865, acc_train=0.1638, loss_test=1.7578, acc_test=0.0766
# poison_percent 20 round 9: loss_train=2.0949, acc_train=0.1602, loss_test=1.7550, acc_test=0.0766
# poison_percent 20 round 10: loss_train=2.0785, acc_train=0.1702, loss_test=1.7517, acc_test=0.0778
# poison_percent 20 round 11: loss_train=2.0993, acc_train=0.1739, loss_test=1.7487, acc_test=0.0772
# poison_percent 20 round 12: loss_train=2.1055, acc_train=0.1689, loss_test=1.7466, acc_test=0.0790
# poison_percent 20 round 13: loss_train=2.0930, acc_train=0.1633, loss_test=1.7440, acc_test=0.0778
# poison_percent 20 round 14: loss_train=2.0724, acc_train=0.1697, loss_test=1.7417, acc_test=0.0797
# poison_percent 20 round 15: loss_train=2.1005, acc_train=0.1705, loss_test=1.7388, acc_test=0.0815
# poison_percent 20 round 16: loss_train=2.0816, acc_train=0.1669, loss_test=1.7360, acc_test=0.0827
# poison_percent 20 round 17: loss_train=2.1102, acc_train=0.1661, loss_test=1.7332, acc_test=0.0839
# poison_percent 20 round 18: loss_train=2.0868, acc_train=0.1638, loss_test=1.7303, acc_test=0.0858
# poison_percent 20 round 19: loss_train=2.1148, acc_train=0.1714, loss_test=1.7282, acc_test=0.0882
# poison_percent 20 round 20: loss_train=2.0861, acc_train=0.2629, loss_test=1.7261, acc_test=0.0901
# poison_percent 20 round 21: loss_train=2.0942, acc_train=0.2548, loss_test=1.7234, acc_test=0.0913
# poison_percent 20 round 22: loss_train=2.0851, acc_train=0.2568, loss_test=1.7215, acc_test=0.0925
# poison_percent 20 round 23: loss_train=2.0865, acc_train=0.2450, loss_test=1.7198, acc_test=0.0944
# poison_percent 20 round 24: loss_train=2.0820, acc_train=0.2498, loss_test=1.7174, acc_test=0.5625
# poison_percent 20 round 25: loss_train=2.0815, acc_train=0.2557, loss_test=1.7151, acc_test=0.5625
# poison_percent 20 round 26: loss_train=2.0738, acc_train=0.2649, loss_test=1.7129, acc_test=0.5619
# poison_percent 20 round 27: loss_train=2.0873, acc_train=0.2671, loss_test=1.7106, acc_test=0.5637
# poison_percent 20 round 28: loss_train=2.0894, acc_train=0.2755, loss_test=1.7088, acc_test=0.5643
# poison_percent 20 round 29: loss_train=2.0878, acc_train=0.2596, loss_test=1.7065, acc_test=0.5650
# poison_percent 20 round 30: loss_train=2.0765, acc_train=0.2649, loss_test=1.7042, acc_test=0.5650
# poison_percent 20 round 31: loss_train=2.0741, acc_train=0.2635, loss_test=1.7018, acc_test=0.5643
# poison_percent 20 round 32: loss_train=2.0783, acc_train=0.2649, loss_test=1.6998, acc_test=0.5668
# poison_percent 20 round 33: loss_train=2.0972, acc_train=0.2635, loss_test=1.6975, acc_test=0.5668
# poison_percent 20 round 34: loss_train=2.0814, acc_train=0.2732, loss_test=1.6959, acc_test=0.5705
# poison_percent 20 round 35: loss_train=2.0779, acc_train=0.2679, loss_test=1.6944, acc_test=0.5711
# poison_percent 20 round 36: loss_train=2.0708, acc_train=0.2785, loss_test=1.6924, acc_test=0.5711
# poison_percent 20 round 37: loss_train=2.0770, acc_train=0.2601, loss_test=1.6907, acc_test=0.5680
# poison_percent 20 round 38: loss_train=2.0615, acc_train=0.2908, loss_test=1.6895, acc_test=0.5686
# poison_percent 20 round 39: loss_train=2.0724, acc_train=0.2755, loss_test=1.6880, acc_test=0.5729
# poison_percent 20 round 40: loss_train=2.0667, acc_train=0.2816, loss_test=1.6860, acc_test=0.5723
# poison_percent 20 round 41: loss_train=2.0914, acc_train=0.2724, loss_test=1.6843, acc_test=0.5723
# poison_percent 20 round 42: loss_train=2.0891, acc_train=0.2696, loss_test=1.6825, acc_test=0.5741
# poison_percent 20 round 43: loss_train=2.1012, acc_train=0.2685, loss_test=1.6808, acc_test=0.5760
# poison_percent 20 round 44: loss_train=2.0784, acc_train=0.2674, loss_test=1.6786, acc_test=0.5741
# poison_percent 20 round 45: loss_train=2.0780, acc_train=0.2668, loss_test=1.6773, acc_test=0.5760
# poison_percent 20 round 46: loss_train=2.0633, acc_train=0.2766, loss_test=1.6755, acc_test=0.5790
# poison_percent 20 round 47: loss_train=2.0611, acc_train=0.2685, loss_test=1.6741, acc_test=0.5784
# poison_percent 20 round 48: loss_train=2.0745, acc_train=0.2682, loss_test=1.6727, acc_test=0.5784
# poison_percent 20 round 49: loss_train=2.0577, acc_train=0.2769, loss_test=1.6712, acc_test=0.5778
# poison_percent 20 round 50: loss_train=2.0646, acc_train=0.2660, loss_test=1.6703, acc_test=0.5797
# poison_percent 20 round 51: loss_train=2.0779, acc_train=0.2696, loss_test=1.6690, acc_test=0.5797
# poison_percent 20 round 52: loss_train=2.0631, acc_train=0.2830, loss_test=1.6679, acc_test=0.5803
# poison_percent 20 round 53: loss_train=2.0701, acc_train=0.2724, loss_test=1.6664, acc_test=0.5784
# poison_percent 20 round 54: loss_train=2.0609, acc_train=0.2746, loss_test=1.6650, acc_test=0.5809
# poison_percent 20 round 55: loss_train=2.0783, acc_train=0.2679, loss_test=1.6633, acc_test=0.5809
# poison_percent 20 round 56: loss_train=2.0710, acc_train=0.2774, loss_test=1.6618, acc_test=0.5809
# poison_percent 20 round 57: loss_train=2.0787, acc_train=0.2696, loss_test=1.6604, acc_test=0.5815
# poison_percent 20 round 58: loss_train=2.0506, acc_train=0.2693, loss_test=1.6588, acc_test=0.5797
# poison_percent 20 round 59: loss_train=2.0921, acc_train=0.2674, loss_test=1.6569, acc_test=0.5797
# poison_percent 20 round 60: loss_train=2.0699, acc_train=0.2760, loss_test=1.6556, acc_test=0.5815
# poison_percent 20 round 61: loss_train=2.0776, acc_train=0.2785, loss_test=1.6547, acc_test=0.5803
# poison_percent 20 round 62: loss_train=2.0627, acc_train=0.2760, loss_test=1.6541, acc_test=0.5797
# poison_percent 20 round 63: loss_train=2.0714, acc_train=0.2794, loss_test=1.6526, acc_test=0.5797
# poison_percent 20 round 64: loss_train=2.0733, acc_train=0.2702, loss_test=1.6515, acc_test=0.5797
# poison_percent 20 round 65: loss_train=2.0718, acc_train=0.2671, loss_test=1.6505, acc_test=0.5797
# poison_percent 20 round 66: loss_train=2.0792, acc_train=0.2741, loss_test=1.6492, acc_test=0.5797
# poison_percent 20 round 67: loss_train=2.0829, acc_train=0.2774, loss_test=1.6477, acc_test=0.5797
# poison_percent 20 round 68: loss_train=2.0845, acc_train=0.2663, loss_test=1.6458, acc_test=0.5803
# poison_percent 20 round 69: loss_train=2.0589, acc_train=0.2788, loss_test=1.6450, acc_test=0.5797
# poison_percent 20 round 70: loss_train=2.0783, acc_train=0.2637, loss_test=1.6440, acc_test=0.5803
# poison_percent 20 round 71: loss_train=2.0736, acc_train=0.2649, loss_test=1.6429, acc_test=0.5803
# poison_percent 20 round 72: loss_train=2.0499, acc_train=0.2688, loss_test=1.6418, acc_test=0.5827
# poison_percent 20 round 73: loss_train=2.0758, acc_train=0.2752, loss_test=1.6407, acc_test=0.5821
# poison_percent 20 round 74: loss_train=2.0652, acc_train=0.2716, loss_test=1.6396, acc_test=0.5846
# poison_percent 20 round 75: loss_train=2.0704, acc_train=0.2685, loss_test=1.6385, acc_test=0.5876
# poison_percent 20 round 76: loss_train=2.0419, acc_train=0.2864, loss_test=1.6373, acc_test=0.5864
# poison_percent 20 round 77: loss_train=2.0631, acc_train=0.2716, loss_test=1.6366, acc_test=0.5858
# poison_percent 20 round 78: loss_train=2.0679, acc_train=0.2769, loss_test=1.6355, acc_test=0.5895
# poison_percent 20 round 79: loss_train=2.0879, acc_train=0.2607, loss_test=1.6343, acc_test=0.5888
# poison_percent 20 round 80: loss_train=2.0658, acc_train=0.2688, loss_test=1.6339, acc_test=0.5901
# poison_percent 20 round 81: loss_train=2.0715, acc_train=0.2668, loss_test=1.6327, acc_test=0.5888
# poison_percent 20 round 82: loss_train=2.0526, acc_train=0.2749, loss_test=1.6319, acc_test=0.5888
# poison_percent 20 round 83: loss_train=2.0566, acc_train=0.2805, loss_test=1.6314, acc_test=0.5895
# poison_percent 20 round 84: loss_train=2.0929, acc_train=0.2543, loss_test=1.6303, acc_test=0.5870
# poison_percent 20 round 85: loss_train=2.0627, acc_train=0.2702, loss_test=1.6289, acc_test=0.5882
# poison_percent 20 round 86: loss_train=2.0824, acc_train=0.2643, loss_test=1.6282, acc_test=0.5876
# poison_percent 20 round 87: loss_train=2.0828, acc_train=0.2576, loss_test=1.6273, acc_test=0.5864
# poison_percent 20 round 88: loss_train=2.0598, acc_train=0.2716, loss_test=1.6271, acc_test=0.5876
# poison_percent 20 round 89: loss_train=2.0583, acc_train=0.2637, loss_test=1.6263, acc_test=0.5882
# poison_percent 20 round 90: loss_train=2.0693, acc_train=0.2766, loss_test=1.6249, acc_test=0.5895
# poison_percent 20 round 91: loss_train=2.0596, acc_train=0.2766, loss_test=1.6243, acc_test=0.5901
# poison_percent 20 round 92: loss_train=2.0435, acc_train=0.2732, loss_test=1.6238, acc_test=0.5913
# poison_percent 20 round 93: loss_train=2.0722, acc_train=0.2730, loss_test=1.6224, acc_test=0.5919
# poison_percent 20 round 94: loss_train=2.0519, acc_train=0.2752, loss_test=1.6215, acc_test=0.5919
# poison_percent 20 round 95: loss_train=2.0715, acc_train=0.2671, loss_test=1.6199, acc_test=0.5925
# poison_percent 20 round 96: loss_train=2.0671, acc_train=0.2668, loss_test=1.6188, acc_test=0.5925
# poison_percent 20 round 97: loss_train=2.0806, acc_train=0.2755, loss_test=1.6180, acc_test=0.5938
# poison_percent 20 round 98: loss_train=2.0485, acc_train=0.2707, loss_test=1.6175, acc_test=0.5938
# poison_percent 20 round 99: loss_train=2.0560, acc_train=0.2833, loss_test=1.6169, acc_test=0.5944
# Training log saved to ./results\FL_ModelN1L3_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=2.1352, acc_train=0.3135, loss_test=1.6178, acc_test=0.6109
# poison_percent 30 round 1: loss_train=2.1545, acc_train=0.3085, loss_test=1.6169, acc_test=0.6195
# poison_percent 30 round 2: loss_train=2.1342, acc_train=0.3085, loss_test=1.6157, acc_test=0.6268
# poison_percent 30 round 3: loss_train=2.1067, acc_train=0.3174, loss_test=1.6142, acc_test=0.6293
# poison_percent 30 round 4: loss_train=2.1153, acc_train=0.3260, loss_test=1.6129, acc_test=0.6342
# poison_percent 30 round 5: loss_train=2.1206, acc_train=0.3169, loss_test=1.6109, acc_test=0.6366
# poison_percent 30 round 6: loss_train=2.1449, acc_train=0.3036, loss_test=1.6088, acc_test=0.6373
# poison_percent 30 round 7: loss_train=2.1137, acc_train=0.3243, loss_test=1.6074, acc_test=0.6379
# poison_percent 30 round 8: loss_train=2.1283, acc_train=0.3075, loss_test=1.6057, acc_test=0.6373
# poison_percent 30 round 9: loss_train=2.1158, acc_train=0.3218, loss_test=1.6037, acc_test=0.6385
# poison_percent 30 round 10: loss_train=2.1397, acc_train=0.3105, loss_test=1.6021, acc_test=0.6397
# poison_percent 30 round 11: loss_train=2.1076, acc_train=0.3191, loss_test=1.6006, acc_test=0.6391
# poison_percent 30 round 12: loss_train=2.1035, acc_train=0.3181, loss_test=1.5992, acc_test=0.6391
# poison_percent 30 round 13: loss_train=2.1027, acc_train=0.3199, loss_test=1.5968, acc_test=0.6397
# poison_percent 30 round 14: loss_train=2.1385, acc_train=0.3149, loss_test=1.5949, acc_test=0.6385
# poison_percent 30 round 15: loss_train=2.1116, acc_train=0.3233, loss_test=1.5934, acc_test=0.6403
# poison_percent 30 round 16: loss_train=2.1256, acc_train=0.3127, loss_test=1.5925, acc_test=0.6409
# poison_percent 30 round 17: loss_train=2.1240, acc_train=0.3120, loss_test=1.5910, acc_test=0.6428
# poison_percent 30 round 18: loss_train=2.1281, acc_train=0.3132, loss_test=1.5894, acc_test=0.6446
# poison_percent 30 round 19: loss_train=2.0962, acc_train=0.3236, loss_test=1.5878, acc_test=0.6464
# poison_percent 30 round 20: loss_train=2.1219, acc_train=0.3174, loss_test=1.5858, acc_test=0.6458
# poison_percent 30 round 21: loss_train=2.1134, acc_train=0.3201, loss_test=1.5842, acc_test=0.6446
# poison_percent 30 round 22: loss_train=2.0953, acc_train=0.3255, loss_test=1.5828, acc_test=0.6464
# poison_percent 30 round 23: loss_train=2.1056, acc_train=0.3277, loss_test=1.5823, acc_test=0.6477
# poison_percent 30 round 24: loss_train=2.1177, acc_train=0.3098, loss_test=1.5801, acc_test=0.6452
# poison_percent 30 round 25: loss_train=2.1087, acc_train=0.3297, loss_test=1.5785, acc_test=0.6477
# poison_percent 30 round 26: loss_train=2.1166, acc_train=0.3184, loss_test=1.5772, acc_test=0.6477
# poison_percent 30 round 27: loss_train=2.1085, acc_train=0.3172, loss_test=1.5760, acc_test=0.6483
# poison_percent 30 round 28: loss_train=2.1038, acc_train=0.3174, loss_test=1.5743, acc_test=0.6483
# poison_percent 30 round 29: loss_train=2.1167, acc_train=0.3103, loss_test=1.5734, acc_test=0.6495
# poison_percent 30 round 30: loss_train=2.1172, acc_train=0.3191, loss_test=1.5722, acc_test=0.6501
# poison_percent 30 round 31: loss_train=2.1024, acc_train=0.3196, loss_test=1.5711, acc_test=0.6513
# poison_percent 30 round 32: loss_train=2.1096, acc_train=0.3105, loss_test=1.5695, acc_test=0.6495
# poison_percent 30 round 33: loss_train=2.1186, acc_train=0.3105, loss_test=1.5681, acc_test=0.6507
# poison_percent 30 round 34: loss_train=2.1125, acc_train=0.3125, loss_test=1.5666, acc_test=0.6526
# poison_percent 30 round 35: loss_train=2.0984, acc_train=0.3273, loss_test=1.5652, acc_test=0.6544
# poison_percent 30 round 36: loss_train=2.1110, acc_train=0.3174, loss_test=1.5644, acc_test=0.6544
# poison_percent 30 round 37: loss_train=2.1023, acc_train=0.3149, loss_test=1.5632, acc_test=0.6550
# poison_percent 30 round 38: loss_train=2.1010, acc_train=0.3149, loss_test=1.5626, acc_test=0.6581
# poison_percent 30 round 39: loss_train=2.1115, acc_train=0.3135, loss_test=1.5620, acc_test=0.6618
# poison_percent 30 round 40: loss_train=2.0845, acc_train=0.3218, loss_test=1.5602, acc_test=0.6581
# poison_percent 30 round 41: loss_train=2.1394, acc_train=0.3029, loss_test=1.5588, acc_test=0.6587
# poison_percent 30 round 42: loss_train=2.1102, acc_train=0.3186, loss_test=1.5583, acc_test=0.6648
# poison_percent 30 round 43: loss_train=2.1055, acc_train=0.3181, loss_test=1.5577, acc_test=0.6654
# poison_percent 30 round 44: loss_train=2.0937, acc_train=0.3263, loss_test=1.5559, acc_test=0.6642
# poison_percent 30 round 45: loss_train=2.0964, acc_train=0.3181, loss_test=1.5549, acc_test=0.6661
# poison_percent 30 round 46: loss_train=2.1101, acc_train=0.3204, loss_test=1.5546, acc_test=0.6673
# poison_percent 30 round 47: loss_train=2.0730, acc_train=0.3339, loss_test=1.5538, acc_test=0.6673
# poison_percent 30 round 48: loss_train=2.0918, acc_train=0.3322, loss_test=1.5527, acc_test=0.6673
# poison_percent 30 round 49: loss_train=2.0881, acc_train=0.3218, loss_test=1.5515, acc_test=0.6673
# poison_percent 30 round 50: loss_train=2.1032, acc_train=0.3189, loss_test=1.5504, acc_test=0.6667
# poison_percent 30 round 51: loss_train=2.1217, acc_train=0.3122, loss_test=1.5503, acc_test=0.6667
# poison_percent 30 round 52: loss_train=2.0996, acc_train=0.3164, loss_test=1.5490, acc_test=0.6654
# poison_percent 30 round 53: loss_train=2.0992, acc_train=0.3164, loss_test=1.5484, acc_test=0.6636
# poison_percent 30 round 54: loss_train=2.0732, acc_train=0.3245, loss_test=1.5483, acc_test=0.6624
# poison_percent 30 round 55: loss_train=2.1187, acc_train=0.3085, loss_test=1.5466, acc_test=0.6636
# poison_percent 30 round 56: loss_train=2.1053, acc_train=0.3144, loss_test=1.5454, acc_test=0.6605
# poison_percent 30 round 57: loss_train=2.1014, acc_train=0.3181, loss_test=1.5445, acc_test=0.6636
# poison_percent 30 round 58: loss_train=2.1022, acc_train=0.3208, loss_test=1.5440, acc_test=0.6661
# poison_percent 30 round 59: loss_train=2.0934, acc_train=0.3243, loss_test=1.5433, acc_test=0.6661
# poison_percent 30 round 60: loss_train=2.0831, acc_train=0.3213, loss_test=1.5422, acc_test=0.6661
# poison_percent 30 round 61: loss_train=2.0630, acc_train=0.3277, loss_test=1.5418, acc_test=0.6667
# poison_percent 30 round 62: loss_train=2.1014, acc_train=0.3206, loss_test=1.5410, acc_test=0.6673
# poison_percent 30 round 63: loss_train=2.1214, acc_train=0.3103, loss_test=1.5401, acc_test=0.6673
# poison_percent 30 round 64: loss_train=2.0906, acc_train=0.3189, loss_test=1.5396, acc_test=0.6673
# poison_percent 30 round 65: loss_train=2.0900, acc_train=0.3221, loss_test=1.5391, acc_test=0.6673
# poison_percent 30 round 66: loss_train=2.1060, acc_train=0.3164, loss_test=1.5388, acc_test=0.6673
# poison_percent 30 round 67: loss_train=2.0906, acc_train=0.3221, loss_test=1.5386, acc_test=0.6685
# poison_percent 30 round 68: loss_train=2.0712, acc_train=0.3300, loss_test=1.5380, acc_test=0.6673
# poison_percent 30 round 69: loss_train=2.0768, acc_train=0.3332, loss_test=1.5372, acc_test=0.6667
# poison_percent 30 round 70: loss_train=2.0964, acc_train=0.3122, loss_test=1.5365, acc_test=0.6673
# poison_percent 30 round 71: loss_train=2.0744, acc_train=0.3339, loss_test=1.5355, acc_test=0.6679
# poison_percent 30 round 72: loss_train=2.1004, acc_train=0.3088, loss_test=1.5350, acc_test=0.6679
# poison_percent 30 round 73: loss_train=2.0996, acc_train=0.3149, loss_test=1.5338, acc_test=0.6648
# poison_percent 30 round 74: loss_train=2.0968, acc_train=0.3233, loss_test=1.5329, acc_test=0.6612
# poison_percent 30 round 75: loss_train=2.0989, acc_train=0.3174, loss_test=1.5328, acc_test=0.6648
# poison_percent 30 round 76: loss_train=2.0949, acc_train=0.3191, loss_test=1.5322, acc_test=0.6654
# poison_percent 30 round 77: loss_train=2.0853, acc_train=0.3270, loss_test=1.5315, acc_test=0.6661
# poison_percent 30 round 78: loss_train=2.1043, acc_train=0.3115, loss_test=1.5308, acc_test=0.6667
# poison_percent 30 round 79: loss_train=2.0935, acc_train=0.3300, loss_test=1.5301, acc_test=0.6673
# poison_percent 30 round 80: loss_train=2.0881, acc_train=0.3297, loss_test=1.5291, acc_test=0.6685
# poison_percent 30 round 81: loss_train=2.0746, acc_train=0.3238, loss_test=1.5279, acc_test=0.6679
# poison_percent 30 round 82: loss_train=2.0762, acc_train=0.3282, loss_test=1.5270, acc_test=0.6679
# poison_percent 30 round 83: loss_train=2.0836, acc_train=0.3312, loss_test=1.5262, acc_test=0.6697
# poison_percent 30 round 84: loss_train=2.0977, acc_train=0.3174, loss_test=1.5261, acc_test=0.6703
# poison_percent 30 round 85: loss_train=2.0951, acc_train=0.3226, loss_test=1.5256, acc_test=0.6697
# poison_percent 30 round 86: loss_train=2.1042, acc_train=0.3191, loss_test=1.5247, acc_test=0.6685
# poison_percent 30 round 87: loss_train=2.0822, acc_train=0.3245, loss_test=1.5245, acc_test=0.6697
# poison_percent 30 round 88: loss_train=2.1048, acc_train=0.3186, loss_test=1.5238, acc_test=0.6691
# poison_percent 30 round 89: loss_train=2.0924, acc_train=0.3105, loss_test=1.5232, acc_test=0.6703
# poison_percent 30 round 90: loss_train=2.0888, acc_train=0.3159, loss_test=1.5229, acc_test=0.6697
# poison_percent 30 round 91: loss_train=2.0668, acc_train=0.3275, loss_test=1.5224, acc_test=0.6685
# poison_percent 30 round 92: loss_train=2.0749, acc_train=0.3327, loss_test=1.5219, acc_test=0.6728
# poison_percent 30 round 93: loss_train=2.0849, acc_train=0.3250, loss_test=1.5220, acc_test=0.6691
# poison_percent 30 round 94: loss_train=2.1004, acc_train=0.3157, loss_test=1.5221, acc_test=0.6728
# poison_percent 30 round 95: loss_train=2.1054, acc_train=0.3004, loss_test=1.5214, acc_test=0.6691
# poison_percent 30 round 96: loss_train=2.0768, acc_train=0.3231, loss_test=1.5217, acc_test=0.6697
# poison_percent 30 round 97: loss_train=2.0895, acc_train=0.3292, loss_test=1.5205, acc_test=0.6697
# poison_percent 30 round 98: loss_train=2.0833, acc_train=0.3310, loss_test=1.5205, acc_test=0.6734
# poison_percent 30 round 99: loss_train=2.0782, acc_train=0.3204, loss_test=1.5195, acc_test=0.6740
# Training log saved to ./results\FL_ModelN1L3_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=2.1537, acc_train=0.3580, loss_test=1.5224, acc_test=0.6979
# poison_percent 40 round 1: loss_train=2.1368, acc_train=0.3625, loss_test=1.5243, acc_test=0.7120
# poison_percent 40 round 2: loss_train=2.1358, acc_train=0.3648, loss_test=1.5251, acc_test=0.7249
# poison_percent 40 round 3: loss_train=2.1417, acc_train=0.3657, loss_test=1.5247, acc_test=0.7310
# poison_percent 40 round 4: loss_train=2.1047, acc_train=0.3712, loss_test=1.5245, acc_test=0.7347
# poison_percent 40 round 5: loss_train=2.1133, acc_train=0.3731, loss_test=1.5247, acc_test=0.7359
# poison_percent 40 round 6: loss_train=2.0986, acc_train=0.3772, loss_test=1.5237, acc_test=0.7408
# poison_percent 40 round 7: loss_train=2.1051, acc_train=0.3691, loss_test=1.5227, acc_test=0.7420
# poison_percent 40 round 8: loss_train=2.1148, acc_train=0.3637, loss_test=1.5215, acc_test=0.7426
# poison_percent 40 round 9: loss_train=2.0882, acc_train=0.3768, loss_test=1.5200, acc_test=0.7463
# poison_percent 40 round 10: loss_train=2.0847, acc_train=0.3763, loss_test=1.5185, acc_test=0.7482
# poison_percent 40 round 11: loss_train=2.0951, acc_train=0.3691, loss_test=1.5173, acc_test=0.7500
# poison_percent 40 round 12: loss_train=2.0879, acc_train=0.3770, loss_test=1.5154, acc_test=0.7488
# poison_percent 40 round 13: loss_train=2.1146, acc_train=0.3646, loss_test=1.5142, acc_test=0.7488
# poison_percent 40 round 14: loss_train=2.0836, acc_train=0.3676, loss_test=1.5121, acc_test=0.7482
# poison_percent 40 round 15: loss_train=2.1047, acc_train=0.3684, loss_test=1.5097, acc_test=0.7463
# poison_percent 40 round 16: loss_train=2.0904, acc_train=0.3731, loss_test=1.5082, acc_test=0.7475
# poison_percent 40 round 17: loss_train=2.0925, acc_train=0.3680, loss_test=1.5059, acc_test=0.7457
# poison_percent 40 round 18: loss_train=2.0699, acc_train=0.3810, loss_test=1.5055, acc_test=0.7475
# poison_percent 40 round 19: loss_train=2.1067, acc_train=0.3716, loss_test=1.5032, acc_test=0.7463
# poison_percent 40 round 20: loss_train=2.1053, acc_train=0.3676, loss_test=1.5013, acc_test=0.7463
# poison_percent 40 round 21: loss_train=2.0868, acc_train=0.3736, loss_test=1.4994, acc_test=0.7463
# poison_percent 40 round 22: loss_train=2.1130, acc_train=0.3590, loss_test=1.4980, acc_test=0.7463
# poison_percent 40 round 23: loss_train=2.0955, acc_train=0.3680, loss_test=1.4972, acc_test=0.7463
# poison_percent 40 round 24: loss_train=2.0870, acc_train=0.3761, loss_test=1.4949, acc_test=0.7457
# poison_percent 40 round 25: loss_train=2.0925, acc_train=0.3680, loss_test=1.4932, acc_test=0.7463
# poison_percent 40 round 26: loss_train=2.0929, acc_train=0.3714, loss_test=1.4919, acc_test=0.7463
# poison_percent 40 round 27: loss_train=2.0800, acc_train=0.3729, loss_test=1.4899, acc_test=0.7463
# poison_percent 40 round 28: loss_train=2.0913, acc_train=0.3659, loss_test=1.4885, acc_test=0.7482
# poison_percent 40 round 29: loss_train=2.0768, acc_train=0.3680, loss_test=1.4868, acc_test=0.7500
# poison_percent 40 round 30: loss_train=2.0831, acc_train=0.3793, loss_test=1.4853, acc_test=0.7512
# poison_percent 40 round 31: loss_train=2.0877, acc_train=0.3697, loss_test=1.4833, acc_test=0.7512
# poison_percent 40 round 32: loss_train=2.0810, acc_train=0.3697, loss_test=1.4820, acc_test=0.7518
# poison_percent 40 round 33: loss_train=2.0881, acc_train=0.3718, loss_test=1.4803, acc_test=0.7518
# poison_percent 40 round 34: loss_train=2.0717, acc_train=0.3723, loss_test=1.4788, acc_test=0.7512
# poison_percent 40 round 35: loss_train=2.0878, acc_train=0.3697, loss_test=1.4781, acc_test=0.7525
# poison_percent 40 round 36: loss_train=2.0859, acc_train=0.3780, loss_test=1.4767, acc_test=0.7543
# poison_percent 40 round 37: loss_train=2.0749, acc_train=0.3729, loss_test=1.4750, acc_test=0.7549
# poison_percent 40 round 38: loss_train=2.0618, acc_train=0.3757, loss_test=1.4733, acc_test=0.7549
# poison_percent 40 round 39: loss_train=2.0451, acc_train=0.3834, loss_test=1.4723, acc_test=0.7561
# poison_percent 40 round 40: loss_train=2.0716, acc_train=0.3789, loss_test=1.4710, acc_test=0.7574
# poison_percent 40 round 41: loss_train=2.0585, acc_train=0.3742, loss_test=1.4701, acc_test=0.7561
# poison_percent 40 round 42: loss_train=2.0586, acc_train=0.3866, loss_test=1.4684, acc_test=0.7586
# poison_percent 40 round 43: loss_train=2.0624, acc_train=0.3840, loss_test=1.4672, acc_test=0.7580
# poison_percent 40 round 44: loss_train=2.0513, acc_train=0.3778, loss_test=1.4661, acc_test=0.7561
# poison_percent 40 round 45: loss_train=2.0579, acc_train=0.3812, loss_test=1.4647, acc_test=0.7555
# poison_percent 40 round 46: loss_train=2.0633, acc_train=0.3731, loss_test=1.4637, acc_test=0.7543
# poison_percent 40 round 47: loss_train=2.0424, acc_train=0.3853, loss_test=1.4625, acc_test=0.7537
# poison_percent 40 round 48: loss_train=2.0715, acc_train=0.3697, loss_test=1.4613, acc_test=0.7512
# poison_percent 40 round 49: loss_train=2.0586, acc_train=0.3832, loss_test=1.4603, acc_test=0.7531
# poison_percent 40 round 50: loss_train=2.0280, acc_train=0.3838, loss_test=1.4590, acc_test=0.7531
# poison_percent 40 round 51: loss_train=2.0675, acc_train=0.3783, loss_test=1.4578, acc_test=0.7543
# poison_percent 40 round 52: loss_train=2.0607, acc_train=0.3862, loss_test=1.4565, acc_test=0.7543
# poison_percent 40 round 53: loss_train=2.0506, acc_train=0.3774, loss_test=1.4550, acc_test=0.7537
# poison_percent 40 round 54: loss_train=2.0569, acc_train=0.3733, loss_test=1.4539, acc_test=0.7537
# poison_percent 40 round 55: loss_train=2.0286, acc_train=0.3962, loss_test=1.4531, acc_test=0.7537
# poison_percent 40 round 56: loss_train=2.0449, acc_train=0.3842, loss_test=1.4520, acc_test=0.7537
# poison_percent 40 round 57: loss_train=2.0489, acc_train=0.3746, loss_test=1.4512, acc_test=0.7531
# poison_percent 40 round 58: loss_train=2.0378, acc_train=0.3834, loss_test=1.4506, acc_test=0.7525
# poison_percent 40 round 59: loss_train=2.0492, acc_train=0.3785, loss_test=1.4498, acc_test=0.7525
# poison_percent 40 round 60: loss_train=2.0509, acc_train=0.3727, loss_test=1.4482, acc_test=0.7525
# poison_percent 40 round 61: loss_train=2.0536, acc_train=0.3768, loss_test=1.4476, acc_test=0.7518
# poison_percent 40 round 62: loss_train=2.0727, acc_train=0.3631, loss_test=1.4469, acc_test=0.7518
# poison_percent 40 round 63: loss_train=2.0569, acc_train=0.3802, loss_test=1.4460, acc_test=0.7525
# poison_percent 40 round 64: loss_train=2.0433, acc_train=0.3812, loss_test=1.4456, acc_test=0.7525
# poison_percent 40 round 65: loss_train=2.0532, acc_train=0.3800, loss_test=1.4447, acc_test=0.7525
# poison_percent 40 round 66: loss_train=2.0364, acc_train=0.3845, loss_test=1.4433, acc_test=0.7525
# poison_percent 40 round 67: loss_train=2.0310, acc_train=0.3866, loss_test=1.4427, acc_test=0.7525
# poison_percent 40 round 68: loss_train=2.0561, acc_train=0.3680, loss_test=1.4420, acc_test=0.7518
# poison_percent 40 round 69: loss_train=2.0424, acc_train=0.3763, loss_test=1.4406, acc_test=0.7518
# poison_percent 40 round 70: loss_train=2.0427, acc_train=0.3759, loss_test=1.4401, acc_test=0.7518
# poison_percent 40 round 71: loss_train=2.0387, acc_train=0.3763, loss_test=1.4390, acc_test=0.7518
# poison_percent 40 round 72: loss_train=2.0511, acc_train=0.3746, loss_test=1.4382, acc_test=0.7512
# poison_percent 40 round 73: loss_train=2.0343, acc_train=0.3836, loss_test=1.4375, acc_test=0.7512
# poison_percent 40 round 74: loss_train=2.0392, acc_train=0.3785, loss_test=1.4368, acc_test=0.7512
# poison_percent 40 round 75: loss_train=2.0502, acc_train=0.3710, loss_test=1.4355, acc_test=0.7512
# poison_percent 40 round 76: loss_train=2.0410, acc_train=0.3834, loss_test=1.4343, acc_test=0.7512
# poison_percent 40 round 77: loss_train=2.0438, acc_train=0.3800, loss_test=1.4339, acc_test=0.7512
# poison_percent 40 round 78: loss_train=2.0353, acc_train=0.3763, loss_test=1.4329, acc_test=0.7512
# poison_percent 40 round 79: loss_train=2.0499, acc_train=0.3695, loss_test=1.4325, acc_test=0.7506
# poison_percent 40 round 80: loss_train=2.0293, acc_train=0.3817, loss_test=1.4313, acc_test=0.7506
# poison_percent 40 round 81: loss_train=2.0134, acc_train=0.3815, loss_test=1.4305, acc_test=0.7506
# ...
# poison_percent 40 round 41: loss_train=2.1008, acc_train=0.4135, loss_test=1.9570, acc_test=0.5000
# poison_percent 40 round 42: loss_train=2.1028, acc_train=0.4065, loss_test=1.9555, acc_test=0.5000
# poison_percent 40 round 43: loss_train=2.1004, acc_train=0.4082, loss_test=1.9539, acc_test=0.5000
# poison_percent 40 round 44: loss_train=2.1012, acc_train=0.4086, loss_test=1.9525, acc_test=0.5000
# poison_percent 40 round 45: loss_train=2.0974, acc_train=0.4109, loss_test=1.9508, acc_test=0.5000
# poison_percent 40 round 46: loss_train=2.1041, acc_train=0.4007, loss_test=1.9493, acc_test=0.5000
# poison_percent 40 round 47: loss_train=2.0970, acc_train=0.4090, loss_test=1.9480, acc_test=0.5000
# poison_percent 40 round 48: loss_train=2.0996, acc_train=0.4041, loss_test=1.9468, acc_test=0.5000
# poison_percent 40 round 49: loss_train=2.1010, acc_train=0.4003, loss_test=1.9457, acc_test=0.5000
# poison_percent 40 round 50: loss_train=2.0979, acc_train=0.4054, loss_test=1.9446, acc_test=0.5000
# poison_percent 40 round 51: loss_train=2.0990, acc_train=0.4032, loss_test=1.9433, acc_test=0.5000
# poison_percent 40 round 52: loss_train=2.0980, acc_train=0.4052, loss_test=1.9415, acc_test=0.5000
# poison_percent 40 round 53: loss_train=2.0978, acc_train=0.4030, loss_test=1.9401, acc_test=0.5000
# poison_percent 40 round 54: loss_train=2.0990, acc_train=0.3996, loss_test=1.9389, acc_test=0.5000
# poison_percent 40 round 55: loss_train=2.0929, acc_train=0.4082, loss_test=1.9378, acc_test=0.5000
# poison_percent 40 round 56: loss_train=2.0929, acc_train=0.4084, loss_test=1.9364, acc_test=0.5000
# poison_percent 40 round 57: loss_train=2.0857, acc_train=0.4154, loss_test=1.9351, acc_test=0.5000
# poison_percent 40 round 58: loss_train=2.0918, acc_train=0.4069, loss_test=1.9340, acc_test=0.5000
# poison_percent 40 round 59: loss_train=2.0880, acc_train=0.4109, loss_test=1.9327, acc_test=0.5000
# poison_percent 40 round 60: loss_train=2.0895, acc_train=0.4065, loss_test=1.9316, acc_test=0.5000
# poison_percent 40 round 61: loss_train=2.0928, acc_train=0.4018, loss_test=1.9302, acc_test=0.5000
# poison_percent 40 round 62: loss_train=2.0882, acc_train=0.4069, loss_test=1.9293, acc_test=0.5000
# poison_percent 40 round 63: loss_train=2.0975, acc_train=0.3951, loss_test=1.9283, acc_test=0.5000
# poison_percent 40 round 64: loss_train=2.0884, acc_train=0.4030, loss_test=1.9273, acc_test=0.5000
# poison_percent 40 round 65: loss_train=2.0898, acc_train=0.4007, loss_test=1.9262, acc_test=0.5000
# poison_percent 40 round 66: loss_train=2.0885, acc_train=0.4067, loss_test=1.9252, acc_test=0.5000
# poison_percent 40 round 67: loss_train=2.0921, acc_train=0.3990, loss_test=1.9239, acc_test=0.5000
# poison_percent 40 round 68: loss_train=2.0815, acc_train=0.4116, loss_test=1.9229, acc_test=0.5000
# poison_percent 40 round 69: loss_train=2.0877, acc_train=0.4054, loss_test=1.9217, acc_test=0.5000
# poison_percent 40 round 70: loss_train=2.0813, acc_train=0.4109, loss_test=1.9208, acc_test=0.5000
# poison_percent 40 round 71: loss_train=2.0800, acc_train=0.4092, loss_test=1.9201, acc_test=0.5000
# poison_percent 40 round 72: loss_train=2.0853, acc_train=0.4052, loss_test=1.9191, acc_test=0.5000
# poison_percent 40 round 73: loss_train=2.0863, acc_train=0.4018, loss_test=1.9182, acc_test=0.5000
# poison_percent 40 round 74: loss_train=2.0842, acc_train=0.4067, loss_test=1.9174, acc_test=0.5000
# poison_percent 40 round 75: loss_train=2.0852, acc_train=0.4035, loss_test=1.9168, acc_test=0.5000
# poison_percent 40 round 76: loss_train=2.0774, acc_train=0.4107, loss_test=1.9160, acc_test=0.5000
# poison_percent 40 round 77: loss_train=2.0856, acc_train=0.4035, loss_test=1.9148, acc_test=0.5000
# poison_percent 40 round 78: loss_train=2.0782, acc_train=0.4075, loss_test=1.9141, acc_test=0.5000
# poison_percent 40 round 79: loss_train=2.0825, acc_train=0.4030, loss_test=1.9134, acc_test=0.5000
# poison_percent 40 round 80: loss_train=2.0843, acc_train=0.4018, loss_test=1.9123, acc_test=0.5000
# poison_percent 40 round 81: loss_train=2.0832, acc_train=0.4015, loss_test=1.9115, acc_test=0.5000
# poison_percent 40 round 82: loss_train=2.0785, acc_train=0.4075, loss_test=1.9106, acc_test=0.5000
# poison_percent 40 round 83: loss_train=2.0815, acc_train=0.4026, loss_test=1.9095, acc_test=0.5000
# poison_percent 40 round 84: loss_train=2.0834, acc_train=0.4005, loss_test=1.9087, acc_test=0.5000
# poison_percent 40 round 85: loss_train=2.0808, acc_train=0.4030, loss_test=1.9079, acc_test=0.5000
# poison_percent 40 round 86: loss_train=2.0833, acc_train=0.3994, loss_test=1.9073, acc_test=0.5000
# poison_percent 40 round 87: loss_train=2.0725, acc_train=0.4137, loss_test=1.9065, acc_test=0.5000
# poison_percent 40 round 88: loss_train=2.0807, acc_train=0.4030, loss_test=1.9057, acc_test=0.5000
# poison_percent 40 round 89: loss_train=2.0806, acc_train=0.4011, loss_test=1.9048, acc_test=0.5000
# poison_percent 40 round 90: loss_train=2.0780, acc_train=0.4026, loss_test=1.9041, acc_test=0.5000
# poison_percent 40 round 91: loss_train=2.0743, acc_train=0.4084, loss_test=1.9034, acc_test=0.5000
# poison_percent 40 round 92: loss_train=2.0785, acc_train=0.4035, loss_test=1.9025, acc_test=0.5000
# poison_percent 40 round 93: loss_train=2.0776, acc_train=0.4015, loss_test=1.9017, acc_test=0.5000
# poison_percent 40 round 94: loss_train=2.0746, acc_train=0.4084, loss_test=1.9009, acc_test=0.5000
# poison_percent 40 round 95: loss_train=2.0776, acc_train=0.4022, loss_test=1.9001, acc_test=0.5000
# poison_percent 40 round 96: loss_train=2.0811, acc_train=0.3979, loss_test=1.8993, acc_test=0.5000
# poison_percent 40 round 97: loss_train=2.0774, acc_train=0.4020, loss_test=1.8987, acc_test=0.5000
# poison_percent 40 round 98: loss_train=2.0693, acc_train=0.4109, loss_test=1.8979, acc_test=0.5000
# poison_percent 40 round 99: loss_train=2.0773, acc_train=0.4015, loss_test=1.8974, acc_test=0.5000
# Training log saved to ./results\FL_ModelN1L6_Batchsize32_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 round 0: loss_train=2.0096, acc_train=0.4783, loss_test=1.8937, acc_test=0.5000
# poison_percent 50 round 1: loss_train=2.0093, acc_train=0.4738, loss_test=1.8901, acc_test=0.5000
# poison_percent 50 round 2: loss_train=2.0049, acc_train=0.4769, loss_test=1.8864, acc_test=0.5000
# poison_percent 50 round 3: loss_train=2.0007, acc_train=0.4805, loss_test=1.8827, acc_test=0.5000
# poison_percent 50 round 4: loss_train=1.9908, acc_train=0.4870, loss_test=1.8794, acc_test=0.5000
# poison_percent 50 round 5: loss_train=1.9902, acc_train=0.4843, loss_test=1.8758, acc_test=0.5000
# poison_percent 50 round 6: loss_train=1.9912, acc_train=0.4823, loss_test=1.8725, acc_test=0.5000
# poison_percent 50 round 7: loss_train=1.9925, acc_train=0.4767, loss_test=1.8690, acc_test=0.5000
# poison_percent 50 round 8: loss_train=1.9840, acc_train=0.4850, loss_test=1.8656, acc_test=0.5000
# poison_percent 50 round 9: loss_train=1.9845, acc_train=0.4819, loss_test=1.8622, acc_test=0.5000
# poison_percent 50 round 10: loss_train=1.9882, acc_train=0.4751, loss_test=1.8588, acc_test=0.5000
# poison_percent 50 round 11: loss_train=1.9808, acc_train=0.4792, loss_test=1.8558, acc_test=0.5000
# poison_percent 50 round 12: loss_train=1.9834, acc_train=0.4731, loss_test=1.8527, acc_test=0.5000
# poison_percent 50 round 13: loss_train=1.9779, acc_train=0.4772, loss_test=1.8496, acc_test=0.5000
# poison_percent 50 round 14: loss_train=1.9700, acc_train=0.4832, loss_test=1.8464, acc_test=0.5000
# poison_percent 50 round 15: loss_train=1.9740, acc_train=0.4779, loss_test=1.8434, acc_test=0.5000
# poison_percent 50 round 16: loss_train=1.9674, acc_train=0.4810, loss_test=1.8402, acc_test=0.5000
# poison_percent 50 round 17: loss_train=1.9685, acc_train=0.4789, loss_test=1.8372, acc_test=0.5000
# poison_percent 50 round 18: loss_train=1.9731, acc_train=0.4725, loss_test=1.8341, acc_test=0.5000
# poison_percent 50 round 19: loss_train=1.9610, acc_train=0.4816, loss_test=1.8313, acc_test=0.5000
# poison_percent 50 round 20: loss_train=1.9579, acc_train=0.4857, loss_test=1.8283, acc_test=0.5000
# poison_percent 50 round 21: loss_train=1.9559, acc_train=0.4857, loss_test=1.8252, acc_test=0.5000
# poison_percent 50 round 22: loss_train=1.9554, acc_train=0.4798, loss_test=1.8225, acc_test=0.5000
# poison_percent 50 round 23: loss_train=1.9567, acc_train=0.4781, loss_test=1.8197, acc_test=0.5000
# poison_percent 50 round 24: loss_train=1.9511, acc_train=0.4826, loss_test=1.8169, acc_test=0.5000
# poison_percent 50 round 25: loss_train=1.9429, acc_train=0.4875, loss_test=1.8142, acc_test=0.5000
# poison_percent 50 round 26: loss_train=1.9549, acc_train=0.4756, loss_test=1.8114, acc_test=0.5000
# poison_percent 50 round 27: loss_train=1.9459, acc_train=0.4819, loss_test=1.8086, acc_test=0.5000
# poison_percent 50 round 28: loss_train=1.9479, acc_train=0.4767, loss_test=1.8057, acc_test=0.5000
# poison_percent 50 round 29: loss_train=1.9409, acc_train=0.4834, loss_test=1.8031, acc_test=0.5000
# poison_percent 50 round 30: loss_train=1.9398, acc_train=0.4837, loss_test=1.8006, acc_test=0.5000
# poison_percent 50 round 31: loss_train=1.9471, acc_train=0.4743, loss_test=1.7979, acc_test=0.5000
# poison_percent 50 round 32: loss_train=1.9410, acc_train=0.4767, loss_test=1.7953, acc_test=0.5000
# poison_percent 50 round 33: loss_train=1.9366, acc_train=0.4803, loss_test=1.7926, acc_test=0.5000
# poison_percent 50 round 34: loss_train=1.9356, acc_train=0.4776, loss_test=1.7901, acc_test=0.5000
# poison_percent 50 round 35: loss_train=1.9288, acc_train=0.4837, loss_test=1.7876, acc_test=0.5000
# poison_percent 50 round 36: loss_train=1.9232, acc_train=0.4873, loss_test=1.7851, acc_test=0.5000
# poison_percent 50 round 37: loss_train=1.9264, acc_train=0.4825, loss_test=1.7824, acc_test=0.5000
# poison_percent 50 round 38: loss_train=1.9253, acc_train=0.4825, loss_test=1.7799, acc_test=0.5000
# poison_percent 50 round 39: loss_train=1.9315, acc_train=0.4743, loss_test=1.7772, acc_test=0.5000
# poison_percent 50 round 40: loss_train=1.9254, acc_train=0.4790, loss_test=1.7748, acc_test=0.5000
# poison_percent 50 round 41: loss_train=1.9242, acc_train=0.4785, loss_test=1.7723, acc_test=0.5000
# poison_percent 50 round 42: loss_train=1.9258, acc_train=0.4772, loss_test=1.7699, acc_test=0.5000
# poison_percent 50 round 43: loss_train=1.9234, acc_train=0.4760, loss_test=1.7675, acc_test=0.5000
# poison_percent 50 round 44: loss_train=1.9089, acc_train=0.4875, loss_test=1.7652, acc_test=0.5000
# poison_percent 50 round 45: loss_train=1.9153, acc_train=0.4816, loss_test=1.7632, acc_test=0.5000
# poison_percent 50 round 46: loss_train=1.9161, acc_train=0.4783, loss_test=1.7609, acc_test=0.5000
# poison_percent 50 round 47: loss_train=1.9147, acc_train=0.4785, loss_test=1.7587, acc_test=0.5000
# poison_percent 50 round 48: loss_train=1.9048, acc_train=0.4854, loss_test=1.7564, acc_test=0.5000
# poison_percent 50 round 49: loss_train=1.9080, acc_train=0.4821, loss_test=1.7544, acc_test=0.5000
# poison_percent 50 round 50: loss_train=1.9103, acc_train=0.4790, loss_test=1.7522, acc_test=0.5000
# poison_percent 50 round 51: loss_train=1.9113, acc_train=0.4756, loss_test=1.7503, acc_test=0.5000
# poison_percent 50 round 52: loss_train=1.9037, acc_train=0.4819, loss_test=1.7482, acc_test=0.5000
# poison_percent 50 round 53: loss_train=1.9069, acc_train=0.4785, loss_test=1.7462, acc_test=0.5000
# poison_percent 50 round 54: loss_train=1.9019, acc_train=0.4805, loss_test=1.7440, acc_test=0.5000
# poison_percent 50 round 55: loss_train=1.8992, acc_train=0.4825, loss_test=1.7416, acc_test=0.5000
# poison_percent 50 round 56: loss_train=1.9024, acc_train=0.4769, loss_test=1.7396, acc_test=0.5000
# poison_percent 50 round 57: loss_train=1.8999, acc_train=0.4785, loss_test=1.7375, acc_test=0.5000
# poison_percent 50 round 58: loss_train=1.8978, acc_train=0.4807, loss_test=1.7352, acc_test=0.5000
# poison_percent 50 round 59: loss_train=1.8954, acc_train=0.4794, loss_test=1.7331, acc_test=0.5000
# poison_percent 50 round 60: loss_train=1.8918, acc_train=0.4828, loss_test=1.7312, acc_test=0.5000
# poison_percent 50 round 61: loss_train=1.8923, acc_train=0.4837, loss_test=1.7292, acc_test=0.5000
# poison_percent 50 round 62: loss_train=1.8880, acc_train=0.4837, loss_test=1.7271, acc_test=0.5000
# poison_percent 50 round 63: loss_train=1.8825, acc_train=0.4875, loss_test=1.7252, acc_test=0.5000
# poison_percent 50 round 64: loss_train=1.8745, acc_train=0.4922, loss_test=1.7232, acc_test=0.5000
# poison_percent 50 round 65: loss_train=1.8937, acc_train=0.4752, loss_test=1.7213, acc_test=0.5000
# poison_percent 50 round 66: loss_train=1.8877, acc_train=0.4799, loss_test=1.7192, acc_test=0.5000
# poison_percent 50 round 67: loss_train=1.8877, acc_train=0.4792, loss_test=1.7172, acc_test=0.5000
# poison_percent 50 round 68: loss_train=1.8832, acc_train=0.4819, loss_test=1.7154, acc_test=0.5000
# poison_percent 50 round 69: loss_train=1.8772, acc_train=0.4873, loss_test=1.7132, acc_test=0.5000
# poison_percent 50 round 70: loss_train=1.8803, acc_train=0.4807, loss_test=1.7112, acc_test=0.5000
# poison_percent 50 round 71: loss_train=1.8855, acc_train=0.4765, loss_test=1.7094, acc_test=0.5000
# poison_percent 50 round 72: loss_train=1.8765, acc_train=0.4843, loss_test=1.7073, acc_test=0.5000
# poison_percent 50 round 73: loss_train=1.8873, acc_train=0.4734, loss_test=1.7054, acc_test=0.5000
# poison_percent 50 round 74: loss_train=1.8814, acc_train=0.4778, loss_test=1.7035, acc_test=0.5000
# poison_percent 50 round 75: loss_train=1.8730, acc_train=0.4841, loss_test=1.7018, acc_test=0.5000
# poison_percent 50 round 76: loss_train=1.8735, acc_train=0.4836, loss_test=1.6998, acc_test=0.5000
# poison_percent 50 round 77: loss_train=1.8689, acc_train=0.4848, loss_test=1.6979, acc_test=0.5000
# poison_percent 50 round 78: loss_train=1.8681, acc_train=0.4823, loss_test=1.6962, acc_test=0.5000
# poison_percent 50 round 79: loss_train=1.8763, acc_train=0.4783, loss_test=1.6943, acc_test=0.5000
# poison_percent 50 round 80: loss_train=1.8660, acc_train=0.4843, loss_test=1.6920, acc_test=0.5000
# poison_percent 50 round 81: loss_train=1.8782, acc_train=0.4751, loss_test=1.6903, acc_test=0.5000
# poison_percent 50 round 82: loss_train=1.8721, acc_train=0.4796, loss_test=1.6886, acc_test=0.5000
# poison_percent 50 round 83: loss_train=1.8712, acc_train=0.4776, loss_test=1.6873, acc_test=0.5000
# poison_percent 50 round 84: loss_train=1.8700, acc_train=0.4779, loss_test=1.6857, acc_test=0.5000
# poison_percent 50 round 85: loss_train=1.8529, acc_train=0.4939, loss_test=1.6838, acc_test=0.5000
# poison_percent 50 round 86: loss_train=1.8619, acc_train=0.4826, loss_test=1.6821, acc_test=0.5000
# poison_percent 50 round 87: loss_train=1.8638, acc_train=0.4807, loss_test=1.6806, acc_test=0.5000
# poison_percent 50 round 88: loss_train=1.8690, acc_train=0.4754, loss_test=1.6790, acc_test=0.5000
# poison_percent 50 round 89: loss_train=1.8612, acc_train=0.4808, loss_test=1.6775, acc_test=0.5000
# poison_percent 50 round 90: loss_train=1.8605, acc_train=0.4817, loss_test=1.6756, acc_test=0.5000
# poison_percent 50 round 91: loss_train=1.8711, acc_train=0.4732, loss_test=1.6741, acc_test=0.5000
# poison_percent 50 round 92: loss_train=1.8587, acc_train=0.4819, loss_test=1.6722, acc_test=0.5000
# poison_percent 50 round 93: loss_train=1.8531, acc_train=0.4850, loss_test=1.6708, acc_test=0.5000
# poison_percent 50 round 94: loss_train=1.8634, acc_train=0.4770, loss_test=1.6693, acc_test=0.5000
# poison_percent 50 round 95: loss_train=1.8584, acc_train=0.4803, loss_test=1.6677, acc_test=0.5000
# poison_percent 50 round 96: loss_train=1.8603, acc_train=0.4778, loss_test=1.6661, acc_test=0.5000
# poison_percent 50 round 97: loss_train=1.8483, acc_train=0.4872, loss_test=1.6646, acc_test=0.5000
# poison_percent 50 round 98: loss_train=1.8548, acc_train=0.4803, loss_test=1.6631, acc_test=0.5000
# poison_percent 50 round 99: loss_train=1.8475, acc_train=0.4852, loss_test=1.6617, acc_test=0.5000
# Training log saved to ./results\FL_ModelN1L6_Batchsize32_rev2\poisoned_50percent\poisoned_50percent.csv
