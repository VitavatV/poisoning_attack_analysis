# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
# def binary_cross_entropy(pred, target):
#     eps = 1e-7
#     pred = torch.clamp(pred, eps, 1 - eps)
#     return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

def multiclass_cross_entropy(logits, target, from_probs=False, eps=1e-7):
    """
    Cross-entropy loss for multiclass (e.g., 10 classes).
    - logits: Tensor shape (N, C) containing raw scores (preferred) or probabilities if from_probs=True
    - target: Tensor shape (N,) or (N,1) containing class indices (0..C-1)
    """
    if logits.dim() == 1:
        logits = logits.unsqueeze(0)
    target = target.squeeze()
    if target.dtype != torch.long:
        target = target.long()
    if from_probs:
        probs = torch.clamp(logits, eps, 1.0 - eps)
        log_probs = torch.log(probs)
        return -log_probs[torch.arange(target.size(0)), target].mean()
    return nn.functional.cross_entropy(logits, target)

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 32
N_CLASSES = 10

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_multiple_poison/train"
TEST_PATH = "../data/mnist_multiple_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
# For 10-class classification
class MNISTNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28*28, N_CLASSES)
    def forward(self, x):
        x = self.fc1(x)
        return x
    
BATCH_SIZE_list = [BATCH_SIZE]
# temp_bs = BATCH_SIZE
# while temp_bs >= 1:
#     BATCH_SIZE_list.append(temp_bs)
#     temp_bs = temp_bs // 2

for rev in range(3):

    model = MNISTNet().to(device)
    for experiment_bs in BATCH_SIZE_list:

        name_save_path = f"CL_ModelN1L1_Batchsize{experiment_bs}_rev{rev}"
        
        for i_poisoned in poison_n_list:
            percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

            # create directory
            NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
            save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
            # Remove existing directory if it exists
            if os.path.exists(save_path):
                shutil.rmtree(save_path)
            if not os.path.exists(save_path):
                os.makedirs(save_path)
            save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
            os.makedirs(save_all_path, exist_ok=True)
            
            # Load data
            X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                    poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                    select='Honest+Poisoned')
            X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
            # print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
            # print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

            if X_test.shape[0] == 0:
                raise ValueError("No valid test images found in the test directory!")

            X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
            y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
            X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
            y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

            torch.save(model, os.path.join(save_path,'model_init.pt'))
            optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

            records = []

            # Training loop
            for epoch in range(EPOCHS):

                # Train
                model.train()
                
                #randomize the training data
                perm = torch.randperm(X_train_tensor.size(0))
                X_train_tensor = X_train_tensor[perm]
                y_train_tensor = y_train_tensor[perm]

                for start in range(0, X_train_tensor.size(0), experiment_bs):
                    end = start + experiment_bs
                    xb = X_train_tensor[start:end]
                    yb = y_train_tensor[start:end]
                    outputs = model(xb)
                    # preds = (outputs >= 0.5).float()
                    preds = torch.argmax(outputs, dim=1, keepdim=True)
                    acc_train = (preds == yb).float().mean().item()
                    loss_train = multiclass_cross_entropy(outputs, yb)
                    optimizer.zero_grad()
                    loss_train.backward()
                    optimizer.step()

                # Evaluate
                model.eval()
                with torch.no_grad():
                    outputs = model(X_test_tensor)
                    # preds = (outputs >= 0.5).float()
                    preds = torch.argmax(outputs, dim=1, keepdim=True)
                    loss_test = multiclass_cross_entropy(outputs, y_test_tensor)
                    acc_test = (preds == y_test_tensor).float().mean().item()
                records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                                'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                'loss_test': loss_test.item(), 'acc_test': acc_test})
                report_txt = f"poison_percent {percent_poisoned} "
                report_txt += f"epoch {epoch}: "
                report_txt += f"loss_train={loss_train.item():.4f}, "
                report_txt += f"acc_train={acc_train:.4f}, "
                report_txt += f"loss_test={loss_test.item():.4f}, "
                report_txt += f"acc_test={acc_test:.4f}"
                print(report_txt)

            torch.save(model, os.path.join(save_path,'model_last.pt'))

            # Save training log
            df = pd.DataFrame(records)
            save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
            df.to_csv(save_name_path, index=False)
            print(f"Training log saved to {save_name_path}")

            # Plot loss and accuracy
            plt.figure(figsize=(10,4))

            plt.subplot(1,2,1)
            plt.plot(df['epoch'], df['loss_test'], marker='o')
            plt.title('Test Loss')
            plt.ylabel('Loss')
            plt.xlabel('Epoch')
            plt.grid(True)
            plt.ylim(0, 1.1)
            # plt.legend()

            plt.subplot(1,2,2)
            plt.plot(df['epoch'], df['acc_test'], marker='o')
            plt.title('Test Accuracy')
            plt.ylabel('Accuracy')
            plt.xlabel('Epoch')
            plt.grid(True)
            plt.ylim(0, 1.1)
            # plt.legend()

            plt.tight_layout()
            save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
            plt.savefig(save_name_path)

            save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
            plt.savefig(save_name_path)
            plt.close()
# Out:
# poison_percent 0 epoch 0: loss_train=0.6166, acc_train=0.7368, loss_test=0.1816, acc_test=0.9706
# poison_percent 0 epoch 1: loss_train=0.2446, acc_train=0.8421, loss_test=0.1151, acc_test=0.9810
# poison_percent 0 epoch 2: loss_train=0.2034, acc_train=0.8947, loss_test=0.1127, acc_test=0.9792
# poison_percent 0 epoch 3: loss_train=0.3693, acc_train=0.8421, loss_test=0.1219, acc_test=0.9773
# poison_percent 0 epoch 4: loss_train=0.3770, acc_train=0.8947, loss_test=0.0925, acc_test=0.9841
# poison_percent 0 epoch 5: loss_train=0.0906, acc_train=1.0000, loss_test=0.1190, acc_test=0.9773
# poison_percent 0 epoch 6: loss_train=0.1095, acc_train=1.0000, loss_test=0.1076, acc_test=0.9786
# poison_percent 0 epoch 7: loss_train=0.1353, acc_train=0.9474, loss_test=0.0959, acc_test=0.9816
# poison_percent 0 epoch 8: loss_train=0.1623, acc_train=0.9474, loss_test=0.1065, acc_test=0.9786
# poison_percent 0 epoch 9: loss_train=0.2507, acc_train=0.9474, loss_test=0.0988, acc_test=0.9822
# poison_percent 0 epoch 10: loss_train=0.0572, acc_train=1.0000, loss_test=0.1085, acc_test=0.9767
# poison_percent 0 epoch 11: loss_train=0.2936, acc_train=0.8947, loss_test=0.1035, acc_test=0.9810
# poison_percent 0 epoch 12: loss_train=0.2987, acc_train=0.8947, loss_test=0.1039, acc_test=0.9804
# poison_percent 0 epoch 13: loss_train=0.0861, acc_train=0.9474, loss_test=0.1013, acc_test=0.9810
# poison_percent 0 epoch 14: loss_train=0.2949, acc_train=0.8947, loss_test=0.1003, acc_test=0.9804
# poison_percent 0 epoch 15: loss_train=0.1695, acc_train=0.9474, loss_test=0.1114, acc_test=0.9773
# poison_percent 0 epoch 16: loss_train=0.1258, acc_train=0.9474, loss_test=0.1131, acc_test=0.9792
# poison_percent 0 epoch 17: loss_train=0.0738, acc_train=1.0000, loss_test=0.1137, acc_test=0.9786
# poison_percent 0 epoch 18: loss_train=0.3250, acc_train=0.9474, loss_test=0.1159, acc_test=0.9792
# poison_percent 0 epoch 19: loss_train=0.0805, acc_train=1.0000, loss_test=0.1140, acc_test=0.9792
# poison_percent 0 epoch 20: loss_train=0.2808, acc_train=0.8947, loss_test=0.1227, acc_test=0.9773
# poison_percent 0 epoch 21: loss_train=0.3537, acc_train=0.8947, loss_test=0.1069, acc_test=0.9804
# poison_percent 0 epoch 22: loss_train=0.1595, acc_train=0.9474, loss_test=0.1342, acc_test=0.9743
# poison_percent 0 epoch 23: loss_train=0.1289, acc_train=0.9474, loss_test=0.1249, acc_test=0.9755
# poison_percent 0 epoch 24: loss_train=0.0344, acc_train=1.0000, loss_test=0.1038, acc_test=0.9804
# poison_percent 0 epoch 25: loss_train=0.5697, acc_train=0.7895, loss_test=0.1177, acc_test=0.9786
# poison_percent 0 epoch 26: loss_train=0.9855, acc_train=0.7895, loss_test=0.1107, acc_test=0.9804
# poison_percent 0 epoch 27: loss_train=0.0270, acc_train=1.0000, loss_test=0.1113, acc_test=0.9798
# poison_percent 0 epoch 28: loss_train=0.1778, acc_train=1.0000, loss_test=0.1181, acc_test=0.9773
# poison_percent 0 epoch 29: loss_train=0.1125, acc_train=1.0000, loss_test=0.1213, acc_test=0.9761
# poison_percent 0 epoch 30: loss_train=0.3828, acc_train=0.9474, loss_test=0.1213, acc_test=0.9786
# poison_percent 0 epoch 31: loss_train=0.8166, acc_train=0.7895, loss_test=0.1173, acc_test=0.9767
# poison_percent 0 epoch 32: loss_train=0.0793, acc_train=0.9474, loss_test=0.1298, acc_test=0.9767
# poison_percent 0 epoch 33: loss_train=0.2078, acc_train=0.9474, loss_test=0.1275, acc_test=0.9773
# poison_percent 0 epoch 34: loss_train=0.0944, acc_train=0.9474, loss_test=0.1153, acc_test=0.9786
# poison_percent 0 epoch 35: loss_train=0.1237, acc_train=0.9474, loss_test=0.1051, acc_test=0.9822
# poison_percent 0 epoch 36: loss_train=0.0302, acc_train=1.0000, loss_test=0.1365, acc_test=0.9712
# poison_percent 0 epoch 37: loss_train=1.0466, acc_train=0.8421, loss_test=0.1114, acc_test=0.9792
# poison_percent 0 epoch 38: loss_train=0.2788, acc_train=0.8947, loss_test=0.1193, acc_test=0.9779
# poison_percent 0 epoch 39: loss_train=0.0828, acc_train=1.0000, loss_test=0.1137, acc_test=0.9786
# poison_percent 0 epoch 40: loss_train=0.1943, acc_train=0.9474, loss_test=0.1206, acc_test=0.9761
# poison_percent 0 epoch 41: loss_train=0.1444, acc_train=0.8947, loss_test=0.1114, acc_test=0.9792
# poison_percent 0 epoch 42: loss_train=0.1309, acc_train=1.0000, loss_test=0.1394, acc_test=0.9706
# poison_percent 0 epoch 43: loss_train=0.1045, acc_train=0.8947, loss_test=0.1127, acc_test=0.9798
# poison_percent 0 epoch 44: loss_train=0.4509, acc_train=0.8947, loss_test=0.1162, acc_test=0.9779
# poison_percent 0 epoch 45: loss_train=0.4398, acc_train=0.8947, loss_test=0.1255, acc_test=0.9761
# poison_percent 0 epoch 46: loss_train=0.4002, acc_train=0.8421, loss_test=0.1271, acc_test=0.9761
# poison_percent 0 epoch 47: loss_train=0.2276, acc_train=0.8947, loss_test=0.1308, acc_test=0.9743
# poison_percent 0 epoch 48: loss_train=0.7444, acc_train=0.9474, loss_test=0.1184, acc_test=0.9773
# poison_percent 0 epoch 49: loss_train=0.3044, acc_train=0.8947, loss_test=0.1206, acc_test=0.9779
# poison_percent 0 epoch 50: loss_train=0.0963, acc_train=1.0000, loss_test=0.1199, acc_test=0.9755
# poison_percent 0 epoch 51: loss_train=0.1400, acc_train=0.9474, loss_test=0.1279, acc_test=0.9749
# poison_percent 0 epoch 52: loss_train=0.1165, acc_train=1.0000, loss_test=0.1185, acc_test=0.9786
# poison_percent 0 epoch 53: loss_train=0.0944, acc_train=0.9474, loss_test=0.1264, acc_test=0.9749
# poison_percent 0 epoch 54: loss_train=0.1066, acc_train=0.9474, loss_test=0.1285, acc_test=0.9761
# poison_percent 0 epoch 55: loss_train=0.1118, acc_train=0.9474, loss_test=0.1232, acc_test=0.9767
# poison_percent 0 epoch 56: loss_train=0.3981, acc_train=0.8421, loss_test=0.1235, acc_test=0.9779
# poison_percent 0 epoch 57: loss_train=0.7647, acc_train=0.7895, loss_test=0.1193, acc_test=0.9773
# poison_percent 0 epoch 58: loss_train=0.0550, acc_train=1.0000, loss_test=0.1128, acc_test=0.9798
# poison_percent 0 epoch 59: loss_train=0.0437, acc_train=1.0000, loss_test=0.1175, acc_test=0.9792
# poison_percent 0 epoch 60: loss_train=0.1767, acc_train=0.8947, loss_test=0.1207, acc_test=0.9786
# poison_percent 0 epoch 61: loss_train=0.6237, acc_train=0.8421, loss_test=0.1255, acc_test=0.9767
# poison_percent 0 epoch 62: loss_train=0.1019, acc_train=0.9474, loss_test=0.1219, acc_test=0.9749
# poison_percent 0 epoch 63: loss_train=0.0271, acc_train=1.0000, loss_test=0.1379, acc_test=0.9724
# poison_percent 0 epoch 64: loss_train=0.1622, acc_train=0.9474, loss_test=0.1253, acc_test=0.9767
# poison_percent 0 epoch 65: loss_train=0.6078, acc_train=0.8421, loss_test=0.1268, acc_test=0.9761
# poison_percent 0 epoch 66: loss_train=0.2690, acc_train=0.8947, loss_test=0.1205, acc_test=0.9779
# poison_percent 0 epoch 67: loss_train=0.1017, acc_train=1.0000, loss_test=0.1260, acc_test=0.9755
# poison_percent 0 epoch 68: loss_train=0.0511, acc_train=1.0000, loss_test=0.1189, acc_test=0.9792
# poison_percent 0 epoch 69: loss_train=0.1482, acc_train=0.9474, loss_test=0.1234, acc_test=0.9767
# poison_percent 0 epoch 70: loss_train=0.1659, acc_train=0.9474, loss_test=0.1208, acc_test=0.9773
# poison_percent 0 epoch 71: loss_train=0.2145, acc_train=0.9474, loss_test=0.1396, acc_test=0.9712
# poison_percent 0 epoch 72: loss_train=0.2952, acc_train=0.8947, loss_test=0.1172, acc_test=0.9786
# poison_percent 0 epoch 73: loss_train=0.0474, acc_train=1.0000, loss_test=0.1180, acc_test=0.9779
# poison_percent 0 epoch 74: loss_train=0.1508, acc_train=0.9474, loss_test=0.1282, acc_test=0.9737
# poison_percent 0 epoch 75: loss_train=0.0624, acc_train=1.0000, loss_test=0.1283, acc_test=0.9761
# poison_percent 0 epoch 76: loss_train=0.2752, acc_train=0.9474, loss_test=0.1386, acc_test=0.9730
# poison_percent 0 epoch 77: loss_train=0.2399, acc_train=0.9474, loss_test=0.1327, acc_test=0.9755
# poison_percent 0 epoch 78: loss_train=0.0699, acc_train=1.0000, loss_test=0.1253, acc_test=0.9761
# poison_percent 0 epoch 79: loss_train=0.2159, acc_train=0.9474, loss_test=0.1187, acc_test=0.9798
# poison_percent 0 epoch 80: loss_train=0.2617, acc_train=0.8421, loss_test=0.1180, acc_test=0.9792
# poison_percent 0 epoch 81: loss_train=0.0587, acc_train=1.0000, loss_test=0.1188, acc_test=0.9779
# poison_percent 0 epoch 82: loss_train=0.5566, acc_train=0.8947, loss_test=0.1345, acc_test=0.9767
# poison_percent 0 epoch 83: loss_train=0.4038, acc_train=0.8947, loss_test=0.1240, acc_test=0.9773
# poison_percent 0 epoch 84: loss_train=0.0312, acc_train=1.0000, loss_test=0.1310, acc_test=0.9773
# poison_percent 0 epoch 85: loss_train=0.0858, acc_train=1.0000, loss_test=0.1300, acc_test=0.9755
# poison_percent 0 epoch 86: loss_train=0.0409, acc_train=1.0000, loss_test=0.1181, acc_test=0.9786
# poison_percent 0 epoch 87: loss_train=0.3088, acc_train=0.8947, loss_test=0.1187, acc_test=0.9786
# poison_percent 0 epoch 88: loss_train=0.0642, acc_train=1.0000, loss_test=0.1145, acc_test=0.9798
# poison_percent 0 epoch 89: loss_train=0.1868, acc_train=0.8947, loss_test=0.1331, acc_test=0.9743
# poison_percent 0 epoch 90: loss_train=0.0174, acc_train=1.0000, loss_test=0.1389, acc_test=0.9730
# poison_percent 0 epoch 91: loss_train=0.0732, acc_train=1.0000, loss_test=0.1113, acc_test=0.9798
# poison_percent 0 epoch 92: loss_train=0.1232, acc_train=0.9474, loss_test=0.1293, acc_test=0.9755
# poison_percent 0 epoch 93: loss_train=0.0964, acc_train=0.9474, loss_test=0.1131, acc_test=0.9792
# poison_percent 0 epoch 94: loss_train=0.0944, acc_train=1.0000, loss_test=0.1328, acc_test=0.9755
# poison_percent 0 epoch 95: loss_train=0.4705, acc_train=0.9474, loss_test=0.1300, acc_test=0.9761
# poison_percent 0 epoch 96: loss_train=0.1440, acc_train=0.9474, loss_test=0.1312, acc_test=0.9749
# poison_percent 0 epoch 97: loss_train=0.3235, acc_train=0.9474, loss_test=0.1341, acc_test=0.9755
# poison_percent 0 epoch 98: loss_train=0.0540, acc_train=1.0000, loss_test=0.1194, acc_test=0.9786
# poison_percent 0 epoch 99: loss_train=0.1531, acc_train=0.9474, loss_test=0.1373, acc_test=0.9712
# Training log saved to ./results\CL_ModelN1L1_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 epoch 0: loss_train=1.9923, acc_train=0.6562, loss_test=0.2509, acc_test=0.9381
# poison_percent 10 epoch 1: loss_train=0.5241, acc_train=0.8750, loss_test=0.3284, acc_test=0.9161
# poison_percent 10 epoch 2: loss_train=0.8789, acc_train=0.7500, loss_test=0.2873, acc_test=0.9295
# poison_percent 10 epoch 3: loss_train=0.7882, acc_train=0.8750, loss_test=0.3157, acc_test=0.9210
# poison_percent 10 epoch 4: loss_train=0.7409, acc_train=0.8125, loss_test=0.3045, acc_test=0.9203
# poison_percent 10 epoch 5: loss_train=0.4613, acc_train=0.8438, loss_test=0.2677, acc_test=0.9424
# poison_percent 10 epoch 6: loss_train=0.5740, acc_train=0.8125, loss_test=0.3202, acc_test=0.9179
# poison_percent 10 epoch 7: loss_train=0.4779, acc_train=0.8125, loss_test=0.2948, acc_test=0.9332
# poison_percent 10 epoch 8: loss_train=0.5638, acc_train=0.8438, loss_test=0.3125, acc_test=0.9283
# poison_percent 10 epoch 9: loss_train=0.4822, acc_train=0.8750, loss_test=0.2685, acc_test=0.9504
# poison_percent 10 epoch 10: loss_train=0.7058, acc_train=0.7500, loss_test=0.2877, acc_test=0.9400
# poison_percent 10 epoch 11: loss_train=0.9551, acc_train=0.6875, loss_test=0.3004, acc_test=0.9393
# poison_percent 10 epoch 12: loss_train=0.6245, acc_train=0.7812, loss_test=0.2722, acc_test=0.9516
# poison_percent 10 epoch 13: loss_train=0.5835, acc_train=0.8125, loss_test=0.2682, acc_test=0.9449
# poison_percent 10 epoch 14: loss_train=0.4798, acc_train=0.8750, loss_test=0.2978, acc_test=0.9418
# poison_percent 10 epoch 15: loss_train=0.4362, acc_train=0.9062, loss_test=0.2922, acc_test=0.9363
# poison_percent 10 epoch 16: loss_train=0.4289, acc_train=0.9062, loss_test=0.2740, acc_test=0.9491
# poison_percent 10 epoch 17: loss_train=1.2102, acc_train=0.5625, loss_test=0.2888, acc_test=0.9363
# poison_percent 10 epoch 18: loss_train=0.7307, acc_train=0.7500, loss_test=0.2638, acc_test=0.9449
# poison_percent 10 epoch 19: loss_train=0.4699, acc_train=0.9062, loss_test=0.3247, acc_test=0.9240
# poison_percent 10 epoch 20: loss_train=0.5127, acc_train=0.8750, loss_test=0.2533, acc_test=0.9504
# poison_percent 10 epoch 21: loss_train=0.3826, acc_train=0.9062, loss_test=0.2584, acc_test=0.9455
# poison_percent 10 epoch 22: loss_train=0.5345, acc_train=0.8750, loss_test=0.2480, acc_test=0.9565
# poison_percent 10 epoch 23: loss_train=0.7049, acc_train=0.7188, loss_test=0.2593, acc_test=0.9516
# poison_percent 10 epoch 24: loss_train=0.5859, acc_train=0.7500, loss_test=0.2417, acc_test=0.9571
# poison_percent 10 epoch 25: loss_train=0.3925, acc_train=0.8750, loss_test=0.2913, acc_test=0.9479
# poison_percent 10 epoch 26: loss_train=0.4644, acc_train=0.8750, loss_test=0.2916, acc_test=0.9381
# poison_percent 10 epoch 27: loss_train=0.6892, acc_train=0.7812, loss_test=0.2537, acc_test=0.9534
# poison_percent 10 epoch 28: loss_train=0.6204, acc_train=0.8125, loss_test=0.2521, acc_test=0.9528
# poison_percent 10 epoch 29: loss_train=0.5491, acc_train=0.8438, loss_test=0.2299, acc_test=0.9663
# poison_percent 10 epoch 30: loss_train=0.6196, acc_train=0.8438, loss_test=0.2926, acc_test=0.9510
# poison_percent 10 epoch 31: loss_train=0.5738, acc_train=0.8125, loss_test=0.2507, acc_test=0.9565
# poison_percent 10 epoch 32: loss_train=0.4019, acc_train=0.9062, loss_test=0.2772, acc_test=0.9608
# poison_percent 10 epoch 33: loss_train=0.5198, acc_train=0.8438, loss_test=0.2464, acc_test=0.9571
# poison_percent 10 epoch 34: loss_train=0.7994, acc_train=0.8125, loss_test=0.3067, acc_test=0.9449
# poison_percent 10 epoch 35: loss_train=0.7353, acc_train=0.7500, loss_test=0.2689, acc_test=0.9522
# poison_percent 10 epoch 36: loss_train=0.6754, acc_train=0.7812, loss_test=0.2810, acc_test=0.9559
# poison_percent 10 epoch 37: loss_train=0.7469, acc_train=0.8438, loss_test=0.2437, acc_test=0.9651
# poison_percent 10 epoch 38: loss_train=0.4359, acc_train=0.8438, loss_test=0.2702, acc_test=0.9504
# poison_percent 10 epoch 39: loss_train=0.4420, acc_train=0.8438, loss_test=0.2614, acc_test=0.9522
# poison_percent 10 epoch 40: loss_train=0.4663, acc_train=0.9375, loss_test=0.3363, acc_test=0.9124
# poison_percent 10 epoch 41: loss_train=0.4386, acc_train=0.8750, loss_test=0.2601, acc_test=0.9583
# poison_percent 10 epoch 42: loss_train=0.5186, acc_train=0.8750, loss_test=0.2490, acc_test=0.9638
# poison_percent 10 epoch 43: loss_train=0.6841, acc_train=0.8750, loss_test=0.2428, acc_test=0.9583
# poison_percent 10 epoch 44: loss_train=0.1992, acc_train=1.0000, loss_test=0.2475, acc_test=0.9602
# poison_percent 10 epoch 45: loss_train=0.2822, acc_train=0.9375, loss_test=0.2434, acc_test=0.9602
# poison_percent 10 epoch 46: loss_train=0.5371, acc_train=0.8125, loss_test=0.2833, acc_test=0.9498
# poison_percent 10 epoch 47: loss_train=0.8691, acc_train=0.6875, loss_test=0.2631, acc_test=0.9596
# poison_percent 10 epoch 48: loss_train=0.5041, acc_train=0.8125, loss_test=0.2736, acc_test=0.9559
# poison_percent 10 epoch 49: loss_train=0.5279, acc_train=0.8750, loss_test=0.2534, acc_test=0.9571
# poison_percent 10 epoch 50: loss_train=0.2851, acc_train=0.9062, loss_test=0.2948, acc_test=0.9534
# poison_percent 10 epoch 51: loss_train=0.5823, acc_train=0.8750, loss_test=0.3029, acc_test=0.9547
# poison_percent 10 epoch 52: loss_train=0.4687, acc_train=0.8750, loss_test=0.2638, acc_test=0.9571
# poison_percent 10 epoch 53: loss_train=0.5931, acc_train=0.7500, loss_test=0.2581, acc_test=0.9589
# poison_percent 10 epoch 54: loss_train=0.5702, acc_train=0.8438, loss_test=0.2480, acc_test=0.9614
# poison_percent 10 epoch 55: loss_train=0.5368, acc_train=0.7812, loss_test=0.3105, acc_test=0.9387
# poison_percent 10 epoch 56: loss_train=0.6718, acc_train=0.8125, loss_test=0.2587, acc_test=0.9553
# poison_percent 10 epoch 57: loss_train=0.7007, acc_train=0.7812, loss_test=0.2593, acc_test=0.9577
# poison_percent 10 epoch 58: loss_train=0.5685, acc_train=0.8750, loss_test=0.2429, acc_test=0.9632
# poison_percent 10 epoch 59: loss_train=0.5674, acc_train=0.7812, loss_test=0.2337, acc_test=0.9675
# poison_percent 10 epoch 60: loss_train=0.5552, acc_train=0.8438, loss_test=0.2217, acc_test=0.9669
# poison_percent 10 epoch 61: loss_train=0.8031, acc_train=0.7500, loss_test=0.2719, acc_test=0.9547
# poison_percent 10 epoch 62: loss_train=0.5183, acc_train=0.8125, loss_test=0.2961, acc_test=0.9510
# poison_percent 10 epoch 63: loss_train=0.6604, acc_train=0.8125, loss_test=0.2652, acc_test=0.9553
# poison_percent 10 epoch 64: loss_train=0.9240, acc_train=0.7500, loss_test=0.2772, acc_test=0.9534
# poison_percent 10 epoch 65: loss_train=0.5812, acc_train=0.8125, loss_test=0.2602, acc_test=0.9596
# poison_percent 10 epoch 66: loss_train=0.6726, acc_train=0.8125, loss_test=0.2492, acc_test=0.9651
# poison_percent 10 epoch 67: loss_train=0.6596, acc_train=0.8438, loss_test=0.2519, acc_test=0.9657
# poison_percent 10 epoch 68: loss_train=0.7967, acc_train=0.7812, loss_test=0.2645, acc_test=0.9602
# poison_percent 10 epoch 69: loss_train=0.4020, acc_train=0.8750, loss_test=0.2824, acc_test=0.9553
# poison_percent 10 epoch 70: loss_train=0.2223, acc_train=1.0000, loss_test=0.2417, acc_test=0.9614
# poison_percent 10 epoch 71: loss_train=0.4098, acc_train=0.8750, loss_test=0.2824, acc_test=0.9430
# poison_percent 10 epoch 72: loss_train=0.6347, acc_train=0.8125, loss_test=0.2829, acc_test=0.9608
# poison_percent 10 epoch 73: loss_train=0.5797, acc_train=0.8125, loss_test=0.2669, acc_test=0.9608
# poison_percent 10 epoch 74: loss_train=0.9525, acc_train=0.6562, loss_test=0.2554, acc_test=0.9626
# poison_percent 10 epoch 75: loss_train=0.4544, acc_train=0.9375, loss_test=0.2242, acc_test=0.9700
# poison_percent 10 epoch 76: loss_train=0.5410, acc_train=0.8125, loss_test=0.2803, acc_test=0.9589
# poison_percent 10 epoch 77: loss_train=0.5955, acc_train=0.8750, loss_test=0.2780, acc_test=0.9559
# poison_percent 10 epoch 78: loss_train=0.4804, acc_train=0.8750, loss_test=0.2505, acc_test=0.9620
# poison_percent 10 epoch 79: loss_train=0.3679, acc_train=0.8750, loss_test=0.2649, acc_test=0.9583
# poison_percent 10 epoch 80: loss_train=0.6154, acc_train=0.7812, loss_test=0.2578, acc_test=0.9602
# poison_percent 10 epoch 81: loss_train=0.9745, acc_train=0.6562, loss_test=0.2516, acc_test=0.9638
# poison_percent 10 epoch 82: loss_train=0.5451, acc_train=0.8750, loss_test=0.2649, acc_test=0.9559
# poison_percent 10 epoch 83: loss_train=0.9100, acc_train=0.7500, loss_test=0.2711, acc_test=0.9491
# poison_percent 10 epoch 84: loss_train=0.5224, acc_train=0.7812, loss_test=0.2141, acc_test=0.9675
# poison_percent 10 epoch 85: loss_train=1.1113, acc_train=0.6562, loss_test=0.2676, acc_test=0.9534
# poison_percent 10 epoch 86: loss_train=0.4186, acc_train=0.8750, loss_test=0.2456, acc_test=0.9620
# poison_percent 10 epoch 87: loss_train=0.2713, acc_train=0.9375, loss_test=0.2448, acc_test=0.9651
# poison_percent 10 epoch 88: loss_train=0.4524, acc_train=0.8750, loss_test=0.2485, acc_test=0.9626
# poison_percent 10 epoch 89: loss_train=0.5817, acc_train=0.8125, loss_test=0.2591, acc_test=0.9583
# poison_percent 10 epoch 90: loss_train=0.5573, acc_train=0.8438, loss_test=0.2728, acc_test=0.9553
# poison_percent 10 epoch 91: loss_train=0.7346, acc_train=0.7812, loss_test=0.2254, acc_test=0.9700
# poison_percent 10 epoch 92: loss_train=0.6852, acc_train=0.7188, loss_test=0.2312, acc_test=0.9663
# poison_percent 10 epoch 93: loss_train=0.5102, acc_train=0.7812, loss_test=0.2682, acc_test=0.9553
# poison_percent 10 epoch 94: loss_train=0.5345, acc_train=0.8438, loss_test=0.2376, acc_test=0.9626
# poison_percent 10 epoch 95: loss_train=0.5248, acc_train=0.8438, loss_test=0.2512, acc_test=0.9577
# poison_percent 10 epoch 96: loss_train=0.4403, acc_train=0.8750, loss_test=0.2433, acc_test=0.9626
# poison_percent 10 epoch 97: loss_train=0.8518, acc_train=0.7500, loss_test=0.2369, acc_test=0.9632
# poison_percent 10 epoch 98: loss_train=0.4119, acc_train=0.8125, loss_test=0.2351, acc_test=0.9645
# poison_percent 10 epoch 99: loss_train=0.8053, acc_train=0.7500, loss_test=0.2703, acc_test=0.9547
# Training log saved to ./results\CL_ModelN1L1_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 epoch 0: loss_train=1.4345, acc_train=0.6452, loss_test=0.3182, acc_test=0.9442
# poison_percent 20 epoch 1: loss_train=0.8302, acc_train=0.6129, loss_test=0.3576, acc_test=0.9301
# poison_percent 20 epoch 2: loss_train=0.6031, acc_train=0.8387, loss_test=0.3987, acc_test=0.9344
# poison_percent 20 epoch 3: loss_train=0.9734, acc_train=0.5806, loss_test=0.3769, acc_test=0.9387
# poison_percent 20 epoch 4: loss_train=0.6590, acc_train=0.7742, loss_test=0.3223, acc_test=0.9363
# poison_percent 20 epoch 5: loss_train=1.1347, acc_train=0.5484, loss_test=0.3475, acc_test=0.9504
# poison_percent 20 epoch 6: loss_train=0.7490, acc_train=0.7419, loss_test=0.3591, acc_test=0.9449
# poison_percent 20 epoch 7: loss_train=1.0478, acc_train=0.6129, loss_test=0.3884, acc_test=0.9161
# poison_percent 20 epoch 8: loss_train=0.5369, acc_train=0.8387, loss_test=0.3623, acc_test=0.9412
# poison_percent 20 epoch 9: loss_train=0.5743, acc_train=0.8065, loss_test=0.3559, acc_test=0.9369
# poison_percent 20 epoch 10: loss_train=1.0056, acc_train=0.6452, loss_test=0.4029, acc_test=0.9173
# poison_percent 20 epoch 11: loss_train=0.6195, acc_train=0.7742, loss_test=0.3702, acc_test=0.9442
# poison_percent 20 epoch 12: loss_train=0.8354, acc_train=0.7097, loss_test=0.3575, acc_test=0.9412
# poison_percent 20 epoch 13: loss_train=0.7465, acc_train=0.7097, loss_test=0.3453, acc_test=0.9344
# poison_percent 20 epoch 14: loss_train=0.6597, acc_train=0.7742, loss_test=0.4488, acc_test=0.9087
# poison_percent 20 epoch 15: loss_train=0.7947, acc_train=0.7419, loss_test=0.3491, acc_test=0.9436
# poison_percent 20 epoch 16: loss_train=0.7230, acc_train=0.7097, loss_test=0.3620, acc_test=0.9473
# poison_percent 20 epoch 17: loss_train=0.6474, acc_train=0.7097, loss_test=0.3627, acc_test=0.9442
# poison_percent 20 epoch 18: loss_train=0.6604, acc_train=0.6774, loss_test=0.3993, acc_test=0.9093
# poison_percent 20 epoch 19: loss_train=0.4808, acc_train=0.8065, loss_test=0.4020, acc_test=0.9210
# poison_percent 20 epoch 20: loss_train=0.6506, acc_train=0.7742, loss_test=0.4007, acc_test=0.9283
# poison_percent 20 epoch 21: loss_train=0.6800, acc_train=0.6774, loss_test=0.3880, acc_test=0.9130
# poison_percent 20 epoch 22: loss_train=0.6435, acc_train=0.8065, loss_test=0.4074, acc_test=0.9295
# poison_percent 20 epoch 23: loss_train=0.7473, acc_train=0.7097, loss_test=0.4116, acc_test=0.9056
# poison_percent 20 epoch 24: loss_train=0.7995, acc_train=0.6129, loss_test=0.3819, acc_test=0.9400
# poison_percent 20 epoch 25: loss_train=0.8801, acc_train=0.6774, loss_test=0.4117, acc_test=0.9216
# poison_percent 20 epoch 26: loss_train=0.9821, acc_train=0.6129, loss_test=0.4103, acc_test=0.9320
# poison_percent 20 epoch 27: loss_train=0.7943, acc_train=0.6452, loss_test=0.3473, acc_test=0.9491
# poison_percent 20 epoch 28: loss_train=1.1188, acc_train=0.6774, loss_test=0.3894, acc_test=0.9406
# poison_percent 20 epoch 29: loss_train=0.7428, acc_train=0.6774, loss_test=0.3615, acc_test=0.9485
# poison_percent 20 epoch 30: loss_train=1.0589, acc_train=0.5806, loss_test=0.3547, acc_test=0.9455
# poison_percent 20 epoch 31: loss_train=0.6976, acc_train=0.8065, loss_test=0.3792, acc_test=0.9406
# poison_percent 20 epoch 32: loss_train=0.8889, acc_train=0.7419, loss_test=0.3722, acc_test=0.9277
# poison_percent 20 epoch 33: loss_train=0.9455, acc_train=0.5806, loss_test=0.3487, acc_test=0.9424
# poison_percent 20 epoch 34: loss_train=0.8092, acc_train=0.7419, loss_test=0.3745, acc_test=0.9344
# poison_percent 20 epoch 35: loss_train=0.4941, acc_train=0.8710, loss_test=0.4204, acc_test=0.9400
# poison_percent 20 epoch 36: loss_train=0.8184, acc_train=0.7097, loss_test=0.3580, acc_test=0.9516
# poison_percent 20 epoch 37: loss_train=0.6089, acc_train=0.8065, loss_test=0.4007, acc_test=0.9277
# poison_percent 20 epoch 38: loss_train=0.8006, acc_train=0.5806, loss_test=0.3160, acc_test=0.9596
# poison_percent 20 epoch 39: loss_train=0.6156, acc_train=0.7097, loss_test=0.3527, acc_test=0.9400
# poison_percent 20 epoch 40: loss_train=0.6323, acc_train=0.8065, loss_test=0.4050, acc_test=0.9197
# poison_percent 20 epoch 41: loss_train=0.7216, acc_train=0.7419, loss_test=0.4138, acc_test=0.9277
# poison_percent 20 epoch 42: loss_train=0.7316, acc_train=0.6774, loss_test=0.4153, acc_test=0.9222
# poison_percent 20 epoch 43: loss_train=0.7534, acc_train=0.6452, loss_test=0.4532, acc_test=0.9136
# poison_percent 20 epoch 44: loss_train=0.5438, acc_train=0.8065, loss_test=0.3495, acc_test=0.9540
# poison_percent 20 epoch 45: loss_train=0.5521, acc_train=0.7742, loss_test=0.3924, acc_test=0.9357
# poison_percent 20 epoch 46: loss_train=0.8256, acc_train=0.7097, loss_test=0.3845, acc_test=0.9301
# poison_percent 20 epoch 47: loss_train=0.9798, acc_train=0.6129, loss_test=0.3964, acc_test=0.9320
# poison_percent 20 epoch 48: loss_train=0.8534, acc_train=0.6129, loss_test=0.3336, acc_test=0.9528
# poison_percent 20 epoch 49: loss_train=0.7086, acc_train=0.7742, loss_test=0.3472, acc_test=0.9393
# poison_percent 20 epoch 50: loss_train=0.8971, acc_train=0.6774, loss_test=0.3471, acc_test=0.9534
# poison_percent 20 epoch 51: loss_train=0.7443, acc_train=0.7419, loss_test=0.3624, acc_test=0.9467
# poison_percent 20 epoch 52: loss_train=0.7162, acc_train=0.7419, loss_test=0.3643, acc_test=0.9350
# poison_percent 20 epoch 53: loss_train=0.7661, acc_train=0.7097, loss_test=0.3628, acc_test=0.9332
# poison_percent 20 epoch 54: loss_train=0.9774, acc_train=0.7097, loss_test=0.3423, acc_test=0.9485
# poison_percent 20 epoch 55: loss_train=0.6965, acc_train=0.7742, loss_test=0.3024, acc_test=0.9559
# poison_percent 20 epoch 56: loss_train=0.8364, acc_train=0.6774, loss_test=0.3511, acc_test=0.9406
# poison_percent 20 epoch 57: loss_train=0.6946, acc_train=0.7419, loss_test=0.3777, acc_test=0.9393
# poison_percent 20 epoch 58: loss_train=0.9360, acc_train=0.6774, loss_test=0.3867, acc_test=0.9412
# poison_percent 20 epoch 59: loss_train=0.7927, acc_train=0.6774, loss_test=0.3992, acc_test=0.9400
# poison_percent 20 epoch 60: loss_train=0.8158, acc_train=0.7742, loss_test=0.3834, acc_test=0.9393
# poison_percent 20 epoch 61: loss_train=0.5981, acc_train=0.7742, loss_test=0.3624, acc_test=0.9381
# poison_percent 20 epoch 62: loss_train=0.7996, acc_train=0.6774, loss_test=0.3936, acc_test=0.9357
# poison_percent 20 epoch 63: loss_train=0.6226, acc_train=0.7742, loss_test=0.4431, acc_test=0.9154
# poison_percent 20 epoch 64: loss_train=0.8776, acc_train=0.6129, loss_test=0.3783, acc_test=0.9430
# poison_percent 20 epoch 65: loss_train=0.6785, acc_train=0.7742, loss_test=0.3802, acc_test=0.9363
# poison_percent 20 epoch 66: loss_train=0.9443, acc_train=0.5806, loss_test=0.4074, acc_test=0.9350
# poison_percent 20 epoch 67: loss_train=0.6771, acc_train=0.7097, loss_test=0.3842, acc_test=0.9350
# poison_percent 20 epoch 68: loss_train=0.8491, acc_train=0.7419, loss_test=0.3405, acc_test=0.9534
# poison_percent 20 epoch 69: loss_train=0.6592, acc_train=0.7419, loss_test=0.4013, acc_test=0.9259
# poison_percent 20 epoch 70: loss_train=1.0506, acc_train=0.8065, loss_test=0.3633, acc_test=0.9387
# poison_percent 20 epoch 71: loss_train=0.8638, acc_train=0.6129, loss_test=0.3487, acc_test=0.9534
# poison_percent 20 epoch 72: loss_train=0.9537, acc_train=0.7419, loss_test=0.4420, acc_test=0.9252
# poison_percent 20 epoch 73: loss_train=0.5287, acc_train=0.9032, loss_test=0.4155, acc_test=0.9210
# poison_percent 20 epoch 74: loss_train=0.5978, acc_train=0.7742, loss_test=0.4021, acc_test=0.9228
# poison_percent 20 epoch 75: loss_train=1.1002, acc_train=0.5484, loss_test=0.3620, acc_test=0.9283
# poison_percent 20 epoch 76: loss_train=0.7535, acc_train=0.6774, loss_test=0.3787, acc_test=0.9314
# poison_percent 20 epoch 77: loss_train=0.6493, acc_train=0.8387, loss_test=0.3663, acc_test=0.9504
# poison_percent 20 epoch 78: loss_train=0.5901, acc_train=0.7742, loss_test=0.4045, acc_test=0.9326
# poison_percent 20 epoch 79: loss_train=0.7827, acc_train=0.6774, loss_test=0.3646, acc_test=0.9455
# poison_percent 20 epoch 80: loss_train=0.5129, acc_train=0.8387, loss_test=0.4173, acc_test=0.9148
# poison_percent 20 epoch 81: loss_train=0.6918, acc_train=0.7419, loss_test=0.3851, acc_test=0.9504
# poison_percent 20 epoch 82: loss_train=1.3179, acc_train=0.6129, loss_test=0.4171, acc_test=0.9216
# poison_percent 20 epoch 83: loss_train=0.6562, acc_train=0.7742, loss_test=0.4072, acc_test=0.9308
# poison_percent 20 epoch 84: loss_train=0.9041, acc_train=0.6774, loss_test=0.3874, acc_test=0.9412
# poison_percent 20 epoch 85: loss_train=0.7909, acc_train=0.6129, loss_test=0.3931, acc_test=0.9191
# poison_percent 20 epoch 86: loss_train=0.5985, acc_train=0.8065, loss_test=0.3584, acc_test=0.9455
# poison_percent 20 epoch 87: loss_train=0.6652, acc_train=0.8065, loss_test=0.4263, acc_test=0.9295
# poison_percent 20 epoch 88: loss_train=0.8982, acc_train=0.6774, loss_test=0.3631, acc_test=0.9387
# poison_percent 20 epoch 89: loss_train=0.6732, acc_train=0.7097, loss_test=0.3890, acc_test=0.9271
# poison_percent 20 epoch 90: loss_train=1.2073, acc_train=0.6452, loss_test=0.3666, acc_test=0.9485
# poison_percent 20 epoch 91: loss_train=1.0440, acc_train=0.6774, loss_test=0.4006, acc_test=0.9252
# poison_percent 20 epoch 92: loss_train=0.4150, acc_train=0.9032, loss_test=0.3778, acc_test=0.9357
# poison_percent 20 epoch 93: loss_train=0.8026, acc_train=0.7097, loss_test=0.3559, acc_test=0.9400
# poison_percent 20 epoch 94: loss_train=0.8645, acc_train=0.7742, loss_test=0.3838, acc_test=0.9381
# poison_percent 20 epoch 95: loss_train=0.6881, acc_train=0.8387, loss_test=0.3638, acc_test=0.9498
# poison_percent 20 epoch 96: loss_train=0.5879, acc_train=0.7742, loss_test=0.3501, acc_test=0.9491
# poison_percent 20 epoch 97: loss_train=0.7985, acc_train=0.7097, loss_test=0.3441, acc_test=0.9418
# poison_percent 20 epoch 98: loss_train=0.3790, acc_train=0.8710, loss_test=0.3648, acc_test=0.9479
# poison_percent 20 epoch 99: loss_train=0.7588, acc_train=0.6774, loss_test=0.4686, acc_test=0.9142
# Training log saved to ./results\CL_ModelN1L1_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 epoch 0: loss_train=0.6574, acc_train=0.6923, loss_test=0.4742, acc_test=0.9069
# poison_percent 30 epoch 1: loss_train=1.1531, acc_train=0.4615, loss_test=0.4300, acc_test=0.9308
# poison_percent 30 epoch 2: loss_train=0.9318, acc_train=0.6154, loss_test=0.4777, acc_test=0.9130
# poison_percent 30 epoch 3: loss_train=0.8655, acc_train=0.6538, loss_test=0.4587, acc_test=0.9105
# poison_percent 30 epoch 4: loss_train=0.7377, acc_train=0.6538, loss_test=0.5279, acc_test=0.8689
# poison_percent 30 epoch 5: loss_train=0.8125, acc_train=0.5769, loss_test=0.4834, acc_test=0.9142
# poison_percent 30 epoch 6: loss_train=0.8258, acc_train=0.6154, loss_test=0.4689, acc_test=0.9118
# poison_percent 30 epoch 7: loss_train=1.2551, acc_train=0.5000, loss_test=0.4815, acc_test=0.8922
# poison_percent 30 epoch 8: loss_train=0.5925, acc_train=0.7692, loss_test=0.4812, acc_test=0.9136
# poison_percent 30 epoch 9: loss_train=0.9347, acc_train=0.6923, loss_test=0.5184, acc_test=0.8609
# poison_percent 30 epoch 10: loss_train=0.5514, acc_train=0.7692, loss_test=0.5218, acc_test=0.8830
# poison_percent 30 epoch 11: loss_train=1.3360, acc_train=0.4231, loss_test=0.4857, acc_test=0.9154
# poison_percent 30 epoch 12: loss_train=0.7976, acc_train=0.5769, loss_test=0.5434, acc_test=0.8891
# poison_percent 30 epoch 13: loss_train=0.9744, acc_train=0.6154, loss_test=0.5073, acc_test=0.9056
# poison_percent 30 epoch 14: loss_train=1.0770, acc_train=0.5769, loss_test=0.4904, acc_test=0.8922
# poison_percent 30 epoch 15: loss_train=0.7927, acc_train=0.7308, loss_test=0.5364, acc_test=0.8609
# poison_percent 30 epoch 16: loss_train=0.8942, acc_train=0.6154, loss_test=0.4384, acc_test=0.9314
# poison_percent 30 epoch 17: loss_train=0.5971, acc_train=0.7692, loss_test=0.4823, acc_test=0.9099
# poison_percent 30 epoch 18: loss_train=0.9168, acc_train=0.6538, loss_test=0.4673, acc_test=0.9222
# poison_percent 30 epoch 19: loss_train=0.6930, acc_train=0.6923, loss_test=0.5079, acc_test=0.8909
# poison_percent 30 epoch 20: loss_train=0.7163, acc_train=0.7308, loss_test=0.5021, acc_test=0.9081
# poison_percent 30 epoch 21: loss_train=0.7450, acc_train=0.6538, loss_test=0.4668, acc_test=0.9271
# poison_percent 30 epoch 22: loss_train=1.1063, acc_train=0.4615, loss_test=0.5406, acc_test=0.8321
# poison_percent 30 epoch 23: loss_train=0.9910, acc_train=0.3462, loss_test=0.5116, acc_test=0.8977
# poison_percent 30 epoch 24: loss_train=1.0487, acc_train=0.6538, loss_test=0.5658, acc_test=0.8487
# poison_percent 30 epoch 25: loss_train=0.7786, acc_train=0.6923, loss_test=0.5574, acc_test=0.8156
# poison_percent 30 epoch 26: loss_train=0.7865, acc_train=0.7692, loss_test=0.5159, acc_test=0.8989
# poison_percent 30 epoch 27: loss_train=0.8914, acc_train=0.6154, loss_test=0.5056, acc_test=0.8934
# poison_percent 30 epoch 28: loss_train=0.8923, acc_train=0.5385, loss_test=0.4960, acc_test=0.9161
# poison_percent 30 epoch 29: loss_train=0.7483, acc_train=0.7308, loss_test=0.5271, acc_test=0.8683
# poison_percent 30 epoch 30: loss_train=0.7008, acc_train=0.6923, loss_test=0.5465, acc_test=0.8885
# poison_percent 30 epoch 31: loss_train=1.1288, acc_train=0.4231, loss_test=0.4847, acc_test=0.9216
# poison_percent 30 epoch 32: loss_train=0.6930, acc_train=0.6923, loss_test=0.5377, acc_test=0.8585
# poison_percent 30 epoch 33: loss_train=0.9814, acc_train=0.6154, loss_test=0.4754, acc_test=0.9130
# poison_percent 30 epoch 34: loss_train=0.7852, acc_train=0.6923, loss_test=0.5157, acc_test=0.8732
# poison_percent 30 epoch 35: loss_train=0.7370, acc_train=0.7308, loss_test=0.4697, acc_test=0.9222
# poison_percent 30 epoch 36: loss_train=0.7416, acc_train=0.6538, loss_test=0.5131, acc_test=0.9013
# poison_percent 30 epoch 37: loss_train=0.7985, acc_train=0.7692, loss_test=0.5694, acc_test=0.8652
# poison_percent 30 epoch 38: loss_train=0.9035, acc_train=0.5769, loss_test=0.4961, acc_test=0.9007
# poison_percent 30 epoch 39: loss_train=0.9132, acc_train=0.5769, loss_test=0.4974, acc_test=0.9142
# poison_percent 30 epoch 40: loss_train=1.5428, acc_train=0.4231, loss_test=0.5082, acc_test=0.9105
# poison_percent 30 epoch 41: loss_train=0.7144, acc_train=0.5769, loss_test=0.5186, acc_test=0.8885
# poison_percent 30 epoch 42: loss_train=1.2529, acc_train=0.5000, loss_test=0.4548, acc_test=0.9112
# poison_percent 30 epoch 43: loss_train=0.7790, acc_train=0.6154, loss_test=0.5034, acc_test=0.9026
# poison_percent 30 epoch 44: loss_train=1.0116, acc_train=0.5385, loss_test=0.5209, acc_test=0.8860
# poison_percent 30 epoch 45: loss_train=0.9158, acc_train=0.5385, loss_test=0.5116, acc_test=0.8817
# poison_percent 30 epoch 46: loss_train=1.2010, acc_train=0.5000, loss_test=0.5029, acc_test=0.8971
# poison_percent 30 epoch 47: loss_train=0.6711, acc_train=0.7308, loss_test=0.4379, acc_test=0.9332
# poison_percent 30 epoch 48: loss_train=1.1353, acc_train=0.5000, loss_test=0.4672, acc_test=0.9240
# poison_percent 30 epoch 49: loss_train=0.9824, acc_train=0.5385, loss_test=0.5804, acc_test=0.8511
# poison_percent 30 epoch 50: loss_train=1.0145, acc_train=0.7308, loss_test=0.5409, acc_test=0.8634
# poison_percent 30 epoch 51: loss_train=0.8730, acc_train=0.6154, loss_test=0.4762, acc_test=0.9001
# poison_percent 30 epoch 52: loss_train=1.1263, acc_train=0.4615, loss_test=0.4807, acc_test=0.9044
# poison_percent 30 epoch 53: loss_train=0.8298, acc_train=0.7308, loss_test=0.5295, acc_test=0.8885
# poison_percent 30 epoch 54: loss_train=0.9349, acc_train=0.4615, loss_test=0.4612, acc_test=0.9118
# poison_percent 30 epoch 55: loss_train=1.0381, acc_train=0.6154, loss_test=0.5097, acc_test=0.9001
# poison_percent 30 epoch 56: loss_train=1.0623, acc_train=0.4615, loss_test=0.5525, acc_test=0.8585
# poison_percent 30 epoch 57: loss_train=0.8873, acc_train=0.6538, loss_test=0.5257, acc_test=0.9050
# poison_percent 30 epoch 58: loss_train=0.9872, acc_train=0.4615, loss_test=0.4851, acc_test=0.9026
# poison_percent 30 epoch 59: loss_train=0.8389, acc_train=0.5769, loss_test=0.4531, acc_test=0.9259
# poison_percent 30 epoch 60: loss_train=0.9657, acc_train=0.5769, loss_test=0.4411, acc_test=0.9301
# poison_percent 30 epoch 61: loss_train=0.7835, acc_train=0.6154, loss_test=0.5096, acc_test=0.9013
# poison_percent 30 epoch 62: loss_train=0.9186, acc_train=0.6538, loss_test=0.5150, acc_test=0.8897
# poison_percent 30 epoch 63: loss_train=1.0260, acc_train=0.5000, loss_test=0.4824, acc_test=0.9093
# poison_percent 30 epoch 64: loss_train=1.1113, acc_train=0.6538, loss_test=0.5521, acc_test=0.8664
# poison_percent 30 epoch 65: loss_train=0.9634, acc_train=0.5769, loss_test=0.4862, acc_test=0.9210
# poison_percent 30 epoch 66: loss_train=0.7932, acc_train=0.7308, loss_test=0.6119, acc_test=0.8468
# poison_percent 30 epoch 67: loss_train=0.9982, acc_train=0.6923, loss_test=0.4760, acc_test=0.8903
# poison_percent 30 epoch 68: loss_train=0.6728, acc_train=0.7308, loss_test=0.5416, acc_test=0.8824
# poison_percent 30 epoch 69: loss_train=1.0145, acc_train=0.4615, loss_test=0.5475, acc_test=0.8873
# poison_percent 30 epoch 70: loss_train=1.0935, acc_train=0.6154, loss_test=0.4633, acc_test=0.9283
# poison_percent 30 epoch 71: loss_train=0.6852, acc_train=0.6923, loss_test=0.4989, acc_test=0.9075
# poison_percent 30 epoch 72: loss_train=0.6732, acc_train=0.6923, loss_test=0.5205, acc_test=0.9020
# poison_percent 30 epoch 73: loss_train=1.2841, acc_train=0.5000, loss_test=0.5410, acc_test=0.8964
# poison_percent 30 epoch 74: loss_train=0.8814, acc_train=0.6154, loss_test=0.4896, acc_test=0.9191
# poison_percent 30 epoch 75: loss_train=0.7888, acc_train=0.6923, loss_test=0.5355, acc_test=0.8768
# poison_percent 30 epoch 76: loss_train=0.7786, acc_train=0.7308, loss_test=0.5321, acc_test=0.9020
# poison_percent 30 epoch 77: loss_train=1.1583, acc_train=0.4231, loss_test=0.5520, acc_test=0.8719
# poison_percent 30 epoch 78: loss_train=0.6287, acc_train=0.7308, loss_test=0.5261, acc_test=0.8934
# poison_percent 30 epoch 79: loss_train=0.8533, acc_train=0.6538, loss_test=0.5012, acc_test=0.9026
# poison_percent 30 epoch 80: loss_train=1.3654, acc_train=0.3846, loss_test=0.5060, acc_test=0.8750
# poison_percent 30 epoch 81: loss_train=1.0974, acc_train=0.5385, loss_test=0.4735, acc_test=0.9075
# poison_percent 30 epoch 82: loss_train=0.8133, acc_train=0.7692, loss_test=0.5100, acc_test=0.8885
# poison_percent 30 epoch 83: loss_train=0.8883, acc_train=0.6923, loss_test=0.4248, acc_test=0.9406
# poison_percent 30 epoch 84: loss_train=0.4734, acc_train=0.7692, loss_test=0.5304, acc_test=0.8732
# poison_percent 30 epoch 85: loss_train=0.9270, acc_train=0.5385, loss_test=0.4928, acc_test=0.9075
# poison_percent 30 epoch 86: loss_train=0.8202, acc_train=0.6538, loss_test=0.4326, acc_test=0.9295
# poison_percent 30 epoch 87: loss_train=0.6300, acc_train=0.7692, loss_test=0.4986, acc_test=0.9228
# poison_percent 30 epoch 88: loss_train=1.0352, acc_train=0.5000, loss_test=0.4954, acc_test=0.9093
# poison_percent 30 epoch 89: loss_train=0.8921, acc_train=0.7692, loss_test=0.4810, acc_test=0.9099
# poison_percent 30 epoch 90: loss_train=0.6850, acc_train=0.6538, loss_test=0.5478, acc_test=0.8658
# poison_percent 30 epoch 91: loss_train=0.9272, acc_train=0.5385, loss_test=0.4885, acc_test=0.9118
# poison_percent 30 epoch 92: loss_train=0.6092, acc_train=0.7692, loss_test=0.4648, acc_test=0.9295
# poison_percent 30 epoch 93: loss_train=1.4088, acc_train=0.5385, loss_test=0.5049, acc_test=0.8964
# poison_percent 30 epoch 94: loss_train=0.9601, acc_train=0.6538, loss_test=0.4806, acc_test=0.9173
# poison_percent 30 epoch 95: loss_train=0.7053, acc_train=0.7692, loss_test=0.5187, acc_test=0.8903
# poison_percent 30 epoch 96: loss_train=0.7878, acc_train=0.6538, loss_test=0.4833, acc_test=0.9179
# poison_percent 30 epoch 97: loss_train=0.8853, acc_train=0.7308, loss_test=0.4319, acc_test=0.9357
# poison_percent 30 epoch 98: loss_train=0.8466, acc_train=0.6538, loss_test=0.5438, acc_test=0.8695
# poison_percent 30 epoch 99: loss_train=1.0328, acc_train=0.5385, loss_test=0.5106, acc_test=0.8762
# Training log saved to ./results\CL_ModelN1L1_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 epoch 0: loss_train=0.7123, acc_train=0.5000, loss_test=0.6652, acc_test=0.7690
# poison_percent 40 epoch 1: loss_train=1.1654, acc_train=0.3000, loss_test=0.6094, acc_test=0.8303
# poison_percent 40 epoch 2: loss_train=0.7296, acc_train=0.7000, loss_test=0.6594, acc_test=0.7947
# poison_percent 40 epoch 3: loss_train=1.5357, acc_train=0.4000, loss_test=0.6538, acc_test=0.7904
# poison_percent 40 epoch 4: loss_train=1.0874, acc_train=0.2000, loss_test=0.6870, acc_test=0.7525
# poison_percent 40 epoch 5: loss_train=1.1663, acc_train=0.4000, loss_test=0.7514, acc_test=0.6808
# poison_percent 40 epoch 6: loss_train=0.9642, acc_train=0.3000, loss_test=0.6630, acc_test=0.7469
# poison_percent 40 epoch 7: loss_train=0.9836, acc_train=0.6000, loss_test=0.6832, acc_test=0.7812
# poison_percent 40 epoch 8: loss_train=0.8591, acc_train=0.7000, loss_test=0.6270, acc_test=0.8131
# poison_percent 40 epoch 9: loss_train=0.7846, acc_train=0.6000, loss_test=0.6537, acc_test=0.7886
# poison_percent 40 epoch 10: loss_train=0.9597, acc_train=0.6000, loss_test=0.7032, acc_test=0.7390
# poison_percent 40 epoch 11: loss_train=0.8623, acc_train=0.6000, loss_test=0.6785, acc_test=0.7616
# poison_percent 40 epoch 12: loss_train=1.2080, acc_train=0.5000, loss_test=0.7214, acc_test=0.7439
# poison_percent 40 epoch 13: loss_train=1.4672, acc_train=0.4000, loss_test=0.6833, acc_test=0.7463
# poison_percent 40 epoch 14: loss_train=1.0056, acc_train=0.6000, loss_test=0.7062, acc_test=0.7402
# poison_percent 40 epoch 15: loss_train=0.9580, acc_train=0.4000, loss_test=0.6720, acc_test=0.7457
# poison_percent 40 epoch 16: loss_train=0.7768, acc_train=0.7000, loss_test=0.7897, acc_test=0.6489
# poison_percent 40 epoch 17: loss_train=1.1360, acc_train=0.2000, loss_test=0.8104, acc_test=0.6324
# poison_percent 40 epoch 18: loss_train=0.9803, acc_train=0.6000, loss_test=0.5951, acc_test=0.8505
# poison_percent 40 epoch 19: loss_train=0.5406, acc_train=0.8000, loss_test=0.7117, acc_test=0.7335
# poison_percent 40 epoch 20: loss_train=1.3130, acc_train=0.4000, loss_test=0.7082, acc_test=0.7341
# poison_percent 40 epoch 21: loss_train=0.6149, acc_train=0.6000, loss_test=0.6840, acc_test=0.7549
# poison_percent 40 epoch 22: loss_train=1.5121, acc_train=0.2000, loss_test=0.6569, acc_test=0.7812
# poison_percent 40 epoch 23: loss_train=1.2478, acc_train=0.4000, loss_test=0.7500, acc_test=0.6869
# poison_percent 40 epoch 24: loss_train=0.8197, acc_train=0.4000, loss_test=0.7036, acc_test=0.7322
# poison_percent 40 epoch 25: loss_train=0.5886, acc_train=0.8000, loss_test=0.7042, acc_test=0.7310
# poison_percent 40 epoch 26: loss_train=0.7470, acc_train=0.7000, loss_test=0.6645, acc_test=0.7751
# poison_percent 40 epoch 27: loss_train=0.6727, acc_train=0.6000, loss_test=0.5917, acc_test=0.8487
# poison_percent 40 epoch 28: loss_train=0.8719, acc_train=0.4000, loss_test=0.6401, acc_test=0.7892
# poison_percent 40 epoch 29: loss_train=0.8346, acc_train=0.4000, loss_test=0.7879, acc_test=0.6532
# poison_percent 40 epoch 30: loss_train=0.5343, acc_train=0.9000, loss_test=0.6895, acc_test=0.7580
# poison_percent 40 epoch 31: loss_train=0.7842, acc_train=0.7000, loss_test=0.6790, acc_test=0.7659
# poison_percent 40 epoch 32: loss_train=0.6762, acc_train=0.7000, loss_test=0.6824, acc_test=0.7426
# poison_percent 40 epoch 33: loss_train=1.5000, acc_train=0.4000, loss_test=0.7120, acc_test=0.7212
# poison_percent 40 epoch 34: loss_train=0.7039, acc_train=0.6000, loss_test=0.5532, acc_test=0.8713
# poison_percent 40 epoch 35: loss_train=0.7177, acc_train=0.7000, loss_test=0.6353, acc_test=0.7966
# poison_percent 40 epoch 36: loss_train=0.8823, acc_train=0.4000, loss_test=0.6441, acc_test=0.8088
# poison_percent 40 epoch 37: loss_train=0.8246, acc_train=0.6000, loss_test=0.6915, acc_test=0.7598
# poison_percent 40 epoch 38: loss_train=0.7155, acc_train=0.6000, loss_test=0.6524, acc_test=0.7990
# poison_percent 40 epoch 39: loss_train=1.1692, acc_train=0.6000, loss_test=0.6803, acc_test=0.7721
# poison_percent 40 epoch 40: loss_train=0.7100, acc_train=0.8000, loss_test=0.6331, acc_test=0.8174
# poison_percent 40 epoch 41: loss_train=1.7782, acc_train=0.6000, loss_test=0.7079, acc_test=0.7102
# poison_percent 40 epoch 42: loss_train=0.8003, acc_train=0.7000, loss_test=0.6234, acc_test=0.8309
# poison_percent 40 epoch 43: loss_train=1.6190, acc_train=0.3000, loss_test=0.6750, acc_test=0.7494
# poison_percent 40 epoch 44: loss_train=0.7510, acc_train=0.6000, loss_test=0.7327, acc_test=0.6906
# poison_percent 40 epoch 45: loss_train=0.6716, acc_train=0.8000, loss_test=0.6408, acc_test=0.8137
# poison_percent 40 epoch 46: loss_train=0.9222, acc_train=0.3000, loss_test=0.7512, acc_test=0.6458
# poison_percent 40 epoch 47: loss_train=0.8419, acc_train=0.7000, loss_test=0.6657, acc_test=0.7739
# poison_percent 40 epoch 48: loss_train=1.5572, acc_train=0.6000, loss_test=0.7307, acc_test=0.7249
# poison_percent 40 epoch 49: loss_train=0.8931, acc_train=0.6000, loss_test=0.6275, acc_test=0.8143
# poison_percent 40 epoch 50: loss_train=0.6443, acc_train=0.6000, loss_test=0.5443, acc_test=0.8707
# poison_percent 40 epoch 51: loss_train=1.0261, acc_train=0.3000, loss_test=0.6356, acc_test=0.8100
# poison_percent 40 epoch 52: loss_train=1.0377, acc_train=0.4000, loss_test=0.6543, acc_test=0.7776
# poison_percent 40 epoch 53: loss_train=0.5873, acc_train=0.7000, loss_test=0.6260, acc_test=0.7966
# poison_percent 40 epoch 54: loss_train=1.0180, acc_train=0.4000, loss_test=0.6090, acc_test=0.8438
# poison_percent 40 epoch 55: loss_train=0.9064, acc_train=0.4000, loss_test=0.6490, acc_test=0.7837
# poison_percent 40 epoch 56: loss_train=0.7190, acc_train=0.6000, loss_test=0.6143, acc_test=0.8186
