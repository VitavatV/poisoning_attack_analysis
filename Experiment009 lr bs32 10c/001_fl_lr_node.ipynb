# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
# def binary_cross_entropy(pred, target):
#     eps = 1e-7
#     pred = torch.clamp(pred, eps, 1 - eps)
#     return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

def multiclass_cross_entropy(logits, target, from_probs=False, eps=1e-7):
    """
    Cross-entropy loss for multiclass (e.g., 10 classes).
    - logits: Tensor shape (N, C) containing raw scores (preferred) or probabilities if from_probs=True
    - target: Tensor shape (N,) or (N,1) containing class indices (0..C-1)
    """
    if logits.dim() == 1:
        logits = logits.unsqueeze(0)
    target = target.squeeze()
    if target.dtype != torch.long:
        target = target.long()
    if from_probs:
        probs = torch.clamp(logits, eps, 1.0 - eps)
        log_probs = torch.log(probs)
        return -log_probs[torch.arange(target.size(0)), target].mean()
    return nn.functional.cross_entropy(logits, target)

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    model = MNISTNet().to(device)
    model.load_state_dict(global_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end]
            yb = y_c_tensor[start:end]
            outputs = model(xb)
            # preds = (outputs >= 0.5).float()
            preds = torch.argmax(outputs, dim=1, keepdim=True)
            loss = multiclass_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # Return a deepcopy to avoid issues with state_dict references
    return copy.deepcopy(model.state_dict()), X_c_tensor.size(0), yb, outputs, preds

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 32
N_CLASSES = 10

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_multiple_poison/train"
TEST_PATH = "../data/mnist_multiple_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
for NODE in [1,2,4,8,16,32]:
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, N_CLASSES)
            self.relu = nn.ReLU()
        def forward(self, x):
            x = self.fc1(x)
            x = self.relu(x)
            x = self.fc2(x)
            # x = torch.sigmoid(x)
            return x

    BATCH_SIZE_list = [BATCH_SIZE]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        global_model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"FL_ModelN{NODE}L2_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                torch.save(global_model, os.path.join(save_path,'model_init.pt'))
                global_weights = global_model.state_dict()

                records = []

                X_train_tensor = {}
                y_train_tensor = {}
                for i in range(N_HONEST):
                    X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"honest_{i}"] = X_c_tensor
                    y_train_tensor[f"honest_{i}"] = y_c_tensor
                for i in range(i_poisoned):
                    X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"poison_{i}"] = X_c_tensor
                    y_train_tensor[f"poison_{i}"] = y_c_tensor

                # Training loop
                for round in range(ROUNDS):
                    # Prepare arguments for honest clients
                    
                    #randomize the training data
                    for i in range(N_HONEST):
                        perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                        X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                        y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                    honest_args = [
                        (
                            X_train_tensor[f"honest_{i}"],
                            y_train_tensor[f"honest_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(N_HONEST)
                    ]

                    # Prepare arguments for poisoned clients
                    
                    #randomize the training data
                    for i in range(i_poisoned):
                        perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                        X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                        y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                    poison_args = [
                        (
                            X_train_tensor[f"poison_{i}"],
                            y_train_tensor[f"poison_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(i_poisoned)
                    ]

                    # Run in parallel
                    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                        honest_results = list(executor.map(train_local_worker, honest_args))
                        poison_results = list(executor.map(train_local_worker, poison_args))

                    local_weights = []
                    local_sizes = []
                    local_y = []
                    local_outputs = []
                    local_preds = []
                    for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                        local_weights.append(l_w)
                        local_sizes.append(l_sz)
                        local_y.extend(l_y)
                        local_outputs.extend(l_out)
                        local_preds.extend(l_pred)
                    loss_train = multiclass_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                    acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                    # Federated averaging (weighted by client data size)
                    new_weights = {}
                    for key in global_weights.keys():
                        new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                    global_weights = new_weights
                    global_model.load_state_dict(global_weights)

                    # Evaluate
                    global_model.eval()
                    with torch.no_grad():
                        outputs = global_model(X_test_tensor)
                        # preds = (outputs > 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        loss_test = multiclass_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'round': round, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"round {round}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(global_model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['round'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['round'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 round 0: loss_train=0.7079, acc_train=0.4915, loss_test=0.7007, acc_test=0.5000
# poison_percent 0 round 1: loss_train=0.6958, acc_train=0.5000, loss_test=0.6892, acc_test=0.5000
# poison_percent 0 round 2: loss_train=0.6785, acc_train=0.5069, loss_test=0.6711, acc_test=0.5000
# poison_percent 0 round 3: loss_train=0.6591, acc_train=0.5069, loss_test=0.6529, acc_test=0.5000
# poison_percent 0 round 4: loss_train=0.6473, acc_train=0.4935, loss_test=0.6359, acc_test=0.5000
# poison_percent 0 round 5: loss_train=0.6251, acc_train=0.5069, loss_test=0.6201, acc_test=0.5000
# poison_percent 0 round 6: loss_train=0.6073, acc_train=0.5127, loss_test=0.6053, acc_test=0.5000
# poison_percent 0 round 7: loss_train=0.6014, acc_train=0.4942, loss_test=0.5914, acc_test=0.5000
# poison_percent 0 round 8: loss_train=0.5841, acc_train=0.5035, loss_test=0.5786, acc_test=0.5000
# poison_percent 0 round 9: loss_train=0.5699, acc_train=0.5050, loss_test=0.5667, acc_test=0.5000
# poison_percent 0 round 10: loss_train=0.5547, acc_train=0.5123, loss_test=0.5556, acc_test=0.5000
# poison_percent 0 round 11: loss_train=0.5530, acc_train=0.4988, loss_test=0.5453, acc_test=0.5000
# poison_percent 0 round 12: loss_train=0.5423, acc_train=0.4985, loss_test=0.5357, acc_test=0.5000
# poison_percent 0 round 13: loss_train=0.5299, acc_train=0.5019, loss_test=0.5268, acc_test=0.5000
# poison_percent 0 round 14: loss_train=0.5178, acc_train=0.5062, loss_test=0.5186, acc_test=0.5000
# poison_percent 0 round 15: loss_train=0.5233, acc_train=0.4900, loss_test=0.5110, acc_test=0.5000
# poison_percent 0 round 16: loss_train=0.5113, acc_train=0.4973, loss_test=0.5040, acc_test=0.5000
# poison_percent 0 round 17: loss_train=0.4889, acc_train=0.5150, loss_test=0.4976, acc_test=0.5000
# poison_percent 0 round 18: loss_train=0.4975, acc_train=0.4958, loss_test=0.4915, acc_test=0.5000
# poison_percent 0 round 19: loss_train=0.4774, acc_train=0.5162, loss_test=0.4860, acc_test=0.5000
# poison_percent 0 round 20: loss_train=0.4894, acc_train=0.4942, loss_test=0.4808, acc_test=0.5000
# poison_percent 0 round 21: loss_train=0.4798, acc_train=0.4985, loss_test=0.4761, acc_test=0.5000
# poison_percent 0 round 22: loss_train=0.4792, acc_train=0.4954, loss_test=0.4717, acc_test=0.5000
# poison_percent 0 round 23: loss_train=0.4707, acc_train=0.4996, loss_test=0.4676, acc_test=0.5000
# poison_percent 0 round 24: loss_train=0.4727, acc_train=0.4915, loss_test=0.4638, acc_test=0.5000
# poison_percent 0 round 25: loss_train=0.4621, acc_train=0.5027, loss_test=0.4603, acc_test=0.5000
# poison_percent 0 round 26: loss_train=0.4612, acc_train=0.4977, loss_test=0.4570, acc_test=0.5000
# poison_percent 0 round 27: loss_train=0.4514, acc_train=0.5088, loss_test=0.4539, acc_test=0.5000
# poison_percent 0 round 28: loss_train=0.4579, acc_train=0.4969, loss_test=0.4511, acc_test=0.5000
# poison_percent 0 round 29: loss_train=0.4447, acc_train=0.5092, loss_test=0.4484, acc_test=0.5000
# poison_percent 0 round 30: loss_train=0.4539, acc_train=0.4946, loss_test=0.4459, acc_test=0.5000
# poison_percent 0 round 31: loss_train=0.4448, acc_train=0.5023, loss_test=0.4436, acc_test=0.5000
# poison_percent 0 round 32: loss_train=0.4427, acc_train=0.5012, loss_test=0.4414, acc_test=0.5000
# poison_percent 0 round 33: loss_train=0.4419, acc_train=0.5019, loss_test=0.4394, acc_test=0.5000
# poison_percent 0 round 34: loss_train=0.4420, acc_train=0.4988, loss_test=0.4374, acc_test=0.5000
# poison_percent 0 round 35: loss_train=0.4363, acc_train=0.5019, loss_test=0.4355, acc_test=0.5000
# poison_percent 0 round 36: loss_train=0.4324, acc_train=0.5062, loss_test=0.4337, acc_test=0.5000
# poison_percent 0 round 37: loss_train=0.4215, acc_train=0.5185, loss_test=0.4320, acc_test=0.5000
# poison_percent 0 round 38: loss_train=0.4326, acc_train=0.5019, loss_test=0.4304, acc_test=0.5000
# poison_percent 0 round 39: loss_train=0.4292, acc_train=0.5031, loss_test=0.4289, acc_test=0.5000
# poison_percent 0 round 40: loss_train=0.4278, acc_train=0.5035, loss_test=0.4275, acc_test=0.5000
# poison_percent 0 round 41: loss_train=0.4295, acc_train=0.4973, loss_test=0.4261, acc_test=0.5000
# poison_percent 0 round 42: loss_train=0.4309, acc_train=0.4954, loss_test=0.4248, acc_test=0.5000
# poison_percent 0 round 43: loss_train=0.4172, acc_train=0.5146, loss_test=0.4235, acc_test=0.5000
# poison_percent 0 round 44: loss_train=0.4308, acc_train=0.4950, loss_test=0.4223, acc_test=0.5000
# poison_percent 0 round 45: loss_train=0.4230, acc_train=0.5012, loss_test=0.4211, acc_test=0.5000
# poison_percent 0 round 46: loss_train=0.4161, acc_train=0.5115, loss_test=0.4199, acc_test=0.5000
# poison_percent 0 round 47: loss_train=0.4195, acc_train=0.5038, loss_test=0.4188, acc_test=0.5000
# poison_percent 0 round 48: loss_train=0.4144, acc_train=0.5065, loss_test=0.4177, acc_test=0.5000
# poison_percent 0 round 49: loss_train=0.4169, acc_train=0.5042, loss_test=0.4167, acc_test=0.5000
# poison_percent 0 round 50: loss_train=0.4121, acc_train=0.5088, loss_test=0.4157, acc_test=0.5000
# poison_percent 0 round 51: loss_train=0.4240, acc_train=0.4915, loss_test=0.4148, acc_test=0.5000
# poison_percent 0 round 52: loss_train=0.4097, acc_train=0.5092, loss_test=0.4139, acc_test=0.5000
# poison_percent 0 round 53: loss_train=0.4130, acc_train=0.5012, loss_test=0.4130, acc_test=0.5000
# poison_percent 0 round 54: loss_train=0.4124, acc_train=0.5031, loss_test=0.4121, acc_test=0.5000
# poison_percent 0 round 55: loss_train=0.4117, acc_train=0.5027, loss_test=0.4113, acc_test=0.5000
# poison_percent 0 round 56: loss_train=0.4161, acc_train=0.4981, loss_test=0.4105, acc_test=0.5000
# poison_percent 0 round 57: loss_train=0.4121, acc_train=0.4973, loss_test=0.4097, acc_test=0.5000
# poison_percent 0 round 58: loss_train=0.4177, acc_train=0.4938, loss_test=0.4089, acc_test=0.5000
# poison_percent 0 round 59: loss_train=0.4155, acc_train=0.4954, loss_test=0.4082, acc_test=0.5000
# poison_percent 0 round 60: loss_train=0.4093, acc_train=0.5008, loss_test=0.4075, acc_test=0.5000
# poison_percent 0 round 61: loss_train=0.3993, acc_train=0.5123, loss_test=0.4069, acc_test=0.5000
# poison_percent 0 round 62: loss_train=0.4204, acc_train=0.4862, loss_test=0.4061, acc_test=0.5000
# poison_percent 0 round 63: loss_train=0.4137, acc_train=0.4935, loss_test=0.4055, acc_test=0.5000
# poison_percent 0 round 64: loss_train=0.4094, acc_train=0.5004, loss_test=0.4048, acc_test=0.5000
# poison_percent 0 round 65: loss_train=0.4159, acc_train=0.4923, loss_test=0.4042, acc_test=0.5000
# poison_percent 0 round 66: loss_train=0.4075, acc_train=0.4954, loss_test=0.4035, acc_test=0.5000
# poison_percent 0 round 67: loss_train=0.4122, acc_train=0.4915, loss_test=0.4028, acc_test=0.5000
# poison_percent 0 round 68: loss_train=0.4035, acc_train=0.5038, loss_test=0.4022, acc_test=0.5000
# poison_percent 0 round 69: loss_train=0.4019, acc_train=0.5042, loss_test=0.4015, acc_test=0.5000
# poison_percent 0 round 70: loss_train=0.4048, acc_train=0.5015, loss_test=0.4009, acc_test=0.5000
# poison_percent 0 round 71: loss_train=0.3994, acc_train=0.5031, loss_test=0.4003, acc_test=0.5000
# poison_percent 0 round 72: loss_train=0.4152, acc_train=0.4858, loss_test=0.3998, acc_test=0.5000
# poison_percent 0 round 73: loss_train=0.4024, acc_train=0.5008, loss_test=0.3992, acc_test=0.5000
# poison_percent 0 round 74: loss_train=0.3989, acc_train=0.5012, loss_test=0.3986, acc_test=0.5000
# poison_percent 0 round 75: loss_train=0.3981, acc_train=0.5012, loss_test=0.3979, acc_test=0.5000
# poison_percent 0 round 76: loss_train=0.4126, acc_train=0.4888, loss_test=0.3974, acc_test=0.5000
# poison_percent 0 round 77: loss_train=0.3940, acc_train=0.5058, loss_test=0.3969, acc_test=0.5000
# poison_percent 0 round 78: loss_train=0.4118, acc_train=0.4796, loss_test=0.3963, acc_test=0.5000
# poison_percent 0 round 79: loss_train=0.3950, acc_train=0.5058, loss_test=0.3957, acc_test=0.5000
# poison_percent 0 round 80: loss_train=0.3799, acc_train=0.5200, loss_test=0.3951, acc_test=0.5000
# poison_percent 0 round 81: loss_train=0.4046, acc_train=0.4892, loss_test=0.3946, acc_test=0.5000
# poison_percent 0 round 82: loss_train=0.3994, acc_train=0.4992, loss_test=0.3941, acc_test=0.5000
# poison_percent 0 round 83: loss_train=0.3975, acc_train=0.4988, loss_test=0.3936, acc_test=0.5000
# poison_percent 0 round 84: loss_train=0.4072, acc_train=0.4881, loss_test=0.3931, acc_test=0.5000
# poison_percent 0 round 85: loss_train=0.4013, acc_train=0.4962, loss_test=0.3926, acc_test=0.5000
# poison_percent 0 round 86: loss_train=0.3905, acc_train=0.5081, loss_test=0.3921, acc_test=0.5000
# poison_percent 0 round 87: loss_train=0.3910, acc_train=0.5004, loss_test=0.3916, acc_test=0.5000
# poison_percent 0 round 88: loss_train=0.3931, acc_train=0.4962, loss_test=0.3910, acc_test=0.5000
# poison_percent 0 round 89: loss_train=0.3995, acc_train=0.4900, loss_test=0.3905, acc_test=0.5000
# poison_percent 0 round 90: loss_train=0.3819, acc_train=0.5104, loss_test=0.3900, acc_test=0.5000
# poison_percent 0 round 91: loss_train=0.3846, acc_train=0.5027, loss_test=0.3894, acc_test=0.5000
# poison_percent 0 round 92: loss_train=0.3932, acc_train=0.4958, loss_test=0.3889, acc_test=0.5000
# poison_percent 0 round 93: loss_train=0.3906, acc_train=0.4985, loss_test=0.3884, acc_test=0.5000
# poison_percent 0 round 94: loss_train=0.3986, acc_train=0.4919, loss_test=0.3879, acc_test=0.5000
# poison_percent 0 round 95: loss_train=0.3958, acc_train=0.4938, loss_test=0.3875, acc_test=0.5000
# poison_percent 0 round 96: loss_train=0.3917, acc_train=0.4958, loss_test=0.3870, acc_test=0.5000
# poison_percent 0 round 97: loss_train=0.3931, acc_train=0.4958, loss_test=0.3866, acc_test=0.5000
# poison_percent 0 round 98: loss_train=0.4011, acc_train=0.4885, loss_test=0.3861, acc_test=0.5000
# poison_percent 0 round 99: loss_train=0.4010, acc_train=0.4919, loss_test=0.3857, acc_test=0.5000
# Training log saved to ./results\FL_ModelN1L2_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 round 0: loss_train=0.7670, acc_train=0.5031, loss_test=0.3850, acc_test=0.5000
# poison_percent 10 round 1: loss_train=0.8000, acc_train=0.5027, loss_test=0.3844, acc_test=0.5000
# poison_percent 10 round 2: loss_train=0.7723, acc_train=0.5082, loss_test=0.3838, acc_test=0.5000
# poison_percent 10 round 3: loss_train=0.8403, acc_train=0.4804, loss_test=0.3832, acc_test=0.5000
# poison_percent 10 round 4: loss_train=0.7964, acc_train=0.4942, loss_test=0.3826, acc_test=0.5000
# poison_percent 10 round 5: loss_train=0.8144, acc_train=0.4969, loss_test=0.3820, acc_test=0.5000
# poison_percent 10 round 6: loss_train=0.7771, acc_train=0.5100, loss_test=0.3814, acc_test=0.5000
# poison_percent 10 round 7: loss_train=0.8167, acc_train=0.4849, loss_test=0.3809, acc_test=0.5000
# poison_percent 10 round 8: loss_train=0.7811, acc_train=0.5089, loss_test=0.3803, acc_test=0.5000
# poison_percent 10 round 9: loss_train=0.7961, acc_train=0.4959, loss_test=0.3798, acc_test=0.5000
# poison_percent 10 round 10: loss_train=0.8122, acc_train=0.5086, loss_test=0.3792, acc_test=0.5000
# poison_percent 10 round 11: loss_train=0.7843, acc_train=0.5089, loss_test=0.3787, acc_test=0.5000
# poison_percent 10 round 12: loss_train=0.8069, acc_train=0.5062, loss_test=0.3782, acc_test=0.5000
# poison_percent 10 round 13: loss_train=0.8084, acc_train=0.4986, loss_test=0.3777, acc_test=0.5000
# poison_percent 10 round 14: loss_train=0.8298, acc_train=0.4900, loss_test=0.3772, acc_test=0.5000
# poison_percent 10 round 15: loss_train=0.8424, acc_train=0.4986, loss_test=0.3766, acc_test=0.5000
# poison_percent 10 round 16: loss_train=0.8214, acc_train=0.5031, loss_test=0.3761, acc_test=0.5000
# poison_percent 10 round 17: loss_train=0.8339, acc_train=0.4990, loss_test=0.3756, acc_test=0.5000
# poison_percent 10 round 18: loss_train=0.8253, acc_train=0.4979, loss_test=0.3751, acc_test=0.5000
# poison_percent 10 round 19: loss_train=0.8150, acc_train=0.5034, loss_test=0.3746, acc_test=0.5000
# poison_percent 10 round 20: loss_train=0.8272, acc_train=0.4959, loss_test=0.3741, acc_test=0.5000
# poison_percent 10 round 21: loss_train=0.7902, acc_train=0.4976, loss_test=0.3736, acc_test=0.5000
# poison_percent 10 round 22: loss_train=0.8309, acc_train=0.4918, loss_test=0.3731, acc_test=0.5000
# poison_percent 10 round 23: loss_train=0.8492, acc_train=0.4938, loss_test=0.3727, acc_test=0.5000
# poison_percent 10 round 24: loss_train=0.8189, acc_train=0.5072, loss_test=0.3721, acc_test=0.5000
# poison_percent 10 round 25: loss_train=0.8391, acc_train=0.5052, loss_test=0.3716, acc_test=0.5000
# poison_percent 10 round 26: loss_train=0.8184, acc_train=0.5031, loss_test=0.3711, acc_test=0.5000
# poison_percent 10 round 27: loss_train=0.8627, acc_train=0.4907, loss_test=0.3705, acc_test=0.5000
# poison_percent 10 round 28: loss_train=0.8701, acc_train=0.4986, loss_test=0.3701, acc_test=0.5000
# poison_percent 10 round 29: loss_train=0.8692, acc_train=0.4928, loss_test=0.3696, acc_test=0.5000
# poison_percent 10 round 30: loss_train=0.8373, acc_train=0.4973, loss_test=0.3691, acc_test=0.5000
# poison_percent 10 round 31: loss_train=0.8425, acc_train=0.4952, loss_test=0.3686, acc_test=0.5000
# poison_percent 10 round 32: loss_train=0.8462, acc_train=0.5076, loss_test=0.3681, acc_test=0.5000
# poison_percent 10 round 33: loss_train=0.8373, acc_train=0.4983, loss_test=0.3677, acc_test=0.5000
# poison_percent 10 round 34: loss_train=0.7992, acc_train=0.5082, loss_test=0.3672, acc_test=0.5000
# poison_percent 10 round 35: loss_train=0.8488, acc_train=0.4955, loss_test=0.3667, acc_test=0.5000
# poison_percent 10 round 36: loss_train=0.8791, acc_train=0.4983, loss_test=0.3663, acc_test=0.5000
# poison_percent 10 round 37: loss_train=0.8313, acc_train=0.5003, loss_test=0.3658, acc_test=0.5000
# poison_percent 10 round 38: loss_train=0.8471, acc_train=0.5079, loss_test=0.3652, acc_test=0.5000
# poison_percent 10 round 39: loss_train=0.8550, acc_train=0.4942, loss_test=0.3648, acc_test=0.5000
# poison_percent 10 round 40: loss_train=0.8353, acc_train=0.5003, loss_test=0.3643, acc_test=0.5000
# poison_percent 10 round 41: loss_train=0.8766, acc_train=0.4904, loss_test=0.3638, acc_test=0.5000
# poison_percent 10 round 42: loss_train=0.8489, acc_train=0.4990, loss_test=0.3633, acc_test=0.5000
# poison_percent 10 round 43: loss_train=0.8431, acc_train=0.5021, loss_test=0.3629, acc_test=0.5000
# poison_percent 10 round 44: loss_train=0.8766, acc_train=0.4952, loss_test=0.3624, acc_test=0.5000
# poison_percent 10 round 45: loss_train=0.8648, acc_train=0.5058, loss_test=0.3619, acc_test=0.5000
# poison_percent 10 round 46: loss_train=0.8330, acc_train=0.4997, loss_test=0.3615, acc_test=0.5000
# poison_percent 10 round 47: loss_train=0.8287, acc_train=0.5052, loss_test=0.3610, acc_test=0.5000
# poison_percent 10 round 48: loss_train=0.8481, acc_train=0.8719, loss_test=0.3606, acc_test=0.9740
# poison_percent 10 round 49: loss_train=0.8592, acc_train=0.8702, loss_test=0.3601, acc_test=0.9740
# poison_percent 10 round 50: loss_train=0.8330, acc_train=0.8747, loss_test=0.3596, acc_test=0.9740
# poison_percent 10 round 51: loss_train=0.8700, acc_train=0.8760, loss_test=0.3591, acc_test=0.9740
# poison_percent 10 round 52: loss_train=0.8391, acc_train=0.8723, loss_test=0.3587, acc_test=0.9740
# poison_percent 10 round 53: loss_train=0.8746, acc_train=0.8771, loss_test=0.3582, acc_test=0.9740
# poison_percent 10 round 54: loss_train=0.8614, acc_train=0.8774, loss_test=0.3578, acc_test=0.9740
# poison_percent 10 round 55: loss_train=0.8506, acc_train=0.8750, loss_test=0.3573, acc_test=0.9740
# poison_percent 10 round 56: loss_train=0.8697, acc_train=0.8736, loss_test=0.3569, acc_test=0.9740
# poison_percent 10 round 57: loss_train=0.8821, acc_train=0.8757, loss_test=0.3564, acc_test=0.9745
# poison_percent 10 round 58: loss_train=0.8696, acc_train=0.8747, loss_test=0.3559, acc_test=0.9745
# poison_percent 10 round 59: loss_train=0.8809, acc_train=0.8723, loss_test=0.3555, acc_test=0.9745
# poison_percent 10 round 60: loss_train=0.8948, acc_train=0.8736, loss_test=0.3551, acc_test=0.9745
# poison_percent 10 round 61: loss_train=0.8539, acc_train=0.8671, loss_test=0.3547, acc_test=0.9740
# poison_percent 10 round 62: loss_train=0.8961, acc_train=0.8688, loss_test=0.3543, acc_test=0.9740
# poison_percent 10 round 63: loss_train=0.9064, acc_train=0.8743, loss_test=0.3538, acc_test=0.9740
# poison_percent 10 round 64: loss_train=0.8504, acc_train=0.8750, loss_test=0.3533, acc_test=0.9750
# poison_percent 10 round 65: loss_train=0.8681, acc_train=0.8740, loss_test=0.3529, acc_test=0.9750
# poison_percent 10 round 66: loss_train=0.8387, acc_train=0.8729, loss_test=0.3524, acc_test=0.9755
# poison_percent 10 round 67: loss_train=0.8601, acc_train=0.8747, loss_test=0.3520, acc_test=0.9755
# poison_percent 10 round 68: loss_train=0.8934, acc_train=0.8726, loss_test=0.3516, acc_test=0.9755
# poison_percent 10 round 69: loss_train=0.8324, acc_train=0.8747, loss_test=0.3511, acc_test=0.9755
# poison_percent 10 round 70: loss_train=0.9065, acc_train=0.8736, loss_test=0.3506, acc_test=0.9755
# poison_percent 10 round 71: loss_train=0.9166, acc_train=0.8750, loss_test=0.3501, acc_test=0.9755
# poison_percent 10 round 72: loss_train=0.9334, acc_train=0.8747, loss_test=0.3497, acc_test=0.9755
# poison_percent 10 round 73: loss_train=0.9191, acc_train=0.8740, loss_test=0.3492, acc_test=0.9755
# poison_percent 10 round 74: loss_train=0.8537, acc_train=0.8743, loss_test=0.3487, acc_test=0.9755
# poison_percent 10 round 75: loss_train=0.9073, acc_train=0.8774, loss_test=0.3483, acc_test=0.9755
# poison_percent 10 round 76: loss_train=0.9041, acc_train=0.8757, loss_test=0.3478, acc_test=0.9755
# poison_percent 10 round 77: loss_train=0.8881, acc_train=0.8777, loss_test=0.3473, acc_test=0.9760
# poison_percent 10 round 78: loss_train=0.9295, acc_train=0.8753, loss_test=0.3468, acc_test=0.9760
# poison_percent 10 round 79: loss_train=0.9300, acc_train=0.8771, loss_test=0.3463, acc_test=0.9760
# poison_percent 10 round 80: loss_train=0.9280, acc_train=0.8726, loss_test=0.3459, acc_test=0.9760
# poison_percent 10 round 81: loss_train=0.9038, acc_train=0.8743, loss_test=0.3455, acc_test=0.9760
# poison_percent 10 round 82: loss_train=0.8953, acc_train=0.8764, loss_test=0.3450, acc_test=0.9760
# poison_percent 10 round 83: loss_train=0.8866, acc_train=0.8740, loss_test=0.3446, acc_test=0.9760
# poison_percent 10 round 84: loss_train=0.9526, acc_train=0.8757, loss_test=0.3441, acc_test=0.9760
# poison_percent 10 round 85: loss_train=0.9214, acc_train=0.8733, loss_test=0.3437, acc_test=0.9760
# poison_percent 10 round 86: loss_train=0.8710, acc_train=0.8781, loss_test=0.3432, acc_test=0.9760
# poison_percent 10 round 87: loss_train=0.9117, acc_train=0.8767, loss_test=0.3428, acc_test=0.9760
# poison_percent 10 round 88: loss_train=0.9271, acc_train=0.8753, loss_test=0.3423, acc_test=0.9765
# poison_percent 10 round 89: loss_train=0.8738, acc_train=0.8767, loss_test=0.3419, acc_test=0.9765
# poison_percent 10 round 90: loss_train=0.8968, acc_train=0.8729, loss_test=0.3414, acc_test=0.9765
# poison_percent 10 round 91: loss_train=0.8452, acc_train=0.8767, loss_test=0.3410, acc_test=0.9765
# poison_percent 10 round 92: loss_train=0.9169, acc_train=0.8743, loss_test=0.3406, acc_test=0.9765
# poison_percent 10 round 93: loss_train=0.9223, acc_train=0.8750, loss_test=0.3401, acc_test=0.9765
# poison_percent 10 round 94: loss_train=0.8985, acc_train=0.8733, loss_test=0.3397, acc_test=0.9765
# poison_percent 10 round 95: loss_train=0.9759, acc_train=0.8740, loss_test=0.3393, acc_test=0.9765
# poison_percent 10 round 96: loss_train=0.9477, acc_train=0.8753, loss_test=0.3388, acc_test=0.9765
# poison_percent 10 round 97: loss_train=0.9489, acc_train=0.8753, loss_test=0.3384, acc_test=0.9765
# poison_percent 10 round 98: loss_train=0.9079, acc_train=0.8771, loss_test=0.3379, acc_test=0.9776
# poison_percent 10 round 99: loss_train=0.9255, acc_train=0.8788, loss_test=0.3374, acc_test=0.9776
# Training log saved to ./results\FL_ModelN1L2_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=1.4266, acc_train=0.7837, loss_test=0.3369, acc_test=0.9776
# poison_percent 20 round 1: loss_train=1.4185, acc_train=0.7908, loss_test=0.3363, acc_test=0.9776
# poison_percent 20 round 2: loss_train=1.4825, acc_train=0.7852, loss_test=0.3357, acc_test=0.9776
# poison_percent 20 round 3: loss_train=1.3889, acc_train=0.7852, loss_test=0.3352, acc_test=0.9776
# poison_percent 20 round 4: loss_train=1.4229, acc_train=0.7902, loss_test=0.3346, acc_test=0.9776
# poison_percent 20 round 5: loss_train=1.4140, acc_train=0.7877, loss_test=0.3340, acc_test=0.9781
# poison_percent 20 round 6: loss_train=1.4620, acc_train=0.7874, loss_test=0.3335, acc_test=0.9781
# poison_percent 20 round 7: loss_train=1.4342, acc_train=0.7877, loss_test=0.3330, acc_test=0.9786
# poison_percent 20 round 8: loss_train=1.4257, acc_train=0.7895, loss_test=0.3325, acc_test=0.9786
# poison_percent 20 round 9: loss_train=1.4468, acc_train=0.7902, loss_test=0.3319, acc_test=0.9786
# poison_percent 20 round 10: loss_train=1.4493, acc_train=0.7874, loss_test=0.3314, acc_test=0.9786
# poison_percent 20 round 11: loss_train=1.4819, acc_train=0.7917, loss_test=0.3308, acc_test=0.9796
# poison_percent 20 round 12: loss_train=1.4298, acc_train=0.7905, loss_test=0.3303, acc_test=0.9796
# poison_percent 20 round 13: loss_train=1.4374, acc_train=0.7898, loss_test=0.3298, acc_test=0.9796
# poison_percent 20 round 14: loss_train=1.3802, acc_train=0.7914, loss_test=0.3292, acc_test=0.9801
# poison_percent 20 round 15: loss_train=1.4947, acc_train=0.7911, loss_test=0.3287, acc_test=0.9801
# poison_percent 20 round 16: loss_train=1.4534, acc_train=0.7923, loss_test=0.3282, acc_test=0.9801
# poison_percent 20 round 17: loss_train=1.4664, acc_train=0.7902, loss_test=0.3276, acc_test=0.9801
# poison_percent 20 round 18: loss_train=1.3982, acc_train=0.7905, loss_test=0.3271, acc_test=0.9801
# poison_percent 20 round 19: loss_train=1.4369, acc_train=0.7862, loss_test=0.3266, acc_test=0.9801
# poison_percent 20 round 20: loss_train=1.3757, acc_train=0.7917, loss_test=0.3261, acc_test=0.9801
# poison_percent 20 round 21: loss_train=1.4106, acc_train=0.7917, loss_test=0.3257, acc_test=0.9801
# poison_percent 20 round 22: loss_train=1.4089, acc_train=0.7895, loss_test=0.3251, acc_test=0.9801
# poison_percent 20 round 23: loss_train=1.4852, acc_train=0.7905, loss_test=0.3246, acc_test=0.9801
# poison_percent 20 round 24: loss_train=1.4186, acc_train=0.7858, loss_test=0.3242, acc_test=0.9801
# poison_percent 20 round 25: loss_train=1.3742, acc_train=0.7905, loss_test=0.3237, acc_test=0.9801
# poison_percent 20 round 26: loss_train=1.4547, acc_train=0.7926, loss_test=0.3232, acc_test=0.9806
# poison_percent 20 round 27: loss_train=1.4678, acc_train=0.7914, loss_test=0.3227, acc_test=0.9806
# poison_percent 20 round 28: loss_train=1.5046, acc_train=0.7883, loss_test=0.3223, acc_test=0.9806
# poison_percent 20 round 29: loss_train=1.4064, acc_train=0.7920, loss_test=0.3218, acc_test=0.9806
# poison_percent 20 round 30: loss_train=1.4630, acc_train=0.7880, loss_test=0.3214, acc_test=0.9806
# poison_percent 20 round 31: loss_train=1.4497, acc_train=0.7914, loss_test=0.3209, acc_test=0.9816
# poison_percent 20 round 32: loss_train=1.4361, acc_train=0.7920, loss_test=0.3204, acc_test=0.9816
# poison_percent 20 round 33: loss_train=1.4597, acc_train=0.7914, loss_test=0.3199, acc_test=0.9821
# poison_percent 20 round 34: loss_train=1.4452, acc_train=0.7908, loss_test=0.3194, acc_test=0.9821
# poison_percent 20 round 35: loss_train=1.5398, acc_train=0.7942, loss_test=0.3190, acc_test=0.9827
# poison_percent 20 round 36: loss_train=1.4630, acc_train=0.7877, loss_test=0.3185, acc_test=0.9827
# poison_percent 20 round 37: loss_train=1.5402, acc_train=0.7911, loss_test=0.3181, acc_test=0.9827
# poison_percent 20 round 38: loss_train=1.4182, acc_train=0.7911, loss_test=0.3176, acc_test=0.9827
# poison_percent 20 round 39: loss_train=1.4810, acc_train=0.7905, loss_test=0.3172, acc_test=0.9827
# poison_percent 20 round 40: loss_train=1.4394, acc_train=0.7923, loss_test=0.3167, acc_test=0.9827
# poison_percent 20 round 41: loss_train=1.4943, acc_train=0.7895, loss_test=0.3162, acc_test=0.9827
# poison_percent 20 round 42: loss_train=1.4847, acc_train=0.7917, loss_test=0.3158, acc_test=0.9827
# poison_percent 20 round 43: loss_train=1.4988, acc_train=0.7895, loss_test=0.3153, acc_test=0.9827
# poison_percent 20 round 44: loss_train=1.4620, acc_train=0.7895, loss_test=0.3149, acc_test=0.9827
# poison_percent 20 round 45: loss_train=1.4684, acc_train=0.7889, loss_test=0.3145, acc_test=0.9827
# poison_percent 20 round 46: loss_train=1.5231, acc_train=0.7908, loss_test=0.3140, acc_test=0.9827
# poison_percent 20 round 47: loss_train=1.5440, acc_train=0.7923, loss_test=0.3135, acc_test=0.9827
# poison_percent 20 round 48: loss_train=1.4198, acc_train=0.7889, loss_test=0.3131, acc_test=0.9827
# poison_percent 20 round 49: loss_train=1.4871, acc_train=0.7905, loss_test=0.3126, acc_test=0.9832
# poison_percent 20 round 50: loss_train=1.4873, acc_train=0.7914, loss_test=0.3122, acc_test=0.9832
# poison_percent 20 round 51: loss_train=1.5090, acc_train=0.7895, loss_test=0.3118, acc_test=0.9832
# poison_percent 20 round 52: loss_train=1.4984, acc_train=0.7920, loss_test=0.3113, acc_test=0.9832
# poison_percent 20 round 53: loss_train=1.4737, acc_train=0.7935, loss_test=0.3109, acc_test=0.9832
# poison_percent 20 round 54: loss_train=1.5288, acc_train=0.7914, loss_test=0.3104, acc_test=0.9832
# poison_percent 20 round 55: loss_train=1.4527, acc_train=0.7889, loss_test=0.3100, acc_test=0.9832
# poison_percent 20 round 56: loss_train=1.4182, acc_train=0.7908, loss_test=0.3095, acc_test=0.9832
# poison_percent 20 round 57: loss_train=1.5038, acc_train=0.7905, loss_test=0.3091, acc_test=0.9832
# poison_percent 20 round 58: loss_train=1.4176, acc_train=0.7929, loss_test=0.3087, acc_test=0.9837
# poison_percent 20 round 59: loss_train=1.5241, acc_train=0.7932, loss_test=0.3082, acc_test=0.9837
# poison_percent 20 round 60: loss_train=1.4884, acc_train=0.7923, loss_test=0.3078, acc_test=0.9837
# poison_percent 20 round 61: loss_train=1.5156, acc_train=0.7923, loss_test=0.3073, acc_test=0.9837
# poison_percent 20 round 62: loss_train=1.4068, acc_train=0.7905, loss_test=0.3069, acc_test=0.9842
# poison_percent 20 round 63: loss_train=1.5014, acc_train=0.7926, loss_test=0.3064, acc_test=0.9842
# poison_percent 20 round 64: loss_train=1.4820, acc_train=0.7923, loss_test=0.3060, acc_test=0.9842
# poison_percent 20 round 65: loss_train=1.4616, acc_train=0.7935, loss_test=0.3056, acc_test=0.9842
# poison_percent 20 round 66: loss_train=1.4292, acc_train=0.7914, loss_test=0.3052, acc_test=0.9842
# poison_percent 20 round 67: loss_train=1.4942, acc_train=0.7911, loss_test=0.3047, acc_test=0.9842
# poison_percent 20 round 68: loss_train=1.4575, acc_train=0.7917, loss_test=0.3043, acc_test=0.9842
# poison_percent 20 round 69: loss_train=1.5215, acc_train=0.7948, loss_test=0.3039, acc_test=0.9842
# poison_percent 20 round 70: loss_train=1.4489, acc_train=0.7911, loss_test=0.3035, acc_test=0.9842
# poison_percent 20 round 71: loss_train=1.4834, acc_train=0.7923, loss_test=0.3031, acc_test=0.9842
# poison_percent 20 round 72: loss_train=1.4833, acc_train=0.7926, loss_test=0.3026, acc_test=0.9847
# poison_percent 20 round 73: loss_train=1.4835, acc_train=0.7920, loss_test=0.3022, acc_test=0.9847
# poison_percent 20 round 74: loss_train=1.5149, acc_train=0.7926, loss_test=0.3018, acc_test=0.9852
# poison_percent 20 round 75: loss_train=1.4535, acc_train=0.7951, loss_test=0.3013, acc_test=0.9852
# poison_percent 20 round 76: loss_train=1.4855, acc_train=0.7892, loss_test=0.3010, acc_test=0.9852
# poison_percent 20 round 77: loss_train=1.5114, acc_train=0.7895, loss_test=0.3006, acc_test=0.9857
# poison_percent 20 round 78: loss_train=1.4752, acc_train=0.7902, loss_test=0.3001, acc_test=0.9857
# poison_percent 20 round 79: loss_train=1.4957, acc_train=0.7905, loss_test=0.2997, acc_test=0.9857
# poison_percent 20 round 80: loss_train=1.4528, acc_train=0.7960, loss_test=0.2993, acc_test=0.9857
# poison_percent 20 round 81: loss_train=1.4582, acc_train=0.7957, loss_test=0.2988, acc_test=0.9857
# poison_percent 20 round 82: loss_train=1.5548, acc_train=0.7908, loss_test=0.2984, acc_test=0.9857
# poison_percent 20 round 83: loss_train=1.4662, acc_train=0.7932, loss_test=0.2980, acc_test=0.9857
# poison_percent 20 round 84: loss_train=1.5615, acc_train=0.7914, loss_test=0.2976, acc_test=0.9857
# poison_percent 20 round 85: loss_train=1.5498, acc_train=0.7926, loss_test=0.2971, acc_test=0.9862
# poison_percent 20 round 86: loss_train=1.5018, acc_train=0.7898, loss_test=0.2968, acc_test=0.9857
# poison_percent 20 round 87: loss_train=1.5321, acc_train=0.7917, loss_test=0.2964, acc_test=0.9862
# poison_percent 20 round 88: loss_train=1.5233, acc_train=0.7895, loss_test=0.2960, acc_test=0.9862
# poison_percent 20 round 89: loss_train=1.5457, acc_train=0.7926, loss_test=0.2956, acc_test=0.9862
# poison_percent 20 round 90: loss_train=1.4893, acc_train=0.7929, loss_test=0.2951, acc_test=0.9862
# poison_percent 20 round 91: loss_train=1.5382, acc_train=0.7932, loss_test=0.2947, acc_test=0.9862
# poison_percent 20 round 92: loss_train=1.4871, acc_train=0.7935, loss_test=0.2943, acc_test=0.9862
# poison_percent 20 round 93: loss_train=1.5220, acc_train=0.7908, loss_test=0.2939, acc_test=0.9862
# poison_percent 20 round 94: loss_train=1.4876, acc_train=0.7945, loss_test=0.2935, acc_test=0.9862
# poison_percent 20 round 95: loss_train=1.5054, acc_train=0.7886, loss_test=0.2931, acc_test=0.9862
# poison_percent 20 round 96: loss_train=1.5109, acc_train=0.7917, loss_test=0.2927, acc_test=0.9862
# poison_percent 20 round 97: loss_train=1.5873, acc_train=0.7929, loss_test=0.2923, acc_test=0.9862
# poison_percent 20 round 98: loss_train=1.5321, acc_train=0.7942, loss_test=0.2919, acc_test=0.9867
# poison_percent 20 round 99: loss_train=1.5183, acc_train=0.7914, loss_test=0.2915, acc_test=0.9872
# Training log saved to ./results\FL_ModelN1L2_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=2.1338, acc_train=0.6966, loss_test=0.2909, acc_test=0.9872
# poison_percent 30 round 1: loss_train=2.2028, acc_train=0.6958, loss_test=0.2904, acc_test=0.9872
# poison_percent 30 round 2: loss_train=2.1781, acc_train=0.6971, loss_test=0.2899, acc_test=0.9872
# poison_percent 30 round 3: loss_train=2.1373, acc_train=0.6937, loss_test=0.2894, acc_test=0.9872
# poison_percent 30 round 4: loss_train=2.1570, acc_train=0.6931, loss_test=0.2888, acc_test=0.9872
# poison_percent 30 round 5: loss_train=2.1481, acc_train=0.6955, loss_test=0.2883, acc_test=0.9872
# poison_percent 30 round 6: loss_train=2.1322, acc_train=0.6963, loss_test=0.2878, acc_test=0.9878
# poison_percent 30 round 7: loss_train=2.1302, acc_train=0.6955, loss_test=0.2873, acc_test=0.9878
# poison_percent 30 round 8: loss_train=2.0998, acc_train=0.6955, loss_test=0.2868, acc_test=0.9878
# poison_percent 30 round 9: loss_train=2.0795, acc_train=0.6947, loss_test=0.2864, acc_test=0.9878
# poison_percent 30 round 10: loss_train=2.1129, acc_train=0.6958, loss_test=0.2859, acc_test=0.9878
# poison_percent 30 round 11: loss_train=2.1836, acc_train=0.6931, loss_test=0.2854, acc_test=0.9878
# poison_percent 30 round 12: loss_train=2.1391, acc_train=0.6950, loss_test=0.2849, acc_test=0.9883
# poison_percent 30 round 13: loss_train=2.1286, acc_train=0.6912, loss_test=0.2844, acc_test=0.9883
# poison_percent 30 round 14: loss_train=2.1059, acc_train=0.6950, loss_test=0.2839, acc_test=0.9883
# poison_percent 30 round 15: loss_train=2.2029, acc_train=0.6953, loss_test=0.2835, acc_test=0.9883
# poison_percent 30 round 16: loss_train=2.1288, acc_train=0.6955, loss_test=0.2830, acc_test=0.9883
# poison_percent 30 round 17: loss_train=2.1545, acc_train=0.6939, loss_test=0.2826, acc_test=0.9883
# poison_percent 30 round 18: loss_train=2.1825, acc_train=0.6955, loss_test=0.2821, acc_test=0.9883
# poison_percent 30 round 19: loss_train=2.1750, acc_train=0.6963, loss_test=0.2817, acc_test=0.9883
# poison_percent 30 round 20: loss_train=2.1754, acc_train=0.6928, loss_test=0.2812, acc_test=0.9883
# poison_percent 30 round 21: loss_train=2.1610, acc_train=0.6961, loss_test=0.2808, acc_test=0.9883
# poison_percent 30 round 22: loss_train=2.1536, acc_train=0.6942, loss_test=0.2803, acc_test=0.9883
# poison_percent 30 round 23: loss_train=2.1507, acc_train=0.6971, loss_test=0.2799, acc_test=0.9883
# poison_percent 30 round 24: loss_train=2.1955, acc_train=0.6958, loss_test=0.2795, acc_test=0.9893
# poison_percent 30 round 25: loss_train=2.1402, acc_train=0.6947, loss_test=0.2790, acc_test=0.9898
# poison_percent 30 round 26: loss_train=2.0926, acc_train=0.6969, loss_test=0.2786, acc_test=0.9898
# poison_percent 30 round 27: loss_train=2.1271, acc_train=0.6977, loss_test=0.2781, acc_test=0.9898
# poison_percent 30 round 28: loss_train=2.1816, acc_train=0.6977, loss_test=0.2777, acc_test=0.9898
# poison_percent 30 round 29: loss_train=2.1704, acc_train=0.6947, loss_test=0.2773, acc_test=0.9898
# poison_percent 30 round 30: loss_train=2.2056, acc_train=0.6953, loss_test=0.2769, acc_test=0.9898
# poison_percent 30 round 31: loss_train=2.1637, acc_train=0.6958, loss_test=0.2764, acc_test=0.9898
# poison_percent 30 round 32: loss_train=2.1527, acc_train=0.6985, loss_test=0.2760, acc_test=0.9898
# poison_percent 30 round 33: loss_train=2.2126, acc_train=0.6953, loss_test=0.2756, acc_test=0.9898
# poison_percent 30 round 34: loss_train=2.1534, acc_train=0.6963, loss_test=0.2752, acc_test=0.9898
# poison_percent 30 round 35: loss_train=2.2027, acc_train=0.6963, loss_test=0.2748, acc_test=0.9898
# poison_percent 30 round 36: loss_train=2.2020, acc_train=0.6961, loss_test=0.2743, acc_test=0.9898
# poison_percent 30 round 37: loss_train=2.0920, acc_train=0.6988, loss_test=0.2739, acc_test=0.9898
# poison_percent 30 round 38: loss_train=2.1017, acc_train=0.6963, loss_test=0.2735, acc_test=0.9898
# poison_percent 30 round 39: loss_train=2.0730, acc_train=0.6966, loss_test=0.2731, acc_test=0.9898
# poison_percent 30 round 40: loss_train=2.1448, acc_train=0.6961, loss_test=0.2727, acc_test=0.9898
# poison_percent 30 round 41: loss_train=2.2049, acc_train=0.6977, loss_test=0.2722, acc_test=0.9898
# poison_percent 30 round 42: loss_train=2.1527, acc_train=0.6982, loss_test=0.2718, acc_test=0.9898
# poison_percent 30 round 43: loss_train=2.1554, acc_train=0.6945, loss_test=0.2714, acc_test=0.9898
# poison_percent 30 round 44: loss_train=2.1547, acc_train=0.6963, loss_test=0.2710, acc_test=0.9898
# poison_percent 30 round 45: loss_train=2.0785, acc_train=0.6961, loss_test=0.2706, acc_test=0.9898
# poison_percent 30 round 46: loss_train=2.2474, acc_train=0.6963, loss_test=0.2702, acc_test=0.9898
# poison_percent 30 round 47: loss_train=2.1962, acc_train=0.6971, loss_test=0.2698, acc_test=0.9898
# poison_percent 30 round 48: loss_train=2.1777, acc_train=0.6966, loss_test=0.2694, acc_test=0.9898
# poison_percent 30 round 49: loss_train=2.1057, acc_train=0.6955, loss_test=0.2689, acc_test=0.9898
# poison_percent 30 round 50: loss_train=2.1224, acc_train=0.6958, loss_test=0.2685, acc_test=0.9898
# poison_percent 30 round 51: loss_train=2.2017, acc_train=0.6977, loss_test=0.2681, acc_test=0.9898
# poison_percent 30 round 52: loss_train=2.1256, acc_train=0.6966, loss_test=0.2677, acc_test=0.9903
# poison_percent 30 round 53: loss_train=2.2056, acc_train=0.6988, loss_test=0.2673, acc_test=0.9908
# poison_percent 30 round 54: loss_train=2.1634, acc_train=0.6950, loss_test=0.2669, acc_test=0.9908
# poison_percent 30 round 55: loss_train=2.1668, acc_train=0.6971, loss_test=0.2665, acc_test=0.9908
# poison_percent 30 round 56: loss_train=2.0800, acc_train=0.6958, loss_test=0.2661, acc_test=0.9908
# poison_percent 30 round 57: loss_train=2.0578, acc_train=0.6993, loss_test=0.2657, acc_test=0.9913
# poison_percent 30 round 58: loss_train=2.1362, acc_train=0.6969, loss_test=0.2654, acc_test=0.9913
# poison_percent 30 round 59: loss_train=2.0770, acc_train=0.6971, loss_test=0.2649, acc_test=0.9913
# poison_percent 30 round 60: loss_train=2.1387, acc_train=0.6942, loss_test=0.2646, acc_test=0.9913
# poison_percent 30 round 61: loss_train=2.1119, acc_train=0.6974, loss_test=0.2642, acc_test=0.9913
# poison_percent 30 round 62: loss_train=2.0950, acc_train=0.6963, loss_test=0.2638, acc_test=0.9913
# poison_percent 30 round 63: loss_train=2.1276, acc_train=0.6969, loss_test=0.2634, acc_test=0.9913
# poison_percent 30 round 64: loss_train=2.1309, acc_train=0.6980, loss_test=0.2630, acc_test=0.9913
# poison_percent 30 round 65: loss_train=2.1537, acc_train=0.6977, loss_test=0.2626, acc_test=0.9913
# poison_percent 30 round 66: loss_train=2.1277, acc_train=0.6977, loss_test=0.2622, acc_test=0.9913
# poison_percent 30 round 67: loss_train=2.1665, acc_train=0.6963, loss_test=0.2618, acc_test=0.9913
# poison_percent 30 round 68: loss_train=2.1104, acc_train=0.6963, loss_test=0.2614, acc_test=0.9913
# poison_percent 30 round 69: loss_train=2.1790, acc_train=0.6993, loss_test=0.2610, acc_test=0.9918
# poison_percent 30 round 70: loss_train=2.0712, acc_train=0.6971, loss_test=0.2607, acc_test=0.9918
# poison_percent 30 round 71: loss_train=2.1509, acc_train=0.6974, loss_test=0.2603, acc_test=0.9918
# poison_percent 30 round 72: loss_train=2.1164, acc_train=0.6969, loss_test=0.2599, acc_test=0.9918
# poison_percent 30 round 73: loss_train=2.1915, acc_train=0.6985, loss_test=0.2595, acc_test=0.9918
# poison_percent 30 round 74: loss_train=2.0680, acc_train=0.6990, loss_test=0.2591, acc_test=0.9918
# poison_percent 30 round 75: loss_train=2.0937, acc_train=0.6982, loss_test=0.2587, acc_test=0.9918
# poison_percent 30 round 76: loss_train=2.1136, acc_train=0.6980, loss_test=0.2584, acc_test=0.9918
# poison_percent 30 round 77: loss_train=2.1616, acc_train=0.6969, loss_test=0.2580, acc_test=0.9918
# poison_percent 30 round 78: loss_train=2.1484, acc_train=0.6993, loss_test=0.2576, acc_test=0.9918
# poison_percent 30 round 79: loss_train=2.1505, acc_train=0.6971, loss_test=0.2573, acc_test=0.9918
# poison_percent 30 round 80: loss_train=2.1805, acc_train=0.6950, loss_test=0.2569, acc_test=0.9918
# poison_percent 30 round 81: loss_train=2.1419, acc_train=0.6963, loss_test=0.2565, acc_test=0.9918
# poison_percent 30 round 82: loss_train=2.1195, acc_train=0.6958, loss_test=0.2562, acc_test=0.9918
# poison_percent 30 round 83: loss_train=2.0901, acc_train=0.6985, loss_test=0.2558, acc_test=0.9918
# poison_percent 30 round 84: loss_train=2.1463, acc_train=0.6969, loss_test=0.2554, acc_test=0.9918
# poison_percent 30 round 85: loss_train=2.1087, acc_train=0.6963, loss_test=0.2551, acc_test=0.9918
# poison_percent 30 round 86: loss_train=2.1098, acc_train=0.6955, loss_test=0.2547, acc_test=0.9918
# poison_percent 30 round 87: loss_train=2.1368, acc_train=0.6971, loss_test=0.2543, acc_test=0.9918
# poison_percent 30 round 88: loss_train=2.1102, acc_train=0.6969, loss_test=0.2540, acc_test=0.9918
# poison_percent 30 round 89: loss_train=2.1498, acc_train=0.6980, loss_test=0.2536, acc_test=0.9918
# poison_percent 30 round 90: loss_train=2.0986, acc_train=0.6969, loss_test=0.2533, acc_test=0.9918
# poison_percent 30 round 91: loss_train=2.1575, acc_train=0.6977, loss_test=0.2529, acc_test=0.9918
# poison_percent 30 round 92: loss_train=2.1078, acc_train=0.6961, loss_test=0.2525, acc_test=0.9918
# poison_percent 30 round 93: loss_train=2.0972, acc_train=0.6958, loss_test=0.2522, acc_test=0.9918
# poison_percent 30 round 94: loss_train=2.1625, acc_train=0.6974, loss_test=0.2518, acc_test=0.9918
# poison_percent 30 round 95: loss_train=2.0698, acc_train=0.6955, loss_test=0.2515, acc_test=0.9918
# poison_percent 30 round 96: loss_train=2.1836, acc_train=0.6966, loss_test=0.2511, acc_test=0.9918
# poison_percent 30 round 97: loss_train=2.1565, acc_train=0.6993, loss_test=0.2507, acc_test=0.9918
# poison_percent 30 round 98: loss_train=2.1170, acc_train=0.6966, loss_test=0.2504, acc_test=0.9918
# poison_percent 30 round 99: loss_train=2.1291, acc_train=0.6953, loss_test=0.2500, acc_test=0.9918
# Training log saved to ./results\FL_ModelN1L2_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=2.6934, acc_train=0.5993, loss_test=0.2496, acc_test=0.9918
# poison_percent 40 round 1: loss_train=2.7585, acc_train=0.5960, loss_test=0.2492, acc_test=0.9918
# poison_percent 40 round 2: loss_train=2.7220, acc_train=0.5997, loss_test=0.2487, acc_test=0.9918
# poison_percent 40 round 3: loss_train=2.8262, acc_train=0.5979, loss_test=0.2483, acc_test=0.9918
# poison_percent 40 round 4: loss_train=2.7452, acc_train=0.5960, loss_test=0.2479, acc_test=0.9918
# poison_percent 40 round 5: loss_train=2.7397, acc_train=0.5986, loss_test=0.2475, acc_test=0.9918
# poison_percent 40 round 6: loss_train=2.7468, acc_train=0.5983, loss_test=0.2471, acc_test=0.9923
# poison_percent 40 round 7: loss_train=2.7089, acc_train=0.5990, loss_test=0.2467, acc_test=0.9929
# poison_percent 40 round 8: loss_train=2.7089, acc_train=0.5990, loss_test=0.2463, acc_test=0.9929
# poison_percent 40 round 9: loss_train=2.7086, acc_train=0.5986, loss_test=0.2458, acc_test=0.9929
# poison_percent 40 round 10: loss_train=2.7366, acc_train=0.5990, loss_test=0.2454, acc_test=0.9929
# poison_percent 40 round 11: loss_train=2.8434, acc_train=0.5977, loss_test=0.2450, acc_test=0.9929
# poison_percent 40 round 12: loss_train=2.7468, acc_train=0.5986, loss_test=0.2446, acc_test=0.9929
# poison_percent 40 round 13: loss_train=2.7411, acc_train=0.5965, loss_test=0.2442, acc_test=0.9929
# poison_percent 40 round 14: loss_train=2.7325, acc_train=0.5977, loss_test=0.2439, acc_test=0.9929
# poison_percent 40 round 15: loss_train=2.7238, acc_train=0.5986, loss_test=0.2435, acc_test=0.9929
# poison_percent 40 round 16: loss_train=2.7046, acc_train=0.5990, loss_test=0.2431, acc_test=0.9929
# poison_percent 40 round 17: loss_train=2.7609, acc_train=0.5983, loss_test=0.2427, acc_test=0.9929
# poison_percent 40 round 18: loss_train=2.7706, acc_train=0.5993, loss_test=0.2423, acc_test=0.9929
# poison_percent 40 round 19: loss_train=2.7310, acc_train=0.6002, loss_test=0.2419, acc_test=0.9929
# poison_percent 40 round 20: loss_train=2.8374, acc_train=0.5963, loss_test=0.2415, acc_test=0.9929
# poison_percent 40 round 21: loss_train=2.7627, acc_train=0.5977, loss_test=0.2412, acc_test=0.9929
# poison_percent 40 round 22: loss_train=2.7191, acc_train=0.5972, loss_test=0.2408, acc_test=0.9929
# poison_percent 40 round 23: loss_train=2.6962, acc_train=0.5979, loss_test=0.2404, acc_test=0.9934
# poison_percent 40 round 24: loss_train=2.7604, acc_train=0.6000, loss_test=0.2400, acc_test=0.9934
# poison_percent 40 round 25: loss_train=2.7337, acc_train=0.5986, loss_test=0.2396, acc_test=0.9934
# poison_percent 40 round 26: loss_train=2.6879, acc_train=0.5981, loss_test=0.2392, acc_test=0.9934
# poison_percent 40 round 27: loss_train=2.6786, acc_train=0.5988, loss_test=0.2389, acc_test=0.9934
# poison_percent 40 round 28: loss_train=2.7378, acc_train=0.5986, loss_test=0.2385, acc_test=0.9934
# poison_percent 40 round 29: loss_train=2.6170, acc_train=0.5993, loss_test=0.2381, acc_test=0.9934
# poison_percent 40 round 30: loss_train=2.6341, acc_train=0.5977, loss_test=0.2378, acc_test=0.9934
# poison_percent 40 round 31: loss_train=2.6167, acc_train=0.5974, loss_test=0.2374, acc_test=0.9934
# poison_percent 40 round 32: loss_train=2.6337, acc_train=0.5983, loss_test=0.2370, acc_test=0.9934
# poison_percent 40 round 33: loss_train=2.7005, acc_train=0.5977, loss_test=0.2367, acc_test=0.9934
# poison_percent 40 round 34: loss_train=2.6769, acc_train=0.5990, loss_test=0.2363, acc_test=0.9934
# poison_percent 40 round 35: loss_train=2.6924, acc_train=0.5986, loss_test=0.2359, acc_test=0.9934
# poison_percent 40 round 36: loss_train=2.6287, acc_train=0.6000, loss_test=0.2356, acc_test=0.9939
# poison_percent 40 round 37: loss_train=2.6363, acc_train=0.5986, loss_test=0.2352, acc_test=0.9939
# poison_percent 40 round 38: loss_train=2.6692, acc_train=0.5993, loss_test=0.2348, acc_test=0.9939
# poison_percent 40 round 39: loss_train=2.5851, acc_train=0.5960, loss_test=0.2345, acc_test=0.9944
# poison_percent 40 round 40: loss_train=2.6699, acc_train=0.5972, loss_test=0.2341, acc_test=0.9944
# poison_percent 40 round 41: loss_train=2.6596, acc_train=0.5995, loss_test=0.2337, acc_test=0.9944
# poison_percent 40 round 42: loss_train=2.6836, acc_train=0.5995, loss_test=0.2334, acc_test=0.9944
# poison_percent 40 round 43: loss_train=2.5874, acc_train=0.5986, loss_test=0.2330, acc_test=0.9944
# poison_percent 40 round 44: loss_train=2.7663, acc_train=0.5970, loss_test=0.2327, acc_test=0.9949
# poison_percent 40 round 45: loss_train=2.6070, acc_train=0.6002, loss_test=0.2323, acc_test=0.9949
# poison_percent 40 round 46: loss_train=2.5975, acc_train=0.5977, loss_test=0.2320, acc_test=0.9949
# poison_percent 40 round 47: loss_train=2.6116, acc_train=0.5988, loss_test=0.2316, acc_test=0.9949
# poison_percent 40 round 48: loss_train=2.6904, acc_train=0.5986, loss_test=0.2312, acc_test=0.9949
# poison_percent 40 round 49: loss_train=2.6300, acc_train=0.5979, loss_test=0.2309, acc_test=0.9949
# poison_percent 40 round 50: loss_train=2.7046, acc_train=0.5972, loss_test=0.2305, acc_test=0.9949
# poison_percent 40 round 51: loss_train=2.6592, acc_train=0.5981, loss_test=0.2302, acc_test=0.9949
# poison_percent 40 round 52: loss_train=2.6420, acc_train=0.5993, loss_test=0.2298, acc_test=0.9949
# poison_percent 40 round 53: loss_train=2.6392, acc_train=0.5974, loss_test=0.2295, acc_test=0.9949
# poison_percent 40 round 54: loss_train=2.6035, acc_train=0.5979, loss_test=0.2291, acc_test=0.9949
# poison_percent 40 round 55: loss_train=2.6161, acc_train=0.5977, loss_test=0.2288, acc_test=0.9949
# poison_percent 40 round 56: loss_train=2.6780, acc_train=0.5972, loss_test=0.2284, acc_test=0.9949
# poison_percent 40 round 57: loss_train=2.6293, acc_train=0.5988, loss_test=0.2281, acc_test=0.9949
# poison_percent 40 round 58: loss_train=2.6566, acc_train=0.5974, loss_test=0.2277, acc_test=0.9949
# poison_percent 40 round 59: loss_train=2.6326, acc_train=0.5979, loss_test=0.2274, acc_test=0.9949
# poison_percent 40 round 60: loss_train=2.6079, acc_train=0.5972, loss_test=0.2270, acc_test=0.9949
# poison_percent 40 round 61: loss_train=2.6063, acc_train=0.6000, loss_test=0.2267, acc_test=0.9949
# poison_percent 40 round 62: loss_train=2.6335, acc_train=0.5983, loss_test=0.2263, acc_test=0.9949
# poison_percent 40 round 63: loss_train=2.5973, acc_train=0.5993, loss_test=0.2260, acc_test=0.9954
# poison_percent 40 round 64: loss_train=2.6979, acc_train=0.5967, loss_test=0.2257, acc_test=0.9954
# poison_percent 40 round 65: loss_train=2.6412, acc_train=0.5983, loss_test=0.2253, acc_test=0.9954
# poison_percent 40 round 66: loss_train=2.6519, acc_train=0.5990, loss_test=0.2250, acc_test=0.9954
# poison_percent 40 round 67: loss_train=2.5810, acc_train=0.5981, loss_test=0.2246, acc_test=0.9954
# poison_percent 40 round 68: loss_train=2.5815, acc_train=0.5990, loss_test=0.2243, acc_test=0.9954
# poison_percent 40 round 69: loss_train=2.5603, acc_train=0.5972, loss_test=0.2239, acc_test=0.9954
# poison_percent 40 round 70: loss_train=2.5506, acc_train=0.5979, loss_test=0.2236, acc_test=0.9954
# poison_percent 40 round 71: loss_train=2.5535, acc_train=0.5990, loss_test=0.2233, acc_test=0.9954
# poison_percent 40 round 72: loss_train=2.4981, acc_train=0.5970, loss_test=0.2230, acc_test=0.9954
# poison_percent 40 round 73: loss_train=2.6001, acc_train=0.5988, loss_test=0.2226, acc_test=0.9954
# poison_percent 40 round 74: loss_train=2.6088, acc_train=0.5965, loss_test=0.2223, acc_test=0.9954
# poison_percent 40 round 75: loss_train=2.5764, acc_train=0.5997, loss_test=0.2219, acc_test=0.9954
# poison_percent 40 round 76: loss_train=2.5800, acc_train=0.5983, loss_test=0.2216, acc_test=0.9954
# poison_percent 40 round 77: loss_train=2.6176, acc_train=0.5990, loss_test=0.2213, acc_test=0.9954
# poison_percent 40 round 78: loss_train=2.6522, acc_train=0.5977, loss_test=0.2209, acc_test=0.9954
# poison_percent 40 round 79: loss_train=2.5844, acc_train=0.5979, loss_test=0.2206, acc_test=0.9954
# poison_percent 40 round 80: loss_train=2.6054, acc_train=0.5963, loss_test=0.2203, acc_test=0.9954
# poison_percent 40 round 81: loss_train=2.6483, acc_train=0.5986, loss_test=0.2199, acc_test=0.9954
# ...
# poison_percent 40 round 41: loss_train=6.1610, acc_train=0.6002, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 42: loss_train=6.1374, acc_train=0.6004, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 43: loss_train=6.1867, acc_train=0.5981, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 44: loss_train=6.1596, acc_train=0.5986, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 45: loss_train=6.1373, acc_train=0.5997, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 46: loss_train=6.1512, acc_train=0.5995, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 47: loss_train=6.1371, acc_train=0.5993, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 48: loss_train=6.1594, acc_train=0.5993, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 49: loss_train=6.1320, acc_train=0.5995, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 50: loss_train=6.1574, acc_train=0.5981, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 51: loss_train=6.1175, acc_train=0.5995, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 52: loss_train=6.1062, acc_train=0.5993, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 53: loss_train=6.1044, acc_train=0.5995, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 54: loss_train=6.1072, acc_train=0.5990, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 55: loss_train=6.1364, acc_train=0.5986, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 56: loss_train=6.1015, acc_train=0.5995, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 57: loss_train=6.1072, acc_train=0.5990, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 58: loss_train=6.0801, acc_train=0.5995, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 59: loss_train=6.0892, acc_train=0.5986, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 60: loss_train=6.0656, acc_train=0.6004, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 61: loss_train=6.0845, acc_train=0.6002, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 62: loss_train=6.0925, acc_train=0.5983, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 63: loss_train=6.0951, acc_train=0.5990, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 64: loss_train=6.0668, acc_train=0.5995, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 65: loss_train=6.0500, acc_train=0.5997, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 66: loss_train=6.0450, acc_train=0.5986, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 67: loss_train=6.0586, acc_train=0.5988, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 68: loss_train=6.0724, acc_train=0.5981, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 69: loss_train=6.0392, acc_train=0.5993, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 70: loss_train=6.0228, acc_train=0.6000, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 71: loss_train=6.0044, acc_train=0.6000, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 72: loss_train=6.0444, acc_train=0.5986, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 73: loss_train=6.0433, acc_train=0.5988, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 74: loss_train=5.9848, acc_train=0.5990, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 75: loss_train=5.9853, acc_train=0.5993, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 76: loss_train=5.9716, acc_train=0.5997, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 77: loss_train=5.9982, acc_train=0.5993, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 78: loss_train=5.9904, acc_train=0.5997, loss_test=0.0014, acc_test=0.9995
# poison_percent 40 round 79: loss_train=5.9748, acc_train=0.5981, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 80: loss_train=5.9811, acc_train=0.5993, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 81: loss_train=5.9934, acc_train=0.5990, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 82: loss_train=5.9698, acc_train=0.5981, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 83: loss_train=5.9485, acc_train=0.5995, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 84: loss_train=5.9791, acc_train=0.5981, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 85: loss_train=5.9138, acc_train=0.5993, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 86: loss_train=5.9459, acc_train=0.5983, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 87: loss_train=5.9697, acc_train=0.5990, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 88: loss_train=5.9158, acc_train=0.5995, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 89: loss_train=5.9074, acc_train=0.5988, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 90: loss_train=5.9253, acc_train=0.5990, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 91: loss_train=5.9657, acc_train=0.5988, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 92: loss_train=5.9006, acc_train=0.5995, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 93: loss_train=5.9027, acc_train=0.5988, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 94: loss_train=5.9112, acc_train=0.5983, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 95: loss_train=5.9264, acc_train=0.5988, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 96: loss_train=5.9098, acc_train=0.5995, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 97: loss_train=5.8496, acc_train=0.5990, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 98: loss_train=5.9000, acc_train=0.6000, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 99: loss_train=5.8790, acc_train=0.5986, loss_test=0.0012, acc_test=0.9995
# Training log saved to ./results\FL_ModelN32L2_Batchsize32_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 round 0: loss_train=7.2886, acc_train=0.5012, loss_test=0.0013, acc_test=0.9995
# poison_percent 50 round 1: loss_train=7.3049, acc_train=0.5012, loss_test=0.0013, acc_test=0.9995
# poison_percent 50 round 2: loss_train=7.2899, acc_train=0.5006, loss_test=0.0014, acc_test=0.9995
# poison_percent 50 round 3: loss_train=7.2528, acc_train=0.5008, loss_test=0.0014, acc_test=0.9995
# poison_percent 50 round 4: loss_train=7.2268, acc_train=0.5012, loss_test=0.0014, acc_test=0.9995
# poison_percent 50 round 5: loss_train=7.1585, acc_train=0.5017, loss_test=0.0015, acc_test=0.9995
# poison_percent 50 round 6: loss_train=7.1572, acc_train=0.5017, loss_test=0.0015, acc_test=0.9995
# poison_percent 50 round 7: loss_train=7.1533, acc_train=0.5010, loss_test=0.0016, acc_test=0.9995
# poison_percent 50 round 8: loss_train=7.1183, acc_train=0.5017, loss_test=0.0016, acc_test=0.9995
# poison_percent 50 round 9: loss_train=7.0793, acc_train=0.5008, loss_test=0.0017, acc_test=0.9995
# poison_percent 50 round 10: loss_train=7.0898, acc_train=0.5008, loss_test=0.0017, acc_test=0.9995
# poison_percent 50 round 11: loss_train=6.9991, acc_train=0.5019, loss_test=0.0018, acc_test=0.9995
# poison_percent 50 round 12: loss_train=6.9866, acc_train=0.5017, loss_test=0.0019, acc_test=0.9995
# poison_percent 50 round 13: loss_train=6.9316, acc_train=0.5015, loss_test=0.0019, acc_test=0.9995
# poison_percent 50 round 14: loss_train=6.9157, acc_train=0.5010, loss_test=0.0020, acc_test=0.9995
# poison_percent 50 round 15: loss_train=6.8824, acc_train=0.5013, loss_test=0.0020, acc_test=0.9995
# poison_percent 50 round 16: loss_train=6.8069, acc_train=0.5019, loss_test=0.0021, acc_test=0.9990
# poison_percent 50 round 17: loss_train=6.8215, acc_train=0.5012, loss_test=0.0022, acc_test=0.9990
# poison_percent 50 round 18: loss_train=6.7704, acc_train=0.5010, loss_test=0.0023, acc_test=0.9990
# poison_percent 50 round 19: loss_train=6.7451, acc_train=0.5012, loss_test=0.0023, acc_test=0.9985
# poison_percent 50 round 20: loss_train=6.7109, acc_train=0.5017, loss_test=0.0024, acc_test=0.9985
# poison_percent 50 round 21: loss_train=6.6542, acc_train=0.5010, loss_test=0.0024, acc_test=0.9985
# poison_percent 50 round 22: loss_train=6.5859, acc_train=0.5015, loss_test=0.0025, acc_test=0.9985
# poison_percent 50 round 23: loss_train=6.5985, acc_train=0.5015, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 24: loss_train=6.5241, acc_train=0.5013, loss_test=0.0027, acc_test=0.9985
# poison_percent 50 round 25: loss_train=6.4792, acc_train=0.5021, loss_test=0.0027, acc_test=0.9985
# poison_percent 50 round 26: loss_train=6.4565, acc_train=0.5006, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 27: loss_train=6.4555, acc_train=0.5006, loss_test=0.0029, acc_test=0.9985
# poison_percent 50 round 28: loss_train=6.3672, acc_train=0.5023, loss_test=0.0029, acc_test=0.9985
# poison_percent 50 round 29: loss_train=6.2710, acc_train=0.5013, loss_test=0.0030, acc_test=0.9985
# poison_percent 50 round 30: loss_train=6.2349, acc_train=0.5021, loss_test=0.0031, acc_test=0.9985
# poison_percent 50 round 31: loss_train=6.2659, acc_train=0.5012, loss_test=0.0031, acc_test=0.9985
# poison_percent 50 round 32: loss_train=6.1848, acc_train=0.5019, loss_test=0.0032, acc_test=0.9985
# poison_percent 50 round 33: loss_train=6.1818, acc_train=0.5017, loss_test=0.0032, acc_test=0.9985
# poison_percent 50 round 34: loss_train=6.1445, acc_train=0.5008, loss_test=0.0033, acc_test=0.9985
# poison_percent 50 round 35: loss_train=6.0581, acc_train=0.5023, loss_test=0.0033, acc_test=0.9985
# poison_percent 50 round 36: loss_train=6.0313, acc_train=0.5006, loss_test=0.0034, acc_test=0.9985
# poison_percent 50 round 37: loss_train=5.9889, acc_train=0.5010, loss_test=0.0034, acc_test=0.9985
# poison_percent 50 round 38: loss_train=5.9392, acc_train=0.5021, loss_test=0.0035, acc_test=0.9985
# poison_percent 50 round 39: loss_train=5.8985, acc_train=0.5013, loss_test=0.0035, acc_test=0.9985
# poison_percent 50 round 40: loss_train=5.8491, acc_train=0.5012, loss_test=0.0036, acc_test=0.9985
# poison_percent 50 round 41: loss_train=5.8386, acc_train=0.5008, loss_test=0.0037, acc_test=0.9985
# poison_percent 50 round 42: loss_train=5.7706, acc_train=0.5012, loss_test=0.0037, acc_test=0.9985
# poison_percent 50 round 43: loss_train=5.6922, acc_train=0.5017, loss_test=0.0038, acc_test=0.9985
# poison_percent 50 round 44: loss_train=5.6514, acc_train=0.5013, loss_test=0.0038, acc_test=0.9985
# poison_percent 50 round 45: loss_train=5.5718, acc_train=0.5019, loss_test=0.0039, acc_test=0.9985
# poison_percent 50 round 46: loss_train=5.6193, acc_train=0.5008, loss_test=0.0040, acc_test=0.9985
# poison_percent 50 round 47: loss_train=5.5141, acc_train=0.5027, loss_test=0.0040, acc_test=0.9985
# poison_percent 50 round 48: loss_train=5.5424, acc_train=0.5006, loss_test=0.0041, acc_test=0.9985
# poison_percent 50 round 49: loss_train=5.4550, acc_train=0.5013, loss_test=0.0041, acc_test=0.9985
# poison_percent 50 round 50: loss_train=5.4248, acc_train=0.5017, loss_test=0.0042, acc_test=0.9985
# poison_percent 50 round 51: loss_train=5.3525, acc_train=0.5021, loss_test=0.0042, acc_test=0.9985
# poison_percent 50 round 52: loss_train=5.2790, acc_train=0.5021, loss_test=0.0043, acc_test=0.9985
# poison_percent 50 round 53: loss_train=5.2181, acc_train=0.5023, loss_test=0.0043, acc_test=0.9985
# poison_percent 50 round 54: loss_train=5.2359, acc_train=0.5019, loss_test=0.0044, acc_test=0.9985
# poison_percent 50 round 55: loss_train=5.1368, acc_train=0.5017, loss_test=0.0045, acc_test=0.9985
# poison_percent 50 round 56: loss_train=5.1003, acc_train=0.5025, loss_test=0.0045, acc_test=0.9985
# poison_percent 50 round 57: loss_train=5.1312, acc_train=0.5004, loss_test=0.0046, acc_test=0.9985
# poison_percent 50 round 58: loss_train=5.0530, acc_train=0.5012, loss_test=0.0047, acc_test=0.9985
# poison_percent 50 round 59: loss_train=5.0043, acc_train=0.5019, loss_test=0.0047, acc_test=0.9985
# poison_percent 50 round 60: loss_train=4.9914, acc_train=0.5012, loss_test=0.0048, acc_test=0.9985
# poison_percent 50 round 61: loss_train=4.9518, acc_train=0.5015, loss_test=0.0049, acc_test=0.9990
# poison_percent 50 round 62: loss_train=4.8972, acc_train=0.5015, loss_test=0.0050, acc_test=0.9990
# poison_percent 50 round 63: loss_train=4.8258, acc_train=0.5008, loss_test=0.0050, acc_test=0.9990
# poison_percent 50 round 64: loss_train=4.8276, acc_train=0.5012, loss_test=0.0051, acc_test=0.9990
# poison_percent 50 round 65: loss_train=4.7983, acc_train=0.5027, loss_test=0.0052, acc_test=0.9990
# poison_percent 50 round 66: loss_train=4.7111, acc_train=0.5015, loss_test=0.0053, acc_test=0.9990
# poison_percent 50 round 67: loss_train=4.6752, acc_train=0.5023, loss_test=0.0054, acc_test=0.9985
# poison_percent 50 round 68: loss_train=4.6749, acc_train=0.5010, loss_test=0.0055, acc_test=0.9985
# poison_percent 50 round 69: loss_train=4.5801, acc_train=0.5023, loss_test=0.0056, acc_test=0.9985
# poison_percent 50 round 70: loss_train=4.5937, acc_train=0.5010, loss_test=0.0057, acc_test=0.9985
# poison_percent 50 round 71: loss_train=4.5384, acc_train=0.5023, loss_test=0.0059, acc_test=0.9985
# poison_percent 50 round 72: loss_train=4.4969, acc_train=0.5002, loss_test=0.0060, acc_test=0.9985
# poison_percent 50 round 73: loss_train=4.4661, acc_train=0.5010, loss_test=0.0061, acc_test=0.9985
# poison_percent 50 round 74: loss_train=4.4332, acc_train=0.5015, loss_test=0.0062, acc_test=0.9980
# poison_percent 50 round 75: loss_train=4.4241, acc_train=0.5008, loss_test=0.0063, acc_test=0.9980
# poison_percent 50 round 76: loss_train=4.3345, acc_train=0.5012, loss_test=0.0064, acc_test=0.9980
# poison_percent 50 round 77: loss_train=4.3236, acc_train=0.4998, loss_test=0.0065, acc_test=0.9974
# poison_percent 50 round 78: loss_train=4.2923, acc_train=0.5002, loss_test=0.0067, acc_test=0.9974
# poison_percent 50 round 79: loss_train=4.2235, acc_train=0.5019, loss_test=0.0068, acc_test=0.9974
# poison_percent 50 round 80: loss_train=4.2392, acc_train=0.5000, loss_test=0.0070, acc_test=0.9974
# poison_percent 50 round 81: loss_train=4.1488, acc_train=0.5015, loss_test=0.0071, acc_test=0.9974
# poison_percent 50 round 82: loss_train=4.1337, acc_train=0.5000, loss_test=0.0073, acc_test=0.9969
# poison_percent 50 round 83: loss_train=4.1596, acc_train=0.5012, loss_test=0.0074, acc_test=0.9969
# poison_percent 50 round 84: loss_train=4.0680, acc_train=0.5017, loss_test=0.0076, acc_test=0.9969
# poison_percent 50 round 85: loss_train=4.0871, acc_train=0.5023, loss_test=0.0078, acc_test=0.9969
# poison_percent 50 round 86: loss_train=4.0631, acc_train=0.4992, loss_test=0.0080, acc_test=0.9969
# poison_percent 50 round 87: loss_train=4.0389, acc_train=0.5006, loss_test=0.0082, acc_test=0.9969
# poison_percent 50 round 88: loss_train=3.9712, acc_train=0.5002, loss_test=0.0084, acc_test=0.9974
# poison_percent 50 round 89: loss_train=3.9312, acc_train=0.5012, loss_test=0.0086, acc_test=0.9969
# poison_percent 50 round 90: loss_train=3.9199, acc_train=0.5012, loss_test=0.0087, acc_test=0.9969
# poison_percent 50 round 91: loss_train=3.8727, acc_train=0.5004, loss_test=0.0090, acc_test=0.9969
# poison_percent 50 round 92: loss_train=3.8068, acc_train=0.5013, loss_test=0.0092, acc_test=0.9969
# poison_percent 50 round 93: loss_train=3.8028, acc_train=0.5019, loss_test=0.0094, acc_test=0.9969
# poison_percent 50 round 94: loss_train=3.8334, acc_train=0.5006, loss_test=0.0096, acc_test=0.9969
# poison_percent 50 round 95: loss_train=3.7716, acc_train=0.5010, loss_test=0.0098, acc_test=0.9969
# poison_percent 50 round 96: loss_train=3.7560, acc_train=0.5006, loss_test=0.0100, acc_test=0.9969
# poison_percent 50 round 97: loss_train=3.7222, acc_train=0.5015, loss_test=0.0102, acc_test=0.9969
# poison_percent 50 round 98: loss_train=3.6968, acc_train=0.5013, loss_test=0.0105, acc_test=0.9969
# poison_percent 50 round 99: loss_train=3.6373, acc_train=0.5021, loss_test=0.0107, acc_test=0.9969
# Training log saved to ./results\FL_ModelN32L2_Batchsize32_rev2\poisoned_50percent\poisoned_50percent.csv
