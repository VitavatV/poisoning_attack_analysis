# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
# def binary_cross_entropy(pred, target):
#     eps = 1e-7
#     pred = torch.clamp(pred, eps, 1 - eps)
#     return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

def multiclass_cross_entropy(logits, target, from_probs=False, eps=1e-7):
    """
    Cross-entropy loss for multiclass (e.g., 10 classes).
    - logits: Tensor shape (N, C) containing raw scores (preferred) or probabilities if from_probs=True
    - target: Tensor shape (N,) or (N,1) containing class indices (0..C-1)
    """
    if logits.dim() == 1:
        logits = logits.unsqueeze(0)
    target = target.squeeze()
    if target.dtype != torch.long:
        target = target.long()
    if from_probs:
        probs = torch.clamp(logits, eps, 1.0 - eps)
        log_probs = torch.log(probs)
        return -log_probs[torch.arange(target.size(0)), target].mean()
    return nn.functional.cross_entropy(logits, target)

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    model = MNISTNet().to(device)
    model.load_state_dict(global_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end]
            yb = y_c_tensor[start:end]
            outputs = model(xb)
            # preds = (outputs >= 0.5).float()
            preds = torch.argmax(outputs, dim=1, keepdim=True)
            loss = multiclass_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # Return a deepcopy to avoid issues with state_dict references
    return copy.deepcopy(model.state_dict()), X_c_tensor.size(0), yb, outputs, preds

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 32
N_CLASSES = 10

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_multiple_poison/train"
TEST_PATH = "../data/mnist_multiple_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
import re
def make_safe_filename(name: str) -> str:
    # remove control chars and characters invalid on Windows
    safe = re.sub(r'[<>:"/\\|?*\x00-\x1F]', '_', name)
    # strip trailing dots/spaces which are problematic on Windows
    safe = safe.rstrip('. ')
    return safe

# %%
for NODE in [1,2,4,8,16,32]:
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, N_CLASSES)
            self.relu = nn.ReLU()
        def forward(self, x):
            x = self.fc1(x)
            x = self.relu(x)
            x = self.fc2(x)
            # x = torch.sigmoid(x)
            return x

    BATCH_SIZE_list = [BATCH_SIZE]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        global_model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"FL_ModelN{NODE}L2_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                torch.save(global_model, os.path.join(save_path,'model_init.pt'))
                global_weights = global_model.state_dict()

                records = []

                X_train_tensor = {}
                y_train_tensor = {}
                for i in range(N_HONEST):
                    X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"honest_{i}"] = X_c_tensor
                    y_train_tensor[f"honest_{i}"] = y_c_tensor
                for i in range(i_poisoned):
                    X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"poison_{i}"] = X_c_tensor
                    y_train_tensor[f"poison_{i}"] = y_c_tensor

                # Training loop
                for round in range(ROUNDS):
                    # Prepare arguments for honest clients
                    
                    #randomize the training data
                    for i in range(N_HONEST):
                        perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                        X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                        y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                    honest_args = [
                        (
                            X_train_tensor[f"honest_{i}"],
                            y_train_tensor[f"honest_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(N_HONEST)
                    ]

                    # Prepare arguments for poisoned clients
                    
                    #randomize the training data
                    for i in range(i_poisoned):
                        perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                        X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                        y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                    poison_args = [
                        (
                            X_train_tensor[f"poison_{i}"],
                            y_train_tensor[f"poison_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(i_poisoned)
                    ]

                    # Run in parallel
                    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                        honest_results = list(executor.map(train_local_worker, honest_args))
                        poison_results = list(executor.map(train_local_worker, poison_args))

                    local_weights = []
                    local_sizes = []
                    local_y = []
                    local_outputs = []
                    local_preds = []
                    for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                        local_weights.append(l_w)
                        local_sizes.append(l_sz)
                        local_y.extend(l_y)
                        local_outputs.extend(l_out)
                        local_preds.extend(l_pred)
                    loss_train = multiclass_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                    acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                    # Federated averaging (weighted by client data size)
                    new_weights = {}
                    for key in global_weights.keys():
                        new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                    global_weights = new_weights
                    global_model.load_state_dict(global_weights)

                    # Evaluate
                    global_model.eval()
                    with torch.no_grad():
                        outputs = global_model(X_test_tensor)
                        # preds = (outputs > 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        loss_test = multiclass_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'round': round, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"round {round}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(global_model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)

                # save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                safe_name = make_safe_filename(NAME_SAVE_update_PATH)
                save_name_path = os.path.abspath(os.path.join(save_path, f'{safe_name}.csv'))
                os.makedirs(os.path.dirname(save_name_path), exist_ok=True)

                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['round'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['round'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 round 0: loss_train=2.4247, acc_train=0.1028, loss_test=2.7498, acc_test=0.0000
# poison_percent 0 round 1: loss_train=2.4173, acc_train=0.1097, loss_test=2.7430, acc_test=0.0000
# poison_percent 0 round 2: loss_train=2.4139, acc_train=0.1069, loss_test=2.7366, acc_test=0.0000
# poison_percent 0 round 3: loss_train=2.4053, acc_train=0.1052, loss_test=2.7322, acc_test=0.0000
# poison_percent 0 round 4: loss_train=2.3935, acc_train=0.0993, loss_test=2.7246, acc_test=0.0000
# poison_percent 0 round 5: loss_train=2.3852, acc_train=0.1011, loss_test=2.7179, acc_test=0.0000
# poison_percent 0 round 6: loss_train=2.3519, acc_train=0.1059, loss_test=2.7115, acc_test=0.0000
# poison_percent 0 round 7: loss_train=2.3571, acc_train=0.1007, loss_test=2.7050, acc_test=0.0000
# poison_percent 0 round 8: loss_train=2.3413, acc_train=0.1069, loss_test=2.6986, acc_test=0.0000
# poison_percent 0 round 9: loss_train=2.3539, acc_train=0.0997, loss_test=2.6920, acc_test=0.0000
# poison_percent 0 round 10: loss_train=2.3405, acc_train=0.1011, loss_test=2.6858, acc_test=0.0000
# poison_percent 0 round 11: loss_train=2.3146, acc_train=0.1121, loss_test=2.6795, acc_test=0.0000
# poison_percent 0 round 12: loss_train=2.3116, acc_train=0.1073, loss_test=2.6733, acc_test=0.0000
# poison_percent 0 round 13: loss_train=2.3239, acc_train=0.0987, loss_test=2.6673, acc_test=0.0000
# poison_percent 0 round 14: loss_train=2.3071, acc_train=0.1056, loss_test=2.6612, acc_test=0.0000
# poison_percent 0 round 15: loss_train=2.3142, acc_train=0.0973, loss_test=2.6553, acc_test=0.0000
# poison_percent 0 round 16: loss_train=2.3101, acc_train=0.0997, loss_test=2.6494, acc_test=0.0000
# poison_percent 0 round 17: loss_train=2.2857, acc_train=0.1059, loss_test=2.6431, acc_test=0.0000
# poison_percent 0 round 18: loss_train=2.3122, acc_train=0.0938, loss_test=2.6371, acc_test=0.0000
# poison_percent 0 round 19: loss_train=2.3124, acc_train=0.0911, loss_test=2.6315, acc_test=0.0000
# poison_percent 0 round 20: loss_train=2.2826, acc_train=0.1028, loss_test=2.6258, acc_test=0.0000
# poison_percent 0 round 21: loss_train=2.2729, acc_train=0.1021, loss_test=2.6202, acc_test=0.0000
# poison_percent 0 round 22: loss_train=2.2898, acc_train=0.0959, loss_test=2.6146, acc_test=0.0000
# poison_percent 0 round 23: loss_train=2.2598, acc_train=0.1090, loss_test=2.6089, acc_test=0.0000
# poison_percent 0 round 24: loss_train=2.2828, acc_train=0.0945, loss_test=2.6034, acc_test=0.0000
# poison_percent 0 round 25: loss_train=2.2756, acc_train=0.1024, loss_test=2.5980, acc_test=0.0000
# poison_percent 0 round 26: loss_train=2.2675, acc_train=0.0973, loss_test=2.5926, acc_test=0.0000
# poison_percent 0 round 27: loss_train=2.2636, acc_train=0.0966, loss_test=2.5874, acc_test=0.0000
# poison_percent 0 round 28: loss_train=2.2371, acc_train=0.1083, loss_test=2.5820, acc_test=0.0000
# poison_percent 0 round 29: loss_train=2.2477, acc_train=0.1011, loss_test=2.5769, acc_test=0.0000
# poison_percent 0 round 30: loss_train=2.2685, acc_train=0.0924, loss_test=2.5717, acc_test=0.0000
# poison_percent 0 round 31: loss_train=2.2671, acc_train=0.0883, loss_test=2.5666, acc_test=0.0000
# poison_percent 0 round 32: loss_train=2.2409, acc_train=0.1000, loss_test=2.5615, acc_test=0.0000
# poison_percent 0 round 33: loss_train=2.2310, acc_train=0.1011, loss_test=2.5567, acc_test=0.0000
# poison_percent 0 round 34: loss_train=2.2330, acc_train=0.1007, loss_test=2.5517, acc_test=0.0000
# poison_percent 0 round 35: loss_train=2.2127, acc_train=0.1056, loss_test=2.5469, acc_test=0.0000
# poison_percent 0 round 36: loss_train=2.2526, acc_train=0.0880, loss_test=2.5422, acc_test=0.0000
# poison_percent 0 round 37: loss_train=2.2342, acc_train=0.0949, loss_test=2.5375, acc_test=0.0000
# poison_percent 0 round 38: loss_train=2.2012, acc_train=0.1111, loss_test=2.5331, acc_test=0.0000
# poison_percent 0 round 39: loss_train=2.2220, acc_train=0.0983, loss_test=2.5283, acc_test=0.0000
# poison_percent 0 round 40: loss_train=2.2167, acc_train=0.0952, loss_test=2.5235, acc_test=0.0000
# poison_percent 0 round 41: loss_train=2.1993, acc_train=0.1104, loss_test=2.5190, acc_test=0.0000
# poison_percent 0 round 42: loss_train=2.2153, acc_train=0.0969, loss_test=2.5147, acc_test=0.0000
# poison_percent 0 round 43: loss_train=2.2106, acc_train=0.0973, loss_test=2.5105, acc_test=0.0000
# poison_percent 0 round 44: loss_train=2.1977, acc_train=0.1014, loss_test=2.5061, acc_test=0.0000
# poison_percent 0 round 45: loss_train=2.1732, acc_train=0.1145, loss_test=2.5018, acc_test=0.0000
# poison_percent 0 round 46: loss_train=2.1845, acc_train=0.1073, loss_test=2.4976, acc_test=0.0000
# poison_percent 0 round 47: loss_train=2.1776, acc_train=0.1083, loss_test=2.4934, acc_test=0.0000
# poison_percent 0 round 48: loss_train=2.1987, acc_train=0.0987, loss_test=2.4893, acc_test=0.0000
# poison_percent 0 round 49: loss_train=2.2101, acc_train=0.0949, loss_test=2.4852, acc_test=0.0000
# poison_percent 0 round 50: loss_train=2.1831, acc_train=0.1031, loss_test=2.4809, acc_test=0.0000
# poison_percent 0 round 51: loss_train=2.1611, acc_train=0.1135, loss_test=2.4769, acc_test=0.0000
# poison_percent 0 round 52: loss_train=2.1734, acc_train=0.1049, loss_test=2.4730, acc_test=0.0000
# poison_percent 0 round 53: loss_train=2.1833, acc_train=0.0949, loss_test=2.4691, acc_test=0.0000
# poison_percent 0 round 54: loss_train=2.1872, acc_train=0.1011, loss_test=2.4652, acc_test=0.0000
# poison_percent 0 round 55: loss_train=2.1715, acc_train=0.1021, loss_test=2.4614, acc_test=0.0000
# poison_percent 0 round 56: loss_train=2.1879, acc_train=0.0914, loss_test=2.4576, acc_test=0.0000
# poison_percent 0 round 57: loss_train=2.1883, acc_train=0.0983, loss_test=2.4537, acc_test=0.0000
# poison_percent 0 round 58: loss_train=2.1637, acc_train=0.1021, loss_test=2.4503, acc_test=0.0000
# poison_percent 0 round 59: loss_train=2.1599, acc_train=0.1093, loss_test=2.4465, acc_test=0.0000
# poison_percent 0 round 60: loss_train=2.1921, acc_train=0.0942, loss_test=2.4430, acc_test=0.0000
# poison_percent 0 round 61: loss_train=2.1640, acc_train=0.0993, loss_test=2.4393, acc_test=0.0000
# poison_percent 0 round 62: loss_train=2.1973, acc_train=0.0904, loss_test=2.4359, acc_test=0.0000
# poison_percent 0 round 63: loss_train=2.1723, acc_train=0.0966, loss_test=2.4325, acc_test=0.0000
# poison_percent 0 round 64: loss_train=2.1437, acc_train=0.1052, loss_test=2.4292, acc_test=0.0000
# poison_percent 0 round 65: loss_train=2.1487, acc_train=0.1049, loss_test=2.4257, acc_test=0.0000
# poison_percent 0 round 66: loss_train=2.1438, acc_train=0.1104, loss_test=2.4224, acc_test=0.0000
# poison_percent 0 round 67: loss_train=2.1293, acc_train=0.1111, loss_test=2.4191, acc_test=0.0000
# poison_percent 0 round 68: loss_train=2.1724, acc_train=0.0969, loss_test=2.4160, acc_test=0.0000
# poison_percent 0 round 69: loss_train=2.1304, acc_train=0.1111, loss_test=2.4128, acc_test=0.0000
# poison_percent 0 round 70: loss_train=2.1594, acc_train=0.0959, loss_test=2.4099, acc_test=0.0000
# poison_percent 0 round 71: loss_train=2.1513, acc_train=0.1011, loss_test=2.4069, acc_test=0.0000
# poison_percent 0 round 72: loss_train=2.1313, acc_train=0.1076, loss_test=2.4037, acc_test=0.0000
# poison_percent 0 round 73: loss_train=2.1308, acc_train=0.1056, loss_test=2.4006, acc_test=0.0000
# poison_percent 0 round 74: loss_train=2.1467, acc_train=0.1007, loss_test=2.3976, acc_test=0.0000
# poison_percent 0 round 75: loss_train=2.1428, acc_train=0.1014, loss_test=2.3948, acc_test=0.0000
# poison_percent 0 round 76: loss_train=2.1370, acc_train=0.1018, loss_test=2.3919, acc_test=0.0000
# poison_percent 0 round 77: loss_train=2.1562, acc_train=0.0949, loss_test=2.3891, acc_test=0.0000
# poison_percent 0 round 78: loss_train=2.1314, acc_train=0.1049, loss_test=2.3863, acc_test=0.0000
# poison_percent 0 round 79: loss_train=2.1482, acc_train=0.0976, loss_test=2.3837, acc_test=0.0000
# poison_percent 0 round 80: loss_train=2.1440, acc_train=0.1007, loss_test=2.3807, acc_test=0.0000
# poison_percent 0 round 81: loss_train=2.1314, acc_train=0.1014, loss_test=2.3781, acc_test=0.0000
# poison_percent 0 round 82: loss_train=2.1457, acc_train=0.0980, loss_test=2.3755, acc_test=0.0000
# poison_percent 0 round 83: loss_train=2.1440, acc_train=0.0973, loss_test=2.3729, acc_test=0.0000
# poison_percent 0 round 84: loss_train=2.1312, acc_train=0.1031, loss_test=2.3702, acc_test=0.0000
# poison_percent 0 round 85: loss_train=2.1270, acc_train=0.1031, loss_test=2.3679, acc_test=0.0000
# poison_percent 0 round 86: loss_train=2.1251, acc_train=0.1052, loss_test=2.3655, acc_test=0.0000
# poison_percent 0 round 87: loss_train=2.1195, acc_train=0.1642, loss_test=2.3630, acc_test=0.0000
# poison_percent 0 round 88: loss_train=2.1285, acc_train=0.1773, loss_test=2.3603, acc_test=0.0000
# poison_percent 0 round 89: loss_train=2.1131, acc_train=0.1908, loss_test=2.3575, acc_test=0.0000
# poison_percent 0 round 90: loss_train=2.1215, acc_train=0.1845, loss_test=2.3550, acc_test=0.0000
# poison_percent 0 round 91: loss_train=2.1164, acc_train=0.1814, loss_test=2.3526, acc_test=0.0000
# poison_percent 0 round 92: loss_train=2.1486, acc_train=0.1718, loss_test=2.3502, acc_test=0.0000
# poison_percent 0 round 93: loss_train=2.1143, acc_train=0.1894, loss_test=2.3478, acc_test=0.0000
# poison_percent 0 round 94: loss_train=2.1354, acc_train=0.1756, loss_test=2.3456, acc_test=0.0000
# poison_percent 0 round 95: loss_train=2.1016, acc_train=0.1832, loss_test=2.3436, acc_test=0.0000
# poison_percent 0 round 96: loss_train=2.0995, acc_train=0.1801, loss_test=2.3417, acc_test=0.0000
# poison_percent 0 round 97: loss_train=2.1031, acc_train=0.1908, loss_test=2.3398, acc_test=0.0000
# poison_percent 0 round 98: loss_train=2.0779, acc_train=0.2025, loss_test=2.3374, acc_test=0.0000
# poison_percent 0 round 99: loss_train=2.1086, acc_train=0.1852, loss_test=2.3351, acc_test=0.0000
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\FL_ModelN1L2_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 round 0: loss_train=2.1766, acc_train=0.1689, loss_test=2.3313, acc_test=0.0000
# poison_percent 10 round 1: loss_train=2.1648, acc_train=0.1714, loss_test=2.3281, acc_test=0.0000
# poison_percent 10 round 2: loss_train=2.1960, acc_train=0.1609, loss_test=2.3247, acc_test=0.0000
# poison_percent 10 round 3: loss_train=2.1829, acc_train=0.1680, loss_test=2.3215, acc_test=0.0000
# poison_percent 10 round 4: loss_train=2.1661, acc_train=0.1609, loss_test=2.3183, acc_test=0.0000
# poison_percent 10 round 5: loss_train=2.1520, acc_train=0.1770, loss_test=2.3154, acc_test=0.0000
# poison_percent 10 round 6: loss_train=2.1474, acc_train=0.1733, loss_test=2.3124, acc_test=0.0000
# poison_percent 10 round 7: loss_train=2.1635, acc_train=0.1575, loss_test=2.3097, acc_test=0.0000
# poison_percent 10 round 8: loss_train=2.1595, acc_train=0.1631, loss_test=2.3069, acc_test=0.0000
# poison_percent 10 round 9: loss_train=2.1718, acc_train=0.1606, loss_test=2.3040, acc_test=0.0000
# poison_percent 10 round 10: loss_train=2.1696, acc_train=0.1510, loss_test=2.3012, acc_test=0.0000
# poison_percent 10 round 11: loss_train=2.2037, acc_train=0.1467, loss_test=2.2983, acc_test=0.0000
# poison_percent 10 round 12: loss_train=2.1578, acc_train=0.1470, loss_test=2.2955, acc_test=0.0000
# poison_percent 10 round 13: loss_train=2.1686, acc_train=0.2178, loss_test=2.2931, acc_test=0.0000
# poison_percent 10 round 14: loss_train=2.1852, acc_train=0.2197, loss_test=2.2905, acc_test=0.0000
# poison_percent 10 round 15: loss_train=2.1578, acc_train=0.2116, loss_test=2.2879, acc_test=0.0000
# poison_percent 10 round 16: loss_train=2.1519, acc_train=0.2175, loss_test=2.2852, acc_test=0.0000
# poison_percent 10 round 17: loss_train=2.1247, acc_train=0.2330, loss_test=2.2826, acc_test=0.4951
# poison_percent 10 round 18: loss_train=2.1348, acc_train=0.2534, loss_test=2.2800, acc_test=0.4957
# poison_percent 10 round 19: loss_train=2.1594, acc_train=0.2587, loss_test=2.2776, acc_test=0.4951
# poison_percent 10 round 20: loss_train=2.1460, acc_train=0.2543, loss_test=2.2751, acc_test=0.4957
# poison_percent 10 round 21: loss_train=2.1440, acc_train=0.2754, loss_test=2.2729, acc_test=0.4957
# poison_percent 10 round 22: loss_train=2.1650, acc_train=0.2627, loss_test=2.2705, acc_test=0.4957
# poison_percent 10 round 23: loss_train=2.1391, acc_train=0.2574, loss_test=2.2680, acc_test=0.4957
# poison_percent 10 round 24: loss_train=2.1501, acc_train=0.2726, loss_test=2.2658, acc_test=0.4957
# poison_percent 10 round 25: loss_train=2.1729, acc_train=0.2726, loss_test=2.2636, acc_test=0.4951
# poison_percent 10 round 26: loss_train=2.1272, acc_train=0.2645, loss_test=2.2612, acc_test=0.4951
# poison_percent 10 round 27: loss_train=2.1213, acc_train=0.2627, loss_test=2.2589, acc_test=0.4951
# poison_percent 10 round 28: loss_train=2.1383, acc_train=0.2710, loss_test=2.2567, acc_test=0.4957
# poison_percent 10 round 29: loss_train=2.1273, acc_train=0.2701, loss_test=2.2545, acc_test=0.4957
# poison_percent 10 round 30: loss_train=2.1423, acc_train=0.2531, loss_test=2.2523, acc_test=0.4957
# poison_percent 10 round 31: loss_train=2.1353, acc_train=0.2593, loss_test=2.2502, acc_test=0.4957
# poison_percent 10 round 32: loss_train=2.1263, acc_train=0.2760, loss_test=2.2481, acc_test=0.4957
# poison_percent 10 round 33: loss_train=2.1148, acc_train=0.2766, loss_test=2.2459, acc_test=0.4963
# poison_percent 10 round 34: loss_train=2.1323, acc_train=0.2636, loss_test=2.2437, acc_test=0.4963
# poison_percent 10 round 35: loss_train=2.1518, acc_train=0.2506, loss_test=2.2414, acc_test=0.4963
# poison_percent 10 round 36: loss_train=2.1612, acc_train=0.2537, loss_test=2.2391, acc_test=0.4963
# poison_percent 10 round 37: loss_train=2.1514, acc_train=0.2698, loss_test=2.2369, acc_test=0.4963
# poison_percent 10 round 38: loss_train=2.1355, acc_train=0.2658, loss_test=2.2349, acc_test=0.4963
# poison_percent 10 round 39: loss_train=2.1198, acc_train=0.2652, loss_test=2.2326, acc_test=0.4963
# poison_percent 10 round 40: loss_train=2.1420, acc_train=0.2704, loss_test=2.2308, acc_test=0.4963
# poison_percent 10 round 41: loss_train=2.1167, acc_train=0.2624, loss_test=2.2288, acc_test=0.4963
# poison_percent 10 round 42: loss_train=2.1212, acc_train=0.2590, loss_test=2.2268, acc_test=0.4963
# poison_percent 10 round 43: loss_train=2.1233, acc_train=0.2707, loss_test=2.2249, acc_test=0.4963
# poison_percent 10 round 44: loss_train=2.1071, acc_train=0.2713, loss_test=2.2230, acc_test=0.4963
# poison_percent 10 round 45: loss_train=2.1005, acc_train=0.2710, loss_test=2.2207, acc_test=0.4963
# poison_percent 10 round 46: loss_train=2.0889, acc_train=0.2630, loss_test=2.2186, acc_test=0.4963
# poison_percent 10 round 47: loss_train=2.1175, acc_train=0.2618, loss_test=2.2168, acc_test=0.4963
# poison_percent 10 round 48: loss_train=2.1079, acc_train=0.2769, loss_test=2.2150, acc_test=0.4963
# poison_percent 10 round 49: loss_train=2.1272, acc_train=0.2528, loss_test=2.2133, acc_test=0.4963
# poison_percent 10 round 50: loss_train=2.1157, acc_train=0.2686, loss_test=2.2115, acc_test=0.4963
# poison_percent 10 round 51: loss_train=2.1016, acc_train=0.2519, loss_test=2.2096, acc_test=0.4963
# poison_percent 10 round 52: loss_train=2.1273, acc_train=0.2543, loss_test=2.2075, acc_test=0.4963
# poison_percent 10 round 53: loss_train=2.1276, acc_train=0.2692, loss_test=2.2053, acc_test=0.4963
# poison_percent 10 round 54: loss_train=2.1130, acc_train=0.2692, loss_test=2.2033, acc_test=0.4963
# poison_percent 10 round 55: loss_train=2.1113, acc_train=0.2577, loss_test=2.2014, acc_test=0.4963
# poison_percent 10 round 56: loss_train=2.0780, acc_train=0.2649, loss_test=2.1997, acc_test=0.4963
# poison_percent 10 round 57: loss_train=2.1303, acc_train=0.2475, loss_test=2.1981, acc_test=0.4963
# poison_percent 10 round 58: loss_train=2.0815, acc_train=0.2574, loss_test=2.1962, acc_test=0.4963
# poison_percent 10 round 59: loss_train=2.0880, acc_train=0.2565, loss_test=2.1943, acc_test=0.4963
# poison_percent 10 round 60: loss_train=2.0951, acc_train=0.2630, loss_test=2.1924, acc_test=0.4963
# poison_percent 10 round 61: loss_train=2.0820, acc_train=0.2649, loss_test=2.1907, acc_test=0.4963
# poison_percent 10 round 62: loss_train=2.0918, acc_train=0.2519, loss_test=2.1886, acc_test=0.4963
# poison_percent 10 round 63: loss_train=2.0996, acc_train=0.2608, loss_test=2.1869, acc_test=0.4963
# poison_percent 10 round 64: loss_train=2.0677, acc_train=0.2683, loss_test=2.1849, acc_test=0.4963
# poison_percent 10 round 65: loss_train=2.1083, acc_train=0.2593, loss_test=2.1830, acc_test=0.4963
# poison_percent 10 round 66: loss_train=2.0596, acc_train=0.2698, loss_test=2.1812, acc_test=0.4963
# poison_percent 10 round 67: loss_train=2.1132, acc_train=0.2488, loss_test=2.1797, acc_test=0.4963
# poison_percent 10 round 68: loss_train=2.0847, acc_train=0.2605, loss_test=2.1780, acc_test=0.4963
# poison_percent 10 round 69: loss_train=2.0859, acc_train=0.2531, loss_test=2.1764, acc_test=0.4963
# poison_percent 10 round 70: loss_train=2.0843, acc_train=0.2488, loss_test=2.1746, acc_test=0.4957
# poison_percent 10 round 71: loss_train=2.1194, acc_train=0.2692, loss_test=2.1728, acc_test=0.4957
# poison_percent 10 round 72: loss_train=2.0875, acc_train=0.2528, loss_test=2.1710, acc_test=0.4957
# poison_percent 10 round 73: loss_train=2.0958, acc_train=0.2590, loss_test=2.1694, acc_test=0.4957
# poison_percent 10 round 74: loss_train=2.0964, acc_train=0.2497, loss_test=2.1676, acc_test=0.4957
# poison_percent 10 round 75: loss_train=2.0770, acc_train=0.2692, loss_test=2.1659, acc_test=0.4957
# poison_percent 10 round 76: loss_train=2.0978, acc_train=0.2577, loss_test=2.1643, acc_test=0.4957
# poison_percent 10 round 77: loss_train=2.0814, acc_train=0.2639, loss_test=2.1626, acc_test=0.4957
# poison_percent 10 round 78: loss_train=2.0695, acc_train=0.2652, loss_test=2.1610, acc_test=0.4957
# poison_percent 10 round 79: loss_train=2.0981, acc_train=0.2568, loss_test=2.1595, acc_test=0.4957
# poison_percent 10 round 80: loss_train=2.0519, acc_train=0.2670, loss_test=2.1580, acc_test=0.4957
# poison_percent 10 round 81: loss_train=2.0630, acc_train=0.2639, loss_test=2.1566, acc_test=0.4957
# poison_percent 10 round 82: loss_train=2.0670, acc_train=0.2614, loss_test=2.1550, acc_test=0.4951
# poison_percent 10 round 83: loss_train=2.0516, acc_train=0.2692, loss_test=2.1533, acc_test=0.4957
# poison_percent 10 round 84: loss_train=2.0597, acc_train=0.2624, loss_test=2.1517, acc_test=0.4957
# poison_percent 10 round 85: loss_train=2.0565, acc_train=0.2673, loss_test=2.1504, acc_test=0.4951
# poison_percent 10 round 86: loss_train=2.0511, acc_train=0.2748, loss_test=2.1488, acc_test=0.4951
# poison_percent 10 round 87: loss_train=2.0724, acc_train=0.2670, loss_test=2.1474, acc_test=0.4951
# poison_percent 10 round 88: loss_train=2.0533, acc_train=0.2723, loss_test=2.1460, acc_test=0.4951
# poison_percent 10 round 89: loss_train=2.0489, acc_train=0.2732, loss_test=2.1447, acc_test=0.4951
# poison_percent 10 round 90: loss_train=2.0437, acc_train=0.2760, loss_test=2.1433, acc_test=0.4951
# poison_percent 10 round 91: loss_train=2.0522, acc_train=0.2565, loss_test=2.1417, acc_test=0.4951
# poison_percent 10 round 92: loss_train=2.0750, acc_train=0.2627, loss_test=2.1400, acc_test=0.4951
# poison_percent 10 round 93: loss_train=2.0595, acc_train=0.2642, loss_test=2.1382, acc_test=0.4951
# poison_percent 10 round 94: loss_train=2.0529, acc_train=0.2698, loss_test=2.1364, acc_test=0.4951
# poison_percent 10 round 95: loss_train=2.0882, acc_train=0.2577, loss_test=2.1350, acc_test=0.4951
# poison_percent 10 round 96: loss_train=2.0648, acc_train=0.2503, loss_test=2.1333, acc_test=0.4951
# poison_percent 10 round 97: loss_train=2.0967, acc_train=0.2515, loss_test=2.1314, acc_test=0.4951
# poison_percent 10 round 98: loss_train=2.0277, acc_train=0.2707, loss_test=2.1298, acc_test=0.4951
# poison_percent 10 round 99: loss_train=2.0583, acc_train=0.2645, loss_test=2.1283, acc_test=0.4951
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\FL_ModelN1L2_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=2.1134, acc_train=0.3090, loss_test=2.1250, acc_test=0.4957
# poison_percent 20 round 1: loss_train=2.1230, acc_train=0.3143, loss_test=2.1223, acc_test=0.4957
# poison_percent 20 round 2: loss_train=2.1275, acc_train=0.3112, loss_test=2.1198, acc_test=0.4957
# poison_percent 20 round 3: loss_train=2.1053, acc_train=0.3143, loss_test=2.1175, acc_test=0.4957
# poison_percent 20 round 4: loss_train=2.1323, acc_train=0.3198, loss_test=2.1152, acc_test=0.4957
# poison_percent 20 round 5: loss_train=2.1264, acc_train=0.3031, loss_test=2.1130, acc_test=0.4957
# poison_percent 20 round 6: loss_train=2.1217, acc_train=0.3037, loss_test=2.1106, acc_test=0.4957
# poison_percent 20 round 7: loss_train=2.1023, acc_train=0.3154, loss_test=2.1083, acc_test=0.4957
# poison_percent 20 round 8: loss_train=2.1204, acc_train=0.3028, loss_test=2.1058, acc_test=0.4957
# poison_percent 20 round 9: loss_train=2.0869, acc_train=0.3210, loss_test=2.1034, acc_test=0.4957
# poison_percent 20 round 10: loss_train=2.0980, acc_train=0.3154, loss_test=2.1012, acc_test=0.4957
# poison_percent 20 round 11: loss_train=2.1147, acc_train=0.3059, loss_test=2.0991, acc_test=0.4957
# poison_percent 20 round 12: loss_train=2.1004, acc_train=0.3187, loss_test=2.0970, acc_test=0.4957
# poison_percent 20 round 13: loss_train=2.1132, acc_train=0.3037, loss_test=2.0950, acc_test=0.4957
# poison_percent 20 round 14: loss_train=2.1216, acc_train=0.3129, loss_test=2.0929, acc_test=0.4963
# poison_percent 20 round 15: loss_train=2.0997, acc_train=0.3131, loss_test=2.0910, acc_test=0.4963
# poison_percent 20 round 16: loss_train=2.1338, acc_train=0.3117, loss_test=2.0890, acc_test=0.4963
# poison_percent 20 round 17: loss_train=2.1219, acc_train=0.3165, loss_test=2.0869, acc_test=0.4963
# poison_percent 20 round 18: loss_train=2.1121, acc_train=0.3073, loss_test=2.0848, acc_test=0.4963
# poison_percent 20 round 19: loss_train=2.0927, acc_train=0.3104, loss_test=2.0830, acc_test=0.4963
# poison_percent 20 round 20: loss_train=2.1124, acc_train=0.3073, loss_test=2.0809, acc_test=0.4963
# poison_percent 20 round 21: loss_train=2.1135, acc_train=0.3159, loss_test=2.0790, acc_test=0.4963
# poison_percent 20 round 22: loss_train=2.0543, acc_train=0.3293, loss_test=2.0770, acc_test=0.4963
# poison_percent 20 round 23: loss_train=2.1008, acc_train=0.3117, loss_test=2.0749, acc_test=0.4963
# poison_percent 20 round 24: loss_train=2.1080, acc_train=0.3159, loss_test=2.0730, acc_test=0.4963
# poison_percent 20 round 25: loss_train=2.0981, acc_train=0.3265, loss_test=2.0711, acc_test=0.4963
# poison_percent 20 round 26: loss_train=2.1179, acc_train=0.3109, loss_test=2.0692, acc_test=0.4963
# poison_percent 20 round 27: loss_train=2.1189, acc_train=0.3056, loss_test=2.0674, acc_test=0.4963
# poison_percent 20 round 28: loss_train=2.0878, acc_train=0.3221, loss_test=2.0654, acc_test=0.4963
# poison_percent 20 round 29: loss_train=2.0838, acc_train=0.3344, loss_test=2.0636, acc_test=0.4963
# poison_percent 20 round 30: loss_train=2.0934, acc_train=0.3207, loss_test=2.0618, acc_test=0.4963
# poison_percent 20 round 31: loss_train=2.0940, acc_train=0.3073, loss_test=2.0598, acc_test=0.4963
# poison_percent 20 round 32: loss_train=2.1141, acc_train=0.3251, loss_test=2.0580, acc_test=0.4963
# poison_percent 20 round 33: loss_train=2.1540, acc_train=0.3031, loss_test=2.0561, acc_test=0.4963
# poison_percent 20 round 34: loss_train=2.0934, acc_train=0.3145, loss_test=2.0544, acc_test=0.4963
# poison_percent 20 round 35: loss_train=2.0887, acc_train=0.3137, loss_test=2.0526, acc_test=0.4963
# poison_percent 20 round 36: loss_train=2.1357, acc_train=0.3101, loss_test=2.0509, acc_test=0.4963
# poison_percent 20 round 37: loss_train=2.1193, acc_train=0.3106, loss_test=2.0493, acc_test=0.4963
# poison_percent 20 round 38: loss_train=2.0971, acc_train=0.3134, loss_test=2.0476, acc_test=0.4963
# poison_percent 20 round 39: loss_train=2.1006, acc_train=0.3117, loss_test=2.0461, acc_test=0.4963
# poison_percent 20 round 40: loss_train=2.1131, acc_train=0.3006, loss_test=2.0444, acc_test=0.4963
# poison_percent 20 round 41: loss_train=2.0889, acc_train=0.3123, loss_test=2.0427, acc_test=0.4963
# poison_percent 20 round 42: loss_train=2.0958, acc_train=0.3173, loss_test=2.0410, acc_test=0.4963
# poison_percent 20 round 43: loss_train=2.1209, acc_train=0.2939, loss_test=2.0394, acc_test=0.4963
# poison_percent 20 round 44: loss_train=2.1003, acc_train=0.3117, loss_test=2.0377, acc_test=0.4963
# poison_percent 20 round 45: loss_train=2.1199, acc_train=0.3159, loss_test=2.0360, acc_test=0.4963
# poison_percent 20 round 46: loss_train=2.1015, acc_train=0.3009, loss_test=2.0345, acc_test=0.4963
# poison_percent 20 round 47: loss_train=2.1017, acc_train=0.3084, loss_test=2.0329, acc_test=0.4963
# poison_percent 20 round 48: loss_train=2.0743, acc_train=0.3154, loss_test=2.0313, acc_test=0.4963
# poison_percent 20 round 49: loss_train=2.0807, acc_train=0.3098, loss_test=2.0296, acc_test=0.4963
# poison_percent 20 round 50: loss_train=2.0822, acc_train=0.3039, loss_test=2.0281, acc_test=0.4963
# poison_percent 20 round 51: loss_train=2.1003, acc_train=0.3151, loss_test=2.0268, acc_test=0.4963
# poison_percent 20 round 52: loss_train=2.0712, acc_train=0.3059, loss_test=2.0252, acc_test=0.4963
# poison_percent 20 round 53: loss_train=2.0978, acc_train=0.3154, loss_test=2.0238, acc_test=0.4963
# poison_percent 20 round 54: loss_train=2.1188, acc_train=0.3084, loss_test=2.0224, acc_test=0.4963
# poison_percent 20 round 55: loss_train=2.0477, acc_train=0.3282, loss_test=2.0209, acc_test=0.4963
# poison_percent 20 round 56: loss_train=2.1127, acc_train=0.3090, loss_test=2.0195, acc_test=0.4963
# poison_percent 20 round 57: loss_train=2.1016, acc_train=0.3087, loss_test=2.0182, acc_test=0.4963
# poison_percent 20 round 58: loss_train=2.0641, acc_train=0.3218, loss_test=2.0169, acc_test=0.4963
# poison_percent 20 round 59: loss_train=2.1071, acc_train=0.3143, loss_test=2.0156, acc_test=0.4963
# poison_percent 20 round 60: loss_train=2.0765, acc_train=0.3067, loss_test=2.0141, acc_test=0.4963
# poison_percent 20 round 61: loss_train=2.0611, acc_train=0.3176, loss_test=2.0127, acc_test=0.4969
# poison_percent 20 round 62: loss_train=2.0711, acc_train=0.3112, loss_test=2.0114, acc_test=0.4963
# poison_percent 20 round 63: loss_train=2.0838, acc_train=0.3204, loss_test=2.0101, acc_test=0.4963
# poison_percent 20 round 64: loss_train=2.0654, acc_train=0.3090, loss_test=2.0089, acc_test=0.4963
# poison_percent 20 round 65: loss_train=2.0900, acc_train=0.3087, loss_test=2.0074, acc_test=0.4963
# poison_percent 20 round 66: loss_train=2.1072, acc_train=0.3210, loss_test=2.0062, acc_test=0.4963
# poison_percent 20 round 67: loss_train=2.0913, acc_train=0.3059, loss_test=2.0048, acc_test=0.4963
# poison_percent 20 round 68: loss_train=2.0651, acc_train=0.3285, loss_test=2.0033, acc_test=0.4969
# poison_percent 20 round 69: loss_train=2.0517, acc_train=0.3154, loss_test=2.0019, acc_test=0.4969
# poison_percent 20 round 70: loss_train=2.0884, acc_train=0.3179, loss_test=2.0007, acc_test=0.4963
# poison_percent 20 round 71: loss_train=2.0667, acc_train=0.3123, loss_test=1.9995, acc_test=0.4963
# poison_percent 20 round 72: loss_train=2.1109, acc_train=0.3201, loss_test=1.9984, acc_test=0.4963
# poison_percent 20 round 73: loss_train=2.1082, acc_train=0.3117, loss_test=1.9969, acc_test=0.4963
# poison_percent 20 round 74: loss_train=2.0440, acc_train=0.3235, loss_test=1.9956, acc_test=0.4963
# poison_percent 20 round 75: loss_train=2.0725, acc_train=0.3137, loss_test=1.9943, acc_test=0.4969
# poison_percent 20 round 76: loss_train=2.0652, acc_train=0.3115, loss_test=1.9932, acc_test=0.4969
# poison_percent 20 round 77: loss_train=2.0877, acc_train=0.3095, loss_test=1.9921, acc_test=0.4969
# poison_percent 20 round 78: loss_train=2.0843, acc_train=0.3162, loss_test=1.9907, acc_test=0.4969
# poison_percent 20 round 79: loss_train=2.0393, acc_train=0.3187, loss_test=1.9894, acc_test=0.4969
# poison_percent 20 round 80: loss_train=2.0952, acc_train=0.3051, loss_test=1.9882, acc_test=0.4969
# poison_percent 20 round 81: loss_train=2.0759, acc_train=0.3120, loss_test=1.9869, acc_test=0.4969
# poison_percent 20 round 82: loss_train=2.0844, acc_train=0.3117, loss_test=1.9857, acc_test=0.4969
# poison_percent 20 round 83: loss_train=2.0999, acc_train=0.3198, loss_test=1.9848, acc_test=0.4969
# poison_percent 20 round 84: loss_train=2.0707, acc_train=0.3196, loss_test=1.9836, acc_test=0.4969
# poison_percent 20 round 85: loss_train=2.0617, acc_train=0.3137, loss_test=1.9826, acc_test=0.4969
# poison_percent 20 round 86: loss_train=2.0444, acc_train=0.3310, loss_test=1.9814, acc_test=0.4969
# poison_percent 20 round 87: loss_train=2.0968, acc_train=0.3009, loss_test=1.9804, acc_test=0.4969
# poison_percent 20 round 88: loss_train=2.0450, acc_train=0.3224, loss_test=1.9795, acc_test=0.4969
# poison_percent 20 round 89: loss_train=2.0298, acc_train=0.3159, loss_test=1.9785, acc_test=0.4969
# poison_percent 20 round 90: loss_train=2.0590, acc_train=0.3176, loss_test=1.9776, acc_test=0.4969
# poison_percent 20 round 91: loss_train=2.0836, acc_train=0.3204, loss_test=1.9766, acc_test=0.4969
# poison_percent 20 round 92: loss_train=2.0704, acc_train=0.3246, loss_test=1.9754, acc_test=0.4969
# poison_percent 20 round 93: loss_train=2.0949, acc_train=0.3090, loss_test=1.9743, acc_test=0.4969
# poison_percent 20 round 94: loss_train=2.0877, acc_train=0.3157, loss_test=1.9733, acc_test=0.4969
# poison_percent 20 round 95: loss_train=2.0617, acc_train=0.3232, loss_test=1.9723, acc_test=0.4969
# poison_percent 20 round 96: loss_train=2.0626, acc_train=0.3218, loss_test=1.9712, acc_test=0.4969
# poison_percent 20 round 97: loss_train=2.0549, acc_train=0.3226, loss_test=1.9700, acc_test=0.4969
# poison_percent 20 round 98: loss_train=2.0599, acc_train=0.3212, loss_test=1.9691, acc_test=0.4969
# poison_percent 20 round 99: loss_train=2.0748, acc_train=0.3045, loss_test=1.9681, acc_test=0.4969
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\FL_ModelN1L2_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=2.1486, acc_train=0.3595, loss_test=1.9654, acc_test=0.4975
# poison_percent 30 round 1: loss_train=2.1585, acc_train=0.3536, loss_test=1.9626, acc_test=0.4975
# poison_percent 30 round 2: loss_train=2.1812, acc_train=0.3647, loss_test=1.9606, acc_test=0.4975
# poison_percent 30 round 3: loss_train=2.1603, acc_train=0.3558, loss_test=1.9586, acc_test=0.4975
# poison_percent 30 round 4: loss_train=2.1102, acc_train=0.3595, loss_test=1.9566, acc_test=0.4975
# poison_percent 30 round 5: loss_train=2.1111, acc_train=0.3664, loss_test=1.9544, acc_test=0.4975
# poison_percent 30 round 6: loss_train=2.1553, acc_train=0.3627, loss_test=1.9526, acc_test=0.4975
# poison_percent 30 round 7: loss_train=2.1250, acc_train=0.3696, loss_test=1.9508, acc_test=0.4982
# poison_percent 30 round 8: loss_train=2.1433, acc_train=0.3536, loss_test=1.9489, acc_test=0.4982
# poison_percent 30 round 9: loss_train=2.1416, acc_train=0.3492, loss_test=1.9468, acc_test=0.4982
# poison_percent 30 round 10: loss_train=2.1414, acc_train=0.3497, loss_test=1.9451, acc_test=0.4982
# poison_percent 30 round 11: loss_train=2.1641, acc_train=0.3440, loss_test=1.9433, acc_test=0.4982
# poison_percent 30 round 12: loss_train=2.1784, acc_train=0.3489, loss_test=1.9416, acc_test=0.4982
# poison_percent 30 round 13: loss_train=2.1134, acc_train=0.3576, loss_test=1.9399, acc_test=0.4988
# poison_percent 30 round 14: loss_train=2.1409, acc_train=0.3600, loss_test=1.9382, acc_test=0.4988
# poison_percent 30 round 15: loss_train=2.1224, acc_train=0.3556, loss_test=1.9363, acc_test=0.4988
# poison_percent 30 round 16: loss_train=2.1767, acc_train=0.3514, loss_test=1.9347, acc_test=0.4988
# poison_percent 30 round 17: loss_train=2.1185, acc_train=0.3613, loss_test=1.9331, acc_test=0.4988
# poison_percent 30 round 18: loss_train=2.1400, acc_train=0.3561, loss_test=1.9315, acc_test=0.4988
# poison_percent 30 round 19: loss_train=2.1474, acc_train=0.3492, loss_test=1.9301, acc_test=0.4988
# poison_percent 30 round 20: loss_train=2.1399, acc_train=0.3524, loss_test=1.9285, acc_test=0.4988
# poison_percent 30 round 21: loss_train=2.1187, acc_train=0.3541, loss_test=1.9269, acc_test=0.4988
# poison_percent 30 round 22: loss_train=2.1060, acc_train=0.3615, loss_test=1.9254, acc_test=0.4988
# poison_percent 30 round 23: loss_train=2.1000, acc_train=0.3655, loss_test=1.9239, acc_test=0.4988
# poison_percent 30 round 24: loss_train=2.1206, acc_train=0.3608, loss_test=1.9224, acc_test=0.4988
# poison_percent 30 round 25: loss_train=2.1729, acc_train=0.3475, loss_test=1.9209, acc_test=0.4988
# poison_percent 30 round 26: loss_train=2.1445, acc_train=0.3487, loss_test=1.9195, acc_test=0.4988
# poison_percent 30 round 27: loss_train=2.1088, acc_train=0.3536, loss_test=1.9180, acc_test=0.4988
# poison_percent 30 round 28: loss_train=2.0958, acc_train=0.3640, loss_test=1.9167, acc_test=0.4988
# poison_percent 30 round 29: loss_train=2.1593, acc_train=0.3448, loss_test=1.9153, acc_test=0.4988
# poison_percent 30 round 30: loss_train=2.0820, acc_train=0.3645, loss_test=1.9140, acc_test=0.4988
# poison_percent 30 round 31: loss_train=2.1292, acc_train=0.3561, loss_test=1.9126, acc_test=0.4988
# poison_percent 30 round 32: loss_train=2.1207, acc_train=0.3588, loss_test=1.9113, acc_test=0.4988
# poison_percent 30 round 33: loss_train=2.1576, acc_train=0.3445, loss_test=1.9101, acc_test=0.4988
# poison_percent 30 round 34: loss_train=2.0833, acc_train=0.3664, loss_test=1.9088, acc_test=0.4988
# poison_percent 30 round 35: loss_train=2.1473, acc_train=0.3509, loss_test=1.9074, acc_test=0.4988
# poison_percent 30 round 36: loss_train=2.1206, acc_train=0.3672, loss_test=1.9063, acc_test=0.4988
# poison_percent 30 round 37: loss_train=2.1237, acc_train=0.3615, loss_test=1.9051, acc_test=0.4988
# poison_percent 30 round 38: loss_train=2.1095, acc_train=0.3499, loss_test=1.9038, acc_test=0.4988
# poison_percent 30 round 39: loss_train=2.1623, acc_train=0.3534, loss_test=1.9024, acc_test=0.4988
# poison_percent 30 round 40: loss_train=2.1029, acc_train=0.3738, loss_test=1.9012, acc_test=0.4988
# poison_percent 30 round 41: loss_train=2.1028, acc_train=0.3659, loss_test=1.9000, acc_test=0.4988
# poison_percent 30 round 42: loss_train=2.1078, acc_train=0.3553, loss_test=1.8989, acc_test=0.4988
# poison_percent 30 round 43: loss_train=2.0989, acc_train=0.3561, loss_test=1.8979, acc_test=0.4988
# poison_percent 30 round 44: loss_train=2.1250, acc_train=0.3704, loss_test=1.8965, acc_test=0.4988
# poison_percent 30 round 45: loss_train=2.0917, acc_train=0.3521, loss_test=1.8953, acc_test=0.4988
# poison_percent 30 round 46: loss_train=2.1403, acc_train=0.3583, loss_test=1.8941, acc_test=0.4988
# poison_percent 30 round 47: loss_train=2.1546, acc_train=0.3519, loss_test=1.8929, acc_test=0.4988
# poison_percent 30 round 48: loss_train=2.1021, acc_train=0.3586, loss_test=1.8916, acc_test=0.4988
# poison_percent 30 round 49: loss_train=2.1345, acc_train=0.3514, loss_test=1.8905, acc_test=0.4988
# poison_percent 30 round 50: loss_train=2.0887, acc_train=0.3699, loss_test=1.8894, acc_test=0.4988
# poison_percent 30 round 51: loss_train=2.0856, acc_train=0.3659, loss_test=1.8884, acc_test=0.4988
# poison_percent 30 round 52: loss_train=2.0754, acc_train=0.3716, loss_test=1.8873, acc_test=0.4988
# poison_percent 30 round 53: loss_train=2.0853, acc_train=0.3521, loss_test=1.8866, acc_test=0.4988
# poison_percent 30 round 54: loss_train=2.1398, acc_train=0.3521, loss_test=1.8856, acc_test=0.4988
# poison_percent 30 round 55: loss_train=2.1341, acc_train=0.3610, loss_test=1.8844, acc_test=0.4988
# poison_percent 30 round 56: loss_train=2.1086, acc_train=0.3630, loss_test=1.8833, acc_test=0.4988
# poison_percent 30 round 57: loss_train=2.0848, acc_train=0.3632, loss_test=1.8824, acc_test=0.4988
# poison_percent 30 round 58: loss_train=2.0896, acc_train=0.3748, loss_test=1.8815, acc_test=0.4988
# poison_percent 30 round 59: loss_train=2.1401, acc_train=0.3618, loss_test=1.8804, acc_test=0.4988
# poison_percent 30 round 60: loss_train=2.1349, acc_train=0.3687, loss_test=1.8795, acc_test=0.4988
# poison_percent 30 round 61: loss_train=2.1141, acc_train=0.3610, loss_test=1.8787, acc_test=0.4988
# poison_percent 30 round 62: loss_train=2.0912, acc_train=0.3603, loss_test=1.8778, acc_test=0.4988
# poison_percent 30 round 63: loss_train=2.1079, acc_train=0.3655, loss_test=1.8770, acc_test=0.4988
# poison_percent 30 round 64: loss_train=2.1395, acc_train=0.3635, loss_test=1.8763, acc_test=0.4988
# poison_percent 30 round 65: loss_train=2.0557, acc_train=0.3694, loss_test=1.8754, acc_test=0.4988
# poison_percent 30 round 66: loss_train=2.1279, acc_train=0.3615, loss_test=1.8745, acc_test=0.4988
# poison_percent 30 round 67: loss_train=2.0892, acc_train=0.3526, loss_test=1.8736, acc_test=0.4988
# poison_percent 30 round 68: loss_train=2.1029, acc_train=0.3494, loss_test=1.8726, acc_test=0.4988
# poison_percent 30 round 69: loss_train=2.0772, acc_train=0.3728, loss_test=1.8717, acc_test=0.4988
# poison_percent 30 round 70: loss_train=2.1077, acc_train=0.3630, loss_test=1.8709, acc_test=0.4988
# poison_percent 30 round 71: loss_train=2.1372, acc_train=0.3581, loss_test=1.8700, acc_test=0.4988
# poison_percent 30 round 72: loss_train=2.1197, acc_train=0.3605, loss_test=1.8692, acc_test=0.4988
# poison_percent 30 round 73: loss_train=2.1290, acc_train=0.3605, loss_test=1.8684, acc_test=0.4988
# poison_percent 30 round 74: loss_train=2.1100, acc_train=0.3581, loss_test=1.8676, acc_test=0.4988
# poison_percent 30 round 75: loss_train=2.1210, acc_train=0.3625, loss_test=1.8668, acc_test=0.4988
# poison_percent 30 round 76: loss_train=2.0911, acc_train=0.3625, loss_test=1.8659, acc_test=0.4988
# poison_percent 30 round 77: loss_train=2.1060, acc_train=0.3541, loss_test=1.8649, acc_test=0.4988
# poison_percent 30 round 78: loss_train=2.1347, acc_train=0.3647, loss_test=1.8641, acc_test=0.4988
# poison_percent 30 round 79: loss_train=2.1216, acc_train=0.3499, loss_test=1.8632, acc_test=0.4988
# poison_percent 30 round 80: loss_train=2.0802, acc_train=0.3716, loss_test=1.8622, acc_test=0.4988
# poison_percent 30 round 81: loss_train=2.1061, acc_train=0.3603, loss_test=1.8613, acc_test=0.4988
# poison_percent 30 round 82: loss_train=2.1534, acc_train=0.3534, loss_test=1.8604, acc_test=0.4988
# poison_percent 30 round 83: loss_train=2.0995, acc_train=0.3586, loss_test=1.8598, acc_test=0.4988
# poison_percent 30 round 84: loss_train=2.0755, acc_train=0.3613, loss_test=1.8591, acc_test=0.4988
# poison_percent 30 round 85: loss_train=2.0452, acc_train=0.3726, loss_test=1.8586, acc_test=0.4988
# poison_percent 30 round 86: loss_train=2.1403, acc_train=0.3627, loss_test=1.8579, acc_test=0.4988
# poison_percent 30 round 87: loss_train=2.1092, acc_train=0.3546, loss_test=1.8573, acc_test=0.4988
# poison_percent 30 round 88: loss_train=2.0668, acc_train=0.3657, loss_test=1.8565, acc_test=0.4988
# poison_percent 30 round 89: loss_train=2.1049, acc_train=0.3652, loss_test=1.8559, acc_test=0.4988
# poison_percent 30 round 90: loss_train=2.0953, acc_train=0.3521, loss_test=1.8552, acc_test=0.4988
# poison_percent 30 round 91: loss_train=2.1340, acc_train=0.3706, loss_test=1.8546, acc_test=0.4988
# poison_percent 30 round 92: loss_train=2.0809, acc_train=0.3664, loss_test=1.8539, acc_test=0.4988
# poison_percent 30 round 93: loss_train=2.1294, acc_train=0.3600, loss_test=1.8534, acc_test=0.4988
# poison_percent 30 round 94: loss_train=2.0835, acc_train=0.3724, loss_test=1.8526, acc_test=0.4988
# poison_percent 30 round 95: loss_train=2.1028, acc_train=0.3620, loss_test=1.8519, acc_test=0.4988
# poison_percent 30 round 96: loss_train=2.1100, acc_train=0.3551, loss_test=1.8513, acc_test=0.4988
# poison_percent 30 round 97: loss_train=2.1194, acc_train=0.3696, loss_test=1.8507, acc_test=0.4988
# poison_percent 30 round 98: loss_train=2.0859, acc_train=0.3632, loss_test=1.8501, acc_test=0.4988
# poison_percent 30 round 99: loss_train=2.1300, acc_train=0.3492, loss_test=1.8497, acc_test=0.4988
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\FL_ModelN1L2_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=2.2247, acc_train=0.3902, loss_test=1.8474, acc_test=0.4994
# poison_percent 40 round 1: loss_train=2.1958, acc_train=0.3983, loss_test=1.8454, acc_test=0.4994
# poison_percent 40 round 2: loss_train=2.1454, acc_train=0.4067, loss_test=1.8435, acc_test=0.4994
# poison_percent 40 round 3: loss_train=2.1319, acc_train=0.3996, loss_test=1.8417, acc_test=0.4994
# poison_percent 40 round 4: loss_train=2.1616, acc_train=0.4092, loss_test=1.8400, acc_test=0.4994
# poison_percent 40 round 5: loss_train=2.1512, acc_train=0.4094, loss_test=1.8385, acc_test=0.4994
# poison_percent 40 round 6: loss_train=2.1467, acc_train=0.4150, loss_test=1.8369, acc_test=0.4994
# poison_percent 40 round 7: loss_train=2.0772, acc_train=0.4154, loss_test=1.8354, acc_test=0.4994
# poison_percent 40 round 8: loss_train=2.1083, acc_train=0.4039, loss_test=1.8341, acc_test=0.4994
# poison_percent 40 round 9: loss_train=2.1524, acc_train=0.4037, loss_test=1.8326, acc_test=0.4994
# poison_percent 40 round 10: loss_train=2.1384, acc_train=0.4101, loss_test=1.8310, acc_test=0.4994
# poison_percent 40 round 11: loss_train=2.1419, acc_train=0.4000, loss_test=1.8294, acc_test=0.4994
# poison_percent 40 round 12: loss_train=2.1347, acc_train=0.4003, loss_test=1.8279, acc_test=0.4994
# poison_percent 40 round 13: loss_train=2.1300, acc_train=0.4041, loss_test=1.8264, acc_test=0.4994
# poison_percent 40 round 14: loss_train=2.1524, acc_train=0.4144, loss_test=1.8250, acc_test=0.4994
# poison_percent 40 round 15: loss_train=2.1185, acc_train=0.4139, loss_test=1.8237, acc_test=0.4994
# poison_percent 40 round 16: loss_train=2.1027, acc_train=0.4084, loss_test=1.8225, acc_test=0.4994
# poison_percent 40 round 17: loss_train=2.1339, acc_train=0.4065, loss_test=1.8211, acc_test=0.4994
# poison_percent 40 round 18: loss_train=2.1625, acc_train=0.4107, loss_test=1.8198, acc_test=0.4994
# poison_percent 40 round 19: loss_train=2.1118, acc_train=0.4167, loss_test=1.8185, acc_test=0.4994
# poison_percent 40 round 20: loss_train=2.1047, acc_train=0.4208, loss_test=1.8171, acc_test=0.4994
# poison_percent 40 round 21: loss_train=2.1255, acc_train=0.4135, loss_test=1.8157, acc_test=0.4994
# poison_percent 40 round 22: loss_train=2.1387, acc_train=0.4097, loss_test=1.8144, acc_test=0.4994
# poison_percent 40 round 23: loss_train=2.1377, acc_train=0.4139, loss_test=1.8131, acc_test=0.4994
# poison_percent 40 round 24: loss_train=2.0737, acc_train=0.4135, loss_test=1.8118, acc_test=0.4994
# poison_percent 40 round 25: loss_train=2.1053, acc_train=0.4167, loss_test=1.8105, acc_test=0.4994
# poison_percent 40 round 26: loss_train=2.1221, acc_train=0.4129, loss_test=1.8091, acc_test=0.4994
# poison_percent 40 round 27: loss_train=2.1139, acc_train=0.4035, loss_test=1.8079, acc_test=0.4994
# poison_percent 40 round 28: loss_train=2.1054, acc_train=0.4227, loss_test=1.8067, acc_test=0.4994
# poison_percent 40 round 29: loss_train=2.0810, acc_train=0.4024, loss_test=1.8055, acc_test=0.4994
# poison_percent 40 round 30: loss_train=2.1372, acc_train=0.4041, loss_test=1.8042, acc_test=0.4994
# poison_percent 40 round 31: loss_train=2.0577, acc_train=0.4107, loss_test=1.8032, acc_test=0.4994
# poison_percent 40 round 32: loss_train=2.1006, acc_train=0.4026, loss_test=1.8020, acc_test=0.4994
# poison_percent 40 round 33: loss_train=2.1516, acc_train=0.4065, loss_test=1.8010, acc_test=0.4994
# poison_percent 40 round 34: loss_train=2.0959, acc_train=0.4144, loss_test=1.7999, acc_test=0.4994
# poison_percent 40 round 35: loss_train=2.0776, acc_train=0.4097, loss_test=1.7988, acc_test=0.4994
# poison_percent 40 round 36: loss_train=2.1070, acc_train=0.3979, loss_test=1.7977, acc_test=0.4994
# poison_percent 40 round 37: loss_train=2.0915, acc_train=0.4216, loss_test=1.7967, acc_test=0.4994
# poison_percent 40 round 38: loss_train=2.0958, acc_train=0.4225, loss_test=1.7957, acc_test=0.4994
# poison_percent 40 round 39: loss_train=2.0601, acc_train=0.4139, loss_test=1.7946, acc_test=0.4994
# poison_percent 40 round 40: loss_train=2.0895, acc_train=0.4075, loss_test=1.7936, acc_test=0.4994
# poison_percent 40 round 41: loss_train=2.0717, acc_train=0.4082, loss_test=1.7925, acc_test=0.4994
# poison_percent 40 round 42: loss_train=2.0852, acc_train=0.4150, loss_test=1.7914, acc_test=0.4994
# poison_percent 40 round 43: loss_train=2.0787, acc_train=0.4124, loss_test=1.7904, acc_test=0.4994
# poison_percent 40 round 44: loss_train=2.0574, acc_train=0.4163, loss_test=1.7894, acc_test=0.4994
# poison_percent 40 round 45: loss_train=2.0963, acc_train=0.4013, loss_test=1.7883, acc_test=0.4994
# poison_percent 40 round 46: loss_train=2.0932, acc_train=0.4235, loss_test=1.7873, acc_test=0.4994
# poison_percent 40 round 47: loss_train=2.0883, acc_train=0.4105, loss_test=1.7864, acc_test=0.4994
# poison_percent 40 round 48: loss_train=2.0783, acc_train=0.4135, loss_test=1.7853, acc_test=0.4994
# poison_percent 40 round 49: loss_train=2.0889, acc_train=0.4092, loss_test=1.7843, acc_test=0.4994
# poison_percent 40 round 50: loss_train=2.0727, acc_train=0.4032, loss_test=1.7833, acc_test=0.4994
# poison_percent 40 round 51: loss_train=2.0756, acc_train=0.4084, loss_test=1.7824, acc_test=0.4994
# poison_percent 40 round 52: loss_train=2.0681, acc_train=0.4020, loss_test=1.7814, acc_test=0.4994
# poison_percent 40 round 53: loss_train=2.0442, acc_train=0.4028, loss_test=1.7805, acc_test=0.4994
# poison_percent 40 round 54: loss_train=2.0541, acc_train=0.4103, loss_test=1.7796, acc_test=0.4994
# poison_percent 40 round 55: loss_train=2.0592, acc_train=0.4090, loss_test=1.7787, acc_test=0.4994
# poison_percent 40 round 56: loss_train=2.0846, acc_train=0.4056, loss_test=1.7778, acc_test=0.4994
# poison_percent 40 round 57: loss_train=2.0716, acc_train=0.4103, loss_test=1.7769, acc_test=0.4994
# poison_percent 40 round 58: loss_train=2.0890, acc_train=0.4047, loss_test=1.7760, acc_test=0.4994
# poison_percent 40 round 59: loss_train=2.0641, acc_train=0.4084, loss_test=1.7752, acc_test=0.4994
# poison_percent 40 round 60: loss_train=2.0589, acc_train=0.4161, loss_test=1.7743, acc_test=0.4994
# poison_percent 40 round 61: loss_train=2.0402, acc_train=0.4018, loss_test=1.7734, acc_test=0.4994
# poison_percent 40 round 62: loss_train=2.0722, acc_train=0.4180, loss_test=1.7725, acc_test=0.4994
# poison_percent 40 round 63: loss_train=2.0847, acc_train=0.4088, loss_test=1.7717, acc_test=0.4994
# poison_percent 40 round 64: loss_train=2.0307, acc_train=0.4193, loss_test=1.7708, acc_test=0.4994
# poison_percent 40 round 65: loss_train=2.0498, acc_train=0.4156, loss_test=1.7700, acc_test=0.4994
# poison_percent 40 round 66: loss_train=2.0709, acc_train=0.4028, loss_test=1.7693, acc_test=0.4994
# poison_percent 40 round 67: loss_train=2.0404, acc_train=0.4094, loss_test=1.7685, acc_test=0.4994
# poison_percent 40 round 68: loss_train=2.0562, acc_train=0.4126, loss_test=1.7677, acc_test=0.4994
# poison_percent 40 round 69: loss_train=2.0562, acc_train=0.4178, loss_test=1.7669, acc_test=0.4994
# poison_percent 40 round 70: loss_train=2.0431, acc_train=0.4075, loss_test=1.7661, acc_test=0.4994
# poison_percent 40 round 71: loss_train=2.0393, acc_train=0.4188, loss_test=1.7653, acc_test=0.4994
# poison_percent 40 round 72: loss_train=2.0349, acc_train=0.4101, loss_test=1.7645, acc_test=0.4994
# poison_percent 40 round 73: loss_train=2.0635, acc_train=0.4097, loss_test=1.7637, acc_test=0.4994
# poison_percent 40 round 74: loss_train=2.0509, acc_train=0.4137, loss_test=1.7629, acc_test=0.4994
# poison_percent 40 round 75: loss_train=2.0388, acc_train=0.4107, loss_test=1.7620, acc_test=0.4994
# poison_percent 40 round 76: loss_train=2.0193, acc_train=0.4208, loss_test=1.7612, acc_test=0.4994
# poison_percent 40 round 77: loss_train=2.0456, acc_train=0.4099, loss_test=1.7605, acc_test=0.4994
# poison_percent 40 round 78: loss_train=2.0278, acc_train=0.4092, loss_test=1.7598, acc_test=0.4994
# ...
# poison_percent 40 round 42: loss_train=0.4264, acc_train=0.8680, loss_test=0.2438, acc_test=0.9418
# poison_percent 40 round 43: loss_train=0.4320, acc_train=0.8635, loss_test=0.2412, acc_test=0.9436
# poison_percent 40 round 44: loss_train=0.4319, acc_train=0.8652, loss_test=0.2399, acc_test=0.9430
# poison_percent 40 round 45: loss_train=0.4270, acc_train=0.8620, loss_test=0.2435, acc_test=0.9418
# poison_percent 40 round 46: loss_train=0.4103, acc_train=0.8646, loss_test=0.2445, acc_test=0.9412
# poison_percent 40 round 47: loss_train=0.4261, acc_train=0.8680, loss_test=0.2415, acc_test=0.9430
# poison_percent 40 round 48: loss_train=0.4312, acc_train=0.8618, loss_test=0.2426, acc_test=0.9418
# poison_percent 40 round 49: loss_train=0.4305, acc_train=0.8657, loss_test=0.2409, acc_test=0.9424
# poison_percent 40 round 50: loss_train=0.4254, acc_train=0.8729, loss_test=0.2469, acc_test=0.9393
# poison_percent 40 round 51: loss_train=0.4277, acc_train=0.8627, loss_test=0.2459, acc_test=0.9393
# poison_percent 40 round 52: loss_train=0.4557, acc_train=0.8511, loss_test=0.2422, acc_test=0.9424
# poison_percent 40 round 53: loss_train=0.4083, acc_train=0.8614, loss_test=0.2411, acc_test=0.9436
# poison_percent 40 round 54: loss_train=0.4180, acc_train=0.8710, loss_test=0.2396, acc_test=0.9442
# poison_percent 40 round 55: loss_train=0.4544, acc_train=0.8597, loss_test=0.2425, acc_test=0.9424
# poison_percent 40 round 56: loss_train=0.4138, acc_train=0.8723, loss_test=0.2438, acc_test=0.9424
# poison_percent 40 round 57: loss_train=0.4103, acc_train=0.8714, loss_test=0.2414, acc_test=0.9430
# poison_percent 40 round 58: loss_train=0.3919, acc_train=0.8795, loss_test=0.2464, acc_test=0.9406
# poison_percent 40 round 59: loss_train=0.4216, acc_train=0.8684, loss_test=0.2474, acc_test=0.9406
# poison_percent 40 round 60: loss_train=0.4513, acc_train=0.8642, loss_test=0.2438, acc_test=0.9436
# poison_percent 40 round 61: loss_train=0.3981, acc_train=0.8729, loss_test=0.2435, acc_test=0.9424
# poison_percent 40 round 62: loss_train=0.4039, acc_train=0.8684, loss_test=0.2428, acc_test=0.9430
# poison_percent 40 round 63: loss_train=0.4082, acc_train=0.8708, loss_test=0.2457, acc_test=0.9412
# poison_percent 40 round 64: loss_train=0.4228, acc_train=0.8672, loss_test=0.2449, acc_test=0.9424
# poison_percent 40 round 65: loss_train=0.4300, acc_train=0.8659, loss_test=0.2437, acc_test=0.9430
# poison_percent 40 round 66: loss_train=0.4178, acc_train=0.8639, loss_test=0.2448, acc_test=0.9442
# poison_percent 40 round 67: loss_train=0.4155, acc_train=0.8716, loss_test=0.2439, acc_test=0.9436
# poison_percent 40 round 68: loss_train=0.4057, acc_train=0.8639, loss_test=0.2448, acc_test=0.9442
# poison_percent 40 round 69: loss_train=0.4036, acc_train=0.8731, loss_test=0.2459, acc_test=0.9442
# poison_percent 40 round 70: loss_train=0.3903, acc_train=0.8718, loss_test=0.2480, acc_test=0.9436
# poison_percent 40 round 71: loss_train=0.3951, acc_train=0.8733, loss_test=0.2502, acc_test=0.9412
# poison_percent 40 round 72: loss_train=0.4083, acc_train=0.8731, loss_test=0.2486, acc_test=0.9436
# poison_percent 40 round 73: loss_train=0.4048, acc_train=0.8746, loss_test=0.2489, acc_test=0.9436
# poison_percent 40 round 74: loss_train=0.4240, acc_train=0.8680, loss_test=0.2502, acc_test=0.9430
# poison_percent 40 round 75: loss_train=0.3850, acc_train=0.8804, loss_test=0.2520, acc_test=0.9412
# poison_percent 40 round 76: loss_train=0.4073, acc_train=0.8753, loss_test=0.2523, acc_test=0.9400
# poison_percent 40 round 77: loss_train=0.3721, acc_train=0.8870, loss_test=0.2532, acc_test=0.9369
# poison_percent 40 round 78: loss_train=0.3835, acc_train=0.8768, loss_test=0.2508, acc_test=0.9418
# poison_percent 40 round 79: loss_train=0.4064, acc_train=0.8731, loss_test=0.2458, acc_test=0.9442
# poison_percent 40 round 80: loss_train=0.4295, acc_train=0.8712, loss_test=0.2499, acc_test=0.9424
# poison_percent 40 round 81: loss_train=0.3977, acc_train=0.8706, loss_test=0.2480, acc_test=0.9418
# poison_percent 40 round 82: loss_train=0.4127, acc_train=0.8744, loss_test=0.2500, acc_test=0.9418
# poison_percent 40 round 83: loss_train=0.4045, acc_train=0.8684, loss_test=0.2517, acc_test=0.9412
# poison_percent 40 round 84: loss_train=0.4080, acc_train=0.8695, loss_test=0.2501, acc_test=0.9412
# poison_percent 40 round 85: loss_train=0.4019, acc_train=0.8708, loss_test=0.2516, acc_test=0.9412
# poison_percent 40 round 86: loss_train=0.4136, acc_train=0.8742, loss_test=0.2538, acc_test=0.9393
# poison_percent 40 round 87: loss_train=0.3791, acc_train=0.8770, loss_test=0.2517, acc_test=0.9406
# poison_percent 40 round 88: loss_train=0.4121, acc_train=0.8770, loss_test=0.2551, acc_test=0.9387
# poison_percent 40 round 89: loss_train=0.3781, acc_train=0.8776, loss_test=0.2532, acc_test=0.9381
# poison_percent 40 round 90: loss_train=0.3986, acc_train=0.8787, loss_test=0.2515, acc_test=0.9393
# poison_percent 40 round 91: loss_train=0.4169, acc_train=0.8678, loss_test=0.2500, acc_test=0.9400
# poison_percent 40 round 92: loss_train=0.3920, acc_train=0.8727, loss_test=0.2504, acc_test=0.9393
# poison_percent 40 round 93: loss_train=0.3931, acc_train=0.8810, loss_test=0.2539, acc_test=0.9400
# poison_percent 40 round 94: loss_train=0.4221, acc_train=0.8716, loss_test=0.2519, acc_test=0.9406
# poison_percent 40 round 95: loss_train=0.3878, acc_train=0.8765, loss_test=0.2551, acc_test=0.9387
# poison_percent 40 round 96: loss_train=0.3813, acc_train=0.8785, loss_test=0.2545, acc_test=0.9387
# poison_percent 40 round 97: loss_train=0.3935, acc_train=0.8765, loss_test=0.2524, acc_test=0.9400
# poison_percent 40 round 98: loss_train=0.4173, acc_train=0.8757, loss_test=0.2535, acc_test=0.9387
# poison_percent 40 round 99: loss_train=0.3834, acc_train=0.8787, loss_test=0.2560, acc_test=0.9381
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\FL_ModelN32L2_Batchsize32_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 round 0: loss_train=0.4066, acc_train=0.8735, loss_test=0.3058, acc_test=0.9087
# poison_percent 50 round 1: loss_train=0.3422, acc_train=0.8892, loss_test=0.4312, acc_test=0.8376
# poison_percent 50 round 2: loss_train=0.3321, acc_train=0.8984, loss_test=0.5427, acc_test=0.7800
# poison_percent 50 round 3: loss_train=0.3313, acc_train=0.9085, loss_test=0.6323, acc_test=0.7328
# poison_percent 50 round 4: loss_train=0.3263, acc_train=0.9013, loss_test=0.7144, acc_test=0.6942
# poison_percent 50 round 5: loss_train=0.2974, acc_train=0.9100, loss_test=0.7751, acc_test=0.6642
# poison_percent 50 round 6: loss_train=0.3240, acc_train=0.9087, loss_test=0.8150, acc_test=0.6458
# poison_percent 50 round 7: loss_train=0.3236, acc_train=0.9064, loss_test=0.8584, acc_test=0.6256
# poison_percent 50 round 8: loss_train=0.3033, acc_train=0.9112, loss_test=0.8721, acc_test=0.6121
# poison_percent 50 round 9: loss_train=0.3179, acc_train=0.9022, loss_test=0.9055, acc_test=0.5944
# poison_percent 50 round 10: loss_train=0.3165, acc_train=0.9071, loss_test=0.9299, acc_test=0.5790
# poison_percent 50 round 11: loss_train=0.3308, acc_train=0.9046, loss_test=0.9309, acc_test=0.5772
# poison_percent 50 round 12: loss_train=0.3021, acc_train=0.9134, loss_test=0.9562, acc_test=0.5643
# poison_percent 50 round 13: loss_train=0.2989, acc_train=0.9114, loss_test=0.9598, acc_test=0.5643
# poison_percent 50 round 14: loss_train=0.3130, acc_train=0.9078, loss_test=0.9649, acc_test=0.5643
# poison_percent 50 round 15: loss_train=0.3018, acc_train=0.9078, loss_test=0.9788, acc_test=0.5558
# poison_percent 50 round 16: loss_train=0.3007, acc_train=0.9078, loss_test=0.9742, acc_test=0.5588
# poison_percent 50 round 17: loss_train=0.3077, acc_train=0.9080, loss_test=0.9821, acc_test=0.5521
# poison_percent 50 round 18: loss_train=0.3153, acc_train=0.9094, loss_test=0.9759, acc_test=0.5533
# poison_percent 50 round 19: loss_train=0.2968, acc_train=0.9131, loss_test=0.9948, acc_test=0.5453
# poison_percent 50 round 20: loss_train=0.3008, acc_train=0.9132, loss_test=0.9796, acc_test=0.5509
# poison_percent 50 round 21: loss_train=0.2777, acc_train=0.9107, loss_test=1.0025, acc_test=0.5374
# poison_percent 50 round 22: loss_train=0.2996, acc_train=0.9100, loss_test=0.9901, acc_test=0.5429
# poison_percent 50 round 23: loss_train=0.2934, acc_train=0.9159, loss_test=0.9968, acc_test=0.5374
# poison_percent 50 round 24: loss_train=0.3184, acc_train=0.9082, loss_test=1.0063, acc_test=0.5331
# poison_percent 50 round 25: loss_train=0.2869, acc_train=0.9165, loss_test=1.0071, acc_test=0.5331
# poison_percent 50 round 26: loss_train=0.3082, acc_train=0.9103, loss_test=1.0058, acc_test=0.5300
# poison_percent 50 round 27: loss_train=0.2954, acc_train=0.9145, loss_test=1.0079, acc_test=0.5288
# poison_percent 50 round 28: loss_train=0.2939, acc_train=0.9156, loss_test=1.0272, acc_test=0.5202
# poison_percent 50 round 29: loss_train=0.2981, acc_train=0.9167, loss_test=1.0195, acc_test=0.5202
# poison_percent 50 round 30: loss_train=0.3122, acc_train=0.9102, loss_test=1.0176, acc_test=0.5214
# poison_percent 50 round 31: loss_train=0.2939, acc_train=0.9127, loss_test=1.0322, acc_test=0.5147
# poison_percent 50 round 32: loss_train=0.3056, acc_train=0.9120, loss_test=1.0274, acc_test=0.5159
# poison_percent 50 round 33: loss_train=0.2954, acc_train=0.9138, loss_test=1.0261, acc_test=0.5172
# poison_percent 50 round 34: loss_train=0.2852, acc_train=0.9140, loss_test=1.0253, acc_test=0.5141
# poison_percent 50 round 35: loss_train=0.3196, acc_train=0.9121, loss_test=1.0355, acc_test=0.5110
# poison_percent 50 round 36: loss_train=0.3096, acc_train=0.9074, loss_test=1.0486, acc_test=0.5018
# poison_percent 50 round 37: loss_train=0.2986, acc_train=0.9152, loss_test=1.0370, acc_test=0.5061
# poison_percent 50 round 38: loss_train=0.2811, acc_train=0.9170, loss_test=1.0527, acc_test=0.4994
# poison_percent 50 round 39: loss_train=0.2932, acc_train=0.9132, loss_test=1.0453, acc_test=0.5006
# poison_percent 50 round 40: loss_train=0.2860, acc_train=0.9158, loss_test=1.0554, acc_test=0.4969
# poison_percent 50 round 41: loss_train=0.2894, acc_train=0.9174, loss_test=1.0542, acc_test=0.4951
# poison_percent 50 round 42: loss_train=0.3131, acc_train=0.9055, loss_test=1.0599, acc_test=0.4933
# poison_percent 50 round 43: loss_train=0.2956, acc_train=0.9136, loss_test=1.0557, acc_test=0.4933
# poison_percent 50 round 44: loss_train=0.3177, acc_train=0.9107, loss_test=1.0511, acc_test=0.4939
# poison_percent 50 round 45: loss_train=0.2983, acc_train=0.9170, loss_test=1.0544, acc_test=0.4914
# poison_percent 50 round 46: loss_train=0.2653, acc_train=0.9273, loss_test=1.0418, acc_test=0.4963
# poison_percent 50 round 47: loss_train=0.2768, acc_train=0.9161, loss_test=1.0456, acc_test=0.4951
# poison_percent 50 round 48: loss_train=0.2726, acc_train=0.9161, loss_test=1.0420, acc_test=0.4957
# poison_percent 50 round 49: loss_train=0.2914, acc_train=0.9121, loss_test=1.0485, acc_test=0.4926
# poison_percent 50 round 50: loss_train=0.2786, acc_train=0.9199, loss_test=1.0448, acc_test=0.4945
# poison_percent 50 round 51: loss_train=0.2556, acc_train=0.9241, loss_test=1.0566, acc_test=0.4939
# poison_percent 50 round 52: loss_train=0.2974, acc_train=0.9121, loss_test=1.0354, acc_test=0.4963
# poison_percent 50 round 53: loss_train=0.2819, acc_train=0.9158, loss_test=1.0560, acc_test=0.4914
# poison_percent 50 round 54: loss_train=0.2752, acc_train=0.9179, loss_test=1.0479, acc_test=0.4902
# poison_percent 50 round 55: loss_train=0.2681, acc_train=0.9212, loss_test=1.0571, acc_test=0.4853
# poison_percent 50 round 56: loss_train=0.2889, acc_train=0.9181, loss_test=1.0580, acc_test=0.4816
# poison_percent 50 round 57: loss_train=0.2809, acc_train=0.9190, loss_test=1.0761, acc_test=0.4786
# poison_percent 50 round 58: loss_train=0.3006, acc_train=0.9103, loss_test=1.0630, acc_test=0.4816
# poison_percent 50 round 59: loss_train=0.2784, acc_train=0.9136, loss_test=1.0809, acc_test=0.4761
# poison_percent 50 round 60: loss_train=0.2766, acc_train=0.9185, loss_test=1.0694, acc_test=0.4761
# poison_percent 50 round 61: loss_train=0.3040, acc_train=0.9132, loss_test=1.0805, acc_test=0.4730
# poison_percent 50 round 62: loss_train=0.2838, acc_train=0.9178, loss_test=1.0877, acc_test=0.4718
# poison_percent 50 round 63: loss_train=0.2942, acc_train=0.9147, loss_test=1.0774, acc_test=0.4724
# poison_percent 50 round 64: loss_train=0.2891, acc_train=0.9129, loss_test=1.0754, acc_test=0.4749
# poison_percent 50 round 65: loss_train=0.2862, acc_train=0.9163, loss_test=1.0704, acc_test=0.4724
# poison_percent 50 round 66: loss_train=0.2815, acc_train=0.9203, loss_test=1.0689, acc_test=0.4737
# poison_percent 50 round 67: loss_train=0.2787, acc_train=0.9187, loss_test=1.0788, acc_test=0.4724
# poison_percent 50 round 68: loss_train=0.2940, acc_train=0.9158, loss_test=1.0772, acc_test=0.4730
# poison_percent 50 round 69: loss_train=0.2722, acc_train=0.9196, loss_test=1.0796, acc_test=0.4706
# poison_percent 50 round 70: loss_train=0.2805, acc_train=0.9116, loss_test=1.0780, acc_test=0.4737
# poison_percent 50 round 71: loss_train=0.3002, acc_train=0.9158, loss_test=1.0778, acc_test=0.4700
# poison_percent 50 round 72: loss_train=0.2829, acc_train=0.9179, loss_test=1.0787, acc_test=0.4706
# poison_percent 50 round 73: loss_train=0.2884, acc_train=0.9147, loss_test=1.0692, acc_test=0.4718
# poison_percent 50 round 74: loss_train=0.2809, acc_train=0.9199, loss_test=1.0687, acc_test=0.4743
# poison_percent 50 round 75: loss_train=0.2589, acc_train=0.9241, loss_test=1.0793, acc_test=0.4706
# poison_percent 50 round 76: loss_train=0.2651, acc_train=0.9187, loss_test=1.0723, acc_test=0.4724
# poison_percent 50 round 77: loss_train=0.2801, acc_train=0.9156, loss_test=1.0711, acc_test=0.4737
# poison_percent 50 round 78: loss_train=0.2802, acc_train=0.9156, loss_test=1.0752, acc_test=0.4718
# poison_percent 50 round 79: loss_train=0.2778, acc_train=0.9187, loss_test=1.0684, acc_test=0.4743
# poison_percent 50 round 80: loss_train=0.2940, acc_train=0.9114, loss_test=1.0858, acc_test=0.4651
# poison_percent 50 round 81: loss_train=0.2878, acc_train=0.9158, loss_test=1.0805, acc_test=0.4694
# poison_percent 50 round 82: loss_train=0.2781, acc_train=0.9178, loss_test=1.0863, acc_test=0.4675
# poison_percent 50 round 83: loss_train=0.2693, acc_train=0.9112, loss_test=1.0885, acc_test=0.4663
# poison_percent 50 round 84: loss_train=0.2893, acc_train=0.9107, loss_test=1.0890, acc_test=0.4645
# poison_percent 50 round 85: loss_train=0.2868, acc_train=0.9192, loss_test=1.0758, acc_test=0.4681
# poison_percent 50 round 86: loss_train=0.2660, acc_train=0.9174, loss_test=1.0846, acc_test=0.4657
# poison_percent 50 round 87: loss_train=0.2748, acc_train=0.9225, loss_test=1.0777, acc_test=0.4694
# poison_percent 50 round 88: loss_train=0.2867, acc_train=0.9143, loss_test=1.0653, acc_test=0.4730
# poison_percent 50 round 89: loss_train=0.2752, acc_train=0.9214, loss_test=1.0823, acc_test=0.4675
# poison_percent 50 round 90: loss_train=0.2630, acc_train=0.9261, loss_test=1.0765, acc_test=0.4712
# poison_percent 50 round 91: loss_train=0.2568, acc_train=0.9221, loss_test=1.0940, acc_test=0.4608
# poison_percent 50 round 92: loss_train=0.2629, acc_train=0.9176, loss_test=1.0859, acc_test=0.4657
# poison_percent 50 round 93: loss_train=0.2652, acc_train=0.9201, loss_test=1.0969, acc_test=0.4614
# poison_percent 50 round 94: loss_train=0.2641, acc_train=0.9246, loss_test=1.0891, acc_test=0.4638
# poison_percent 50 round 95: loss_train=0.2714, acc_train=0.9176, loss_test=1.0992, acc_test=0.4589
# poison_percent 50 round 96: loss_train=0.2764, acc_train=0.9181, loss_test=1.0982, acc_test=0.4577
# poison_percent 50 round 97: loss_train=0.2641, acc_train=0.9237, loss_test=1.1037, acc_test=0.4559
# poison_percent 50 round 98: loss_train=0.2702, acc_train=0.9199, loss_test=1.0852, acc_test=0.4620
# poison_percent 50 round 99: loss_train=0.2705, acc_train=0.9185, loss_test=1.0990, acc_test=0.4589
# Training log saved to d:\github\poisoning_attack_analysis\Experiment009 lr bs32 10c\results\FL_ModelN32L2_Batchsize32_rev2\poisoned_50percent\poisoned_50percent.csv
