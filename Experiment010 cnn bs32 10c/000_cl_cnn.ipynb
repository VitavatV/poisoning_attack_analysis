# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.conv1 = nn.Conv2d(1, 1, kernel_size=3, padding=1) # 28x28
#         self.pool = nn.MaxPool2d(2, 2) # 14x14
#         self.fc1 = nn.Linear(1 * 14 * 14, 1)
#         self.relu = nn.ReLU()
        
#     def forward(self, x):
#         x = x.view(-1, 1, 28, 28)
#         x = self.pool(self.relu(self.conv1(x)))
#         x = x.view(x.size(0), -1)
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

    
# save state_dict + metadata (safe, portable)
def save_model(model, img_size, n_classes, learning_rate, experiment_bs, file_path):

    state = {
        "model_state_dict": model.state_dict(),                     # CPU/GPU tensors okay
        "arch": "MNISTNet",
        "img_size": img_size,
        "num_classes": n_classes,
        "training_args": {"lr": learning_rate, "batch_size": experiment_bs}
    }
    # ensure weights are on CPU to avoid GPU-only pickle issues
    state["model_state_dict"] = {k: v.cpu() for k, v in state["model_state_dict"].items()}
    torch.save(state, file_path)
    
def load_model(file_path, device):

    checkpoint = torch.load(file_path, map_location=device)
    model = MNISTNet().to(device)              # must have MNISTNet class defined/importable
    model.load_state_dict(checkpoint["model_state_dict"])
    model.eval()
    return model

# %% [markdown]
# # 4.Loss

# %%
# def binary_cross_entropy(pred, target):
#     eps = 1e-7
#     pred = torch.clamp(pred, eps, 1 - eps)
#     return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

def multiclass_cross_entropy(logits, target, from_probs=False, eps=1e-7):
    """
    Cross-entropy loss for multiclass (e.g., 10 classes).
    - logits: Tensor shape (N, C) containing raw scores (preferred) or probabilities if from_probs=True
    - target: Tensor shape (N,) or (N,1) containing class indices (0..C-1)
    """
    if logits.dim() == 1:
        logits = logits.unsqueeze(0)
    target = target.squeeze()
    if target.dtype != torch.long:
        target = target.long()
    if from_probs:
        probs = torch.clamp(logits, eps, 1.0 - eps)
        log_probs = torch.log(probs)
        return -log_probs[torch.arange(target.size(0)), target].mean()
    return nn.functional.cross_entropy(logits, target)

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 32
N_CLASSES = 10

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_multiple_poison/train"
TEST_PATH = "../data/mnist_multiple_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
# For 10-class classification
class MNISTNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 1, kernel_size=3, padding=1) # 28x28
        self.pool = nn.MaxPool2d(2, 2) # 14x14
        self.fc1 = nn.Linear(1 * 14 * 14, N_CLASSES)
        self.relu = nn.ReLU()
    def forward(self, x):
        x = x.view(-1, 1, 28, 28)
        x = self.pool(self.relu(self.conv1(x)))
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        return x
    
BATCH_SIZE_list = [BATCH_SIZE]
# temp_bs = BATCH_SIZE
# while temp_bs >= 1:
#     BATCH_SIZE_list.append(temp_bs)
#     temp_bs = temp_bs // 2

for rev in range(3):

    model = MNISTNet().to(device)
    for experiment_bs in BATCH_SIZE_list:

        name_save_path = f"CL_ModelN1L1_Batchsize{experiment_bs}_rev{rev}"
        
        for i_poisoned in poison_n_list:
            percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

            # create directory
            NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
            save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
            # Remove existing directory if it exists
            if os.path.exists(save_path):
                shutil.rmtree(save_path)
            if not os.path.exists(save_path):
                os.makedirs(save_path)
            save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
            os.makedirs(save_all_path, exist_ok=True)
            
            # Load data
            X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                    poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                    select='Honest+Poisoned')
            X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
            # print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
            # print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

            if X_test.shape[0] == 0:
                raise ValueError("No valid test images found in the test directory!")

            X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
            y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
            X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
            y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

            # torch.save(model, os.path.join(save_path,'model_init.pt'))
            save_path_name = os.path.join(save_path,'model_init.pt')
            save_model(model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)
            
            optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

            records = []

            # Training loop
            for epoch in range(EPOCHS):

                # Train
                model.train()
                
                #randomize the training data
                perm = torch.randperm(X_train_tensor.size(0))
                X_train_tensor = X_train_tensor[perm]
                y_train_tensor = y_train_tensor[perm]

                for start in range(0, X_train_tensor.size(0), experiment_bs):
                    end = start + experiment_bs
                    xb = X_train_tensor[start:end]
                    yb = y_train_tensor[start:end]
                    outputs = model(xb)
                    # preds = (outputs >= 0.5).float()
                    preds = torch.argmax(outputs, dim=1, keepdim=True)
                    acc_train = (preds == yb).float().mean().item()
                    loss_train = multiclass_cross_entropy(outputs, yb)
                    optimizer.zero_grad()
                    loss_train.backward()
                    optimizer.step()

                # Evaluate
                model.eval()
                with torch.no_grad():
                    outputs = model(X_test_tensor)
                    # preds = (outputs >= 0.5).float()
                    preds = torch.argmax(outputs, dim=1, keepdim=True)
                    loss_test = multiclass_cross_entropy(outputs, y_test_tensor)
                    acc_test = (preds == y_test_tensor).float().mean().item()
                records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                                'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                'loss_test': loss_test.item(), 'acc_test': acc_test})
                report_txt = f"poison_percent {percent_poisoned} "
                report_txt += f"epoch {epoch}: "
                report_txt += f"loss_train={loss_train.item():.4f}, "
                report_txt += f"acc_train={acc_train:.4f}, "
                report_txt += f"loss_test={loss_test.item():.4f}, "
                report_txt += f"acc_test={acc_test:.4f}"
                print(report_txt)

            # torch.save(model, os.path.join(save_path,'model_last.pt'))
            save_path_name = os.path.join(save_path,'model_last.pt')
            save_model(model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)

            # Save training log
            df = pd.DataFrame(records)
            save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
            df.to_csv(save_name_path, index=False)
            print(f"Training log saved to {save_name_path}")

            # Plot loss and accuracy
            plt.figure(figsize=(10,4))

            plt.subplot(1,2,1)
            plt.plot(df['epoch'], df['loss_test'], marker='o')
            plt.title('Test Loss')
            plt.ylabel('Loss')
            plt.xlabel('Epoch')
            plt.grid(True)
            plt.ylim(0, 1.1)
            # plt.legend()

            plt.subplot(1,2,2)
            plt.plot(df['epoch'], df['acc_test'], marker='o')
            plt.title('Test Accuracy')
            plt.ylabel('Accuracy')
            plt.xlabel('Epoch')
            plt.grid(True)
            plt.ylim(0, 1.1)
            # plt.legend()

            plt.tight_layout()
            save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
            plt.savefig(save_name_path)

            save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
            plt.savefig(save_name_path)
            plt.close()
# Out:
# poison_percent 0 epoch 0: loss_train=0.3384, acc_train=0.8947, loss_test=0.1142, acc_test=0.9749
# poison_percent 0 epoch 1: loss_train=0.4359, acc_train=0.8421, loss_test=0.1029, acc_test=0.9792
# poison_percent 0 epoch 2: loss_train=0.1096, acc_train=0.9474, loss_test=0.1011, acc_test=0.9828
# poison_percent 0 epoch 3: loss_train=0.1912, acc_train=0.8947, loss_test=0.0857, acc_test=0.9841
# poison_percent 0 epoch 4: loss_train=0.2711, acc_train=0.9474, loss_test=0.0976, acc_test=0.9828
# poison_percent 0 epoch 5: loss_train=0.1181, acc_train=1.0000, loss_test=0.1121, acc_test=0.9804
# poison_percent 0 epoch 6: loss_train=0.3593, acc_train=0.9474, loss_test=0.1127, acc_test=0.9786
# poison_percent 0 epoch 7: loss_train=0.2365, acc_train=0.8947, loss_test=0.1099, acc_test=0.9828
# poison_percent 0 epoch 8: loss_train=0.5682, acc_train=0.8421, loss_test=0.1020, acc_test=0.9779
# poison_percent 0 epoch 9: loss_train=0.5585, acc_train=0.8947, loss_test=0.1365, acc_test=0.9700
# poison_percent 0 epoch 10: loss_train=0.7085, acc_train=0.7895, loss_test=0.1198, acc_test=0.9724
# poison_percent 0 epoch 11: loss_train=0.3571, acc_train=0.9474, loss_test=0.1202, acc_test=0.9767
# poison_percent 0 epoch 12: loss_train=0.3587, acc_train=0.8947, loss_test=0.1433, acc_test=0.9645
# poison_percent 0 epoch 13: loss_train=0.1733, acc_train=1.0000, loss_test=0.1165, acc_test=0.9773
# poison_percent 0 epoch 14: loss_train=0.7403, acc_train=0.8421, loss_test=0.1117, acc_test=0.9749
# poison_percent 0 epoch 15: loss_train=0.1092, acc_train=1.0000, loss_test=0.1078, acc_test=0.9761
# poison_percent 0 epoch 16: loss_train=0.1040, acc_train=1.0000, loss_test=0.0892, acc_test=0.9828
# poison_percent 0 epoch 17: loss_train=0.7473, acc_train=0.8421, loss_test=0.1385, acc_test=0.9632
# poison_percent 0 epoch 18: loss_train=0.0836, acc_train=1.0000, loss_test=0.0962, acc_test=0.9816
# poison_percent 0 epoch 19: loss_train=0.4389, acc_train=0.8947, loss_test=0.0955, acc_test=0.9792
# poison_percent 0 epoch 20: loss_train=0.1331, acc_train=0.9474, loss_test=0.0972, acc_test=0.9792
# poison_percent 0 epoch 21: loss_train=0.1519, acc_train=0.9474, loss_test=0.0870, acc_test=0.9816
# poison_percent 0 epoch 22: loss_train=0.5978, acc_train=0.7895, loss_test=0.0983, acc_test=0.9798
# poison_percent 0 epoch 23: loss_train=0.3025, acc_train=0.8947, loss_test=0.0878, acc_test=0.9859
# poison_percent 0 epoch 24: loss_train=1.1934, acc_train=0.7368, loss_test=0.1014, acc_test=0.9779
# poison_percent 0 epoch 25: loss_train=0.4273, acc_train=0.8947, loss_test=0.1160, acc_test=0.9712
# poison_percent 0 epoch 26: loss_train=0.2302, acc_train=0.8947, loss_test=0.1232, acc_test=0.9706
# poison_percent 0 epoch 27: loss_train=0.0832, acc_train=1.0000, loss_test=0.1142, acc_test=0.9761
# poison_percent 0 epoch 28: loss_train=0.2152, acc_train=0.8947, loss_test=0.0938, acc_test=0.9841
# poison_percent 0 epoch 29: loss_train=0.4539, acc_train=0.7895, loss_test=0.0909, acc_test=0.9822
# poison_percent 0 epoch 30: loss_train=0.0375, acc_train=1.0000, loss_test=0.0995, acc_test=0.9804
# poison_percent 0 epoch 31: loss_train=0.1165, acc_train=1.0000, loss_test=0.0929, acc_test=0.9804
# poison_percent 0 epoch 32: loss_train=0.0529, acc_train=1.0000, loss_test=0.0962, acc_test=0.9792
# poison_percent 0 epoch 33: loss_train=0.1933, acc_train=0.9474, loss_test=0.1206, acc_test=0.9730
# poison_percent 0 epoch 34: loss_train=0.3065, acc_train=0.9474, loss_test=0.1186, acc_test=0.9706
# poison_percent 0 epoch 35: loss_train=0.3851, acc_train=0.8947, loss_test=0.1004, acc_test=0.9792
# poison_percent 0 epoch 36: loss_train=0.1046, acc_train=0.9474, loss_test=0.1037, acc_test=0.9792
# poison_percent 0 epoch 37: loss_train=0.1926, acc_train=0.9474, loss_test=0.1168, acc_test=0.9718
# poison_percent 0 epoch 38: loss_train=0.1704, acc_train=0.8947, loss_test=0.0912, acc_test=0.9798
# poison_percent 0 epoch 39: loss_train=0.4950, acc_train=0.8947, loss_test=0.1245, acc_test=0.9688
# poison_percent 0 epoch 40: loss_train=0.1966, acc_train=0.9474, loss_test=0.0996, acc_test=0.9822
# poison_percent 0 epoch 41: loss_train=0.3082, acc_train=0.8947, loss_test=0.1128, acc_test=0.9749
# poison_percent 0 epoch 42: loss_train=0.1544, acc_train=0.9474, loss_test=0.1096, acc_test=0.9786
# poison_percent 0 epoch 43: loss_train=0.4875, acc_train=0.8421, loss_test=0.1054, acc_test=0.9779
# poison_percent 0 epoch 44: loss_train=0.0256, acc_train=1.0000, loss_test=0.0951, acc_test=0.9816
# poison_percent 0 epoch 45: loss_train=0.2658, acc_train=0.8947, loss_test=0.0963, acc_test=0.9810
# poison_percent 0 epoch 46: loss_train=0.4795, acc_train=0.8947, loss_test=0.1027, acc_test=0.9761
# poison_percent 0 epoch 47: loss_train=0.1337, acc_train=0.9474, loss_test=0.0836, acc_test=0.9853
# poison_percent 0 epoch 48: loss_train=0.0559, acc_train=1.0000, loss_test=0.0904, acc_test=0.9835
# poison_percent 0 epoch 49: loss_train=0.4348, acc_train=0.8947, loss_test=0.1066, acc_test=0.9755
# poison_percent 0 epoch 50: loss_train=0.0543, acc_train=1.0000, loss_test=0.0900, acc_test=0.9822
# poison_percent 0 epoch 51: loss_train=0.1984, acc_train=0.9474, loss_test=0.1091, acc_test=0.9743
# poison_percent 0 epoch 52: loss_train=0.1028, acc_train=1.0000, loss_test=0.1158, acc_test=0.9749
# poison_percent 0 epoch 53: loss_train=0.2305, acc_train=0.9474, loss_test=0.1184, acc_test=0.9700
# poison_percent 0 epoch 54: loss_train=0.4326, acc_train=0.8421, loss_test=0.1042, acc_test=0.9767
# poison_percent 0 epoch 55: loss_train=0.3047, acc_train=0.8947, loss_test=0.1020, acc_test=0.9798
# poison_percent 0 epoch 56: loss_train=0.2948, acc_train=0.8421, loss_test=0.1268, acc_test=0.9694
# poison_percent 0 epoch 57: loss_train=0.3524, acc_train=0.8421, loss_test=0.1060, acc_test=0.9761
# poison_percent 0 epoch 58: loss_train=0.1225, acc_train=1.0000, loss_test=0.1186, acc_test=0.9743
# poison_percent 0 epoch 59: loss_train=0.8444, acc_train=0.8947, loss_test=0.1076, acc_test=0.9779
# poison_percent 0 epoch 60: loss_train=0.1157, acc_train=0.9474, loss_test=0.1092, acc_test=0.9786
# poison_percent 0 epoch 61: loss_train=0.1266, acc_train=0.9474, loss_test=0.1128, acc_test=0.9724
# poison_percent 0 epoch 62: loss_train=0.3135, acc_train=0.9474, loss_test=0.1136, acc_test=0.9737
# poison_percent 0 epoch 63: loss_train=0.3821, acc_train=0.8947, loss_test=0.1172, acc_test=0.9737
# poison_percent 0 epoch 64: loss_train=0.1579, acc_train=0.9474, loss_test=0.1023, acc_test=0.9773
# poison_percent 0 epoch 65: loss_train=0.2239, acc_train=0.8421, loss_test=0.1036, acc_test=0.9767
# poison_percent 0 epoch 66: loss_train=0.3314, acc_train=0.8947, loss_test=0.1036, acc_test=0.9755
# poison_percent 0 epoch 67: loss_train=0.2747, acc_train=0.8947, loss_test=0.1250, acc_test=0.9700
# poison_percent 0 epoch 68: loss_train=0.0909, acc_train=0.9474, loss_test=0.1179, acc_test=0.9724
# poison_percent 0 epoch 69: loss_train=0.0903, acc_train=0.9474, loss_test=0.1071, acc_test=0.9786
# poison_percent 0 epoch 70: loss_train=0.4099, acc_train=0.7895, loss_test=0.0906, acc_test=0.9835
# poison_percent 0 epoch 71: loss_train=0.0624, acc_train=1.0000, loss_test=0.0981, acc_test=0.9798
# poison_percent 0 epoch 72: loss_train=0.2367, acc_train=0.9474, loss_test=0.1004, acc_test=0.9786
# poison_percent 0 epoch 73: loss_train=0.2327, acc_train=0.9474, loss_test=0.1054, acc_test=0.9773
# poison_percent 0 epoch 74: loss_train=0.2865, acc_train=0.8947, loss_test=0.1193, acc_test=0.9706
# poison_percent 0 epoch 75: loss_train=0.3490, acc_train=0.8421, loss_test=0.0894, acc_test=0.9822
# poison_percent 0 epoch 76: loss_train=0.0620, acc_train=1.0000, loss_test=0.1111, acc_test=0.9798
# poison_percent 0 epoch 77: loss_train=0.1369, acc_train=0.9474, loss_test=0.1099, acc_test=0.9730
# poison_percent 0 epoch 78: loss_train=0.2454, acc_train=0.9474, loss_test=0.1014, acc_test=0.9786
# poison_percent 0 epoch 79: loss_train=0.4615, acc_train=0.8947, loss_test=0.1189, acc_test=0.9718
# poison_percent 0 epoch 80: loss_train=0.0771, acc_train=1.0000, loss_test=0.1061, acc_test=0.9767
# poison_percent 0 epoch 81: loss_train=0.1329, acc_train=0.9474, loss_test=0.1067, acc_test=0.9779
# poison_percent 0 epoch 82: loss_train=0.2548, acc_train=0.8421, loss_test=0.1358, acc_test=0.9645
# poison_percent 0 epoch 83: loss_train=0.1242, acc_train=0.9474, loss_test=0.0979, acc_test=0.9798
# poison_percent 0 epoch 84: loss_train=0.0924, acc_train=1.0000, loss_test=0.1086, acc_test=0.9755
# poison_percent 0 epoch 85: loss_train=0.0920, acc_train=1.0000, loss_test=0.1256, acc_test=0.9669
# poison_percent 0 epoch 86: loss_train=0.2892, acc_train=0.9474, loss_test=0.1152, acc_test=0.9730
# poison_percent 0 epoch 87: loss_train=0.1329, acc_train=0.9474, loss_test=0.1284, acc_test=0.9681
# poison_percent 0 epoch 88: loss_train=0.2170, acc_train=0.8947, loss_test=0.1005, acc_test=0.9786
# poison_percent 0 epoch 89: loss_train=0.2036, acc_train=0.8947, loss_test=0.1259, acc_test=0.9694
# poison_percent 0 epoch 90: loss_train=0.1861, acc_train=0.9474, loss_test=0.1024, acc_test=0.9779
# poison_percent 0 epoch 91: loss_train=0.4791, acc_train=0.8947, loss_test=0.1059, acc_test=0.9779
# poison_percent 0 epoch 92: loss_train=0.0412, acc_train=1.0000, loss_test=0.1108, acc_test=0.9773
# poison_percent 0 epoch 93: loss_train=0.0562, acc_train=1.0000, loss_test=0.0887, acc_test=0.9822
# poison_percent 0 epoch 94: loss_train=0.6552, acc_train=0.8947, loss_test=0.0970, acc_test=0.9779
# poison_percent 0 epoch 95: loss_train=0.4058, acc_train=0.8947, loss_test=0.1080, acc_test=0.9779
# poison_percent 0 epoch 96: loss_train=0.6021, acc_train=0.7895, loss_test=0.1067, acc_test=0.9761
# poison_percent 0 epoch 97: loss_train=0.2940, acc_train=0.8947, loss_test=0.0969, acc_test=0.9786
# poison_percent 0 epoch 98: loss_train=0.3109, acc_train=0.9474, loss_test=0.1145, acc_test=0.9743
# poison_percent 0 epoch 99: loss_train=0.3678, acc_train=0.8421, loss_test=0.1030, acc_test=0.9786
# Training log saved to ./results\CL_ModelN1L1_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 epoch 0: loss_train=1.0427, acc_train=0.7812, loss_test=0.2743, acc_test=0.9657
# poison_percent 10 epoch 1: loss_train=0.7339, acc_train=0.8438, loss_test=0.2068, acc_test=0.9773
# poison_percent 10 epoch 2: loss_train=0.6155, acc_train=0.8750, loss_test=0.2502, acc_test=0.9632
# poison_percent 10 epoch 3: loss_train=0.7172, acc_train=0.7812, loss_test=0.2311, acc_test=0.9688
# poison_percent 10 epoch 4: loss_train=0.8895, acc_train=0.8125, loss_test=0.2602, acc_test=0.9645
# poison_percent 10 epoch 5: loss_train=0.5400, acc_train=0.8125, loss_test=0.2388, acc_test=0.9694
# poison_percent 10 epoch 6: loss_train=0.6499, acc_train=0.8125, loss_test=0.2643, acc_test=0.9657
# poison_percent 10 epoch 7: loss_train=0.7503, acc_train=0.8125, loss_test=0.2884, acc_test=0.9583
# poison_percent 10 epoch 8: loss_train=0.3620, acc_train=0.9062, loss_test=0.2565, acc_test=0.9675
# poison_percent 10 epoch 9: loss_train=0.4882, acc_train=0.8438, loss_test=0.2864, acc_test=0.9553
# poison_percent 10 epoch 10: loss_train=0.6744, acc_train=0.7500, loss_test=0.2660, acc_test=0.9657
# poison_percent 10 epoch 11: loss_train=0.4983, acc_train=0.8438, loss_test=0.2726, acc_test=0.9565
# poison_percent 10 epoch 12: loss_train=0.4077, acc_train=0.8750, loss_test=0.2464, acc_test=0.9700
# poison_percent 10 epoch 13: loss_train=0.6537, acc_train=0.8438, loss_test=0.2305, acc_test=0.9700
# poison_percent 10 epoch 14: loss_train=0.7198, acc_train=0.7812, loss_test=0.2585, acc_test=0.9712
# poison_percent 10 epoch 15: loss_train=0.6720, acc_train=0.8125, loss_test=0.2576, acc_test=0.9681
# poison_percent 10 epoch 16: loss_train=0.4964, acc_train=0.7812, loss_test=0.3176, acc_test=0.9498
# poison_percent 10 epoch 17: loss_train=0.4482, acc_train=0.9062, loss_test=0.2565, acc_test=0.9638
# poison_percent 10 epoch 18: loss_train=0.5538, acc_train=0.8438, loss_test=0.2674, acc_test=0.9651
# poison_percent 10 epoch 19: loss_train=0.4453, acc_train=0.9062, loss_test=0.2644, acc_test=0.9620
# poison_percent 10 epoch 20: loss_train=0.6948, acc_train=0.7500, loss_test=0.2850, acc_test=0.9614
# poison_percent 10 epoch 21: loss_train=0.5872, acc_train=0.8438, loss_test=0.2610, acc_test=0.9688
# poison_percent 10 epoch 22: loss_train=0.6174, acc_train=0.8438, loss_test=0.2602, acc_test=0.9626
# poison_percent 10 epoch 23: loss_train=0.2771, acc_train=1.0000, loss_test=0.2636, acc_test=0.9657
# poison_percent 10 epoch 24: loss_train=0.7342, acc_train=0.7188, loss_test=0.2397, acc_test=0.9681
# poison_percent 10 epoch 25: loss_train=0.4759, acc_train=0.8750, loss_test=0.2602, acc_test=0.9663
# poison_percent 10 epoch 26: loss_train=0.3281, acc_train=0.8750, loss_test=0.2736, acc_test=0.9583
# poison_percent 10 epoch 27: loss_train=0.4858, acc_train=0.8750, loss_test=0.2355, acc_test=0.9730
# poison_percent 10 epoch 28: loss_train=0.5388, acc_train=0.8438, loss_test=0.2384, acc_test=0.9700
# poison_percent 10 epoch 29: loss_train=0.7039, acc_train=0.7812, loss_test=0.2631, acc_test=0.9651
# poison_percent 10 epoch 30: loss_train=0.5290, acc_train=0.8438, loss_test=0.2331, acc_test=0.9681
# poison_percent 10 epoch 31: loss_train=0.7713, acc_train=0.6875, loss_test=0.2419, acc_test=0.9681
# poison_percent 10 epoch 32: loss_train=0.7254, acc_train=0.7812, loss_test=0.2561, acc_test=0.9657
# poison_percent 10 epoch 33: loss_train=0.7404, acc_train=0.8125, loss_test=0.2479, acc_test=0.9657
# poison_percent 10 epoch 34: loss_train=0.6950, acc_train=0.6562, loss_test=0.2250, acc_test=0.9743
# poison_percent 10 epoch 35: loss_train=0.5257, acc_train=0.8438, loss_test=0.2710, acc_test=0.9614
# poison_percent 10 epoch 36: loss_train=0.7485, acc_train=0.7812, loss_test=0.2850, acc_test=0.9614
# poison_percent 10 epoch 37: loss_train=0.5129, acc_train=0.8438, loss_test=0.2436, acc_test=0.9700
# poison_percent 10 epoch 38: loss_train=0.4162, acc_train=0.8750, loss_test=0.2520, acc_test=0.9669
# poison_percent 10 epoch 39: loss_train=0.5370, acc_train=0.8438, loss_test=0.2637, acc_test=0.9614
# poison_percent 10 epoch 40: loss_train=0.5189, acc_train=0.8438, loss_test=0.2380, acc_test=0.9700
# poison_percent 10 epoch 41: loss_train=0.6144, acc_train=0.8438, loss_test=0.2593, acc_test=0.9663
# poison_percent 10 epoch 42: loss_train=1.1949, acc_train=0.6250, loss_test=0.2536, acc_test=0.9638
# poison_percent 10 epoch 43: loss_train=0.3273, acc_train=0.9375, loss_test=0.2319, acc_test=0.9706
# poison_percent 10 epoch 44: loss_train=0.9865, acc_train=0.7188, loss_test=0.2591, acc_test=0.9614
# poison_percent 10 epoch 45: loss_train=0.5946, acc_train=0.7812, loss_test=0.2462, acc_test=0.9657
# poison_percent 10 epoch 46: loss_train=0.5498, acc_train=0.9062, loss_test=0.2517, acc_test=0.9681
# poison_percent 10 epoch 47: loss_train=0.7273, acc_train=0.7188, loss_test=0.2367, acc_test=0.9694
# poison_percent 10 epoch 48: loss_train=0.8890, acc_train=0.8125, loss_test=0.2608, acc_test=0.9651
# poison_percent 10 epoch 49: loss_train=0.5372, acc_train=0.8438, loss_test=0.2680, acc_test=0.9620
# poison_percent 10 epoch 50: loss_train=0.6936, acc_train=0.8438, loss_test=0.2879, acc_test=0.9583
# poison_percent 10 epoch 51: loss_train=0.7027, acc_train=0.8750, loss_test=0.2544, acc_test=0.9632
# poison_percent 10 epoch 52: loss_train=0.8185, acc_train=0.7188, loss_test=0.2237, acc_test=0.9730
# poison_percent 10 epoch 53: loss_train=0.7970, acc_train=0.6562, loss_test=0.2682, acc_test=0.9651
# poison_percent 10 epoch 54: loss_train=0.5025, acc_train=0.8750, loss_test=0.2538, acc_test=0.9669
# poison_percent 10 epoch 55: loss_train=0.8922, acc_train=0.7188, loss_test=0.2338, acc_test=0.9694
# poison_percent 10 epoch 56: loss_train=0.6969, acc_train=0.7812, loss_test=0.2558, acc_test=0.9688
# poison_percent 10 epoch 57: loss_train=0.5644, acc_train=0.8125, loss_test=0.2457, acc_test=0.9657
# poison_percent 10 epoch 58: loss_train=0.6841, acc_train=0.7812, loss_test=0.2913, acc_test=0.9620
# poison_percent 10 epoch 59: loss_train=0.6652, acc_train=0.8750, loss_test=0.2881, acc_test=0.9608
# poison_percent 10 epoch 60: loss_train=0.8184, acc_train=0.7812, loss_test=0.2698, acc_test=0.9638
# poison_percent 10 epoch 61: loss_train=0.6048, acc_train=0.8125, loss_test=0.2490, acc_test=0.9681
# poison_percent 10 epoch 62: loss_train=1.0464, acc_train=0.5938, loss_test=0.2548, acc_test=0.9651
# poison_percent 10 epoch 63: loss_train=0.6987, acc_train=0.7812, loss_test=0.2591, acc_test=0.9675
# poison_percent 10 epoch 64: loss_train=1.0029, acc_train=0.7500, loss_test=0.2533, acc_test=0.9645
# poison_percent 10 epoch 65: loss_train=0.9748, acc_train=0.6875, loss_test=0.2535, acc_test=0.9645
# poison_percent 10 epoch 66: loss_train=0.9291, acc_train=0.6562, loss_test=0.2444, acc_test=0.9718
# poison_percent 10 epoch 67: loss_train=0.7751, acc_train=0.8125, loss_test=0.2538, acc_test=0.9669
# poison_percent 10 epoch 68: loss_train=0.7044, acc_train=0.7500, loss_test=0.2548, acc_test=0.9688
# poison_percent 10 epoch 69: loss_train=0.8378, acc_train=0.6562, loss_test=0.2565, acc_test=0.9681
# poison_percent 10 epoch 70: loss_train=0.8900, acc_train=0.7500, loss_test=0.2574, acc_test=0.9669
# poison_percent 10 epoch 71: loss_train=0.4699, acc_train=0.8438, loss_test=0.2723, acc_test=0.9608
# poison_percent 10 epoch 72: loss_train=0.6331, acc_train=0.7812, loss_test=0.2601, acc_test=0.9657
# poison_percent 10 epoch 73: loss_train=0.4543, acc_train=0.8438, loss_test=0.2527, acc_test=0.9675
# poison_percent 10 epoch 74: loss_train=0.5496, acc_train=0.8438, loss_test=0.2398, acc_test=0.9700
# poison_percent 10 epoch 75: loss_train=0.6684, acc_train=0.7812, loss_test=0.2580, acc_test=0.9669
# poison_percent 10 epoch 76: loss_train=0.6728, acc_train=0.8125, loss_test=0.2482, acc_test=0.9675
# poison_percent 10 epoch 77: loss_train=1.1218, acc_train=0.6875, loss_test=0.2600, acc_test=0.9638
# poison_percent 10 epoch 78: loss_train=0.4606, acc_train=0.8438, loss_test=0.2228, acc_test=0.9755
# poison_percent 10 epoch 79: loss_train=0.4342, acc_train=0.9062, loss_test=0.2789, acc_test=0.9608
# poison_percent 10 epoch 80: loss_train=0.5945, acc_train=0.7812, loss_test=0.2217, acc_test=0.9737
# poison_percent 10 epoch 81: loss_train=0.5330, acc_train=0.7812, loss_test=0.2708, acc_test=0.9657
# poison_percent 10 epoch 82: loss_train=0.7162, acc_train=0.8438, loss_test=0.2391, acc_test=0.9694
# poison_percent 10 epoch 83: loss_train=0.5846, acc_train=0.7500, loss_test=0.2367, acc_test=0.9706
# poison_percent 10 epoch 84: loss_train=0.8108, acc_train=0.7812, loss_test=0.2363, acc_test=0.9694
# poison_percent 10 epoch 85: loss_train=0.6870, acc_train=0.8438, loss_test=0.2757, acc_test=0.9620
# poison_percent 10 epoch 86: loss_train=0.5404, acc_train=0.8438, loss_test=0.2590, acc_test=0.9645
# poison_percent 10 epoch 87: loss_train=0.6615, acc_train=0.7812, loss_test=0.2675, acc_test=0.9645
# poison_percent 10 epoch 88: loss_train=0.6205, acc_train=0.8438, loss_test=0.2445, acc_test=0.9700
# poison_percent 10 epoch 89: loss_train=0.6273, acc_train=0.8125, loss_test=0.2022, acc_test=0.9755
# poison_percent 10 epoch 90: loss_train=1.1415, acc_train=0.6250, loss_test=0.2409, acc_test=0.9694
# poison_percent 10 epoch 91: loss_train=0.4655, acc_train=0.8125, loss_test=0.2863, acc_test=0.9608
# poison_percent 10 epoch 92: loss_train=0.5647, acc_train=0.8438, loss_test=0.2596, acc_test=0.9688
# poison_percent 10 epoch 93: loss_train=0.8928, acc_train=0.7188, loss_test=0.2296, acc_test=0.9730
# poison_percent 10 epoch 94: loss_train=0.5470, acc_train=0.7812, loss_test=0.2205, acc_test=0.9767
# poison_percent 10 epoch 95: loss_train=0.7428, acc_train=0.7500, loss_test=0.2370, acc_test=0.9694
# poison_percent 10 epoch 96: loss_train=0.6993, acc_train=0.8125, loss_test=0.2511, acc_test=0.9651
# poison_percent 10 epoch 97: loss_train=0.8024, acc_train=0.7188, loss_test=0.2203, acc_test=0.9724
# poison_percent 10 epoch 98: loss_train=0.9025, acc_train=0.7500, loss_test=0.2307, acc_test=0.9712
# poison_percent 10 epoch 99: loss_train=0.7337, acc_train=0.6875, loss_test=0.2290, acc_test=0.9669
# Training log saved to ./results\CL_ModelN1L1_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 epoch 0: loss_train=0.6853, acc_train=0.7097, loss_test=0.3497, acc_test=0.9669
# poison_percent 20 epoch 1: loss_train=1.0289, acc_train=0.6774, loss_test=0.3514, acc_test=0.9608
# poison_percent 20 epoch 2: loss_train=0.6698, acc_train=0.7742, loss_test=0.3388, acc_test=0.9638
# poison_percent 20 epoch 3: loss_train=0.9092, acc_train=0.6774, loss_test=0.3641, acc_test=0.9589
# poison_percent 20 epoch 4: loss_train=0.5640, acc_train=0.8065, loss_test=0.3655, acc_test=0.9528
# poison_percent 20 epoch 5: loss_train=1.0377, acc_train=0.6774, loss_test=0.3542, acc_test=0.9565
# poison_percent 20 epoch 6: loss_train=0.7161, acc_train=0.7742, loss_test=0.3715, acc_test=0.9614
# poison_percent 20 epoch 7: loss_train=0.6629, acc_train=0.7419, loss_test=0.3393, acc_test=0.9632
# poison_percent 20 epoch 8: loss_train=0.8604, acc_train=0.6452, loss_test=0.3861, acc_test=0.9479
# poison_percent 20 epoch 9: loss_train=0.9487, acc_train=0.6452, loss_test=0.3533, acc_test=0.9596
# poison_percent 20 epoch 10: loss_train=0.6582, acc_train=0.8065, loss_test=0.3798, acc_test=0.9577
# poison_percent 20 epoch 11: loss_train=0.7075, acc_train=0.7419, loss_test=0.3479, acc_test=0.9614
# poison_percent 20 epoch 12: loss_train=0.7675, acc_train=0.7097, loss_test=0.3394, acc_test=0.9645
# poison_percent 20 epoch 13: loss_train=0.7041, acc_train=0.7097, loss_test=0.3523, acc_test=0.9571
# poison_percent 20 epoch 14: loss_train=1.0569, acc_train=0.6129, loss_test=0.3993, acc_test=0.9522
# poison_percent 20 epoch 15: loss_train=0.8616, acc_train=0.6774, loss_test=0.3629, acc_test=0.9577
# poison_percent 20 epoch 16: loss_train=0.7120, acc_train=0.7097, loss_test=0.3854, acc_test=0.9583
# poison_percent 20 epoch 17: loss_train=0.6938, acc_train=0.8065, loss_test=0.3850, acc_test=0.9504
# poison_percent 20 epoch 18: loss_train=0.8511, acc_train=0.6129, loss_test=0.3652, acc_test=0.9583
# poison_percent 20 epoch 19: loss_train=0.8895, acc_train=0.6774, loss_test=0.3222, acc_test=0.9675
# poison_percent 20 epoch 20: loss_train=0.6890, acc_train=0.7419, loss_test=0.3528, acc_test=0.9638
# poison_percent 20 epoch 21: loss_train=0.8938, acc_train=0.6452, loss_test=0.3364, acc_test=0.9645
# poison_percent 20 epoch 22: loss_train=0.9382, acc_train=0.6452, loss_test=0.3727, acc_test=0.9516
# poison_percent 20 epoch 23: loss_train=0.7566, acc_train=0.7097, loss_test=0.4086, acc_test=0.9387
# poison_percent 20 epoch 24: loss_train=0.7822, acc_train=0.6774, loss_test=0.3600, acc_test=0.9638
# poison_percent 20 epoch 25: loss_train=0.9014, acc_train=0.7742, loss_test=0.3777, acc_test=0.9540
# poison_percent 20 epoch 26: loss_train=0.9081, acc_train=0.6129, loss_test=0.3368, acc_test=0.9663
# poison_percent 20 epoch 27: loss_train=0.9206, acc_train=0.6774, loss_test=0.3468, acc_test=0.9632
# poison_percent 20 epoch 28: loss_train=0.8868, acc_train=0.7419, loss_test=0.3387, acc_test=0.9663
# poison_percent 20 epoch 29: loss_train=0.9514, acc_train=0.5161, loss_test=0.3712, acc_test=0.9565
# poison_percent 20 epoch 30: loss_train=0.9302, acc_train=0.6774, loss_test=0.3378, acc_test=0.9626
# poison_percent 20 epoch 31: loss_train=0.9306, acc_train=0.6129, loss_test=0.3755, acc_test=0.9485
# poison_percent 20 epoch 32: loss_train=0.8899, acc_train=0.6129, loss_test=0.3646, acc_test=0.9553
# poison_percent 20 epoch 33: loss_train=0.7426, acc_train=0.8065, loss_test=0.3729, acc_test=0.9553
# poison_percent 20 epoch 34: loss_train=0.7666, acc_train=0.7097, loss_test=0.3381, acc_test=0.9626
# poison_percent 20 epoch 35: loss_train=0.8547, acc_train=0.8387, loss_test=0.3828, acc_test=0.9522
# poison_percent 20 epoch 36: loss_train=1.0448, acc_train=0.6452, loss_test=0.3685, acc_test=0.9589
# poison_percent 20 epoch 37: loss_train=0.7420, acc_train=0.7742, loss_test=0.3214, acc_test=0.9638
# poison_percent 20 epoch 38: loss_train=0.9063, acc_train=0.7419, loss_test=0.3323, acc_test=0.9651
# poison_percent 20 epoch 39: loss_train=0.4323, acc_train=0.9355, loss_test=0.3472, acc_test=0.9608
# poison_percent 20 epoch 40: loss_train=0.7539, acc_train=0.7419, loss_test=0.3891, acc_test=0.9534
# poison_percent 20 epoch 41: loss_train=0.8607, acc_train=0.6774, loss_test=0.3523, acc_test=0.9620
# poison_percent 20 epoch 42: loss_train=0.5138, acc_train=0.8065, loss_test=0.3291, acc_test=0.9669
# poison_percent 20 epoch 43: loss_train=0.7849, acc_train=0.7097, loss_test=0.3489, acc_test=0.9614
# poison_percent 20 epoch 44: loss_train=0.7403, acc_train=0.7097, loss_test=0.3599, acc_test=0.9608
# poison_percent 20 epoch 45: loss_train=0.5880, acc_train=0.7742, loss_test=0.3458, acc_test=0.9602
# poison_percent 20 epoch 46: loss_train=0.7847, acc_train=0.7742, loss_test=0.3687, acc_test=0.9485
# poison_percent 20 epoch 47: loss_train=0.6949, acc_train=0.7097, loss_test=0.3571, acc_test=0.9608
# poison_percent 20 epoch 48: loss_train=0.8522, acc_train=0.7097, loss_test=0.3547, acc_test=0.9577
# poison_percent 20 epoch 49: loss_train=0.9844, acc_train=0.6452, loss_test=0.3697, acc_test=0.9565
# poison_percent 20 epoch 50: loss_train=0.6852, acc_train=0.8065, loss_test=0.3259, acc_test=0.9645
# poison_percent 20 epoch 51: loss_train=0.6822, acc_train=0.7097, loss_test=0.3554, acc_test=0.9614
# poison_percent 20 epoch 52: loss_train=0.6000, acc_train=0.6774, loss_test=0.3724, acc_test=0.9540
# poison_percent 20 epoch 53: loss_train=1.0399, acc_train=0.6452, loss_test=0.3692, acc_test=0.9565
# poison_percent 20 epoch 54: loss_train=0.5581, acc_train=0.7742, loss_test=0.3792, acc_test=0.9577
# poison_percent 20 epoch 55: loss_train=0.7259, acc_train=0.5806, loss_test=0.3405, acc_test=0.9651
# poison_percent 20 epoch 56: loss_train=0.7267, acc_train=0.6774, loss_test=0.3478, acc_test=0.9645
# poison_percent 20 epoch 57: loss_train=0.4787, acc_train=0.8387, loss_test=0.3264, acc_test=0.9632
# poison_percent 20 epoch 58: loss_train=0.7945, acc_train=0.6774, loss_test=0.3700, acc_test=0.9571
# poison_percent 20 epoch 59: loss_train=0.7643, acc_train=0.7419, loss_test=0.3489, acc_test=0.9626
# poison_percent 20 epoch 60: loss_train=0.9153, acc_train=0.6452, loss_test=0.3934, acc_test=0.9510
# poison_percent 20 epoch 61: loss_train=0.9130, acc_train=0.6129, loss_test=0.3413, acc_test=0.9626
# poison_percent 20 epoch 62: loss_train=0.5079, acc_train=0.8710, loss_test=0.3280, acc_test=0.9645
# poison_percent 20 epoch 63: loss_train=0.6656, acc_train=0.7419, loss_test=0.3501, acc_test=0.9608
# poison_percent 20 epoch 64: loss_train=0.7534, acc_train=0.6452, loss_test=0.3589, acc_test=0.9602
# poison_percent 20 epoch 65: loss_train=1.0279, acc_train=0.5806, loss_test=0.3499, acc_test=0.9602
# poison_percent 20 epoch 66: loss_train=0.5696, acc_train=0.7742, loss_test=0.3773, acc_test=0.9406
# poison_percent 20 epoch 67: loss_train=0.7287, acc_train=0.7742, loss_test=0.3491, acc_test=0.9614
# poison_percent 20 epoch 68: loss_train=0.8815, acc_train=0.6774, loss_test=0.3563, acc_test=0.9596
# poison_percent 20 epoch 69: loss_train=0.6311, acc_train=0.7742, loss_test=0.3533, acc_test=0.9614
# poison_percent 20 epoch 70: loss_train=0.9821, acc_train=0.6129, loss_test=0.3206, acc_test=0.9694
# poison_percent 20 epoch 71: loss_train=0.6665, acc_train=0.7419, loss_test=0.3638, acc_test=0.9632
# poison_percent 20 epoch 72: loss_train=0.7513, acc_train=0.5806, loss_test=0.3375, acc_test=0.9626
# poison_percent 20 epoch 73: loss_train=0.8578, acc_train=0.6774, loss_test=0.3474, acc_test=0.9559
# poison_percent 20 epoch 74: loss_train=0.7557, acc_train=0.7742, loss_test=0.3595, acc_test=0.9553
# poison_percent 20 epoch 75: loss_train=0.7956, acc_train=0.6774, loss_test=0.3679, acc_test=0.9583
# poison_percent 20 epoch 76: loss_train=0.5484, acc_train=0.7742, loss_test=0.3696, acc_test=0.9583
# poison_percent 20 epoch 77: loss_train=0.7938, acc_train=0.7097, loss_test=0.3735, acc_test=0.9571
# poison_percent 20 epoch 78: loss_train=0.8865, acc_train=0.5806, loss_test=0.3253, acc_test=0.9657
# poison_percent 20 epoch 79: loss_train=1.0531, acc_train=0.6129, loss_test=0.3525, acc_test=0.9589
# poison_percent 20 epoch 80: loss_train=1.0071, acc_train=0.5806, loss_test=0.3330, acc_test=0.9632
# poison_percent 20 epoch 81: loss_train=0.5663, acc_train=0.8065, loss_test=0.3462, acc_test=0.9638
# poison_percent 20 epoch 82: loss_train=0.7872, acc_train=0.6452, loss_test=0.3590, acc_test=0.9602
# poison_percent 20 epoch 83: loss_train=0.8250, acc_train=0.7742, loss_test=0.3850, acc_test=0.9498
# poison_percent 20 epoch 84: loss_train=0.8142, acc_train=0.7097, loss_test=0.3670, acc_test=0.9596
# poison_percent 20 epoch 85: loss_train=0.4823, acc_train=0.8065, loss_test=0.3319, acc_test=0.9626
# poison_percent 20 epoch 86: loss_train=0.9226, acc_train=0.6129, loss_test=0.3880, acc_test=0.9522
# poison_percent 20 epoch 87: loss_train=0.6327, acc_train=0.7742, loss_test=0.3477, acc_test=0.9620
# poison_percent 20 epoch 88: loss_train=0.7105, acc_train=0.6774, loss_test=0.3656, acc_test=0.9596
# poison_percent 20 epoch 89: loss_train=1.0512, acc_train=0.7097, loss_test=0.3736, acc_test=0.9528
# poison_percent 20 epoch 90: loss_train=0.8404, acc_train=0.7742, loss_test=0.3586, acc_test=0.9608
# poison_percent 20 epoch 91: loss_train=0.6405, acc_train=0.7742, loss_test=0.3737, acc_test=0.9583
# poison_percent 20 epoch 92: loss_train=0.6971, acc_train=0.7742, loss_test=0.3284, acc_test=0.9681
# poison_percent 20 epoch 93: loss_train=0.8935, acc_train=0.6774, loss_test=0.3517, acc_test=0.9608
# poison_percent 20 epoch 94: loss_train=0.6151, acc_train=0.7097, loss_test=0.3721, acc_test=0.9547
# poison_percent 20 epoch 95: loss_train=0.8950, acc_train=0.6129, loss_test=0.3558, acc_test=0.9547
# poison_percent 20 epoch 96: loss_train=0.9552, acc_train=0.6129, loss_test=0.3770, acc_test=0.9571
# poison_percent 20 epoch 97: loss_train=0.8976, acc_train=0.7097, loss_test=0.3601, acc_test=0.9602
# poison_percent 20 epoch 98: loss_train=0.5788, acc_train=0.8065, loss_test=0.3781, acc_test=0.9534
# poison_percent 20 epoch 99: loss_train=0.7463, acc_train=0.7419, loss_test=0.3459, acc_test=0.9614
# Training log saved to ./results\CL_ModelN1L1_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 epoch 0: loss_train=0.9035, acc_train=0.5385, loss_test=0.5110, acc_test=0.9222
# poison_percent 30 epoch 1: loss_train=0.7802, acc_train=0.6154, loss_test=0.4676, acc_test=0.9295
# poison_percent 30 epoch 2: loss_train=0.8632, acc_train=0.5385, loss_test=0.4965, acc_test=0.8952
# poison_percent 30 epoch 3: loss_train=0.9227, acc_train=0.5769, loss_test=0.4866, acc_test=0.9283
# poison_percent 30 epoch 4: loss_train=0.8877, acc_train=0.5769, loss_test=0.4567, acc_test=0.9289
# poison_percent 30 epoch 5: loss_train=0.8370, acc_train=0.6923, loss_test=0.5003, acc_test=0.9154
# poison_percent 30 epoch 6: loss_train=0.9819, acc_train=0.6923, loss_test=0.4840, acc_test=0.9038
# poison_percent 30 epoch 7: loss_train=0.8754, acc_train=0.5385, loss_test=0.5062, acc_test=0.9038
# poison_percent 30 epoch 8: loss_train=0.9639, acc_train=0.5385, loss_test=0.5010, acc_test=0.8964
# poison_percent 30 epoch 9: loss_train=1.1214, acc_train=0.5000, loss_test=0.4328, acc_test=0.9400
# poison_percent 30 epoch 10: loss_train=0.9521, acc_train=0.5000, loss_test=0.5156, acc_test=0.9050
# poison_percent 30 epoch 11: loss_train=0.6868, acc_train=0.7308, loss_test=0.4781, acc_test=0.9228
# poison_percent 30 epoch 12: loss_train=0.8351, acc_train=0.5769, loss_test=0.4603, acc_test=0.9308
# poison_percent 30 epoch 13: loss_train=1.0512, acc_train=0.5769, loss_test=0.4986, acc_test=0.9191
# poison_percent 30 epoch 14: loss_train=0.9295, acc_train=0.6538, loss_test=0.5330, acc_test=0.8995
# poison_percent 30 epoch 15: loss_train=0.8143, acc_train=0.6538, loss_test=0.5086, acc_test=0.9075
# poison_percent 30 epoch 16: loss_train=0.8182, acc_train=0.5769, loss_test=0.4864, acc_test=0.9105
# poison_percent 30 epoch 17: loss_train=1.4817, acc_train=0.5000, loss_test=0.4928, acc_test=0.9277
# poison_percent 30 epoch 18: loss_train=0.5716, acc_train=0.7692, loss_test=0.5039, acc_test=0.9112
# poison_percent 30 epoch 19: loss_train=1.0488, acc_train=0.5769, loss_test=0.4869, acc_test=0.9283
# poison_percent 30 epoch 20: loss_train=0.7591, acc_train=0.5769, loss_test=0.5054, acc_test=0.9167
# poison_percent 30 epoch 21: loss_train=0.8460, acc_train=0.5385, loss_test=0.4799, acc_test=0.9246
# poison_percent 30 epoch 22: loss_train=0.8250, acc_train=0.6154, loss_test=0.4990, acc_test=0.9062
# poison_percent 30 epoch 23: loss_train=0.8380, acc_train=0.6538, loss_test=0.4455, acc_test=0.9350
# poison_percent 30 epoch 24: loss_train=0.8273, acc_train=0.5769, loss_test=0.4704, acc_test=0.9308
# poison_percent 30 epoch 25: loss_train=0.9173, acc_train=0.4615, loss_test=0.4975, acc_test=0.9314
# poison_percent 30 epoch 26: loss_train=0.9763, acc_train=0.4231, loss_test=0.4489, acc_test=0.9271
# poison_percent 30 epoch 27: loss_train=1.4600, acc_train=0.4615, loss_test=0.5017, acc_test=0.9056
# poison_percent 30 epoch 28: loss_train=0.8370, acc_train=0.6538, loss_test=0.4989, acc_test=0.9020
# poison_percent 30 epoch 29: loss_train=0.7860, acc_train=0.5769, loss_test=0.4979, acc_test=0.8977
# poison_percent 30 epoch 30: loss_train=0.9500, acc_train=0.5000, loss_test=0.5041, acc_test=0.9099
# poison_percent 30 epoch 31: loss_train=0.9316, acc_train=0.5769, loss_test=0.5191, acc_test=0.8781
# poison_percent 30 epoch 32: loss_train=0.9292, acc_train=0.5385, loss_test=0.4582, acc_test=0.9369
# poison_percent 30 epoch 33: loss_train=1.0688, acc_train=0.5769, loss_test=0.4874, acc_test=0.9265
# poison_percent 30 epoch 34: loss_train=0.8103, acc_train=0.6538, loss_test=0.4765, acc_test=0.9314
# poison_percent 30 epoch 35: loss_train=0.8463, acc_train=0.5769, loss_test=0.5125, acc_test=0.9136
# poison_percent 30 epoch 36: loss_train=0.6447, acc_train=0.7692, loss_test=0.5198, acc_test=0.9161
# poison_percent 30 epoch 37: loss_train=0.6189, acc_train=0.7308, loss_test=0.4641, acc_test=0.9277
# poison_percent 30 epoch 38: loss_train=0.9902, acc_train=0.5769, loss_test=0.5231, acc_test=0.9118
# poison_percent 30 epoch 39: loss_train=1.2906, acc_train=0.5769, loss_test=0.4572, acc_test=0.9338
# poison_percent 30 epoch 40: loss_train=1.0113, acc_train=0.6923, loss_test=0.5511, acc_test=0.9056
# poison_percent 30 epoch 41: loss_train=0.8797, acc_train=0.6538, loss_test=0.4449, acc_test=0.9344
# poison_percent 30 epoch 42: loss_train=0.9311, acc_train=0.5769, loss_test=0.4970, acc_test=0.9240
# poison_percent 30 epoch 43: loss_train=0.8222, acc_train=0.6538, loss_test=0.4700, acc_test=0.9332
# poison_percent 30 epoch 44: loss_train=0.7492, acc_train=0.7308, loss_test=0.4855, acc_test=0.9179
# poison_percent 30 epoch 45: loss_train=0.8995, acc_train=0.5385, loss_test=0.5120, acc_test=0.9069
# poison_percent 30 epoch 46: loss_train=0.7968, acc_train=0.6923, loss_test=0.4716, acc_test=0.9295
# poison_percent 30 epoch 47: loss_train=0.6003, acc_train=0.7692, loss_test=0.4794, acc_test=0.9161
# poison_percent 30 epoch 48: loss_train=0.7014, acc_train=0.6538, loss_test=0.5013, acc_test=0.9044
# poison_percent 30 epoch 49: loss_train=0.7774, acc_train=0.6923, loss_test=0.5066, acc_test=0.8958
# poison_percent 30 epoch 50: loss_train=0.6495, acc_train=0.5769, loss_test=0.4866, acc_test=0.9289
# poison_percent 30 epoch 51: loss_train=0.8398, acc_train=0.6538, loss_test=0.4991, acc_test=0.9252
# poison_percent 30 epoch 52: loss_train=0.7917, acc_train=0.6923, loss_test=0.4643, acc_test=0.9344
# poison_percent 30 epoch 53: loss_train=0.7862, acc_train=0.6154, loss_test=0.5275, acc_test=0.8848
# poison_percent 30 epoch 54: loss_train=0.9996, acc_train=0.6154, loss_test=0.4778, acc_test=0.9234
# poison_percent 30 epoch 55: loss_train=0.8386, acc_train=0.6538, loss_test=0.4555, acc_test=0.9338
# poison_percent 30 epoch 56: loss_train=0.9197, acc_train=0.6923, loss_test=0.4890, acc_test=0.9240
# poison_percent 30 epoch 57: loss_train=1.2185, acc_train=0.5000, loss_test=0.4782, acc_test=0.9210
# poison_percent 30 epoch 58: loss_train=0.7167, acc_train=0.7308, loss_test=0.4925, acc_test=0.9197
# poison_percent 30 epoch 59: loss_train=0.8629, acc_train=0.5769, loss_test=0.5078, acc_test=0.9020
# poison_percent 30 epoch 60: loss_train=0.9710, acc_train=0.6923, loss_test=0.5031, acc_test=0.9228
# poison_percent 30 epoch 61: loss_train=0.9238, acc_train=0.6923, loss_test=0.5150, acc_test=0.9007
# poison_percent 30 epoch 62: loss_train=0.7811, acc_train=0.6154, loss_test=0.4997, acc_test=0.9222
# poison_percent 30 epoch 63: loss_train=0.8377, acc_train=0.5000, loss_test=0.4867, acc_test=0.9203
# poison_percent 30 epoch 64: loss_train=0.9051, acc_train=0.7308, loss_test=0.5027, acc_test=0.9179
# poison_percent 30 epoch 65: loss_train=0.6414, acc_train=0.7308, loss_test=0.5292, acc_test=0.8995
# poison_percent 30 epoch 66: loss_train=0.9903, acc_train=0.5000, loss_test=0.5009, acc_test=0.9154
# poison_percent 30 epoch 67: loss_train=0.7461, acc_train=0.6923, loss_test=0.4946, acc_test=0.9087
# poison_percent 30 epoch 68: loss_train=0.8442, acc_train=0.6923, loss_test=0.4757, acc_test=0.9271
# poison_percent 30 epoch 69: loss_train=1.2662, acc_train=0.5769, loss_test=0.4794, acc_test=0.9277
# poison_percent 30 epoch 70: loss_train=0.8494, acc_train=0.7308, loss_test=0.5166, acc_test=0.9142
# poison_percent 30 epoch 71: loss_train=0.9059, acc_train=0.5385, loss_test=0.4983, acc_test=0.9167
# poison_percent 30 epoch 72: loss_train=0.7769, acc_train=0.6154, loss_test=0.4732, acc_test=0.9301
# poison_percent 30 epoch 73: loss_train=1.0127, acc_train=0.6154, loss_test=0.4750, acc_test=0.9185
# poison_percent 30 epoch 74: loss_train=0.7783, acc_train=0.7308, loss_test=0.4810, acc_test=0.9210
# poison_percent 30 epoch 75: loss_train=0.8577, acc_train=0.5000, loss_test=0.5157, acc_test=0.9130
# poison_percent 30 epoch 76: loss_train=0.8548, acc_train=0.6538, loss_test=0.4880, acc_test=0.9203
# poison_percent 30 epoch 77: loss_train=0.8729, acc_train=0.5385, loss_test=0.4645, acc_test=0.9393
# poison_percent 30 epoch 78: loss_train=0.9118, acc_train=0.5385, loss_test=0.4582, acc_test=0.9350
# poison_percent 30 epoch 79: loss_train=1.0139, acc_train=0.5000, loss_test=0.4844, acc_test=0.9308
# poison_percent 30 epoch 80: loss_train=1.1556, acc_train=0.6154, loss_test=0.4535, acc_test=0.9363
# poison_percent 30 epoch 81: loss_train=0.9354, acc_train=0.6538, loss_test=0.4455, acc_test=0.9393
# poison_percent 30 epoch 82: loss_train=0.9792, acc_train=0.6154, loss_test=0.4783, acc_test=0.9234
# poison_percent 30 epoch 83: loss_train=0.9430, acc_train=0.5000, loss_test=0.5019, acc_test=0.9148
# poison_percent 30 epoch 84: loss_train=0.7143, acc_train=0.6923, loss_test=0.4916, acc_test=0.9246
# poison_percent 30 epoch 85: loss_train=0.8441, acc_train=0.5769, loss_test=0.4807, acc_test=0.9112
# poison_percent 30 epoch 86: loss_train=1.0385, acc_train=0.5769, loss_test=0.4974, acc_test=0.9154
# poison_percent 30 epoch 87: loss_train=0.8089, acc_train=0.6538, loss_test=0.4546, acc_test=0.9277
# poison_percent 30 epoch 88: loss_train=0.8583, acc_train=0.6923, loss_test=0.4737, acc_test=0.9375
# poison_percent 30 epoch 89: loss_train=0.7621, acc_train=0.6923, loss_test=0.4806, acc_test=0.9326
# poison_percent 30 epoch 90: loss_train=0.9838, acc_train=0.6154, loss_test=0.5269, acc_test=0.8940
# poison_percent 30 epoch 91: loss_train=1.0043, acc_train=0.5000, loss_test=0.4404, acc_test=0.9369
# poison_percent 30 epoch 92: loss_train=0.9119, acc_train=0.6923, loss_test=0.4924, acc_test=0.9271
# poison_percent 30 epoch 93: loss_train=1.0327, acc_train=0.5769, loss_test=0.5306, acc_test=0.8799
# poison_percent 30 epoch 94: loss_train=0.9199, acc_train=0.5385, loss_test=0.5048, acc_test=0.9197
# poison_percent 30 epoch 95: loss_train=1.3300, acc_train=0.3846, loss_test=0.5100, acc_test=0.8995
# poison_percent 30 epoch 96: loss_train=0.8646, acc_train=0.6154, loss_test=0.4628, acc_test=0.9234
# poison_percent 30 epoch 97: loss_train=1.0839, acc_train=0.5385, loss_test=0.4842, acc_test=0.9246
# poison_percent 30 epoch 98: loss_train=0.7804, acc_train=0.6923, loss_test=0.4676, acc_test=0.9320
# poison_percent 30 epoch 99: loss_train=0.7981, acc_train=0.7308, loss_test=0.4719, acc_test=0.9246
# Training log saved to ./results\CL_ModelN1L1_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 epoch 0: loss_train=0.6929, acc_train=0.7000, loss_test=0.6268, acc_test=0.7960
# poison_percent 40 epoch 1: loss_train=1.0151, acc_train=0.4000, loss_test=0.6060, acc_test=0.8039
# poison_percent 40 epoch 2: loss_train=0.8228, acc_train=0.6000, loss_test=0.6386, acc_test=0.8027
# poison_percent 40 epoch 3: loss_train=1.0022, acc_train=0.5000, loss_test=0.6455, acc_test=0.7788
# poison_percent 40 epoch 4: loss_train=2.3230, acc_train=0.2000, loss_test=0.5942, acc_test=0.8523
# poison_percent 40 epoch 5: loss_train=1.0028, acc_train=0.5000, loss_test=0.6489, acc_test=0.7923
# poison_percent 40 epoch 6: loss_train=1.3302, acc_train=0.3000, loss_test=0.6323, acc_test=0.7708
# poison_percent 40 epoch 7: loss_train=1.0368, acc_train=0.4000, loss_test=0.6510, acc_test=0.7684
# poison_percent 40 epoch 8: loss_train=0.8337, acc_train=0.5000, loss_test=0.6387, acc_test=0.7770
# poison_percent 40 epoch 9: loss_train=0.8632, acc_train=0.6000, loss_test=0.6489, acc_test=0.7843
# poison_percent 40 epoch 10: loss_train=0.8727, acc_train=0.5000, loss_test=0.6103, acc_test=0.8241
# poison_percent 40 epoch 11: loss_train=0.7767, acc_train=0.6000, loss_test=0.6593, acc_test=0.7745
# poison_percent 40 epoch 12: loss_train=1.0662, acc_train=0.3000, loss_test=0.6317, acc_test=0.7953
# poison_percent 40 epoch 13: loss_train=0.9381, acc_train=0.4000, loss_test=0.6375, acc_test=0.7880
# poison_percent 40 epoch 14: loss_train=0.8685, acc_train=0.7000, loss_test=0.6088, acc_test=0.8088
# poison_percent 40 epoch 15: loss_train=0.8680, acc_train=0.7000, loss_test=0.6193, acc_test=0.8217
# poison_percent 40 epoch 16: loss_train=0.9576, acc_train=0.6000, loss_test=0.6555, acc_test=0.7733
# poison_percent 40 epoch 17: loss_train=0.8060, acc_train=0.6000, loss_test=0.6114, acc_test=0.8395
# poison_percent 40 epoch 18: loss_train=0.7109, acc_train=0.7000, loss_test=0.6545, acc_test=0.7721
# poison_percent 40 epoch 19: loss_train=1.3281, acc_train=0.3000, loss_test=0.6565, acc_test=0.7837
# poison_percent 40 epoch 20: loss_train=1.0159, acc_train=0.7000, loss_test=0.6306, acc_test=0.8027
# poison_percent 40 epoch 21: loss_train=1.0011, acc_train=0.3000, loss_test=0.6598, acc_test=0.7537
# poison_percent 40 epoch 22: loss_train=1.1376, acc_train=0.4000, loss_test=0.6588, acc_test=0.7463
# poison_percent 40 epoch 23: loss_train=1.1495, acc_train=0.4000, loss_test=0.6516, acc_test=0.7690
# poison_percent 40 epoch 24: loss_train=0.6611, acc_train=0.8000, loss_test=0.5865, acc_test=0.8364
# poison_percent 40 epoch 25: loss_train=1.1564, acc_train=0.5000, loss_test=0.6130, acc_test=0.8370
# poison_percent 40 epoch 26: loss_train=0.9042, acc_train=0.5000, loss_test=0.6737, acc_test=0.7230
# poison_percent 40 epoch 27: loss_train=1.6270, acc_train=0.0000, loss_test=0.6177, acc_test=0.8082
# poison_percent 40 epoch 28: loss_train=1.4024, acc_train=0.5000, loss_test=0.6314, acc_test=0.8125
# poison_percent 40 epoch 29: loss_train=0.9852, acc_train=0.5000, loss_test=0.6066, acc_test=0.8444
# poison_percent 40 epoch 30: loss_train=0.6715, acc_train=0.7000, loss_test=0.6786, acc_test=0.7641
# poison_percent 40 epoch 31: loss_train=0.9044, acc_train=0.5000, loss_test=0.6410, acc_test=0.7831
# poison_percent 40 epoch 32: loss_train=0.7437, acc_train=0.7000, loss_test=0.5866, acc_test=0.8621
# poison_percent 40 epoch 33: loss_train=0.7961, acc_train=0.6000, loss_test=0.6320, acc_test=0.7874
# poison_percent 40 epoch 34: loss_train=0.7642, acc_train=0.5000, loss_test=0.6592, acc_test=0.7757
# poison_percent 40 epoch 35: loss_train=0.7387, acc_train=0.6000, loss_test=0.6548, acc_test=0.7788
# poison_percent 40 epoch 36: loss_train=1.3302, acc_train=0.3000, loss_test=0.6574, acc_test=0.7494
# poison_percent 40 epoch 37: loss_train=0.7613, acc_train=0.8000, loss_test=0.6624, acc_test=0.7659
# poison_percent 40 epoch 38: loss_train=0.7349, acc_train=0.7000, loss_test=0.6262, acc_test=0.8070
# poison_percent 40 epoch 39: loss_train=1.4620, acc_train=0.2000, loss_test=0.6318, acc_test=0.7990
# poison_percent 40 epoch 40: loss_train=0.7474, acc_train=0.7000, loss_test=0.6300, acc_test=0.8107
# poison_percent 40 epoch 41: loss_train=0.8505, acc_train=0.5000, loss_test=0.6738, acc_test=0.7574
# poison_percent 40 epoch 42: loss_train=1.2265, acc_train=0.5000, loss_test=0.6396, acc_test=0.7800
# poison_percent 40 epoch 43: loss_train=0.8446, acc_train=0.5000, loss_test=0.6279, acc_test=0.7947
# poison_percent 40 epoch 44: loss_train=1.1383, acc_train=0.5000, loss_test=0.6797, acc_test=0.7371
# poison_percent 40 epoch 45: loss_train=0.8257, acc_train=0.7000, loss_test=0.6188, acc_test=0.8309
# poison_percent 40 epoch 46: loss_train=0.4059, acc_train=0.9000, loss_test=0.6428, acc_test=0.7923
# poison_percent 40 epoch 47: loss_train=1.2883, acc_train=0.4000, loss_test=0.5855, acc_test=0.8474
# poison_percent 40 epoch 48: loss_train=1.1453, acc_train=0.3000, loss_test=0.6256, acc_test=0.8094
# poison_percent 40 epoch 49: loss_train=0.6825, acc_train=0.9000, loss_test=0.6714, acc_test=0.7390
# poison_percent 40 epoch 50: loss_train=0.9006, acc_train=0.5000, loss_test=0.6506, acc_test=0.7892
# poison_percent 40 epoch 51: loss_train=1.3490, acc_train=0.3000, loss_test=0.6239, acc_test=0.8009
# poison_percent 40 epoch 52: loss_train=0.7374, acc_train=0.6000, loss_test=0.6338, acc_test=0.8131
# poison_percent 40 epoch 53: loss_train=1.2086, acc_train=0.1000, loss_test=0.6401, acc_test=0.7635
# poison_percent 40 epoch 54: loss_train=0.9517, acc_train=0.5000, loss_test=0.7099, acc_test=0.6949
# poison_percent 40 epoch 55: loss_train=1.2647, acc_train=0.4000, loss_test=0.6630, acc_test=0.7800
# poison_percent 40 epoch 56: loss_train=1.0631, acc_train=0.5000, loss_test=0.6016, acc_test=0.8180
# poison_percent 40 epoch 57: loss_train=1.1579, acc_train=0.6000, loss_test=0.5921, acc_test=0.8517
# poison_percent 40 epoch 58: loss_train=0.9811, acc_train=0.4000, loss_test=0.6444, acc_test=0.8076
# poison_percent 40 epoch 59: loss_train=0.8043, acc_train=0.4000, loss_test=0.6612, acc_test=0.7672
# poison_percent 40 epoch 60: loss_train=1.0229, acc_train=0.4000, loss_test=0.6342, acc_test=0.8002
# poison_percent 40 epoch 61: loss_train=0.6679, acc_train=0.6000, loss_test=0.6512, acc_test=0.7733
# poison_percent 40 epoch 62: loss_train=0.7787, acc_train=0.5000, loss_test=0.6896, acc_test=0.7335
# poison_percent 40 epoch 63: loss_train=0.7083, acc_train=0.6000, loss_test=0.6037, acc_test=0.8315
# poison_percent 40 epoch 64: loss_train=0.8459, acc_train=0.5000, loss_test=0.6613, acc_test=0.7672
# poison_percent 40 epoch 65: loss_train=1.4136, acc_train=0.4000, loss_test=0.6373, acc_test=0.7880
# poison_percent 40 epoch 66: loss_train=0.7666, acc_train=0.5000, loss_test=0.6041, acc_test=0.8235
# poison_percent 40 epoch 67: loss_train=0.6821, acc_train=0.7000, loss_test=0.6476, acc_test=0.7874
# poison_percent 40 epoch 68: loss_train=0.7597, acc_train=0.3000, loss_test=0.6566, acc_test=0.7347
# poison_percent 40 epoch 69: loss_train=1.3530, acc_train=0.6000, loss_test=0.6463, acc_test=0.7641
# poison_percent 40 epoch 70: loss_train=1.0951, acc_train=0.5000, loss_test=0.6498, acc_test=0.7972
# poison_percent 40 epoch 71: loss_train=0.5837, acc_train=0.8000, loss_test=0.6335, acc_test=0.8045
# poison_percent 40 epoch 72: loss_train=0.7901, acc_train=0.6000, loss_test=0.6154, acc_test=0.8168
# poison_percent 40 epoch 73: loss_train=0.7385, acc_train=0.7000, loss_test=0.6590, acc_test=0.7672
# poison_percent 40 epoch 74: loss_train=0.4561, acc_train=0.8000, loss_test=0.6313, acc_test=0.7904
# poison_percent 40 epoch 75: loss_train=1.0385, acc_train=0.4000, loss_test=0.6597, acc_test=0.7500
# poison_percent 40 epoch 76: loss_train=0.5876, acc_train=0.8000, loss_test=0.6041, acc_test=0.8174
# poison_percent 40 epoch 77: loss_train=0.5307, acc_train=0.7000, loss_test=0.6358, acc_test=0.8260
# poison_percent 40 epoch 78: loss_train=0.7942, acc_train=0.6000, loss_test=0.6278, acc_test=0.7880
# poison_percent 40 epoch 79: loss_train=1.0244, acc_train=0.4000, loss_test=0.6052, acc_test=0.8505
# poison_percent 40 epoch 80: loss_train=0.6789, acc_train=0.7000, loss_test=0.6217, acc_test=0.7947
# poison_percent 40 epoch 81: loss_train=1.0552, acc_train=0.5000, loss_test=0.6600, acc_test=0.7328
# ...
# poison_percent 40 epoch 41: loss_train=0.6918, acc_train=0.6000, loss_test=0.6510, acc_test=0.7610
# poison_percent 40 epoch 42: loss_train=1.2788, acc_train=0.2000, loss_test=0.6842, acc_test=0.7028
# poison_percent 40 epoch 43: loss_train=0.9148, acc_train=0.4000, loss_test=0.6670, acc_test=0.7316
# poison_percent 40 epoch 44: loss_train=1.4056, acc_train=0.3000, loss_test=0.6665, acc_test=0.7500
# poison_percent 40 epoch 45: loss_train=0.8045, acc_train=0.5000, loss_test=0.6603, acc_test=0.7279
# poison_percent 40 epoch 46: loss_train=1.1302, acc_train=0.3000, loss_test=0.6848, acc_test=0.7500
# poison_percent 40 epoch 47: loss_train=0.9800, acc_train=0.3000, loss_test=0.6534, acc_test=0.7543
# poison_percent 40 epoch 48: loss_train=0.8445, acc_train=0.4000, loss_test=0.6911, acc_test=0.6722
# poison_percent 40 epoch 49: loss_train=0.8084, acc_train=0.4000, loss_test=0.6329, acc_test=0.7635
# poison_percent 40 epoch 50: loss_train=1.1896, acc_train=0.2000, loss_test=0.7041, acc_test=0.6832
# poison_percent 40 epoch 51: loss_train=0.9405, acc_train=0.4000, loss_test=0.6282, acc_test=0.7733
# poison_percent 40 epoch 52: loss_train=1.0102, acc_train=0.4000, loss_test=0.6601, acc_test=0.7316
# poison_percent 40 epoch 53: loss_train=0.6376, acc_train=0.5000, loss_test=0.6598, acc_test=0.7377
# poison_percent 40 epoch 54: loss_train=1.2936, acc_train=0.4000, loss_test=0.6731, acc_test=0.7310
# poison_percent 40 epoch 55: loss_train=0.9793, acc_train=0.6000, loss_test=0.6764, acc_test=0.7243
# poison_percent 40 epoch 56: loss_train=1.1535, acc_train=0.4000, loss_test=0.6970, acc_test=0.7163
# poison_percent 40 epoch 57: loss_train=1.2451, acc_train=0.2000, loss_test=0.6295, acc_test=0.7782
# poison_percent 40 epoch 58: loss_train=0.8612, acc_train=0.5000, loss_test=0.6530, acc_test=0.7469
# poison_percent 40 epoch 59: loss_train=1.0325, acc_train=0.4000, loss_test=0.6670, acc_test=0.7377
# poison_percent 40 epoch 60: loss_train=0.9971, acc_train=0.6000, loss_test=0.6800, acc_test=0.7108
# poison_percent 40 epoch 61: loss_train=1.0341, acc_train=0.6000, loss_test=0.6795, acc_test=0.7335
# poison_percent 40 epoch 62: loss_train=0.9484, acc_train=0.6000, loss_test=0.6805, acc_test=0.7390
# poison_percent 40 epoch 63: loss_train=0.9283, acc_train=0.5000, loss_test=0.6710, acc_test=0.7279
# poison_percent 40 epoch 64: loss_train=1.7138, acc_train=0.4000, loss_test=0.6839, acc_test=0.7230
# poison_percent 40 epoch 65: loss_train=0.9749, acc_train=0.5000, loss_test=0.6712, acc_test=0.7304
# poison_percent 40 epoch 66: loss_train=1.0575, acc_train=0.5000, loss_test=0.6962, acc_test=0.7273
# poison_percent 40 epoch 67: loss_train=1.6004, acc_train=0.5000, loss_test=0.7562, acc_test=0.6311
# poison_percent 40 epoch 68: loss_train=0.8819, acc_train=0.5000, loss_test=0.6366, acc_test=0.7727
# poison_percent 40 epoch 69: loss_train=0.7949, acc_train=0.5000, loss_test=0.6478, acc_test=0.7776
# poison_percent 40 epoch 70: loss_train=0.8453, acc_train=0.4000, loss_test=0.6586, acc_test=0.7402
# poison_percent 40 epoch 71: loss_train=1.0976, acc_train=0.5000, loss_test=0.7263, acc_test=0.6844
# poison_percent 40 epoch 72: loss_train=1.1500, acc_train=0.5000, loss_test=0.6493, acc_test=0.7623
# poison_percent 40 epoch 73: loss_train=1.0974, acc_train=0.7000, loss_test=0.7139, acc_test=0.6863
# poison_percent 40 epoch 74: loss_train=0.9425, acc_train=0.6000, loss_test=0.7013, acc_test=0.7120
# poison_percent 40 epoch 75: loss_train=1.0634, acc_train=0.4000, loss_test=0.7336, acc_test=0.6526
# poison_percent 40 epoch 76: loss_train=1.1913, acc_train=0.4000, loss_test=0.6331, acc_test=0.7500
# poison_percent 40 epoch 77: loss_train=0.8398, acc_train=0.6000, loss_test=0.6124, acc_test=0.8015
# poison_percent 40 epoch 78: loss_train=1.1385, acc_train=0.3000, loss_test=0.6738, acc_test=0.7286
# poison_percent 40 epoch 79: loss_train=0.7682, acc_train=0.5000, loss_test=0.6545, acc_test=0.7623
# poison_percent 40 epoch 80: loss_train=0.8741, acc_train=0.5000, loss_test=0.7159, acc_test=0.6532
# poison_percent 40 epoch 81: loss_train=0.9407, acc_train=0.4000, loss_test=0.6486, acc_test=0.7469
# poison_percent 40 epoch 82: loss_train=1.1120, acc_train=0.3000, loss_test=0.6702, acc_test=0.7267
# poison_percent 40 epoch 83: loss_train=0.7250, acc_train=0.8000, loss_test=0.6545, acc_test=0.7365
# poison_percent 40 epoch 84: loss_train=0.9063, acc_train=0.6000, loss_test=0.6980, acc_test=0.7016
# poison_percent 40 epoch 85: loss_train=0.9900, acc_train=0.7000, loss_test=0.6620, acc_test=0.7433
# poison_percent 40 epoch 86: loss_train=0.9537, acc_train=0.7000, loss_test=0.6553, acc_test=0.7316
# poison_percent 40 epoch 87: loss_train=1.0434, acc_train=0.6000, loss_test=0.6858, acc_test=0.7040
# poison_percent 40 epoch 88: loss_train=1.0984, acc_train=0.2000, loss_test=0.6916, acc_test=0.7194
# poison_percent 40 epoch 89: loss_train=1.0295, acc_train=0.2000, loss_test=0.6646, acc_test=0.7371
# poison_percent 40 epoch 90: loss_train=0.7915, acc_train=0.6000, loss_test=0.6460, acc_test=0.7384
# poison_percent 40 epoch 91: loss_train=0.6225, acc_train=0.6000, loss_test=0.6594, acc_test=0.7586
# poison_percent 40 epoch 92: loss_train=1.0025, acc_train=0.4000, loss_test=0.6402, acc_test=0.7475
# poison_percent 40 epoch 93: loss_train=0.6907, acc_train=0.7000, loss_test=0.7134, acc_test=0.6722
# poison_percent 40 epoch 94: loss_train=0.9786, acc_train=0.5000, loss_test=0.6736, acc_test=0.7230
# poison_percent 40 epoch 95: loss_train=1.0387, acc_train=0.4000, loss_test=0.7165, acc_test=0.6667
# poison_percent 40 epoch 96: loss_train=0.7238, acc_train=0.7000, loss_test=0.7101, acc_test=0.7040
# poison_percent 40 epoch 97: loss_train=1.0617, acc_train=0.5000, loss_test=0.6745, acc_test=0.7316
# poison_percent 40 epoch 98: loss_train=0.8766, acc_train=0.6000, loss_test=0.7040, acc_test=0.6869
# poison_percent 40 epoch 99: loss_train=1.1226, acc_train=0.6000, loss_test=0.6706, acc_test=0.7426
# Training log saved to ./results\CL_ModelN1L1_Batchsize32_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 epoch 0: loss_train=0.8871, acc_train=0.5000, loss_test=0.8720, acc_test=0.5055
# poison_percent 50 epoch 1: loss_train=1.0221, acc_train=0.5000, loss_test=0.8220, acc_test=0.5650
# poison_percent 50 epoch 2: loss_train=0.8953, acc_train=0.5357, loss_test=0.8931, acc_test=0.4890
# poison_percent 50 epoch 3: loss_train=0.7685, acc_train=0.6429, loss_test=0.8216, acc_test=0.5521
# poison_percent 50 epoch 4: loss_train=0.9634, acc_train=0.4286, loss_test=0.8036, acc_test=0.5625
# poison_percent 50 epoch 5: loss_train=1.1411, acc_train=0.3571, loss_test=0.8277, acc_test=0.5362
# poison_percent 50 epoch 6: loss_train=0.9041, acc_train=0.5714, loss_test=0.8606, acc_test=0.5221
# poison_percent 50 epoch 7: loss_train=0.9400, acc_train=0.4643, loss_test=0.8895, acc_test=0.4871
# poison_percent 50 epoch 8: loss_train=0.6285, acc_train=0.7500, loss_test=0.8575, acc_test=0.5116
# poison_percent 50 epoch 9: loss_train=0.9731, acc_train=0.4643, loss_test=0.7968, acc_test=0.5858
# poison_percent 50 epoch 10: loss_train=0.9002, acc_train=0.6071, loss_test=0.8932, acc_test=0.4828
# poison_percent 50 epoch 11: loss_train=1.1761, acc_train=0.3571, loss_test=0.8534, acc_test=0.5141
# poison_percent 50 epoch 12: loss_train=0.8476, acc_train=0.5357, loss_test=0.8405, acc_test=0.5484
# poison_percent 50 epoch 13: loss_train=0.8653, acc_train=0.4643, loss_test=0.8500, acc_test=0.5184
# poison_percent 50 epoch 14: loss_train=1.0768, acc_train=0.5000, loss_test=0.8737, acc_test=0.5000
# poison_percent 50 epoch 15: loss_train=0.9963, acc_train=0.3929, loss_test=0.8597, acc_test=0.5227
# poison_percent 50 epoch 16: loss_train=1.0525, acc_train=0.3929, loss_test=0.8909, acc_test=0.4798
# poison_percent 50 epoch 17: loss_train=0.9556, acc_train=0.4286, loss_test=0.8171, acc_test=0.5637
# poison_percent 50 epoch 18: loss_train=0.9792, acc_train=0.4286, loss_test=0.8231, acc_test=0.5521
# poison_percent 50 epoch 19: loss_train=0.9195, acc_train=0.5000, loss_test=0.8729, acc_test=0.4914
# poison_percent 50 epoch 20: loss_train=0.9308, acc_train=0.4286, loss_test=0.8835, acc_test=0.5025
# poison_percent 50 epoch 21: loss_train=0.9683, acc_train=0.5000, loss_test=0.8563, acc_test=0.5233
# poison_percent 50 epoch 22: loss_train=0.7926, acc_train=0.6786, loss_test=0.8408, acc_test=0.5355
# poison_percent 50 epoch 23: loss_train=0.9444, acc_train=0.4643, loss_test=0.7696, acc_test=0.6195
# poison_percent 50 epoch 24: loss_train=0.9670, acc_train=0.5357, loss_test=0.8663, acc_test=0.5184
# poison_percent 50 epoch 25: loss_train=0.6616, acc_train=0.7857, loss_test=0.8180, acc_test=0.5515
# poison_percent 50 epoch 26: loss_train=1.0951, acc_train=0.3929, loss_test=0.9209, acc_test=0.4730
# poison_percent 50 epoch 27: loss_train=0.9485, acc_train=0.6429, loss_test=0.8279, acc_test=0.5509
# poison_percent 50 epoch 28: loss_train=0.8816, acc_train=0.6429, loss_test=0.8476, acc_test=0.5453
# poison_percent 50 epoch 29: loss_train=1.1456, acc_train=0.2857, loss_test=0.8001, acc_test=0.5821
# poison_percent 50 epoch 30: loss_train=0.8351, acc_train=0.4643, loss_test=0.8466, acc_test=0.5129
# poison_percent 50 epoch 31: loss_train=0.8402, acc_train=0.5714, loss_test=0.8521, acc_test=0.5129
# poison_percent 50 epoch 32: loss_train=1.0251, acc_train=0.4286, loss_test=0.8321, acc_test=0.5478
# poison_percent 50 epoch 33: loss_train=0.8243, acc_train=0.5714, loss_test=0.8883, acc_test=0.4877
# poison_percent 50 epoch 34: loss_train=0.8145, acc_train=0.6071, loss_test=0.8491, acc_test=0.5564
# poison_percent 50 epoch 35: loss_train=0.9239, acc_train=0.4286, loss_test=0.8618, acc_test=0.5116
# poison_percent 50 epoch 36: loss_train=1.1274, acc_train=0.3214, loss_test=0.8950, acc_test=0.4749
# poison_percent 50 epoch 37: loss_train=0.8828, acc_train=0.6071, loss_test=0.8596, acc_test=0.5294
# poison_percent 50 epoch 38: loss_train=1.0021, acc_train=0.4286, loss_test=0.8439, acc_test=0.5172
# poison_percent 50 epoch 39: loss_train=0.7722, acc_train=0.6071, loss_test=0.8504, acc_test=0.5165
# poison_percent 50 epoch 40: loss_train=0.6809, acc_train=0.5357, loss_test=0.8202, acc_test=0.5637
# poison_percent 50 epoch 41: loss_train=0.8175, acc_train=0.5714, loss_test=0.8463, acc_test=0.5625
# poison_percent 50 epoch 42: loss_train=0.8881, acc_train=0.6071, loss_test=0.8241, acc_test=0.5343
# poison_percent 50 epoch 43: loss_train=1.0448, acc_train=0.5000, loss_test=0.8461, acc_test=0.5239
# poison_percent 50 epoch 44: loss_train=0.7566, acc_train=0.6786, loss_test=0.8493, acc_test=0.5447
# poison_percent 50 epoch 45: loss_train=0.8468, acc_train=0.5357, loss_test=0.8633, acc_test=0.4994
# poison_percent 50 epoch 46: loss_train=0.8227, acc_train=0.5000, loss_test=0.8375, acc_test=0.5411
# poison_percent 50 epoch 47: loss_train=1.0322, acc_train=0.5000, loss_test=0.8458, acc_test=0.5172
# poison_percent 50 epoch 48: loss_train=1.1603, acc_train=0.5000, loss_test=0.8782, acc_test=0.4884
# poison_percent 50 epoch 49: loss_train=1.1267, acc_train=0.6071, loss_test=0.8776, acc_test=0.4835
# poison_percent 50 epoch 50: loss_train=1.0710, acc_train=0.5000, loss_test=0.8155, acc_test=0.5692
# poison_percent 50 epoch 51: loss_train=0.8569, acc_train=0.5000, loss_test=0.8787, acc_test=0.4920
# poison_percent 50 epoch 52: loss_train=0.8908, acc_train=0.6429, loss_test=0.8669, acc_test=0.5049
# poison_percent 50 epoch 53: loss_train=1.1239, acc_train=0.3929, loss_test=0.8018, acc_test=0.5815
# poison_percent 50 epoch 54: loss_train=0.7583, acc_train=0.6786, loss_test=0.8959, acc_test=0.4779
# poison_percent 50 epoch 55: loss_train=0.9571, acc_train=0.5000, loss_test=0.8742, acc_test=0.5031
# poison_percent 50 epoch 56: loss_train=0.8266, acc_train=0.6071, loss_test=0.8498, acc_test=0.5600
# poison_percent 50 epoch 57: loss_train=0.8218, acc_train=0.6429, loss_test=0.8421, acc_test=0.5245
# poison_percent 50 epoch 58: loss_train=0.9305, acc_train=0.4643, loss_test=0.8503, acc_test=0.5184
# poison_percent 50 epoch 59: loss_train=1.0797, acc_train=0.3571, loss_test=0.8312, acc_test=0.5343
# poison_percent 50 epoch 60: loss_train=0.8978, acc_train=0.6429, loss_test=0.8933, acc_test=0.4841
# poison_percent 50 epoch 61: loss_train=0.7788, acc_train=0.6071, loss_test=0.8141, acc_test=0.5600
# poison_percent 50 epoch 62: loss_train=1.1893, acc_train=0.3929, loss_test=0.8665, acc_test=0.5043
# poison_percent 50 epoch 63: loss_train=1.0236, acc_train=0.4286, loss_test=0.8788, acc_test=0.5006
# poison_percent 50 epoch 64: loss_train=0.8106, acc_train=0.7143, loss_test=0.8695, acc_test=0.5055
# poison_percent 50 epoch 65: loss_train=1.0905, acc_train=0.4643, loss_test=0.8911, acc_test=0.4859
# poison_percent 50 epoch 66: loss_train=0.9234, acc_train=0.5357, loss_test=0.8777, acc_test=0.4963
# poison_percent 50 epoch 67: loss_train=0.9365, acc_train=0.6786, loss_test=0.8914, acc_test=0.4877
# poison_percent 50 epoch 68: loss_train=0.9410, acc_train=0.5714, loss_test=0.8529, acc_test=0.5190
# poison_percent 50 epoch 69: loss_train=0.9025, acc_train=0.6429, loss_test=0.8762, acc_test=0.5080
# poison_percent 50 epoch 70: loss_train=0.9302, acc_train=0.5357, loss_test=0.8494, acc_test=0.5110
# poison_percent 50 epoch 71: loss_train=0.8454, acc_train=0.5714, loss_test=0.9033, acc_test=0.4669
# poison_percent 50 epoch 72: loss_train=1.0491, acc_train=0.4643, loss_test=0.8557, acc_test=0.5178
# poison_percent 50 epoch 73: loss_train=0.9244, acc_train=0.5357, loss_test=0.8668, acc_test=0.5031
# poison_percent 50 epoch 74: loss_train=0.8336, acc_train=0.5714, loss_test=0.8521, acc_test=0.5276
# poison_percent 50 epoch 75: loss_train=0.8150, acc_train=0.6071, loss_test=0.8225, acc_test=0.5754
# poison_percent 50 epoch 76: loss_train=0.8652, acc_train=0.6071, loss_test=0.8274, acc_test=0.5386
# poison_percent 50 epoch 77: loss_train=0.9294, acc_train=0.5714, loss_test=0.8891, acc_test=0.5043
# poison_percent 50 epoch 78: loss_train=0.9183, acc_train=0.5000, loss_test=0.8576, acc_test=0.5147
# poison_percent 50 epoch 79: loss_train=0.9457, acc_train=0.3929, loss_test=0.8325, acc_test=0.5509
# poison_percent 50 epoch 80: loss_train=1.0257, acc_train=0.5000, loss_test=0.8322, acc_test=0.5582
# poison_percent 50 epoch 81: loss_train=0.7370, acc_train=0.6786, loss_test=0.8514, acc_test=0.5159
# poison_percent 50 epoch 82: loss_train=1.2777, acc_train=0.3214, loss_test=0.8515, acc_test=0.5208
# poison_percent 50 epoch 83: loss_train=0.8511, acc_train=0.4643, loss_test=0.8721, acc_test=0.5386
# poison_percent 50 epoch 84: loss_train=1.0436, acc_train=0.3929, loss_test=0.9426, acc_test=0.4700
# poison_percent 50 epoch 85: loss_train=1.0989, acc_train=0.4643, loss_test=0.8580, acc_test=0.5227
# poison_percent 50 epoch 86: loss_train=0.9678, acc_train=0.3929, loss_test=0.9003, acc_test=0.4749
# poison_percent 50 epoch 87: loss_train=0.7455, acc_train=0.6429, loss_test=0.8600, acc_test=0.4951
# poison_percent 50 epoch 88: loss_train=0.8154, acc_train=0.4643, loss_test=0.8899, acc_test=0.4884
# poison_percent 50 epoch 89: loss_train=0.9133, acc_train=0.5714, loss_test=0.8602, acc_test=0.5141
# poison_percent 50 epoch 90: loss_train=0.7630, acc_train=0.6071, loss_test=0.8973, acc_test=0.4718
# poison_percent 50 epoch 91: loss_train=0.7765, acc_train=0.7143, loss_test=0.8384, acc_test=0.5411
# poison_percent 50 epoch 92: loss_train=0.9759, acc_train=0.4643, loss_test=0.8870, acc_test=0.4884
# poison_percent 50 epoch 93: loss_train=0.9138, acc_train=0.5357, loss_test=0.8501, acc_test=0.5172
# poison_percent 50 epoch 94: loss_train=1.0447, acc_train=0.5357, loss_test=0.8227, acc_test=0.5411
# poison_percent 50 epoch 95: loss_train=0.8856, acc_train=0.5000, loss_test=0.8871, acc_test=0.4957
# poison_percent 50 epoch 96: loss_train=1.0284, acc_train=0.5357, loss_test=0.9023, acc_test=0.4773
# poison_percent 50 epoch 97: loss_train=1.0437, acc_train=0.4286, loss_test=0.8681, acc_test=0.4988
# poison_percent 50 epoch 98: loss_train=0.8871, acc_train=0.4643, loss_test=0.8183, acc_test=0.5423
# poison_percent 50 epoch 99: loss_train=1.0657, acc_train=0.5714, loss_test=0.8603, acc_test=0.5123
# Training log saved to ./results\CL_ModelN1L1_Batchsize32_rev2\poisoned_50percent\poisoned_50percent.csv
