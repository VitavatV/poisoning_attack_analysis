# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x
    
# save state_dict + metadata (safe, portable)
def save_model(model, img_size, n_classes, learning_rate, experiment_bs, file_path):

    state = {
        "model_state_dict": model.state_dict(),                     # CPU/GPU tensors okay
        "arch": "MNISTNet",
        "img_size": img_size,
        "num_classes": n_classes,
        "training_args": {"lr": learning_rate, "batch_size": experiment_bs}
    }
    # ensure weights are on CPU to avoid GPU-only pickle issues
    state["model_state_dict"] = {k: v.cpu() for k, v in state["model_state_dict"].items()}
    torch.save(state, file_path)
    
def load_model(file_path, device):

    checkpoint = torch.load(file_path, map_location=device)
    model = MNISTNet().to(device)              # must have MNISTNet class defined/importable
    model.load_state_dict(checkpoint["model_state_dict"])
    model.eval()
    return model

# %% [markdown]
# # 4.Loss

# %%
# def binary_cross_entropy(pred, target):
#     eps = 1e-7
#     pred = torch.clamp(pred, eps, 1 - eps)
#     return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

def multiclass_cross_entropy(logits, target, from_probs=False, eps=1e-7):
    """
    Cross-entropy loss for multiclass (e.g., 10 classes).
    - logits: Tensor shape (N, C) containing raw scores (preferred) or probabilities if from_probs=True
    - target: Tensor shape (N,) or (N,1) containing class indices (0..C-1)
    """
    if logits.dim() == 1:
        logits = logits.unsqueeze(0)
    target = target.squeeze()
    if target.dtype != torch.long:
        target = target.long()
    if from_probs:
        probs = torch.clamp(logits, eps, 1.0 - eps)
        log_probs = torch.log(probs)
        return -log_probs[torch.arange(target.size(0)), target].mean()
    return nn.functional.cross_entropy(logits, target)

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE =32
N_CLASSES = 10

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_multiple_poison/train"
TEST_PATH = "../data/mnist_multiple_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
for NODE in [1,2,4,8,16,32]:
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            self.conv1 = nn.Conv2d(1, NODE, kernel_size=3, padding=1) # 28x28
            self.pool = nn.MaxPool2d(2, 2) # 14x14
            self.fc1 = nn.Linear(NODE * 14 * 14, N_CLASSES)
            self.relu = nn.ReLU()
            
        def forward(self, x):
            x = x.view(-1, 1, 28, 28)
            x = self.pool(self.relu(self.conv1(x)))
            x = x.view(x.size(0), -1)
            x = self.fc1(x)
            # x = torch.sigmoid(x)
            return x

    BATCH_SIZE_list = [32]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"CL_ModelN{NODE}L2_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                        poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                        select='Honest+Poisoned')
                X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
                # print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
                # print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")

                X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
                y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                # torch.save(model, os.path.join(save_path,'model_init.pt'))
                save_path_name = os.path.join(save_path,'model_init.pt')
                save_model(model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)
                
                optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

                records = []

                # Training loop
                for epoch in range(EPOCHS):

                    # Train
                    model.train()
                    
                    #randomize the training data
                    perm = torch.randperm(X_train_tensor.size(0))
                    X_train_tensor = X_train_tensor[perm]
                    y_train_tensor = y_train_tensor[perm]

                    for start in range(0, X_train_tensor.size(0), experiment_bs):
                        end = start + experiment_bs
                        xb = X_train_tensor[start:end]
                        yb = y_train_tensor[start:end]
                        outputs = model(xb)
                        # preds = (outputs >= 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        acc_train = (preds == yb).float().mean().item()
                        loss_train = multiclass_cross_entropy(outputs, yb)
                        optimizer.zero_grad()
                        loss_train.backward()
                        optimizer.step()

                    # Evaluate
                    model.eval()
                    with torch.no_grad():
                        outputs = model(X_test_tensor)
                        # preds = (outputs >= 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        loss_test = multiclass_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"epoch {epoch}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                # torch.save(model, os.path.join(save_path,'model_last.pt'))
                save_path_name = os.path.join(save_path,'model_last.pt')
                save_model(model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['epoch'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['epoch'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 epoch 0: loss_train=0.0365, acc_train=1.0000, loss_test=0.0661, acc_test=0.9949
# poison_percent 0 epoch 1: loss_train=0.0305, acc_train=1.0000, loss_test=0.0200, acc_test=0.9964
# poison_percent 0 epoch 2: loss_train=0.0101, acc_train=1.0000, loss_test=0.0118, acc_test=0.9969
# poison_percent 0 epoch 3: loss_train=0.0025, acc_train=1.0000, loss_test=0.0085, acc_test=0.9964
# poison_percent 0 epoch 4: loss_train=0.0106, acc_train=1.0000, loss_test=0.0069, acc_test=0.9974
# poison_percent 0 epoch 5: loss_train=0.0117, acc_train=1.0000, loss_test=0.0060, acc_test=0.9974
# poison_percent 0 epoch 6: loss_train=0.0015, acc_train=1.0000, loss_test=0.0052, acc_test=0.9980
# poison_percent 0 epoch 7: loss_train=0.0003, acc_train=1.0000, loss_test=0.0047, acc_test=0.9980
# poison_percent 0 epoch 8: loss_train=0.0002, acc_train=1.0000, loss_test=0.0043, acc_test=0.9995
# poison_percent 0 epoch 9: loss_train=0.0004, acc_train=1.0000, loss_test=0.0040, acc_test=0.9990
# poison_percent 0 epoch 10: loss_train=0.0082, acc_train=1.0000, loss_test=0.0038, acc_test=0.9995
# poison_percent 0 epoch 11: loss_train=0.0002, acc_train=1.0000, loss_test=0.0035, acc_test=0.9995
# poison_percent 0 epoch 12: loss_train=0.0002, acc_train=1.0000, loss_test=0.0034, acc_test=0.9995
# poison_percent 0 epoch 13: loss_train=0.0003, acc_train=1.0000, loss_test=0.0033, acc_test=0.9995
# poison_percent 0 epoch 14: loss_train=0.0002, acc_train=1.0000, loss_test=0.0032, acc_test=0.9995
# poison_percent 0 epoch 15: loss_train=0.0021, acc_train=1.0000, loss_test=0.0037, acc_test=0.9985
# poison_percent 0 epoch 16: loss_train=0.0001, acc_train=1.0000, loss_test=0.0035, acc_test=0.9985
# poison_percent 0 epoch 17: loss_train=0.1565, acc_train=0.8750, loss_test=0.0030, acc_test=0.9995
# poison_percent 0 epoch 18: loss_train=0.0000, acc_train=1.0000, loss_test=0.0030, acc_test=0.9990
# poison_percent 0 epoch 19: loss_train=0.0001, acc_train=1.0000, loss_test=0.0032, acc_test=0.9990
# poison_percent 0 epoch 20: loss_train=0.0001, acc_train=1.0000, loss_test=0.0028, acc_test=0.9995
# poison_percent 0 epoch 21: loss_train=0.0001, acc_train=1.0000, loss_test=0.0032, acc_test=0.9985
# poison_percent 0 epoch 22: loss_train=0.0000, acc_train=1.0000, loss_test=0.0030, acc_test=0.9990
# poison_percent 0 epoch 23: loss_train=0.0000, acc_train=1.0000, loss_test=0.0027, acc_test=0.9995
# poison_percent 0 epoch 24: loss_train=0.0001, acc_train=1.0000, loss_test=0.0029, acc_test=0.9990
# poison_percent 0 epoch 25: loss_train=0.0001, acc_train=1.0000, loss_test=0.0027, acc_test=0.9995
# poison_percent 0 epoch 26: loss_train=0.0000, acc_train=1.0000, loss_test=0.0037, acc_test=0.9985
# poison_percent 0 epoch 27: loss_train=0.0000, acc_train=1.0000, loss_test=0.0031, acc_test=0.9985
# poison_percent 0 epoch 28: loss_train=0.0000, acc_train=1.0000, loss_test=0.0033, acc_test=0.9985
# poison_percent 0 epoch 29: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9985
# poison_percent 0 epoch 30: loss_train=0.0001, acc_train=1.0000, loss_test=0.0031, acc_test=0.9985
# poison_percent 0 epoch 31: loss_train=0.0000, acc_train=1.0000, loss_test=0.0033, acc_test=0.9985
# poison_percent 0 epoch 32: loss_train=0.0001, acc_train=1.0000, loss_test=0.0025, acc_test=0.9990
# poison_percent 0 epoch 33: loss_train=0.0001, acc_train=1.0000, loss_test=0.0029, acc_test=0.9995
# poison_percent 0 epoch 34: loss_train=0.0000, acc_train=1.0000, loss_test=0.0027, acc_test=0.9995
# poison_percent 0 epoch 35: loss_train=0.0004, acc_train=1.0000, loss_test=0.0032, acc_test=0.9985
# poison_percent 0 epoch 36: loss_train=0.0000, acc_train=1.0000, loss_test=0.0033, acc_test=0.9985
# poison_percent 0 epoch 37: loss_train=0.0003, acc_train=1.0000, loss_test=0.0027, acc_test=0.9995
# poison_percent 0 epoch 38: loss_train=0.0000, acc_train=1.0000, loss_test=0.0036, acc_test=0.9985
# poison_percent 0 epoch 39: loss_train=0.0001, acc_train=1.0000, loss_test=0.0034, acc_test=0.9990
# poison_percent 0 epoch 40: loss_train=0.0000, acc_train=1.0000, loss_test=0.0049, acc_test=0.9980
# poison_percent 0 epoch 41: loss_train=0.0002, acc_train=1.0000, loss_test=0.0025, acc_test=0.9990
# poison_percent 0 epoch 42: loss_train=0.0000, acc_train=1.0000, loss_test=0.0027, acc_test=0.9995
# poison_percent 0 epoch 43: loss_train=0.0000, acc_train=1.0000, loss_test=0.0032, acc_test=0.9990
# poison_percent 0 epoch 44: loss_train=0.0088, acc_train=1.0000, loss_test=0.0033, acc_test=0.9990
# poison_percent 0 epoch 45: loss_train=0.0000, acc_train=1.0000, loss_test=0.0025, acc_test=0.9995
# poison_percent 0 epoch 46: loss_train=0.0001, acc_train=1.0000, loss_test=0.0026, acc_test=0.9995
# poison_percent 0 epoch 47: loss_train=0.0000, acc_train=1.0000, loss_test=0.0029, acc_test=0.9995
# poison_percent 0 epoch 48: loss_train=0.0000, acc_train=1.0000, loss_test=0.0025, acc_test=0.9995
# poison_percent 0 epoch 49: loss_train=0.0001, acc_train=1.0000, loss_test=0.0031, acc_test=0.9990
# poison_percent 0 epoch 50: loss_train=0.0000, acc_train=1.0000, loss_test=0.0029, acc_test=0.9995
# poison_percent 0 epoch 51: loss_train=0.0000, acc_train=1.0000, loss_test=0.0027, acc_test=0.9990
# poison_percent 0 epoch 52: loss_train=0.0000, acc_train=1.0000, loss_test=0.0027, acc_test=0.9995
# poison_percent 0 epoch 53: loss_train=0.0000, acc_train=1.0000, loss_test=0.0041, acc_test=0.9985
# poison_percent 0 epoch 54: loss_train=0.0000, acc_train=1.0000, loss_test=0.0039, acc_test=0.9990
# poison_percent 0 epoch 55: loss_train=0.0000, acc_train=1.0000, loss_test=0.0043, acc_test=0.9985
# poison_percent 0 epoch 56: loss_train=0.0000, acc_train=1.0000, loss_test=0.0035, acc_test=0.9990
# poison_percent 0 epoch 57: loss_train=0.0000, acc_train=1.0000, loss_test=0.0034, acc_test=0.9990
# poison_percent 0 epoch 58: loss_train=0.0000, acc_train=1.0000, loss_test=0.0033, acc_test=0.9990
# poison_percent 0 epoch 59: loss_train=0.0000, acc_train=1.0000, loss_test=0.0048, acc_test=0.9985
# poison_percent 0 epoch 60: loss_train=0.0000, acc_train=1.0000, loss_test=0.0030, acc_test=0.9995
# poison_percent 0 epoch 61: loss_train=0.0000, acc_train=1.0000, loss_test=0.0038, acc_test=0.9990
# poison_percent 0 epoch 62: loss_train=0.0000, acc_train=1.0000, loss_test=0.0042, acc_test=0.9985
# poison_percent 0 epoch 63: loss_train=0.0000, acc_train=1.0000, loss_test=0.0031, acc_test=0.9995
# poison_percent 0 epoch 64: loss_train=0.0000, acc_train=1.0000, loss_test=0.0031, acc_test=0.9995
# poison_percent 0 epoch 65: loss_train=0.0000, acc_train=1.0000, loss_test=0.0030, acc_test=0.9995
# poison_percent 0 epoch 66: loss_train=0.0000, acc_train=1.0000, loss_test=0.0030, acc_test=0.9995
# poison_percent 0 epoch 67: loss_train=0.0000, acc_train=1.0000, loss_test=0.0032, acc_test=0.9995
# poison_percent 0 epoch 68: loss_train=0.0000, acc_train=1.0000, loss_test=0.0030, acc_test=0.9985
# poison_percent 0 epoch 69: loss_train=0.0000, acc_train=1.0000, loss_test=0.0030, acc_test=0.9990
# poison_percent 0 epoch 70: loss_train=0.0000, acc_train=1.0000, loss_test=0.0030, acc_test=0.9990
# poison_percent 0 epoch 71: loss_train=0.0000, acc_train=1.0000, loss_test=0.0032, acc_test=0.9995
# poison_percent 0 epoch 72: loss_train=0.0002, acc_train=1.0000, loss_test=0.0035, acc_test=0.9995
# poison_percent 0 epoch 73: loss_train=0.0000, acc_train=1.0000, loss_test=0.0032, acc_test=0.9995
# poison_percent 0 epoch 74: loss_train=0.0000, acc_train=1.0000, loss_test=0.0033, acc_test=0.9995
# poison_percent 0 epoch 75: loss_train=0.0000, acc_train=1.0000, loss_test=0.0032, acc_test=0.9990
# poison_percent 0 epoch 76: loss_train=0.0000, acc_train=1.0000, loss_test=0.0034, acc_test=0.9995
# poison_percent 0 epoch 77: loss_train=0.0000, acc_train=1.0000, loss_test=0.0033, acc_test=0.9995
# poison_percent 0 epoch 78: loss_train=0.0000, acc_train=1.0000, loss_test=0.0032, acc_test=0.9985
# poison_percent 0 epoch 79: loss_train=0.0000, acc_train=1.0000, loss_test=0.0036, acc_test=0.9995
# poison_percent 0 epoch 80: loss_train=0.0001, acc_train=1.0000, loss_test=0.0039, acc_test=0.9990
# poison_percent 0 epoch 81: loss_train=0.0000, acc_train=1.0000, loss_test=0.0038, acc_test=0.9995
# poison_percent 0 epoch 82: loss_train=0.0002, acc_train=1.0000, loss_test=0.0031, acc_test=0.9990
# poison_percent 0 epoch 83: loss_train=0.0000, acc_train=1.0000, loss_test=0.0033, acc_test=0.9995
# poison_percent 0 epoch 84: loss_train=0.0005, acc_train=1.0000, loss_test=0.0031, acc_test=0.9990
# poison_percent 0 epoch 85: loss_train=0.0000, acc_train=1.0000, loss_test=0.0033, acc_test=0.9990
# poison_percent 0 epoch 86: loss_train=0.0000, acc_train=1.0000, loss_test=0.0036, acc_test=0.9995
# poison_percent 0 epoch 87: loss_train=0.0000, acc_train=1.0000, loss_test=0.0032, acc_test=0.9985
# poison_percent 0 epoch 88: loss_train=0.0000, acc_train=1.0000, loss_test=0.0032, acc_test=0.9985
# poison_percent 0 epoch 89: loss_train=0.0000, acc_train=1.0000, loss_test=0.0044, acc_test=0.9990
# poison_percent 0 epoch 90: loss_train=0.0000, acc_train=1.0000, loss_test=0.0033, acc_test=0.9985
# poison_percent 0 epoch 91: loss_train=0.0000, acc_train=1.0000, loss_test=0.0036, acc_test=0.9990
# poison_percent 0 epoch 92: loss_train=0.0000, acc_train=1.0000, loss_test=0.0035, acc_test=0.9990
# poison_percent 0 epoch 93: loss_train=0.0000, acc_train=1.0000, loss_test=0.0038, acc_test=0.9995
# poison_percent 0 epoch 94: loss_train=0.0000, acc_train=1.0000, loss_test=0.0036, acc_test=0.9995
# poison_percent 0 epoch 95: loss_train=0.0000, acc_train=1.0000, loss_test=0.0033, acc_test=0.9990
# poison_percent 0 epoch 96: loss_train=0.0000, acc_train=1.0000, loss_test=0.0032, acc_test=0.9990
# poison_percent 0 epoch 97: loss_train=0.0000, acc_train=1.0000, loss_test=0.0033, acc_test=0.9990
# poison_percent 0 epoch 98: loss_train=0.0000, acc_train=1.0000, loss_test=0.0033, acc_test=0.9990
# poison_percent 0 epoch 99: loss_train=0.0000, acc_train=1.0000, loss_test=0.0035, acc_test=0.9990
# Training log saved to ./results\CL_ModelN1L2_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 epoch 0: loss_train=1.0350, acc_train=0.9062, loss_test=0.1026, acc_test=0.9709
# poison_percent 10 epoch 1: loss_train=1.1717, acc_train=0.8750, loss_test=0.0661, acc_test=0.9760
# poison_percent 10 epoch 2: loss_train=0.4842, acc_train=0.8438, loss_test=0.1568, acc_test=0.9408
# poison_percent 10 epoch 3: loss_train=0.7152, acc_train=0.7812, loss_test=0.1328, acc_test=0.9628
# poison_percent 10 epoch 4: loss_train=0.3672, acc_train=0.8750, loss_test=0.1262, acc_test=0.9765
# poison_percent 10 epoch 5: loss_train=0.3327, acc_train=0.9062, loss_test=0.1371, acc_test=0.9776
# poison_percent 10 epoch 6: loss_train=0.6014, acc_train=0.8125, loss_test=0.1329, acc_test=0.9923
# poison_percent 10 epoch 7: loss_train=0.2742, acc_train=0.9375, loss_test=0.1350, acc_test=0.9903
# poison_percent 10 epoch 8: loss_train=0.5214, acc_train=0.8125, loss_test=0.1316, acc_test=0.9969
# poison_percent 10 epoch 9: loss_train=0.1800, acc_train=0.9688, loss_test=0.1461, acc_test=0.9918
# poison_percent 10 epoch 10: loss_train=0.2727, acc_train=0.9375, loss_test=0.1358, acc_test=0.9974
# poison_percent 10 epoch 11: loss_train=0.3843, acc_train=0.9062, loss_test=0.1377, acc_test=0.9990
# poison_percent 10 epoch 12: loss_train=0.3187, acc_train=0.9062, loss_test=0.1281, acc_test=0.9990
# poison_percent 10 epoch 13: loss_train=0.1397, acc_train=1.0000, loss_test=0.1222, acc_test=0.9990
# poison_percent 10 epoch 14: loss_train=0.3928, acc_train=0.8750, loss_test=0.1295, acc_test=0.9990
# poison_percent 10 epoch 15: loss_train=0.8017, acc_train=0.7188, loss_test=0.1225, acc_test=0.9990
# poison_percent 10 epoch 16: loss_train=0.3366, acc_train=0.9062, loss_test=0.1197, acc_test=0.9990
# poison_percent 10 epoch 17: loss_train=0.2053, acc_train=0.9688, loss_test=0.1274, acc_test=0.9990
# poison_percent 10 epoch 18: loss_train=0.3225, acc_train=0.9375, loss_test=0.1222, acc_test=0.9990
# poison_percent 10 epoch 19: loss_train=0.3611, acc_train=0.8750, loss_test=0.1201, acc_test=0.9990
# poison_percent 10 epoch 20: loss_train=0.4380, acc_train=0.8438, loss_test=0.1311, acc_test=0.9990
# poison_percent 10 epoch 21: loss_train=0.4817, acc_train=0.8438, loss_test=0.1313, acc_test=0.9990
# poison_percent 10 epoch 22: loss_train=0.5892, acc_train=0.7812, loss_test=0.1133, acc_test=0.9990
# poison_percent 10 epoch 23: loss_train=0.2362, acc_train=0.9375, loss_test=0.1246, acc_test=0.9990
# poison_percent 10 epoch 24: loss_train=0.2272, acc_train=0.9375, loss_test=0.1195, acc_test=0.9990
# poison_percent 10 epoch 25: loss_train=0.2786, acc_train=0.9375, loss_test=0.1339, acc_test=0.9990
# poison_percent 10 epoch 26: loss_train=0.4728, acc_train=0.8438, loss_test=0.1339, acc_test=0.9985
# poison_percent 10 epoch 27: loss_train=0.2454, acc_train=0.9375, loss_test=0.1145, acc_test=0.9990
# poison_percent 10 epoch 28: loss_train=0.4259, acc_train=0.8438, loss_test=0.1234, acc_test=0.9990
# poison_percent 10 epoch 29: loss_train=0.2662, acc_train=0.9375, loss_test=0.1183, acc_test=0.9990
# poison_percent 10 epoch 30: loss_train=0.2518, acc_train=0.9375, loss_test=0.1298, acc_test=0.9990
# poison_percent 10 epoch 31: loss_train=0.3082, acc_train=0.9062, loss_test=0.1201, acc_test=0.9990
# poison_percent 10 epoch 32: loss_train=0.3388, acc_train=0.9062, loss_test=0.1236, acc_test=0.9990
# poison_percent 10 epoch 33: loss_train=0.2123, acc_train=0.9688, loss_test=0.1369, acc_test=0.9990
# poison_percent 10 epoch 34: loss_train=0.1785, acc_train=0.9688, loss_test=0.1227, acc_test=0.9990
# poison_percent 10 epoch 35: loss_train=0.3228, acc_train=0.9062, loss_test=0.1225, acc_test=0.9985
# poison_percent 10 epoch 36: loss_train=0.3272, acc_train=0.9062, loss_test=0.1109, acc_test=0.9990
# poison_percent 10 epoch 37: loss_train=0.3158, acc_train=0.8750, loss_test=0.1267, acc_test=0.9990
# poison_percent 10 epoch 38: loss_train=0.3901, acc_train=0.8750, loss_test=0.1232, acc_test=0.9995
# poison_percent 10 epoch 39: loss_train=0.3779, acc_train=0.8750, loss_test=0.1229, acc_test=0.9990
# poison_percent 10 epoch 40: loss_train=0.2276, acc_train=0.9375, loss_test=0.1162, acc_test=0.9990
# poison_percent 10 epoch 41: loss_train=0.2106, acc_train=0.9688, loss_test=0.1074, acc_test=0.9995
# poison_percent 10 epoch 42: loss_train=0.4787, acc_train=0.7812, loss_test=0.1361, acc_test=0.9985
# poison_percent 10 epoch 43: loss_train=0.4207, acc_train=0.8750, loss_test=0.1059, acc_test=0.9995
# poison_percent 10 epoch 44: loss_train=0.7255, acc_train=0.7500, loss_test=0.1238, acc_test=0.9990
# poison_percent 10 epoch 45: loss_train=0.1270, acc_train=1.0000, loss_test=0.1137, acc_test=0.9995
# poison_percent 10 epoch 46: loss_train=0.3056, acc_train=0.9062, loss_test=0.1246, acc_test=0.9995
# poison_percent 10 epoch 47: loss_train=0.3087, acc_train=0.9062, loss_test=0.1161, acc_test=0.9995
# poison_percent 10 epoch 48: loss_train=0.5787, acc_train=0.8125, loss_test=0.1158, acc_test=0.9995
# poison_percent 10 epoch 49: loss_train=0.3943, acc_train=0.8750, loss_test=0.1110, acc_test=0.9995
# poison_percent 10 epoch 50: loss_train=0.1998, acc_train=0.9375, loss_test=0.1212, acc_test=0.9995
# poison_percent 10 epoch 51: loss_train=0.5122, acc_train=0.8125, loss_test=0.1225, acc_test=0.9985
# poison_percent 10 epoch 52: loss_train=0.2570, acc_train=0.9375, loss_test=0.1309, acc_test=0.9985
# poison_percent 10 epoch 53: loss_train=0.1989, acc_train=0.9688, loss_test=0.1229, acc_test=0.9995
# poison_percent 10 epoch 54: loss_train=0.3651, acc_train=0.8438, loss_test=0.1164, acc_test=0.9995
# poison_percent 10 epoch 55: loss_train=0.2997, acc_train=0.9062, loss_test=0.1182, acc_test=0.9995
# poison_percent 10 epoch 56: loss_train=0.7158, acc_train=0.7188, loss_test=0.1179, acc_test=0.9990
# poison_percent 10 epoch 57: loss_train=0.3990, acc_train=0.8750, loss_test=0.1184, acc_test=0.9995
# poison_percent 10 epoch 58: loss_train=0.4835, acc_train=0.8125, loss_test=0.1350, acc_test=0.9985
# poison_percent 10 epoch 59: loss_train=0.3795, acc_train=0.8750, loss_test=0.1180, acc_test=0.9990
# poison_percent 10 epoch 60: loss_train=0.5598, acc_train=0.7812, loss_test=0.1337, acc_test=0.9995
# poison_percent 10 epoch 61: loss_train=0.2310, acc_train=0.9375, loss_test=0.1247, acc_test=0.9990
# poison_percent 10 epoch 62: loss_train=0.4125, acc_train=0.8750, loss_test=0.1264, acc_test=0.9985
# poison_percent 10 epoch 63: loss_train=0.1810, acc_train=0.9688, loss_test=0.1239, acc_test=0.9990
# poison_percent 10 epoch 64: loss_train=0.3869, acc_train=0.8438, loss_test=0.1217, acc_test=0.9990
# poison_percent 10 epoch 65: loss_train=0.4922, acc_train=0.8438, loss_test=0.1314, acc_test=0.9990
# poison_percent 10 epoch 66: loss_train=0.5622, acc_train=0.8125, loss_test=0.1172, acc_test=0.9990
# poison_percent 10 epoch 67: loss_train=0.4096, acc_train=0.8750, loss_test=0.1175, acc_test=0.9990
# poison_percent 10 epoch 68: loss_train=0.2541, acc_train=0.9375, loss_test=0.1142, acc_test=0.9990
# poison_percent 10 epoch 69: loss_train=0.4141, acc_train=0.8438, loss_test=0.1290, acc_test=0.9990
# poison_percent 10 epoch 70: loss_train=0.2881, acc_train=0.8750, loss_test=0.1168, acc_test=0.9990
# poison_percent 10 epoch 71: loss_train=0.3161, acc_train=0.8750, loss_test=0.1220, acc_test=0.9990
# poison_percent 10 epoch 72: loss_train=0.3525, acc_train=0.9062, loss_test=0.1213, acc_test=0.9990
# poison_percent 10 epoch 73: loss_train=0.3130, acc_train=0.9062, loss_test=0.1228, acc_test=0.9990
# poison_percent 10 epoch 74: loss_train=0.3095, acc_train=0.9062, loss_test=0.1227, acc_test=0.9990
# poison_percent 10 epoch 75: loss_train=0.2448, acc_train=0.9375, loss_test=0.1137, acc_test=0.9990
# poison_percent 10 epoch 76: loss_train=0.3543, acc_train=0.8750, loss_test=0.1160, acc_test=0.9990
# poison_percent 10 epoch 77: loss_train=0.2521, acc_train=0.9375, loss_test=0.1195, acc_test=0.9990
# poison_percent 10 epoch 78: loss_train=0.4197, acc_train=0.8438, loss_test=0.1178, acc_test=0.9990
# poison_percent 10 epoch 79: loss_train=0.3145, acc_train=0.8750, loss_test=0.1318, acc_test=0.9990
# poison_percent 10 epoch 80: loss_train=0.3827, acc_train=0.8750, loss_test=0.1199, acc_test=0.9990
# poison_percent 10 epoch 81: loss_train=0.4596, acc_train=0.8438, loss_test=0.1195, acc_test=0.9990
# poison_percent 10 epoch 82: loss_train=0.1876, acc_train=0.9688, loss_test=0.1263, acc_test=0.9990
# poison_percent 10 epoch 83: loss_train=0.4034, acc_train=0.8438, loss_test=0.1254, acc_test=0.9990
# poison_percent 10 epoch 84: loss_train=0.4935, acc_train=0.8125, loss_test=0.1163, acc_test=0.9990
# poison_percent 10 epoch 85: loss_train=0.3874, acc_train=0.8750, loss_test=0.1329, acc_test=0.9990
# poison_percent 10 epoch 86: loss_train=0.4550, acc_train=0.8438, loss_test=0.1321, acc_test=0.9990
# poison_percent 10 epoch 87: loss_train=0.4600, acc_train=0.8125, loss_test=0.1224, acc_test=0.9990
# poison_percent 10 epoch 88: loss_train=0.2398, acc_train=0.9375, loss_test=0.1161, acc_test=0.9990
# poison_percent 10 epoch 89: loss_train=0.3649, acc_train=0.8750, loss_test=0.1095, acc_test=0.9990
# poison_percent 10 epoch 90: loss_train=0.3957, acc_train=0.8750, loss_test=0.1156, acc_test=0.9990
# poison_percent 10 epoch 91: loss_train=0.3195, acc_train=0.9062, loss_test=0.1208, acc_test=0.9990
# poison_percent 10 epoch 92: loss_train=0.4008, acc_train=0.8750, loss_test=0.1251, acc_test=0.9990
# poison_percent 10 epoch 93: loss_train=0.2496, acc_train=0.9375, loss_test=0.1211, acc_test=0.9990
# poison_percent 10 epoch 94: loss_train=0.3434, acc_train=0.9062, loss_test=0.1181, acc_test=0.9990
# poison_percent 10 epoch 95: loss_train=0.4853, acc_train=0.8125, loss_test=0.1201, acc_test=0.9990
# poison_percent 10 epoch 96: loss_train=0.3790, acc_train=0.8750, loss_test=0.1290, acc_test=0.9985
# poison_percent 10 epoch 97: loss_train=0.2884, acc_train=0.9062, loss_test=0.1196, acc_test=0.9985
# poison_percent 10 epoch 98: loss_train=0.2675, acc_train=0.9375, loss_test=0.1065, acc_test=0.9990
# poison_percent 10 epoch 99: loss_train=0.2887, acc_train=0.9062, loss_test=0.1115, acc_test=0.9990
# Training log saved to ./results\CL_ModelN1L2_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 epoch 0: loss_train=0.5768, acc_train=0.7222, loss_test=0.2354, acc_test=0.9980
# poison_percent 20 epoch 1: loss_train=0.4164, acc_train=0.8333, loss_test=0.2125, acc_test=0.9985
# poison_percent 20 epoch 2: loss_train=0.6718, acc_train=0.7222, loss_test=0.2360, acc_test=0.9980
# poison_percent 20 epoch 3: loss_train=0.4108, acc_train=0.8333, loss_test=0.2233, acc_test=0.9985
# poison_percent 20 epoch 4: loss_train=0.9588, acc_train=0.5000, loss_test=0.2176, acc_test=0.9985
# poison_percent 20 epoch 5: loss_train=0.4995, acc_train=0.7778, loss_test=0.2353, acc_test=0.9985
# poison_percent 20 epoch 6: loss_train=0.3727, acc_train=0.8889, loss_test=0.2426, acc_test=0.9980
# poison_percent 20 epoch 7: loss_train=0.3868, acc_train=0.8889, loss_test=0.2335, acc_test=0.9985
# poison_percent 20 epoch 8: loss_train=0.5118, acc_train=0.7778, loss_test=0.2331, acc_test=0.9985
# poison_percent 20 epoch 9: loss_train=0.3217, acc_train=0.9444, loss_test=0.2446, acc_test=0.9974
# poison_percent 20 epoch 10: loss_train=0.4918, acc_train=0.8333, loss_test=0.2615, acc_test=0.9974
# poison_percent 20 epoch 11: loss_train=0.5352, acc_train=0.7778, loss_test=0.2145, acc_test=0.9985
# poison_percent 20 epoch 12: loss_train=0.4514, acc_train=0.8333, loss_test=0.2065, acc_test=0.9980
# poison_percent 20 epoch 13: loss_train=0.2786, acc_train=0.9444, loss_test=0.2122, acc_test=0.9974
# poison_percent 20 epoch 14: loss_train=0.7244, acc_train=0.6111, loss_test=0.2484, acc_test=0.9974
# poison_percent 20 epoch 15: loss_train=0.5354, acc_train=0.7778, loss_test=0.2221, acc_test=0.9974
# poison_percent 20 epoch 16: loss_train=0.4825, acc_train=0.8333, loss_test=0.2513, acc_test=0.9974
# poison_percent 20 epoch 17: loss_train=0.5060, acc_train=0.7778, loss_test=0.2191, acc_test=0.9980
# poison_percent 20 epoch 18: loss_train=0.3487, acc_train=0.8889, loss_test=0.2180, acc_test=0.9980
# poison_percent 20 epoch 19: loss_train=0.5280, acc_train=0.7778, loss_test=0.2293, acc_test=0.9980
# poison_percent 20 epoch 20: loss_train=0.3724, acc_train=0.8889, loss_test=0.2458, acc_test=0.9974
# poison_percent 20 epoch 21: loss_train=0.6539, acc_train=0.7222, loss_test=0.2224, acc_test=0.9974
# poison_percent 20 epoch 22: loss_train=0.4597, acc_train=0.8333, loss_test=0.2238, acc_test=0.9974
# poison_percent 20 epoch 23: loss_train=0.6746, acc_train=0.6667, loss_test=0.2459, acc_test=0.9974
# poison_percent 20 epoch 24: loss_train=0.3012, acc_train=0.9444, loss_test=0.2281, acc_test=0.9980
# poison_percent 20 epoch 25: loss_train=0.4522, acc_train=0.8333, loss_test=0.2333, acc_test=0.9974
# poison_percent 20 epoch 26: loss_train=0.4589, acc_train=0.7778, loss_test=0.2270, acc_test=0.9974
# poison_percent 20 epoch 27: loss_train=0.3187, acc_train=0.8889, loss_test=0.2334, acc_test=0.9974
# poison_percent 20 epoch 28: loss_train=0.4913, acc_train=0.7778, loss_test=0.2415, acc_test=0.9974
# poison_percent 20 epoch 29: loss_train=0.4399, acc_train=0.8333, loss_test=0.2301, acc_test=0.9974
# poison_percent 20 epoch 30: loss_train=0.8510, acc_train=0.5556, loss_test=0.2333, acc_test=0.9969
# poison_percent 20 epoch 31: loss_train=0.4787, acc_train=0.8333, loss_test=0.2425, acc_test=0.9969
# poison_percent 20 epoch 32: loss_train=0.4486, acc_train=0.8333, loss_test=0.2325, acc_test=0.9974
# poison_percent 20 epoch 33: loss_train=0.4075, acc_train=0.8333, loss_test=0.2153, acc_test=0.9980
# poison_percent 20 epoch 34: loss_train=0.5605, acc_train=0.7778, loss_test=0.2413, acc_test=0.9969
# poison_percent 20 epoch 35: loss_train=0.6455, acc_train=0.7222, loss_test=0.2242, acc_test=0.9969
# poison_percent 20 epoch 36: loss_train=0.6211, acc_train=0.7222, loss_test=0.2311, acc_test=0.9974
# poison_percent 20 epoch 37: loss_train=0.4673, acc_train=0.8333, loss_test=0.2519, acc_test=0.9974
# poison_percent 20 epoch 38: loss_train=0.4698, acc_train=0.8333, loss_test=0.2362, acc_test=0.9969
# poison_percent 20 epoch 39: loss_train=0.5784, acc_train=0.7222, loss_test=0.2220, acc_test=0.9974
# poison_percent 20 epoch 40: loss_train=0.3106, acc_train=0.9444, loss_test=0.2299, acc_test=0.9974
# poison_percent 20 epoch 41: loss_train=0.5130, acc_train=0.7778, loss_test=0.2379, acc_test=0.9969
# poison_percent 20 epoch 42: loss_train=0.4356, acc_train=0.8333, loss_test=0.2359, acc_test=0.9969
# poison_percent 20 epoch 43: loss_train=0.7044, acc_train=0.6111, loss_test=0.2296, acc_test=0.9969
# poison_percent 20 epoch 44: loss_train=0.3411, acc_train=0.9444, loss_test=0.2313, acc_test=0.9969
# poison_percent 20 epoch 45: loss_train=0.5411, acc_train=0.7778, loss_test=0.2314, acc_test=0.9969
# poison_percent 20 epoch 46: loss_train=0.4522, acc_train=0.8333, loss_test=0.2398, acc_test=0.9969
# poison_percent 20 epoch 47: loss_train=0.4315, acc_train=0.8333, loss_test=0.2248, acc_test=0.9969
# poison_percent 20 epoch 48: loss_train=0.6144, acc_train=0.7222, loss_test=0.2133, acc_test=0.9969
# poison_percent 20 epoch 49: loss_train=0.4157, acc_train=0.8333, loss_test=0.2181, acc_test=0.9969
# poison_percent 20 epoch 50: loss_train=0.6532, acc_train=0.7222, loss_test=0.2111, acc_test=0.9969
# poison_percent 20 epoch 51: loss_train=0.5261, acc_train=0.7778, loss_test=0.2296, acc_test=0.9969
# poison_percent 20 epoch 52: loss_train=0.4557, acc_train=0.8889, loss_test=0.2512, acc_test=0.9959
# poison_percent 20 epoch 53: loss_train=0.5912, acc_train=0.7222, loss_test=0.2350, acc_test=0.9964
# poison_percent 20 epoch 54: loss_train=0.3083, acc_train=0.9444, loss_test=0.2160, acc_test=0.9969
# poison_percent 20 epoch 55: loss_train=0.3748, acc_train=0.8889, loss_test=0.2117, acc_test=0.9974
# poison_percent 20 epoch 56: loss_train=0.4264, acc_train=0.8333, loss_test=0.2468, acc_test=0.9959
# poison_percent 20 epoch 57: loss_train=0.4284, acc_train=0.8333, loss_test=0.2398, acc_test=0.9964
# poison_percent 20 epoch 58: loss_train=0.3472, acc_train=0.8889, loss_test=0.2401, acc_test=0.9964
# poison_percent 20 epoch 59: loss_train=0.3960, acc_train=0.8333, loss_test=0.2595, acc_test=0.9964
# poison_percent 20 epoch 60: loss_train=0.7444, acc_train=0.6667, loss_test=0.2285, acc_test=0.9964
# poison_percent 20 epoch 61: loss_train=0.2792, acc_train=0.9444, loss_test=0.2258, acc_test=0.9964
# poison_percent 20 epoch 62: loss_train=0.5125, acc_train=0.8333, loss_test=0.2292, acc_test=0.9964
# poison_percent 20 epoch 63: loss_train=0.4432, acc_train=0.8333, loss_test=0.2408, acc_test=0.9964
# poison_percent 20 epoch 64: loss_train=0.5804, acc_train=0.7222, loss_test=0.2120, acc_test=0.9964
# poison_percent 20 epoch 65: loss_train=0.4953, acc_train=0.8333, loss_test=0.2384, acc_test=0.9959
# poison_percent 20 epoch 66: loss_train=0.6979, acc_train=0.6667, loss_test=0.2378, acc_test=0.9954
# poison_percent 20 epoch 67: loss_train=0.6678, acc_train=0.6667, loss_test=0.2546, acc_test=0.9954
# poison_percent 20 epoch 68: loss_train=0.3134, acc_train=0.8889, loss_test=0.2148, acc_test=0.9959
# poison_percent 20 epoch 69: loss_train=0.5413, acc_train=0.7778, loss_test=0.2536, acc_test=0.9954
# poison_percent 20 epoch 70: loss_train=0.3221, acc_train=0.8889, loss_test=0.2306, acc_test=0.9949
# poison_percent 20 epoch 71: loss_train=0.6185, acc_train=0.7222, loss_test=0.2180, acc_test=0.9964
# poison_percent 20 epoch 72: loss_train=0.6116, acc_train=0.6667, loss_test=0.2327, acc_test=0.9959
# poison_percent 20 epoch 73: loss_train=0.4152, acc_train=0.8333, loss_test=0.2294, acc_test=0.9954
# poison_percent 20 epoch 74: loss_train=0.3399, acc_train=0.8889, loss_test=0.2245, acc_test=0.9954
# poison_percent 20 epoch 75: loss_train=0.3375, acc_train=0.8889, loss_test=0.2406, acc_test=0.9949
# poison_percent 20 epoch 76: loss_train=0.4452, acc_train=0.8333, loss_test=0.2290, acc_test=0.9954
# poison_percent 20 epoch 77: loss_train=0.4925, acc_train=0.7778, loss_test=0.2318, acc_test=0.9959
# poison_percent 20 epoch 78: loss_train=0.3700, acc_train=0.8889, loss_test=0.2399, acc_test=0.9954
# poison_percent 20 epoch 79: loss_train=0.4308, acc_train=0.8333, loss_test=0.2222, acc_test=0.9949
# poison_percent 20 epoch 80: loss_train=0.6008, acc_train=0.7222, loss_test=0.2271, acc_test=0.9944
# poison_percent 20 epoch 81: loss_train=0.5556, acc_train=0.7222, loss_test=0.2357, acc_test=0.9944
# poison_percent 20 epoch 82: loss_train=0.5080, acc_train=0.7778, loss_test=0.2226, acc_test=0.9954
# poison_percent 20 epoch 83: loss_train=0.5778, acc_train=0.7222, loss_test=0.2283, acc_test=0.9949
# poison_percent 20 epoch 84: loss_train=0.5760, acc_train=0.7778, loss_test=0.1931, acc_test=0.9964
# poison_percent 20 epoch 85: loss_train=0.6473, acc_train=0.6667, loss_test=0.2309, acc_test=0.9954
# poison_percent 20 epoch 86: loss_train=0.5711, acc_train=0.7222, loss_test=0.2225, acc_test=0.9944
# poison_percent 20 epoch 87: loss_train=0.2930, acc_train=0.9444, loss_test=0.2359, acc_test=0.9949
# poison_percent 20 epoch 88: loss_train=0.3884, acc_train=0.8889, loss_test=0.2405, acc_test=0.9939
# poison_percent 20 epoch 89: loss_train=0.6309, acc_train=0.7222, loss_test=0.2151, acc_test=0.9954
# poison_percent 20 epoch 90: loss_train=0.4458, acc_train=0.8333, loss_test=0.2406, acc_test=0.9944
# poison_percent 20 epoch 91: loss_train=0.4327, acc_train=0.8333, loss_test=0.2263, acc_test=0.9944
# poison_percent 20 epoch 92: loss_train=0.4940, acc_train=0.8333, loss_test=0.2429, acc_test=0.9923
# poison_percent 20 epoch 93: loss_train=0.5697, acc_train=0.7778, loss_test=0.2276, acc_test=0.9939
# poison_percent 20 epoch 94: loss_train=0.4167, acc_train=0.8333, loss_test=0.2181, acc_test=0.9949
# poison_percent 20 epoch 95: loss_train=0.5168, acc_train=0.7778, loss_test=0.2327, acc_test=0.9939
# poison_percent 20 epoch 96: loss_train=0.4700, acc_train=0.8333, loss_test=0.2304, acc_test=0.9939
# poison_percent 20 epoch 97: loss_train=0.5399, acc_train=0.7778, loss_test=0.2261, acc_test=0.9939
# poison_percent 20 epoch 98: loss_train=0.4447, acc_train=0.8333, loss_test=0.2365, acc_test=0.9939
# poison_percent 20 epoch 99: loss_train=0.6243, acc_train=0.7222, loss_test=0.2357, acc_test=0.9954
# Training log saved to ./results\CL_ModelN1L2_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 epoch 0: loss_train=0.5157, acc_train=0.8333, loss_test=0.3708, acc_test=0.9867
# poison_percent 30 epoch 1: loss_train=0.5508, acc_train=0.8333, loss_test=0.3437, acc_test=0.9913
# poison_percent 30 epoch 2: loss_train=0.5409, acc_train=0.8333, loss_test=0.3717, acc_test=0.9898
# poison_percent 30 epoch 3: loss_train=0.7697, acc_train=0.5000, loss_test=0.3657, acc_test=0.9913
# poison_percent 30 epoch 4: loss_train=0.9234, acc_train=0.5000, loss_test=0.3595, acc_test=0.9908
# poison_percent 30 epoch 5: loss_train=0.5482, acc_train=0.8333, loss_test=0.3460, acc_test=0.9908
# poison_percent 30 epoch 6: loss_train=0.6700, acc_train=0.6667, loss_test=0.3684, acc_test=0.9898
# poison_percent 30 epoch 7: loss_train=0.4627, acc_train=0.8333, loss_test=0.3431, acc_test=0.9913
# poison_percent 30 epoch 8: loss_train=0.4101, acc_train=1.0000, loss_test=0.3742, acc_test=0.9888
# poison_percent 30 epoch 9: loss_train=0.3332, acc_train=1.0000, loss_test=0.3719, acc_test=0.9883
# poison_percent 30 epoch 10: loss_train=0.4863, acc_train=0.8333, loss_test=0.3456, acc_test=0.9908
# poison_percent 30 epoch 11: loss_train=1.0529, acc_train=0.3333, loss_test=0.3330, acc_test=0.9908
# poison_percent 30 epoch 12: loss_train=0.8134, acc_train=0.5000, loss_test=0.3786, acc_test=0.9898
# poison_percent 30 epoch 13: loss_train=0.5675, acc_train=0.8333, loss_test=0.3798, acc_test=0.9878
# poison_percent 30 epoch 14: loss_train=0.4958, acc_train=0.8333, loss_test=0.3849, acc_test=0.9913
# poison_percent 30 epoch 15: loss_train=0.8027, acc_train=0.5000, loss_test=0.3811, acc_test=0.9893
# poison_percent 30 epoch 16: loss_train=0.3438, acc_train=1.0000, loss_test=0.3751, acc_test=0.9903
# poison_percent 30 epoch 17: loss_train=0.5102, acc_train=0.8333, loss_test=0.3621, acc_test=0.9903
# poison_percent 30 epoch 18: loss_train=0.6133, acc_train=0.6667, loss_test=0.3656, acc_test=0.9908
# poison_percent 30 epoch 19: loss_train=0.6586, acc_train=0.6667, loss_test=0.3681, acc_test=0.9888
# poison_percent 30 epoch 20: loss_train=0.6339, acc_train=0.6667, loss_test=0.3631, acc_test=0.9898
# poison_percent 30 epoch 21: loss_train=0.4078, acc_train=1.0000, loss_test=0.3745, acc_test=0.9908
# poison_percent 30 epoch 22: loss_train=0.5678, acc_train=0.6667, loss_test=0.3917, acc_test=0.9872
# poison_percent 30 epoch 23: loss_train=0.9190, acc_train=0.3333, loss_test=0.3709, acc_test=0.9878
# poison_percent 30 epoch 24: loss_train=1.0292, acc_train=0.3333, loss_test=0.3600, acc_test=0.9903
# poison_percent 30 epoch 25: loss_train=0.7444, acc_train=0.3333, loss_test=0.3649, acc_test=0.9888
# poison_percent 30 epoch 26: loss_train=0.6427, acc_train=0.6667, loss_test=0.3644, acc_test=0.9898
# poison_percent 30 epoch 27: loss_train=0.3700, acc_train=1.0000, loss_test=0.3713, acc_test=0.9883
# poison_percent 30 epoch 28: loss_train=0.6953, acc_train=0.6667, loss_test=0.3494, acc_test=0.9908
# poison_percent 30 epoch 29: loss_train=0.7060, acc_train=0.5000, loss_test=0.3597, acc_test=0.9878
# poison_percent 30 epoch 30: loss_train=0.4889, acc_train=0.8333, loss_test=0.3609, acc_test=0.9888
# poison_percent 30 epoch 31: loss_train=0.3117, acc_train=1.0000, loss_test=0.3614, acc_test=0.9908
# poison_percent 30 epoch 32: loss_train=0.4375, acc_train=0.8333, loss_test=0.3585, acc_test=0.9888
# poison_percent 30 epoch 33: loss_train=0.8244, acc_train=0.5000, loss_test=0.3878, acc_test=0.9832
# poison_percent 30 epoch 34: loss_train=0.4553, acc_train=0.8333, loss_test=0.3738, acc_test=0.9878
# poison_percent 30 epoch 35: loss_train=0.5326, acc_train=0.8333, loss_test=0.3565, acc_test=0.9908
# poison_percent 30 epoch 36: loss_train=0.6597, acc_train=0.6667, loss_test=0.3470, acc_test=0.9908
# poison_percent 30 epoch 37: loss_train=0.3604, acc_train=1.0000, loss_test=0.3643, acc_test=0.9878
# poison_percent 30 epoch 38: loss_train=0.4680, acc_train=0.8333, loss_test=0.3618, acc_test=0.9908
# poison_percent 30 epoch 39: loss_train=0.6350, acc_train=0.6667, loss_test=0.3554, acc_test=0.9893
# poison_percent 30 epoch 40: loss_train=0.5098, acc_train=0.8333, loss_test=0.3589, acc_test=0.9903
# poison_percent 30 epoch 41: loss_train=0.4881, acc_train=0.8333, loss_test=0.3529, acc_test=0.9918
# poison_percent 30 epoch 42: loss_train=0.5291, acc_train=0.8333, loss_test=0.3772, acc_test=0.9867
# poison_percent 30 epoch 43: loss_train=0.5702, acc_train=0.8333, loss_test=0.3739, acc_test=0.9801
# poison_percent 30 epoch 44: loss_train=0.4791, acc_train=0.8333, loss_test=0.3561, acc_test=0.9898
# poison_percent 30 epoch 45: loss_train=0.3662, acc_train=1.0000, loss_test=0.3480, acc_test=0.9908
# poison_percent 30 epoch 46: loss_train=0.4861, acc_train=0.8333, loss_test=0.3663, acc_test=0.9908
# poison_percent 30 epoch 47: loss_train=0.7437, acc_train=0.5000, loss_test=0.3717, acc_test=0.9908
# poison_percent 30 epoch 48: loss_train=0.6932, acc_train=0.6667, loss_test=0.3648, acc_test=0.9908
# poison_percent 30 epoch 49: loss_train=0.3807, acc_train=1.0000, loss_test=0.3642, acc_test=0.9908
# poison_percent 30 epoch 50: loss_train=0.4638, acc_train=0.8333, loss_test=0.3895, acc_test=0.9837
# poison_percent 30 epoch 51: loss_train=0.4054, acc_train=1.0000, loss_test=0.3784, acc_test=0.9847
# poison_percent 30 epoch 52: loss_train=0.5564, acc_train=0.6667, loss_test=0.3747, acc_test=0.9837
# poison_percent 30 epoch 53: loss_train=0.3973, acc_train=1.0000, loss_test=0.3910, acc_test=0.9786
# poison_percent 30 epoch 54: loss_train=0.7606, acc_train=0.5000, loss_test=0.3814, acc_test=0.9893
# poison_percent 30 epoch 55: loss_train=0.5998, acc_train=0.6667, loss_test=0.3733, acc_test=0.9847
# poison_percent 30 epoch 56: loss_train=0.6422, acc_train=0.6667, loss_test=0.3643, acc_test=0.9883
# poison_percent 30 epoch 57: loss_train=0.5083, acc_train=0.8333, loss_test=0.3843, acc_test=0.9796
# poison_percent 30 epoch 58: loss_train=0.4879, acc_train=0.8333, loss_test=0.3669, acc_test=0.9857
# poison_percent 30 epoch 59: loss_train=0.4350, acc_train=0.8333, loss_test=0.3556, acc_test=0.9908
# poison_percent 30 epoch 60: loss_train=0.6412, acc_train=0.6667, loss_test=0.3790, acc_test=0.9857
# poison_percent 30 epoch 61: loss_train=0.8253, acc_train=0.3333, loss_test=0.3613, acc_test=0.9888
# poison_percent 30 epoch 62: loss_train=0.5750, acc_train=0.6667, loss_test=0.3583, acc_test=0.9903
# poison_percent 30 epoch 63: loss_train=0.5910, acc_train=0.6667, loss_test=0.3664, acc_test=0.9862
# poison_percent 30 epoch 64: loss_train=0.5978, acc_train=0.6667, loss_test=0.3812, acc_test=0.9862
# poison_percent 30 epoch 65: loss_train=0.5301, acc_train=0.8333, loss_test=0.3511, acc_test=0.9893
# poison_percent 30 epoch 66: loss_train=0.7698, acc_train=0.5000, loss_test=0.3368, acc_test=0.9893
# poison_percent 30 epoch 67: loss_train=0.5032, acc_train=0.8333, loss_test=0.3683, acc_test=0.9857
# poison_percent 30 epoch 68: loss_train=0.8364, acc_train=0.5000, loss_test=0.3530, acc_test=0.9903
# poison_percent 30 epoch 69: loss_train=0.5094, acc_train=0.8333, loss_test=0.3651, acc_test=0.9832
# poison_percent 30 epoch 70: loss_train=0.4056, acc_train=1.0000, loss_test=0.3675, acc_test=0.9776
# poison_percent 30 epoch 71: loss_train=0.5079, acc_train=0.8333, loss_test=0.3685, acc_test=0.9852
# poison_percent 30 epoch 72: loss_train=0.6236, acc_train=0.6667, loss_test=0.3668, acc_test=0.9827
# poison_percent 30 epoch 73: loss_train=0.6504, acc_train=0.6667, loss_test=0.3718, acc_test=0.9857
# poison_percent 30 epoch 74: loss_train=0.8761, acc_train=0.3333, loss_test=0.3791, acc_test=0.9806
# poison_percent 30 epoch 75: loss_train=0.5749, acc_train=0.6667, loss_test=0.3637, acc_test=0.9872
# poison_percent 30 epoch 76: loss_train=0.6299, acc_train=0.6667, loss_test=0.3731, acc_test=0.9847
# poison_percent 30 epoch 77: loss_train=0.5982, acc_train=0.6667, loss_test=0.3397, acc_test=0.9898
# poison_percent 30 epoch 78: loss_train=0.5026, acc_train=0.8333, loss_test=0.3576, acc_test=0.9852
# poison_percent 30 epoch 79: loss_train=0.7183, acc_train=0.3333, loss_test=0.3853, acc_test=0.9760
# poison_percent 30 epoch 80: loss_train=0.5883, acc_train=0.6667, loss_test=0.3579, acc_test=0.9811
# poison_percent 30 epoch 81: loss_train=0.2955, acc_train=1.0000, loss_test=0.3544, acc_test=0.9852
# poison_percent 30 epoch 82: loss_train=0.3337, acc_train=1.0000, loss_test=0.3628, acc_test=0.9852
# poison_percent 30 epoch 83: loss_train=0.5329, acc_train=0.8333, loss_test=0.3587, acc_test=0.9883
# poison_percent 30 epoch 84: loss_train=0.7728, acc_train=0.5000, loss_test=0.3669, acc_test=0.9888
# poison_percent 30 epoch 85: loss_train=0.3039, acc_train=1.0000, loss_test=0.3336, acc_test=0.9867
# poison_percent 30 epoch 86: loss_train=0.6411, acc_train=0.6667, loss_test=0.3487, acc_test=0.9893
# poison_percent 30 epoch 87: loss_train=0.5142, acc_train=0.8333, loss_test=0.3775, acc_test=0.9842
# poison_percent 30 epoch 88: loss_train=0.4540, acc_train=0.8333, loss_test=0.3619, acc_test=0.9816
# poison_percent 30 epoch 89: loss_train=0.7719, acc_train=0.5000, loss_test=0.3561, acc_test=0.9872
# poison_percent 30 epoch 90: loss_train=0.3083, acc_train=1.0000, loss_test=0.3785, acc_test=0.9796
# poison_percent 30 epoch 91: loss_train=0.6987, acc_train=0.6667, loss_test=0.3760, acc_test=0.9750
# poison_percent 30 epoch 92: loss_train=0.6846, acc_train=0.6667, loss_test=0.3786, acc_test=0.9827
# poison_percent 30 epoch 93: loss_train=0.4275, acc_train=1.0000, loss_test=0.3671, acc_test=0.9872
# poison_percent 30 epoch 94: loss_train=0.3258, acc_train=1.0000, loss_test=0.3597, acc_test=0.9872
# poison_percent 30 epoch 95: loss_train=0.4577, acc_train=0.8333, loss_test=0.3719, acc_test=0.9852
# poison_percent 30 epoch 96: loss_train=0.7026, acc_train=0.6667, loss_test=0.3767, acc_test=0.9806
# poison_percent 30 epoch 97: loss_train=0.7352, acc_train=0.5000, loss_test=0.3662, acc_test=0.9862
# poison_percent 30 epoch 98: loss_train=0.7566, acc_train=0.5000, loss_test=0.3600, acc_test=0.9883
# poison_percent 30 epoch 99: loss_train=0.5054, acc_train=0.8333, loss_test=0.3651, acc_test=0.9811
# Training log saved to ./results\CL_ModelN1L2_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 epoch 0: loss_train=0.6486, acc_train=0.6818, loss_test=0.5121, acc_test=0.9383
# poison_percent 40 epoch 1: loss_train=0.6375, acc_train=0.6818, loss_test=0.5072, acc_test=0.9413
# poison_percent 40 epoch 2: loss_train=0.6639, acc_train=0.6364, loss_test=0.5159, acc_test=0.9408
# poison_percent 40 epoch 3: loss_train=0.5940, acc_train=0.7273, loss_test=0.5193, acc_test=0.9393
# poison_percent 40 epoch 4: loss_train=0.6704, acc_train=0.5909, loss_test=0.5284, acc_test=0.9097
# poison_percent 40 epoch 5: loss_train=0.7271, acc_train=0.5455, loss_test=0.5021, acc_test=0.9423
# poison_percent 40 epoch 6: loss_train=0.6742, acc_train=0.5909, loss_test=0.5271, acc_test=0.9281
# poison_percent 40 epoch 7: loss_train=0.7309, acc_train=0.4545, loss_test=0.4990, acc_test=0.9423
# poison_percent 40 epoch 8: loss_train=0.6370, acc_train=0.6364, loss_test=0.5270, acc_test=0.9235
# poison_percent 40 epoch 9: loss_train=0.6913, acc_train=0.5000, loss_test=0.5344, acc_test=0.9209
# poison_percent 40 epoch 10: loss_train=0.6109, acc_train=0.6818, loss_test=0.5047, acc_test=0.9393
# poison_percent 40 epoch 11: loss_train=0.7232, acc_train=0.4545, loss_test=0.5263, acc_test=0.9281
# poison_percent 40 epoch 12: loss_train=0.6874, acc_train=0.5909, loss_test=0.5033, acc_test=0.9403
# poison_percent 40 epoch 13: loss_train=0.6933, acc_train=0.5455, loss_test=0.5226, acc_test=0.9321
# poison_percent 40 epoch 14: loss_train=0.7044, acc_train=0.5909, loss_test=0.5235, acc_test=0.9286
# poison_percent 40 epoch 15: loss_train=0.6982, acc_train=0.6364, loss_test=0.5230, acc_test=0.9276
# poison_percent 40 epoch 16: loss_train=0.7624, acc_train=0.3636, loss_test=0.5393, acc_test=0.8888
# poison_percent 40 epoch 17: loss_train=0.6380, acc_train=0.6818, loss_test=0.5281, acc_test=0.9255
# poison_percent 40 epoch 18: loss_train=0.6880, acc_train=0.5909, loss_test=0.5338, acc_test=0.9224
# poison_percent 40 epoch 19: loss_train=0.6800, acc_train=0.6364, loss_test=0.5234, acc_test=0.9311
# poison_percent 40 epoch 20: loss_train=0.6741, acc_train=0.5455, loss_test=0.5429, acc_test=0.8837
# poison_percent 40 epoch 21: loss_train=0.6691, acc_train=0.7273, loss_test=0.5285, acc_test=0.9240
# poison_percent 40 epoch 22: loss_train=0.5848, acc_train=0.7273, loss_test=0.5144, acc_test=0.9311
# poison_percent 40 epoch 23: loss_train=0.6818, acc_train=0.6364, loss_test=0.5311, acc_test=0.9087
# poison_percent 40 epoch 24: loss_train=0.6664, acc_train=0.5909, loss_test=0.5349, acc_test=0.9020
# poison_percent 40 epoch 25: loss_train=0.6438, acc_train=0.5455, loss_test=0.5551, acc_test=0.8995
# poison_percent 40 epoch 26: loss_train=0.7125, acc_train=0.5000, loss_test=0.5398, acc_test=0.9168
# poison_percent 40 epoch 27: loss_train=0.6251, acc_train=0.6364, loss_test=0.5225, acc_test=0.9240
# poison_percent 40 epoch 28: loss_train=0.6965, acc_train=0.5455, loss_test=0.5497, acc_test=0.9066
# poison_percent 40 epoch 29: loss_train=0.6624, acc_train=0.6364, loss_test=0.5356, acc_test=0.9133
# poison_percent 40 epoch 30: loss_train=0.6962, acc_train=0.4545, loss_test=0.5327, acc_test=0.9128
# poison_percent 40 epoch 31: loss_train=0.6175, acc_train=0.6818, loss_test=0.5310, acc_test=0.9204
# poison_percent 40 epoch 32: loss_train=0.8037, acc_train=0.4091, loss_test=0.5281, acc_test=0.9235
# poison_percent 40 epoch 33: loss_train=0.7140, acc_train=0.5000, loss_test=0.5087, acc_test=0.9321
# poison_percent 40 epoch 34: loss_train=0.6292, acc_train=0.5909, loss_test=0.5299, acc_test=0.9281
# poison_percent 40 epoch 35: loss_train=0.6171, acc_train=0.6818, loss_test=0.5381, acc_test=0.9158
# poison_percent 40 epoch 36: loss_train=0.5810, acc_train=0.7273, loss_test=0.5133, acc_test=0.9357
# poison_percent 40 epoch 37: loss_train=0.7085, acc_train=0.5000, loss_test=0.5207, acc_test=0.9281
# poison_percent 40 epoch 38: loss_train=0.6272, acc_train=0.7273, loss_test=0.5241, acc_test=0.9286
# poison_percent 40 epoch 39: loss_train=0.7150, acc_train=0.5000, loss_test=0.5277, acc_test=0.9342
# poison_percent 40 epoch 40: loss_train=0.7314, acc_train=0.5000, loss_test=0.5465, acc_test=0.9051
# poison_percent 40 epoch 41: loss_train=0.6385, acc_train=0.5909, loss_test=0.5003, acc_test=0.9408
# poison_percent 40 epoch 42: loss_train=0.6772, acc_train=0.5455, loss_test=0.5023, acc_test=0.9423
# poison_percent 40 epoch 43: loss_train=0.7141, acc_train=0.4545, loss_test=0.5368, acc_test=0.9102
# poison_percent 40 epoch 44: loss_train=0.6337, acc_train=0.6364, loss_test=0.4926, acc_test=0.9510
# poison_percent 40 epoch 45: loss_train=0.6293, acc_train=0.6818, loss_test=0.5259, acc_test=0.9306
# poison_percent 40 epoch 46: loss_train=0.6475, acc_train=0.5909, loss_test=0.4962, acc_test=0.9439
# poison_percent 40 epoch 47: loss_train=0.6347, acc_train=0.7273, loss_test=0.5135, acc_test=0.9362
# poison_percent 40 epoch 48: loss_train=0.6583, acc_train=0.5909, loss_test=0.5354, acc_test=0.9199
# poison_percent 40 epoch 49: loss_train=0.7159, acc_train=0.4545, loss_test=0.5155, acc_test=0.9148
# poison_percent 40 epoch 50: loss_train=0.6128, acc_train=0.6364, loss_test=0.5389, acc_test=0.9071
# poison_percent 40 epoch 51: loss_train=0.6719, acc_train=0.5455, loss_test=0.5305, acc_test=0.9173
# poison_percent 40 epoch 52: loss_train=0.6732, acc_train=0.5455, loss_test=0.5236, acc_test=0.9194
# poison_percent 40 epoch 53: loss_train=0.6901, acc_train=0.5455, loss_test=0.5304, acc_test=0.9077
# poison_percent 40 epoch 54: loss_train=0.6535, acc_train=0.5909, loss_test=0.5347, acc_test=0.9056
# poison_percent 40 epoch 55: loss_train=0.6808, acc_train=0.5000, loss_test=0.5169, acc_test=0.9337
# poison_percent 40 epoch 56: loss_train=0.6333, acc_train=0.6364, loss_test=0.5305, acc_test=0.9026
# poison_percent 40 epoch 57: loss_train=0.6460, acc_train=0.7273, loss_test=0.5383, acc_test=0.9133
# poison_percent 40 epoch 58: loss_train=0.6558, acc_train=0.5000, loss_test=0.5286, acc_test=0.9117
# poison_percent 40 epoch 59: loss_train=0.7072, acc_train=0.5000, loss_test=0.5031, acc_test=0.9408
# poison_percent 40 epoch 60: loss_train=0.6626, acc_train=0.5909, loss_test=0.5206, acc_test=0.9235
# poison_percent 40 epoch 61: loss_train=0.6179, acc_train=0.6818, loss_test=0.5269, acc_test=0.9214
# poison_percent 40 epoch 62: loss_train=0.7038, acc_train=0.5909, loss_test=0.5157, acc_test=0.9214
# poison_percent 40 epoch 63: loss_train=0.8356, acc_train=0.4091, loss_test=0.5203, acc_test=0.9270
# poison_percent 40 epoch 64: loss_train=0.7043, acc_train=0.5000, loss_test=0.5018, acc_test=0.9444
# poison_percent 40 epoch 65: loss_train=0.6789, acc_train=0.5455, loss_test=0.5201, acc_test=0.9321
# poison_percent 40 epoch 66: loss_train=0.5940, acc_train=0.6818, loss_test=0.5279, acc_test=0.9255
# poison_percent 40 epoch 67: loss_train=0.7452, acc_train=0.5000, loss_test=0.5170, acc_test=0.9276
# poison_percent 40 epoch 68: loss_train=0.5935, acc_train=0.7727, loss_test=0.5279, acc_test=0.9153
# poison_percent 40 epoch 69: loss_train=0.6345, acc_train=0.5909, loss_test=0.5298, acc_test=0.9291
# poison_percent 40 epoch 70: loss_train=0.6191, acc_train=0.6364, loss_test=0.5032, acc_test=0.9393
# poison_percent 40 epoch 71: loss_train=0.6671, acc_train=0.5909, loss_test=0.5283, acc_test=0.9163
# poison_percent 40 epoch 72: loss_train=0.6094, acc_train=0.6364, loss_test=0.5515, acc_test=0.8985
# poison_percent 40 epoch 73: loss_train=0.6836, acc_train=0.5000, loss_test=0.5258, acc_test=0.9204
# poison_percent 40 epoch 74: loss_train=0.6897, acc_train=0.5455, loss_test=0.4977, acc_test=0.9408
# poison_percent 40 epoch 75: loss_train=0.5512, acc_train=0.7727, loss_test=0.5203, acc_test=0.9337
# poison_percent 40 epoch 76: loss_train=0.6691, acc_train=0.5455, loss_test=0.5219, acc_test=0.9270
# poison_percent 40 epoch 77: loss_train=0.6143, acc_train=0.6818, loss_test=0.5221, acc_test=0.9240
# poison_percent 40 epoch 78: loss_train=0.7340, acc_train=0.4091, loss_test=0.5449, acc_test=0.8735
# poison_percent 40 epoch 79: loss_train=0.5846, acc_train=0.7727, loss_test=0.5219, acc_test=0.9311
# poison_percent 40 epoch 80: loss_train=0.7052, acc_train=0.5455, loss_test=0.5319, acc_test=0.9173
# poison_percent 40 epoch 81: loss_train=0.5798, acc_train=0.7727, loss_test=0.5268, acc_test=0.9087
# ...
# poison_percent 40 epoch 41: loss_train=0.3872, acc_train=0.8182, loss_test=0.7243, acc_test=0.6796
# poison_percent 40 epoch 42: loss_train=0.5747, acc_train=0.7273, loss_test=0.6213, acc_test=0.7347
# poison_percent 40 epoch 43: loss_train=0.5545, acc_train=0.7273, loss_test=0.8128, acc_test=0.6276
# poison_percent 40 epoch 44: loss_train=0.5501, acc_train=0.7273, loss_test=0.7442, acc_test=0.6622
# poison_percent 40 epoch 45: loss_train=0.5163, acc_train=0.7727, loss_test=0.8213, acc_test=0.6209
# poison_percent 40 epoch 46: loss_train=0.5287, acc_train=0.7727, loss_test=0.6638, acc_test=0.7270
# poison_percent 40 epoch 47: loss_train=0.6694, acc_train=0.7273, loss_test=0.8003, acc_test=0.6429
# poison_percent 40 epoch 48: loss_train=0.4230, acc_train=0.8182, loss_test=0.7728, acc_test=0.6786
# poison_percent 40 epoch 49: loss_train=0.6222, acc_train=0.6818, loss_test=0.7166, acc_test=0.6862
# poison_percent 40 epoch 50: loss_train=0.5415, acc_train=0.7727, loss_test=0.7607, acc_test=0.6536
# poison_percent 40 epoch 51: loss_train=0.4019, acc_train=0.8182, loss_test=0.7832, acc_test=0.6332
# poison_percent 40 epoch 52: loss_train=0.3925, acc_train=0.9091, loss_test=0.8021, acc_test=0.6163
# poison_percent 40 epoch 53: loss_train=0.4811, acc_train=0.8182, loss_test=0.8140, acc_test=0.6219
# poison_percent 40 epoch 54: loss_train=0.4771, acc_train=0.7273, loss_test=0.7178, acc_test=0.6658
# poison_percent 40 epoch 55: loss_train=0.4553, acc_train=0.7727, loss_test=0.8213, acc_test=0.6352
# poison_percent 40 epoch 56: loss_train=0.4180, acc_train=0.7727, loss_test=0.9816, acc_test=0.5485
# poison_percent 40 epoch 57: loss_train=0.3849, acc_train=0.8182, loss_test=0.7779, acc_test=0.6454
# poison_percent 40 epoch 58: loss_train=0.5375, acc_train=0.7727, loss_test=0.7851, acc_test=0.6398
# poison_percent 40 epoch 59: loss_train=0.5434, acc_train=0.7727, loss_test=0.7453, acc_test=0.6602
# poison_percent 40 epoch 60: loss_train=0.4530, acc_train=0.7727, loss_test=0.7455, acc_test=0.6510
# poison_percent 40 epoch 61: loss_train=0.3000, acc_train=0.8636, loss_test=0.7670, acc_test=0.6505
# poison_percent 40 epoch 62: loss_train=0.7833, acc_train=0.6364, loss_test=0.8183, acc_test=0.6372
# poison_percent 40 epoch 63: loss_train=0.4151, acc_train=0.8182, loss_test=0.8114, acc_test=0.6235
# poison_percent 40 epoch 64: loss_train=0.6858, acc_train=0.6364, loss_test=0.8028, acc_test=0.6265
# poison_percent 40 epoch 65: loss_train=0.6689, acc_train=0.5455, loss_test=0.8944, acc_test=0.6240
# poison_percent 40 epoch 66: loss_train=0.4001, acc_train=0.7727, loss_test=0.7791, acc_test=0.6571
# poison_percent 40 epoch 67: loss_train=0.2041, acc_train=0.9545, loss_test=0.7080, acc_test=0.6796
# poison_percent 40 epoch 68: loss_train=0.5532, acc_train=0.7727, loss_test=0.6293, acc_test=0.7301
# poison_percent 40 epoch 69: loss_train=0.4430, acc_train=0.8636, loss_test=0.8447, acc_test=0.6219
# poison_percent 40 epoch 70: loss_train=0.5973, acc_train=0.6364, loss_test=0.8359, acc_test=0.6219
# poison_percent 40 epoch 71: loss_train=0.5672, acc_train=0.6364, loss_test=0.7203, acc_test=0.6786
# poison_percent 40 epoch 72: loss_train=0.4516, acc_train=0.8182, loss_test=0.8411, acc_test=0.6286
# poison_percent 40 epoch 73: loss_train=0.3122, acc_train=0.9091, loss_test=0.8716, acc_test=0.6056
# poison_percent 40 epoch 74: loss_train=0.3104, acc_train=0.9545, loss_test=0.8844, acc_test=0.5684
# poison_percent 40 epoch 75: loss_train=0.4218, acc_train=0.7727, loss_test=0.8094, acc_test=0.6250
# poison_percent 40 epoch 76: loss_train=0.3115, acc_train=0.9091, loss_test=0.8351, acc_test=0.6168
# poison_percent 40 epoch 77: loss_train=0.4423, acc_train=0.8636, loss_test=0.7792, acc_test=0.6413
# poison_percent 40 epoch 78: loss_train=0.4980, acc_train=0.7727, loss_test=0.8672, acc_test=0.5985
# poison_percent 40 epoch 79: loss_train=0.3905, acc_train=0.7727, loss_test=0.8103, acc_test=0.6510
# poison_percent 40 epoch 80: loss_train=0.6559, acc_train=0.5455, loss_test=0.8574, acc_test=0.6020
# poison_percent 40 epoch 81: loss_train=0.5511, acc_train=0.6818, loss_test=0.8553, acc_test=0.6158
# poison_percent 40 epoch 82: loss_train=0.4720, acc_train=0.8636, loss_test=0.7957, acc_test=0.6342
# poison_percent 40 epoch 83: loss_train=0.4641, acc_train=0.7727, loss_test=0.8549, acc_test=0.6230
# poison_percent 40 epoch 84: loss_train=0.5396, acc_train=0.7727, loss_test=0.7879, acc_test=0.6204
# poison_percent 40 epoch 85: loss_train=0.4170, acc_train=0.8636, loss_test=0.8441, acc_test=0.6250
# poison_percent 40 epoch 86: loss_train=0.7255, acc_train=0.5000, loss_test=0.6646, acc_test=0.7077
# poison_percent 40 epoch 87: loss_train=0.5698, acc_train=0.7727, loss_test=0.7983, acc_test=0.6342
# poison_percent 40 epoch 88: loss_train=0.3952, acc_train=0.8182, loss_test=0.9321, acc_test=0.5714
# poison_percent 40 epoch 89: loss_train=0.6169, acc_train=0.6818, loss_test=0.8697, acc_test=0.6347
# poison_percent 40 epoch 90: loss_train=0.3810, acc_train=0.7273, loss_test=0.6944, acc_test=0.7071
# poison_percent 40 epoch 91: loss_train=0.4320, acc_train=0.7273, loss_test=0.8970, acc_test=0.5668
# poison_percent 40 epoch 92: loss_train=0.4323, acc_train=0.8182, loss_test=0.8256, acc_test=0.6622
# poison_percent 40 epoch 93: loss_train=0.3617, acc_train=0.8636, loss_test=0.7258, acc_test=0.7046
# poison_percent 40 epoch 94: loss_train=0.4291, acc_train=0.8182, loss_test=0.6860, acc_test=0.6959
# poison_percent 40 epoch 95: loss_train=0.7650, acc_train=0.6364, loss_test=0.8009, acc_test=0.6546
# poison_percent 40 epoch 96: loss_train=0.4534, acc_train=0.7727, loss_test=0.7852, acc_test=0.6592
# poison_percent 40 epoch 97: loss_train=0.5459, acc_train=0.6818, loss_test=0.7208, acc_test=0.6673
# poison_percent 40 epoch 98: loss_train=0.4416, acc_train=0.7727, loss_test=0.8526, acc_test=0.6031
# poison_percent 40 epoch 99: loss_train=0.3055, acc_train=0.9091, loss_test=0.8716, acc_test=0.6209
# Training log saved to ./results\CL_ModelN32L2_Batchsize32_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 epoch 0: loss_train=0.5201, acc_train=0.7500, loss_test=1.3020, acc_test=0.4276
# poison_percent 50 epoch 1: loss_train=0.6667, acc_train=0.5000, loss_test=1.0748, acc_test=0.5082
# poison_percent 50 epoch 2: loss_train=0.6469, acc_train=0.6250, loss_test=1.1917, acc_test=0.4342
# poison_percent 50 epoch 3: loss_train=0.7097, acc_train=0.6875, loss_test=1.0664, acc_test=0.5031
# poison_percent 50 epoch 4: loss_train=0.3579, acc_train=0.8750, loss_test=0.9533, acc_test=0.5464
# poison_percent 50 epoch 5: loss_train=0.4859, acc_train=0.7500, loss_test=1.0392, acc_test=0.5097
# poison_percent 50 epoch 6: loss_train=0.5913, acc_train=0.6250, loss_test=1.1906, acc_test=0.4571
# poison_percent 50 epoch 7: loss_train=0.6847, acc_train=0.6250, loss_test=1.0995, acc_test=0.4791
# poison_percent 50 epoch 8: loss_train=0.9642, acc_train=0.5625, loss_test=1.0149, acc_test=0.5143
# poison_percent 50 epoch 9: loss_train=0.3556, acc_train=0.8750, loss_test=1.0510, acc_test=0.5219
# poison_percent 50 epoch 10: loss_train=0.4803, acc_train=0.6875, loss_test=1.1098, acc_test=0.4531
# poison_percent 50 epoch 11: loss_train=0.3949, acc_train=0.8125, loss_test=1.0432, acc_test=0.4827
# poison_percent 50 epoch 12: loss_train=0.5267, acc_train=0.8125, loss_test=1.0874, acc_test=0.5000
# poison_percent 50 epoch 13: loss_train=0.6392, acc_train=0.6250, loss_test=1.0508, acc_test=0.4954
# poison_percent 50 epoch 14: loss_train=0.5072, acc_train=0.8125, loss_test=1.1508, acc_test=0.4408
# poison_percent 50 epoch 15: loss_train=0.3749, acc_train=0.8750, loss_test=1.0177, acc_test=0.5235
# poison_percent 50 epoch 16: loss_train=0.5652, acc_train=0.6250, loss_test=1.1847, acc_test=0.4617
# poison_percent 50 epoch 17: loss_train=0.4658, acc_train=0.6250, loss_test=1.1017, acc_test=0.4740
# poison_percent 50 epoch 18: loss_train=0.4606, acc_train=0.7500, loss_test=1.1176, acc_test=0.4847
# poison_percent 50 epoch 19: loss_train=0.5378, acc_train=0.8125, loss_test=1.0598, acc_test=0.4908
# poison_percent 50 epoch 20: loss_train=0.4450, acc_train=0.8125, loss_test=1.2291, acc_test=0.4235
# poison_percent 50 epoch 21: loss_train=0.3884, acc_train=0.7500, loss_test=0.9870, acc_test=0.5102
# poison_percent 50 epoch 22: loss_train=0.4277, acc_train=0.8750, loss_test=1.0316, acc_test=0.4990
# poison_percent 50 epoch 23: loss_train=0.5357, acc_train=0.7500, loss_test=1.1138, acc_test=0.4714
# poison_percent 50 epoch 24: loss_train=0.6595, acc_train=0.6250, loss_test=1.1250, acc_test=0.4704
# poison_percent 50 epoch 25: loss_train=0.5930, acc_train=0.6250, loss_test=0.9667, acc_test=0.5469
# poison_percent 50 epoch 26: loss_train=0.7487, acc_train=0.5625, loss_test=0.9513, acc_test=0.5709
# poison_percent 50 epoch 27: loss_train=0.2262, acc_train=0.9375, loss_test=1.0715, acc_test=0.4770
# poison_percent 50 epoch 28: loss_train=0.7221, acc_train=0.5625, loss_test=1.0571, acc_test=0.5357
# poison_percent 50 epoch 29: loss_train=0.4919, acc_train=0.7500, loss_test=1.0622, acc_test=0.4898
# poison_percent 50 epoch 30: loss_train=0.4509, acc_train=0.8750, loss_test=0.9807, acc_test=0.5245
# poison_percent 50 epoch 31: loss_train=0.5123, acc_train=0.6875, loss_test=1.0701, acc_test=0.5189
# poison_percent 50 epoch 32: loss_train=0.7978, acc_train=0.6875, loss_test=1.0446, acc_test=0.5398
# poison_percent 50 epoch 33: loss_train=0.6317, acc_train=0.6250, loss_test=1.0615, acc_test=0.4750
# poison_percent 50 epoch 34: loss_train=0.5601, acc_train=0.6875, loss_test=1.0023, acc_test=0.5383
# poison_percent 50 epoch 35: loss_train=0.5426, acc_train=0.7500, loss_test=0.9452, acc_test=0.5954
# poison_percent 50 epoch 36: loss_train=0.6052, acc_train=0.7500, loss_test=1.0325, acc_test=0.4949
# poison_percent 50 epoch 37: loss_train=0.9236, acc_train=0.3750, loss_test=0.9383, acc_test=0.5918
# poison_percent 50 epoch 38: loss_train=0.4520, acc_train=0.8125, loss_test=1.0761, acc_test=0.4852
# poison_percent 50 epoch 39: loss_train=0.4248, acc_train=0.8125, loss_test=1.1542, acc_test=0.4607
# poison_percent 50 epoch 40: loss_train=0.5459, acc_train=0.6875, loss_test=0.9760, acc_test=0.5148
# poison_percent 50 epoch 41: loss_train=0.3305, acc_train=1.0000, loss_test=0.9329, acc_test=0.5612
# poison_percent 50 epoch 42: loss_train=0.3526, acc_train=0.8125, loss_test=1.0299, acc_test=0.5199
# poison_percent 50 epoch 43: loss_train=0.5030, acc_train=0.8125, loss_test=1.0063, acc_test=0.5311
# poison_percent 50 epoch 44: loss_train=0.5784, acc_train=0.6875, loss_test=1.0251, acc_test=0.5133
# poison_percent 50 epoch 45: loss_train=0.4122, acc_train=0.8125, loss_test=1.0299, acc_test=0.5219
# poison_percent 50 epoch 46: loss_train=0.5130, acc_train=0.8125, loss_test=1.0112, acc_test=0.5449
# poison_percent 50 epoch 47: loss_train=0.5911, acc_train=0.6875, loss_test=1.2510, acc_test=0.4301
# poison_percent 50 epoch 48: loss_train=0.4219, acc_train=0.8750, loss_test=0.9957, acc_test=0.5286
# poison_percent 50 epoch 49: loss_train=0.4833, acc_train=0.6875, loss_test=1.0038, acc_test=0.5684
# poison_percent 50 epoch 50: loss_train=0.6202, acc_train=0.7500, loss_test=0.9314, acc_test=0.5464
# poison_percent 50 epoch 51: loss_train=0.5677, acc_train=0.8750, loss_test=1.0022, acc_test=0.5010
# poison_percent 50 epoch 52: loss_train=0.4692, acc_train=0.8125, loss_test=1.0112, acc_test=0.5454
# poison_percent 50 epoch 53: loss_train=0.6487, acc_train=0.5000, loss_test=1.0677, acc_test=0.5158
# poison_percent 50 epoch 54: loss_train=0.6512, acc_train=0.5625, loss_test=1.0116, acc_test=0.5668
# poison_percent 50 epoch 55: loss_train=0.7907, acc_train=0.3750, loss_test=1.0005, acc_test=0.5587
# poison_percent 50 epoch 56: loss_train=0.2809, acc_train=0.9375, loss_test=0.9543, acc_test=0.5755
# poison_percent 50 epoch 57: loss_train=0.4736, acc_train=0.8125, loss_test=0.9740, acc_test=0.5347
# poison_percent 50 epoch 58: loss_train=0.5101, acc_train=0.7500, loss_test=1.0848, acc_test=0.5046
# poison_percent 50 epoch 59: loss_train=0.7750, acc_train=0.5625, loss_test=0.9711, acc_test=0.5689
# poison_percent 50 epoch 60: loss_train=0.3448, acc_train=0.8125, loss_test=1.2171, acc_test=0.4510
# poison_percent 50 epoch 61: loss_train=0.5518, acc_train=0.7500, loss_test=1.0885, acc_test=0.4653
# poison_percent 50 epoch 62: loss_train=0.2908, acc_train=1.0000, loss_test=0.9790, acc_test=0.5418
# poison_percent 50 epoch 63: loss_train=0.5246, acc_train=0.6250, loss_test=1.0091, acc_test=0.5097
# poison_percent 50 epoch 64: loss_train=0.4037, acc_train=0.8125, loss_test=0.9588, acc_test=0.5929
# poison_percent 50 epoch 65: loss_train=1.5739, acc_train=0.6250, loss_test=1.1049, acc_test=0.4730
# poison_percent 50 epoch 66: loss_train=0.3526, acc_train=0.8750, loss_test=1.1566, acc_test=0.4490
# poison_percent 50 epoch 67: loss_train=0.3414, acc_train=0.8750, loss_test=0.9947, acc_test=0.5250
# poison_percent 50 epoch 68: loss_train=0.5549, acc_train=0.6875, loss_test=1.0555, acc_test=0.5352
# poison_percent 50 epoch 69: loss_train=0.3831, acc_train=0.8125, loss_test=0.9480, acc_test=0.5602
# poison_percent 50 epoch 70: loss_train=0.4293, acc_train=0.8125, loss_test=1.0384, acc_test=0.5653
# poison_percent 50 epoch 71: loss_train=0.6068, acc_train=0.6875, loss_test=1.1287, acc_test=0.4816
# poison_percent 50 epoch 72: loss_train=0.4829, acc_train=0.6875, loss_test=1.0235, acc_test=0.5531
# poison_percent 50 epoch 73: loss_train=0.4236, acc_train=0.7500, loss_test=1.0080, acc_test=0.5260
# poison_percent 50 epoch 74: loss_train=0.5531, acc_train=0.7500, loss_test=1.1384, acc_test=0.4653
# poison_percent 50 epoch 75: loss_train=0.4090, acc_train=0.9375, loss_test=1.0585, acc_test=0.4776
# poison_percent 50 epoch 76: loss_train=0.3070, acc_train=0.8750, loss_test=1.0427, acc_test=0.4867
# poison_percent 50 epoch 77: loss_train=0.3427, acc_train=0.8125, loss_test=1.1064, acc_test=0.4949
# poison_percent 50 epoch 78: loss_train=0.3945, acc_train=0.8750, loss_test=1.0920, acc_test=0.4699
# poison_percent 50 epoch 79: loss_train=0.3084, acc_train=0.9375, loss_test=1.0284, acc_test=0.5265
# poison_percent 50 epoch 80: loss_train=0.5125, acc_train=0.8750, loss_test=1.1210, acc_test=0.4939
# poison_percent 50 epoch 81: loss_train=0.5254, acc_train=0.6250, loss_test=1.1574, acc_test=0.4878
# poison_percent 50 epoch 82: loss_train=0.5614, acc_train=0.5625, loss_test=1.1380, acc_test=0.5010
# poison_percent 50 epoch 83: loss_train=0.5419, acc_train=0.8125, loss_test=1.0026, acc_test=0.5311
# poison_percent 50 epoch 84: loss_train=0.4456, acc_train=0.7500, loss_test=0.9766, acc_test=0.5770
# poison_percent 50 epoch 85: loss_train=0.7887, acc_train=0.5625, loss_test=0.9261, acc_test=0.5643
# poison_percent 50 epoch 86: loss_train=0.4714, acc_train=0.8125, loss_test=1.1954, acc_test=0.4408
# poison_percent 50 epoch 87: loss_train=0.4354, acc_train=0.8125, loss_test=0.9805, acc_test=0.5383
# poison_percent 50 epoch 88: loss_train=0.5603, acc_train=0.6875, loss_test=1.0344, acc_test=0.5276
# poison_percent 50 epoch 89: loss_train=0.5186, acc_train=0.6875, loss_test=1.0954, acc_test=0.4847
# poison_percent 50 epoch 90: loss_train=0.3749, acc_train=0.9375, loss_test=1.0254, acc_test=0.5510
# poison_percent 50 epoch 91: loss_train=0.6086, acc_train=0.5625, loss_test=1.1301, acc_test=0.5347
# poison_percent 50 epoch 92: loss_train=0.5379, acc_train=0.6875, loss_test=1.0796, acc_test=0.5245
# poison_percent 50 epoch 93: loss_train=0.4443, acc_train=0.6875, loss_test=1.0231, acc_test=0.5321
# poison_percent 50 epoch 94: loss_train=0.7083, acc_train=0.6250, loss_test=1.1875, acc_test=0.4811
# poison_percent 50 epoch 95: loss_train=0.7107, acc_train=0.5625, loss_test=1.1189, acc_test=0.4592
# poison_percent 50 epoch 96: loss_train=0.4877, acc_train=0.6875, loss_test=1.0919, acc_test=0.4806
# poison_percent 50 epoch 97: loss_train=0.4310, acc_train=0.7500, loss_test=1.0493, acc_test=0.5082
# poison_percent 50 epoch 98: loss_train=0.4687, acc_train=0.6875, loss_test=1.2113, acc_test=0.4245
# poison_percent 50 epoch 99: loss_train=0.5945, acc_train=0.7500, loss_test=1.2435, acc_test=0.4434
# Training log saved to ./results\CL_ModelN32L2_Batchsize32_rev2\poisoned_50percent\poisoned_50percent.csv
