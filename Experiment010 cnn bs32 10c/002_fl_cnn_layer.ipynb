# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x
    
# save state_dict + metadata (safe, portable)
def save_model(model, img_size, n_classes, learning_rate, experiment_bs, file_path):

    state = {
        "model_state_dict": model.state_dict(),                     # CPU/GPU tensors okay
        "arch": "MNISTNet",
        "img_size": img_size,
        "num_classes": n_classes,
        "training_args": {"lr": learning_rate, "batch_size": experiment_bs}
    }
    # ensure weights are on CPU to avoid GPU-only pickle issues
    state["model_state_dict"] = {k: v.cpu() for k, v in state["model_state_dict"].items()}
    torch.save(state, file_path)
    
def load_model(file_path, device):

    checkpoint = torch.load(file_path, map_location=device)
    model = MNISTNet().to(device)              # must have MNISTNet class defined/importable
    model.load_state_dict(checkpoint["model_state_dict"])
    model.eval()
    return model

# %% [markdown]
# # 4.Loss

# %%
# def binary_cross_entropy(pred, target):
#     eps = 1e-7
#     pred = torch.clamp(pred, eps, 1 - eps)
#     return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

def multiclass_cross_entropy(logits, target, from_probs=False, eps=1e-7):
    """
    Cross-entropy loss for multiclass (e.g., 10 classes).
    - logits: Tensor shape (N, C) containing raw scores (preferred) or probabilities if from_probs=True
    - target: Tensor shape (N,) or (N,1) containing class indices (0..C-1)
    """
    if logits.dim() == 1:
        logits = logits.unsqueeze(0)
    target = target.squeeze()
    if target.dtype != torch.long:
        target = target.long()
    if from_probs:
        probs = torch.clamp(logits, eps, 1.0 - eps)
        log_probs = torch.log(probs)
        return -log_probs[torch.arange(target.size(0)), target].mean()
    return nn.functional.cross_entropy(logits, target)

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    # create model on target device
    model = MNISTNet().to(device)
    # ensure weights are mapped to the worker device
    state_on_device = {k: v.to(device) for k, v in global_weights.items()}
    model.load_state_dict(state_on_device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end].to(device)
            yb = y_c_tensor[start:end].to(device)
            outputs = model(xb)
            # preds = (outputs >= 0.5).float()
            preds = torch.argmax(outputs, dim=1, keepdim=True)
            loss = multiclass_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # return CPU copies for safe aggregation in main thread
    returned_state = {k: v.detach().cpu() for k, v in model.state_dict().items()}
    return returned_state, X_c_tensor.size(0), yb.detach().cpu(), outputs.detach().cpu(), preds.detach().cpu()

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 32
N_CLASSES = 10

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_multiple_poison/train"
TEST_PATH = "../data/mnist_multiple_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
import re
def make_safe_filename(name: str) -> str:
    # remove control chars and characters invalid on Windows
    safe = re.sub(r'[<>:"/\\|?*\x00-\x1F]', '_', name)
    # strip trailing dots/spaces which are problematic on Windows
    safe = safe.rstrip('. ')
    return safe

# %%
NODE = 1
for LAYER in [3,4,5,6]: # LAYER - (first,last)
        
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            
            # 1. Define the stack of hidden layers (Linear + ReLU)
            # Use a list comprehension to create the (Linear, ReLU) pairs
            hidden_layers = []
            for _ in range(LAYER-2):
                hidden_layers.append(nn.Conv2d(NODE, NODE, kernel_size=3, padding=1))
                hidden_layers.append(nn.ReLU())
                
            # 2. Use nn.Sequential to wrap the entire dynamic stack
            self.dynamic_hidden = nn.Sequential(*hidden_layers)
            
            # Other layers
            self.conv1 = nn.Conv2d(1, NODE, kernel_size=3, padding=1) # 28x28
            self.pool = nn.MaxPool2d(2, 2) # 14x14
            self.fc1 = nn.Linear(NODE * 14 * 14, N_CLASSES)
            self.relu = nn.ReLU()

        def forward(self, x):
            x = x.view(-1, 1, 28, 28)
            x = self.pool(self.relu(self.conv1(x)))
            x = nn.ReLU()(x) # We need to manually apply ReLU here
            
            # Dynamic Hidden Layers (Executed sequentially without a loop)
            x = self.dynamic_hidden(x)
                
            # Output Layer
            x = x.view(x.size(0), -1)
            x = self.fc1(x)
            # x = torch.sigmoid(x)
            
            return x

    BATCH_SIZE_list = [BATCH_SIZE]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        global_model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"FL_ModelN{NODE}L{LAYER}_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                # torch.save(model, os.path.join(save_path,'model_init.pt'))
                save_path_name = os.path.join(save_path,'model_init.pt')
                save_model(global_model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)
                
                global_weights = global_model.state_dict()

                records = []

                X_train_tensor = {}
                y_train_tensor = {}
                for i in range(N_HONEST):
                    X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"honest_{i}"] = X_c_tensor
                    y_train_tensor[f"honest_{i}"] = y_c_tensor
                for i in range(i_poisoned):
                    X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"poison_{i}"] = X_c_tensor
                    y_train_tensor[f"poison_{i}"] = y_c_tensor

                # Training loop
                for round in range(ROUNDS):
                    # Prepare arguments for honest clients
                    
                    #randomize the training data
                    for i in range(N_HONEST):
                        perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                        X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                        y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                    honest_args = [
                        (
                            X_train_tensor[f"honest_{i}"],
                            y_train_tensor[f"honest_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(N_HONEST)
                    ]

                    # Prepare arguments for poisoned clients
                    
                    #randomize the training data
                    for i in range(i_poisoned):
                        perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                        X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                        y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                    poison_args = [
                        (
                            X_train_tensor[f"poison_{i}"],
                            y_train_tensor[f"poison_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(i_poisoned)
                    ]

                    # Run in parallel
                    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                        honest_results = list(executor.map(train_local_worker, honest_args))
                        poison_results = list(executor.map(train_local_worker, poison_args))

                    local_weights = []
                    local_sizes = []
                    local_y = []
                    local_outputs = []
                    local_preds = []
                    for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                        local_weights.append(l_w)
                        local_sizes.append(l_sz)
                        local_y.extend(l_y)
                        local_outputs.extend(l_out)
                        local_preds.extend(l_pred)
                    loss_train = multiclass_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                    acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                    # Federated averaging (weighted by client data size)
                    new_weights = {}
                    for key in global_weights.keys():
                        new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                    global_weights = new_weights
                    global_model.load_state_dict(global_weights)

                    # Evaluate
                    global_model.eval()
                    with torch.no_grad():
                        outputs = global_model(X_test_tensor)
                        # preds = (outputs > 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        loss_test = multiclass_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'round': round, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"round {round}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                # torch.save(model, os.path.join(save_path,'model_last.pt'))
                save_path_name = os.path.join(save_path,'model_last.pt')
                save_model(global_model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)

                # Save training log
                df = pd.DataFrame(records)
                
                # save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                safe_name = make_safe_filename(NAME_SAVE_update_PATH)
                save_name_path = os.path.abspath(os.path.join(save_path, f'{safe_name}.csv'))
                os.makedirs(os.path.dirname(save_name_path), exist_ok=True)

                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['round'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['round'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 round 0: loss_train=2.3112, acc_train=0.0793, loss_test=2.3330, acc_test=0.0000
# poison_percent 0 round 1: loss_train=2.3111, acc_train=0.0790, loss_test=2.3202, acc_test=0.0000
# poison_percent 0 round 2: loss_train=2.3115, acc_train=0.0666, loss_test=2.3118, acc_test=0.0000
# poison_percent 0 round 3: loss_train=2.3108, acc_train=0.0624, loss_test=2.3088, acc_test=0.0000
# poison_percent 0 round 4: loss_train=2.3104, acc_train=0.0676, loss_test=2.3092, acc_test=0.0000
# poison_percent 0 round 5: loss_train=2.3092, acc_train=0.0821, loss_test=2.3084, acc_test=0.0000
# poison_percent 0 round 6: loss_train=2.3099, acc_train=0.0697, loss_test=2.3067, acc_test=0.0000
# poison_percent 0 round 7: loss_train=2.3091, acc_train=0.0645, loss_test=2.3035, acc_test=0.0000
# poison_percent 0 round 8: loss_train=2.3103, acc_train=0.0752, loss_test=2.3017, acc_test=0.0000
# poison_percent 0 round 9: loss_train=2.3087, acc_train=0.0700, loss_test=2.2999, acc_test=0.0000
# poison_percent 0 round 10: loss_train=2.3092, acc_train=0.0800, loss_test=2.2976, acc_test=0.0000
# poison_percent 0 round 11: loss_train=2.3083, acc_train=0.0742, loss_test=2.2974, acc_test=0.0000
# poison_percent 0 round 12: loss_train=2.3075, acc_train=0.0818, loss_test=2.2992, acc_test=0.0000
# poison_percent 0 round 13: loss_train=2.3094, acc_train=0.0814, loss_test=2.2979, acc_test=0.0000
# poison_percent 0 round 14: loss_train=2.3080, acc_train=0.0693, loss_test=2.3010, acc_test=0.0000
# poison_percent 0 round 15: loss_train=2.3083, acc_train=0.0735, loss_test=2.2983, acc_test=0.0000
# poison_percent 0 round 16: loss_train=2.3071, acc_train=0.0790, loss_test=2.2996, acc_test=0.0000
# poison_percent 0 round 17: loss_train=2.3065, acc_train=0.0786, loss_test=2.2990, acc_test=0.0000
# poison_percent 0 round 18: loss_train=2.3076, acc_train=0.0821, loss_test=2.3002, acc_test=0.0000
# poison_percent 0 round 19: loss_train=2.3076, acc_train=0.0780, loss_test=2.3015, acc_test=0.0000
# poison_percent 0 round 20: loss_train=2.3068, acc_train=0.0731, loss_test=2.2977, acc_test=0.0000
# poison_percent 0 round 21: loss_train=2.3062, acc_train=0.0845, loss_test=2.2937, acc_test=0.0000
# poison_percent 0 round 22: loss_train=2.3048, acc_train=0.0966, loss_test=2.2904, acc_test=0.0208
# poison_percent 0 round 23: loss_train=2.3023, acc_train=0.1004, loss_test=2.2885, acc_test=0.0521
# poison_percent 0 round 24: loss_train=2.3016, acc_train=0.1087, loss_test=2.2832, acc_test=0.3438
# poison_percent 0 round 25: loss_train=2.2984, acc_train=0.1345, loss_test=2.2717, acc_test=0.4957
# poison_percent 0 round 26: loss_train=2.2911, acc_train=0.1845, loss_test=2.2642, acc_test=0.5012
# poison_percent 0 round 27: loss_train=2.2879, acc_train=0.1970, loss_test=2.2467, acc_test=0.5055
# poison_percent 0 round 28: loss_train=2.2809, acc_train=0.2201, loss_test=2.2309, acc_test=0.5165
# poison_percent 0 round 29: loss_train=2.2690, acc_train=0.2518, loss_test=2.2142, acc_test=0.5196
# poison_percent 0 round 30: loss_train=2.2640, acc_train=0.2187, loss_test=2.1894, acc_test=0.5178
# poison_percent 0 round 31: loss_train=2.2474, acc_train=0.2397, loss_test=2.1684, acc_test=0.5190
# poison_percent 0 round 32: loss_train=2.2382, acc_train=0.2442, loss_test=2.1433, acc_test=0.5349
# poison_percent 0 round 33: loss_train=2.2177, acc_train=0.2946, loss_test=2.1165, acc_test=0.5686
# poison_percent 0 round 34: loss_train=2.2018, acc_train=0.3118, loss_test=2.0949, acc_test=0.6048
# poison_percent 0 round 35: loss_train=2.1821, acc_train=0.3501, loss_test=2.0748, acc_test=0.6360
# poison_percent 0 round 36: loss_train=2.1640, acc_train=0.4053, loss_test=2.0492, acc_test=0.6850
# poison_percent 0 round 37: loss_train=2.1409, acc_train=0.4439, loss_test=2.0227, acc_test=0.7218
# poison_percent 0 round 38: loss_train=2.1153, acc_train=0.4940, loss_test=1.9938, acc_test=0.7837
# poison_percent 0 round 39: loss_train=2.0944, acc_train=0.5212, loss_test=1.9601, acc_test=0.8180
# poison_percent 0 round 40: loss_train=2.0725, acc_train=0.5547, loss_test=1.9316, acc_test=0.8450
# poison_percent 0 round 41: loss_train=2.0424, acc_train=0.5723, loss_test=1.8968, acc_test=0.8621
# poison_percent 0 round 42: loss_train=2.0101, acc_train=0.6109, loss_test=1.8634, acc_test=0.8897
# poison_percent 0 round 43: loss_train=1.9807, acc_train=0.6244, loss_test=1.8300, acc_test=0.8995
# poison_percent 0 round 44: loss_train=1.9506, acc_train=0.6409, loss_test=1.7887, acc_test=0.9038
# poison_percent 0 round 45: loss_train=1.9182, acc_train=0.6685, loss_test=1.7514, acc_test=0.9124
# poison_percent 0 round 46: loss_train=1.8814, acc_train=0.6789, loss_test=1.7105, acc_test=0.9185
# poison_percent 0 round 47: loss_train=1.8489, acc_train=0.6913, loss_test=1.6606, acc_test=0.9265
# poison_percent 0 round 48: loss_train=1.8144, acc_train=0.7127, loss_test=1.6252, acc_test=0.9308
# poison_percent 0 round 49: loss_train=1.7892, acc_train=0.6947, loss_test=1.5804, acc_test=0.9301
# poison_percent 0 round 50: loss_train=1.7437, acc_train=0.7154, loss_test=1.5397, acc_test=0.9308
# poison_percent 0 round 51: loss_train=1.7022, acc_train=0.7227, loss_test=1.4905, acc_test=0.9338
# poison_percent 0 round 52: loss_train=1.6640, acc_train=0.7292, loss_test=1.4477, acc_test=0.9320
# poison_percent 0 round 53: loss_train=1.6322, acc_train=0.7230, loss_test=1.3955, acc_test=0.9363
# poison_percent 0 round 54: loss_train=1.5953, acc_train=0.7437, loss_test=1.3439, acc_test=0.9381
# poison_percent 0 round 55: loss_train=1.5644, acc_train=0.7406, loss_test=1.2993, acc_test=0.9393
# poison_percent 0 round 56: loss_train=1.5166, acc_train=0.7509, loss_test=1.2598, acc_test=0.9369
# poison_percent 0 round 57: loss_train=1.4926, acc_train=0.7454, loss_test=1.2125, acc_test=0.9363
# poison_percent 0 round 58: loss_train=1.4431, acc_train=0.7616, loss_test=1.1641, acc_test=0.9350
# poison_percent 0 round 59: loss_train=1.4166, acc_train=0.7647, loss_test=1.1233, acc_test=0.9363
# poison_percent 0 round 60: loss_train=1.3915, acc_train=0.7530, loss_test=1.0746, acc_test=0.9363
# poison_percent 0 round 61: loss_train=1.3324, acc_train=0.7703, loss_test=1.0358, acc_test=0.9363
# poison_percent 0 round 62: loss_train=1.2977, acc_train=0.7641, loss_test=0.9917, acc_test=0.9387
# poison_percent 0 round 63: loss_train=1.2820, acc_train=0.7603, loss_test=0.9550, acc_test=0.9375
# poison_percent 0 round 64: loss_train=1.2544, acc_train=0.7551, loss_test=0.9090, acc_test=0.9412
# poison_percent 0 round 65: loss_train=1.2275, acc_train=0.7537, loss_test=0.8720, acc_test=0.9412
# poison_percent 0 round 66: loss_train=1.1862, acc_train=0.7599, loss_test=0.8382, acc_test=0.9424
# poison_percent 0 round 67: loss_train=1.1624, acc_train=0.7620, loss_test=0.8044, acc_test=0.9412
# poison_percent 0 round 68: loss_train=1.1347, acc_train=0.7658, loss_test=0.7695, acc_test=0.9412
# poison_percent 0 round 69: loss_train=1.0926, acc_train=0.7803, loss_test=0.7394, acc_test=0.9400
# poison_percent 0 round 70: loss_train=1.0729, acc_train=0.7803, loss_test=0.7133, acc_test=0.9400
# poison_percent 0 round 71: loss_train=1.0645, acc_train=0.7627, loss_test=0.6812, acc_test=0.9412
# poison_percent 0 round 72: loss_train=1.0159, acc_train=0.7799, loss_test=0.6510, acc_test=0.9412
# poison_percent 0 round 73: loss_train=0.9855, acc_train=0.7858, loss_test=0.6279, acc_test=0.9412
# poison_percent 0 round 74: loss_train=0.9608, acc_train=0.7910, loss_test=0.6059, acc_test=0.9418
# poison_percent 0 round 75: loss_train=0.9576, acc_train=0.7758, loss_test=0.5814, acc_test=0.9412
# poison_percent 0 round 76: loss_train=0.9329, acc_train=0.7861, loss_test=0.5569, acc_test=0.9424
# poison_percent 0 round 77: loss_train=0.9035, acc_train=0.7930, loss_test=0.5368, acc_test=0.9424
# poison_percent 0 round 78: loss_train=0.8913, acc_train=0.7913, loss_test=0.5213, acc_test=0.9418
# poison_percent 0 round 79: loss_train=0.8758, acc_train=0.7861, loss_test=0.4979, acc_test=0.9430
# poison_percent 0 round 80: loss_train=0.8674, acc_train=0.7723, loss_test=0.4810, acc_test=0.9430
# poison_percent 0 round 81: loss_train=0.8375, acc_train=0.7930, loss_test=0.4657, acc_test=0.9424
# poison_percent 0 round 82: loss_train=0.8205, acc_train=0.7875, loss_test=0.4523, acc_test=0.9424
# poison_percent 0 round 83: loss_train=0.8051, acc_train=0.7982, loss_test=0.4381, acc_test=0.9430
# poison_percent 0 round 84: loss_train=0.7820, acc_train=0.8006, loss_test=0.4219, acc_test=0.9442
# poison_percent 0 round 85: loss_train=0.7619, acc_train=0.8034, loss_test=0.4090, acc_test=0.9442
# poison_percent 0 round 86: loss_train=0.7557, acc_train=0.7999, loss_test=0.3979, acc_test=0.9436
# poison_percent 0 round 87: loss_train=0.7610, acc_train=0.7996, loss_test=0.3869, acc_test=0.9436
# poison_percent 0 round 88: loss_train=0.7680, acc_train=0.7844, loss_test=0.3767, acc_test=0.9449
# poison_percent 0 round 89: loss_train=0.7452, acc_train=0.7968, loss_test=0.3662, acc_test=0.9449
# poison_percent 0 round 90: loss_train=0.7114, acc_train=0.8079, loss_test=0.3563, acc_test=0.9455
# poison_percent 0 round 91: loss_train=0.7061, acc_train=0.8037, loss_test=0.3511, acc_test=0.9442
# poison_percent 0 round 92: loss_train=0.7049, acc_train=0.8003, loss_test=0.3396, acc_test=0.9467
# poison_percent 0 round 93: loss_train=0.7067, acc_train=0.8023, loss_test=0.3357, acc_test=0.9442
# poison_percent 0 round 94: loss_train=0.6882, acc_train=0.8072, loss_test=0.3298, acc_test=0.9449
# poison_percent 0 round 95: loss_train=0.6704, acc_train=0.8082, loss_test=0.3189, acc_test=0.9473
# poison_percent 0 round 96: loss_train=0.6599, acc_train=0.8151, loss_test=0.3141, acc_test=0.9473
# poison_percent 0 round 97: loss_train=0.6562, acc_train=0.8096, loss_test=0.3057, acc_test=0.9485
# poison_percent 0 round 98: loss_train=0.6516, acc_train=0.8227, loss_test=0.3006, acc_test=0.9485
# poison_percent 0 round 99: loss_train=0.6439, acc_train=0.8137, loss_test=0.2954, acc_test=0.9491
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\FL_ModelN1L3_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 round 0: loss_train=0.9490, acc_train=0.7407, loss_test=0.2643, acc_test=0.9577
# poison_percent 10 round 1: loss_train=0.9654, acc_train=0.7342, loss_test=0.2537, acc_test=0.9608
# poison_percent 10 round 2: loss_train=0.9420, acc_train=0.7358, loss_test=0.2505, acc_test=0.9608
# poison_percent 10 round 3: loss_train=0.9372, acc_train=0.7460, loss_test=0.2485, acc_test=0.9608
# poison_percent 10 round 4: loss_train=0.9576, acc_train=0.7345, loss_test=0.2439, acc_test=0.9608
# poison_percent 10 round 5: loss_train=0.9622, acc_train=0.7287, loss_test=0.2412, acc_test=0.9608
# poison_percent 10 round 6: loss_train=0.9369, acc_train=0.7407, loss_test=0.2382, acc_test=0.9614
# poison_percent 10 round 7: loss_train=0.9473, acc_train=0.7410, loss_test=0.2360, acc_test=0.9614
# poison_percent 10 round 8: loss_train=0.9468, acc_train=0.7330, loss_test=0.2324, acc_test=0.9620
# poison_percent 10 round 9: loss_train=0.9581, acc_train=0.7342, loss_test=0.2300, acc_test=0.9620
# poison_percent 10 round 10: loss_train=0.9484, acc_train=0.7386, loss_test=0.2270, acc_test=0.9620
# poison_percent 10 round 11: loss_train=0.9922, acc_train=0.7240, loss_test=0.2233, acc_test=0.9626
# poison_percent 10 round 12: loss_train=0.9995, acc_train=0.7290, loss_test=0.2247, acc_test=0.9608
# poison_percent 10 round 13: loss_train=0.9357, acc_train=0.7463, loss_test=0.2226, acc_test=0.9614
# poison_percent 10 round 14: loss_train=0.9312, acc_train=0.7488, loss_test=0.2157, acc_test=0.9632
# poison_percent 10 round 15: loss_train=0.9422, acc_train=0.7488, loss_test=0.2150, acc_test=0.9620
# poison_percent 10 round 16: loss_train=0.9462, acc_train=0.7410, loss_test=0.2126, acc_test=0.9632
# poison_percent 10 round 17: loss_train=0.9673, acc_train=0.7355, loss_test=0.2128, acc_test=0.9632
# poison_percent 10 round 18: loss_train=0.9311, acc_train=0.7565, loss_test=0.2098, acc_test=0.9626
# poison_percent 10 round 19: loss_train=0.9351, acc_train=0.7491, loss_test=0.2079, acc_test=0.9626
# poison_percent 10 round 20: loss_train=0.9555, acc_train=0.7512, loss_test=0.2073, acc_test=0.9632
# poison_percent 10 round 21: loss_train=0.9343, acc_train=0.7469, loss_test=0.2073, acc_test=0.9632
# poison_percent 10 round 22: loss_train=0.9731, acc_train=0.7420, loss_test=0.2017, acc_test=0.9638
# poison_percent 10 round 23: loss_train=0.9893, acc_train=0.7386, loss_test=0.2010, acc_test=0.9638
# poison_percent 10 round 24: loss_train=0.9878, acc_train=0.7364, loss_test=0.2030, acc_test=0.9638
# poison_percent 10 round 25: loss_train=0.9323, acc_train=0.7550, loss_test=0.1983, acc_test=0.9645
# poison_percent 10 round 26: loss_train=0.9611, acc_train=0.7463, loss_test=0.2007, acc_test=0.9638
# poison_percent 10 round 27: loss_train=0.9467, acc_train=0.7472, loss_test=0.1987, acc_test=0.9638
# poison_percent 10 round 28: loss_train=0.9488, acc_train=0.7485, loss_test=0.1958, acc_test=0.9626
# poison_percent 10 round 29: loss_train=0.9496, acc_train=0.7488, loss_test=0.1952, acc_test=0.9632
# poison_percent 10 round 30: loss_train=0.9389, acc_train=0.7565, loss_test=0.1933, acc_test=0.9638
# poison_percent 10 round 31: loss_train=0.9688, acc_train=0.7515, loss_test=0.1888, acc_test=0.9663
# poison_percent 10 round 32: loss_train=0.9320, acc_train=0.7571, loss_test=0.1898, acc_test=0.9651
# poison_percent 10 round 33: loss_train=0.9294, acc_train=0.7540, loss_test=0.1895, acc_test=0.9651
# poison_percent 10 round 34: loss_train=0.9242, acc_train=0.7559, loss_test=0.1880, acc_test=0.9657
# poison_percent 10 round 35: loss_train=0.9542, acc_train=0.7491, loss_test=0.1858, acc_test=0.9657
# poison_percent 10 round 36: loss_train=0.9471, acc_train=0.7488, loss_test=0.1871, acc_test=0.9657
# poison_percent 10 round 37: loss_train=0.9443, acc_train=0.7500, loss_test=0.1853, acc_test=0.9657
# poison_percent 10 round 38: loss_train=0.9352, acc_train=0.7593, loss_test=0.1842, acc_test=0.9657
# poison_percent 10 round 39: loss_train=0.9363, acc_train=0.7602, loss_test=0.1836, acc_test=0.9657
# poison_percent 10 round 40: loss_train=0.9890, acc_train=0.7543, loss_test=0.1823, acc_test=0.9657
# poison_percent 10 round 41: loss_train=0.9604, acc_train=0.7584, loss_test=0.1825, acc_test=0.9657
# poison_percent 10 round 42: loss_train=0.9486, acc_train=0.7559, loss_test=0.1802, acc_test=0.9669
# poison_percent 10 round 43: loss_train=0.9598, acc_train=0.7611, loss_test=0.1814, acc_test=0.9663
# poison_percent 10 round 44: loss_train=0.9588, acc_train=0.7519, loss_test=0.1785, acc_test=0.9663
# poison_percent 10 round 45: loss_train=0.9772, acc_train=0.7568, loss_test=0.1783, acc_test=0.9663
# poison_percent 10 round 46: loss_train=0.9451, acc_train=0.7599, loss_test=0.1782, acc_test=0.9663
# poison_percent 10 round 47: loss_train=0.9648, acc_train=0.7519, loss_test=0.1772, acc_test=0.9663
# poison_percent 10 round 48: loss_train=0.9668, acc_train=0.7593, loss_test=0.1759, acc_test=0.9663
# poison_percent 10 round 49: loss_train=0.9787, acc_train=0.7488, loss_test=0.1750, acc_test=0.9663
# poison_percent 10 round 50: loss_train=0.9726, acc_train=0.7568, loss_test=0.1764, acc_test=0.9663
# poison_percent 10 round 51: loss_train=0.9823, acc_train=0.7519, loss_test=0.1723, acc_test=0.9663
# poison_percent 10 round 52: loss_train=0.9623, acc_train=0.7611, loss_test=0.1723, acc_test=0.9663
# poison_percent 10 round 53: loss_train=0.9867, acc_train=0.7519, loss_test=0.1719, acc_test=0.9663
# poison_percent 10 round 54: loss_train=0.9689, acc_train=0.7587, loss_test=0.1708, acc_test=0.9663
# poison_percent 10 round 55: loss_train=0.9784, acc_train=0.7568, loss_test=0.1702, acc_test=0.9663
# poison_percent 10 round 56: loss_train=1.0195, acc_train=0.7460, loss_test=0.1689, acc_test=0.9663
# poison_percent 10 round 57: loss_train=0.9763, acc_train=0.7584, loss_test=0.1706, acc_test=0.9663
# poison_percent 10 round 58: loss_train=0.9633, acc_train=0.7590, loss_test=0.1680, acc_test=0.9663
# poison_percent 10 round 59: loss_train=0.9732, acc_train=0.7584, loss_test=0.1670, acc_test=0.9663
# poison_percent 10 round 60: loss_train=0.9694, acc_train=0.7577, loss_test=0.1695, acc_test=0.9663
# poison_percent 10 round 61: loss_train=1.0086, acc_train=0.7528, loss_test=0.1667, acc_test=0.9663
# poison_percent 10 round 62: loss_train=0.9770, acc_train=0.7593, loss_test=0.1677, acc_test=0.9663
# poison_percent 10 round 63: loss_train=0.9560, acc_train=0.7689, loss_test=0.1650, acc_test=0.9663
# poison_percent 10 round 64: loss_train=0.9952, acc_train=0.7571, loss_test=0.1647, acc_test=0.9657
# poison_percent 10 round 65: loss_train=0.9675, acc_train=0.7540, loss_test=0.1645, acc_test=0.9663
# poison_percent 10 round 66: loss_train=0.9797, acc_train=0.7506, loss_test=0.1643, acc_test=0.9663
# poison_percent 10 round 67: loss_train=0.9533, acc_train=0.7717, loss_test=0.1638, acc_test=0.9657
# poison_percent 10 round 68: loss_train=1.0022, acc_train=0.7503, loss_test=0.1642, acc_test=0.9657
# poison_percent 10 round 69: loss_train=0.9936, acc_train=0.7593, loss_test=0.1635, acc_test=0.9657
# poison_percent 10 round 70: loss_train=0.9725, acc_train=0.7633, loss_test=0.1627, acc_test=0.9657
# poison_percent 10 round 71: loss_train=0.9760, acc_train=0.7723, loss_test=0.1606, acc_test=0.9657
# poison_percent 10 round 72: loss_train=0.9898, acc_train=0.7633, loss_test=0.1623, acc_test=0.9657
# poison_percent 10 round 73: loss_train=1.0044, acc_train=0.7472, loss_test=0.1613, acc_test=0.9657
# poison_percent 10 round 74: loss_train=0.9959, acc_train=0.7571, loss_test=0.1623, acc_test=0.9657
# poison_percent 10 round 75: loss_train=0.9565, acc_train=0.7676, loss_test=0.1595, acc_test=0.9657
# poison_percent 10 round 76: loss_train=0.9013, acc_train=0.7689, loss_test=0.1599, acc_test=0.9657
# poison_percent 10 round 77: loss_train=1.0254, acc_train=0.7556, loss_test=0.1567, acc_test=0.9657
# poison_percent 10 round 78: loss_train=0.9514, acc_train=0.7618, loss_test=0.1579, acc_test=0.9657
# poison_percent 10 round 79: loss_train=0.9970, acc_train=0.7584, loss_test=0.1590, acc_test=0.9657
# poison_percent 10 round 80: loss_train=0.9916, acc_train=0.7593, loss_test=0.1583, acc_test=0.9657
# poison_percent 10 round 81: loss_train=0.9572, acc_train=0.7775, loss_test=0.1577, acc_test=0.9657
# poison_percent 10 round 82: loss_train=0.9619, acc_train=0.7686, loss_test=0.1586, acc_test=0.9657
# poison_percent 10 round 83: loss_train=0.9802, acc_train=0.7605, loss_test=0.1588, acc_test=0.9657
# poison_percent 10 round 84: loss_train=0.9482, acc_train=0.7698, loss_test=0.1546, acc_test=0.9669
# poison_percent 10 round 85: loss_train=0.9713, acc_train=0.7689, loss_test=0.1548, acc_test=0.9669
# poison_percent 10 round 86: loss_train=1.0108, acc_train=0.7512, loss_test=0.1544, acc_test=0.9663
# poison_percent 10 round 87: loss_train=0.9745, acc_train=0.7618, loss_test=0.1557, acc_test=0.9663
# poison_percent 10 round 88: loss_train=0.9889, acc_train=0.7584, loss_test=0.1549, acc_test=0.9663
# poison_percent 10 round 89: loss_train=0.9893, acc_train=0.7602, loss_test=0.1531, acc_test=0.9669
# poison_percent 10 round 90: loss_train=0.9645, acc_train=0.7639, loss_test=0.1526, acc_test=0.9675
# poison_percent 10 round 91: loss_train=0.9593, acc_train=0.7614, loss_test=0.1546, acc_test=0.9669
# poison_percent 10 round 92: loss_train=0.9705, acc_train=0.7738, loss_test=0.1527, acc_test=0.9669
# poison_percent 10 round 93: loss_train=0.9697, acc_train=0.7667, loss_test=0.1531, acc_test=0.9669
# poison_percent 10 round 94: loss_train=0.9534, acc_train=0.7720, loss_test=0.1525, acc_test=0.9675
# poison_percent 10 round 95: loss_train=1.0020, acc_train=0.7741, loss_test=0.1549, acc_test=0.9669
# poison_percent 10 round 96: loss_train=0.9318, acc_train=0.7778, loss_test=0.1540, acc_test=0.9669
# poison_percent 10 round 97: loss_train=0.9716, acc_train=0.7698, loss_test=0.1506, acc_test=0.9675
# poison_percent 10 round 98: loss_train=1.0025, acc_train=0.7707, loss_test=0.1512, acc_test=0.9675
# poison_percent 10 round 99: loss_train=0.9433, acc_train=0.7760, loss_test=0.1525, acc_test=0.9675
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\FL_ModelN1L3_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=1.3870, acc_train=0.6961, loss_test=0.1345, acc_test=0.9700
# poison_percent 20 round 1: loss_train=1.3474, acc_train=0.7064, loss_test=0.1292, acc_test=0.9706
# poison_percent 20 round 2: loss_train=1.3430, acc_train=0.7022, loss_test=0.1289, acc_test=0.9718
# poison_percent 20 round 3: loss_train=1.3253, acc_train=0.7042, loss_test=0.1274, acc_test=0.9718
# poison_percent 20 round 4: loss_train=1.3342, acc_train=0.7011, loss_test=0.1281, acc_test=0.9718
# poison_percent 20 round 5: loss_train=1.3283, acc_train=0.7056, loss_test=0.1269, acc_test=0.9718
# poison_percent 20 round 6: loss_train=1.3358, acc_train=0.7058, loss_test=0.1272, acc_test=0.9718
# poison_percent 20 round 7: loss_train=1.3357, acc_train=0.7022, loss_test=0.1274, acc_test=0.9718
# poison_percent 20 round 8: loss_train=1.3308, acc_train=0.7044, loss_test=0.1276, acc_test=0.9718
# poison_percent 20 round 9: loss_train=1.3230, acc_train=0.6944, loss_test=0.1277, acc_test=0.9718
# poison_percent 20 round 10: loss_train=1.2964, acc_train=0.7075, loss_test=0.1262, acc_test=0.9718
# poison_percent 20 round 11: loss_train=1.3119, acc_train=0.7083, loss_test=0.1265, acc_test=0.9718
# poison_percent 20 round 12: loss_train=1.3526, acc_train=0.7089, loss_test=0.1267, acc_test=0.9718
# poison_percent 20 round 13: loss_train=1.2985, acc_train=0.7039, loss_test=0.1271, acc_test=0.9718
# poison_percent 20 round 14: loss_train=1.2724, acc_train=0.7011, loss_test=0.1265, acc_test=0.9718
# poison_percent 20 round 15: loss_train=1.3366, acc_train=0.7056, loss_test=0.1263, acc_test=0.9718
# poison_percent 20 round 16: loss_train=1.3005, acc_train=0.7089, loss_test=0.1278, acc_test=0.9718
# poison_percent 20 round 17: loss_train=1.2724, acc_train=0.7058, loss_test=0.1283, acc_test=0.9718
# poison_percent 20 round 18: loss_train=1.3116, acc_train=0.7061, loss_test=0.1261, acc_test=0.9718
# poison_percent 20 round 19: loss_train=1.3298, acc_train=0.7008, loss_test=0.1264, acc_test=0.9718
# poison_percent 20 round 20: loss_train=1.2812, acc_train=0.7072, loss_test=0.1275, acc_test=0.9718
# poison_percent 20 round 21: loss_train=1.3088, acc_train=0.7159, loss_test=0.1261, acc_test=0.9718
# poison_percent 20 round 22: loss_train=1.2723, acc_train=0.7078, loss_test=0.1276, acc_test=0.9712
# poison_percent 20 round 23: loss_train=1.3007, acc_train=0.7033, loss_test=0.1274, acc_test=0.9718
# poison_percent 20 round 24: loss_train=1.3315, acc_train=0.7039, loss_test=0.1253, acc_test=0.9724
# poison_percent 20 round 25: loss_train=1.3126, acc_train=0.6989, loss_test=0.1267, acc_test=0.9718
# poison_percent 20 round 26: loss_train=1.2606, acc_train=0.7167, loss_test=0.1260, acc_test=0.9724
# poison_percent 20 round 27: loss_train=1.2941, acc_train=0.7042, loss_test=0.1269, acc_test=0.9712
# poison_percent 20 round 28: loss_train=1.2807, acc_train=0.7109, loss_test=0.1262, acc_test=0.9724
# poison_percent 20 round 29: loss_train=1.3256, acc_train=0.6969, loss_test=0.1250, acc_test=0.9724
# poison_percent 20 round 30: loss_train=1.2851, acc_train=0.7117, loss_test=0.1256, acc_test=0.9718
# poison_percent 20 round 31: loss_train=1.2331, acc_train=0.7150, loss_test=0.1261, acc_test=0.9724
# poison_percent 20 round 32: loss_train=1.2790, acc_train=0.7025, loss_test=0.1266, acc_test=0.9718
# poison_percent 20 round 33: loss_train=1.2868, acc_train=0.7097, loss_test=0.1248, acc_test=0.9724
# poison_percent 20 round 34: loss_train=1.2961, acc_train=0.7111, loss_test=0.1261, acc_test=0.9718
# poison_percent 20 round 35: loss_train=1.2686, acc_train=0.7075, loss_test=0.1257, acc_test=0.9724
# poison_percent 20 round 36: loss_train=1.2797, acc_train=0.7014, loss_test=0.1265, acc_test=0.9718
# poison_percent 20 round 37: loss_train=1.2820, acc_train=0.7069, loss_test=0.1250, acc_test=0.9730
# poison_percent 20 round 38: loss_train=1.2878, acc_train=0.7092, loss_test=0.1255, acc_test=0.9724
# poison_percent 20 round 39: loss_train=1.2436, acc_train=0.7131, loss_test=0.1254, acc_test=0.9724
# poison_percent 20 round 40: loss_train=1.2626, acc_train=0.7025, loss_test=0.1235, acc_test=0.9730
# poison_percent 20 round 41: loss_train=1.2875, acc_train=0.7097, loss_test=0.1258, acc_test=0.9718
# poison_percent 20 round 42: loss_train=1.2553, acc_train=0.7053, loss_test=0.1252, acc_test=0.9730
# poison_percent 20 round 43: loss_train=1.3472, acc_train=0.7050, loss_test=0.1257, acc_test=0.9730
# poison_percent 20 round 44: loss_train=1.2569, acc_train=0.7111, loss_test=0.1262, acc_test=0.9724
# poison_percent 20 round 45: loss_train=1.3062, acc_train=0.7067, loss_test=0.1261, acc_test=0.9730
# poison_percent 20 round 46: loss_train=1.2499, acc_train=0.7117, loss_test=0.1244, acc_test=0.9730
# poison_percent 20 round 47: loss_train=1.2659, acc_train=0.7120, loss_test=0.1263, acc_test=0.9718
# poison_percent 20 round 48: loss_train=1.3047, acc_train=0.7044, loss_test=0.1245, acc_test=0.9730
# poison_percent 20 round 49: loss_train=1.2996, acc_train=0.7000, loss_test=0.1249, acc_test=0.9737
# poison_percent 20 round 50: loss_train=1.2234, acc_train=0.7209, loss_test=0.1263, acc_test=0.9724
# poison_percent 20 round 51: loss_train=1.2896, acc_train=0.7047, loss_test=0.1249, acc_test=0.9730
# poison_percent 20 round 52: loss_train=1.2747, acc_train=0.7075, loss_test=0.1238, acc_test=0.9730
# poison_percent 20 round 53: loss_train=1.2949, acc_train=0.7058, loss_test=0.1245, acc_test=0.9730
# poison_percent 20 round 54: loss_train=1.2534, acc_train=0.7097, loss_test=0.1239, acc_test=0.9730
# poison_percent 20 round 55: loss_train=1.2284, acc_train=0.7162, loss_test=0.1247, acc_test=0.9730
# poison_percent 20 round 56: loss_train=1.3070, acc_train=0.7036, loss_test=0.1241, acc_test=0.9730
# poison_percent 20 round 57: loss_train=1.2492, acc_train=0.7162, loss_test=0.1245, acc_test=0.9730
# poison_percent 20 round 58: loss_train=1.2782, acc_train=0.7044, loss_test=0.1245, acc_test=0.9730
# poison_percent 20 round 59: loss_train=1.2725, acc_train=0.7058, loss_test=0.1249, acc_test=0.9730
# poison_percent 20 round 60: loss_train=1.2899, acc_train=0.7081, loss_test=0.1245, acc_test=0.9724
# poison_percent 20 round 61: loss_train=1.2587, acc_train=0.7159, loss_test=0.1232, acc_test=0.9730
# poison_percent 20 round 62: loss_train=1.3266, acc_train=0.6994, loss_test=0.1228, acc_test=0.9724
# poison_percent 20 round 63: loss_train=1.2445, acc_train=0.7131, loss_test=0.1234, acc_test=0.9724
# poison_percent 20 round 64: loss_train=1.2770, acc_train=0.7123, loss_test=0.1248, acc_test=0.9724
# poison_percent 20 round 65: loss_train=1.2639, acc_train=0.7064, loss_test=0.1248, acc_test=0.9724
# poison_percent 20 round 66: loss_train=1.2609, acc_train=0.7123, loss_test=0.1244, acc_test=0.9724
# poison_percent 20 round 67: loss_train=1.2958, acc_train=0.7064, loss_test=0.1241, acc_test=0.9724
# poison_percent 20 round 68: loss_train=1.2780, acc_train=0.7078, loss_test=0.1238, acc_test=0.9724
# poison_percent 20 round 69: loss_train=1.2581, acc_train=0.7042, loss_test=0.1238, acc_test=0.9724
# poison_percent 20 round 70: loss_train=1.2908, acc_train=0.7064, loss_test=0.1242, acc_test=0.9724
# poison_percent 20 round 71: loss_train=1.2642, acc_train=0.7075, loss_test=0.1231, acc_test=0.9724
# poison_percent 20 round 72: loss_train=1.2571, acc_train=0.7109, loss_test=0.1239, acc_test=0.9724
# poison_percent 20 round 73: loss_train=1.2434, acc_train=0.7039, loss_test=0.1226, acc_test=0.9724
# poison_percent 20 round 74: loss_train=1.2293, acc_train=0.7170, loss_test=0.1237, acc_test=0.9724
# poison_percent 20 round 75: loss_train=1.2647, acc_train=0.7164, loss_test=0.1239, acc_test=0.9724
# poison_percent 20 round 76: loss_train=1.2552, acc_train=0.7014, loss_test=0.1232, acc_test=0.9724
# poison_percent 20 round 77: loss_train=1.2615, acc_train=0.7117, loss_test=0.1243, acc_test=0.9724
# poison_percent 20 round 78: loss_train=1.3079, acc_train=0.7067, loss_test=0.1255, acc_test=0.9724
# poison_percent 20 round 79: loss_train=1.2899, acc_train=0.7036, loss_test=0.1252, acc_test=0.9724
# poison_percent 20 round 80: loss_train=1.2793, acc_train=0.7058, loss_test=0.1240, acc_test=0.9724
# poison_percent 20 round 81: loss_train=1.2812, acc_train=0.7162, loss_test=0.1245, acc_test=0.9724
# poison_percent 20 round 82: loss_train=1.2502, acc_train=0.7117, loss_test=0.1242, acc_test=0.9724
# poison_percent 20 round 83: loss_train=1.2480, acc_train=0.7170, loss_test=0.1242, acc_test=0.9724
# poison_percent 20 round 84: loss_train=1.2885, acc_train=0.7064, loss_test=0.1239, acc_test=0.9724
# poison_percent 20 round 85: loss_train=1.2485, acc_train=0.7187, loss_test=0.1230, acc_test=0.9724
# poison_percent 20 round 86: loss_train=1.2233, acc_train=0.7192, loss_test=0.1233, acc_test=0.9724
# poison_percent 20 round 87: loss_train=1.3028, acc_train=0.6944, loss_test=0.1211, acc_test=0.9724
# poison_percent 20 round 88: loss_train=1.2579, acc_train=0.7120, loss_test=0.1232, acc_test=0.9724
# poison_percent 20 round 89: loss_train=1.2450, acc_train=0.7167, loss_test=0.1229, acc_test=0.9724
# poison_percent 20 round 90: loss_train=1.2490, acc_train=0.7103, loss_test=0.1229, acc_test=0.9724
# poison_percent 20 round 91: loss_train=1.2486, acc_train=0.7234, loss_test=0.1223, acc_test=0.9724
# poison_percent 20 round 92: loss_train=1.2445, acc_train=0.7109, loss_test=0.1237, acc_test=0.9724
# poison_percent 20 round 93: loss_train=1.2652, acc_train=0.7067, loss_test=0.1233, acc_test=0.9724
# poison_percent 20 round 94: loss_train=1.2263, acc_train=0.7162, loss_test=0.1234, acc_test=0.9724
# poison_percent 20 round 95: loss_train=1.2453, acc_train=0.7164, loss_test=0.1235, acc_test=0.9724
# poison_percent 20 round 96: loss_train=1.2735, acc_train=0.7056, loss_test=0.1224, acc_test=0.9724
# poison_percent 20 round 97: loss_train=1.2411, acc_train=0.7187, loss_test=0.1216, acc_test=0.9737
# poison_percent 20 round 98: loss_train=1.2063, acc_train=0.7201, loss_test=0.1228, acc_test=0.9724
# poison_percent 20 round 99: loss_train=1.2432, acc_train=0.7187, loss_test=0.1227, acc_test=0.9724
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\FL_ModelN1L3_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=1.6293, acc_train=0.6392, loss_test=0.1085, acc_test=0.9767
# poison_percent 30 round 1: loss_train=1.6004, acc_train=0.6528, loss_test=0.1016, acc_test=0.9804
# poison_percent 30 round 2: loss_train=1.5680, acc_train=0.6444, loss_test=0.1001, acc_test=0.9804
# poison_percent 30 round 3: loss_train=1.5603, acc_train=0.6412, loss_test=0.0987, acc_test=0.9810
# poison_percent 30 round 4: loss_train=1.5259, acc_train=0.6464, loss_test=0.0994, acc_test=0.9810
# poison_percent 30 round 5: loss_train=1.5210, acc_train=0.6479, loss_test=0.0969, acc_test=0.9822
# poison_percent 30 round 6: loss_train=1.4918, acc_train=0.6471, loss_test=0.0978, acc_test=0.9816
# poison_percent 30 round 7: loss_train=1.5281, acc_train=0.6449, loss_test=0.0986, acc_test=0.9816
# poison_percent 30 round 8: loss_train=1.5021, acc_train=0.6437, loss_test=0.0979, acc_test=0.9816
# poison_percent 30 round 9: loss_train=1.5002, acc_train=0.6461, loss_test=0.0982, acc_test=0.9816
# poison_percent 30 round 10: loss_train=1.4749, acc_train=0.6548, loss_test=0.0981, acc_test=0.9822
# poison_percent 30 round 11: loss_train=1.5167, acc_train=0.6474, loss_test=0.1001, acc_test=0.9816
# poison_percent 30 round 12: loss_train=1.4113, acc_train=0.6503, loss_test=0.0989, acc_test=0.9822
# poison_percent 30 round 13: loss_train=1.4773, acc_train=0.6437, loss_test=0.1005, acc_test=0.9816
# poison_percent 30 round 14: loss_train=1.4395, acc_train=0.6518, loss_test=0.1006, acc_test=0.9822
# poison_percent 30 round 15: loss_train=1.4509, acc_train=0.6434, loss_test=0.0998, acc_test=0.9822
# poison_percent 30 round 16: loss_train=1.4734, acc_train=0.6476, loss_test=0.1011, acc_test=0.9816
# poison_percent 30 round 17: loss_train=1.4374, acc_train=0.6464, loss_test=0.1008, acc_test=0.9822
# poison_percent 30 round 18: loss_train=1.4544, acc_train=0.6461, loss_test=0.1014, acc_test=0.9822
# poison_percent 30 round 19: loss_train=1.4508, acc_train=0.6498, loss_test=0.1022, acc_test=0.9822
# poison_percent 30 round 20: loss_train=1.4328, acc_train=0.6545, loss_test=0.1029, acc_test=0.9816
# poison_percent 30 round 21: loss_train=1.4464, acc_train=0.6525, loss_test=0.1029, acc_test=0.9822
# poison_percent 30 round 22: loss_train=1.4494, acc_train=0.6498, loss_test=0.1014, acc_test=0.9822
# poison_percent 30 round 23: loss_train=1.4414, acc_train=0.6496, loss_test=0.1043, acc_test=0.9816
# poison_percent 30 round 24: loss_train=1.4509, acc_train=0.6464, loss_test=0.1022, acc_test=0.9822
# poison_percent 30 round 25: loss_train=1.4726, acc_train=0.6496, loss_test=0.1037, acc_test=0.9822
# poison_percent 30 round 26: loss_train=1.4490, acc_train=0.6424, loss_test=0.1040, acc_test=0.9828
# poison_percent 30 round 27: loss_train=1.4650, acc_train=0.6454, loss_test=0.1056, acc_test=0.9816
# poison_percent 30 round 28: loss_train=1.4562, acc_train=0.6476, loss_test=0.1047, acc_test=0.9828
# poison_percent 30 round 29: loss_train=1.4260, acc_train=0.6503, loss_test=0.1060, acc_test=0.9828
# poison_percent 30 round 30: loss_train=1.4294, acc_train=0.6481, loss_test=0.1055, acc_test=0.9828
# poison_percent 30 round 31: loss_train=1.4143, acc_train=0.6464, loss_test=0.1057, acc_test=0.9828
# poison_percent 30 round 32: loss_train=1.4484, acc_train=0.6501, loss_test=0.1055, acc_test=0.9828
# poison_percent 30 round 33: loss_train=1.4131, acc_train=0.6471, loss_test=0.1062, acc_test=0.9828
# poison_percent 30 round 34: loss_train=1.4401, acc_train=0.6454, loss_test=0.1064, acc_test=0.9828
# poison_percent 30 round 35: loss_train=1.3761, acc_train=0.6562, loss_test=0.1062, acc_test=0.9828
# poison_percent 30 round 36: loss_train=1.3646, acc_train=0.6594, loss_test=0.1051, acc_test=0.9828
# poison_percent 30 round 37: loss_train=1.4175, acc_train=0.6498, loss_test=0.1068, acc_test=0.9828
# poison_percent 30 round 38: loss_train=1.3993, acc_train=0.6567, loss_test=0.1070, acc_test=0.9822
# poison_percent 30 round 39: loss_train=1.3829, acc_train=0.6464, loss_test=0.1075, acc_test=0.9822
# poison_percent 30 round 40: loss_train=1.3983, acc_train=0.6481, loss_test=0.1080, acc_test=0.9822
# poison_percent 30 round 41: loss_train=1.4473, acc_train=0.6456, loss_test=0.1084, acc_test=0.9822
# poison_percent 30 round 42: loss_train=1.4429, acc_train=0.6400, loss_test=0.1085, acc_test=0.9822
# poison_percent 30 round 43: loss_train=1.4303, acc_train=0.6525, loss_test=0.1084, acc_test=0.9822
# poison_percent 30 round 44: loss_train=1.3903, acc_train=0.6424, loss_test=0.1076, acc_test=0.9822
# poison_percent 30 round 45: loss_train=1.4247, acc_train=0.6424, loss_test=0.1081, acc_test=0.9822
# poison_percent 30 round 46: loss_train=1.4231, acc_train=0.6449, loss_test=0.1092, acc_test=0.9822
# poison_percent 30 round 47: loss_train=1.4104, acc_train=0.6516, loss_test=0.1083, acc_test=0.9822
# poison_percent 30 round 48: loss_train=1.4092, acc_train=0.6424, loss_test=0.1084, acc_test=0.9822
# poison_percent 30 round 49: loss_train=1.4304, acc_train=0.6380, loss_test=0.1107, acc_test=0.9816
# poison_percent 30 round 50: loss_train=1.4097, acc_train=0.6503, loss_test=0.1109, acc_test=0.9816
# poison_percent 30 round 51: loss_train=1.4294, acc_train=0.6466, loss_test=0.1096, acc_test=0.9822
# poison_percent 30 round 52: loss_train=1.3820, acc_train=0.6506, loss_test=0.1099, acc_test=0.9816
# poison_percent 30 round 53: loss_train=1.3794, acc_train=0.6503, loss_test=0.1103, acc_test=0.9816
# poison_percent 30 round 54: loss_train=1.3832, acc_train=0.6511, loss_test=0.1101, acc_test=0.9822
# poison_percent 30 round 55: loss_train=1.3886, acc_train=0.6488, loss_test=0.1107, acc_test=0.9822
# poison_percent 30 round 56: loss_train=1.3928, acc_train=0.6422, loss_test=0.1096, acc_test=0.9822
# poison_percent 30 round 57: loss_train=1.3842, acc_train=0.6488, loss_test=0.1098, acc_test=0.9822
# poison_percent 30 round 58: loss_train=1.3810, acc_train=0.6424, loss_test=0.1119, acc_test=0.9816
# poison_percent 30 round 59: loss_train=1.3954, acc_train=0.6540, loss_test=0.1114, acc_test=0.9822
# poison_percent 30 round 60: loss_train=1.3669, acc_train=0.6508, loss_test=0.1120, acc_test=0.9822
# poison_percent 30 round 61: loss_train=1.3796, acc_train=0.6565, loss_test=0.1125, acc_test=0.9816
# poison_percent 30 round 62: loss_train=1.3698, acc_train=0.6535, loss_test=0.1122, acc_test=0.9816
# poison_percent 30 round 63: loss_train=1.3420, acc_train=0.6513, loss_test=0.1128, acc_test=0.9816
# poison_percent 30 round 64: loss_train=1.3789, acc_train=0.6447, loss_test=0.1140, acc_test=0.9816
# poison_percent 30 round 65: loss_train=1.4053, acc_train=0.6459, loss_test=0.1126, acc_test=0.9816
# poison_percent 30 round 66: loss_train=1.3869, acc_train=0.6414, loss_test=0.1137, acc_test=0.9816
# poison_percent 30 round 67: loss_train=1.3445, acc_train=0.6518, loss_test=0.1127, acc_test=0.9822
# poison_percent 30 round 68: loss_train=1.3700, acc_train=0.6466, loss_test=0.1131, acc_test=0.9822
# poison_percent 30 round 69: loss_train=1.3978, acc_train=0.6498, loss_test=0.1138, acc_test=0.9816
# poison_percent 30 round 70: loss_train=1.3945, acc_train=0.6451, loss_test=0.1148, acc_test=0.9816
# poison_percent 30 round 71: loss_train=1.3192, acc_train=0.6629, loss_test=0.1152, acc_test=0.9816
# poison_percent 30 round 72: loss_train=1.3755, acc_train=0.6518, loss_test=0.1145, acc_test=0.9816
# poison_percent 30 round 73: loss_train=1.4075, acc_train=0.6363, loss_test=0.1143, acc_test=0.9816
# poison_percent 30 round 74: loss_train=1.3796, acc_train=0.6479, loss_test=0.1153, acc_test=0.9810
# poison_percent 30 round 75: loss_train=1.3642, acc_train=0.6508, loss_test=0.1147, acc_test=0.9810
# poison_percent 30 round 76: loss_train=1.3785, acc_train=0.6496, loss_test=0.1142, acc_test=0.9810
# poison_percent 30 round 77: loss_train=1.3339, acc_train=0.6513, loss_test=0.1146, acc_test=0.9810
# poison_percent 30 round 78: loss_train=1.3527, acc_train=0.6486, loss_test=0.1155, acc_test=0.9810
# poison_percent 30 round 79: loss_train=1.3692, acc_train=0.6508, loss_test=0.1154, acc_test=0.9810
# poison_percent 30 round 80: loss_train=1.3538, acc_train=0.6530, loss_test=0.1162, acc_test=0.9810
# poison_percent 30 round 81: loss_train=1.3524, acc_train=0.6503, loss_test=0.1164, acc_test=0.9810
# poison_percent 30 round 82: loss_train=1.3652, acc_train=0.6483, loss_test=0.1158, acc_test=0.9810
# poison_percent 30 round 83: loss_train=1.3454, acc_train=0.6528, loss_test=0.1154, acc_test=0.9810
# poison_percent 30 round 84: loss_train=1.3395, acc_train=0.6540, loss_test=0.1159, acc_test=0.9810
# poison_percent 30 round 85: loss_train=1.3480, acc_train=0.6525, loss_test=0.1164, acc_test=0.9810
# poison_percent 30 round 86: loss_train=1.3569, acc_train=0.6533, loss_test=0.1170, acc_test=0.9810
# poison_percent 30 round 87: loss_train=1.3915, acc_train=0.6454, loss_test=0.1177, acc_test=0.9810
# poison_percent 30 round 88: loss_train=1.4136, acc_train=0.6400, loss_test=0.1172, acc_test=0.9810
# poison_percent 30 round 89: loss_train=1.3393, acc_train=0.6565, loss_test=0.1177, acc_test=0.9810
# poison_percent 30 round 90: loss_train=1.3700, acc_train=0.6550, loss_test=0.1182, acc_test=0.9810
# poison_percent 30 round 91: loss_train=1.3754, acc_train=0.6444, loss_test=0.1175, acc_test=0.9810
# poison_percent 30 round 92: loss_train=1.3584, acc_train=0.6516, loss_test=0.1185, acc_test=0.9810
# poison_percent 30 round 93: loss_train=1.3104, acc_train=0.6479, loss_test=0.1183, acc_test=0.9810
# poison_percent 30 round 94: loss_train=1.3337, acc_train=0.6565, loss_test=0.1184, acc_test=0.9810
# poison_percent 30 round 95: loss_train=1.3486, acc_train=0.6567, loss_test=0.1186, acc_test=0.9810
# poison_percent 30 round 96: loss_train=1.3312, acc_train=0.6459, loss_test=0.1187, acc_test=0.9810
# poison_percent 30 round 97: loss_train=1.3693, acc_train=0.6447, loss_test=0.1197, acc_test=0.9810
# poison_percent 30 round 98: loss_train=1.3623, acc_train=0.6442, loss_test=0.1187, acc_test=0.9810
# poison_percent 30 round 99: loss_train=1.3389, acc_train=0.6572, loss_test=0.1183, acc_test=0.9810
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\FL_ModelN1L3_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=1.6531, acc_train=0.5724, loss_test=0.1095, acc_test=0.9847
# poison_percent 40 round 1: loss_train=1.5753, acc_train=0.5867, loss_test=0.1048, acc_test=0.9853
# poison_percent 40 round 2: loss_train=1.5058, acc_train=0.5859, loss_test=0.1039, acc_test=0.9865
# poison_percent 40 round 3: loss_train=1.4784, acc_train=0.5929, loss_test=0.1057, acc_test=0.9865
# poison_percent 40 round 4: loss_train=1.4470, acc_train=0.5955, loss_test=0.1054, acc_test=0.9871
# poison_percent 40 round 5: loss_train=1.3648, acc_train=0.6094, loss_test=0.1063, acc_test=0.9877
# poison_percent 40 round 6: loss_train=1.3581, acc_train=0.6006, loss_test=0.1061, acc_test=0.9884
# poison_percent 40 round 7: loss_train=1.3758, acc_train=0.6027, loss_test=0.1072, acc_test=0.9884
# poison_percent 40 round 8: loss_train=1.3524, acc_train=0.6123, loss_test=0.1078, acc_test=0.9890
# poison_percent 40 round 9: loss_train=1.3666, acc_train=0.6085, loss_test=0.1090, acc_test=0.9877
# poison_percent 40 round 10: loss_train=1.3131, acc_train=0.6081, loss_test=0.1096, acc_test=0.9877
# poison_percent 40 round 11: loss_train=1.2719, acc_train=0.6205, loss_test=0.1113, acc_test=0.9884
# poison_percent 40 round 12: loss_train=1.2713, acc_train=0.6085, loss_test=0.1105, acc_test=0.9890
# poison_percent 40 round 13: loss_train=1.2733, acc_train=0.6158, loss_test=0.1108, acc_test=0.9896
# poison_percent 40 round 14: loss_train=1.2603, acc_train=0.6192, loss_test=0.1129, acc_test=0.9896
# poison_percent 40 round 15: loss_train=1.2766, acc_train=0.6158, loss_test=0.1135, acc_test=0.9896
# poison_percent 40 round 16: loss_train=1.2399, acc_train=0.6168, loss_test=0.1148, acc_test=0.9896
# poison_percent 40 round 17: loss_train=1.2038, acc_train=0.6290, loss_test=0.1152, acc_test=0.9896
# poison_percent 40 round 18: loss_train=1.2672, acc_train=0.6188, loss_test=0.1159, acc_test=0.9896
# poison_percent 40 round 19: loss_train=1.2290, acc_train=0.6279, loss_test=0.1171, acc_test=0.9896
# poison_percent 40 round 20: loss_train=1.2406, acc_train=0.6207, loss_test=0.1182, acc_test=0.9896
# poison_percent 40 round 21: loss_train=1.2076, acc_train=0.6181, loss_test=0.1175, acc_test=0.9896
# poison_percent 40 round 22: loss_train=1.2082, acc_train=0.6143, loss_test=0.1185, acc_test=0.9896
# poison_percent 40 round 23: loss_train=1.2204, acc_train=0.6256, loss_test=0.1199, acc_test=0.9896
# poison_percent 40 round 24: loss_train=1.1908, acc_train=0.6247, loss_test=0.1190, acc_test=0.9896
# poison_percent 40 round 25: loss_train=1.2179, acc_train=0.6202, loss_test=0.1211, acc_test=0.9890
# poison_percent 40 round 26: loss_train=1.2177, acc_train=0.6217, loss_test=0.1216, acc_test=0.9890
# poison_percent 40 round 27: loss_train=1.1929, acc_train=0.6183, loss_test=0.1214, acc_test=0.9890
# poison_percent 40 round 28: loss_train=1.2048, acc_train=0.6177, loss_test=0.1232, acc_test=0.9890
# poison_percent 40 round 29: loss_train=1.2280, acc_train=0.6123, loss_test=0.1252, acc_test=0.9890
# poison_percent 40 round 30: loss_train=1.2228, acc_train=0.6173, loss_test=0.1248, acc_test=0.9890
# poison_percent 40 round 31: loss_train=1.1805, acc_train=0.6215, loss_test=0.1245, acc_test=0.9890
# poison_percent 40 round 32: loss_train=1.1819, acc_train=0.6145, loss_test=0.1254, acc_test=0.9890
# poison_percent 40 round 33: loss_train=1.1798, acc_train=0.6173, loss_test=0.1262, acc_test=0.9890
# poison_percent 40 round 34: loss_train=1.1653, acc_train=0.6209, loss_test=0.1272, acc_test=0.9884
# poison_percent 40 round 35: loss_train=1.1803, acc_train=0.6181, loss_test=0.1283, acc_test=0.9884
# poison_percent 40 round 36: loss_train=1.1943, acc_train=0.6166, loss_test=0.1306, acc_test=0.9884
# poison_percent 40 round 37: loss_train=1.1585, acc_train=0.6205, loss_test=0.1298, acc_test=0.9884
# poison_percent 40 round 38: loss_train=1.1844, acc_train=0.6188, loss_test=0.1319, acc_test=0.9884
# poison_percent 40 round 39: loss_train=1.2144, acc_train=0.6070, loss_test=0.1324, acc_test=0.9884
# poison_percent 40 round 40: loss_train=1.1964, acc_train=0.6230, loss_test=0.1323, acc_test=0.9884
# poison_percent 40 round 41: loss_train=1.1574, acc_train=0.6194, loss_test=0.1321, acc_test=0.9896
# poison_percent 40 round 42: loss_train=1.1505, acc_train=0.6181, loss_test=0.1331, acc_test=0.9896
# poison_percent 40 round 43: loss_train=1.1512, acc_train=0.6202, loss_test=0.1339, acc_test=0.9896
# poison_percent 40 round 44: loss_train=1.1539, acc_train=0.6170, loss_test=0.1344, acc_test=0.9896
# poison_percent 40 round 45: loss_train=1.1696, acc_train=0.6170, loss_test=0.1355, acc_test=0.9896
# poison_percent 40 round 46: loss_train=1.1722, acc_train=0.6115, loss_test=0.1363, acc_test=0.9896
# poison_percent 40 round 47: loss_train=1.1796, acc_train=0.6119, loss_test=0.1359, acc_test=0.9902
# poison_percent 40 round 48: loss_train=1.1618, acc_train=0.6188, loss_test=0.1380, acc_test=0.9896
# poison_percent 40 round 49: loss_train=1.1416, acc_train=0.6277, loss_test=0.1382, acc_test=0.9896
# poison_percent 40 round 50: loss_train=1.1631, acc_train=0.6200, loss_test=0.1377, acc_test=0.9902
# poison_percent 40 round 51: loss_train=1.1351, acc_train=0.6252, loss_test=0.1394, acc_test=0.9896
# poison_percent 40 round 52: loss_train=1.1408, acc_train=0.6252, loss_test=0.1393, acc_test=0.9902
# poison_percent 40 round 53: loss_train=1.1429, acc_train=0.6309, loss_test=0.1388, acc_test=0.9902
# poison_percent 40 round 54: loss_train=1.1723, acc_train=0.6162, loss_test=0.1416, acc_test=0.9902
# poison_percent 40 round 55: loss_train=1.1567, acc_train=0.6126, loss_test=0.1416, acc_test=0.9902
# poison_percent 40 round 56: loss_train=1.1272, acc_train=0.6237, loss_test=0.1422, acc_test=0.9902
# poison_percent 40 round 57: loss_train=1.1512, acc_train=0.6111, loss_test=0.1430, acc_test=0.9902
# poison_percent 40 round 58: loss_train=1.1602, acc_train=0.6091, loss_test=0.1450, acc_test=0.9896
# poison_percent 40 round 59: loss_train=1.1468, acc_train=0.6160, loss_test=0.1453, acc_test=0.9902
# poison_percent 40 round 60: loss_train=1.1554, acc_train=0.6134, loss_test=0.1441, acc_test=0.9902
# poison_percent 40 round 61: loss_train=1.1663, acc_train=0.6141, loss_test=0.1455, acc_test=0.9902
# poison_percent 40 round 62: loss_train=1.1298, acc_train=0.6155, loss_test=0.1461, acc_test=0.9902
# poison_percent 40 round 63: loss_train=1.1580, acc_train=0.6094, loss_test=0.1459, acc_test=0.9902
# poison_percent 40 round 64: loss_train=1.1281, acc_train=0.6188, loss_test=0.1467, acc_test=0.9902
# poison_percent 40 round 65: loss_train=1.1508, acc_train=0.6162, loss_test=0.1471, acc_test=0.9902
# poison_percent 40 round 66: loss_train=1.1440, acc_train=0.6173, loss_test=0.1481, acc_test=0.9902
# poison_percent 40 round 67: loss_train=1.1527, acc_train=0.6040, loss_test=0.1484, acc_test=0.9902
# poison_percent 40 round 68: loss_train=1.1419, acc_train=0.6126, loss_test=0.1477, acc_test=0.9902
# poison_percent 40 round 69: loss_train=1.1575, acc_train=0.6057, loss_test=0.1494, acc_test=0.9902
# poison_percent 40 round 70: loss_train=1.1415, acc_train=0.6098, loss_test=0.1496, acc_test=0.9902
# poison_percent 40 round 71: loss_train=1.1432, acc_train=0.6166, loss_test=0.1522, acc_test=0.9902
# poison_percent 40 round 72: loss_train=1.1219, acc_train=0.6170, loss_test=0.1512, acc_test=0.9902
# poison_percent 40 round 73: loss_train=1.1274, acc_train=0.6132, loss_test=0.1512, acc_test=0.9902
# poison_percent 40 round 74: loss_train=1.1559, acc_train=0.6145, loss_test=0.1541, acc_test=0.9902
# poison_percent 40 round 75: loss_train=1.0933, acc_train=0.6241, loss_test=0.1541, acc_test=0.9902
# poison_percent 40 round 76: loss_train=1.1194, acc_train=0.6128, loss_test=0.1548, acc_test=0.9902
# poison_percent 40 round 77: loss_train=1.1231, acc_train=0.6109, loss_test=0.1539, acc_test=0.9902
# poison_percent 40 round 78: loss_train=1.1276, acc_train=0.6202, loss_test=0.1549, acc_test=0.9902
# ...
# poison_percent 40 round 90: loss_train=1.1389, acc_train=0.6053, loss_test=0.1613, acc_test=0.9908
# poison_percent 40 round 91: loss_train=1.1178, acc_train=0.6188, loss_test=0.1627, acc_test=0.9908
# poison_percent 40 round 92: loss_train=1.1217, acc_train=0.6153, loss_test=0.1638, acc_test=0.9902
# poison_percent 40 round 93: loss_train=1.1130, acc_train=0.6126, loss_test=0.1627, acc_test=0.9908
# poison_percent 40 round 94: loss_train=1.1025, acc_train=0.6232, loss_test=0.1647, acc_test=0.9902
# poison_percent 40 round 95: loss_train=1.1269, acc_train=0.6143, loss_test=0.1647, acc_test=0.9908
# poison_percent 40 round 96: loss_train=1.1075, acc_train=0.6168, loss_test=0.1649, acc_test=0.9902
# poison_percent 40 round 97: loss_train=1.1185, acc_train=0.6076, loss_test=0.1653, acc_test=0.9902
# poison_percent 40 round 98: loss_train=1.1235, acc_train=0.6066, loss_test=0.1654, acc_test=0.9902
# poison_percent 40 round 99: loss_train=1.1221, acc_train=0.6049, loss_test=0.1673, acc_test=0.9902
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\FL_ModelN1L3_Batchsize32_rev0\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 round 0: loss_train=1.2591, acc_train=0.5510, loss_test=0.1721, acc_test=0.9884
# poison_percent 50 round 1: loss_train=1.1955, acc_train=0.5698, loss_test=0.1764, acc_test=0.9871
# poison_percent 50 round 2: loss_train=1.1465, acc_train=0.5846, loss_test=0.1839, acc_test=0.9865
# poison_percent 50 round 3: loss_train=1.1001, acc_train=0.6005, loss_test=0.1895, acc_test=0.9859
# poison_percent 50 round 4: loss_train=1.0692, acc_train=0.6114, loss_test=0.1962, acc_test=0.9841
# poison_percent 50 round 5: loss_train=1.0371, acc_train=0.6269, loss_test=0.2030, acc_test=0.9822
# poison_percent 50 round 6: loss_train=1.0443, acc_train=0.6347, loss_test=0.2099, acc_test=0.9816
# poison_percent 50 round 7: loss_train=1.0128, acc_train=0.6446, loss_test=0.2163, acc_test=0.9804
# poison_percent 50 round 8: loss_train=0.9457, acc_train=0.6591, loss_test=0.2219, acc_test=0.9792
# poison_percent 50 round 9: loss_train=0.9550, acc_train=0.6641, loss_test=0.2277, acc_test=0.9767
# poison_percent 50 round 10: loss_train=0.9520, acc_train=0.6652, loss_test=0.2333, acc_test=0.9749
# poison_percent 50 round 11: loss_train=0.9613, acc_train=0.6652, loss_test=0.2383, acc_test=0.9724
# poison_percent 50 round 12: loss_train=0.9316, acc_train=0.6788, loss_test=0.2447, acc_test=0.9706
# poison_percent 50 round 13: loss_train=0.9196, acc_train=0.6790, loss_test=0.2462, acc_test=0.9688
# poison_percent 50 round 14: loss_train=0.9292, acc_train=0.6833, loss_test=0.2506, acc_test=0.9681
# poison_percent 50 round 15: loss_train=0.9295, acc_train=0.6837, loss_test=0.2553, acc_test=0.9669
# poison_percent 50 round 16: loss_train=0.9109, acc_train=0.6875, loss_test=0.2593, acc_test=0.9645
# poison_percent 50 round 17: loss_train=0.9229, acc_train=0.6869, loss_test=0.2655, acc_test=0.9608
# poison_percent 50 round 18: loss_train=0.8851, acc_train=0.7035, loss_test=0.2687, acc_test=0.9577
# poison_percent 50 round 19: loss_train=0.8875, acc_train=0.6983, loss_test=0.2710, acc_test=0.9571
# poison_percent 50 round 20: loss_train=0.8893, acc_train=0.7066, loss_test=0.2750, acc_test=0.9547
# poison_percent 50 round 21: loss_train=0.9080, acc_train=0.7037, loss_test=0.2761, acc_test=0.9534
# poison_percent 50 round 22: loss_train=0.8782, acc_train=0.7111, loss_test=0.2797, acc_test=0.9516
# poison_percent 50 round 23: loss_train=0.8770, acc_train=0.7198, loss_test=0.2818, acc_test=0.9498
# poison_percent 50 round 24: loss_train=0.8885, acc_train=0.7061, loss_test=0.2847, acc_test=0.9498
# poison_percent 50 round 25: loss_train=0.8857, acc_train=0.7025, loss_test=0.2862, acc_test=0.9491
# poison_percent 50 round 26: loss_train=0.8740, acc_train=0.7102, loss_test=0.2884, acc_test=0.9479
# poison_percent 50 round 27: loss_train=0.8832, acc_train=0.7124, loss_test=0.2931, acc_test=0.9455
# poison_percent 50 round 28: loss_train=0.8584, acc_train=0.7175, loss_test=0.2941, acc_test=0.9436
# poison_percent 50 round 29: loss_train=0.8925, acc_train=0.7144, loss_test=0.2952, acc_test=0.9406
# poison_percent 50 round 30: loss_train=0.8619, acc_train=0.7166, loss_test=0.2972, acc_test=0.9387
# poison_percent 50 round 31: loss_train=0.8881, acc_train=0.7142, loss_test=0.3016, acc_test=0.9320
# poison_percent 50 round 32: loss_train=0.8679, acc_train=0.7164, loss_test=0.3027, acc_test=0.9320
# poison_percent 50 round 33: loss_train=0.8694, acc_train=0.7252, loss_test=0.3086, acc_test=0.9240
# poison_percent 50 round 34: loss_train=0.8822, acc_train=0.7149, loss_test=0.3112, acc_test=0.9228
# poison_percent 50 round 35: loss_train=0.9028, acc_train=0.7099, loss_test=0.3117, acc_test=0.9234
# poison_percent 50 round 36: loss_train=0.8851, acc_train=0.7169, loss_test=0.3161, acc_test=0.9161
# poison_percent 50 round 37: loss_train=0.8661, acc_train=0.7216, loss_test=0.3156, acc_test=0.9179
# poison_percent 50 round 38: loss_train=0.8497, acc_train=0.7260, loss_test=0.3169, acc_test=0.9173
# poison_percent 50 round 39: loss_train=0.8771, acc_train=0.7166, loss_test=0.3177, acc_test=0.9179
# poison_percent 50 round 40: loss_train=0.8816, acc_train=0.7106, loss_test=0.3183, acc_test=0.9185
# poison_percent 50 round 41: loss_train=0.8545, acc_train=0.7261, loss_test=0.3215, acc_test=0.9142
# poison_percent 50 round 42: loss_train=0.8835, acc_train=0.7119, loss_test=0.3225, acc_test=0.9124
# poison_percent 50 round 43: loss_train=0.8675, acc_train=0.7171, loss_test=0.3235, acc_test=0.9130
# poison_percent 50 round 44: loss_train=0.8715, acc_train=0.7171, loss_test=0.3258, acc_test=0.9081
# poison_percent 50 round 45: loss_train=0.8720, acc_train=0.7214, loss_test=0.3289, acc_test=0.9062
# poison_percent 50 round 46: loss_train=0.8489, acc_train=0.7229, loss_test=0.3294, acc_test=0.9050
# poison_percent 50 round 47: loss_train=0.8536, acc_train=0.7229, loss_test=0.3296, acc_test=0.9050
# poison_percent 50 round 48: loss_train=0.8520, acc_train=0.7231, loss_test=0.3325, acc_test=0.9026
# poison_percent 50 round 49: loss_train=0.8781, acc_train=0.7167, loss_test=0.3358, acc_test=0.8971
# poison_percent 50 round 50: loss_train=0.8600, acc_train=0.7137, loss_test=0.3344, acc_test=0.9026
# poison_percent 50 round 51: loss_train=0.8973, acc_train=0.7008, loss_test=0.3373, acc_test=0.8971
# poison_percent 50 round 52: loss_train=0.8567, acc_train=0.7178, loss_test=0.3400, acc_test=0.8958
# poison_percent 50 round 53: loss_train=0.8789, acc_train=0.7173, loss_test=0.3410, acc_test=0.8940
# poison_percent 50 round 54: loss_train=0.8971, acc_train=0.7028, loss_test=0.3433, acc_test=0.8903
# poison_percent 50 round 55: loss_train=0.8660, acc_train=0.7106, loss_test=0.3417, acc_test=0.8940
# poison_percent 50 round 56: loss_train=0.8648, acc_train=0.7115, loss_test=0.3426, acc_test=0.8940
# poison_percent 50 round 57: loss_train=0.8706, acc_train=0.7075, loss_test=0.3442, acc_test=0.8928
# poison_percent 50 round 58: loss_train=0.8521, acc_train=0.7167, loss_test=0.3481, acc_test=0.8866
# poison_percent 50 round 59: loss_train=0.8612, acc_train=0.7158, loss_test=0.3463, acc_test=0.8891
# poison_percent 50 round 60: loss_train=0.8654, acc_train=0.7146, loss_test=0.3497, acc_test=0.8860
# poison_percent 50 round 61: loss_train=0.8433, acc_train=0.7198, loss_test=0.3520, acc_test=0.8848
# poison_percent 50 round 62: loss_train=0.8748, acc_train=0.7081, loss_test=0.3529, acc_test=0.8836
# poison_percent 50 round 63: loss_train=0.8597, acc_train=0.7158, loss_test=0.3522, acc_test=0.8873
# poison_percent 50 round 64: loss_train=0.8474, acc_train=0.7101, loss_test=0.3548, acc_test=0.8842
# poison_percent 50 round 65: loss_train=0.8789, acc_train=0.7086, loss_test=0.3554, acc_test=0.8848
# poison_percent 50 round 66: loss_train=0.8392, acc_train=0.7182, loss_test=0.3561, acc_test=0.8836
# poison_percent 50 round 67: loss_train=0.8712, acc_train=0.7095, loss_test=0.3582, acc_test=0.8817
# poison_percent 50 round 68: loss_train=0.8748, acc_train=0.7050, loss_test=0.3597, acc_test=0.8805
# poison_percent 50 round 69: loss_train=0.8577, acc_train=0.7102, loss_test=0.3622, acc_test=0.8775
# poison_percent 50 round 70: loss_train=0.8734, acc_train=0.7007, loss_test=0.3593, acc_test=0.8842
# poison_percent 50 round 71: loss_train=0.8466, acc_train=0.7155, loss_test=0.3640, acc_test=0.8781
# poison_percent 50 round 72: loss_train=0.8705, acc_train=0.7023, loss_test=0.3654, acc_test=0.8781
# poison_percent 50 round 73: loss_train=0.8695, acc_train=0.6976, loss_test=0.3682, acc_test=0.8750
# poison_percent 50 round 74: loss_train=0.8603, acc_train=0.7064, loss_test=0.3676, acc_test=0.8775
# poison_percent 50 round 75: loss_train=0.8766, acc_train=0.7005, loss_test=0.3671, acc_test=0.8793
# poison_percent 50 round 76: loss_train=0.8505, acc_train=0.7117, loss_test=0.3700, acc_test=0.8756
# poison_percent 50 round 77: loss_train=0.8439, acc_train=0.7148, loss_test=0.3730, acc_test=0.8725
# poison_percent 50 round 78: loss_train=0.8690, acc_train=0.7041, loss_test=0.3726, acc_test=0.8738
# poison_percent 50 round 79: loss_train=0.8633, acc_train=0.7113, loss_test=0.3753, acc_test=0.8701
# poison_percent 50 round 80: loss_train=0.8930, acc_train=0.6947, loss_test=0.3758, acc_test=0.8707
# poison_percent 50 round 81: loss_train=0.8742, acc_train=0.7014, loss_test=0.3744, acc_test=0.8738
# poison_percent 50 round 82: loss_train=0.8743, acc_train=0.6958, loss_test=0.3760, acc_test=0.8738
# poison_percent 50 round 83: loss_train=0.8808, acc_train=0.7025, loss_test=0.3779, acc_test=0.8725
# poison_percent 50 round 84: loss_train=0.8637, acc_train=0.7032, loss_test=0.3807, acc_test=0.8701
# poison_percent 50 round 85: loss_train=0.8622, acc_train=0.7059, loss_test=0.3803, acc_test=0.8732
# poison_percent 50 round 86: loss_train=0.8692, acc_train=0.6943, loss_test=0.3827, acc_test=0.8713
# poison_percent 50 round 87: loss_train=0.8718, acc_train=0.6999, loss_test=0.3840, acc_test=0.8701
# poison_percent 50 round 88: loss_train=0.8652, acc_train=0.7026, loss_test=0.3845, acc_test=0.8719
# poison_percent 50 round 89: loss_train=0.9075, acc_train=0.6884, loss_test=0.3852, acc_test=0.8725
# poison_percent 50 round 90: loss_train=0.8629, acc_train=0.6997, loss_test=0.3880, acc_test=0.8689
# poison_percent 50 round 91: loss_train=0.8530, acc_train=0.7072, loss_test=0.3895, acc_test=0.8676
# poison_percent 50 round 92: loss_train=0.8583, acc_train=0.7021, loss_test=0.3899, acc_test=0.8695
# poison_percent 50 round 93: loss_train=0.8678, acc_train=0.6940, loss_test=0.3921, acc_test=0.8683
# poison_percent 50 round 94: loss_train=0.8570, acc_train=0.7016, loss_test=0.3929, acc_test=0.8695
# poison_percent 50 round 95: loss_train=0.8804, acc_train=0.6945, loss_test=0.3952, acc_test=0.8658
# poison_percent 50 round 96: loss_train=0.8615, acc_train=0.6945, loss_test=0.3944, acc_test=0.8701
# poison_percent 50 round 97: loss_train=0.8769, acc_train=0.6918, loss_test=0.3976, acc_test=0.8664
# poison_percent 50 round 98: loss_train=0.8888, acc_train=0.6853, loss_test=0.4008, acc_test=0.8627
# poison_percent 50 round 99: loss_train=0.8571, acc_train=0.6997, loss_test=0.3990, acc_test=0.8664
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\FL_ModelN1L3_Batchsize32_rev0\poisoned_50percent\poisoned_50percent.csv
# poison_percent 0 round 0: loss_train=2.2998, acc_train=0.1169, loss_test=2.2168, acc_test=0.3830
# poison_percent 0 round 1: loss_train=2.2689, acc_train=0.1842, loss_test=2.1743, acc_test=0.5613
# poison_percent 0 round 2: loss_train=2.2387, acc_train=0.2528, loss_test=2.1025, acc_test=0.7825
# poison_percent 0 round 3: loss_train=2.2019, acc_train=0.3191, loss_test=2.0339, acc_test=0.8529
# poison_percent 0 round 4: loss_train=2.1575, acc_train=0.3912, loss_test=1.9530, acc_test=0.8848
# poison_percent 0 round 5: loss_train=2.1157, acc_train=0.4264, loss_test=1.8409, acc_test=0.9210
# poison_percent 0 round 6: loss_train=2.0499, acc_train=0.4905, loss_test=1.7346, acc_test=0.9277
# poison_percent 0 round 7: loss_train=2.0037, acc_train=0.4902, loss_test=1.6199, acc_test=0.9308
# poison_percent 0 round 8: loss_train=1.9305, acc_train=0.5492, loss_test=1.5046, acc_test=0.9332
# poison_percent 0 round 9: loss_train=1.8612, acc_train=0.5805, loss_test=1.3918, acc_test=0.9320
# poison_percent 0 round 10: loss_train=1.7973, acc_train=0.5892, loss_test=1.2751, acc_test=0.9295
# poison_percent 0 round 11: loss_train=1.7331, acc_train=0.6047, loss_test=1.1592, acc_test=0.9271
# poison_percent 0 round 12: loss_train=1.6651, acc_train=0.6133, loss_test=1.0540, acc_test=0.9240
# poison_percent 0 round 13: loss_train=1.5900, acc_train=0.6385, loss_test=0.9637, acc_test=0.9216
# poison_percent 0 round 14: loss_train=1.4956, acc_train=0.6685, loss_test=0.8788, acc_test=0.9197
# poison_percent 0 round 15: loss_train=1.4590, acc_train=0.6668, loss_test=0.7974, acc_test=0.9161
# poison_percent 0 round 16: loss_train=1.3615, acc_train=0.6702, loss_test=0.7346, acc_test=0.9130
# poison_percent 0 round 17: loss_train=1.2959, acc_train=0.7058, loss_test=0.6740, acc_test=0.9112
# poison_percent 0 round 18: loss_train=1.2130, acc_train=0.7171, loss_test=0.6303, acc_test=0.9081
# poison_percent 0 round 19: loss_train=1.1936, acc_train=0.7068, loss_test=0.5851, acc_test=0.9075
# poison_percent 0 round 20: loss_train=1.1597, acc_train=0.6982, loss_test=0.5441, acc_test=0.9075
# poison_percent 0 round 21: loss_train=1.0764, acc_train=0.7278, loss_test=0.5121, acc_test=0.9056
# poison_percent 0 round 22: loss_train=1.0360, acc_train=0.7254, loss_test=0.4901, acc_test=0.9050
# poison_percent 0 round 23: loss_train=0.9671, acc_train=0.7437, loss_test=0.4558, acc_test=0.9075
# poison_percent 0 round 24: loss_train=0.9231, acc_train=0.7647, loss_test=0.4342, acc_test=0.9069
# poison_percent 0 round 25: loss_train=0.8957, acc_train=0.7554, loss_test=0.4088, acc_test=0.9118
# poison_percent 0 round 26: loss_train=0.8565, acc_train=0.7730, loss_test=0.3965, acc_test=0.9093
# poison_percent 0 round 27: loss_train=0.8565, acc_train=0.7668, loss_test=0.3761, acc_test=0.9118
# poison_percent 0 round 28: loss_train=0.8172, acc_train=0.7699, loss_test=0.3628, acc_test=0.9136
# poison_percent 0 round 29: loss_train=0.7939, acc_train=0.7682, loss_test=0.3497, acc_test=0.9154
# poison_percent 0 round 30: loss_train=0.7482, acc_train=0.7823, loss_test=0.3314, acc_test=0.9167
# poison_percent 0 round 31: loss_train=0.7329, acc_train=0.7858, loss_test=0.3222, acc_test=0.9173
# poison_percent 0 round 32: loss_train=0.6941, acc_train=0.7944, loss_test=0.3078, acc_test=0.9222
# poison_percent 0 round 33: loss_train=0.6715, acc_train=0.8013, loss_test=0.2999, acc_test=0.9252
# poison_percent 0 round 34: loss_train=0.7000, acc_train=0.7941, loss_test=0.2918, acc_test=0.9271
# poison_percent 0 round 35: loss_train=0.6901, acc_train=0.8013, loss_test=0.2814, acc_test=0.9295
# poison_percent 0 round 36: loss_train=0.6566, acc_train=0.8092, loss_test=0.2766, acc_test=0.9301
# poison_percent 0 round 37: loss_train=0.6392, acc_train=0.8072, loss_test=0.2697, acc_test=0.9314
# poison_percent 0 round 38: loss_train=0.6293, acc_train=0.8151, loss_test=0.2600, acc_test=0.9332
# poison_percent 0 round 39: loss_train=0.6044, acc_train=0.8227, loss_test=0.2462, acc_test=0.9350
# poison_percent 0 round 40: loss_train=0.5863, acc_train=0.8282, loss_test=0.2432, acc_test=0.9381
# poison_percent 0 round 41: loss_train=0.5860, acc_train=0.8189, loss_test=0.2379, acc_test=0.9387
# poison_percent 0 round 42: loss_train=0.5827, acc_train=0.8261, loss_test=0.2338, acc_test=0.9400
# poison_percent 0 round 43: loss_train=0.5494, acc_train=0.8362, loss_test=0.2290, acc_test=0.9412
# poison_percent 0 round 44: loss_train=0.5751, acc_train=0.8275, loss_test=0.2243, acc_test=0.9418
# poison_percent 0 round 45: loss_train=0.5448, acc_train=0.8344, loss_test=0.2185, acc_test=0.9436
# poison_percent 0 round 46: loss_train=0.5523, acc_train=0.8379, loss_test=0.2153, acc_test=0.9455
# poison_percent 0 round 47: loss_train=0.5299, acc_train=0.8379, loss_test=0.2109, acc_test=0.9461
