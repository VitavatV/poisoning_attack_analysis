# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x
    
# save state_dict + metadata (safe, portable)
def save_model(model, img_size, n_classes, learning_rate, experiment_bs, file_path):

    state = {
        "model_state_dict": model.state_dict(),                     # CPU/GPU tensors okay
        "arch": "MNISTNet",
        "img_size": img_size,
        "num_classes": n_classes,
        "training_args": {"lr": learning_rate, "batch_size": experiment_bs}
    }
    # ensure weights are on CPU to avoid GPU-only pickle issues
    state["model_state_dict"] = {k: v.cpu() for k, v in state["model_state_dict"].items()}
    torch.save(state, file_path)
    
def load_model(file_path, device):

    checkpoint = torch.load(file_path, map_location=device)
    model = MNISTNet().to(device)              # must have MNISTNet class defined/importable
    model.load_state_dict(checkpoint["model_state_dict"])
    model.eval()
    return model

# %% [markdown]
# # 4.Loss

# %%
# def binary_cross_entropy(pred, target):
#     eps = 1e-7
#     pred = torch.clamp(pred, eps, 1 - eps)
#     return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

def multiclass_cross_entropy(logits, target, from_probs=False, eps=1e-7):
    """
    Cross-entropy loss for multiclass (e.g., 10 classes).
    - logits: Tensor shape (N, C) containing raw scores (preferred) or probabilities if from_probs=True
    - target: Tensor shape (N,) or (N,1) containing class indices (0..C-1)
    """
    if logits.dim() == 1:
        logits = logits.unsqueeze(0)
    target = target.squeeze()
    if target.dtype != torch.long:
        target = target.long()
    if from_probs:
        probs = torch.clamp(logits, eps, 1.0 - eps)
        log_probs = torch.log(probs)
        return -log_probs[torch.arange(target.size(0)), target].mean()
    return nn.functional.cross_entropy(logits, target)

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 32
N_CLASSES = 10

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_multiple_poison/train"
TEST_PATH = "../data/mnist_multiple_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
import re
def make_safe_filename(name: str) -> str:
    # remove control chars and characters invalid on Windows
    safe = re.sub(r'[<>:"/\\|?*\x00-\x1F]', '_', name)
    # strip trailing dots/spaces which are problematic on Windows
    safe = safe.rstrip('. ')
    return safe

# %%
NODE = 1
for LAYER in [3,4,5,6]: # LAYER - (first,last)
            
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            
            # 1. Define the stack of hidden layers (Linear + ReLU)
            # Use a list comprehension to create the (Linear, ReLU) pairs
            hidden_layers = []
            for _ in range(LAYER-2):
                hidden_layers.append(nn.Conv2d(NODE, NODE, kernel_size=3, padding=1))
                hidden_layers.append(nn.ReLU())
                
            # 2. Use nn.Sequential to wrap the entire dynamic stack
            self.dynamic_hidden = nn.Sequential(*hidden_layers)
            
            # Other layers
            self.conv1 = nn.Conv2d(1, NODE, kernel_size=3, padding=1) # 28x28
            self.pool = nn.MaxPool2d(2, 2) # 14x14
            self.fc1 = nn.Linear(NODE * 14 * 14, N_CLASSES)
            self.relu = nn.ReLU()

        def forward(self, x):
            x = x.view(-1, 1, 28, 28)
            x = self.pool(self.relu(self.conv1(x)))
            x = nn.ReLU()(x) # We need to manually apply ReLU here
            
            # Dynamic Hidden Layers (Executed sequentially without a loop)
            x = self.dynamic_hidden(x)
                
            # Output Layer
            x = x.view(x.size(0), -1)
            x = self.fc1(x)
            # x = torch.sigmoid(x)
            
            return x

    BATCH_SIZE_list = [32]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"CL_ModelN{NODE}L{LAYER}_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                        poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                        select='Honest+Poisoned')
                X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
                # print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
                # print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")

                X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
                y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                # torch.save(model, os.path.join(save_path,'model_init.pt'))
                save_path_name = os.path.join(save_path,'model_init.pt')
                save_model(model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)
                
                optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

                records = []

                # Training loop
                for epoch in range(EPOCHS):

                    # Train
                    model.train()
                    
                    #randomize the training data
                    perm = torch.randperm(X_train_tensor.size(0))
                    X_train_tensor = X_train_tensor[perm]
                    y_train_tensor = y_train_tensor[perm]

                    for start in range(0, X_train_tensor.size(0), experiment_bs):
                        end = start + experiment_bs
                        xb = X_train_tensor[start:end]
                        yb = y_train_tensor[start:end]
                        outputs = model(xb)
                        # preds = (outputs >= 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        acc_train = (preds == yb).float().mean().item()
                        loss_train = multiclass_cross_entropy(outputs, yb)
                        optimizer.zero_grad()
                        loss_train.backward()
                        optimizer.step()

                    # Evaluate
                    model.eval()
                    with torch.no_grad():
                        outputs = model(X_test_tensor)
                        # preds = (outputs >= 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        loss_test = multiclass_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"epoch {epoch}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                # torch.save(model, os.path.join(save_path,'model_last.pt'))
                save_path_name = os.path.join(save_path,'model_last.pt')
                save_model(model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)

                # Save training log
                df = pd.DataFrame(records)
                
                # save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                safe_name = make_safe_filename(NAME_SAVE_update_PATH)
                save_name_path = os.path.abspath(os.path.join(save_path, f'{safe_name}.csv'))
                os.makedirs(os.path.dirname(save_name_path), exist_ok=True)

                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['epoch'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['epoch'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 epoch 0: loss_train=0.1671, acc_train=1.0000, loss_test=0.2208, acc_test=0.9522
# poison_percent 0 epoch 1: loss_train=0.1017, acc_train=0.9474, loss_test=0.1220, acc_test=0.9730
# poison_percent 0 epoch 2: loss_train=0.1146, acc_train=0.9474, loss_test=0.1187, acc_test=0.9749
# poison_percent 0 epoch 3: loss_train=0.0505, acc_train=1.0000, loss_test=0.1077, acc_test=0.9767
# poison_percent 0 epoch 4: loss_train=0.2357, acc_train=0.9474, loss_test=0.0937, acc_test=0.9767
# poison_percent 0 epoch 5: loss_train=0.6425, acc_train=0.8947, loss_test=0.0924, acc_test=0.9755
# poison_percent 0 epoch 6: loss_train=0.2425, acc_train=0.8421, loss_test=0.0981, acc_test=0.9816
# poison_percent 0 epoch 7: loss_train=0.0955, acc_train=1.0000, loss_test=0.0932, acc_test=0.9767
# poison_percent 0 epoch 8: loss_train=0.3362, acc_train=0.7895, loss_test=0.1019, acc_test=0.9737
# poison_percent 0 epoch 9: loss_train=0.4309, acc_train=0.8421, loss_test=0.0926, acc_test=0.9779
# poison_percent 0 epoch 10: loss_train=0.0967, acc_train=0.9474, loss_test=0.1030, acc_test=0.9755
# poison_percent 0 epoch 11: loss_train=0.1459, acc_train=0.8947, loss_test=0.1027, acc_test=0.9743
# poison_percent 0 epoch 12: loss_train=0.0719, acc_train=1.0000, loss_test=0.1079, acc_test=0.9737
# poison_percent 0 epoch 13: loss_train=0.3011, acc_train=0.8947, loss_test=0.0810, acc_test=0.9792
# poison_percent 0 epoch 14: loss_train=0.0795, acc_train=1.0000, loss_test=0.1180, acc_test=0.9645
# poison_percent 0 epoch 15: loss_train=0.0621, acc_train=1.0000, loss_test=0.0966, acc_test=0.9743
# poison_percent 0 epoch 16: loss_train=0.9420, acc_train=0.7895, loss_test=0.0703, acc_test=0.9841
# poison_percent 0 epoch 17: loss_train=0.1287, acc_train=0.9474, loss_test=0.1109, acc_test=0.9706
# poison_percent 0 epoch 18: loss_train=0.1267, acc_train=0.9474, loss_test=0.0764, acc_test=0.9810
# poison_percent 0 epoch 19: loss_train=0.1750, acc_train=0.9474, loss_test=0.0727, acc_test=0.9835
# poison_percent 0 epoch 20: loss_train=0.0218, acc_train=1.0000, loss_test=0.1025, acc_test=0.9743
# poison_percent 0 epoch 21: loss_train=0.3604, acc_train=0.9474, loss_test=0.0926, acc_test=0.9773
# poison_percent 0 epoch 22: loss_train=0.0715, acc_train=0.9474, loss_test=0.0729, acc_test=0.9822
# poison_percent 0 epoch 23: loss_train=0.0924, acc_train=1.0000, loss_test=0.0778, acc_test=0.9810
# poison_percent 0 epoch 24: loss_train=0.0978, acc_train=0.9474, loss_test=0.0791, acc_test=0.9804
# poison_percent 0 epoch 25: loss_train=0.0425, acc_train=1.0000, loss_test=0.0910, acc_test=0.9749
# poison_percent 0 epoch 26: loss_train=0.4024, acc_train=0.7895, loss_test=0.0952, acc_test=0.9706
# poison_percent 0 epoch 27: loss_train=0.0329, acc_train=1.0000, loss_test=0.0978, acc_test=0.9749
# poison_percent 0 epoch 28: loss_train=0.0958, acc_train=0.9474, loss_test=0.1028, acc_test=0.9688
# poison_percent 0 epoch 29: loss_train=0.0327, acc_train=1.0000, loss_test=0.0893, acc_test=0.9743
# poison_percent 0 epoch 30: loss_train=0.2441, acc_train=0.8947, loss_test=0.0715, acc_test=0.9804
# poison_percent 0 epoch 31: loss_train=0.0685, acc_train=0.9474, loss_test=0.1057, acc_test=0.9718
# poison_percent 0 epoch 32: loss_train=0.0361, acc_train=1.0000, loss_test=0.0899, acc_test=0.9773
# poison_percent 0 epoch 33: loss_train=0.4365, acc_train=0.8947, loss_test=0.0935, acc_test=0.9743
# poison_percent 0 epoch 34: loss_train=0.2810, acc_train=0.9474, loss_test=0.0987, acc_test=0.9706
# poison_percent 0 epoch 35: loss_train=0.1253, acc_train=1.0000, loss_test=0.0909, acc_test=0.9755
# poison_percent 0 epoch 36: loss_train=0.1440, acc_train=0.9474, loss_test=0.1016, acc_test=0.9688
# poison_percent 0 epoch 37: loss_train=0.0384, acc_train=1.0000, loss_test=0.1153, acc_test=0.9700
# poison_percent 0 epoch 38: loss_train=0.0778, acc_train=0.9474, loss_test=0.0823, acc_test=0.9779
# poison_percent 0 epoch 39: loss_train=0.0510, acc_train=1.0000, loss_test=0.0807, acc_test=0.9798
# poison_percent 0 epoch 40: loss_train=0.0812, acc_train=1.0000, loss_test=0.0734, acc_test=0.9804
# poison_percent 0 epoch 41: loss_train=0.7597, acc_train=0.8947, loss_test=0.1089, acc_test=0.9700
# poison_percent 0 epoch 42: loss_train=0.2495, acc_train=0.9474, loss_test=0.0904, acc_test=0.9767
# poison_percent 0 epoch 43: loss_train=0.0421, acc_train=1.0000, loss_test=0.0676, acc_test=0.9816
# poison_percent 0 epoch 44: loss_train=0.0169, acc_train=1.0000, loss_test=0.0783, acc_test=0.9767
# poison_percent 0 epoch 45: loss_train=0.1102, acc_train=0.9474, loss_test=0.0809, acc_test=0.9779
# poison_percent 0 epoch 46: loss_train=0.2025, acc_train=0.9474, loss_test=0.0918, acc_test=0.9755
# poison_percent 0 epoch 47: loss_train=0.0221, acc_train=1.0000, loss_test=0.0841, acc_test=0.9786
# poison_percent 0 epoch 48: loss_train=0.0562, acc_train=1.0000, loss_test=0.0783, acc_test=0.9786
# poison_percent 0 epoch 49: loss_train=0.1082, acc_train=0.9474, loss_test=0.0831, acc_test=0.9779
# poison_percent 0 epoch 50: loss_train=0.3653, acc_train=0.8421, loss_test=0.0998, acc_test=0.9724
# poison_percent 0 epoch 51: loss_train=0.0348, acc_train=1.0000, loss_test=0.0912, acc_test=0.9761
# poison_percent 0 epoch 52: loss_train=0.3404, acc_train=0.8421, loss_test=0.1165, acc_test=0.9718
# poison_percent 0 epoch 53: loss_train=0.1782, acc_train=0.9474, loss_test=0.1071, acc_test=0.9737
# poison_percent 0 epoch 54: loss_train=0.4117, acc_train=0.9474, loss_test=0.0992, acc_test=0.9724
# poison_percent 0 epoch 55: loss_train=0.2094, acc_train=0.9474, loss_test=0.0753, acc_test=0.9804
# poison_percent 0 epoch 56: loss_train=0.0125, acc_train=1.0000, loss_test=0.0689, acc_test=0.9810
# poison_percent 0 epoch 57: loss_train=0.1395, acc_train=1.0000, loss_test=0.0692, acc_test=0.9810
# poison_percent 0 epoch 58: loss_train=0.1239, acc_train=0.8947, loss_test=0.0821, acc_test=0.9767
# poison_percent 0 epoch 59: loss_train=0.2439, acc_train=0.8947, loss_test=0.0862, acc_test=0.9761
# poison_percent 0 epoch 60: loss_train=0.1666, acc_train=0.8947, loss_test=0.1337, acc_test=0.9675
# poison_percent 0 epoch 61: loss_train=0.2515, acc_train=0.9474, loss_test=0.0859, acc_test=0.9761
# poison_percent 0 epoch 62: loss_train=0.1084, acc_train=0.9474, loss_test=0.0785, acc_test=0.9779
# poison_percent 0 epoch 63: loss_train=0.4677, acc_train=0.9474, loss_test=0.0682, acc_test=0.9798
# poison_percent 0 epoch 64: loss_train=0.0435, acc_train=1.0000, loss_test=0.0803, acc_test=0.9755
# poison_percent 0 epoch 65: loss_train=0.0284, acc_train=1.0000, loss_test=0.1024, acc_test=0.9743
# poison_percent 0 epoch 66: loss_train=0.1909, acc_train=0.8947, loss_test=0.0869, acc_test=0.9749
# poison_percent 0 epoch 67: loss_train=0.2804, acc_train=0.9474, loss_test=0.0938, acc_test=0.9749
# poison_percent 0 epoch 68: loss_train=0.1251, acc_train=1.0000, loss_test=0.1093, acc_test=0.9724
# poison_percent 0 epoch 69: loss_train=0.0944, acc_train=0.9474, loss_test=0.1134, acc_test=0.9737
# poison_percent 0 epoch 70: loss_train=0.1766, acc_train=0.9474, loss_test=0.0822, acc_test=0.9786
# poison_percent 0 epoch 71: loss_train=0.6799, acc_train=0.8421, loss_test=0.0925, acc_test=0.9718
# poison_percent 0 epoch 72: loss_train=0.3978, acc_train=0.8947, loss_test=0.1090, acc_test=0.9694
# poison_percent 0 epoch 73: loss_train=0.1197, acc_train=0.9474, loss_test=0.0934, acc_test=0.9749
# poison_percent 0 epoch 74: loss_train=0.0636, acc_train=0.9474, loss_test=0.0679, acc_test=0.9810
# poison_percent 0 epoch 75: loss_train=0.0509, acc_train=1.0000, loss_test=0.0628, acc_test=0.9828
# poison_percent 0 epoch 76: loss_train=0.0103, acc_train=1.0000, loss_test=0.0742, acc_test=0.9779
# poison_percent 0 epoch 77: loss_train=0.0373, acc_train=1.0000, loss_test=0.0677, acc_test=0.9798
# poison_percent 0 epoch 78: loss_train=0.1458, acc_train=0.9474, loss_test=0.0822, acc_test=0.9773
# poison_percent 0 epoch 79: loss_train=0.3561, acc_train=0.8947, loss_test=0.1049, acc_test=0.9737
# poison_percent 0 epoch 80: loss_train=0.0394, acc_train=1.0000, loss_test=0.0870, acc_test=0.9761
# poison_percent 0 epoch 81: loss_train=0.3094, acc_train=0.8947, loss_test=0.0691, acc_test=0.9792
# poison_percent 0 epoch 82: loss_train=0.0774, acc_train=0.9474, loss_test=0.1319, acc_test=0.9681
# poison_percent 0 epoch 83: loss_train=0.1873, acc_train=0.9474, loss_test=0.0892, acc_test=0.9761
# poison_percent 0 epoch 84: loss_train=0.2786, acc_train=0.9474, loss_test=0.0814, acc_test=0.9767
# poison_percent 0 epoch 85: loss_train=0.0227, acc_train=1.0000, loss_test=0.1060, acc_test=0.9712
# poison_percent 0 epoch 86: loss_train=0.2807, acc_train=0.8947, loss_test=0.0752, acc_test=0.9779
# poison_percent 0 epoch 87: loss_train=0.0360, acc_train=1.0000, loss_test=0.0839, acc_test=0.9773
# poison_percent 0 epoch 88: loss_train=0.1200, acc_train=0.9474, loss_test=0.0652, acc_test=0.9804
# poison_percent 0 epoch 89: loss_train=0.1006, acc_train=0.9474, loss_test=0.0946, acc_test=0.9767
# poison_percent 0 epoch 90: loss_train=0.1465, acc_train=0.9474, loss_test=0.1013, acc_test=0.9712
# poison_percent 0 epoch 91: loss_train=0.0889, acc_train=0.9474, loss_test=0.0848, acc_test=0.9773
# poison_percent 0 epoch 92: loss_train=0.0420, acc_train=1.0000, loss_test=0.0935, acc_test=0.9755
# poison_percent 0 epoch 93: loss_train=0.2105, acc_train=0.8947, loss_test=0.0869, acc_test=0.9767
# poison_percent 0 epoch 94: loss_train=0.4154, acc_train=0.8421, loss_test=0.1091, acc_test=0.9712
# poison_percent 0 epoch 95: loss_train=0.2931, acc_train=0.8947, loss_test=0.1113, acc_test=0.9712
# poison_percent 0 epoch 96: loss_train=0.1047, acc_train=0.9474, loss_test=0.0669, acc_test=0.9835
# poison_percent 0 epoch 97: loss_train=0.1678, acc_train=0.8947, loss_test=0.0592, acc_test=0.9816
# poison_percent 0 epoch 98: loss_train=0.1597, acc_train=0.9474, loss_test=0.0992, acc_test=0.9743
# poison_percent 0 epoch 99: loss_train=0.0554, acc_train=1.0000, loss_test=0.0953, acc_test=0.9743
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\CL_ModelN1L3_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 epoch 0: loss_train=0.5246, acc_train=0.8438, loss_test=0.1733, acc_test=0.9767
# poison_percent 10 epoch 1: loss_train=1.1311, acc_train=0.7500, loss_test=0.2196, acc_test=0.9755
# poison_percent 10 epoch 2: loss_train=0.4459, acc_train=0.8750, loss_test=0.2088, acc_test=0.9804
# poison_percent 10 epoch 3: loss_train=0.7832, acc_train=0.7812, loss_test=0.2223, acc_test=0.9798
# poison_percent 10 epoch 4: loss_train=0.8463, acc_train=0.7500, loss_test=0.2108, acc_test=0.9810
# poison_percent 10 epoch 5: loss_train=0.5491, acc_train=0.8750, loss_test=0.2208, acc_test=0.9773
# poison_percent 10 epoch 6: loss_train=0.5990, acc_train=0.8125, loss_test=0.2322, acc_test=0.9779
# poison_percent 10 epoch 7: loss_train=0.4365, acc_train=0.9062, loss_test=0.2237, acc_test=0.9779
# poison_percent 10 epoch 8: loss_train=0.4986, acc_train=0.8438, loss_test=0.2230, acc_test=0.9773
# poison_percent 10 epoch 9: loss_train=0.6573, acc_train=0.8125, loss_test=0.2483, acc_test=0.9614
# poison_percent 10 epoch 10: loss_train=0.4905, acc_train=0.7188, loss_test=0.1909, acc_test=0.9804
# poison_percent 10 epoch 11: loss_train=0.6507, acc_train=0.8125, loss_test=0.2046, acc_test=0.9798
# poison_percent 10 epoch 12: loss_train=0.6125, acc_train=0.8438, loss_test=0.2137, acc_test=0.9779
# poison_percent 10 epoch 13: loss_train=0.6106, acc_train=0.9062, loss_test=0.2138, acc_test=0.9786
# poison_percent 10 epoch 14: loss_train=0.4082, acc_train=0.9062, loss_test=0.2171, acc_test=0.9792
# poison_percent 10 epoch 15: loss_train=0.8877, acc_train=0.7188, loss_test=0.2283, acc_test=0.9779
# poison_percent 10 epoch 16: loss_train=0.4659, acc_train=0.8750, loss_test=0.2312, acc_test=0.9737
# poison_percent 10 epoch 17: loss_train=0.4884, acc_train=0.8750, loss_test=0.2009, acc_test=0.9816
# poison_percent 10 epoch 18: loss_train=0.5231, acc_train=0.8125, loss_test=0.2120, acc_test=0.9798
# poison_percent 10 epoch 19: loss_train=0.6645, acc_train=0.7500, loss_test=0.1951, acc_test=0.9810
# poison_percent 10 epoch 20: loss_train=0.5078, acc_train=0.8750, loss_test=0.2111, acc_test=0.9761
# poison_percent 10 epoch 21: loss_train=0.4791, acc_train=0.8438, loss_test=0.2073, acc_test=0.9810
# poison_percent 10 epoch 22: loss_train=0.6939, acc_train=0.8125, loss_test=0.2133, acc_test=0.9779
# poison_percent 10 epoch 23: loss_train=0.6924, acc_train=0.8125, loss_test=0.2317, acc_test=0.9743
# poison_percent 10 epoch 24: loss_train=0.4307, acc_train=0.8438, loss_test=0.2019, acc_test=0.9773
# poison_percent 10 epoch 25: loss_train=0.4405, acc_train=0.8125, loss_test=0.2027, acc_test=0.9798
# poison_percent 10 epoch 26: loss_train=0.3159, acc_train=0.9062, loss_test=0.2178, acc_test=0.9730
# poison_percent 10 epoch 27: loss_train=0.6982, acc_train=0.7812, loss_test=0.1843, acc_test=0.9810
# poison_percent 10 epoch 28: loss_train=0.6490, acc_train=0.8438, loss_test=0.2151, acc_test=0.9804
# poison_percent 10 epoch 29: loss_train=0.6843, acc_train=0.7500, loss_test=0.1880, acc_test=0.9816
# poison_percent 10 epoch 30: loss_train=0.6600, acc_train=0.8438, loss_test=0.1881, acc_test=0.9810
# poison_percent 10 epoch 31: loss_train=0.3633, acc_train=0.9062, loss_test=0.2146, acc_test=0.9773
# poison_percent 10 epoch 32: loss_train=0.5617, acc_train=0.8125, loss_test=0.1923, acc_test=0.9816
# poison_percent 10 epoch 33: loss_train=0.6681, acc_train=0.8438, loss_test=0.2086, acc_test=0.9773
# poison_percent 10 epoch 34: loss_train=0.4783, acc_train=0.8125, loss_test=0.2108, acc_test=0.9779
# poison_percent 10 epoch 35: loss_train=0.4712, acc_train=0.8750, loss_test=0.1949, acc_test=0.9767
# poison_percent 10 epoch 36: loss_train=0.4778, acc_train=0.7812, loss_test=0.2045, acc_test=0.9792
# poison_percent 10 epoch 37: loss_train=0.3127, acc_train=0.9375, loss_test=0.2158, acc_test=0.9779
# poison_percent 10 epoch 38: loss_train=0.3316, acc_train=0.9375, loss_test=0.1906, acc_test=0.9822
# poison_percent 10 epoch 39: loss_train=0.9336, acc_train=0.7188, loss_test=0.2059, acc_test=0.9810
# poison_percent 10 epoch 40: loss_train=0.6260, acc_train=0.8125, loss_test=0.2397, acc_test=0.9718
# poison_percent 10 epoch 41: loss_train=0.5974, acc_train=0.8438, loss_test=0.2226, acc_test=0.9749
# poison_percent 10 epoch 42: loss_train=0.4639, acc_train=0.8438, loss_test=0.2149, acc_test=0.9786
# poison_percent 10 epoch 43: loss_train=0.5511, acc_train=0.8438, loss_test=0.2185, acc_test=0.9755
# poison_percent 10 epoch 44: loss_train=0.6896, acc_train=0.7500, loss_test=0.1964, acc_test=0.9816
# poison_percent 10 epoch 45: loss_train=0.3592, acc_train=0.9062, loss_test=0.2270, acc_test=0.9749
# poison_percent 10 epoch 46: loss_train=0.4758, acc_train=0.8438, loss_test=0.2230, acc_test=0.9730
# poison_percent 10 epoch 47: loss_train=0.3338, acc_train=0.9062, loss_test=0.1999, acc_test=0.9773
# poison_percent 10 epoch 48: loss_train=0.6401, acc_train=0.7812, loss_test=0.2258, acc_test=0.9773
# poison_percent 10 epoch 49: loss_train=0.6039, acc_train=0.8125, loss_test=0.2053, acc_test=0.9804
# poison_percent 10 epoch 50: loss_train=0.5615, acc_train=0.8750, loss_test=0.2219, acc_test=0.9730
# poison_percent 10 epoch 51: loss_train=0.5544, acc_train=0.7812, loss_test=0.2028, acc_test=0.9773
# poison_percent 10 epoch 52: loss_train=0.4132, acc_train=0.8750, loss_test=0.2218, acc_test=0.9730
# poison_percent 10 epoch 53: loss_train=0.2697, acc_train=0.9375, loss_test=0.2126, acc_test=0.9786
# poison_percent 10 epoch 54: loss_train=0.5703, acc_train=0.8750, loss_test=0.2249, acc_test=0.9724
# poison_percent 10 epoch 55: loss_train=1.0284, acc_train=0.6562, loss_test=0.2132, acc_test=0.9773
# poison_percent 10 epoch 56: loss_train=0.7456, acc_train=0.8125, loss_test=0.2166, acc_test=0.9730
# poison_percent 10 epoch 57: loss_train=0.5960, acc_train=0.7500, loss_test=0.2193, acc_test=0.9767
# poison_percent 10 epoch 58: loss_train=0.4217, acc_train=0.8750, loss_test=0.2156, acc_test=0.9779
# poison_percent 10 epoch 59: loss_train=0.5014, acc_train=0.8438, loss_test=0.2246, acc_test=0.9730
# poison_percent 10 epoch 60: loss_train=0.4469, acc_train=0.8438, loss_test=0.2189, acc_test=0.9779
# poison_percent 10 epoch 61: loss_train=0.6230, acc_train=0.8125, loss_test=0.2091, acc_test=0.9779
# poison_percent 10 epoch 62: loss_train=0.4434, acc_train=0.8438, loss_test=0.2117, acc_test=0.9749
# poison_percent 10 epoch 63: loss_train=0.5541, acc_train=0.8750, loss_test=0.2464, acc_test=0.9663
# poison_percent 10 epoch 64: loss_train=0.6795, acc_train=0.8125, loss_test=0.2052, acc_test=0.9773
# poison_percent 10 epoch 65: loss_train=0.2198, acc_train=0.9688, loss_test=0.2021, acc_test=0.9779
# poison_percent 10 epoch 66: loss_train=0.8214, acc_train=0.7188, loss_test=0.1933, acc_test=0.9810
# poison_percent 10 epoch 67: loss_train=0.3391, acc_train=0.9375, loss_test=0.2164, acc_test=0.9700
# poison_percent 10 epoch 68: loss_train=0.4193, acc_train=0.9062, loss_test=0.2207, acc_test=0.9730
# poison_percent 10 epoch 69: loss_train=0.8612, acc_train=0.7500, loss_test=0.2020, acc_test=0.9798
# poison_percent 10 epoch 70: loss_train=0.6617, acc_train=0.7188, loss_test=0.2229, acc_test=0.9749
# poison_percent 10 epoch 71: loss_train=0.2021, acc_train=0.9688, loss_test=0.2127, acc_test=0.9724
# poison_percent 10 epoch 72: loss_train=0.3543, acc_train=0.9375, loss_test=0.2258, acc_test=0.9706
# poison_percent 10 epoch 73: loss_train=0.7572, acc_train=0.7188, loss_test=0.2120, acc_test=0.9755
# poison_percent 10 epoch 74: loss_train=0.6422, acc_train=0.7812, loss_test=0.2250, acc_test=0.9761
# poison_percent 10 epoch 75: loss_train=0.7755, acc_train=0.7188, loss_test=0.2011, acc_test=0.9798
# poison_percent 10 epoch 76: loss_train=0.6904, acc_train=0.7812, loss_test=0.2047, acc_test=0.9779
# poison_percent 10 epoch 77: loss_train=0.5716, acc_train=0.8125, loss_test=0.1944, acc_test=0.9798
# poison_percent 10 epoch 78: loss_train=0.5685, acc_train=0.8125, loss_test=0.2077, acc_test=0.9786
# poison_percent 10 epoch 79: loss_train=0.4122, acc_train=0.9375, loss_test=0.1799, acc_test=0.9816
# poison_percent 10 epoch 80: loss_train=0.4797, acc_train=0.8125, loss_test=0.2359, acc_test=0.9706
# poison_percent 10 epoch 81: loss_train=0.4958, acc_train=0.8125, loss_test=0.2258, acc_test=0.9724
# poison_percent 10 epoch 82: loss_train=0.6823, acc_train=0.7812, loss_test=0.1960, acc_test=0.9743
# poison_percent 10 epoch 83: loss_train=0.3832, acc_train=0.8750, loss_test=0.2202, acc_test=0.9755
# poison_percent 10 epoch 84: loss_train=0.3191, acc_train=0.9375, loss_test=0.2270, acc_test=0.9712
# poison_percent 10 epoch 85: loss_train=0.5021, acc_train=0.8438, loss_test=0.2071, acc_test=0.9798
# poison_percent 10 epoch 86: loss_train=0.2143, acc_train=0.9375, loss_test=0.2195, acc_test=0.9755
# poison_percent 10 epoch 87: loss_train=0.3810, acc_train=0.9062, loss_test=0.2186, acc_test=0.9755
# poison_percent 10 epoch 88: loss_train=0.5173, acc_train=0.8750, loss_test=0.2068, acc_test=0.9810
# poison_percent 10 epoch 89: loss_train=0.4456, acc_train=0.9062, loss_test=0.2372, acc_test=0.9712
# poison_percent 10 epoch 90: loss_train=0.4784, acc_train=0.8750, loss_test=0.2107, acc_test=0.9767
# poison_percent 10 epoch 91: loss_train=0.5684, acc_train=0.7500, loss_test=0.2091, acc_test=0.9761
# poison_percent 10 epoch 92: loss_train=0.4064, acc_train=0.8438, loss_test=0.2078, acc_test=0.9773
# poison_percent 10 epoch 93: loss_train=0.6214, acc_train=0.8438, loss_test=0.2448, acc_test=0.9657
# poison_percent 10 epoch 94: loss_train=0.4782, acc_train=0.8750, loss_test=0.1938, acc_test=0.9810
# poison_percent 10 epoch 95: loss_train=0.4766, acc_train=0.8438, loss_test=0.2160, acc_test=0.9773
# poison_percent 10 epoch 96: loss_train=0.5351, acc_train=0.8125, loss_test=0.2280, acc_test=0.9669
# poison_percent 10 epoch 97: loss_train=0.7915, acc_train=0.7500, loss_test=0.1847, acc_test=0.9798
# poison_percent 10 epoch 98: loss_train=0.4164, acc_train=0.8438, loss_test=0.2230, acc_test=0.9749
# poison_percent 10 epoch 99: loss_train=0.4838, acc_train=0.8438, loss_test=0.2263, acc_test=0.9712
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\CL_ModelN1L3_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 epoch 0: loss_train=0.9466, acc_train=0.5484, loss_test=0.3010, acc_test=0.9730
# poison_percent 20 epoch 1: loss_train=0.8890, acc_train=0.6129, loss_test=0.2834, acc_test=0.9737
# poison_percent 20 epoch 2: loss_train=0.9012, acc_train=0.6129, loss_test=0.3465, acc_test=0.9657
# poison_percent 20 epoch 3: loss_train=0.7158, acc_train=0.7419, loss_test=0.3358, acc_test=0.9651
# poison_percent 20 epoch 4: loss_train=0.7197, acc_train=0.7419, loss_test=0.3366, acc_test=0.9651
# poison_percent 20 epoch 5: loss_train=0.6424, acc_train=0.7419, loss_test=0.3348, acc_test=0.9681
# poison_percent 20 epoch 6: loss_train=0.6785, acc_train=0.7742, loss_test=0.3195, acc_test=0.9730
# poison_percent 20 epoch 7: loss_train=0.9524, acc_train=0.6129, loss_test=0.3015, acc_test=0.9718
# poison_percent 20 epoch 8: loss_train=0.5969, acc_train=0.8710, loss_test=0.3248, acc_test=0.9694
# poison_percent 20 epoch 9: loss_train=0.8487, acc_train=0.6452, loss_test=0.3339, acc_test=0.9688
# poison_percent 20 epoch 10: loss_train=0.6466, acc_train=0.7419, loss_test=0.3060, acc_test=0.9706
# poison_percent 20 epoch 11: loss_train=0.6120, acc_train=0.8065, loss_test=0.3200, acc_test=0.9694
# poison_percent 20 epoch 12: loss_train=0.6888, acc_train=0.7097, loss_test=0.3479, acc_test=0.9638
# poison_percent 20 epoch 13: loss_train=0.7775, acc_train=0.6774, loss_test=0.3183, acc_test=0.9730
# poison_percent 20 epoch 14: loss_train=0.8399, acc_train=0.6452, loss_test=0.3263, acc_test=0.9669
# poison_percent 20 epoch 15: loss_train=0.6199, acc_train=0.7742, loss_test=0.3154, acc_test=0.9718
# poison_percent 20 epoch 16: loss_train=0.6093, acc_train=0.8387, loss_test=0.3533, acc_test=0.9620
# poison_percent 20 epoch 17: loss_train=0.6147, acc_train=0.7419, loss_test=0.3259, acc_test=0.9669
# poison_percent 20 epoch 18: loss_train=0.8399, acc_train=0.7097, loss_test=0.3441, acc_test=0.9681
# poison_percent 20 epoch 19: loss_train=0.9133, acc_train=0.7097, loss_test=0.3173, acc_test=0.9730
# poison_percent 20 epoch 20: loss_train=0.6188, acc_train=0.7419, loss_test=0.3494, acc_test=0.9528
# poison_percent 20 epoch 21: loss_train=0.8198, acc_train=0.7097, loss_test=0.3590, acc_test=0.9614
# poison_percent 20 epoch 22: loss_train=0.5320, acc_train=0.7742, loss_test=0.3288, acc_test=0.9657
# poison_percent 20 epoch 23: loss_train=0.7474, acc_train=0.6452, loss_test=0.3362, acc_test=0.9651
# poison_percent 20 epoch 24: loss_train=0.8791, acc_train=0.6129, loss_test=0.3014, acc_test=0.9718
# poison_percent 20 epoch 25: loss_train=0.9875, acc_train=0.6129, loss_test=0.3356, acc_test=0.9669
# poison_percent 20 epoch 26: loss_train=0.8898, acc_train=0.6452, loss_test=0.3294, acc_test=0.9651
# poison_percent 20 epoch 27: loss_train=0.8166, acc_train=0.7097, loss_test=0.3219, acc_test=0.9675
# poison_percent 20 epoch 28: loss_train=0.6752, acc_train=0.7419, loss_test=0.3169, acc_test=0.9669
# poison_percent 20 epoch 29: loss_train=0.8394, acc_train=0.7742, loss_test=0.3049, acc_test=0.9743
# poison_percent 20 epoch 30: loss_train=0.8515, acc_train=0.7742, loss_test=0.3243, acc_test=0.9694
# poison_percent 20 epoch 31: loss_train=0.6440, acc_train=0.7419, loss_test=0.3006, acc_test=0.9724
# poison_percent 20 epoch 32: loss_train=0.7170, acc_train=0.6774, loss_test=0.3111, acc_test=0.9706
# poison_percent 20 epoch 33: loss_train=1.0483, acc_train=0.5484, loss_test=0.3256, acc_test=0.9688
# poison_percent 20 epoch 34: loss_train=0.6061, acc_train=0.7742, loss_test=0.3114, acc_test=0.9694
# poison_percent 20 epoch 35: loss_train=0.7036, acc_train=0.7419, loss_test=0.3274, acc_test=0.9632
# poison_percent 20 epoch 36: loss_train=0.6107, acc_train=0.8065, loss_test=0.3434, acc_test=0.9645
# poison_percent 20 epoch 37: loss_train=0.6332, acc_train=0.7419, loss_test=0.3034, acc_test=0.9706
# poison_percent 20 epoch 38: loss_train=0.7226, acc_train=0.7097, loss_test=0.3173, acc_test=0.9712
# poison_percent 20 epoch 39: loss_train=0.7969, acc_train=0.6774, loss_test=0.3167, acc_test=0.9712
# poison_percent 20 epoch 40: loss_train=0.9455, acc_train=0.6452, loss_test=0.3230, acc_test=0.9694
# poison_percent 20 epoch 41: loss_train=0.6769, acc_train=0.7742, loss_test=0.3393, acc_test=0.9657
# poison_percent 20 epoch 42: loss_train=0.5636, acc_train=0.8065, loss_test=0.2996, acc_test=0.9743
# poison_percent 20 epoch 43: loss_train=0.7657, acc_train=0.7419, loss_test=0.3406, acc_test=0.9657
# poison_percent 20 epoch 44: loss_train=0.6558, acc_train=0.6774, loss_test=0.3477, acc_test=0.9602
# poison_percent 20 epoch 45: loss_train=0.8555, acc_train=0.6452, loss_test=0.3231, acc_test=0.9675
# poison_percent 20 epoch 46: loss_train=1.0854, acc_train=0.6452, loss_test=0.3034, acc_test=0.9718
# poison_percent 20 epoch 47: loss_train=0.6295, acc_train=0.7419, loss_test=0.3050, acc_test=0.9749
# poison_percent 20 epoch 48: loss_train=0.6644, acc_train=0.8065, loss_test=0.3507, acc_test=0.9589
# poison_percent 20 epoch 49: loss_train=0.5528, acc_train=0.7097, loss_test=0.3615, acc_test=0.9577
# poison_percent 20 epoch 50: loss_train=0.4669, acc_train=0.8387, loss_test=0.3283, acc_test=0.9657
# poison_percent 20 epoch 51: loss_train=0.4279, acc_train=0.8710, loss_test=0.3389, acc_test=0.9651
# poison_percent 20 epoch 52: loss_train=0.7719, acc_train=0.7097, loss_test=0.3399, acc_test=0.9602
# poison_percent 20 epoch 53: loss_train=0.6961, acc_train=0.7419, loss_test=0.3800, acc_test=0.9547
# poison_percent 20 epoch 54: loss_train=0.6562, acc_train=0.7419, loss_test=0.3385, acc_test=0.9675
# poison_percent 20 epoch 55: loss_train=0.6730, acc_train=0.7419, loss_test=0.3138, acc_test=0.9712
# poison_percent 20 epoch 56: loss_train=0.7928, acc_train=0.7097, loss_test=0.3342, acc_test=0.9681
# poison_percent 20 epoch 57: loss_train=0.5922, acc_train=0.8065, loss_test=0.3090, acc_test=0.9706
# poison_percent 20 epoch 58: loss_train=0.6164, acc_train=0.8065, loss_test=0.3322, acc_test=0.9700
# poison_percent 20 epoch 59: loss_train=0.8138, acc_train=0.7097, loss_test=0.3162, acc_test=0.9724
# poison_percent 20 epoch 60: loss_train=0.7258, acc_train=0.7097, loss_test=0.3169, acc_test=0.9688
# poison_percent 20 epoch 61: loss_train=0.4886, acc_train=0.8387, loss_test=0.3114, acc_test=0.9749
# poison_percent 20 epoch 62: loss_train=0.5371, acc_train=0.8387, loss_test=0.3350, acc_test=0.9583
# poison_percent 20 epoch 63: loss_train=1.0705, acc_train=0.5806, loss_test=0.3401, acc_test=0.9651
# poison_percent 20 epoch 64: loss_train=0.6731, acc_train=0.6774, loss_test=0.2953, acc_test=0.9773
# poison_percent 20 epoch 65: loss_train=0.7447, acc_train=0.7419, loss_test=0.3209, acc_test=0.9663
# poison_percent 20 epoch 66: loss_train=0.5760, acc_train=0.8387, loss_test=0.3201, acc_test=0.9645
# poison_percent 20 epoch 67: loss_train=0.5816, acc_train=0.8065, loss_test=0.3371, acc_test=0.9681
# poison_percent 20 epoch 68: loss_train=0.5720, acc_train=0.8065, loss_test=0.3236, acc_test=0.9700
# poison_percent 20 epoch 69: loss_train=0.6946, acc_train=0.7419, loss_test=0.2994, acc_test=0.9681
# poison_percent 20 epoch 70: loss_train=0.8199, acc_train=0.6129, loss_test=0.3301, acc_test=0.9675
# poison_percent 20 epoch 71: loss_train=0.6767, acc_train=0.7097, loss_test=0.3324, acc_test=0.9626
# poison_percent 20 epoch 72: loss_train=0.7415, acc_train=0.7097, loss_test=0.3013, acc_test=0.9675
# poison_percent 20 epoch 73: loss_train=0.8615, acc_train=0.6774, loss_test=0.3267, acc_test=0.9706
# poison_percent 20 epoch 74: loss_train=0.7518, acc_train=0.7742, loss_test=0.3335, acc_test=0.9663
# poison_percent 20 epoch 75: loss_train=0.9650, acc_train=0.6452, loss_test=0.3319, acc_test=0.9663
# poison_percent 20 epoch 76: loss_train=0.8374, acc_train=0.6452, loss_test=0.3123, acc_test=0.9730
# poison_percent 20 epoch 77: loss_train=0.9061, acc_train=0.7419, loss_test=0.3358, acc_test=0.9688
# poison_percent 20 epoch 78: loss_train=1.1571, acc_train=0.5484, loss_test=0.3193, acc_test=0.9651
# poison_percent 20 epoch 79: loss_train=0.7201, acc_train=0.6774, loss_test=0.3337, acc_test=0.9645
# poison_percent 20 epoch 80: loss_train=0.6709, acc_train=0.8065, loss_test=0.3312, acc_test=0.9688
# poison_percent 20 epoch 81: loss_train=0.6810, acc_train=0.7097, loss_test=0.3307, acc_test=0.9571
# poison_percent 20 epoch 82: loss_train=0.5598, acc_train=0.8387, loss_test=0.3273, acc_test=0.9669
# poison_percent 20 epoch 83: loss_train=0.7633, acc_train=0.6774, loss_test=0.3496, acc_test=0.9645
# poison_percent 20 epoch 84: loss_train=0.5846, acc_train=0.8387, loss_test=0.3097, acc_test=0.9669
# poison_percent 20 epoch 85: loss_train=0.7494, acc_train=0.6452, loss_test=0.3201, acc_test=0.9700
# poison_percent 20 epoch 86: loss_train=0.7026, acc_train=0.6774, loss_test=0.2812, acc_test=0.9767
# poison_percent 20 epoch 87: loss_train=0.8823, acc_train=0.5806, loss_test=0.3339, acc_test=0.9638
# poison_percent 20 epoch 88: loss_train=0.9013, acc_train=0.6129, loss_test=0.3237, acc_test=0.9688
# poison_percent 20 epoch 89: loss_train=0.7361, acc_train=0.6774, loss_test=0.3172, acc_test=0.9700
# poison_percent 20 epoch 90: loss_train=0.6753, acc_train=0.7097, loss_test=0.3028, acc_test=0.9688
# poison_percent 20 epoch 91: loss_train=0.5923, acc_train=0.8710, loss_test=0.3207, acc_test=0.9712
# poison_percent 20 epoch 92: loss_train=0.7831, acc_train=0.7419, loss_test=0.3342, acc_test=0.9675
# poison_percent 20 epoch 93: loss_train=0.8630, acc_train=0.6774, loss_test=0.3528, acc_test=0.9430
# poison_percent 20 epoch 94: loss_train=0.8131, acc_train=0.6774, loss_test=0.3199, acc_test=0.9712
# poison_percent 20 epoch 95: loss_train=0.6141, acc_train=0.8065, loss_test=0.3278, acc_test=0.9632
# poison_percent 20 epoch 96: loss_train=0.7325, acc_train=0.6774, loss_test=0.3114, acc_test=0.9743
# poison_percent 20 epoch 97: loss_train=1.0986, acc_train=0.6129, loss_test=0.3217, acc_test=0.9688
# poison_percent 20 epoch 98: loss_train=0.7584, acc_train=0.6774, loss_test=0.3240, acc_test=0.9706
# poison_percent 20 epoch 99: loss_train=0.6862, acc_train=0.8065, loss_test=0.3425, acc_test=0.9675
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\CL_ModelN1L3_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 epoch 0: loss_train=0.8311, acc_train=0.6154, loss_test=0.4621, acc_test=0.9473
# poison_percent 30 epoch 1: loss_train=0.5592, acc_train=0.8077, loss_test=0.4655, acc_test=0.9350
# poison_percent 30 epoch 2: loss_train=0.8004, acc_train=0.6538, loss_test=0.4466, acc_test=0.9442
# poison_percent 30 epoch 3: loss_train=0.9710, acc_train=0.6538, loss_test=0.4562, acc_test=0.9203
# poison_percent 30 epoch 4: loss_train=0.6632, acc_train=0.6923, loss_test=0.4458, acc_test=0.9504
# poison_percent 30 epoch 5: loss_train=0.6022, acc_train=0.7308, loss_test=0.4256, acc_test=0.9571
# poison_percent 30 epoch 6: loss_train=1.1063, acc_train=0.3846, loss_test=0.4745, acc_test=0.9430
# poison_percent 30 epoch 7: loss_train=0.8781, acc_train=0.4615, loss_test=0.4700, acc_test=0.9326
# poison_percent 30 epoch 8: loss_train=0.9985, acc_train=0.5000, loss_test=0.4541, acc_test=0.9510
# poison_percent 30 epoch 9: loss_train=0.6524, acc_train=0.7692, loss_test=0.4702, acc_test=0.9498
# poison_percent 30 epoch 10: loss_train=0.8704, acc_train=0.6154, loss_test=0.4599, acc_test=0.9375
# poison_percent 30 epoch 11: loss_train=0.7634, acc_train=0.5769, loss_test=0.4798, acc_test=0.9093
# poison_percent 30 epoch 12: loss_train=1.0742, acc_train=0.5385, loss_test=0.4467, acc_test=0.9540
# poison_percent 30 epoch 13: loss_train=0.8679, acc_train=0.5385, loss_test=0.4371, acc_test=0.9571
# poison_percent 30 epoch 14: loss_train=0.8165, acc_train=0.5769, loss_test=0.4752, acc_test=0.9442
# poison_percent 30 epoch 15: loss_train=0.8041, acc_train=0.6538, loss_test=0.4384, acc_test=0.9148
# poison_percent 30 epoch 16: loss_train=0.7085, acc_train=0.6538, loss_test=0.4655, acc_test=0.9338
# poison_percent 30 epoch 17: loss_train=0.9240, acc_train=0.6154, loss_test=0.4524, acc_test=0.9449
# poison_percent 30 epoch 18: loss_train=0.8249, acc_train=0.5769, loss_test=0.4728, acc_test=0.9161
# poison_percent 30 epoch 19: loss_train=0.9148, acc_train=0.5769, loss_test=0.4354, acc_test=0.9424
# poison_percent 30 epoch 20: loss_train=0.9735, acc_train=0.5769, loss_test=0.4657, acc_test=0.9498
# poison_percent 30 epoch 21: loss_train=0.8619, acc_train=0.5769, loss_test=0.4759, acc_test=0.9344
# poison_percent 30 epoch 22: loss_train=0.9872, acc_train=0.5385, loss_test=0.4454, acc_test=0.9510
# poison_percent 30 epoch 23: loss_train=0.6944, acc_train=0.6154, loss_test=0.4328, acc_test=0.9528
# poison_percent 30 epoch 24: loss_train=0.8128, acc_train=0.5000, loss_test=0.4837, acc_test=0.9252
# poison_percent 30 epoch 25: loss_train=0.5438, acc_train=0.8077, loss_test=0.4689, acc_test=0.9467
# poison_percent 30 epoch 26: loss_train=0.5952, acc_train=0.8077, loss_test=0.4524, acc_test=0.9516
# poison_percent 30 epoch 27: loss_train=0.9778, acc_train=0.5385, loss_test=0.4361, acc_test=0.9516
# poison_percent 30 epoch 28: loss_train=0.7676, acc_train=0.6154, loss_test=0.4632, acc_test=0.9491
# poison_percent 30 epoch 29: loss_train=1.0213, acc_train=0.5385, loss_test=0.4711, acc_test=0.9442
# poison_percent 30 epoch 30: loss_train=0.8222, acc_train=0.6538, loss_test=0.4548, acc_test=0.9449
# poison_percent 30 epoch 31: loss_train=0.5231, acc_train=0.8077, loss_test=0.4741, acc_test=0.9203
# poison_percent 30 epoch 32: loss_train=1.1797, acc_train=0.5385, loss_test=0.4497, acc_test=0.9522
# poison_percent 30 epoch 33: loss_train=0.8258, acc_train=0.6154, loss_test=0.5115, acc_test=0.9277
# poison_percent 30 epoch 34: loss_train=0.8351, acc_train=0.5769, loss_test=0.4816, acc_test=0.8952
# poison_percent 30 epoch 35: loss_train=0.7542, acc_train=0.6538, loss_test=0.4431, acc_test=0.9461
# poison_percent 30 epoch 36: loss_train=0.9482, acc_train=0.4615, loss_test=0.4826, acc_test=0.9265
# poison_percent 30 epoch 37: loss_train=0.6748, acc_train=0.6538, loss_test=0.4708, acc_test=0.9357
# poison_percent 30 epoch 38: loss_train=0.7932, acc_train=0.5000, loss_test=0.4363, acc_test=0.9442
# poison_percent 30 epoch 39: loss_train=0.7992, acc_train=0.5769, loss_test=0.4837, acc_test=0.9252
# poison_percent 30 epoch 40: loss_train=0.9457, acc_train=0.6538, loss_test=0.4505, acc_test=0.9461
# poison_percent 30 epoch 41: loss_train=0.5945, acc_train=0.7308, loss_test=0.4710, acc_test=0.9363
# poison_percent 30 epoch 42: loss_train=0.8698, acc_train=0.5000, loss_test=0.4704, acc_test=0.9105
# poison_percent 30 epoch 43: loss_train=0.8488, acc_train=0.6923, loss_test=0.4459, acc_test=0.9528
# poison_percent 30 epoch 44: loss_train=0.7936, acc_train=0.5769, loss_test=0.4528, acc_test=0.9400
# poison_percent 30 epoch 45: loss_train=0.7519, acc_train=0.6154, loss_test=0.4627, acc_test=0.9485
# poison_percent 30 epoch 46: loss_train=0.6119, acc_train=0.6923, loss_test=0.4382, acc_test=0.9461
# poison_percent 30 epoch 47: loss_train=0.9189, acc_train=0.5000, loss_test=0.4375, acc_test=0.9528
# poison_percent 30 epoch 48: loss_train=0.5686, acc_train=0.8077, loss_test=0.4685, acc_test=0.9442
# poison_percent 30 epoch 49: loss_train=0.7818, acc_train=0.6154, loss_test=0.4599, acc_test=0.9510
# poison_percent 30 epoch 50: loss_train=0.8989, acc_train=0.6154, loss_test=0.4682, acc_test=0.9393
# poison_percent 30 epoch 51: loss_train=0.7522, acc_train=0.6154, loss_test=0.4662, acc_test=0.9406
# poison_percent 30 epoch 52: loss_train=0.8385, acc_train=0.5769, loss_test=0.4511, acc_test=0.9467
# poison_percent 30 epoch 53: loss_train=0.9198, acc_train=0.5385, loss_test=0.4463, acc_test=0.9491
# poison_percent 30 epoch 54: loss_train=0.6085, acc_train=0.7692, loss_test=0.4502, acc_test=0.9528
# poison_percent 30 epoch 55: loss_train=0.7986, acc_train=0.6923, loss_test=0.4159, acc_test=0.9583
# poison_percent 30 epoch 56: loss_train=0.7451, acc_train=0.6538, loss_test=0.4653, acc_test=0.9277
# poison_percent 30 epoch 57: loss_train=0.7722, acc_train=0.6538, loss_test=0.4838, acc_test=0.9259
# poison_percent 30 epoch 58: loss_train=0.9688, acc_train=0.5385, loss_test=0.4880, acc_test=0.9277
# poison_percent 30 epoch 59: loss_train=0.9544, acc_train=0.5769, loss_test=0.4599, acc_test=0.9461
# poison_percent 30 epoch 60: loss_train=0.9874, acc_train=0.5769, loss_test=0.4411, acc_test=0.9547
# poison_percent 30 epoch 61: loss_train=0.7976, acc_train=0.6538, loss_test=0.4689, acc_test=0.9510
# poison_percent 30 epoch 62: loss_train=0.7263, acc_train=0.7308, loss_test=0.4636, acc_test=0.9252
# poison_percent 30 epoch 63: loss_train=0.7366, acc_train=0.6538, loss_test=0.4434, acc_test=0.9540
# poison_percent 30 epoch 64: loss_train=0.8856, acc_train=0.5385, loss_test=0.4657, acc_test=0.9461
# poison_percent 30 epoch 65: loss_train=0.6758, acc_train=0.6538, loss_test=0.4524, acc_test=0.9485
# poison_percent 30 epoch 66: loss_train=0.6858, acc_train=0.7308, loss_test=0.4463, acc_test=0.9455
# poison_percent 30 epoch 67: loss_train=0.7259, acc_train=0.6538, loss_test=0.4513, acc_test=0.9504
# poison_percent 30 epoch 68: loss_train=0.8025, acc_train=0.6154, loss_test=0.4927, acc_test=0.9393
# poison_percent 30 epoch 69: loss_train=0.4741, acc_train=0.8462, loss_test=0.4317, acc_test=0.9540
# poison_percent 30 epoch 70: loss_train=0.6585, acc_train=0.6923, loss_test=0.4375, acc_test=0.9522
# poison_percent 30 epoch 71: loss_train=0.7813, acc_train=0.5769, loss_test=0.4414, acc_test=0.9467
# poison_percent 30 epoch 72: loss_train=0.8840, acc_train=0.6154, loss_test=0.4515, acc_test=0.9491
# poison_percent 30 epoch 73: loss_train=0.7449, acc_train=0.6538, loss_test=0.5154, acc_test=0.9148
# poison_percent 30 epoch 74: loss_train=0.9409, acc_train=0.4615, loss_test=0.4531, acc_test=0.9498
# poison_percent 30 epoch 75: loss_train=0.8796, acc_train=0.5385, loss_test=0.4379, acc_test=0.9473
# poison_percent 30 epoch 76: loss_train=0.8214, acc_train=0.6538, loss_test=0.4774, acc_test=0.8983
# poison_percent 30 epoch 77: loss_train=0.7127, acc_train=0.6538, loss_test=0.4626, acc_test=0.9504
# poison_percent 30 epoch 78: loss_train=0.6339, acc_train=0.8077, loss_test=0.4932, acc_test=0.8983
# poison_percent 30 epoch 79: loss_train=0.6756, acc_train=0.6923, loss_test=0.4332, acc_test=0.9547
# poison_percent 30 epoch 80: loss_train=0.9585, acc_train=0.5385, loss_test=0.4474, acc_test=0.9516
# poison_percent 30 epoch 81: loss_train=0.6410, acc_train=0.8077, loss_test=0.5240, acc_test=0.8254
# poison_percent 30 epoch 82: loss_train=0.4728, acc_train=0.8846, loss_test=0.4615, acc_test=0.9375
# poison_percent 30 epoch 83: loss_train=0.8605, acc_train=0.5769, loss_test=0.4431, acc_test=0.9498
# poison_percent 30 epoch 84: loss_train=0.7746, acc_train=0.6538, loss_test=0.4454, acc_test=0.9559
# poison_percent 30 epoch 85: loss_train=0.9624, acc_train=0.5000, loss_test=0.4797, acc_test=0.9442
# poison_percent 30 epoch 86: loss_train=0.9978, acc_train=0.5385, loss_test=0.4648, acc_test=0.9449
# poison_percent 30 epoch 87: loss_train=0.7138, acc_train=0.6923, loss_test=0.4635, acc_test=0.9265
# poison_percent 30 epoch 88: loss_train=0.9973, acc_train=0.5769, loss_test=0.4630, acc_test=0.9430
# poison_percent 30 epoch 89: loss_train=0.9310, acc_train=0.5769, loss_test=0.4875, acc_test=0.9375
# poison_percent 30 epoch 90: loss_train=0.6882, acc_train=0.6538, loss_test=0.4363, acc_test=0.9528
# poison_percent 30 epoch 91: loss_train=0.8504, acc_train=0.5385, loss_test=0.4397, acc_test=0.9436
# poison_percent 30 epoch 92: loss_train=0.7500, acc_train=0.6923, loss_test=0.4488, acc_test=0.9498
# poison_percent 30 epoch 93: loss_train=0.8626, acc_train=0.6154, loss_test=0.4824, acc_test=0.8977
# poison_percent 30 epoch 94: loss_train=1.0228, acc_train=0.5769, loss_test=0.4761, acc_test=0.9259
# poison_percent 30 epoch 95: loss_train=0.7123, acc_train=0.6923, loss_test=0.4725, acc_test=0.9277
# poison_percent 30 epoch 96: loss_train=0.7651, acc_train=0.6923, loss_test=0.4463, acc_test=0.9485
# poison_percent 30 epoch 97: loss_train=1.2081, acc_train=0.4615, loss_test=0.4452, acc_test=0.9516
# poison_percent 30 epoch 98: loss_train=0.8849, acc_train=0.5769, loss_test=0.4430, acc_test=0.9510
# poison_percent 30 epoch 99: loss_train=0.9806, acc_train=0.5000, loss_test=0.4676, acc_test=0.9406
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\CL_ModelN1L3_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 epoch 0: loss_train=0.7067, acc_train=0.6000, loss_test=0.5968, acc_test=0.8211
# poison_percent 40 epoch 1: loss_train=0.8957, acc_train=0.4000, loss_test=0.6061, acc_test=0.8211
# poison_percent 40 epoch 2: loss_train=0.9312, acc_train=0.6000, loss_test=0.6136, acc_test=0.8407
# poison_percent 40 epoch 3: loss_train=0.6774, acc_train=0.7000, loss_test=0.5755, acc_test=0.8676
# poison_percent 40 epoch 4: loss_train=0.6141, acc_train=0.8000, loss_test=0.5942, acc_test=0.8621
# poison_percent 40 epoch 5: loss_train=0.7348, acc_train=0.5000, loss_test=0.5815, acc_test=0.8456
# poison_percent 40 epoch 6: loss_train=1.0175, acc_train=0.5000, loss_test=0.5714, acc_test=0.8676
# poison_percent 40 epoch 7: loss_train=0.8293, acc_train=0.5000, loss_test=0.5982, acc_test=0.8560
# poison_percent 40 epoch 8: loss_train=0.6654, acc_train=0.7000, loss_test=0.6007, acc_test=0.8499
# poison_percent 40 epoch 9: loss_train=0.6481, acc_train=0.6000, loss_test=0.5828, acc_test=0.8634
# poison_percent 40 epoch 10: loss_train=0.7755, acc_train=0.5000, loss_test=0.6161, acc_test=0.8211
# poison_percent 40 epoch 11: loss_train=1.3109, acc_train=0.6000, loss_test=0.6108, acc_test=0.8211
# poison_percent 40 epoch 12: loss_train=0.9129, acc_train=0.7000, loss_test=0.6320, acc_test=0.8113
# poison_percent 40 epoch 13: loss_train=1.6405, acc_train=0.4000, loss_test=0.6250, acc_test=0.8284
# poison_percent 40 epoch 14: loss_train=0.9534, acc_train=0.5000, loss_test=0.6058, acc_test=0.8058
# poison_percent 40 epoch 15: loss_train=0.4515, acc_train=0.9000, loss_test=0.5981, acc_test=0.8585
# poison_percent 40 epoch 16: loss_train=0.5660, acc_train=0.9000, loss_test=0.6206, acc_test=0.7923
# poison_percent 40 epoch 17: loss_train=1.5392, acc_train=0.6000, loss_test=0.6106, acc_test=0.8125
# poison_percent 40 epoch 18: loss_train=0.9830, acc_train=0.3000, loss_test=0.6270, acc_test=0.8015
# poison_percent 40 epoch 19: loss_train=0.5616, acc_train=0.7000, loss_test=0.5896, acc_test=0.8407
# poison_percent 40 epoch 20: loss_train=0.8608, acc_train=0.4000, loss_test=0.6025, acc_test=0.8487
# poison_percent 40 epoch 21: loss_train=0.6590, acc_train=0.6000, loss_test=0.5937, acc_test=0.8425
# poison_percent 40 epoch 22: loss_train=0.8965, acc_train=0.4000, loss_test=0.6371, acc_test=0.8192
# poison_percent 40 epoch 23: loss_train=0.7949, acc_train=0.4000, loss_test=0.6079, acc_test=0.8315
# poison_percent 40 epoch 24: loss_train=0.6822, acc_train=0.6000, loss_test=0.5929, acc_test=0.8756
# poison_percent 40 epoch 25: loss_train=1.0214, acc_train=0.5000, loss_test=0.5859, acc_test=0.8689
# poison_percent 40 epoch 26: loss_train=1.1415, acc_train=0.4000, loss_test=0.5830, acc_test=0.8664
# poison_percent 40 epoch 27: loss_train=0.7341, acc_train=0.7000, loss_test=0.6120, acc_test=0.8284
# poison_percent 40 epoch 28: loss_train=0.9076, acc_train=0.5000, loss_test=0.6239, acc_test=0.8137
# poison_percent 40 epoch 29: loss_train=1.3042, acc_train=0.7000, loss_test=0.6381, acc_test=0.8180
# poison_percent 40 epoch 30: loss_train=0.6840, acc_train=0.5000, loss_test=0.6484, acc_test=0.7886
# poison_percent 40 epoch 31: loss_train=0.8615, acc_train=0.7000, loss_test=0.6121, acc_test=0.8027
# poison_percent 40 epoch 32: loss_train=0.7810, acc_train=0.6000, loss_test=0.5868, acc_test=0.8732
# poison_percent 40 epoch 33: loss_train=0.8452, acc_train=0.5000, loss_test=0.6158, acc_test=0.8474
# poison_percent 40 epoch 34: loss_train=0.9614, acc_train=0.5000, loss_test=0.5990, acc_test=0.8401
# poison_percent 40 epoch 35: loss_train=0.9357, acc_train=0.6000, loss_test=0.5778, acc_test=0.8511
# poison_percent 40 epoch 36: loss_train=0.6284, acc_train=0.7000, loss_test=0.6283, acc_test=0.8119
# poison_percent 40 epoch 37: loss_train=1.2205, acc_train=0.5000, loss_test=0.5952, acc_test=0.8248
# poison_percent 40 epoch 38: loss_train=0.9315, acc_train=0.6000, loss_test=0.6150, acc_test=0.8346
# poison_percent 40 epoch 39: loss_train=0.6854, acc_train=0.8000, loss_test=0.6355, acc_test=0.7616
# poison_percent 40 epoch 40: loss_train=0.7452, acc_train=0.7000, loss_test=0.6193, acc_test=0.8186
# poison_percent 40 epoch 41: loss_train=0.7657, acc_train=0.6000, loss_test=0.6623, acc_test=0.7420
# poison_percent 40 epoch 42: loss_train=1.1062, acc_train=0.4000, loss_test=0.5682, acc_test=0.8805
# poison_percent 40 epoch 43: loss_train=0.7264, acc_train=0.6000, loss_test=0.6136, acc_test=0.8339
# poison_percent 40 epoch 44: loss_train=0.7221, acc_train=0.5000, loss_test=0.6093, acc_test=0.8370
# poison_percent 40 epoch 45: loss_train=0.9015, acc_train=0.5000, loss_test=0.6166, acc_test=0.7868
# poison_percent 40 epoch 46: loss_train=0.7394, acc_train=0.6000, loss_test=0.6086, acc_test=0.8229
# poison_percent 40 epoch 47: loss_train=0.8892, acc_train=0.5000, loss_test=0.5978, acc_test=0.8444
# poison_percent 40 epoch 48: loss_train=0.7187, acc_train=0.6000, loss_test=0.6106, acc_test=0.8309
# poison_percent 40 epoch 49: loss_train=1.1480, acc_train=0.3000, loss_test=0.5793, acc_test=0.8235
# poison_percent 40 epoch 50: loss_train=1.0076, acc_train=0.4000, loss_test=0.6088, acc_test=0.8431
# poison_percent 40 epoch 51: loss_train=0.8464, acc_train=0.7000, loss_test=0.5799, acc_test=0.8505
# poison_percent 40 epoch 52: loss_train=0.8631, acc_train=0.6000, loss_test=0.6451, acc_test=0.7684
# poison_percent 40 epoch 53: loss_train=0.8180, acc_train=0.6000, loss_test=0.6546, acc_test=0.7494
# poison_percent 40 epoch 54: loss_train=1.0798, acc_train=0.3000, loss_test=0.5747, acc_test=0.8873
# poison_percent 40 epoch 55: loss_train=0.8597, acc_train=0.4000, loss_test=0.6281, acc_test=0.7984
# poison_percent 40 epoch 56: loss_train=0.9095, acc_train=0.5000, loss_test=0.6144, acc_test=0.8413
# poison_percent 40 epoch 57: loss_train=0.5392, acc_train=0.9000, loss_test=0.6399, acc_test=0.8027
# poison_percent 40 epoch 58: loss_train=0.6060, acc_train=0.7000, loss_test=0.6414, acc_test=0.7831
# poison_percent 40 epoch 59: loss_train=0.8040, acc_train=0.6000, loss_test=0.6190, acc_test=0.8382
# poison_percent 40 epoch 60: loss_train=0.8975, acc_train=0.5000, loss_test=0.5755, acc_test=0.8468
# poison_percent 40 epoch 61: loss_train=0.6511, acc_train=0.8000, loss_test=0.6415, acc_test=0.7763
# poison_percent 40 epoch 62: loss_train=0.6857, acc_train=0.7000, loss_test=0.5953, acc_test=0.8646
# poison_percent 40 epoch 63: loss_train=0.9094, acc_train=0.3000, loss_test=0.5716, acc_test=0.8744
# poison_percent 40 epoch 64: loss_train=0.8618, acc_train=0.7000, loss_test=0.6086, acc_test=0.8536
# poison_percent 40 epoch 65: loss_train=0.8349, acc_train=0.3000, loss_test=0.5616, acc_test=0.8879
# poison_percent 40 epoch 66: loss_train=1.1745, acc_train=0.3000, loss_test=0.5622, acc_test=0.8873
# poison_percent 40 epoch 67: loss_train=0.8532, acc_train=0.6000, loss_test=0.5917, acc_test=0.8542
# poison_percent 40 epoch 68: loss_train=0.8035, acc_train=0.5000, loss_test=0.5673, acc_test=0.8787
# poison_percent 40 epoch 69: loss_train=0.7118, acc_train=0.7000, loss_test=0.6001, acc_test=0.8536
# poison_percent 40 epoch 70: loss_train=1.4289, acc_train=0.2000, loss_test=0.6526, acc_test=0.7855
# poison_percent 40 epoch 71: loss_train=0.8127, acc_train=0.6000, loss_test=0.6146, acc_test=0.8529
# poison_percent 40 epoch 72: loss_train=1.1532, acc_train=0.4000, loss_test=0.6415, acc_test=0.7292
# poison_percent 40 epoch 73: loss_train=0.8196, acc_train=0.6000, loss_test=0.5973, acc_test=0.8664
# poison_percent 40 epoch 74: loss_train=0.9558, acc_train=0.5000, loss_test=0.6098, acc_test=0.8260
# poison_percent 40 epoch 75: loss_train=0.7631, acc_train=0.7000, loss_test=0.6353, acc_test=0.7880
# poison_percent 40 epoch 76: loss_train=0.5945, acc_train=0.7000, loss_test=0.5658, acc_test=0.8854
# poison_percent 40 epoch 77: loss_train=0.8933, acc_train=0.5000, loss_test=0.5849, acc_test=0.8438
# poison_percent 40 epoch 78: loss_train=0.7557, acc_train=0.6000, loss_test=0.6413, acc_test=0.8064
# ...
# poison_percent 40 epoch 37: loss_train=0.6451, acc_train=0.9000, loss_test=0.5472, acc_test=0.8499
# poison_percent 40 epoch 38: loss_train=0.7817, acc_train=0.7000, loss_test=0.6269, acc_test=0.7757
# poison_percent 40 epoch 39: loss_train=0.8581, acc_train=0.5000, loss_test=0.6234, acc_test=0.7531
# poison_percent 40 epoch 40: loss_train=0.8045, acc_train=0.4000, loss_test=0.6213, acc_test=0.7886
# poison_percent 40 epoch 41: loss_train=0.6842, acc_train=0.7000, loss_test=0.6502, acc_test=0.7488
# poison_percent 40 epoch 42: loss_train=0.9454, acc_train=0.6000, loss_test=0.6265, acc_test=0.7862
# poison_percent 40 epoch 43: loss_train=0.7027, acc_train=0.5000, loss_test=0.6232, acc_test=0.7604
# poison_percent 40 epoch 44: loss_train=0.7244, acc_train=0.7000, loss_test=0.6110, acc_test=0.7953
# poison_percent 40 epoch 45: loss_train=0.6037, acc_train=0.8000, loss_test=0.6163, acc_test=0.8033
# poison_percent 40 epoch 46: loss_train=0.7116, acc_train=0.7000, loss_test=0.5878, acc_test=0.8143
# poison_percent 40 epoch 47: loss_train=0.7347, acc_train=0.6000, loss_test=0.6503, acc_test=0.7525
# poison_percent 40 epoch 48: loss_train=0.8441, acc_train=0.7000, loss_test=0.6410, acc_test=0.7678
# poison_percent 40 epoch 49: loss_train=0.8026, acc_train=0.5000, loss_test=0.5681, acc_test=0.8303
# poison_percent 40 epoch 50: loss_train=1.0631, acc_train=0.4000, loss_test=0.6250, acc_test=0.7806
# poison_percent 40 epoch 51: loss_train=0.8801, acc_train=0.6000, loss_test=0.5986, acc_test=0.7819
# poison_percent 40 epoch 52: loss_train=0.9601, acc_train=0.4000, loss_test=0.6356, acc_test=0.7531
# poison_percent 40 epoch 53: loss_train=0.9443, acc_train=0.3000, loss_test=0.7030, acc_test=0.6844
# poison_percent 40 epoch 54: loss_train=0.6439, acc_train=0.7000, loss_test=0.6159, acc_test=0.7678
# poison_percent 40 epoch 55: loss_train=0.9928, acc_train=0.4000, loss_test=0.5925, acc_test=0.8002
# poison_percent 40 epoch 56: loss_train=1.4194, acc_train=0.5000, loss_test=0.6317, acc_test=0.7567
# poison_percent 40 epoch 57: loss_train=0.8586, acc_train=0.4000, loss_test=0.6494, acc_test=0.7298
# poison_percent 40 epoch 58: loss_train=0.5971, acc_train=0.7000, loss_test=0.6290, acc_test=0.7714
# poison_percent 40 epoch 59: loss_train=1.0953, acc_train=0.4000, loss_test=0.6095, acc_test=0.7623
# poison_percent 40 epoch 60: loss_train=0.8227, acc_train=0.2000, loss_test=0.5798, acc_test=0.8119
# poison_percent 40 epoch 61: loss_train=1.3729, acc_train=0.3000, loss_test=0.5912, acc_test=0.8064
# poison_percent 40 epoch 62: loss_train=1.1099, acc_train=0.5000, loss_test=0.5738, acc_test=0.8254
# poison_percent 40 epoch 63: loss_train=0.7192, acc_train=0.6000, loss_test=0.6140, acc_test=0.7886
# poison_percent 40 epoch 64: loss_train=0.8493, acc_train=0.5000, loss_test=0.6126, acc_test=0.7990
# poison_percent 40 epoch 65: loss_train=0.9359, acc_train=0.5000, loss_test=0.6039, acc_test=0.8051
# poison_percent 40 epoch 66: loss_train=0.7457, acc_train=0.6000, loss_test=0.6668, acc_test=0.7004
# poison_percent 40 epoch 67: loss_train=0.6504, acc_train=0.8000, loss_test=0.5805, acc_test=0.8015
# poison_percent 40 epoch 68: loss_train=0.7400, acc_train=0.6000, loss_test=0.6345, acc_test=0.7629
# poison_percent 40 epoch 69: loss_train=0.9733, acc_train=0.4000, loss_test=0.5844, acc_test=0.8186
# poison_percent 40 epoch 70: loss_train=0.5487, acc_train=0.7000, loss_test=0.6216, acc_test=0.7757
# poison_percent 40 epoch 71: loss_train=0.6509, acc_train=0.8000, loss_test=0.5977, acc_test=0.8100
# poison_percent 40 epoch 72: loss_train=1.0245, acc_train=0.5000, loss_test=0.6124, acc_test=0.7653
# poison_percent 40 epoch 73: loss_train=0.8500, acc_train=0.6000, loss_test=0.6365, acc_test=0.7298
# poison_percent 40 epoch 74: loss_train=1.3973, acc_train=0.3000, loss_test=0.5811, acc_test=0.7696
# poison_percent 40 epoch 75: loss_train=0.8700, acc_train=0.6000, loss_test=0.5952, acc_test=0.7904
# poison_percent 40 epoch 76: loss_train=1.1825, acc_train=0.5000, loss_test=0.6142, acc_test=0.8082
# poison_percent 40 epoch 77: loss_train=0.5005, acc_train=0.9000, loss_test=0.5917, acc_test=0.7537
# poison_percent 40 epoch 78: loss_train=0.7522, acc_train=0.5000, loss_test=0.6482, acc_test=0.7623
# poison_percent 40 epoch 79: loss_train=0.8077, acc_train=0.6000, loss_test=0.6142, acc_test=0.8021
# poison_percent 40 epoch 80: loss_train=0.9824, acc_train=0.5000, loss_test=0.5745, acc_test=0.8223
# poison_percent 40 epoch 81: loss_train=0.8383, acc_train=0.5000, loss_test=0.5718, acc_test=0.8315
# poison_percent 40 epoch 82: loss_train=1.0270, acc_train=0.5000, loss_test=0.6948, acc_test=0.6801
# poison_percent 40 epoch 83: loss_train=0.8632, acc_train=0.6000, loss_test=0.5943, acc_test=0.8039
# poison_percent 40 epoch 84: loss_train=0.6884, acc_train=0.6000, loss_test=0.6134, acc_test=0.7592
# poison_percent 40 epoch 85: loss_train=1.1431, acc_train=0.5000, loss_test=0.6080, acc_test=0.7880
# poison_percent 40 epoch 86: loss_train=0.8482, acc_train=0.5000, loss_test=0.6120, acc_test=0.7733
# poison_percent 40 epoch 87: loss_train=0.9670, acc_train=0.5000, loss_test=0.6323, acc_test=0.7420
# poison_percent 40 epoch 88: loss_train=0.7779, acc_train=0.6000, loss_test=0.6045, acc_test=0.8217
# poison_percent 40 epoch 89: loss_train=1.0126, acc_train=0.4000, loss_test=0.5976, acc_test=0.7917
# poison_percent 40 epoch 90: loss_train=0.8248, acc_train=0.7000, loss_test=0.5864, acc_test=0.8150
# poison_percent 40 epoch 91: loss_train=0.9419, acc_train=0.8000, loss_test=0.6390, acc_test=0.7788
# poison_percent 40 epoch 92: loss_train=0.8767, acc_train=0.5000, loss_test=0.6009, acc_test=0.7518
# poison_percent 40 epoch 93: loss_train=0.8411, acc_train=0.6000, loss_test=0.5721, acc_test=0.8321
# poison_percent 40 epoch 94: loss_train=0.8438, acc_train=0.5000, loss_test=0.6255, acc_test=0.7812
# poison_percent 40 epoch 95: loss_train=0.8636, acc_train=0.6000, loss_test=0.6269, acc_test=0.7843
# poison_percent 40 epoch 96: loss_train=0.7388, acc_train=0.7000, loss_test=0.6300, acc_test=0.7978
# poison_percent 40 epoch 97: loss_train=0.7966, acc_train=0.5000, loss_test=0.5992, acc_test=0.7904
# poison_percent 40 epoch 98: loss_train=0.7094, acc_train=0.6000, loss_test=0.6634, acc_test=0.7034
# poison_percent 40 epoch 99: loss_train=0.7503, acc_train=0.5000, loss_test=0.6293, acc_test=0.7733
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\CL_ModelN1L3_Batchsize32_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 epoch 0: loss_train=0.9782, acc_train=0.5000, loss_test=0.8013, acc_test=0.4957
# poison_percent 50 epoch 1: loss_train=0.9904, acc_train=0.5000, loss_test=0.8203, acc_test=0.4688
# poison_percent 50 epoch 2: loss_train=0.8583, acc_train=0.5357, loss_test=0.7531, acc_test=0.6085
# poison_percent 50 epoch 3: loss_train=0.8277, acc_train=0.5357, loss_test=0.7784, acc_test=0.5325
# poison_percent 50 epoch 4: loss_train=0.7940, acc_train=0.6429, loss_test=0.8290, acc_test=0.5282
# poison_percent 50 epoch 5: loss_train=1.0234, acc_train=0.2143, loss_test=0.7316, acc_test=0.6366
# poison_percent 50 epoch 6: loss_train=0.8866, acc_train=0.5357, loss_test=0.7819, acc_test=0.5594
# poison_percent 50 epoch 7: loss_train=0.6843, acc_train=0.6071, loss_test=0.7963, acc_test=0.5368
# poison_percent 50 epoch 8: loss_train=1.0374, acc_train=0.5714, loss_test=0.8390, acc_test=0.4920
# poison_percent 50 epoch 9: loss_train=0.7742, acc_train=0.6071, loss_test=0.7829, acc_test=0.5938
# poison_percent 50 epoch 10: loss_train=0.9247, acc_train=0.4643, loss_test=0.7440, acc_test=0.6115
# poison_percent 50 epoch 11: loss_train=0.9348, acc_train=0.5357, loss_test=0.8409, acc_test=0.4718
# poison_percent 50 epoch 12: loss_train=0.8459, acc_train=0.5357, loss_test=0.8055, acc_test=0.4926
# poison_percent 50 epoch 13: loss_train=0.9420, acc_train=0.4643, loss_test=0.8257, acc_test=0.4957
# poison_percent 50 epoch 14: loss_train=0.7454, acc_train=0.5714, loss_test=0.8188, acc_test=0.5098
# poison_percent 50 epoch 15: loss_train=1.0632, acc_train=0.4643, loss_test=0.8410, acc_test=0.4369
# poison_percent 50 epoch 16: loss_train=0.8235, acc_train=0.4286, loss_test=0.7959, acc_test=0.5723
# poison_percent 50 epoch 17: loss_train=0.8203, acc_train=0.5714, loss_test=0.7436, acc_test=0.6354
# poison_percent 50 epoch 18: loss_train=0.6665, acc_train=0.7143, loss_test=0.8520, acc_test=0.4430
# poison_percent 50 epoch 19: loss_train=0.8938, acc_train=0.4286, loss_test=0.7737, acc_test=0.5882
# poison_percent 50 epoch 20: loss_train=0.7881, acc_train=0.5357, loss_test=0.7936, acc_test=0.5674
# poison_percent 50 epoch 21: loss_train=0.7647, acc_train=0.6071, loss_test=0.7877, acc_test=0.5196
# poison_percent 50 epoch 22: loss_train=0.6734, acc_train=0.6786, loss_test=0.8393, acc_test=0.5263
# poison_percent 50 epoch 23: loss_train=0.6559, acc_train=0.5357, loss_test=0.7578, acc_test=0.6121
# poison_percent 50 epoch 24: loss_train=0.8537, acc_train=0.5000, loss_test=0.7818, acc_test=0.5214
# poison_percent 50 epoch 25: loss_train=0.6276, acc_train=0.7500, loss_test=0.8479, acc_test=0.4283
# poison_percent 50 epoch 26: loss_train=0.7069, acc_train=0.6429, loss_test=0.8653, acc_test=0.4154
# poison_percent 50 epoch 27: loss_train=0.7881, acc_train=0.6786, loss_test=0.7766, acc_test=0.5165
# poison_percent 50 epoch 28: loss_train=0.9055, acc_train=0.4286, loss_test=0.7706, acc_test=0.5790
# poison_percent 50 epoch 29: loss_train=0.8876, acc_train=0.3929, loss_test=0.8803, acc_test=0.4295
# poison_percent 50 epoch 30: loss_train=0.9708, acc_train=0.5357, loss_test=0.7657, acc_test=0.5839
# poison_percent 50 epoch 31: loss_train=0.7243, acc_train=0.6429, loss_test=0.7506, acc_test=0.6268
# poison_percent 50 epoch 32: loss_train=0.8574, acc_train=0.5357, loss_test=0.7396, acc_test=0.6324
# poison_percent 50 epoch 33: loss_train=0.7324, acc_train=0.6071, loss_test=0.7546, acc_test=0.5723
# poison_percent 50 epoch 34: loss_train=0.9070, acc_train=0.5000, loss_test=0.7612, acc_test=0.6078
# poison_percent 50 epoch 35: loss_train=0.8665, acc_train=0.5000, loss_test=0.8198, acc_test=0.4737
# poison_percent 50 epoch 36: loss_train=1.0086, acc_train=0.6071, loss_test=0.8014, acc_test=0.5276
# poison_percent 50 epoch 37: loss_train=0.9462, acc_train=0.3571, loss_test=0.8044, acc_test=0.4847
# poison_percent 50 epoch 38: loss_train=0.7958, acc_train=0.5000, loss_test=0.7925, acc_test=0.5594
# poison_percent 50 epoch 39: loss_train=1.0173, acc_train=0.3929, loss_test=0.8046, acc_test=0.5025
# poison_percent 50 epoch 40: loss_train=0.9375, acc_train=0.3929, loss_test=0.8243, acc_test=0.5061
# poison_percent 50 epoch 41: loss_train=0.8426, acc_train=0.6071, loss_test=0.8300, acc_test=0.4804
# poison_percent 50 epoch 42: loss_train=1.0734, acc_train=0.5000, loss_test=0.7328, acc_test=0.6373
# poison_percent 50 epoch 43: loss_train=0.7222, acc_train=0.5714, loss_test=0.7884, acc_test=0.5502
# poison_percent 50 epoch 44: loss_train=0.9346, acc_train=0.5357, loss_test=0.8755, acc_test=0.3885
# poison_percent 50 epoch 45: loss_train=0.8156, acc_train=0.5714, loss_test=0.7881, acc_test=0.5190
# poison_percent 50 epoch 46: loss_train=1.1577, acc_train=0.4286, loss_test=0.8237, acc_test=0.4516
# poison_percent 50 epoch 47: loss_train=0.8344, acc_train=0.6071, loss_test=0.7737, acc_test=0.5674
# poison_percent 50 epoch 48: loss_train=0.7701, acc_train=0.5357, loss_test=0.7788, acc_test=0.5754
# poison_percent 50 epoch 49: loss_train=0.9613, acc_train=0.5000, loss_test=0.7638, acc_test=0.5913
# poison_percent 50 epoch 50: loss_train=0.7316, acc_train=0.5357, loss_test=0.8497, acc_test=0.4228
# poison_percent 50 epoch 51: loss_train=1.0029, acc_train=0.4286, loss_test=0.7403, acc_test=0.6195
# poison_percent 50 epoch 52: loss_train=0.7959, acc_train=0.5000, loss_test=0.8277, acc_test=0.4957
# poison_percent 50 epoch 53: loss_train=1.0260, acc_train=0.5357, loss_test=0.8232, acc_test=0.4565
# poison_percent 50 epoch 54: loss_train=0.9328, acc_train=0.5357, loss_test=0.8156, acc_test=0.4779
# poison_percent 50 epoch 55: loss_train=0.9213, acc_train=0.4286, loss_test=0.8531, acc_test=0.5276
# poison_percent 50 epoch 56: loss_train=0.7773, acc_train=0.4643, loss_test=0.8184, acc_test=0.5165
# poison_percent 50 epoch 57: loss_train=1.0500, acc_train=0.4286, loss_test=0.8370, acc_test=0.4663
# poison_percent 50 epoch 58: loss_train=0.8108, acc_train=0.4286, loss_test=0.8471, acc_test=0.4596
# poison_percent 50 epoch 59: loss_train=1.0066, acc_train=0.3929, loss_test=0.7985, acc_test=0.5294
# poison_percent 50 epoch 60: loss_train=0.7386, acc_train=0.6786, loss_test=0.7993, acc_test=0.5165
# poison_percent 50 epoch 61: loss_train=0.8032, acc_train=0.6071, loss_test=0.7599, acc_test=0.5815
# poison_percent 50 epoch 62: loss_train=0.8463, acc_train=0.4643, loss_test=0.8644, acc_test=0.4093
# poison_percent 50 epoch 63: loss_train=1.1611, acc_train=0.3571, loss_test=0.8308, acc_test=0.4608
# poison_percent 50 epoch 64: loss_train=0.9022, acc_train=0.3929, loss_test=0.7615, acc_test=0.5993
# poison_percent 50 epoch 65: loss_train=0.9858, acc_train=0.3214, loss_test=0.8483, acc_test=0.4332
# poison_percent 50 epoch 66: loss_train=0.8869, acc_train=0.4643, loss_test=0.8052, acc_test=0.5343
# poison_percent 50 epoch 67: loss_train=0.8871, acc_train=0.4643, loss_test=0.7651, acc_test=0.5729
# poison_percent 50 epoch 68: loss_train=0.9148, acc_train=0.6429, loss_test=0.7952, acc_test=0.5441
# poison_percent 50 epoch 69: loss_train=0.9075, acc_train=0.5714, loss_test=0.8631, acc_test=0.4381
# poison_percent 50 epoch 70: loss_train=0.7913, acc_train=0.4643, loss_test=0.8541, acc_test=0.4841
# poison_percent 50 epoch 71: loss_train=0.8350, acc_train=0.5714, loss_test=0.7864, acc_test=0.5116
# poison_percent 50 epoch 72: loss_train=0.9316, acc_train=0.4643, loss_test=0.8390, acc_test=0.4442
# poison_percent 50 epoch 73: loss_train=0.7866, acc_train=0.5714, loss_test=0.8274, acc_test=0.5392
# poison_percent 50 epoch 74: loss_train=0.8884, acc_train=0.3929, loss_test=0.8291, acc_test=0.4920
# poison_percent 50 epoch 75: loss_train=0.7768, acc_train=0.5714, loss_test=0.8458, acc_test=0.4406
# poison_percent 50 epoch 76: loss_train=0.9199, acc_train=0.4286, loss_test=0.7666, acc_test=0.5925
# poison_percent 50 epoch 77: loss_train=0.8344, acc_train=0.6071, loss_test=0.8535, acc_test=0.4320
# poison_percent 50 epoch 78: loss_train=0.8292, acc_train=0.4286, loss_test=0.8090, acc_test=0.5417
# poison_percent 50 epoch 79: loss_train=0.6932, acc_train=0.6429, loss_test=0.8433, acc_test=0.4400
# poison_percent 50 epoch 80: loss_train=0.8310, acc_train=0.6429, loss_test=0.7987, acc_test=0.5588
# poison_percent 50 epoch 81: loss_train=0.7651, acc_train=0.5714, loss_test=0.8287, acc_test=0.5214
# poison_percent 50 epoch 82: loss_train=1.0891, acc_train=0.3929, loss_test=0.8110, acc_test=0.4810
# poison_percent 50 epoch 83: loss_train=0.8772, acc_train=0.4286, loss_test=0.8156, acc_test=0.4730
# poison_percent 50 epoch 84: loss_train=1.0657, acc_train=0.4643, loss_test=0.8071, acc_test=0.5257
# poison_percent 50 epoch 85: loss_train=1.0266, acc_train=0.3571, loss_test=0.8062, acc_test=0.4939
# poison_percent 50 epoch 86: loss_train=0.7768, acc_train=0.5000, loss_test=0.7739, acc_test=0.5968
# poison_percent 50 epoch 87: loss_train=0.8243, acc_train=0.6071, loss_test=0.7633, acc_test=0.5705
# poison_percent 50 epoch 88: loss_train=0.8735, acc_train=0.4286, loss_test=0.7791, acc_test=0.5404
# poison_percent 50 epoch 89: loss_train=0.7714, acc_train=0.6071, loss_test=0.8758, acc_test=0.3885
# poison_percent 50 epoch 90: loss_train=0.7534, acc_train=0.5714, loss_test=0.8009, acc_test=0.4890
# poison_percent 50 epoch 91: loss_train=0.8145, acc_train=0.5000, loss_test=0.7673, acc_test=0.5754
# poison_percent 50 epoch 92: loss_train=0.8825, acc_train=0.5000, loss_test=0.7637, acc_test=0.5938
# poison_percent 50 epoch 93: loss_train=1.0023, acc_train=0.3929, loss_test=0.8369, acc_test=0.5080
# poison_percent 50 epoch 94: loss_train=0.7784, acc_train=0.6071, loss_test=0.8006, acc_test=0.5159
# poison_percent 50 epoch 95: loss_train=0.8028, acc_train=0.5714, loss_test=0.8452, acc_test=0.4461
# poison_percent 50 epoch 96: loss_train=0.8782, acc_train=0.6071, loss_test=0.8499, acc_test=0.4516
