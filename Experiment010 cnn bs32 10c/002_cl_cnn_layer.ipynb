# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x
    
# save state_dict + metadata (safe, portable)
def save_model(model, img_size, n_classes, learning_rate, experiment_bs, file_path):

    state = {
        "model_state_dict": model.state_dict(),                     # CPU/GPU tensors okay
        "arch": "MNISTNet",
        "img_size": img_size,
        "num_classes": n_classes,
        "training_args": {"lr": learning_rate, "batch_size": experiment_bs}
    }
    # ensure weights are on CPU to avoid GPU-only pickle issues
    state["model_state_dict"] = {k: v.cpu() for k, v in state["model_state_dict"].items()}
    torch.save(state, file_path)
    
def load_model(file_path, device):

    checkpoint = torch.load(file_path, map_location=device)
    model = MNISTNet().to(device)              # must have MNISTNet class defined/importable
    model.load_state_dict(checkpoint["model_state_dict"])
    model.eval()
    return model

# %% [markdown]
# # 4.Loss

# %%
# def binary_cross_entropy(pred, target):
#     eps = 1e-7
#     pred = torch.clamp(pred, eps, 1 - eps)
#     return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

def multiclass_cross_entropy(logits, target, from_probs=False, eps=1e-7):
    """
    Cross-entropy loss for multiclass (e.g., 10 classes).
    - logits: Tensor shape (N, C) containing raw scores (preferred) or probabilities if from_probs=True
    - target: Tensor shape (N,) or (N,1) containing class indices (0..C-1)
    """
    if logits.dim() == 1:
        logits = logits.unsqueeze(0)
    target = target.squeeze()
    if target.dtype != torch.long:
        target = target.long()
    if from_probs:
        probs = torch.clamp(logits, eps, 1.0 - eps)
        log_probs = torch.log(probs)
        return -log_probs[torch.arange(target.size(0)), target].mean()
    return nn.functional.cross_entropy(logits, target)

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 32
N_CLASSES = 10

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_multiple_poison/train"
TEST_PATH = "../data/mnist_multiple_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
NODE = 1
for LAYER in [3,4,5,6]: # LAYER - (first,last)
            
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            
            # 1. Define the stack of hidden layers (Linear + ReLU)
            # Use a list comprehension to create the (Linear, ReLU) pairs
            hidden_layers = []
            for _ in range(LAYER-2):
                hidden_layers.append(nn.Conv2d(NODE, NODE, kernel_size=3, padding=1))
                hidden_layers.append(nn.ReLU())
                
            # 2. Use nn.Sequential to wrap the entire dynamic stack
            self.dynamic_hidden = nn.Sequential(*hidden_layers)
            
            # Other layers
            self.conv1 = nn.Conv2d(1, NODE, kernel_size=3, padding=1) # 28x28
            self.pool = nn.MaxPool2d(2, 2) # 14x14
            self.fc1 = nn.Linear(NODE * 14 * 14, N_CLASSES)
            self.relu = nn.ReLU()

        def forward(self, x):
            x = x.view(-1, 1, 28, 28)
            x = self.pool(self.relu(self.conv1(x)))
            x = nn.ReLU()(x) # We need to manually apply ReLU here
            
            # Dynamic Hidden Layers (Executed sequentially without a loop)
            x = self.dynamic_hidden(x)
                
            # Output Layer
            x = x.view(x.size(0), -1)
            x = self.fc1(x)
            # x = torch.sigmoid(x)
            
            return x

    BATCH_SIZE_list = [32]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"CL_ModelN{NODE}L{LAYER}_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                        poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                        select='Honest+Poisoned')
                X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
                # print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
                # print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")

                X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
                y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                # torch.save(model, os.path.join(save_path,'model_init.pt'))
                save_path_name = os.path.join(save_path,'model_init.pt')
                save_model(model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)
                
                optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

                records = []

                # Training loop
                for epoch in range(EPOCHS):

                    # Train
                    model.train()
                    
                    #randomize the training data
                    perm = torch.randperm(X_train_tensor.size(0))
                    X_train_tensor = X_train_tensor[perm]
                    y_train_tensor = y_train_tensor[perm]

                    for start in range(0, X_train_tensor.size(0), experiment_bs):
                        end = start + experiment_bs
                        xb = X_train_tensor[start:end]
                        yb = y_train_tensor[start:end]
                        outputs = model(xb)
                        # preds = (outputs >= 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        acc_train = (preds == yb).float().mean().item()
                        loss_train = multiclass_cross_entropy(outputs, yb)
                        optimizer.zero_grad()
                        loss_train.backward()
                        optimizer.step()

                    # Evaluate
                    model.eval()
                    with torch.no_grad():
                        outputs = model(X_test_tensor)
                        # preds = (outputs >= 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        loss_test = multiclass_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"epoch {epoch}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                # torch.save(model, os.path.join(save_path,'model_last.pt'))
                save_path_name = os.path.join(save_path,'model_last.pt')
                save_model(model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['epoch'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['epoch'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 epoch 0: loss_train=0.4297, acc_train=0.8750, loss_test=0.3341, acc_test=0.9801
# poison_percent 0 epoch 1: loss_train=0.0053, acc_train=1.0000, loss_test=0.0125, acc_test=0.9969
# poison_percent 0 epoch 2: loss_train=0.0006, acc_train=1.0000, loss_test=0.0083, acc_test=0.9980
# poison_percent 0 epoch 3: loss_train=0.0010, acc_train=1.0000, loss_test=0.0065, acc_test=0.9980
# poison_percent 0 epoch 4: loss_train=0.0003, acc_train=1.0000, loss_test=0.0055, acc_test=0.9985
# poison_percent 0 epoch 5: loss_train=0.0001, acc_train=1.0000, loss_test=0.0047, acc_test=0.9990
# poison_percent 0 epoch 6: loss_train=0.0001, acc_train=1.0000, loss_test=0.0044, acc_test=0.9980
# poison_percent 0 epoch 7: loss_train=0.0003, acc_train=1.0000, loss_test=0.0039, acc_test=0.9990
# poison_percent 0 epoch 8: loss_train=0.0001, acc_train=1.0000, loss_test=0.0034, acc_test=0.9990
# poison_percent 0 epoch 9: loss_train=0.0001, acc_train=1.0000, loss_test=0.0037, acc_test=0.9990
# poison_percent 0 epoch 10: loss_train=0.0020, acc_train=1.0000, loss_test=0.0032, acc_test=0.9985
# poison_percent 0 epoch 11: loss_train=0.0002, acc_train=1.0000, loss_test=0.0033, acc_test=0.9990
# poison_percent 0 epoch 12: loss_train=0.0003, acc_train=1.0000, loss_test=0.0031, acc_test=0.9985
# poison_percent 0 epoch 13: loss_train=0.0004, acc_train=1.0000, loss_test=0.0041, acc_test=0.9990
# poison_percent 0 epoch 14: loss_train=0.0000, acc_train=1.0000, loss_test=0.0030, acc_test=0.9990
# poison_percent 0 epoch 15: loss_train=0.0001, acc_train=1.0000, loss_test=0.0028, acc_test=0.9985
# poison_percent 0 epoch 16: loss_train=0.0000, acc_train=1.0000, loss_test=0.0035, acc_test=0.9990
# poison_percent 0 epoch 17: loss_train=0.0009, acc_train=1.0000, loss_test=0.0031, acc_test=0.9990
# poison_percent 0 epoch 18: loss_train=0.0000, acc_train=1.0000, loss_test=0.0027, acc_test=0.9990
# poison_percent 0 epoch 19: loss_train=0.0009, acc_train=1.0000, loss_test=0.0041, acc_test=0.9990
# poison_percent 0 epoch 20: loss_train=0.0000, acc_train=1.0000, loss_test=0.0036, acc_test=0.9990
# poison_percent 0 epoch 21: loss_train=0.0000, acc_train=1.0000, loss_test=0.0028, acc_test=0.9990
# poison_percent 0 epoch 22: loss_train=0.0000, acc_train=1.0000, loss_test=0.0036, acc_test=0.9990
# poison_percent 0 epoch 23: loss_train=0.0003, acc_train=1.0000, loss_test=0.0031, acc_test=0.9990
# poison_percent 0 epoch 24: loss_train=0.0000, acc_train=1.0000, loss_test=0.0051, acc_test=0.9980
# poison_percent 0 epoch 25: loss_train=0.0000, acc_train=1.0000, loss_test=0.0045, acc_test=0.9980
# poison_percent 0 epoch 26: loss_train=0.0001, acc_train=1.0000, loss_test=0.0027, acc_test=0.9990
# poison_percent 0 epoch 27: loss_train=0.0001, acc_train=1.0000, loss_test=0.0025, acc_test=0.9990
# poison_percent 0 epoch 28: loss_train=0.0000, acc_train=1.0000, loss_test=0.0037, acc_test=0.9990
# poison_percent 0 epoch 29: loss_train=0.0000, acc_train=1.0000, loss_test=0.0038, acc_test=0.9990
# poison_percent 0 epoch 30: loss_train=0.0000, acc_train=1.0000, loss_test=0.0040, acc_test=0.9985
# poison_percent 0 epoch 31: loss_train=0.0006, acc_train=1.0000, loss_test=0.0030, acc_test=0.9985
# poison_percent 0 epoch 32: loss_train=0.0000, acc_train=1.0000, loss_test=0.0031, acc_test=0.9990
# poison_percent 0 epoch 33: loss_train=0.0000, acc_train=1.0000, loss_test=0.0031, acc_test=0.9990
# poison_percent 0 epoch 34: loss_train=0.0000, acc_train=1.0000, loss_test=0.0029, acc_test=0.9990
# poison_percent 0 epoch 35: loss_train=0.0194, acc_train=1.0000, loss_test=0.0034, acc_test=0.9990
# poison_percent 0 epoch 36: loss_train=0.0899, acc_train=0.8750, loss_test=0.0035, acc_test=0.9990
# poison_percent 0 epoch 37: loss_train=0.0000, acc_train=1.0000, loss_test=0.0026, acc_test=0.9990
# poison_percent 0 epoch 38: loss_train=0.0000, acc_train=1.0000, loss_test=0.0043, acc_test=0.9990
# poison_percent 0 epoch 39: loss_train=0.0000, acc_train=1.0000, loss_test=0.0031, acc_test=0.9990
# poison_percent 0 epoch 40: loss_train=0.0001, acc_train=1.0000, loss_test=0.0028, acc_test=0.9990
# poison_percent 0 epoch 41: loss_train=0.0000, acc_train=1.0000, loss_test=0.0058, acc_test=0.9980
# poison_percent 0 epoch 42: loss_train=0.0000, acc_train=1.0000, loss_test=0.0027, acc_test=0.9990
# poison_percent 0 epoch 43: loss_train=0.0000, acc_train=1.0000, loss_test=0.0036, acc_test=0.9990
# poison_percent 0 epoch 44: loss_train=0.0000, acc_train=1.0000, loss_test=0.0040, acc_test=0.9990
# poison_percent 0 epoch 45: loss_train=0.0000, acc_train=1.0000, loss_test=0.0028, acc_test=0.9995
# poison_percent 0 epoch 46: loss_train=0.0000, acc_train=1.0000, loss_test=0.0055, acc_test=0.9980
# poison_percent 0 epoch 47: loss_train=0.0000, acc_train=1.0000, loss_test=0.0055, acc_test=0.9980
# poison_percent 0 epoch 48: loss_train=0.0000, acc_train=1.0000, loss_test=0.0027, acc_test=0.9990
# poison_percent 0 epoch 49: loss_train=0.0000, acc_train=1.0000, loss_test=0.0047, acc_test=0.9985
# poison_percent 0 epoch 50: loss_train=0.0000, acc_train=1.0000, loss_test=0.0054, acc_test=0.9974
# poison_percent 0 epoch 51: loss_train=0.0000, acc_train=1.0000, loss_test=0.0062, acc_test=0.9974
# poison_percent 0 epoch 52: loss_train=0.0000, acc_train=1.0000, loss_test=0.0037, acc_test=0.9990
# poison_percent 0 epoch 53: loss_train=0.0000, acc_train=1.0000, loss_test=0.0054, acc_test=0.9980
# poison_percent 0 epoch 54: loss_train=0.0000, acc_train=1.0000, loss_test=0.0029, acc_test=0.9985
# poison_percent 0 epoch 55: loss_train=0.0000, acc_train=1.0000, loss_test=0.0031, acc_test=0.9995
# poison_percent 0 epoch 56: loss_train=0.0000, acc_train=1.0000, loss_test=0.0040, acc_test=0.9985
# poison_percent 0 epoch 57: loss_train=0.0000, acc_train=1.0000, loss_test=0.0046, acc_test=0.9985
# poison_percent 0 epoch 58: loss_train=0.0000, acc_train=1.0000, loss_test=0.0032, acc_test=0.9995
# poison_percent 0 epoch 59: loss_train=0.0000, acc_train=1.0000, loss_test=0.0051, acc_test=0.9985
# poison_percent 0 epoch 60: loss_train=0.0000, acc_train=1.0000, loss_test=0.0035, acc_test=0.9995
# poison_percent 0 epoch 61: loss_train=0.0000, acc_train=1.0000, loss_test=0.0032, acc_test=0.9985
# poison_percent 0 epoch 62: loss_train=0.0000, acc_train=1.0000, loss_test=0.0030, acc_test=0.9995
# poison_percent 0 epoch 63: loss_train=0.0000, acc_train=1.0000, loss_test=0.0038, acc_test=0.9990
# poison_percent 0 epoch 64: loss_train=0.0000, acc_train=1.0000, loss_test=0.0069, acc_test=0.9974
# poison_percent 0 epoch 65: loss_train=0.0000, acc_train=1.0000, loss_test=0.0044, acc_test=0.9990
# poison_percent 0 epoch 66: loss_train=0.0000, acc_train=1.0000, loss_test=0.0036, acc_test=0.9995
# poison_percent 0 epoch 67: loss_train=0.0000, acc_train=1.0000, loss_test=0.0041, acc_test=0.9990
# poison_percent 0 epoch 68: loss_train=0.0000, acc_train=1.0000, loss_test=0.0033, acc_test=0.9995
# poison_percent 0 epoch 69: loss_train=0.0000, acc_train=1.0000, loss_test=0.0060, acc_test=0.9985
# poison_percent 0 epoch 70: loss_train=0.0000, acc_train=1.0000, loss_test=0.0062, acc_test=0.9985
# poison_percent 0 epoch 71: loss_train=0.0029, acc_train=1.0000, loss_test=0.0047, acc_test=0.9990
# poison_percent 0 epoch 72: loss_train=0.0000, acc_train=1.0000, loss_test=0.0044, acc_test=0.9995
# poison_percent 0 epoch 73: loss_train=0.0000, acc_train=1.0000, loss_test=0.0052, acc_test=0.9990
# poison_percent 0 epoch 74: loss_train=0.0000, acc_train=1.0000, loss_test=0.0042, acc_test=0.9995
# poison_percent 0 epoch 75: loss_train=0.0000, acc_train=1.0000, loss_test=0.0040, acc_test=0.9990
# poison_percent 0 epoch 76: loss_train=0.0000, acc_train=1.0000, loss_test=0.0055, acc_test=0.9985
# poison_percent 0 epoch 77: loss_train=0.0000, acc_train=1.0000, loss_test=0.0046, acc_test=0.9995
# poison_percent 0 epoch 78: loss_train=0.0000, acc_train=1.0000, loss_test=0.0053, acc_test=0.9985
# poison_percent 0 epoch 79: loss_train=0.0000, acc_train=1.0000, loss_test=0.0046, acc_test=0.9990
# poison_percent 0 epoch 80: loss_train=0.0000, acc_train=1.0000, loss_test=0.0054, acc_test=0.9990
# poison_percent 0 epoch 81: loss_train=0.0000, acc_train=1.0000, loss_test=0.0045, acc_test=0.9995
# poison_percent 0 epoch 82: loss_train=0.0000, acc_train=1.0000, loss_test=0.0052, acc_test=0.9990
# poison_percent 0 epoch 83: loss_train=0.0000, acc_train=1.0000, loss_test=0.0046, acc_test=0.9990
# poison_percent 0 epoch 84: loss_train=0.0000, acc_train=1.0000, loss_test=0.0052, acc_test=0.9990
# poison_percent 0 epoch 85: loss_train=0.0000, acc_train=1.0000, loss_test=0.0054, acc_test=0.9990
# poison_percent 0 epoch 86: loss_train=0.0000, acc_train=1.0000, loss_test=0.0046, acc_test=0.9990
# poison_percent 0 epoch 87: loss_train=0.0000, acc_train=1.0000, loss_test=0.0071, acc_test=0.9990
# poison_percent 0 epoch 88: loss_train=0.0000, acc_train=1.0000, loss_test=0.0050, acc_test=0.9995
# poison_percent 0 epoch 89: loss_train=0.0000, acc_train=1.0000, loss_test=0.0094, acc_test=0.9990
# poison_percent 0 epoch 90: loss_train=0.0027, acc_train=1.0000, loss_test=0.0055, acc_test=0.9990
# poison_percent 0 epoch 91: loss_train=0.0000, acc_train=1.0000, loss_test=0.0052, acc_test=0.9995
# poison_percent 0 epoch 92: loss_train=0.0000, acc_train=1.0000, loss_test=0.0058, acc_test=0.9990
# poison_percent 0 epoch 93: loss_train=0.0000, acc_train=1.0000, loss_test=0.0055, acc_test=0.9995
# poison_percent 0 epoch 94: loss_train=0.0000, acc_train=1.0000, loss_test=0.0058, acc_test=0.9990
# poison_percent 0 epoch 95: loss_train=0.0000, acc_train=1.0000, loss_test=0.0056, acc_test=0.9995
# poison_percent 0 epoch 96: loss_train=0.0000, acc_train=1.0000, loss_test=0.0057, acc_test=0.9995
# poison_percent 0 epoch 97: loss_train=0.0000, acc_train=1.0000, loss_test=0.0052, acc_test=0.9995
# poison_percent 0 epoch 98: loss_train=0.0000, acc_train=1.0000, loss_test=0.0056, acc_test=0.9995
# poison_percent 0 epoch 99: loss_train=0.0000, acc_train=1.0000, loss_test=0.0055, acc_test=0.9995
# Training log saved to ./results\CL_ModelN1L3_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 epoch 0: loss_train=1.3985, acc_train=0.9062, loss_test=0.1455, acc_test=0.9648
# poison_percent 10 epoch 1: loss_train=0.8146, acc_train=0.9062, loss_test=0.0722, acc_test=0.9730
# poison_percent 10 epoch 2: loss_train=0.3708, acc_train=0.8750, loss_test=0.1490, acc_test=0.9536
# poison_percent 10 epoch 3: loss_train=0.4048, acc_train=0.8438, loss_test=0.1434, acc_test=0.9776
# poison_percent 10 epoch 4: loss_train=0.3909, acc_train=0.8438, loss_test=0.1233, acc_test=0.9903
# poison_percent 10 epoch 5: loss_train=0.6839, acc_train=0.7812, loss_test=0.1324, acc_test=0.9923
# poison_percent 10 epoch 6: loss_train=0.6985, acc_train=0.7188, loss_test=0.1389, acc_test=0.9934
# poison_percent 10 epoch 7: loss_train=0.2580, acc_train=0.9375, loss_test=0.1382, acc_test=0.9949
# poison_percent 10 epoch 8: loss_train=0.4115, acc_train=0.8750, loss_test=0.1211, acc_test=0.9969
# poison_percent 10 epoch 9: loss_train=0.1971, acc_train=0.9688, loss_test=0.1287, acc_test=0.9954
# poison_percent 10 epoch 10: loss_train=0.1088, acc_train=1.0000, loss_test=0.1241, acc_test=0.9974
# poison_percent 10 epoch 11: loss_train=0.3219, acc_train=0.8750, loss_test=0.1102, acc_test=0.9980
# poison_percent 10 epoch 12: loss_train=0.2980, acc_train=0.9062, loss_test=0.1176, acc_test=0.9969
# poison_percent 10 epoch 13: loss_train=0.3461, acc_train=0.9062, loss_test=0.1315, acc_test=0.9969
# poison_percent 10 epoch 14: loss_train=0.2608, acc_train=0.9375, loss_test=0.1296, acc_test=0.9985
# poison_percent 10 epoch 15: loss_train=0.4725, acc_train=0.8438, loss_test=0.1355, acc_test=0.9969
# poison_percent 10 epoch 16: loss_train=0.6049, acc_train=0.7500, loss_test=0.1110, acc_test=0.9985
# poison_percent 10 epoch 17: loss_train=0.5773, acc_train=0.7812, loss_test=0.1186, acc_test=0.9974
# poison_percent 10 epoch 18: loss_train=0.2917, acc_train=0.9062, loss_test=0.1283, acc_test=0.9985
# poison_percent 10 epoch 19: loss_train=0.3042, acc_train=0.9062, loss_test=0.1197, acc_test=0.9985
# poison_percent 10 epoch 20: loss_train=0.5955, acc_train=0.7812, loss_test=0.1208, acc_test=0.9990
# poison_percent 10 epoch 21: loss_train=0.1719, acc_train=0.9688, loss_test=0.0967, acc_test=0.9985
# poison_percent 10 epoch 22: loss_train=0.1952, acc_train=0.9688, loss_test=0.1163, acc_test=0.9985
# poison_percent 10 epoch 23: loss_train=0.5867, acc_train=0.7812, loss_test=0.1210, acc_test=0.9990
# poison_percent 10 epoch 24: loss_train=0.1944, acc_train=0.9688, loss_test=0.1161, acc_test=0.9990
# poison_percent 10 epoch 25: loss_train=0.3531, acc_train=0.8750, loss_test=0.1147, acc_test=0.9980
# poison_percent 10 epoch 26: loss_train=0.4731, acc_train=0.8438, loss_test=0.1232, acc_test=0.9990
# poison_percent 10 epoch 27: loss_train=0.4091, acc_train=0.8438, loss_test=0.1205, acc_test=0.9990
# poison_percent 10 epoch 28: loss_train=0.1119, acc_train=1.0000, loss_test=0.1169, acc_test=0.9985
# poison_percent 10 epoch 29: loss_train=0.3587, acc_train=0.9062, loss_test=0.1299, acc_test=0.9990
# poison_percent 10 epoch 30: loss_train=0.4078, acc_train=0.8750, loss_test=0.1046, acc_test=0.9990
# poison_percent 10 epoch 31: loss_train=0.5273, acc_train=0.8125, loss_test=0.1266, acc_test=0.9985
# poison_percent 10 epoch 32: loss_train=0.5153, acc_train=0.8438, loss_test=0.1138, acc_test=0.9985
# poison_percent 10 epoch 33: loss_train=0.3235, acc_train=0.9062, loss_test=0.1464, acc_test=0.9985
# poison_percent 10 epoch 34: loss_train=0.3781, acc_train=0.8750, loss_test=0.1084, acc_test=0.9985
# poison_percent 10 epoch 35: loss_train=0.4821, acc_train=0.8125, loss_test=0.1273, acc_test=0.9985
# poison_percent 10 epoch 36: loss_train=0.3043, acc_train=0.9062, loss_test=0.1083, acc_test=0.9995
# poison_percent 10 epoch 37: loss_train=0.3737, acc_train=0.8750, loss_test=0.1116, acc_test=0.9985
# poison_percent 10 epoch 38: loss_train=0.2664, acc_train=0.9062, loss_test=0.1376, acc_test=0.9985
# poison_percent 10 epoch 39: loss_train=0.3413, acc_train=0.9062, loss_test=0.1133, acc_test=0.9995
# poison_percent 10 epoch 40: loss_train=0.2140, acc_train=0.9375, loss_test=0.1227, acc_test=0.9995
# poison_percent 10 epoch 41: loss_train=0.2737, acc_train=0.9062, loss_test=0.1208, acc_test=0.9985
# poison_percent 10 epoch 42: loss_train=0.2932, acc_train=0.9062, loss_test=0.1180, acc_test=0.9995
# poison_percent 10 epoch 43: loss_train=0.3679, acc_train=0.8750, loss_test=0.1230, acc_test=0.9995
# poison_percent 10 epoch 44: loss_train=0.3574, acc_train=0.8438, loss_test=0.1138, acc_test=0.9985
# poison_percent 10 epoch 45: loss_train=0.3775, acc_train=0.8438, loss_test=0.1175, acc_test=0.9985
# poison_percent 10 epoch 46: loss_train=0.4188, acc_train=0.8438, loss_test=0.1245, acc_test=0.9985
# poison_percent 10 epoch 47: loss_train=0.3981, acc_train=0.8750, loss_test=0.1117, acc_test=0.9990
# poison_percent 10 epoch 48: loss_train=0.2888, acc_train=0.9062, loss_test=0.1187, acc_test=0.9985
# poison_percent 10 epoch 49: loss_train=0.1824, acc_train=0.9688, loss_test=0.1341, acc_test=0.9985
# poison_percent 10 epoch 50: loss_train=0.3984, acc_train=0.8750, loss_test=0.1302, acc_test=0.9995
# poison_percent 10 epoch 51: loss_train=0.2423, acc_train=0.9375, loss_test=0.1204, acc_test=0.9995
# poison_percent 10 epoch 52: loss_train=0.2618, acc_train=0.9375, loss_test=0.1264, acc_test=0.9990
# poison_percent 10 epoch 53: loss_train=0.4423, acc_train=0.8438, loss_test=0.1267, acc_test=0.9995
# poison_percent 10 epoch 54: loss_train=0.4202, acc_train=0.8438, loss_test=0.1283, acc_test=0.9990
# poison_percent 10 epoch 55: loss_train=0.2726, acc_train=0.9375, loss_test=0.1240, acc_test=0.9990
# poison_percent 10 epoch 56: loss_train=0.4338, acc_train=0.8438, loss_test=0.1137, acc_test=0.9990
# poison_percent 10 epoch 57: loss_train=0.3399, acc_train=0.8750, loss_test=0.1173, acc_test=0.9995
# poison_percent 10 epoch 58: loss_train=0.2206, acc_train=0.9375, loss_test=0.1107, acc_test=0.9990
# poison_percent 10 epoch 59: loss_train=0.3712, acc_train=0.8750, loss_test=0.1105, acc_test=0.9995
# poison_percent 10 epoch 60: loss_train=0.3713, acc_train=0.8750, loss_test=0.1330, acc_test=0.9995
# poison_percent 10 epoch 61: loss_train=0.5953, acc_train=0.7812, loss_test=0.0936, acc_test=0.9995
# poison_percent 10 epoch 62: loss_train=0.3151, acc_train=0.9062, loss_test=0.1453, acc_test=0.9990
# poison_percent 10 epoch 63: loss_train=0.4341, acc_train=0.8438, loss_test=0.1133, acc_test=0.9990
# poison_percent 10 epoch 64: loss_train=0.2337, acc_train=0.9375, loss_test=0.1028, acc_test=0.9990
# poison_percent 10 epoch 65: loss_train=0.5088, acc_train=0.8125, loss_test=0.1165, acc_test=0.9990
# poison_percent 10 epoch 66: loss_train=0.4333, acc_train=0.8438, loss_test=0.1238, acc_test=0.9990
# poison_percent 10 epoch 67: loss_train=0.3179, acc_train=0.8750, loss_test=0.1337, acc_test=0.9990
# poison_percent 10 epoch 68: loss_train=0.5016, acc_train=0.8125, loss_test=0.1166, acc_test=0.9995
# poison_percent 10 epoch 69: loss_train=0.4185, acc_train=0.8438, loss_test=0.1339, acc_test=0.9995
# poison_percent 10 epoch 70: loss_train=0.5231, acc_train=0.7812, loss_test=0.1208, acc_test=0.9990
# poison_percent 10 epoch 71: loss_train=0.3096, acc_train=0.9062, loss_test=0.1277, acc_test=0.9995
# poison_percent 10 epoch 72: loss_train=0.1114, acc_train=1.0000, loss_test=0.1093, acc_test=0.9995
# poison_percent 10 epoch 73: loss_train=0.3035, acc_train=0.9062, loss_test=0.1235, acc_test=0.9990
# poison_percent 10 epoch 74: loss_train=0.2603, acc_train=0.9375, loss_test=0.1380, acc_test=0.9990
# poison_percent 10 epoch 75: loss_train=0.4482, acc_train=0.8438, loss_test=0.1287, acc_test=0.9990
# poison_percent 10 epoch 76: loss_train=0.4581, acc_train=0.8438, loss_test=0.1169, acc_test=0.9995
# poison_percent 10 epoch 77: loss_train=0.3933, acc_train=0.8750, loss_test=0.1231, acc_test=0.9990
# poison_percent 10 epoch 78: loss_train=0.5341, acc_train=0.8125, loss_test=0.1177, acc_test=0.9995
# poison_percent 10 epoch 79: loss_train=0.3388, acc_train=0.8750, loss_test=0.1261, acc_test=0.9995
# poison_percent 10 epoch 80: loss_train=0.5106, acc_train=0.8125, loss_test=0.1428, acc_test=0.9990
# poison_percent 10 epoch 81: loss_train=0.4067, acc_train=0.8750, loss_test=0.1199, acc_test=0.9990
# poison_percent 10 epoch 82: loss_train=0.2205, acc_train=0.9375, loss_test=0.1074, acc_test=0.9995
# poison_percent 10 epoch 83: loss_train=0.4006, acc_train=0.8750, loss_test=0.1272, acc_test=0.9995
# poison_percent 10 epoch 84: loss_train=0.2899, acc_train=0.9062, loss_test=0.1133, acc_test=0.9995
# poison_percent 10 epoch 85: loss_train=0.3560, acc_train=0.9062, loss_test=0.1097, acc_test=0.9995
# poison_percent 10 epoch 86: loss_train=0.3320, acc_train=0.9062, loss_test=0.1263, acc_test=0.9990
# poison_percent 10 epoch 87: loss_train=0.1208, acc_train=1.0000, loss_test=0.1178, acc_test=0.9995
# poison_percent 10 epoch 88: loss_train=0.3579, acc_train=0.8750, loss_test=0.1243, acc_test=0.9995
# poison_percent 10 epoch 89: loss_train=0.2733, acc_train=0.9062, loss_test=0.1186, acc_test=0.9995
# poison_percent 10 epoch 90: loss_train=0.3542, acc_train=0.8750, loss_test=0.1101, acc_test=0.9995
# poison_percent 10 epoch 91: loss_train=0.2786, acc_train=0.9375, loss_test=0.1136, acc_test=0.9995
# poison_percent 10 epoch 92: loss_train=0.4584, acc_train=0.8438, loss_test=0.1235, acc_test=0.9995
# poison_percent 10 epoch 93: loss_train=0.2318, acc_train=0.9375, loss_test=0.1324, acc_test=0.9995
# poison_percent 10 epoch 94: loss_train=0.3922, acc_train=0.8750, loss_test=0.1227, acc_test=0.9995
# poison_percent 10 epoch 95: loss_train=0.2972, acc_train=0.9062, loss_test=0.1034, acc_test=0.9995
# poison_percent 10 epoch 96: loss_train=0.5290, acc_train=0.8125, loss_test=0.1321, acc_test=0.9995
# poison_percent 10 epoch 97: loss_train=0.3560, acc_train=0.9062, loss_test=0.1112, acc_test=0.9995
# poison_percent 10 epoch 98: loss_train=0.2588, acc_train=0.9375, loss_test=0.1514, acc_test=0.9990
# poison_percent 10 epoch 99: loss_train=0.3397, acc_train=0.9062, loss_test=0.1218, acc_test=0.9995
# Training log saved to ./results\CL_ModelN1L3_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 epoch 0: loss_train=0.3142, acc_train=0.9444, loss_test=0.2388, acc_test=0.9985
# poison_percent 20 epoch 1: loss_train=0.5932, acc_train=0.6667, loss_test=0.2388, acc_test=0.9990
# poison_percent 20 epoch 2: loss_train=0.4747, acc_train=0.8333, loss_test=0.2368, acc_test=0.9990
# poison_percent 20 epoch 3: loss_train=0.2118, acc_train=1.0000, loss_test=0.2214, acc_test=0.9990
# poison_percent 20 epoch 4: loss_train=0.4770, acc_train=0.8333, loss_test=0.2270, acc_test=0.9990
# poison_percent 20 epoch 5: loss_train=0.5260, acc_train=0.7778, loss_test=0.2320, acc_test=0.9990
# poison_percent 20 epoch 6: loss_train=0.3879, acc_train=0.8889, loss_test=0.2569, acc_test=0.9985
# poison_percent 20 epoch 7: loss_train=0.7063, acc_train=0.6667, loss_test=0.2136, acc_test=0.9995
# poison_percent 20 epoch 8: loss_train=0.2658, acc_train=0.9444, loss_test=0.2327, acc_test=0.9990
# poison_percent 20 epoch 9: loss_train=0.3341, acc_train=0.8889, loss_test=0.2004, acc_test=0.9990
# poison_percent 20 epoch 10: loss_train=0.3582, acc_train=0.8889, loss_test=0.2172, acc_test=0.9995
# poison_percent 20 epoch 11: loss_train=0.5536, acc_train=0.7778, loss_test=0.2584, acc_test=0.9985
# poison_percent 20 epoch 12: loss_train=0.5347, acc_train=0.7778, loss_test=0.2191, acc_test=0.9990
# poison_percent 20 epoch 13: loss_train=0.4629, acc_train=0.8333, loss_test=0.2322, acc_test=0.9990
# poison_percent 20 epoch 14: loss_train=0.6106, acc_train=0.7222, loss_test=0.2195, acc_test=0.9990
# poison_percent 20 epoch 15: loss_train=0.4631, acc_train=0.8333, loss_test=0.2174, acc_test=0.9990
# poison_percent 20 epoch 16: loss_train=0.3790, acc_train=0.8889, loss_test=0.2274, acc_test=0.9990
# poison_percent 20 epoch 17: loss_train=0.4788, acc_train=0.8333, loss_test=0.2440, acc_test=0.9985
# poison_percent 20 epoch 18: loss_train=0.5511, acc_train=0.7222, loss_test=0.2278, acc_test=0.9990
# poison_percent 20 epoch 19: loss_train=0.5525, acc_train=0.7778, loss_test=0.2173, acc_test=0.9985
# poison_percent 20 epoch 20: loss_train=0.7174, acc_train=0.6667, loss_test=0.2072, acc_test=0.9990
# poison_percent 20 epoch 21: loss_train=0.3626, acc_train=0.8889, loss_test=0.2466, acc_test=0.9990
# poison_percent 20 epoch 22: loss_train=0.3836, acc_train=0.8889, loss_test=0.2162, acc_test=0.9985
# poison_percent 20 epoch 23: loss_train=0.5485, acc_train=0.7222, loss_test=0.2296, acc_test=0.9990
# poison_percent 20 epoch 24: loss_train=0.4559, acc_train=0.8333, loss_test=0.2476, acc_test=0.9990
# poison_percent 20 epoch 25: loss_train=0.4768, acc_train=0.7778, loss_test=0.2402, acc_test=0.9980
# poison_percent 20 epoch 26: loss_train=0.4846, acc_train=0.8333, loss_test=0.2325, acc_test=0.9990
# poison_percent 20 epoch 27: loss_train=0.5489, acc_train=0.7778, loss_test=0.2248, acc_test=0.9980
# poison_percent 20 epoch 28: loss_train=0.4492, acc_train=0.8333, loss_test=0.2229, acc_test=0.9990
# poison_percent 20 epoch 29: loss_train=0.4705, acc_train=0.8333, loss_test=0.1985, acc_test=0.9990
# poison_percent 20 epoch 30: loss_train=0.2524, acc_train=1.0000, loss_test=0.2440, acc_test=0.9980
# poison_percent 20 epoch 31: loss_train=0.3432, acc_train=0.8889, loss_test=0.2450, acc_test=0.9980
# poison_percent 20 epoch 32: loss_train=0.6446, acc_train=0.7222, loss_test=0.2372, acc_test=0.9985
# poison_percent 20 epoch 33: loss_train=0.5086, acc_train=0.7778, loss_test=0.2282, acc_test=0.9980
# poison_percent 20 epoch 34: loss_train=0.6303, acc_train=0.7222, loss_test=0.2274, acc_test=0.9985
# poison_percent 20 epoch 35: loss_train=0.2888, acc_train=0.9444, loss_test=0.2117, acc_test=0.9985
# poison_percent 20 epoch 36: loss_train=0.4915, acc_train=0.8333, loss_test=0.2296, acc_test=0.9985
# poison_percent 20 epoch 37: loss_train=0.5923, acc_train=0.7778, loss_test=0.2092, acc_test=0.9985
# poison_percent 20 epoch 38: loss_train=0.3717, acc_train=0.8889, loss_test=0.2336, acc_test=0.9980
# poison_percent 20 epoch 39: loss_train=0.4930, acc_train=0.8333, loss_test=0.2165, acc_test=0.9990
# poison_percent 20 epoch 40: loss_train=0.5967, acc_train=0.7222, loss_test=0.2322, acc_test=0.9980
# poison_percent 20 epoch 41: loss_train=0.4582, acc_train=0.8333, loss_test=0.2450, acc_test=0.9974
# poison_percent 20 epoch 42: loss_train=0.3284, acc_train=0.8889, loss_test=0.2329, acc_test=0.9980
# poison_percent 20 epoch 43: loss_train=0.8289, acc_train=0.5556, loss_test=0.2245, acc_test=0.9985
# poison_percent 20 epoch 44: loss_train=0.7826, acc_train=0.6111, loss_test=0.2243, acc_test=0.9985
# poison_percent 20 epoch 45: loss_train=0.5524, acc_train=0.7778, loss_test=0.2178, acc_test=0.9980
# poison_percent 20 epoch 46: loss_train=0.6039, acc_train=0.7222, loss_test=0.2411, acc_test=0.9980
# poison_percent 20 epoch 47: loss_train=0.4142, acc_train=0.8889, loss_test=0.2595, acc_test=0.9969
# poison_percent 20 epoch 48: loss_train=0.6567, acc_train=0.7222, loss_test=0.2212, acc_test=0.9980
# poison_percent 20 epoch 49: loss_train=0.3326, acc_train=0.8889, loss_test=0.2146, acc_test=0.9980
# poison_percent 20 epoch 50: loss_train=0.4785, acc_train=0.7778, loss_test=0.2370, acc_test=0.9980
# poison_percent 20 epoch 51: loss_train=0.4323, acc_train=0.8333, loss_test=0.2377, acc_test=0.9980
# poison_percent 20 epoch 52: loss_train=0.4058, acc_train=0.8889, loss_test=0.2333, acc_test=0.9980
# poison_percent 20 epoch 53: loss_train=0.4407, acc_train=0.8333, loss_test=0.2106, acc_test=0.9980
# poison_percent 20 epoch 54: loss_train=0.4633, acc_train=0.7778, loss_test=0.2378, acc_test=0.9974
# poison_percent 20 epoch 55: loss_train=0.3374, acc_train=0.8889, loss_test=0.2191, acc_test=0.9980
# poison_percent 20 epoch 56: loss_train=0.3821, acc_train=0.8889, loss_test=0.2135, acc_test=0.9985
# poison_percent 20 epoch 57: loss_train=0.3623, acc_train=0.8889, loss_test=0.2203, acc_test=0.9980
# poison_percent 20 epoch 58: loss_train=0.3114, acc_train=0.9444, loss_test=0.2258, acc_test=0.9985
# poison_percent 20 epoch 59: loss_train=0.4085, acc_train=0.8333, loss_test=0.2156, acc_test=0.9969
# poison_percent 20 epoch 60: loss_train=0.8261, acc_train=0.5556, loss_test=0.2224, acc_test=0.9985
# poison_percent 20 epoch 61: loss_train=0.3482, acc_train=0.8889, loss_test=0.2180, acc_test=0.9974
# poison_percent 20 epoch 62: loss_train=0.6635, acc_train=0.7222, loss_test=0.2069, acc_test=0.9980
# poison_percent 20 epoch 63: loss_train=0.5665, acc_train=0.7222, loss_test=0.2425, acc_test=0.9969
# poison_percent 20 epoch 64: loss_train=0.4798, acc_train=0.8333, loss_test=0.2252, acc_test=0.9969
# poison_percent 20 epoch 65: loss_train=0.5433, acc_train=0.7778, loss_test=0.2044, acc_test=0.9974
# poison_percent 20 epoch 66: loss_train=0.3839, acc_train=0.8889, loss_test=0.2232, acc_test=0.9959
# poison_percent 20 epoch 67: loss_train=0.4057, acc_train=0.8889, loss_test=0.2326, acc_test=0.9954
# poison_percent 20 epoch 68: loss_train=0.8103, acc_train=0.6111, loss_test=0.2321, acc_test=0.9959
# poison_percent 20 epoch 69: loss_train=0.5721, acc_train=0.8333, loss_test=0.2172, acc_test=0.9969
# poison_percent 20 epoch 70: loss_train=0.5866, acc_train=0.7778, loss_test=0.2161, acc_test=0.9969
# poison_percent 20 epoch 71: loss_train=0.4708, acc_train=0.8333, loss_test=0.2384, acc_test=0.9969
# poison_percent 20 epoch 72: loss_train=0.4096, acc_train=0.8889, loss_test=0.2096, acc_test=0.9974
# poison_percent 20 epoch 73: loss_train=0.4689, acc_train=0.8333, loss_test=0.2086, acc_test=0.9969
# poison_percent 20 epoch 74: loss_train=0.5466, acc_train=0.7778, loss_test=0.2187, acc_test=0.9964
# poison_percent 20 epoch 75: loss_train=0.4408, acc_train=0.7778, loss_test=0.2560, acc_test=0.9959
# poison_percent 20 epoch 76: loss_train=0.4910, acc_train=0.7778, loss_test=0.2227, acc_test=0.9959
# poison_percent 20 epoch 77: loss_train=0.4508, acc_train=0.7778, loss_test=0.2308, acc_test=0.9959
# poison_percent 20 epoch 78: loss_train=0.4347, acc_train=0.8889, loss_test=0.2361, acc_test=0.9959
# poison_percent 20 epoch 79: loss_train=0.3619, acc_train=0.8889, loss_test=0.2467, acc_test=0.9969
# poison_percent 20 epoch 80: loss_train=0.5078, acc_train=0.7222, loss_test=0.2408, acc_test=0.9954
# poison_percent 20 epoch 81: loss_train=0.5441, acc_train=0.7778, loss_test=0.2078, acc_test=0.9969
# poison_percent 20 epoch 82: loss_train=0.7775, acc_train=0.6111, loss_test=0.2538, acc_test=0.9959
# poison_percent 20 epoch 83: loss_train=0.3211, acc_train=0.8889, loss_test=0.2437, acc_test=0.9954
# poison_percent 20 epoch 84: loss_train=0.6237, acc_train=0.7222, loss_test=0.2148, acc_test=0.9959
# poison_percent 20 epoch 85: loss_train=0.3975, acc_train=0.8333, loss_test=0.2463, acc_test=0.9939
# poison_percent 20 epoch 86: loss_train=0.3428, acc_train=0.8889, loss_test=0.2172, acc_test=0.9959
# poison_percent 20 epoch 87: loss_train=0.3743, acc_train=0.8889, loss_test=0.2376, acc_test=0.9954
# poison_percent 20 epoch 88: loss_train=0.3428, acc_train=0.8889, loss_test=0.2333, acc_test=0.9954
# poison_percent 20 epoch 89: loss_train=0.4312, acc_train=0.8889, loss_test=0.2289, acc_test=0.9949
# poison_percent 20 epoch 90: loss_train=0.3817, acc_train=0.8889, loss_test=0.2331, acc_test=0.9954
# poison_percent 20 epoch 91: loss_train=0.5482, acc_train=0.7778, loss_test=0.2141, acc_test=0.9954
# poison_percent 20 epoch 92: loss_train=0.3960, acc_train=0.8333, loss_test=0.2072, acc_test=0.9959
# poison_percent 20 epoch 93: loss_train=0.6138, acc_train=0.7222, loss_test=0.2143, acc_test=0.9959
# poison_percent 20 epoch 94: loss_train=0.3040, acc_train=0.8889, loss_test=0.2189, acc_test=0.9959
# poison_percent 20 epoch 95: loss_train=0.2834, acc_train=0.9444, loss_test=0.2287, acc_test=0.9949
# poison_percent 20 epoch 96: loss_train=0.5977, acc_train=0.7222, loss_test=0.2380, acc_test=0.9959
# poison_percent 20 epoch 97: loss_train=0.4380, acc_train=0.8333, loss_test=0.2215, acc_test=0.9954
# poison_percent 20 epoch 98: loss_train=0.3815, acc_train=0.8333, loss_test=0.2277, acc_test=0.9949
# poison_percent 20 epoch 99: loss_train=0.6161, acc_train=0.7222, loss_test=0.2471, acc_test=0.9944
# Training log saved to ./results\CL_ModelN1L3_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 epoch 0: loss_train=0.6050, acc_train=0.6667, loss_test=0.3886, acc_test=0.9821
# poison_percent 30 epoch 1: loss_train=0.5275, acc_train=0.8333, loss_test=0.3587, acc_test=0.9893
# poison_percent 30 epoch 2: loss_train=0.6251, acc_train=0.6667, loss_test=0.3800, acc_test=0.9883
# poison_percent 30 epoch 3: loss_train=0.8467, acc_train=0.5000, loss_test=0.3335, acc_test=0.9913
# poison_percent 30 epoch 4: loss_train=0.7372, acc_train=0.5000, loss_test=0.3654, acc_test=0.9898
# poison_percent 30 epoch 5: loss_train=0.5515, acc_train=0.8333, loss_test=0.3700, acc_test=0.9878
# poison_percent 30 epoch 6: loss_train=0.5045, acc_train=1.0000, loss_test=0.3577, acc_test=0.9908
# poison_percent 30 epoch 7: loss_train=0.4428, acc_train=0.8333, loss_test=0.3567, acc_test=0.9898
# poison_percent 30 epoch 8: loss_train=1.0035, acc_train=0.3333, loss_test=0.3726, acc_test=0.9888
# poison_percent 30 epoch 9: loss_train=0.5077, acc_train=0.8333, loss_test=0.3462, acc_test=0.9898
# poison_percent 30 epoch 10: loss_train=0.4144, acc_train=1.0000, loss_test=0.3708, acc_test=0.9888
# poison_percent 30 epoch 11: loss_train=0.4485, acc_train=1.0000, loss_test=0.3583, acc_test=0.9888
# poison_percent 30 epoch 12: loss_train=0.4986, acc_train=0.8333, loss_test=0.3775, acc_test=0.9872
# poison_percent 30 epoch 13: loss_train=1.1190, acc_train=0.3333, loss_test=0.3553, acc_test=0.9893
# poison_percent 30 epoch 14: loss_train=0.7618, acc_train=0.5000, loss_test=0.3683, acc_test=0.9878
# poison_percent 30 epoch 15: loss_train=0.7075, acc_train=0.6667, loss_test=0.3286, acc_test=0.9913
# poison_percent 30 epoch 16: loss_train=0.4512, acc_train=0.8333, loss_test=0.3403, acc_test=0.9903
# poison_percent 30 epoch 17: loss_train=0.6193, acc_train=0.6667, loss_test=0.3773, acc_test=0.9883
# poison_percent 30 epoch 18: loss_train=0.5523, acc_train=0.8333, loss_test=0.3776, acc_test=0.9878
# poison_percent 30 epoch 19: loss_train=0.4644, acc_train=0.8333, loss_test=0.3514, acc_test=0.9908
# poison_percent 30 epoch 20: loss_train=0.4768, acc_train=0.8333, loss_test=0.3688, acc_test=0.9888
# poison_percent 30 epoch 21: loss_train=0.4713, acc_train=0.8333, loss_test=0.3604, acc_test=0.9893
# poison_percent 30 epoch 22: loss_train=0.4920, acc_train=0.8333, loss_test=0.3696, acc_test=0.9883
# poison_percent 30 epoch 23: loss_train=0.5543, acc_train=0.8333, loss_test=0.3675, acc_test=0.9893
# poison_percent 30 epoch 24: loss_train=0.3866, acc_train=1.0000, loss_test=0.3741, acc_test=0.9888
# poison_percent 30 epoch 25: loss_train=0.5437, acc_train=0.8333, loss_test=0.3775, acc_test=0.9878
# poison_percent 30 epoch 26: loss_train=0.6228, acc_train=0.6667, loss_test=0.3589, acc_test=0.9893
# poison_percent 30 epoch 27: loss_train=0.6435, acc_train=0.6667, loss_test=0.3400, acc_test=0.9908
# poison_percent 30 epoch 28: loss_train=0.6897, acc_train=0.6667, loss_test=0.3530, acc_test=0.9898
# poison_percent 30 epoch 29: loss_train=0.5160, acc_train=0.8333, loss_test=0.3697, acc_test=0.9878
# poison_percent 30 epoch 30: loss_train=0.8665, acc_train=0.5000, loss_test=0.3736, acc_test=0.9878
# poison_percent 30 epoch 31: loss_train=0.9141, acc_train=0.5000, loss_test=0.3483, acc_test=0.9893
# poison_percent 30 epoch 32: loss_train=0.8174, acc_train=0.5000, loss_test=0.3743, acc_test=0.9872
# poison_percent 30 epoch 33: loss_train=0.6086, acc_train=0.6667, loss_test=0.3772, acc_test=0.9872
# poison_percent 30 epoch 34: loss_train=0.5954, acc_train=0.8333, loss_test=0.3553, acc_test=0.9883
# poison_percent 30 epoch 35: loss_train=0.6797, acc_train=0.5000, loss_test=0.3417, acc_test=0.9908
# poison_percent 30 epoch 36: loss_train=0.6895, acc_train=0.5000, loss_test=0.3822, acc_test=0.9832
# poison_percent 30 epoch 37: loss_train=0.3255, acc_train=1.0000, loss_test=0.3482, acc_test=0.9903
# poison_percent 30 epoch 38: loss_train=0.7103, acc_train=0.5000, loss_test=0.3835, acc_test=0.9857
# poison_percent 30 epoch 39: loss_train=0.6210, acc_train=0.6667, loss_test=0.3785, acc_test=0.9821
# poison_percent 30 epoch 40: loss_train=0.9940, acc_train=0.3333, loss_test=0.3477, acc_test=0.9893
# poison_percent 30 epoch 41: loss_train=0.4490, acc_train=0.8333, loss_test=0.3582, acc_test=0.9847
# poison_percent 30 epoch 42: loss_train=0.6907, acc_train=0.6667, loss_test=0.3750, acc_test=0.9872
# poison_percent 30 epoch 43: loss_train=0.4834, acc_train=0.8333, loss_test=0.3644, acc_test=0.9878
# poison_percent 30 epoch 44: loss_train=0.9171, acc_train=0.5000, loss_test=0.3561, acc_test=0.9857
# poison_percent 30 epoch 45: loss_train=0.3012, acc_train=1.0000, loss_test=0.3503, acc_test=0.9883
# poison_percent 30 epoch 46: loss_train=0.8137, acc_train=0.3333, loss_test=0.3681, acc_test=0.9847
# poison_percent 30 epoch 47: loss_train=0.4972, acc_train=0.8333, loss_test=0.3679, acc_test=0.9852
# poison_percent 30 epoch 48: loss_train=0.7580, acc_train=0.5000, loss_test=0.3465, acc_test=0.9893
# poison_percent 30 epoch 49: loss_train=0.6828, acc_train=0.6667, loss_test=0.3480, acc_test=0.9888
# poison_percent 30 epoch 50: loss_train=0.3580, acc_train=1.0000, loss_test=0.3627, acc_test=0.9867
# poison_percent 30 epoch 51: loss_train=0.6642, acc_train=0.5000, loss_test=0.3688, acc_test=0.9872
# poison_percent 30 epoch 52: loss_train=0.4809, acc_train=0.8333, loss_test=0.3726, acc_test=0.9872
# poison_percent 30 epoch 53: loss_train=0.3667, acc_train=1.0000, loss_test=0.3881, acc_test=0.9811
# poison_percent 30 epoch 54: loss_train=0.5340, acc_train=0.8333, loss_test=0.3494, acc_test=0.9878
# poison_percent 30 epoch 55: loss_train=0.7689, acc_train=0.3333, loss_test=0.3535, acc_test=0.9883
# poison_percent 30 epoch 56: loss_train=0.6104, acc_train=0.6667, loss_test=0.3634, acc_test=0.9867
# poison_percent 30 epoch 57: loss_train=0.6539, acc_train=0.6667, loss_test=0.3718, acc_test=0.9847
# poison_percent 30 epoch 58: loss_train=0.5778, acc_train=0.6667, loss_test=0.3683, acc_test=0.9872
# poison_percent 30 epoch 59: loss_train=0.9773, acc_train=0.3333, loss_test=0.3703, acc_test=0.9862
# poison_percent 30 epoch 60: loss_train=0.7907, acc_train=0.5000, loss_test=0.3512, acc_test=0.9878
# poison_percent 30 epoch 61: loss_train=0.3266, acc_train=1.0000, loss_test=0.3398, acc_test=0.9888
# poison_percent 30 epoch 62: loss_train=0.6079, acc_train=0.6667, loss_test=0.3724, acc_test=0.9852
# poison_percent 30 epoch 63: loss_train=0.4489, acc_train=0.8333, loss_test=0.3747, acc_test=0.9862
# poison_percent 30 epoch 64: loss_train=0.8602, acc_train=0.3333, loss_test=0.3612, acc_test=0.9867
# poison_percent 30 epoch 65: loss_train=0.5069, acc_train=0.8333, loss_test=0.3609, acc_test=0.9862
# poison_percent 30 epoch 66: loss_train=0.5004, acc_train=0.6667, loss_test=0.3274, acc_test=0.9903
# poison_percent 30 epoch 67: loss_train=0.4661, acc_train=0.8333, loss_test=0.3961, acc_test=0.9832
# poison_percent 30 epoch 68: loss_train=0.7685, acc_train=0.5000, loss_test=0.3592, acc_test=0.9872
# poison_percent 30 epoch 69: loss_train=0.5465, acc_train=0.6667, loss_test=0.3806, acc_test=0.9857
# poison_percent 30 epoch 70: loss_train=0.6673, acc_train=0.6667, loss_test=0.3542, acc_test=0.9878
# poison_percent 30 epoch 71: loss_train=0.3841, acc_train=0.8333, loss_test=0.3682, acc_test=0.9862
# poison_percent 30 epoch 72: loss_train=0.6067, acc_train=0.6667, loss_test=0.3303, acc_test=0.9898
# poison_percent 30 epoch 73: loss_train=0.3305, acc_train=1.0000, loss_test=0.3349, acc_test=0.9898
# poison_percent 30 epoch 74: loss_train=0.6434, acc_train=0.6667, loss_test=0.3656, acc_test=0.9867
# poison_percent 30 epoch 75: loss_train=0.3284, acc_train=1.0000, loss_test=0.3654, acc_test=0.9857
# poison_percent 30 epoch 76: loss_train=0.6658, acc_train=0.6667, loss_test=0.3439, acc_test=0.9893
# poison_percent 30 epoch 77: loss_train=0.3151, acc_train=1.0000, loss_test=0.3598, acc_test=0.9867
# poison_percent 30 epoch 78: loss_train=0.6293, acc_train=0.6667, loss_test=0.3469, acc_test=0.9883
# poison_percent 30 epoch 79: loss_train=0.5984, acc_train=0.6667, loss_test=0.3511, acc_test=0.9893
# poison_percent 30 epoch 80: loss_train=0.7314, acc_train=0.6667, loss_test=0.3343, acc_test=0.9898
# poison_percent 30 epoch 81: loss_train=0.5960, acc_train=0.6667, loss_test=0.3574, acc_test=0.9872
# poison_percent 30 epoch 82: loss_train=0.3196, acc_train=1.0000, loss_test=0.3425, acc_test=0.9893
# poison_percent 30 epoch 83: loss_train=0.4587, acc_train=0.8333, loss_test=0.3906, acc_test=0.9857
# poison_percent 30 epoch 84: loss_train=0.5009, acc_train=0.8333, loss_test=0.3768, acc_test=0.9857
# poison_percent 30 epoch 85: loss_train=0.7712, acc_train=0.5000, loss_test=0.3556, acc_test=0.9867
# poison_percent 30 epoch 86: loss_train=0.4923, acc_train=0.6667, loss_test=0.3834, acc_test=0.9842
# poison_percent 30 epoch 87: loss_train=1.1906, acc_train=0.3333, loss_test=0.3511, acc_test=0.9888
# poison_percent 30 epoch 88: loss_train=0.8557, acc_train=0.3333, loss_test=0.3493, acc_test=0.9893
# poison_percent 30 epoch 89: loss_train=0.2786, acc_train=1.0000, loss_test=0.3320, acc_test=0.9898
# poison_percent 30 epoch 90: loss_train=0.5169, acc_train=0.8333, loss_test=0.3561, acc_test=0.9862
# poison_percent 30 epoch 91: loss_train=0.8710, acc_train=0.3333, loss_test=0.3824, acc_test=0.9852
# poison_percent 30 epoch 92: loss_train=0.6618, acc_train=0.6667, loss_test=0.3877, acc_test=0.9801
# poison_percent 30 epoch 93: loss_train=0.7706, acc_train=0.3333, loss_test=0.3771, acc_test=0.9857
# poison_percent 30 epoch 94: loss_train=0.7552, acc_train=0.5000, loss_test=0.3507, acc_test=0.9872
# poison_percent 30 epoch 95: loss_train=0.4839, acc_train=0.8333, loss_test=0.3511, acc_test=0.9888
# poison_percent 30 epoch 96: loss_train=0.4918, acc_train=0.8333, loss_test=0.3609, acc_test=0.9862
# poison_percent 30 epoch 97: loss_train=0.6985, acc_train=0.6667, loss_test=0.3823, acc_test=0.9847
# poison_percent 30 epoch 98: loss_train=0.4860, acc_train=0.8333, loss_test=0.3782, acc_test=0.9847
# poison_percent 30 epoch 99: loss_train=0.4785, acc_train=0.8333, loss_test=0.3473, acc_test=0.9883
# Training log saved to ./results\CL_ModelN1L3_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 epoch 0: loss_train=0.7268, acc_train=0.5000, loss_test=0.5184, acc_test=0.9291
# poison_percent 40 epoch 1: loss_train=0.5523, acc_train=0.8182, loss_test=0.4982, acc_test=0.9480
# poison_percent 40 epoch 2: loss_train=0.6698, acc_train=0.5909, loss_test=0.5305, acc_test=0.9189
# poison_percent 40 epoch 3: loss_train=0.6400, acc_train=0.5909, loss_test=0.5236, acc_test=0.9286
# poison_percent 40 epoch 4: loss_train=0.6893, acc_train=0.6364, loss_test=0.5276, acc_test=0.9255
# poison_percent 40 epoch 5: loss_train=0.6813, acc_train=0.5455, loss_test=0.5189, acc_test=0.9209
# poison_percent 40 epoch 6: loss_train=0.7320, acc_train=0.5000, loss_test=0.4869, acc_test=0.9413
# poison_percent 40 epoch 7: loss_train=0.6149, acc_train=0.7273, loss_test=0.5425, acc_test=0.8903
# poison_percent 40 epoch 8: loss_train=0.6361, acc_train=0.5909, loss_test=0.5248, acc_test=0.9230
# poison_percent 40 epoch 9: loss_train=0.6479, acc_train=0.6818, loss_test=0.5338, acc_test=0.9010
# poison_percent 40 epoch 10: loss_train=0.6495, acc_train=0.6364, loss_test=0.4926, acc_test=0.9444
# poison_percent 40 epoch 11: loss_train=0.6442, acc_train=0.7273, loss_test=0.5218, acc_test=0.9133
# poison_percent 40 epoch 12: loss_train=0.7260, acc_train=0.5000, loss_test=0.5210, acc_test=0.9240
# poison_percent 40 epoch 13: loss_train=0.7629, acc_train=0.3636, loss_test=0.4870, acc_test=0.9551
# poison_percent 40 epoch 14: loss_train=0.6395, acc_train=0.5909, loss_test=0.4941, acc_test=0.9464
# poison_percent 40 epoch 15: loss_train=0.6734, acc_train=0.5909, loss_test=0.5103, acc_test=0.9327
# poison_percent 40 epoch 16: loss_train=0.6235, acc_train=0.6364, loss_test=0.5103, acc_test=0.9265
# poison_percent 40 epoch 17: loss_train=0.6236, acc_train=0.5909, loss_test=0.4777, acc_test=0.9566
# poison_percent 40 epoch 18: loss_train=0.6410, acc_train=0.5909, loss_test=0.5288, acc_test=0.9133
# poison_percent 40 epoch 19: loss_train=0.7448, acc_train=0.3636, loss_test=0.5172, acc_test=0.9316
# poison_percent 40 epoch 20: loss_train=0.6825, acc_train=0.5909, loss_test=0.5254, acc_test=0.9219
# poison_percent 40 epoch 21: loss_train=0.5953, acc_train=0.7727, loss_test=0.5215, acc_test=0.9230
# poison_percent 40 epoch 22: loss_train=0.6246, acc_train=0.7273, loss_test=0.5289, acc_test=0.9214
# poison_percent 40 epoch 23: loss_train=0.6321, acc_train=0.6364, loss_test=0.5087, acc_test=0.9378
# poison_percent 40 epoch 24: loss_train=0.5911, acc_train=0.7727, loss_test=0.4988, acc_test=0.9449
# poison_percent 40 epoch 25: loss_train=0.6557, acc_train=0.5909, loss_test=0.5331, acc_test=0.9158
# poison_percent 40 epoch 26: loss_train=0.6746, acc_train=0.5455, loss_test=0.5431, acc_test=0.9082
# poison_percent 40 epoch 27: loss_train=0.7419, acc_train=0.4091, loss_test=0.5055, acc_test=0.9301
# poison_percent 40 epoch 28: loss_train=0.6367, acc_train=0.5909, loss_test=0.4999, acc_test=0.9337
# poison_percent 40 epoch 29: loss_train=0.6930, acc_train=0.5000, loss_test=0.5067, acc_test=0.9316
# poison_percent 40 epoch 30: loss_train=0.7581, acc_train=0.3636, loss_test=0.5080, acc_test=0.9224
# poison_percent 40 epoch 31: loss_train=0.7173, acc_train=0.5455, loss_test=0.5082, acc_test=0.9316
# poison_percent 40 epoch 32: loss_train=0.7407, acc_train=0.5000, loss_test=0.5258, acc_test=0.9209
# poison_percent 40 epoch 33: loss_train=0.6534, acc_train=0.5909, loss_test=0.5343, acc_test=0.8980
# poison_percent 40 epoch 34: loss_train=0.6595, acc_train=0.5000, loss_test=0.5260, acc_test=0.9199
# poison_percent 40 epoch 35: loss_train=0.6582, acc_train=0.5455, loss_test=0.5198, acc_test=0.9184
# poison_percent 40 epoch 36: loss_train=0.7026, acc_train=0.5909, loss_test=0.5136, acc_test=0.9286
# poison_percent 40 epoch 37: loss_train=0.6515, acc_train=0.5909, loss_test=0.5267, acc_test=0.9077
# poison_percent 40 epoch 38: loss_train=0.6558, acc_train=0.6364, loss_test=0.5033, acc_test=0.9265
# poison_percent 40 epoch 39: loss_train=0.6720, acc_train=0.5455, loss_test=0.5098, acc_test=0.9347
# poison_percent 40 epoch 40: loss_train=0.6130, acc_train=0.6818, loss_test=0.5257, acc_test=0.9204
# poison_percent 40 epoch 41: loss_train=0.8033, acc_train=0.3636, loss_test=0.5094, acc_test=0.9352
# poison_percent 40 epoch 42: loss_train=0.7532, acc_train=0.5000, loss_test=0.5116, acc_test=0.9296
# poison_percent 40 epoch 43: loss_train=0.6427, acc_train=0.6364, loss_test=0.5148, acc_test=0.9270
# poison_percent 40 epoch 44: loss_train=0.6454, acc_train=0.6364, loss_test=0.5388, acc_test=0.8872
# poison_percent 40 epoch 45: loss_train=0.6514, acc_train=0.6818, loss_test=0.5248, acc_test=0.9199
# poison_percent 40 epoch 46: loss_train=0.6933, acc_train=0.5000, loss_test=0.4692, acc_test=0.9520
# poison_percent 40 epoch 47: loss_train=0.7330, acc_train=0.4545, loss_test=0.4956, acc_test=0.9408
# poison_percent 40 epoch 48: loss_train=0.6814, acc_train=0.5000, loss_test=0.5413, acc_test=0.8857
# poison_percent 40 epoch 49: loss_train=0.6671, acc_train=0.6364, loss_test=0.4965, acc_test=0.9418
# poison_percent 40 epoch 50: loss_train=0.7292, acc_train=0.5000, loss_test=0.4996, acc_test=0.9291
# poison_percent 40 epoch 51: loss_train=0.6986, acc_train=0.5455, loss_test=0.5064, acc_test=0.9306
# poison_percent 40 epoch 52: loss_train=0.5621, acc_train=0.7273, loss_test=0.5094, acc_test=0.9296
# poison_percent 40 epoch 53: loss_train=0.7504, acc_train=0.4545, loss_test=0.5010, acc_test=0.9352
# poison_percent 40 epoch 54: loss_train=0.6588, acc_train=0.6364, loss_test=0.5112, acc_test=0.9235
# poison_percent 40 epoch 55: loss_train=0.6364, acc_train=0.6364, loss_test=0.4999, acc_test=0.9393
# poison_percent 40 epoch 56: loss_train=0.6181, acc_train=0.6364, loss_test=0.5222, acc_test=0.9082
# poison_percent 40 epoch 57: loss_train=0.7499, acc_train=0.4091, loss_test=0.4983, acc_test=0.9393
# poison_percent 40 epoch 58: loss_train=0.6898, acc_train=0.5455, loss_test=0.5232, acc_test=0.8969
# poison_percent 40 epoch 59: loss_train=0.6597, acc_train=0.6364, loss_test=0.5068, acc_test=0.9286
# poison_percent 40 epoch 60: loss_train=0.6952, acc_train=0.5455, loss_test=0.5209, acc_test=0.9245
# poison_percent 40 epoch 61: loss_train=0.6778, acc_train=0.6364, loss_test=0.5018, acc_test=0.9286
# poison_percent 40 epoch 62: loss_train=0.6814, acc_train=0.5000, loss_test=0.5293, acc_test=0.9000
# poison_percent 40 epoch 63: loss_train=0.6669, acc_train=0.5909, loss_test=0.5317, acc_test=0.8969
# poison_percent 40 epoch 64: loss_train=0.5888, acc_train=0.7273, loss_test=0.5218, acc_test=0.9179
# poison_percent 40 epoch 65: loss_train=0.5797, acc_train=0.6818, loss_test=0.5047, acc_test=0.9357
# poison_percent 40 epoch 66: loss_train=0.5621, acc_train=0.7727, loss_test=0.4999, acc_test=0.9337
# poison_percent 40 epoch 67: loss_train=0.6785, acc_train=0.5909, loss_test=0.5204, acc_test=0.9097
# poison_percent 40 epoch 68: loss_train=0.5694, acc_train=0.7727, loss_test=0.5288, acc_test=0.9087
# poison_percent 40 epoch 69: loss_train=0.7404, acc_train=0.5000, loss_test=0.5037, acc_test=0.9245
# poison_percent 40 epoch 70: loss_train=0.6255, acc_train=0.6818, loss_test=0.5077, acc_test=0.9153
# poison_percent 40 epoch 71: loss_train=0.6898, acc_train=0.5455, loss_test=0.5061, acc_test=0.9332
# poison_percent 40 epoch 72: loss_train=0.6512, acc_train=0.6364, loss_test=0.4971, acc_test=0.9260
# poison_percent 40 epoch 73: loss_train=0.6178, acc_train=0.7273, loss_test=0.5184, acc_test=0.9097
# poison_percent 40 epoch 74: loss_train=0.6620, acc_train=0.6364, loss_test=0.5264, acc_test=0.9184
# poison_percent 40 epoch 75: loss_train=0.5903, acc_train=0.7273, loss_test=0.5266, acc_test=0.9087
# poison_percent 40 epoch 76: loss_train=0.6707, acc_train=0.5909, loss_test=0.5186, acc_test=0.9184
# poison_percent 40 epoch 77: loss_train=0.7939, acc_train=0.3636, loss_test=0.5082, acc_test=0.9204
# poison_percent 40 epoch 78: loss_train=0.6818, acc_train=0.6364, loss_test=0.5017, acc_test=0.9250
# poison_percent 40 epoch 79: loss_train=0.6293, acc_train=0.6818, loss_test=0.4741, acc_test=0.9474
# poison_percent 40 epoch 80: loss_train=0.6133, acc_train=0.6818, loss_test=0.5011, acc_test=0.9327
# poison_percent 40 epoch 81: loss_train=0.6651, acc_train=0.5455, loss_test=0.5058, acc_test=0.9255
# ...
# poison_percent 40 epoch 41: loss_train=0.6932, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 42: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 43: loss_train=0.6933, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 44: loss_train=0.6933, acc_train=0.3182, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 45: loss_train=0.6932, acc_train=0.3636, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 46: loss_train=0.6930, acc_train=0.6364, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 47: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 48: loss_train=0.6933, acc_train=0.3636, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 49: loss_train=0.6927, acc_train=0.6364, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 50: loss_train=0.6941, acc_train=0.2727, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 51: loss_train=0.6937, acc_train=0.3182, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 52: loss_train=0.6932, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 53: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 54: loss_train=0.6930, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 55: loss_train=0.6930, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 56: loss_train=0.6930, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 57: loss_train=0.6933, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 58: loss_train=0.6931, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 59: loss_train=0.6925, acc_train=0.5909, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 60: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 61: loss_train=0.6930, acc_train=0.6364, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 62: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 63: loss_train=0.6931, acc_train=0.5455, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 64: loss_train=0.6929, acc_train=0.6364, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 65: loss_train=0.6933, acc_train=0.4545, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 66: loss_train=0.6933, acc_train=0.3182, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 67: loss_train=0.6930, acc_train=0.5455, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 68: loss_train=0.6932, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 69: loss_train=0.6940, acc_train=0.3636, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 70: loss_train=0.6930, acc_train=0.5455, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 71: loss_train=0.6932, acc_train=0.3636, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 72: loss_train=0.6930, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 73: loss_train=0.6936, acc_train=0.3636, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 74: loss_train=0.6936, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 75: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 76: loss_train=0.6933, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 77: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 78: loss_train=0.6932, acc_train=0.3182, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 79: loss_train=0.6931, acc_train=0.5455, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 80: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 81: loss_train=0.6937, acc_train=0.3636, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 82: loss_train=0.6940, acc_train=0.4091, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 83: loss_train=0.6939, acc_train=0.3636, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 84: loss_train=0.6932, acc_train=0.4545, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 85: loss_train=0.6930, acc_train=0.5455, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 86: loss_train=0.6930, acc_train=0.5455, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 87: loss_train=0.6931, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 88: loss_train=0.6933, acc_train=0.4545, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 89: loss_train=0.6934, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 90: loss_train=0.6931, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 91: loss_train=0.6933, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 92: loss_train=0.6937, acc_train=0.3636, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 93: loss_train=0.6930, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 94: loss_train=0.6932, acc_train=0.4545, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 95: loss_train=0.6931, acc_train=0.5455, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 96: loss_train=0.6936, acc_train=0.3182, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 97: loss_train=0.6931, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 98: loss_train=0.6932, acc_train=0.3636, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 99: loss_train=0.6933, acc_train=0.4545, loss_test=0.6931, acc_test=0.5000
# Training log saved to ./results\CL_ModelN1L6_Batchsize32_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 epoch 0: loss_train=0.6931, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 1: loss_train=0.6926, acc_train=0.6875, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 2: loss_train=0.6931, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 3: loss_train=0.6933, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 4: loss_train=0.6931, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 5: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 6: loss_train=0.6931, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 7: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 8: loss_train=0.6930, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 9: loss_train=0.6929, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 10: loss_train=0.6932, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 11: loss_train=0.6932, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 12: loss_train=0.6932, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 13: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 14: loss_train=0.6942, acc_train=0.0625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 15: loss_train=0.6935, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 16: loss_train=0.6933, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 17: loss_train=0.6935, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 18: loss_train=0.6947, acc_train=0.2500, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 19: loss_train=0.6938, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 20: loss_train=0.6930, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 21: loss_train=0.6921, acc_train=0.6875, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 22: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 23: loss_train=0.6935, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 24: loss_train=0.6923, acc_train=0.6875, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 25: loss_train=0.6936, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 26: loss_train=0.6948, acc_train=0.2500, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 27: loss_train=0.6932, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 28: loss_train=0.6934, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 29: loss_train=0.6933, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 30: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 31: loss_train=0.6930, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 32: loss_train=0.6933, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 33: loss_train=0.6925, acc_train=0.6875, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 34: loss_train=0.6932, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 35: loss_train=0.6938, acc_train=0.2500, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 36: loss_train=0.6932, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 37: loss_train=0.6929, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 38: loss_train=0.6934, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 39: loss_train=0.6939, acc_train=0.3750, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 40: loss_train=0.6928, acc_train=0.6875, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 41: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 42: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 43: loss_train=0.6927, acc_train=0.5625, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 44: loss_train=0.6921, acc_train=0.8125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 45: loss_train=0.6925, acc_train=0.6250, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 46: loss_train=0.6931, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 47: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 48: loss_train=0.6932, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 49: loss_train=0.6934, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 50: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 51: loss_train=0.6931, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 52: loss_train=0.6930, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 53: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 54: loss_train=0.6934, acc_train=0.2500, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 55: loss_train=0.6928, acc_train=0.5625, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 56: loss_train=0.6936, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 57: loss_train=0.6932, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 58: loss_train=0.6931, acc_train=0.6875, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 59: loss_train=0.6935, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 60: loss_train=0.6930, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 61: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 62: loss_train=0.6931, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 63: loss_train=0.6932, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 64: loss_train=0.6937, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 65: loss_train=0.6937, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 66: loss_train=0.6939, acc_train=0.2500, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 67: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 68: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 69: loss_train=0.6921, acc_train=0.9375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 70: loss_train=0.6928, acc_train=0.5625, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 71: loss_train=0.6938, acc_train=0.3750, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 72: loss_train=0.6937, acc_train=0.4375, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 73: loss_train=0.6932, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 74: loss_train=0.6932, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 75: loss_train=0.6927, acc_train=0.6875, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 76: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 77: loss_train=0.6931, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 78: loss_train=0.6928, acc_train=0.5625, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 79: loss_train=0.6941, acc_train=0.2500, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 80: loss_train=0.6931, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 81: loss_train=0.6932, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 82: loss_train=0.6929, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 83: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 84: loss_train=0.6940, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 85: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 86: loss_train=0.6931, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 87: loss_train=0.6939, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 88: loss_train=0.6927, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 89: loss_train=0.6923, acc_train=0.6250, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 90: loss_train=0.6936, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 91: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 92: loss_train=0.6933, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 93: loss_train=0.6931, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 94: loss_train=0.6926, acc_train=0.5625, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 95: loss_train=0.6932, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 96: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 97: loss_train=0.6936, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 98: loss_train=0.6929, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 99: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# Training log saved to ./results\CL_ModelN1L6_Batchsize32_rev2\poisoned_50percent\poisoned_50percent.csv
