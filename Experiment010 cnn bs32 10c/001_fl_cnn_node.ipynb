# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x
    
# save state_dict + metadata (safe, portable)
def save_model(model, img_size, n_classes, learning_rate, experiment_bs, file_path):

    state = {
        "model_state_dict": model.state_dict(),                     # CPU/GPU tensors okay
        "arch": "MNISTNet",
        "img_size": img_size,
        "num_classes": n_classes,
        "training_args": {"lr": learning_rate, "batch_size": experiment_bs}
    }
    # ensure weights are on CPU to avoid GPU-only pickle issues
    state["model_state_dict"] = {k: v.cpu() for k, v in state["model_state_dict"].items()}
    torch.save(state, file_path)
    
def load_model(file_path, device):

    checkpoint = torch.load(file_path, map_location=device)
    model = MNISTNet().to(device)              # must have MNISTNet class defined/importable
    model.load_state_dict(checkpoint["model_state_dict"])
    model.eval()
    return model

# %% [markdown]
# # 4.Loss

# %%
# def binary_cross_entropy(pred, target):
#     eps = 1e-7
#     pred = torch.clamp(pred, eps, 1 - eps)
#     return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

def multiclass_cross_entropy(logits, target, from_probs=False, eps=1e-7):
    """
    Cross-entropy loss for multiclass (e.g., 10 classes).
    - logits: Tensor shape (N, C) containing raw scores (preferred) or probabilities if from_probs=True
    - target: Tensor shape (N,) or (N,1) containing class indices (0..C-1)
    """
    if logits.dim() == 1:
        logits = logits.unsqueeze(0)
    target = target.squeeze()
    if target.dtype != torch.long:
        target = target.long()
    if from_probs:
        probs = torch.clamp(logits, eps, 1.0 - eps)
        log_probs = torch.log(probs)
        return -log_probs[torch.arange(target.size(0)), target].mean()
    return nn.functional.cross_entropy(logits, target)

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    # create model on target device
    model = MNISTNet().to(device)
    # ensure weights are mapped to the worker device
    state_on_device = {k: v.to(device) for k, v in global_weights.items()}
    model.load_state_dict(state_on_device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end].to(device)
            yb = y_c_tensor[start:end].to(device)
            outputs = model(xb)
            # preds = (outputs >= 0.5).float()
            preds = torch.argmax(outputs, dim=1, keepdim=True)
            loss = multiclass_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # return CPU copies for safe aggregation in main thread
    returned_state = {k: v.detach().cpu() for k, v in model.state_dict().items()}
    return returned_state, X_c_tensor.size(0), yb.detach().cpu(), outputs.detach().cpu(), preds.detach().cpu()

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 32
N_CLASSES = 10

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_multiple_poison/train"
TEST_PATH = "../data/mnist_multiple_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
import re
def make_safe_filename(name: str) -> str:
    # remove control chars and characters invalid on Windows
    safe = re.sub(r'[<>:"/\\|?*\x00-\x1F]', '_', name)
    # strip trailing dots/spaces which are problematic on Windows
    safe = safe.rstrip('. ')
    return safe

# %%
for NODE in [1,2,4,8,16,32]:
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            self.conv1 = nn.Conv2d(1, NODE, kernel_size=3, padding=1) # 28x28
            self.pool = nn.MaxPool2d(2, 2) # 14x14
            self.fc1 = nn.Linear(NODE * 14 * 14, N_CLASSES)
            self.relu = nn.ReLU()
            
        def forward(self, x):
            x = x.view(-1, 1, 28, 28)
            x = self.pool(self.relu(self.conv1(x)))
            x = x.view(x.size(0), -1)
            x = self.fc1(x)
            # x = torch.sigmoid(x)
            return x

    BATCH_SIZE_list = [BATCH_SIZE]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        global_model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"FL_ModelN{NODE}L2_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                # torch.save(model, os.path.join(save_path,'model_init.pt'))
                save_path_name = os.path.join(save_path,'model_init.pt')
                save_model(global_model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)
                
                global_weights = global_model.state_dict()

                records = []

                X_train_tensor = {}
                y_train_tensor = {}
                for i in range(N_HONEST):
                    X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"honest_{i}"] = X_c_tensor
                    y_train_tensor[f"honest_{i}"] = y_c_tensor
                for i in range(i_poisoned):
                    X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"poison_{i}"] = X_c_tensor
                    y_train_tensor[f"poison_{i}"] = y_c_tensor

                # Training loop
                for round in range(ROUNDS):
                    # Prepare arguments for honest clients
                    
                    #randomize the training data
                    for i in range(N_HONEST):
                        perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                        X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                        y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                    honest_args = [
                        (
                            X_train_tensor[f"honest_{i}"],
                            y_train_tensor[f"honest_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(N_HONEST)
                    ]

                    # Prepare arguments for poisoned clients
                    
                    #randomize the training data
                    for i in range(i_poisoned):
                        perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                        X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                        y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                    poison_args = [
                        (
                            X_train_tensor[f"poison_{i}"],
                            y_train_tensor[f"poison_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(i_poisoned)
                    ]

                    # Run in parallel
                    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                        honest_results = list(executor.map(train_local_worker, honest_args))
                        poison_results = list(executor.map(train_local_worker, poison_args))

                    local_weights = []
                    local_sizes = []
                    local_y = []
                    local_outputs = []
                    local_preds = []
                    for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                        local_weights.append(l_w)
                        local_sizes.append(l_sz)
                        local_y.extend(l_y)
                        local_outputs.extend(l_out)
                        local_preds.extend(l_pred)
                    loss_train = multiclass_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                    acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                    # Federated averaging (weighted by client data size)
                    new_weights = {}
                    for key in global_weights.keys():
                        new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                    global_weights = new_weights
                    global_model.load_state_dict(global_weights)

                    # Evaluate
                    global_model.eval()
                    with torch.no_grad():
                        outputs = global_model(X_test_tensor)
                        # preds = (outputs > 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        loss_test = multiclass_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'round': round, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"round {round}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                # torch.save(model, os.path.join(save_path,'model_last.pt'))
                save_path_name = os.path.join(save_path,'model_last.pt')
                save_model(global_model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)

                # Save training log
                df = pd.DataFrame(records)
                
                # save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                safe_name = make_safe_filename(NAME_SAVE_update_PATH)
                save_name_path = os.path.abspath(os.path.join(save_path, f'{safe_name}.csv'))
                os.makedirs(os.path.dirname(save_name_path), exist_ok=True)

                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['round'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['round'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 round 0: loss_train=2.3032, acc_train=0.1149, loss_test=2.3391, acc_test=0.0031
# poison_percent 0 round 1: loss_train=2.2956, acc_train=0.1359, loss_test=2.3284, acc_test=0.0025
# poison_percent 0 round 2: loss_train=2.2878, acc_train=0.1673, loss_test=2.3175, acc_test=0.0018
# poison_percent 0 round 3: loss_train=2.2770, acc_train=0.2001, loss_test=2.3097, acc_test=0.0067
# poison_percent 0 round 4: loss_train=2.2650, acc_train=0.2356, loss_test=2.2971, acc_test=0.0294
# poison_percent 0 round 5: loss_train=2.2462, acc_train=0.2825, loss_test=2.2775, acc_test=0.1042
# poison_percent 0 round 6: loss_train=2.2277, acc_train=0.3236, loss_test=2.2596, acc_test=0.1489
# poison_percent 0 round 7: loss_train=2.2041, acc_train=0.3743, loss_test=2.2381, acc_test=0.1881
# poison_percent 0 round 8: loss_train=2.1827, acc_train=0.3977, loss_test=2.2072, acc_test=0.2494
# poison_percent 0 round 9: loss_train=2.1489, acc_train=0.4495, loss_test=2.1692, acc_test=0.3370
# poison_percent 0 round 10: loss_train=2.1197, acc_train=0.4805, loss_test=2.1244, acc_test=0.4381
# poison_percent 0 round 11: loss_train=2.0836, acc_train=0.5195, loss_test=2.0745, acc_test=0.5631
# poison_percent 0 round 12: loss_train=2.0444, acc_train=0.5647, loss_test=2.0170, acc_test=0.6863
# poison_percent 0 round 13: loss_train=1.9908, acc_train=0.6078, loss_test=1.9437, acc_test=0.7880
# poison_percent 0 round 14: loss_train=1.9341, acc_train=0.6478, loss_test=1.8696, acc_test=0.8395
# poison_percent 0 round 15: loss_train=1.8710, acc_train=0.6823, loss_test=1.7851, acc_test=0.8725
# poison_percent 0 round 16: loss_train=1.8200, acc_train=0.6875, loss_test=1.6880, acc_test=0.9020
# poison_percent 0 round 17: loss_train=1.7679, acc_train=0.6944, loss_test=1.5882, acc_test=0.9130
# poison_percent 0 round 18: loss_train=1.6861, acc_train=0.7303, loss_test=1.4903, acc_test=0.9179
# poison_percent 0 round 19: loss_train=1.6177, acc_train=0.7334, loss_test=1.3982, acc_test=0.9203
# poison_percent 0 round 20: loss_train=1.5514, acc_train=0.7389, loss_test=1.2937, acc_test=0.9265
# poison_percent 0 round 21: loss_train=1.4838, acc_train=0.7378, loss_test=1.1945, acc_test=0.9295
# poison_percent 0 round 22: loss_train=1.3956, acc_train=0.7554, loss_test=1.1037, acc_test=0.9289
# poison_percent 0 round 23: loss_train=1.3409, acc_train=0.7541, loss_test=1.0207, acc_test=0.9289
# poison_percent 0 round 24: loss_train=1.2827, acc_train=0.7499, loss_test=0.9310, acc_test=0.9320
# poison_percent 0 round 25: loss_train=1.1982, acc_train=0.7710, loss_test=0.8615, acc_test=0.9308
# poison_percent 0 round 26: loss_train=1.1559, acc_train=0.7582, loss_test=0.7927, acc_test=0.9308
# poison_percent 0 round 27: loss_train=1.0845, acc_train=0.7734, loss_test=0.7269, acc_test=0.9320
# poison_percent 0 round 28: loss_train=1.0487, acc_train=0.7685, loss_test=0.6719, acc_test=0.9320
# poison_percent 0 round 29: loss_train=0.9948, acc_train=0.7730, loss_test=0.6197, acc_test=0.9332
# poison_percent 0 round 30: loss_train=0.9503, acc_train=0.7858, loss_test=0.5753, acc_test=0.9326
# poison_percent 0 round 31: loss_train=0.9290, acc_train=0.7816, loss_test=0.5347, acc_test=0.9350
# poison_percent 0 round 32: loss_train=0.8634, acc_train=0.7896, loss_test=0.5022, acc_test=0.9344
# poison_percent 0 round 33: loss_train=0.8424, acc_train=0.7986, loss_test=0.4728, acc_test=0.9338
# poison_percent 0 round 34: loss_train=0.8062, acc_train=0.7954, loss_test=0.4466, acc_test=0.9344
# poison_percent 0 round 35: loss_train=0.7489, acc_train=0.8161, loss_test=0.4226, acc_test=0.9338
# poison_percent 0 round 36: loss_train=0.7642, acc_train=0.7975, loss_test=0.3990, acc_test=0.9338
# poison_percent 0 round 37: loss_train=0.7219, acc_train=0.8079, loss_test=0.3776, acc_test=0.9369
# poison_percent 0 round 38: loss_train=0.6965, acc_train=0.8123, loss_test=0.3637, acc_test=0.9375
# poison_percent 0 round 39: loss_train=0.6879, acc_train=0.8182, loss_test=0.3477, acc_test=0.9387
# poison_percent 0 round 40: loss_train=0.6755, acc_train=0.8065, loss_test=0.3324, acc_test=0.9387
# poison_percent 0 round 41: loss_train=0.6232, acc_train=0.8279, loss_test=0.3225, acc_test=0.9387
# poison_percent 0 round 42: loss_train=0.6340, acc_train=0.8351, loss_test=0.3111, acc_test=0.9387
# poison_percent 0 round 43: loss_train=0.5935, acc_train=0.8375, loss_test=0.3004, acc_test=0.9387
# poison_percent 0 round 44: loss_train=0.5670, acc_train=0.8368, loss_test=0.2911, acc_test=0.9393
# poison_percent 0 round 45: loss_train=0.5992, acc_train=0.8275, loss_test=0.2836, acc_test=0.9400
# poison_percent 0 round 46: loss_train=0.6097, acc_train=0.8275, loss_test=0.2754, acc_test=0.9418
# poison_percent 0 round 47: loss_train=0.6050, acc_train=0.8320, loss_test=0.2638, acc_test=0.9436
# poison_percent 0 round 48: loss_train=0.5258, acc_train=0.8593, loss_test=0.2587, acc_test=0.9442
# poison_percent 0 round 49: loss_train=0.5241, acc_train=0.8493, loss_test=0.2538, acc_test=0.9467
# poison_percent 0 round 50: loss_train=0.5351, acc_train=0.8479, loss_test=0.2471, acc_test=0.9473
# poison_percent 0 round 51: loss_train=0.5151, acc_train=0.8510, loss_test=0.2438, acc_test=0.9473
# poison_percent 0 round 52: loss_train=0.5046, acc_train=0.8575, loss_test=0.2370, acc_test=0.9485
# poison_percent 0 round 53: loss_train=0.4944, acc_train=0.8527, loss_test=0.2331, acc_test=0.9491
# poison_percent 0 round 54: loss_train=0.5055, acc_train=0.8472, loss_test=0.2286, acc_test=0.9498
# poison_percent 0 round 55: loss_train=0.4943, acc_train=0.8610, loss_test=0.2273, acc_test=0.9504
# poison_percent 0 round 56: loss_train=0.4923, acc_train=0.8458, loss_test=0.2216, acc_test=0.9516
# poison_percent 0 round 57: loss_train=0.4844, acc_train=0.8586, loss_test=0.2188, acc_test=0.9516
# poison_percent 0 round 58: loss_train=0.4791, acc_train=0.8606, loss_test=0.2158, acc_test=0.9522
# poison_percent 0 round 59: loss_train=0.4784, acc_train=0.8651, loss_test=0.2135, acc_test=0.9522
# poison_percent 0 round 60: loss_train=0.4856, acc_train=0.8582, loss_test=0.2106, acc_test=0.9534
# poison_percent 0 round 61: loss_train=0.5116, acc_train=0.8551, loss_test=0.2077, acc_test=0.9540
# poison_percent 0 round 62: loss_train=0.4647, acc_train=0.8610, loss_test=0.2067, acc_test=0.9540
# poison_percent 0 round 63: loss_train=0.4953, acc_train=0.8600, loss_test=0.2037, acc_test=0.9553
# poison_percent 0 round 64: loss_train=0.4718, acc_train=0.8620, loss_test=0.2020, acc_test=0.9553
# poison_percent 0 round 65: loss_train=0.4404, acc_train=0.8741, loss_test=0.1974, acc_test=0.9559
# poison_percent 0 round 66: loss_train=0.4551, acc_train=0.8769, loss_test=0.1951, acc_test=0.9565
# poison_percent 0 round 67: loss_train=0.4369, acc_train=0.8734, loss_test=0.1930, acc_test=0.9559
# poison_percent 0 round 68: loss_train=0.4351, acc_train=0.8720, loss_test=0.1925, acc_test=0.9547
# poison_percent 0 round 69: loss_train=0.4464, acc_train=0.8675, loss_test=0.1911, acc_test=0.9553
# poison_percent 0 round 70: loss_train=0.4426, acc_train=0.8644, loss_test=0.1893, acc_test=0.9553
# poison_percent 0 round 71: loss_train=0.4105, acc_train=0.8758, loss_test=0.1861, acc_test=0.9565
# poison_percent 0 round 72: loss_train=0.4365, acc_train=0.8693, loss_test=0.1886, acc_test=0.9571
# poison_percent 0 round 73: loss_train=0.4209, acc_train=0.8817, loss_test=0.1853, acc_test=0.9571
# poison_percent 0 round 74: loss_train=0.3851, acc_train=0.8789, loss_test=0.1832, acc_test=0.9571
# poison_percent 0 round 75: loss_train=0.4149, acc_train=0.8813, loss_test=0.1826, acc_test=0.9565
# poison_percent 0 round 76: loss_train=0.4468, acc_train=0.8717, loss_test=0.1830, acc_test=0.9565
# poison_percent 0 round 77: loss_train=0.4221, acc_train=0.8769, loss_test=0.1791, acc_test=0.9571
# poison_percent 0 round 78: loss_train=0.4499, acc_train=0.8751, loss_test=0.1772, acc_test=0.9571
# poison_percent 0 round 79: loss_train=0.4262, acc_train=0.8806, loss_test=0.1750, acc_test=0.9583
# poison_percent 0 round 80: loss_train=0.4592, acc_train=0.8662, loss_test=0.1739, acc_test=0.9589
# poison_percent 0 round 81: loss_train=0.4456, acc_train=0.8700, loss_test=0.1751, acc_test=0.9583
# poison_percent 0 round 82: loss_train=0.3977, acc_train=0.8841, loss_test=0.1737, acc_test=0.9596
# poison_percent 0 round 83: loss_train=0.4081, acc_train=0.8838, loss_test=0.1735, acc_test=0.9596
# poison_percent 0 round 84: loss_train=0.3904, acc_train=0.8820, loss_test=0.1716, acc_test=0.9602
# poison_percent 0 round 85: loss_train=0.4137, acc_train=0.8831, loss_test=0.1723, acc_test=0.9608
# poison_percent 0 round 86: loss_train=0.4088, acc_train=0.8813, loss_test=0.1681, acc_test=0.9608
# poison_percent 0 round 87: loss_train=0.4363, acc_train=0.8744, loss_test=0.1687, acc_test=0.9608
# poison_percent 0 round 88: loss_train=0.3916, acc_train=0.8810, loss_test=0.1685, acc_test=0.9608
# poison_percent 0 round 89: loss_train=0.4157, acc_train=0.8744, loss_test=0.1678, acc_test=0.9608
# poison_percent 0 round 90: loss_train=0.3881, acc_train=0.8862, loss_test=0.1667, acc_test=0.9614
# poison_percent 0 round 91: loss_train=0.4288, acc_train=0.8717, loss_test=0.1671, acc_test=0.9596
# poison_percent 0 round 92: loss_train=0.4080, acc_train=0.8827, loss_test=0.1676, acc_test=0.9608
# poison_percent 0 round 93: loss_train=0.4211, acc_train=0.8772, loss_test=0.1641, acc_test=0.9614
# poison_percent 0 round 94: loss_train=0.4669, acc_train=0.8679, loss_test=0.1629, acc_test=0.9614
# poison_percent 0 round 95: loss_train=0.3894, acc_train=0.8913, loss_test=0.1628, acc_test=0.9620
# poison_percent 0 round 96: loss_train=0.4198, acc_train=0.8779, loss_test=0.1629, acc_test=0.9614
# poison_percent 0 round 97: loss_train=0.4022, acc_train=0.8862, loss_test=0.1628, acc_test=0.9614
# poison_percent 0 round 98: loss_train=0.3873, acc_train=0.8886, loss_test=0.1621, acc_test=0.9620
# poison_percent 0 round 99: loss_train=0.4212, acc_train=0.8720, loss_test=0.1598, acc_test=0.9620
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\FL_ModelN1L2_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 round 0: loss_train=1.2665, acc_train=0.7964, loss_test=0.1445, acc_test=0.9651
# poison_percent 10 round 1: loss_train=1.2036, acc_train=0.7949, loss_test=0.1400, acc_test=0.9663
# poison_percent 10 round 2: loss_train=1.2131, acc_train=0.7918, loss_test=0.1373, acc_test=0.9681
# poison_percent 10 round 3: loss_train=1.1791, acc_train=0.7973, loss_test=0.1353, acc_test=0.9688
# poison_percent 10 round 4: loss_train=1.1847, acc_train=0.7964, loss_test=0.1346, acc_test=0.9688
# poison_percent 10 round 5: loss_train=1.1725, acc_train=0.7936, loss_test=0.1327, acc_test=0.9688
# poison_percent 10 round 6: loss_train=1.1663, acc_train=0.7939, loss_test=0.1325, acc_test=0.9681
# poison_percent 10 round 7: loss_train=1.2324, acc_train=0.7859, loss_test=0.1307, acc_test=0.9688
# poison_percent 10 round 8: loss_train=1.2618, acc_train=0.7902, loss_test=0.1308, acc_test=0.9688
# poison_percent 10 round 9: loss_train=1.2162, acc_train=0.7936, loss_test=0.1302, acc_test=0.9688
# poison_percent 10 round 10: loss_train=1.2407, acc_train=0.7942, loss_test=0.1297, acc_test=0.9694
# poison_percent 10 round 11: loss_train=1.1501, acc_train=0.8041, loss_test=0.1302, acc_test=0.9688
# poison_percent 10 round 12: loss_train=1.1752, acc_train=0.8035, loss_test=0.1299, acc_test=0.9688
# poison_percent 10 round 13: loss_train=1.1723, acc_train=0.8020, loss_test=0.1299, acc_test=0.9688
# poison_percent 10 round 14: loss_train=1.1448, acc_train=0.8072, loss_test=0.1292, acc_test=0.9694
# poison_percent 10 round 15: loss_train=1.2189, acc_train=0.7927, loss_test=0.1270, acc_test=0.9718
# poison_percent 10 round 16: loss_train=1.2368, acc_train=0.8004, loss_test=0.1257, acc_test=0.9718
# poison_percent 10 round 17: loss_train=1.1504, acc_train=0.7946, loss_test=0.1259, acc_test=0.9718
# poison_percent 10 round 18: loss_train=1.2583, acc_train=0.7973, loss_test=0.1265, acc_test=0.9706
# poison_percent 10 round 19: loss_train=1.2029, acc_train=0.8029, loss_test=0.1260, acc_test=0.9712
# poison_percent 10 round 20: loss_train=1.2000, acc_train=0.7973, loss_test=0.1281, acc_test=0.9706
# poison_percent 10 round 21: loss_train=1.2153, acc_train=0.7946, loss_test=0.1261, acc_test=0.9706
# poison_percent 10 round 22: loss_train=1.1720, acc_train=0.7986, loss_test=0.1256, acc_test=0.9712
# poison_percent 10 round 23: loss_train=1.1639, acc_train=0.8029, loss_test=0.1251, acc_test=0.9706
# poison_percent 10 round 24: loss_train=1.1908, acc_train=0.8060, loss_test=0.1246, acc_test=0.9712
# poison_percent 10 round 25: loss_train=1.1763, acc_train=0.8035, loss_test=0.1232, acc_test=0.9712
# poison_percent 10 round 26: loss_train=1.1987, acc_train=0.7918, loss_test=0.1241, acc_test=0.9712
# poison_percent 10 round 27: loss_train=1.2098, acc_train=0.7976, loss_test=0.1240, acc_test=0.9712
# poison_percent 10 round 28: loss_train=1.1551, acc_train=0.7924, loss_test=0.1241, acc_test=0.9712
# poison_percent 10 round 29: loss_train=1.2053, acc_train=0.7973, loss_test=0.1243, acc_test=0.9706
# poison_percent 10 round 30: loss_train=1.2095, acc_train=0.7998, loss_test=0.1231, acc_test=0.9712
# poison_percent 10 round 31: loss_train=1.1899, acc_train=0.8020, loss_test=0.1212, acc_test=0.9718
# poison_percent 10 round 32: loss_train=1.1915, acc_train=0.8001, loss_test=0.1212, acc_test=0.9724
# poison_percent 10 round 33: loss_train=1.2080, acc_train=0.8029, loss_test=0.1216, acc_test=0.9718
# poison_percent 10 round 34: loss_train=1.1961, acc_train=0.8066, loss_test=0.1213, acc_test=0.9718
# poison_percent 10 round 35: loss_train=1.1889, acc_train=0.7952, loss_test=0.1213, acc_test=0.9712
# poison_percent 10 round 36: loss_train=1.1845, acc_train=0.8004, loss_test=0.1209, acc_test=0.9718
# poison_percent 10 round 37: loss_train=1.2484, acc_train=0.7952, loss_test=0.1216, acc_test=0.9712
# poison_percent 10 round 38: loss_train=1.1742, acc_train=0.7998, loss_test=0.1218, acc_test=0.9712
# poison_percent 10 round 39: loss_train=1.2020, acc_train=0.7983, loss_test=0.1217, acc_test=0.9712
# poison_percent 10 round 40: loss_train=1.2361, acc_train=0.8075, loss_test=0.1207, acc_test=0.9718
# poison_percent 10 round 41: loss_train=1.1911, acc_train=0.8038, loss_test=0.1201, acc_test=0.9718
# poison_percent 10 round 42: loss_train=1.1819, acc_train=0.8045, loss_test=0.1193, acc_test=0.9724
# poison_percent 10 round 43: loss_train=1.1603, acc_train=0.8097, loss_test=0.1186, acc_test=0.9730
# poison_percent 10 round 44: loss_train=1.1765, acc_train=0.7995, loss_test=0.1183, acc_test=0.9730
# poison_percent 10 round 45: loss_train=1.1530, acc_train=0.8051, loss_test=0.1187, acc_test=0.9718
# poison_percent 10 round 46: loss_train=1.1956, acc_train=0.8048, loss_test=0.1178, acc_test=0.9737
# poison_percent 10 round 47: loss_train=1.2111, acc_train=0.8004, loss_test=0.1173, acc_test=0.9737
# poison_percent 10 round 48: loss_train=1.1338, acc_train=0.8085, loss_test=0.1168, acc_test=0.9737
# poison_percent 10 round 49: loss_train=1.1589, acc_train=0.7970, loss_test=0.1181, acc_test=0.9737
# poison_percent 10 round 50: loss_train=1.1782, acc_train=0.8085, loss_test=0.1181, acc_test=0.9737
# poison_percent 10 round 51: loss_train=1.1895, acc_train=0.8004, loss_test=0.1176, acc_test=0.9737
# poison_percent 10 round 52: loss_train=1.1683, acc_train=0.8029, loss_test=0.1173, acc_test=0.9737
# poison_percent 10 round 53: loss_train=1.2340, acc_train=0.8038, loss_test=0.1173, acc_test=0.9737
# poison_percent 10 round 54: loss_train=1.1866, acc_train=0.8032, loss_test=0.1169, acc_test=0.9737
# poison_percent 10 round 55: loss_train=1.1581, acc_train=0.8116, loss_test=0.1174, acc_test=0.9737
# poison_percent 10 round 56: loss_train=1.2481, acc_train=0.8001, loss_test=0.1151, acc_test=0.9743
# poison_percent 10 round 57: loss_train=1.1602, acc_train=0.8082, loss_test=0.1158, acc_test=0.9743
# poison_percent 10 round 58: loss_train=1.1672, acc_train=0.8069, loss_test=0.1155, acc_test=0.9743
# poison_percent 10 round 59: loss_train=1.1936, acc_train=0.8091, loss_test=0.1149, acc_test=0.9743
# poison_percent 10 round 60: loss_train=1.1956, acc_train=0.7998, loss_test=0.1160, acc_test=0.9743
# poison_percent 10 round 61: loss_train=1.2002, acc_train=0.8029, loss_test=0.1163, acc_test=0.9743
# poison_percent 10 round 62: loss_train=1.1808, acc_train=0.8004, loss_test=0.1160, acc_test=0.9743
# poison_percent 10 round 63: loss_train=1.1807, acc_train=0.8023, loss_test=0.1150, acc_test=0.9749
# poison_percent 10 round 64: loss_train=1.2062, acc_train=0.8017, loss_test=0.1150, acc_test=0.9749
# poison_percent 10 round 65: loss_train=1.2146, acc_train=0.8007, loss_test=0.1152, acc_test=0.9749
# poison_percent 10 round 66: loss_train=1.1673, acc_train=0.8091, loss_test=0.1149, acc_test=0.9749
# poison_percent 10 round 67: loss_train=1.1584, acc_train=0.8100, loss_test=0.1143, acc_test=0.9749
# poison_percent 10 round 68: loss_train=1.1834, acc_train=0.7998, loss_test=0.1149, acc_test=0.9749
# poison_percent 10 round 69: loss_train=1.1787, acc_train=0.8168, loss_test=0.1145, acc_test=0.9755
# poison_percent 10 round 70: loss_train=1.2304, acc_train=0.8063, loss_test=0.1143, acc_test=0.9755
# poison_percent 10 round 71: loss_train=1.2102, acc_train=0.8007, loss_test=0.1144, acc_test=0.9761
# poison_percent 10 round 72: loss_train=1.1560, acc_train=0.8075, loss_test=0.1132, acc_test=0.9761
# poison_percent 10 round 73: loss_train=1.1777, acc_train=0.8038, loss_test=0.1138, acc_test=0.9767
# poison_percent 10 round 74: loss_train=1.2287, acc_train=0.7955, loss_test=0.1131, acc_test=0.9767
# poison_percent 10 round 75: loss_train=1.1833, acc_train=0.8051, loss_test=0.1136, acc_test=0.9755
# poison_percent 10 round 76: loss_train=1.2522, acc_train=0.8029, loss_test=0.1130, acc_test=0.9755
# poison_percent 10 round 77: loss_train=1.1457, acc_train=0.8088, loss_test=0.1143, acc_test=0.9755
# poison_percent 10 round 78: loss_train=1.1940, acc_train=0.8020, loss_test=0.1134, acc_test=0.9773
# poison_percent 10 round 79: loss_train=1.0995, acc_train=0.8137, loss_test=0.1120, acc_test=0.9773
# poison_percent 10 round 80: loss_train=1.1673, acc_train=0.8023, loss_test=0.1123, acc_test=0.9773
# poison_percent 10 round 81: loss_train=1.1989, acc_train=0.7933, loss_test=0.1113, acc_test=0.9773
# poison_percent 10 round 82: loss_train=1.2197, acc_train=0.8100, loss_test=0.1126, acc_test=0.9773
# poison_percent 10 round 83: loss_train=1.1730, acc_train=0.8014, loss_test=0.1113, acc_test=0.9773
# poison_percent 10 round 84: loss_train=1.1906, acc_train=0.8038, loss_test=0.1119, acc_test=0.9773
# poison_percent 10 round 85: loss_train=1.1880, acc_train=0.8038, loss_test=0.1116, acc_test=0.9773
# poison_percent 10 round 86: loss_train=1.1786, acc_train=0.8069, loss_test=0.1105, acc_test=0.9773
# poison_percent 10 round 87: loss_train=1.1904, acc_train=0.8001, loss_test=0.1124, acc_test=0.9773
# poison_percent 10 round 88: loss_train=1.1359, acc_train=0.8116, loss_test=0.1138, acc_test=0.9773
# poison_percent 10 round 89: loss_train=1.2268, acc_train=0.8017, loss_test=0.1131, acc_test=0.9773
# poison_percent 10 round 90: loss_train=1.1462, acc_train=0.8128, loss_test=0.1124, acc_test=0.9773
# poison_percent 10 round 91: loss_train=1.1577, acc_train=0.8156, loss_test=0.1128, acc_test=0.9773
# poison_percent 10 round 92: loss_train=1.1889, acc_train=0.8032, loss_test=0.1138, acc_test=0.9773
# poison_percent 10 round 93: loss_train=1.2464, acc_train=0.8017, loss_test=0.1138, acc_test=0.9767
# poison_percent 10 round 94: loss_train=1.1955, acc_train=0.8048, loss_test=0.1146, acc_test=0.9767
# poison_percent 10 round 95: loss_train=1.1339, acc_train=0.8097, loss_test=0.1130, acc_test=0.9773
# poison_percent 10 round 96: loss_train=1.1791, acc_train=0.8051, loss_test=0.1122, acc_test=0.9773
# poison_percent 10 round 97: loss_train=1.1733, acc_train=0.7992, loss_test=0.1114, acc_test=0.9773
# poison_percent 10 round 98: loss_train=1.2040, acc_train=0.8097, loss_test=0.1116, acc_test=0.9773
# poison_percent 10 round 99: loss_train=1.2308, acc_train=0.8097, loss_test=0.1109, acc_test=0.9773
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\FL_ModelN1L2_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=1.9424, acc_train=0.7310, loss_test=0.1029, acc_test=0.9779
# poison_percent 20 round 1: loss_train=1.8223, acc_train=0.7357, loss_test=0.0983, acc_test=0.9792
# poison_percent 20 round 2: loss_train=1.8599, acc_train=0.7312, loss_test=0.0965, acc_test=0.9798
# poison_percent 20 round 3: loss_train=1.7276, acc_train=0.7360, loss_test=0.0956, acc_test=0.9798
# poison_percent 20 round 4: loss_train=1.8120, acc_train=0.7318, loss_test=0.0951, acc_test=0.9804
# poison_percent 20 round 5: loss_train=1.8218, acc_train=0.7335, loss_test=0.0942, acc_test=0.9804
# poison_percent 20 round 6: loss_train=1.8884, acc_train=0.7296, loss_test=0.0937, acc_test=0.9804
# poison_percent 20 round 7: loss_train=1.8229, acc_train=0.7354, loss_test=0.0939, acc_test=0.9804
# poison_percent 20 round 8: loss_train=1.7781, acc_train=0.7304, loss_test=0.0943, acc_test=0.9804
# poison_percent 20 round 9: loss_train=1.8160, acc_train=0.7304, loss_test=0.0949, acc_test=0.9804
# poison_percent 20 round 10: loss_train=1.7770, acc_train=0.7357, loss_test=0.0949, acc_test=0.9804
# poison_percent 20 round 11: loss_train=1.7581, acc_train=0.7363, loss_test=0.0944, acc_test=0.9804
# poison_percent 20 round 12: loss_train=1.8117, acc_train=0.7251, loss_test=0.0958, acc_test=0.9804
# poison_percent 20 round 13: loss_train=1.8140, acc_train=0.7315, loss_test=0.0953, acc_test=0.9804
# poison_percent 20 round 14: loss_train=1.7594, acc_train=0.7268, loss_test=0.0948, acc_test=0.9810
# poison_percent 20 round 15: loss_train=1.6981, acc_train=0.7418, loss_test=0.0958, acc_test=0.9804
# poison_percent 20 round 16: loss_train=1.7446, acc_train=0.7323, loss_test=0.0958, acc_test=0.9810
# poison_percent 20 round 17: loss_train=1.7776, acc_train=0.7346, loss_test=0.0950, acc_test=0.9810
# poison_percent 20 round 18: loss_train=1.6863, acc_train=0.7351, loss_test=0.0952, acc_test=0.9816
# poison_percent 20 round 19: loss_train=1.7014, acc_train=0.7346, loss_test=0.0959, acc_test=0.9810
# poison_percent 20 round 20: loss_train=1.6892, acc_train=0.7326, loss_test=0.0966, acc_test=0.9804
# poison_percent 20 round 21: loss_train=1.7534, acc_train=0.7363, loss_test=0.0968, acc_test=0.9804
# poison_percent 20 round 22: loss_train=1.7689, acc_train=0.7374, loss_test=0.0965, acc_test=0.9804
# poison_percent 20 round 23: loss_train=1.7833, acc_train=0.7365, loss_test=0.0970, acc_test=0.9804
# poison_percent 20 round 24: loss_train=1.7718, acc_train=0.7340, loss_test=0.0965, acc_test=0.9810
# poison_percent 20 round 25: loss_train=1.7681, acc_train=0.7220, loss_test=0.0966, acc_test=0.9810
# poison_percent 20 round 26: loss_train=1.7634, acc_train=0.7351, loss_test=0.0977, acc_test=0.9810
# poison_percent 20 round 27: loss_train=1.6811, acc_train=0.7318, loss_test=0.0976, acc_test=0.9810
# poison_percent 20 round 28: loss_train=1.7455, acc_train=0.7268, loss_test=0.0973, acc_test=0.9810
# poison_percent 20 round 29: loss_train=1.7170, acc_train=0.7357, loss_test=0.0972, acc_test=0.9810
# poison_percent 20 round 30: loss_train=1.7025, acc_train=0.7284, loss_test=0.0969, acc_test=0.9810
# poison_percent 20 round 31: loss_train=1.7935, acc_train=0.7296, loss_test=0.0977, acc_test=0.9810
# poison_percent 20 round 32: loss_train=1.6778, acc_train=0.7371, loss_test=0.0981, acc_test=0.9810
# poison_percent 20 round 33: loss_train=1.7141, acc_train=0.7363, loss_test=0.0979, acc_test=0.9810
# poison_percent 20 round 34: loss_train=1.7793, acc_train=0.7279, loss_test=0.0985, acc_test=0.9810
# poison_percent 20 round 35: loss_train=1.7105, acc_train=0.7399, loss_test=0.0992, acc_test=0.9810
# poison_percent 20 round 36: loss_train=1.7190, acc_train=0.7393, loss_test=0.0998, acc_test=0.9810
# poison_percent 20 round 37: loss_train=1.6499, acc_train=0.7413, loss_test=0.0999, acc_test=0.9810
# poison_percent 20 round 38: loss_train=1.7145, acc_train=0.7265, loss_test=0.0993, acc_test=0.9810
# poison_percent 20 round 39: loss_train=1.8073, acc_train=0.7360, loss_test=0.0991, acc_test=0.9810
# poison_percent 20 round 40: loss_train=1.6798, acc_train=0.7368, loss_test=0.0991, acc_test=0.9810
# poison_percent 20 round 41: loss_train=1.6784, acc_train=0.7346, loss_test=0.0996, acc_test=0.9810
# poison_percent 20 round 42: loss_train=1.7750, acc_train=0.7212, loss_test=0.0995, acc_test=0.9810
# poison_percent 20 round 43: loss_train=1.6524, acc_train=0.7307, loss_test=0.0999, acc_test=0.9804
# poison_percent 20 round 44: loss_train=1.6631, acc_train=0.7377, loss_test=0.0996, acc_test=0.9804
# poison_percent 20 round 45: loss_train=1.7432, acc_train=0.7287, loss_test=0.1009, acc_test=0.9804
# poison_percent 20 round 46: loss_train=1.6971, acc_train=0.7399, loss_test=0.1006, acc_test=0.9804
# poison_percent 20 round 47: loss_train=1.7246, acc_train=0.7340, loss_test=0.1010, acc_test=0.9804
# poison_percent 20 round 48: loss_train=1.6461, acc_train=0.7365, loss_test=0.1012, acc_test=0.9804
# poison_percent 20 round 49: loss_train=1.6673, acc_train=0.7351, loss_test=0.1009, acc_test=0.9804
# poison_percent 20 round 50: loss_train=1.6779, acc_train=0.7276, loss_test=0.1014, acc_test=0.9804
# poison_percent 20 round 51: loss_train=1.6456, acc_train=0.7424, loss_test=0.1001, acc_test=0.9804
# poison_percent 20 round 52: loss_train=1.7286, acc_train=0.7304, loss_test=0.1007, acc_test=0.9804
# poison_percent 20 round 53: loss_train=1.6978, acc_train=0.7231, loss_test=0.1010, acc_test=0.9804
# poison_percent 20 round 54: loss_train=1.6354, acc_train=0.7407, loss_test=0.1013, acc_test=0.9804
# poison_percent 20 round 55: loss_train=1.6793, acc_train=0.7332, loss_test=0.1016, acc_test=0.9804
# poison_percent 20 round 56: loss_train=1.7065, acc_train=0.7365, loss_test=0.1008, acc_test=0.9804
# poison_percent 20 round 57: loss_train=1.6828, acc_train=0.7301, loss_test=0.1018, acc_test=0.9804
# poison_percent 20 round 58: loss_train=1.6895, acc_train=0.7374, loss_test=0.1022, acc_test=0.9804
# poison_percent 20 round 59: loss_train=1.6877, acc_train=0.7323, loss_test=0.1024, acc_test=0.9810
# poison_percent 20 round 60: loss_train=1.7269, acc_train=0.7351, loss_test=0.1034, acc_test=0.9804
# poison_percent 20 round 61: loss_train=1.7157, acc_train=0.7273, loss_test=0.1042, acc_test=0.9804
# poison_percent 20 round 62: loss_train=1.6718, acc_train=0.7315, loss_test=0.1051, acc_test=0.9798
# poison_percent 20 round 63: loss_train=1.7226, acc_train=0.7296, loss_test=0.1038, acc_test=0.9804
# poison_percent 20 round 64: loss_train=1.6880, acc_train=0.7296, loss_test=0.1036, acc_test=0.9810
# poison_percent 20 round 65: loss_train=1.6560, acc_train=0.7449, loss_test=0.1042, acc_test=0.9810
# poison_percent 20 round 66: loss_train=1.7144, acc_train=0.7332, loss_test=0.1042, acc_test=0.9804
# poison_percent 20 round 67: loss_train=1.7359, acc_train=0.7332, loss_test=0.1041, acc_test=0.9810
# poison_percent 20 round 68: loss_train=1.7388, acc_train=0.7282, loss_test=0.1040, acc_test=0.9810
# poison_percent 20 round 69: loss_train=1.6748, acc_train=0.7365, loss_test=0.1044, acc_test=0.9810
# poison_percent 20 round 70: loss_train=1.6702, acc_train=0.7337, loss_test=0.1038, acc_test=0.9810
# poison_percent 20 round 71: loss_train=1.7237, acc_train=0.7329, loss_test=0.1037, acc_test=0.9804
# poison_percent 20 round 72: loss_train=1.7218, acc_train=0.7357, loss_test=0.1053, acc_test=0.9804
# poison_percent 20 round 73: loss_train=1.6835, acc_train=0.7296, loss_test=0.1049, acc_test=0.9804
# poison_percent 20 round 74: loss_train=1.7197, acc_train=0.7329, loss_test=0.1050, acc_test=0.9804
# poison_percent 20 round 75: loss_train=1.6737, acc_train=0.7293, loss_test=0.1052, acc_test=0.9804
# poison_percent 20 round 76: loss_train=1.6622, acc_train=0.7265, loss_test=0.1051, acc_test=0.9804
# poison_percent 20 round 77: loss_train=1.7069, acc_train=0.7323, loss_test=0.1051, acc_test=0.9804
# poison_percent 20 round 78: loss_train=1.6885, acc_train=0.7360, loss_test=0.1059, acc_test=0.9804
# poison_percent 20 round 79: loss_train=1.6461, acc_train=0.7326, loss_test=0.1051, acc_test=0.9804
# poison_percent 20 round 80: loss_train=1.6542, acc_train=0.7332, loss_test=0.1059, acc_test=0.9804
# poison_percent 20 round 81: loss_train=1.6773, acc_train=0.7315, loss_test=0.1073, acc_test=0.9804
# poison_percent 20 round 82: loss_train=1.6422, acc_train=0.7349, loss_test=0.1070, acc_test=0.9804
# poison_percent 20 round 83: loss_train=1.6983, acc_train=0.7304, loss_test=0.1076, acc_test=0.9804
# poison_percent 20 round 84: loss_train=1.6592, acc_train=0.7377, loss_test=0.1067, acc_test=0.9798
# poison_percent 20 round 85: loss_train=1.6698, acc_train=0.7323, loss_test=0.1069, acc_test=0.9804
# poison_percent 20 round 86: loss_train=1.6980, acc_train=0.7251, loss_test=0.1067, acc_test=0.9804
# poison_percent 20 round 87: loss_train=1.6946, acc_train=0.7326, loss_test=0.1064, acc_test=0.9798
# poison_percent 20 round 88: loss_train=1.6802, acc_train=0.7332, loss_test=0.1068, acc_test=0.9804
# poison_percent 20 round 89: loss_train=1.7183, acc_train=0.7284, loss_test=0.1076, acc_test=0.9798
# poison_percent 20 round 90: loss_train=1.6404, acc_train=0.7337, loss_test=0.1076, acc_test=0.9798
# poison_percent 20 round 91: loss_train=1.7006, acc_train=0.7248, loss_test=0.1070, acc_test=0.9798
# poison_percent 20 round 92: loss_train=1.6810, acc_train=0.7256, loss_test=0.1069, acc_test=0.9798
# poison_percent 20 round 93: loss_train=1.6815, acc_train=0.7312, loss_test=0.1067, acc_test=0.9798
# poison_percent 20 round 94: loss_train=1.6428, acc_train=0.7323, loss_test=0.1076, acc_test=0.9798
# poison_percent 20 round 95: loss_train=1.7113, acc_train=0.7337, loss_test=0.1073, acc_test=0.9804
# poison_percent 20 round 96: loss_train=1.6474, acc_train=0.7365, loss_test=0.1071, acc_test=0.9798
# poison_percent 20 round 97: loss_train=1.6482, acc_train=0.7343, loss_test=0.1076, acc_test=0.9798
# poison_percent 20 round 98: loss_train=1.6668, acc_train=0.7304, loss_test=0.1079, acc_test=0.9798
# poison_percent 20 round 99: loss_train=1.7231, acc_train=0.7293, loss_test=0.1083, acc_test=0.9798
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\FL_ModelN1L2_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=2.3322, acc_train=0.6498, loss_test=0.1014, acc_test=0.9816
# poison_percent 30 round 1: loss_train=2.2773, acc_train=0.6476, loss_test=0.0982, acc_test=0.9822
# poison_percent 30 round 2: loss_train=2.2305, acc_train=0.6565, loss_test=0.0963, acc_test=0.9822
# poison_percent 30 round 3: loss_train=2.2002, acc_train=0.6496, loss_test=0.0955, acc_test=0.9822
# poison_percent 30 round 4: loss_train=2.1779, acc_train=0.6511, loss_test=0.0953, acc_test=0.9822
# poison_percent 30 round 5: loss_train=2.1852, acc_train=0.6488, loss_test=0.0946, acc_test=0.9822
# poison_percent 30 round 6: loss_train=2.1362, acc_train=0.6585, loss_test=0.0962, acc_test=0.9822
# poison_percent 30 round 7: loss_train=2.1266, acc_train=0.6508, loss_test=0.0966, acc_test=0.9822
# poison_percent 30 round 8: loss_train=2.1050, acc_train=0.6538, loss_test=0.0964, acc_test=0.9822
# poison_percent 30 round 9: loss_train=2.0895, acc_train=0.6464, loss_test=0.0970, acc_test=0.9822
# poison_percent 30 round 10: loss_train=2.1067, acc_train=0.6555, loss_test=0.0975, acc_test=0.9822
# poison_percent 30 round 11: loss_train=2.0744, acc_train=0.6545, loss_test=0.0984, acc_test=0.9822
# poison_percent 30 round 12: loss_train=2.0836, acc_train=0.6518, loss_test=0.0997, acc_test=0.9835
# poison_percent 30 round 13: loss_train=2.0453, acc_train=0.6523, loss_test=0.1001, acc_test=0.9835
# poison_percent 30 round 14: loss_train=2.0821, acc_train=0.6498, loss_test=0.1014, acc_test=0.9835
# poison_percent 30 round 15: loss_train=2.0443, acc_train=0.6530, loss_test=0.1018, acc_test=0.9835
# poison_percent 30 round 16: loss_train=2.0580, acc_train=0.6525, loss_test=0.1026, acc_test=0.9835
# poison_percent 30 round 17: loss_train=2.0400, acc_train=0.6486, loss_test=0.1040, acc_test=0.9835
# poison_percent 30 round 18: loss_train=2.0149, acc_train=0.6587, loss_test=0.1046, acc_test=0.9835
# poison_percent 30 round 19: loss_train=2.0467, acc_train=0.6520, loss_test=0.1050, acc_test=0.9835
# poison_percent 30 round 20: loss_train=2.0193, acc_train=0.6488, loss_test=0.1057, acc_test=0.9828
# poison_percent 30 round 21: loss_train=2.0084, acc_train=0.6548, loss_test=0.1061, acc_test=0.9828
# poison_percent 30 round 22: loss_train=2.0059, acc_train=0.6535, loss_test=0.1076, acc_test=0.9828
# poison_percent 30 round 23: loss_train=1.9857, acc_train=0.6518, loss_test=0.1090, acc_test=0.9828
# poison_percent 30 round 24: loss_train=1.9606, acc_train=0.6513, loss_test=0.1096, acc_test=0.9828
# poison_percent 30 round 25: loss_train=1.9822, acc_train=0.6476, loss_test=0.1101, acc_test=0.9828
# poison_percent 30 round 26: loss_train=1.9858, acc_train=0.6589, loss_test=0.1104, acc_test=0.9828
# poison_percent 30 round 27: loss_train=2.0133, acc_train=0.6474, loss_test=0.1111, acc_test=0.9828
# poison_percent 30 round 28: loss_train=1.9410, acc_train=0.6488, loss_test=0.1112, acc_test=0.9828
# poison_percent 30 round 29: loss_train=1.9831, acc_train=0.6513, loss_test=0.1116, acc_test=0.9828
# poison_percent 30 round 30: loss_train=1.9315, acc_train=0.6587, loss_test=0.1123, acc_test=0.9828
# poison_percent 30 round 31: loss_train=1.9301, acc_train=0.6439, loss_test=0.1126, acc_test=0.9828
# poison_percent 30 round 32: loss_train=1.9546, acc_train=0.6562, loss_test=0.1131, acc_test=0.9828
# poison_percent 30 round 33: loss_train=1.9707, acc_train=0.6518, loss_test=0.1135, acc_test=0.9828
# poison_percent 30 round 34: loss_train=1.9385, acc_train=0.6530, loss_test=0.1151, acc_test=0.9828
# poison_percent 30 round 35: loss_train=1.9176, acc_train=0.6562, loss_test=0.1157, acc_test=0.9828
# poison_percent 30 round 36: loss_train=1.9777, acc_train=0.6449, loss_test=0.1164, acc_test=0.9828
# poison_percent 30 round 37: loss_train=1.9280, acc_train=0.6538, loss_test=0.1167, acc_test=0.9828
# poison_percent 30 round 38: loss_train=1.8884, acc_train=0.6614, loss_test=0.1173, acc_test=0.9828
# poison_percent 30 round 39: loss_train=1.9162, acc_train=0.6577, loss_test=0.1182, acc_test=0.9828
# poison_percent 30 round 40: loss_train=1.9000, acc_train=0.6476, loss_test=0.1180, acc_test=0.9828
# poison_percent 30 round 41: loss_train=1.8736, acc_train=0.6552, loss_test=0.1195, acc_test=0.9828
# poison_percent 30 round 42: loss_train=1.8817, acc_train=0.6533, loss_test=0.1202, acc_test=0.9822
# poison_percent 30 round 43: loss_train=1.8887, acc_train=0.6513, loss_test=0.1206, acc_test=0.9822
# poison_percent 30 round 44: loss_train=1.9033, acc_train=0.6545, loss_test=0.1212, acc_test=0.9822
# poison_percent 30 round 45: loss_train=1.9400, acc_train=0.6479, loss_test=0.1207, acc_test=0.9822
# poison_percent 30 round 46: loss_train=1.9021, acc_train=0.6508, loss_test=0.1203, acc_test=0.9828
# poison_percent 30 round 47: loss_train=1.8590, acc_train=0.6592, loss_test=0.1220, acc_test=0.9822
# poison_percent 30 round 48: loss_train=1.8883, acc_train=0.6555, loss_test=0.1224, acc_test=0.9822
# poison_percent 30 round 49: loss_train=1.8576, acc_train=0.6538, loss_test=0.1232, acc_test=0.9822
# poison_percent 30 round 50: loss_train=1.9512, acc_train=0.6400, loss_test=0.1242, acc_test=0.9822
# poison_percent 30 round 51: loss_train=1.8721, acc_train=0.6562, loss_test=0.1244, acc_test=0.9822
# poison_percent 30 round 52: loss_train=1.8882, acc_train=0.6555, loss_test=0.1257, acc_test=0.9822
# poison_percent 30 round 53: loss_train=1.8859, acc_train=0.6592, loss_test=0.1256, acc_test=0.9822
# poison_percent 30 round 54: loss_train=1.8797, acc_train=0.6520, loss_test=0.1261, acc_test=0.9822
# poison_percent 30 round 55: loss_train=1.8549, acc_train=0.6488, loss_test=0.1260, acc_test=0.9822
# poison_percent 30 round 56: loss_train=1.8836, acc_train=0.6533, loss_test=0.1269, acc_test=0.9822
# poison_percent 30 round 57: loss_train=1.8725, acc_train=0.6486, loss_test=0.1281, acc_test=0.9822
# poison_percent 30 round 58: loss_train=1.8001, acc_train=0.6560, loss_test=0.1280, acc_test=0.9822
# poison_percent 30 round 59: loss_train=1.9014, acc_train=0.6543, loss_test=0.1283, acc_test=0.9822
# poison_percent 30 round 60: loss_train=1.8834, acc_train=0.6493, loss_test=0.1289, acc_test=0.9822
# poison_percent 30 round 61: loss_train=1.8619, acc_train=0.6550, loss_test=0.1297, acc_test=0.9816
# poison_percent 30 round 62: loss_train=1.8774, acc_train=0.6456, loss_test=0.1295, acc_test=0.9822
# poison_percent 30 round 63: loss_train=1.8270, acc_train=0.6572, loss_test=0.1299, acc_test=0.9816
# poison_percent 30 round 64: loss_train=1.8913, acc_train=0.6528, loss_test=0.1298, acc_test=0.9816
# poison_percent 30 round 65: loss_train=1.8455, acc_train=0.6486, loss_test=0.1301, acc_test=0.9816
# poison_percent 30 round 66: loss_train=1.8797, acc_train=0.6496, loss_test=0.1310, acc_test=0.9816
# poison_percent 30 round 67: loss_train=1.8159, acc_train=0.6503, loss_test=0.1318, acc_test=0.9816
# poison_percent 30 round 68: loss_train=1.8089, acc_train=0.6585, loss_test=0.1313, acc_test=0.9816
# poison_percent 30 round 69: loss_train=1.8075, acc_train=0.6528, loss_test=0.1321, acc_test=0.9816
# poison_percent 30 round 70: loss_train=1.8517, acc_train=0.6513, loss_test=0.1327, acc_test=0.9816
# poison_percent 30 round 71: loss_train=1.8298, acc_train=0.6550, loss_test=0.1320, acc_test=0.9816
# poison_percent 30 round 72: loss_train=1.8097, acc_train=0.6572, loss_test=0.1329, acc_test=0.9816
# poison_percent 30 round 73: loss_train=1.8720, acc_train=0.6511, loss_test=0.1331, acc_test=0.9822
# poison_percent 30 round 74: loss_train=1.8660, acc_train=0.6456, loss_test=0.1343, acc_test=0.9822
# poison_percent 30 round 75: loss_train=1.8331, acc_train=0.6469, loss_test=0.1351, acc_test=0.9816
# poison_percent 30 round 76: loss_train=1.8356, acc_train=0.6513, loss_test=0.1368, acc_test=0.9816
# poison_percent 30 round 77: loss_train=1.8287, acc_train=0.6577, loss_test=0.1377, acc_test=0.9804
# poison_percent 30 round 78: loss_train=1.8444, acc_train=0.6552, loss_test=0.1366, acc_test=0.9810
# poison_percent 30 round 79: loss_train=1.8230, acc_train=0.6483, loss_test=0.1364, acc_test=0.9810
# poison_percent 30 round 80: loss_train=1.8104, acc_train=0.6493, loss_test=0.1354, acc_test=0.9804
# poison_percent 30 round 81: loss_train=1.8402, acc_train=0.6442, loss_test=0.1353, acc_test=0.9804
# poison_percent 30 round 82: loss_train=1.8290, acc_train=0.6508, loss_test=0.1352, acc_test=0.9804
# poison_percent 30 round 83: loss_train=1.8066, acc_train=0.6516, loss_test=0.1357, acc_test=0.9804
# poison_percent 30 round 84: loss_train=1.7967, acc_train=0.6540, loss_test=0.1365, acc_test=0.9804
# poison_percent 30 round 85: loss_train=1.8083, acc_train=0.6543, loss_test=0.1361, acc_test=0.9804
# poison_percent 30 round 86: loss_train=1.7854, acc_train=0.6597, loss_test=0.1365, acc_test=0.9804
# poison_percent 30 round 87: loss_train=1.7707, acc_train=0.6560, loss_test=0.1374, acc_test=0.9804
# poison_percent 30 round 88: loss_train=1.8368, acc_train=0.6496, loss_test=0.1380, acc_test=0.9804
# poison_percent 30 round 89: loss_train=1.8211, acc_train=0.6511, loss_test=0.1376, acc_test=0.9804
# poison_percent 30 round 90: loss_train=1.8217, acc_train=0.6483, loss_test=0.1377, acc_test=0.9804
# poison_percent 30 round 91: loss_train=1.7980, acc_train=0.6577, loss_test=0.1377, acc_test=0.9804
# poison_percent 30 round 92: loss_train=1.8002, acc_train=0.6552, loss_test=0.1378, acc_test=0.9804
# poison_percent 30 round 93: loss_train=1.8218, acc_train=0.6427, loss_test=0.1373, acc_test=0.9804
# poison_percent 30 round 94: loss_train=1.8006, acc_train=0.6508, loss_test=0.1382, acc_test=0.9804
# poison_percent 30 round 95: loss_train=1.8057, acc_train=0.6469, loss_test=0.1382, acc_test=0.9804
# poison_percent 30 round 96: loss_train=1.7931, acc_train=0.6486, loss_test=0.1387, acc_test=0.9804
# poison_percent 30 round 97: loss_train=1.7964, acc_train=0.6442, loss_test=0.1394, acc_test=0.9804
# poison_percent 30 round 98: loss_train=1.7780, acc_train=0.6575, loss_test=0.1395, acc_test=0.9798
# poison_percent 30 round 99: loss_train=1.8272, acc_train=0.6493, loss_test=0.1400, acc_test=0.9798
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\FL_ModelN1L2_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=2.3059, acc_train=0.5718, loss_test=0.1345, acc_test=0.9828
# poison_percent 40 round 1: loss_train=2.1894, acc_train=0.5803, loss_test=0.1313, acc_test=0.9835
# poison_percent 40 round 2: loss_train=2.1703, acc_train=0.5726, loss_test=0.1307, acc_test=0.9841
# poison_percent 40 round 3: loss_train=2.0875, acc_train=0.5748, loss_test=0.1299, acc_test=0.9847
# poison_percent 40 round 4: loss_train=2.0871, acc_train=0.5728, loss_test=0.1297, acc_test=0.9853
# poison_percent 40 round 5: loss_train=2.0298, acc_train=0.5713, loss_test=0.1305, acc_test=0.9853
# poison_percent 40 round 6: loss_train=2.0026, acc_train=0.5722, loss_test=0.1314, acc_test=0.9853
# poison_percent 40 round 7: loss_train=1.9938, acc_train=0.5703, loss_test=0.1336, acc_test=0.9853
# poison_percent 40 round 8: loss_train=1.9538, acc_train=0.5842, loss_test=0.1353, acc_test=0.9859
# poison_percent 40 round 9: loss_train=1.8890, acc_train=0.5839, loss_test=0.1371, acc_test=0.9859
# poison_percent 40 round 10: loss_train=1.8808, acc_train=0.5818, loss_test=0.1393, acc_test=0.9865
# poison_percent 40 round 11: loss_train=1.8352, acc_train=0.5807, loss_test=0.1410, acc_test=0.9865
# poison_percent 40 round 12: loss_train=1.8227, acc_train=0.5803, loss_test=0.1438, acc_test=0.9865
# poison_percent 40 round 13: loss_train=1.8133, acc_train=0.5782, loss_test=0.1456, acc_test=0.9865
# poison_percent 40 round 14: loss_train=1.8105, acc_train=0.5856, loss_test=0.1479, acc_test=0.9865
# poison_percent 40 round 15: loss_train=1.7583, acc_train=0.5884, loss_test=0.1508, acc_test=0.9865
# poison_percent 40 round 16: loss_train=1.7272, acc_train=0.5906, loss_test=0.1530, acc_test=0.9865
# poison_percent 40 round 17: loss_train=1.7329, acc_train=0.5829, loss_test=0.1553, acc_test=0.9859
# poison_percent 40 round 18: loss_train=1.7041, acc_train=0.5835, loss_test=0.1570, acc_test=0.9859
# poison_percent 40 round 19: loss_train=1.6824, acc_train=0.5848, loss_test=0.1590, acc_test=0.9859
# poison_percent 40 round 20: loss_train=1.6795, acc_train=0.5865, loss_test=0.1618, acc_test=0.9859
# poison_percent 40 round 21: loss_train=1.6938, acc_train=0.5799, loss_test=0.1635, acc_test=0.9853
# poison_percent 40 round 22: loss_train=1.6777, acc_train=0.5765, loss_test=0.1647, acc_test=0.9853
# poison_percent 40 round 23: loss_train=1.6497, acc_train=0.5782, loss_test=0.1668, acc_test=0.9853
# poison_percent 40 round 24: loss_train=1.6753, acc_train=0.5803, loss_test=0.1683, acc_test=0.9853
# poison_percent 40 round 25: loss_train=1.6079, acc_train=0.5814, loss_test=0.1700, acc_test=0.9853
# poison_percent 40 round 26: loss_train=1.6337, acc_train=0.5807, loss_test=0.1722, acc_test=0.9853
# poison_percent 40 round 27: loss_train=1.6033, acc_train=0.5882, loss_test=0.1738, acc_test=0.9853
# poison_percent 40 round 28: loss_train=1.6387, acc_train=0.5792, loss_test=0.1758, acc_test=0.9853
# poison_percent 40 round 29: loss_train=1.5758, acc_train=0.5874, loss_test=0.1774, acc_test=0.9853
# poison_percent 40 round 30: loss_train=1.5958, acc_train=0.5797, loss_test=0.1787, acc_test=0.9853
# poison_percent 40 round 31: loss_train=1.5691, acc_train=0.5863, loss_test=0.1804, acc_test=0.9853
# poison_percent 40 round 32: loss_train=1.5596, acc_train=0.5861, loss_test=0.1831, acc_test=0.9847
# poison_percent 40 round 33: loss_train=1.5434, acc_train=0.5865, loss_test=0.1839, acc_test=0.9847
# poison_percent 40 round 34: loss_train=1.5293, acc_train=0.5946, loss_test=0.1859, acc_test=0.9847
# poison_percent 40 round 35: loss_train=1.5442, acc_train=0.5852, loss_test=0.1878, acc_test=0.9847
# poison_percent 40 round 36: loss_train=1.5442, acc_train=0.5788, loss_test=0.1886, acc_test=0.9847
# poison_percent 40 round 37: loss_train=1.5560, acc_train=0.5762, loss_test=0.1901, acc_test=0.9847
# poison_percent 40 round 38: loss_train=1.5081, acc_train=0.5884, loss_test=0.1916, acc_test=0.9841
# poison_percent 40 round 39: loss_train=1.5306, acc_train=0.5884, loss_test=0.1936, acc_test=0.9841
# poison_percent 40 round 40: loss_train=1.5114, acc_train=0.5820, loss_test=0.1951, acc_test=0.9841
# poison_percent 40 round 41: loss_train=1.5090, acc_train=0.5803, loss_test=0.1965, acc_test=0.9841
# poison_percent 40 round 42: loss_train=1.4924, acc_train=0.5897, loss_test=0.1980, acc_test=0.9841
# poison_percent 40 round 43: loss_train=1.5221, acc_train=0.5831, loss_test=0.1993, acc_test=0.9841
# poison_percent 40 round 44: loss_train=1.4913, acc_train=0.5844, loss_test=0.2005, acc_test=0.9841
# poison_percent 40 round 45: loss_train=1.5119, acc_train=0.5799, loss_test=0.2021, acc_test=0.9841
# poison_percent 40 round 46: loss_train=1.4512, acc_train=0.5889, loss_test=0.2028, acc_test=0.9841
# poison_percent 40 round 47: loss_train=1.4812, acc_train=0.5812, loss_test=0.2037, acc_test=0.9835
# poison_percent 40 round 48: loss_train=1.4671, acc_train=0.5871, loss_test=0.2059, acc_test=0.9828
# poison_percent 40 round 49: loss_train=1.4707, acc_train=0.5884, loss_test=0.2076, acc_test=0.9828
# poison_percent 40 round 50: loss_train=1.4706, acc_train=0.5833, loss_test=0.2083, acc_test=0.9828
# poison_percent 40 round 51: loss_train=1.4611, acc_train=0.5767, loss_test=0.2096, acc_test=0.9828
# poison_percent 40 round 52: loss_train=1.4217, acc_train=0.5910, loss_test=0.2109, acc_test=0.9828
# poison_percent 40 round 53: loss_train=1.4436, acc_train=0.5871, loss_test=0.2116, acc_test=0.9828
# poison_percent 40 round 54: loss_train=1.4672, acc_train=0.5784, loss_test=0.2124, acc_test=0.9828
# poison_percent 40 round 55: loss_train=1.4525, acc_train=0.5820, loss_test=0.2136, acc_test=0.9828
# poison_percent 40 round 56: loss_train=1.4294, acc_train=0.5982, loss_test=0.2148, acc_test=0.9828
# poison_percent 40 round 57: loss_train=1.4326, acc_train=0.5865, loss_test=0.2157, acc_test=0.9822
# poison_percent 40 round 58: loss_train=1.4624, acc_train=0.5775, loss_test=0.2172, acc_test=0.9816
# poison_percent 40 round 59: loss_train=1.4176, acc_train=0.5846, loss_test=0.2186, acc_test=0.9816
# poison_percent 40 round 60: loss_train=1.4286, acc_train=0.5852, loss_test=0.2199, acc_test=0.9816
# poison_percent 40 round 61: loss_train=1.4174, acc_train=0.5878, loss_test=0.2215, acc_test=0.9816
# poison_percent 40 round 62: loss_train=1.4152, acc_train=0.5856, loss_test=0.2223, acc_test=0.9810
# poison_percent 40 round 63: loss_train=1.4281, acc_train=0.5780, loss_test=0.2236, acc_test=0.9804
# poison_percent 40 round 64: loss_train=1.4290, acc_train=0.5846, loss_test=0.2246, acc_test=0.9798
# poison_percent 40 round 65: loss_train=1.3991, acc_train=0.5839, loss_test=0.2260, acc_test=0.9798
# poison_percent 40 round 66: loss_train=1.4263, acc_train=0.5780, loss_test=0.2271, acc_test=0.9792
# poison_percent 40 round 67: loss_train=1.3703, acc_train=0.5908, loss_test=0.2281, acc_test=0.9792
# poison_percent 40 round 68: loss_train=1.3895, acc_train=0.5876, loss_test=0.2298, acc_test=0.9792
# poison_percent 40 round 69: loss_train=1.4084, acc_train=0.5829, loss_test=0.2306, acc_test=0.9792
# poison_percent 40 round 70: loss_train=1.4079, acc_train=0.5818, loss_test=0.2308, acc_test=0.9792
# poison_percent 40 round 71: loss_train=1.3882, acc_train=0.5777, loss_test=0.2318, acc_test=0.9792
# poison_percent 40 round 72: loss_train=1.3798, acc_train=0.5876, loss_test=0.2324, acc_test=0.9792
# poison_percent 40 round 73: loss_train=1.3623, acc_train=0.5824, loss_test=0.2324, acc_test=0.9792
# poison_percent 40 round 74: loss_train=1.4037, acc_train=0.5767, loss_test=0.2331, acc_test=0.9792
# poison_percent 40 round 75: loss_train=1.3695, acc_train=0.5895, loss_test=0.2346, acc_test=0.9792
# poison_percent 40 round 76: loss_train=1.4027, acc_train=0.5827, loss_test=0.2356, acc_test=0.9792
# poison_percent 40 round 77: loss_train=1.3942, acc_train=0.5767, loss_test=0.2369, acc_test=0.9792
# poison_percent 40 round 78: loss_train=1.4052, acc_train=0.5805, loss_test=0.2380, acc_test=0.9792
# ...
# poison_percent 10 round 19: loss_train=1.1197, acc_train=0.7995, loss_test=0.1437, acc_test=0.9657
# poison_percent 10 round 20: loss_train=1.1054, acc_train=0.7924, loss_test=0.1432, acc_test=0.9645
# poison_percent 10 round 21: loss_train=1.1098, acc_train=0.8014, loss_test=0.1435, acc_test=0.9651
# poison_percent 10 round 22: loss_train=1.0691, acc_train=0.7946, loss_test=0.1425, acc_test=0.9645
# poison_percent 10 round 23: loss_train=1.1946, acc_train=0.7905, loss_test=0.1418, acc_test=0.9657
# poison_percent 10 round 24: loss_train=1.1391, acc_train=0.7918, loss_test=0.1410, acc_test=0.9669
# poison_percent 10 round 25: loss_train=1.0861, acc_train=0.7961, loss_test=0.1415, acc_test=0.9675
# poison_percent 10 round 26: loss_train=1.0574, acc_train=0.8032, loss_test=0.1402, acc_test=0.9675
# poison_percent 10 round 27: loss_train=1.1421, acc_train=0.7998, loss_test=0.1399, acc_test=0.9681
# poison_percent 10 round 28: loss_train=1.1398, acc_train=0.8041, loss_test=0.1398, acc_test=0.9681
# poison_percent 10 round 29: loss_train=1.1098, acc_train=0.7955, loss_test=0.1384, acc_test=0.9688
# poison_percent 10 round 30: loss_train=1.1257, acc_train=0.7862, loss_test=0.1361, acc_test=0.9688
# poison_percent 10 round 31: loss_train=1.1807, acc_train=0.7840, loss_test=0.1383, acc_test=0.9675
# poison_percent 10 round 32: loss_train=1.0991, acc_train=0.7942, loss_test=0.1384, acc_test=0.9681
# poison_percent 10 round 33: loss_train=1.1293, acc_train=0.7924, loss_test=0.1383, acc_test=0.9688
# poison_percent 10 round 34: loss_train=1.1571, acc_train=0.7942, loss_test=0.1391, acc_test=0.9675
# poison_percent 10 round 35: loss_train=1.0970, acc_train=0.8054, loss_test=0.1375, acc_test=0.9694
# poison_percent 10 round 36: loss_train=1.1128, acc_train=0.7973, loss_test=0.1377, acc_test=0.9688
# poison_percent 10 round 37: loss_train=1.1384, acc_train=0.7927, loss_test=0.1367, acc_test=0.9694
# poison_percent 10 round 38: loss_train=1.1071, acc_train=0.7939, loss_test=0.1350, acc_test=0.9694
# poison_percent 10 round 39: loss_train=1.1159, acc_train=0.7952, loss_test=0.1354, acc_test=0.9688
# poison_percent 10 round 40: loss_train=1.1707, acc_train=0.7939, loss_test=0.1358, acc_test=0.9688
# poison_percent 10 round 41: loss_train=1.1633, acc_train=0.7908, loss_test=0.1334, acc_test=0.9694
# poison_percent 10 round 42: loss_train=1.1247, acc_train=0.7992, loss_test=0.1346, acc_test=0.9694
# poison_percent 10 round 43: loss_train=1.1226, acc_train=0.7840, loss_test=0.1352, acc_test=0.9694
# poison_percent 10 round 44: loss_train=1.1173, acc_train=0.7955, loss_test=0.1338, acc_test=0.9694
# poison_percent 10 round 45: loss_train=1.1059, acc_train=0.7946, loss_test=0.1329, acc_test=0.9694
# poison_percent 10 round 46: loss_train=1.1242, acc_train=0.7939, loss_test=0.1345, acc_test=0.9694
# poison_percent 10 round 47: loss_train=1.1071, acc_train=0.8007, loss_test=0.1337, acc_test=0.9694
# poison_percent 10 round 48: loss_train=1.1485, acc_train=0.7986, loss_test=0.1315, acc_test=0.9694
# poison_percent 10 round 49: loss_train=1.1277, acc_train=0.7970, loss_test=0.1331, acc_test=0.9688
# poison_percent 10 round 50: loss_train=1.0670, acc_train=0.8023, loss_test=0.1329, acc_test=0.9694
# poison_percent 10 round 51: loss_train=1.1551, acc_train=0.7949, loss_test=0.1343, acc_test=0.9688
# poison_percent 10 round 52: loss_train=1.1004, acc_train=0.8007, loss_test=0.1325, acc_test=0.9681
# poison_percent 10 round 53: loss_train=1.1525, acc_train=0.7877, loss_test=0.1309, acc_test=0.9700
# poison_percent 10 round 54: loss_train=1.0844, acc_train=0.8032, loss_test=0.1310, acc_test=0.9706
# poison_percent 10 round 55: loss_train=1.1408, acc_train=0.7976, loss_test=0.1305, acc_test=0.9706
# poison_percent 10 round 56: loss_train=1.1488, acc_train=0.8020, loss_test=0.1316, acc_test=0.9700
# poison_percent 10 round 57: loss_train=1.1081, acc_train=0.7918, loss_test=0.1297, acc_test=0.9712
# poison_percent 10 round 58: loss_train=1.1735, acc_train=0.7989, loss_test=0.1313, acc_test=0.9706
# poison_percent 10 round 59: loss_train=1.1621, acc_train=0.7958, loss_test=0.1298, acc_test=0.9712
# poison_percent 10 round 60: loss_train=1.1156, acc_train=0.8072, loss_test=0.1300, acc_test=0.9706
# poison_percent 10 round 61: loss_train=1.1117, acc_train=0.8079, loss_test=0.1291, acc_test=0.9706
# poison_percent 10 round 62: loss_train=1.1236, acc_train=0.8038, loss_test=0.1289, acc_test=0.9706
# poison_percent 10 round 63: loss_train=1.1668, acc_train=0.7908, loss_test=0.1300, acc_test=0.9712
# poison_percent 10 round 64: loss_train=1.1633, acc_train=0.7939, loss_test=0.1288, acc_test=0.9712
# poison_percent 10 round 65: loss_train=1.1570, acc_train=0.7964, loss_test=0.1272, acc_test=0.9712
# poison_percent 10 round 66: loss_train=1.0928, acc_train=0.8020, loss_test=0.1277, acc_test=0.9718
# poison_percent 10 round 67: loss_train=1.0706, acc_train=0.8113, loss_test=0.1268, acc_test=0.9718
# poison_percent 10 round 68: loss_train=1.1676, acc_train=0.7955, loss_test=0.1290, acc_test=0.9712
# poison_percent 10 round 69: loss_train=1.1696, acc_train=0.7964, loss_test=0.1288, acc_test=0.9712
# poison_percent 10 round 70: loss_train=1.1195, acc_train=0.8060, loss_test=0.1283, acc_test=0.9712
# poison_percent 10 round 71: loss_train=1.1438, acc_train=0.7933, loss_test=0.1271, acc_test=0.9718
# poison_percent 10 round 72: loss_train=1.1241, acc_train=0.8026, loss_test=0.1266, acc_test=0.9718
# poison_percent 10 round 73: loss_train=1.1610, acc_train=0.8001, loss_test=0.1273, acc_test=0.9718
# poison_percent 10 round 74: loss_train=1.0804, acc_train=0.8075, loss_test=0.1278, acc_test=0.9718
# poison_percent 10 round 75: loss_train=1.1221, acc_train=0.7989, loss_test=0.1273, acc_test=0.9718
# poison_percent 10 round 76: loss_train=1.1105, acc_train=0.8038, loss_test=0.1269, acc_test=0.9718
# poison_percent 10 round 77: loss_train=1.1319, acc_train=0.7992, loss_test=0.1269, acc_test=0.9718
# poison_percent 10 round 78: loss_train=1.0978, acc_train=0.8048, loss_test=0.1275, acc_test=0.9718
# poison_percent 10 round 79: loss_train=1.1859, acc_train=0.7952, loss_test=0.1259, acc_test=0.9718
# poison_percent 10 round 80: loss_train=1.1295, acc_train=0.8079, loss_test=0.1255, acc_test=0.9730
# poison_percent 10 round 81: loss_train=1.1670, acc_train=0.7970, loss_test=0.1261, acc_test=0.9718
# poison_percent 10 round 82: loss_train=1.0987, acc_train=0.8014, loss_test=0.1254, acc_test=0.9718
# poison_percent 10 round 83: loss_train=1.1286, acc_train=0.8085, loss_test=0.1265, acc_test=0.9718
# poison_percent 10 round 84: loss_train=1.1284, acc_train=0.7973, loss_test=0.1246, acc_test=0.9737
# poison_percent 10 round 85: loss_train=1.1342, acc_train=0.8045, loss_test=0.1254, acc_test=0.9724
# poison_percent 10 round 86: loss_train=1.1702, acc_train=0.7918, loss_test=0.1248, acc_test=0.9730
# poison_percent 10 round 87: loss_train=1.1290, acc_train=0.8020, loss_test=0.1262, acc_test=0.9718
# poison_percent 10 round 88: loss_train=1.2209, acc_train=0.7887, loss_test=0.1239, acc_test=0.9730
# poison_percent 10 round 89: loss_train=1.1182, acc_train=0.8075, loss_test=0.1251, acc_test=0.9730
# poison_percent 10 round 90: loss_train=1.1878, acc_train=0.8045, loss_test=0.1257, acc_test=0.9730
# poison_percent 10 round 91: loss_train=1.1496, acc_train=0.7952, loss_test=0.1236, acc_test=0.9737
# poison_percent 10 round 92: loss_train=1.1243, acc_train=0.8011, loss_test=0.1224, acc_test=0.9737
# poison_percent 10 round 93: loss_train=1.1332, acc_train=0.8035, loss_test=0.1228, acc_test=0.9737
# poison_percent 10 round 94: loss_train=1.1619, acc_train=0.8029, loss_test=0.1242, acc_test=0.9730
# poison_percent 10 round 95: loss_train=1.1543, acc_train=0.8017, loss_test=0.1239, acc_test=0.9737
# poison_percent 10 round 96: loss_train=1.1715, acc_train=0.7967, loss_test=0.1242, acc_test=0.9730
# poison_percent 10 round 97: loss_train=1.1493, acc_train=0.7998, loss_test=0.1228, acc_test=0.9737
# poison_percent 10 round 98: loss_train=1.1321, acc_train=0.8032, loss_test=0.1231, acc_test=0.9737
# poison_percent 10 round 99: loss_train=1.0916, acc_train=0.8057, loss_test=0.1250, acc_test=0.9730
# Training log saved to d:\github\poisoning_attack_analysis\Experiment010 cnn bs32 10c\results\FL_ModelN1L2_Batchsize32_rev1\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=1.7530, acc_train=0.7337, loss_test=0.1118, acc_test=0.9755
# poison_percent 20 round 1: loss_train=1.7192, acc_train=0.7379, loss_test=0.1074, acc_test=0.9779
# poison_percent 20 round 2: loss_train=1.7340, acc_train=0.7301, loss_test=0.1051, acc_test=0.9779
# poison_percent 20 round 3: loss_train=1.6795, acc_train=0.7357, loss_test=0.1041, acc_test=0.9779
# poison_percent 20 round 4: loss_train=1.6986, acc_train=0.7377, loss_test=0.1046, acc_test=0.9779
# poison_percent 20 round 5: loss_train=1.7354, acc_train=0.7229, loss_test=0.1038, acc_test=0.9786
# poison_percent 20 round 6: loss_train=1.7376, acc_train=0.7201, loss_test=0.1036, acc_test=0.9786
# poison_percent 20 round 7: loss_train=1.7038, acc_train=0.7335, loss_test=0.1037, acc_test=0.9786
# poison_percent 20 round 8: loss_train=1.6542, acc_train=0.7296, loss_test=0.1042, acc_test=0.9786
# poison_percent 20 round 9: loss_train=1.6667, acc_train=0.7365, loss_test=0.1043, acc_test=0.9786
# poison_percent 20 round 10: loss_train=1.6672, acc_train=0.7374, loss_test=0.1050, acc_test=0.9786
# poison_percent 20 round 11: loss_train=1.6392, acc_train=0.7287, loss_test=0.1046, acc_test=0.9792
# poison_percent 20 round 12: loss_train=1.6384, acc_train=0.7377, loss_test=0.1049, acc_test=0.9792
# poison_percent 20 round 13: loss_train=1.6580, acc_train=0.7335, loss_test=0.1055, acc_test=0.9792
# poison_percent 20 round 14: loss_train=1.6888, acc_train=0.7315, loss_test=0.1052, acc_test=0.9792
# poison_percent 20 round 15: loss_train=1.6162, acc_train=0.7349, loss_test=0.1047, acc_test=0.9792
# poison_percent 20 round 16: loss_train=1.6866, acc_train=0.7229, loss_test=0.1048, acc_test=0.9792
# poison_percent 20 round 17: loss_train=1.6514, acc_train=0.7307, loss_test=0.1046, acc_test=0.9792
# poison_percent 20 round 18: loss_train=1.6371, acc_train=0.7321, loss_test=0.1064, acc_test=0.9792
# poison_percent 20 round 19: loss_train=1.6821, acc_train=0.7268, loss_test=0.1060, acc_test=0.9792
# poison_percent 20 round 20: loss_train=1.6487, acc_train=0.7318, loss_test=0.1065, acc_test=0.9792
# poison_percent 20 round 21: loss_train=1.6396, acc_train=0.7368, loss_test=0.1068, acc_test=0.9792
# poison_percent 20 round 22: loss_train=1.6608, acc_train=0.7273, loss_test=0.1058, acc_test=0.9792
# poison_percent 20 round 23: loss_train=1.6121, acc_train=0.7312, loss_test=0.1057, acc_test=0.9798
# poison_percent 20 round 24: loss_train=1.5868, acc_train=0.7354, loss_test=0.1068, acc_test=0.9792
# poison_percent 20 round 25: loss_train=1.6318, acc_train=0.7365, loss_test=0.1062, acc_test=0.9798
# poison_percent 20 round 26: loss_train=1.6637, acc_train=0.7265, loss_test=0.1071, acc_test=0.9798
# poison_percent 20 round 27: loss_train=1.5809, acc_train=0.7337, loss_test=0.1072, acc_test=0.9792
# poison_percent 20 round 28: loss_train=1.5808, acc_train=0.7312, loss_test=0.1071, acc_test=0.9792
# poison_percent 20 round 29: loss_train=1.6457, acc_train=0.7243, loss_test=0.1071, acc_test=0.9792
# poison_percent 20 round 30: loss_train=1.6550, acc_train=0.7259, loss_test=0.1076, acc_test=0.9798
# poison_percent 20 round 31: loss_train=1.6142, acc_train=0.7290, loss_test=0.1089, acc_test=0.9792
# poison_percent 20 round 32: loss_train=1.6333, acc_train=0.7385, loss_test=0.1084, acc_test=0.9798
# poison_percent 20 round 33: loss_train=1.6361, acc_train=0.7371, loss_test=0.1088, acc_test=0.9798
# poison_percent 20 round 34: loss_train=1.6291, acc_train=0.7301, loss_test=0.1089, acc_test=0.9798
# poison_percent 20 round 35: loss_train=1.6155, acc_train=0.7357, loss_test=0.1090, acc_test=0.9798
# poison_percent 20 round 36: loss_train=1.6298, acc_train=0.7346, loss_test=0.1083, acc_test=0.9798
# poison_percent 20 round 37: loss_train=1.6262, acc_train=0.7323, loss_test=0.1085, acc_test=0.9798
# poison_percent 20 round 38: loss_train=1.6377, acc_train=0.7318, loss_test=0.1080, acc_test=0.9798
# poison_percent 20 round 39: loss_train=1.5781, acc_train=0.7326, loss_test=0.1100, acc_test=0.9798
# poison_percent 20 round 40: loss_train=1.6642, acc_train=0.7248, loss_test=0.1087, acc_test=0.9798
# poison_percent 20 round 41: loss_train=1.5707, acc_train=0.7385, loss_test=0.1095, acc_test=0.9798
# poison_percent 20 round 42: loss_train=1.5944, acc_train=0.7284, loss_test=0.1082, acc_test=0.9798
# poison_percent 20 round 43: loss_train=1.6392, acc_train=0.7284, loss_test=0.1097, acc_test=0.9798
# poison_percent 20 round 44: loss_train=1.5795, acc_train=0.7301, loss_test=0.1094, acc_test=0.9798
# poison_percent 20 round 45: loss_train=1.5997, acc_train=0.7206, loss_test=0.1089, acc_test=0.9798
# poison_percent 20 round 46: loss_train=1.6203, acc_train=0.7351, loss_test=0.1104, acc_test=0.9798
# poison_percent 20 round 47: loss_train=1.5761, acc_train=0.7388, loss_test=0.1102, acc_test=0.9798
# poison_percent 20 round 48: loss_train=1.5766, acc_train=0.7371, loss_test=0.1097, acc_test=0.9798
# poison_percent 20 round 49: loss_train=1.5959, acc_train=0.7329, loss_test=0.1109, acc_test=0.9792
# poison_percent 20 round 50: loss_train=1.5922, acc_train=0.7301, loss_test=0.1104, acc_test=0.9798
# poison_percent 20 round 51: loss_train=1.5863, acc_train=0.7321, loss_test=0.1106, acc_test=0.9798
# poison_percent 20 round 52: loss_train=1.5806, acc_train=0.7340, loss_test=0.1115, acc_test=0.9792
# poison_percent 20 round 53: loss_train=1.5879, acc_train=0.7410, loss_test=0.1116, acc_test=0.9792
# poison_percent 20 round 54: loss_train=1.5954, acc_train=0.7312, loss_test=0.1121, acc_test=0.9792
# poison_percent 20 round 55: loss_train=1.5582, acc_train=0.7332, loss_test=0.1123, acc_test=0.9792
# poison_percent 20 round 56: loss_train=1.6062, acc_train=0.7290, loss_test=0.1133, acc_test=0.9786
# poison_percent 20 round 57: loss_train=1.5596, acc_train=0.7265, loss_test=0.1136, acc_test=0.9786
# poison_percent 20 round 58: loss_train=1.5814, acc_train=0.7371, loss_test=0.1135, acc_test=0.9792
# poison_percent 20 round 59: loss_train=1.6060, acc_train=0.7346, loss_test=0.1143, acc_test=0.9786
# poison_percent 20 round 60: loss_train=1.6032, acc_train=0.7340, loss_test=0.1145, acc_test=0.9786
# poison_percent 20 round 61: loss_train=1.5734, acc_train=0.7321, loss_test=0.1133, acc_test=0.9786
# poison_percent 20 round 62: loss_train=1.6408, acc_train=0.7273, loss_test=0.1134, acc_test=0.9786
# poison_percent 20 round 63: loss_train=1.6337, acc_train=0.7310, loss_test=0.1136, acc_test=0.9786
# poison_percent 20 round 64: loss_train=1.6042, acc_train=0.7363, loss_test=0.1148, acc_test=0.9779
# poison_percent 20 round 65: loss_train=1.6126, acc_train=0.7273, loss_test=0.1141, acc_test=0.9786
# poison_percent 20 round 66: loss_train=1.5272, acc_train=0.7418, loss_test=0.1135, acc_test=0.9779
# poison_percent 20 round 67: loss_train=1.6139, acc_train=0.7315, loss_test=0.1147, acc_test=0.9779
# poison_percent 20 round 68: loss_train=1.5625, acc_train=0.7282, loss_test=0.1154, acc_test=0.9779
# poison_percent 20 round 69: loss_train=1.6381, acc_train=0.7265, loss_test=0.1150, acc_test=0.9779
# poison_percent 20 round 70: loss_train=1.6326, acc_train=0.7304, loss_test=0.1151, acc_test=0.9779
# poison_percent 20 round 71: loss_train=1.6028, acc_train=0.7318, loss_test=0.1148, acc_test=0.9786
# poison_percent 20 round 72: loss_train=1.5869, acc_train=0.7351, loss_test=0.1139, acc_test=0.9779
# poison_percent 20 round 73: loss_train=1.6171, acc_train=0.7282, loss_test=0.1146, acc_test=0.9786
# poison_percent 20 round 74: loss_train=1.5449, acc_train=0.7290, loss_test=0.1139, acc_test=0.9786
# poison_percent 20 round 75: loss_train=1.5857, acc_train=0.7301, loss_test=0.1146, acc_test=0.9779
# poison_percent 20 round 76: loss_train=1.5532, acc_train=0.7346, loss_test=0.1153, acc_test=0.9779
# poison_percent 20 round 77: loss_train=1.6238, acc_train=0.7371, loss_test=0.1161, acc_test=0.9779
# poison_percent 20 round 78: loss_train=1.5775, acc_train=0.7337, loss_test=0.1165, acc_test=0.9779
