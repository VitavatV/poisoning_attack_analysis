# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x
    
# save state_dict + metadata (safe, portable)
def save_model(model, img_size, n_classes, learning_rate, experiment_bs, file_path):

    state = {
        "model_state_dict": model.state_dict(),                     # CPU/GPU tensors okay
        "arch": "MNISTNet",
        "img_size": img_size,
        "num_classes": n_classes,
        "training_args": {"lr": learning_rate, "batch_size": experiment_bs}
    }
    # ensure weights are on CPU to avoid GPU-only pickle issues
    state["model_state_dict"] = {k: v.cpu() for k, v in state["model_state_dict"].items()}
    torch.save(state, file_path)
    
def load_model(file_path, device):

    checkpoint = torch.load(file_path, map_location=device)
    model = MNISTNet().to(device)              # must have MNISTNet class defined/importable
    model.load_state_dict(checkpoint["model_state_dict"])
    model.eval()
    return model

# %% [markdown]
# # 4.Loss

# %%
# def binary_cross_entropy(pred, target):
#     eps = 1e-7
#     pred = torch.clamp(pred, eps, 1 - eps)
#     return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

def multiclass_cross_entropy(logits, target, from_probs=False, eps=1e-7):
    """
    Cross-entropy loss for multiclass (e.g., 10 classes).
    - logits: Tensor shape (N, C) containing raw scores (preferred) or probabilities if from_probs=True
    - target: Tensor shape (N,) or (N,1) containing class indices (0..C-1)
    """
    if logits.dim() == 1:
        logits = logits.unsqueeze(0)
    target = target.squeeze()
    if target.dtype != torch.long:
        target = target.long()
    if from_probs:
        probs = torch.clamp(logits, eps, 1.0 - eps)
        log_probs = torch.log(probs)
        return -log_probs[torch.arange(target.size(0)), target].mean()
    return nn.functional.cross_entropy(logits, target)

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    # create model on target device
    model = MNISTNet().to(device)
    # ensure weights are mapped to the worker device
    state_on_device = {k: v.to(device) for k, v in global_weights.items()}
    model.load_state_dict(state_on_device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end].to(device)
            yb = y_c_tensor[start:end].to(device)
            outputs = model(xb)
            # preds = (outputs >= 0.5).float()
            preds = torch.argmax(outputs, dim=1, keepdim=True)
            loss = multiclass_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # return CPU copies for safe aggregation in main thread
    returned_state = {k: v.detach().cpu() for k, v in model.state_dict().items()}
    return returned_state, X_c_tensor.size(0), yb.detach().cpu(), outputs.detach().cpu(), preds.detach().cpu()

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 32
N_CLASSES = 10

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_multiple_poison/train"
TEST_PATH = "../data/mnist_multiple_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
for NODE in [1,2,4,8,16,32]:
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            self.conv1 = nn.Conv2d(1, NODE, kernel_size=3, padding=1) # 28x28
            self.pool = nn.MaxPool2d(2, 2) # 14x14
            self.fc1 = nn.Linear(NODE * 14 * 14, N_CLASSES)
            self.relu = nn.ReLU()
            
        def forward(self, x):
            x = x.view(-1, 1, 28, 28)
            x = self.pool(self.relu(self.conv1(x)))
            x = x.view(x.size(0), -1)
            x = self.fc1(x)
            # x = torch.sigmoid(x)
            return x

    BATCH_SIZE_list = [BATCH_SIZE]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        global_model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"FL_ModelN{NODE}L2_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                # torch.save(model, os.path.join(save_path,'model_init.pt'))
                save_path_name = os.path.join(save_path,'model_init.pt')
                save_model(global_model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)
                
                global_weights = global_model.state_dict()

                records = []

                X_train_tensor = {}
                y_train_tensor = {}
                for i in range(N_HONEST):
                    X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"honest_{i}"] = X_c_tensor
                    y_train_tensor[f"honest_{i}"] = y_c_tensor
                for i in range(i_poisoned):
                    X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"poison_{i}"] = X_c_tensor
                    y_train_tensor[f"poison_{i}"] = y_c_tensor

                # Training loop
                for round in range(ROUNDS):
                    # Prepare arguments for honest clients
                    
                    #randomize the training data
                    for i in range(N_HONEST):
                        perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                        X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                        y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                    honest_args = [
                        (
                            X_train_tensor[f"honest_{i}"],
                            y_train_tensor[f"honest_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(N_HONEST)
                    ]

                    # Prepare arguments for poisoned clients
                    
                    #randomize the training data
                    for i in range(i_poisoned):
                        perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                        X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                        y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                    poison_args = [
                        (
                            X_train_tensor[f"poison_{i}"],
                            y_train_tensor[f"poison_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(i_poisoned)
                    ]

                    # Run in parallel
                    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                        honest_results = list(executor.map(train_local_worker, honest_args))
                        poison_results = list(executor.map(train_local_worker, poison_args))

                    local_weights = []
                    local_sizes = []
                    local_y = []
                    local_outputs = []
                    local_preds = []
                    for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                        local_weights.append(l_w)
                        local_sizes.append(l_sz)
                        local_y.extend(l_y)
                        local_outputs.extend(l_out)
                        local_preds.extend(l_pred)
                    loss_train = multiclass_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                    acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                    # Federated averaging (weighted by client data size)
                    new_weights = {}
                    for key in global_weights.keys():
                        new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                    global_weights = new_weights
                    global_model.load_state_dict(global_weights)

                    # Evaluate
                    global_model.eval()
                    with torch.no_grad():
                        outputs = global_model(X_test_tensor)
                        # preds = (outputs > 0.5).float()
                        preds = torch.argmax(outputs, dim=1, keepdim=True)
                        loss_test = multiclass_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'round': round, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"round {round}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                # torch.save(model, os.path.join(save_path,'model_last.pt'))
                save_path_name = os.path.join(save_path,'model_last.pt')
                save_model(global_model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['round'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['round'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 round 0: loss_train=0.6549, acc_train=0.6800, loss_test=0.6564, acc_test=0.6658
# poison_percent 0 round 1: loss_train=0.5856, acc_train=0.8200, loss_test=0.5688, acc_test=0.8888
# poison_percent 0 round 2: loss_train=0.4389, acc_train=0.9600, loss_test=0.4120, acc_test=0.9628
# poison_percent 0 round 3: loss_train=0.2373, acc_train=0.9900, loss_test=0.2481, acc_test=0.9862
# poison_percent 0 round 4: loss_train=0.1421, acc_train=0.9800, loss_test=0.1313, acc_test=0.9939
# poison_percent 0 round 5: loss_train=0.0655, acc_train=1.0000, loss_test=0.0699, acc_test=0.9954
# poison_percent 0 round 6: loss_train=0.0466, acc_train=0.9900, loss_test=0.0413, acc_test=0.9949
# poison_percent 0 round 7: loss_train=0.0392, acc_train=0.9900, loss_test=0.0281, acc_test=0.9949
# poison_percent 0 round 8: loss_train=0.0184, acc_train=0.9900, loss_test=0.0210, acc_test=0.9954
# poison_percent 0 round 9: loss_train=0.0463, acc_train=0.9800, loss_test=0.0169, acc_test=0.9954
# poison_percent 0 round 10: loss_train=0.0279, acc_train=0.9900, loss_test=0.0145, acc_test=0.9954
# poison_percent 0 round 11: loss_train=0.0197, acc_train=0.9900, loss_test=0.0130, acc_test=0.9954
# poison_percent 0 round 12: loss_train=0.0306, acc_train=0.9900, loss_test=0.0120, acc_test=0.9954
# poison_percent 0 round 13: loss_train=0.0107, acc_train=1.0000, loss_test=0.0113, acc_test=0.9954
# poison_percent 0 round 14: loss_train=0.0495, acc_train=0.9900, loss_test=0.0109, acc_test=0.9954
# poison_percent 0 round 15: loss_train=0.0249, acc_train=0.9800, loss_test=0.0106, acc_test=0.9954
# poison_percent 0 round 16: loss_train=0.0846, acc_train=0.9900, loss_test=0.0106, acc_test=0.9954
# poison_percent 0 round 17: loss_train=0.0321, acc_train=0.9900, loss_test=0.0104, acc_test=0.9954
# poison_percent 0 round 18: loss_train=0.0627, acc_train=0.9900, loss_test=0.0102, acc_test=0.9954
# poison_percent 0 round 19: loss_train=0.0033, acc_train=1.0000, loss_test=0.0101, acc_test=0.9954
# poison_percent 0 round 20: loss_train=0.0017, acc_train=1.0000, loss_test=0.0102, acc_test=0.9954
# poison_percent 0 round 21: loss_train=0.0393, acc_train=0.9900, loss_test=0.0103, acc_test=0.9954
# poison_percent 0 round 22: loss_train=0.0002, acc_train=1.0000, loss_test=0.0103, acc_test=0.9954
# poison_percent 0 round 23: loss_train=0.0047, acc_train=1.0000, loss_test=0.0103, acc_test=0.9954
# poison_percent 0 round 24: loss_train=0.0302, acc_train=0.9900, loss_test=0.0103, acc_test=0.9954
# poison_percent 0 round 25: loss_train=0.0286, acc_train=0.9900, loss_test=0.0107, acc_test=0.9954
# poison_percent 0 round 26: loss_train=0.0351, acc_train=0.9900, loss_test=0.0107, acc_test=0.9954
# poison_percent 0 round 27: loss_train=0.0021, acc_train=1.0000, loss_test=0.0108, acc_test=0.9954
# poison_percent 0 round 28: loss_train=0.0142, acc_train=0.9900, loss_test=0.0110, acc_test=0.9954
# poison_percent 0 round 29: loss_train=0.0243, acc_train=0.9900, loss_test=0.0109, acc_test=0.9954
# poison_percent 0 round 30: loss_train=0.0069, acc_train=1.0000, loss_test=0.0113, acc_test=0.9954
# poison_percent 0 round 31: loss_train=0.0346, acc_train=0.9900, loss_test=0.0115, acc_test=0.9954
# poison_percent 0 round 32: loss_train=0.1647, acc_train=0.9800, loss_test=0.0115, acc_test=0.9954
# poison_percent 0 round 33: loss_train=0.0425, acc_train=0.9900, loss_test=0.0116, acc_test=0.9954
# poison_percent 0 round 34: loss_train=0.1064, acc_train=0.9900, loss_test=0.0116, acc_test=0.9954
# poison_percent 0 round 35: loss_train=0.0088, acc_train=0.9900, loss_test=0.0117, acc_test=0.9954
# poison_percent 0 round 36: loss_train=0.0087, acc_train=1.0000, loss_test=0.0117, acc_test=0.9954
# poison_percent 0 round 37: loss_train=0.0000, acc_train=1.0000, loss_test=0.0121, acc_test=0.9954
# poison_percent 0 round 38: loss_train=0.0000, acc_train=1.0000, loss_test=0.0119, acc_test=0.9954
# poison_percent 0 round 39: loss_train=0.0368, acc_train=0.9900, loss_test=0.0121, acc_test=0.9954
# poison_percent 0 round 40: loss_train=0.0005, acc_train=1.0000, loss_test=0.0119, acc_test=0.9954
# poison_percent 0 round 41: loss_train=0.0001, acc_train=1.0000, loss_test=0.0121, acc_test=0.9954
# poison_percent 0 round 42: loss_train=0.0127, acc_train=0.9900, loss_test=0.0122, acc_test=0.9954
# poison_percent 0 round 43: loss_train=0.0111, acc_train=0.9900, loss_test=0.0121, acc_test=0.9954
# poison_percent 0 round 44: loss_train=0.0029, acc_train=1.0000, loss_test=0.0121, acc_test=0.9954
# poison_percent 0 round 45: loss_train=0.0000, acc_train=1.0000, loss_test=0.0122, acc_test=0.9954
# poison_percent 0 round 46: loss_train=0.0000, acc_train=1.0000, loss_test=0.0119, acc_test=0.9954
# poison_percent 0 round 47: loss_train=0.0071, acc_train=0.9900, loss_test=0.0119, acc_test=0.9954
# poison_percent 0 round 48: loss_train=0.0011, acc_train=1.0000, loss_test=0.0117, acc_test=0.9954
# poison_percent 0 round 49: loss_train=0.0001, acc_train=1.0000, loss_test=0.0122, acc_test=0.9954
# poison_percent 0 round 50: loss_train=0.0811, acc_train=0.9900, loss_test=0.0122, acc_test=0.9954
# poison_percent 0 round 51: loss_train=0.0096, acc_train=0.9900, loss_test=0.0122, acc_test=0.9959
# poison_percent 0 round 52: loss_train=0.1348, acc_train=0.9900, loss_test=0.0123, acc_test=0.9954
# poison_percent 0 round 53: loss_train=0.0009, acc_train=1.0000, loss_test=0.0121, acc_test=0.9959
# poison_percent 0 round 54: loss_train=0.0005, acc_train=1.0000, loss_test=0.0123, acc_test=0.9959
# poison_percent 0 round 55: loss_train=0.0000, acc_train=1.0000, loss_test=0.0122, acc_test=0.9964
# poison_percent 0 round 56: loss_train=0.0702, acc_train=0.9800, loss_test=0.0122, acc_test=0.9964
# poison_percent 0 round 57: loss_train=0.0576, acc_train=0.9900, loss_test=0.0122, acc_test=0.9964
# poison_percent 0 round 58: loss_train=0.0607, acc_train=0.9900, loss_test=0.0123, acc_test=0.9964
# poison_percent 0 round 59: loss_train=0.0118, acc_train=0.9900, loss_test=0.0123, acc_test=0.9964
# poison_percent 0 round 60: loss_train=0.0000, acc_train=1.0000, loss_test=0.0122, acc_test=0.9964
# poison_percent 0 round 61: loss_train=0.0554, acc_train=0.9900, loss_test=0.0121, acc_test=0.9964
# poison_percent 0 round 62: loss_train=0.0006, acc_train=1.0000, loss_test=0.0122, acc_test=0.9964
# poison_percent 0 round 63: loss_train=0.0189, acc_train=0.9900, loss_test=0.0122, acc_test=0.9964
# poison_percent 0 round 64: loss_train=0.2121, acc_train=0.9800, loss_test=0.0122, acc_test=0.9964
# poison_percent 0 round 65: loss_train=0.1386, acc_train=0.9900, loss_test=0.0122, acc_test=0.9964
# poison_percent 0 round 66: loss_train=0.0604, acc_train=0.9900, loss_test=0.0121, acc_test=0.9964
# poison_percent 0 round 67: loss_train=0.0000, acc_train=1.0000, loss_test=0.0121, acc_test=0.9964
# poison_percent 0 round 68: loss_train=0.0000, acc_train=1.0000, loss_test=0.0118, acc_test=0.9964
# poison_percent 0 round 69: loss_train=0.0227, acc_train=0.9900, loss_test=0.0119, acc_test=0.9964
# poison_percent 0 round 70: loss_train=0.1053, acc_train=0.9800, loss_test=0.0119, acc_test=0.9964
# poison_percent 0 round 71: loss_train=0.0000, acc_train=1.0000, loss_test=0.0120, acc_test=0.9964
# poison_percent 0 round 72: loss_train=0.0132, acc_train=0.9900, loss_test=0.0119, acc_test=0.9964
# poison_percent 0 round 73: loss_train=0.0021, acc_train=1.0000, loss_test=0.0119, acc_test=0.9964
# poison_percent 0 round 74: loss_train=0.0016, acc_train=1.0000, loss_test=0.0119, acc_test=0.9964
# poison_percent 0 round 75: loss_train=0.0004, acc_train=1.0000, loss_test=0.0119, acc_test=0.9964
# poison_percent 0 round 76: loss_train=0.0001, acc_train=1.0000, loss_test=0.0119, acc_test=0.9964
# poison_percent 0 round 77: loss_train=0.0707, acc_train=0.9900, loss_test=0.0117, acc_test=0.9964
# poison_percent 0 round 78: loss_train=0.0001, acc_train=1.0000, loss_test=0.0117, acc_test=0.9964
# poison_percent 0 round 79: loss_train=0.0001, acc_train=1.0000, loss_test=0.0118, acc_test=0.9964
# poison_percent 0 round 80: loss_train=0.0000, acc_train=1.0000, loss_test=0.0118, acc_test=0.9964
# poison_percent 0 round 81: loss_train=0.0000, acc_train=1.0000, loss_test=0.0119, acc_test=0.9964
# poison_percent 0 round 82: loss_train=0.0000, acc_train=1.0000, loss_test=0.0120, acc_test=0.9964
# poison_percent 0 round 83: loss_train=0.0031, acc_train=1.0000, loss_test=0.0119, acc_test=0.9964
# poison_percent 0 round 84: loss_train=0.0001, acc_train=1.0000, loss_test=0.0119, acc_test=0.9964
# poison_percent 0 round 85: loss_train=0.0000, acc_train=1.0000, loss_test=0.0119, acc_test=0.9964
# poison_percent 0 round 86: loss_train=0.0129, acc_train=0.9900, loss_test=0.0120, acc_test=0.9964
# poison_percent 0 round 87: loss_train=0.0003, acc_train=1.0000, loss_test=0.0118, acc_test=0.9969
# poison_percent 0 round 88: loss_train=0.0000, acc_train=1.0000, loss_test=0.0117, acc_test=0.9974
# poison_percent 0 round 89: loss_train=0.0000, acc_train=1.0000, loss_test=0.0118, acc_test=0.9974
# poison_percent 0 round 90: loss_train=0.0006, acc_train=1.0000, loss_test=0.0118, acc_test=0.9974
# poison_percent 0 round 91: loss_train=0.0013, acc_train=1.0000, loss_test=0.0117, acc_test=0.9974
# poison_percent 0 round 92: loss_train=0.0000, acc_train=1.0000, loss_test=0.0118, acc_test=0.9974
# poison_percent 0 round 93: loss_train=0.0981, acc_train=0.9800, loss_test=0.0117, acc_test=0.9974
# poison_percent 0 round 94: loss_train=0.0000, acc_train=1.0000, loss_test=0.0116, acc_test=0.9974
# poison_percent 0 round 95: loss_train=0.0000, acc_train=1.0000, loss_test=0.0115, acc_test=0.9974
# poison_percent 0 round 96: loss_train=0.0000, acc_train=1.0000, loss_test=0.0115, acc_test=0.9974
# poison_percent 0 round 97: loss_train=0.0297, acc_train=0.9900, loss_test=0.0116, acc_test=0.9974
# poison_percent 0 round 98: loss_train=0.0000, acc_train=1.0000, loss_test=0.0115, acc_test=0.9974
# poison_percent 0 round 99: loss_train=0.0000, acc_train=1.0000, loss_test=0.0115, acc_test=0.9974
# Training log saved to ./results\FL_ModelN1L2_Batchsize1_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 round 0: loss_train=1.7176, acc_train=0.8929, loss_test=0.0115, acc_test=0.9974
# poison_percent 10 round 1: loss_train=1.5788, acc_train=0.9018, loss_test=0.0115, acc_test=0.9974
# poison_percent 10 round 2: loss_train=1.8108, acc_train=0.8839, loss_test=0.0114, acc_test=0.9974
# poison_percent 10 round 3: loss_train=1.7191, acc_train=0.8929, loss_test=0.0114, acc_test=0.9974
# poison_percent 10 round 4: loss_train=1.7207, acc_train=0.8929, loss_test=0.0114, acc_test=0.9974
# poison_percent 10 round 5: loss_train=1.7369, acc_train=0.8839, loss_test=0.0114, acc_test=0.9974
# poison_percent 10 round 6: loss_train=1.8485, acc_train=0.8839, loss_test=0.0114, acc_test=0.9974
# poison_percent 10 round 7: loss_train=1.7160, acc_train=0.8929, loss_test=0.0114, acc_test=0.9974
# poison_percent 10 round 8: loss_train=1.4431, acc_train=0.9018, loss_test=0.0113, acc_test=0.9974
# poison_percent 10 round 9: loss_train=1.7638, acc_train=0.8839, loss_test=0.0114, acc_test=0.9974
# poison_percent 10 round 10: loss_train=1.7195, acc_train=0.8929, loss_test=0.0114, acc_test=0.9974
# poison_percent 10 round 11: loss_train=1.7128, acc_train=0.8929, loss_test=0.0114, acc_test=0.9974
# poison_percent 10 round 12: loss_train=1.7175, acc_train=0.8929, loss_test=0.0114, acc_test=0.9974
# poison_percent 10 round 13: loss_train=1.7129, acc_train=0.8929, loss_test=0.0115, acc_test=0.9974
# poison_percent 10 round 14: loss_train=1.6500, acc_train=0.8929, loss_test=0.0115, acc_test=0.9974
# poison_percent 10 round 15: loss_train=1.6074, acc_train=0.8839, loss_test=0.0114, acc_test=0.9974
# poison_percent 10 round 16: loss_train=1.7175, acc_train=0.8929, loss_test=0.0115, acc_test=0.9974
# poison_percent 10 round 17: loss_train=1.7144, acc_train=0.8929, loss_test=0.0115, acc_test=0.9974
# poison_percent 10 round 18: loss_train=1.4325, acc_train=0.9107, loss_test=0.0115, acc_test=0.9974
# poison_percent 10 round 19: loss_train=1.8199, acc_train=0.8839, loss_test=0.0115, acc_test=0.9974
# poison_percent 10 round 20: loss_train=1.5827, acc_train=0.8929, loss_test=0.0115, acc_test=0.9974
# poison_percent 10 round 21: loss_train=1.7381, acc_train=0.8839, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 22: loss_train=1.7147, acc_train=0.8750, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 23: loss_train=1.6872, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 24: loss_train=1.7144, acc_train=0.8929, loss_test=0.0117, acc_test=0.9974
# poison_percent 10 round 25: loss_train=1.7160, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 26: loss_train=1.6357, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 27: loss_train=1.7113, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 28: loss_train=1.8093, acc_train=0.8839, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 29: loss_train=1.7175, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 30: loss_train=1.7133, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 31: loss_train=1.7144, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 32: loss_train=1.7191, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 33: loss_train=1.7128, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 34: loss_train=1.7469, acc_train=0.8839, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 35: loss_train=1.6584, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 36: loss_train=1.7175, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 37: loss_train=1.7191, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 38: loss_train=1.7118, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 39: loss_train=1.7167, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 40: loss_train=1.5587, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 41: loss_train=1.7160, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 42: loss_train=1.7144, acc_train=0.8929, loss_test=0.0117, acc_test=0.9974
# poison_percent 10 round 43: loss_train=1.7160, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 44: loss_train=1.7160, acc_train=0.8929, loss_test=0.0116, acc_test=0.9974
# poison_percent 10 round 45: loss_train=1.7191, acc_train=0.8929, loss_test=0.0117, acc_test=0.9974
# poison_percent 10 round 46: loss_train=1.7612, acc_train=0.8839, loss_test=0.0117, acc_test=0.9974
# poison_percent 10 round 47: loss_train=1.7160, acc_train=0.8929, loss_test=0.0117, acc_test=0.9974
# poison_percent 10 round 48: loss_train=1.5808, acc_train=0.8929, loss_test=0.0118, acc_test=0.9974
# poison_percent 10 round 49: loss_train=1.7647, acc_train=0.8839, loss_test=0.0118, acc_test=0.9974
# poison_percent 10 round 50: loss_train=1.7175, acc_train=0.8929, loss_test=0.0118, acc_test=0.9974
# poison_percent 10 round 51: loss_train=1.7191, acc_train=0.8929, loss_test=0.0118, acc_test=0.9974
# poison_percent 10 round 52: loss_train=1.7175, acc_train=0.8929, loss_test=0.0118, acc_test=0.9974
# poison_percent 10 round 53: loss_train=1.8454, acc_train=0.8839, loss_test=0.0118, acc_test=0.9974
# poison_percent 10 round 54: loss_train=1.6616, acc_train=0.8929, loss_test=0.0119, acc_test=0.9974
# poison_percent 10 round 55: loss_train=1.7323, acc_train=0.8839, loss_test=0.0119, acc_test=0.9974
# poison_percent 10 round 56: loss_train=1.7182, acc_train=0.8929, loss_test=0.0119, acc_test=0.9974
# poison_percent 10 round 57: loss_train=1.7204, acc_train=0.8929, loss_test=0.0119, acc_test=0.9974
# poison_percent 10 round 58: loss_train=1.7160, acc_train=0.8929, loss_test=0.0119, acc_test=0.9974
# poison_percent 10 round 59: loss_train=1.7176, acc_train=0.8929, loss_test=0.0119, acc_test=0.9974
# poison_percent 10 round 60: loss_train=1.5805, acc_train=0.9018, loss_test=0.0119, acc_test=0.9974
# poison_percent 10 round 61: loss_train=1.7177, acc_train=0.8929, loss_test=0.0119, acc_test=0.9974
# poison_percent 10 round 62: loss_train=1.6721, acc_train=0.8929, loss_test=0.0120, acc_test=0.9974
# poison_percent 10 round 63: loss_train=1.7191, acc_train=0.8929, loss_test=0.0120, acc_test=0.9974
# poison_percent 10 round 64: loss_train=1.6716, acc_train=0.8929, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 65: loss_train=2.1210, acc_train=0.8661, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 66: loss_train=1.7175, acc_train=0.8929, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 67: loss_train=1.8599, acc_train=0.8839, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 68: loss_train=1.7238, acc_train=0.8929, loss_test=0.0120, acc_test=0.9974
# poison_percent 10 round 69: loss_train=1.7191, acc_train=0.8929, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 70: loss_train=1.6625, acc_train=0.8929, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 71: loss_train=2.0401, acc_train=0.8661, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 72: loss_train=1.7160, acc_train=0.8929, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 73: loss_train=1.8662, acc_train=0.8839, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 74: loss_train=1.7206, acc_train=0.8929, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 75: loss_train=1.5723, acc_train=0.9018, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 76: loss_train=1.5731, acc_train=0.9018, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 77: loss_train=1.7736, acc_train=0.8750, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 78: loss_train=1.7236, acc_train=0.8929, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 79: loss_train=1.7207, acc_train=0.8929, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 80: loss_train=1.6829, acc_train=0.8929, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 81: loss_train=1.5767, acc_train=0.9018, loss_test=0.0121, acc_test=0.9974
# poison_percent 10 round 82: loss_train=1.7749, acc_train=0.8839, loss_test=0.0122, acc_test=0.9974
# poison_percent 10 round 83: loss_train=1.7202, acc_train=0.8929, loss_test=0.0122, acc_test=0.9974
# poison_percent 10 round 84: loss_train=1.5736, acc_train=0.9018, loss_test=0.0123, acc_test=0.9974
# poison_percent 10 round 85: loss_train=1.7304, acc_train=0.8839, loss_test=0.0123, acc_test=0.9974
# poison_percent 10 round 86: loss_train=1.7175, acc_train=0.8929, loss_test=0.0123, acc_test=0.9974
# poison_percent 10 round 87: loss_train=1.6876, acc_train=0.8929, loss_test=0.0123, acc_test=0.9974
# poison_percent 10 round 88: loss_train=1.7032, acc_train=0.8929, loss_test=0.0124, acc_test=0.9974
# poison_percent 10 round 89: loss_train=1.7144, acc_train=0.8929, loss_test=0.0124, acc_test=0.9974
# poison_percent 10 round 90: loss_train=1.7207, acc_train=0.8929, loss_test=0.0124, acc_test=0.9974
# poison_percent 10 round 91: loss_train=1.4974, acc_train=0.9018, loss_test=0.0124, acc_test=0.9974
# poison_percent 10 round 92: loss_train=1.8418, acc_train=0.8839, loss_test=0.0124, acc_test=0.9974
# poison_percent 10 round 93: loss_train=1.7151, acc_train=0.8929, loss_test=0.0125, acc_test=0.9974
# poison_percent 10 round 94: loss_train=1.7113, acc_train=0.8929, loss_test=0.0125, acc_test=0.9974
# poison_percent 10 round 95: loss_train=1.8426, acc_train=0.8839, loss_test=0.0125, acc_test=0.9974
# poison_percent 10 round 96: loss_train=1.7153, acc_train=0.8929, loss_test=0.0125, acc_test=0.9974
# poison_percent 10 round 97: loss_train=1.8266, acc_train=0.8839, loss_test=0.0125, acc_test=0.9974
# poison_percent 10 round 98: loss_train=1.7160, acc_train=0.8839, loss_test=0.0125, acc_test=0.9974
# poison_percent 10 round 99: loss_train=1.7241, acc_train=0.8929, loss_test=0.0125, acc_test=0.9974
# Training log saved to ./results\FL_ModelN1L2_Batchsize1_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=3.1581, acc_train=0.8000, loss_test=0.0125, acc_test=0.9974
# poison_percent 20 round 1: loss_train=3.2118, acc_train=0.8000, loss_test=0.0126, acc_test=0.9974
# poison_percent 20 round 2: loss_train=3.0975, acc_train=0.8000, loss_test=0.0125, acc_test=0.9974
# poison_percent 20 round 3: loss_train=3.3351, acc_train=0.7920, loss_test=0.0126, acc_test=0.9974
# poison_percent 20 round 4: loss_train=3.2053, acc_train=0.8000, loss_test=0.0126, acc_test=0.9974
# poison_percent 20 round 5: loss_train=3.2099, acc_train=0.8000, loss_test=0.0125, acc_test=0.9974
# poison_percent 20 round 6: loss_train=3.2053, acc_train=0.8000, loss_test=0.0125, acc_test=0.9974
# poison_percent 20 round 7: loss_train=3.2100, acc_train=0.8000, loss_test=0.0126, acc_test=0.9974
# poison_percent 20 round 8: loss_train=3.1492, acc_train=0.8000, loss_test=0.0126, acc_test=0.9974
# poison_percent 20 round 9: loss_train=3.2043, acc_train=0.8000, loss_test=0.0126, acc_test=0.9974
# poison_percent 20 round 10: loss_train=3.2071, acc_train=0.8000, loss_test=0.0126, acc_test=0.9974
# poison_percent 20 round 11: loss_train=3.1328, acc_train=0.8000, loss_test=0.0126, acc_test=0.9974
# poison_percent 20 round 12: loss_train=3.2025, acc_train=0.8000, loss_test=0.0126, acc_test=0.9974
# poison_percent 20 round 13: loss_train=3.2068, acc_train=0.8000, loss_test=0.0127, acc_test=0.9974
# poison_percent 20 round 14: loss_train=3.2068, acc_train=0.8000, loss_test=0.0127, acc_test=0.9974
# poison_percent 20 round 15: loss_train=3.2096, acc_train=0.8000, loss_test=0.0127, acc_test=0.9974
# poison_percent 20 round 16: loss_train=2.9929, acc_train=0.8080, loss_test=0.0127, acc_test=0.9974
# poison_percent 20 round 17: loss_train=3.3427, acc_train=0.7840, loss_test=0.0127, acc_test=0.9974
# poison_percent 20 round 18: loss_train=3.2152, acc_train=0.8000, loss_test=0.0127, acc_test=0.9974
# poison_percent 20 round 19: loss_train=3.0861, acc_train=0.8000, loss_test=0.0127, acc_test=0.9974
# poison_percent 20 round 20: loss_train=3.0922, acc_train=0.8000, loss_test=0.0127, acc_test=0.9974
# poison_percent 20 round 21: loss_train=3.2105, acc_train=0.8000, loss_test=0.0127, acc_test=0.9974
# poison_percent 20 round 22: loss_train=3.3329, acc_train=0.7920, loss_test=0.0127, acc_test=0.9974
# poison_percent 20 round 23: loss_train=3.2068, acc_train=0.8000, loss_test=0.0127, acc_test=0.9974
# poison_percent 20 round 24: loss_train=3.1554, acc_train=0.8000, loss_test=0.0128, acc_test=0.9974
# poison_percent 20 round 25: loss_train=3.2137, acc_train=0.8000, loss_test=0.0128, acc_test=0.9974
# poison_percent 20 round 26: loss_train=3.2117, acc_train=0.7920, loss_test=0.0128, acc_test=0.9974
# poison_percent 20 round 27: loss_train=3.2039, acc_train=0.8000, loss_test=0.0128, acc_test=0.9974
# poison_percent 20 round 28: loss_train=3.1755, acc_train=0.8000, loss_test=0.0128, acc_test=0.9974
# poison_percent 20 round 29: loss_train=3.2495, acc_train=0.7920, loss_test=0.0128, acc_test=0.9974
# poison_percent 20 round 30: loss_train=3.3371, acc_train=0.7920, loss_test=0.0128, acc_test=0.9980
# poison_percent 20 round 31: loss_train=3.3799, acc_train=0.7840, loss_test=0.0129, acc_test=0.9980
# poison_percent 20 round 32: loss_train=3.1539, acc_train=0.8000, loss_test=0.0129, acc_test=0.9980
# poison_percent 20 round 33: loss_train=3.2094, acc_train=0.8000, loss_test=0.0129, acc_test=0.9980
# poison_percent 20 round 34: loss_train=2.9845, acc_train=0.8000, loss_test=0.0129, acc_test=0.9980
# poison_percent 20 round 35: loss_train=3.0806, acc_train=0.8080, loss_test=0.0129, acc_test=0.9980
# poison_percent 20 round 36: loss_train=3.3345, acc_train=0.7920, loss_test=0.0129, acc_test=0.9980
# poison_percent 20 round 37: loss_train=3.1872, acc_train=0.7920, loss_test=0.0129, acc_test=0.9980
# poison_percent 20 round 38: loss_train=3.2025, acc_train=0.8000, loss_test=0.0129, acc_test=0.9980
# poison_percent 20 round 39: loss_train=3.2042, acc_train=0.8000, loss_test=0.0129, acc_test=0.9980
# poison_percent 20 round 40: loss_train=3.1999, acc_train=0.8000, loss_test=0.0129, acc_test=0.9980
# poison_percent 20 round 41: loss_train=3.3277, acc_train=0.7840, loss_test=0.0129, acc_test=0.9980
# poison_percent 20 round 42: loss_train=3.3301, acc_train=0.7920, loss_test=0.0129, acc_test=0.9980
# poison_percent 20 round 43: loss_train=3.2403, acc_train=0.7920, loss_test=0.0130, acc_test=0.9980
# poison_percent 20 round 44: loss_train=3.1200, acc_train=0.7920, loss_test=0.0130, acc_test=0.9980
# poison_percent 20 round 45: loss_train=3.2096, acc_train=0.8000, loss_test=0.0130, acc_test=0.9980
# poison_percent 20 round 46: loss_train=3.1980, acc_train=0.8000, loss_test=0.0130, acc_test=0.9980
# poison_percent 20 round 47: loss_train=3.1187, acc_train=0.8000, loss_test=0.0130, acc_test=0.9980
# poison_percent 20 round 48: loss_train=3.2082, acc_train=0.8000, loss_test=0.0130, acc_test=0.9980
# poison_percent 20 round 49: loss_train=3.2068, acc_train=0.8000, loss_test=0.0130, acc_test=0.9980
# poison_percent 20 round 50: loss_train=3.1648, acc_train=0.8000, loss_test=0.0130, acc_test=0.9980
# poison_percent 20 round 51: loss_train=2.9495, acc_train=0.8160, loss_test=0.0130, acc_test=0.9980
# poison_percent 20 round 52: loss_train=3.2125, acc_train=0.8000, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 53: loss_train=3.1409, acc_train=0.8000, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 54: loss_train=3.2116, acc_train=0.8000, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 55: loss_train=3.2538, acc_train=0.7920, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 56: loss_train=3.2053, acc_train=0.8000, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 57: loss_train=3.0842, acc_train=0.8000, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 58: loss_train=3.1782, acc_train=0.7920, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 59: loss_train=3.2068, acc_train=0.8000, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 60: loss_train=3.3259, acc_train=0.7920, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 61: loss_train=3.2040, acc_train=0.8000, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 62: loss_train=3.2011, acc_train=0.8000, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 63: loss_train=3.2082, acc_train=0.8000, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 64: loss_train=3.2082, acc_train=0.8000, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 65: loss_train=3.1803, acc_train=0.8000, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 66: loss_train=3.2025, acc_train=0.8000, loss_test=0.0131, acc_test=0.9980
# poison_percent 20 round 67: loss_train=3.0736, acc_train=0.8080, loss_test=0.0132, acc_test=0.9980
# poison_percent 20 round 68: loss_train=3.2082, acc_train=0.8000, loss_test=0.0132, acc_test=0.9980
# poison_percent 20 round 69: loss_train=3.2491, acc_train=0.7920, loss_test=0.0132, acc_test=0.9980
# poison_percent 20 round 70: loss_train=3.0841, acc_train=0.8000, loss_test=0.0132, acc_test=0.9980
# poison_percent 20 round 71: loss_train=3.0769, acc_train=0.8080, loss_test=0.0132, acc_test=0.9980
# poison_percent 20 round 72: loss_train=3.3625, acc_train=0.7840, loss_test=0.0132, acc_test=0.9980
# poison_percent 20 round 73: loss_train=3.1924, acc_train=0.8000, loss_test=0.0132, acc_test=0.9980
# poison_percent 20 round 74: loss_train=3.2083, acc_train=0.8000, loss_test=0.0132, acc_test=0.9980
# poison_percent 20 round 75: loss_train=3.1682, acc_train=0.8000, loss_test=0.0132, acc_test=0.9980
# poison_percent 20 round 76: loss_train=3.2199, acc_train=0.7920, loss_test=0.0132, acc_test=0.9980
# poison_percent 20 round 77: loss_train=3.1741, acc_train=0.7920, loss_test=0.0133, acc_test=0.9980
# poison_percent 20 round 78: loss_train=3.1214, acc_train=0.7920, loss_test=0.0133, acc_test=0.9980
# poison_percent 20 round 79: loss_train=3.2098, acc_train=0.8000, loss_test=0.0133, acc_test=0.9980
# poison_percent 20 round 80: loss_train=3.1331, acc_train=0.8000, loss_test=0.0133, acc_test=0.9980
# poison_percent 20 round 81: loss_train=3.3304, acc_train=0.7920, loss_test=0.0133, acc_test=0.9980
# poison_percent 20 round 82: loss_train=3.4327, acc_train=0.7840, loss_test=0.0133, acc_test=0.9980
# poison_percent 20 round 83: loss_train=3.0276, acc_train=0.8080, loss_test=0.0133, acc_test=0.9980
# poison_percent 20 round 84: loss_train=3.2039, acc_train=0.8000, loss_test=0.0133, acc_test=0.9980
# poison_percent 20 round 85: loss_train=3.1137, acc_train=0.8000, loss_test=0.0133, acc_test=0.9980
# poison_percent 20 round 86: loss_train=3.2028, acc_train=0.8000, loss_test=0.0133, acc_test=0.9980
# poison_percent 20 round 87: loss_train=3.1929, acc_train=0.8000, loss_test=0.0133, acc_test=0.9980
# poison_percent 20 round 88: loss_train=3.2097, acc_train=0.8000, loss_test=0.0133, acc_test=0.9980
# poison_percent 20 round 89: loss_train=3.0345, acc_train=0.8080, loss_test=0.0133, acc_test=0.9980
# poison_percent 20 round 90: loss_train=3.2011, acc_train=0.8000, loss_test=0.0134, acc_test=0.9980
# poison_percent 20 round 91: loss_train=3.1293, acc_train=0.8000, loss_test=0.0134, acc_test=0.9980
# poison_percent 20 round 92: loss_train=3.0849, acc_train=0.8000, loss_test=0.0134, acc_test=0.9980
# poison_percent 20 round 93: loss_train=3.1600, acc_train=0.8000, loss_test=0.0134, acc_test=0.9980
# poison_percent 20 round 94: loss_train=3.2128, acc_train=0.7920, loss_test=0.0134, acc_test=0.9980
# poison_percent 20 round 95: loss_train=3.0876, acc_train=0.8080, loss_test=0.0134, acc_test=0.9980
# poison_percent 20 round 96: loss_train=3.0625, acc_train=0.8000, loss_test=0.0134, acc_test=0.9980
# poison_percent 20 round 97: loss_train=3.0809, acc_train=0.8080, loss_test=0.0134, acc_test=0.9980
# poison_percent 20 round 98: loss_train=3.2076, acc_train=0.8000, loss_test=0.0134, acc_test=0.9980
# poison_percent 20 round 99: loss_train=3.0132, acc_train=0.8000, loss_test=0.0134, acc_test=0.9980
# Training log saved to ./results\FL_ModelN1L2_Batchsize1_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=4.8530, acc_train=0.6923, loss_test=0.0135, acc_test=0.9980
# poison_percent 30 round 1: loss_train=4.7005, acc_train=0.6993, loss_test=0.0135, acc_test=0.9985
# poison_percent 30 round 2: loss_train=4.8123, acc_train=0.6993, loss_test=0.0137, acc_test=0.9985
# poison_percent 30 round 3: loss_train=4.8184, acc_train=0.6993, loss_test=0.0138, acc_test=0.9985
# poison_percent 30 round 4: loss_train=4.7091, acc_train=0.6993, loss_test=0.0138, acc_test=0.9985
# poison_percent 30 round 5: loss_train=4.7530, acc_train=0.6923, loss_test=0.0139, acc_test=0.9985
# poison_percent 30 round 6: loss_train=4.8214, acc_train=0.6993, loss_test=0.0140, acc_test=0.9985
# poison_percent 30 round 7: loss_train=4.7692, acc_train=0.6923, loss_test=0.0140, acc_test=0.9985
# poison_percent 30 round 8: loss_train=4.7059, acc_train=0.7063, loss_test=0.0140, acc_test=0.9985
# poison_percent 30 round 9: loss_train=4.8160, acc_train=0.6993, loss_test=0.0140, acc_test=0.9985
# poison_percent 30 round 10: loss_train=4.4989, acc_train=0.7133, loss_test=0.0140, acc_test=0.9985
# poison_percent 30 round 11: loss_train=4.8491, acc_train=0.6923, loss_test=0.0140, acc_test=0.9985
# poison_percent 30 round 12: loss_train=4.7284, acc_train=0.6923, loss_test=0.0140, acc_test=0.9985
# poison_percent 30 round 13: loss_train=4.8492, acc_train=0.6923, loss_test=0.0140, acc_test=0.9985
# poison_percent 30 round 14: loss_train=4.8066, acc_train=0.6923, loss_test=0.0141, acc_test=0.9985
# poison_percent 30 round 15: loss_train=4.5555, acc_train=0.7063, loss_test=0.0141, acc_test=0.9985
# poison_percent 30 round 16: loss_train=4.6587, acc_train=0.7063, loss_test=0.0141, acc_test=0.9985
# poison_percent 30 round 17: loss_train=4.8227, acc_train=0.6853, loss_test=0.0141, acc_test=0.9985
# poison_percent 30 round 18: loss_train=4.8552, acc_train=0.6923, loss_test=0.0141, acc_test=0.9985
# poison_percent 30 round 19: loss_train=4.7308, acc_train=0.6993, loss_test=0.0141, acc_test=0.9985
# poison_percent 30 round 20: loss_train=4.8160, acc_train=0.6993, loss_test=0.0141, acc_test=0.9985
# poison_percent 30 round 21: loss_train=4.8184, acc_train=0.6993, loss_test=0.0141, acc_test=0.9985
# poison_percent 30 round 22: loss_train=4.5717, acc_train=0.7063, loss_test=0.0142, acc_test=0.9985
# poison_percent 30 round 23: loss_train=4.7232, acc_train=0.6993, loss_test=0.0141, acc_test=0.9985
# poison_percent 30 round 24: loss_train=4.7094, acc_train=0.7063, loss_test=0.0141, acc_test=0.9985
# poison_percent 30 round 25: loss_train=4.7329, acc_train=0.6993, loss_test=0.0142, acc_test=0.9985
# poison_percent 30 round 26: loss_train=4.7879, acc_train=0.6993, loss_test=0.0142, acc_test=0.9985
# poison_percent 30 round 27: loss_train=4.6985, acc_train=0.7063, loss_test=0.0142, acc_test=0.9985
# poison_percent 30 round 28: loss_train=4.7649, acc_train=0.6993, loss_test=0.0142, acc_test=0.9985
# poison_percent 30 round 29: loss_train=4.9726, acc_train=0.6783, loss_test=0.0142, acc_test=0.9985
# poison_percent 30 round 30: loss_train=4.8209, acc_train=0.6993, loss_test=0.0142, acc_test=0.9985
# poison_percent 30 round 31: loss_train=4.9259, acc_train=0.6923, loss_test=0.0143, acc_test=0.9985
# poison_percent 30 round 32: loss_train=4.8279, acc_train=0.6923, loss_test=0.0143, acc_test=0.9985
# poison_percent 30 round 33: loss_train=4.9576, acc_train=0.6853, loss_test=0.0143, acc_test=0.9985
# poison_percent 30 round 34: loss_train=4.7841, acc_train=0.6993, loss_test=0.0143, acc_test=0.9985
# poison_percent 30 round 35: loss_train=4.8628, acc_train=0.6923, loss_test=0.0143, acc_test=0.9985
# poison_percent 30 round 36: loss_train=4.7887, acc_train=0.6923, loss_test=0.0143, acc_test=0.9985
# poison_percent 30 round 37: loss_train=4.7895, acc_train=0.6993, loss_test=0.0143, acc_test=0.9985
# poison_percent 30 round 38: loss_train=4.7652, acc_train=0.6923, loss_test=0.0143, acc_test=0.9985
# poison_percent 30 round 39: loss_train=4.8132, acc_train=0.6923, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 40: loss_train=4.8124, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 41: loss_train=4.7258, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 42: loss_train=4.8283, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 43: loss_train=4.8172, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 44: loss_train=4.7984, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 45: loss_train=4.8221, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 46: loss_train=4.8071, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 47: loss_train=4.7660, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 48: loss_train=4.7329, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 49: loss_train=4.5800, acc_train=0.7133, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 50: loss_train=4.9299, acc_train=0.6923, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 51: loss_train=4.8428, acc_train=0.6923, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 52: loss_train=4.8444, acc_train=0.6923, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 53: loss_train=4.8111, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 54: loss_train=4.9014, acc_train=0.6783, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 55: loss_train=4.8972, acc_train=0.6923, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 56: loss_train=4.6712, acc_train=0.6993, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 57: loss_train=4.7683, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 58: loss_train=4.7010, acc_train=0.7063, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 59: loss_train=4.7406, acc_train=0.6923, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 60: loss_train=4.6374, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 61: loss_train=4.7596, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 62: loss_train=4.6225, acc_train=0.7063, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 63: loss_train=4.7344, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 64: loss_train=4.9373, acc_train=0.6923, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 65: loss_train=4.8197, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 66: loss_train=4.6489, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 67: loss_train=4.6346, acc_train=0.7063, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 68: loss_train=4.7448, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 69: loss_train=4.7095, acc_train=0.7063, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 70: loss_train=4.6026, acc_train=0.7063, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 71: loss_train=4.8221, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 72: loss_train=4.9271, acc_train=0.6923, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 73: loss_train=4.8246, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 74: loss_train=4.8234, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 75: loss_train=4.7882, acc_train=0.6993, loss_test=0.0144, acc_test=0.9985
# poison_percent 30 round 76: loss_train=4.7466, acc_train=0.6993, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 77: loss_train=4.8221, acc_train=0.6993, loss_test=0.0146, acc_test=0.9985
# poison_percent 30 round 78: loss_train=4.7527, acc_train=0.6923, loss_test=0.0146, acc_test=0.9985
# poison_percent 30 round 79: loss_train=4.8148, acc_train=0.6993, loss_test=0.0146, acc_test=0.9985
# poison_percent 30 round 80: loss_train=4.7287, acc_train=0.6923, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 81: loss_train=4.7063, acc_train=0.7063, loss_test=0.0146, acc_test=0.9985
# poison_percent 30 round 82: loss_train=4.9179, acc_train=0.6853, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 83: loss_train=4.8209, acc_train=0.6993, loss_test=0.0146, acc_test=0.9985
# poison_percent 30 round 84: loss_train=4.6132, acc_train=0.7063, loss_test=0.0146, acc_test=0.9985
# poison_percent 30 round 85: loss_train=4.6794, acc_train=0.7063, loss_test=0.0146, acc_test=0.9985
# poison_percent 30 round 86: loss_train=4.8234, acc_train=0.6993, loss_test=0.0146, acc_test=0.9985
# poison_percent 30 round 87: loss_train=4.5817, acc_train=0.7063, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 88: loss_train=4.8792, acc_train=0.6923, loss_test=0.0146, acc_test=0.9985
# poison_percent 30 round 89: loss_train=4.8493, acc_train=0.6923, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 90: loss_train=4.6472, acc_train=0.6993, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 91: loss_train=4.8197, acc_train=0.6993, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 92: loss_train=4.7367, acc_train=0.6993, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 93: loss_train=4.8209, acc_train=0.6993, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 94: loss_train=4.6464, acc_train=0.7063, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 95: loss_train=4.7947, acc_train=0.6923, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 96: loss_train=4.9215, acc_train=0.6923, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 97: loss_train=4.8374, acc_train=0.6923, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 98: loss_train=4.6959, acc_train=0.7063, loss_test=0.0145, acc_test=0.9985
# poison_percent 30 round 99: loss_train=4.7306, acc_train=0.6993, loss_test=0.0145, acc_test=0.9985
# Training log saved to ./results\FL_ModelN1L2_Batchsize1_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=6.2562, acc_train=0.5988, loss_test=0.0146, acc_test=0.9985
# poison_percent 40 round 1: loss_train=6.3360, acc_train=0.5928, loss_test=0.0147, acc_test=0.9985
# poison_percent 40 round 2: loss_train=6.3684, acc_train=0.5988, loss_test=0.0149, acc_test=0.9985
# poison_percent 40 round 3: loss_train=6.2989, acc_train=0.6048, loss_test=0.0151, acc_test=0.9990
# poison_percent 40 round 4: loss_train=6.1726, acc_train=0.6108, loss_test=0.0153, acc_test=0.9990
# poison_percent 40 round 5: loss_train=6.3114, acc_train=0.6048, loss_test=0.0155, acc_test=0.9990
# poison_percent 40 round 6: loss_train=6.5489, acc_train=0.5808, loss_test=0.0157, acc_test=0.9990
# poison_percent 40 round 7: loss_train=6.2061, acc_train=0.6108, loss_test=0.0159, acc_test=0.9990
# poison_percent 40 round 8: loss_train=6.4673, acc_train=0.5928, loss_test=0.0164, acc_test=0.9980
# poison_percent 40 round 9: loss_train=6.3739, acc_train=0.5988, loss_test=0.0168, acc_test=0.9980
# poison_percent 40 round 10: loss_train=6.3797, acc_train=0.5988, loss_test=0.0171, acc_test=0.9980
# poison_percent 40 round 11: loss_train=6.2572, acc_train=0.5988, loss_test=0.0175, acc_test=0.9980
# poison_percent 40 round 12: loss_train=6.2382, acc_train=0.6108, loss_test=0.0178, acc_test=0.9980
# poison_percent 40 round 13: loss_train=6.5006, acc_train=0.5928, loss_test=0.0179, acc_test=0.9980
# poison_percent 40 round 14: loss_train=6.3866, acc_train=0.5988, loss_test=0.0184, acc_test=0.9980
# poison_percent 40 round 15: loss_train=6.4868, acc_train=0.5928, loss_test=0.0190, acc_test=0.9980
# poison_percent 40 round 16: loss_train=6.3989, acc_train=0.5988, loss_test=0.0193, acc_test=0.9980
# poison_percent 40 round 17: loss_train=6.3138, acc_train=0.5928, loss_test=0.0197, acc_test=0.9974
# poison_percent 40 round 18: loss_train=6.4404, acc_train=0.5928, loss_test=0.0202, acc_test=0.9974
# poison_percent 40 round 19: loss_train=6.2624, acc_train=0.5988, loss_test=0.0204, acc_test=0.9974
# poison_percent 40 round 20: loss_train=6.4472, acc_train=0.5928, loss_test=0.0207, acc_test=0.9974
# poison_percent 40 round 21: loss_train=6.1703, acc_train=0.6048, loss_test=0.0211, acc_test=0.9974
# poison_percent 40 round 22: loss_train=6.3784, acc_train=0.5868, loss_test=0.0215, acc_test=0.9974
# poison_percent 40 round 23: loss_train=6.3670, acc_train=0.5928, loss_test=0.0220, acc_test=0.9974
# poison_percent 40 round 24: loss_train=6.4841, acc_train=0.5808, loss_test=0.0224, acc_test=0.9974
# poison_percent 40 round 25: loss_train=6.2593, acc_train=0.5988, loss_test=0.0229, acc_test=0.9974
# poison_percent 40 round 26: loss_train=6.4002, acc_train=0.5988, loss_test=0.0233, acc_test=0.9974
# poison_percent 40 round 27: loss_train=6.3323, acc_train=0.6048, loss_test=0.0237, acc_test=0.9974
# poison_percent 40 round 28: loss_train=6.2420, acc_train=0.5928, loss_test=0.0240, acc_test=0.9974
# poison_percent 40 round 29: loss_train=6.3247, acc_train=0.6048, loss_test=0.0246, acc_test=0.9969
# poison_percent 40 round 30: loss_train=6.3815, acc_train=0.5988, loss_test=0.0251, acc_test=0.9969
# poison_percent 40 round 31: loss_train=6.4172, acc_train=0.5988, loss_test=0.0254, acc_test=0.9969
# poison_percent 40 round 32: loss_train=6.2719, acc_train=0.5988, loss_test=0.0257, acc_test=0.9969
# poison_percent 40 round 33: loss_train=6.1633, acc_train=0.6048, loss_test=0.0261, acc_test=0.9969
# poison_percent 40 round 34: loss_train=6.2972, acc_train=0.6048, loss_test=0.0268, acc_test=0.9969
# poison_percent 40 round 35: loss_train=6.1010, acc_train=0.6108, loss_test=0.0275, acc_test=0.9969
# poison_percent 40 round 36: loss_train=6.4442, acc_train=0.5868, loss_test=0.0283, acc_test=0.9969
# poison_percent 40 round 37: loss_train=6.3256, acc_train=0.5928, loss_test=0.0288, acc_test=0.9969
# poison_percent 40 round 38: loss_train=6.1286, acc_train=0.5928, loss_test=0.0294, acc_test=0.9969
# poison_percent 40 round 39: loss_train=6.1453, acc_train=0.6108, loss_test=0.0301, acc_test=0.9964
# poison_percent 40 round 40: loss_train=6.2576, acc_train=0.5868, loss_test=0.0307, acc_test=0.9964
# poison_percent 40 round 41: loss_train=6.1361, acc_train=0.5988, loss_test=0.0319, acc_test=0.9954
# poison_percent 40 round 42: loss_train=6.0678, acc_train=0.6048, loss_test=0.0328, acc_test=0.9954
# poison_percent 40 round 43: loss_train=6.3618, acc_train=0.5928, loss_test=0.0333, acc_test=0.9949
# poison_percent 40 round 44: loss_train=6.2521, acc_train=0.6048, loss_test=0.0341, acc_test=0.9949
# poison_percent 40 round 45: loss_train=6.0361, acc_train=0.6108, loss_test=0.0351, acc_test=0.9949
# poison_percent 40 round 46: loss_train=6.1477, acc_train=0.6048, loss_test=0.0362, acc_test=0.9949
# poison_percent 40 round 47: loss_train=6.2183, acc_train=0.5988, loss_test=0.0369, acc_test=0.9949
# poison_percent 40 round 48: loss_train=6.1571, acc_train=0.5988, loss_test=0.0370, acc_test=0.9949
# poison_percent 40 round 49: loss_train=6.2198, acc_train=0.5988, loss_test=0.0382, acc_test=0.9949
# poison_percent 40 round 50: loss_train=5.8335, acc_train=0.5988, loss_test=0.0394, acc_test=0.9949
# poison_percent 40 round 51: loss_train=5.8680, acc_train=0.6168, loss_test=0.0404, acc_test=0.9949
# poison_percent 40 round 52: loss_train=6.1169, acc_train=0.6048, loss_test=0.0428, acc_test=0.9939
# poison_percent 40 round 53: loss_train=6.2213, acc_train=0.5988, loss_test=0.0440, acc_test=0.9939
# poison_percent 40 round 54: loss_train=6.1647, acc_train=0.5988, loss_test=0.0461, acc_test=0.9934
# poison_percent 40 round 55: loss_train=6.2722, acc_train=0.5868, loss_test=0.0483, acc_test=0.9929
# poison_percent 40 round 56: loss_train=5.8781, acc_train=0.6228, loss_test=0.0513, acc_test=0.9929
# poison_percent 40 round 57: loss_train=5.8928, acc_train=0.6108, loss_test=0.0545, acc_test=0.9923
# poison_percent 40 round 58: loss_train=6.4944, acc_train=0.5868, loss_test=0.0575, acc_test=0.9913
# poison_percent 40 round 59: loss_train=6.2423, acc_train=0.5988, loss_test=0.0613, acc_test=0.9903
# poison_percent 40 round 60: loss_train=6.2349, acc_train=0.5988, loss_test=0.0643, acc_test=0.9898
# poison_percent 40 round 61: loss_train=5.9368, acc_train=0.6048, loss_test=0.0689, acc_test=0.9888
# poison_percent 40 round 62: loss_train=5.8039, acc_train=0.6048, loss_test=0.0746, acc_test=0.9878
# poison_percent 40 round 63: loss_train=5.9804, acc_train=0.5988, loss_test=0.0833, acc_test=0.9867
# poison_percent 40 round 64: loss_train=5.8036, acc_train=0.6168, loss_test=0.0925, acc_test=0.9852
# poison_percent 40 round 65: loss_train=6.0080, acc_train=0.5988, loss_test=0.1014, acc_test=0.9837
# poison_percent 40 round 66: loss_train=6.0270, acc_train=0.6108, loss_test=0.1135, acc_test=0.9827
# poison_percent 40 round 67: loss_train=5.1708, acc_train=0.6168, loss_test=0.1250, acc_test=0.9806
# poison_percent 40 round 68: loss_train=5.7384, acc_train=0.6168, loss_test=0.1446, acc_test=0.9801
# poison_percent 40 round 69: loss_train=5.5918, acc_train=0.6108, loss_test=0.1649, acc_test=0.9765
# poison_percent 40 round 70: loss_train=5.1680, acc_train=0.6108, loss_test=0.1907, acc_test=0.9745
# poison_percent 40 round 71: loss_train=4.8533, acc_train=0.6168, loss_test=0.2239, acc_test=0.9709
# poison_percent 40 round 72: loss_train=4.4064, acc_train=0.6707, loss_test=0.2662, acc_test=0.9679
# poison_percent 40 round 73: loss_train=4.4612, acc_train=0.6527, loss_test=0.3196, acc_test=0.9638
# poison_percent 40 round 74: loss_train=3.9127, acc_train=0.6647, loss_test=0.3731, acc_test=0.9551
# poison_percent 40 round 75: loss_train=3.1397, acc_train=0.6587, loss_test=0.4300, acc_test=0.9480
# poison_percent 40 round 76: loss_train=3.4163, acc_train=0.6707, loss_test=0.4863, acc_test=0.9423
# poison_percent 40 round 77: loss_train=3.5278, acc_train=0.6826, loss_test=0.5476, acc_test=0.9286
# poison_percent 40 round 78: loss_train=3.7328, acc_train=0.6886, loss_test=0.6045, acc_test=0.9214
# poison_percent 40 round 79: loss_train=4.1500, acc_train=0.6766, loss_test=0.6415, acc_test=0.9194
# poison_percent 40 round 80: loss_train=3.4259, acc_train=0.7186, loss_test=0.6749, acc_test=0.9138
# poison_percent 40 round 81: loss_train=3.8329, acc_train=0.6886, loss_test=0.7027, acc_test=0.9087
# ...
# poison_percent 50 round 35: loss_train=3.6443, acc_train=0.7650, loss_test=0.7625, acc_test=0.8653
# poison_percent 50 round 36: loss_train=3.9679, acc_train=0.7400, loss_test=0.7548, acc_test=0.8658
# poison_percent 50 round 37: loss_train=3.7937, acc_train=0.7450, loss_test=0.7429, acc_test=0.8679
# poison_percent 50 round 38: loss_train=4.4598, acc_train=0.7000, loss_test=0.7445, acc_test=0.8668
# poison_percent 50 round 39: loss_train=4.1478, acc_train=0.7300, loss_test=0.7519, acc_test=0.8638
# poison_percent 50 round 40: loss_train=3.6619, acc_train=0.7650, loss_test=0.7336, acc_test=0.8673
# poison_percent 50 round 41: loss_train=3.7721, acc_train=0.7500, loss_test=0.7242, acc_test=0.8679
# poison_percent 50 round 42: loss_train=4.7633, acc_train=0.6900, loss_test=0.7189, acc_test=0.8689
# poison_percent 50 round 43: loss_train=4.0378, acc_train=0.7450, loss_test=0.7102, acc_test=0.8709
# poison_percent 50 round 44: loss_train=4.2659, acc_train=0.7150, loss_test=0.6921, acc_test=0.8770
# poison_percent 50 round 45: loss_train=4.6287, acc_train=0.7050, loss_test=0.6986, acc_test=0.8735
# poison_percent 50 round 46: loss_train=4.2798, acc_train=0.7250, loss_test=0.6824, acc_test=0.8791
# poison_percent 50 round 47: loss_train=4.2628, acc_train=0.7200, loss_test=0.6821, acc_test=0.8776
# poison_percent 50 round 48: loss_train=4.5067, acc_train=0.7150, loss_test=0.6878, acc_test=0.8740
# poison_percent 50 round 49: loss_train=4.1329, acc_train=0.7300, loss_test=0.6886, acc_test=0.8704
# poison_percent 50 round 50: loss_train=5.0230, acc_train=0.6800, loss_test=0.6640, acc_test=0.8801
# poison_percent 50 round 51: loss_train=3.8884, acc_train=0.7450, loss_test=0.6550, acc_test=0.8801
# poison_percent 50 round 52: loss_train=4.1729, acc_train=0.7350, loss_test=0.6364, acc_test=0.8842
# poison_percent 50 round 53: loss_train=4.0978, acc_train=0.7300, loss_test=0.6423, acc_test=0.8827
# poison_percent 50 round 54: loss_train=4.1965, acc_train=0.7350, loss_test=0.6159, acc_test=0.8883
# poison_percent 50 round 55: loss_train=4.3562, acc_train=0.7300, loss_test=0.6170, acc_test=0.8862
# poison_percent 50 round 56: loss_train=4.2519, acc_train=0.7350, loss_test=0.6110, acc_test=0.8862
# poison_percent 50 round 57: loss_train=4.0398, acc_train=0.7450, loss_test=0.6090, acc_test=0.8862
# poison_percent 50 round 58: loss_train=3.9749, acc_train=0.7450, loss_test=0.6063, acc_test=0.8872
# poison_percent 50 round 59: loss_train=3.7211, acc_train=0.7500, loss_test=0.5973, acc_test=0.8883
# poison_percent 50 round 60: loss_train=3.9800, acc_train=0.7400, loss_test=0.5879, acc_test=0.8893
# poison_percent 50 round 61: loss_train=3.9728, acc_train=0.7500, loss_test=0.5882, acc_test=0.8888
# poison_percent 50 round 62: loss_train=3.4396, acc_train=0.7800, loss_test=0.5892, acc_test=0.8888
# poison_percent 50 round 63: loss_train=4.4147, acc_train=0.7250, loss_test=0.5919, acc_test=0.8867
# poison_percent 50 round 64: loss_train=4.7158, acc_train=0.6850, loss_test=0.5805, acc_test=0.8883
# poison_percent 50 round 65: loss_train=4.5186, acc_train=0.7200, loss_test=0.5595, acc_test=0.8949
# poison_percent 50 round 66: loss_train=4.0529, acc_train=0.7450, loss_test=0.5362, acc_test=0.9010
# poison_percent 50 round 67: loss_train=4.6610, acc_train=0.7050, loss_test=0.5451, acc_test=0.8959
# poison_percent 50 round 68: loss_train=4.0888, acc_train=0.7350, loss_test=0.5536, acc_test=0.8929
# poison_percent 50 round 69: loss_train=3.9538, acc_train=0.7550, loss_test=0.5456, acc_test=0.8929
# poison_percent 50 round 70: loss_train=4.2880, acc_train=0.7250, loss_test=0.5283, acc_test=0.8995
# poison_percent 50 round 71: loss_train=3.8579, acc_train=0.7500, loss_test=0.5172, acc_test=0.9005
# poison_percent 50 round 72: loss_train=3.5569, acc_train=0.7750, loss_test=0.5193, acc_test=0.8995
# poison_percent 50 round 73: loss_train=4.0329, acc_train=0.7500, loss_test=0.5192, acc_test=0.8990
# poison_percent 50 round 74: loss_train=4.2740, acc_train=0.7350, loss_test=0.5087, acc_test=0.9010
# poison_percent 50 round 75: loss_train=3.4675, acc_train=0.7850, loss_test=0.4995, acc_test=0.9020
# poison_percent 50 round 76: loss_train=4.2788, acc_train=0.7250, loss_test=0.4999, acc_test=0.9015
# poison_percent 50 round 77: loss_train=4.2030, acc_train=0.7350, loss_test=0.4818, acc_test=0.9061
# poison_percent 50 round 78: loss_train=4.0040, acc_train=0.7400, loss_test=0.4748, acc_test=0.9077
# poison_percent 50 round 79: loss_train=4.0325, acc_train=0.7500, loss_test=0.4843, acc_test=0.9036
# poison_percent 50 round 80: loss_train=4.2497, acc_train=0.7300, loss_test=0.4751, acc_test=0.9051
# poison_percent 50 round 81: loss_train=4.4702, acc_train=0.7200, loss_test=0.4692, acc_test=0.9061
# poison_percent 50 round 82: loss_train=4.2730, acc_train=0.7350, loss_test=0.4567, acc_test=0.9102
# poison_percent 50 round 83: loss_train=4.2232, acc_train=0.7350, loss_test=0.4553, acc_test=0.9097
# poison_percent 50 round 84: loss_train=4.3692, acc_train=0.7250, loss_test=0.4503, acc_test=0.9097
# poison_percent 50 round 85: loss_train=4.1110, acc_train=0.7300, loss_test=0.4527, acc_test=0.9077
# poison_percent 50 round 86: loss_train=4.6219, acc_train=0.7100, loss_test=0.4387, acc_test=0.9117
# poison_percent 50 round 87: loss_train=3.5261, acc_train=0.7600, loss_test=0.4394, acc_test=0.9102
# poison_percent 50 round 88: loss_train=4.2504, acc_train=0.7300, loss_test=0.4258, acc_test=0.9153
# poison_percent 50 round 89: loss_train=4.1932, acc_train=0.7400, loss_test=0.4361, acc_test=0.9092
# poison_percent 50 round 90: loss_train=3.6619, acc_train=0.7700, loss_test=0.4343, acc_test=0.9087
# poison_percent 50 round 91: loss_train=4.0488, acc_train=0.7450, loss_test=0.4354, acc_test=0.9082
# poison_percent 50 round 92: loss_train=4.8241, acc_train=0.6900, loss_test=0.4031, acc_test=0.9168
# poison_percent 50 round 93: loss_train=3.5706, acc_train=0.7700, loss_test=0.4078, acc_test=0.9148
# poison_percent 50 round 94: loss_train=4.5202, acc_train=0.7200, loss_test=0.4047, acc_test=0.9143
# poison_percent 50 round 95: loss_train=4.2306, acc_train=0.7250, loss_test=0.4010, acc_test=0.9148
# poison_percent 50 round 96: loss_train=4.2402, acc_train=0.7350, loss_test=0.3963, acc_test=0.9158
# poison_percent 50 round 97: loss_train=4.3530, acc_train=0.7300, loss_test=0.3953, acc_test=0.9148
# poison_percent 50 round 98: loss_train=3.2260, acc_train=0.8000, loss_test=0.3831, acc_test=0.9189
# poison_percent 50 round 99: loss_train=4.0312, acc_train=0.7500, loss_test=0.3738, acc_test=0.9209
# Training log saved to ./results\FL_ModelN2L2_Batchsize1_rev0\poisoned_50percent\poisoned_50percent.csv
# poison_percent 0 round 0: loss_train=0.5958, acc_train=0.7200, loss_test=0.5683, acc_test=0.9510
# poison_percent 0 round 1: loss_train=0.4149, acc_train=0.9700, loss_test=0.3701, acc_test=0.9959
# poison_percent 0 round 2: loss_train=0.1975, acc_train=1.0000, loss_test=0.1911, acc_test=0.9949
# poison_percent 0 round 3: loss_train=0.1092, acc_train=0.9800, loss_test=0.0887, acc_test=0.9949
# poison_percent 0 round 4: loss_train=0.0435, acc_train=1.0000, loss_test=0.0442, acc_test=0.9964
# poison_percent 0 round 5: loss_train=0.0418, acc_train=0.9900, loss_test=0.0254, acc_test=0.9964
# poison_percent 0 round 6: loss_train=0.0422, acc_train=0.9800, loss_test=0.0165, acc_test=0.9959
# poison_percent 0 round 7: loss_train=0.0127, acc_train=1.0000, loss_test=0.0122, acc_test=0.9964
# poison_percent 0 round 8: loss_train=0.0075, acc_train=1.0000, loss_test=0.0100, acc_test=0.9964
# poison_percent 0 round 9: loss_train=0.0661, acc_train=0.9700, loss_test=0.0087, acc_test=0.9964
# poison_percent 0 round 10: loss_train=0.0036, acc_train=1.0000, loss_test=0.0078, acc_test=0.9969
# poison_percent 0 round 11: loss_train=0.0510, acc_train=0.9900, loss_test=0.0074, acc_test=0.9964
# poison_percent 0 round 12: loss_train=0.0341, acc_train=0.9900, loss_test=0.0071, acc_test=0.9969
# poison_percent 0 round 13: loss_train=0.0008, acc_train=1.0000, loss_test=0.0070, acc_test=0.9969
# poison_percent 0 round 14: loss_train=0.0277, acc_train=0.9900, loss_test=0.0069, acc_test=0.9969
# poison_percent 0 round 15: loss_train=0.0031, acc_train=1.0000, loss_test=0.0069, acc_test=0.9969
# poison_percent 0 round 16: loss_train=0.0012, acc_train=1.0000, loss_test=0.0070, acc_test=0.9974
# poison_percent 0 round 17: loss_train=0.0017, acc_train=1.0000, loss_test=0.0069, acc_test=0.9974
# poison_percent 0 round 18: loss_train=0.0001, acc_train=1.0000, loss_test=0.0072, acc_test=0.9974
# poison_percent 0 round 19: loss_train=0.0003, acc_train=1.0000, loss_test=0.0072, acc_test=0.9974
# poison_percent 0 round 20: loss_train=0.0144, acc_train=0.9900, loss_test=0.0073, acc_test=0.9974
# poison_percent 0 round 21: loss_train=0.0903, acc_train=0.9700, loss_test=0.0074, acc_test=0.9974
# poison_percent 0 round 22: loss_train=0.0453, acc_train=0.9900, loss_test=0.0077, acc_test=0.9974
# poison_percent 0 round 23: loss_train=0.0913, acc_train=0.9900, loss_test=0.0077, acc_test=0.9974
# poison_percent 0 round 24: loss_train=0.0001, acc_train=1.0000, loss_test=0.0078, acc_test=0.9974
# poison_percent 0 round 25: loss_train=0.0002, acc_train=1.0000, loss_test=0.0082, acc_test=0.9974
# poison_percent 0 round 26: loss_train=0.0202, acc_train=0.9900, loss_test=0.0080, acc_test=0.9974
# poison_percent 0 round 27: loss_train=0.0000, acc_train=1.0000, loss_test=0.0082, acc_test=0.9974
# poison_percent 0 round 28: loss_train=0.0660, acc_train=0.9900, loss_test=0.0084, acc_test=0.9974
# poison_percent 0 round 29: loss_train=0.0485, acc_train=0.9900, loss_test=0.0085, acc_test=0.9974
# poison_percent 0 round 30: loss_train=0.0253, acc_train=0.9900, loss_test=0.0087, acc_test=0.9974
# poison_percent 0 round 31: loss_train=0.0000, acc_train=1.0000, loss_test=0.0087, acc_test=0.9980
# poison_percent 0 round 32: loss_train=0.0000, acc_train=1.0000, loss_test=0.0088, acc_test=0.9980
# poison_percent 0 round 33: loss_train=0.0197, acc_train=0.9900, loss_test=0.0085, acc_test=0.9980
# poison_percent 0 round 34: loss_train=0.0000, acc_train=1.0000, loss_test=0.0087, acc_test=0.9980
# poison_percent 0 round 35: loss_train=0.0000, acc_train=1.0000, loss_test=0.0088, acc_test=0.9980
# poison_percent 0 round 36: loss_train=0.0418, acc_train=0.9900, loss_test=0.0089, acc_test=0.9980
# poison_percent 0 round 37: loss_train=0.1180, acc_train=0.9900, loss_test=0.0090, acc_test=0.9980
# poison_percent 0 round 38: loss_train=0.0002, acc_train=1.0000, loss_test=0.0092, acc_test=0.9980
# poison_percent 0 round 39: loss_train=0.0308, acc_train=0.9900, loss_test=0.0091, acc_test=0.9980
# poison_percent 0 round 40: loss_train=0.0904, acc_train=0.9800, loss_test=0.0091, acc_test=0.9980
# poison_percent 0 round 41: loss_train=0.0333, acc_train=0.9900, loss_test=0.0088, acc_test=0.9980
# poison_percent 0 round 42: loss_train=0.0001, acc_train=1.0000, loss_test=0.0091, acc_test=0.9980
# poison_percent 0 round 43: loss_train=0.1630, acc_train=0.9900, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 44: loss_train=0.0498, acc_train=0.9900, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 45: loss_train=0.0000, acc_train=1.0000, loss_test=0.0092, acc_test=0.9980
# poison_percent 0 round 46: loss_train=0.0000, acc_train=1.0000, loss_test=0.0094, acc_test=0.9980
# poison_percent 0 round 47: loss_train=0.0447, acc_train=0.9900, loss_test=0.0095, acc_test=0.9980
# poison_percent 0 round 48: loss_train=0.0408, acc_train=0.9900, loss_test=0.0094, acc_test=0.9980
# poison_percent 0 round 49: loss_train=0.0001, acc_train=1.0000, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 50: loss_train=0.0002, acc_train=1.0000, loss_test=0.0091, acc_test=0.9980
# poison_percent 0 round 51: loss_train=0.0011, acc_train=1.0000, loss_test=0.0092, acc_test=0.9980
# poison_percent 0 round 52: loss_train=0.0172, acc_train=0.9900, loss_test=0.0094, acc_test=0.9980
# poison_percent 0 round 53: loss_train=0.0300, acc_train=0.9900, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 54: loss_train=0.0129, acc_train=0.9900, loss_test=0.0091, acc_test=0.9980
# poison_percent 0 round 55: loss_train=0.0000, acc_train=1.0000, loss_test=0.0091, acc_test=0.9980
# poison_percent 0 round 56: loss_train=0.0000, acc_train=1.0000, loss_test=0.0091, acc_test=0.9980
# poison_percent 0 round 57: loss_train=0.0000, acc_train=1.0000, loss_test=0.0094, acc_test=0.9980
# poison_percent 0 round 58: loss_train=0.0000, acc_train=1.0000, loss_test=0.0094, acc_test=0.9980
# poison_percent 0 round 59: loss_train=0.0930, acc_train=0.9900, loss_test=0.0092, acc_test=0.9980
# poison_percent 0 round 60: loss_train=0.0001, acc_train=1.0000, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 61: loss_train=0.0000, acc_train=1.0000, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 62: loss_train=0.0196, acc_train=0.9900, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 63: loss_train=0.1594, acc_train=0.9900, loss_test=0.0094, acc_test=0.9980
# poison_percent 0 round 64: loss_train=0.0001, acc_train=1.0000, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 65: loss_train=0.0004, acc_train=1.0000, loss_test=0.0094, acc_test=0.9980
# poison_percent 0 round 66: loss_train=0.0046, acc_train=1.0000, loss_test=0.0094, acc_test=0.9980
# poison_percent 0 round 67: loss_train=0.0217, acc_train=0.9900, loss_test=0.0094, acc_test=0.9980
# poison_percent 0 round 68: loss_train=0.0000, acc_train=1.0000, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 69: loss_train=0.0000, acc_train=1.0000, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 70: loss_train=0.0000, acc_train=1.0000, loss_test=0.0094, acc_test=0.9980
# poison_percent 0 round 71: loss_train=0.0005, acc_train=1.0000, loss_test=0.0094, acc_test=0.9980
# poison_percent 0 round 72: loss_train=0.0209, acc_train=0.9900, loss_test=0.0094, acc_test=0.9980
# poison_percent 0 round 73: loss_train=0.0030, acc_train=1.0000, loss_test=0.0092, acc_test=0.9980
# poison_percent 0 round 74: loss_train=0.0000, acc_train=1.0000, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 75: loss_train=0.0000, acc_train=1.0000, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 76: loss_train=0.0000, acc_train=1.0000, loss_test=0.0092, acc_test=0.9980
# poison_percent 0 round 77: loss_train=0.0000, acc_train=1.0000, loss_test=0.0091, acc_test=0.9974
# poison_percent 0 round 78: loss_train=0.0295, acc_train=0.9900, loss_test=0.0092, acc_test=0.9974
# poison_percent 0 round 79: loss_train=0.0000, acc_train=1.0000, loss_test=0.0091, acc_test=0.9974
# poison_percent 0 round 80: loss_train=0.0000, acc_train=1.0000, loss_test=0.0092, acc_test=0.9980
# poison_percent 0 round 81: loss_train=0.0260, acc_train=0.9900, loss_test=0.0092, acc_test=0.9980
# poison_percent 0 round 82: loss_train=0.0161, acc_train=0.9900, loss_test=0.0092, acc_test=0.9974
# poison_percent 0 round 83: loss_train=0.1386, acc_train=0.9900, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 84: loss_train=0.0000, acc_train=1.0000, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 85: loss_train=0.0000, acc_train=1.0000, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 86: loss_train=0.0000, acc_train=1.0000, loss_test=0.0092, acc_test=0.9980
# poison_percent 0 round 87: loss_train=0.0000, acc_train=1.0000, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 88: loss_train=0.0000, acc_train=1.0000, loss_test=0.0092, acc_test=0.9980
# poison_percent 0 round 89: loss_train=0.0077, acc_train=0.9900, loss_test=0.0093, acc_test=0.9980
# poison_percent 0 round 90: loss_train=0.0000, acc_train=1.0000, loss_test=0.0091, acc_test=0.9974
# poison_percent 0 round 91: loss_train=0.0000, acc_train=1.0000, loss_test=0.0091, acc_test=0.9974
# poison_percent 0 round 92: loss_train=0.0000, acc_train=1.0000, loss_test=0.0092, acc_test=0.9974
# poison_percent 0 round 93: loss_train=0.0000, acc_train=1.0000, loss_test=0.0092, acc_test=0.9980
# poison_percent 0 round 94: loss_train=0.0000, acc_train=1.0000, loss_test=0.0092, acc_test=0.9980
# poison_percent 0 round 95: loss_train=0.0007, acc_train=1.0000, loss_test=0.0093, acc_test=0.9980
