# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    model = MNISTNet().to(device)
    model.load_state_dict(global_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end]
            yb = y_c_tensor[start:end]
            outputs = model(xb)
            preds = (outputs >= 0.5).float()
            loss = binary_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # Return a deepcopy to avoid issues with state_dict references
    return copy.deepcopy(model.state_dict()), X_c_tensor.size(0), yb, outputs, preds

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 32
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_binary_poison/train"
TEST_PATH = "../data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
for NODE in [4,8,16,32]:#[1,2,4,8,16,32]:
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, 1)
            self.relu = nn.ReLU()
        def forward(self, x):
            x = self.fc1(x)
            x = self.relu(x)
            x = self.fc2(x)
            x = torch.sigmoid(x)
            return x

    BATCH_SIZE_list = [BATCH_SIZE]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        global_model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"FL_ModelN{NODE}L2_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                # local_epoch = # 29 image x 2 class x 100+i_poisoned clents / 32 batch_size / 100+i_poisoned clents
                LOCAL_EPOCHS = max(1, (29 * 2 * (N_HONEST + i_poisoned)) // (experiment_bs * (N_HONEST + i_poisoned)))
                
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                torch.save(global_model, os.path.join(save_path,'model_init.pt'))
                global_weights = global_model.state_dict()

                records = []

                X_train_tensor = {}
                y_train_tensor = {}
                for i in range(N_HONEST):
                    X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"honest_{i}"] = X_c_tensor
                    y_train_tensor[f"honest_{i}"] = y_c_tensor
                for i in range(i_poisoned):
                    X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"poison_{i}"] = X_c_tensor
                    y_train_tensor[f"poison_{i}"] = y_c_tensor

                # Training loop
                for round in range(ROUNDS):
                    # Prepare arguments for honest clients
                    
                    #randomize the training data
                    for i in range(N_HONEST):
                        perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                        X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                        y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                    honest_args = [
                        (
                            X_train_tensor[f"honest_{i}"],
                            y_train_tensor[f"honest_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(N_HONEST)
                    ]

                    # Prepare arguments for poisoned clients
                    
                    #randomize the training data
                    for i in range(i_poisoned):
                        perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                        X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                        y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                    poison_args = [
                        (
                            X_train_tensor[f"poison_{i}"],
                            y_train_tensor[f"poison_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(i_poisoned)
                    ]

                    # Run in parallel
                    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                        honest_results = list(executor.map(train_local_worker, honest_args))
                        poison_results = list(executor.map(train_local_worker, poison_args))

                    local_weights = []
                    local_sizes = []
                    local_y = []
                    local_outputs = []
                    local_preds = []
                    for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                        local_weights.append(l_w)
                        local_sizes.append(l_sz)
                        local_y.extend(l_y)
                        local_outputs.extend(l_out)
                        local_preds.extend(l_pred)
                    loss_train = binary_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                    acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                    # Federated averaging (weighted by client data size)
                    new_weights = {}
                    for key in global_weights.keys():
                        new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                    global_weights = new_weights
                    global_model.load_state_dict(global_weights)

                    # Evaluate
                    global_model.eval()
                    with torch.no_grad():
                        outputs = global_model(X_test_tensor)
                        preds = (outputs > 0.5).float()
                        loss_test = binary_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'round': round, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"round {round}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(global_model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['round'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['round'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 round 0: loss_train=0.6713, acc_train=0.5688, loss_test=0.6568, acc_test=0.6480
# poison_percent 0 round 1: loss_train=0.6480, acc_train=0.7123, loss_test=0.6360, acc_test=0.7842
# poison_percent 0 round 2: loss_train=0.6248, acc_train=0.8358, loss_test=0.6137, acc_test=0.8643
# poison_percent 0 round 3: loss_train=0.6036, acc_train=0.9058, loss_test=0.5902, acc_test=0.9255
# poison_percent 0 round 4: loss_train=0.5789, acc_train=0.9500, loss_test=0.5629, acc_test=0.9689
# poison_percent 0 round 5: loss_train=0.5525, acc_train=0.9738, loss_test=0.5317, acc_test=0.9867
# poison_percent 0 round 6: loss_train=0.5206, acc_train=0.9881, loss_test=0.4992, acc_test=0.9934
# poison_percent 0 round 7: loss_train=0.4894, acc_train=0.9908, loss_test=0.4672, acc_test=0.9949
# poison_percent 0 round 8: loss_train=0.4587, acc_train=0.9885, loss_test=0.4367, acc_test=0.9954
# poison_percent 0 round 9: loss_train=0.4293, acc_train=0.9904, loss_test=0.4078, acc_test=0.9949
# poison_percent 0 round 10: loss_train=0.4011, acc_train=0.9900, loss_test=0.3808, acc_test=0.9949
# poison_percent 0 round 11: loss_train=0.3752, acc_train=0.9908, loss_test=0.3556, acc_test=0.9954
# poison_percent 0 round 12: loss_train=0.3512, acc_train=0.9904, loss_test=0.3320, acc_test=0.9954
# poison_percent 0 round 13: loss_train=0.3286, acc_train=0.9873, loss_test=0.3099, acc_test=0.9954
# poison_percent 0 round 14: loss_train=0.3096, acc_train=0.9877, loss_test=0.2893, acc_test=0.9954
# poison_percent 0 round 15: loss_train=0.2869, acc_train=0.9896, loss_test=0.2700, acc_test=0.9954
# poison_percent 0 round 16: loss_train=0.2684, acc_train=0.9892, loss_test=0.2520, acc_test=0.9954
# poison_percent 0 round 17: loss_train=0.2512, acc_train=0.9869, loss_test=0.2351, acc_test=0.9959
# poison_percent 0 round 18: loss_train=0.2324, acc_train=0.9900, loss_test=0.2193, acc_test=0.9964
# poison_percent 0 round 19: loss_train=0.2217, acc_train=0.9881, loss_test=0.2047, acc_test=0.9964
# poison_percent 0 round 20: loss_train=0.2067, acc_train=0.9888, loss_test=0.1910, acc_test=0.9964
# poison_percent 0 round 21: loss_train=0.1937, acc_train=0.9919, loss_test=0.1782, acc_test=0.9964
# poison_percent 0 round 22: loss_train=0.1803, acc_train=0.9904, loss_test=0.1662, acc_test=0.9964
# poison_percent 0 round 23: loss_train=0.1705, acc_train=0.9892, loss_test=0.1552, acc_test=0.9964
# poison_percent 0 round 24: loss_train=0.1573, acc_train=0.9931, loss_test=0.1448, acc_test=0.9969
# poison_percent 0 round 25: loss_train=0.1495, acc_train=0.9904, loss_test=0.1351, acc_test=0.9969
# poison_percent 0 round 26: loss_train=0.1393, acc_train=0.9919, loss_test=0.1260, acc_test=0.9969
# poison_percent 0 round 27: loss_train=0.1315, acc_train=0.9935, loss_test=0.1176, acc_test=0.9969
# poison_percent 0 round 28: loss_train=0.1214, acc_train=0.9927, loss_test=0.1098, acc_test=0.9969
# poison_percent 0 round 29: loss_train=0.1117, acc_train=0.9919, loss_test=0.1025, acc_test=0.9969
# poison_percent 0 round 30: loss_train=0.1062, acc_train=0.9931, loss_test=0.0957, acc_test=0.9969
# poison_percent 0 round 31: loss_train=0.0973, acc_train=0.9954, loss_test=0.0894, acc_test=0.9969
# poison_percent 0 round 32: loss_train=0.0934, acc_train=0.9946, loss_test=0.0835, acc_test=0.9969
# poison_percent 0 round 33: loss_train=0.0877, acc_train=0.9950, loss_test=0.0780, acc_test=0.9969
# poison_percent 0 round 34: loss_train=0.0815, acc_train=0.9931, loss_test=0.0729, acc_test=0.9969
# poison_percent 0 round 35: loss_train=0.0752, acc_train=0.9950, loss_test=0.0682, acc_test=0.9974
# poison_percent 0 round 36: loss_train=0.0727, acc_train=0.9938, loss_test=0.0638, acc_test=0.9974
# poison_percent 0 round 37: loss_train=0.0677, acc_train=0.9942, loss_test=0.0596, acc_test=0.9980
# poison_percent 0 round 38: loss_train=0.0640, acc_train=0.9935, loss_test=0.0558, acc_test=0.9980
# poison_percent 0 round 39: loss_train=0.0626, acc_train=0.9938, loss_test=0.0522, acc_test=0.9980
# poison_percent 0 round 40: loss_train=0.0569, acc_train=0.9946, loss_test=0.0489, acc_test=0.9980
# poison_percent 0 round 41: loss_train=0.0524, acc_train=0.9958, loss_test=0.0458, acc_test=0.9980
# poison_percent 0 round 42: loss_train=0.0488, acc_train=0.9965, loss_test=0.0429, acc_test=0.9980
# poison_percent 0 round 43: loss_train=0.0479, acc_train=0.9958, loss_test=0.0402, acc_test=0.9980
# poison_percent 0 round 44: loss_train=0.0441, acc_train=0.9958, loss_test=0.0377, acc_test=0.9980
# poison_percent 0 round 45: loss_train=0.0403, acc_train=0.9965, loss_test=0.0354, acc_test=0.9980
# poison_percent 0 round 46: loss_train=0.0408, acc_train=0.9965, loss_test=0.0332, acc_test=0.9980
# poison_percent 0 round 47: loss_train=0.0398, acc_train=0.9942, loss_test=0.0312, acc_test=0.9980
# poison_percent 0 round 48: loss_train=0.0363, acc_train=0.9965, loss_test=0.0294, acc_test=0.9980
# poison_percent 0 round 49: loss_train=0.0367, acc_train=0.9958, loss_test=0.0276, acc_test=0.9980
# poison_percent 0 round 50: loss_train=0.0322, acc_train=0.9962, loss_test=0.0260, acc_test=0.9980
# poison_percent 0 round 51: loss_train=0.0318, acc_train=0.9958, loss_test=0.0245, acc_test=0.9985
# poison_percent 0 round 52: loss_train=0.0323, acc_train=0.9950, loss_test=0.0231, acc_test=0.9985
# poison_percent 0 round 53: loss_train=0.0327, acc_train=0.9946, loss_test=0.0218, acc_test=0.9985
# poison_percent 0 round 54: loss_train=0.0286, acc_train=0.9950, loss_test=0.0205, acc_test=0.9985
# poison_percent 0 round 55: loss_train=0.0253, acc_train=0.9969, loss_test=0.0194, acc_test=0.9985
# poison_percent 0 round 56: loss_train=0.0240, acc_train=0.9958, loss_test=0.0183, acc_test=0.9985
# poison_percent 0 round 57: loss_train=0.0229, acc_train=0.9962, loss_test=0.0174, acc_test=0.9985
# poison_percent 0 round 58: loss_train=0.0242, acc_train=0.9962, loss_test=0.0164, acc_test=0.9985
# poison_percent 0 round 59: loss_train=0.0209, acc_train=0.9969, loss_test=0.0156, acc_test=0.9985
# poison_percent 0 round 60: loss_train=0.0252, acc_train=0.9954, loss_test=0.0148, acc_test=0.9990
# poison_percent 0 round 61: loss_train=0.0175, acc_train=0.9965, loss_test=0.0140, acc_test=0.9990
# poison_percent 0 round 62: loss_train=0.0188, acc_train=0.9973, loss_test=0.0133, acc_test=0.9990
# poison_percent 0 round 63: loss_train=0.0182, acc_train=0.9965, loss_test=0.0127, acc_test=0.9990
# poison_percent 0 round 64: loss_train=0.0170, acc_train=0.9969, loss_test=0.0121, acc_test=0.9990
# poison_percent 0 round 65: loss_train=0.0181, acc_train=0.9958, loss_test=0.0115, acc_test=0.9990
# poison_percent 0 round 66: loss_train=0.0158, acc_train=0.9969, loss_test=0.0110, acc_test=0.9990
# poison_percent 0 round 67: loss_train=0.0157, acc_train=0.9969, loss_test=0.0105, acc_test=0.9990
# poison_percent 0 round 68: loss_train=0.0182, acc_train=0.9958, loss_test=0.0100, acc_test=0.9990
# poison_percent 0 round 69: loss_train=0.0186, acc_train=0.9962, loss_test=0.0096, acc_test=0.9990
# poison_percent 0 round 70: loss_train=0.0140, acc_train=0.9969, loss_test=0.0092, acc_test=0.9990
# poison_percent 0 round 71: loss_train=0.0145, acc_train=0.9969, loss_test=0.0089, acc_test=0.9990
# poison_percent 0 round 72: loss_train=0.0118, acc_train=0.9981, loss_test=0.0085, acc_test=0.9990
# poison_percent 0 round 73: loss_train=0.0157, acc_train=0.9965, loss_test=0.0082, acc_test=0.9990
# poison_percent 0 round 74: loss_train=0.0138, acc_train=0.9969, loss_test=0.0079, acc_test=0.9990
# poison_percent 0 round 75: loss_train=0.0117, acc_train=0.9977, loss_test=0.0076, acc_test=0.9990
# poison_percent 0 round 76: loss_train=0.0120, acc_train=0.9973, loss_test=0.0073, acc_test=0.9990
# poison_percent 0 round 77: loss_train=0.0130, acc_train=0.9977, loss_test=0.0070, acc_test=0.9990
# poison_percent 0 round 78: loss_train=0.0121, acc_train=0.9977, loss_test=0.0068, acc_test=0.9990
# poison_percent 0 round 79: loss_train=0.0142, acc_train=0.9958, loss_test=0.0066, acc_test=0.9990
# poison_percent 0 round 80: loss_train=0.0127, acc_train=0.9969, loss_test=0.0064, acc_test=0.9990
# poison_percent 0 round 81: loss_train=0.0105, acc_train=0.9973, loss_test=0.0062, acc_test=0.9990
# poison_percent 0 round 82: loss_train=0.0139, acc_train=0.9965, loss_test=0.0060, acc_test=0.9990
# poison_percent 0 round 83: loss_train=0.0169, acc_train=0.9950, loss_test=0.0058, acc_test=0.9990
# poison_percent 0 round 84: loss_train=0.0161, acc_train=0.9954, loss_test=0.0056, acc_test=0.9990
# poison_percent 0 round 85: loss_train=0.0136, acc_train=0.9962, loss_test=0.0055, acc_test=0.9990
# poison_percent 0 round 86: loss_train=0.0129, acc_train=0.9962, loss_test=0.0053, acc_test=0.9990
# poison_percent 0 round 87: loss_train=0.0175, acc_train=0.9946, loss_test=0.0052, acc_test=0.9990
# poison_percent 0 round 88: loss_train=0.0150, acc_train=0.9958, loss_test=0.0051, acc_test=0.9990
# poison_percent 0 round 89: loss_train=0.0162, acc_train=0.9954, loss_test=0.0049, acc_test=0.9990
# poison_percent 0 round 90: loss_train=0.0131, acc_train=0.9965, loss_test=0.0048, acc_test=0.9990
# poison_percent 0 round 91: loss_train=0.0075, acc_train=0.9977, loss_test=0.0047, acc_test=0.9990
# poison_percent 0 round 92: loss_train=0.0094, acc_train=0.9973, loss_test=0.0046, acc_test=0.9990
# poison_percent 0 round 93: loss_train=0.0078, acc_train=0.9981, loss_test=0.0045, acc_test=0.9990
# poison_percent 0 round 94: loss_train=0.0077, acc_train=0.9977, loss_test=0.0044, acc_test=0.9990
# poison_percent 0 round 95: loss_train=0.0086, acc_train=0.9973, loss_test=0.0043, acc_test=0.9990
# poison_percent 0 round 96: loss_train=0.0086, acc_train=0.9969, loss_test=0.0042, acc_test=0.9990
# poison_percent 0 round 97: loss_train=0.0125, acc_train=0.9958, loss_test=0.0041, acc_test=0.9990
# poison_percent 0 round 98: loss_train=0.0079, acc_train=0.9981, loss_test=0.0041, acc_test=0.9990
# poison_percent 0 round 99: loss_train=0.0100, acc_train=0.9969, loss_test=0.0040, acc_test=0.9990
# Training log saved to ./results\FL_ModelN4L2_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 round 0: loss_train=0.9089, acc_train=0.8894, loss_test=0.0039, acc_test=0.9990
# poison_percent 10 round 1: loss_train=0.9044, acc_train=0.8908, loss_test=0.0038, acc_test=0.9990
# poison_percent 10 round 2: loss_train=0.9149, acc_train=0.8905, loss_test=0.0038, acc_test=0.9990
# poison_percent 10 round 3: loss_train=0.9140, acc_train=0.8901, loss_test=0.0037, acc_test=0.9990
# poison_percent 10 round 4: loss_train=0.9283, acc_train=0.8911, loss_test=0.0037, acc_test=0.9990
# poison_percent 10 round 5: loss_train=0.9404, acc_train=0.8915, loss_test=0.0036, acc_test=0.9990
# poison_percent 10 round 6: loss_train=0.9512, acc_train=0.8898, loss_test=0.0036, acc_test=0.9990
# poison_percent 10 round 7: loss_train=0.9754, acc_train=0.8887, loss_test=0.0035, acc_test=0.9990
# poison_percent 10 round 8: loss_train=0.9656, acc_train=0.8894, loss_test=0.0035, acc_test=0.9990
# poison_percent 10 round 9: loss_train=0.9609, acc_train=0.8911, loss_test=0.0035, acc_test=0.9990
# poison_percent 10 round 10: loss_train=0.9638, acc_train=0.8905, loss_test=0.0034, acc_test=0.9990
# poison_percent 10 round 11: loss_train=0.9710, acc_train=0.8905, loss_test=0.0034, acc_test=0.9990
# poison_percent 10 round 12: loss_train=0.9778, acc_train=0.8908, loss_test=0.0033, acc_test=0.9990
# poison_percent 10 round 13: loss_train=0.9868, acc_train=0.8911, loss_test=0.0033, acc_test=0.9990
# poison_percent 10 round 14: loss_train=0.9906, acc_train=0.8905, loss_test=0.0033, acc_test=0.9990
# poison_percent 10 round 15: loss_train=0.9866, acc_train=0.8905, loss_test=0.0032, acc_test=0.9990
# poison_percent 10 round 16: loss_train=1.0238, acc_train=0.8891, loss_test=0.0032, acc_test=0.9990
# poison_percent 10 round 17: loss_train=0.9865, acc_train=0.8905, loss_test=0.0032, acc_test=0.9990
# poison_percent 10 round 18: loss_train=1.0257, acc_train=0.8901, loss_test=0.0031, acc_test=0.9990
# poison_percent 10 round 19: loss_train=1.0396, acc_train=0.8905, loss_test=0.0031, acc_test=0.9990
# poison_percent 10 round 20: loss_train=1.0288, acc_train=0.8901, loss_test=0.0031, acc_test=0.9990
# poison_percent 10 round 21: loss_train=1.0542, acc_train=0.8918, loss_test=0.0031, acc_test=0.9990
# poison_percent 10 round 22: loss_train=1.0480, acc_train=0.8908, loss_test=0.0030, acc_test=0.9990
# poison_percent 10 round 23: loss_train=1.0729, acc_train=0.8901, loss_test=0.0030, acc_test=0.9990
# poison_percent 10 round 24: loss_train=1.0573, acc_train=0.8918, loss_test=0.0030, acc_test=0.9990
# poison_percent 10 round 25: loss_train=1.0787, acc_train=0.8911, loss_test=0.0030, acc_test=0.9990
# poison_percent 10 round 26: loss_train=1.0575, acc_train=0.8894, loss_test=0.0030, acc_test=0.9990
# poison_percent 10 round 27: loss_train=1.0841, acc_train=0.8911, loss_test=0.0029, acc_test=0.9990
# poison_percent 10 round 28: loss_train=1.0578, acc_train=0.8918, loss_test=0.0029, acc_test=0.9990
# poison_percent 10 round 29: loss_train=1.0775, acc_train=0.8908, loss_test=0.0029, acc_test=0.9990
# poison_percent 10 round 30: loss_train=1.0773, acc_train=0.8911, loss_test=0.0029, acc_test=0.9990
# poison_percent 10 round 31: loss_train=1.1088, acc_train=0.8894, loss_test=0.0029, acc_test=0.9990
# poison_percent 10 round 32: loss_train=1.1023, acc_train=0.8908, loss_test=0.0029, acc_test=0.9990
# poison_percent 10 round 33: loss_train=1.1287, acc_train=0.8905, loss_test=0.0028, acc_test=0.9990
# poison_percent 10 round 34: loss_train=1.0976, acc_train=0.8911, loss_test=0.0028, acc_test=0.9990
# poison_percent 10 round 35: loss_train=1.1101, acc_train=0.8911, loss_test=0.0028, acc_test=0.9990
# poison_percent 10 round 36: loss_train=1.1400, acc_train=0.8891, loss_test=0.0028, acc_test=0.9990
# poison_percent 10 round 37: loss_train=1.1447, acc_train=0.8905, loss_test=0.0028, acc_test=0.9990
# poison_percent 10 round 38: loss_train=1.1446, acc_train=0.8915, loss_test=0.0028, acc_test=0.9990
# poison_percent 10 round 39: loss_train=1.1439, acc_train=0.8905, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 40: loss_train=1.1446, acc_train=0.8908, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 41: loss_train=1.1509, acc_train=0.8911, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 42: loss_train=1.1659, acc_train=0.8911, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 43: loss_train=1.1825, acc_train=0.8901, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 44: loss_train=1.1925, acc_train=0.8911, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 45: loss_train=1.1873, acc_train=0.8918, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 46: loss_train=1.1942, acc_train=0.8905, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 47: loss_train=1.1914, acc_train=0.8898, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 48: loss_train=1.2060, acc_train=0.8901, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 49: loss_train=1.2141, acc_train=0.8905, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 50: loss_train=1.2005, acc_train=0.8908, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 51: loss_train=1.2083, acc_train=0.8915, loss_test=0.0027, acc_test=0.9990
# poison_percent 10 round 52: loss_train=1.2439, acc_train=0.8905, loss_test=0.0026, acc_test=0.9990
# poison_percent 10 round 53: loss_train=1.2398, acc_train=0.8901, loss_test=0.0026, acc_test=0.9990
# poison_percent 10 round 54: loss_train=1.2383, acc_train=0.8894, loss_test=0.0026, acc_test=0.9990
# poison_percent 10 round 55: loss_train=1.2609, acc_train=0.8901, loss_test=0.0026, acc_test=0.9990
# poison_percent 10 round 56: loss_train=1.2369, acc_train=0.8922, loss_test=0.0026, acc_test=0.9990
# poison_percent 10 round 57: loss_train=1.2747, acc_train=0.8908, loss_test=0.0026, acc_test=0.9990
# poison_percent 10 round 58: loss_train=1.2666, acc_train=0.8918, loss_test=0.0026, acc_test=0.9990
# poison_percent 10 round 59: loss_train=1.2746, acc_train=0.8915, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 60: loss_train=1.2552, acc_train=0.8911, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 61: loss_train=1.2820, acc_train=0.8905, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 62: loss_train=1.2900, acc_train=0.8901, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 63: loss_train=1.2985, acc_train=0.8905, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 64: loss_train=1.3067, acc_train=0.8915, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 65: loss_train=1.2907, acc_train=0.8911, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 66: loss_train=1.3161, acc_train=0.8908, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 67: loss_train=1.3060, acc_train=0.8908, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 68: loss_train=1.3262, acc_train=0.8908, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 69: loss_train=1.3191, acc_train=0.8908, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 70: loss_train=1.3541, acc_train=0.8905, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 71: loss_train=1.3376, acc_train=0.8905, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 72: loss_train=1.3301, acc_train=0.8908, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 73: loss_train=1.3529, acc_train=0.8911, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 74: loss_train=1.3173, acc_train=0.8922, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 75: loss_train=1.3289, acc_train=0.8901, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 76: loss_train=1.3546, acc_train=0.8925, loss_test=0.0025, acc_test=0.9990
# poison_percent 10 round 77: loss_train=1.3543, acc_train=0.8915, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 78: loss_train=1.3767, acc_train=0.8905, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 79: loss_train=1.3713, acc_train=0.8911, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 80: loss_train=1.3688, acc_train=0.8898, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 81: loss_train=1.3936, acc_train=0.8901, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 82: loss_train=1.3787, acc_train=0.8905, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 83: loss_train=1.3993, acc_train=0.8908, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 84: loss_train=1.4019, acc_train=0.8922, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 85: loss_train=1.3915, acc_train=0.8911, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 86: loss_train=1.4107, acc_train=0.8905, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 87: loss_train=1.4034, acc_train=0.8911, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 88: loss_train=1.4108, acc_train=0.8918, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 89: loss_train=1.4161, acc_train=0.8911, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 90: loss_train=1.4286, acc_train=0.8915, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 91: loss_train=1.4357, acc_train=0.8915, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 92: loss_train=1.4336, acc_train=0.8898, loss_test=0.0023, acc_test=0.9990
# poison_percent 10 round 93: loss_train=1.4287, acc_train=0.8908, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 94: loss_train=1.4380, acc_train=0.8905, loss_test=0.0023, acc_test=0.9990
# poison_percent 10 round 95: loss_train=1.4612, acc_train=0.8911, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 96: loss_train=1.4553, acc_train=0.8911, loss_test=0.0024, acc_test=0.9990
# poison_percent 10 round 97: loss_train=1.4435, acc_train=0.8918, loss_test=0.0023, acc_test=0.9990
# poison_percent 10 round 98: loss_train=1.4668, acc_train=0.8905, loss_test=0.0023, acc_test=0.9990
# poison_percent 10 round 99: loss_train=1.4657, acc_train=0.8922, loss_test=0.0023, acc_test=0.9990
# Training log saved to ./results\FL_ModelN4L2_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=2.6871, acc_train=0.7991, loss_test=0.0023, acc_test=0.9990
# poison_percent 20 round 1: loss_train=2.7015, acc_train=0.7988, loss_test=0.0023, acc_test=0.9990
# poison_percent 20 round 2: loss_train=2.7446, acc_train=0.7975, loss_test=0.0023, acc_test=0.9990
# poison_percent 20 round 3: loss_train=2.7479, acc_train=0.7982, loss_test=0.0023, acc_test=0.9990
# poison_percent 20 round 4: loss_train=2.7476, acc_train=0.7985, loss_test=0.0023, acc_test=0.9990
# poison_percent 20 round 5: loss_train=2.7169, acc_train=0.7991, loss_test=0.0023, acc_test=0.9990
# poison_percent 20 round 6: loss_train=2.7468, acc_train=0.7997, loss_test=0.0023, acc_test=0.9990
# poison_percent 20 round 7: loss_train=2.7168, acc_train=0.7997, loss_test=0.0022, acc_test=0.9990
# poison_percent 20 round 8: loss_train=2.7325, acc_train=0.7997, loss_test=0.0022, acc_test=0.9990
# poison_percent 20 round 9: loss_train=2.7425, acc_train=0.7997, loss_test=0.0022, acc_test=0.9990
# poison_percent 20 round 10: loss_train=2.7512, acc_train=0.7994, loss_test=0.0022, acc_test=0.9990
# poison_percent 20 round 11: loss_train=2.7978, acc_train=0.7994, loss_test=0.0022, acc_test=0.9990
# poison_percent 20 round 12: loss_train=2.7748, acc_train=0.7991, loss_test=0.0022, acc_test=0.9990
# poison_percent 20 round 13: loss_train=2.7419, acc_train=0.7997, loss_test=0.0022, acc_test=0.9990
# poison_percent 20 round 14: loss_train=2.7713, acc_train=0.7994, loss_test=0.0021, acc_test=0.9990
# poison_percent 20 round 15: loss_train=2.7624, acc_train=0.7985, loss_test=0.0021, acc_test=0.9990
# poison_percent 20 round 16: loss_train=2.7841, acc_train=0.7985, loss_test=0.0021, acc_test=0.9990
# poison_percent 20 round 17: loss_train=2.7902, acc_train=0.7988, loss_test=0.0021, acc_test=0.9990
# poison_percent 20 round 18: loss_train=2.8261, acc_train=0.7991, loss_test=0.0021, acc_test=0.9990
# poison_percent 20 round 19: loss_train=2.7568, acc_train=0.7985, loss_test=0.0021, acc_test=0.9990
# poison_percent 20 round 20: loss_train=2.7844, acc_train=0.7988, loss_test=0.0021, acc_test=0.9990
# poison_percent 20 round 21: loss_train=2.8029, acc_train=0.7988, loss_test=0.0021, acc_test=0.9990
# poison_percent 20 round 22: loss_train=2.8116, acc_train=0.7988, loss_test=0.0021, acc_test=0.9990
# poison_percent 20 round 23: loss_train=2.7994, acc_train=0.7994, loss_test=0.0021, acc_test=0.9990
# poison_percent 20 round 24: loss_train=2.7871, acc_train=0.7997, loss_test=0.0021, acc_test=0.9990
# poison_percent 20 round 25: loss_train=2.8124, acc_train=0.7994, loss_test=0.0021, acc_test=0.9990
# poison_percent 20 round 26: loss_train=2.7901, acc_train=0.7997, loss_test=0.0020, acc_test=0.9990
# poison_percent 20 round 27: loss_train=2.7825, acc_train=0.7994, loss_test=0.0020, acc_test=0.9990
# poison_percent 20 round 28: loss_train=2.8379, acc_train=0.7988, loss_test=0.0020, acc_test=0.9990
# poison_percent 20 round 29: loss_train=2.8619, acc_train=0.7975, loss_test=0.0020, acc_test=0.9990
# poison_percent 20 round 30: loss_train=2.8247, acc_train=0.7997, loss_test=0.0020, acc_test=0.9990
# poison_percent 20 round 31: loss_train=2.8050, acc_train=0.8000, loss_test=0.0020, acc_test=0.9990
# poison_percent 20 round 32: loss_train=2.8464, acc_train=0.8000, loss_test=0.0020, acc_test=0.9995
# poison_percent 20 round 33: loss_train=2.8239, acc_train=0.8006, loss_test=0.0020, acc_test=0.9995
# poison_percent 20 round 34: loss_train=2.8554, acc_train=0.7991, loss_test=0.0020, acc_test=0.9995
# poison_percent 20 round 35: loss_train=2.8493, acc_train=0.8000, loss_test=0.0020, acc_test=0.9995
# poison_percent 20 round 36: loss_train=2.8287, acc_train=0.8000, loss_test=0.0020, acc_test=0.9995
# poison_percent 20 round 37: loss_train=2.8700, acc_train=0.7978, loss_test=0.0020, acc_test=0.9995
# poison_percent 20 round 38: loss_train=2.8717, acc_train=0.7982, loss_test=0.0020, acc_test=0.9995
# poison_percent 20 round 39: loss_train=2.8582, acc_train=0.7994, loss_test=0.0020, acc_test=0.9995
# poison_percent 20 round 40: loss_train=2.8584, acc_train=0.7991, loss_test=0.0020, acc_test=0.9995
# poison_percent 20 round 41: loss_train=2.8685, acc_train=0.7997, loss_test=0.0020, acc_test=0.9995
# poison_percent 20 round 42: loss_train=2.8590, acc_train=0.8000, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 43: loss_train=2.8628, acc_train=0.7994, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 44: loss_train=2.8709, acc_train=0.7991, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 45: loss_train=2.8974, acc_train=0.7997, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 46: loss_train=2.8748, acc_train=0.7997, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 47: loss_train=2.8830, acc_train=0.7982, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 48: loss_train=2.8735, acc_train=0.8003, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 49: loss_train=2.8945, acc_train=0.7991, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 50: loss_train=2.9172, acc_train=0.7978, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 51: loss_train=2.8810, acc_train=0.7994, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 52: loss_train=2.8843, acc_train=0.7978, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 53: loss_train=2.9294, acc_train=0.7978, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 54: loss_train=2.8973, acc_train=0.7988, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 55: loss_train=2.9092, acc_train=0.7991, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 56: loss_train=2.8805, acc_train=0.7997, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 57: loss_train=2.9228, acc_train=0.7994, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 58: loss_train=2.9148, acc_train=0.7985, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 59: loss_train=2.9238, acc_train=0.7988, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 60: loss_train=2.9204, acc_train=0.7994, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 61: loss_train=2.9248, acc_train=0.7994, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 62: loss_train=2.9132, acc_train=0.7997, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 63: loss_train=2.9237, acc_train=0.7994, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 64: loss_train=2.9338, acc_train=0.7991, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 65: loss_train=2.9102, acc_train=0.7978, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 66: loss_train=2.9249, acc_train=0.8000, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 67: loss_train=2.9156, acc_train=0.7994, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 68: loss_train=2.9245, acc_train=0.7994, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 69: loss_train=2.9326, acc_train=0.8000, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 70: loss_train=2.9454, acc_train=0.7994, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 71: loss_train=2.9421, acc_train=0.7982, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 72: loss_train=2.9622, acc_train=0.7985, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 73: loss_train=2.9249, acc_train=0.8000, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 74: loss_train=2.9352, acc_train=0.7985, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 75: loss_train=2.9606, acc_train=0.7991, loss_test=0.0019, acc_test=0.9995
# poison_percent 20 round 76: loss_train=2.9634, acc_train=0.7994, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 77: loss_train=2.9465, acc_train=0.8000, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 78: loss_train=2.9505, acc_train=0.7997, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 79: loss_train=2.9375, acc_train=0.8003, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 80: loss_train=2.9606, acc_train=0.7985, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 81: loss_train=2.9463, acc_train=0.7991, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 82: loss_train=2.9770, acc_train=0.7988, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 83: loss_train=2.9969, acc_train=0.7982, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 84: loss_train=2.9515, acc_train=0.7988, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 85: loss_train=2.9955, acc_train=0.7994, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 86: loss_train=3.0013, acc_train=0.7991, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 87: loss_train=2.9695, acc_train=0.7997, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 88: loss_train=2.9683, acc_train=0.7994, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 89: loss_train=2.9885, acc_train=0.7994, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 90: loss_train=3.0009, acc_train=0.7988, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 91: loss_train=2.9760, acc_train=0.8000, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 92: loss_train=2.9684, acc_train=0.7997, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 93: loss_train=2.9904, acc_train=0.7988, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 94: loss_train=2.9797, acc_train=0.8003, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 95: loss_train=3.0251, acc_train=0.7991, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 96: loss_train=3.0074, acc_train=0.7988, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 97: loss_train=3.0026, acc_train=0.7994, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 98: loss_train=2.9882, acc_train=0.7994, loss_test=0.0018, acc_test=0.9995
# poison_percent 20 round 99: loss_train=3.0068, acc_train=0.7982, loss_test=0.0018, acc_test=0.9995
# Training log saved to ./results\FL_ModelN4L2_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=4.5016, acc_train=0.6993, loss_test=0.0018, acc_test=0.9995
# poison_percent 30 round 1: loss_train=4.5038, acc_train=0.6985, loss_test=0.0018, acc_test=0.9995
# poison_percent 30 round 2: loss_train=4.5095, acc_train=0.6990, loss_test=0.0017, acc_test=0.9995
# poison_percent 30 round 3: loss_train=4.5314, acc_train=0.6990, loss_test=0.0017, acc_test=0.9995
# poison_percent 30 round 4: loss_train=4.5230, acc_train=0.6982, loss_test=0.0017, acc_test=0.9995
# poison_percent 30 round 5: loss_train=4.5663, acc_train=0.6985, loss_test=0.0017, acc_test=0.9995
# poison_percent 30 round 6: loss_train=4.5316, acc_train=0.6982, loss_test=0.0017, acc_test=0.9995
# poison_percent 30 round 7: loss_train=4.5058, acc_train=0.6985, loss_test=0.0016, acc_test=0.9995
# poison_percent 30 round 8: loss_train=4.5264, acc_train=0.6996, loss_test=0.0016, acc_test=0.9995
# poison_percent 30 round 9: loss_train=4.5128, acc_train=0.6996, loss_test=0.0016, acc_test=0.9995
# poison_percent 30 round 10: loss_train=4.4859, acc_train=0.6985, loss_test=0.0016, acc_test=0.9995
# poison_percent 30 round 11: loss_train=4.5004, acc_train=0.6988, loss_test=0.0016, acc_test=0.9995
# poison_percent 30 round 12: loss_train=4.5312, acc_train=0.6996, loss_test=0.0016, acc_test=0.9995
# poison_percent 30 round 13: loss_train=4.5042, acc_train=0.6988, loss_test=0.0016, acc_test=0.9995
# poison_percent 30 round 14: loss_train=4.5373, acc_train=0.6982, loss_test=0.0016, acc_test=0.9995
# poison_percent 30 round 15: loss_train=4.5325, acc_train=0.6993, loss_test=0.0016, acc_test=0.9995
# poison_percent 30 round 16: loss_train=4.5278, acc_train=0.6988, loss_test=0.0015, acc_test=0.9995
# poison_percent 30 round 17: loss_train=4.5207, acc_train=0.6988, loss_test=0.0015, acc_test=0.9995
# poison_percent 30 round 18: loss_train=4.5312, acc_train=0.6988, loss_test=0.0015, acc_test=0.9995
# poison_percent 30 round 19: loss_train=4.5154, acc_train=0.6982, loss_test=0.0015, acc_test=0.9995
# poison_percent 30 round 20: loss_train=4.5387, acc_train=0.6988, loss_test=0.0015, acc_test=0.9995
# poison_percent 30 round 21: loss_train=4.5368, acc_train=0.6985, loss_test=0.0015, acc_test=0.9995
# poison_percent 30 round 22: loss_train=4.5175, acc_train=0.6990, loss_test=0.0015, acc_test=0.9995
# poison_percent 30 round 23: loss_train=4.5375, acc_train=0.6974, loss_test=0.0015, acc_test=0.9995
# poison_percent 30 round 24: loss_train=4.5335, acc_train=0.6990, loss_test=0.0015, acc_test=0.9995
# poison_percent 30 round 25: loss_train=4.5271, acc_train=0.6980, loss_test=0.0015, acc_test=0.9995
# poison_percent 30 round 26: loss_train=4.5113, acc_train=0.6988, loss_test=0.0015, acc_test=0.9995
# poison_percent 30 round 27: loss_train=4.5211, acc_train=0.6993, loss_test=0.0015, acc_test=0.9995
# poison_percent 30 round 28: loss_train=4.5181, acc_train=0.6988, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 29: loss_train=4.5375, acc_train=0.6974, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 30: loss_train=4.5276, acc_train=0.6990, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 31: loss_train=4.5372, acc_train=0.6985, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 32: loss_train=4.5224, acc_train=0.6982, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 33: loss_train=4.5464, acc_train=0.6985, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 34: loss_train=4.5322, acc_train=0.6977, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 35: loss_train=4.5346, acc_train=0.6993, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 36: loss_train=4.5155, acc_train=0.6990, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 37: loss_train=4.5253, acc_train=0.6985, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 38: loss_train=4.5352, acc_train=0.6985, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 39: loss_train=4.5416, acc_train=0.6985, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 40: loss_train=4.5517, acc_train=0.6990, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 41: loss_train=4.5468, acc_train=0.6982, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 42: loss_train=4.5251, acc_train=0.6985, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 43: loss_train=4.5704, acc_train=0.6982, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 44: loss_train=4.5307, acc_train=0.6988, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 45: loss_train=4.5512, acc_train=0.6974, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 46: loss_train=4.5348, acc_train=0.6988, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 47: loss_train=4.5297, acc_train=0.6990, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 48: loss_train=4.5411, acc_train=0.6990, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 49: loss_train=4.5462, acc_train=0.6988, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 50: loss_train=4.5491, acc_train=0.6988, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 51: loss_train=4.5475, acc_train=0.6980, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 52: loss_train=4.5197, acc_train=0.6993, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 53: loss_train=4.5483, acc_train=0.6998, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 54: loss_train=4.5482, acc_train=0.6993, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 55: loss_train=4.5364, acc_train=0.6990, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 56: loss_train=4.5540, acc_train=0.6982, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 57: loss_train=4.5461, acc_train=0.6990, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 58: loss_train=4.5653, acc_train=0.6985, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 59: loss_train=4.5544, acc_train=0.6985, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 60: loss_train=4.5564, acc_train=0.6988, loss_test=0.0014, acc_test=0.9995
# poison_percent 30 round 61: loss_train=4.5617, acc_train=0.6980, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 62: loss_train=4.5702, acc_train=0.6982, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 63: loss_train=4.5461, acc_train=0.6993, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 64: loss_train=4.5413, acc_train=0.6980, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 65: loss_train=4.5399, acc_train=0.6990, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 66: loss_train=4.5383, acc_train=0.6996, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 67: loss_train=4.5731, acc_train=0.6977, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 68: loss_train=4.5536, acc_train=0.6980, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 69: loss_train=4.5507, acc_train=0.6985, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 70: loss_train=4.5559, acc_train=0.6990, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 71: loss_train=4.5362, acc_train=0.6993, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 72: loss_train=4.5597, acc_train=0.6980, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 73: loss_train=4.5502, acc_train=0.6985, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 74: loss_train=4.5639, acc_train=0.6980, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 75: loss_train=4.5625, acc_train=0.6985, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 76: loss_train=4.5421, acc_train=0.6982, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 77: loss_train=4.5443, acc_train=0.6982, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 78: loss_train=4.5640, acc_train=0.6988, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 79: loss_train=4.5787, acc_train=0.6990, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 80: loss_train=4.5620, acc_train=0.6980, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 81: loss_train=4.5633, acc_train=0.6985, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 82: loss_train=4.5660, acc_train=0.6982, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 83: loss_train=4.5468, acc_train=0.6985, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 84: loss_train=4.5622, acc_train=0.6982, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 85: loss_train=4.5639, acc_train=0.6993, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 86: loss_train=4.5628, acc_train=0.6988, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 87: loss_train=4.5960, acc_train=0.6980, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 88: loss_train=4.5493, acc_train=0.6990, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 89: loss_train=4.5784, acc_train=0.6988, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 90: loss_train=4.5787, acc_train=0.6982, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 91: loss_train=4.5448, acc_train=0.6985, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 92: loss_train=4.5783, acc_train=0.6985, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 93: loss_train=4.5757, acc_train=0.6980, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 94: loss_train=4.5824, acc_train=0.6982, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 95: loss_train=4.5368, acc_train=0.6990, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 96: loss_train=4.5369, acc_train=0.6988, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 97: loss_train=4.5678, acc_train=0.6977, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 98: loss_train=4.5914, acc_train=0.6982, loss_test=0.0013, acc_test=0.9995
# poison_percent 30 round 99: loss_train=4.5722, acc_train=0.6985, loss_test=0.0013, acc_test=0.9995
# Training log saved to ./results\FL_ModelN4L2_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=6.1001, acc_train=0.5986, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 1: loss_train=6.1112, acc_train=0.5983, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 2: loss_train=6.0613, acc_train=0.5979, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 3: loss_train=6.1138, acc_train=0.5983, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 4: loss_train=6.0999, acc_train=0.5993, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 5: loss_train=6.1012, acc_train=0.5974, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 6: loss_train=6.0982, acc_train=0.5986, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 7: loss_train=6.1034, acc_train=0.5988, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 8: loss_train=6.1089, acc_train=0.5988, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 9: loss_train=6.0802, acc_train=0.5988, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 10: loss_train=6.0944, acc_train=0.5979, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 11: loss_train=6.0940, acc_train=0.5986, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 12: loss_train=6.0799, acc_train=0.5983, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 13: loss_train=6.0912, acc_train=0.5981, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 14: loss_train=6.0930, acc_train=0.5983, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 15: loss_train=6.0918, acc_train=0.5979, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 16: loss_train=6.0250, acc_train=0.5990, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 17: loss_train=6.0712, acc_train=0.5986, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 18: loss_train=6.0932, acc_train=0.5979, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 19: loss_train=6.0429, acc_train=0.5993, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 20: loss_train=6.0699, acc_train=0.5981, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 21: loss_train=6.0714, acc_train=0.5983, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 22: loss_train=6.0760, acc_train=0.5983, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 23: loss_train=6.0772, acc_train=0.5979, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 24: loss_train=6.0599, acc_train=0.5983, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 25: loss_train=6.0579, acc_train=0.5990, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 26: loss_train=6.0368, acc_train=0.5988, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 27: loss_train=6.0501, acc_train=0.5988, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 28: loss_train=6.0736, acc_train=0.5979, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 29: loss_train=6.0650, acc_train=0.5986, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 30: loss_train=6.0575, acc_train=0.5981, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 31: loss_train=6.0525, acc_train=0.5983, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 32: loss_train=6.0406, acc_train=0.5988, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 33: loss_train=6.0490, acc_train=0.5983, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 34: loss_train=6.0332, acc_train=0.5988, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 35: loss_train=6.0569, acc_train=0.5981, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 36: loss_train=6.0494, acc_train=0.5988, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 37: loss_train=6.0616, acc_train=0.5979, loss_test=0.0011, acc_test=0.9995
# poison_percent 40 round 38: loss_train=6.0591, acc_train=0.5979, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 39: loss_train=6.0632, acc_train=0.5983, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 40: loss_train=6.0402, acc_train=0.5986, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 41: loss_train=6.0409, acc_train=0.5981, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 42: loss_train=6.0379, acc_train=0.5986, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 43: loss_train=6.0139, acc_train=0.5981, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 44: loss_train=6.0498, acc_train=0.5981, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 45: loss_train=6.0057, acc_train=0.5972, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 46: loss_train=6.0420, acc_train=0.5981, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 47: loss_train=6.0270, acc_train=0.5981, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 48: loss_train=6.0268, acc_train=0.5995, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 49: loss_train=6.0077, acc_train=0.5990, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 50: loss_train=6.0192, acc_train=0.5983, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 51: loss_train=6.0161, acc_train=0.5979, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 52: loss_train=6.0368, acc_train=0.5988, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 53: loss_train=6.0228, acc_train=0.5983, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 54: loss_train=5.9962, acc_train=0.5986, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 55: loss_train=6.0242, acc_train=0.5977, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 56: loss_train=6.0130, acc_train=0.5979, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 57: loss_train=6.0112, acc_train=0.5986, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 58: loss_train=6.0050, acc_train=0.5983, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 59: loss_train=6.0199, acc_train=0.5988, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 60: loss_train=6.0008, acc_train=0.5981, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 61: loss_train=6.0000, acc_train=0.5972, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 62: loss_train=5.9926, acc_train=0.5988, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 63: loss_train=5.9947, acc_train=0.5986, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 64: loss_train=5.9893, acc_train=0.5979, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 65: loss_train=5.9894, acc_train=0.5990, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 66: loss_train=5.9851, acc_train=0.5986, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 67: loss_train=5.9889, acc_train=0.5981, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 68: loss_train=6.0263, acc_train=0.5981, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 69: loss_train=6.0168, acc_train=0.5986, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 70: loss_train=5.9899, acc_train=0.5986, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 71: loss_train=5.9864, acc_train=0.5988, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 72: loss_train=6.0087, acc_train=0.5990, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 73: loss_train=5.9707, acc_train=0.5993, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 74: loss_train=5.9790, acc_train=0.5990, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 75: loss_train=5.9794, acc_train=0.5988, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 76: loss_train=6.0095, acc_train=0.5981, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 77: loss_train=5.9748, acc_train=0.5983, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 78: loss_train=5.9577, acc_train=0.5981, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 79: loss_train=5.9667, acc_train=0.5986, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 80: loss_train=5.9735, acc_train=0.5988, loss_test=0.0010, acc_test=0.9995
# poison_percent 40 round 81: loss_train=5.9681, acc_train=0.5981, loss_test=0.0010, acc_test=0.9995
# ...
# poison_percent 40 round 41: loss_train=6.1573, acc_train=0.5988, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 42: loss_train=6.1824, acc_train=0.5988, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 43: loss_train=6.1754, acc_train=0.5983, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 44: loss_train=6.1688, acc_train=0.5983, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 45: loss_train=6.1853, acc_train=0.5988, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 46: loss_train=6.1551, acc_train=0.5990, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 47: loss_train=6.1530, acc_train=0.5990, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 48: loss_train=6.1486, acc_train=0.5990, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 49: loss_train=6.1445, acc_train=0.6000, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 50: loss_train=6.1134, acc_train=0.5983, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 51: loss_train=6.1463, acc_train=0.6000, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 52: loss_train=6.1054, acc_train=0.5990, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 53: loss_train=6.1132, acc_train=0.5990, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 54: loss_train=6.0694, acc_train=0.5997, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 55: loss_train=6.0502, acc_train=0.5986, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 56: loss_train=6.1104, acc_train=0.5988, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 57: loss_train=6.0484, acc_train=0.6002, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 58: loss_train=6.0919, acc_train=0.5986, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 59: loss_train=6.0697, acc_train=0.6000, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 60: loss_train=6.0641, acc_train=0.5995, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 61: loss_train=6.0493, acc_train=0.6002, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 62: loss_train=6.0760, acc_train=0.6000, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 63: loss_train=6.0511, acc_train=0.5995, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 64: loss_train=6.0791, acc_train=0.5977, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 65: loss_train=6.0357, acc_train=0.5990, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 66: loss_train=6.0700, acc_train=0.5988, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 67: loss_train=6.0362, acc_train=0.5993, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 68: loss_train=6.0580, acc_train=0.5988, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 69: loss_train=6.0111, acc_train=0.5995, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 70: loss_train=6.0449, acc_train=0.5993, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 71: loss_train=6.0020, acc_train=0.6002, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 72: loss_train=5.9877, acc_train=0.5995, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 73: loss_train=6.0420, acc_train=0.5988, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 74: loss_train=6.0285, acc_train=0.5981, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 75: loss_train=6.0298, acc_train=0.5983, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 76: loss_train=6.0078, acc_train=0.5993, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 77: loss_train=5.9949, acc_train=0.5995, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 78: loss_train=5.9673, acc_train=0.5990, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 79: loss_train=5.9847, acc_train=0.5995, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 80: loss_train=5.9468, acc_train=0.5995, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 81: loss_train=5.9518, acc_train=0.6006, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 82: loss_train=5.9866, acc_train=0.5990, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 83: loss_train=5.9269, acc_train=0.5995, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 84: loss_train=5.9547, acc_train=0.5981, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 85: loss_train=5.9420, acc_train=0.5990, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 86: loss_train=5.9142, acc_train=0.5986, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 87: loss_train=5.9327, acc_train=0.5993, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 88: loss_train=5.9016, acc_train=0.5990, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 89: loss_train=5.8911, acc_train=0.5995, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 90: loss_train=5.9391, acc_train=0.5986, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 91: loss_train=5.8872, acc_train=0.5993, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 92: loss_train=5.8759, acc_train=0.5995, loss_test=0.0013, acc_test=0.9995
# poison_percent 40 round 93: loss_train=5.8910, acc_train=0.5990, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 94: loss_train=5.8375, acc_train=0.5990, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 95: loss_train=5.8983, acc_train=0.5981, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 96: loss_train=5.8512, acc_train=0.5988, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 97: loss_train=5.8782, acc_train=0.5993, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 98: loss_train=5.8542, acc_train=0.5993, loss_test=0.0012, acc_test=0.9995
# poison_percent 40 round 99: loss_train=5.8428, acc_train=0.5990, loss_test=0.0012, acc_test=0.9995
# Training log saved to ./results\FL_ModelN32L2_Batchsize32_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 round 0: loss_train=7.3020, acc_train=0.5008, loss_test=0.0013, acc_test=0.9995
# poison_percent 50 round 1: loss_train=7.2841, acc_train=0.5002, loss_test=0.0013, acc_test=0.9995
# poison_percent 50 round 2: loss_train=7.2683, acc_train=0.5006, loss_test=0.0013, acc_test=0.9995
# poison_percent 50 round 3: loss_train=7.1857, acc_train=0.5004, loss_test=0.0014, acc_test=0.9995
# poison_percent 50 round 4: loss_train=7.2049, acc_train=0.5012, loss_test=0.0014, acc_test=0.9995
# poison_percent 50 round 5: loss_train=7.1515, acc_train=0.5004, loss_test=0.0015, acc_test=0.9995
# poison_percent 50 round 6: loss_train=7.1093, acc_train=0.5006, loss_test=0.0015, acc_test=0.9995
# poison_percent 50 round 7: loss_train=7.1386, acc_train=0.5010, loss_test=0.0015, acc_test=0.9995
# poison_percent 50 round 8: loss_train=7.0828, acc_train=0.5017, loss_test=0.0016, acc_test=0.9995
# poison_percent 50 round 9: loss_train=7.0182, acc_train=0.5017, loss_test=0.0016, acc_test=0.9995
# poison_percent 50 round 10: loss_train=6.9625, acc_train=0.5019, loss_test=0.0017, acc_test=0.9995
# poison_percent 50 round 11: loss_train=6.9963, acc_train=0.5002, loss_test=0.0017, acc_test=0.9995
# poison_percent 50 round 12: loss_train=6.9317, acc_train=0.5010, loss_test=0.0018, acc_test=0.9995
# poison_percent 50 round 13: loss_train=6.9362, acc_train=0.5013, loss_test=0.0019, acc_test=0.9995
# poison_percent 50 round 14: loss_train=6.8785, acc_train=0.5017, loss_test=0.0019, acc_test=0.9995
# poison_percent 50 round 15: loss_train=6.8683, acc_train=0.5010, loss_test=0.0020, acc_test=0.9995
# poison_percent 50 round 16: loss_train=6.8212, acc_train=0.5017, loss_test=0.0020, acc_test=0.9995
# poison_percent 50 round 17: loss_train=6.7599, acc_train=0.5013, loss_test=0.0021, acc_test=0.9995
# poison_percent 50 round 18: loss_train=6.7293, acc_train=0.5023, loss_test=0.0021, acc_test=0.9995
# poison_percent 50 round 19: loss_train=6.7037, acc_train=0.5012, loss_test=0.0022, acc_test=0.9990
# poison_percent 50 round 20: loss_train=6.6197, acc_train=0.5015, loss_test=0.0023, acc_test=0.9985
# poison_percent 50 round 21: loss_train=6.6132, acc_train=0.5015, loss_test=0.0023, acc_test=0.9985
# poison_percent 50 round 22: loss_train=6.5836, acc_train=0.5008, loss_test=0.0024, acc_test=0.9985
# poison_percent 50 round 23: loss_train=6.5925, acc_train=0.5006, loss_test=0.0024, acc_test=0.9985
# poison_percent 50 round 24: loss_train=6.5045, acc_train=0.5019, loss_test=0.0025, acc_test=0.9985
# poison_percent 50 round 25: loss_train=6.4688, acc_train=0.5008, loss_test=0.0025, acc_test=0.9985
# poison_percent 50 round 26: loss_train=6.4151, acc_train=0.5004, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 27: loss_train=6.3661, acc_train=0.5017, loss_test=0.0027, acc_test=0.9985
# poison_percent 50 round 28: loss_train=6.3353, acc_train=0.5013, loss_test=0.0027, acc_test=0.9985
# poison_percent 50 round 29: loss_train=6.2985, acc_train=0.5015, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 30: loss_train=6.2488, acc_train=0.5013, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 31: loss_train=6.2434, acc_train=0.5013, loss_test=0.0029, acc_test=0.9985
# poison_percent 50 round 32: loss_train=6.1781, acc_train=0.5013, loss_test=0.0029, acc_test=0.9985
# poison_percent 50 round 33: loss_train=6.1194, acc_train=0.5019, loss_test=0.0030, acc_test=0.9985
# poison_percent 50 round 34: loss_train=6.0705, acc_train=0.5006, loss_test=0.0030, acc_test=0.9985
# poison_percent 50 round 35: loss_train=6.0065, acc_train=0.5013, loss_test=0.0030, acc_test=0.9985
# poison_percent 50 round 36: loss_train=5.9216, acc_train=0.5010, loss_test=0.0031, acc_test=0.9985
# poison_percent 50 round 37: loss_train=5.9530, acc_train=0.5010, loss_test=0.0031, acc_test=0.9985
# poison_percent 50 round 38: loss_train=5.8831, acc_train=0.5013, loss_test=0.0032, acc_test=0.9985
# poison_percent 50 round 39: loss_train=5.8476, acc_train=0.5006, loss_test=0.0032, acc_test=0.9985
# poison_percent 50 round 40: loss_train=5.8289, acc_train=0.5012, loss_test=0.0032, acc_test=0.9985
# poison_percent 50 round 41: loss_train=5.7386, acc_train=0.5019, loss_test=0.0033, acc_test=0.9985
# poison_percent 50 round 42: loss_train=5.7230, acc_train=0.5010, loss_test=0.0033, acc_test=0.9985
# poison_percent 50 round 43: loss_train=5.6693, acc_train=0.5017, loss_test=0.0034, acc_test=0.9985
# poison_percent 50 round 44: loss_train=5.5915, acc_train=0.5019, loss_test=0.0034, acc_test=0.9985
# poison_percent 50 round 45: loss_train=5.5047, acc_train=0.5012, loss_test=0.0034, acc_test=0.9985
# poison_percent 50 round 46: loss_train=5.5489, acc_train=0.5006, loss_test=0.0035, acc_test=0.9985
# poison_percent 50 round 47: loss_train=5.4236, acc_train=0.5012, loss_test=0.0035, acc_test=0.9985
# poison_percent 50 round 48: loss_train=5.3941, acc_train=0.5012, loss_test=0.0036, acc_test=0.9985
# poison_percent 50 round 49: loss_train=5.4051, acc_train=0.5013, loss_test=0.0036, acc_test=0.9985
# poison_percent 50 round 50: loss_train=5.3221, acc_train=0.5017, loss_test=0.0036, acc_test=0.9985
# poison_percent 50 round 51: loss_train=5.3554, acc_train=0.5012, loss_test=0.0037, acc_test=0.9985
# poison_percent 50 round 52: loss_train=5.2881, acc_train=0.5015, loss_test=0.0037, acc_test=0.9985
# poison_percent 50 round 53: loss_train=5.2074, acc_train=0.5008, loss_test=0.0038, acc_test=0.9985
# poison_percent 50 round 54: loss_train=5.2085, acc_train=0.5004, loss_test=0.0038, acc_test=0.9985
# poison_percent 50 round 55: loss_train=5.1369, acc_train=0.5006, loss_test=0.0039, acc_test=0.9985
# poison_percent 50 round 56: loss_train=5.1027, acc_train=0.5010, loss_test=0.0039, acc_test=0.9985
# poison_percent 50 round 57: loss_train=5.0752, acc_train=0.5008, loss_test=0.0040, acc_test=0.9985
# poison_percent 50 round 58: loss_train=5.0386, acc_train=0.5004, loss_test=0.0040, acc_test=0.9985
# poison_percent 50 round 59: loss_train=5.0131, acc_train=0.5006, loss_test=0.0041, acc_test=0.9985
# poison_percent 50 round 60: loss_train=4.8773, acc_train=0.5006, loss_test=0.0042, acc_test=0.9985
# poison_percent 50 round 61: loss_train=4.8812, acc_train=0.5015, loss_test=0.0042, acc_test=0.9985
# poison_percent 50 round 62: loss_train=4.8827, acc_train=0.5004, loss_test=0.0043, acc_test=0.9985
# poison_percent 50 round 63: loss_train=4.8486, acc_train=0.5012, loss_test=0.0043, acc_test=0.9985
# poison_percent 50 round 64: loss_train=4.7711, acc_train=0.5013, loss_test=0.0044, acc_test=0.9985
# poison_percent 50 round 65: loss_train=4.7412, acc_train=0.5010, loss_test=0.0045, acc_test=0.9985
# poison_percent 50 round 66: loss_train=4.7056, acc_train=0.5008, loss_test=0.0045, acc_test=0.9985
# poison_percent 50 round 67: loss_train=4.6657, acc_train=0.5008, loss_test=0.0046, acc_test=0.9985
# poison_percent 50 round 68: loss_train=4.6967, acc_train=0.5012, loss_test=0.0047, acc_test=0.9985
# poison_percent 50 round 69: loss_train=4.6607, acc_train=0.5004, loss_test=0.0048, acc_test=0.9985
# poison_percent 50 round 70: loss_train=4.5821, acc_train=0.4996, loss_test=0.0049, acc_test=0.9985
# poison_percent 50 round 71: loss_train=4.5125, acc_train=0.5002, loss_test=0.0050, acc_test=0.9990
# poison_percent 50 round 72: loss_train=4.5171, acc_train=0.5004, loss_test=0.0051, acc_test=0.9990
# poison_percent 50 round 73: loss_train=4.4407, acc_train=0.5013, loss_test=0.0052, acc_test=0.9990
# poison_percent 50 round 74: loss_train=4.4198, acc_train=0.4996, loss_test=0.0053, acc_test=0.9990
# poison_percent 50 round 75: loss_train=4.4206, acc_train=0.4994, loss_test=0.0054, acc_test=0.9990
# poison_percent 50 round 76: loss_train=4.3259, acc_train=0.5008, loss_test=0.0055, acc_test=0.9990
# poison_percent 50 round 77: loss_train=4.3639, acc_train=0.4996, loss_test=0.0056, acc_test=0.9990
# poison_percent 50 round 78: loss_train=4.3012, acc_train=0.5013, loss_test=0.0057, acc_test=0.9990
# poison_percent 50 round 79: loss_train=4.2832, acc_train=0.5010, loss_test=0.0058, acc_test=0.9990
# poison_percent 50 round 80: loss_train=4.2516, acc_train=0.5010, loss_test=0.0059, acc_test=0.9990
# poison_percent 50 round 81: loss_train=4.2012, acc_train=0.4996, loss_test=0.0060, acc_test=0.9990
# poison_percent 50 round 82: loss_train=4.1834, acc_train=0.5000, loss_test=0.0062, acc_test=0.9990
# poison_percent 50 round 83: loss_train=4.1417, acc_train=0.5012, loss_test=0.0063, acc_test=0.9995
# poison_percent 50 round 84: loss_train=4.1648, acc_train=0.5010, loss_test=0.0065, acc_test=0.9990
# poison_percent 50 round 85: loss_train=4.1056, acc_train=0.4998, loss_test=0.0066, acc_test=0.9985
# poison_percent 50 round 86: loss_train=4.1043, acc_train=0.5000, loss_test=0.0067, acc_test=0.9985
# poison_percent 50 round 87: loss_train=4.0442, acc_train=0.5015, loss_test=0.0069, acc_test=0.9985
# poison_percent 50 round 88: loss_train=4.0465, acc_train=0.5012, loss_test=0.0070, acc_test=0.9985
# poison_percent 50 round 89: loss_train=3.9752, acc_train=0.5013, loss_test=0.0072, acc_test=0.9985
# poison_percent 50 round 90: loss_train=3.9830, acc_train=0.5012, loss_test=0.0074, acc_test=0.9985
# poison_percent 50 round 91: loss_train=3.9421, acc_train=0.5004, loss_test=0.0075, acc_test=0.9980
# poison_percent 50 round 92: loss_train=3.9302, acc_train=0.5010, loss_test=0.0077, acc_test=0.9980
# poison_percent 50 round 93: loss_train=3.8938, acc_train=0.5017, loss_test=0.0079, acc_test=0.9980
# poison_percent 50 round 94: loss_train=3.8807, acc_train=0.5015, loss_test=0.0081, acc_test=0.9980
# poison_percent 50 round 95: loss_train=3.8354, acc_train=0.5012, loss_test=0.0082, acc_test=0.9980
# poison_percent 50 round 96: loss_train=3.8078, acc_train=0.5025, loss_test=0.0084, acc_test=0.9980
# poison_percent 50 round 97: loss_train=3.7496, acc_train=0.5010, loss_test=0.0086, acc_test=0.9980
# poison_percent 50 round 98: loss_train=3.7492, acc_train=0.5017, loss_test=0.0088, acc_test=0.9980
# poison_percent 50 round 99: loss_train=3.7001, acc_train=0.5012, loss_test=0.0090, acc_test=0.9974
# Training log saved to ./results\FL_ModelN32L2_Batchsize32_rev2\poisoned_50percent\poisoned_50percent.csv
