# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    model = MNISTNet().to(device)
    model.load_state_dict(global_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end]
            yb = y_c_tensor[start:end]
            outputs = model(xb)
            preds = (outputs >= 0.5).float()
            loss = binary_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # Return a deepcopy to avoid issues with state_dict references
    return copy.deepcopy(model.state_dict()), X_c_tensor.size(0), yb, outputs, preds

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 32
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_binary_poison/train"
TEST_PATH = "../data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0]#[0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Poison n list: [0]

# %%
NODE = 1
for LAYER in [3]:#[3,4,5,6]: # LAYER - (first,last)

    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            
            # 1. Define the stack of hidden layers (Linear + ReLU)
            # Use a list comprehension to create the (Linear, ReLU) pairs
            hidden_layers = []
            for _ in range(LAYER-2):
                hidden_layers.append(nn.Linear(NODE, NODE))
                hidden_layers.append(nn.ReLU())
                
            # 2. Use nn.Sequential to wrap the entire dynamic stack
            self.dynamic_hidden = nn.Sequential(*hidden_layers)
            
            # Other layers
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, 1)

        def forward(self, x):
            # Flatten the input
            x = x.view(x.size(0), -1) 
            
            # Input Layer
            x = self.fc1(x)
            x = nn.ReLU()(x) # We need to manually apply ReLU here
            
            # Dynamic Hidden Layers (Executed sequentially without a loop)
            x = self.dynamic_hidden(x)
                
            # Output Layer
            x = self.fc2(x)
            x = torch.sigmoid(x)
            
            return x

    BATCH_SIZE_list = [BATCH_SIZE]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        global_model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"FL_ModelN{NODE}L{LAYER}_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                # local_epoch = # 29 image x 2 class x 100+i_poisoned clents / 32 batch_size / 100+i_poisoned clents
                LOCAL_EPOCHS = max(1, (29 * 2 * (N_HONEST + i_poisoned)) // (experiment_bs * (N_HONEST + i_poisoned)))
                
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                torch.save(global_model, os.path.join(save_path,'model_init.pt'))
                global_weights = global_model.state_dict()

                records = []

                X_train_tensor = {}
                y_train_tensor = {}
                for i in range(N_HONEST):
                    X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"honest_{i}"] = X_c_tensor
                    y_train_tensor[f"honest_{i}"] = y_c_tensor
                for i in range(i_poisoned):
                    X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"poison_{i}"] = X_c_tensor
                    y_train_tensor[f"poison_{i}"] = y_c_tensor

                # Training loop
                for round in range(ROUNDS):
                    # Prepare arguments for honest clients
                    
                    #randomize the training data
                    for i in range(N_HONEST):
                        perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                        X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                        y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                    honest_args = [
                        (
                            X_train_tensor[f"honest_{i}"],
                            y_train_tensor[f"honest_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(N_HONEST)
                    ]

                    # Prepare arguments for poisoned clients
                    
                    #randomize the training data
                    for i in range(i_poisoned):
                        perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                        X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                        y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                    poison_args = [
                        (
                            X_train_tensor[f"poison_{i}"],
                            y_train_tensor[f"poison_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(i_poisoned)
                    ]

                    # Run in parallel
                    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                        honest_results = list(executor.map(train_local_worker, honest_args))
                        poison_results = list(executor.map(train_local_worker, poison_args))

                    local_weights = []
                    local_sizes = []
                    local_y = []
                    local_outputs = []
                    local_preds = []
                    for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                        local_weights.append(l_w)
                        local_sizes.append(l_sz)
                        local_y.extend(l_y)
                        local_outputs.extend(l_out)
                        local_preds.extend(l_pred)
                    loss_train = binary_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                    acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                    # Federated averaging (weighted by client data size)
                    new_weights = {}
                    for key in global_weights.keys():
                        new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                    global_weights = new_weights
                    global_model.load_state_dict(global_weights)

                    # Evaluate
                    global_model.eval()
                    with torch.no_grad():
                        outputs = global_model(X_test_tensor)
                        preds = (outputs > 0.5).float()
                        loss_test = binary_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'round': round, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"round {round}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(global_model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['round'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['round'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 round 0: loss_train=0.7151, acc_train=0.5104, loss_test=0.7195, acc_test=0.5000
# poison_percent 0 round 1: loss_train=0.7207, acc_train=0.4965, loss_test=0.7185, acc_test=0.5000
# poison_percent 0 round 2: loss_train=0.7168, acc_train=0.5027, loss_test=0.7173, acc_test=0.5000
# poison_percent 0 round 3: loss_train=0.7171, acc_train=0.4996, loss_test=0.7161, acc_test=0.5000
# poison_percent 0 round 4: loss_train=0.7161, acc_train=0.4988, loss_test=0.7148, acc_test=0.5000
# poison_percent 0 round 5: loss_train=0.7179, acc_train=0.4919, loss_test=0.7134, acc_test=0.5000
# poison_percent 0 round 6: loss_train=0.7137, acc_train=0.4981, loss_test=0.7119, acc_test=0.5000
# poison_percent 0 round 7: loss_train=0.7145, acc_train=0.4927, loss_test=0.7103, acc_test=0.5000
# poison_percent 0 round 8: loss_train=0.7061, acc_train=0.5085, loss_test=0.7085, acc_test=0.5000
# poison_percent 0 round 9: loss_train=0.7037, acc_train=0.5104, loss_test=0.7067, acc_test=0.5000
# poison_percent 0 round 10: loss_train=0.7061, acc_train=0.4996, loss_test=0.7048, acc_test=0.5000
# poison_percent 0 round 11: loss_train=0.7058, acc_train=0.4958, loss_test=0.7028, acc_test=0.5000
# poison_percent 0 round 12: loss_train=0.7039, acc_train=0.4958, loss_test=0.7007, acc_test=0.5000
# poison_percent 0 round 13: loss_train=0.7025, acc_train=0.4938, loss_test=0.6985, acc_test=0.5000
# poison_percent 0 round 14: loss_train=0.6970, acc_train=0.5023, loss_test=0.6963, acc_test=0.5000
# poison_percent 0 round 15: loss_train=0.6938, acc_train=0.5050, loss_test=0.6939, acc_test=0.5000
# poison_percent 0 round 16: loss_train=0.6934, acc_train=0.5000, loss_test=0.6915, acc_test=0.5000
# poison_percent 0 round 17: loss_train=0.6862, acc_train=0.5138, loss_test=0.6891, acc_test=0.5000
# poison_percent 0 round 18: loss_train=0.6887, acc_train=0.4996, loss_test=0.6865, acc_test=0.5000
# poison_percent 0 round 19: loss_train=0.6863, acc_train=0.4996, loss_test=0.6839, acc_test=0.5000
# poison_percent 0 round 20: loss_train=0.6829, acc_train=0.5015, loss_test=0.6812, acc_test=0.5000
# poison_percent 0 round 21: loss_train=0.6777, acc_train=0.5092, loss_test=0.6784, acc_test=0.5000
# poison_percent 0 round 22: loss_train=0.6771, acc_train=0.5023, loss_test=0.6755, acc_test=0.5000
# poison_percent 0 round 23: loss_train=0.6760, acc_train=0.4965, loss_test=0.6726, acc_test=0.5000
# poison_percent 0 round 24: loss_train=0.6714, acc_train=0.5035, loss_test=0.6696, acc_test=0.5000
# poison_percent 0 round 25: loss_train=0.6693, acc_train=0.5004, loss_test=0.6665, acc_test=0.5000
# poison_percent 0 round 26: loss_train=0.6606, acc_train=0.5196, loss_test=0.6633, acc_test=0.5000
# poison_percent 0 round 27: loss_train=0.6589, acc_train=0.5154, loss_test=0.6600, acc_test=0.5000
# poison_percent 0 round 28: loss_train=0.6631, acc_train=0.4854, loss_test=0.6567, acc_test=0.5000
# poison_percent 0 round 29: loss_train=0.6532, acc_train=0.5138, loss_test=0.6533, acc_test=0.5010
# poison_percent 0 round 30: loss_train=0.6511, acc_train=0.5112, loss_test=0.6498, acc_test=0.5077
# poison_percent 0 round 31: loss_train=0.6477, acc_train=0.5181, loss_test=0.6463, acc_test=0.5179
# poison_percent 0 round 32: loss_train=0.6463, acc_train=0.5173, loss_test=0.6427, acc_test=0.5311
# poison_percent 0 round 33: loss_train=0.6438, acc_train=0.5227, loss_test=0.6390, acc_test=0.5510
# poison_percent 0 round 34: loss_train=0.6399, acc_train=0.5442, loss_test=0.6353, acc_test=0.5791
# poison_percent 0 round 35: loss_train=0.6377, acc_train=0.5662, loss_test=0.6315, acc_test=0.6133
# poison_percent 0 round 36: loss_train=0.6321, acc_train=0.6046, loss_test=0.6278, acc_test=0.6505
# poison_percent 0 round 37: loss_train=0.6290, acc_train=0.6469, loss_test=0.6242, acc_test=0.6878
# poison_percent 0 round 38: loss_train=0.6258, acc_train=0.6981, loss_test=0.6206, acc_test=0.7347
# poison_percent 0 round 39: loss_train=0.6233, acc_train=0.7385, loss_test=0.6172, acc_test=0.7765
# poison_percent 0 round 40: loss_train=0.6176, acc_train=0.7823, loss_test=0.6140, acc_test=0.8092
# poison_percent 0 round 41: loss_train=0.6152, acc_train=0.8177, loss_test=0.6110, acc_test=0.8367
# poison_percent 0 round 42: loss_train=0.6115, acc_train=0.8542, loss_test=0.6082, acc_test=0.8617
# poison_percent 0 round 43: loss_train=0.6091, acc_train=0.8804, loss_test=0.6056, acc_test=0.8827
# poison_percent 0 round 44: loss_train=0.6060, acc_train=0.8923, loss_test=0.6032, acc_test=0.9015
# poison_percent 0 round 45: loss_train=0.6050, acc_train=0.9131, loss_test=0.6009, acc_test=0.9214
# poison_percent 0 round 46: loss_train=0.6010, acc_train=0.9296, loss_test=0.5989, acc_test=0.9321
# poison_percent 0 round 47: loss_train=0.5991, acc_train=0.9438, loss_test=0.5969, acc_test=0.9423
# poison_percent 0 round 48: loss_train=0.5962, acc_train=0.9500, loss_test=0.5952, acc_test=0.9485
# poison_percent 0 round 49: loss_train=0.5973, acc_train=0.9546, loss_test=0.5936, acc_test=0.9556
# poison_percent 0 round 50: loss_train=0.5937, acc_train=0.9585, loss_test=0.5920, acc_test=0.9602
# poison_percent 0 round 51: loss_train=0.5924, acc_train=0.9646, loss_test=0.5906, acc_test=0.9663
# poison_percent 0 round 52: loss_train=0.5925, acc_train=0.9700, loss_test=0.5892, acc_test=0.9714
# poison_percent 0 round 53: loss_train=0.5915, acc_train=0.9685, loss_test=0.5880, acc_test=0.9755
# poison_percent 0 round 54: loss_train=0.5905, acc_train=0.9738, loss_test=0.5868, acc_test=0.9770
# poison_percent 0 round 55: loss_train=0.5871, acc_train=0.9762, loss_test=0.5856, acc_test=0.9786
# poison_percent 0 round 56: loss_train=0.5864, acc_train=0.9792, loss_test=0.5845, acc_test=0.9821
# poison_percent 0 round 57: loss_train=0.5845, acc_train=0.9812, loss_test=0.5835, acc_test=0.9842
# poison_percent 0 round 58: loss_train=0.5849, acc_train=0.9819, loss_test=0.5825, acc_test=0.9862
# poison_percent 0 round 59: loss_train=0.5848, acc_train=0.9788, loss_test=0.5816, acc_test=0.9872
# poison_percent 0 round 60: loss_train=0.5828, acc_train=0.9812, loss_test=0.5807, acc_test=0.9888
# poison_percent 0 round 61: loss_train=0.5814, acc_train=0.9835, loss_test=0.5798, acc_test=0.9893
# poison_percent 0 round 62: loss_train=0.5810, acc_train=0.9823, loss_test=0.5789, acc_test=0.9903
# poison_percent 0 round 63: loss_train=0.5804, acc_train=0.9850, loss_test=0.5781, acc_test=0.9918
# poison_percent 0 round 64: loss_train=0.5794, acc_train=0.9831, loss_test=0.5773, acc_test=0.9923
# poison_percent 0 round 65: loss_train=0.5778, acc_train=0.9862, loss_test=0.5765, acc_test=0.9934
# poison_percent 0 round 66: loss_train=0.5771, acc_train=0.9908, loss_test=0.5757, acc_test=0.9934
# poison_percent 0 round 67: loss_train=0.5760, acc_train=0.9873, loss_test=0.5749, acc_test=0.9934
# poison_percent 0 round 68: loss_train=0.5760, acc_train=0.9869, loss_test=0.5741, acc_test=0.9939
# poison_percent 0 round 69: loss_train=0.5748, acc_train=0.9888, loss_test=0.5733, acc_test=0.9944
# poison_percent 0 round 70: loss_train=0.5746, acc_train=0.9888, loss_test=0.5726, acc_test=0.9944
# poison_percent 0 round 71: loss_train=0.5727, acc_train=0.9923, loss_test=0.5718, acc_test=0.9944
# poison_percent 0 round 72: loss_train=0.5734, acc_train=0.9912, loss_test=0.5710, acc_test=0.9949
# poison_percent 0 round 73: loss_train=0.5712, acc_train=0.9900, loss_test=0.5703, acc_test=0.9949
# poison_percent 0 round 74: loss_train=0.5717, acc_train=0.9896, loss_test=0.5695, acc_test=0.9949
# poison_percent 0 round 75: loss_train=0.5706, acc_train=0.9900, loss_test=0.5688, acc_test=0.9949
# poison_percent 0 round 76: loss_train=0.5702, acc_train=0.9935, loss_test=0.5681, acc_test=0.9949
# poison_percent 0 round 77: loss_train=0.5681, acc_train=0.9908, loss_test=0.5673, acc_test=0.9949
# poison_percent 0 round 78: loss_train=0.5683, acc_train=0.9904, loss_test=0.5666, acc_test=0.9954
# poison_percent 0 round 79: loss_train=0.5676, acc_train=0.9923, loss_test=0.5659, acc_test=0.9954
# poison_percent 0 round 80: loss_train=0.5666, acc_train=0.9915, loss_test=0.5652, acc_test=0.9959
# poison_percent 0 round 81: loss_train=0.5652, acc_train=0.9942, loss_test=0.5644, acc_test=0.9959
# poison_percent 0 round 82: loss_train=0.5653, acc_train=0.9908, loss_test=0.5637, acc_test=0.9959
# poison_percent 0 round 83: loss_train=0.5644, acc_train=0.9912, loss_test=0.5630, acc_test=0.9959
# poison_percent 0 round 84: loss_train=0.5640, acc_train=0.9923, loss_test=0.5623, acc_test=0.9959
# poison_percent 0 round 85: loss_train=0.5616, acc_train=0.9927, loss_test=0.5616, acc_test=0.9959
# poison_percent 0 round 86: loss_train=0.5627, acc_train=0.9923, loss_test=0.5609, acc_test=0.9959
# poison_percent 0 round 87: loss_train=0.5614, acc_train=0.9923, loss_test=0.5602, acc_test=0.9959
# poison_percent 0 round 88: loss_train=0.5615, acc_train=0.9927, loss_test=0.5595, acc_test=0.9959
# poison_percent 0 round 89: loss_train=0.5592, acc_train=0.9946, loss_test=0.5588, acc_test=0.9959
# poison_percent 0 round 90: loss_train=0.5589, acc_train=0.9938, loss_test=0.5581, acc_test=0.9959
# poison_percent 0 round 91: loss_train=0.5588, acc_train=0.9915, loss_test=0.5574, acc_test=0.9964
# poison_percent 0 round 92: loss_train=0.5579, acc_train=0.9954, loss_test=0.5567, acc_test=0.9964
# poison_percent 0 round 93: loss_train=0.5588, acc_train=0.9938, loss_test=0.5560, acc_test=0.9964
# poison_percent 0 round 94: loss_train=0.5558, acc_train=0.9927, loss_test=0.5553, acc_test=0.9969
# poison_percent 0 round 95: loss_train=0.5573, acc_train=0.9927, loss_test=0.5546, acc_test=0.9969
# poison_percent 0 round 96: loss_train=0.5547, acc_train=0.9935, loss_test=0.5539, acc_test=0.9969
# poison_percent 0 round 97: loss_train=0.5552, acc_train=0.9931, loss_test=0.5532, acc_test=0.9969
# poison_percent 0 round 98: loss_train=0.5527, acc_train=0.9954, loss_test=0.5525, acc_test=0.9969
# poison_percent 0 round 99: loss_train=0.5525, acc_train=0.9950, loss_test=0.5518, acc_test=0.9969
# Training log saved to ./results\FL_ModelN1L3_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 0 round 0: loss_train=0.8659, acc_train=0.5004, loss_test=0.8637, acc_test=0.5000
# poison_percent 0 round 1: loss_train=0.8617, acc_train=0.4992, loss_test=0.8578, acc_test=0.5000
# poison_percent 0 round 2: loss_train=0.8569, acc_train=0.4985, loss_test=0.8522, acc_test=0.5000
# poison_percent 0 round 3: loss_train=0.8526, acc_train=0.4977, loss_test=0.8468, acc_test=0.5000
# poison_percent 0 round 4: loss_train=0.8452, acc_train=0.4992, loss_test=0.8415, acc_test=0.5000
# poison_percent 0 round 5: loss_train=0.8270, acc_train=0.5096, loss_test=0.8363, acc_test=0.5000
# poison_percent 0 round 6: loss_train=0.8304, acc_train=0.5027, loss_test=0.8313, acc_test=0.5000
# poison_percent 0 round 7: loss_train=0.8344, acc_train=0.4954, loss_test=0.8263, acc_test=0.5000
# poison_percent 0 round 8: loss_train=0.8265, acc_train=0.4981, loss_test=0.8215, acc_test=0.5000
# poison_percent 0 round 9: loss_train=0.8308, acc_train=0.4908, loss_test=0.8168, acc_test=0.5000
# poison_percent 0 round 10: loss_train=0.8157, acc_train=0.4992, loss_test=0.8122, acc_test=0.5000
# poison_percent 0 round 11: loss_train=0.7986, acc_train=0.5092, loss_test=0.8076, acc_test=0.5000
# poison_percent 0 round 12: loss_train=0.8133, acc_train=0.4942, loss_test=0.8032, acc_test=0.5000
# poison_percent 0 round 13: loss_train=0.8050, acc_train=0.4973, loss_test=0.7988, acc_test=0.5000
# poison_percent 0 round 14: loss_train=0.7952, acc_train=0.5012, loss_test=0.7946, acc_test=0.5000
# poison_percent 0 round 15: loss_train=0.8080, acc_train=0.4885, loss_test=0.7904, acc_test=0.5000
# poison_percent 0 round 16: loss_train=0.7894, acc_train=0.4996, loss_test=0.7862, acc_test=0.5000
# poison_percent 0 round 17: loss_train=0.7784, acc_train=0.5050, loss_test=0.7822, acc_test=0.5000
# poison_percent 0 round 18: loss_train=0.7822, acc_train=0.4985, loss_test=0.7782, acc_test=0.5000
# poison_percent 0 round 19: loss_train=0.7875, acc_train=0.4912, loss_test=0.7744, acc_test=0.5000
# poison_percent 0 round 20: loss_train=0.7821, acc_train=0.4923, loss_test=0.7706, acc_test=0.5000
# poison_percent 0 round 21: loss_train=0.7628, acc_train=0.5050, loss_test=0.7668, acc_test=0.5000
# poison_percent 0 round 22: loss_train=0.7713, acc_train=0.4958, loss_test=0.7632, acc_test=0.5000
# poison_percent 0 round 23: loss_train=0.7616, acc_train=0.4996, loss_test=0.7596, acc_test=0.5000
# poison_percent 0 round 24: loss_train=0.7478, acc_train=0.5088, loss_test=0.7561, acc_test=0.5000
# poison_percent 0 round 25: loss_train=0.7567, acc_train=0.4977, loss_test=0.7526, acc_test=0.5000
# poison_percent 0 round 26: loss_train=0.7609, acc_train=0.4931, loss_test=0.7492, acc_test=0.5000
# poison_percent 0 round 27: loss_train=0.7358, acc_train=0.5092, loss_test=0.7459, acc_test=0.5000
# poison_percent 0 round 28: loss_train=0.7395, acc_train=0.5038, loss_test=0.7426, acc_test=0.5000
# poison_percent 0 round 29: loss_train=0.7301, acc_train=0.5088, loss_test=0.7393, acc_test=0.5000
# poison_percent 0 round 30: loss_train=0.7302, acc_train=0.5065, loss_test=0.7362, acc_test=0.5000
# poison_percent 0 round 31: loss_train=0.7160, acc_train=0.5146, loss_test=0.7331, acc_test=0.5000
# poison_percent 0 round 32: loss_train=0.7252, acc_train=0.5050, loss_test=0.7300, acc_test=0.5000
# poison_percent 0 round 33: loss_train=0.7164, acc_train=0.5100, loss_test=0.7270, acc_test=0.5000
# poison_percent 0 round 34: loss_train=0.7338, acc_train=0.4946, loss_test=0.7241, acc_test=0.5000
# poison_percent 0 round 35: loss_train=0.7202, acc_train=0.5023, loss_test=0.7212, acc_test=0.5000
# poison_percent 0 round 36: loss_train=0.7351, acc_train=0.4892, loss_test=0.7183, acc_test=0.5000
# poison_percent 0 round 37: loss_train=0.7162, acc_train=0.5008, loss_test=0.7155, acc_test=0.5000
# poison_percent 0 round 38: loss_train=0.6980, acc_train=0.5135, loss_test=0.7127, acc_test=0.5000
# poison_percent 0 round 39: loss_train=0.7142, acc_train=0.4988, loss_test=0.7100, acc_test=0.5000
# poison_percent 0 round 40: loss_train=0.7145, acc_train=0.4962, loss_test=0.7073, acc_test=0.5000
# poison_percent 0 round 41: loss_train=0.6861, acc_train=0.5165, loss_test=0.7047, acc_test=0.5000
# poison_percent 0 round 42: loss_train=0.7000, acc_train=0.5038, loss_test=0.7020, acc_test=0.5000
# poison_percent 0 round 43: loss_train=0.7094, acc_train=0.4938, loss_test=0.6995, acc_test=0.5000
# poison_percent 0 round 44: loss_train=0.7149, acc_train=0.4877, loss_test=0.6969, acc_test=0.5000
# poison_percent 0 round 45: loss_train=0.6905, acc_train=0.5054, loss_test=0.6944, acc_test=0.5000
# poison_percent 0 round 46: loss_train=0.6946, acc_train=0.4996, loss_test=0.6919, acc_test=0.5000
# poison_percent 0 round 47: loss_train=0.7024, acc_train=0.4912, loss_test=0.6895, acc_test=0.5000
# poison_percent 0 round 48: loss_train=0.6967, acc_train=0.4942, loss_test=0.6871, acc_test=0.5000
# poison_percent 0 round 49: loss_train=0.6820, acc_train=0.5035, loss_test=0.6847, acc_test=0.5000
# poison_percent 0 round 50: loss_train=0.6711, acc_train=0.5104, loss_test=0.6823, acc_test=0.5000
# poison_percent 0 round 51: loss_train=0.6795, acc_train=0.5035, loss_test=0.6800, acc_test=0.5000
# poison_percent 0 round 52: loss_train=0.6876, acc_train=0.4935, loss_test=0.6777, acc_test=0.5000
# poison_percent 0 round 53: loss_train=0.6837, acc_train=0.4958, loss_test=0.6754, acc_test=0.5000
# poison_percent 0 round 54: loss_train=0.6771, acc_train=0.4981, loss_test=0.6732, acc_test=0.5000
# poison_percent 0 round 55: loss_train=0.6563, acc_train=0.5135, loss_test=0.6710, acc_test=0.5000
# poison_percent 0 round 56: loss_train=0.6679, acc_train=0.5027, loss_test=0.6688, acc_test=0.5000
# poison_percent 0 round 57: loss_train=0.6698, acc_train=0.5000, loss_test=0.6666, acc_test=0.5000
# poison_percent 0 round 58: loss_train=0.6504, acc_train=0.5135, loss_test=0.6644, acc_test=0.5000
# poison_percent 0 round 59: loss_train=0.6604, acc_train=0.5038, loss_test=0.6623, acc_test=0.5000
# poison_percent 0 round 60: loss_train=0.6744, acc_train=0.4904, loss_test=0.6601, acc_test=0.5000
# poison_percent 0 round 61: loss_train=0.6511, acc_train=0.5073, loss_test=0.6580, acc_test=0.5000
# poison_percent 0 round 62: loss_train=0.6510, acc_train=0.5069, loss_test=0.6560, acc_test=0.5000
# poison_percent 0 round 63: loss_train=0.6571, acc_train=0.4996, loss_test=0.6539, acc_test=0.5000
# poison_percent 0 round 64: loss_train=0.6643, acc_train=0.4915, loss_test=0.6519, acc_test=0.5000
# poison_percent 0 round 65: loss_train=0.6351, acc_train=0.5135, loss_test=0.6499, acc_test=0.5000
# poison_percent 0 round 66: loss_train=0.6502, acc_train=0.4981, loss_test=0.6479, acc_test=0.5000
# poison_percent 0 round 67: loss_train=0.6555, acc_train=0.4935, loss_test=0.6459, acc_test=0.5000
# poison_percent 0 round 68: loss_train=0.6542, acc_train=0.4950, loss_test=0.6439, acc_test=0.5000
# poison_percent 0 round 69: loss_train=0.6525, acc_train=0.4942, loss_test=0.6420, acc_test=0.5000
# poison_percent 0 round 70: loss_train=0.6450, acc_train=0.4985, loss_test=0.6401, acc_test=0.5000
# poison_percent 0 round 71: loss_train=0.6410, acc_train=0.4996, loss_test=0.6381, acc_test=0.5000
# poison_percent 0 round 72: loss_train=0.6348, acc_train=0.5031, loss_test=0.6363, acc_test=0.5000
# poison_percent 0 round 73: loss_train=0.6351, acc_train=0.5019, loss_test=0.6344, acc_test=0.5000
# poison_percent 0 round 74: loss_train=0.6399, acc_train=0.4950, loss_test=0.6325, acc_test=0.5000
# poison_percent 0 round 75: loss_train=0.6392, acc_train=0.4938, loss_test=0.6306, acc_test=0.5000
# poison_percent 0 round 76: loss_train=0.6365, acc_train=0.4962, loss_test=0.6288, acc_test=0.5000
# poison_percent 0 round 77: loss_train=0.6269, acc_train=0.5019, loss_test=0.6269, acc_test=0.5000
# poison_percent 0 round 78: loss_train=0.6486, acc_train=0.4823, loss_test=0.6251, acc_test=0.5000
# poison_percent 0 round 79: loss_train=0.6169, acc_train=0.5069, loss_test=0.6233, acc_test=0.5000
# poison_percent 0 round 80: loss_train=0.6267, acc_train=0.4981, loss_test=0.6215, acc_test=0.5000
# poison_percent 0 round 81: loss_train=0.6283, acc_train=0.4935, loss_test=0.6198, acc_test=0.5000
# poison_percent 0 round 82: loss_train=0.6119, acc_train=0.5073, loss_test=0.6180, acc_test=0.5000
# poison_percent 0 round 83: loss_train=0.6496, acc_train=0.4738, loss_test=0.6162, acc_test=0.5000
# poison_percent 0 round 84: loss_train=0.6247, acc_train=0.4927, loss_test=0.6145, acc_test=0.5000
# poison_percent 0 round 85: loss_train=0.6248, acc_train=0.4923, loss_test=0.6128, acc_test=0.5000
# poison_percent 0 round 86: loss_train=0.6155, acc_train=0.4985, loss_test=0.6110, acc_test=0.5000
# poison_percent 0 round 87: loss_train=0.6223, acc_train=0.4912, loss_test=0.6093, acc_test=0.5000
# poison_percent 0 round 88: loss_train=0.6218, acc_train=0.4892, loss_test=0.6076, acc_test=0.5000
# poison_percent 0 round 89: loss_train=0.6118, acc_train=0.4962, loss_test=0.6059, acc_test=0.5000
# poison_percent 0 round 90: loss_train=0.6036, acc_train=0.5042, loss_test=0.6043, acc_test=0.5000
# poison_percent 0 round 91: loss_train=0.6069, acc_train=0.4985, loss_test=0.6026, acc_test=0.5000
# poison_percent 0 round 92: loss_train=0.5950, acc_train=0.5069, loss_test=0.6009, acc_test=0.5000
# poison_percent 0 round 93: loss_train=0.6109, acc_train=0.4912, loss_test=0.5993, acc_test=0.5000
# poison_percent 0 round 94: loss_train=0.5956, acc_train=0.5050, loss_test=0.5977, acc_test=0.5000
# poison_percent 0 round 95: loss_train=0.5999, acc_train=0.4973, loss_test=0.5961, acc_test=0.5000
# poison_percent 0 round 96: loss_train=0.5937, acc_train=0.5035, loss_test=0.5945, acc_test=0.5000
# poison_percent 0 round 97: loss_train=0.6065, acc_train=0.4904, loss_test=0.5929, acc_test=0.5000
# poison_percent 0 round 98: loss_train=0.5914, acc_train=0.5015, loss_test=0.5913, acc_test=0.5000
# poison_percent 0 round 99: loss_train=0.5972, acc_train=0.4946, loss_test=0.5897, acc_test=0.5000
# Training log saved to ./results\FL_ModelN1L3_Batchsize32_rev1\poisoned_0percent\poisoned_0percent.csv
# poison_percent 0 round 0: loss_train=0.6842, acc_train=0.5758, loss_test=0.6780, acc_test=0.6862
# poison_percent 0 round 1: loss_train=0.6730, acc_train=0.7519, loss_test=0.6657, acc_test=0.8434
# poison_percent 0 round 2: loss_train=0.6620, acc_train=0.8865, loss_test=0.6534, acc_test=0.9337
# poison_percent 0 round 3: loss_train=0.6502, acc_train=0.9377, loss_test=0.6414, acc_test=0.9633
# poison_percent 0 round 4: loss_train=0.6383, acc_train=0.9523, loss_test=0.6296, acc_test=0.9689
# poison_percent 0 round 5: loss_train=0.6276, acc_train=0.9604, loss_test=0.6182, acc_test=0.9740
# poison_percent 0 round 6: loss_train=0.6151, acc_train=0.9619, loss_test=0.6071, acc_test=0.9755
# poison_percent 0 round 7: loss_train=0.6047, acc_train=0.9588, loss_test=0.5963, acc_test=0.9735
# poison_percent 0 round 8: loss_train=0.5933, acc_train=0.9565, loss_test=0.5857, acc_test=0.9735
# poison_percent 0 round 9: loss_train=0.5850, acc_train=0.9573, loss_test=0.5755, acc_test=0.9735
# poison_percent 0 round 10: loss_train=0.5726, acc_train=0.9554, loss_test=0.5655, acc_test=0.9714
# poison_percent 0 round 11: loss_train=0.5644, acc_train=0.9569, loss_test=0.5558, acc_test=0.9704
# poison_percent 0 round 12: loss_train=0.5560, acc_train=0.9531, loss_test=0.5465, acc_test=0.9684
# poison_percent 0 round 13: loss_train=0.5465, acc_train=0.9546, loss_test=0.5374, acc_test=0.9679
# poison_percent 0 round 14: loss_train=0.5380, acc_train=0.9558, loss_test=0.5287, acc_test=0.9663
# poison_percent 0 round 15: loss_train=0.5285, acc_train=0.9538, loss_test=0.5202, acc_test=0.9663
# poison_percent 0 round 16: loss_train=0.5199, acc_train=0.9535, loss_test=0.5121, acc_test=0.9663
# poison_percent 0 round 17: loss_train=0.5126, acc_train=0.9515, loss_test=0.5041, acc_test=0.9679
# poison_percent 0 round 18: loss_train=0.5040, acc_train=0.9519, loss_test=0.4965, acc_test=0.9673
# poison_percent 0 round 19: loss_train=0.4972, acc_train=0.9496, loss_test=0.4892, acc_test=0.9684
# poison_percent 0 round 20: loss_train=0.4869, acc_train=0.9546, loss_test=0.4820, acc_test=0.9684
# poison_percent 0 round 21: loss_train=0.4854, acc_train=0.9535, loss_test=0.4752, acc_test=0.9689
# poison_percent 0 round 22: loss_train=0.4792, acc_train=0.9504, loss_test=0.4685, acc_test=0.9689
# poison_percent 0 round 23: loss_train=0.4743, acc_train=0.9519, loss_test=0.4622, acc_test=0.9699
# poison_percent 0 round 24: loss_train=0.4714, acc_train=0.9462, loss_test=0.4561, acc_test=0.9704
# poison_percent 0 round 25: loss_train=0.4583, acc_train=0.9538, loss_test=0.4502, acc_test=0.9709
# poison_percent 0 round 26: loss_train=0.4533, acc_train=0.9608, loss_test=0.4446, acc_test=0.9714
# poison_percent 0 round 27: loss_train=0.4480, acc_train=0.9535, loss_test=0.4392, acc_test=0.9714
# poison_percent 0 round 28: loss_train=0.4521, acc_train=0.9538, loss_test=0.4339, acc_test=0.9714
# poison_percent 0 round 29: loss_train=0.4385, acc_train=0.9608, loss_test=0.4288, acc_test=0.9719
# poison_percent 0 round 30: loss_train=0.4342, acc_train=0.9581, loss_test=0.4240, acc_test=0.9719
# poison_percent 0 round 31: loss_train=0.4291, acc_train=0.9581, loss_test=0.4194, acc_test=0.9719
# poison_percent 0 round 32: loss_train=0.4190, acc_train=0.9662, loss_test=0.4150, acc_test=0.9735
# poison_percent 0 round 33: loss_train=0.4243, acc_train=0.9658, loss_test=0.4107, acc_test=0.9740
# poison_percent 0 round 34: loss_train=0.4143, acc_train=0.9658, loss_test=0.4066, acc_test=0.9740
# poison_percent 0 round 35: loss_train=0.4114, acc_train=0.9662, loss_test=0.4026, acc_test=0.9750
# poison_percent 0 round 36: loss_train=0.4156, acc_train=0.9631, loss_test=0.3988, acc_test=0.9745
# poison_percent 0 round 37: loss_train=0.4043, acc_train=0.9681, loss_test=0.3952, acc_test=0.9755
# poison_percent 0 round 38: loss_train=0.4032, acc_train=0.9669, loss_test=0.3917, acc_test=0.9765
# poison_percent 0 round 39: loss_train=0.4000, acc_train=0.9677, loss_test=0.3883, acc_test=0.9770
# poison_percent 0 round 40: loss_train=0.3870, acc_train=0.9708, loss_test=0.3851, acc_test=0.9776
# poison_percent 0 round 41: loss_train=0.3868, acc_train=0.9650, loss_test=0.3820, acc_test=0.9776
# poison_percent 0 round 42: loss_train=0.3870, acc_train=0.9658, loss_test=0.3791, acc_test=0.9776
# poison_percent 0 round 43: loss_train=0.3831, acc_train=0.9685, loss_test=0.3762, acc_test=0.9786
# poison_percent 0 round 44: loss_train=0.3795, acc_train=0.9719, loss_test=0.3734, acc_test=0.9791
# poison_percent 0 round 45: loss_train=0.3785, acc_train=0.9688, loss_test=0.3707, acc_test=0.9791
# poison_percent 0 round 46: loss_train=0.3764, acc_train=0.9712, loss_test=0.3681, acc_test=0.9791
# poison_percent 0 round 47: loss_train=0.3747, acc_train=0.9746, loss_test=0.3657, acc_test=0.9796
# poison_percent 0 round 48: loss_train=0.3803, acc_train=0.9681, loss_test=0.3632, acc_test=0.9801
# poison_percent 0 round 49: loss_train=0.3790, acc_train=0.9692, loss_test=0.3609, acc_test=0.9801
# poison_percent 0 round 50: loss_train=0.3567, acc_train=0.9765, loss_test=0.3587, acc_test=0.9821
# poison_percent 0 round 51: loss_train=0.3613, acc_train=0.9735, loss_test=0.3566, acc_test=0.9821
# poison_percent 0 round 52: loss_train=0.3622, acc_train=0.9727, loss_test=0.3545, acc_test=0.9821
# poison_percent 0 round 53: loss_train=0.3588, acc_train=0.9750, loss_test=0.3525, acc_test=0.9821
# poison_percent 0 round 54: loss_train=0.3627, acc_train=0.9731, loss_test=0.3505, acc_test=0.9821
# poison_percent 0 round 55: loss_train=0.3547, acc_train=0.9727, loss_test=0.3486, acc_test=0.9827
# poison_percent 0 round 56: loss_train=0.3476, acc_train=0.9769, loss_test=0.3468, acc_test=0.9827
# poison_percent 0 round 57: loss_train=0.3518, acc_train=0.9742, loss_test=0.3450, acc_test=0.9832
# poison_percent 0 round 58: loss_train=0.3522, acc_train=0.9731, loss_test=0.3433, acc_test=0.9832
# poison_percent 0 round 59: loss_train=0.3511, acc_train=0.9727, loss_test=0.3417, acc_test=0.9837
# poison_percent 0 round 60: loss_train=0.3443, acc_train=0.9735, loss_test=0.3401, acc_test=0.9837
# poison_percent 0 round 61: loss_train=0.3543, acc_train=0.9715, loss_test=0.3385, acc_test=0.9837
# poison_percent 0 round 62: loss_train=0.3521, acc_train=0.9769, loss_test=0.3370, acc_test=0.9837
# poison_percent 0 round 63: loss_train=0.3517, acc_train=0.9777, loss_test=0.3355, acc_test=0.9837
# poison_percent 0 round 64: loss_train=0.3401, acc_train=0.9785, loss_test=0.3341, acc_test=0.9837
# poison_percent 0 round 65: loss_train=0.3396, acc_train=0.9800, loss_test=0.3327, acc_test=0.9837
# poison_percent 0 round 66: loss_train=0.3372, acc_train=0.9773, loss_test=0.3314, acc_test=0.9842
# poison_percent 0 round 67: loss_train=0.3339, acc_train=0.9750, loss_test=0.3301, acc_test=0.9847
# poison_percent 0 round 68: loss_train=0.3390, acc_train=0.9777, loss_test=0.3288, acc_test=0.9857
# poison_percent 0 round 69: loss_train=0.3358, acc_train=0.9765, loss_test=0.3275, acc_test=0.9862
# poison_percent 0 round 70: loss_train=0.3332, acc_train=0.9804, loss_test=0.3263, acc_test=0.9867
# poison_percent 0 round 71: loss_train=0.3327, acc_train=0.9808, loss_test=0.3251, acc_test=0.9867
# poison_percent 0 round 72: loss_train=0.3302, acc_train=0.9815, loss_test=0.3240, acc_test=0.9867
# poison_percent 0 round 73: loss_train=0.3332, acc_train=0.9835, loss_test=0.3229, acc_test=0.9872
# poison_percent 0 round 74: loss_train=0.3283, acc_train=0.9765, loss_test=0.3218, acc_test=0.9872
# poison_percent 0 round 75: loss_train=0.3409, acc_train=0.9773, loss_test=0.3207, acc_test=0.9872
# poison_percent 0 round 76: loss_train=0.3181, acc_train=0.9781, loss_test=0.3197, acc_test=0.9872
# poison_percent 0 round 77: loss_train=0.3318, acc_train=0.9792, loss_test=0.3187, acc_test=0.9872
# poison_percent 0 round 78: loss_train=0.3272, acc_train=0.9792, loss_test=0.3177, acc_test=0.9872
# poison_percent 0 round 79: loss_train=0.3212, acc_train=0.9750, loss_test=0.3167, acc_test=0.9872
# poison_percent 0 round 80: loss_train=0.3275, acc_train=0.9785, loss_test=0.3158, acc_test=0.9872
# poison_percent 0 round 81: loss_train=0.3229, acc_train=0.9804, loss_test=0.3148, acc_test=0.9872
# poison_percent 0 round 82: loss_train=0.3206, acc_train=0.9808, loss_test=0.3139, acc_test=0.9872
# poison_percent 0 round 83: loss_train=0.3120, acc_train=0.9804, loss_test=0.3130, acc_test=0.9872
# poison_percent 0 round 84: loss_train=0.3151, acc_train=0.9792, loss_test=0.3122, acc_test=0.9872
# poison_percent 0 round 85: loss_train=0.3169, acc_train=0.9808, loss_test=0.3113, acc_test=0.9872
# poison_percent 0 round 86: loss_train=0.3166, acc_train=0.9838, loss_test=0.3104, acc_test=0.9872
# poison_percent 0 round 87: loss_train=0.3163, acc_train=0.9804, loss_test=0.3096, acc_test=0.9878
# poison_percent 0 round 88: loss_train=0.3192, acc_train=0.9788, loss_test=0.3088, acc_test=0.9883
# poison_percent 0 round 89: loss_train=0.3142, acc_train=0.9796, loss_test=0.3080, acc_test=0.9883
# poison_percent 0 round 90: loss_train=0.3166, acc_train=0.9846, loss_test=0.3071, acc_test=0.9888
# poison_percent 0 round 91: loss_train=0.3167, acc_train=0.9827, loss_test=0.3063, acc_test=0.9888
# poison_percent 0 round 92: loss_train=0.3177, acc_train=0.9785, loss_test=0.3056, acc_test=0.9888
# poison_percent 0 round 93: loss_train=0.3148, acc_train=0.9835, loss_test=0.3048, acc_test=0.9888
# poison_percent 0 round 94: loss_train=0.3231, acc_train=0.9788, loss_test=0.3041, acc_test=0.9888
# poison_percent 0 round 95: loss_train=0.3097, acc_train=0.9823, loss_test=0.3034, acc_test=0.9888
# poison_percent 0 round 96: loss_train=0.3119, acc_train=0.9800, loss_test=0.3027, acc_test=0.9888
# poison_percent 0 round 97: loss_train=0.3144, acc_train=0.9792, loss_test=0.3021, acc_test=0.9888
# poison_percent 0 round 98: loss_train=0.3051, acc_train=0.9808, loss_test=0.3014, acc_test=0.9888
# poison_percent 0 round 99: loss_train=0.3084, acc_train=0.9792, loss_test=0.3007, acc_test=0.9888
# Training log saved to ./results\FL_ModelN1L3_Batchsize32_rev2\poisoned_0percent\poisoned_0percent.csv
