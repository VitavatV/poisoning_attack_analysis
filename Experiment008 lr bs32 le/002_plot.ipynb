# %%
import pandas as pd

NODE = [1]
LAYER = [2,3,4,5,6]
REV = [0,1,2]
APPROACH = ['CL','FL']
POISONED = [0,10,20,30,40,50]
METRICS = ['loss_train', 'acc_train', 'loss_test', 'acc_test']
result_path = 'results'

dt_list = []

for a in APPROACH:
    for n in NODE:
        for l in LAYER:
            for r in REV:
                exp_name = f'{a}_ModelN{n}L{l}_Batchsize32'
                exp_rev_name = f'{a}_ModelN{n}L{l}_Batchsize32_rev{r}'
                for p in POISONED:
                    sub_f_name = f'poisoned_{p}percent'
                    
                    dt_list.append({
                        'NODE':n,
                        'LAYER':l,
                        'REV':r,
                        'APPROACH':a,
                        'EXPERIMENT':exp_name,
                        'EXPERIMENT_REV':exp_rev_name,
                        'POISONED':p,
                        'SUB_FLODER':sub_f_name,
                        'CSV':f'{result_path}\{exp_rev_name}\{sub_f_name}\{sub_f_name}.csv',
                    })

df_exp = pd.DataFrame(dt_list)
print(df_exp.head())
# Out:
# <string>:31: SyntaxWarning: invalid escape sequence '\{'
# <string>:31: SyntaxWarning: invalid escape sequence '\{'
# <string>:31: SyntaxWarning: invalid escape sequence '\{'
# <>:31: SyntaxWarning: invalid escape sequence '\{'
# <>:31: SyntaxWarning: invalid escape sequence '\{'
# <>:31: SyntaxWarning: invalid escape sequence '\{'
# <string>:31: SyntaxWarning: invalid escape sequence '\{'
# <string>:31: SyntaxWarning: invalid escape sequence '\{'
# <string>:31: SyntaxWarning: invalid escape sequence '\{'
# <>:31: SyntaxWarning: invalid escape sequence '\{'
# <>:31: SyntaxWarning: invalid escape sequence '\{'
# <>:31: SyntaxWarning: invalid escape sequence '\{'
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_7352\1723101382.py:31: SyntaxWarning: invalid escape sequence '\{'
#   'CSV':f'{result_path}\{exp_rev_name}\{sub_f_name}\{sub_f_name}.csv',
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_7352\1723101382.py:31: SyntaxWarning: invalid escape sequence '\{'
#   'CSV':f'{result_path}\{exp_rev_name}\{sub_f_name}\{sub_f_name}.csv',
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_7352\1723101382.py:31: SyntaxWarning: invalid escape sequence '\{'
#   'CSV':f'{result_path}\{exp_rev_name}\{sub_f_name}\{sub_f_name}.csv',
#    NODE  LAYER  REV APPROACH                EXPERIMENT  \
# 0     1      2    0       CL  CL_ModelN1L2_Batchsize32
# 1     1      2    0       CL  CL_ModelN1L2_Batchsize32
# 2     1      2    0       CL  CL_ModelN1L2_Batchsize32
# 3     1      2    0       CL  CL_ModelN1L2_Batchsize32
# 4     1      2    0       CL  CL_ModelN1L2_Batchsize32
#
#                   EXPERIMENT_REV  POISONED          SUB_FLODER  \
# 0  CL_ModelN1L2_Batchsize32_rev0         0   poisoned_0percent
# 1  CL_ModelN1L2_Batchsize32_rev0        10  poisoned_10percent
# 2  CL_ModelN1L2_Batchsize32_rev0        20  poisoned_20percent
# 3  CL_ModelN1L2_Batchsize32_rev0        30  poisoned_30percent
# 4  CL_ModelN1L2_Batchsize32_rev0        40  poisoned_40percent
#
#                                                  CSV
# 0  results\CL_ModelN1L2_Batchsize32_rev0\poisoned...
# 1  results\CL_ModelN1L2_Batchsize32_rev0\poisoned...
# 2  results\CL_ModelN1L2_Batchsize32_rev0\poisoned...
# 3  results\CL_ModelN1L2_Batchsize32_rev0\poisoned...
# 4  results\CL_ModelN1L2_Batchsize32_rev0\poisoned...

# %%
import pandas as pd
import matplotlib.pyplot as plt

exp_name_list = df_exp['EXPERIMENT'].unique()
# Loop through each CSV file
for i_exp in exp_name_list:

        df_filter = df_exp[df_exp['EXPERIMENT']==i_exp]
             
               
        # Create figure with subplots
        fig, axes = plt.subplots(4, 3, figsize=(12, 10))
        fig.suptitle(f"{i_exp}", fontsize=16)

        for idx,row in df_filter.iterrows():
                
            csv_file = row['CSV']
            sub_f_name = row['SUB_FLODER']
            rev = row['REV']

            # Read CSV into DataFrame
            df = pd.read_csv(csv_file)
            
            
            # Check if required columns exist
            ep_rnd = 'epoch'
            if row['APPROACH'] == 'FL':
                 ep_rnd = 'round'
            required_cols = [ep_rnd]+METRICS
            if not all(col in df.columns for col in required_cols):
                print(f"Skipping {csv_file}: Missing required columns")
                continue

            for i_metric, metric in enumerate(METRICS):
            
                # axes[i_metric, rev].plot(df[ep_rnd], df[metric], marker='o', label=f'{sub_f_name}')
                axes[i_metric, rev].plot(df[ep_rnd], df[metric], label=f'{sub_f_name}')


        for i_metric, metric in enumerate(METRICS):
             for rev in REV:
                axes[i_metric, rev].set_title(f'Rev{rev}')
                axes[i_metric, rev].set_xlabel(ep_rnd)
                axes[i_metric, rev].set_ylabel(f'{metric}')
                axes[i_metric, rev].grid(True)
                # if i_metric==0 and rev ==0:
                    # axes[i_metric, rev].legend()
                    # move legend to bottom out of chart
                    
        # collect handles/labels from the plotted axes (use first row or aggregate)
        handles, labels = [], []
        for rev in [0]:#REV:
            h, l = axes[0, rev].get_legend_handles_labels()
            handles.extend(h)
            labels.extend(l)

        # place a single legend below the figure
        if handles:
            fig.legend(handles, labels, loc='lower center',
                       bbox_to_anchor=(0.5, -0.02), ncol=min(len(labels), 6),
                       frameon=False)

        # leave space for the legend at the bottom
        plt.tight_layout(rect=[0, 0.06, 1, 1])
        # plt.tight_layout()
        
        # Save figure
        # output_name = csv_file.replace('.csv', '_plot.png')
        # plt.savefig(output_name, dpi=300, bbox_inches='tight')
        # print(f"✓ Plotted: {csv_file} -> {output_name}")
        
        plt.show()


# get table value from df_exp for each experiment
dt_list = []
for i_exp in exp_name_list:

        df_filter = df_exp[df_exp['EXPERIMENT']==i_exp]
        
        for idx,row in df_filter.iterrows():
                
            csv_file = row['CSV']
            sub_f_name = row['SUB_FLODER']
            rev = row['REV']

            # Read CSV into DataFrame
            df = pd.read_csv(csv_file)
            
            # Check if required columns exist
            ep_rnd = 'epoch'
            if row['APPROACH'] == 'FL':
                 ep_rnd = 'round'
            required_cols = [ep_rnd]+METRICS
            if not all(col in df.columns for col in required_cols):
                print(f"Skipping {csv_file}: Missing required columns")
                continue

            # get last row values
            last_row = df.iloc[-1]
            # find settle epoch where loss_test does not change more than 0.01 for 5 consecutive epochs
            settle_epoch = df[ep_rnd].iloc[-1]
            # for i in range(len(df)-5):
            #     if all(abs(df['loss_test'].iloc[i+j] - df['loss_test'].iloc[i+j+1]) < 0.05 for j in range(5)):
            #         settle_epoch = df[ep_rnd].iloc[i]
            #         break
            # if settle_epoch is not None:
            #     last_row = df[df[ep_rnd]==settle_epoch].iloc[0]

            data_entry = {
                'NODE':row['NODE'],
                'LAYER':row['LAYER'],
                'REV':rev,
                'APPROACH':row['APPROACH'],
                'EXPERIMENT':i_exp,
                'POISONED':row['POISONED'],
                'SUB_FLODER':sub_f_name,
                'SETTLE_EPOCH':settle_epoch,
            }
            for metric in METRICS:
                data_entry[metric] = last_row[metric]
            dt_list.append(data_entry)
df_results = pd.DataFrame(dt_list)

# list acc_test
dt_last_epoch_list = []
dt_loss_test_list = []
dt_acc_test_list = []
# pivot table for each experiment
# columns by POISONED, index by REV, values by METRICS
for i_exp in exp_name_list:
    df_filter = df_results[df_results['EXPERIMENT']==i_exp]

    pivot_table = df_filter.pivot(index='REV', columns='POISONED', values='SETTLE_EPOCH')
    mediamn_row = pivot_table.median()
    mediamn_row.name = i_exp
    pivot_table = pd.concat([pivot_table, mediamn_row.to_frame().T])
    for col in pivot_table.columns:
        pivot_table[col] = pivot_table[col].astype(int)
    print(f"=== Experiment: {i_exp} - Settle Epoch ===")
    print(pivot_table)
    print("\n")
    dt_last_epoch_list.append({
        'EXPERIMENT':i_exp,
        '0%_poisoned':pivot_table.iloc[-1, 0],
        '10%_poisoned':pivot_table.iloc[-1, 1],
        '20%_poisoned':pivot_table.iloc[-1, 2],
        '30%_poisoned':pivot_table.iloc[-1, 3],
        '40%_poisoned':pivot_table.iloc[-1, 4],
        '50%_poisoned':pivot_table.iloc[-1, 5],
    })

    for metric in METRICS:
        pivot_table = df_filter.pivot(index='REV', columns='POISONED', values=metric)
        # add last median row
        median_row = pivot_table.median()
        median_row.name = i_exp
        pivot_table = pd.concat([pivot_table, median_row.to_frame().T])
        print(f"=== Experiment: {i_exp} - Metric: {metric} ===")
        print(pivot_table)
        if metric == 'loss_test':
            dt_loss_test_list.append({
                'EXPERIMENT':i_exp,
                '0%_poisoned':pivot_table.iloc[-1, 0],
                '10%_poisoned':pivot_table.iloc[-1, 1],
                '20%_poisoned':pivot_table.iloc[-1, 2],
                '30%_poisoned':pivot_table.iloc[-1, 3],
                '40%_poisoned':pivot_table.iloc[-1, 4],
                '50%_poisoned':pivot_table.iloc[-1, 5],
            })
        if metric == 'acc_test':
            dt_acc_test_list.append({
                'EXPERIMENT':i_exp,
                '0%_poisoned':pivot_table.iloc[-1, 0],
                '10%_poisoned':pivot_table.iloc[-1, 1],
                '20%_poisoned':pivot_table.iloc[-1, 2],
                '30%_poisoned':pivot_table.iloc[-1, 3],
                '40%_poisoned':pivot_table.iloc[-1, 4],
                '50%_poisoned':pivot_table.iloc[-1, 5],
            })
        print("\n")

df_last_epoch_summary = pd.DataFrame(dt_last_epoch_list)
print("=== Summary of last epoch metrics ===")
print(df_last_epoch_summary)
df_loss_test_summary = pd.DataFrame(dt_loss_test_list)
print("=== Summary of loss_test ===")
print(df_loss_test_summary)
df_acc_test_summary = pd.DataFrame(dt_acc_test_list)
print("=== Summary of acc_test ===")
print(df_acc_test_summary)

df_last_epoch_summary.to_csv('results/summary_last_epoch_002.csv', index=False)
df_loss_test_summary.to_csv('results/summary_loss_test_002.csv', index=False)
df_acc_test_summary.to_csv('results/summary_acc_test_002.csv', index=False)

print("Done!")
# Out:
# === Experiment: CL_ModelN1L2_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# CL_ModelN1L2_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: CL_ModelN1L2_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.000123  0.286465  0.528879  0.347926  0.625577
# 1                         0.000275  0.336578  0.529128  0.400397  0.584186
# 2                         0.000156  0.212056  0.438375  0.460419  0.649515
# CL_ModelN1L2_Batchsize32  0.000156  0.286465  0.528879  0.400397  0.625577
#
# POISONED                        50
# 0                         0.686401
# 1                         0.665760
# 2                         0.645426
# CL_ModelN1L2_Batchsize32  0.665760
#
#
# === Experiment: CL_ModelN1L2_Batchsize32 - Metric: acc_train ===
# POISONED                   0        10        20        30        40      50
# 0                         1.0  0.90625  0.777778  1.000000  0.545455  0.5000
# 1                         1.0  0.87500  0.777778  0.833333  0.727273  0.6250
# 2                         1.0  0.93750  0.833333  0.833333  0.590909  0.5625
# CL_ModelN1L2_Batchsize32  1.0  0.90625  0.777778  0.833333  0.590909  0.5625
#
#
# === Experiment: CL_ModelN1L2_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.000494  0.132613  0.247097  0.390429  0.535648
# 1                         0.002938  0.109493  0.215725  0.372837  0.535073
# 2                         0.000772  0.136712  0.228826  0.400815  0.505998
# CL_ModelN1L2_Batchsize32  0.000772  0.132613  0.228826  0.390429  0.535073
#
# POISONED                        50
# 0                         0.688089
# 1                         0.687839
# 2                         0.768799
# CL_ModelN1L2_Batchsize32  0.688089
#
#
# === Experiment: CL_ModelN1L2_Batchsize32 - Metric: acc_test ===
# POISONED                       0         10        20        30        40  \
# 0                         1.00000  0.990306  0.976531  0.938776  0.840816
# 1                         0.99898  0.994388  0.982143  0.943878  0.846939
# 2                         0.99949  0.987755  0.984184  0.926020  0.880612
# CL_ModelN1L2_Batchsize32  0.99949  0.990306  0.982143  0.938776  0.846939
#
# POISONED                        50
# 0                         0.521429
# 1                         0.567857
# 2                         0.443878
# CL_ModelN1L2_Batchsize32  0.521429
#
#
# === Experiment: CL_ModelN1L3_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# CL_ModelN1L3_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: CL_ModelN1L3_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.000822  0.357872  0.588746  0.442916  0.652658
# 1                         0.692835  0.693011  0.692622  0.693149  0.693464
# 2                         0.000958  0.253581  0.384002  0.509615  0.660581
# CL_ModelN1L3_Batchsize32  0.000958  0.357872  0.588746  0.509615  0.660581
#
# POISONED                        50
# 0                         0.635570
# 1                         0.693333
# 2                         0.634428
# CL_ModelN1L3_Batchsize32  0.635570
#
#
# === Experiment: CL_ModelN1L3_Batchsize32 - Metric: acc_train ===
# POISONED                    0        10        20        30        40      50
# 0                         1.00  0.87500  0.722222  0.833333  0.590909  0.6875
# 1                         0.75  0.53125  0.666667  0.500000  0.409091  0.4375
# 2                         1.00  0.93750  0.833333  0.833333  0.681818  0.6875
# CL_ModelN1L3_Batchsize32  1.00  0.87500  0.722222  0.833333  0.590909  0.6875
#
#
# === Experiment: CL_ModelN1L3_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.001565  0.127932  0.238883  0.342619  0.553712
# 1                         0.693147  0.693150  0.693148  0.693149  0.693149
# 2                         0.002029  0.118965  0.249207  0.357778  0.525751
# CL_ModelN1L3_Batchsize32  0.002029  0.127932  0.249207  0.357778  0.553712
#
# POISONED                        50
# 0                         0.681204
# 1                         0.693148
# 2                         0.690967
# CL_ModelN1L3_Batchsize32  0.690967
#
#
# === Experiment: CL_ModelN1L3_Batchsize32 - Metric: acc_test ===
# POISONED                       0         10        20        30        40  \
# 0                         0.99949  0.996429  0.985714  0.980102  0.823469
# 1                         0.50000  0.500000  0.500000  0.500000  0.500000
# 2                         0.99949  0.993367  0.981633  0.968367  0.884694
# CL_ModelN1L3_Batchsize32  0.99949  0.993367  0.981633  0.968367  0.823469
#
# POISONED                        50
# 0                         0.600000
# 1                         0.500000
# 2                         0.613775
# CL_ModelN1L3_Batchsize32  0.600000
#
#
# === Experiment: CL_ModelN1L4_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# CL_ModelN1L4_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: CL_ModelN1L4_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.692792  0.692691  0.692596  0.695518  0.693507
# 1                         0.690974  0.695524  0.694005  0.694135  0.692818
# 2                         0.692619  0.693021  0.693208  0.693148  0.693543
# CL_ModelN1L4_Batchsize32  0.692619  0.693021  0.693208  0.694135  0.693507
#
# POISONED                        50
# 0                         0.693029
# 1                         0.693860
# 2                         0.693147
# CL_ModelN1L4_Batchsize32  0.693147
#
#
# === Experiment: CL_ModelN1L4_Batchsize32 - Metric: acc_train ===
# POISONED                     0        10        20        30        40      50
# 0                         0.625  0.59375  0.555556  0.333333  0.363636  0.5625
# 1                         0.625  0.25000  0.388889  0.000000  0.545455  0.4375
# 2                         0.625  0.53125  0.444444  0.500000  0.409091  0.5000
# CL_ModelN1L4_Batchsize32  0.625  0.53125  0.444444  0.333333  0.409091  0.5000
#
#
# === Experiment: CL_ModelN1L4_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.693148  0.693151  0.693160  0.693173  0.693148
# 1                         0.693187  0.693159  0.693154  0.693147  0.693155
# 2                         0.693149  0.693149  0.693147  0.693148  0.693149
# CL_ModelN1L4_Batchsize32  0.693149  0.693151  0.693154  0.693148  0.693149
#
# POISONED                        50
# 0                         0.693148
# 1                         0.693160
# 2                         0.693147
# CL_ModelN1L4_Batchsize32  0.693148
#
#
# === Experiment: CL_ModelN1L4_Batchsize32 - Metric: acc_test ===
# POISONED                   0    10   20   30   40   50
# 0                         0.5  0.5  0.5  0.5  0.5  0.5
# 1                         0.5  0.5  0.5  0.5  0.5  0.5
# 2                         0.5  0.5  0.5  0.5  0.5  0.5
# CL_ModelN1L4_Batchsize32  0.5  0.5  0.5  0.5  0.5  0.5
#
#
# === Experiment: CL_ModelN1L5_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# CL_ModelN1L5_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: CL_ModelN1L5_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.692468  0.693499  0.693959  0.696015  0.692899
# 1                         0.693149  0.693186  0.693261  0.692507  0.693024
# 2                         0.693561  0.693111  0.694437  0.693723  0.693434
# CL_ModelN1L5_Batchsize32  0.693149  0.693186  0.693959  0.693723  0.693024
#
# POISONED                        50
# 0                         0.693212
# 1                         0.693147
# 2                         0.693719
# CL_ModelN1L5_Batchsize32  0.693212
#
#
# === Experiment: CL_ModelN1L5_Batchsize32 - Metric: acc_train ===
# POISONED                     0        10        20        30        40      50
# 0                         0.625  0.40625  0.333333  0.000000  0.727273  0.4375
# 1                         0.500  0.46875  0.444444  0.666667  0.545455  0.5000
# 2                         0.250  0.53125  0.111111  0.333333  0.272727  0.1875
# CL_ModelN1L5_Batchsize32  0.500  0.46875  0.333333  0.333333  0.545455  0.4375
#
#
# === Experiment: CL_ModelN1L5_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.693152  0.693148  0.693149  0.693150  0.693147
# 1                         0.693149  0.693147  0.693148  0.693149  0.693148
# 2                         0.693147  0.693147  0.693148  0.693149  0.693147
# CL_ModelN1L5_Batchsize32  0.693149  0.693147  0.693148  0.693149  0.693147
#
# POISONED                        50
# 0                         0.693147
# 1                         0.693147
# 2                         0.693148
# CL_ModelN1L5_Batchsize32  0.693147
#
#
# === Experiment: CL_ModelN1L5_Batchsize32 - Metric: acc_test ===
# POISONED                   0    10   20   30   40   50
# 0                         0.5  0.5  0.5  0.5  0.5  0.5
# 1                         0.5  0.5  0.5  0.5  0.5  0.5
# 2                         0.5  0.5  0.5  0.5  0.5  0.5
# CL_ModelN1L5_Batchsize32  0.5  0.5  0.5  0.5  0.5  0.5
#
#
# === Experiment: CL_ModelN1L6_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# CL_ModelN1L6_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: CL_ModelN1L6_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.693546  0.693147  0.692929  0.692212  0.693256
# 1                         0.692997  0.693119  0.693263  0.692983  0.693754
# 2                         0.693152  0.693147  0.692851  0.693151  0.693173
# CL_ModelN1L6_Batchsize32  0.693152  0.693147  0.692929  0.692983  0.693256
#
# POISONED                       50
# 0                         0.69315
# 1                         0.69264
# 2                         0.69342
# CL_ModelN1L6_Batchsize32  0.69315
#
#
# === Experiment: CL_ModelN1L6_Batchsize32 - Metric: acc_train ===
# POISONED                     0       10        20        30        40      50
# 0                         0.375  0.5000  0.611111  0.666667  0.363636  0.5000
# 1                         0.625  0.5625  0.388889  0.666667  0.363636  0.6250
# 2                         0.500  0.5000  0.555556  0.500000  0.454545  0.4375
# CL_ModelN1L6_Batchsize32  0.500  0.5000  0.555556  0.666667  0.363636  0.5000
#
#
# === Experiment: CL_ModelN1L6_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.693148  0.693147  0.693148  0.693152  0.693147
# 1                         0.693147  0.693147  0.693147  0.693147  0.693150
# 2                         0.693152  0.693147  0.693151  0.693151  0.693147
# CL_ModelN1L6_Batchsize32  0.693148  0.693147  0.693148  0.693151  0.693147
#
# POISONED                        50
# 0                         0.693151
# 1                         0.693149
# 2                         0.693149
# CL_ModelN1L6_Batchsize32  0.693149
#
#
# === Experiment: CL_ModelN1L6_Batchsize32 - Metric: acc_test ===
# POISONED                   0    10   20   30   40   50
# 0                         0.5  0.5  0.5  0.5  0.5  0.5
# 1                         0.5  0.5  0.5  0.5  0.5  0.5
# 2                         0.5  0.5  0.5  0.5  0.5  0.5
# CL_ModelN1L6_Batchsize32  0.5  0.5  0.5  0.5  0.5  0.5
#
#
# === Experiment: FL_ModelN1L2_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# FL_ModelN1L2_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: FL_ModelN1L2_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.401031  0.925516  1.518342  2.129058  2.591367
# 1                         0.348698  0.455668  0.788524  1.172142  1.505652
# 2                         0.158330  0.783364  1.487406  2.066457  2.747168
# FL_ModelN1L2_Batchsize32  0.348698  0.783364  1.487406  2.066457  2.591367
#
# POISONED                        50
# 0                         2.624339
# 1                         1.649155
# 2                         2.813569
# FL_ModelN1L2_Batchsize32  2.624339
#
#
# === Experiment: FL_ModelN1L2_Batchsize32 - Metric: acc_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.491923  0.878777  0.791385  0.695266  0.597421
# 1                         0.976923  0.882212  0.792923  0.696073  0.597651
# 2                         0.991154  0.887706  0.796923  0.698225  0.597881
# FL_ModelN1L2_Batchsize32  0.976923  0.882212  0.792923  0.696073  0.597651
#
# POISONED                        50
# 0                         0.501538
# 1                         0.500385
# 2                         0.498846
# FL_ModelN1L2_Batchsize32  0.500385
#
#
# === Experiment: FL_ModelN1L2_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.385686  0.337408  0.291455  0.250010  0.214030
# 1                         0.339005  0.199345  0.159278  0.133973  0.115494
# 2                         0.157414  0.133956  0.114876  0.099757  0.087597
# FL_ModelN1L2_Batchsize32  0.339005  0.199345  0.159278  0.133973  0.115494
#
# POISONED                        50
# 0                         0.184542
# 1                         0.105467
# 2                         0.078969
# FL_ModelN1L2_Batchsize32  0.105467
#
#
# === Experiment: FL_ModelN1L2_Batchsize32 - Metric: acc_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.500000  0.977551  0.987245  0.991837  0.995408
# 1                         0.986224  0.994898  0.996429  0.997449  0.998980
# 2                         0.994388  0.994388  0.995408  0.997449  0.996939
# FL_ModelN1L2_Batchsize32  0.986224  0.994388  0.995408  0.997449  0.996939
#
# POISONED                        50
# 0                         0.997449
# 1                         0.999490
# 2                         0.997959
# FL_ModelN1L2_Batchsize32  0.997959
#
#
# === Experiment: FL_ModelN1L3_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# FL_ModelN1L3_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: FL_ModelN1L3_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.552511  0.544543  0.563143  0.614940  0.685451
# 1                         0.597226  0.701019  0.693846  0.693935  0.693204
# 2                         0.308382  0.659495  0.648952  0.657308  0.675877
# FL_ModelN1L3_Batchsize32  0.552511  0.659495  0.648952  0.657308  0.685451
#
# POISONED                        50
# 0                         0.751718
# 1                         0.693201
# 2                         0.696580
# FL_ModelN1L3_Batchsize32  0.696580
#
#
# === Experiment: FL_ModelN1L3_Batchsize32 - Metric: acc_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.995000  0.890110  0.797846  0.698763  0.599263
# 1                         0.494615  0.492102  0.507385  0.487897  0.442193
# 2                         0.979231  0.875343  0.799385  0.701452  0.601566
# FL_ModelN1L3_Batchsize32  0.979231  0.875343  0.797846  0.698763  0.599263
#
# POISONED                        50
# 0                         0.503654
# 1                         0.446346
# 2                         0.509038
# FL_ModelN1L3_Batchsize32  0.503654
#
#
# === Experiment: FL_ModelN1L3_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.551803  0.494644  0.448138  0.415824  0.399279
# 1                         0.589703  0.699187  0.694568  0.693362  0.693147
# 2                         0.300694  0.649703  0.618226  0.596623  0.585789
# FL_ModelN1L3_Batchsize32  0.551803  0.649703  0.618226  0.596623  0.585789
#
# POISONED                        50
# 0                         0.400780
# 1                         0.693147
# 2                         0.589736
# FL_ModelN1L3_Batchsize32  0.589736
#
#
# === Experiment: FL_ModelN1L3_Batchsize32 - Metric: acc_test ===
# POISONED                        0         10       20        30        40  \
# 0                         0.996939  0.998469  0.99898  0.998980  0.997959
# 1                         0.500000  0.500000  0.50000  0.500000  0.500000
# 2                         0.988775  0.981122  0.99898  0.998469  0.997449
# FL_ModelN1L3_Batchsize32  0.988775  0.981122  0.99898  0.998469  0.997449
#
# POISONED                        50
# 0                         0.996429
# 1                         0.500000
# 2                         0.984694
# FL_ModelN1L3_Batchsize32  0.984694
#
#
# === Experiment: FL_ModelN1L4_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# FL_ModelN1L4_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: FL_ModelN1L4_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.212134  0.560939  1.039312  1.527138  1.938021
# 1                         0.812684  0.738153  0.709052  0.696509  0.693606
# 2                         0.510646  0.518275  0.552165  0.613011  0.687475
# FL_ModelN1L4_Batchsize32  0.510646  0.560939  0.709052  0.696509  0.693606
#
# POISONED                        50
# 0                         1.923001
# 1                         0.693209
# 2                         0.760294
# FL_ModelN1L4_Batchsize32  0.760294
#
#
# === Experiment: FL_ModelN1L4_Batchsize32 - Metric: acc_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.984615  0.886676  0.793538  0.697956  0.598342
# 1                         0.513462  0.510646  0.494769  0.495428  0.502073
# 2                         0.997692  0.891827  0.799385  0.699301  0.600875
# FL_ModelN1L4_Batchsize32  0.984615  0.886676  0.793538  0.697956  0.598342
#
# POISONED                        50
# 0                         0.499808
# 1                         0.500385
# 2                         0.505577
# FL_ModelN1L4_Batchsize32  0.500385
#
#
# === Experiment: FL_ModelN1L4_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.201850  0.142311  0.120172  0.101959  0.086940
# 1                         0.826387  0.744801  0.707153  0.695774  0.693671
# 2                         0.510941  0.461914  0.421402  0.393147  0.380302
# FL_ModelN1L4_Batchsize32  0.510941  0.461914  0.421402  0.393147  0.380302
#
# POISONED                        50
# 0                         0.078342
# 1                         0.693158
# 2                         0.386429
# FL_ModelN1L4_Batchsize32  0.386429
#
#
# === Experiment: FL_ModelN1L4_Batchsize32 - Metric: acc_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.994898  0.995918  0.996429  0.997449  0.998980
# 1                         0.500000  0.500000  0.500000  0.500000  0.500000
# 2                         0.998980  0.998980  0.998980  0.998980  0.996939
# FL_ModelN1L4_Batchsize32  0.994898  0.995918  0.996429  0.997449  0.996939
#
# POISONED                        50
# 0                         0.999490
# 1                         0.500000
# 2                         0.990816
# FL_ModelN1L4_Batchsize32  0.990816
#
#
# === Experiment: FL_ModelN1L5_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# FL_ModelN1L5_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: FL_ModelN1L5_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.730131  0.713195  0.699252  0.694020  0.693758
# 1                         0.723236  0.704142  0.698321  0.693193  0.693107
# 2                         0.693602  0.693209  0.693205  0.693201  0.693206
# FL_ModelN1L5_Batchsize32  0.723236  0.704142  0.698321  0.693201  0.693206
#
# POISONED                        50
# 0                         0.693206
# 1                         0.693205
# 2                         0.693203
# FL_ModelN1L5_Batchsize32  0.693205
#
#
# === Experiment: FL_ModelN1L5_Batchsize32 - Metric: acc_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.507308  0.497940  0.503077  0.506993  0.494012
# 1                         0.493846  0.499657  0.487692  0.509145  0.508291
# 2                         0.496154  0.439217  0.441231  0.445670  0.440811
# FL_ModelN1L5_Batchsize32  0.496154  0.497940  0.487692  0.506993  0.494012
#
# POISONED                        50
# 0                         0.441346
# 1                         0.441923
# 2                         0.444231
# FL_ModelN1L5_Batchsize32  0.441923
#
#
# === Experiment: FL_ModelN1L5_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.734224  0.712298  0.699888  0.694737  0.693411
# 1                         0.720233  0.703951  0.696280  0.693783  0.693177
# 2                         0.693371  0.693147  0.693147  0.693147  0.693147
# FL_ModelN1L5_Batchsize32  0.720233  0.703951  0.696280  0.693783  0.693177
#
# POISONED                        50
# 0                         0.693147
# 1                         0.693147
# 2                         0.693147
# FL_ModelN1L5_Batchsize32  0.693147
#
#
# === Experiment: FL_ModelN1L5_Batchsize32 - Metric: acc_test ===
# POISONED                   0    10   20   30   40   50
# 0                         0.5  0.5  0.5  0.5  0.5  0.5
# 1                         0.5  0.5  0.5  0.5  0.5  0.5
# 2                         0.5  0.5  0.5  0.5  0.5  0.5
# FL_ModelN1L5_Batchsize32  0.5  0.5  0.5  0.5  0.5  0.5
#
#
# === Experiment: FL_ModelN1L6_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# FL_ModelN1L6_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: FL_ModelN1L6_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.693352  0.693375  0.693379  0.693370  0.693395
# 1                         0.696692  0.693770  0.693216  0.693205  0.693203
# 2                         0.713002  0.693778  0.693260  0.693269  0.693278
# FL_ModelN1L6_Batchsize32  0.696692  0.693770  0.693260  0.693269  0.693278
#
# POISONED                        50
# 0                         0.693380
# 1                         0.693201
# 2                         0.693293
# FL_ModelN1L6_Batchsize32  0.693293
#
#
# === Experiment: FL_ModelN1L6_Batchsize32 - Metric: acc_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.447692  0.442308  0.441231  0.443518  0.437126
# 1                         0.500769  0.502404  0.501538  0.442442  0.444265
# 2                         0.489231  0.506868  0.449538  0.444325  0.442423
# FL_ModelN1L6_Batchsize32  0.489231  0.502404  0.449538  0.443518  0.442423
#
# POISONED                        50
# 0                         0.440577
# 1                         0.447115
# 2                         0.435769
# FL_ModelN1L6_Batchsize32  0.440577
#
#
# === Experiment: FL_ModelN1L6_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.693147  0.693147  0.693147  0.693147  0.693147
# 1                         0.696749  0.693892  0.693186  0.693147  0.693147
# 2                         0.708940  0.694289  0.693147  0.693147  0.693147
# FL_ModelN1L6_Batchsize32  0.696749  0.693892  0.693147  0.693147  0.693147
#
# POISONED                        50
# 0                         0.693147
# 1                         0.693147
# 2                         0.693147
# FL_ModelN1L6_Batchsize32  0.693147
#
#
# === Experiment: FL_ModelN1L6_Batchsize32 - Metric: acc_test ===
# POISONED                   0    10   20   30   40   50
# 0                         0.5  0.5  0.5  0.5  0.5  0.5
# 1                         0.5  0.5  0.5  0.5  0.5  0.5
# 2                         0.5  0.5  0.5  0.5  0.5  0.5
# FL_ModelN1L6_Batchsize32  0.5  0.5  0.5  0.5  0.5  0.5
#
#
# === Summary of last epoch metrics ===
#                  EXPERIMENT  0%_poisoned  10%_poisoned  20%_poisoned  \
# 0  CL_ModelN1L2_Batchsize32           99            99            99
# 1  CL_ModelN1L3_Batchsize32           99            99            99
# 2  CL_ModelN1L4_Batchsize32           99            99            99
# 3  CL_ModelN1L5_Batchsize32           99            99            99
# 4  CL_ModelN1L6_Batchsize32           99            99            99
# 5  FL_ModelN1L2_Batchsize32           99            99            99
# 6  FL_ModelN1L3_Batchsize32           99            99            99
# 7  FL_ModelN1L4_Batchsize32           99            99            99
# 8  FL_ModelN1L5_Batchsize32           99            99            99
# 9  FL_ModelN1L6_Batchsize32           99            99            99
#
#    30%_poisoned  40%_poisoned  50%_poisoned
# 0            99            99            99
# 1            99            99            99
# 2            99            99            99
# 3            99            99            99
# 4            99            99            99
# 5            99            99            99
# 6            99            99            99
# 7            99            99            99
# 8            99            99            99
# 9            99            99            99
# === Summary of loss_test ===
#                  EXPERIMENT  0%_poisoned  10%_poisoned  20%_poisoned  \
# 0  CL_ModelN1L2_Batchsize32     0.000772      0.132613      0.228826
# 1  CL_ModelN1L3_Batchsize32     0.002029      0.127932      0.249207
# 2  CL_ModelN1L4_Batchsize32     0.693149      0.693151      0.693154
# 3  CL_ModelN1L5_Batchsize32     0.693149      0.693147      0.693148
# 4  CL_ModelN1L6_Batchsize32     0.693148      0.693147      0.693148
# 5  FL_ModelN1L2_Batchsize32     0.339005      0.199345      0.159278
# 6  FL_ModelN1L3_Batchsize32     0.551803      0.649703      0.618226
# 7  FL_ModelN1L4_Batchsize32     0.510941      0.461914      0.421402
# 8  FL_ModelN1L5_Batchsize32     0.720233      0.703951      0.696280
# 9  FL_ModelN1L6_Batchsize32     0.696749      0.693892      0.693147
#
#    30%_poisoned  40%_poisoned  50%_poisoned
# 0      0.390429      0.535073      0.688089
# 1      0.357778      0.553712      0.690967
# 2      0.693148      0.693149      0.693148
# 3      0.693149      0.693147      0.693147
# 4      0.693151      0.693147      0.693149
# 5      0.133973      0.115494      0.105467
# 6      0.596623      0.585789      0.589736
# 7      0.393147      0.380302      0.386429
# 8      0.693783      0.693177      0.693147
# 9      0.693147      0.693147      0.693147
# === Summary of acc_test ===
#                  EXPERIMENT  0%_poisoned  10%_poisoned  20%_poisoned  \
# 0  CL_ModelN1L2_Batchsize32     0.999490      0.990306      0.982143
# 1  CL_ModelN1L3_Batchsize32     0.999490      0.993367      0.981633
# 2  CL_ModelN1L4_Batchsize32     0.500000      0.500000      0.500000
# 3  CL_ModelN1L5_Batchsize32     0.500000      0.500000      0.500000
# 4  CL_ModelN1L6_Batchsize32     0.500000      0.500000      0.500000
# 5  FL_ModelN1L2_Batchsize32     0.986224      0.994388      0.995408
# 6  FL_ModelN1L3_Batchsize32     0.988775      0.981122      0.998980
# 7  FL_ModelN1L4_Batchsize32     0.994898      0.995918      0.996429
# 8  FL_ModelN1L5_Batchsize32     0.500000      0.500000      0.500000
# 9  FL_ModelN1L6_Batchsize32     0.500000      0.500000      0.500000
#
#    30%_poisoned  40%_poisoned  50%_poisoned
# 0      0.938776      0.846939      0.521429
# 1      0.968367      0.823469      0.600000
# 2      0.500000      0.500000      0.500000
# 3      0.500000      0.500000      0.500000
# 4      0.500000      0.500000      0.500000
# 5      0.997449      0.996939      0.997959
# 6      0.998469      0.997449      0.984694
# 7      0.997449      0.996939      0.990816
# 8      0.500000      0.500000      0.500000
# 9      0.500000      0.500000      0.500000
# Done!
