# %%
import pandas as pd

NODE = [1]
LAYER = [2,3,4,5,6]
REV = [0,1,2]
APPROACH = ['CL','FL']
POISONED = [0,10,20,30,40,50]
METRICS = ['loss_train', 'acc_train', 'loss_test', 'acc_test']
result_path = 'results'

dt_list = []

for a in APPROACH:
    for n in NODE:
        for l in LAYER:
            for r in REV:
                exp_name = f'{a}_ModelN{n}L{l}_Batchsize32'
                exp_rev_name = f'{a}_ModelN{n}L{l}_Batchsize32_rev{r}'
                for p in POISONED:
                    sub_f_name = f'poisoned_{p}percent'
                    
                    dt_list.append({
                        'NODE':n,
                        'LAYER':l,
                        'REV':r,
                        'APPROACH':a,
                        'EXPERIMENT':exp_name,
                        'EXPERIMENT_REV':exp_rev_name,
                        'POISONED':p,
                        'SUB_FLODER':sub_f_name,
                        'CSV':f'{result_path}\{exp_rev_name}\{sub_f_name}\{sub_f_name}.csv',
                    })

df_exp = pd.DataFrame(dt_list)
print(df_exp.head())
# Out:
# <string>:31: SyntaxWarning: invalid escape sequence '\{'
# <string>:31: SyntaxWarning: invalid escape sequence '\{'
# <string>:31: SyntaxWarning: invalid escape sequence '\{'
# <>:31: SyntaxWarning: invalid escape sequence '\{'
# <>:31: SyntaxWarning: invalid escape sequence '\{'
# <>:31: SyntaxWarning: invalid escape sequence '\{'
# <string>:31: SyntaxWarning: invalid escape sequence '\{'
# <string>:31: SyntaxWarning: invalid escape sequence '\{'
# <string>:31: SyntaxWarning: invalid escape sequence '\{'
# <>:31: SyntaxWarning: invalid escape sequence '\{'
# <>:31: SyntaxWarning: invalid escape sequence '\{'
# <>:31: SyntaxWarning: invalid escape sequence '\{'
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_13428\1723101382.py:31: SyntaxWarning: invalid escape sequence '\{'
#   'CSV':f'{result_path}\{exp_rev_name}\{sub_f_name}\{sub_f_name}.csv',
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_13428\1723101382.py:31: SyntaxWarning: invalid escape sequence '\{'
#   'CSV':f'{result_path}\{exp_rev_name}\{sub_f_name}\{sub_f_name}.csv',
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_13428\1723101382.py:31: SyntaxWarning: invalid escape sequence '\{'
#   'CSV':f'{result_path}\{exp_rev_name}\{sub_f_name}\{sub_f_name}.csv',
#    NODE  LAYER  REV APPROACH                EXPERIMENT  \
# 0     1      2    0       CL  CL_ModelN1L2_Batchsize32
# 1     1      2    0       CL  CL_ModelN1L2_Batchsize32
# 2     1      2    0       CL  CL_ModelN1L2_Batchsize32
# 3     1      2    0       CL  CL_ModelN1L2_Batchsize32
# 4     1      2    0       CL  CL_ModelN1L2_Batchsize32
#
#                   EXPERIMENT_REV  POISONED          SUB_FLODER  \
# 0  CL_ModelN1L2_Batchsize32_rev0         0   poisoned_0percent
# 1  CL_ModelN1L2_Batchsize32_rev0        10  poisoned_10percent
# 2  CL_ModelN1L2_Batchsize32_rev0        20  poisoned_20percent
# 3  CL_ModelN1L2_Batchsize32_rev0        30  poisoned_30percent
# 4  CL_ModelN1L2_Batchsize32_rev0        40  poisoned_40percent
#
#                                                  CSV
# 0  results\CL_ModelN1L2_Batchsize32_rev0\poisoned...
# 1  results\CL_ModelN1L2_Batchsize32_rev0\poisoned...
# 2  results\CL_ModelN1L2_Batchsize32_rev0\poisoned...
# 3  results\CL_ModelN1L2_Batchsize32_rev0\poisoned...
# 4  results\CL_ModelN1L2_Batchsize32_rev0\poisoned...

# %%
import pandas as pd
import matplotlib.pyplot as plt

exp_name_list = df_exp['EXPERIMENT'].unique()
# Loop through each CSV file
for i_exp in exp_name_list:

        df_filter = df_exp[df_exp['EXPERIMENT']==i_exp]
             
               
        # Create figure with subplots
        fig, axes = plt.subplots(4, 3, figsize=(12, 10))
        fig.suptitle(f"{i_exp}", fontsize=16)

        for idx,row in df_filter.iterrows():
                
            csv_file = row['CSV']
            sub_f_name = row['SUB_FLODER']
            rev = row['REV']

            # Read CSV into DataFrame
            df = pd.read_csv(csv_file)
            
            
            # Check if required columns exist
            ep_rnd = 'epoch'
            if row['APPROACH'] == 'FL':
                 ep_rnd = 'round'
            required_cols = [ep_rnd]+METRICS
            if not all(col in df.columns for col in required_cols):
                print(f"Skipping {csv_file}: Missing required columns")
                continue

            for i_metric, metric in enumerate(METRICS):
            
                # axes[i_metric, rev].plot(df[ep_rnd], df[metric], marker='o', label=f'{sub_f_name}')
                axes[i_metric, rev].plot(df[ep_rnd], df[metric], label=f'{sub_f_name}')


        for i_metric, metric in enumerate(METRICS):
             for rev in REV:
                axes[i_metric, rev].set_title(f'Rev{rev}')
                axes[i_metric, rev].set_xlabel(ep_rnd)
                axes[i_metric, rev].set_ylabel(f'{metric}')
                axes[i_metric, rev].grid(True)
                # if i_metric==0 and rev ==0:
                    # axes[i_metric, rev].legend()
                    # move legend to bottom out of chart
                    
        # collect handles/labels from the plotted axes (use first row or aggregate)
        handles, labels = [], []
        for rev in [0]:#REV:
            h, l = axes[0, rev].get_legend_handles_labels()
            handles.extend(h)
            labels.extend(l)

        # place a single legend below the figure
        if handles:
            fig.legend(handles, labels, loc='lower center',
                       bbox_to_anchor=(0.5, -0.02), ncol=min(len(labels), 6),
                       frameon=False)

        # leave space for the legend at the bottom
        plt.tight_layout(rect=[0, 0.06, 1, 1])
        # plt.tight_layout()
        
        # Save figure
        # output_name = csv_file.replace('.csv', '_plot.png')
        # plt.savefig(output_name, dpi=300, bbox_inches='tight')
        # print(f"✓ Plotted: {csv_file} -> {output_name}")
        
        plt.show()


# get table value from df_exp for each experiment
dt_list = []
for i_exp in exp_name_list:

        df_filter = df_exp[df_exp['EXPERIMENT']==i_exp]
        
        for idx,row in df_filter.iterrows():
                
            csv_file = row['CSV']
            sub_f_name = row['SUB_FLODER']
            rev = row['REV']

            # Read CSV into DataFrame
            df = pd.read_csv(csv_file)
            
            # Check if required columns exist
            ep_rnd = 'epoch'
            if row['APPROACH'] == 'FL':
                 ep_rnd = 'round'
            required_cols = [ep_rnd]+METRICS
            if not all(col in df.columns for col in required_cols):
                print(f"Skipping {csv_file}: Missing required columns")
                continue

            # get last row values
            last_row = df.iloc[-1]
            # find settle epoch where loss_test does not change more than 0.01 for 5 consecutive epochs
            settle_epoch = df[ep_rnd].iloc[-1]
            # for i in range(len(df)-5):
            #     if all(abs(df['loss_test'].iloc[i+j] - df['loss_test'].iloc[i+j+1]) < 0.05 for j in range(5)):
            #         settle_epoch = df[ep_rnd].iloc[i]
            #         break
            # if settle_epoch is not None:
            #     last_row = df[df[ep_rnd]==settle_epoch].iloc[0]

            data_entry = {
                'NODE':row['NODE'],
                'LAYER':row['LAYER'],
                'REV':rev,
                'APPROACH':row['APPROACH'],
                'EXPERIMENT':i_exp,
                'POISONED':row['POISONED'],
                'SUB_FLODER':sub_f_name,
                'SETTLE_EPOCH':settle_epoch,
            }
            for metric in METRICS:
                data_entry[metric] = last_row[metric]
            dt_list.append(data_entry)
df_results = pd.DataFrame(dt_list)

# list acc_test
dt_last_epoch_list = []
dt_loss_test_list = []
dt_acc_test_list = []
# pivot table for each experiment
# columns by POISONED, index by REV, values by METRICS
for i_exp in exp_name_list:
    df_filter = df_results[df_results['EXPERIMENT']==i_exp]

    pivot_table = df_filter.pivot(index='REV', columns='POISONED', values='SETTLE_EPOCH')
    mediamn_row = pivot_table.median()
    mediamn_row.name = i_exp
    pivot_table = pd.concat([pivot_table, mediamn_row.to_frame().T])
    for col in pivot_table.columns:
        pivot_table[col] = pivot_table[col].astype(int)
    print(f"=== Experiment: {i_exp} - Settle Epoch ===")
    print(pivot_table)
    print("\n")
    dt_last_epoch_list.append({
        'EXPERIMENT':i_exp,
        '0%_poisoned':pivot_table.iloc[-1, 0],
        '10%_poisoned':pivot_table.iloc[-1, 1],
        '20%_poisoned':pivot_table.iloc[-1, 2],
        '30%_poisoned':pivot_table.iloc[-1, 3],
        '40%_poisoned':pivot_table.iloc[-1, 4],
        '50%_poisoned':pivot_table.iloc[-1, 5],
    })

    for metric in METRICS:
        pivot_table = df_filter.pivot(index='REV', columns='POISONED', values=metric)
        # add last median row
        median_row = pivot_table.median()
        median_row.name = i_exp
        pivot_table = pd.concat([pivot_table, median_row.to_frame().T])
        print(f"=== Experiment: {i_exp} - Metric: {metric} ===")
        print(pivot_table)
        if metric == 'loss_test':
            dt_loss_test_list.append({
                'EXPERIMENT':i_exp,
                '0%_poisoned':pivot_table.iloc[-1, 0],
                '10%_poisoned':pivot_table.iloc[-1, 1],
                '20%_poisoned':pivot_table.iloc[-1, 2],
                '30%_poisoned':pivot_table.iloc[-1, 3],
                '40%_poisoned':pivot_table.iloc[-1, 4],
                '50%_poisoned':pivot_table.iloc[-1, 5],
            })
        if metric == 'acc_test':
            dt_acc_test_list.append({
                'EXPERIMENT':i_exp,
                '0%_poisoned':pivot_table.iloc[-1, 0],
                '10%_poisoned':pivot_table.iloc[-1, 1],
                '20%_poisoned':pivot_table.iloc[-1, 2],
                '30%_poisoned':pivot_table.iloc[-1, 3],
                '40%_poisoned':pivot_table.iloc[-1, 4],
                '50%_poisoned':pivot_table.iloc[-1, 5],
            })
        print("\n")

df_last_epoch_summary = pd.DataFrame(dt_last_epoch_list)
print("=== Summary of last epoch metrics ===")
print(df_last_epoch_summary)
df_loss_test_summary = pd.DataFrame(dt_loss_test_list)
print("=== Summary of loss_test ===")
print(df_loss_test_summary)
df_acc_test_summary = pd.DataFrame(dt_acc_test_list)
print("=== Summary of acc_test ===")
print(df_acc_test_summary)

df_last_epoch_summary.to_csv('results/summary_last_epoch_002.csv', index=False)
df_loss_test_summary.to_csv('results/summary_loss_test_002.csv', index=False)
df_acc_test_summary.to_csv('results/summary_acc_test_002.csv', index=False)

print("Done!")
# Out:
# === Experiment: CL_ModelN1L2_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# CL_ModelN1L2_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: CL_ModelN1L2_Batchsize32 - Metric: loss_train ===
# POISONED                            0         10        20        30  \
# 0                         1.266602e-06  0.288711  0.624325  0.505384
# 1                         1.192093e-07  0.328084  0.248854  0.777869
# 2                         1.192093e-07  0.342863  0.324271  0.627650
# CL_ModelN1L2_Batchsize32  1.192093e-07  0.328084  0.324271  0.627650
#
# POISONED                        40        50
# 0                         0.686992  0.666669
# 1                         0.638964  0.703407
# 2                         0.635499  0.663096
# CL_ModelN1L2_Batchsize32  0.638964  0.666669
#
#
# === Experiment: CL_ModelN1L2_Batchsize32 - Metric: acc_train ===
# POISONED                   0        10        20        30        40      50
# 0                         1.0  0.90625  0.722222  0.833333  0.590909  0.5625
# 1                         1.0  0.87500  1.000000  0.500000  0.681818  0.5000
# 2                         1.0  0.87500  0.944444  0.666667  0.727273  0.5625
# CL_ModelN1L2_Batchsize32  1.0  0.87500  0.944444  0.666667  0.681818  0.5625
#
#
# === Experiment: CL_ModelN1L2_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.003485  0.111453  0.235695  0.365094  0.529510
# 1                         0.002427  0.100416  0.252417  0.368605  0.521145
# 2                         0.001057  0.117375  0.249029  0.363548  0.532535
# CL_ModelN1L2_Batchsize32  0.002427  0.111453  0.249029  0.365094  0.529510
#
# POISONED                        50
# 0                         0.685141
# 1                         0.720962
# 2                         0.709234
# CL_ModelN1L2_Batchsize32  0.709234
#
#
# === Experiment: CL_ModelN1L2_Batchsize32 - Metric: acc_test ===
# POISONED                       0        10        20        30        40  \
# 0                         0.99898  0.99898  0.995408  0.981122  0.909694
# 1                         0.99949  0.99949  0.993367  0.982653  0.920918
# 2                         0.99949  0.99898  0.992857  0.985714  0.922449
# CL_ModelN1L2_Batchsize32  0.99949  0.99898  0.993367  0.982653  0.920918
#
# POISONED                        50
# 0                         0.561224
# 1                         0.458163
# 2                         0.469898
# CL_ModelN1L2_Batchsize32  0.469898
#
#
# === Experiment: CL_ModelN1L3_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# CL_ModelN1L3_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: CL_ModelN1L3_Batchsize32 - Metric: loss_train ===
# POISONED                            0         10        20        30  \
# 0                         1.192093e-07  0.339700  0.616106  0.478540
# 1                         1.192093e-07  0.251694  0.559457  0.520567
# 2                         6.930935e-01  0.693362  0.693147  0.693150
# CL_ModelN1L3_Batchsize32  1.192093e-07  0.339700  0.616106  0.520567
#
# POISONED                        40        50
# 0                         0.645527  0.616034
# 1                         0.609108  0.658249
# 2                         0.693141  0.693280
# CL_ModelN1L3_Batchsize32  0.645527  0.658249
#
#
# === Experiment: CL_ModelN1L3_Batchsize32 - Metric: acc_train ===
# POISONED                     0        10        20        30        40      50
# 0                         1.000  0.90625  0.722222  0.833333  0.636364  0.5625
# 1                         1.000  0.93750  0.777778  0.833333  0.727273  0.6875
# 2                         0.625  0.40625  0.500000  0.500000  0.590909  0.3750
# CL_ModelN1L3_Batchsize32  1.000  0.90625  0.722222  0.833333  0.636364  0.5625
#
#
# === Experiment: CL_ModelN1L3_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.005516  0.121777  0.247080  0.347336  0.519285
# 1                         0.001530  0.117799  0.241963  0.375729  0.527829
# 2                         0.693147  0.693148  0.693147  0.693150  0.693147
# CL_ModelN1L3_Batchsize32  0.005516  0.121777  0.247080  0.375729  0.527829
#
# POISONED                        50
# 0                         0.692285
# 1                         0.673730
# 2                         0.693147
# CL_ModelN1L3_Batchsize32  0.692285
#
#
# === Experiment: CL_ModelN1L3_Batchsize32 - Metric: acc_test ===
# POISONED                       0         10        20        30        40  \
# 0                         0.99949  0.999490  0.994388  0.988265  0.905102
# 1                         0.99898  0.998469  0.996939  0.980102  0.905612
# 2                         0.50000  0.500000  0.500000  0.500000  0.500000
# CL_ModelN1L3_Batchsize32  0.99898  0.998469  0.994388  0.980102  0.905102
#
# POISONED                        50
# 0                         0.555612
# 1                         0.610714
# 2                         0.500000
# CL_ModelN1L3_Batchsize32  0.555612
#
#
# === Experiment: CL_ModelN1L4_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# CL_ModelN1L4_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: CL_ModelN1L4_Batchsize32 - Metric: loss_train ===
# POISONED                            0         10        20        30  \
# 0                         6.932755e-01  0.693097  0.693614  0.693151
# 1                         1.192093e-07  0.242259  0.466862  0.773184
# 2                         1.192093e-07  0.213049  0.497789  0.659489
# CL_ModelN1L4_Batchsize32  1.192093e-07  0.242259  0.497789  0.693151
#
# POISONED                        40        50
# 0                         0.693214  0.692760
# 1                         0.648853  0.678484
# 2                         0.689825  0.670586
# CL_ModelN1L4_Batchsize32  0.689825  0.678484
#
#
# === Experiment: CL_ModelN1L4_Batchsize32 - Metric: acc_train ===
# POISONED                     0        10        20   30        40      50
# 0                         0.375  0.53125  0.333333  0.5  0.409091  0.5625
# 1                         1.000  0.90625  0.722222  0.5  0.545455  0.6875
# 2                         1.000  0.93750  0.777778  0.5  0.545455  0.6250
# CL_ModelN1L4_Batchsize32  1.000  0.90625  0.722222  0.5  0.545455  0.6250
#
#
# === Experiment: CL_ModelN1L4_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.693147  0.693147  0.693148  0.693150  0.693147
# 1                         0.007708  0.119305  0.238387  0.384548  0.532976
# 2                         0.003593  0.114067  0.233345  0.372142  0.527995
# CL_ModelN1L4_Batchsize32  0.007708  0.119305  0.238387  0.384548  0.532976
#
# POISONED                        50
# 0                         0.693152
# 1                         0.705855
# 2                         0.693957
# CL_ModelN1L4_Batchsize32  0.693957
#
#
# === Experiment: CL_ModelN1L4_Batchsize32 - Metric: acc_test ===
# POISONED                       0         10        20        30        40  \
# 0                         0.50000  0.500000  0.500000  0.500000  0.500000
# 1                         0.99898  0.996429  0.988265  0.970408  0.889796
# 2                         0.99949  0.998469  0.997959  0.983673  0.893878
# CL_ModelN1L4_Batchsize32  0.99898  0.996429  0.988265  0.970408  0.889796
#
# POISONED                        50
# 0                         0.500000
# 1                         0.521429
# 2                         0.533673
# CL_ModelN1L4_Batchsize32  0.521429
#
#
# === Experiment: CL_ModelN1L5_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# CL_ModelN1L5_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: CL_ModelN1L5_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.693163  0.692745  0.692923  0.693408  0.692790
# 1                         0.000011  0.287254  0.509138  0.714969  0.707121
# 2                         0.693149  0.693059  0.693150  0.693193  0.693402
# CL_ModelN1L5_Batchsize32  0.693149  0.692745  0.692923  0.693408  0.693402
#
# POISONED                        50
# 0                         0.692335
# 1                         0.672883
# 2                         0.693147
# CL_ModelN1L5_Batchsize32  0.692335
#
#
# === Experiment: CL_ModelN1L5_Batchsize32 - Metric: acc_train ===
# POISONED                     0        10        20        30        40      50
# 0                         0.375  0.59375  0.611111  0.333333  0.681818  0.6875
# 1                         1.000  0.90625  0.777778  0.666667  0.545455  0.6875
# 2                         0.500  0.62500  0.500000  0.333333  0.454545  0.5000
# CL_ModelN1L5_Batchsize32  0.500  0.62500  0.611111  0.333333  0.545455  0.6875
#
#
# === Experiment: CL_ModelN1L5_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.693147  0.693149  0.693148  0.693147  0.693148
# 1                         0.003115  0.134656  0.224065  0.383912  0.492629
# 2                         0.693149  0.693147  0.693150  0.693147  0.693151
# CL_ModelN1L5_Batchsize32  0.693147  0.693147  0.693148  0.693147  0.693148
#
# POISONED                        50
# 0                         0.693150
# 1                         0.698126
# 2                         0.693147
# CL_ModelN1L5_Batchsize32  0.693150
#
#
# === Experiment: CL_ModelN1L5_Batchsize32 - Metric: acc_test ===
# POISONED                        0         10        20       30        40  \
# 0                         0.500000  0.500000  0.500000  0.50000  0.500000
# 1                         0.998469  0.997959  0.995918  0.97551  0.895918
# 2                         0.500000  0.500000  0.500000  0.50000  0.500000
# CL_ModelN1L5_Batchsize32  0.500000  0.500000  0.500000  0.50000  0.500000
#
# POISONED                       50
# 0                         0.50000
# 1                         0.55102
# 2                         0.50000
# CL_ModelN1L5_Batchsize32  0.50000
#
#
# === Experiment: CL_ModelN1L6_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# CL_ModelN1L6_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: CL_ModelN1L6_Batchsize32 - Metric: loss_train ===
# POISONED                            0         10        20        30  \
# 0                         1.415610e-07  0.337752  0.631246  0.782218
# 1                         6.933235e-01  0.693148  0.693251  0.691747
# 2                         6.928208e-01  0.693474  0.693150  0.692422
# CL_ModelN1L6_Batchsize32  6.928208e-01  0.693148  0.693150  0.692422
#
# POISONED                        40        50
# 0                         0.613059  0.683777
# 1                         0.693298  0.693150
# 2                         0.693252  0.693150
# CL_ModelN1L6_Batchsize32  0.693252  0.693150
#
#
# === Experiment: CL_ModelN1L6_Batchsize32 - Metric: acc_train ===
# POISONED                     0        10        20        30        40      50
# 0                         1.000  0.90625  0.666667  0.500000  0.681818  0.5625
# 1                         0.375  0.50000  0.444444  0.833333  0.454545  0.5000
# 2                         0.625  0.37500  0.500000  0.666667  0.454545  0.5000
# CL_ModelN1L6_Batchsize32  0.625  0.50000  0.500000  0.666667  0.454545  0.5000
#
#
# === Experiment: CL_ModelN1L6_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.001229  0.134181  0.249236  0.367463  0.519034
# 1                         0.693147  0.693148  0.693148  0.693150  0.693148
# 2                         0.693148  0.693148  0.693150  0.693149  0.693148
# CL_ModelN1L6_Batchsize32  0.693147  0.693148  0.693148  0.693149  0.693148
#
# POISONED                        50
# 0                         0.692898
# 1                         0.693150
# 2                         0.693150
# CL_ModelN1L6_Batchsize32  0.693150
#
#
# === Experiment: CL_ModelN1L6_Batchsize32 - Metric: acc_test ===
# POISONED                       0        10        20        30        40  \
# 0                         0.99949  0.99898  0.997449  0.985204  0.890306
# 1                         0.50000  0.50000  0.500000  0.500000  0.500000
# 2                         0.50000  0.50000  0.500000  0.500000  0.500000
# CL_ModelN1L6_Batchsize32  0.50000  0.50000  0.500000  0.500000  0.500000
#
# POISONED                        50
# 0                         0.538776
# 1                         0.500000
# 2                         0.500000
# CL_ModelN1L6_Batchsize32  0.500000
#
#
# === Experiment: FL_ModelN1L2_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# FL_ModelN1L2_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: FL_ModelN1L2_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.055847  0.876375  1.860392  2.744964  3.121215
# 1                         0.030971  1.055090  2.196134  3.160162  3.532160
# 2                         0.133320  0.683895  1.592506  2.329474  2.641927
# FL_ModelN1L2_Batchsize32  0.055847  0.876375  1.860392  2.744964  3.121215
#
# POISONED                        50
# 0                         2.730195
# 1                         2.994008
# 2                         2.352408
# FL_ModelN1L2_Batchsize32  2.730195
#
#
# === Experiment: FL_ModelN1L2_Batchsize32 - Metric: acc_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.992308  0.888736  0.800000  0.697687  0.598802
# 1                         0.991538  0.887706  0.796615  0.699301  0.599033
# 2                         0.990769  0.885989  0.797846  0.698494  0.599033
# FL_ModelN1L2_Batchsize32  0.991538  0.887706  0.797846  0.698494  0.599033
#
# POISONED                        50
# 0                         0.501154
# 1                         0.501923
# 2                         0.499615
# FL_ModelN1L2_Batchsize32  0.501154
#
#
# === Experiment: FL_ModelN1L2_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.049400  0.011529  0.009364  0.009324  0.013028
# 1                         0.023029  0.010110  0.007413  0.005995  0.008081
# 2                         0.126015  0.020056  0.011749  0.010241  0.013103
# FL_ModelN1L2_Batchsize32  0.049400  0.011529  0.009364  0.009324  0.013028
#
# POISONED                        50
# 0                         0.033802
# 1                         0.023196
# 2                         0.030142
# FL_ModelN1L2_Batchsize32  0.030142
#
#
# === Experiment: FL_ModelN1L2_Batchsize32 - Metric: acc_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.994898  0.994898  0.995408  0.995408  0.994898
# 1                         0.994388  0.996429  0.997959  0.997449  0.996939
# 2                         0.993878  0.994898  0.995918  0.995918  0.996429
# FL_ModelN1L2_Batchsize32  0.994388  0.994898  0.995918  0.995918  0.996429
#
# POISONED                        50
# 0                         0.989286
# 1                         0.994388
# 2                         0.994898
# FL_ModelN1L2_Batchsize32  0.994388
#
#
# === Experiment: FL_ModelN1L3_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# FL_ModelN1L3_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: FL_ModelN1L3_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.543813  0.549809  1.696634  2.581667  2.780284
# 1                         0.031303  1.216832  2.607033  4.049604  4.944665
# 2                         0.053950  1.111278  2.149449  2.750103  2.591698
# FL_ModelN1L3_Batchsize32  0.053950  1.111278  2.149449  2.750103  2.780284
#
# POISONED                        50
# 0                         2.217979
# 1                         4.125953
# 2                         1.643856
# FL_ModelN1L3_Batchsize32  2.217979
#
#
# === Experiment: FL_ModelN1L3_Batchsize32 - Metric: acc_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.976154  0.886332  0.799385  0.697687  0.597881
# 1                         0.990769  0.888393  0.798462  0.698225  0.598111
# 2                         0.986538  0.885302  0.798462  0.698763  0.602027
# FL_ModelN1L3_Batchsize32  0.986538  0.886332  0.798462  0.698225  0.598111
#
# POISONED                        50
# 0                         0.503846
# 1                         0.501538
# 2                         0.512500
# FL_ModelN1L3_Batchsize32  0.503846
#
#
# === Experiment: FL_ModelN1L3_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.537782  0.026151  0.011326  0.010869  0.015392
# 1                         0.017885  0.004639  0.002985  0.002627  0.002652
# 2                         0.040242  0.010486  0.010033  0.020821  0.053322
# FL_ModelN1L3_Batchsize32  0.040242  0.010486  0.010033  0.010869  0.015392
#
# POISONED                        50
# 0                         0.043461
# 1                         0.010927
# 2                         0.173569
# FL_ModelN1L3_Batchsize32  0.043461
#
#
# === Experiment: FL_ModelN1L3_Batchsize32 - Metric: acc_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.981633  0.994388  0.996429  0.996939  0.996429
# 1                         0.997449  0.997959  0.998469  0.998469  0.998980
# 2                         0.993367  0.994898  0.996429  0.994388  0.984184
# FL_ModelN1L3_Batchsize32  0.993367  0.994898  0.996429  0.996939  0.996429
#
# POISONED                        50
# 0                         0.988775
# 1                         0.996429
# 2                         0.950000
# FL_ModelN1L3_Batchsize32  0.988775
#
#
# === Experiment: FL_ModelN1L4_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# FL_ModelN1L4_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: FL_ModelN1L4_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.693196  0.693202  0.693200  0.693200  0.693209
# 1                         0.693209  0.693204  0.693201  0.693207  0.693206
# 2                         0.695526  0.694972  0.694804  0.694640  0.694403
# FL_ModelN1L4_Batchsize32  0.693209  0.693204  0.693201  0.693207  0.693209
#
# POISONED                        50
# 0                         0.693208
# 1                         0.693203
# 2                         0.694214
# FL_ModelN1L4_Batchsize32  0.693208
#
#
# === Experiment: FL_ModelN1L4_Batchsize32 - Metric: acc_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.450769  0.445055  0.446462  0.446746  0.437356
# 1                         0.438462  0.443338  0.446154  0.439753  0.441732
# 2                         0.435000  0.443681  0.441846  0.439753  0.443344
# FL_ModelN1L4_Batchsize32  0.438462  0.443681  0.446154  0.439753  0.441732
#
# POISONED                        50
# 0                         0.440385
# 1                         0.444038
# 2                         0.444808
# FL_ModelN1L4_Batchsize32  0.444038
#
#
# === Experiment: FL_ModelN1L4_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.693147  0.693147  0.693147  0.693147  0.693147
# 1                         0.693147  0.693147  0.693147  0.693147  0.693147
# 2                         0.693148  0.693147  0.693148  0.693147  0.693147
# FL_ModelN1L4_Batchsize32  0.693147  0.693147  0.693147  0.693147  0.693147
#
# POISONED                        50
# 0                         0.693147
# 1                         0.693147
# 2                         0.693148
# FL_ModelN1L4_Batchsize32  0.693147
#
#
# === Experiment: FL_ModelN1L4_Batchsize32 - Metric: acc_test ===
# POISONED                   0    10   20   30   40   50
# 0                         0.5  0.5  0.5  0.5  0.5  0.5
# 1                         0.5  0.5  0.5  0.5  0.5  0.5
# 2                         0.5  0.5  0.5  0.5  0.5  0.5
# FL_ModelN1L4_Batchsize32  0.5  0.5  0.5  0.5  0.5  0.5
#
#
# === Experiment: FL_ModelN1L5_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# FL_ModelN1L5_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: FL_ModelN1L5_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.410984  0.675220  1.779707  2.469556  2.325470
# 1                         0.695553  0.694175  0.693341  0.693328  0.693285
# 2                         0.695587  0.695354  0.694998  0.694487  0.694344
# FL_ModelN1L5_Batchsize32  0.695553  0.694175  0.694998  0.694487  0.694344
#
# POISONED                        50
# 0                         1.502118
# 1                         0.693294
# 2                         0.694260
# FL_ModelN1L5_Batchsize32  0.694260
#
#
# === Experiment: FL_ModelN1L5_Batchsize32 - Metric: acc_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.966154  0.889766  0.796923  0.698763  0.597881
# 1                         0.445769  0.443338  0.441538  0.440022  0.448181
# 2                         0.443077  0.439217  0.439692  0.449704  0.447490
# FL_ModelN1L5_Batchsize32  0.445769  0.443338  0.441538  0.449704  0.448181
#
# POISONED                        50
# 0                         0.505769
# 1                         0.441346
# 2                         0.443462
# FL_ModelN1L5_Batchsize32  0.443462
#
#
# === Experiment: FL_ModelN1L5_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.401662  0.027248  0.010686  0.007573  0.013977
# 1                         0.693147  0.693147  0.693147  0.693147  0.693147
# 2                         0.693148  0.693148  0.693148  0.693147  0.693148
# FL_ModelN1L5_Batchsize32  0.693147  0.693147  0.693147  0.693147  0.693147
#
# POISONED                        50
# 0                         0.082915
# 1                         0.693147
# 2                         0.693148
# FL_ModelN1L5_Batchsize32  0.693147
#
#
# === Experiment: FL_ModelN1L5_Batchsize32 - Metric: acc_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.971939  0.993878  0.997449  0.997449  0.997449
# 1                         0.500000  0.500000  0.500000  0.500000  0.500000
# 2                         0.500000  0.500000  0.500000  0.500000  0.500000
# FL_ModelN1L5_Batchsize32  0.500000  0.500000  0.500000  0.500000  0.500000
#
# POISONED                        50
# 0                         0.994388
# 1                         0.500000
# 2                         0.500000
# FL_ModelN1L5_Batchsize32  0.500000
#
#
# === Experiment: FL_ModelN1L6_Batchsize32 - Settle Epoch ===
# POISONED                  0   10  20  30  40  50
# 0                         99  99  99  99  99  99
# 1                         99  99  99  99  99  99
# 2                         99  99  99  99  99  99
# FL_ModelN1L6_Batchsize32  99  99  99  99  99  99
#
#
# === Experiment: FL_ModelN1L6_Batchsize32 - Metric: loss_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.693207  0.693214  0.693202  0.693202  0.693208
# 1                         0.693249  0.693204  0.693202  0.693195  0.693203
# 2                         0.693179  0.693201  0.693206  0.693208  0.693205
# FL_ModelN1L6_Batchsize32  0.693207  0.693204  0.693202  0.693202  0.693205
#
# POISONED                        50
# 0                         0.693204
# 1                         0.693204
# 2                         0.693204
# FL_ModelN1L6_Batchsize32  0.693204
#
#
# === Experiment: FL_ModelN1L6_Batchsize32 - Metric: acc_train ===
# POISONED                        0         10        20        30        40  \
# 0                         0.440769  0.433723  0.444923  0.445132  0.439429
# 1                         0.498462  0.442651  0.446462  0.451856  0.444035
# 2                         0.506538  0.446772  0.442154  0.439484  0.443344
# FL_ModelN1L6_Batchsize32  0.498462  0.442651  0.444923  0.445132  0.443344
#
# POISONED                        50
# 0                         0.443654
# 1                         0.443077
# 2                         0.444038
# FL_ModelN1L6_Batchsize32  0.443654
#
#
# === Experiment: FL_ModelN1L6_Batchsize32 - Metric: loss_test ===
# POISONED                        0         10        20        30        40  \
# 0                         0.693147  0.693147  0.693147  0.693147  0.693147
# 1                         0.693172  0.693147  0.693147  0.693147  0.693147
# 2                         0.693150  0.693147  0.693147  0.693147  0.693147
# FL_ModelN1L6_Batchsize32  0.693150  0.693147  0.693147  0.693147  0.693147
#
# POISONED                        50
# 0                         0.693147
# 1                         0.693147
# 2                         0.693147
# FL_ModelN1L6_Batchsize32  0.693147
#
#
# === Experiment: FL_ModelN1L6_Batchsize32 - Metric: acc_test ===
# POISONED                   0    10   20   30   40   50
# 0                         0.5  0.5  0.5  0.5  0.5  0.5
# 1                         0.5  0.5  0.5  0.5  0.5  0.5
# 2                         0.5  0.5  0.5  0.5  0.5  0.5
# FL_ModelN1L6_Batchsize32  0.5  0.5  0.5  0.5  0.5  0.5
#
#
# === Summary of last epoch metrics ===
#                  EXPERIMENT  0%_poisoned  10%_poisoned  20%_poisoned  \
# 0  CL_ModelN1L2_Batchsize32           99            99            99
# 1  CL_ModelN1L3_Batchsize32           99            99            99
# 2  CL_ModelN1L4_Batchsize32           99            99            99
# 3  CL_ModelN1L5_Batchsize32           99            99            99
# 4  CL_ModelN1L6_Batchsize32           99            99            99
# 5  FL_ModelN1L2_Batchsize32           99            99            99
# 6  FL_ModelN1L3_Batchsize32           99            99            99
# 7  FL_ModelN1L4_Batchsize32           99            99            99
# 8  FL_ModelN1L5_Batchsize32           99            99            99
# 9  FL_ModelN1L6_Batchsize32           99            99            99
#
#    30%_poisoned  40%_poisoned  50%_poisoned
# 0            99            99            99
# 1            99            99            99
# 2            99            99            99
# 3            99            99            99
# 4            99            99            99
# 5            99            99            99
# 6            99            99            99
# 7            99            99            99
# 8            99            99            99
# 9            99            99            99
# === Summary of loss_test ===
#                  EXPERIMENT  0%_poisoned  10%_poisoned  20%_poisoned  \
# 0  CL_ModelN1L2_Batchsize32     0.002427      0.111453      0.249029
# 1  CL_ModelN1L3_Batchsize32     0.005516      0.121777      0.247080
# 2  CL_ModelN1L4_Batchsize32     0.007708      0.119305      0.238387
# 3  CL_ModelN1L5_Batchsize32     0.693147      0.693147      0.693148
# 4  CL_ModelN1L6_Batchsize32     0.693147      0.693148      0.693148
# 5  FL_ModelN1L2_Batchsize32     0.049400      0.011529      0.009364
# 6  FL_ModelN1L3_Batchsize32     0.040242      0.010486      0.010033
# 7  FL_ModelN1L4_Batchsize32     0.693147      0.693147      0.693147
# 8  FL_ModelN1L5_Batchsize32     0.693147      0.693147      0.693147
# 9  FL_ModelN1L6_Batchsize32     0.693150      0.693147      0.693147
#
#    30%_poisoned  40%_poisoned  50%_poisoned
# 0      0.365094      0.529510      0.709234
# 1      0.375729      0.527829      0.692285
# 2      0.384548      0.532976      0.693957
# 3      0.693147      0.693148      0.693150
# 4      0.693149      0.693148      0.693150
# 5      0.009324      0.013028      0.030142
# 6      0.010869      0.015392      0.043461
# 7      0.693147      0.693147      0.693147
# 8      0.693147      0.693147      0.693147
# 9      0.693147      0.693147      0.693147
# === Summary of acc_test ===
#                  EXPERIMENT  0%_poisoned  10%_poisoned  20%_poisoned  \
# 0  CL_ModelN1L2_Batchsize32     0.999490      0.998980      0.993367
# 1  CL_ModelN1L3_Batchsize32     0.998980      0.998469      0.994388
# 2  CL_ModelN1L4_Batchsize32     0.998980      0.996429      0.988265
# 3  CL_ModelN1L5_Batchsize32     0.500000      0.500000      0.500000
# 4  CL_ModelN1L6_Batchsize32     0.500000      0.500000      0.500000
# 5  FL_ModelN1L2_Batchsize32     0.994388      0.994898      0.995918
# 6  FL_ModelN1L3_Batchsize32     0.993367      0.994898      0.996429
# 7  FL_ModelN1L4_Batchsize32     0.500000      0.500000      0.500000
# 8  FL_ModelN1L5_Batchsize32     0.500000      0.500000      0.500000
# 9  FL_ModelN1L6_Batchsize32     0.500000      0.500000      0.500000
#
#    30%_poisoned  40%_poisoned  50%_poisoned
# 0      0.982653      0.920918      0.469898
# 1      0.980102      0.905102      0.555612
# 2      0.970408      0.889796      0.521429
# 3      0.500000      0.500000      0.500000
# 4      0.500000      0.500000      0.500000
# 5      0.995918      0.996429      0.994388
# 6      0.996939      0.996429      0.988775
# 7      0.500000      0.500000      0.500000
# 8      0.500000      0.500000      0.500000
# 9      0.500000      0.500000      0.500000
# Done!
