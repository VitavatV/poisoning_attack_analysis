# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x
    
# save state_dict + metadata (safe, portable)
def save_model(model, img_size, n_classes, learning_rate, experiment_bs, file_path):

    state = {
        "model_state_dict": model.state_dict(),                     # CPU/GPU tensors okay
        "arch": "MNISTNet",
        "img_size": img_size,
        "num_classes": n_classes,
        "training_args": {"lr": learning_rate, "batch_size": experiment_bs}
    }
    # ensure weights are on CPU to avoid GPU-only pickle issues
    state["model_state_dict"] = {k: v.cpu() for k, v in state["model_state_dict"].items()}
    torch.save(state, file_path)
    
def load_model(file_path, device):

    checkpoint = torch.load(file_path, map_location=device)
    model = MNISTNet().to(device)              # must have MNISTNet class defined/importable
    model.load_state_dict(checkpoint["model_state_dict"])
    model.eval()
    return model

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    # create model on target device
    model = MNISTNet().to(device)
    # ensure weights are mapped to the worker device
    state_on_device = {k: v.to(device) for k, v in global_weights.items()}
    model.load_state_dict(state_on_device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end].to(device)
            yb = y_c_tensor[start:end].to(device)
            outputs = model(xb)
            preds = (outputs >= 0.5).float()
            loss = binary_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # return CPU copies for safe aggregation in main thread
    returned_state = {k: v.detach().cpu() for k, v in model.state_dict().items()}
    return returned_state, X_c_tensor.size(0), yb.detach().cpu(), outputs.detach().cpu(), preds.detach().cpu()

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 32
N_CLASSES = 2

# Set device
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")

DATA_PATH = "../data/mnist_binary_poison/train"
TEST_PATH = "../data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
for NODE in [1,2,4,8,16,32]:
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            self.conv1 = nn.Conv2d(1, NODE, kernel_size=3, padding=1) # 28x28
            self.pool = nn.MaxPool2d(2, 2) # 14x14
            self.fc1 = nn.Linear(NODE * 14 * 14, 1)
            self.relu = nn.ReLU()
            
        def forward(self, x):
            x = x.view(-1, 1, 28, 28)
            x = self.pool(self.relu(self.conv1(x)))
            x = x.view(x.size(0), -1)
            x = self.fc1(x)
            x = torch.sigmoid(x)
            return x

    BATCH_SIZE_list = []
    temp_bs = BATCH_SIZE
    while temp_bs >= 1:
        BATCH_SIZE_list.append(temp_bs)
        temp_bs = temp_bs // 2

    for rev in range(3):

        global_model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"FL_ModelN{NODE}L2_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                # local_epoch = # 29 image x 2 class x 100+i_poisoned clents / 32 batch_size / 100+i_poisoned clents
                LOCAL_EPOCHS = max(1, (29 * 2 * (N_HONEST + i_poisoned)) // (experiment_bs * (N_HONEST + i_poisoned)))
                
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                # torch.save(model, os.path.join(save_path,'model_init.pt'))
                save_path_name = os.path.join(save_path,'model_init.pt')
                save_model(global_model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)
                
                global_weights = global_model.state_dict()

                records = []

                X_train_tensor = {}
                y_train_tensor = {}
                for i in range(N_HONEST):
                    X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"honest_{i}"] = X_c_tensor
                    y_train_tensor[f"honest_{i}"] = y_c_tensor
                for i in range(i_poisoned):
                    X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                    if len(X_c) == 0:
                        continue
                    X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                    y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                    X_train_tensor[f"poison_{i}"] = X_c_tensor
                    y_train_tensor[f"poison_{i}"] = y_c_tensor

                # Training loop
                for round in range(ROUNDS):
                    # Prepare arguments for honest clients
                    
                    #randomize the training data
                    for i in range(N_HONEST):
                        perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                        X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                        y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                    honest_args = [
                        (
                            X_train_tensor[f"honest_{i}"],
                            y_train_tensor[f"honest_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(N_HONEST)
                    ]

                    # Prepare arguments for poisoned clients
                    
                    #randomize the training data
                    for i in range(i_poisoned):
                        perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                        X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                        y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                    poison_args = [
                        (
                            X_train_tensor[f"poison_{i}"],
                            y_train_tensor[f"poison_{i}"],
                            global_weights,
                            LEARNING_RATE,
                            LOCAL_EPOCHS,
                            experiment_bs,
                            device
                        )
                        for i in range(i_poisoned)
                    ]

                    # Run in parallel
                    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                        honest_results = list(executor.map(train_local_worker, honest_args))
                        poison_results = list(executor.map(train_local_worker, poison_args))

                    local_weights = []
                    local_sizes = []
                    local_y = []
                    local_outputs = []
                    local_preds = []
                    for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                        local_weights.append(l_w)
                        local_sizes.append(l_sz)
                        local_y.extend(l_y)
                        local_outputs.extend(l_out)
                        local_preds.extend(l_pred)
                    loss_train = binary_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                    acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                    # Federated averaging (weighted by client data size)
                    new_weights = {}
                    for key in global_weights.keys():
                        new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                    global_weights = new_weights
                    global_model.load_state_dict(global_weights)

                    # Evaluate
                    global_model.eval()
                    with torch.no_grad():
                        outputs = global_model(X_test_tensor)
                        preds = (outputs > 0.5).float()
                        loss_test = binary_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'round': round, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"round {round}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                # torch.save(model, os.path.join(save_path,'model_last.pt'))
                save_path_name = os.path.join(save_path,'model_last.pt')
                save_model(global_model, IMG_SIZE, N_CLASSES, LEARNING_RATE, experiment_bs, save_path_name)

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['round'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['round'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 round 0: loss_train=0.6857, acc_train=0.4965, loss_test=0.6842, acc_test=0.5000
# poison_percent 0 round 1: loss_train=0.6835, acc_train=0.4988, loss_test=0.6823, acc_test=0.5010
# poison_percent 0 round 2: loss_train=0.6823, acc_train=0.4958, loss_test=0.6802, acc_test=0.5031
# poison_percent 0 round 3: loss_train=0.6787, acc_train=0.5254, loss_test=0.6780, acc_test=0.5133
# poison_percent 0 round 4: loss_train=0.6756, acc_train=0.5396, loss_test=0.6756, acc_test=0.5306
# poison_percent 0 round 5: loss_train=0.6747, acc_train=0.5435, loss_test=0.6731, acc_test=0.5408
# poison_percent 0 round 6: loss_train=0.6723, acc_train=0.5577, loss_test=0.6705, acc_test=0.5577
# poison_percent 0 round 7: loss_train=0.6679, acc_train=0.5900, loss_test=0.6675, acc_test=0.5796
# poison_percent 0 round 8: loss_train=0.6659, acc_train=0.6073, loss_test=0.6644, acc_test=0.6066
# poison_percent 0 round 9: loss_train=0.6635, acc_train=0.6238, loss_test=0.6610, acc_test=0.6337
# poison_percent 0 round 10: loss_train=0.6585, acc_train=0.6665, loss_test=0.6575, acc_test=0.6684
# poison_percent 0 round 11: loss_train=0.6533, acc_train=0.7227, loss_test=0.6537, acc_test=0.7077
# poison_percent 0 round 12: loss_train=0.6514, acc_train=0.7365, loss_test=0.6496, acc_test=0.7464
# poison_percent 0 round 13: loss_train=0.6476, acc_train=0.7604, loss_test=0.6453, acc_test=0.7719
# poison_percent 0 round 14: loss_train=0.6436, acc_train=0.7904, loss_test=0.6407, acc_test=0.8000
# poison_percent 0 round 15: loss_train=0.6379, acc_train=0.8069, loss_test=0.6359, acc_test=0.8122
# poison_percent 0 round 16: loss_train=0.6336, acc_train=0.8300, loss_test=0.6307, acc_test=0.8245
# poison_percent 0 round 17: loss_train=0.6273, acc_train=0.8450, loss_test=0.6254, acc_test=0.8388
# poison_percent 0 round 18: loss_train=0.6223, acc_train=0.8535, loss_test=0.6198, acc_test=0.8495
# poison_percent 0 round 19: loss_train=0.6169, acc_train=0.8692, loss_test=0.6138, acc_test=0.8658
# poison_percent 0 round 20: loss_train=0.6093, acc_train=0.8735, loss_test=0.6076, acc_test=0.8760
# poison_percent 0 round 21: loss_train=0.6050, acc_train=0.8862, loss_test=0.6011, acc_test=0.8883
# poison_percent 0 round 22: loss_train=0.5969, acc_train=0.8985, loss_test=0.5943, acc_test=0.8929
# poison_percent 0 round 23: loss_train=0.5917, acc_train=0.9046, loss_test=0.5873, acc_test=0.9026
# poison_percent 0 round 24: loss_train=0.5831, acc_train=0.9131, loss_test=0.5800, acc_test=0.9102
# poison_percent 0 round 25: loss_train=0.5780, acc_train=0.9127, loss_test=0.5725, acc_test=0.9143
# poison_percent 0 round 26: loss_train=0.5703, acc_train=0.9208, loss_test=0.5647, acc_test=0.9204
# poison_percent 0 round 27: loss_train=0.5632, acc_train=0.9223, loss_test=0.5568, acc_test=0.9281
# poison_percent 0 round 28: loss_train=0.5559, acc_train=0.9331, loss_test=0.5487, acc_test=0.9362
# poison_percent 0 round 29: loss_train=0.5436, acc_train=0.9450, loss_test=0.5402, acc_test=0.9439
# poison_percent 0 round 30: loss_train=0.5361, acc_train=0.9496, loss_test=0.5315, acc_test=0.9520
# poison_percent 0 round 31: loss_train=0.5275, acc_train=0.9527, loss_test=0.5225, acc_test=0.9561
# poison_percent 0 round 32: loss_train=0.5194, acc_train=0.9569, loss_test=0.5134, acc_test=0.9577
# poison_percent 0 round 33: loss_train=0.5092, acc_train=0.9604, loss_test=0.5040, acc_test=0.9622
# poison_percent 0 round 34: loss_train=0.5014, acc_train=0.9627, loss_test=0.4946, acc_test=0.9653
# poison_percent 0 round 35: loss_train=0.4904, acc_train=0.9708, loss_test=0.4851, acc_test=0.9699
# poison_percent 0 round 36: loss_train=0.4815, acc_train=0.9708, loss_test=0.4753, acc_test=0.9724
# poison_percent 0 round 37: loss_train=0.4715, acc_train=0.9727, loss_test=0.4653, acc_test=0.9745
# poison_percent 0 round 38: loss_train=0.4606, acc_train=0.9750, loss_test=0.4552, acc_test=0.9755
# poison_percent 0 round 39: loss_train=0.4507, acc_train=0.9785, loss_test=0.4450, acc_test=0.9770
# poison_percent 0 round 40: loss_train=0.4417, acc_train=0.9823, loss_test=0.4348, acc_test=0.9801
# poison_percent 0 round 41: loss_train=0.4308, acc_train=0.9835, loss_test=0.4245, acc_test=0.9821
# poison_percent 0 round 42: loss_train=0.4214, acc_train=0.9823, loss_test=0.4141, acc_test=0.9842
# poison_percent 0 round 43: loss_train=0.4113, acc_train=0.9835, loss_test=0.4038, acc_test=0.9847
# poison_percent 0 round 44: loss_train=0.4012, acc_train=0.9827, loss_test=0.3933, acc_test=0.9852
# poison_percent 0 round 45: loss_train=0.3872, acc_train=0.9858, loss_test=0.3829, acc_test=0.9857
# poison_percent 0 round 46: loss_train=0.3771, acc_train=0.9865, loss_test=0.3724, acc_test=0.9867
# poison_percent 0 round 47: loss_train=0.3695, acc_train=0.9877, loss_test=0.3618, acc_test=0.9878
# poison_percent 0 round 48: loss_train=0.3586, acc_train=0.9888, loss_test=0.3515, acc_test=0.9883
# poison_percent 0 round 49: loss_train=0.3503, acc_train=0.9873, loss_test=0.3411, acc_test=0.9888
# poison_percent 0 round 50: loss_train=0.3383, acc_train=0.9877, loss_test=0.3308, acc_test=0.9893
# poison_percent 0 round 51: loss_train=0.3317, acc_train=0.9865, loss_test=0.3207, acc_test=0.9893
# poison_percent 0 round 52: loss_train=0.3194, acc_train=0.9900, loss_test=0.3106, acc_test=0.9903
# poison_percent 0 round 53: loss_train=0.3108, acc_train=0.9885, loss_test=0.3006, acc_test=0.9898
# poison_percent 0 round 54: loss_train=0.2972, acc_train=0.9908, loss_test=0.2907, acc_test=0.9913
# poison_percent 0 round 55: loss_train=0.2900, acc_train=0.9877, loss_test=0.2809, acc_test=0.9918
# poison_percent 0 round 56: loss_train=0.2790, acc_train=0.9896, loss_test=0.2715, acc_test=0.9918
# poison_percent 0 round 57: loss_train=0.2706, acc_train=0.9888, loss_test=0.2621, acc_test=0.9929
# poison_percent 0 round 58: loss_train=0.2582, acc_train=0.9923, loss_test=0.2528, acc_test=0.9929
# poison_percent 0 round 59: loss_train=0.2524, acc_train=0.9896, loss_test=0.2438, acc_test=0.9934
# poison_percent 0 round 60: loss_train=0.2446, acc_train=0.9908, loss_test=0.2350, acc_test=0.9939
# poison_percent 0 round 61: loss_train=0.2359, acc_train=0.9896, loss_test=0.2263, acc_test=0.9939
# poison_percent 0 round 62: loss_train=0.2259, acc_train=0.9919, loss_test=0.2180, acc_test=0.9939
# poison_percent 0 round 63: loss_train=0.2192, acc_train=0.9912, loss_test=0.2098, acc_test=0.9944
# poison_percent 0 round 64: loss_train=0.2087, acc_train=0.9908, loss_test=0.2018, acc_test=0.9944
# poison_percent 0 round 65: loss_train=0.2029, acc_train=0.9900, loss_test=0.1940, acc_test=0.9944
# poison_percent 0 round 66: loss_train=0.1950, acc_train=0.9892, loss_test=0.1864, acc_test=0.9944
# poison_percent 0 round 67: loss_train=0.1872, acc_train=0.9904, loss_test=0.1792, acc_test=0.9944
# poison_percent 0 round 68: loss_train=0.1814, acc_train=0.9900, loss_test=0.1722, acc_test=0.9944
# poison_percent 0 round 69: loss_train=0.1738, acc_train=0.9935, loss_test=0.1652, acc_test=0.9944
# poison_percent 0 round 70: loss_train=0.1672, acc_train=0.9908, loss_test=0.1586, acc_test=0.9944
# poison_percent 0 round 71: loss_train=0.1573, acc_train=0.9915, loss_test=0.1522, acc_test=0.9944
# poison_percent 0 round 72: loss_train=0.1518, acc_train=0.9927, loss_test=0.1461, acc_test=0.9944
# poison_percent 0 round 73: loss_train=0.1541, acc_train=0.9881, loss_test=0.1403, acc_test=0.9944
# poison_percent 0 round 74: loss_train=0.1416, acc_train=0.9915, loss_test=0.1346, acc_test=0.9944
# poison_percent 0 round 75: loss_train=0.1385, acc_train=0.9904, loss_test=0.1292, acc_test=0.9944
# poison_percent 0 round 76: loss_train=0.1330, acc_train=0.9908, loss_test=0.1239, acc_test=0.9944
# poison_percent 0 round 77: loss_train=0.1265, acc_train=0.9900, loss_test=0.1188, acc_test=0.9944
# poison_percent 0 round 78: loss_train=0.1216, acc_train=0.9892, loss_test=0.1139, acc_test=0.9944
# poison_percent 0 round 79: loss_train=0.1181, acc_train=0.9900, loss_test=0.1092, acc_test=0.9944
# poison_percent 0 round 80: loss_train=0.1113, acc_train=0.9904, loss_test=0.1048, acc_test=0.9944
# poison_percent 0 round 81: loss_train=0.1112, acc_train=0.9888, loss_test=0.1004, acc_test=0.9944
# poison_percent 0 round 82: loss_train=0.1055, acc_train=0.9888, loss_test=0.0963, acc_test=0.9944
# poison_percent 0 round 83: loss_train=0.1000, acc_train=0.9904, loss_test=0.0924, acc_test=0.9944
# poison_percent 0 round 84: loss_train=0.0957, acc_train=0.9915, loss_test=0.0886, acc_test=0.9944
# poison_percent 0 round 85: loss_train=0.0918, acc_train=0.9912, loss_test=0.0851, acc_test=0.9944
# poison_percent 0 round 86: loss_train=0.0923, acc_train=0.9892, loss_test=0.0817, acc_test=0.9944
# poison_percent 0 round 87: loss_train=0.0865, acc_train=0.9912, loss_test=0.0785, acc_test=0.9944
# poison_percent 0 round 88: loss_train=0.0825, acc_train=0.9900, loss_test=0.0754, acc_test=0.9944
# poison_percent 0 round 89: loss_train=0.0777, acc_train=0.9931, loss_test=0.0724, acc_test=0.9944
# poison_percent 0 round 90: loss_train=0.0790, acc_train=0.9908, loss_test=0.0697, acc_test=0.9944
# poison_percent 0 round 91: loss_train=0.0778, acc_train=0.9896, loss_test=0.0669, acc_test=0.9944
# poison_percent 0 round 92: loss_train=0.0750, acc_train=0.9892, loss_test=0.0643, acc_test=0.9944
# poison_percent 0 round 93: loss_train=0.0675, acc_train=0.9915, loss_test=0.0619, acc_test=0.9944
# poison_percent 0 round 94: loss_train=0.0649, acc_train=0.9923, loss_test=0.0596, acc_test=0.9944
# poison_percent 0 round 95: loss_train=0.0673, acc_train=0.9912, loss_test=0.0573, acc_test=0.9949
# poison_percent 0 round 96: loss_train=0.0598, acc_train=0.9923, loss_test=0.0552, acc_test=0.9949
# poison_percent 0 round 97: loss_train=0.0591, acc_train=0.9915, loss_test=0.0532, acc_test=0.9949
# poison_percent 0 round 98: loss_train=0.0581, acc_train=0.9908, loss_test=0.0512, acc_test=0.9949
# poison_percent 0 round 99: loss_train=0.0558, acc_train=0.9923, loss_test=0.0494, acc_test=0.9949
# Training log saved to ./results\FL_ModelN1L2_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 round 0: loss_train=0.4502, acc_train=0.8874, loss_test=0.0480, acc_test=0.9949
# poison_percent 10 round 1: loss_train=0.4549, acc_train=0.8863, loss_test=0.0467, acc_test=0.9949
# poison_percent 10 round 2: loss_train=0.4620, acc_train=0.8846, loss_test=0.0454, acc_test=0.9949
# poison_percent 10 round 3: loss_train=0.4676, acc_train=0.8860, loss_test=0.0442, acc_test=0.9949
# poison_percent 10 round 4: loss_train=0.4662, acc_train=0.8856, loss_test=0.0430, acc_test=0.9949
# poison_percent 10 round 5: loss_train=0.4812, acc_train=0.8860, loss_test=0.0419, acc_test=0.9949
# poison_percent 10 round 6: loss_train=0.4766, acc_train=0.8867, loss_test=0.0409, acc_test=0.9949
# poison_percent 10 round 7: loss_train=0.4836, acc_train=0.8856, loss_test=0.0398, acc_test=0.9949
# poison_percent 10 round 8: loss_train=0.4905, acc_train=0.8887, loss_test=0.0389, acc_test=0.9949
# poison_percent 10 round 9: loss_train=0.4902, acc_train=0.8870, loss_test=0.0379, acc_test=0.9949
# poison_percent 10 round 10: loss_train=0.4867, acc_train=0.8867, loss_test=0.0370, acc_test=0.9949
# poison_percent 10 round 11: loss_train=0.5005, acc_train=0.8860, loss_test=0.0361, acc_test=0.9949
# poison_percent 10 round 12: loss_train=0.4945, acc_train=0.8880, loss_test=0.0352, acc_test=0.9949
# poison_percent 10 round 13: loss_train=0.5171, acc_train=0.8850, loss_test=0.0344, acc_test=0.9949
# poison_percent 10 round 14: loss_train=0.5136, acc_train=0.8853, loss_test=0.0336, acc_test=0.9949
# poison_percent 10 round 15: loss_train=0.5204, acc_train=0.8877, loss_test=0.0328, acc_test=0.9949
# poison_percent 10 round 16: loss_train=0.5128, acc_train=0.8843, loss_test=0.0320, acc_test=0.9949
# poison_percent 10 round 17: loss_train=0.5303, acc_train=0.8853, loss_test=0.0313, acc_test=0.9949
# poison_percent 10 round 18: loss_train=0.5274, acc_train=0.8867, loss_test=0.0306, acc_test=0.9949
# poison_percent 10 round 19: loss_train=0.5409, acc_train=0.8860, loss_test=0.0300, acc_test=0.9949
# poison_percent 10 round 20: loss_train=0.5497, acc_train=0.8856, loss_test=0.0293, acc_test=0.9949
# poison_percent 10 round 21: loss_train=0.5404, acc_train=0.8877, loss_test=0.0287, acc_test=0.9949
# poison_percent 10 round 22: loss_train=0.5430, acc_train=0.8856, loss_test=0.0281, acc_test=0.9949
# poison_percent 10 round 23: loss_train=0.5684, acc_train=0.8863, loss_test=0.0276, acc_test=0.9949
# poison_percent 10 round 24: loss_train=0.5635, acc_train=0.8905, loss_test=0.0270, acc_test=0.9949
# poison_percent 10 round 25: loss_train=0.5645, acc_train=0.8880, loss_test=0.0265, acc_test=0.9949
# poison_percent 10 round 26: loss_train=0.5823, acc_train=0.8856, loss_test=0.0260, acc_test=0.9949
# poison_percent 10 round 27: loss_train=0.5657, acc_train=0.8877, loss_test=0.0255, acc_test=0.9949
# poison_percent 10 round 28: loss_train=0.5855, acc_train=0.8863, loss_test=0.0250, acc_test=0.9949
# poison_percent 10 round 29: loss_train=0.5758, acc_train=0.8863, loss_test=0.0245, acc_test=0.9949
# poison_percent 10 round 30: loss_train=0.5811, acc_train=0.8891, loss_test=0.0241, acc_test=0.9949
# poison_percent 10 round 31: loss_train=0.5780, acc_train=0.8880, loss_test=0.0237, acc_test=0.9949
# poison_percent 10 round 32: loss_train=0.5841, acc_train=0.8863, loss_test=0.0233, acc_test=0.9949
# poison_percent 10 round 33: loss_train=0.6007, acc_train=0.8891, loss_test=0.0229, acc_test=0.9949
# poison_percent 10 round 34: loss_train=0.5953, acc_train=0.8887, loss_test=0.0225, acc_test=0.9949
# poison_percent 10 round 35: loss_train=0.6197, acc_train=0.8870, loss_test=0.0221, acc_test=0.9949
# poison_percent 10 round 36: loss_train=0.6158, acc_train=0.8877, loss_test=0.0217, acc_test=0.9949
# poison_percent 10 round 37: loss_train=0.6008, acc_train=0.8880, loss_test=0.0214, acc_test=0.9949
# poison_percent 10 round 38: loss_train=0.6158, acc_train=0.8894, loss_test=0.0210, acc_test=0.9949
# poison_percent 10 round 39: loss_train=0.6334, acc_train=0.8877, loss_test=0.0207, acc_test=0.9949
# poison_percent 10 round 40: loss_train=0.6388, acc_train=0.8874, loss_test=0.0204, acc_test=0.9949
# poison_percent 10 round 41: loss_train=0.6333, acc_train=0.8891, loss_test=0.0201, acc_test=0.9949
# poison_percent 10 round 42: loss_train=0.6470, acc_train=0.8877, loss_test=0.0198, acc_test=0.9949
# poison_percent 10 round 43: loss_train=0.6457, acc_train=0.8880, loss_test=0.0195, acc_test=0.9949
# poison_percent 10 round 44: loss_train=0.6400, acc_train=0.8880, loss_test=0.0192, acc_test=0.9949
# poison_percent 10 round 45: loss_train=0.6410, acc_train=0.8867, loss_test=0.0189, acc_test=0.9949
# poison_percent 10 round 46: loss_train=0.6523, acc_train=0.8887, loss_test=0.0187, acc_test=0.9949
# poison_percent 10 round 47: loss_train=0.6527, acc_train=0.8874, loss_test=0.0184, acc_test=0.9949
# poison_percent 10 round 48: loss_train=0.6622, acc_train=0.8870, loss_test=0.0182, acc_test=0.9949
# poison_percent 10 round 49: loss_train=0.6710, acc_train=0.8877, loss_test=0.0179, acc_test=0.9949
# poison_percent 10 round 50: loss_train=0.6593, acc_train=0.8891, loss_test=0.0177, acc_test=0.9949
# poison_percent 10 round 51: loss_train=0.6784, acc_train=0.8894, loss_test=0.0175, acc_test=0.9949
# poison_percent 10 round 52: loss_train=0.7052, acc_train=0.8877, loss_test=0.0172, acc_test=0.9949
# poison_percent 10 round 53: loss_train=0.6914, acc_train=0.8874, loss_test=0.0170, acc_test=0.9949
# poison_percent 10 round 54: loss_train=0.6894, acc_train=0.8860, loss_test=0.0168, acc_test=0.9949
# poison_percent 10 round 55: loss_train=0.7007, acc_train=0.8894, loss_test=0.0166, acc_test=0.9949
# poison_percent 10 round 56: loss_train=0.7149, acc_train=0.8863, loss_test=0.0164, acc_test=0.9949
# poison_percent 10 round 57: loss_train=0.6817, acc_train=0.8884, loss_test=0.0163, acc_test=0.9949
# poison_percent 10 round 58: loss_train=0.6928, acc_train=0.8867, loss_test=0.0161, acc_test=0.9949
# poison_percent 10 round 59: loss_train=0.7047, acc_train=0.8894, loss_test=0.0159, acc_test=0.9949
# poison_percent 10 round 60: loss_train=0.7130, acc_train=0.8877, loss_test=0.0157, acc_test=0.9949
# poison_percent 10 round 61: loss_train=0.7206, acc_train=0.8884, loss_test=0.0155, acc_test=0.9949
# poison_percent 10 round 62: loss_train=0.7283, acc_train=0.8877, loss_test=0.0154, acc_test=0.9949
# poison_percent 10 round 63: loss_train=0.7292, acc_train=0.8880, loss_test=0.0152, acc_test=0.9949
# poison_percent 10 round 64: loss_train=0.7174, acc_train=0.8880, loss_test=0.0151, acc_test=0.9949
# poison_percent 10 round 65: loss_train=0.7308, acc_train=0.8874, loss_test=0.0149, acc_test=0.9949
# poison_percent 10 round 66: loss_train=0.7191, acc_train=0.8880, loss_test=0.0148, acc_test=0.9949
# poison_percent 10 round 67: loss_train=0.7386, acc_train=0.8898, loss_test=0.0146, acc_test=0.9949
# poison_percent 10 round 68: loss_train=0.7629, acc_train=0.8877, loss_test=0.0145, acc_test=0.9949
# poison_percent 10 round 69: loss_train=0.7322, acc_train=0.8884, loss_test=0.0144, acc_test=0.9949
# poison_percent 10 round 70: loss_train=0.7495, acc_train=0.8867, loss_test=0.0142, acc_test=0.9949
# poison_percent 10 round 71: loss_train=0.7580, acc_train=0.8887, loss_test=0.0141, acc_test=0.9949
# poison_percent 10 round 72: loss_train=0.7308, acc_train=0.8874, loss_test=0.0140, acc_test=0.9949
# poison_percent 10 round 73: loss_train=0.7796, acc_train=0.8880, loss_test=0.0138, acc_test=0.9949
# poison_percent 10 round 74: loss_train=0.7801, acc_train=0.8880, loss_test=0.0137, acc_test=0.9949
# poison_percent 10 round 75: loss_train=0.7632, acc_train=0.8894, loss_test=0.0136, acc_test=0.9949
# poison_percent 10 round 76: loss_train=0.7899, acc_train=0.8874, loss_test=0.0134, acc_test=0.9949
# poison_percent 10 round 77: loss_train=0.7956, acc_train=0.8891, loss_test=0.0134, acc_test=0.9949
# poison_percent 10 round 78: loss_train=0.7809, acc_train=0.8877, loss_test=0.0132, acc_test=0.9949
# poison_percent 10 round 79: loss_train=0.7689, acc_train=0.8894, loss_test=0.0131, acc_test=0.9949
# poison_percent 10 round 80: loss_train=0.7899, acc_train=0.8880, loss_test=0.0130, acc_test=0.9949
# poison_percent 10 round 81: loss_train=0.8000, acc_train=0.8887, loss_test=0.0129, acc_test=0.9949
# poison_percent 10 round 82: loss_train=0.7839, acc_train=0.8894, loss_test=0.0128, acc_test=0.9949
# poison_percent 10 round 83: loss_train=0.7918, acc_train=0.8880, loss_test=0.0128, acc_test=0.9949
# poison_percent 10 round 84: loss_train=0.8031, acc_train=0.8894, loss_test=0.0127, acc_test=0.9949
# poison_percent 10 round 85: loss_train=0.8069, acc_train=0.8874, loss_test=0.0126, acc_test=0.9949
# poison_percent 10 round 86: loss_train=0.8042, acc_train=0.8884, loss_test=0.0125, acc_test=0.9949
# poison_percent 10 round 87: loss_train=0.8184, acc_train=0.8870, loss_test=0.0124, acc_test=0.9949
# poison_percent 10 round 88: loss_train=0.8078, acc_train=0.8884, loss_test=0.0123, acc_test=0.9949
# poison_percent 10 round 89: loss_train=0.8399, acc_train=0.8898, loss_test=0.0123, acc_test=0.9949
# poison_percent 10 round 90: loss_train=0.8341, acc_train=0.8887, loss_test=0.0122, acc_test=0.9949
# poison_percent 10 round 91: loss_train=0.8334, acc_train=0.8887, loss_test=0.0121, acc_test=0.9949
# poison_percent 10 round 92: loss_train=0.8498, acc_train=0.8887, loss_test=0.0120, acc_test=0.9949
# poison_percent 10 round 93: loss_train=0.8398, acc_train=0.8898, loss_test=0.0120, acc_test=0.9949
# poison_percent 10 round 94: loss_train=0.8528, acc_train=0.8877, loss_test=0.0119, acc_test=0.9949
# poison_percent 10 round 95: loss_train=0.8479, acc_train=0.8891, loss_test=0.0118, acc_test=0.9949
# poison_percent 10 round 96: loss_train=0.8543, acc_train=0.8887, loss_test=0.0118, acc_test=0.9949
# poison_percent 10 round 97: loss_train=0.8418, acc_train=0.8898, loss_test=0.0117, acc_test=0.9949
# poison_percent 10 round 98: loss_train=0.8539, acc_train=0.8901, loss_test=0.0116, acc_test=0.9949
# poison_percent 10 round 99: loss_train=0.8764, acc_train=0.8887, loss_test=0.0115, acc_test=0.9949
# Training log saved to ./results\FL_ModelN1L2_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=1.5969, acc_train=0.7957, loss_test=0.0115, acc_test=0.9949
# poison_percent 20 round 1: loss_train=1.5909, acc_train=0.7948, loss_test=0.0115, acc_test=0.9949
# poison_percent 20 round 2: loss_train=1.5938, acc_train=0.7975, loss_test=0.0115, acc_test=0.9949
# poison_percent 20 round 3: loss_train=1.6091, acc_train=0.7954, loss_test=0.0115, acc_test=0.9949
# poison_percent 20 round 4: loss_train=1.6272, acc_train=0.7985, loss_test=0.0114, acc_test=0.9949
# poison_percent 20 round 5: loss_train=1.5912, acc_train=0.7972, loss_test=0.0114, acc_test=0.9949
# poison_percent 20 round 6: loss_train=1.5904, acc_train=0.7972, loss_test=0.0114, acc_test=0.9949
# poison_percent 20 round 7: loss_train=1.6078, acc_train=0.7969, loss_test=0.0113, acc_test=0.9949
# poison_percent 20 round 8: loss_train=1.6449, acc_train=0.7969, loss_test=0.0113, acc_test=0.9949
# poison_percent 20 round 9: loss_train=1.6356, acc_train=0.7969, loss_test=0.0113, acc_test=0.9949
# poison_percent 20 round 10: loss_train=1.6297, acc_train=0.7982, loss_test=0.0113, acc_test=0.9949
# poison_percent 20 round 11: loss_train=1.6390, acc_train=0.7969, loss_test=0.0112, acc_test=0.9949
# poison_percent 20 round 12: loss_train=1.6223, acc_train=0.7963, loss_test=0.0112, acc_test=0.9949
# poison_percent 20 round 13: loss_train=1.6287, acc_train=0.7975, loss_test=0.0112, acc_test=0.9949
# poison_percent 20 round 14: loss_train=1.6528, acc_train=0.7975, loss_test=0.0111, acc_test=0.9949
# poison_percent 20 round 15: loss_train=1.6611, acc_train=0.7957, loss_test=0.0111, acc_test=0.9949
# poison_percent 20 round 16: loss_train=1.6212, acc_train=0.7963, loss_test=0.0110, acc_test=0.9949
# poison_percent 20 round 17: loss_train=1.6226, acc_train=0.7966, loss_test=0.0110, acc_test=0.9949
# poison_percent 20 round 18: loss_train=1.6876, acc_train=0.7978, loss_test=0.0110, acc_test=0.9949
# poison_percent 20 round 19: loss_train=1.6493, acc_train=0.7978, loss_test=0.0109, acc_test=0.9949
# poison_percent 20 round 20: loss_train=1.6645, acc_train=0.7966, loss_test=0.0109, acc_test=0.9949
# poison_percent 20 round 21: loss_train=1.6581, acc_train=0.7975, loss_test=0.0109, acc_test=0.9949
# poison_percent 20 round 22: loss_train=1.6617, acc_train=0.7954, loss_test=0.0109, acc_test=0.9949
# poison_percent 20 round 23: loss_train=1.6821, acc_train=0.7975, loss_test=0.0108, acc_test=0.9949
# poison_percent 20 round 24: loss_train=1.6955, acc_train=0.7969, loss_test=0.0108, acc_test=0.9949
# poison_percent 20 round 25: loss_train=1.7069, acc_train=0.7969, loss_test=0.0108, acc_test=0.9949
# poison_percent 20 round 26: loss_train=1.6511, acc_train=0.7982, loss_test=0.0108, acc_test=0.9949
# poison_percent 20 round 27: loss_train=1.6958, acc_train=0.7951, loss_test=0.0107, acc_test=0.9949
# poison_percent 20 round 28: loss_train=1.6945, acc_train=0.7972, loss_test=0.0107, acc_test=0.9949
# poison_percent 20 round 29: loss_train=1.6895, acc_train=0.7963, loss_test=0.0107, acc_test=0.9949
# poison_percent 20 round 30: loss_train=1.7200, acc_train=0.7969, loss_test=0.0106, acc_test=0.9949
# poison_percent 20 round 31: loss_train=1.6991, acc_train=0.7975, loss_test=0.0106, acc_test=0.9949
# poison_percent 20 round 32: loss_train=1.6862, acc_train=0.7969, loss_test=0.0106, acc_test=0.9949
# poison_percent 20 round 33: loss_train=1.7063, acc_train=0.7966, loss_test=0.0106, acc_test=0.9949
# poison_percent 20 round 34: loss_train=1.6864, acc_train=0.7994, loss_test=0.0105, acc_test=0.9949
# poison_percent 20 round 35: loss_train=1.6955, acc_train=0.7975, loss_test=0.0105, acc_test=0.9949
# poison_percent 20 round 36: loss_train=1.7362, acc_train=0.7966, loss_test=0.0105, acc_test=0.9949
# poison_percent 20 round 37: loss_train=1.7321, acc_train=0.7969, loss_test=0.0105, acc_test=0.9949
# poison_percent 20 round 38: loss_train=1.7437, acc_train=0.7975, loss_test=0.0104, acc_test=0.9949
# poison_percent 20 round 39: loss_train=1.6878, acc_train=0.7988, loss_test=0.0104, acc_test=0.9949
# poison_percent 20 round 40: loss_train=1.7148, acc_train=0.7991, loss_test=0.0104, acc_test=0.9949
# poison_percent 20 round 41: loss_train=1.7450, acc_train=0.7982, loss_test=0.0104, acc_test=0.9949
# poison_percent 20 round 42: loss_train=1.7558, acc_train=0.7975, loss_test=0.0104, acc_test=0.9949
# poison_percent 20 round 43: loss_train=1.7088, acc_train=0.7963, loss_test=0.0103, acc_test=0.9949
# poison_percent 20 round 44: loss_train=1.7520, acc_train=0.7975, loss_test=0.0103, acc_test=0.9949
# poison_percent 20 round 45: loss_train=1.7370, acc_train=0.7982, loss_test=0.0103, acc_test=0.9949
# poison_percent 20 round 46: loss_train=1.7411, acc_train=0.7994, loss_test=0.0103, acc_test=0.9949
# poison_percent 20 round 47: loss_train=1.7410, acc_train=0.7972, loss_test=0.0102, acc_test=0.9949
# poison_percent 20 round 48: loss_train=1.7523, acc_train=0.7985, loss_test=0.0102, acc_test=0.9949
# poison_percent 20 round 49: loss_train=1.7619, acc_train=0.7972, loss_test=0.0102, acc_test=0.9949
# poison_percent 20 round 50: loss_train=1.7759, acc_train=0.7978, loss_test=0.0102, acc_test=0.9949
# poison_percent 20 round 51: loss_train=1.7346, acc_train=0.7978, loss_test=0.0102, acc_test=0.9949
# poison_percent 20 round 52: loss_train=1.7657, acc_train=0.7969, loss_test=0.0101, acc_test=0.9949
# poison_percent 20 round 53: loss_train=1.7172, acc_train=0.7997, loss_test=0.0101, acc_test=0.9949
# poison_percent 20 round 54: loss_train=1.7973, acc_train=0.7969, loss_test=0.0101, acc_test=0.9949
# poison_percent 20 round 55: loss_train=1.7626, acc_train=0.7982, loss_test=0.0101, acc_test=0.9949
# poison_percent 20 round 56: loss_train=1.7368, acc_train=0.7975, loss_test=0.0100, acc_test=0.9949
# poison_percent 20 round 57: loss_train=1.7923, acc_train=0.7982, loss_test=0.0100, acc_test=0.9949
# poison_percent 20 round 58: loss_train=1.7873, acc_train=0.7972, loss_test=0.0100, acc_test=0.9949
# poison_percent 20 round 59: loss_train=1.7937, acc_train=0.7988, loss_test=0.0100, acc_test=0.9949
# poison_percent 20 round 60: loss_train=1.7796, acc_train=0.7975, loss_test=0.0100, acc_test=0.9949
# poison_percent 20 round 61: loss_train=1.7843, acc_train=0.7994, loss_test=0.0099, acc_test=0.9949
# poison_percent 20 round 62: loss_train=1.7562, acc_train=0.7991, loss_test=0.0099, acc_test=0.9949
# poison_percent 20 round 63: loss_train=1.7881, acc_train=0.7963, loss_test=0.0099, acc_test=0.9949
# poison_percent 20 round 64: loss_train=1.8002, acc_train=0.7975, loss_test=0.0099, acc_test=0.9949
# poison_percent 20 round 65: loss_train=1.7914, acc_train=0.7969, loss_test=0.0099, acc_test=0.9949
# poison_percent 20 round 66: loss_train=1.7911, acc_train=0.7978, loss_test=0.0099, acc_test=0.9949
# poison_percent 20 round 67: loss_train=1.7597, acc_train=0.7988, loss_test=0.0098, acc_test=0.9949
# poison_percent 20 round 68: loss_train=1.7888, acc_train=0.7985, loss_test=0.0098, acc_test=0.9949
# poison_percent 20 round 69: loss_train=1.8008, acc_train=0.7988, loss_test=0.0098, acc_test=0.9949
# poison_percent 20 round 70: loss_train=1.7835, acc_train=0.7985, loss_test=0.0098, acc_test=0.9949
# poison_percent 20 round 71: loss_train=1.8196, acc_train=0.7963, loss_test=0.0098, acc_test=0.9949
# poison_percent 20 round 72: loss_train=1.8051, acc_train=0.7975, loss_test=0.0098, acc_test=0.9949
# poison_percent 20 round 73: loss_train=1.8148, acc_train=0.7978, loss_test=0.0098, acc_test=0.9949
# poison_percent 20 round 74: loss_train=1.8148, acc_train=0.7972, loss_test=0.0098, acc_test=0.9949
# poison_percent 20 round 75: loss_train=1.7989, acc_train=0.7975, loss_test=0.0098, acc_test=0.9949
# poison_percent 20 round 76: loss_train=1.8134, acc_train=0.7975, loss_test=0.0097, acc_test=0.9949
# poison_percent 20 round 77: loss_train=1.8618, acc_train=0.7982, loss_test=0.0097, acc_test=0.9949
# poison_percent 20 round 78: loss_train=1.8591, acc_train=0.7978, loss_test=0.0097, acc_test=0.9949
# poison_percent 20 round 79: loss_train=1.8623, acc_train=0.7982, loss_test=0.0097, acc_test=0.9949
# poison_percent 20 round 80: loss_train=1.8458, acc_train=0.7982, loss_test=0.0097, acc_test=0.9949
# poison_percent 20 round 81: loss_train=1.8456, acc_train=0.7966, loss_test=0.0096, acc_test=0.9949
# poison_percent 20 round 82: loss_train=1.8427, acc_train=0.7982, loss_test=0.0096, acc_test=0.9949
# poison_percent 20 round 83: loss_train=1.8380, acc_train=0.7988, loss_test=0.0096, acc_test=0.9949
# poison_percent 20 round 84: loss_train=1.8715, acc_train=0.7963, loss_test=0.0096, acc_test=0.9949
# poison_percent 20 round 85: loss_train=1.8901, acc_train=0.7966, loss_test=0.0096, acc_test=0.9949
# poison_percent 20 round 86: loss_train=1.8337, acc_train=0.7997, loss_test=0.0095, acc_test=0.9949
# poison_percent 20 round 87: loss_train=1.8288, acc_train=0.7963, loss_test=0.0095, acc_test=0.9949
# poison_percent 20 round 88: loss_train=1.8936, acc_train=0.7985, loss_test=0.0095, acc_test=0.9949
# poison_percent 20 round 89: loss_train=1.8453, acc_train=0.7975, loss_test=0.0095, acc_test=0.9949
# poison_percent 20 round 90: loss_train=1.8692, acc_train=0.7966, loss_test=0.0095, acc_test=0.9949
# poison_percent 20 round 91: loss_train=1.8739, acc_train=0.7982, loss_test=0.0095, acc_test=0.9949
# poison_percent 20 round 92: loss_train=1.8552, acc_train=0.7972, loss_test=0.0095, acc_test=0.9954
# poison_percent 20 round 93: loss_train=1.8745, acc_train=0.7982, loss_test=0.0094, acc_test=0.9954
# poison_percent 20 round 94: loss_train=1.9218, acc_train=0.7982, loss_test=0.0094, acc_test=0.9954
# poison_percent 20 round 95: loss_train=1.8988, acc_train=0.7994, loss_test=0.0094, acc_test=0.9954
# poison_percent 20 round 96: loss_train=1.8839, acc_train=0.7975, loss_test=0.0094, acc_test=0.9954
# poison_percent 20 round 97: loss_train=1.8825, acc_train=0.7972, loss_test=0.0094, acc_test=0.9954
# poison_percent 20 round 98: loss_train=1.9241, acc_train=0.7985, loss_test=0.0093, acc_test=0.9954
# poison_percent 20 round 99: loss_train=1.8604, acc_train=0.8000, loss_test=0.0094, acc_test=0.9954
# Training log saved to ./results\FL_ModelN1L2_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=2.8753, acc_train=0.6990, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 1: loss_train=2.8312, acc_train=0.6993, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 2: loss_train=2.8602, acc_train=0.6982, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 3: loss_train=2.8475, acc_train=0.6988, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 4: loss_train=2.8444, acc_train=0.6980, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 5: loss_train=2.8010, acc_train=0.6993, loss_test=0.0095, acc_test=0.9954
# poison_percent 30 round 6: loss_train=2.8744, acc_train=0.6980, loss_test=0.0095, acc_test=0.9954
# poison_percent 30 round 7: loss_train=2.8242, acc_train=0.6982, loss_test=0.0095, acc_test=0.9954
# poison_percent 30 round 8: loss_train=2.8417, acc_train=0.6988, loss_test=0.0095, acc_test=0.9954
# poison_percent 30 round 9: loss_train=2.8761, acc_train=0.6963, loss_test=0.0095, acc_test=0.9954
# poison_percent 30 round 10: loss_train=2.8495, acc_train=0.6996, loss_test=0.0095, acc_test=0.9954
# poison_percent 30 round 11: loss_train=2.8697, acc_train=0.6980, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 12: loss_train=2.8350, acc_train=0.6982, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 13: loss_train=2.8416, acc_train=0.6990, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 14: loss_train=2.8470, acc_train=0.6982, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 15: loss_train=2.8182, acc_train=0.6977, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 16: loss_train=2.8618, acc_train=0.6977, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 17: loss_train=2.8321, acc_train=0.6985, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 18: loss_train=2.8230, acc_train=0.6980, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 19: loss_train=2.8552, acc_train=0.6977, loss_test=0.0095, acc_test=0.9954
# poison_percent 30 round 20: loss_train=2.8237, acc_train=0.6985, loss_test=0.0095, acc_test=0.9954
# poison_percent 30 round 21: loss_train=2.8436, acc_train=0.6982, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 22: loss_train=2.8153, acc_train=0.6990, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 23: loss_train=2.8153, acc_train=0.6985, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 24: loss_train=2.8149, acc_train=0.6988, loss_test=0.0095, acc_test=0.9954
# poison_percent 30 round 25: loss_train=2.8328, acc_train=0.6969, loss_test=0.0095, acc_test=0.9954
# poison_percent 30 round 26: loss_train=2.8245, acc_train=0.6977, loss_test=0.0095, acc_test=0.9954
# poison_percent 30 round 27: loss_train=2.7915, acc_train=0.6988, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 28: loss_train=2.8480, acc_train=0.6996, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 29: loss_train=2.8055, acc_train=0.6969, loss_test=0.0095, acc_test=0.9954
# poison_percent 30 round 30: loss_train=2.8391, acc_train=0.6993, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 31: loss_train=2.8295, acc_train=0.6977, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 32: loss_train=2.8039, acc_train=0.6980, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 33: loss_train=2.8213, acc_train=0.6980, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 34: loss_train=2.8151, acc_train=0.6977, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 35: loss_train=2.8104, acc_train=0.6974, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 36: loss_train=2.8420, acc_train=0.6993, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 37: loss_train=2.7879, acc_train=0.6982, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 38: loss_train=2.7975, acc_train=0.6993, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 39: loss_train=2.8061, acc_train=0.6982, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 40: loss_train=2.8122, acc_train=0.6988, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 41: loss_train=2.8254, acc_train=0.6980, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 42: loss_train=2.8284, acc_train=0.6988, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 43: loss_train=2.8040, acc_train=0.6980, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 44: loss_train=2.7995, acc_train=0.6988, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 45: loss_train=2.7637, acc_train=0.6985, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 46: loss_train=2.8252, acc_train=0.6969, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 47: loss_train=2.7849, acc_train=0.6974, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 48: loss_train=2.8003, acc_train=0.6988, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 49: loss_train=2.7887, acc_train=0.6988, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 50: loss_train=2.8320, acc_train=0.6982, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 51: loss_train=2.7837, acc_train=0.6985, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 52: loss_train=2.7972, acc_train=0.6982, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 53: loss_train=2.7538, acc_train=0.6998, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 54: loss_train=2.7648, acc_train=0.6996, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 55: loss_train=2.7482, acc_train=0.6998, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 56: loss_train=2.7771, acc_train=0.6998, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 57: loss_train=2.8103, acc_train=0.6971, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 58: loss_train=2.8313, acc_train=0.6977, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 59: loss_train=2.8093, acc_train=0.6974, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 60: loss_train=2.8008, acc_train=0.6971, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 61: loss_train=2.8122, acc_train=0.6977, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 62: loss_train=2.7960, acc_train=0.6971, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 63: loss_train=2.7479, acc_train=0.6985, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 64: loss_train=2.7868, acc_train=0.6985, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 65: loss_train=2.7977, acc_train=0.6982, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 66: loss_train=2.7842, acc_train=0.6969, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 67: loss_train=2.7607, acc_train=0.6996, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 68: loss_train=2.8208, acc_train=0.6977, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 69: loss_train=2.7880, acc_train=0.6985, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 70: loss_train=2.8178, acc_train=0.6980, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 71: loss_train=2.8156, acc_train=0.6969, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 72: loss_train=2.8049, acc_train=0.6974, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 73: loss_train=2.7995, acc_train=0.6971, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 74: loss_train=2.7875, acc_train=0.6998, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 75: loss_train=2.7979, acc_train=0.6974, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 76: loss_train=2.7946, acc_train=0.6980, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 77: loss_train=2.7841, acc_train=0.6990, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 78: loss_train=2.7770, acc_train=0.6988, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 79: loss_train=2.7826, acc_train=0.6977, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 80: loss_train=2.7839, acc_train=0.6974, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 81: loss_train=2.7833, acc_train=0.6988, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 82: loss_train=2.8041, acc_train=0.6985, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 83: loss_train=2.7856, acc_train=0.6974, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 84: loss_train=2.8301, acc_train=0.6982, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 85: loss_train=2.7461, acc_train=0.6980, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 86: loss_train=2.7854, acc_train=0.6977, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 87: loss_train=2.7847, acc_train=0.6988, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 88: loss_train=2.7769, acc_train=0.6982, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 89: loss_train=2.7635, acc_train=0.6980, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 90: loss_train=2.7744, acc_train=0.6982, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 91: loss_train=2.7699, acc_train=0.6990, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 92: loss_train=2.7858, acc_train=0.6974, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 93: loss_train=2.7700, acc_train=0.6998, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 94: loss_train=2.7485, acc_train=0.6985, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 95: loss_train=2.8037, acc_train=0.6982, loss_test=0.0094, acc_test=0.9954
# poison_percent 30 round 96: loss_train=2.7674, acc_train=0.6977, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 97: loss_train=2.8073, acc_train=0.6974, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 98: loss_train=2.7403, acc_train=0.6990, loss_test=0.0093, acc_test=0.9954
# poison_percent 30 round 99: loss_train=2.7450, acc_train=0.6977, loss_test=0.0093, acc_test=0.9954
# Training log saved to ./results\FL_ModelN1L2_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=3.6364, acc_train=0.5990, loss_test=0.0094, acc_test=0.9954
# poison_percent 40 round 1: loss_train=3.7048, acc_train=0.5977, loss_test=0.0094, acc_test=0.9954
# poison_percent 40 round 2: loss_train=3.6792, acc_train=0.5988, loss_test=0.0095, acc_test=0.9954
# poison_percent 40 round 3: loss_train=3.6655, acc_train=0.5997, loss_test=0.0095, acc_test=0.9954
# poison_percent 40 round 4: loss_train=3.6968, acc_train=0.5979, loss_test=0.0095, acc_test=0.9959
# poison_percent 40 round 5: loss_train=3.6453, acc_train=0.5979, loss_test=0.0096, acc_test=0.9959
# poison_percent 40 round 6: loss_train=3.6530, acc_train=0.5979, loss_test=0.0096, acc_test=0.9959
# poison_percent 40 round 7: loss_train=3.6774, acc_train=0.5977, loss_test=0.0096, acc_test=0.9959
# poison_percent 40 round 8: loss_train=3.6228, acc_train=0.5981, loss_test=0.0096, acc_test=0.9959
# poison_percent 40 round 9: loss_train=3.6248, acc_train=0.5986, loss_test=0.0097, acc_test=0.9959
# poison_percent 40 round 10: loss_train=3.5895, acc_train=0.5983, loss_test=0.0097, acc_test=0.9959
# poison_percent 40 round 11: loss_train=3.6193, acc_train=0.5990, loss_test=0.0097, acc_test=0.9959
# poison_percent 40 round 12: loss_train=3.5831, acc_train=0.5979, loss_test=0.0098, acc_test=0.9959
# poison_percent 40 round 13: loss_train=3.5998, acc_train=0.5967, loss_test=0.0098, acc_test=0.9959
# poison_percent 40 round 14: loss_train=3.5932, acc_train=0.5986, loss_test=0.0099, acc_test=0.9959
# poison_percent 40 round 15: loss_train=3.6095, acc_train=0.5981, loss_test=0.0099, acc_test=0.9959
# poison_percent 40 round 16: loss_train=3.5737, acc_train=0.5977, loss_test=0.0099, acc_test=0.9959
# poison_percent 40 round 17: loss_train=3.6240, acc_train=0.5986, loss_test=0.0099, acc_test=0.9959
# poison_percent 40 round 18: loss_train=3.5562, acc_train=0.5986, loss_test=0.0100, acc_test=0.9959
# poison_percent 40 round 19: loss_train=3.5583, acc_train=0.5990, loss_test=0.0100, acc_test=0.9959
# poison_percent 40 round 20: loss_train=3.5377, acc_train=0.5988, loss_test=0.0100, acc_test=0.9959
# poison_percent 40 round 21: loss_train=3.5772, acc_train=0.5977, loss_test=0.0100, acc_test=0.9959
# poison_percent 40 round 22: loss_train=3.5229, acc_train=0.5977, loss_test=0.0100, acc_test=0.9959
# poison_percent 40 round 23: loss_train=3.5669, acc_train=0.5988, loss_test=0.0101, acc_test=0.9959
# poison_percent 40 round 24: loss_train=3.5134, acc_train=0.5986, loss_test=0.0101, acc_test=0.9959
# poison_percent 40 round 25: loss_train=3.5300, acc_train=0.5986, loss_test=0.0102, acc_test=0.9959
# poison_percent 40 round 26: loss_train=3.5308, acc_train=0.5990, loss_test=0.0102, acc_test=0.9959
# poison_percent 40 round 27: loss_train=3.5213, acc_train=0.5986, loss_test=0.0103, acc_test=0.9959
# poison_percent 40 round 28: loss_train=3.4797, acc_train=0.5981, loss_test=0.0103, acc_test=0.9959
# poison_percent 40 round 29: loss_train=3.4881, acc_train=0.5981, loss_test=0.0103, acc_test=0.9959
# poison_percent 40 round 30: loss_train=3.4942, acc_train=0.5983, loss_test=0.0104, acc_test=0.9959
# poison_percent 40 round 31: loss_train=3.4529, acc_train=0.5990, loss_test=0.0104, acc_test=0.9959
# poison_percent 40 round 32: loss_train=3.4717, acc_train=0.5997, loss_test=0.0105, acc_test=0.9959
# poison_percent 40 round 33: loss_train=3.4779, acc_train=0.5986, loss_test=0.0105, acc_test=0.9959
# poison_percent 40 round 34: loss_train=3.4626, acc_train=0.5997, loss_test=0.0105, acc_test=0.9959
# poison_percent 40 round 35: loss_train=3.4249, acc_train=0.5977, loss_test=0.0105, acc_test=0.9959
# poison_percent 40 round 36: loss_train=3.4578, acc_train=0.5981, loss_test=0.0106, acc_test=0.9959
# poison_percent 40 round 37: loss_train=3.4365, acc_train=0.5983, loss_test=0.0106, acc_test=0.9959
# poison_percent 40 round 38: loss_train=3.4264, acc_train=0.5993, loss_test=0.0106, acc_test=0.9959
# poison_percent 40 round 39: loss_train=3.4187, acc_train=0.5993, loss_test=0.0107, acc_test=0.9959
# poison_percent 40 round 40: loss_train=3.4178, acc_train=0.5993, loss_test=0.0107, acc_test=0.9959
# poison_percent 40 round 41: loss_train=3.4110, acc_train=0.5993, loss_test=0.0107, acc_test=0.9959
# poison_percent 40 round 42: loss_train=3.3908, acc_train=0.5979, loss_test=0.0108, acc_test=0.9954
# poison_percent 40 round 43: loss_train=3.3642, acc_train=0.5986, loss_test=0.0108, acc_test=0.9954
# poison_percent 40 round 44: loss_train=3.3527, acc_train=0.5977, loss_test=0.0108, acc_test=0.9954
# poison_percent 40 round 45: loss_train=3.3984, acc_train=0.5988, loss_test=0.0109, acc_test=0.9954
# poison_percent 40 round 46: loss_train=3.4107, acc_train=0.5993, loss_test=0.0109, acc_test=0.9954
# poison_percent 40 round 47: loss_train=3.3804, acc_train=0.5993, loss_test=0.0109, acc_test=0.9954
# poison_percent 40 round 48: loss_train=3.3040, acc_train=0.5983, loss_test=0.0110, acc_test=0.9954
# poison_percent 40 round 49: loss_train=3.3616, acc_train=0.5988, loss_test=0.0110, acc_test=0.9954
# poison_percent 40 round 50: loss_train=3.3469, acc_train=0.6004, loss_test=0.0111, acc_test=0.9954
# poison_percent 40 round 51: loss_train=3.3399, acc_train=0.5974, loss_test=0.0111, acc_test=0.9954
# poison_percent 40 round 52: loss_train=3.3406, acc_train=0.5993, loss_test=0.0111, acc_test=0.9954
# poison_percent 40 round 53: loss_train=3.3340, acc_train=0.5988, loss_test=0.0111, acc_test=0.9954
# poison_percent 40 round 54: loss_train=3.3073, acc_train=0.5995, loss_test=0.0112, acc_test=0.9954
# poison_percent 40 round 55: loss_train=3.3346, acc_train=0.5988, loss_test=0.0112, acc_test=0.9954
# poison_percent 40 round 56: loss_train=3.2908, acc_train=0.5995, loss_test=0.0112, acc_test=0.9954
# poison_percent 40 round 57: loss_train=3.3383, acc_train=0.5981, loss_test=0.0113, acc_test=0.9954
# poison_percent 40 round 58: loss_train=3.3222, acc_train=0.5986, loss_test=0.0114, acc_test=0.9954
# poison_percent 40 round 59: loss_train=3.2959, acc_train=0.5974, loss_test=0.0114, acc_test=0.9954
# poison_percent 40 round 60: loss_train=3.2866, acc_train=0.5990, loss_test=0.0114, acc_test=0.9949
# poison_percent 40 round 61: loss_train=3.2900, acc_train=0.5990, loss_test=0.0115, acc_test=0.9949
# poison_percent 40 round 62: loss_train=3.2630, acc_train=0.5990, loss_test=0.0115, acc_test=0.9949
# poison_percent 40 round 63: loss_train=3.2782, acc_train=0.5988, loss_test=0.0116, acc_test=0.9949
# poison_percent 40 round 64: loss_train=3.2648, acc_train=0.5990, loss_test=0.0116, acc_test=0.9949
# poison_percent 40 round 65: loss_train=3.2539, acc_train=0.5986, loss_test=0.0116, acc_test=0.9949
# poison_percent 40 round 66: loss_train=3.2722, acc_train=0.5986, loss_test=0.0117, acc_test=0.9949
# poison_percent 40 round 67: loss_train=3.2918, acc_train=0.5993, loss_test=0.0117, acc_test=0.9949
# poison_percent 40 round 68: loss_train=3.2457, acc_train=0.5986, loss_test=0.0118, acc_test=0.9949
# poison_percent 40 round 69: loss_train=3.2636, acc_train=0.5993, loss_test=0.0118, acc_test=0.9949
# poison_percent 40 round 70: loss_train=3.2540, acc_train=0.5983, loss_test=0.0119, acc_test=0.9949
# poison_percent 40 round 71: loss_train=3.2373, acc_train=0.5981, loss_test=0.0119, acc_test=0.9949
# poison_percent 40 round 72: loss_train=3.2446, acc_train=0.5997, loss_test=0.0119, acc_test=0.9949
# poison_percent 40 round 73: loss_train=3.2138, acc_train=0.5983, loss_test=0.0120, acc_test=0.9949
# poison_percent 40 round 74: loss_train=3.2331, acc_train=0.6002, loss_test=0.0120, acc_test=0.9949
# poison_percent 40 round 75: loss_train=3.2104, acc_train=0.5997, loss_test=0.0121, acc_test=0.9949
# poison_percent 40 round 76: loss_train=3.2340, acc_train=0.5979, loss_test=0.0121, acc_test=0.9949
# poison_percent 40 round 77: loss_train=3.1756, acc_train=0.5993, loss_test=0.0121, acc_test=0.9949
# poison_percent 40 round 78: loss_train=3.2139, acc_train=0.5995, loss_test=0.0121, acc_test=0.9949
# poison_percent 40 round 79: loss_train=3.2166, acc_train=0.5983, loss_test=0.0122, acc_test=0.9949
# poison_percent 40 round 80: loss_train=3.1736, acc_train=0.5993, loss_test=0.0122, acc_test=0.9949
# poison_percent 40 round 81: loss_train=3.2200, acc_train=0.5993, loss_test=0.0122, acc_test=0.9949
# ...
# poison_percent 10 round 81: loss_train=1.7109, acc_train=0.8911, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 82: loss_train=1.7330, acc_train=0.8902, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 83: loss_train=1.6539, acc_train=0.8929, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 84: loss_train=1.6738, acc_train=0.8938, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 85: loss_train=1.7176, acc_train=0.8911, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 86: loss_train=1.7081, acc_train=0.8893, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 87: loss_train=1.6744, acc_train=0.8938, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 88: loss_train=1.6959, acc_train=0.8920, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 89: loss_train=1.7133, acc_train=0.8911, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 90: loss_train=1.7154, acc_train=0.8893, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 91: loss_train=1.7115, acc_train=0.8920, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 92: loss_train=1.6917, acc_train=0.8920, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 93: loss_train=1.6935, acc_train=0.8920, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 94: loss_train=1.7070, acc_train=0.8911, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 95: loss_train=1.6887, acc_train=0.8929, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 96: loss_train=1.6819, acc_train=0.8911, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 97: loss_train=1.7047, acc_train=0.8920, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 98: loss_train=1.7069, acc_train=0.8893, loss_test=0.0101, acc_test=0.9985
# poison_percent 10 round 99: loss_train=1.7041, acc_train=0.8920, loss_test=0.0101, acc_test=0.9985
# Training log saved to ./results\FL_ModelN1L2_Batchsize16_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=3.1656, acc_train=0.8000, loss_test=0.0101, acc_test=0.9985
# poison_percent 20 round 1: loss_train=3.1130, acc_train=0.8008, loss_test=0.0101, acc_test=0.9985
# poison_percent 20 round 2: loss_train=3.1489, acc_train=0.8008, loss_test=0.0101, acc_test=0.9985
# poison_percent 20 round 3: loss_train=3.1829, acc_train=0.7984, loss_test=0.0100, acc_test=0.9985
# poison_percent 20 round 4: loss_train=3.1265, acc_train=0.8024, loss_test=0.0100, acc_test=0.9985
# poison_percent 20 round 5: loss_train=3.1681, acc_train=0.8000, loss_test=0.0100, acc_test=0.9985
# poison_percent 20 round 6: loss_train=3.1758, acc_train=0.7984, loss_test=0.0100, acc_test=0.9985
# poison_percent 20 round 7: loss_train=3.1716, acc_train=0.7984, loss_test=0.0100, acc_test=0.9985
# poison_percent 20 round 8: loss_train=3.1636, acc_train=0.7984, loss_test=0.0100, acc_test=0.9985
# poison_percent 20 round 9: loss_train=3.1603, acc_train=0.7992, loss_test=0.0100, acc_test=0.9985
# poison_percent 20 round 10: loss_train=3.1831, acc_train=0.7992, loss_test=0.0099, acc_test=0.9985
# poison_percent 20 round 11: loss_train=3.1381, acc_train=0.7992, loss_test=0.0099, acc_test=0.9985
# poison_percent 20 round 12: loss_train=3.1336, acc_train=0.7984, loss_test=0.0099, acc_test=0.9985
# poison_percent 20 round 13: loss_train=3.1449, acc_train=0.8000, loss_test=0.0099, acc_test=0.9985
# poison_percent 20 round 14: loss_train=3.1905, acc_train=0.7984, loss_test=0.0099, acc_test=0.9985
# poison_percent 20 round 15: loss_train=3.1611, acc_train=0.8016, loss_test=0.0099, acc_test=0.9985
# poison_percent 20 round 16: loss_train=3.1822, acc_train=0.8000, loss_test=0.0099, acc_test=0.9985
# poison_percent 20 round 17: loss_train=3.1515, acc_train=0.8008, loss_test=0.0099, acc_test=0.9985
# poison_percent 20 round 18: loss_train=3.1590, acc_train=0.8008, loss_test=0.0099, acc_test=0.9985
# poison_percent 20 round 19: loss_train=3.1547, acc_train=0.7992, loss_test=0.0099, acc_test=0.9985
# poison_percent 20 round 20: loss_train=3.1591, acc_train=0.7992, loss_test=0.0098, acc_test=0.9985
# poison_percent 20 round 21: loss_train=3.1833, acc_train=0.7992, loss_test=0.0098, acc_test=0.9985
# poison_percent 20 round 22: loss_train=3.1786, acc_train=0.8000, loss_test=0.0098, acc_test=0.9985
# poison_percent 20 round 23: loss_train=3.1357, acc_train=0.8000, loss_test=0.0098, acc_test=0.9985
# poison_percent 20 round 24: loss_train=3.1665, acc_train=0.8000, loss_test=0.0098, acc_test=0.9985
# poison_percent 20 round 25: loss_train=3.1489, acc_train=0.8000, loss_test=0.0098, acc_test=0.9985
# poison_percent 20 round 26: loss_train=3.1632, acc_train=0.7984, loss_test=0.0098, acc_test=0.9985
# poison_percent 20 round 27: loss_train=3.1773, acc_train=0.8000, loss_test=0.0098, acc_test=0.9985
# poison_percent 20 round 28: loss_train=3.1362, acc_train=0.8008, loss_test=0.0097, acc_test=0.9985
# poison_percent 20 round 29: loss_train=3.1784, acc_train=0.7984, loss_test=0.0097, acc_test=0.9985
# poison_percent 20 round 30: loss_train=3.1637, acc_train=0.8008, loss_test=0.0097, acc_test=0.9985
# poison_percent 20 round 31: loss_train=3.1508, acc_train=0.7992, loss_test=0.0097, acc_test=0.9985
# poison_percent 20 round 32: loss_train=3.1714, acc_train=0.7976, loss_test=0.0097, acc_test=0.9985
# poison_percent 20 round 33: loss_train=3.1923, acc_train=0.7976, loss_test=0.0097, acc_test=0.9985
# poison_percent 20 round 34: loss_train=3.1524, acc_train=0.8000, loss_test=0.0097, acc_test=0.9985
# poison_percent 20 round 35: loss_train=3.1522, acc_train=0.8008, loss_test=0.0097, acc_test=0.9985
# poison_percent 20 round 36: loss_train=3.1798, acc_train=0.7976, loss_test=0.0097, acc_test=0.9985
# poison_percent 20 round 37: loss_train=3.1621, acc_train=0.7992, loss_test=0.0096, acc_test=0.9985
# poison_percent 20 round 38: loss_train=3.1537, acc_train=0.7984, loss_test=0.0096, acc_test=0.9985
# poison_percent 20 round 39: loss_train=3.1373, acc_train=0.8000, loss_test=0.0097, acc_test=0.9985
# poison_percent 20 round 40: loss_train=3.1650, acc_train=0.8008, loss_test=0.0096, acc_test=0.9985
# poison_percent 20 round 41: loss_train=3.1734, acc_train=0.7984, loss_test=0.0096, acc_test=0.9985
# poison_percent 20 round 42: loss_train=3.1385, acc_train=0.8000, loss_test=0.0096, acc_test=0.9985
# poison_percent 20 round 43: loss_train=3.1619, acc_train=0.7984, loss_test=0.0096, acc_test=0.9985
# poison_percent 20 round 44: loss_train=3.1338, acc_train=0.8000, loss_test=0.0096, acc_test=0.9985
# poison_percent 20 round 45: loss_train=3.1533, acc_train=0.8016, loss_test=0.0096, acc_test=0.9985
# poison_percent 20 round 46: loss_train=3.1543, acc_train=0.7976, loss_test=0.0096, acc_test=0.9985
# poison_percent 20 round 47: loss_train=3.1964, acc_train=0.7960, loss_test=0.0096, acc_test=0.9985
# poison_percent 20 round 48: loss_train=3.1717, acc_train=0.8000, loss_test=0.0096, acc_test=0.9985
# poison_percent 20 round 49: loss_train=3.1822, acc_train=0.7992, loss_test=0.0096, acc_test=0.9985
# poison_percent 20 round 50: loss_train=3.1838, acc_train=0.7984, loss_test=0.0096, acc_test=0.9985
# poison_percent 20 round 51: loss_train=3.1605, acc_train=0.8008, loss_test=0.0095, acc_test=0.9985
# poison_percent 20 round 52: loss_train=3.1506, acc_train=0.7984, loss_test=0.0095, acc_test=0.9985
# poison_percent 20 round 53: loss_train=3.1753, acc_train=0.7992, loss_test=0.0095, acc_test=0.9985
# poison_percent 20 round 54: loss_train=3.1793, acc_train=0.7984, loss_test=0.0095, acc_test=0.9985
# poison_percent 20 round 55: loss_train=3.1587, acc_train=0.7992, loss_test=0.0095, acc_test=0.9985
# poison_percent 20 round 56: loss_train=3.1529, acc_train=0.8008, loss_test=0.0095, acc_test=0.9985
# poison_percent 20 round 57: loss_train=3.1981, acc_train=0.7984, loss_test=0.0095, acc_test=0.9980
# poison_percent 20 round 58: loss_train=3.1319, acc_train=0.8000, loss_test=0.0095, acc_test=0.9980
# poison_percent 20 round 59: loss_train=3.1425, acc_train=0.8008, loss_test=0.0095, acc_test=0.9980
# poison_percent 20 round 60: loss_train=3.2028, acc_train=0.7984, loss_test=0.0095, acc_test=0.9980
# poison_percent 20 round 61: loss_train=3.1322, acc_train=0.8016, loss_test=0.0095, acc_test=0.9980
# poison_percent 20 round 62: loss_train=3.1449, acc_train=0.8024, loss_test=0.0095, acc_test=0.9980
# poison_percent 20 round 63: loss_train=3.1338, acc_train=0.8024, loss_test=0.0095, acc_test=0.9980
# poison_percent 20 round 64: loss_train=3.1597, acc_train=0.8016, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 65: loss_train=3.1558, acc_train=0.7992, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 66: loss_train=3.1446, acc_train=0.8016, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 67: loss_train=3.1385, acc_train=0.8008, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 68: loss_train=3.1455, acc_train=0.8008, loss_test=0.0095, acc_test=0.9980
# poison_percent 20 round 69: loss_train=3.1304, acc_train=0.7984, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 70: loss_train=3.1991, acc_train=0.7984, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 71: loss_train=3.1521, acc_train=0.7992, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 72: loss_train=3.1781, acc_train=0.7984, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 73: loss_train=3.1708, acc_train=0.7992, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 74: loss_train=3.1960, acc_train=0.7984, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 75: loss_train=3.1481, acc_train=0.7984, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 76: loss_train=3.1434, acc_train=0.8008, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 77: loss_train=3.1478, acc_train=0.8008, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 78: loss_train=3.1676, acc_train=0.7976, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 79: loss_train=3.1994, acc_train=0.7976, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 80: loss_train=3.1671, acc_train=0.8000, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 81: loss_train=3.1910, acc_train=0.7968, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 82: loss_train=3.1858, acc_train=0.7992, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 83: loss_train=3.1360, acc_train=0.7984, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 84: loss_train=3.1465, acc_train=0.7984, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 85: loss_train=3.1635, acc_train=0.8000, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 86: loss_train=3.1055, acc_train=0.8008, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 87: loss_train=3.1356, acc_train=0.8000, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 88: loss_train=3.1491, acc_train=0.8016, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 89: loss_train=3.2176, acc_train=0.7976, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 90: loss_train=3.1382, acc_train=0.8008, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 91: loss_train=3.1572, acc_train=0.8000, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 92: loss_train=3.1363, acc_train=0.8000, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 93: loss_train=3.1695, acc_train=0.7992, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 94: loss_train=3.1797, acc_train=0.8008, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 95: loss_train=3.1811, acc_train=0.7976, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 96: loss_train=3.1796, acc_train=0.7984, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 97: loss_train=3.1618, acc_train=0.7984, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 98: loss_train=3.1352, acc_train=0.8016, loss_test=0.0094, acc_test=0.9980
# poison_percent 20 round 99: loss_train=3.1709, acc_train=0.7992, loss_test=0.0094, acc_test=0.9980
# Training log saved to ./results\FL_ModelN1L2_Batchsize16_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=4.7528, acc_train=0.7000, loss_test=0.0094, acc_test=0.9980
# poison_percent 30 round 1: loss_train=4.7451, acc_train=0.7000, loss_test=0.0094, acc_test=0.9980
# poison_percent 30 round 2: loss_train=4.7301, acc_train=0.7000, loss_test=0.0094, acc_test=0.9980
# poison_percent 30 round 3: loss_train=4.7382, acc_train=0.6979, loss_test=0.0094, acc_test=0.9980
# poison_percent 30 round 4: loss_train=4.7379, acc_train=0.7007, loss_test=0.0094, acc_test=0.9980
# poison_percent 30 round 5: loss_train=4.7277, acc_train=0.6986, loss_test=0.0094, acc_test=0.9980
# poison_percent 30 round 6: loss_train=4.7821, acc_train=0.6993, loss_test=0.0094, acc_test=0.9980
# poison_percent 30 round 7: loss_train=4.6861, acc_train=0.7014, loss_test=0.0094, acc_test=0.9980
# poison_percent 30 round 8: loss_train=4.7980, acc_train=0.6979, loss_test=0.0094, acc_test=0.9980
# poison_percent 30 round 9: loss_train=4.7697, acc_train=0.6979, loss_test=0.0094, acc_test=0.9980
# poison_percent 30 round 10: loss_train=4.7599, acc_train=0.6972, loss_test=0.0094, acc_test=0.9980
# poison_percent 30 round 11: loss_train=4.7145, acc_train=0.7007, loss_test=0.0094, acc_test=0.9980
# poison_percent 30 round 12: loss_train=4.7037, acc_train=0.7000, loss_test=0.0094, acc_test=0.9980
# poison_percent 30 round 13: loss_train=4.7187, acc_train=0.6979, loss_test=0.0094, acc_test=0.9980
# poison_percent 30 round 14: loss_train=4.7328, acc_train=0.7000, loss_test=0.0095, acc_test=0.9980
# poison_percent 30 round 15: loss_train=4.7483, acc_train=0.7000, loss_test=0.0095, acc_test=0.9980
# poison_percent 30 round 16: loss_train=4.7522, acc_train=0.6979, loss_test=0.0095, acc_test=0.9980
# poison_percent 30 round 17: loss_train=4.7801, acc_train=0.7000, loss_test=0.0095, acc_test=0.9980
# poison_percent 30 round 18: loss_train=4.6984, acc_train=0.6993, loss_test=0.0095, acc_test=0.9980
# poison_percent 30 round 19: loss_train=4.7248, acc_train=0.7000, loss_test=0.0095, acc_test=0.9980
# poison_percent 30 round 20: loss_train=4.7470, acc_train=0.6979, loss_test=0.0096, acc_test=0.9980
# poison_percent 30 round 21: loss_train=4.7442, acc_train=0.7007, loss_test=0.0096, acc_test=0.9980
# poison_percent 30 round 22: loss_train=4.7548, acc_train=0.6972, loss_test=0.0096, acc_test=0.9980
# poison_percent 30 round 23: loss_train=4.7625, acc_train=0.6986, loss_test=0.0096, acc_test=0.9980
# poison_percent 30 round 24: loss_train=4.6925, acc_train=0.7021, loss_test=0.0097, acc_test=0.9980
# poison_percent 30 round 25: loss_train=4.7598, acc_train=0.6993, loss_test=0.0097, acc_test=0.9980
# poison_percent 30 round 26: loss_train=4.7714, acc_train=0.6979, loss_test=0.0098, acc_test=0.9980
# poison_percent 30 round 27: loss_train=4.7255, acc_train=0.7014, loss_test=0.0098, acc_test=0.9980
# poison_percent 30 round 28: loss_train=4.6929, acc_train=0.7028, loss_test=0.0099, acc_test=0.9980
# poison_percent 30 round 29: loss_train=4.7625, acc_train=0.7000, loss_test=0.0099, acc_test=0.9980
# poison_percent 30 round 30: loss_train=4.7393, acc_train=0.7007, loss_test=0.0100, acc_test=0.9980
# poison_percent 30 round 31: loss_train=4.7687, acc_train=0.6993, loss_test=0.0100, acc_test=0.9985
# poison_percent 30 round 32: loss_train=4.7516, acc_train=0.6993, loss_test=0.0101, acc_test=0.9985
# poison_percent 30 round 33: loss_train=4.6949, acc_train=0.6993, loss_test=0.0101, acc_test=0.9985
# poison_percent 30 round 34: loss_train=4.7514, acc_train=0.6979, loss_test=0.0101, acc_test=0.9985
# poison_percent 30 round 35: loss_train=4.7436, acc_train=0.6965, loss_test=0.0102, acc_test=0.9985
# poison_percent 30 round 36: loss_train=4.6922, acc_train=0.7000, loss_test=0.0102, acc_test=0.9985
# poison_percent 30 round 37: loss_train=4.7278, acc_train=0.6986, loss_test=0.0102, acc_test=0.9985
# poison_percent 30 round 38: loss_train=4.7285, acc_train=0.6986, loss_test=0.0102, acc_test=0.9985
# poison_percent 30 round 39: loss_train=4.7322, acc_train=0.7007, loss_test=0.0103, acc_test=0.9985
