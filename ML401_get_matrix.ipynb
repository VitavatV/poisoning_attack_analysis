# %%
import pandas as pd

# %%
df_baseline_csv = pd.read_csv('results\ML101_linear_CL_batch_poisoned_0\ML101_linear_CL_batch_poisoned_0.csv')
df_baseline_csv = df_baseline_csv[df_baseline_csv['batch']==-1].reset_index(drop=True)
df_25_csv = pd.read_csv('results\ML101_linear_CL_batch_poisoned_25\ML101_linear_CL_batch_poisoned_25.csv')
df_25_csv = df_25_csv[df_25_csv['batch']==-1].reset_index(drop=True)
df_50_csv = pd.read_csv('results\ML101_linear_CL_batch_poisoned_50\ML101_linear_CL_batch_poisoned_50.csv')
df_50_csv = df_50_csv[df_50_csv['batch']==-1].reset_index(drop=True)
df_75_csv = pd.read_csv('results\ML101_linear_CL_batch_poisoned_75\ML101_linear_CL_batch_poisoned_75.csv')
df_75_csv = df_75_csv[df_75_csv['batch']==-1].reset_index(drop=True)
df_100_csv = pd.read_csv('results\ML101_linear_CL_batch_poisoned_100\ML101_linear_CL_batch_poisoned_100.csv')
df_100_csv = df_100_csv[df_100_csv['batch']==-1].reset_index(drop=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:3: SyntaxWarning: invalid escape sequence '\M'
# <>:5: SyntaxWarning: invalid escape sequence '\M'
# <>:7: SyntaxWarning: invalid escape sequence '\M'
# <>:9: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:3: SyntaxWarning: invalid escape sequence '\M'
# <>:5: SyntaxWarning: invalid escape sequence '\M'
# <>:7: SyntaxWarning: invalid escape sequence '\M'
# <>:9: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_5364\1332665289.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df_baseline_csv = pd.read_csv('results\ML101_linear_CL_batch_poisoned_0\ML101_linear_CL_batch_poisoned_0.csv')
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_5364\1332665289.py:3: SyntaxWarning: invalid escape sequence '\M'
#   df_25_csv = pd.read_csv('results\ML101_linear_CL_batch_poisoned_25\ML101_linear_CL_batch_poisoned_25.csv')
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_5364\1332665289.py:5: SyntaxWarning: invalid escape sequence '\M'
#   df_50_csv = pd.read_csv('results\ML101_linear_CL_batch_poisoned_50\ML101_linear_CL_batch_poisoned_50.csv')
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_5364\1332665289.py:7: SyntaxWarning: invalid escape sequence '\M'
#   df_75_csv = pd.read_csv('results\ML101_linear_CL_batch_poisoned_75\ML101_linear_CL_batch_poisoned_75.csv')
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_5364\1332665289.py:9: SyntaxWarning: invalid escape sequence '\M'
#   df_100_csv = pd.read_csv('results\ML101_linear_CL_batch_poisoned_100\ML101_linear_CL_batch_poisoned_100.csv')

# %%
df_baseline_csv.head()  # Display the first few rows of the baseline dataframe
# Out:
#    epoch  batch  epoch_batch  w1_before  w2_before  b1_before      loss  \
# 0      1     -1          1.0   0.300000   0.400000   0.600000  0.638488
# 1      2     -1          2.0   0.181047   0.518588   0.384524  0.587348
# 2      3     -1          3.0   0.086089   0.649964   0.216401  0.546901
# 3      4     -1          4.0   0.009092   0.788148   0.084170  0.513162
# 4      5     -1          5.0  -0.055214   0.928358  -0.022117  0.484030
#
#    accuracy   grad_w1   grad_w2   grad_b1  w1_after  w2_after  b1_after
# 0    0.5000  0.118953 -0.118588  0.215476  0.181047  0.518588  0.384524
# 1    0.5570  0.094959 -0.131376  0.168122  0.086089  0.649964  0.216401
# 2    0.6935  0.076996 -0.138184  0.132231  0.009092  0.788148  0.084170
# 3    0.8060  0.064306 -0.140210  0.106287 -0.055214  0.928358 -0.022117
# 4    0.8805  0.055551 -0.138972  0.087806 -0.110765  1.067330 -0.109922

# %%
# Convergent Training Loss: final loss value
convergent_loss = [
    df_baseline_csv['loss'].iloc[-1],
    df_25_csv['loss'].iloc[-1],
    df_50_csv['loss'].iloc[-1],
    df_75_csv['loss'].iloc[-1],
    df_100_csv['loss'].iloc[-1]
]

# Global Model Accuracy on clean test data: final accuracy value
final_accuracy = [
    df_baseline_csv['accuracy'].iloc[-1],
    df_25_csv['accuracy'].iloc[-1],
    df_50_csv['accuracy'].iloc[-1],
    df_75_csv['accuracy'].iloc[-1],
    df_100_csv['accuracy'].iloc[-1]
]

# Time to Convergence: first epoch where accuracy >= threshold (e.g., 0.95)
def get_time_to_convergence(df, accuracy_threshold = 0.95):
    convergence_idx = df[df['accuracy'] >= accuracy_threshold].index
    return convergence_idx[0] if len(convergence_idx) > 0 else None
    
acc_thresh = 0.90
time_to_convergence_90 = [
    get_time_to_convergence(df_baseline_csv, acc_thresh),
    get_time_to_convergence(df_25_csv, acc_thresh),
    get_time_to_convergence(df_50_csv, acc_thresh),
    get_time_to_convergence(df_75_csv, acc_thresh),
    get_time_to_convergence(df_100_csv, acc_thresh)
]
acc_thresh = 0.80
time_to_convergence_80 = [
    get_time_to_convergence(df_baseline_csv, acc_thresh),
    get_time_to_convergence(df_25_csv, acc_thresh),
    get_time_to_convergence(df_50_csv, acc_thresh),
    get_time_to_convergence(df_75_csv, acc_thresh),
    get_time_to_convergence(df_100_csv, acc_thresh)
]
acc_thresh = 0.70
time_to_convergence_70 = [
    get_time_to_convergence(df_baseline_csv, acc_thresh),
    get_time_to_convergence(df_25_csv, acc_thresh),
    get_time_to_convergence(df_50_csv, acc_thresh),
    get_time_to_convergence(df_75_csv, acc_thresh),
    get_time_to_convergence(df_100_csv, acc_thresh)
]
acc_thresh = 0.60
time_to_convergence_60 = [
    get_time_to_convergence(df_baseline_csv, acc_thresh),
    get_time_to_convergence(df_25_csv, acc_thresh),
    get_time_to_convergence(df_50_csv, acc_thresh),
    get_time_to_convergence(df_75_csv, acc_thresh),
    get_time_to_convergence(df_100_csv, acc_thresh)
]
acc_thresh = 0.50
time_to_convergence_50 = [
    get_time_to_convergence(df_baseline_csv, acc_thresh),
    get_time_to_convergence(df_25_csv, acc_thresh),
    get_time_to_convergence(df_50_csv, acc_thresh),
    get_time_to_convergence(df_75_csv, acc_thresh),
    get_time_to_convergence(df_100_csv, acc_thresh)
]

# Robustness Score: accuracy degradation compared to baseline
robustness_100 = [
    df_baseline_csv['accuracy'].iloc[-1] - df_baseline_csv['accuracy'].iloc[-1],
    df_baseline_csv['accuracy'].iloc[-1] - df_25_csv['accuracy'].iloc[-1],
    df_baseline_csv['accuracy'].iloc[-1] - df_50_csv['accuracy'].iloc[-1],
    df_baseline_csv['accuracy'].iloc[-1] - df_75_csv['accuracy'].iloc[-1],
    df_baseline_csv['accuracy'].iloc[-1] - df_100_csv['accuracy'].iloc[-1]
]

print(f"Convergent Training Loss: {convergent_loss}")
print(f"Final Accuracy: {final_accuracy}")
print(f"Time to Convergence 90% (epoch): {time_to_convergence_90}")
print(f"Time to Convergence 80% (epoch): {time_to_convergence_80}")
print(f"Time to Convergence 70% (epoch): {time_to_convergence_70}")
print(f"Time to Convergence 60% (epoch): {time_to_convergence_60}")
print(f"Time to Convergence 50% (epoch): {time_to_convergence_50}")
print(f"Robustness Score: {robustness_100}")
# Out:
# Convergent Training Loss: [np.float64(0.094552494585514), np.float64(0.5186864137649536), np.float64(0.6433804631233215), np.float64(0.6842697858810425), np.float64(0.6930771470069885)]
# Final Accuracy: [np.float64(1.0), np.float64(0.800000011920929), np.float64(0.6666666865348816), np.float64(0.5714285969734192), np.float64(0.5080000162124634)]
# Time to Convergence 90% (epoch): [np.int64(5), None, None, None, None]
# Time to Convergence 80% (epoch): [np.int64(3), np.int64(20), None, None, None]
# Time to Convergence 70% (epoch): [np.int64(3), np.int64(4), None, None, None]
# Time to Convergence 60% (epoch): [np.int64(2), np.int64(3), np.int64(5), None, None]
# Time to Convergence 50% (epoch): [0, 0, 0, 0, np.int64(0)]
# Robustness Score: [np.float64(0.4919999837875366), np.float64(0.4285714030265808), np.float64(0.3333333134651184), np.float64(0.19999998807907104), np.float64(0.0)]

# %%
import numpy as np
import pandas as pd

# Prepare data for the table
metrics_table = pd.DataFrame({
    'Poisoned %': ['0 (Baseline)', '25', '50', '75', '100'],
    'Final Accuracy': final_accuracy,
    'Convergent Loss': convergent_loss,
    'Robustness (vs Baseline)': robustness_100,
    'Time to 50%': time_to_convergence_50,
    'Time to 60%': time_to_convergence_60,
    'Time to 70%': time_to_convergence_70,
    'Time to 80%': time_to_convergence_80,
    'Time to 90%': time_to_convergence_90
})

# Convert numpy types to native Python types for display
metrics_table = metrics_table.applymap(lambda x: x.item() if isinstance(x, (np.generic,)) else x)

print(metrics_table)
# Out:
#      Poisoned %  Final Accuracy  Convergent Loss  Robustness (vs Baseline)  \
# 0  0 (Baseline)        1.000000         0.094552                  0.492000
# 1            25        0.800000         0.518686                  0.428571
# 2            50        0.666667         0.643380                  0.333333
# 3            75        0.571429         0.684270                  0.200000
# 4           100        0.508000         0.693077                  0.000000
#
#    Time to 50%  Time to 60%  Time to 70%  Time to 80%  Time to 90%
# 0            0          2.0          3.0          3.0          5.0
# 1            0          3.0          4.0         20.0          NaN
# 2            0          5.0          NaN          NaN          NaN
# 3            0          NaN          NaN          NaN          NaN
# 4            0          NaN          NaN          NaN          NaN
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_5364\2177702750.py:18: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   metrics_table = metrics_table.applymap(lambda x: x.item() if isinstance(x, (np.generic,)) else x)

# %%
df_baseline_csv = pd.read_csv('results\ML302_linear_FLW_batch_poisoned_0\ML302_linear_FLW_batch_poisoned_0.csv')
df_baseline_csv = df_baseline_csv[df_baseline_csv['batch']==-1].reset_index(drop=True)
df_25_csv = pd.read_csv('results\ML302_linear_FLW_batch_poisoned_25\ML302_linear_FLW_batch_poisoned_25.csv')
df_25_csv = df_25_csv[df_25_csv['batch']==-1].reset_index(drop=True)
df_50_csv = pd.read_csv('results\ML302_linear_FLW_batch_poisoned_50\ML302_linear_FLW_batch_poisoned_50.csv')
df_50_csv = df_50_csv[df_50_csv['batch']==-1].reset_index(drop=True)
df_75_csv = pd.read_csv('results\ML302_linear_FLW_batch_poisoned_75\ML302_linear_FLW_batch_poisoned_75.csv')
df_75_csv = df_75_csv[df_75_csv['batch']==-1].reset_index(drop=True)
df_100_csv = pd.read_csv('results\ML302_linear_FLW_batch_poisoned_100\ML302_linear_FLW_batch_poisoned_100.csv')
df_100_csv = df_100_csv[df_100_csv['batch']==-1].reset_index(drop=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:3: SyntaxWarning: invalid escape sequence '\M'
# <>:5: SyntaxWarning: invalid escape sequence '\M'
# <>:7: SyntaxWarning: invalid escape sequence '\M'
# <>:9: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:3: SyntaxWarning: invalid escape sequence '\M'
# <>:5: SyntaxWarning: invalid escape sequence '\M'
# <>:7: SyntaxWarning: invalid escape sequence '\M'
# <>:9: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_5364\1560117000.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df_baseline_csv = pd.read_csv('results\ML302_linear_FLW_batch_poisoned_0\ML302_linear_FLW_batch_poisoned_0.csv')
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_5364\1560117000.py:3: SyntaxWarning: invalid escape sequence '\M'
#   df_25_csv = pd.read_csv('results\ML302_linear_FLW_batch_poisoned_25\ML302_linear_FLW_batch_poisoned_25.csv')
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_5364\1560117000.py:5: SyntaxWarning: invalid escape sequence '\M'
#   df_50_csv = pd.read_csv('results\ML302_linear_FLW_batch_poisoned_50\ML302_linear_FLW_batch_poisoned_50.csv')
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_5364\1560117000.py:7: SyntaxWarning: invalid escape sequence '\M'
#   df_75_csv = pd.read_csv('results\ML302_linear_FLW_batch_poisoned_75\ML302_linear_FLW_batch_poisoned_75.csv')
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_5364\1560117000.py:9: SyntaxWarning: invalid escape sequence '\M'
#   df_100_csv = pd.read_csv('results\ML302_linear_FLW_batch_poisoned_100\ML302_linear_FLW_batch_poisoned_100.csv')

# %%
# Convergent Training Loss: final loss value
convergent_loss = [
    df_baseline_csv['loss'].iloc[-1],
    df_25_csv['loss'].iloc[-1],
    df_50_csv['loss'].iloc[-1],
    df_75_csv['loss'].iloc[-1],
    df_100_csv['loss'].iloc[-1]
]

# Global Model Accuracy on clean test data: final accuracy value
final_accuracy = [
    df_baseline_csv['accuracy'].iloc[-1],
    df_25_csv['accuracy'].iloc[-1],
    df_50_csv['accuracy'].iloc[-1],
    df_75_csv['accuracy'].iloc[-1],
    df_100_csv['accuracy'].iloc[-1]
]

# Time to Convergence: first epoch where accuracy >= threshold (e.g., 0.95)
def get_time_to_convergence(df, accuracy_threshold = 0.95):
    convergence_idx = df[df['accuracy'] >= accuracy_threshold].index
    return convergence_idx[0] if len(convergence_idx) > 0 else None
    
acc_thresh = 0.90
time_to_convergence_90 = [
    get_time_to_convergence(df_baseline_csv, acc_thresh),
    get_time_to_convergence(df_25_csv, acc_thresh),
    get_time_to_convergence(df_50_csv, acc_thresh),
    get_time_to_convergence(df_75_csv, acc_thresh),
    get_time_to_convergence(df_100_csv, acc_thresh)
]
acc_thresh = 0.80
time_to_convergence_80 = [
    get_time_to_convergence(df_baseline_csv, acc_thresh),
    get_time_to_convergence(df_25_csv, acc_thresh),
    get_time_to_convergence(df_50_csv, acc_thresh),
    get_time_to_convergence(df_75_csv, acc_thresh),
    get_time_to_convergence(df_100_csv, acc_thresh)
]
acc_thresh = 0.70
time_to_convergence_70 = [
    get_time_to_convergence(df_baseline_csv, acc_thresh),
    get_time_to_convergence(df_25_csv, acc_thresh),
    get_time_to_convergence(df_50_csv, acc_thresh),
    get_time_to_convergence(df_75_csv, acc_thresh),
    get_time_to_convergence(df_100_csv, acc_thresh)
]
acc_thresh = 0.60
time_to_convergence_60 = [
    get_time_to_convergence(df_baseline_csv, acc_thresh),
    get_time_to_convergence(df_25_csv, acc_thresh),
    get_time_to_convergence(df_50_csv, acc_thresh),
    get_time_to_convergence(df_75_csv, acc_thresh),
    get_time_to_convergence(df_100_csv, acc_thresh)
]
acc_thresh = 0.50
time_to_convergence_50 = [
    get_time_to_convergence(df_baseline_csv, acc_thresh),
    get_time_to_convergence(df_25_csv, acc_thresh),
    get_time_to_convergence(df_50_csv, acc_thresh),
    get_time_to_convergence(df_75_csv, acc_thresh),
    get_time_to_convergence(df_100_csv, acc_thresh)
]

# Robustness Score: accuracy degradation compared to baseline
robustness_100 = [
    df_baseline_csv['accuracy'].iloc[-1] - df_baseline_csv['accuracy'].iloc[-1],
    df_baseline_csv['accuracy'].iloc[-1] - df_25_csv['accuracy'].iloc[-1],
    df_baseline_csv['accuracy'].iloc[-1] - df_50_csv['accuracy'].iloc[-1],
    df_baseline_csv['accuracy'].iloc[-1] - df_75_csv['accuracy'].iloc[-1],
    df_baseline_csv['accuracy'].iloc[-1] - df_100_csv['accuracy'].iloc[-1]
]

print(f"Convergent Training Loss: {convergent_loss}")
print(f"Final Accuracy: {final_accuracy}")
print(f"Time to Convergence 90% (epoch): {time_to_convergence_90}")
print(f"Time to Convergence 80% (epoch): {time_to_convergence_80}")
print(f"Time to Convergence 70% (epoch): {time_to_convergence_70}")
print(f"Time to Convergence 60% (epoch): {time_to_convergence_60}")
print(f"Time to Convergence 50% (epoch): {time_to_convergence_50}")
print(f"Robustness Score: {robustness_100}")
# Out:
# Convergent Training Loss: [np.float64(0.0935807302594184), np.float64(0.5185511708259583), np.float64(0.6433342695236206), np.float64(0.684252083), np.float64(0.6930771470069885)]
# Final Accuracy: [np.float64(1.0), np.float64(0.800000011920929), np.float64(0.6666666865348816), np.float64(0.571428597), np.float64(0.5137500166893005)]
# Time to Convergence 90% (epoch): [np.int64(5), None, None, None, None]
# Time to Convergence 80% (epoch): [np.int64(4), np.int64(20), None, None, None]
# Time to Convergence 70% (epoch): [np.int64(3), np.int64(4), None, None, None]
# Time to Convergence 60% (epoch): [np.int64(2), np.int64(3), np.int64(5), None, None]
# Time to Convergence 50% (epoch): [0, 0, 0, 0, np.int64(0)]
# Robustness Score: [np.float64(0.48624998331069946), np.float64(0.42857140299999996), np.float64(0.3333333134651184), np.float64(0.19999998807907104), np.float64(0.0)]

# %%
import numpy as np
import pandas as pd

# Prepare data for the table
metrics_table = pd.DataFrame({
    'Poisoned %': ['0 (Baseline)', '25', '50', '75', '100'],
    'Final Accuracy': final_accuracy,
    'Convergent Loss': convergent_loss,
    'Robustness (vs Baseline)': robustness_100,
    'Time to 50%': time_to_convergence_50,
    'Time to 60%': time_to_convergence_60,
    'Time to 70%': time_to_convergence_70,
    'Time to 80%': time_to_convergence_80,
    'Time to 90%': time_to_convergence_90
})

# Convert numpy types to native Python types for display
metrics_table = metrics_table.applymap(lambda x: x.item() if isinstance(x, (np.generic,)) else x)

print(metrics_table)
# Out:
#      Poisoned %  Final Accuracy  Convergent Loss  Robustness (vs Baseline)  \
# 0  0 (Baseline)        1.000000         0.093581                  0.486250
# 1            25        0.800000         0.518551                  0.428571
# 2            50        0.666667         0.643334                  0.333333
# 3            75        0.571429         0.684252                  0.200000
# 4           100        0.513750         0.693077                  0.000000
#
#    Time to 50%  Time to 60%  Time to 70%  Time to 80%  Time to 90%
# 0            0          2.0          3.0          4.0          5.0
# 1            0          3.0          4.0         20.0          NaN
# 2            0          5.0          NaN          NaN          NaN
# 3            0          NaN          NaN          NaN          NaN
# 4            0          NaN          NaN          NaN          NaN
# C:\Users\Vitavat\AppData\Local\Temp\ipykernel_5364\2177702750.py:18: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   metrics_table = metrics_table.applymap(lambda x: x.item() if isinstance(x, (np.generic,)) else x)
