# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 32
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_binary_poison/train"
TEST_PATH = "../data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
for NODE in [1,2,4,8,16,32]:
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, 1)
            self.relu = nn.ReLU()
        def forward(self, x):
            x = self.fc1(x)
            x = self.relu(x)
            x = self.fc2(x)
            x = torch.sigmoid(x)
            return x

    BATCH_SIZE_list = [BATCH_SIZE]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"CL_ModelN{NODE}L2_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                        poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                        select='Honest+Poisoned')
                X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
                # print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
                # print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")

                X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
                y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                torch.save(model, os.path.join(save_path,'model_init.pt'))
                optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

                records = []

                # Training loop
                for epoch in range(EPOCHS):

                    # Train
                    model.train()
                    
                    #randomize the training data
                    perm = torch.randperm(X_train_tensor.size(0))
                    X_train_tensor = X_train_tensor[perm]
                    y_train_tensor = y_train_tensor[perm]

                    for start in range(0, X_train_tensor.size(0), experiment_bs):
                        end = start + experiment_bs
                        xb = X_train_tensor[start:end]
                        yb = y_train_tensor[start:end]
                        outputs = model(xb)
                        preds = (outputs >= 0.5).float()
                        acc_train = (preds == yb).float().mean().item()
                        loss_train = binary_cross_entropy(outputs, yb)
                        optimizer.zero_grad()
                        loss_train.backward()
                        optimizer.step()

                    # Evaluate
                    model.eval()
                    with torch.no_grad():
                        outputs = model(X_test_tensor)
                        preds = (outputs >= 0.5).float()
                        loss_test = binary_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"epoch {epoch}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['epoch'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['epoch'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 epoch 0: loss_train=0.5812, acc_train=0.2500, loss_test=0.3895, acc_test=0.5000
# poison_percent 0 epoch 1: loss_train=0.1719, acc_train=1.0000, loss_test=0.3346, acc_test=0.9923
# poison_percent 0 epoch 2: loss_train=0.3625, acc_train=1.0000, loss_test=0.2927, acc_test=0.9949
# poison_percent 0 epoch 3: loss_train=0.3205, acc_train=1.0000, loss_test=0.2573, acc_test=0.9980
# poison_percent 0 epoch 4: loss_train=0.2248, acc_train=1.0000, loss_test=0.2274, acc_test=0.9985
# poison_percent 0 epoch 5: loss_train=0.1501, acc_train=1.0000, loss_test=0.2016, acc_test=0.9995
# poison_percent 0 epoch 6: loss_train=0.1417, acc_train=1.0000, loss_test=0.1794, acc_test=0.9995
# poison_percent 0 epoch 7: loss_train=0.1193, acc_train=1.0000, loss_test=0.1601, acc_test=0.9995
# poison_percent 0 epoch 8: loss_train=0.1424, acc_train=1.0000, loss_test=0.1433, acc_test=1.0000
# poison_percent 0 epoch 9: loss_train=0.0954, acc_train=1.0000, loss_test=0.1287, acc_test=1.0000
# poison_percent 0 epoch 10: loss_train=0.0875, acc_train=1.0000, loss_test=0.1157, acc_test=1.0000
# poison_percent 0 epoch 11: loss_train=0.1291, acc_train=1.0000, loss_test=0.1043, acc_test=1.0000
# poison_percent 0 epoch 12: loss_train=0.1163, acc_train=1.0000, loss_test=0.0944, acc_test=1.0000
# poison_percent 0 epoch 13: loss_train=0.1058, acc_train=1.0000, loss_test=0.0854, acc_test=1.0000
# poison_percent 0 epoch 14: loss_train=0.0572, acc_train=1.0000, loss_test=0.0775, acc_test=1.0000
# poison_percent 0 epoch 15: loss_train=0.0693, acc_train=1.0000, loss_test=0.0704, acc_test=1.0000
# poison_percent 0 epoch 16: loss_train=0.0159, acc_train=1.0000, loss_test=0.0642, acc_test=1.0000
# poison_percent 0 epoch 17: loss_train=0.0586, acc_train=1.0000, loss_test=0.0585, acc_test=1.0000
# poison_percent 0 epoch 18: loss_train=0.0394, acc_train=1.0000, loss_test=0.0535, acc_test=1.0000
# poison_percent 0 epoch 19: loss_train=0.0478, acc_train=1.0000, loss_test=0.0489, acc_test=1.0000
# poison_percent 0 epoch 20: loss_train=0.0438, acc_train=1.0000, loss_test=0.0448, acc_test=1.0000
# poison_percent 0 epoch 21: loss_train=0.0401, acc_train=1.0000, loss_test=0.0411, acc_test=1.0000
# poison_percent 0 epoch 22: loss_train=0.0276, acc_train=1.0000, loss_test=0.0377, acc_test=1.0000
# poison_percent 0 epoch 23: loss_train=0.0338, acc_train=1.0000, loss_test=0.0347, acc_test=1.0000
# poison_percent 0 epoch 24: loss_train=0.0234, acc_train=1.0000, loss_test=0.0318, acc_test=1.0000
# poison_percent 0 epoch 25: loss_train=0.0286, acc_train=1.0000, loss_test=0.0294, acc_test=1.0000
# poison_percent 0 epoch 26: loss_train=0.0327, acc_train=1.0000, loss_test=0.0271, acc_test=1.0000
# poison_percent 0 epoch 27: loss_train=0.0245, acc_train=1.0000, loss_test=0.0250, acc_test=1.0000
# poison_percent 0 epoch 28: loss_train=0.0222, acc_train=1.0000, loss_test=0.0230, acc_test=1.0000
# poison_percent 0 epoch 29: loss_train=0.0307, acc_train=1.0000, loss_test=0.0213, acc_test=1.0000
# poison_percent 0 epoch 30: loss_train=0.0188, acc_train=1.0000, loss_test=0.0197, acc_test=1.0000
# poison_percent 0 epoch 31: loss_train=0.0044, acc_train=1.0000, loss_test=0.0181, acc_test=1.0000
# poison_percent 0 epoch 32: loss_train=0.0080, acc_train=1.0000, loss_test=0.0167, acc_test=1.0000
# poison_percent 0 epoch 33: loss_train=0.0111, acc_train=1.0000, loss_test=0.0155, acc_test=1.0000
# poison_percent 0 epoch 34: loss_train=0.0171, acc_train=1.0000, loss_test=0.0143, acc_test=1.0000
# poison_percent 0 epoch 35: loss_train=0.0032, acc_train=1.0000, loss_test=0.0133, acc_test=1.0000
# poison_percent 0 epoch 36: loss_train=0.0146, acc_train=1.0000, loss_test=0.0124, acc_test=1.0000
# poison_percent 0 epoch 37: loss_train=0.0388, acc_train=1.0000, loss_test=0.0114, acc_test=1.0000
# poison_percent 0 epoch 38: loss_train=0.0050, acc_train=1.0000, loss_test=0.0105, acc_test=1.0000
# poison_percent 0 epoch 39: loss_train=0.0115, acc_train=1.0000, loss_test=0.0099, acc_test=1.0000
# poison_percent 0 epoch 40: loss_train=0.0128, acc_train=1.0000, loss_test=0.0092, acc_test=1.0000
# poison_percent 0 epoch 41: loss_train=0.0099, acc_train=1.0000, loss_test=0.0084, acc_test=1.0000
# poison_percent 0 epoch 42: loss_train=0.0073, acc_train=1.0000, loss_test=0.0079, acc_test=1.0000
# poison_percent 0 epoch 43: loss_train=0.0055, acc_train=1.0000, loss_test=0.0074, acc_test=1.0000
# poison_percent 0 epoch 44: loss_train=0.0033, acc_train=1.0000, loss_test=0.0068, acc_test=1.0000
# poison_percent 0 epoch 45: loss_train=0.0058, acc_train=1.0000, loss_test=0.0064, acc_test=1.0000
# poison_percent 0 epoch 46: loss_train=0.0067, acc_train=1.0000, loss_test=0.0059, acc_test=1.0000
# poison_percent 0 epoch 47: loss_train=0.0025, acc_train=1.0000, loss_test=0.0055, acc_test=1.0000
# poison_percent 0 epoch 48: loss_train=0.0046, acc_train=1.0000, loss_test=0.0051, acc_test=1.0000
# poison_percent 0 epoch 49: loss_train=0.0043, acc_train=1.0000, loss_test=0.0049, acc_test=1.0000
# poison_percent 0 epoch 50: loss_train=0.0050, acc_train=1.0000, loss_test=0.0045, acc_test=1.0000
# poison_percent 0 epoch 51: loss_train=0.0046, acc_train=1.0000, loss_test=0.0042, acc_test=1.0000
# poison_percent 0 epoch 52: loss_train=0.0026, acc_train=1.0000, loss_test=0.0038, acc_test=1.0000
# poison_percent 0 epoch 53: loss_train=0.0024, acc_train=1.0000, loss_test=0.0036, acc_test=1.0000
# poison_percent 0 epoch 54: loss_train=0.0051, acc_train=1.0000, loss_test=0.0033, acc_test=1.0000
# poison_percent 0 epoch 55: loss_train=0.0014, acc_train=1.0000, loss_test=0.0032, acc_test=1.0000
# poison_percent 0 epoch 56: loss_train=0.0013, acc_train=1.0000, loss_test=0.0030, acc_test=1.0000
# poison_percent 0 epoch 57: loss_train=0.0023, acc_train=1.0000, loss_test=0.0028, acc_test=1.0000
# poison_percent 0 epoch 58: loss_train=0.0032, acc_train=1.0000, loss_test=0.0027, acc_test=1.0000
# poison_percent 0 epoch 59: loss_train=0.0025, acc_train=1.0000, loss_test=0.0025, acc_test=1.0000
# poison_percent 0 epoch 60: loss_train=0.0019, acc_train=1.0000, loss_test=0.0023, acc_test=1.0000
# poison_percent 0 epoch 61: loss_train=0.0014, acc_train=1.0000, loss_test=0.0023, acc_test=1.0000
# poison_percent 0 epoch 62: loss_train=0.0008, acc_train=1.0000, loss_test=0.0020, acc_test=1.0000
# poison_percent 0 epoch 63: loss_train=0.0011, acc_train=1.0000, loss_test=0.0019, acc_test=1.0000
# poison_percent 0 epoch 64: loss_train=0.0003, acc_train=1.0000, loss_test=0.0018, acc_test=1.0000
# poison_percent 0 epoch 65: loss_train=0.0006, acc_train=1.0000, loss_test=0.0017, acc_test=1.0000
# poison_percent 0 epoch 66: loss_train=0.0015, acc_train=1.0000, loss_test=0.0015, acc_test=1.0000
# poison_percent 0 epoch 67: loss_train=0.0011, acc_train=1.0000, loss_test=0.0016, acc_test=1.0000
# poison_percent 0 epoch 68: loss_train=0.0010, acc_train=1.0000, loss_test=0.0014, acc_test=1.0000
# poison_percent 0 epoch 69: loss_train=0.0005, acc_train=1.0000, loss_test=0.0014, acc_test=1.0000
# poison_percent 0 epoch 70: loss_train=0.0011, acc_train=1.0000, loss_test=0.0012, acc_test=1.0000
# poison_percent 0 epoch 71: loss_train=0.0006, acc_train=1.0000, loss_test=0.0012, acc_test=1.0000
# poison_percent 0 epoch 72: loss_train=0.0006, acc_train=1.0000, loss_test=0.0012, acc_test=1.0000
# poison_percent 0 epoch 73: loss_train=0.0009, acc_train=1.0000, loss_test=0.0010, acc_test=1.0000
# poison_percent 0 epoch 74: loss_train=0.0008, acc_train=1.0000, loss_test=0.0011, acc_test=1.0000
# poison_percent 0 epoch 75: loss_train=0.0006, acc_train=1.0000, loss_test=0.0010, acc_test=1.0000
# poison_percent 0 epoch 76: loss_train=0.0006, acc_train=1.0000, loss_test=0.0009, acc_test=1.0000
# poison_percent 0 epoch 77: loss_train=0.0006, acc_train=1.0000, loss_test=0.0010, acc_test=1.0000
# poison_percent 0 epoch 78: loss_train=0.0004, acc_train=1.0000, loss_test=0.0009, acc_test=1.0000
# poison_percent 0 epoch 79: loss_train=0.0004, acc_train=1.0000, loss_test=0.0008, acc_test=1.0000
# poison_percent 0 epoch 80: loss_train=0.0002, acc_train=1.0000, loss_test=0.0007, acc_test=1.0000
# poison_percent 0 epoch 81: loss_train=0.0006, acc_train=1.0000, loss_test=0.0008, acc_test=1.0000
# poison_percent 0 epoch 82: loss_train=0.0005, acc_train=1.0000, loss_test=0.0007, acc_test=1.0000
# poison_percent 0 epoch 83: loss_train=0.0002, acc_train=1.0000, loss_test=0.0008, acc_test=1.0000
# poison_percent 0 epoch 84: loss_train=0.0004, acc_train=1.0000, loss_test=0.0006, acc_test=1.0000
# poison_percent 0 epoch 85: loss_train=0.0003, acc_train=1.0000, loss_test=0.0007, acc_test=1.0000
# poison_percent 0 epoch 86: loss_train=0.0004, acc_train=1.0000, loss_test=0.0006, acc_test=1.0000
# poison_percent 0 epoch 87: loss_train=0.0002, acc_train=1.0000, loss_test=0.0007, acc_test=1.0000
# poison_percent 0 epoch 88: loss_train=0.0002, acc_train=1.0000, loss_test=0.0006, acc_test=1.0000
# poison_percent 0 epoch 89: loss_train=0.0002, acc_train=1.0000, loss_test=0.0006, acc_test=1.0000
# poison_percent 0 epoch 90: loss_train=0.0002, acc_train=1.0000, loss_test=0.0006, acc_test=1.0000
# poison_percent 0 epoch 91: loss_train=0.0002, acc_train=1.0000, loss_test=0.0006, acc_test=1.0000
# poison_percent 0 epoch 92: loss_train=0.0002, acc_train=1.0000, loss_test=0.0005, acc_test=1.0000
# poison_percent 0 epoch 93: loss_train=0.0002, acc_train=1.0000, loss_test=0.0005, acc_test=1.0000
# poison_percent 0 epoch 94: loss_train=0.0002, acc_train=1.0000, loss_test=0.0006, acc_test=1.0000
# poison_percent 0 epoch 95: loss_train=0.0002, acc_train=1.0000, loss_test=0.0005, acc_test=1.0000
# poison_percent 0 epoch 96: loss_train=0.0001, acc_train=1.0000, loss_test=0.0005, acc_test=1.0000
# poison_percent 0 epoch 97: loss_train=0.0001, acc_train=1.0000, loss_test=0.0006, acc_test=0.9995
# poison_percent 0 epoch 98: loss_train=0.0001, acc_train=1.0000, loss_test=0.0005, acc_test=1.0000
# poison_percent 0 epoch 99: loss_train=0.0001, acc_train=1.0000, loss_test=0.0005, acc_test=1.0000
# Training log saved to ./results\CL_ModelN1L2_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 epoch 0: loss_train=1.0464, acc_train=0.9062, loss_test=0.0129, acc_test=0.9969
# poison_percent 10 epoch 1: loss_train=1.1932, acc_train=0.8438, loss_test=0.1265, acc_test=0.9571
# poison_percent 10 epoch 2: loss_train=0.5275, acc_train=0.9375, loss_test=0.1083, acc_test=0.9633
# poison_percent 10 epoch 3: loss_train=0.2760, acc_train=0.9688, loss_test=0.1231, acc_test=0.9495
# poison_percent 10 epoch 4: loss_train=0.3126, acc_train=0.9375, loss_test=0.1241, acc_test=0.9480
# poison_percent 10 epoch 5: loss_train=1.4538, acc_train=0.7500, loss_test=0.1059, acc_test=0.9571
# poison_percent 10 epoch 6: loss_train=0.3807, acc_train=0.9375, loss_test=0.1252, acc_test=0.9474
# poison_percent 10 epoch 7: loss_train=1.3266, acc_train=0.7812, loss_test=0.0943, acc_test=0.9597
# poison_percent 10 epoch 8: loss_train=0.8068, acc_train=0.7188, loss_test=0.1109, acc_test=0.9515
# poison_percent 10 epoch 9: loss_train=0.3563, acc_train=0.9062, loss_test=0.1208, acc_test=0.9495
# poison_percent 10 epoch 10: loss_train=0.9337, acc_train=0.8125, loss_test=0.1052, acc_test=0.9612
# poison_percent 10 epoch 11: loss_train=0.3322, acc_train=0.8750, loss_test=0.1575, acc_test=0.9520
# poison_percent 10 epoch 12: loss_train=0.4280, acc_train=0.8750, loss_test=0.1491, acc_test=0.9556
# poison_percent 10 epoch 13: loss_train=0.4134, acc_train=0.8125, loss_test=0.1587, acc_test=0.9551
# poison_percent 10 epoch 14: loss_train=0.5020, acc_train=0.8438, loss_test=0.1562, acc_test=0.9551
# poison_percent 10 epoch 15: loss_train=0.4294, acc_train=0.8125, loss_test=0.1448, acc_test=0.9638
# poison_percent 10 epoch 16: loss_train=0.1266, acc_train=1.0000, loss_test=0.1573, acc_test=0.9612
# poison_percent 10 epoch 17: loss_train=0.3524, acc_train=0.9062, loss_test=0.1656, acc_test=0.9510
# poison_percent 10 epoch 18: loss_train=0.3980, acc_train=0.8438, loss_test=0.1545, acc_test=0.9638
# poison_percent 10 epoch 19: loss_train=0.2445, acc_train=0.9375, loss_test=0.1362, acc_test=0.9679
# poison_percent 10 epoch 20: loss_train=0.4451, acc_train=0.9062, loss_test=0.1725, acc_test=0.9480
# poison_percent 10 epoch 21: loss_train=0.2898, acc_train=0.9375, loss_test=0.1362, acc_test=0.9714
# poison_percent 10 epoch 22: loss_train=0.3728, acc_train=0.9062, loss_test=0.1423, acc_test=0.9714
# poison_percent 10 epoch 23: loss_train=0.5610, acc_train=0.8125, loss_test=0.1550, acc_test=0.9633
# poison_percent 10 epoch 24: loss_train=0.3119, acc_train=0.8750, loss_test=0.1477, acc_test=0.9694
# poison_percent 10 epoch 25: loss_train=0.2299, acc_train=0.9688, loss_test=0.1559, acc_test=0.9684
# poison_percent 10 epoch 26: loss_train=0.3014, acc_train=0.8750, loss_test=0.1486, acc_test=0.9719
# poison_percent 10 epoch 27: loss_train=0.6596, acc_train=0.8125, loss_test=0.1242, acc_test=0.9786
# poison_percent 10 epoch 28: loss_train=0.2765, acc_train=0.9062, loss_test=0.1340, acc_test=0.9791
# poison_percent 10 epoch 29: loss_train=0.3042, acc_train=0.9375, loss_test=0.1436, acc_test=0.9770
# poison_percent 10 epoch 30: loss_train=0.2645, acc_train=0.9375, loss_test=0.1497, acc_test=0.9765
# poison_percent 10 epoch 31: loss_train=0.4566, acc_train=0.8438, loss_test=0.1411, acc_test=0.9765
# poison_percent 10 epoch 32: loss_train=0.3911, acc_train=0.8750, loss_test=0.1520, acc_test=0.9684
# poison_percent 10 epoch 33: loss_train=0.3119, acc_train=0.8750, loss_test=0.1330, acc_test=0.9801
# poison_percent 10 epoch 34: loss_train=0.4718, acc_train=0.8438, loss_test=0.1158, acc_test=0.9847
# poison_percent 10 epoch 35: loss_train=0.2327, acc_train=0.9375, loss_test=0.1306, acc_test=0.9837
# poison_percent 10 epoch 36: loss_train=0.0843, acc_train=1.0000, loss_test=0.1257, acc_test=0.9811
# poison_percent 10 epoch 37: loss_train=0.5818, acc_train=0.8438, loss_test=0.1444, acc_test=0.9781
# poison_percent 10 epoch 38: loss_train=0.3892, acc_train=0.8750, loss_test=0.1518, acc_test=0.9770
# poison_percent 10 epoch 39: loss_train=0.2319, acc_train=0.9375, loss_test=0.1601, acc_test=0.9709
# poison_percent 10 epoch 40: loss_train=0.4416, acc_train=0.8750, loss_test=0.1329, acc_test=0.9806
# poison_percent 10 epoch 41: loss_train=0.1364, acc_train=0.9688, loss_test=0.1473, acc_test=0.9714
# poison_percent 10 epoch 42: loss_train=0.3414, acc_train=0.8750, loss_test=0.1776, acc_test=0.9709
# poison_percent 10 epoch 43: loss_train=0.3881, acc_train=0.8438, loss_test=0.1404, acc_test=0.9827
# poison_percent 10 epoch 44: loss_train=0.5822, acc_train=0.7812, loss_test=0.1505, acc_test=0.9816
# poison_percent 10 epoch 45: loss_train=0.2631, acc_train=0.8750, loss_test=0.1413, acc_test=0.9816
# poison_percent 10 epoch 46: loss_train=0.6938, acc_train=0.7812, loss_test=0.1322, acc_test=0.9857
# poison_percent 10 epoch 47: loss_train=0.3142, acc_train=0.9062, loss_test=0.1452, acc_test=0.9786
# poison_percent 10 epoch 48: loss_train=0.4795, acc_train=0.8750, loss_test=0.1430, acc_test=0.9852
# poison_percent 10 epoch 49: loss_train=0.3724, acc_train=0.8750, loss_test=0.1287, acc_test=0.9913
# poison_percent 10 epoch 50: loss_train=0.4183, acc_train=0.8750, loss_test=0.1445, acc_test=0.9837
# poison_percent 10 epoch 51: loss_train=0.5951, acc_train=0.7812, loss_test=0.1378, acc_test=0.9852
# poison_percent 10 epoch 52: loss_train=0.4599, acc_train=0.8750, loss_test=0.1294, acc_test=0.9867
# poison_percent 10 epoch 53: loss_train=0.4795, acc_train=0.8125, loss_test=0.1307, acc_test=0.9913
# poison_percent 10 epoch 54: loss_train=0.3545, acc_train=0.8750, loss_test=0.1335, acc_test=0.9883
# poison_percent 10 epoch 55: loss_train=0.1695, acc_train=0.9688, loss_test=0.1185, acc_test=0.9929
# poison_percent 10 epoch 56: loss_train=0.2598, acc_train=0.9375, loss_test=0.1344, acc_test=0.9878
# poison_percent 10 epoch 57: loss_train=0.1984, acc_train=0.9688, loss_test=0.1298, acc_test=0.9862
# poison_percent 10 epoch 58: loss_train=0.4003, acc_train=0.8750, loss_test=0.1353, acc_test=0.9898
# poison_percent 10 epoch 59: loss_train=0.4655, acc_train=0.8125, loss_test=0.1368, acc_test=0.9867
# poison_percent 10 epoch 60: loss_train=0.3904, acc_train=0.8750, loss_test=0.1204, acc_test=0.9923
# poison_percent 10 epoch 61: loss_train=0.2924, acc_train=0.9062, loss_test=0.1193, acc_test=0.9908
# poison_percent 10 epoch 62: loss_train=0.3086, acc_train=0.9062, loss_test=0.1542, acc_test=0.9878
# poison_percent 10 epoch 63: loss_train=0.5280, acc_train=0.7500, loss_test=0.1463, acc_test=0.9852
# poison_percent 10 epoch 64: loss_train=0.4004, acc_train=0.8750, loss_test=0.1329, acc_test=0.9883
# poison_percent 10 epoch 65: loss_train=0.3427, acc_train=0.8750, loss_test=0.1273, acc_test=0.9898
# poison_percent 10 epoch 66: loss_train=0.4356, acc_train=0.8438, loss_test=0.1256, acc_test=0.9908
# poison_percent 10 epoch 67: loss_train=0.4318, acc_train=0.8438, loss_test=0.1406, acc_test=0.9908
# poison_percent 10 epoch 68: loss_train=0.3362, acc_train=0.8438, loss_test=0.1186, acc_test=0.9934
# poison_percent 10 epoch 69: loss_train=0.2360, acc_train=0.9688, loss_test=0.1554, acc_test=0.9827
# poison_percent 10 epoch 70: loss_train=0.3020, acc_train=0.9062, loss_test=0.1388, acc_test=0.9913
# poison_percent 10 epoch 71: loss_train=0.3567, acc_train=0.9062, loss_test=0.1584, acc_test=0.9898
# poison_percent 10 epoch 72: loss_train=0.2638, acc_train=0.9375, loss_test=0.1361, acc_test=0.9888
# poison_percent 10 epoch 73: loss_train=0.2611, acc_train=0.9062, loss_test=0.1283, acc_test=0.9908
# poison_percent 10 epoch 74: loss_train=0.1597, acc_train=0.9688, loss_test=0.1280, acc_test=0.9888
# poison_percent 10 epoch 75: loss_train=0.5277, acc_train=0.8125, loss_test=0.1482, acc_test=0.9908
# poison_percent 10 epoch 76: loss_train=0.2687, acc_train=0.9375, loss_test=0.1173, acc_test=0.9923
# poison_percent 10 epoch 77: loss_train=0.7024, acc_train=0.7500, loss_test=0.1268, acc_test=0.9918
# poison_percent 10 epoch 78: loss_train=0.3776, acc_train=0.8750, loss_test=0.1330, acc_test=0.9888
# poison_percent 10 epoch 79: loss_train=0.3243, acc_train=0.8750, loss_test=0.1254, acc_test=0.9929
# poison_percent 10 epoch 80: loss_train=0.2404, acc_train=0.9375, loss_test=0.1485, acc_test=0.9867
# poison_percent 10 epoch 81: loss_train=0.2582, acc_train=0.9375, loss_test=0.1353, acc_test=0.9908
# poison_percent 10 epoch 82: loss_train=0.2958, acc_train=0.9062, loss_test=0.1170, acc_test=0.9923
# poison_percent 10 epoch 83: loss_train=0.3317, acc_train=0.8750, loss_test=0.1387, acc_test=0.9908
# poison_percent 10 epoch 84: loss_train=0.2645, acc_train=0.9375, loss_test=0.1240, acc_test=0.9918
# poison_percent 10 epoch 85: loss_train=0.5662, acc_train=0.8125, loss_test=0.1509, acc_test=0.9857
# poison_percent 10 epoch 86: loss_train=0.1925, acc_train=0.9688, loss_test=0.1305, acc_test=0.9923
# poison_percent 10 epoch 87: loss_train=0.4294, acc_train=0.8438, loss_test=0.1121, acc_test=0.9939
# poison_percent 10 epoch 88: loss_train=0.4545, acc_train=0.8125, loss_test=0.1370, acc_test=0.9888
# poison_percent 10 epoch 89: loss_train=0.2451, acc_train=0.9062, loss_test=0.1189, acc_test=0.9913
# poison_percent 10 epoch 90: loss_train=0.4613, acc_train=0.8125, loss_test=0.1272, acc_test=0.9934
# poison_percent 10 epoch 91: loss_train=0.5189, acc_train=0.8125, loss_test=0.1276, acc_test=0.9918
# poison_percent 10 epoch 92: loss_train=0.5666, acc_train=0.7812, loss_test=0.1338, acc_test=0.9908
# poison_percent 10 epoch 93: loss_train=0.3050, acc_train=0.9062, loss_test=0.1225, acc_test=0.9934
# poison_percent 10 epoch 94: loss_train=0.1870, acc_train=0.9375, loss_test=0.1261, acc_test=0.9923
# poison_percent 10 epoch 95: loss_train=0.4875, acc_train=0.8438, loss_test=0.1286, acc_test=0.9913
# poison_percent 10 epoch 96: loss_train=0.4194, acc_train=0.8438, loss_test=0.1334, acc_test=0.9913
# poison_percent 10 epoch 97: loss_train=0.2040, acc_train=0.9375, loss_test=0.1518, acc_test=0.9852
# poison_percent 10 epoch 98: loss_train=0.4407, acc_train=0.8438, loss_test=0.1309, acc_test=0.9913
# poison_percent 10 epoch 99: loss_train=0.2865, acc_train=0.9062, loss_test=0.1326, acc_test=0.9903
# Training log saved to ./results\CL_ModelN1L2_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 epoch 0: loss_train=0.4790, acc_train=0.8333, loss_test=0.2258, acc_test=0.9806
# poison_percent 20 epoch 1: loss_train=0.5113, acc_train=0.7778, loss_test=0.2569, acc_test=0.9776
# poison_percent 20 epoch 2: loss_train=0.4518, acc_train=0.8333, loss_test=0.2529, acc_test=0.9653
# poison_percent 20 epoch 3: loss_train=0.6627, acc_train=0.6667, loss_test=0.2188, acc_test=0.9852
# poison_percent 20 epoch 4: loss_train=0.4370, acc_train=0.8889, loss_test=0.2348, acc_test=0.9796
# poison_percent 20 epoch 5: loss_train=0.2871, acc_train=0.8889, loss_test=0.2468, acc_test=0.9816
# poison_percent 20 epoch 6: loss_train=0.3123, acc_train=0.8889, loss_test=0.2951, acc_test=0.9531
# poison_percent 20 epoch 7: loss_train=0.6930, acc_train=0.6667, loss_test=0.2181, acc_test=0.9862
# poison_percent 20 epoch 8: loss_train=0.4885, acc_train=0.8333, loss_test=0.2321, acc_test=0.9852
# poison_percent 20 epoch 9: loss_train=0.4663, acc_train=0.7778, loss_test=0.2412, acc_test=0.9811
# poison_percent 20 epoch 10: loss_train=0.5098, acc_train=0.7222, loss_test=0.2516, acc_test=0.9714
# poison_percent 20 epoch 11: loss_train=0.5985, acc_train=0.7222, loss_test=0.2502, acc_test=0.9770
# poison_percent 20 epoch 12: loss_train=0.4512, acc_train=0.7778, loss_test=0.2480, acc_test=0.9806
# poison_percent 20 epoch 13: loss_train=0.5046, acc_train=0.7778, loss_test=0.2431, acc_test=0.9837
# poison_percent 20 epoch 14: loss_train=0.3760, acc_train=0.8889, loss_test=0.2454, acc_test=0.9786
# poison_percent 20 epoch 15: loss_train=0.8277, acc_train=0.6667, loss_test=0.2500, acc_test=0.9837
# poison_percent 20 epoch 16: loss_train=0.6806, acc_train=0.6111, loss_test=0.2672, acc_test=0.9786
# poison_percent 20 epoch 17: loss_train=0.7587, acc_train=0.6111, loss_test=0.2174, acc_test=0.9888
# poison_percent 20 epoch 18: loss_train=0.5555, acc_train=0.7222, loss_test=0.2385, acc_test=0.9806
# poison_percent 20 epoch 19: loss_train=0.3804, acc_train=0.9444, loss_test=0.2689, acc_test=0.9765
# poison_percent 20 epoch 20: loss_train=0.4635, acc_train=0.8333, loss_test=0.2695, acc_test=0.9709
# poison_percent 20 epoch 21: loss_train=0.4442, acc_train=0.8889, loss_test=0.2455, acc_test=0.9872
# poison_percent 20 epoch 22: loss_train=0.7315, acc_train=0.6667, loss_test=0.2292, acc_test=0.9832
# poison_percent 20 epoch 23: loss_train=0.6093, acc_train=0.7222, loss_test=0.2758, acc_test=0.9668
# poison_percent 20 epoch 24: loss_train=0.5213, acc_train=0.7778, loss_test=0.2121, acc_test=0.9898
# poison_percent 20 epoch 25: loss_train=0.4827, acc_train=0.7778, loss_test=0.2613, acc_test=0.9745
# poison_percent 20 epoch 26: loss_train=0.2518, acc_train=0.9444, loss_test=0.2323, acc_test=0.9857
# poison_percent 20 epoch 27: loss_train=0.5552, acc_train=0.7222, loss_test=0.2186, acc_test=0.9903
# poison_percent 20 epoch 28: loss_train=0.3281, acc_train=0.8889, loss_test=0.2560, acc_test=0.9745
# poison_percent 20 epoch 29: loss_train=0.6252, acc_train=0.7778, loss_test=0.2129, acc_test=0.9872
# poison_percent 20 epoch 30: loss_train=0.5422, acc_train=0.8333, loss_test=0.2303, acc_test=0.9857
# poison_percent 20 epoch 31: loss_train=0.5298, acc_train=0.7222, loss_test=0.2964, acc_test=0.9510
# poison_percent 20 epoch 32: loss_train=0.4035, acc_train=0.8333, loss_test=0.2303, acc_test=0.9862
# poison_percent 20 epoch 33: loss_train=0.4386, acc_train=0.7778, loss_test=0.2719, acc_test=0.9679
# poison_percent 20 epoch 34: loss_train=0.7082, acc_train=0.6667, loss_test=0.2453, acc_test=0.9816
# poison_percent 20 epoch 35: loss_train=0.3076, acc_train=0.9444, loss_test=0.2377, acc_test=0.9867
# poison_percent 20 epoch 36: loss_train=0.4042, acc_train=0.8889, loss_test=0.2201, acc_test=0.9898
# poison_percent 20 epoch 37: loss_train=0.5456, acc_train=0.7222, loss_test=0.2347, acc_test=0.9796
# poison_percent 20 epoch 38: loss_train=0.4013, acc_train=0.8333, loss_test=0.2543, acc_test=0.9852
# poison_percent 20 epoch 39: loss_train=0.4772, acc_train=0.8333, loss_test=0.2704, acc_test=0.9719
# poison_percent 20 epoch 40: loss_train=0.3640, acc_train=0.8889, loss_test=0.2603, acc_test=0.9689
# poison_percent 20 epoch 41: loss_train=0.5209, acc_train=0.7778, loss_test=0.2529, acc_test=0.9867
# poison_percent 20 epoch 42: loss_train=0.3343, acc_train=0.8889, loss_test=0.2433, acc_test=0.9770
# poison_percent 20 epoch 43: loss_train=0.3882, acc_train=0.8333, loss_test=0.2322, acc_test=0.9811
# poison_percent 20 epoch 44: loss_train=0.5827, acc_train=0.7222, loss_test=0.2578, acc_test=0.9786
# poison_percent 20 epoch 45: loss_train=0.5015, acc_train=0.8333, loss_test=0.2791, acc_test=0.9520
# poison_percent 20 epoch 46: loss_train=0.2928, acc_train=0.9444, loss_test=0.2388, acc_test=0.9862
# poison_percent 20 epoch 47: loss_train=0.2773, acc_train=0.8889, loss_test=0.2176, acc_test=0.9867
# poison_percent 20 epoch 48: loss_train=0.4596, acc_train=0.8333, loss_test=0.2093, acc_test=0.9888
# poison_percent 20 epoch 49: loss_train=0.3079, acc_train=0.8889, loss_test=0.2527, acc_test=0.9852
# poison_percent 20 epoch 50: loss_train=0.4703, acc_train=0.8333, loss_test=0.2552, acc_test=0.9592
# poison_percent 20 epoch 51: loss_train=0.2871, acc_train=0.9444, loss_test=0.2595, acc_test=0.9714
# poison_percent 20 epoch 52: loss_train=0.3803, acc_train=0.8889, loss_test=0.2131, acc_test=0.9893
# poison_percent 20 epoch 53: loss_train=0.3834, acc_train=0.8333, loss_test=0.2381, acc_test=0.9832
# poison_percent 20 epoch 54: loss_train=0.5382, acc_train=0.7222, loss_test=0.2532, acc_test=0.9765
# poison_percent 20 epoch 55: loss_train=0.2440, acc_train=0.9444, loss_test=0.2648, acc_test=0.9811
# poison_percent 20 epoch 56: loss_train=0.3672, acc_train=0.8889, loss_test=0.2652, acc_test=0.9811
# poison_percent 20 epoch 57: loss_train=0.4797, acc_train=0.8333, loss_test=0.2107, acc_test=0.9867
# poison_percent 20 epoch 58: loss_train=0.5267, acc_train=0.7778, loss_test=0.2508, acc_test=0.9796
# poison_percent 20 epoch 59: loss_train=0.6412, acc_train=0.6667, loss_test=0.2285, acc_test=0.9862
# poison_percent 20 epoch 60: loss_train=0.3480, acc_train=0.8889, loss_test=0.2696, acc_test=0.9673
# poison_percent 20 epoch 61: loss_train=0.5800, acc_train=0.7222, loss_test=0.2375, acc_test=0.9837
# poison_percent 20 epoch 62: loss_train=0.6039, acc_train=0.7222, loss_test=0.2412, acc_test=0.9837
# poison_percent 20 epoch 63: loss_train=0.3389, acc_train=0.8889, loss_test=0.2210, acc_test=0.9857
# poison_percent 20 epoch 64: loss_train=0.3980, acc_train=0.8333, loss_test=0.2631, acc_test=0.9842
# poison_percent 20 epoch 65: loss_train=0.4970, acc_train=0.7222, loss_test=0.2418, acc_test=0.9816
# poison_percent 20 epoch 66: loss_train=0.4072, acc_train=0.8889, loss_test=0.2802, acc_test=0.9679
# poison_percent 20 epoch 67: loss_train=0.6179, acc_train=0.7222, loss_test=0.2636, acc_test=0.9770
# poison_percent 20 epoch 68: loss_train=0.3596, acc_train=0.8889, loss_test=0.2353, acc_test=0.9811
# poison_percent 20 epoch 69: loss_train=0.3987, acc_train=0.8889, loss_test=0.2634, acc_test=0.9679
# poison_percent 20 epoch 70: loss_train=0.3879, acc_train=0.8889, loss_test=0.2165, acc_test=0.9847
# poison_percent 20 epoch 71: loss_train=0.3852, acc_train=0.8333, loss_test=0.2344, acc_test=0.9852
# poison_percent 20 epoch 72: loss_train=0.4890, acc_train=0.8333, loss_test=0.2516, acc_test=0.9821
# poison_percent 20 epoch 73: loss_train=0.5607, acc_train=0.7222, loss_test=0.2315, acc_test=0.9770
# poison_percent 20 epoch 74: loss_train=0.4898, acc_train=0.7222, loss_test=0.2560, acc_test=0.9852
# poison_percent 20 epoch 75: loss_train=0.4662, acc_train=0.7222, loss_test=0.2473, acc_test=0.9811
# poison_percent 20 epoch 76: loss_train=0.3840, acc_train=0.8889, loss_test=0.2377, acc_test=0.9806
# poison_percent 20 epoch 77: loss_train=0.4411, acc_train=0.8333, loss_test=0.2763, acc_test=0.9612
# poison_percent 20 epoch 78: loss_train=0.6975, acc_train=0.6667, loss_test=0.2538, acc_test=0.9842
# poison_percent 20 epoch 79: loss_train=0.3616, acc_train=0.8889, loss_test=0.2194, acc_test=0.9878
# poison_percent 20 epoch 80: loss_train=0.2732, acc_train=0.9444, loss_test=0.2214, acc_test=0.9770
# poison_percent 20 epoch 81: loss_train=0.6268, acc_train=0.6111, loss_test=0.2724, acc_test=0.9592
# poison_percent 20 epoch 82: loss_train=0.7129, acc_train=0.7222, loss_test=0.2030, acc_test=0.9893
# poison_percent 20 epoch 83: loss_train=0.2709, acc_train=0.9444, loss_test=0.2119, acc_test=0.9857
# poison_percent 20 epoch 84: loss_train=0.6245, acc_train=0.7222, loss_test=0.2245, acc_test=0.9842
# poison_percent 20 epoch 85: loss_train=0.5334, acc_train=0.7778, loss_test=0.2639, acc_test=0.9750
# poison_percent 20 epoch 86: loss_train=0.2951, acc_train=0.8889, loss_test=0.2493, acc_test=0.9816
# poison_percent 20 epoch 87: loss_train=0.5242, acc_train=0.7778, loss_test=0.2783, acc_test=0.9638
# poison_percent 20 epoch 88: loss_train=0.4629, acc_train=0.7778, loss_test=0.2109, acc_test=0.9827
# poison_percent 20 epoch 89: loss_train=0.4041, acc_train=0.8889, loss_test=0.2427, acc_test=0.9811
# poison_percent 20 epoch 90: loss_train=0.2946, acc_train=0.9444, loss_test=0.2416, acc_test=0.9852
# poison_percent 20 epoch 91: loss_train=0.5222, acc_train=0.7778, loss_test=0.2762, acc_test=0.9699
# poison_percent 20 epoch 92: loss_train=0.4546, acc_train=0.8889, loss_test=0.2649, acc_test=0.9663
# poison_percent 20 epoch 93: loss_train=0.4784, acc_train=0.7778, loss_test=0.2342, acc_test=0.9847
# poison_percent 20 epoch 94: loss_train=0.4406, acc_train=0.8333, loss_test=0.2308, acc_test=0.9898
# poison_percent 20 epoch 95: loss_train=0.6812, acc_train=0.7222, loss_test=0.3040, acc_test=0.9515
# poison_percent 20 epoch 96: loss_train=0.4824, acc_train=0.7778, loss_test=0.2105, acc_test=0.9862
# poison_percent 20 epoch 97: loss_train=0.5490, acc_train=0.7222, loss_test=0.2224, acc_test=0.9878
# poison_percent 20 epoch 98: loss_train=0.6901, acc_train=0.6111, loss_test=0.2469, acc_test=0.9796
# poison_percent 20 epoch 99: loss_train=0.5289, acc_train=0.7778, loss_test=0.2471, acc_test=0.9765
# Training log saved to ./results\CL_ModelN1L2_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 epoch 0: loss_train=0.3487, acc_train=0.8333, loss_test=0.3601, acc_test=0.9495
# poison_percent 30 epoch 1: loss_train=0.4349, acc_train=0.8333, loss_test=0.3636, acc_test=0.9531
# poison_percent 30 epoch 2: loss_train=0.3529, acc_train=1.0000, loss_test=0.3409, acc_test=0.9653
# poison_percent 30 epoch 3: loss_train=0.9783, acc_train=0.3333, loss_test=0.3726, acc_test=0.9362
# poison_percent 30 epoch 4: loss_train=0.2788, acc_train=1.0000, loss_test=0.3846, acc_test=0.9337
# poison_percent 30 epoch 5: loss_train=0.4590, acc_train=0.8333, loss_test=0.3683, acc_test=0.9393
# poison_percent 30 epoch 6: loss_train=0.3900, acc_train=0.8333, loss_test=0.3727, acc_test=0.9551
# poison_percent 30 epoch 7: loss_train=0.7231, acc_train=0.5000, loss_test=0.4398, acc_test=0.8969
# poison_percent 30 epoch 8: loss_train=0.5707, acc_train=0.6667, loss_test=0.3818, acc_test=0.9510
# poison_percent 30 epoch 9: loss_train=0.5311, acc_train=0.8333, loss_test=0.3033, acc_test=0.9765
# poison_percent 30 epoch 10: loss_train=0.5368, acc_train=0.6667, loss_test=0.3628, acc_test=0.9500
# poison_percent 30 epoch 11: loss_train=0.3592, acc_train=1.0000, loss_test=0.3942, acc_test=0.9327
# poison_percent 30 epoch 12: loss_train=0.5185, acc_train=0.6667, loss_test=0.3573, acc_test=0.9526
# poison_percent 30 epoch 13: loss_train=0.5118, acc_train=0.6667, loss_test=0.3405, acc_test=0.9592
# poison_percent 30 epoch 14: loss_train=0.4522, acc_train=0.8333, loss_test=0.3486, acc_test=0.9673
# poison_percent 30 epoch 15: loss_train=0.3673, acc_train=1.0000, loss_test=0.3744, acc_test=0.9500
# poison_percent 30 epoch 16: loss_train=0.4440, acc_train=0.6667, loss_test=0.3999, acc_test=0.9281
# poison_percent 30 epoch 17: loss_train=0.7685, acc_train=0.5000, loss_test=0.3557, acc_test=0.9628
# poison_percent 30 epoch 18: loss_train=0.6407, acc_train=0.6667, loss_test=0.3945, acc_test=0.9260
# poison_percent 30 epoch 19: loss_train=0.7304, acc_train=0.5000, loss_test=0.4202, acc_test=0.8929
# poison_percent 30 epoch 20: loss_train=0.5673, acc_train=0.6667, loss_test=0.3207, acc_test=0.9699
# poison_percent 30 epoch 21: loss_train=0.4645, acc_train=0.8333, loss_test=0.3668, acc_test=0.9556
# poison_percent 30 epoch 22: loss_train=0.7030, acc_train=0.6667, loss_test=0.3800, acc_test=0.9602
# poison_percent 30 epoch 23: loss_train=0.7395, acc_train=0.5000, loss_test=0.4087, acc_test=0.9398
# poison_percent 30 epoch 24: loss_train=0.7762, acc_train=0.6667, loss_test=0.3832, acc_test=0.9505
# poison_percent 30 epoch 25: loss_train=0.7048, acc_train=0.6667, loss_test=0.3998, acc_test=0.9434
# poison_percent 30 epoch 26: loss_train=0.6550, acc_train=0.6667, loss_test=0.3603, acc_test=0.9556
# poison_percent 30 epoch 27: loss_train=0.9957, acc_train=0.6667, loss_test=0.3671, acc_test=0.9617
# poison_percent 30 epoch 28: loss_train=0.5558, acc_train=0.8333, loss_test=0.3763, acc_test=0.9429
# poison_percent 30 epoch 29: loss_train=0.8057, acc_train=0.5000, loss_test=0.4070, acc_test=0.9179
# poison_percent 30 epoch 30: loss_train=0.3604, acc_train=1.0000, loss_test=0.4103, acc_test=0.9316
# poison_percent 30 epoch 31: loss_train=0.7404, acc_train=0.5000, loss_test=0.3146, acc_test=0.9765
# poison_percent 30 epoch 32: loss_train=0.9187, acc_train=0.5000, loss_test=0.3857, acc_test=0.9454
# poison_percent 30 epoch 33: loss_train=0.4656, acc_train=0.8333, loss_test=0.3514, acc_test=0.9673
# poison_percent 30 epoch 34: loss_train=0.4047, acc_train=0.8333, loss_test=0.3736, acc_test=0.9551
# poison_percent 30 epoch 35: loss_train=0.9893, acc_train=0.5000, loss_test=0.3888, acc_test=0.9556
# poison_percent 30 epoch 36: loss_train=0.7141, acc_train=0.5000, loss_test=0.3634, acc_test=0.9638
# poison_percent 30 epoch 37: loss_train=0.4825, acc_train=0.6667, loss_test=0.3803, acc_test=0.9148
# poison_percent 30 epoch 38: loss_train=0.9516, acc_train=0.3333, loss_test=0.3873, acc_test=0.9342
# poison_percent 30 epoch 39: loss_train=0.4862, acc_train=0.6667, loss_test=0.3860, acc_test=0.9480
# poison_percent 30 epoch 40: loss_train=0.4596, acc_train=0.8333, loss_test=0.4125, acc_test=0.9189
# poison_percent 30 epoch 41: loss_train=1.3681, acc_train=0.0000, loss_test=0.3636, acc_test=0.9556
# poison_percent 30 epoch 42: loss_train=0.6624, acc_train=0.5000, loss_test=0.4055, acc_test=0.9179
# poison_percent 30 epoch 43: loss_train=0.6479, acc_train=0.6667, loss_test=0.3736, acc_test=0.9546
# poison_percent 30 epoch 44: loss_train=0.4058, acc_train=0.8333, loss_test=0.3659, acc_test=0.9617
# poison_percent 30 epoch 45: loss_train=0.5464, acc_train=0.6667, loss_test=0.3566, acc_test=0.9622
# poison_percent 30 epoch 46: loss_train=0.6656, acc_train=0.6667, loss_test=0.3841, acc_test=0.9531
# poison_percent 30 epoch 47: loss_train=0.4149, acc_train=0.8333, loss_test=0.3837, acc_test=0.9464
# poison_percent 30 epoch 48: loss_train=0.4754, acc_train=0.8333, loss_test=0.3170, acc_test=0.9719
# poison_percent 30 epoch 49: loss_train=0.6762, acc_train=0.6667, loss_test=0.4004, acc_test=0.9026
# poison_percent 30 epoch 50: loss_train=0.3706, acc_train=1.0000, loss_test=0.3542, acc_test=0.9633
# poison_percent 30 epoch 51: loss_train=0.5375, acc_train=0.6667, loss_test=0.3640, acc_test=0.9587
# poison_percent 30 epoch 52: loss_train=0.5617, acc_train=0.6667, loss_test=0.4359, acc_test=0.9046
# poison_percent 30 epoch 53: loss_train=0.5564, acc_train=0.6667, loss_test=0.3640, acc_test=0.9577
# poison_percent 30 epoch 54: loss_train=0.3629, acc_train=0.8333, loss_test=0.3905, acc_test=0.9459
# poison_percent 30 epoch 55: loss_train=0.7782, acc_train=0.5000, loss_test=0.3612, acc_test=0.9582
# poison_percent 30 epoch 56: loss_train=0.5502, acc_train=0.6667, loss_test=0.4039, acc_test=0.9224
# poison_percent 30 epoch 57: loss_train=0.3625, acc_train=1.0000, loss_test=0.3580, acc_test=0.9622
# poison_percent 30 epoch 58: loss_train=0.8594, acc_train=0.5000, loss_test=0.3688, acc_test=0.9541
# poison_percent 30 epoch 59: loss_train=0.7965, acc_train=0.3333, loss_test=0.3884, acc_test=0.9474
# poison_percent 30 epoch 60: loss_train=0.7591, acc_train=0.5000, loss_test=0.3964, acc_test=0.9449
# poison_percent 30 epoch 61: loss_train=0.4447, acc_train=0.8333, loss_test=0.3383, acc_test=0.9684
# poison_percent 30 epoch 62: loss_train=0.6104, acc_train=0.6667, loss_test=0.3225, acc_test=0.9663
# poison_percent 30 epoch 63: loss_train=0.6462, acc_train=0.6667, loss_test=0.3681, acc_test=0.9571
# poison_percent 30 epoch 64: loss_train=0.6712, acc_train=0.6667, loss_test=0.3602, acc_test=0.9577
# poison_percent 30 epoch 65: loss_train=0.6483, acc_train=0.6667, loss_test=0.3465, acc_test=0.9648
# poison_percent 30 epoch 66: loss_train=0.4625, acc_train=0.8333, loss_test=0.3988, acc_test=0.9316
# poison_percent 30 epoch 67: loss_train=0.8956, acc_train=0.5000, loss_test=0.3778, acc_test=0.9490
# poison_percent 30 epoch 68: loss_train=0.4119, acc_train=0.8333, loss_test=0.4077, acc_test=0.9332
# poison_percent 30 epoch 69: loss_train=0.4607, acc_train=0.8333, loss_test=0.3854, acc_test=0.9505
# poison_percent 30 epoch 70: loss_train=0.3551, acc_train=1.0000, loss_test=0.3922, acc_test=0.9495
# poison_percent 30 epoch 71: loss_train=0.4024, acc_train=0.8333, loss_test=0.3587, acc_test=0.9622
# poison_percent 30 epoch 72: loss_train=0.6633, acc_train=0.6667, loss_test=0.3891, acc_test=0.9454
# poison_percent 30 epoch 73: loss_train=0.5849, acc_train=0.8333, loss_test=0.4170, acc_test=0.9087
# poison_percent 30 epoch 74: loss_train=0.6545, acc_train=0.6667, loss_test=0.3549, acc_test=0.9617
# poison_percent 30 epoch 75: loss_train=0.4615, acc_train=0.8333, loss_test=0.3543, acc_test=0.9612
# poison_percent 30 epoch 76: loss_train=0.5846, acc_train=0.5000, loss_test=0.3715, acc_test=0.9566
# poison_percent 30 epoch 77: loss_train=0.6100, acc_train=0.6667, loss_test=0.3884, acc_test=0.9464
# poison_percent 30 epoch 78: loss_train=0.4882, acc_train=0.8333, loss_test=0.3982, acc_test=0.9276
# poison_percent 30 epoch 79: loss_train=0.5249, acc_train=0.8333, loss_test=0.3213, acc_test=0.9714
# poison_percent 30 epoch 80: loss_train=0.5250, acc_train=0.6667, loss_test=0.3652, acc_test=0.9551
# poison_percent 30 epoch 81: loss_train=0.5971, acc_train=0.6667, loss_test=0.3556, acc_test=0.9648
# poison_percent 30 epoch 82: loss_train=0.7840, acc_train=0.5000, loss_test=0.3539, acc_test=0.9582
# poison_percent 30 epoch 83: loss_train=0.8254, acc_train=0.5000, loss_test=0.3912, acc_test=0.9408
# poison_percent 30 epoch 84: loss_train=0.5330, acc_train=0.6667, loss_test=0.3685, acc_test=0.9582
# poison_percent 30 epoch 85: loss_train=0.8077, acc_train=0.3333, loss_test=0.3757, acc_test=0.9566
# poison_percent 30 epoch 86: loss_train=0.6494, acc_train=0.8333, loss_test=0.3873, acc_test=0.9490
# poison_percent 30 epoch 87: loss_train=0.4624, acc_train=0.6667, loss_test=0.4242, acc_test=0.9148
# poison_percent 30 epoch 88: loss_train=0.9868, acc_train=0.5000, loss_test=0.3653, acc_test=0.9561
# poison_percent 30 epoch 89: loss_train=0.3352, acc_train=1.0000, loss_test=0.4204, acc_test=0.9117
# poison_percent 30 epoch 90: loss_train=0.3157, acc_train=1.0000, loss_test=0.3686, acc_test=0.9571
# poison_percent 30 epoch 91: loss_train=1.0136, acc_train=0.1667, loss_test=0.3453, acc_test=0.9597
# poison_percent 30 epoch 92: loss_train=0.4442, acc_train=0.8333, loss_test=0.3555, acc_test=0.9597
# poison_percent 30 epoch 93: loss_train=0.3573, acc_train=1.0000, loss_test=0.3976, acc_test=0.9439
# poison_percent 30 epoch 94: loss_train=0.6010, acc_train=0.6667, loss_test=0.3888, acc_test=0.9464
# poison_percent 30 epoch 95: loss_train=0.5488, acc_train=0.6667, loss_test=0.3549, acc_test=0.9597
# poison_percent 30 epoch 96: loss_train=0.5753, acc_train=0.8333, loss_test=0.3692, acc_test=0.9551
# poison_percent 30 epoch 97: loss_train=0.9586, acc_train=0.3333, loss_test=0.4219, acc_test=0.9082
# poison_percent 30 epoch 98: loss_train=0.4783, acc_train=0.8333, loss_test=0.3949, acc_test=0.9515
# poison_percent 30 epoch 99: loss_train=0.3479, acc_train=1.0000, loss_test=0.3904, acc_test=0.9388
# Training log saved to ./results\CL_ModelN1L2_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 epoch 0: loss_train=0.5276, acc_train=0.7727, loss_test=0.5160, acc_test=0.8556
# poison_percent 40 epoch 1: loss_train=0.5979, acc_train=0.6818, loss_test=0.5153, acc_test=0.8500
# poison_percent 40 epoch 2: loss_train=0.6486, acc_train=0.6364, loss_test=0.5238, acc_test=0.8230
# poison_percent 40 epoch 3: loss_train=0.5814, acc_train=0.5909, loss_test=0.5690, acc_test=0.7974
# poison_percent 40 epoch 4: loss_train=0.6420, acc_train=0.5909, loss_test=0.5487, acc_test=0.8199
# poison_percent 40 epoch 5: loss_train=0.6274, acc_train=0.6364, loss_test=0.5408, acc_test=0.8153
# poison_percent 40 epoch 6: loss_train=0.6541, acc_train=0.4545, loss_test=0.5611, acc_test=0.8041
# poison_percent 40 epoch 7: loss_train=0.6387, acc_train=0.6818, loss_test=0.5636, acc_test=0.8031
# poison_percent 40 epoch 8: loss_train=0.6292, acc_train=0.5909, loss_test=0.5155, acc_test=0.8612
# poison_percent 40 epoch 9: loss_train=0.7146, acc_train=0.4545, loss_test=0.5340, acc_test=0.8342
# poison_percent 40 epoch 10: loss_train=0.6105, acc_train=0.6818, loss_test=0.5393, acc_test=0.8138
# poison_percent 40 epoch 11: loss_train=0.6696, acc_train=0.6818, loss_test=0.5306, acc_test=0.8480
# poison_percent 40 epoch 12: loss_train=0.6380, acc_train=0.6818, loss_test=0.5455, acc_test=0.8347
# poison_percent 40 epoch 13: loss_train=0.6634, acc_train=0.5455, loss_test=0.5524, acc_test=0.8230
# poison_percent 40 epoch 14: loss_train=0.6119, acc_train=0.5909, loss_test=0.5226, acc_test=0.8495
# poison_percent 40 epoch 15: loss_train=0.6162, acc_train=0.7273, loss_test=0.5092, acc_test=0.8531
# poison_percent 40 epoch 16: loss_train=0.6212, acc_train=0.6364, loss_test=0.4538, acc_test=0.9260
# poison_percent 40 epoch 17: loss_train=0.5936, acc_train=0.6818, loss_test=0.5709, acc_test=0.7954
# poison_percent 40 epoch 18: loss_train=0.6157, acc_train=0.6364, loss_test=0.5563, acc_test=0.7893
# poison_percent 40 epoch 19: loss_train=0.6266, acc_train=0.6818, loss_test=0.4547, acc_test=0.9189
# poison_percent 40 epoch 20: loss_train=0.5914, acc_train=0.6364, loss_test=0.5114, acc_test=0.8536
# poison_percent 40 epoch 21: loss_train=0.7100, acc_train=0.5909, loss_test=0.5251, acc_test=0.8413
# poison_percent 40 epoch 22: loss_train=0.6704, acc_train=0.5000, loss_test=0.5437, acc_test=0.8434
# poison_percent 40 epoch 23: loss_train=0.7130, acc_train=0.4545, loss_test=0.5493, acc_test=0.8352
# poison_percent 40 epoch 24: loss_train=0.5929, acc_train=0.7273, loss_test=0.5149, acc_test=0.8526
# poison_percent 40 epoch 25: loss_train=0.6100, acc_train=0.6364, loss_test=0.5037, acc_test=0.8883
# poison_percent 40 epoch 26: loss_train=0.6331, acc_train=0.6364, loss_test=0.5343, acc_test=0.8408
# poison_percent 40 epoch 27: loss_train=0.5615, acc_train=0.7273, loss_test=0.5514, acc_test=0.8286
# poison_percent 40 epoch 28: loss_train=0.6782, acc_train=0.5909, loss_test=0.5289, acc_test=0.8587
# poison_percent 40 epoch 29: loss_train=0.6858, acc_train=0.6364, loss_test=0.5058, acc_test=0.8847
# poison_percent 40 epoch 30: loss_train=0.6748, acc_train=0.5909, loss_test=0.5427, acc_test=0.8148
# poison_percent 40 epoch 31: loss_train=0.6675, acc_train=0.5455, loss_test=0.5174, acc_test=0.8760
# poison_percent 40 epoch 32: loss_train=0.5637, acc_train=0.7273, loss_test=0.5402, acc_test=0.8367
# poison_percent 40 epoch 33: loss_train=0.5290, acc_train=0.6818, loss_test=0.4998, acc_test=0.8755
# poison_percent 40 epoch 34: loss_train=0.7528, acc_train=0.5000, loss_test=0.5025, acc_test=0.8862
# poison_percent 40 epoch 35: loss_train=0.5761, acc_train=0.6818, loss_test=0.5533, acc_test=0.8235
# poison_percent 40 epoch 36: loss_train=0.6341, acc_train=0.5000, loss_test=0.4987, acc_test=0.8867
# poison_percent 40 epoch 37: loss_train=0.5862, acc_train=0.7273, loss_test=0.5169, acc_test=0.8760
# poison_percent 40 epoch 38: loss_train=0.6555, acc_train=0.6364, loss_test=0.4999, acc_test=0.8648
# poison_percent 40 epoch 39: loss_train=0.7103, acc_train=0.5909, loss_test=0.5407, acc_test=0.8434
# poison_percent 40 epoch 40: loss_train=0.7827, acc_train=0.4091, loss_test=0.5255, acc_test=0.8138
# poison_percent 40 epoch 41: loss_train=0.6386, acc_train=0.6364, loss_test=0.5250, acc_test=0.8628
# poison_percent 40 epoch 42: loss_train=0.5131, acc_train=0.7727, loss_test=0.5414, acc_test=0.8342
# poison_percent 40 epoch 43: loss_train=0.6347, acc_train=0.6364, loss_test=0.5611, acc_test=0.8005
# poison_percent 40 epoch 44: loss_train=0.7407, acc_train=0.5000, loss_test=0.4892, acc_test=0.8929
# poison_percent 40 epoch 45: loss_train=0.7428, acc_train=0.5455, loss_test=0.5241, acc_test=0.8551
# poison_percent 40 epoch 46: loss_train=0.5970, acc_train=0.5455, loss_test=0.5357, acc_test=0.8510
# poison_percent 40 epoch 47: loss_train=0.6332, acc_train=0.6364, loss_test=0.5785, acc_test=0.7755
# poison_percent 40 epoch 48: loss_train=0.6028, acc_train=0.6818, loss_test=0.5217, acc_test=0.8495
# poison_percent 40 epoch 49: loss_train=0.6501, acc_train=0.6364, loss_test=0.6063, acc_test=0.7383
# poison_percent 40 epoch 50: loss_train=0.6907, acc_train=0.7727, loss_test=0.5440, acc_test=0.7923
# poison_percent 40 epoch 51: loss_train=0.5628, acc_train=0.7273, loss_test=0.4945, acc_test=0.8684
# poison_percent 40 epoch 52: loss_train=0.5575, acc_train=0.7727, loss_test=0.5522, acc_test=0.7883
# poison_percent 40 epoch 53: loss_train=0.6968, acc_train=0.5909, loss_test=0.5291, acc_test=0.8520
# poison_percent 40 epoch 54: loss_train=0.7497, acc_train=0.4091, loss_test=0.5399, acc_test=0.8454
# poison_percent 40 epoch 55: loss_train=0.6443, acc_train=0.5455, loss_test=0.4977, acc_test=0.8806
# poison_percent 40 epoch 56: loss_train=0.6981, acc_train=0.4091, loss_test=0.5385, acc_test=0.8480
# poison_percent 40 epoch 57: loss_train=0.5611, acc_train=0.7273, loss_test=0.4799, acc_test=0.8760
# poison_percent 40 epoch 58: loss_train=0.5853, acc_train=0.6818, loss_test=0.5516, acc_test=0.8255
# poison_percent 40 epoch 59: loss_train=0.6418, acc_train=0.6364, loss_test=0.4629, acc_test=0.9148
# poison_percent 40 epoch 60: loss_train=0.6340, acc_train=0.6364, loss_test=0.5321, acc_test=0.8413
# poison_percent 40 epoch 61: loss_train=0.6077, acc_train=0.6364, loss_test=0.4543, acc_test=0.9235
# poison_percent 40 epoch 62: loss_train=0.7007, acc_train=0.5909, loss_test=0.5502, acc_test=0.8235
# poison_percent 40 epoch 63: loss_train=0.6303, acc_train=0.6818, loss_test=0.5696, acc_test=0.7827
# poison_percent 40 epoch 64: loss_train=0.6386, acc_train=0.6818, loss_test=0.5355, acc_test=0.8260
# poison_percent 40 epoch 65: loss_train=0.6820, acc_train=0.6364, loss_test=0.5033, acc_test=0.8694
# poison_percent 40 epoch 66: loss_train=0.6504, acc_train=0.6364, loss_test=0.5701, acc_test=0.7985
# poison_percent 40 epoch 67: loss_train=0.6727, acc_train=0.5455, loss_test=0.5200, acc_test=0.8704
# poison_percent 40 epoch 68: loss_train=0.6048, acc_train=0.6818, loss_test=0.5554, acc_test=0.8255
# poison_percent 40 epoch 69: loss_train=0.6741, acc_train=0.5455, loss_test=0.5311, acc_test=0.8541
# poison_percent 40 epoch 70: loss_train=0.6288, acc_train=0.6818, loss_test=0.5411, acc_test=0.8378
# poison_percent 40 epoch 71: loss_train=0.6304, acc_train=0.6818, loss_test=0.4946, acc_test=0.8801
# poison_percent 40 epoch 72: loss_train=0.6737, acc_train=0.6364, loss_test=0.5331, acc_test=0.8510
# poison_percent 40 epoch 73: loss_train=0.6508, acc_train=0.5455, loss_test=0.5559, acc_test=0.8026
# poison_percent 40 epoch 74: loss_train=0.6644, acc_train=0.5000, loss_test=0.5512, acc_test=0.8148
# poison_percent 40 epoch 75: loss_train=0.5556, acc_train=0.5455, loss_test=0.5079, acc_test=0.8776
# poison_percent 40 epoch 76: loss_train=0.5434, acc_train=0.8636, loss_test=0.5282, acc_test=0.8668
# poison_percent 40 epoch 77: loss_train=0.8350, acc_train=0.3182, loss_test=0.5417, acc_test=0.8408
# poison_percent 40 epoch 78: loss_train=0.6084, acc_train=0.7273, loss_test=0.5569, acc_test=0.7985
# poison_percent 40 epoch 79: loss_train=0.5040, acc_train=0.7727, loss_test=0.4854, acc_test=0.8923
# poison_percent 40 epoch 80: loss_train=0.5704, acc_train=0.8182, loss_test=0.5467, acc_test=0.8311
# poison_percent 40 epoch 81: loss_train=0.6120, acc_train=0.6818, loss_test=0.4956, acc_test=0.8944
# ...
# poison_percent 40 epoch 41: loss_train=0.2423, acc_train=0.9545, loss_test=1.1063, acc_test=0.6485
# poison_percent 40 epoch 42: loss_train=0.3395, acc_train=0.8636, loss_test=1.0029, acc_test=0.6342
# poison_percent 40 epoch 43: loss_train=0.4660, acc_train=0.7727, loss_test=1.3043, acc_test=0.6051
# poison_percent 40 epoch 44: loss_train=0.3049, acc_train=0.8636, loss_test=1.0673, acc_test=0.6219
# poison_percent 40 epoch 45: loss_train=0.4652, acc_train=0.7727, loss_test=1.2575, acc_test=0.5413
# poison_percent 40 epoch 46: loss_train=0.3921, acc_train=0.8636, loss_test=1.1404, acc_test=0.6276
# poison_percent 40 epoch 47: loss_train=0.5229, acc_train=0.7273, loss_test=0.8553, acc_test=0.7224
# poison_percent 40 epoch 48: loss_train=0.3803, acc_train=0.8182, loss_test=1.1114, acc_test=0.6571
# poison_percent 40 epoch 49: loss_train=0.4273, acc_train=0.7727, loss_test=1.1247, acc_test=0.6332
# poison_percent 40 epoch 50: loss_train=0.2359, acc_train=0.9091, loss_test=1.2447, acc_test=0.6102
# poison_percent 40 epoch 51: loss_train=0.2659, acc_train=0.8636, loss_test=1.1464, acc_test=0.6082
# poison_percent 40 epoch 52: loss_train=1.1036, acc_train=0.8182, loss_test=1.0368, acc_test=0.6510
# poison_percent 40 epoch 53: loss_train=0.2972, acc_train=0.9091, loss_test=1.2192, acc_test=0.5668
# poison_percent 40 epoch 54: loss_train=0.3157, acc_train=0.8182, loss_test=0.9913, acc_test=0.6408
# poison_percent 40 epoch 55: loss_train=0.2999, acc_train=0.9091, loss_test=0.9333, acc_test=0.6985
# poison_percent 40 epoch 56: loss_train=0.2596, acc_train=0.9091, loss_test=1.2745, acc_test=0.6107
# poison_percent 40 epoch 57: loss_train=0.3101, acc_train=0.9091, loss_test=1.1766, acc_test=0.6260
# poison_percent 40 epoch 58: loss_train=0.4349, acc_train=0.6818, loss_test=0.9745, acc_test=0.7061
# poison_percent 40 epoch 59: loss_train=0.4119, acc_train=0.7727, loss_test=1.1682, acc_test=0.6403
# poison_percent 40 epoch 60: loss_train=0.3343, acc_train=0.9091, loss_test=1.2121, acc_test=0.5964
# poison_percent 40 epoch 61: loss_train=0.4599, acc_train=0.8182, loss_test=1.2210, acc_test=0.6352
# poison_percent 40 epoch 62: loss_train=0.2186, acc_train=0.9545, loss_test=1.1740, acc_test=0.6163
# poison_percent 40 epoch 63: loss_train=0.3340, acc_train=0.8182, loss_test=1.1027, acc_test=0.6648
# poison_percent 40 epoch 64: loss_train=0.3480, acc_train=0.8182, loss_test=1.2680, acc_test=0.5867
# poison_percent 40 epoch 65: loss_train=0.3477, acc_train=0.8182, loss_test=1.1608, acc_test=0.6367
# poison_percent 40 epoch 66: loss_train=0.3301, acc_train=0.8636, loss_test=1.1701, acc_test=0.6199
# poison_percent 40 epoch 67: loss_train=0.2502, acc_train=0.9091, loss_test=1.1154, acc_test=0.6837
# poison_percent 40 epoch 68: loss_train=0.2048, acc_train=1.0000, loss_test=1.2873, acc_test=0.5668
# poison_percent 40 epoch 69: loss_train=0.3648, acc_train=0.9091, loss_test=1.3747, acc_test=0.6214
# poison_percent 40 epoch 70: loss_train=0.4448, acc_train=0.8182, loss_test=1.1626, acc_test=0.6444
# poison_percent 40 epoch 71: loss_train=0.2965, acc_train=0.8636, loss_test=1.2492, acc_test=0.5867
# poison_percent 40 epoch 72: loss_train=0.3826, acc_train=0.8636, loss_test=1.2839, acc_test=0.6056
# poison_percent 40 epoch 73: loss_train=0.3545, acc_train=0.7727, loss_test=1.3252, acc_test=0.5969
# poison_percent 40 epoch 74: loss_train=0.3135, acc_train=0.8636, loss_test=1.1475, acc_test=0.6755
# poison_percent 40 epoch 75: loss_train=0.1332, acc_train=1.0000, loss_test=1.1024, acc_test=0.6367
# poison_percent 40 epoch 76: loss_train=0.2508, acc_train=0.8636, loss_test=1.1755, acc_test=0.6245
# poison_percent 40 epoch 77: loss_train=0.4228, acc_train=0.7727, loss_test=1.2231, acc_test=0.6143
# poison_percent 40 epoch 78: loss_train=0.2836, acc_train=0.8182, loss_test=1.2620, acc_test=0.6189
# poison_percent 40 epoch 79: loss_train=0.2906, acc_train=0.8636, loss_test=1.3355, acc_test=0.5832
# poison_percent 40 epoch 80: loss_train=0.5186, acc_train=0.6364, loss_test=1.3129, acc_test=0.5770
# poison_percent 40 epoch 81: loss_train=0.2513, acc_train=0.9091, loss_test=1.2380, acc_test=0.6587
# poison_percent 40 epoch 82: loss_train=0.3339, acc_train=0.8182, loss_test=1.2035, acc_test=0.6327
# poison_percent 40 epoch 83: loss_train=0.3384, acc_train=0.8636, loss_test=1.2650, acc_test=0.6388
# poison_percent 40 epoch 84: loss_train=0.4527, acc_train=0.7273, loss_test=1.3705, acc_test=0.5638
# poison_percent 40 epoch 85: loss_train=0.2346, acc_train=0.9545, loss_test=1.2878, acc_test=0.5918
# poison_percent 40 epoch 86: loss_train=0.3225, acc_train=0.7727, loss_test=1.2548, acc_test=0.6270
# poison_percent 40 epoch 87: loss_train=0.3171, acc_train=0.8636, loss_test=1.2706, acc_test=0.5969
# poison_percent 40 epoch 88: loss_train=0.2761, acc_train=0.8182, loss_test=1.4453, acc_test=0.6219
# poison_percent 40 epoch 89: loss_train=0.2451, acc_train=0.8636, loss_test=1.3954, acc_test=0.6031
# poison_percent 40 epoch 90: loss_train=0.0735, acc_train=1.0000, loss_test=1.3030, acc_test=0.6005
# poison_percent 40 epoch 91: loss_train=0.2467, acc_train=0.9091, loss_test=1.3355, acc_test=0.5658
# poison_percent 40 epoch 92: loss_train=0.3190, acc_train=0.9091, loss_test=1.2022, acc_test=0.6587
# poison_percent 40 epoch 93: loss_train=0.1900, acc_train=0.9091, loss_test=1.2527, acc_test=0.6209
# poison_percent 40 epoch 94: loss_train=0.2203, acc_train=0.9545, loss_test=1.2565, acc_test=0.6235
# poison_percent 40 epoch 95: loss_train=0.8694, acc_train=0.9091, loss_test=1.3196, acc_test=0.6270
# poison_percent 40 epoch 96: loss_train=0.3438, acc_train=0.8636, loss_test=1.1141, acc_test=0.6520
# poison_percent 40 epoch 97: loss_train=0.1704, acc_train=0.9091, loss_test=1.1236, acc_test=0.6622
# poison_percent 40 epoch 98: loss_train=0.2988, acc_train=0.8636, loss_test=1.2344, acc_test=0.6668
# poison_percent 40 epoch 99: loss_train=0.2074, acc_train=0.9091, loss_test=1.0778, acc_test=0.7102
# Training log saved to ./results\CL_ModelN32L2_Batchsize32_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 epoch 0: loss_train=0.5663, acc_train=0.8125, loss_test=1.7432, acc_test=0.4944
# poison_percent 50 epoch 1: loss_train=0.2292, acc_train=0.9375, loss_test=1.5660, acc_test=0.5811
# poison_percent 50 epoch 2: loss_train=0.3084, acc_train=0.8750, loss_test=1.7713, acc_test=0.5158
# poison_percent 50 epoch 3: loss_train=0.2841, acc_train=0.8125, loss_test=1.6429, acc_test=0.5265
# poison_percent 50 epoch 4: loss_train=0.4851, acc_train=0.8125, loss_test=1.7165, acc_test=0.5000
# poison_percent 50 epoch 5: loss_train=0.3599, acc_train=0.8125, loss_test=1.6614, acc_test=0.5189
# poison_percent 50 epoch 6: loss_train=1.0285, acc_train=0.6875, loss_test=1.7638, acc_test=0.4867
# poison_percent 50 epoch 7: loss_train=0.4075, acc_train=0.8125, loss_test=1.5566, acc_test=0.5480
# poison_percent 50 epoch 8: loss_train=0.9346, acc_train=0.7500, loss_test=1.4667, acc_test=0.5301
# poison_percent 50 epoch 9: loss_train=0.5461, acc_train=0.7500, loss_test=1.6820, acc_test=0.5082
# poison_percent 50 epoch 10: loss_train=0.3684, acc_train=0.8125, loss_test=1.7780, acc_test=0.4719
# poison_percent 50 epoch 11: loss_train=0.2634, acc_train=0.8750, loss_test=1.8068, acc_test=0.4393
# poison_percent 50 epoch 12: loss_train=0.4016, acc_train=0.8125, loss_test=1.6859, acc_test=0.4934
# poison_percent 50 epoch 13: loss_train=0.4057, acc_train=0.8750, loss_test=1.7113, acc_test=0.5224
# poison_percent 50 epoch 14: loss_train=0.3774, acc_train=0.8125, loss_test=1.5684, acc_test=0.5556
# poison_percent 50 epoch 15: loss_train=0.4799, acc_train=0.7500, loss_test=1.6831, acc_test=0.4791
# poison_percent 50 epoch 16: loss_train=0.6753, acc_train=0.6875, loss_test=1.4322, acc_test=0.5577
# poison_percent 50 epoch 17: loss_train=0.4554, acc_train=0.7500, loss_test=1.8422, acc_test=0.4673
# poison_percent 50 epoch 18: loss_train=0.3546, acc_train=0.9375, loss_test=1.4317, acc_test=0.5724
# poison_percent 50 epoch 19: loss_train=0.2589, acc_train=0.8750, loss_test=1.5308, acc_test=0.5005
# poison_percent 50 epoch 20: loss_train=0.3519, acc_train=0.8750, loss_test=1.5451, acc_test=0.5245
# poison_percent 50 epoch 21: loss_train=0.5333, acc_train=0.7500, loss_test=1.9341, acc_test=0.4097
# poison_percent 50 epoch 22: loss_train=0.3580, acc_train=0.8125, loss_test=1.8025, acc_test=0.4709
# poison_percent 50 epoch 23: loss_train=0.3486, acc_train=0.9375, loss_test=1.8896, acc_test=0.4724
# poison_percent 50 epoch 24: loss_train=0.4300, acc_train=0.7500, loss_test=1.6111, acc_test=0.4923
# poison_percent 50 epoch 25: loss_train=0.3475, acc_train=0.8125, loss_test=2.1082, acc_test=0.3923
# poison_percent 50 epoch 26: loss_train=0.2821, acc_train=0.8125, loss_test=1.5546, acc_test=0.5429
# poison_percent 50 epoch 27: loss_train=0.2997, acc_train=0.8750, loss_test=1.6683, acc_test=0.5255
# poison_percent 50 epoch 28: loss_train=0.2298, acc_train=1.0000, loss_test=1.7903, acc_test=0.4556
# poison_percent 50 epoch 29: loss_train=0.4319, acc_train=0.8125, loss_test=1.5922, acc_test=0.5112
# poison_percent 50 epoch 30: loss_train=0.3748, acc_train=0.7500, loss_test=1.6851, acc_test=0.5296
# poison_percent 50 epoch 31: loss_train=0.6650, acc_train=0.6875, loss_test=1.4419, acc_test=0.5276
# poison_percent 50 epoch 32: loss_train=0.3784, acc_train=0.8750, loss_test=1.6707, acc_test=0.5199
# poison_percent 50 epoch 33: loss_train=0.2932, acc_train=0.9375, loss_test=1.5782, acc_test=0.4898
# poison_percent 50 epoch 34: loss_train=0.4079, acc_train=0.8125, loss_test=1.9053, acc_test=0.4056
# poison_percent 50 epoch 35: loss_train=0.1728, acc_train=0.9375, loss_test=1.6674, acc_test=0.5536
# poison_percent 50 epoch 36: loss_train=0.3057, acc_train=0.8125, loss_test=1.5398, acc_test=0.5403
# poison_percent 50 epoch 37: loss_train=1.6410, acc_train=0.5625, loss_test=1.5831, acc_test=0.5250
# poison_percent 50 epoch 38: loss_train=0.2065, acc_train=0.9375, loss_test=1.6934, acc_test=0.4959
# poison_percent 50 epoch 39: loss_train=0.3305, acc_train=0.8750, loss_test=1.3405, acc_test=0.5673
# poison_percent 50 epoch 40: loss_train=0.2690, acc_train=0.8125, loss_test=1.5131, acc_test=0.5230
# poison_percent 50 epoch 41: loss_train=0.2433, acc_train=0.8750, loss_test=1.8362, acc_test=0.4556
# poison_percent 50 epoch 42: loss_train=0.6091, acc_train=0.6250, loss_test=1.5851, acc_test=0.5434
# poison_percent 50 epoch 43: loss_train=0.2943, acc_train=0.8750, loss_test=1.3843, acc_test=0.5903
# poison_percent 50 epoch 44: loss_train=2.4791, acc_train=0.6250, loss_test=1.6231, acc_test=0.4704
# poison_percent 50 epoch 45: loss_train=0.3334, acc_train=0.8125, loss_test=1.5981, acc_test=0.4770
# poison_percent 50 epoch 46: loss_train=0.3124, acc_train=0.8750, loss_test=1.8774, acc_test=0.4480
# poison_percent 50 epoch 47: loss_train=0.2777, acc_train=0.8125, loss_test=1.4098, acc_test=0.5791
# poison_percent 50 epoch 48: loss_train=0.2796, acc_train=0.8750, loss_test=1.5518, acc_test=0.5500
# poison_percent 50 epoch 49: loss_train=0.3154, acc_train=0.8125, loss_test=1.8549, acc_test=0.4709
# poison_percent 50 epoch 50: loss_train=0.3799, acc_train=0.8125, loss_test=1.5358, acc_test=0.5505
# poison_percent 50 epoch 51: loss_train=0.4116, acc_train=0.7500, loss_test=1.7601, acc_test=0.5408
# poison_percent 50 epoch 52: loss_train=0.2686, acc_train=0.9375, loss_test=1.7976, acc_test=0.5153
# poison_percent 50 epoch 53: loss_train=0.4809, acc_train=0.6875, loss_test=1.5831, acc_test=0.5066
# poison_percent 50 epoch 54: loss_train=0.4975, acc_train=0.7500, loss_test=1.8397, acc_test=0.4643
# poison_percent 50 epoch 55: loss_train=0.3159, acc_train=0.7500, loss_test=1.9238, acc_test=0.4281
# poison_percent 50 epoch 56: loss_train=0.2739, acc_train=0.8750, loss_test=1.4910, acc_test=0.5423
# poison_percent 50 epoch 57: loss_train=0.2021, acc_train=0.8750, loss_test=1.9145, acc_test=0.4260
# poison_percent 50 epoch 58: loss_train=0.4561, acc_train=0.8125, loss_test=1.7045, acc_test=0.4969
# poison_percent 50 epoch 59: loss_train=0.3457, acc_train=0.7500, loss_test=1.4621, acc_test=0.5964
# poison_percent 50 epoch 60: loss_train=0.1654, acc_train=1.0000, loss_test=1.8867, acc_test=0.4281
# poison_percent 50 epoch 61: loss_train=0.4353, acc_train=0.8125, loss_test=1.4896, acc_test=0.5791
# poison_percent 50 epoch 62: loss_train=0.4015, acc_train=0.8125, loss_test=1.4427, acc_test=0.5541
# poison_percent 50 epoch 63: loss_train=0.3292, acc_train=0.8750, loss_test=1.8161, acc_test=0.4827
# poison_percent 50 epoch 64: loss_train=0.5535, acc_train=0.6875, loss_test=1.8298, acc_test=0.4949
# poison_percent 50 epoch 65: loss_train=0.1630, acc_train=0.8750, loss_test=1.5872, acc_test=0.5077
# poison_percent 50 epoch 66: loss_train=0.3589, acc_train=0.8125, loss_test=1.8681, acc_test=0.5122
# poison_percent 50 epoch 67: loss_train=0.2014, acc_train=0.8750, loss_test=1.5712, acc_test=0.5607
# poison_percent 50 epoch 68: loss_train=0.2684, acc_train=0.8750, loss_test=1.5733, acc_test=0.5515
# poison_percent 50 epoch 69: loss_train=0.2143, acc_train=0.8750, loss_test=1.7766, acc_test=0.5092
# poison_percent 50 epoch 70: loss_train=0.3460, acc_train=0.8125, loss_test=1.8359, acc_test=0.4515
# poison_percent 50 epoch 71: loss_train=0.2568, acc_train=0.9375, loss_test=1.7634, acc_test=0.4347
# poison_percent 50 epoch 72: loss_train=0.5306, acc_train=0.6250, loss_test=1.9252, acc_test=0.4184
# poison_percent 50 epoch 73: loss_train=0.3630, acc_train=0.8125, loss_test=1.9044, acc_test=0.5015
# poison_percent 50 epoch 74: loss_train=1.3242, acc_train=0.8125, loss_test=1.8411, acc_test=0.4883
# poison_percent 50 epoch 75: loss_train=0.1573, acc_train=1.0000, loss_test=1.7367, acc_test=0.5194
# poison_percent 50 epoch 76: loss_train=0.3325, acc_train=0.8750, loss_test=1.7349, acc_test=0.5347
# poison_percent 50 epoch 77: loss_train=0.5198, acc_train=0.7500, loss_test=1.4681, acc_test=0.6071
# poison_percent 50 epoch 78: loss_train=0.2384, acc_train=0.8750, loss_test=1.7516, acc_test=0.4872
# poison_percent 50 epoch 79: loss_train=0.2791, acc_train=0.8750, loss_test=1.6075, acc_test=0.5658
# poison_percent 50 epoch 80: loss_train=0.5744, acc_train=0.7500, loss_test=1.8302, acc_test=0.4520
# poison_percent 50 epoch 81: loss_train=0.8063, acc_train=0.5000, loss_test=1.8800, acc_test=0.5306
# poison_percent 50 epoch 82: loss_train=0.3258, acc_train=0.8750, loss_test=1.8086, acc_test=0.5041
# poison_percent 50 epoch 83: loss_train=0.2401, acc_train=0.8125, loss_test=1.8060, acc_test=0.4837
# poison_percent 50 epoch 84: loss_train=0.1921, acc_train=0.9375, loss_test=1.9300, acc_test=0.4383
# poison_percent 50 epoch 85: loss_train=0.2768, acc_train=0.9375, loss_test=2.0230, acc_test=0.4541
# poison_percent 50 epoch 86: loss_train=1.4424, acc_train=0.6250, loss_test=2.0482, acc_test=0.4327
# poison_percent 50 epoch 87: loss_train=0.2966, acc_train=0.8750, loss_test=1.6359, acc_test=0.5260
# poison_percent 50 epoch 88: loss_train=0.3851, acc_train=0.8125, loss_test=1.9048, acc_test=0.4735
# poison_percent 50 epoch 89: loss_train=0.2493, acc_train=0.8750, loss_test=2.0246, acc_test=0.4597
# poison_percent 50 epoch 90: loss_train=0.2167, acc_train=0.8750, loss_test=1.9347, acc_test=0.5000
# poison_percent 50 epoch 91: loss_train=0.1967, acc_train=1.0000, loss_test=1.7314, acc_test=0.5311
# poison_percent 50 epoch 92: loss_train=0.1800, acc_train=0.9375, loss_test=1.8032, acc_test=0.5347
# poison_percent 50 epoch 93: loss_train=0.4338, acc_train=0.7500, loss_test=1.8985, acc_test=0.4949
# poison_percent 50 epoch 94: loss_train=0.1500, acc_train=0.9375, loss_test=1.9642, acc_test=0.4842
# poison_percent 50 epoch 95: loss_train=0.1420, acc_train=0.9375, loss_test=1.9793, acc_test=0.5117
# poison_percent 50 epoch 96: loss_train=0.4509, acc_train=0.8125, loss_test=1.5988, acc_test=0.5663
# poison_percent 50 epoch 97: loss_train=1.2822, acc_train=0.7500, loss_test=1.9795, acc_test=0.4867
# poison_percent 50 epoch 98: loss_train=0.1726, acc_train=1.0000, loss_test=1.9611, acc_test=0.5015
# poison_percent 50 epoch 99: loss_train=0.2379, acc_train=0.8125, loss_test=1.8505, acc_test=0.5286
# Training log saved to ./results\CL_ModelN32L2_Batchsize32_rev2\poisoned_50percent\poisoned_50percent.csv
