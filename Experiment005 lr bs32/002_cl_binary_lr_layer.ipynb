# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def load_mnist_binary_data(data_dir, honest_range=100, poison_range=100, img_size=28,select='Honest+Poisoned'):
    X = []
    y = []
    def load_honest(X, y):
        for i in range(honest_range):
            folder = os.path.join(data_dir, f"honest_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    def load_poisoned(X, y):
        for i in range(poison_range):
            folder = os.path.join(data_dir, f"poison_{i}")
            if not os.path.exists(folder):
                continue
            for label in os.listdir(folder):
                label_folder = os.path.join(folder, label)
                if not os.path.isdir(label_folder):
                    continue
                for fname in os.listdir(label_folder):
                    if fname.endswith('.png') or fname.endswith('.jpg'):
                        img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                        X.append(np.array(img).flatten() / 255.0)
                        y.append(label)
        return X, y
    
    if select == 'Honest+Poisoned':
        X, y = load_honest(X, y)
        X, y = load_poisoned(X, y)
    elif select == 'Poisoned+Honest':
        X, y = load_poisoned(X, y)
        X, y = load_honest(X, y)
    elif select == 'Honest':
        X, y = load_honest(X, y)
    elif select == 'Poisoned':
        X, y = load_poisoned(X, y)

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

def load_mnist_binary_test_data(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 32)
#         self.fc2 = nn.Linear(32, 1)
#         self.relu = nn.ReLU()
#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         x = torch.sigmoid(x)
#         return x

# %%
# class MNISTNet(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(28*28, 1)
#     def forward(self, x):
#         x = self.fc1(x)
#         x = torch.sigmoid(x)
#         return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 32
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_binary_poison/train"
TEST_PATH = "../data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
NODE = 1
for LAYER in [3,4,5,6]: # LAYER - (first,last)
    
    class MNISTNet(nn.Module):
        def __init__(self):
            super().__init__()
            
            # 1. Define the stack of hidden layers (Linear + ReLU)
            # Use a list comprehension to create the (Linear, ReLU) pairs
            hidden_layers = []
            for _ in range(LAYER-2):
                hidden_layers.append(nn.Linear(NODE, NODE))
                hidden_layers.append(nn.ReLU())
                
            # 2. Use nn.Sequential to wrap the entire dynamic stack
            self.dynamic_hidden = nn.Sequential(*hidden_layers)
            
            # Other layers
            self.fc1 = nn.Linear(28*28, NODE)
            self.fc2 = nn.Linear(NODE, 1)

        def forward(self, x):
            # Flatten the input
            x = x.view(x.size(0), -1) 
            
            # Input Layer
            x = self.fc1(x)
            x = nn.ReLU()(x) # We need to manually apply ReLU here
            
            # Dynamic Hidden Layers (Executed sequentially without a loop)
            x = self.dynamic_hidden(x)
                
            # Output Layer
            x = self.fc2(x)
            x = torch.sigmoid(x)
            
            return x

    BATCH_SIZE_list = [BATCH_SIZE]
    # temp_bs = BATCH_SIZE
    # while temp_bs >= 1:
    #     BATCH_SIZE_list.append(temp_bs)
    #     temp_bs = temp_bs // 2

    for rev in range(3):

        model = MNISTNet().to(device)
        for experiment_bs in BATCH_SIZE_list:

            name_save_path = f"CL_ModelN{NODE}L{LAYER}_Batchsize{experiment_bs}_rev{rev}"
            
            for i_poisoned in poison_n_list:
                percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

                # create directory
                NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
                save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
                # Remove existing directory if it exists
                if os.path.exists(save_path):
                    shutil.rmtree(save_path)
                if not os.path.exists(save_path):
                    os.makedirs(save_path)
                save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
                os.makedirs(save_all_path, exist_ok=True)
                
                # Load data
                X_train, y_train = load_mnist_binary_data( DATA_PATH, honest_range=N_HONEST, 
                                                        poison_range=i_poisoned, img_size=IMG_SIZE, 
                                                        select='Honest+Poisoned')
                X_test, y_test = load_mnist_binary_test_data( TEST_PATH, img_size=IMG_SIZE)
                # print(f"Loaded train: X={X_train.shape}, y={y_train.shape}")
                # print(f"Loaded test: X={X_test.shape}, y={y_test.shape}")

                if X_test.shape[0] == 0:
                    raise ValueError("No valid test images found in the test directory!")

                X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
                y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(device)
                X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

                torch.save(model, os.path.join(save_path,'model_init.pt'))
                optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

                records = []

                # Training loop
                for epoch in range(EPOCHS):

                    # Train
                    model.train()
                    
                    #randomize the training data
                    perm = torch.randperm(X_train_tensor.size(0))
                    X_train_tensor = X_train_tensor[perm]
                    y_train_tensor = y_train_tensor[perm]

                    for start in range(0, X_train_tensor.size(0), experiment_bs):
                        end = start + experiment_bs
                        xb = X_train_tensor[start:end]
                        yb = y_train_tensor[start:end]
                        outputs = model(xb)
                        preds = (outputs >= 0.5).float()
                        acc_train = (preds == yb).float().mean().item()
                        loss_train = binary_cross_entropy(outputs, yb)
                        optimizer.zero_grad()
                        loss_train.backward()
                        optimizer.step()

                    # Evaluate
                    model.eval()
                    with torch.no_grad():
                        outputs = model(X_test_tensor)
                        preds = (outputs >= 0.5).float()
                        loss_test = binary_cross_entropy(outputs, y_test_tensor)
                        acc_test = (preds == y_test_tensor).float().mean().item()
                    records.append({'poison_percent': percent_poisoned, 'epoch': epoch, 
                                    'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                    'loss_test': loss_test.item(), 'acc_test': acc_test})
                    report_txt = f"poison_percent {percent_poisoned} "
                    report_txt += f"epoch {epoch}: "
                    report_txt += f"loss_train={loss_train.item():.4f}, "
                    report_txt += f"acc_train={acc_train:.4f}, "
                    report_txt += f"loss_test={loss_test.item():.4f}, "
                    report_txt += f"acc_test={acc_test:.4f}"
                    print(report_txt)

                torch.save(model, os.path.join(save_path,'model_last.pt'))

                # Save training log
                df = pd.DataFrame(records)
                save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
                df.to_csv(save_name_path, index=False)
                print(f"Training log saved to {save_name_path}")

                # Plot loss and accuracy
                plt.figure(figsize=(10,4))

                plt.subplot(1,2,1)
                plt.plot(df['epoch'], df['loss_test'], marker='o')
                plt.title('Test Loss')
                plt.ylabel('Loss')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.subplot(1,2,2)
                plt.plot(df['epoch'], df['acc_test'], marker='o')
                plt.title('Test Accuracy')
                plt.ylabel('Accuracy')
                plt.xlabel('Epoch')
                plt.grid(True)
                plt.ylim(0, 1.1)
                # plt.legend()

                plt.tight_layout()
                save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
                plt.savefig(save_name_path)

                save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
                plt.savefig(save_name_path)
                plt.close()
# Out:
# poison_percent 0 epoch 0: loss_train=0.5467, acc_train=1.0000, loss_test=0.5497, acc_test=0.9862
# poison_percent 0 epoch 1: loss_train=0.5254, acc_train=1.0000, loss_test=0.4748, acc_test=0.9969
# poison_percent 0 epoch 2: loss_train=0.4162, acc_train=1.0000, loss_test=0.4022, acc_test=0.9980
# poison_percent 0 epoch 3: loss_train=0.3050, acc_train=1.0000, loss_test=0.3364, acc_test=0.9985
# poison_percent 0 epoch 4: loss_train=0.2798, acc_train=1.0000, loss_test=0.2806, acc_test=0.9990
# poison_percent 0 epoch 5: loss_train=0.2907, acc_train=1.0000, loss_test=0.2347, acc_test=0.9990
# poison_percent 0 epoch 6: loss_train=0.1704, acc_train=1.0000, loss_test=0.1977, acc_test=0.9990
# poison_percent 0 epoch 7: loss_train=0.1187, acc_train=1.0000, loss_test=0.1677, acc_test=0.9985
# poison_percent 0 epoch 8: loss_train=0.1424, acc_train=1.0000, loss_test=0.1436, acc_test=0.9995
# poison_percent 0 epoch 9: loss_train=0.1622, acc_train=1.0000, loss_test=0.1239, acc_test=0.9995
# poison_percent 0 epoch 10: loss_train=0.1242, acc_train=1.0000, loss_test=0.1077, acc_test=0.9995
# poison_percent 0 epoch 11: loss_train=0.0929, acc_train=1.0000, loss_test=0.0941, acc_test=0.9995
# poison_percent 0 epoch 12: loss_train=0.0816, acc_train=1.0000, loss_test=0.0832, acc_test=0.9995
# poison_percent 0 epoch 13: loss_train=0.0721, acc_train=1.0000, loss_test=0.0737, acc_test=0.9995
# poison_percent 0 epoch 14: loss_train=0.0403, acc_train=1.0000, loss_test=0.0653, acc_test=0.9995
# poison_percent 0 epoch 15: loss_train=0.0678, acc_train=1.0000, loss_test=0.0584, acc_test=1.0000
# poison_percent 0 epoch 16: loss_train=0.0705, acc_train=1.0000, loss_test=0.0522, acc_test=0.9995
# poison_percent 0 epoch 17: loss_train=0.0635, acc_train=1.0000, loss_test=0.0469, acc_test=0.9995
# poison_percent 0 epoch 18: loss_train=0.0574, acc_train=1.0000, loss_test=0.0426, acc_test=1.0000
# poison_percent 0 epoch 19: loss_train=0.0519, acc_train=1.0000, loss_test=0.0385, acc_test=0.9995
# poison_percent 0 epoch 20: loss_train=0.0201, acc_train=1.0000, loss_test=0.0350, acc_test=0.9995
# poison_percent 0 epoch 21: loss_train=0.0243, acc_train=1.0000, loss_test=0.0319, acc_test=0.9995
# poison_percent 0 epoch 22: loss_train=0.0334, acc_train=1.0000, loss_test=0.0292, acc_test=0.9995
# poison_percent 0 epoch 23: loss_train=0.0200, acc_train=1.0000, loss_test=0.0265, acc_test=0.9995
# poison_percent 0 epoch 24: loss_train=0.0230, acc_train=1.0000, loss_test=0.0245, acc_test=0.9995
# poison_percent 0 epoch 25: loss_train=0.0166, acc_train=1.0000, loss_test=0.0225, acc_test=0.9990
# poison_percent 0 epoch 26: loss_train=0.0232, acc_train=1.0000, loss_test=0.0206, acc_test=1.0000
# poison_percent 0 epoch 27: loss_train=0.0176, acc_train=1.0000, loss_test=0.0192, acc_test=0.9990
# poison_percent 0 epoch 28: loss_train=0.0229, acc_train=1.0000, loss_test=0.0176, acc_test=0.9995
# poison_percent 0 epoch 29: loss_train=0.0179, acc_train=1.0000, loss_test=0.0164, acc_test=0.9990
# poison_percent 0 epoch 30: loss_train=0.0107, acc_train=1.0000, loss_test=0.0151, acc_test=0.9990
# poison_percent 0 epoch 31: loss_train=0.0125, acc_train=1.0000, loss_test=0.0138, acc_test=0.9995
# poison_percent 0 epoch 32: loss_train=0.0091, acc_train=1.0000, loss_test=0.0130, acc_test=0.9990
# poison_percent 0 epoch 33: loss_train=0.0106, acc_train=1.0000, loss_test=0.0122, acc_test=0.9990
# poison_percent 0 epoch 34: loss_train=0.0077, acc_train=1.0000, loss_test=0.0114, acc_test=0.9990
# poison_percent 0 epoch 35: loss_train=0.0090, acc_train=1.0000, loss_test=0.0105, acc_test=0.9995
# poison_percent 0 epoch 36: loss_train=0.0101, acc_train=1.0000, loss_test=0.0098, acc_test=1.0000
# poison_percent 0 epoch 37: loss_train=0.0061, acc_train=1.0000, loss_test=0.0093, acc_test=0.9990
# poison_percent 0 epoch 38: loss_train=0.0117, acc_train=1.0000, loss_test=0.0086, acc_test=0.9995
# poison_percent 0 epoch 39: loss_train=0.0052, acc_train=1.0000, loss_test=0.0081, acc_test=0.9995
# poison_percent 0 epoch 40: loss_train=0.0075, acc_train=1.0000, loss_test=0.0076, acc_test=0.9990
# poison_percent 0 epoch 41: loss_train=0.0081, acc_train=1.0000, loss_test=0.0072, acc_test=0.9995
# poison_percent 0 epoch 42: loss_train=0.0053, acc_train=1.0000, loss_test=0.0067, acc_test=0.9995
# poison_percent 0 epoch 43: loss_train=0.0039, acc_train=1.0000, loss_test=0.0063, acc_test=0.9995
# poison_percent 0 epoch 44: loss_train=0.0037, acc_train=1.0000, loss_test=0.0061, acc_test=0.9990
# poison_percent 0 epoch 45: loss_train=0.0061, acc_train=1.0000, loss_test=0.0058, acc_test=0.9990
# poison_percent 0 epoch 46: loss_train=0.0032, acc_train=1.0000, loss_test=0.0053, acc_test=1.0000
# poison_percent 0 epoch 47: loss_train=0.0060, acc_train=1.0000, loss_test=0.0051, acc_test=0.9995
# poison_percent 0 epoch 48: loss_train=0.0035, acc_train=1.0000, loss_test=0.0047, acc_test=0.9995
# poison_percent 0 epoch 49: loss_train=0.0020, acc_train=1.0000, loss_test=0.0046, acc_test=1.0000
# poison_percent 0 epoch 50: loss_train=0.0025, acc_train=1.0000, loss_test=0.0045, acc_test=0.9995
# poison_percent 0 epoch 51: loss_train=0.0023, acc_train=1.0000, loss_test=0.0043, acc_test=0.9995
# poison_percent 0 epoch 52: loss_train=0.0033, acc_train=1.0000, loss_test=0.0041, acc_test=0.9995
# poison_percent 0 epoch 53: loss_train=0.0016, acc_train=1.0000, loss_test=0.0038, acc_test=0.9995
# poison_percent 0 epoch 54: loss_train=0.0034, acc_train=1.0000, loss_test=0.0037, acc_test=0.9995
# poison_percent 0 epoch 55: loss_train=0.0027, acc_train=1.0000, loss_test=0.0037, acc_test=0.9995
# poison_percent 0 epoch 56: loss_train=0.0014, acc_train=1.0000, loss_test=0.0035, acc_test=0.9995
# poison_percent 0 epoch 57: loss_train=0.0025, acc_train=1.0000, loss_test=0.0034, acc_test=0.9995
# poison_percent 0 epoch 58: loss_train=0.0027, acc_train=1.0000, loss_test=0.0033, acc_test=0.9995
# poison_percent 0 epoch 59: loss_train=0.0015, acc_train=1.0000, loss_test=0.0032, acc_test=0.9995
# poison_percent 0 epoch 60: loss_train=0.0027, acc_train=1.0000, loss_test=0.0029, acc_test=1.0000
# poison_percent 0 epoch 61: loss_train=0.0017, acc_train=1.0000, loss_test=0.0029, acc_test=0.9995
# poison_percent 0 epoch 62: loss_train=0.0019, acc_train=1.0000, loss_test=0.0028, acc_test=1.0000
# poison_percent 0 epoch 63: loss_train=0.0013, acc_train=1.0000, loss_test=0.0026, acc_test=1.0000
# poison_percent 0 epoch 64: loss_train=0.0020, acc_train=1.0000, loss_test=0.0025, acc_test=1.0000
# poison_percent 0 epoch 65: loss_train=0.0015, acc_train=1.0000, loss_test=0.0025, acc_test=1.0000
# poison_percent 0 epoch 66: loss_train=0.0018, acc_train=1.0000, loss_test=0.0024, acc_test=1.0000
# poison_percent 0 epoch 67: loss_train=0.0016, acc_train=1.0000, loss_test=0.0024, acc_test=1.0000
# poison_percent 0 epoch 68: loss_train=0.0015, acc_train=1.0000, loss_test=0.0023, acc_test=1.0000
# poison_percent 0 epoch 69: loss_train=0.0009, acc_train=1.0000, loss_test=0.0023, acc_test=1.0000
# poison_percent 0 epoch 70: loss_train=0.0012, acc_train=1.0000, loss_test=0.0022, acc_test=1.0000
# poison_percent 0 epoch 71: loss_train=0.0017, acc_train=1.0000, loss_test=0.0022, acc_test=1.0000
# poison_percent 0 epoch 72: loss_train=0.0013, acc_train=1.0000, loss_test=0.0022, acc_test=1.0000
# poison_percent 0 epoch 73: loss_train=0.0014, acc_train=1.0000, loss_test=0.0021, acc_test=1.0000
# poison_percent 0 epoch 74: loss_train=0.0011, acc_train=1.0000, loss_test=0.0021, acc_test=0.9995
# poison_percent 0 epoch 75: loss_train=0.0006, acc_train=1.0000, loss_test=0.0021, acc_test=1.0000
# poison_percent 0 epoch 76: loss_train=0.0012, acc_train=1.0000, loss_test=0.0026, acc_test=0.9990
# poison_percent 0 epoch 77: loss_train=0.0011, acc_train=1.0000, loss_test=0.0016, acc_test=1.0000
# poison_percent 0 epoch 78: loss_train=0.0012, acc_train=1.0000, loss_test=0.0015, acc_test=1.0000
# poison_percent 0 epoch 79: loss_train=0.0012, acc_train=1.0000, loss_test=0.0015, acc_test=1.0000
# poison_percent 0 epoch 80: loss_train=0.0012, acc_train=1.0000, loss_test=0.0014, acc_test=1.0000
# poison_percent 0 epoch 81: loss_train=0.0011, acc_train=1.0000, loss_test=0.0014, acc_test=1.0000
# poison_percent 0 epoch 82: loss_train=0.0010, acc_train=1.0000, loss_test=0.0014, acc_test=1.0000
# poison_percent 0 epoch 83: loss_train=0.0010, acc_train=1.0000, loss_test=0.0014, acc_test=1.0000
# poison_percent 0 epoch 84: loss_train=0.0011, acc_train=1.0000, loss_test=0.0014, acc_test=1.0000
# poison_percent 0 epoch 85: loss_train=0.0009, acc_train=1.0000, loss_test=0.0013, acc_test=1.0000
# poison_percent 0 epoch 86: loss_train=0.0007, acc_train=1.0000, loss_test=0.0013, acc_test=1.0000
# poison_percent 0 epoch 87: loss_train=0.0006, acc_train=1.0000, loss_test=0.0015, acc_test=1.0000
# poison_percent 0 epoch 88: loss_train=0.0007, acc_train=1.0000, loss_test=0.0015, acc_test=1.0000
# poison_percent 0 epoch 89: loss_train=0.0006, acc_train=1.0000, loss_test=0.0015, acc_test=1.0000
# poison_percent 0 epoch 90: loss_train=0.0006, acc_train=1.0000, loss_test=0.0014, acc_test=1.0000
# poison_percent 0 epoch 91: loss_train=0.0008, acc_train=1.0000, loss_test=0.0014, acc_test=1.0000
# poison_percent 0 epoch 92: loss_train=0.0008, acc_train=1.0000, loss_test=0.0014, acc_test=1.0000
# poison_percent 0 epoch 93: loss_train=0.0007, acc_train=1.0000, loss_test=0.0014, acc_test=1.0000
# poison_percent 0 epoch 94: loss_train=0.0006, acc_train=1.0000, loss_test=0.0014, acc_test=0.9995
# poison_percent 0 epoch 95: loss_train=0.0006, acc_train=1.0000, loss_test=0.0011, acc_test=1.0000
# poison_percent 0 epoch 96: loss_train=0.0007, acc_train=1.0000, loss_test=0.0011, acc_test=1.0000
# poison_percent 0 epoch 97: loss_train=0.0007, acc_train=1.0000, loss_test=0.0011, acc_test=1.0000
# poison_percent 0 epoch 98: loss_train=0.0007, acc_train=1.0000, loss_test=0.0013, acc_test=1.0000
# poison_percent 0 epoch 99: loss_train=0.0008, acc_train=1.0000, loss_test=0.0016, acc_test=0.9995
# Training log saved to ./results\CL_ModelN1L3_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 epoch 0: loss_train=0.4351, acc_train=0.9375, loss_test=0.0016, acc_test=1.0000
# poison_percent 10 epoch 1: loss_train=0.7823, acc_train=0.8750, loss_test=0.0032, acc_test=0.9995
# poison_percent 10 epoch 2: loss_train=0.4390, acc_train=0.9375, loss_test=0.0069, acc_test=0.9995
# poison_percent 10 epoch 3: loss_train=0.7737, acc_train=0.8750, loss_test=0.0138, acc_test=1.0000
# poison_percent 10 epoch 4: loss_train=0.3386, acc_train=0.9375, loss_test=0.0249, acc_test=1.0000
# poison_percent 10 epoch 5: loss_train=0.4833, acc_train=0.9375, loss_test=0.0760, acc_test=0.9867
# poison_percent 10 epoch 6: loss_train=0.3842, acc_train=0.8750, loss_test=0.1200, acc_test=0.9913
# poison_percent 10 epoch 7: loss_train=0.4218, acc_train=0.8750, loss_test=0.1211, acc_test=0.9944
# poison_percent 10 epoch 8: loss_train=0.4065, acc_train=0.8750, loss_test=0.1209, acc_test=0.9959
# poison_percent 10 epoch 9: loss_train=0.5136, acc_train=0.8125, loss_test=0.1359, acc_test=0.9939
# poison_percent 10 epoch 10: loss_train=0.2670, acc_train=0.9062, loss_test=0.1509, acc_test=0.9939
# poison_percent 10 epoch 11: loss_train=0.4027, acc_train=0.8750, loss_test=0.1256, acc_test=0.9964
# poison_percent 10 epoch 12: loss_train=0.2423, acc_train=0.9375, loss_test=0.1197, acc_test=0.9964
# poison_percent 10 epoch 13: loss_train=0.4116, acc_train=0.8438, loss_test=0.1229, acc_test=0.9959
# poison_percent 10 epoch 14: loss_train=0.3430, acc_train=0.9062, loss_test=0.1259, acc_test=0.9954
# poison_percent 10 epoch 15: loss_train=0.2858, acc_train=0.9062, loss_test=0.1359, acc_test=0.9939
# poison_percent 10 epoch 16: loss_train=0.3728, acc_train=0.8750, loss_test=0.1289, acc_test=0.9954
# poison_percent 10 epoch 17: loss_train=0.2939, acc_train=0.9062, loss_test=0.1176, acc_test=0.9969
# poison_percent 10 epoch 18: loss_train=0.4813, acc_train=0.8125, loss_test=0.1229, acc_test=0.9959
# poison_percent 10 epoch 19: loss_train=0.2354, acc_train=0.9375, loss_test=0.1177, acc_test=0.9959
# poison_percent 10 epoch 20: loss_train=0.4270, acc_train=0.8438, loss_test=0.1228, acc_test=0.9959
# poison_percent 10 epoch 21: loss_train=0.1813, acc_train=0.9688, loss_test=0.1247, acc_test=0.9954
# poison_percent 10 epoch 22: loss_train=0.1825, acc_train=0.9688, loss_test=0.1288, acc_test=0.9959
# poison_percent 10 epoch 23: loss_train=0.4097, acc_train=0.8750, loss_test=0.1196, acc_test=0.9959
# poison_percent 10 epoch 24: loss_train=0.5452, acc_train=0.8125, loss_test=0.1271, acc_test=0.9959
# poison_percent 10 epoch 25: loss_train=0.3782, acc_train=0.8750, loss_test=0.1240, acc_test=0.9964
# poison_percent 10 epoch 26: loss_train=0.4142, acc_train=0.8438, loss_test=0.1269, acc_test=0.9959
# poison_percent 10 epoch 27: loss_train=0.4028, acc_train=0.8438, loss_test=0.1217, acc_test=0.9969
# poison_percent 10 epoch 28: loss_train=0.1644, acc_train=0.9688, loss_test=0.1225, acc_test=0.9959
# poison_percent 10 epoch 29: loss_train=0.1887, acc_train=0.9688, loss_test=0.1258, acc_test=0.9964
# poison_percent 10 epoch 30: loss_train=0.4618, acc_train=0.8438, loss_test=0.1160, acc_test=0.9969
# poison_percent 10 epoch 31: loss_train=0.3156, acc_train=0.9062, loss_test=0.1203, acc_test=0.9954
# poison_percent 10 epoch 32: loss_train=0.3528, acc_train=0.8750, loss_test=0.1200, acc_test=0.9964
# poison_percent 10 epoch 33: loss_train=0.2629, acc_train=0.9375, loss_test=0.1197, acc_test=0.9969
# poison_percent 10 epoch 34: loss_train=0.2614, acc_train=0.9375, loss_test=0.1164, acc_test=0.9974
# poison_percent 10 epoch 35: loss_train=0.1892, acc_train=0.9688, loss_test=0.1276, acc_test=0.9964
# poison_percent 10 epoch 36: loss_train=0.5082, acc_train=0.7812, loss_test=0.1262, acc_test=0.9954
# poison_percent 10 epoch 37: loss_train=0.3183, acc_train=0.9062, loss_test=0.1165, acc_test=0.9974
# poison_percent 10 epoch 38: loss_train=0.3560, acc_train=0.8750, loss_test=0.1098, acc_test=0.9980
# poison_percent 10 epoch 39: loss_train=0.3037, acc_train=0.9062, loss_test=0.1178, acc_test=0.9980
# poison_percent 10 epoch 40: loss_train=0.3759, acc_train=0.8750, loss_test=0.1256, acc_test=0.9954
# poison_percent 10 epoch 41: loss_train=0.3209, acc_train=0.9062, loss_test=0.1218, acc_test=0.9954
# poison_percent 10 epoch 42: loss_train=0.1759, acc_train=0.9688, loss_test=0.1245, acc_test=0.9980
# poison_percent 10 epoch 43: loss_train=0.3319, acc_train=0.9062, loss_test=0.1315, acc_test=0.9954
# poison_percent 10 epoch 44: loss_train=0.3053, acc_train=0.9062, loss_test=0.1170, acc_test=0.9969
# poison_percent 10 epoch 45: loss_train=0.2457, acc_train=0.9375, loss_test=0.1269, acc_test=0.9974
# poison_percent 10 epoch 46: loss_train=0.3967, acc_train=0.8750, loss_test=0.1241, acc_test=0.9974
# poison_percent 10 epoch 47: loss_train=0.4383, acc_train=0.8438, loss_test=0.1324, acc_test=0.9954
# poison_percent 10 epoch 48: loss_train=0.4515, acc_train=0.8438, loss_test=0.1238, acc_test=0.9974
# poison_percent 10 epoch 49: loss_train=0.5455, acc_train=0.8125, loss_test=0.1223, acc_test=0.9980
# poison_percent 10 epoch 50: loss_train=0.2615, acc_train=0.9375, loss_test=0.1255, acc_test=0.9974
# poison_percent 10 epoch 51: loss_train=0.2303, acc_train=0.9375, loss_test=0.1148, acc_test=0.9980
# poison_percent 10 epoch 52: loss_train=0.1919, acc_train=0.9688, loss_test=0.1290, acc_test=0.9964
# poison_percent 10 epoch 53: loss_train=0.8942, acc_train=0.6250, loss_test=0.1206, acc_test=0.9964
# poison_percent 10 epoch 54: loss_train=0.2601, acc_train=0.9375, loss_test=0.1430, acc_test=0.9964
# poison_percent 10 epoch 55: loss_train=0.6603, acc_train=0.7500, loss_test=0.1225, acc_test=0.9974
# poison_percent 10 epoch 56: loss_train=0.2613, acc_train=0.9375, loss_test=0.1120, acc_test=0.9980
# poison_percent 10 epoch 57: loss_train=0.1794, acc_train=0.9688, loss_test=0.1110, acc_test=0.9980
# poison_percent 10 epoch 58: loss_train=0.3877, acc_train=0.8750, loss_test=0.1179, acc_test=0.9959
# poison_percent 10 epoch 59: loss_train=0.3653, acc_train=0.8750, loss_test=0.1174, acc_test=0.9964
# poison_percent 10 epoch 60: loss_train=0.3016, acc_train=0.9062, loss_test=0.1057, acc_test=0.9985
# poison_percent 10 epoch 61: loss_train=0.1692, acc_train=0.9688, loss_test=0.1143, acc_test=0.9974
# poison_percent 10 epoch 62: loss_train=0.2342, acc_train=0.9375, loss_test=0.1207, acc_test=0.9980
# poison_percent 10 epoch 63: loss_train=0.1723, acc_train=0.9688, loss_test=0.1248, acc_test=0.9954
# poison_percent 10 epoch 64: loss_train=0.2835, acc_train=0.9062, loss_test=0.1171, acc_test=0.9980
# poison_percent 10 epoch 65: loss_train=0.2527, acc_train=0.9375, loss_test=0.1098, acc_test=0.9980
# poison_percent 10 epoch 66: loss_train=0.3974, acc_train=0.8750, loss_test=0.1189, acc_test=0.9974
# poison_percent 10 epoch 67: loss_train=0.1847, acc_train=0.9688, loss_test=0.1237, acc_test=0.9969
# poison_percent 10 epoch 68: loss_train=0.2507, acc_train=0.9375, loss_test=0.1221, acc_test=0.9969
# poison_percent 10 epoch 69: loss_train=0.1739, acc_train=0.9688, loss_test=0.1214, acc_test=0.9974
# poison_percent 10 epoch 70: loss_train=0.2179, acc_train=0.9375, loss_test=0.1243, acc_test=0.9974
# poison_percent 10 epoch 71: loss_train=0.1814, acc_train=0.9688, loss_test=0.1325, acc_test=0.9969
# poison_percent 10 epoch 72: loss_train=0.3076, acc_train=0.9062, loss_test=0.1177, acc_test=0.9974
# poison_percent 10 epoch 73: loss_train=0.2123, acc_train=0.9375, loss_test=0.1332, acc_test=0.9964
# poison_percent 10 epoch 74: loss_train=0.4869, acc_train=0.8125, loss_test=0.1075, acc_test=0.9980
# poison_percent 10 epoch 75: loss_train=0.2553, acc_train=0.9062, loss_test=0.1250, acc_test=0.9969
# poison_percent 10 epoch 76: loss_train=0.4198, acc_train=0.8750, loss_test=0.1253, acc_test=0.9959
# poison_percent 10 epoch 77: loss_train=0.5536, acc_train=0.7812, loss_test=0.1290, acc_test=0.9969
# poison_percent 10 epoch 78: loss_train=0.5739, acc_train=0.7812, loss_test=0.1262, acc_test=0.9959
# poison_percent 10 epoch 79: loss_train=0.2438, acc_train=0.9375, loss_test=0.1168, acc_test=0.9969
# poison_percent 10 epoch 80: loss_train=0.4385, acc_train=0.8438, loss_test=0.1295, acc_test=0.9964
# poison_percent 10 epoch 81: loss_train=0.1905, acc_train=0.9688, loss_test=0.1370, acc_test=0.9959
# poison_percent 10 epoch 82: loss_train=0.4886, acc_train=0.8125, loss_test=0.1073, acc_test=0.9969
# poison_percent 10 epoch 83: loss_train=0.3737, acc_train=0.8750, loss_test=0.1273, acc_test=0.9964
# poison_percent 10 epoch 84: loss_train=0.5031, acc_train=0.8125, loss_test=0.1245, acc_test=0.9959
# poison_percent 10 epoch 85: loss_train=0.2446, acc_train=0.9375, loss_test=0.1204, acc_test=0.9959
# poison_percent 10 epoch 86: loss_train=0.3666, acc_train=0.8750, loss_test=0.1226, acc_test=0.9959
# poison_percent 10 epoch 87: loss_train=0.5253, acc_train=0.8125, loss_test=0.1193, acc_test=0.9954
# poison_percent 10 epoch 88: loss_train=0.2352, acc_train=0.9375, loss_test=0.1136, acc_test=0.9964
# poison_percent 10 epoch 89: loss_train=0.1264, acc_train=1.0000, loss_test=0.1293, acc_test=0.9954
# poison_percent 10 epoch 90: loss_train=0.1839, acc_train=0.9688, loss_test=0.1232, acc_test=0.9949
# poison_percent 10 epoch 91: loss_train=0.2032, acc_train=0.9375, loss_test=0.1243, acc_test=0.9959
# poison_percent 10 epoch 92: loss_train=0.3982, acc_train=0.8750, loss_test=0.1188, acc_test=0.9959
# poison_percent 10 epoch 93: loss_train=0.2427, acc_train=0.9375, loss_test=0.1306, acc_test=0.9959
# poison_percent 10 epoch 94: loss_train=0.1888, acc_train=0.9688, loss_test=0.1235, acc_test=0.9959
# poison_percent 10 epoch 95: loss_train=0.4043, acc_train=0.8438, loss_test=0.1115, acc_test=0.9959
# poison_percent 10 epoch 96: loss_train=0.4320, acc_train=0.8438, loss_test=0.1243, acc_test=0.9964
# poison_percent 10 epoch 97: loss_train=0.4330, acc_train=0.8438, loss_test=0.1299, acc_test=0.9944
# poison_percent 10 epoch 98: loss_train=0.4438, acc_train=0.8125, loss_test=0.1263, acc_test=0.9954
# poison_percent 10 epoch 99: loss_train=0.3579, acc_train=0.8750, loss_test=0.1279, acc_test=0.9964
# Training log saved to ./results\CL_ModelN1L3_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 epoch 0: loss_train=0.3394, acc_train=0.8889, loss_test=0.2233, acc_test=0.9867
# poison_percent 20 epoch 1: loss_train=0.2573, acc_train=0.9444, loss_test=0.2312, acc_test=0.9918
# poison_percent 20 epoch 2: loss_train=0.7703, acc_train=0.6667, loss_test=0.2360, acc_test=0.9903
# poison_percent 20 epoch 3: loss_train=0.5613, acc_train=0.7778, loss_test=0.2390, acc_test=0.9908
# poison_percent 20 epoch 4: loss_train=0.4619, acc_train=0.7778, loss_test=0.2439, acc_test=0.9903
# poison_percent 20 epoch 5: loss_train=0.5216, acc_train=0.7222, loss_test=0.2314, acc_test=0.9918
# poison_percent 20 epoch 6: loss_train=0.5296, acc_train=0.7778, loss_test=0.2152, acc_test=0.9923
# poison_percent 20 epoch 7: loss_train=0.3665, acc_train=0.8889, loss_test=0.2326, acc_test=0.9918
# poison_percent 20 epoch 8: loss_train=0.4625, acc_train=0.7778, loss_test=0.2308, acc_test=0.9923
# poison_percent 20 epoch 9: loss_train=0.5485, acc_train=0.7778, loss_test=0.2272, acc_test=0.9918
# poison_percent 20 epoch 10: loss_train=0.7554, acc_train=0.6111, loss_test=0.2377, acc_test=0.9898
# poison_percent 20 epoch 11: loss_train=0.4134, acc_train=0.8333, loss_test=0.2198, acc_test=0.9923
# poison_percent 20 epoch 12: loss_train=0.3762, acc_train=0.8889, loss_test=0.2318, acc_test=0.9918
# poison_percent 20 epoch 13: loss_train=0.3860, acc_train=0.8889, loss_test=0.2408, acc_test=0.9908
# poison_percent 20 epoch 14: loss_train=0.3708, acc_train=0.8889, loss_test=0.2257, acc_test=0.9898
# poison_percent 20 epoch 15: loss_train=0.4300, acc_train=0.8333, loss_test=0.2234, acc_test=0.9923
# poison_percent 20 epoch 16: loss_train=0.5278, acc_train=0.7778, loss_test=0.2149, acc_test=0.9923
# poison_percent 20 epoch 17: loss_train=0.5542, acc_train=0.7222, loss_test=0.2446, acc_test=0.9908
# poison_percent 20 epoch 18: loss_train=0.7421, acc_train=0.6111, loss_test=0.2530, acc_test=0.9883
# poison_percent 20 epoch 19: loss_train=0.4451, acc_train=0.8333, loss_test=0.2366, acc_test=0.9913
# poison_percent 20 epoch 20: loss_train=0.4477, acc_train=0.8333, loss_test=0.2390, acc_test=0.9898
# poison_percent 20 epoch 21: loss_train=0.3510, acc_train=0.8889, loss_test=0.2173, acc_test=0.9918
# poison_percent 20 epoch 22: loss_train=0.7514, acc_train=0.6111, loss_test=0.2303, acc_test=0.9908
# poison_percent 20 epoch 23: loss_train=0.6716, acc_train=0.6667, loss_test=0.2355, acc_test=0.9898
# poison_percent 20 epoch 24: loss_train=0.4096, acc_train=0.8333, loss_test=0.2221, acc_test=0.9913
# poison_percent 20 epoch 25: loss_train=0.7504, acc_train=0.6111, loss_test=0.2464, acc_test=0.9893
# poison_percent 20 epoch 26: loss_train=0.4624, acc_train=0.8333, loss_test=0.2139, acc_test=0.9923
# poison_percent 20 epoch 27: loss_train=0.5314, acc_train=0.7778, loss_test=0.2386, acc_test=0.9893
# poison_percent 20 epoch 28: loss_train=0.4738, acc_train=0.8333, loss_test=0.2424, acc_test=0.9888
# poison_percent 20 epoch 29: loss_train=0.5590, acc_train=0.7778, loss_test=0.2449, acc_test=0.9893
# poison_percent 20 epoch 30: loss_train=0.6590, acc_train=0.6667, loss_test=0.2631, acc_test=0.9857
# poison_percent 20 epoch 31: loss_train=0.5067, acc_train=0.7778, loss_test=0.2337, acc_test=0.9908
# poison_percent 20 epoch 32: loss_train=0.6164, acc_train=0.7222, loss_test=0.2230, acc_test=0.9923
# poison_percent 20 epoch 33: loss_train=0.6728, acc_train=0.6667, loss_test=0.2198, acc_test=0.9908
# poison_percent 20 epoch 34: loss_train=0.5800, acc_train=0.7222, loss_test=0.2183, acc_test=0.9903
# poison_percent 20 epoch 35: loss_train=0.5128, acc_train=0.7778, loss_test=0.2406, acc_test=0.9903
# poison_percent 20 epoch 36: loss_train=0.4362, acc_train=0.8333, loss_test=0.2366, acc_test=0.9903
# poison_percent 20 epoch 37: loss_train=0.4702, acc_train=0.8333, loss_test=0.2492, acc_test=0.9878
# poison_percent 20 epoch 38: loss_train=0.6214, acc_train=0.7222, loss_test=0.2433, acc_test=0.9888
# poison_percent 20 epoch 39: loss_train=0.3990, acc_train=0.8889, loss_test=0.2430, acc_test=0.9888
# poison_percent 20 epoch 40: loss_train=0.5347, acc_train=0.7778, loss_test=0.2274, acc_test=0.9918
# poison_percent 20 epoch 41: loss_train=0.4610, acc_train=0.8333, loss_test=0.2185, acc_test=0.9903
# poison_percent 20 epoch 42: loss_train=0.2349, acc_train=1.0000, loss_test=0.2472, acc_test=0.9867
# poison_percent 20 epoch 43: loss_train=0.3607, acc_train=0.8889, loss_test=0.2681, acc_test=0.9816
# poison_percent 20 epoch 44: loss_train=0.6022, acc_train=0.7222, loss_test=0.2354, acc_test=0.9893
# poison_percent 20 epoch 45: loss_train=0.3634, acc_train=0.8889, loss_test=0.2193, acc_test=0.9903
# poison_percent 20 epoch 46: loss_train=0.4653, acc_train=0.8333, loss_test=0.2487, acc_test=0.9862
# poison_percent 20 epoch 47: loss_train=0.5282, acc_train=0.7778, loss_test=0.2409, acc_test=0.9883
# poison_percent 20 epoch 48: loss_train=0.3012, acc_train=0.9444, loss_test=0.2194, acc_test=0.9908
# poison_percent 20 epoch 49: loss_train=0.6969, acc_train=0.6667, loss_test=0.2127, acc_test=0.9913
# poison_percent 20 epoch 50: loss_train=0.5301, acc_train=0.7778, loss_test=0.2222, acc_test=0.9903
# poison_percent 20 epoch 51: loss_train=0.3067, acc_train=0.9444, loss_test=0.2373, acc_test=0.9888
# poison_percent 20 epoch 52: loss_train=0.3571, acc_train=0.8889, loss_test=0.2457, acc_test=0.9857
# poison_percent 20 epoch 53: loss_train=0.4215, acc_train=0.8333, loss_test=0.2346, acc_test=0.9903
# poison_percent 20 epoch 54: loss_train=0.4263, acc_train=0.8333, loss_test=0.2376, acc_test=0.9867
# poison_percent 20 epoch 55: loss_train=0.6738, acc_train=0.6667, loss_test=0.2404, acc_test=0.9867
# poison_percent 20 epoch 56: loss_train=0.5129, acc_train=0.7778, loss_test=0.2229, acc_test=0.9903
# poison_percent 20 epoch 57: loss_train=0.4425, acc_train=0.8333, loss_test=0.2260, acc_test=0.9908
# poison_percent 20 epoch 58: loss_train=0.4489, acc_train=0.8333, loss_test=0.2293, acc_test=0.9903
# poison_percent 20 epoch 59: loss_train=0.7070, acc_train=0.6111, loss_test=0.2611, acc_test=0.9842
# poison_percent 20 epoch 60: loss_train=0.2747, acc_train=0.9444, loss_test=0.2195, acc_test=0.9903
# poison_percent 20 epoch 61: loss_train=0.5458, acc_train=0.7778, loss_test=0.2408, acc_test=0.9872
# poison_percent 20 epoch 62: loss_train=0.2706, acc_train=0.9444, loss_test=0.2359, acc_test=0.9878
# poison_percent 20 epoch 63: loss_train=0.4280, acc_train=0.8333, loss_test=0.2360, acc_test=0.9878
# poison_percent 20 epoch 64: loss_train=0.4172, acc_train=0.8333, loss_test=0.2284, acc_test=0.9903
# poison_percent 20 epoch 65: loss_train=0.5586, acc_train=0.7222, loss_test=0.2098, acc_test=0.9913
# poison_percent 20 epoch 66: loss_train=0.4292, acc_train=0.8333, loss_test=0.2469, acc_test=0.9862
# poison_percent 20 epoch 67: loss_train=0.5695, acc_train=0.7778, loss_test=0.2347, acc_test=0.9883
# poison_percent 20 epoch 68: loss_train=0.6460, acc_train=0.6667, loss_test=0.2162, acc_test=0.9903
# poison_percent 20 epoch 69: loss_train=0.3657, acc_train=0.8889, loss_test=0.2225, acc_test=0.9913
# poison_percent 20 epoch 70: loss_train=0.2634, acc_train=0.9444, loss_test=0.2387, acc_test=0.9872
# poison_percent 20 epoch 71: loss_train=0.4519, acc_train=0.8333, loss_test=0.2254, acc_test=0.9898
# poison_percent 20 epoch 72: loss_train=0.5035, acc_train=0.7222, loss_test=0.2326, acc_test=0.9883
# poison_percent 20 epoch 73: loss_train=0.3981, acc_train=0.8889, loss_test=0.2500, acc_test=0.9852
# poison_percent 20 epoch 74: loss_train=0.5549, acc_train=0.7222, loss_test=0.2005, acc_test=0.9918
# poison_percent 20 epoch 75: loss_train=0.3646, acc_train=0.8889, loss_test=0.2557, acc_test=0.9842
# poison_percent 20 epoch 76: loss_train=0.5601, acc_train=0.7778, loss_test=0.2240, acc_test=0.9888
# poison_percent 20 epoch 77: loss_train=0.6915, acc_train=0.6111, loss_test=0.2347, acc_test=0.9878
# poison_percent 20 epoch 78: loss_train=0.2417, acc_train=1.0000, loss_test=0.2389, acc_test=0.9872
# poison_percent 20 epoch 79: loss_train=0.4824, acc_train=0.7778, loss_test=0.2495, acc_test=0.9852
# poison_percent 20 epoch 80: loss_train=0.3063, acc_train=0.8889, loss_test=0.2285, acc_test=0.9878
# poison_percent 20 epoch 81: loss_train=0.3715, acc_train=0.8889, loss_test=0.2166, acc_test=0.9913
# poison_percent 20 epoch 82: loss_train=0.6043, acc_train=0.7222, loss_test=0.2221, acc_test=0.9903
# poison_percent 20 epoch 83: loss_train=0.6778, acc_train=0.7222, loss_test=0.2455, acc_test=0.9872
# poison_percent 20 epoch 84: loss_train=0.3846, acc_train=0.8333, loss_test=0.2094, acc_test=0.9918
# poison_percent 20 epoch 85: loss_train=0.4912, acc_train=0.7778, loss_test=0.2261, acc_test=0.9878
# poison_percent 20 epoch 86: loss_train=0.2709, acc_train=0.9444, loss_test=0.2218, acc_test=0.9898
# poison_percent 20 epoch 87: loss_train=0.6055, acc_train=0.7222, loss_test=0.2407, acc_test=0.9862
# poison_percent 20 epoch 88: loss_train=0.5871, acc_train=0.7222, loss_test=0.2431, acc_test=0.9878
# poison_percent 20 epoch 89: loss_train=0.4368, acc_train=0.8333, loss_test=0.2337, acc_test=0.9872
# poison_percent 20 epoch 90: loss_train=0.4531, acc_train=0.8333, loss_test=0.2253, acc_test=0.9883
# poison_percent 20 epoch 91: loss_train=0.5125, acc_train=0.7778, loss_test=0.2382, acc_test=0.9867
# poison_percent 20 epoch 92: loss_train=0.5648, acc_train=0.7222, loss_test=0.2257, acc_test=0.9898
# poison_percent 20 epoch 93: loss_train=0.4518, acc_train=0.8333, loss_test=0.2470, acc_test=0.9867
# poison_percent 20 epoch 94: loss_train=0.2558, acc_train=0.9444, loss_test=0.2309, acc_test=0.9888
# poison_percent 20 epoch 95: loss_train=0.4491, acc_train=0.8333, loss_test=0.2331, acc_test=0.9862
# poison_percent 20 epoch 96: loss_train=0.3280, acc_train=0.8889, loss_test=0.2411, acc_test=0.9857
# poison_percent 20 epoch 97: loss_train=0.5162, acc_train=0.7778, loss_test=0.2497, acc_test=0.9857
# poison_percent 20 epoch 98: loss_train=0.2968, acc_train=0.9444, loss_test=0.2279, acc_test=0.9888
# poison_percent 20 epoch 99: loss_train=0.5887, acc_train=0.7222, loss_test=0.2389, acc_test=0.9857
# Training log saved to ./results\CL_ModelN1L3_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 epoch 0: loss_train=0.7400, acc_train=0.5000, loss_test=0.3675, acc_test=0.9617
# poison_percent 30 epoch 1: loss_train=0.6233, acc_train=0.6667, loss_test=0.3762, acc_test=0.9653
# poison_percent 30 epoch 2: loss_train=0.7997, acc_train=0.5000, loss_test=0.4031, acc_test=0.9541
# poison_percent 30 epoch 3: loss_train=0.7930, acc_train=0.5000, loss_test=0.3753, acc_test=0.9699
# poison_percent 30 epoch 4: loss_train=0.5781, acc_train=0.6667, loss_test=0.3686, acc_test=0.9730
# poison_percent 30 epoch 5: loss_train=0.4856, acc_train=0.8333, loss_test=0.3497, acc_test=0.9821
# poison_percent 30 epoch 6: loss_train=0.7332, acc_train=0.5000, loss_test=0.3741, acc_test=0.9776
# poison_percent 30 epoch 7: loss_train=0.7957, acc_train=0.5000, loss_test=0.3574, acc_test=0.9816
# poison_percent 30 epoch 8: loss_train=0.6228, acc_train=0.6667, loss_test=0.3693, acc_test=0.9786
# poison_percent 30 epoch 9: loss_train=0.3439, acc_train=1.0000, loss_test=0.3717, acc_test=0.9796
# poison_percent 30 epoch 10: loss_train=0.7208, acc_train=0.5000, loss_test=0.3598, acc_test=0.9781
# poison_percent 30 epoch 11: loss_train=0.6085, acc_train=0.6667, loss_test=0.3508, acc_test=0.9816
# poison_percent 30 epoch 12: loss_train=0.4362, acc_train=1.0000, loss_test=0.3696, acc_test=0.9760
# poison_percent 30 epoch 13: loss_train=0.4800, acc_train=0.8333, loss_test=0.3566, acc_test=0.9821
# poison_percent 30 epoch 14: loss_train=0.4751, acc_train=0.6667, loss_test=0.3562, acc_test=0.9827
# poison_percent 30 epoch 15: loss_train=0.6152, acc_train=0.6667, loss_test=0.3703, acc_test=0.9821
# poison_percent 30 epoch 16: loss_train=0.5270, acc_train=0.8333, loss_test=0.3574, acc_test=0.9806
# poison_percent 30 epoch 17: loss_train=0.6600, acc_train=0.6667, loss_test=0.3889, acc_test=0.9663
# poison_percent 30 epoch 18: loss_train=0.3552, acc_train=1.0000, loss_test=0.3667, acc_test=0.9796
# poison_percent 30 epoch 19: loss_train=0.8007, acc_train=0.5000, loss_test=0.3731, acc_test=0.9781
# poison_percent 30 epoch 20: loss_train=0.4663, acc_train=0.8333, loss_test=0.3734, acc_test=0.9786
# poison_percent 30 epoch 21: loss_train=0.6307, acc_train=0.6667, loss_test=0.3622, acc_test=0.9791
# poison_percent 30 epoch 22: loss_train=0.2967, acc_train=1.0000, loss_test=0.3576, acc_test=0.9801
# poison_percent 30 epoch 23: loss_train=0.5609, acc_train=0.6667, loss_test=0.3719, acc_test=0.9786
# poison_percent 30 epoch 24: loss_train=0.4820, acc_train=0.8333, loss_test=0.3924, acc_test=0.9638
# poison_percent 30 epoch 25: loss_train=0.6889, acc_train=0.6667, loss_test=0.3744, acc_test=0.9781
# poison_percent 30 epoch 26: loss_train=0.5727, acc_train=0.6667, loss_test=0.3649, acc_test=0.9796
# poison_percent 30 epoch 27: loss_train=0.7264, acc_train=0.6667, loss_test=0.3717, acc_test=0.9735
# poison_percent 30 epoch 28: loss_train=0.6004, acc_train=0.6667, loss_test=0.3513, acc_test=0.9791
# poison_percent 30 epoch 29: loss_train=0.6285, acc_train=0.6667, loss_test=0.3783, acc_test=0.9750
# poison_percent 30 epoch 30: loss_train=0.4145, acc_train=0.8333, loss_test=0.3523, acc_test=0.9821
# poison_percent 30 epoch 31: loss_train=0.7433, acc_train=0.5000, loss_test=0.3315, acc_test=0.9832
# poison_percent 30 epoch 32: loss_train=0.6821, acc_train=0.5000, loss_test=0.3590, acc_test=0.9786
# poison_percent 30 epoch 33: loss_train=0.4703, acc_train=0.8333, loss_test=0.3369, acc_test=0.9832
# poison_percent 30 epoch 34: loss_train=0.6493, acc_train=0.6667, loss_test=0.3828, acc_test=0.9699
# poison_percent 30 epoch 35: loss_train=0.5435, acc_train=0.8333, loss_test=0.3402, acc_test=0.9821
# poison_percent 30 epoch 36: loss_train=0.7353, acc_train=0.5000, loss_test=0.3483, acc_test=0.9821
# poison_percent 30 epoch 37: loss_train=0.6186, acc_train=0.8333, loss_test=0.3389, acc_test=0.9816
# poison_percent 30 epoch 38: loss_train=0.4394, acc_train=0.8333, loss_test=0.3475, acc_test=0.9827
# poison_percent 30 epoch 39: loss_train=0.4438, acc_train=0.8333, loss_test=0.3581, acc_test=0.9791
# poison_percent 30 epoch 40: loss_train=0.4208, acc_train=0.8333, loss_test=0.3665, acc_test=0.9755
# poison_percent 30 epoch 41: loss_train=0.5223, acc_train=0.8333, loss_test=0.3696, acc_test=0.9755
# poison_percent 30 epoch 42: loss_train=0.3084, acc_train=1.0000, loss_test=0.3669, acc_test=0.9684
# poison_percent 30 epoch 43: loss_train=0.7864, acc_train=0.5000, loss_test=0.3694, acc_test=0.9760
# poison_percent 30 epoch 44: loss_train=0.3295, acc_train=1.0000, loss_test=0.3338, acc_test=0.9816
# poison_percent 30 epoch 45: loss_train=0.6058, acc_train=0.6667, loss_test=0.3690, acc_test=0.9760
# poison_percent 30 epoch 46: loss_train=0.4855, acc_train=0.8333, loss_test=0.3621, acc_test=0.9781
# poison_percent 30 epoch 47: loss_train=0.6326, acc_train=0.6667, loss_test=0.3641, acc_test=0.9745
# poison_percent 30 epoch 48: loss_train=0.7597, acc_train=0.5000, loss_test=0.4112, acc_test=0.9449
# poison_percent 30 epoch 49: loss_train=0.5444, acc_train=0.6667, loss_test=0.3485, acc_test=0.9801
# poison_percent 30 epoch 50: loss_train=1.5369, acc_train=0.6667, loss_test=0.3706, acc_test=0.9745
# poison_percent 30 epoch 51: loss_train=0.4004, acc_train=0.8333, loss_test=0.3632, acc_test=0.9740
# poison_percent 30 epoch 52: loss_train=0.4712, acc_train=0.8333, loss_test=0.3619, acc_test=0.9755
# poison_percent 30 epoch 53: loss_train=0.4808, acc_train=0.8333, loss_test=0.3700, acc_test=0.9689
# poison_percent 30 epoch 54: loss_train=0.3943, acc_train=0.8333, loss_test=0.3657, acc_test=0.9765
# poison_percent 30 epoch 55: loss_train=0.3398, acc_train=1.0000, loss_test=0.3534, acc_test=0.9781
# poison_percent 30 epoch 56: loss_train=0.7048, acc_train=0.5000, loss_test=0.3715, acc_test=0.9730
# poison_percent 30 epoch 57: loss_train=0.6497, acc_train=0.6667, loss_test=0.3678, acc_test=0.9679
# poison_percent 30 epoch 58: loss_train=0.6820, acc_train=0.5000, loss_test=0.3876, acc_test=0.9607
# poison_percent 30 epoch 59: loss_train=0.5383, acc_train=0.6667, loss_test=0.3723, acc_test=0.9658
# poison_percent 30 epoch 60: loss_train=0.4855, acc_train=0.8333, loss_test=0.3602, acc_test=0.9786
# poison_percent 30 epoch 61: loss_train=0.5225, acc_train=0.8333, loss_test=0.3789, acc_test=0.9658
# poison_percent 30 epoch 62: loss_train=0.5746, acc_train=0.6667, loss_test=0.3677, acc_test=0.9679
# poison_percent 30 epoch 63: loss_train=0.8142, acc_train=0.5000, loss_test=0.3424, acc_test=0.9781
# poison_percent 30 epoch 64: loss_train=0.4830, acc_train=0.6667, loss_test=0.3682, acc_test=0.9735
# poison_percent 30 epoch 65: loss_train=0.5915, acc_train=0.6667, loss_test=0.3713, acc_test=0.9673
# poison_percent 30 epoch 66: loss_train=0.6933, acc_train=0.6667, loss_test=0.4001, acc_test=0.9490
# poison_percent 30 epoch 67: loss_train=0.4902, acc_train=0.8333, loss_test=0.3984, acc_test=0.9485
# poison_percent 30 epoch 68: loss_train=0.7855, acc_train=0.5000, loss_test=0.3628, acc_test=0.9755
# poison_percent 30 epoch 69: loss_train=0.4851, acc_train=0.8333, loss_test=0.3645, acc_test=0.9740
# poison_percent 30 epoch 70: loss_train=0.5125, acc_train=0.8333, loss_test=0.3612, acc_test=0.9755
# poison_percent 30 epoch 71: loss_train=0.6433, acc_train=0.6667, loss_test=0.3774, acc_test=0.9628
# poison_percent 30 epoch 72: loss_train=0.3496, acc_train=1.0000, loss_test=0.3595, acc_test=0.9735
# poison_percent 30 epoch 73: loss_train=0.4889, acc_train=0.8333, loss_test=0.3917, acc_test=0.9515
# poison_percent 30 epoch 74: loss_train=0.4921, acc_train=0.8333, loss_test=0.3612, acc_test=0.9750
# poison_percent 30 epoch 75: loss_train=0.8012, acc_train=0.5000, loss_test=0.3588, acc_test=0.9745
# poison_percent 30 epoch 76: loss_train=0.4970, acc_train=0.8333, loss_test=0.3552, acc_test=0.9740
# poison_percent 30 epoch 77: loss_train=0.6068, acc_train=0.6667, loss_test=0.3509, acc_test=0.9765
# poison_percent 30 epoch 78: loss_train=0.3016, acc_train=1.0000, loss_test=0.3456, acc_test=0.9781
# poison_percent 30 epoch 79: loss_train=0.4725, acc_train=0.8333, loss_test=0.3886, acc_test=0.9561
# poison_percent 30 epoch 80: loss_train=0.5462, acc_train=0.8333, loss_test=0.3616, acc_test=0.9709
# poison_percent 30 epoch 81: loss_train=0.9509, acc_train=0.3333, loss_test=0.3641, acc_test=0.9745
# poison_percent 30 epoch 82: loss_train=0.3748, acc_train=1.0000, loss_test=0.3564, acc_test=0.9745
# poison_percent 30 epoch 83: loss_train=0.7634, acc_train=0.5000, loss_test=0.3501, acc_test=0.9724
# poison_percent 30 epoch 84: loss_train=0.4653, acc_train=0.8333, loss_test=0.3568, acc_test=0.9740
# poison_percent 30 epoch 85: loss_train=0.7292, acc_train=0.5000, loss_test=0.3332, acc_test=0.9811
# poison_percent 30 epoch 86: loss_train=0.9290, acc_train=0.3333, loss_test=0.3329, acc_test=0.9806
# poison_percent 30 epoch 87: loss_train=0.5900, acc_train=0.6667, loss_test=0.3571, acc_test=0.9740
# poison_percent 30 epoch 88: loss_train=0.3311, acc_train=1.0000, loss_test=0.3725, acc_test=0.9648
# poison_percent 30 epoch 89: loss_train=0.4517, acc_train=0.8333, loss_test=0.3575, acc_test=0.9750
# poison_percent 30 epoch 90: loss_train=0.4165, acc_train=0.8333, loss_test=0.3688, acc_test=0.9668
# poison_percent 30 epoch 91: loss_train=0.5045, acc_train=0.8333, loss_test=0.3519, acc_test=0.9760
# poison_percent 30 epoch 92: loss_train=0.7725, acc_train=0.5000, loss_test=0.3719, acc_test=0.9648
# poison_percent 30 epoch 93: loss_train=0.4436, acc_train=0.8333, loss_test=0.3827, acc_test=0.9602
# poison_percent 30 epoch 94: loss_train=0.3823, acc_train=0.8333, loss_test=0.3649, acc_test=0.9704
# poison_percent 30 epoch 95: loss_train=0.3702, acc_train=1.0000, loss_test=0.3592, acc_test=0.9745
# poison_percent 30 epoch 96: loss_train=0.7465, acc_train=0.5000, loss_test=0.3461, acc_test=0.9776
# poison_percent 30 epoch 97: loss_train=0.7109, acc_train=0.6667, loss_test=0.3825, acc_test=0.9571
# poison_percent 30 epoch 98: loss_train=0.4813, acc_train=0.6667, loss_test=0.3667, acc_test=0.9668
# poison_percent 30 epoch 99: loss_train=0.4429, acc_train=0.8333, loss_test=0.3426, acc_test=0.9801
# Training log saved to ./results\CL_ModelN1L3_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 epoch 0: loss_train=0.6012, acc_train=0.7273, loss_test=0.5045, acc_test=0.9128
# poison_percent 40 epoch 1: loss_train=0.6648, acc_train=0.5000, loss_test=0.5222, acc_test=0.9077
# poison_percent 40 epoch 2: loss_train=0.6170, acc_train=0.6364, loss_test=0.4842, acc_test=0.9459
# poison_percent 40 epoch 3: loss_train=0.6898, acc_train=0.5455, loss_test=0.5256, acc_test=0.8923
# poison_percent 40 epoch 4: loss_train=0.5167, acc_train=0.8182, loss_test=0.4847, acc_test=0.9510
# poison_percent 40 epoch 5: loss_train=0.6286, acc_train=0.6364, loss_test=0.5063, acc_test=0.9281
# poison_percent 40 epoch 6: loss_train=0.6638, acc_train=0.6364, loss_test=0.5420, acc_test=0.8658
# poison_percent 40 epoch 7: loss_train=0.5949, acc_train=0.7727, loss_test=0.5025, acc_test=0.9265
# poison_percent 40 epoch 8: loss_train=0.6462, acc_train=0.5909, loss_test=0.5336, acc_test=0.8908
# poison_percent 40 epoch 9: loss_train=0.6824, acc_train=0.5909, loss_test=0.5237, acc_test=0.9148
# poison_percent 40 epoch 10: loss_train=0.6633, acc_train=0.6364, loss_test=0.4974, acc_test=0.9388
# poison_percent 40 epoch 11: loss_train=0.6775, acc_train=0.5455, loss_test=0.4981, acc_test=0.9270
# poison_percent 40 epoch 12: loss_train=0.6786, acc_train=0.5909, loss_test=0.4950, acc_test=0.9342
# poison_percent 40 epoch 13: loss_train=0.6154, acc_train=0.7273, loss_test=0.4919, acc_test=0.9439
# poison_percent 40 epoch 14: loss_train=0.6645, acc_train=0.5455, loss_test=0.5068, acc_test=0.9250
# poison_percent 40 epoch 15: loss_train=0.6350, acc_train=0.6818, loss_test=0.5120, acc_test=0.9184
# poison_percent 40 epoch 16: loss_train=0.6730, acc_train=0.6818, loss_test=0.5517, acc_test=0.8571
# poison_percent 40 epoch 17: loss_train=0.5375, acc_train=0.7273, loss_test=0.4847, acc_test=0.9372
# poison_percent 40 epoch 18: loss_train=0.7053, acc_train=0.5909, loss_test=0.4994, acc_test=0.9204
# poison_percent 40 epoch 19: loss_train=0.6001, acc_train=0.6364, loss_test=0.4948, acc_test=0.9316
# poison_percent 40 epoch 20: loss_train=0.8054, acc_train=0.6364, loss_test=0.5154, acc_test=0.9087
# poison_percent 40 epoch 21: loss_train=0.6966, acc_train=0.5000, loss_test=0.4972, acc_test=0.9352
# poison_percent 40 epoch 22: loss_train=0.8123, acc_train=0.4091, loss_test=0.4835, acc_test=0.9413
# poison_percent 40 epoch 23: loss_train=0.6710, acc_train=0.5909, loss_test=0.4967, acc_test=0.9301
# poison_percent 40 epoch 24: loss_train=0.6576, acc_train=0.6818, loss_test=0.5082, acc_test=0.9092
# poison_percent 40 epoch 25: loss_train=0.5876, acc_train=0.7727, loss_test=0.5011, acc_test=0.9168
# poison_percent 40 epoch 26: loss_train=0.6345, acc_train=0.7273, loss_test=0.4673, acc_test=0.9556
# poison_percent 40 epoch 27: loss_train=0.6673, acc_train=0.5909, loss_test=0.5204, acc_test=0.8908
# poison_percent 40 epoch 28: loss_train=0.6762, acc_train=0.6818, loss_test=0.5020, acc_test=0.9163
# poison_percent 40 epoch 29: loss_train=0.6303, acc_train=0.6364, loss_test=0.5050, acc_test=0.9031
# poison_percent 40 epoch 30: loss_train=0.6408, acc_train=0.6364, loss_test=0.4864, acc_test=0.9352
# poison_percent 40 epoch 31: loss_train=0.6423, acc_train=0.6818, loss_test=0.5131, acc_test=0.9031
# poison_percent 40 epoch 32: loss_train=0.7471, acc_train=0.4091, loss_test=0.5328, acc_test=0.8699
# poison_percent 40 epoch 33: loss_train=0.6690, acc_train=0.5909, loss_test=0.5022, acc_test=0.9235
# poison_percent 40 epoch 34: loss_train=0.6215, acc_train=0.5909, loss_test=0.5338, acc_test=0.8740
# poison_percent 40 epoch 35: loss_train=0.6861, acc_train=0.5909, loss_test=0.5209, acc_test=0.8974
# poison_percent 40 epoch 36: loss_train=0.7239, acc_train=0.4545, loss_test=0.5049, acc_test=0.9010
# poison_percent 40 epoch 37: loss_train=0.7446, acc_train=0.5455, loss_test=0.5441, acc_test=0.8679
# poison_percent 40 epoch 38: loss_train=0.6500, acc_train=0.5909, loss_test=0.5017, acc_test=0.9255
# poison_percent 40 epoch 39: loss_train=0.5420, acc_train=0.8182, loss_test=0.4708, acc_test=0.9480
# poison_percent 40 epoch 40: loss_train=0.5376, acc_train=0.8636, loss_test=0.5032, acc_test=0.9199
# poison_percent 40 epoch 41: loss_train=0.5855, acc_train=0.6818, loss_test=0.5305, acc_test=0.8832
# poison_percent 40 epoch 42: loss_train=0.6376, acc_train=0.5455, loss_test=0.5215, acc_test=0.8821
# poison_percent 40 epoch 43: loss_train=0.6616, acc_train=0.6364, loss_test=0.5040, acc_test=0.9133
# poison_percent 40 epoch 44: loss_train=0.6429, acc_train=0.6364, loss_test=0.5190, acc_test=0.8964
# poison_percent 40 epoch 45: loss_train=0.6070, acc_train=0.7273, loss_test=0.4922, acc_test=0.9230
# poison_percent 40 epoch 46: loss_train=0.6840, acc_train=0.5909, loss_test=0.5205, acc_test=0.8918
# poison_percent 40 epoch 47: loss_train=0.6738, acc_train=0.5455, loss_test=0.4889, acc_test=0.9337
# poison_percent 40 epoch 48: loss_train=0.6285, acc_train=0.7727, loss_test=0.5018, acc_test=0.9031
# poison_percent 40 epoch 49: loss_train=0.5431, acc_train=0.7273, loss_test=0.5609, acc_test=0.8199
# poison_percent 40 epoch 50: loss_train=0.6889, acc_train=0.5455, loss_test=0.5193, acc_test=0.8969
# poison_percent 40 epoch 51: loss_train=0.5094, acc_train=0.8182, loss_test=0.5065, acc_test=0.9112
# poison_percent 40 epoch 52: loss_train=0.6455, acc_train=0.6818, loss_test=0.4902, acc_test=0.9337
# poison_percent 40 epoch 53: loss_train=0.6207, acc_train=0.6818, loss_test=0.5053, acc_test=0.9041
# poison_percent 40 epoch 54: loss_train=0.6476, acc_train=0.5455, loss_test=0.4900, acc_test=0.9184
# poison_percent 40 epoch 55: loss_train=0.7162, acc_train=0.5455, loss_test=0.4771, acc_test=0.9321
# poison_percent 40 epoch 56: loss_train=0.5998, acc_train=0.8182, loss_test=0.5103, acc_test=0.9031
# poison_percent 40 epoch 57: loss_train=0.6562, acc_train=0.6364, loss_test=0.5007, acc_test=0.9148
# poison_percent 40 epoch 58: loss_train=0.6751, acc_train=0.6364, loss_test=0.5099, acc_test=0.9077
# poison_percent 40 epoch 59: loss_train=0.6017, acc_train=0.6818, loss_test=0.5101, acc_test=0.8964
# poison_percent 40 epoch 60: loss_train=0.5708, acc_train=0.7273, loss_test=0.5240, acc_test=0.8847
# poison_percent 40 epoch 61: loss_train=0.6095, acc_train=0.6818, loss_test=0.5084, acc_test=0.9051
# poison_percent 40 epoch 62: loss_train=0.6547, acc_train=0.5455, loss_test=0.4873, acc_test=0.9209
# poison_percent 40 epoch 63: loss_train=0.6340, acc_train=0.6364, loss_test=0.5123, acc_test=0.9087
# poison_percent 40 epoch 64: loss_train=0.6906, acc_train=0.5909, loss_test=0.4967, acc_test=0.9214
# poison_percent 40 epoch 65: loss_train=0.6129, acc_train=0.6818, loss_test=0.5076, acc_test=0.9066
# poison_percent 40 epoch 66: loss_train=0.6018, acc_train=0.7273, loss_test=0.5281, acc_test=0.8684
# poison_percent 40 epoch 67: loss_train=0.7512, acc_train=0.5000, loss_test=0.5000, acc_test=0.9148
# poison_percent 40 epoch 68: loss_train=0.6395, acc_train=0.5909, loss_test=0.5115, acc_test=0.9051
# poison_percent 40 epoch 69: loss_train=0.5872, acc_train=0.7273, loss_test=0.5065, acc_test=0.9087
# poison_percent 40 epoch 70: loss_train=0.6476, acc_train=0.6364, loss_test=0.5041, acc_test=0.8995
# poison_percent 40 epoch 71: loss_train=0.7451, acc_train=0.5455, loss_test=0.4814, acc_test=0.9332
# poison_percent 40 epoch 72: loss_train=0.6943, acc_train=0.5455, loss_test=0.5225, acc_test=0.8837
# poison_percent 40 epoch 73: loss_train=0.6243, acc_train=0.5909, loss_test=0.5375, acc_test=0.8495
# poison_percent 40 epoch 74: loss_train=0.5184, acc_train=0.8636, loss_test=0.4982, acc_test=0.9082
# poison_percent 40 epoch 75: loss_train=0.6714, acc_train=0.5909, loss_test=0.5278, acc_test=0.8786
# poison_percent 40 epoch 76: loss_train=0.6305, acc_train=0.6364, loss_test=0.5311, acc_test=0.8592
# poison_percent 40 epoch 77: loss_train=0.6255, acc_train=0.6818, loss_test=0.5183, acc_test=0.8908
# poison_percent 40 epoch 78: loss_train=0.6262, acc_train=0.7273, loss_test=0.5035, acc_test=0.9046
# poison_percent 40 epoch 79: loss_train=0.6641, acc_train=0.5909, loss_test=0.5174, acc_test=0.8872
# poison_percent 40 epoch 80: loss_train=0.7959, acc_train=0.4545, loss_test=0.5244, acc_test=0.8765
# poison_percent 40 epoch 81: loss_train=0.6637, acc_train=0.5909, loss_test=0.4884, acc_test=0.9194
# ...
# poison_percent 40 epoch 41: loss_train=0.6936, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 42: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 43: loss_train=0.6931, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 44: loss_train=0.6929, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 45: loss_train=0.6933, acc_train=0.4545, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 46: loss_train=0.6958, acc_train=0.2273, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 47: loss_train=0.6932, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 48: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 49: loss_train=0.6929, acc_train=0.5455, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 50: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 51: loss_train=0.6934, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 52: loss_train=0.6933, acc_train=0.4545, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 53: loss_train=0.6932, acc_train=0.2727, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 54: loss_train=0.6931, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 55: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 56: loss_train=0.6942, acc_train=0.2727, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 57: loss_train=0.6934, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 58: loss_train=0.6929, acc_train=0.5455, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 59: loss_train=0.6932, acc_train=0.4545, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 60: loss_train=0.6932, acc_train=0.4545, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 61: loss_train=0.6938, acc_train=0.3636, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 62: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 63: loss_train=0.6934, acc_train=0.3636, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 64: loss_train=0.6933, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 65: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 66: loss_train=0.6932, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 67: loss_train=0.6933, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 68: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 69: loss_train=0.6933, acc_train=0.4545, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 70: loss_train=0.6932, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 71: loss_train=0.6934, acc_train=0.4545, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 72: loss_train=0.6930, acc_train=0.5455, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 73: loss_train=0.6931, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 74: loss_train=0.6928, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 75: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 76: loss_train=0.6938, acc_train=0.4091, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 77: loss_train=0.6934, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 78: loss_train=0.6928, acc_train=0.5455, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 79: loss_train=0.6931, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 80: loss_train=0.6926, acc_train=0.5909, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 81: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 82: loss_train=0.6932, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 40 epoch 83: loss_train=0.6924, acc_train=0.6818, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 84: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 85: loss_train=0.6929, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 86: loss_train=0.6931, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 87: loss_train=0.6932, acc_train=0.4091, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 88: loss_train=0.6932, acc_train=0.4545, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 89: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 90: loss_train=0.6933, acc_train=0.4545, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 91: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 92: loss_train=0.6932, acc_train=0.4545, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 93: loss_train=0.6930, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 94: loss_train=0.6929, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 95: loss_train=0.6931, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 96: loss_train=0.6931, acc_train=0.5455, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 97: loss_train=0.6931, acc_train=0.5909, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 98: loss_train=0.6935, acc_train=0.3636, loss_test=0.6931, acc_test=0.5000
# poison_percent 40 epoch 99: loss_train=0.6932, acc_train=0.4545, loss_test=0.6931, acc_test=0.5000
# Training log saved to ./results\CL_ModelN1L6_Batchsize32_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 epoch 0: loss_train=0.6929, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 1: loss_train=0.6936, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 2: loss_train=0.6930, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 3: loss_train=0.6928, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 4: loss_train=0.6929, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 5: loss_train=0.6948, acc_train=0.3125, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 6: loss_train=0.6932, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 7: loss_train=0.6919, acc_train=0.6875, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 8: loss_train=0.6932, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 9: loss_train=0.6957, acc_train=0.2500, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 10: loss_train=0.6931, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 11: loss_train=0.6930, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 12: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 13: loss_train=0.6932, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 14: loss_train=0.6929, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 15: loss_train=0.6931, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 16: loss_train=0.6933, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 17: loss_train=0.6934, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 18: loss_train=0.6931, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 19: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 20: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 21: loss_train=0.6931, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 22: loss_train=0.6942, acc_train=0.3125, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 23: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 24: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 25: loss_train=0.6928, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 26: loss_train=0.6932, acc_train=0.5000, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 27: loss_train=0.6938, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 28: loss_train=0.6936, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 29: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 30: loss_train=0.6932, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 31: loss_train=0.6944, acc_train=0.1250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 32: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 33: loss_train=0.6927, acc_train=0.5625, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 34: loss_train=0.6930, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 35: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 36: loss_train=0.6933, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 37: loss_train=0.6926, acc_train=0.8125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 38: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 39: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 40: loss_train=0.6939, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 41: loss_train=0.6929, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 42: loss_train=0.6943, acc_train=0.3125, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 43: loss_train=0.6934, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 44: loss_train=0.6933, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 45: loss_train=0.6931, acc_train=0.7500, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 46: loss_train=0.6931, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 47: loss_train=0.6936, acc_train=0.4375, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 48: loss_train=0.6933, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 49: loss_train=0.6928, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 50: loss_train=0.6939, acc_train=0.1250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 51: loss_train=0.6935, acc_train=0.4375, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 52: loss_train=0.6931, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 53: loss_train=0.6933, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 54: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 55: loss_train=0.6940, acc_train=0.3750, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 56: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 57: loss_train=0.6927, acc_train=0.7500, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 58: loss_train=0.6927, acc_train=0.5625, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 59: loss_train=0.6933, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 60: loss_train=0.6932, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 61: loss_train=0.6930, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 62: loss_train=0.6925, acc_train=0.6875, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 63: loss_train=0.6933, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 64: loss_train=0.6931, acc_train=0.7500, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 65: loss_train=0.6929, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 66: loss_train=0.6932, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 67: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 68: loss_train=0.6936, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 69: loss_train=0.6940, acc_train=0.2500, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 70: loss_train=0.6933, acc_train=0.2500, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 71: loss_train=0.6935, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 72: loss_train=0.6939, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 73: loss_train=0.6929, acc_train=0.5625, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 74: loss_train=0.6941, acc_train=0.3750, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 75: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 76: loss_train=0.6936, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 77: loss_train=0.6933, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 78: loss_train=0.6932, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 79: loss_train=0.6927, acc_train=0.6250, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 80: loss_train=0.6933, acc_train=0.2500, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 81: loss_train=0.6933, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 82: loss_train=0.6933, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 83: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 84: loss_train=0.6936, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 85: loss_train=0.6929, acc_train=0.5625, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 86: loss_train=0.6944, acc_train=0.3125, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 87: loss_train=0.6938, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 88: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 89: loss_train=0.6934, acc_train=0.3750, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 90: loss_train=0.6931, acc_train=0.5000, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 91: loss_train=0.6941, acc_train=0.3750, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 92: loss_train=0.6939, acc_train=0.2500, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 93: loss_train=0.6939, acc_train=0.1875, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 94: loss_train=0.6934, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 95: loss_train=0.6926, acc_train=0.6250, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 96: loss_train=0.6927, acc_train=0.5625, loss_test=0.6932, acc_test=0.5000
# poison_percent 50 epoch 97: loss_train=0.6938, acc_train=0.3125, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 98: loss_train=0.6932, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# poison_percent 50 epoch 99: loss_train=0.6934, acc_train=0.4375, loss_test=0.6931, acc_test=0.5000
# Training log saved to ./results\CL_ModelN1L6_Batchsize32_rev2\poisoned_50percent\poisoned_50percent.csv
