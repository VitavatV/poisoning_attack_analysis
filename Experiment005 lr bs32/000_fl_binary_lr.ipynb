# %% [markdown]
# # 1.Library

# %%
import os
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

import copy
import concurrent.futures

# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 2.Data Loader

# %%
def get_client_data(data_dir, client_type, idx, img_size=28):
    X, y = [], []
    folder = os.path.join(data_dir, f"{client_type}_{idx}")
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def load_mnist_binary_test_data_flat(test_dir, img_size=28):
    X = []
    y = []
    if not os.path.exists(test_dir):
        return X, y
    for label in ['0', '1']:
        label_folder = os.path.join(test_dir, label)
        if not os.path.isdir(label_folder):
            continue
        for fname in os.listdir(label_folder):
            if fname.endswith('.png') or fname.endswith('.jpg'):
                img = Image.open(os.path.join(label_folder, fname)).convert('L').resize((img_size, img_size))
                X.append(np.array(img).flatten() / 255.0)
                y.append(label)
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# %% [markdown]
# # 3.Model

# %%
class MNISTNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28*28, 1)
    def forward(self, x):
        x = self.fc1(x)
        x = torch.sigmoid(x)
        return x

# %% [markdown]
# # 4.Loss

# %%
def binary_cross_entropy(pred, target):
    eps = 1e-7
    pred = torch.clamp(pred, eps, 1 - eps)
    return -(target * torch.log(pred) + (1 - target) * torch.log(1 - pred)).mean()

# %%
def train_local_worker(args):
    X_c_tensor, y_c_tensor, global_weights, learning_rate, local_epoch, experiment_bs, device = args
    model = MNISTNet().to(device)
    model.load_state_dict(global_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(local_epoch):
        for start in range(0, X_c_tensor.size(0), experiment_bs):
            end = start + experiment_bs
            xb = X_c_tensor[start:end]
            yb = y_c_tensor[start:end]
            outputs = model(xb)
            preds = (outputs >= 0.5).float()
            loss = binary_cross_entropy(outputs, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    # Return a deepcopy to avoid issues with state_dict references
    return copy.deepcopy(model.state_dict()), X_c_tensor.size(0), yb, outputs, preds

# %%
def average_weights(w_list):
    avg = {}
    for k in w_list[0].keys():
        avg[k] = sum([w[k] for w in w_list]) / len(w_list)
    return avg

# %% [markdown]
# # 5.Configuration

# %%
N_HONEST = 100
N_POISONED = 100
IMG_SIZE = 28
LEARNING_RATE = 0.001
ROUNDS = 100
LOCAL_EPOCHS = 1
BATCH_SIZE = 32
N_CLASSES = 2

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

DATA_PATH = "../data/mnist_binary_poison/train"
TEST_PATH = "../data/mnist_binary_poison/test"

RESULT_PATH = "./results"

# %% [markdown]
# # 6.Main

# %%
poison_percent = [0, 10, 20, 30, 40, 50]
poison_n_list = []
for p in range(0,N_POISONED+1):
    percent = int((p / (p+N_HONEST)) * 100)
    if percent in poison_percent:
        poison_percent.remove(percent)
        print(f"Adding poison n: {p} for percent: {percent}")
        poison_n_list.append(p)
print("Poison n list:", poison_n_list)
# Out:
# Adding poison n: 0 for percent: 0
# Adding poison n: 12 for percent: 10
# Adding poison n: 25 for percent: 20
# Adding poison n: 43 for percent: 30
# Adding poison n: 67 for percent: 40
# Adding poison n: 100 for percent: 50
# Poison n list: [0, 12, 25, 43, 67, 100]

# %%
BATCH_SIZE_list = [BATCH_SIZE]
# temp_bs = BATCH_SIZE
# while temp_bs >= 1:
#     BATCH_SIZE_list.append(temp_bs)
#     temp_bs = temp_bs // 2

for rev in range(3):

    global_model = MNISTNet().to(device)
    for experiment_bs in BATCH_SIZE_list:

        name_save_path = f"FL_ModelN1L1_Batchsize{experiment_bs}_rev{rev}"
        
        for i_poisoned in poison_n_list:
            percent_poisoned = int((i_poisoned / (i_poisoned + N_HONEST)) * 100)

            # create directory
            NAME_SAVE_update_PATH = f"poisoned_{percent_poisoned}percent"
            save_path = os.path.join(RESULT_PATH,name_save_path,NAME_SAVE_update_PATH)
            # Remove existing directory if it exists
            if os.path.exists(save_path):
                shutil.rmtree(save_path)
            if not os.path.exists(save_path):
                os.makedirs(save_path)
            save_all_path = os.path.join(RESULT_PATH,name_save_path,'all')
            os.makedirs(save_all_path, exist_ok=True)
            
            # Load data
            X_test, y_test = load_mnist_binary_test_data_flat(TEST_PATH, img_size=IMG_SIZE)
            if X_test.shape[0] == 0:
                raise ValueError("No valid test images found in the test directory!")
            X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
            y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(device)

            torch.save(global_model, os.path.join(save_path,'model_init.pt'))
            global_weights = global_model.state_dict()

            records = []

            X_train_tensor = {}
            y_train_tensor = {}
            for i in range(N_HONEST):
                X_c, y_c = get_client_data(DATA_PATH, "honest", i, img_size=IMG_SIZE)
                if len(X_c) == 0:
                    continue
                X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                X_train_tensor[f"honest_{i}"] = X_c_tensor
                y_train_tensor[f"honest_{i}"] = y_c_tensor
            for i in range(i_poisoned):
                X_c, y_c = get_client_data(DATA_PATH, "poison", i, img_size=IMG_SIZE)
                if len(X_c) == 0:
                    continue
                X_c_tensor = torch.tensor(X_c, dtype=torch.float32).to(device)
                y_c_tensor = torch.tensor(y_c, dtype=torch.float32).unsqueeze(1).to(device)
                X_train_tensor[f"poison_{i}"] = X_c_tensor
                y_train_tensor[f"poison_{i}"] = y_c_tensor

            # Training loop
            for round in range(ROUNDS):
                # Prepare arguments for honest clients
                
                #randomize the training data
                for i in range(N_HONEST):
                    perm = torch.randperm(X_train_tensor[f"honest_{i}"].size(0))
                    X_train_tensor[f"honest_{i}"] = X_train_tensor[f"honest_{i}"][perm]
                    y_train_tensor[f"honest_{i}"] = y_train_tensor[f"honest_{i}"][perm]

                honest_args = [
                    (
                        X_train_tensor[f"honest_{i}"],
                        y_train_tensor[f"honest_{i}"],
                        global_weights,
                        LEARNING_RATE,
                        LOCAL_EPOCHS,
                        experiment_bs,
                        device
                    )
                    for i in range(N_HONEST)
                ]

                # Prepare arguments for poisoned clients
                
                #randomize the training data
                for i in range(i_poisoned):
                    perm = torch.randperm(X_train_tensor[f"poison_{i}"].size(0))
                    X_train_tensor[f"poison_{i}"] = X_train_tensor[f"poison_{i}"][perm]
                    y_train_tensor[f"poison_{i}"] = y_train_tensor[f"poison_{i}"][perm]

                poison_args = [
                    (
                        X_train_tensor[f"poison_{i}"],
                        y_train_tensor[f"poison_{i}"],
                        global_weights,
                        LEARNING_RATE,
                        LOCAL_EPOCHS,
                        experiment_bs,
                        device
                    )
                    for i in range(i_poisoned)
                ]

                # Run in parallel
                with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
                    honest_results = list(executor.map(train_local_worker, honest_args))
                    poison_results = list(executor.map(train_local_worker, poison_args))

                local_weights = []
                local_sizes = []
                local_y = []
                local_outputs = []
                local_preds = []
                for l_w, l_sz, l_y, l_out, l_pred in honest_results + poison_results:
                    local_weights.append(l_w)
                    local_sizes.append(l_sz)
                    local_y.extend(l_y)
                    local_outputs.extend(l_out)
                    local_preds.extend(l_pred)
                loss_train = binary_cross_entropy(torch.stack(local_outputs), torch.stack(local_y))
                acc_train = (torch.stack(local_preds) == torch.stack(local_y)).float().mean().item()


                # Federated averaging (weighted by client data size)
                new_weights = {}
                for key in global_weights.keys():
                    new_weights[key] = sum([w[key]*sz for w, sz in zip(local_weights, local_sizes)]) / sum(local_sizes)
                global_weights = new_weights
                global_model.load_state_dict(global_weights)

                # Evaluate
                global_model.eval()
                with torch.no_grad():
                    outputs = global_model(X_test_tensor)
                    preds = (outputs > 0.5).float()
                    loss_test = binary_cross_entropy(outputs, y_test_tensor)
                    acc_test = (preds == y_test_tensor).float().mean().item()
                records.append({'poison_percent': percent_poisoned, 'round': round, 
                                'loss_train': loss_train.item(), 'acc_train': acc_train, 
                                'loss_test': loss_test.item(), 'acc_test': acc_test})
                report_txt = f"poison_percent {percent_poisoned} "
                report_txt += f"round {round}: "
                report_txt += f"loss_train={loss_train.item():.4f}, "
                report_txt += f"acc_train={acc_train:.4f}, "
                report_txt += f"loss_test={loss_test.item():.4f}, "
                report_txt += f"acc_test={acc_test:.4f}"
                print(report_txt)

            torch.save(global_model, os.path.join(save_path,'model_last.pt'))

            # Save training log
            df = pd.DataFrame(records)
            save_name_path = os.path.join(save_path, f'{NAME_SAVE_update_PATH}.csv')
            df.to_csv(save_name_path, index=False)
            print(f"Training log saved to {save_name_path}")

            # Plot loss and accuracy
            plt.figure(figsize=(10,4))

            plt.subplot(1,2,1)
            plt.plot(df['round'], df['loss_test'], marker='o')
            plt.title('Test Loss')
            plt.ylabel('Loss')
            plt.xlabel('Epoch')
            plt.grid(True)
            plt.ylim(0, 1.1)
            # plt.legend()

            plt.subplot(1,2,2)
            plt.plot(df['round'], df['acc_test'], marker='o')
            plt.title('Test Accuracy')
            plt.ylabel('Accuracy')
            plt.xlabel('Epoch')
            plt.grid(True)
            plt.ylim(0, 1.1)
            # plt.legend()

            plt.tight_layout()
            save_name_path = os.path.join(save_path, f'loss_accuracy.jpg')
            plt.savefig(save_name_path)

            save_name_path = os.path.join(save_all_path, f'{NAME_SAVE_update_PATH}_latest.jpg')
            plt.savefig(save_name_path)
            plt.close()
# Out:
# poison_percent 0 round 0: loss_train=0.6310, acc_train=0.8462, loss_test=0.6052, acc_test=0.9020
# poison_percent 0 round 1: loss_train=0.5829, acc_train=0.9204, loss_test=0.5593, acc_test=0.9429
# poison_percent 0 round 2: loss_train=0.5412, acc_train=0.9488, loss_test=0.5185, acc_test=0.9612
# poison_percent 0 round 3: loss_train=0.5064, acc_train=0.9673, loss_test=0.4822, acc_test=0.9770
# poison_percent 0 round 4: loss_train=0.4702, acc_train=0.9777, loss_test=0.4495, acc_test=0.9806
# poison_percent 0 round 5: loss_train=0.4379, acc_train=0.9796, loss_test=0.4197, acc_test=0.9847
# poison_percent 0 round 6: loss_train=0.4129, acc_train=0.9850, loss_test=0.3923, acc_test=0.9867
# poison_percent 0 round 7: loss_train=0.3818, acc_train=0.9842, loss_test=0.3670, acc_test=0.9872
# poison_percent 0 round 8: loss_train=0.3635, acc_train=0.9881, loss_test=0.3435, acc_test=0.9903
# poison_percent 0 round 9: loss_train=0.3394, acc_train=0.9900, loss_test=0.3216, acc_test=0.9913
# poison_percent 0 round 10: loss_train=0.3089, acc_train=0.9938, loss_test=0.3012, acc_test=0.9923
# poison_percent 0 round 11: loss_train=0.2946, acc_train=0.9931, loss_test=0.2821, acc_test=0.9934
# poison_percent 0 round 12: loss_train=0.2782, acc_train=0.9923, loss_test=0.2644, acc_test=0.9944
# poison_percent 0 round 13: loss_train=0.2619, acc_train=0.9919, loss_test=0.2479, acc_test=0.9959
# poison_percent 0 round 14: loss_train=0.2477, acc_train=0.9904, loss_test=0.2324, acc_test=0.9959
# poison_percent 0 round 15: loss_train=0.2291, acc_train=0.9923, loss_test=0.2180, acc_test=0.9949
# poison_percent 0 round 16: loss_train=0.2167, acc_train=0.9900, loss_test=0.2046, acc_test=0.9949
# poison_percent 0 round 17: loss_train=0.2009, acc_train=0.9927, loss_test=0.1921, acc_test=0.9949
# poison_percent 0 round 18: loss_train=0.1947, acc_train=0.9904, loss_test=0.1806, acc_test=0.9949
# poison_percent 0 round 19: loss_train=0.1806, acc_train=0.9923, loss_test=0.1698, acc_test=0.9949
# poison_percent 0 round 20: loss_train=0.1682, acc_train=0.9919, loss_test=0.1598, acc_test=0.9954
# poison_percent 0 round 21: loss_train=0.1620, acc_train=0.9915, loss_test=0.1505, acc_test=0.9959
# poison_percent 0 round 22: loss_train=0.1533, acc_train=0.9919, loss_test=0.1418, acc_test=0.9964
# poison_percent 0 round 23: loss_train=0.1437, acc_train=0.9915, loss_test=0.1337, acc_test=0.9964
# poison_percent 0 round 24: loss_train=0.1342, acc_train=0.9900, loss_test=0.1262, acc_test=0.9964
# poison_percent 0 round 25: loss_train=0.1295, acc_train=0.9912, loss_test=0.1192, acc_test=0.9964
# poison_percent 0 round 26: loss_train=0.1232, acc_train=0.9908, loss_test=0.1126, acc_test=0.9964
# poison_percent 0 round 27: loss_train=0.1153, acc_train=0.9938, loss_test=0.1065, acc_test=0.9964
# poison_percent 0 round 28: loss_train=0.1123, acc_train=0.9915, loss_test=0.1009, acc_test=0.9964
# poison_percent 0 round 29: loss_train=0.1048, acc_train=0.9915, loss_test=0.0956, acc_test=0.9969
# poison_percent 0 round 30: loss_train=0.0979, acc_train=0.9935, loss_test=0.0907, acc_test=0.9974
# poison_percent 0 round 31: loss_train=0.0956, acc_train=0.9919, loss_test=0.0861, acc_test=0.9974
# poison_percent 0 round 32: loss_train=0.0907, acc_train=0.9938, loss_test=0.0818, acc_test=0.9974
# poison_percent 0 round 33: loss_train=0.0881, acc_train=0.9915, loss_test=0.0778, acc_test=0.9980
# poison_percent 0 round 34: loss_train=0.0819, acc_train=0.9904, loss_test=0.0740, acc_test=0.9980
# poison_percent 0 round 35: loss_train=0.0805, acc_train=0.9908, loss_test=0.0705, acc_test=0.9974
# poison_percent 0 round 36: loss_train=0.0789, acc_train=0.9896, loss_test=0.0672, acc_test=0.9974
# poison_percent 0 round 37: loss_train=0.0717, acc_train=0.9942, loss_test=0.0641, acc_test=0.9974
# poison_percent 0 round 38: loss_train=0.0694, acc_train=0.9931, loss_test=0.0611, acc_test=0.9974
# poison_percent 0 round 39: loss_train=0.0673, acc_train=0.9912, loss_test=0.0584, acc_test=0.9974
# poison_percent 0 round 40: loss_train=0.0650, acc_train=0.9927, loss_test=0.0558, acc_test=0.9974
# poison_percent 0 round 41: loss_train=0.0592, acc_train=0.9931, loss_test=0.0534, acc_test=0.9974
# poison_percent 0 round 42: loss_train=0.0622, acc_train=0.9912, loss_test=0.0511, acc_test=0.9974
# poison_percent 0 round 43: loss_train=0.0582, acc_train=0.9919, loss_test=0.0489, acc_test=0.9974
# poison_percent 0 round 44: loss_train=0.0585, acc_train=0.9900, loss_test=0.0469, acc_test=0.9974
# poison_percent 0 round 45: loss_train=0.0555, acc_train=0.9923, loss_test=0.0449, acc_test=0.9974
# poison_percent 0 round 46: loss_train=0.0566, acc_train=0.9888, loss_test=0.0431, acc_test=0.9974
# poison_percent 0 round 47: loss_train=0.0476, acc_train=0.9954, loss_test=0.0414, acc_test=0.9974
# poison_percent 0 round 48: loss_train=0.0503, acc_train=0.9919, loss_test=0.0398, acc_test=0.9974
# poison_percent 0 round 49: loss_train=0.0508, acc_train=0.9919, loss_test=0.0383, acc_test=0.9974
# poison_percent 0 round 50: loss_train=0.0469, acc_train=0.9935, loss_test=0.0369, acc_test=0.9974
# poison_percent 0 round 51: loss_train=0.0422, acc_train=0.9935, loss_test=0.0355, acc_test=0.9974
# poison_percent 0 round 52: loss_train=0.0454, acc_train=0.9923, loss_test=0.0342, acc_test=0.9974
# poison_percent 0 round 53: loss_train=0.0429, acc_train=0.9923, loss_test=0.0330, acc_test=0.9974
# poison_percent 0 round 54: loss_train=0.0441, acc_train=0.9900, loss_test=0.0318, acc_test=0.9974
# poison_percent 0 round 55: loss_train=0.0384, acc_train=0.9942, loss_test=0.0307, acc_test=0.9974
# poison_percent 0 round 56: loss_train=0.0369, acc_train=0.9946, loss_test=0.0297, acc_test=0.9974
# poison_percent 0 round 57: loss_train=0.0401, acc_train=0.9919, loss_test=0.0287, acc_test=0.9980
# poison_percent 0 round 58: loss_train=0.0368, acc_train=0.9938, loss_test=0.0277, acc_test=0.9980
# poison_percent 0 round 59: loss_train=0.0381, acc_train=0.9927, loss_test=0.0268, acc_test=0.9980
# poison_percent 0 round 60: loss_train=0.0346, acc_train=0.9935, loss_test=0.0259, acc_test=0.9980
# poison_percent 0 round 61: loss_train=0.0380, acc_train=0.9908, loss_test=0.0251, acc_test=0.9980
# poison_percent 0 round 62: loss_train=0.0316, acc_train=0.9935, loss_test=0.0243, acc_test=0.9980
# poison_percent 0 round 63: loss_train=0.0345, acc_train=0.9923, loss_test=0.0236, acc_test=0.9980
# poison_percent 0 round 64: loss_train=0.0313, acc_train=0.9938, loss_test=0.0229, acc_test=0.9980
# poison_percent 0 round 65: loss_train=0.0286, acc_train=0.9927, loss_test=0.0222, acc_test=0.9980
# poison_percent 0 round 66: loss_train=0.0308, acc_train=0.9927, loss_test=0.0215, acc_test=0.9980
# poison_percent 0 round 67: loss_train=0.0312, acc_train=0.9919, loss_test=0.0209, acc_test=0.9980
# poison_percent 0 round 68: loss_train=0.0311, acc_train=0.9935, loss_test=0.0203, acc_test=0.9980
# poison_percent 0 round 69: loss_train=0.0294, acc_train=0.9923, loss_test=0.0197, acc_test=0.9980
# poison_percent 0 round 70: loss_train=0.0289, acc_train=0.9927, loss_test=0.0192, acc_test=0.9980
# poison_percent 0 round 71: loss_train=0.0252, acc_train=0.9950, loss_test=0.0187, acc_test=0.9980
# poison_percent 0 round 72: loss_train=0.0251, acc_train=0.9942, loss_test=0.0182, acc_test=0.9980
# poison_percent 0 round 73: loss_train=0.0263, acc_train=0.9931, loss_test=0.0177, acc_test=0.9980
# poison_percent 0 round 74: loss_train=0.0255, acc_train=0.9942, loss_test=0.0172, acc_test=0.9980
# poison_percent 0 round 75: loss_train=0.0224, acc_train=0.9950, loss_test=0.0168, acc_test=0.9980
# poison_percent 0 round 76: loss_train=0.0240, acc_train=0.9942, loss_test=0.0164, acc_test=0.9980
# poison_percent 0 round 77: loss_train=0.0210, acc_train=0.9954, loss_test=0.0160, acc_test=0.9980
# poison_percent 0 round 78: loss_train=0.0254, acc_train=0.9938, loss_test=0.0156, acc_test=0.9985
# poison_percent 0 round 79: loss_train=0.0258, acc_train=0.9935, loss_test=0.0152, acc_test=0.9985
# poison_percent 0 round 80: loss_train=0.0218, acc_train=0.9950, loss_test=0.0148, acc_test=0.9985
# poison_percent 0 round 81: loss_train=0.0234, acc_train=0.9942, loss_test=0.0145, acc_test=0.9985
# poison_percent 0 round 82: loss_train=0.0265, acc_train=0.9923, loss_test=0.0142, acc_test=0.9985
# poison_percent 0 round 83: loss_train=0.0230, acc_train=0.9942, loss_test=0.0138, acc_test=0.9985
# poison_percent 0 round 84: loss_train=0.0259, acc_train=0.9931, loss_test=0.0135, acc_test=0.9985
# poison_percent 0 round 85: loss_train=0.0179, acc_train=0.9958, loss_test=0.0132, acc_test=0.9985
# poison_percent 0 round 86: loss_train=0.0266, acc_train=0.9927, loss_test=0.0130, acc_test=0.9985
# poison_percent 0 round 87: loss_train=0.0213, acc_train=0.9938, loss_test=0.0127, acc_test=0.9985
# poison_percent 0 round 88: loss_train=0.0205, acc_train=0.9942, loss_test=0.0124, acc_test=0.9985
# poison_percent 0 round 89: loss_train=0.0220, acc_train=0.9942, loss_test=0.0122, acc_test=0.9985
# poison_percent 0 round 90: loss_train=0.0202, acc_train=0.9958, loss_test=0.0119, acc_test=0.9985
# poison_percent 0 round 91: loss_train=0.0255, acc_train=0.9915, loss_test=0.0117, acc_test=0.9985
# poison_percent 0 round 92: loss_train=0.0189, acc_train=0.9954, loss_test=0.0114, acc_test=0.9985
# poison_percent 0 round 93: loss_train=0.0195, acc_train=0.9958, loss_test=0.0112, acc_test=0.9985
# poison_percent 0 round 94: loss_train=0.0205, acc_train=0.9954, loss_test=0.0110, acc_test=0.9985
# poison_percent 0 round 95: loss_train=0.0231, acc_train=0.9931, loss_test=0.0108, acc_test=0.9985
# poison_percent 0 round 96: loss_train=0.0206, acc_train=0.9942, loss_test=0.0106, acc_test=0.9985
# poison_percent 0 round 97: loss_train=0.0183, acc_train=0.9950, loss_test=0.0104, acc_test=0.9985
# poison_percent 0 round 98: loss_train=0.0231, acc_train=0.9931, loss_test=0.0102, acc_test=0.9985
# poison_percent 0 round 99: loss_train=0.0181, acc_train=0.9950, loss_test=0.0100, acc_test=0.9985
# Training log saved to ./results\FL_ModelN1L1_Batchsize32_rev0\poisoned_0percent\poisoned_0percent.csv
# poison_percent 10 round 0: loss_train=0.8149, acc_train=0.8891, loss_test=0.0099, acc_test=0.9985
# poison_percent 10 round 1: loss_train=0.8487, acc_train=0.8891, loss_test=0.0098, acc_test=0.9985
# poison_percent 10 round 2: loss_train=0.8441, acc_train=0.8887, loss_test=0.0097, acc_test=0.9985
# poison_percent 10 round 3: loss_train=0.8577, acc_train=0.8905, loss_test=0.0095, acc_test=0.9985
# poison_percent 10 round 4: loss_train=0.8400, acc_train=0.8898, loss_test=0.0094, acc_test=0.9985
# poison_percent 10 round 5: loss_train=0.8821, acc_train=0.8860, loss_test=0.0093, acc_test=0.9985
# poison_percent 10 round 6: loss_train=0.8522, acc_train=0.8877, loss_test=0.0092, acc_test=0.9985
# poison_percent 10 round 7: loss_train=0.8690, acc_train=0.8887, loss_test=0.0091, acc_test=0.9985
# poison_percent 10 round 8: loss_train=0.8746, acc_train=0.8891, loss_test=0.0090, acc_test=0.9985
# poison_percent 10 round 9: loss_train=0.8721, acc_train=0.8884, loss_test=0.0088, acc_test=0.9985
# poison_percent 10 round 10: loss_train=0.8925, acc_train=0.8860, loss_test=0.0087, acc_test=0.9985
# poison_percent 10 round 11: loss_train=0.8825, acc_train=0.8877, loss_test=0.0086, acc_test=0.9985
# poison_percent 10 round 12: loss_train=0.8843, acc_train=0.8901, loss_test=0.0085, acc_test=0.9985
# poison_percent 10 round 13: loss_train=0.8975, acc_train=0.8894, loss_test=0.0085, acc_test=0.9985
# poison_percent 10 round 14: loss_train=0.8919, acc_train=0.8880, loss_test=0.0084, acc_test=0.9985
# poison_percent 10 round 15: loss_train=0.9081, acc_train=0.8880, loss_test=0.0083, acc_test=0.9985
# poison_percent 10 round 16: loss_train=0.9127, acc_train=0.8891, loss_test=0.0082, acc_test=0.9985
# poison_percent 10 round 17: loss_train=0.9223, acc_train=0.8877, loss_test=0.0081, acc_test=0.9985
# poison_percent 10 round 18: loss_train=0.9352, acc_train=0.8887, loss_test=0.0080, acc_test=0.9985
# poison_percent 10 round 19: loss_train=0.9295, acc_train=0.8880, loss_test=0.0079, acc_test=0.9985
# poison_percent 10 round 20: loss_train=0.9268, acc_train=0.8887, loss_test=0.0079, acc_test=0.9985
# poison_percent 10 round 21: loss_train=0.9119, acc_train=0.8894, loss_test=0.0078, acc_test=0.9985
# poison_percent 10 round 22: loss_train=0.9214, acc_train=0.8898, loss_test=0.0077, acc_test=0.9985
# poison_percent 10 round 23: loss_train=0.9202, acc_train=0.8905, loss_test=0.0076, acc_test=0.9985
# poison_percent 10 round 24: loss_train=0.9457, acc_train=0.8898, loss_test=0.0075, acc_test=0.9985
# poison_percent 10 round 25: loss_train=0.9210, acc_train=0.8891, loss_test=0.0075, acc_test=0.9985
# poison_percent 10 round 26: loss_train=0.9654, acc_train=0.8887, loss_test=0.0074, acc_test=0.9985
# poison_percent 10 round 27: loss_train=0.9649, acc_train=0.8908, loss_test=0.0073, acc_test=0.9985
# poison_percent 10 round 28: loss_train=0.9469, acc_train=0.8880, loss_test=0.0073, acc_test=0.9985
# poison_percent 10 round 29: loss_train=0.9514, acc_train=0.8894, loss_test=0.0072, acc_test=0.9985
# poison_percent 10 round 30: loss_train=0.9482, acc_train=0.8905, loss_test=0.0071, acc_test=0.9985
# poison_percent 10 round 31: loss_train=0.9371, acc_train=0.8901, loss_test=0.0071, acc_test=0.9985
# poison_percent 10 round 32: loss_train=0.9708, acc_train=0.8887, loss_test=0.0070, acc_test=0.9985
# poison_percent 10 round 33: loss_train=0.9434, acc_train=0.8911, loss_test=0.0069, acc_test=0.9985
# poison_percent 10 round 34: loss_train=0.9628, acc_train=0.8894, loss_test=0.0069, acc_test=0.9985
# poison_percent 10 round 35: loss_train=0.9701, acc_train=0.8922, loss_test=0.0068, acc_test=0.9985
# poison_percent 10 round 36: loss_train=0.9763, acc_train=0.8905, loss_test=0.0068, acc_test=0.9985
# poison_percent 10 round 37: loss_train=0.9953, acc_train=0.8898, loss_test=0.0067, acc_test=0.9985
# poison_percent 10 round 38: loss_train=0.9969, acc_train=0.8891, loss_test=0.0067, acc_test=0.9985
# poison_percent 10 round 39: loss_train=1.0087, acc_train=0.8874, loss_test=0.0066, acc_test=0.9985
# poison_percent 10 round 40: loss_train=1.0092, acc_train=0.8884, loss_test=0.0066, acc_test=0.9985
# poison_percent 10 round 41: loss_train=0.9841, acc_train=0.8884, loss_test=0.0065, acc_test=0.9985
# poison_percent 10 round 42: loss_train=0.9892, acc_train=0.8891, loss_test=0.0064, acc_test=0.9985
# poison_percent 10 round 43: loss_train=1.0207, acc_train=0.8894, loss_test=0.0064, acc_test=0.9990
# poison_percent 10 round 44: loss_train=1.0178, acc_train=0.8880, loss_test=0.0063, acc_test=0.9990
# poison_percent 10 round 45: loss_train=1.0126, acc_train=0.8884, loss_test=0.0063, acc_test=0.9990
# poison_percent 10 round 46: loss_train=1.0086, acc_train=0.8891, loss_test=0.0063, acc_test=0.9990
# poison_percent 10 round 47: loss_train=1.0602, acc_train=0.8874, loss_test=0.0062, acc_test=0.9990
# poison_percent 10 round 48: loss_train=1.0345, acc_train=0.8874, loss_test=0.0062, acc_test=0.9990
# poison_percent 10 round 49: loss_train=1.0388, acc_train=0.8894, loss_test=0.0061, acc_test=0.9990
# poison_percent 10 round 50: loss_train=1.0132, acc_train=0.8891, loss_test=0.0061, acc_test=0.9990
# poison_percent 10 round 51: loss_train=0.9971, acc_train=0.8898, loss_test=0.0060, acc_test=0.9990
# poison_percent 10 round 52: loss_train=1.0623, acc_train=0.8880, loss_test=0.0060, acc_test=0.9990
# poison_percent 10 round 53: loss_train=1.0531, acc_train=0.8894, loss_test=0.0059, acc_test=0.9990
# poison_percent 10 round 54: loss_train=1.0518, acc_train=0.8877, loss_test=0.0059, acc_test=0.9990
# poison_percent 10 round 55: loss_train=1.0444, acc_train=0.8887, loss_test=0.0059, acc_test=0.9990
# poison_percent 10 round 56: loss_train=1.0291, acc_train=0.8880, loss_test=0.0058, acc_test=0.9990
# poison_percent 10 round 57: loss_train=1.0425, acc_train=0.8887, loss_test=0.0058, acc_test=0.9990
# poison_percent 10 round 58: loss_train=1.0559, acc_train=0.8884, loss_test=0.0057, acc_test=0.9990
# poison_percent 10 round 59: loss_train=1.0422, acc_train=0.8887, loss_test=0.0057, acc_test=0.9990
# poison_percent 10 round 60: loss_train=1.0767, acc_train=0.8898, loss_test=0.0057, acc_test=0.9990
# poison_percent 10 round 61: loss_train=1.0795, acc_train=0.8884, loss_test=0.0056, acc_test=0.9990
# poison_percent 10 round 62: loss_train=1.0725, acc_train=0.8915, loss_test=0.0056, acc_test=0.9990
# poison_percent 10 round 63: loss_train=1.0498, acc_train=0.8877, loss_test=0.0056, acc_test=0.9990
# poison_percent 10 round 64: loss_train=1.1010, acc_train=0.8887, loss_test=0.0055, acc_test=0.9990
# poison_percent 10 round 65: loss_train=1.1074, acc_train=0.8905, loss_test=0.0055, acc_test=0.9990
# poison_percent 10 round 66: loss_train=1.0755, acc_train=0.8894, loss_test=0.0055, acc_test=0.9990
# poison_percent 10 round 67: loss_train=1.0939, acc_train=0.8877, loss_test=0.0054, acc_test=0.9990
# poison_percent 10 round 68: loss_train=1.0624, acc_train=0.8894, loss_test=0.0054, acc_test=0.9990
# poison_percent 10 round 69: loss_train=1.0773, acc_train=0.8891, loss_test=0.0054, acc_test=0.9990
# poison_percent 10 round 70: loss_train=1.1168, acc_train=0.8880, loss_test=0.0053, acc_test=0.9990
# poison_percent 10 round 71: loss_train=1.0887, acc_train=0.8884, loss_test=0.0053, acc_test=0.9990
# poison_percent 10 round 72: loss_train=1.0783, acc_train=0.8901, loss_test=0.0053, acc_test=0.9990
# poison_percent 10 round 73: loss_train=1.0898, acc_train=0.8884, loss_test=0.0052, acc_test=0.9990
# poison_percent 10 round 74: loss_train=1.1081, acc_train=0.8905, loss_test=0.0052, acc_test=0.9990
# poison_percent 10 round 75: loss_train=1.0841, acc_train=0.8887, loss_test=0.0052, acc_test=0.9990
# poison_percent 10 round 76: loss_train=1.1246, acc_train=0.8891, loss_test=0.0052, acc_test=0.9990
# poison_percent 10 round 77: loss_train=1.1181, acc_train=0.8884, loss_test=0.0051, acc_test=0.9990
# poison_percent 10 round 78: loss_train=1.1347, acc_train=0.8880, loss_test=0.0051, acc_test=0.9990
# poison_percent 10 round 79: loss_train=1.1241, acc_train=0.8918, loss_test=0.0051, acc_test=0.9990
# poison_percent 10 round 80: loss_train=1.0981, acc_train=0.8898, loss_test=0.0051, acc_test=0.9990
# poison_percent 10 round 81: loss_train=1.1182, acc_train=0.8891, loss_test=0.0050, acc_test=0.9990
# poison_percent 10 round 82: loss_train=1.0955, acc_train=0.8901, loss_test=0.0050, acc_test=0.9990
# poison_percent 10 round 83: loss_train=1.1500, acc_train=0.8908, loss_test=0.0050, acc_test=0.9990
# poison_percent 10 round 84: loss_train=1.1307, acc_train=0.8887, loss_test=0.0050, acc_test=0.9990
# poison_percent 10 round 85: loss_train=1.1623, acc_train=0.8880, loss_test=0.0049, acc_test=0.9990
# poison_percent 10 round 86: loss_train=1.1645, acc_train=0.8874, loss_test=0.0049, acc_test=0.9990
# poison_percent 10 round 87: loss_train=1.1713, acc_train=0.8891, loss_test=0.0049, acc_test=0.9990
# poison_percent 10 round 88: loss_train=1.1241, acc_train=0.8915, loss_test=0.0049, acc_test=0.9990
# poison_percent 10 round 89: loss_train=1.1804, acc_train=0.8891, loss_test=0.0048, acc_test=0.9990
# poison_percent 10 round 90: loss_train=1.1344, acc_train=0.8898, loss_test=0.0048, acc_test=0.9990
# poison_percent 10 round 91: loss_train=1.1769, acc_train=0.8898, loss_test=0.0048, acc_test=0.9990
# poison_percent 10 round 92: loss_train=1.1617, acc_train=0.8905, loss_test=0.0048, acc_test=0.9990
# poison_percent 10 round 93: loss_train=1.1590, acc_train=0.8884, loss_test=0.0047, acc_test=0.9990
# poison_percent 10 round 94: loss_train=1.1451, acc_train=0.8891, loss_test=0.0047, acc_test=0.9990
# poison_percent 10 round 95: loss_train=1.1630, acc_train=0.8901, loss_test=0.0047, acc_test=0.9990
# poison_percent 10 round 96: loss_train=1.1525, acc_train=0.8891, loss_test=0.0047, acc_test=0.9990
# poison_percent 10 round 97: loss_train=1.1589, acc_train=0.8908, loss_test=0.0047, acc_test=0.9990
# poison_percent 10 round 98: loss_train=1.1550, acc_train=0.8905, loss_test=0.0046, acc_test=0.9990
# poison_percent 10 round 99: loss_train=1.1620, acc_train=0.8898, loss_test=0.0046, acc_test=0.9990
# Training log saved to ./results\FL_ModelN1L1_Batchsize32_rev0\poisoned_10percent\poisoned_10percent.csv
# poison_percent 20 round 0: loss_train=2.1722, acc_train=0.7985, loss_test=0.0046, acc_test=0.9990
# poison_percent 20 round 1: loss_train=2.1664, acc_train=0.7978, loss_test=0.0046, acc_test=0.9990
# poison_percent 20 round 2: loss_train=2.2215, acc_train=0.7982, loss_test=0.0046, acc_test=0.9990
# poison_percent 20 round 3: loss_train=2.1732, acc_train=0.7969, loss_test=0.0046, acc_test=0.9990
# poison_percent 20 round 4: loss_train=2.1836, acc_train=0.7975, loss_test=0.0046, acc_test=0.9990
# poison_percent 20 round 5: loss_train=2.1813, acc_train=0.7978, loss_test=0.0045, acc_test=0.9990
# poison_percent 20 round 6: loss_train=2.2549, acc_train=0.7978, loss_test=0.0045, acc_test=0.9990
# poison_percent 20 round 7: loss_train=2.2322, acc_train=0.7975, loss_test=0.0045, acc_test=0.9990
# poison_percent 20 round 8: loss_train=2.2117, acc_train=0.7988, loss_test=0.0045, acc_test=0.9990
# poison_percent 20 round 9: loss_train=2.2182, acc_train=0.7997, loss_test=0.0045, acc_test=0.9990
# poison_percent 20 round 10: loss_train=2.2015, acc_train=0.7972, loss_test=0.0045, acc_test=0.9990
# poison_percent 20 round 11: loss_train=2.1951, acc_train=0.7975, loss_test=0.0045, acc_test=0.9990
# poison_percent 20 round 12: loss_train=2.2342, acc_train=0.7985, loss_test=0.0044, acc_test=0.9990
# poison_percent 20 round 13: loss_train=2.2257, acc_train=0.7972, loss_test=0.0044, acc_test=0.9990
# poison_percent 20 round 14: loss_train=2.1928, acc_train=0.7963, loss_test=0.0044, acc_test=0.9990
# poison_percent 20 round 15: loss_train=2.2529, acc_train=0.7972, loss_test=0.0044, acc_test=0.9990
# poison_percent 20 round 16: loss_train=2.2380, acc_train=0.7969, loss_test=0.0044, acc_test=0.9990
# poison_percent 20 round 17: loss_train=2.2543, acc_train=0.7960, loss_test=0.0044, acc_test=0.9990
# poison_percent 20 round 18: loss_train=2.2545, acc_train=0.7963, loss_test=0.0044, acc_test=0.9990
# poison_percent 20 round 19: loss_train=2.2177, acc_train=0.8000, loss_test=0.0043, acc_test=0.9990
# poison_percent 20 round 20: loss_train=2.2600, acc_train=0.7982, loss_test=0.0043, acc_test=0.9990
# poison_percent 20 round 21: loss_train=2.2442, acc_train=0.7969, loss_test=0.0043, acc_test=0.9990
# poison_percent 20 round 22: loss_train=2.2709, acc_train=0.7966, loss_test=0.0043, acc_test=0.9990
# poison_percent 20 round 23: loss_train=2.2437, acc_train=0.7982, loss_test=0.0043, acc_test=0.9990
# poison_percent 20 round 24: loss_train=2.2147, acc_train=0.7988, loss_test=0.0043, acc_test=0.9990
# poison_percent 20 round 25: loss_train=2.2403, acc_train=0.7982, loss_test=0.0043, acc_test=0.9990
# poison_percent 20 round 26: loss_train=2.2827, acc_train=0.7975, loss_test=0.0042, acc_test=0.9990
# poison_percent 20 round 27: loss_train=2.2179, acc_train=0.7985, loss_test=0.0042, acc_test=0.9990
# poison_percent 20 round 28: loss_train=2.2394, acc_train=0.7978, loss_test=0.0042, acc_test=0.9990
# poison_percent 20 round 29: loss_train=2.2687, acc_train=0.7966, loss_test=0.0042, acc_test=0.9990
# poison_percent 20 round 30: loss_train=2.2512, acc_train=0.7978, loss_test=0.0042, acc_test=0.9990
# poison_percent 20 round 31: loss_train=2.2961, acc_train=0.7975, loss_test=0.0042, acc_test=0.9990
# poison_percent 20 round 32: loss_train=2.2872, acc_train=0.7982, loss_test=0.0042, acc_test=0.9990
# poison_percent 20 round 33: loss_train=2.2542, acc_train=0.7978, loss_test=0.0042, acc_test=0.9990
# poison_percent 20 round 34: loss_train=2.2804, acc_train=0.7957, loss_test=0.0041, acc_test=0.9990
# poison_percent 20 round 35: loss_train=2.3005, acc_train=0.7978, loss_test=0.0041, acc_test=0.9990
# poison_percent 20 round 36: loss_train=2.2883, acc_train=0.7960, loss_test=0.0041, acc_test=0.9990
# poison_percent 20 round 37: loss_train=2.3119, acc_train=0.7982, loss_test=0.0041, acc_test=0.9990
# poison_percent 20 round 38: loss_train=2.2860, acc_train=0.7963, loss_test=0.0041, acc_test=0.9990
# poison_percent 20 round 39: loss_train=2.3037, acc_train=0.7994, loss_test=0.0041, acc_test=0.9990
# poison_percent 20 round 40: loss_train=2.2873, acc_train=0.7972, loss_test=0.0041, acc_test=0.9990
# poison_percent 20 round 41: loss_train=2.3186, acc_train=0.7969, loss_test=0.0041, acc_test=0.9990
# poison_percent 20 round 42: loss_train=2.2666, acc_train=0.7972, loss_test=0.0041, acc_test=0.9990
# poison_percent 20 round 43: loss_train=2.2757, acc_train=0.7975, loss_test=0.0040, acc_test=0.9990
# poison_percent 20 round 44: loss_train=2.3154, acc_train=0.7957, loss_test=0.0040, acc_test=0.9990
# poison_percent 20 round 45: loss_train=2.3352, acc_train=0.7954, loss_test=0.0040, acc_test=0.9990
# poison_percent 20 round 46: loss_train=2.3427, acc_train=0.7972, loss_test=0.0040, acc_test=0.9990
# poison_percent 20 round 47: loss_train=2.3329, acc_train=0.7975, loss_test=0.0040, acc_test=0.9990
# poison_percent 20 round 48: loss_train=2.3308, acc_train=0.7988, loss_test=0.0040, acc_test=0.9990
# poison_percent 20 round 49: loss_train=2.3418, acc_train=0.7978, loss_test=0.0040, acc_test=0.9990
# poison_percent 20 round 50: loss_train=2.3375, acc_train=0.7969, loss_test=0.0040, acc_test=0.9985
# poison_percent 20 round 51: loss_train=2.3294, acc_train=0.7988, loss_test=0.0040, acc_test=0.9985
# poison_percent 20 round 52: loss_train=2.2969, acc_train=0.7972, loss_test=0.0039, acc_test=0.9985
# poison_percent 20 round 53: loss_train=2.3411, acc_train=0.7975, loss_test=0.0039, acc_test=0.9985
# poison_percent 20 round 54: loss_train=2.3225, acc_train=0.7985, loss_test=0.0039, acc_test=0.9985
# poison_percent 20 round 55: loss_train=2.2846, acc_train=0.7994, loss_test=0.0039, acc_test=0.9985
# poison_percent 20 round 56: loss_train=2.3493, acc_train=0.7972, loss_test=0.0039, acc_test=0.9985
# poison_percent 20 round 57: loss_train=2.3346, acc_train=0.7960, loss_test=0.0039, acc_test=0.9985
# poison_percent 20 round 58: loss_train=2.3544, acc_train=0.7972, loss_test=0.0039, acc_test=0.9985
# poison_percent 20 round 59: loss_train=2.3493, acc_train=0.7978, loss_test=0.0039, acc_test=0.9985
# poison_percent 20 round 60: loss_train=2.3680, acc_train=0.7988, loss_test=0.0039, acc_test=0.9985
# poison_percent 20 round 61: loss_train=2.3266, acc_train=0.7982, loss_test=0.0039, acc_test=0.9985
# poison_percent 20 round 62: loss_train=2.3483, acc_train=0.7985, loss_test=0.0038, acc_test=0.9985
# poison_percent 20 round 63: loss_train=2.3324, acc_train=0.7978, loss_test=0.0038, acc_test=0.9985
# poison_percent 20 round 64: loss_train=2.3526, acc_train=0.7994, loss_test=0.0038, acc_test=0.9985
# poison_percent 20 round 65: loss_train=2.3451, acc_train=0.7969, loss_test=0.0038, acc_test=0.9985
# poison_percent 20 round 66: loss_train=2.3998, acc_train=0.7960, loss_test=0.0038, acc_test=0.9985
# poison_percent 20 round 67: loss_train=2.3310, acc_train=0.7985, loss_test=0.0038, acc_test=0.9985
# poison_percent 20 round 68: loss_train=2.3440, acc_train=0.7969, loss_test=0.0038, acc_test=0.9985
# poison_percent 20 round 69: loss_train=2.3869, acc_train=0.7978, loss_test=0.0038, acc_test=0.9985
# poison_percent 20 round 70: loss_train=2.3533, acc_train=0.7972, loss_test=0.0038, acc_test=0.9985
# poison_percent 20 round 71: loss_train=2.3923, acc_train=0.7972, loss_test=0.0038, acc_test=0.9985
# poison_percent 20 round 72: loss_train=2.3987, acc_train=0.7972, loss_test=0.0037, acc_test=0.9985
# poison_percent 20 round 73: loss_train=2.4098, acc_train=0.7994, loss_test=0.0037, acc_test=0.9985
# poison_percent 20 round 74: loss_train=2.3720, acc_train=0.7985, loss_test=0.0037, acc_test=0.9985
# poison_percent 20 round 75: loss_train=2.3755, acc_train=0.7982, loss_test=0.0037, acc_test=0.9985
# poison_percent 20 round 76: loss_train=2.3849, acc_train=0.7978, loss_test=0.0037, acc_test=0.9985
# poison_percent 20 round 77: loss_train=2.4078, acc_train=0.7982, loss_test=0.0037, acc_test=0.9985
# poison_percent 20 round 78: loss_train=2.4097, acc_train=0.7985, loss_test=0.0037, acc_test=0.9985
# poison_percent 20 round 79: loss_train=2.3761, acc_train=0.7994, loss_test=0.0037, acc_test=0.9985
# poison_percent 20 round 80: loss_train=2.3906, acc_train=0.7988, loss_test=0.0037, acc_test=0.9985
# poison_percent 20 round 81: loss_train=2.4451, acc_train=0.7978, loss_test=0.0037, acc_test=0.9985
# poison_percent 20 round 82: loss_train=2.3896, acc_train=0.7988, loss_test=0.0037, acc_test=0.9985
# poison_percent 20 round 83: loss_train=2.4015, acc_train=0.7991, loss_test=0.0037, acc_test=0.9985
# poison_percent 20 round 84: loss_train=2.4035, acc_train=0.7972, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 85: loss_train=2.3844, acc_train=0.7994, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 86: loss_train=2.4214, acc_train=0.7988, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 87: loss_train=2.3845, acc_train=0.7997, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 88: loss_train=2.4301, acc_train=0.7972, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 89: loss_train=2.3978, acc_train=0.7966, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 90: loss_train=2.4384, acc_train=0.7982, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 91: loss_train=2.4348, acc_train=0.7982, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 92: loss_train=2.4267, acc_train=0.7985, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 93: loss_train=2.4323, acc_train=0.7985, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 94: loss_train=2.3999, acc_train=0.7988, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 95: loss_train=2.4445, acc_train=0.7988, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 96: loss_train=2.4214, acc_train=0.7997, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 97: loss_train=2.4839, acc_train=0.7972, loss_test=0.0036, acc_test=0.9985
# poison_percent 20 round 98: loss_train=2.3928, acc_train=0.7978, loss_test=0.0035, acc_test=0.9985
# poison_percent 20 round 99: loss_train=2.4498, acc_train=0.7966, loss_test=0.0035, acc_test=0.9985
# Training log saved to ./results\FL_ModelN1L1_Batchsize32_rev0\poisoned_20percent\poisoned_20percent.csv
# poison_percent 30 round 0: loss_train=3.6978, acc_train=0.6958, loss_test=0.0035, acc_test=0.9985
# poison_percent 30 round 1: loss_train=3.6929, acc_train=0.6977, loss_test=0.0035, acc_test=0.9985
# poison_percent 30 round 2: loss_train=3.7056, acc_train=0.6985, loss_test=0.0035, acc_test=0.9985
# poison_percent 30 round 3: loss_train=3.6927, acc_train=0.6971, loss_test=0.0035, acc_test=0.9985
# poison_percent 30 round 4: loss_train=3.7244, acc_train=0.6980, loss_test=0.0035, acc_test=0.9985
# poison_percent 30 round 5: loss_train=3.6623, acc_train=0.6969, loss_test=0.0035, acc_test=0.9985
# poison_percent 30 round 6: loss_train=3.6883, acc_train=0.6980, loss_test=0.0035, acc_test=0.9985
# poison_percent 30 round 7: loss_train=3.7476, acc_train=0.6974, loss_test=0.0035, acc_test=0.9985
# poison_percent 30 round 8: loss_train=3.7057, acc_train=0.6985, loss_test=0.0035, acc_test=0.9985
# poison_percent 30 round 9: loss_train=3.7299, acc_train=0.6974, loss_test=0.0034, acc_test=0.9985
# poison_percent 30 round 10: loss_train=3.7009, acc_train=0.6974, loss_test=0.0034, acc_test=0.9985
# poison_percent 30 round 11: loss_train=3.6703, acc_train=0.6980, loss_test=0.0034, acc_test=0.9985
# poison_percent 30 round 12: loss_train=3.6966, acc_train=0.6982, loss_test=0.0034, acc_test=0.9985
# poison_percent 30 round 13: loss_train=3.7114, acc_train=0.6990, loss_test=0.0034, acc_test=0.9985
# poison_percent 30 round 14: loss_train=3.7067, acc_train=0.6963, loss_test=0.0034, acc_test=0.9985
# poison_percent 30 round 15: loss_train=3.6735, acc_train=0.6982, loss_test=0.0034, acc_test=0.9985
# poison_percent 30 round 16: loss_train=3.7226, acc_train=0.6980, loss_test=0.0034, acc_test=0.9985
# poison_percent 30 round 17: loss_train=3.7566, acc_train=0.6974, loss_test=0.0034, acc_test=0.9985
# poison_percent 30 round 18: loss_train=3.7352, acc_train=0.6985, loss_test=0.0034, acc_test=0.9985
# poison_percent 30 round 19: loss_train=3.6821, acc_train=0.6980, loss_test=0.0034, acc_test=0.9985
# poison_percent 30 round 20: loss_train=3.7192, acc_train=0.6988, loss_test=0.0034, acc_test=0.9985
# poison_percent 30 round 21: loss_train=3.7352, acc_train=0.6971, loss_test=0.0033, acc_test=0.9985
# poison_percent 30 round 22: loss_train=3.7104, acc_train=0.6993, loss_test=0.0033, acc_test=0.9985
# poison_percent 30 round 23: loss_train=3.7248, acc_train=0.6963, loss_test=0.0033, acc_test=0.9985
# poison_percent 30 round 24: loss_train=3.6861, acc_train=0.6966, loss_test=0.0033, acc_test=0.9985
# poison_percent 30 round 25: loss_train=3.7416, acc_train=0.6971, loss_test=0.0033, acc_test=0.9985
# poison_percent 30 round 26: loss_train=3.6920, acc_train=0.6985, loss_test=0.0033, acc_test=0.9985
# poison_percent 30 round 27: loss_train=3.7481, acc_train=0.6974, loss_test=0.0033, acc_test=0.9985
# poison_percent 30 round 28: loss_train=3.7186, acc_train=0.6982, loss_test=0.0033, acc_test=0.9985
# poison_percent 30 round 29: loss_train=3.7199, acc_train=0.6977, loss_test=0.0033, acc_test=0.9985
# poison_percent 30 round 30: loss_train=3.7397, acc_train=0.6969, loss_test=0.0033, acc_test=0.9985
# poison_percent 30 round 31: loss_train=3.7331, acc_train=0.6980, loss_test=0.0033, acc_test=0.9985
# poison_percent 30 round 32: loss_train=3.7063, acc_train=0.6971, loss_test=0.0033, acc_test=0.9985
# poison_percent 30 round 33: loss_train=3.7416, acc_train=0.6980, loss_test=0.0033, acc_test=0.9985
# poison_percent 30 round 34: loss_train=3.7440, acc_train=0.6982, loss_test=0.0033, acc_test=0.9985
# poison_percent 30 round 35: loss_train=3.7322, acc_train=0.6982, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 36: loss_train=3.7449, acc_train=0.6980, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 37: loss_train=3.7548, acc_train=0.6969, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 38: loss_train=3.7150, acc_train=0.6963, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 39: loss_train=3.7128, acc_train=0.6980, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 40: loss_train=3.7251, acc_train=0.6982, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 41: loss_train=3.7112, acc_train=0.6974, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 42: loss_train=3.7251, acc_train=0.6982, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 43: loss_train=3.7245, acc_train=0.6977, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 44: loss_train=3.7276, acc_train=0.6980, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 45: loss_train=3.7150, acc_train=0.6974, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 46: loss_train=3.7130, acc_train=0.6977, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 47: loss_train=3.7386, acc_train=0.6988, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 48: loss_train=3.7748, acc_train=0.6990, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 49: loss_train=3.7373, acc_train=0.6969, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 50: loss_train=3.7168, acc_train=0.6982, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 51: loss_train=3.7358, acc_train=0.6966, loss_test=0.0032, acc_test=0.9985
# poison_percent 30 round 52: loss_train=3.7780, acc_train=0.6974, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 53: loss_train=3.7942, acc_train=0.6982, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 54: loss_train=3.7758, acc_train=0.6971, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 55: loss_train=3.7733, acc_train=0.6977, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 56: loss_train=3.7608, acc_train=0.6974, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 57: loss_train=3.7489, acc_train=0.6971, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 58: loss_train=3.7255, acc_train=0.6980, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 59: loss_train=3.7438, acc_train=0.6990, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 60: loss_train=3.7121, acc_train=0.6996, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 61: loss_train=3.7451, acc_train=0.6971, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 62: loss_train=3.7383, acc_train=0.6982, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 63: loss_train=3.7577, acc_train=0.6996, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 64: loss_train=3.7250, acc_train=0.7004, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 65: loss_train=3.7773, acc_train=0.6974, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 66: loss_train=3.7364, acc_train=0.6980, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 67: loss_train=3.7761, acc_train=0.6985, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 68: loss_train=3.7301, acc_train=0.6985, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 69: loss_train=3.7825, acc_train=0.6985, loss_test=0.0031, acc_test=0.9985
# poison_percent 30 round 70: loss_train=3.7581, acc_train=0.6988, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 71: loss_train=3.7806, acc_train=0.6985, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 72: loss_train=3.7612, acc_train=0.6988, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 73: loss_train=3.7655, acc_train=0.6982, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 74: loss_train=3.7890, acc_train=0.6971, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 75: loss_train=3.7932, acc_train=0.6977, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 76: loss_train=3.7617, acc_train=0.6974, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 77: loss_train=3.7826, acc_train=0.6988, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 78: loss_train=3.8026, acc_train=0.6974, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 79: loss_train=3.7858, acc_train=0.6971, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 80: loss_train=3.7921, acc_train=0.6977, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 81: loss_train=3.7445, acc_train=0.6985, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 82: loss_train=3.7459, acc_train=0.6977, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 83: loss_train=3.7806, acc_train=0.6982, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 84: loss_train=3.7721, acc_train=0.6974, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 85: loss_train=3.7878, acc_train=0.6990, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 86: loss_train=3.7722, acc_train=0.6980, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 87: loss_train=3.7497, acc_train=0.6974, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 88: loss_train=3.7811, acc_train=0.6980, loss_test=0.0030, acc_test=0.9985
# poison_percent 30 round 89: loss_train=3.7926, acc_train=0.6980, loss_test=0.0029, acc_test=0.9985
# poison_percent 30 round 90: loss_train=3.8033, acc_train=0.6980, loss_test=0.0029, acc_test=0.9985
# poison_percent 30 round 91: loss_train=3.8059, acc_train=0.6982, loss_test=0.0029, acc_test=0.9985
# poison_percent 30 round 92: loss_train=3.7874, acc_train=0.6977, loss_test=0.0029, acc_test=0.9985
# poison_percent 30 round 93: loss_train=3.7943, acc_train=0.6990, loss_test=0.0029, acc_test=0.9985
# poison_percent 30 round 94: loss_train=3.8075, acc_train=0.6982, loss_test=0.0029, acc_test=0.9985
# poison_percent 30 round 95: loss_train=3.7932, acc_train=0.6980, loss_test=0.0029, acc_test=0.9985
# poison_percent 30 round 96: loss_train=3.8202, acc_train=0.6988, loss_test=0.0029, acc_test=0.9985
# poison_percent 30 round 97: loss_train=3.8000, acc_train=0.6988, loss_test=0.0029, acc_test=0.9985
# poison_percent 30 round 98: loss_train=3.7703, acc_train=0.6985, loss_test=0.0029, acc_test=0.9985
# poison_percent 30 round 99: loss_train=3.8164, acc_train=0.6998, loss_test=0.0029, acc_test=0.9985
# Training log saved to ./results\FL_ModelN1L1_Batchsize32_rev0\poisoned_30percent\poisoned_30percent.csv
# poison_percent 40 round 0: loss_train=5.0982, acc_train=0.5986, loss_test=0.0029, acc_test=0.9985
# poison_percent 40 round 1: loss_train=5.0621, acc_train=0.5977, loss_test=0.0029, acc_test=0.9985
# poison_percent 40 round 2: loss_train=5.0373, acc_train=0.5981, loss_test=0.0029, acc_test=0.9985
# poison_percent 40 round 3: loss_train=5.0725, acc_train=0.5981, loss_test=0.0029, acc_test=0.9985
# poison_percent 40 round 4: loss_train=5.0793, acc_train=0.5977, loss_test=0.0029, acc_test=0.9985
# poison_percent 40 round 5: loss_train=5.0273, acc_train=0.5981, loss_test=0.0029, acc_test=0.9985
# poison_percent 40 round 6: loss_train=5.0716, acc_train=0.5974, loss_test=0.0029, acc_test=0.9985
# poison_percent 40 round 7: loss_train=5.1002, acc_train=0.5983, loss_test=0.0029, acc_test=0.9985
# poison_percent 40 round 8: loss_train=5.0198, acc_train=0.5986, loss_test=0.0029, acc_test=0.9985
# poison_percent 40 round 9: loss_train=5.0855, acc_train=0.5972, loss_test=0.0029, acc_test=0.9985
# poison_percent 40 round 10: loss_train=5.0552, acc_train=0.5967, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 11: loss_train=5.0834, acc_train=0.5986, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 12: loss_train=5.0960, acc_train=0.5979, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 13: loss_train=5.0850, acc_train=0.5979, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 14: loss_train=5.0504, acc_train=0.5983, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 15: loss_train=5.0494, acc_train=0.5983, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 16: loss_train=5.0475, acc_train=0.5981, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 17: loss_train=5.0382, acc_train=0.5986, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 18: loss_train=5.0617, acc_train=0.5981, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 19: loss_train=5.0555, acc_train=0.5995, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 20: loss_train=5.0446, acc_train=0.5981, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 21: loss_train=5.0108, acc_train=0.5977, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 22: loss_train=5.0516, acc_train=0.5990, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 23: loss_train=5.0300, acc_train=0.5977, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 24: loss_train=5.0764, acc_train=0.5979, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 25: loss_train=5.0683, acc_train=0.5983, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 26: loss_train=5.0743, acc_train=0.5979, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 27: loss_train=5.0700, acc_train=0.5988, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 28: loss_train=5.0556, acc_train=0.5995, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 29: loss_train=5.0715, acc_train=0.5983, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 30: loss_train=5.0425, acc_train=0.5988, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 31: loss_train=5.0471, acc_train=0.5983, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 32: loss_train=5.0406, acc_train=0.5990, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 33: loss_train=5.0401, acc_train=0.5983, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 34: loss_train=5.0440, acc_train=0.5979, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 35: loss_train=4.9876, acc_train=0.5979, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 36: loss_train=5.0568, acc_train=0.5983, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 37: loss_train=5.1017, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 38: loss_train=5.0486, acc_train=0.5988, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 39: loss_train=5.0229, acc_train=0.5977, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 40: loss_train=5.0332, acc_train=0.5988, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 41: loss_train=5.0397, acc_train=0.5977, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 42: loss_train=5.0479, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 43: loss_train=5.0260, acc_train=0.5977, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 44: loss_train=5.0411, acc_train=0.5986, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 45: loss_train=5.0268, acc_train=0.5972, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 46: loss_train=5.0220, acc_train=0.5986, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 47: loss_train=5.0121, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 48: loss_train=4.9748, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 49: loss_train=5.0185, acc_train=0.5993, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 50: loss_train=5.0456, acc_train=0.5974, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 51: loss_train=4.9878, acc_train=0.5986, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 52: loss_train=5.0730, acc_train=0.5983, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 53: loss_train=5.0115, acc_train=0.5986, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 54: loss_train=4.9956, acc_train=0.5983, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 55: loss_train=5.0328, acc_train=0.5974, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 56: loss_train=5.0681, acc_train=0.5990, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 57: loss_train=4.9936, acc_train=0.5986, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 58: loss_train=5.0326, acc_train=0.5983, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 59: loss_train=5.0102, acc_train=0.5983, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 60: loss_train=5.0017, acc_train=0.5990, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 61: loss_train=4.9846, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 62: loss_train=4.9770, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 63: loss_train=5.0032, acc_train=0.5979, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 64: loss_train=5.0304, acc_train=0.5986, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 65: loss_train=5.0263, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 66: loss_train=5.0310, acc_train=0.5986, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 67: loss_train=4.9938, acc_train=0.5986, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 68: loss_train=5.0185, acc_train=0.5981, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 69: loss_train=4.9892, acc_train=0.5986, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 70: loss_train=5.0131, acc_train=0.5986, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 71: loss_train=4.9541, acc_train=0.5993, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 72: loss_train=5.0126, acc_train=0.5988, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 73: loss_train=5.0203, acc_train=0.5981, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 74: loss_train=5.0127, acc_train=0.5983, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 75: loss_train=4.9778, acc_train=0.5974, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 76: loss_train=5.0496, acc_train=0.5983, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 77: loss_train=4.9851, acc_train=0.5993, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 78: loss_train=5.0203, acc_train=0.5977, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 79: loss_train=5.0107, acc_train=0.5979, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 80: loss_train=4.9760, acc_train=0.5986, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 81: loss_train=4.9877, acc_train=0.5983, loss_test=0.0026, acc_test=0.9985
# ...
# poison_percent 40 round 41: loss_train=5.0031, acc_train=0.5981, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 42: loss_train=5.0423, acc_train=0.5981, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 43: loss_train=4.9850, acc_train=0.5990, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 44: loss_train=5.0239, acc_train=0.5995, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 45: loss_train=5.0141, acc_train=0.5965, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 46: loss_train=5.0098, acc_train=0.5986, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 47: loss_train=5.0439, acc_train=0.5972, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 48: loss_train=5.0423, acc_train=0.5983, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 49: loss_train=4.9693, acc_train=0.5979, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 50: loss_train=4.9877, acc_train=0.5986, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 51: loss_train=4.9777, acc_train=0.5988, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 52: loss_train=5.0244, acc_train=0.5988, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 53: loss_train=5.0182, acc_train=0.5983, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 54: loss_train=5.0378, acc_train=0.5977, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 55: loss_train=4.9763, acc_train=0.5979, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 56: loss_train=4.9594, acc_train=0.5974, loss_test=0.0028, acc_test=0.9985
# poison_percent 40 round 57: loss_train=5.0058, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 58: loss_train=5.0405, acc_train=0.5993, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 59: loss_train=5.0028, acc_train=0.5983, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 60: loss_train=5.0238, acc_train=0.5977, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 61: loss_train=4.9653, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 62: loss_train=5.0196, acc_train=0.5979, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 63: loss_train=4.9994, acc_train=0.5993, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 64: loss_train=4.9808, acc_train=0.5983, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 65: loss_train=5.0193, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 66: loss_train=5.0080, acc_train=0.5986, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 67: loss_train=5.0406, acc_train=0.5974, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 68: loss_train=4.9807, acc_train=0.5979, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 69: loss_train=5.0040, acc_train=0.5970, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 70: loss_train=4.9837, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 71: loss_train=5.0365, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 72: loss_train=5.0093, acc_train=0.5990, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 73: loss_train=5.0321, acc_train=0.5988, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 74: loss_train=4.9627, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 75: loss_train=5.0177, acc_train=0.5988, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 76: loss_train=4.9603, acc_train=0.5990, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 77: loss_train=5.0060, acc_train=0.5983, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 78: loss_train=4.9860, acc_train=0.5983, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 79: loss_train=4.9619, acc_train=0.5997, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 80: loss_train=4.9715, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 81: loss_train=4.9623, acc_train=0.5979, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 82: loss_train=4.9508, acc_train=0.5988, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 83: loss_train=4.9817, acc_train=0.5983, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 84: loss_train=5.0341, acc_train=0.5972, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 85: loss_train=4.9695, acc_train=0.5983, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 86: loss_train=4.9890, acc_train=0.5972, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 87: loss_train=4.9758, acc_train=0.5981, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 88: loss_train=5.0146, acc_train=0.5983, loss_test=0.0027, acc_test=0.9985
# poison_percent 40 round 89: loss_train=4.9968, acc_train=0.5981, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 90: loss_train=4.9727, acc_train=0.5993, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 91: loss_train=5.0228, acc_train=0.5977, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 92: loss_train=5.0012, acc_train=0.5983, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 93: loss_train=5.0000, acc_train=0.5972, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 94: loss_train=4.9743, acc_train=0.5977, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 95: loss_train=4.9743, acc_train=0.5977, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 96: loss_train=4.9917, acc_train=0.5972, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 97: loss_train=5.0043, acc_train=0.5979, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 98: loss_train=4.9492, acc_train=0.5986, loss_test=0.0026, acc_test=0.9985
# poison_percent 40 round 99: loss_train=5.0209, acc_train=0.5986, loss_test=0.0026, acc_test=0.9985
# Training log saved to ./results\FL_ModelN1L1_Batchsize32_rev2\poisoned_40percent\poisoned_40percent.csv
# poison_percent 50 round 0: loss_train=6.1699, acc_train=0.4988, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 1: loss_train=6.2085, acc_train=0.5002, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 2: loss_train=6.1597, acc_train=0.5000, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 3: loss_train=6.1922, acc_train=0.4996, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 4: loss_train=6.1424, acc_train=0.4990, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 5: loss_train=6.1319, acc_train=0.5015, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 6: loss_train=6.1628, acc_train=0.4998, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 7: loss_train=6.2060, acc_train=0.4994, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 8: loss_train=6.1067, acc_train=0.5006, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 9: loss_train=6.1665, acc_train=0.5002, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 10: loss_train=6.1005, acc_train=0.5002, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 11: loss_train=6.1488, acc_train=0.4998, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 12: loss_train=6.1140, acc_train=0.4994, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 13: loss_train=6.1247, acc_train=0.4998, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 14: loss_train=6.1690, acc_train=0.5002, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 15: loss_train=6.1042, acc_train=0.4992, loss_test=0.0026, acc_test=0.9985
# poison_percent 50 round 16: loss_train=6.1384, acc_train=0.4990, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 17: loss_train=6.1290, acc_train=0.4992, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 18: loss_train=6.0995, acc_train=0.5010, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 19: loss_train=6.1036, acc_train=0.5000, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 20: loss_train=6.0934, acc_train=0.5002, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 21: loss_train=6.0886, acc_train=0.4996, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 22: loss_train=6.0877, acc_train=0.4998, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 23: loss_train=6.0810, acc_train=0.4985, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 24: loss_train=6.1192, acc_train=0.4994, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 25: loss_train=6.0978, acc_train=0.4996, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 26: loss_train=6.0918, acc_train=0.4996, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 27: loss_train=6.0422, acc_train=0.5000, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 28: loss_train=6.0763, acc_train=0.5006, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 29: loss_train=6.0611, acc_train=0.4992, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 30: loss_train=6.0435, acc_train=0.4996, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 31: loss_train=6.0142, acc_train=0.4994, loss_test=0.0026, acc_test=0.9990
# poison_percent 50 round 32: loss_train=6.0745, acc_train=0.5000, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 33: loss_train=6.0172, acc_train=0.4996, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 34: loss_train=6.0132, acc_train=0.5002, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 35: loss_train=6.0206, acc_train=0.5010, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 36: loss_train=5.9993, acc_train=0.5000, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 37: loss_train=5.9693, acc_train=0.4996, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 38: loss_train=6.0094, acc_train=0.4990, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 39: loss_train=6.0282, acc_train=0.4996, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 40: loss_train=6.0316, acc_train=0.4996, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 41: loss_train=5.9587, acc_train=0.5004, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 42: loss_train=6.0000, acc_train=0.4996, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 43: loss_train=5.9178, acc_train=0.4988, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 44: loss_train=5.9338, acc_train=0.4998, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 45: loss_train=5.9906, acc_train=0.5008, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 46: loss_train=5.9473, acc_train=0.5000, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 47: loss_train=5.9521, acc_train=0.4996, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 48: loss_train=5.9356, acc_train=0.4990, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 49: loss_train=5.9368, acc_train=0.5004, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 50: loss_train=5.9477, acc_train=0.4998, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 51: loss_train=5.9240, acc_train=0.4996, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 52: loss_train=5.9367, acc_train=0.5008, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 53: loss_train=5.9579, acc_train=0.4996, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 54: loss_train=5.9792, acc_train=0.4996, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 55: loss_train=5.8982, acc_train=0.4998, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 56: loss_train=5.9585, acc_train=0.4985, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 57: loss_train=5.9545, acc_train=0.4996, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 58: loss_train=5.9487, acc_train=0.4990, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 59: loss_train=5.9010, acc_train=0.4996, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 60: loss_train=5.9049, acc_train=0.4996, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 61: loss_train=5.9141, acc_train=0.4994, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 62: loss_train=5.9436, acc_train=0.5002, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 63: loss_train=5.8630, acc_train=0.4994, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 64: loss_train=5.8794, acc_train=0.5000, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 65: loss_train=5.8769, acc_train=0.5006, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 66: loss_train=5.9395, acc_train=0.5000, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 67: loss_train=5.8675, acc_train=0.4988, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 68: loss_train=5.8906, acc_train=0.4996, loss_test=0.0027, acc_test=0.9990
# poison_percent 50 round 69: loss_train=5.8886, acc_train=0.5002, loss_test=0.0028, acc_test=0.9990
# poison_percent 50 round 70: loss_train=5.8610, acc_train=0.4990, loss_test=0.0028, acc_test=0.9990
# poison_percent 50 round 71: loss_train=5.8582, acc_train=0.5000, loss_test=0.0028, acc_test=0.9990
# poison_percent 50 round 72: loss_train=5.8668, acc_train=0.5000, loss_test=0.0028, acc_test=0.9990
# poison_percent 50 round 73: loss_train=5.8240, acc_train=0.4998, loss_test=0.0028, acc_test=0.9990
# poison_percent 50 round 74: loss_train=5.8275, acc_train=0.4996, loss_test=0.0028, acc_test=0.9990
# poison_percent 50 round 75: loss_train=5.8092, acc_train=0.4994, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 76: loss_train=5.8580, acc_train=0.4996, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 77: loss_train=5.8212, acc_train=0.4992, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 78: loss_train=5.8285, acc_train=0.5004, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 79: loss_train=5.8291, acc_train=0.4992, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 80: loss_train=5.8150, acc_train=0.5004, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 81: loss_train=5.8254, acc_train=0.4996, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 82: loss_train=5.7915, acc_train=0.4994, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 83: loss_train=5.7750, acc_train=0.4998, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 84: loss_train=5.7828, acc_train=0.5002, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 85: loss_train=5.8046, acc_train=0.4992, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 86: loss_train=5.7722, acc_train=0.4992, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 87: loss_train=5.8149, acc_train=0.5006, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 88: loss_train=5.7599, acc_train=0.5008, loss_test=0.0028, acc_test=0.9985
# poison_percent 50 round 89: loss_train=5.7753, acc_train=0.4994, loss_test=0.0029, acc_test=0.9985
# poison_percent 50 round 90: loss_train=5.7411, acc_train=0.4994, loss_test=0.0029, acc_test=0.9985
# poison_percent 50 round 91: loss_train=5.7980, acc_train=0.5000, loss_test=0.0029, acc_test=0.9985
# poison_percent 50 round 92: loss_train=5.7628, acc_train=0.4998, loss_test=0.0029, acc_test=0.9985
# poison_percent 50 round 93: loss_train=5.7755, acc_train=0.4996, loss_test=0.0029, acc_test=0.9990
# poison_percent 50 round 94: loss_train=5.7412, acc_train=0.4994, loss_test=0.0029, acc_test=0.9990
# poison_percent 50 round 95: loss_train=5.6974, acc_train=0.5000, loss_test=0.0029, acc_test=0.9990
# poison_percent 50 round 96: loss_train=5.7198, acc_train=0.4992, loss_test=0.0029, acc_test=0.9990
# poison_percent 50 round 97: loss_train=5.7045, acc_train=0.4994, loss_test=0.0029, acc_test=0.9990
# poison_percent 50 round 98: loss_train=5.7484, acc_train=0.4992, loss_test=0.0029, acc_test=0.9990
# poison_percent 50 round 99: loss_train=5.7053, acc_train=0.5002, loss_test=0.0029, acc_test=0.9990
# Training log saved to ./results\FL_ModelN1L1_Batchsize32_rev2\poisoned_50percent\poisoned_50percent.csv
